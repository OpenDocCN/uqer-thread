# %% [markdown]
# # 数据获取以及转存

# %% [markdown]
# 1. 获取数据
# --------------------
# ***

# %% [markdown]
# 我们提供了``DataAPI``帮助你获取各种行情，基本面数据。

# %%
data = DataAPI.MktEqudAdjGet(ticker = '600000')

# %%
data.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <mercury-input-3-8453368af19f> in <module>()
# ----> 1 data.tail()
#
# NameError: name 'data' is not defined

# %% [markdown]
# 2. 存储数据
# ------------------
# ***

# %% [markdown]
# 数据保存只需要一行代码：（可以储存为``.csv``或者``.xlsx``格式，分别通过``to_csv``和``to_excel``方法）

# %%
data.to_csv(u'spd_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <mercury-input-1-ce81392b8821> in <module>()
# ----> 1 data.to_csv(u'spd_data.csv')
#
# NameError: name 'data' is not defined

# %% [markdown]
# 接着就可以在你的``data``页下看到你保存的数据。

# %% [markdown]
# ![image](http://ww2.sinaimg.cn/large/63ef6a8dgw1es8b86zblyj21g30oswpx.jpg)

# %% [markdown]
# 3. 数据下载
# -------------------
# ***

# %% [markdown]
# 所有在``Data``页面下的数据都可以通过点击下载图标下载至本地：

# %% [markdown]
# ![](http://ww3.sinaimg.cn/large/63ef6a8dgw1esjqoz3ujkj20ej0rv77o.jpg)

# %% [markdown]
# 4. 数据上传
# -------------------------
# ***

# %% [markdown]
# 数据上传可以通过``Data``页面下的``上传``按钮完成：

# %% [markdown]
# ![](http://ww1.sinaimg.cn/large/63ef6a8dgw1esjqtvtyurj20cc0a63zw.jpg)

# %% [markdown]
# 上传完成后的数据会在``Data``页面下显示，然后在我们的环境中当作本地文件读入，例如：

# %%
import pandas as pd
data = pd.read_excel(u'alpha基金数据.xlsx')

# %%
data.head()
# Out:
#          secID  ticker exchangeCD secShortName secShortNameEn   tradeDate  \
# 0  600000.XSHG  600000       XSHG         浦发银行       SPD Bank  2006-01-04
# 1  600000.XSHG  600000       XSHG         浦发银行       SPD Bank  2006-01-05
# 2  600000.XSHG  600000       XSHG         浦发银行       SPD Bank  2006-01-06
# 3  600000.XSHG  600000       XSHG         浦发银行       SPD Bank  2006-01-09
# 4  600000.XSHG  600000       XSHG         浦发银行       SPD Bank  2006-01-10
#
#    preClosePrice  openPrice  highestPrice  lowestPrice  closePrice  \
# 0          1.888      1.901         1.990        1.897       1.985
# 1          1.985      1.985         2.033        1.967       2.017
# 2          2.017      2.014         2.097        1.994       2.076
# 3          2.076      2.081         2.083        2.021       2.050
# 4          2.050      2.048         2.081        1.996       2.056
#
#    turnoverVol  turnoverValue
# 0     16333311      165103152
# 1     17738144      182986496
# 2     18643248      197474272
# 3     16893784      178273616
# 4     14359288      150867104
