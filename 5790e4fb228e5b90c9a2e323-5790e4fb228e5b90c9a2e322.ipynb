# %% [markdown]
# #

# %% [raw]
# import quartz
# from CAL.PyCAL import *
# import numpy as np
# start = '2016-01-01'                       # 回测起始时间
# end = '2016-07-19'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe=universe = set_universe('SH50')+['600007.XSHG','600004.XSHG','600028.XSHG','600050.XSHG','600016.XSHG','600018.XSHG','600085.XSHG','600654.XSHG','600031.XSHG','600030.XSHG'\
# '000157.XSZG','000651.XSZG','000063.XSZG']
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 5                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# cal=Calendar('China.SSE')
# from matplotlib import pylab
# import seaborn as sns
#
# #DataAPI.settings.cache_enabled = True
#
# def initialize(account):                   # 初始化虚拟账户状态
#     account.mairushijian={}
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     buylist=[]
#     sellist=[]
#     last10day=cal.advanceDate(account.previous_date,'-10B')
#     STlist = DataAPI.SecSTGet(secID=universe, beginDate=account.previous_date, endDate=account.previous_date, field=['secID'],pandas='1')['secID'].tolist()
#     #ST列表
#     stocklist=[s for s in account.universe if s not in STlist]
#     for stk in stocklist :
#         if stk not in account.valid_secpos:
#             price=DataAPI.MktEqudAdjGet(beginDate=last10day,endDate=account.previous_date,secID=stk,field=u"closePrice",pandas="1")
#             if len(price['closePrice'])==0:
#                 continue
#             maxprice=max(price['closePrice'].tolist())
#             ma=DataAPI.MktStockFactorsDateRangeGet(secID=stk,beginDate=last10day,endDate=account.previous_date,field=u"secID,MA20,MA10",pandas="1")
#             hist=account.get_attribute_history('closePrice',10)
#             ma10=ma['MA10']
#             ma20=ma['MA20']
#             try:
#                 if ma10[0]>hist[stk][-1] :
#                    order(stk,5000)
#                 if ma10[0]*1.04<hist[stk][-1] :
#                    order(stk,-2000)
#             except:
#                 pass
#
# bt,acct=quartz.backtest(start=start,
#             end=end,
#             benchmark=benchmark,
#             universe=universe,
#             capital_base=capital_base,
#             initialize=initialize,
#             handle_data=handle_data,
#             refresh_rate=refresh_rate)
#
# perf=quartz.perf_parse(bt,acct)
#
# out_keys=['annualized_return','volatility','information_ratio',
#     'sharpe','max_drawdown','alpha','beta']
#
# for k in out_keys:
#     print'%s:%s'%(k,perf[k])
#
# perf['cumulative_returns'].plot()
# perf['benchmark_cumulative_returns'].plot()
# pylab.legend(['current_strategy','HS300'])
