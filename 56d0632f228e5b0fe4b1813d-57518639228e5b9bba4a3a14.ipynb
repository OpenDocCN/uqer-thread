# %% [markdown]
# # 量化简单入门策略-在上证30均线之上选择个股突破的股票

# %% [raw]
# import datetime
# from CAL.PyCAL import Date
# from CAL.PyCAL import Calendar
# from CAL.PyCAL import BizDayConvention
# # 第一步：设置基本参数
# start = '2015-01-01'
# end = '2016-01-01'     # 回测结束时间
# capital_base = 1000000
# refresh_rate = 239
# benchmark = 'HS300'
# freq = 'm'
#
#
# # 第二步：选择主题，设置股票池
# universe = set_universe('HS300')
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     #print 'start:',account.current_date,account.current_minute
#         #print account.current_date
#         #print '收盘了'
#         c = account.referencePortfolioValue
#         today_minutes=account.get_history(238) #今天
#         stocks=[]
#         dt = Date.fromDateTime(account.current_date)
#         cal = Calendar('China.SSE')
#         lastTDay = cal.advanceDate(dt,'-1B',BizDayConvention.Preceding)
#         lastT30Day = cal.advanceDate(dt,'-29B',BizDayConvention.Preceding)
#         #print lastTDay,lastT30Day
#         current_date=dt.strftime('%Y%m%d')
#         last_date=lastTDay.strftime('%Y%m%d')
#         last_date=lastT30Day.strftime('%Y%m%d')
#         #获取上海指数及30日均线
#         sh_index=DataAPI.MktIdxdGet(tradeDate=u"",indexID=u"",ticker=u"000001",beginDate=last_date,endDate=current_date,field=u"",pandas="1")
#         sh_index1=DataAPI.MktIdxdGet(tradeDate=u"",indexID=u"",ticker=u"000001",beginDate=account.current_date,endDate=account.current_date,field=u"",pandas="1")
#         # print sh_index
#         sh_index_ma=sh_index['closeIndex'].mean()
#         sh_index_ma_pre=sh_index['preCloseIndex'].mean()
#         sh_current_index=sh_index1['openIndex'].mean()
#         # sh_index_ma,sh_index1['openIndex'].mean()
#         if sh_current_index>=sh_index_ma:
#             for s in account.universe:
#                 open_price=today_minutes[s]['openPrice'][0]  #09:31分钟开盘价
#                 pre_close_price=today_minutes[s]['closePrice'][-1] #15:28分钟收盘价
#                 high_price=today_minutes[s]['highPrice'].max() #当日最高价
#                 last_10day = account.get_daily_history(10) #最近10日
#                 close_last_day=last_10day[s]['closePrice'][-1] #昨日收盘价
#                 max_10day=last_10day[s]['highPrice'].max() #最近10日最高价
#                 mean_10day=last_10day[s]['closePrice'].mean() #最近10日平均
#                 #print account.current_date,s,close_last_day,open_price,pre_close_price,high_price
#                 #print account.current_date,s,pre_close_price,close_last_day*1.099
#                 #最高价打到过5%  并且如果收盘价打到了涨停，那就买不进去了，不知道别人怎么控制的
#                 if high_price>close_last_day*1.05 and pre_close_price>mean_10day and pre_close_price<mean_10day*1.3  and open_price <= max_10day and pre_close_price<close_last_day*1.099:
#                     stocks.append(s)
#
#         # print stocks
#             if len(stocks)==0 :
#                 return
#             w=min(0.1,1.0/len(stocks))# 最大仓位1/10
#         # print w
#             for s in stocks:
#                 p=today_minutes[s]['closePrice'][-1] #15:28分钟收盘价
#                 num=int(c * w / p)
#                 order(s, num)
#         else:
#               for s in account.valid_secpos:     #清仓
#                     order_to(s, 0)
