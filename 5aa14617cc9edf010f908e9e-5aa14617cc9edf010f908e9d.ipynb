# %% [markdown]
# # bug_report

# %%
a = '000002.XSHE'
x = DataAPI.MktStockFactorsOneDayGet(secID=a, tradeDate='2018-01-03', field='secID,tradeDate,MACD,BullPower,RSI', pandas='1')
x
# Out:
#          secID   tradeDate  MACD  BullPower      RSI
# 0  000002.XSHE  2018-01-03     0     2.9634  75.6369
