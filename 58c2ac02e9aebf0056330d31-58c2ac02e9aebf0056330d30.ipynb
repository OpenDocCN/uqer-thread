# %% [markdown]
# # 不同市值选股

# %%
import pandas as pd
#perf1=pd.DataFrame(perf)
perf1.cumulative_returns.plot(figsize=(14,7))
#perf2=pd.DataFrame(perf)
perf2.cumulative_returns.plot(figsize=(14,7))
#perf3=pd.DataFrame(perf)
perf3.cumulative_returns.plot(figsize=(14,7))

# %% [raw]
# start = '2012-12-01' #回测开始时间
# end = '2017-02-27'  # 回测结束时间
# benchmark = "HS300"                  # 策略对标标的
# NumOfStocks=100
# universe=DynamicUniverse('A').apply_filter(Factor.LCAP.num_range(1,100))
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 20                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# commission = Commission(buycost=0.0003, sellcost=0.0013, unit='perValue')
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     for stock in account.security_position:
#         if stock not in account.universe:
#             order_pct_to(stock,0)
#
#     for s in account.universe:
#         if len(account.security_position)>=NumOfStocks:
#             return
#         if s not in account.security_position:
#             order_pct_to(s,(0.01))
