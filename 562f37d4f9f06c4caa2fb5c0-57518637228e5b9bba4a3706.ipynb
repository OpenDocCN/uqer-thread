# %% [markdown]
# # 【大师系列】麦克•贝利2-2-2 选股法则

# %% [markdown]
# 麦克•贝利是亚利桑那大学数量分析博士，曾任教维吉尼亚大学，财务行为学领域的专家。麦克•贝利在其发表的研究成果阐述了自己的价值投资理念，并发展出一种简单的选股标准，称为2-2-2 法则。
# ---
# ***
# 参考申万研报《麦克•贝利2-2-2 选股法则——申万大师系列_价值投资篇之十八》，其选股法则为：
# 1. 股票预期市盈率低于市场平均预期市盈率的“2”分之一
# 2. 公司预期盈利成长率大于市场平均预估盈利成长率的“2”分之一
# 3. 股票的市净率小于“2”

# %% [raw]
# from CAL.PyCAL import *
# import numpy as np
# import pandas as pd
# start = '2011-01-01'                       # 回测起始时间
# end = '2015-10-26'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')           # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 30                          # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# cal = Calendar('China.SSE')
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     current_date = account.current_date
#     yesterday = cal.advanceDate(current_date,'-1B',BizDayConvention.Unadjusted)
#     eq_except = pd.DataFrame()
#     for s in xrange(100,len(account.universe),100): #由于API的读取限制，分批运行API。
#         #该API又第三方朝阳永续提供
#         tmp = DataAPI.GG.CESTReportGGGet(BeginPubDate=yesterday.strftime("%Y%m%d"),EndPubDate=current_date.strftime("%Y%m%d"),secID=account.universe[s-100:s],field=['publishDate','secID','PE_con','C7'],pandas="1")
#         eq_except = pd.concat([eq_except,tmp],axis = 0)
#
#     tmp = DataAPI.GG.CESTReportGGGet(BeginPubDate=yesterday.strftime("%Y%m%d"),EndPubDate=current_date.strftime("%Y%m%d"),secID=account.universe[s:],field=['publishDate','secID','PE_con','C7'],pandas="1")
#     eq_except = pd.concat([eq_except,tmp],axis = 0)
#
#     eq_except = eq_except.set_index('secID')
#     filter_list = []
#
#     for stk in list(set(eq_except.index.tolist())):
#         if eq_except.ix[stk]['PE_con'].mean() < eq_except['PE_con'].mean()/2 and eq_except.ix[stk]['C7'].mean() > eq_except['C7'].mean()/2:
#             filter_list.append(stk)
#     if len(filter_list) == 0:
#         buy_list = []
#     else:
#         eq_pb = DataAPI.MktEqudGet(secID=filter_list,tradeDate=yesterday.strftime("%Y%m%d"),field=['secID','PB'],pandas="1")
#         buy_list = eq_pb[eq_pb['PB'] < 2]['secID'].tolist()
#
#     print buy_list
#     for stk in account.valid_secpos:
#         if stk not in buy_list:
#             order_to(stk, 0)
#         else:
#             order_to(stk, account.referencePortfolioValue/account.referencePrice[stk]/len(buy_list))
#
#     for stk in buy_list:
#         if stk not in account.valid_secpos:
#             if np.isnan(account.referencePrice[stk]) or account.referencePrice[stk] == 0:  # 停牌或是还没有上市等原因不能交易
#                 continue
#             order_to(stk, account.referencePortfolioValue/account.referencePrice[stk]/len(buy_list))

# %% [markdown]
# 结果满足条件的股票数较少，当选出的股票数过少时应更加注意风险。
