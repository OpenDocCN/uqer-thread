# %% [markdown]
# # 练习1

# %% [raw]
# start = '2006-02-01'                       # 回测起始时间
# end = '2015-11-29'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# #universe = StockScreener(Factor.LCAP.nsmall(200))           # 证券池，支持股票和基金
# universe = set_universe('HS300')
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 30                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     price1=1000.0
#     for stock in account.universe:
#
#         price=account.referencePrice[stock]
#         if price<price1:
#             price1=price
#             stock1=stock
#
#     for stk in account.avail_secpos:
#         if stk!=stock1:
#             order_to(stk,0)
#     if stock1 not in account.avail_secpos:
#         order(stock1,account.referencePortfolioValue/account.referencePrice[stock1])

# %% [raw]
# start = '2011-02-01'                       # 回测起始时间
# end = '2015-11-29'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = StockScreener(Factor.LCAP.nsmall(200))           # 证券池，支持股票和基金
# #universe = set_universe('HS300')
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 30                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     price1=1000.0
#     for stock in account.universe:
#         price=account.referencePrice[stock]
#         if price<price1:
#             price1=price
#             stock1=stock
#
#     for stk in account.avail_secpos:
#         if stk!=stock1:
#             order_to(stk,0)
#     if stock1 not in account.avail_secpos:
#         order(stock1,account.referencePortfolioValue/account.referencePrice[stock1])
