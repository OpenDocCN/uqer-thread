# %% [markdown]
# # 大跌见真金

# %% [raw]
# import pandas as pd
# import numpy as np
# import datetime
# from datetime import timedelta
# import matplotlib.pyplot as plt
# #%pylab inline
# import time
#
# start = '2012-08-01'
# end = '2015-08-01'
# benchmark = 'HS300'
# capital_base = 1000000
# security_base = {}
# commission = Commission(buycost=0.0008, sellcost=0.0018) # 佣金万八
# slippage = Slippage()
#
#
# #start = '2015-08-26'                       # 回测起始时间
# #end = '2016-05-21'                         # 回测结束时间
# #benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('A')               # 证券池，支持股票和基金
# #capital_base = 1e+7                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):    # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     end_date = account.previous_date   # 回测结束时间
#     now_date = account.current_date.strftime('%Y%m%d')
#     start_date = end_date + datetime.timedelta(days=-90)          # 回测起始时间
#     end_date1 = end_date.strftime('%Y%m%d')
#     start_date1 = start_date.strftime('%Y%m%d')
#
#     trade_cale = DataAPI.TradeCalGet(exchangeCD=u"XSHG,XSHE",beginDate=u"",endDate=end_date1,field=u"",pandas="1")
#     trade_cale = trade_cale[trade_cale[u'isOpen'] ==1]
#     end_date2 = trade_cale['calendarDate'].tail(1).values #格式为2016-05-20
#     end_date3 = datetime.datetime.strptime(end_date2[0],"%Y-%m-%d").strftime('%Y%m%d') #转换成格式20160520
#
#     hs300_index = DataAPI.MktIdxdGet(tradeDate=end_date3,indexID=u"",ticker=u"000300",beginDate=u"",endDate=u"",field=u"",pandas="1")
#     #hs300_index = DataAPI.MktIdxdGet(tradeDate=end_date3,indexID=u"",ticker=u"399006",beginDate=u"",endDate=u"",field=u"",pandas="1")
#
#     if hs300_index['CHGPct'].values<-0.015 and hs300_index['CHGPct'].values>-0.03:
#         all_stk_prc = DataAPI.MktEqudGet(tradeDate=end_date3,secID=u"",ticker=u"",isOpen="",beginDate=u"",endDate=u"",field=u"",pandas="1")
#         all_stk_prc = all_stk_prc[ all_stk_prc['exchangeCD'] == 'XSHE']
#         all_stk_prc['B'] = all_stk_prc['secShortName'].map(lambda x: 'B' in x)
#         all_stk_prc['ST'] = all_stk_prc['secShortName'].map(lambda x: 'ST' in x)
#         all_stk_prc = all_stk_prc[all_stk_prc['B']==False]
#         all_stk_prc = all_stk_prc[all_stk_prc['ST']==False]
#         all_stk_prc = all_stk_prc[all_stk_prc[u'isOpen']==1]
#         #all_stk_prc = all_stk_prc[all_stk_prc[u'negMarketValue']<1e+10]
#         all_stk_prc['pct_ch'] = all_stk_prc[u'closePrice']/all_stk_prc[u'preClosePrice'] - 1
#         all_stk_prc = all_stk_prc[all_stk_prc['pct_ch']>0.05]
#         all_stk_prc = all_stk_prc[all_stk_prc['pct_ch']<0.099]
#         all_stk_prc = all_stk_prc[all_stk_prc['secID']!='300186.XSHE']
#         all_stk_prc = all_stk_prc[all_stk_prc['secID']!='000033.XSHE']  #000033.XSHE
#
#         #all_stk_prc['1_3'] = 0
#         buylist = all_stk_prc['secID'].values
#         stk_num = len(buylist)
#         #买入
#         for stk in buylist:
#             if stk not in account.valid_secpos:
#                 cash_ratio = account.cash/account.referencePortfolioValue
#                 order_pct(stk,cash_ratio*0.5/stk_num)
#     # 卖出股票
#
#     for stock in account.valid_secpos.keys():
#         chicang = DataAPI.MktEqudGet(tradeDate=end_date1,secID=stock,ticker=u"",isOpen="",beginDate=u"",endDate=u"",field=u"",pandas="1")
#         if chicang['closePrice'].values<account.valid_seccost[stock]*0.97:
#                 order_to(stock, 0)
#         else:
#             pass
#         if chicang['closePrice'].values>account.valid_seccost[stock]*1.07:
#                 order_to(stock, 0)
#         else:
#             pass
#
#
#     return
