# %% [markdown]
# # 做T测试

# %% [raw]
# start = '2015-10-14'
# end   = '2016-01-19'
# capital_base = 100000
# refresh_rate = 1
# commission=Commission(0.0004,0.0004)
# benchmark = '002552.XSHE'
# freq = 'm'
#
# universe = [benchmark, ]
#
# def initialize(account):
#     account.gap=dict(zip(universe, [0.005]))
#     account.weight = [1]
#     account.weightmap = dict(zip(universe, account.weight))
#
# def handle_data(account):
#     c = account.referencePortfolioValue
#     for stock in account.universe:
#         w = account.weightmap.get(stock, 0)
#         if account.current_minute=='09:30':
#             p = account.referencePrice[stock]
#             if account.avail_secpos.get(stock, 0)>0:
#                 order_to(stock,0,price=p*(1+account.gap[stock]),otype='limit')
#             order(stock,int(c * w / p/200)*100,price=p*(1-account.gap[stock]),otype='limit')
