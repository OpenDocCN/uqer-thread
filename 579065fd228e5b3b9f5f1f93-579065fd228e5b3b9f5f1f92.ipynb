# %% [markdown]
# #

# %% [raw]
# start = '2015-01-01'                       # 回测起始时间
# end = '2016-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = StockScreener(Factor.LCAP.nsmall(20)|Factor.LCAP.nlarge(20))  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# stk_num=10
#
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     month=0
#     strategy=0
#     today = account.current_date
#     if month!=today.month:
#         month=today.month
#         if month in [1,6,8]:#空仓
#             strategy=1
#         elif month in [2,5,7,10]:#小市值
#             strategy=2
#         elif month in [3,4,9,12]:#大盘股
#             strategy=3
#     #实现每月第一天确定strategy后，每天都进行判断，实现第一天由于停牌等导致无法实现的仓位调整在可以实现时最快执行
#     if strategy==1:
#         for s in account.valid_secpos:
#             order_to(s,0)
#     elif strategy==2:
#         valid_universe=StockScreener(Factor.LCAP.nsmall(20))
#         valid_universe=valid_universe.preview(today)
#         valid_universe=[s for s in valid_universe if (s in account.universe and account.referencePrice[s]>0)]
#         buy_universe = StockScreener(Factor.LCAP.nsmall(stk_num))
#         buy_universe=buy_universe.preview(today)
#         buy_universe=[s for s in buy_universe if (s in account.universe and account.referencePrice[s]>0)]
#         print buy_universe
#         for s in account.valid_secpos:
#             if s not in valid_universe:
#                 order_to(s,0)
#         for s in buy_universe:
#             order_pct_to(s,1/stk_num)
#     elif strategy==3:
#         valid_universe=StockScreener(Factor.LCAP.nlarge(20))
#         valid_universe=valid_universe.preview(today)
#         valid_universe=[s for s in valid_universe if (s in account.universe and account.referencePrice[s]>0)]
#         buy_universe=StockScreener(Factor.LCAP.nlarge(stk_num))
#         buy_universe=buy_universe.preview(today)
#         buy_universe=[s for s in buy_universe if (s in account.universe and account.referencePrice[s]>0)]
#         print buy_universe
#         for s in account.valid_secpos:
#             if s not in valid_universe:
#                 order_to(s,0)
#         for s in buy_universe:
#             order_pct_to(s,1/stk_num)
