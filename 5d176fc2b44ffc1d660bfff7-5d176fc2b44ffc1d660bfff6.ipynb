# %% [markdown]
# # test02

# %% [raw]
# import datetime
#
# # utils
# def ticker2secID(ticker):
#     """
#     给定股票代码转化为股票内部编码
#     Args:
#         tickers (list): 需要转化的股票代码列表
#     Returns:
#         list: 转化为内部编码的股票编码列表
#
#     Examples:
#         >> tickers = ['600000','000001']
#         >> secIDs = ticker2secID(tickers)
#     """
#     universe = DataAPI.FundGet(ticker=ticker, field=u"ticker,secID",pandas="1") # 获取所有的A股（包括已退市）
#     universe = dict(universe.set_index('ticker')['secID'])
#     if isinstance(ticker, list):
#         res = []
#         for i in ticker:
#             if i in universe:
#                 res.append(universe[i])
#             else:
#                 print i, ' 在universe中不存在，没有找到对应的secID！'
#         return res
#     else:
#         raise ValueError('ticker should be list！')
#
#
# start = '2019-02-01'                       # 回测起始时间
# end = '2019-03-03'                         # 回测结束时间
# # universe = DynamicUniverse('A')        # 证券池，支持股票、基金、期货、指数四种资产
# # universe = ['510360.XSHG', '510390.XSHG']
# universe = ticker2secID(['002987'])
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = (1, ['14:50'])                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# # stocks = ['510360.XSHG', '510390.XSHG']
# stocks = ticker2secID(['002987'])
# unit = 100000
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'otc_fund': AccountConfig(account_type='otc_fund', capital_base=10000000)
# }
#
# def initialize(context):
#     print('hello')
#     pass
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     account = context.get_account('otc_fund')
#
#     previous_date = context.previous_date.strftime('%Y-%m-%d')
#     # print('date: %s %s' % (context.now, context.now.strftime('%w')))  # 2018-01-02 00:00:00
#     # timenow = datetime.datetime.strptime(context.now,'%Y-%m-%d %H:%M:%S')
#     weekday = int(context.now.strftime('%w'))
#     # print(dir(account))
#     if weekday == 2:
#         for s in stocks:
#             orderid = account.purchase(s, unit)
#             print('[%s] order [%s:%s]: %d' % (context.now, s, DataAPI.FundGet(secID=s, field='secShortName').secShortName[0], unit))
#             # print(account.get_order(orderid))
