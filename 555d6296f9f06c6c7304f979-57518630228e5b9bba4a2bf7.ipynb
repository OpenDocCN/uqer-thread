# %% [markdown]
# # 步步高模拟交易

# %% [markdown]
# **策略实现**
#
# - 投资域 ：沪深300成分股
# - 业绩基准 ：沪深300指数
# - 调仓频率 ：60个交易日
# - 买入卖出信号 ：初始时任意买PE大于20的股票10只,每次调仓时,剔除所有PE大于50的股票,再补充PE大于20的股票
# - 回测周期 ：2011年1月1日至2015年4月1日

# %% [raw]
# import numpy
# start = '2015-03-01'                       # 回测起始时间
# end = '2015-04-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')  # 证券池，支持股票和基金
# capital_base = 10000000                      # 起始资金
# longest_history = 5                        # handle_data 函数中可以使用的历史数据最长窗口长度
# refresh_rate = 1                          # 调仓频率，即每 refresh_rate 个交易日执行一次 handle_data() 函数
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     dt = Date.fromDateTime(account.current_date)
#     cal = Calendar('China.IB')
#     lastTDay = cal.advanceDate(dt,'-1B',BizDayConvention.Preceding)   #计算出前一个交易日期
#     lastdt = lastTDay.strftime("%Y%m%d")
#     for s in account.universe:
#         try:
#             pe = DataAPI.MktStockFactorsOneDayGet(tradeDate=lastdt ,secID=u"",ticker=s[:6],field=u"PE",pandas="1").get('PE')[0]  #前一交易日pe
#         except:
#             return
#         if pe > 1 and s not in account.valid_secpos:
#             order(s, capital_base / account.referencePrice[s] / 10)
#         elif pe > 50 and s in account.valid_secpos:
#             order_to(s, 0)
#     return
