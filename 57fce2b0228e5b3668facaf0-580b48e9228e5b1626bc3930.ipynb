# %% [markdown]
# #

# %%
import pandas as pd
import numpy as np
bdt="20160311" #期间开始
edt="20161011" #期间结束


themeName =u'锂电池'   
#获取某主题相关股票的信息
ztid=DataAPI.TickersByThemesGet(themeID=u"",themeName=themeName,beginDate=u"",endDate=u"",isNew=u"",field=u"",pandas="1")
gpjc=ztid.secShortName.tolist() #股票简称
stocklist=ztid.secID.tolist() #股票代码
returnall=[] #设立收益列表
mrktval1=[]
mrktval2=[]
ysdf=pd.DataFrame()
#print(stocklist)
#获取股票list中的各股票收益并装入returnall中
for i in stocklist:
    price1=DataAPI.MktEqudAdjGet(secID=i,\
                             beginDate=bdt,endDate=bdt,field=u"secID,closePrice",pandas="1")#期间开始价格
    price2=DataAPI.MktEqudAdjGet(secID=i,\
                             beginDate=edt,endDate=edt,field=u"secID,closePrice,negMarketValue,marketValue",pandas="1")#期间结束价格
    returnget=round(float(price2.closePrice[0]/price1.closePrice[0]-1),4)#收益，保留四位小数
    returnget1=str(returnget*100)+'%'
    returnall.append(returnget1)
    mrktval1.append(int(price2.negMarketValue/100000000))
    mrktval2.append(int(price2.marketValue/100000000))
#print mrktval1
indexlen=len(stocklist)+1#为了设置Index
alltable=pd.DataFrame(np.array(zip(stocklist,gpjc,returnall)),columns=['代码','股票简称','期间涨幅'])#index=list(range(1,indexlen))

alltable1=alltable.join(pd.Series(mrktval1,name='流动市值'))
alltable2=alltable1.join(pd.Series(mrktval2,name='总市值'))


alltable2
# Out:
#              代码   股票简称     期间涨幅  流动市值   总市值
# 0   002091.XSHE   江苏国泰   53.64%    77    79
# 1   002407.XSHE    多氟多   53.29%   154   204
# 2   300037.XSHE    新宙邦   45.81%    60   102
# 3   000009.XSHE   中国宝安   25.78%   227   230
# 4   000636.XSHE   风华高科   20.82%    77    92
# 5   000839.XSHE   中信国安  129.71%   452   452
# 6   600549.XSHG   厦门钨业    57.1%   231   282
# 7   600884.XSHG   杉杉股份   38.34%   132   181
# 8   000009.XSHE   中国宝安   25.78%   227   230
# 9   000049.XSHE   德赛电池   23.59%    86    86
# 10  000839.XSHE   中信国安  129.71%   452   452
# 11  000913.XSHE  *ST钱江  119.93%    85    85
# 12  000969.XSHE   安泰科技   32.58%   105   126
# 13  002056.XSHE   横店东磁   61.14%   121   121
# 14  002070.XSHE   众和股份    6.47%   101   114
# 15  002074.XSHE   国轩高科   11.05%   160   299
# 16  002139.XSHE   拓邦股份   37.32%    39    62
# 17  002190.XSHE   成飞集成   23.49%   124   124
# 18  002206.XSHE    海利得   46.84%    61    86
# 19  002460.XSHE   赣锋锂业   58.05%   151   220
# 20  002594.XSHE    比亚迪   12.93%   486  1579
# 21  300014.XSHE   亿纬锂能   79.19%   137   143
# 22  300037.XSHE    新宙邦   45.81%    60   102
# 23  300068.XSHE   南都电源   64.88%   127   171
# 24  300073.XSHE   当升科技  135.93%    91   102
# 25  600078.XSHG   澄星股份    16.4%    46    46
# 26  600390.XSHG  *ST金瑞   16.61%    67    67
# 27  600460.XSHG    士兰微   26.48%    83    83
# 28  600470.XSHG   六国化工    7.57%    39    39
# 29  600478.XSHG    科力远    5.08%   136   148
# 30  600482.XSHG   中国动力   12.83%   178   591
# 31  600549.XSHG   厦门钨业    57.1%   231   282
# 32  600884.XSHG   杉杉股份   38.34%   132   181
# 33  002074.XSHE   国轩高科   11.05%   160   299
# 34  002108.XSHE   沧州明珠   41.65%   137   138
# 35  002139.XSHE   拓邦股份   37.32%    39    62
# 36  002263.XSHE    大东南   17.65%    66    68
# 37  002407.XSHE    多氟多   53.29%   154   204
# 38  002460.XSHE   赣锋锂业   58.05%   151   220
# 39  002466.XSHE   天齐锂业   26.29%   380   384
# 40  300014.XSHE   亿纬锂能   79.19%   137   143
# 41  300037.XSHE    新宙邦   45.81%    60   102
# 42  300207.XSHE    欣旺达   53.04%   140   208
# 43  000049.XSHE   德赛电池   23.59%    86    86
# 44  002466.XSHE   天齐锂业   26.29%   380   384
# 45  000973.XSHE   佛塑科技   11.05%    66    83
# 46  002389.XSHE   南洋科技     0.0%    68    91
# 47  000792.XSHE   盐湖股份   13.65%   300   356
# 48  002091.XSHE   江苏国泰   53.64%    77    79
# 49  002411.XSHE   必康股份   90.93%    77   421
# 50  300037.XSHE    新宙邦   45.81%    60   102
# 51  300073.XSHE   当升科技  135.93%    91   102
# 52  600390.XSHG  *ST金瑞   16.61%    67    67
# 53  603026.XSHG   石大胜华   45.75%    60    86
# 54  002091.XSHE   江苏国泰   53.64%    77    79
# 55  002466.XSHE   天齐锂业   26.29%   380   384
# 56  300037.XSHE    新宙邦   45.81%    60   102
# 57  600478.XSHG    科力远    5.08%   136   148
# 58  000973.XSHE   佛塑科技   11.05%    66    83
# 59  002389.XSHE   南洋科技     0.0%    68    91
