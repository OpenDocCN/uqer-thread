# %% [markdown]
# # MA_20151129_a

# %% [raw]
# import numpy as np
#
# start = '2014-01-01'                       # 回测起始时间
# end = '2015-11-27'                         # 回测结束时间
# #benchmark = 'HS300'                        # 策略参考标准
# benchmark = '399006.ZICN'
# universe = ['159915.XSHE']  # 证券池，支持股票和基金
#
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# #self defined data
# window_short = 1
# window_long =20
# universe_tuple = tuple(universe)
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     hist = account.get_attribute_history('closePrice',window_long)
#     fund = universe_tuple[0]
#     #today = account.current_date
#     #print today
#     #print hist[universe_tuple[0]][-window_short:]
#     #print hist[universe_tuple[0]][-window_long:]
#
#     maShort =  np.mean(hist[universe_tuple[0]][-window_short:])
#     maLong = np.mean(hist[universe_tuple[0]][-window_long:])
#     #print maShort
#     #print maLong
#
#     if maShort>= maLong:
#         approximationAmount = int(account.cash / hist[universe_tuple[0]][-1]/100.0) * 100
#     #    print "buy:"+str(approximationAmount)
#         order(universe_tuple[0],approximationAmount)
#     elif maShort < maLong:
#         order_to(universe_tuple[0],0)
#     #    print "sell"
#     #print r'----'
#
#
# print 'window   annualized_return   sharpe   max_drawdown'
# for window_short in range(1,10,1):
#     strategy = quartz.sim_condition.strategy.TradingStrategy(initialize, handle_data)
#     bt_test, acct = quartz.quick_backtest(sim_params, strategy, idxmap_all, data_all)
#     perf = quartz.perf_parse(bt_test, acct)
#     print '  {0:2d}        {1:>7.4}          {2:>7.4}    {3:>7.4}'.format(window_short, perf['annualized_return'], perf['sharpe'], perf['max_drawdown'])
