# %% [markdown]
# # Notebook5

# %%
data2 =DataAPI.FdmtBSGet(secID=set_universe('HS300'),reportType=u"A",endDateRep="",beginDateRep="",beginYear="2012",endYear="2017",fiscalPeriod="",endDate=u"",beginDate=u"",publishDateEnd=u"",publishDateBegin=u"",field=u"secID,secShortName,endDate,publishDate,TAssets,STBorr,LTBorr,NCLWithin1Y,LTPayable,bondPayable,cashCEquiv,TShEquity,TLiab,estimatedLiab,deferTaxLiab,specificPayables,TEquityAttrP,paidInCapital",pandas="1")
#data2 = data2.sort_values('publishDate').groupby(['secID','endDate']).last().reset_index()
data2
# Out:
#             secID secShortName     endDate publishDate       TAssets  \
# 0     000001.XSHE         平安银行  2016-12-31  2017-04-22  2.953434e+12
# 1     000001.XSHE         平安银行  2016-12-31  2017-03-17  2.953434e+12
# 2     000001.XSHE         平安银行  2015-12-31  2017-03-17  2.507149e+12
# 3     000001.XSHE         平安银行  2015-12-31  2016-10-21  2.507149e+12
# 4     000001.XSHE         平安银行  2015-12-31  2016-08-12  2.507149e+12
# 5     000001.XSHE         平安银行  2015-12-31  2016-04-21  2.507149e+12
# 6     000001.XSHE         平安银行  2015-12-31  2016-03-10  2.507149e+12
# 7     000001.XSHE         平安银行  2014-12-31  2016-03-10  2.186459e+12
# 8     000001.XSHE         平安银行  2014-12-31  2015-10-23  2.186459e+12
# 9     000001.XSHE         平安银行  2014-12-31  2015-08-14  2.186459e+12
# 10    000001.XSHE         平安银行  2014-12-31  2015-04-24  2.186459e+12
# 11    000001.XSHE         平安银行  2014-12-31  2015-03-13  2.186459e+12
# 12    000001.XSHE         平安银行  2013-12-31  2015-03-13  1.891741e+12
# ...
