# %% [markdown]
# # Halloween Cycle example

# %% [markdown]
# Halloween Cycle example

# %% [raw]
# start = '2011-10-01'                       # 回测起始时间
# end = '2014-10-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['601398.XSHG','600028.XSHG', '601988.XSHG', '600036.XSHG','600030.XSHG','601318.XSHG', '600000.XSHG', '600019.XSHG', '600519.XSHG', '601166.XSHG']
# capital_base = 1000000                      # 起始资金
# refresh_rate = 1                           # 调仓频率，即每 refresh_rate 个交易日执行一次 handle_data() 函数
#
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     today = account.current_date
#     for s in account.universe:
#         if(today.month == 10) and (s not in account.valid_secpos):
#             amount = account.cash / len(account.universe) / account.referencePrice[s]
#             order(s,amount)
#         elif today.month == 5:
#             order_to(s,0)

# %% [markdown]
# it's OK......
