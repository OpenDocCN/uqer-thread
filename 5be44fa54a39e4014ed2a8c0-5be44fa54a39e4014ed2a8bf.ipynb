# %% [markdown]
# # Notebook2

# %%
DataAPI.EquGet(secID=u"",ticker=u"",equTypeCD=u"A",listStatusCD=u"",field=u"",pandas="1")
# Out:
#               secID    ticker exchangeCD  ListSectorCD ListSector transCurrCD  \
# 0       000001.XSHE    000001       XSHE             1         主板         CNY
# 1       000002.XSHE    000002       XSHE             1         主板         CNY
# 2       000003.XSHE    000003       XSHE             1         主板         CNY
# 3       000004.XSHE    000004       XSHE             1         主板         CNY
# 4       000005.XSHE    000005       XSHE             1         主板         CNY
# 5       000006.XSHE    000006       XSHE             1         主板         CNY
# 6       000007.XSHE    000007       XSHE             1         主板         CNY
# 7       000008.XSHE    000008       XSHE             1         主板         CNY
# 8       000009.XSHE    000009       XSHE             1         主板         CNY
# 9       000010.XSHE    000010       XSHE             1         主板         CNY
# 10      000011.XSHE    000011       XSHE             1         主板         CNY
# 11      000012.XSHE    000012       XSHE             1         主板         CNY
# 12      000013.XSHE    000013       XSHE             1         主板         CNY
# 13      000014.XSHE    000014       XSHE             1         主板         CNY
# 14      000015.XSHE    000015       XSHE             1         主板         CNY
# 15      000016.XSHE    000016       XSHE             1         主板         CNY
# 16      000017.XSHE    000017       XSHE             1         主板         CNY
# 17      000018.XSHE    000018       XSHE             1         主板         CNY
# 18      000019.XSHE    000019       XSHE             1         主板         CNY
# 19      000020.XSHE    000020       XSHE             1         主板         CNY
# 20      000021.XSHE    000021       XSHE             1         主板         CNY
# 21      000022.XSHE    000022       XSHE             1         主板         CNY
# 22      000023.XSHE    000023       XSHE             1         主板         CNY
# 23      000024.XSHE    000024       XSHE             1         主板         CNY
# 24      000025.XSHE    000025       XSHE             1         主板         CNY
# 25      000026.XSHE    000026       XSHE             1         主板         CNY
# 26      000027.XSHE    000027       XSHE             1         主板         CNY
# 27      000028.XSHE    000028       XSHE             1         主板         CNY
# 28      000029.XSHE    000029       XSHE             1         主板         CNY
# 29      000030.XSHE    000030       XSHE             1         主板         CNY
# ...             ...       ...        ...           ...        ...         ...
# 3644    603937.XSHG    603937       XSHG             1         主板         CNY
# 3645    603938.XSHG    603938       XSHG             1         主板         CNY
# 3646    603939.XSHG    603939       XSHG             1         主板         CNY
# 3647    603955.XSHG    603955       XSHG             1         主板         CNY
# 3648    603958.XSHG    603958       XSHG             1         主板         CNY
# 3649    603959.XSHG    603959       XSHG             1         主板         CNY
# 3650    603960.XSHG    603960       XSHG             1         主板         CNY
# 3651    603963.XSHG    603963       XSHG             1         主板         CNY
# 3652    603966.XSHG    603966       XSHG             1         主板         CNY
# 3653    603968.XSHG    603968       XSHG             1         主板         CNY
# 3654    603969.XSHG    603969       XSHG             1         主板         CNY
# 3655    603970.XSHG    603970       XSHG             1         主板         CNY
# 3656    603976.XSHG    603976       XSHG             1         主板         CNY
# 3657    603977.XSHG    603977       XSHG             1         主板         CNY
# 3658    603978.XSHG    603978       XSHG             1         主板         CNY
# 3659    603979.XSHG    603979       XSHG             1         主板         CNY
# 3660    603980.XSHG    603980       XSHG             1         主板         CNY
# 3661    603985.XSHG    603985       XSHG             1         主板         CNY
# 3662    603986.XSHG    603986       XSHG             1         主板         CNY
# 3663    603987.XSHG    603987       XSHG             1         主板         CNY
# 3664    603988.XSHG    603988       XSHG             1         主板         CNY
# 3665    603989.XSHG    603989       XSHG             1         主板         CNY
# 3666    603990.XSHG    603990       XSHG             1         主板         CNY
# 3667    603991.XSHG    603991       XSHG             1         主板         CNY
# 3668    603993.XSHG    603993       XSHG             1         主板         CNY
# 3669    603996.XSHG    603996       XSHG             1         主板         CNY
# 3670    603997.XSHG    603997       XSHG             1         主板         CNY
# 3671    603998.XSHG    603998       XSHG             1         主板         CNY
# 3672    603999.XSHG    603999       XSHG             1         主板         CNY
# 3673  DY600018.XSHG  DY600018       XSHG             1         主板         CNY
#
#      secShortName          secFullName listStatusCD    listDate      ...       \
# 0            平安银行           平安银行股份有限公司            L  1991-04-03      ...
# 1             万科A           万科企业股份有限公司            L  1991-01-29      ...
# 2           PT金田A       金田实业(集团)股份有限公司           DE  1991-07-03      ...
# 3            国农科技       深圳中国农大科技股份有限公司            L  1991-01-14      ...
# 4            世纪星源         深圳世纪星源股份有限公司            L  1990-12-10      ...
# 5            深振业A      深圳市振业(集团)股份有限公司            L  1992-04-27      ...
# 6             全新好         深圳市全新好股份有限公司            L  1992-04-13      ...
# 7            神州高铁         神州高铁技术股份有限公司            L  1992-05-07      ...
# 8            中国宝安         中国宝安集团股份有限公司            L  1991-06-25      ...
# 9            美丽生态         深圳美丽生态股份有限公司            L  1995-10-27      ...
# 10           深物业A    深圳市物业发展(集团)股份有限公司            L  1992-03-30      ...
# 11            南玻A         中国南玻集团股份有限公司            L  1992-02-28      ...
# 12         *ST石化A       深圳石化工业集团股份有限公司           DE  1992-05-06      ...
# 13           沙河股份           沙河实业股份有限公司            L  1992-06-02      ...
# 14          PT中浩A       深圳中浩(集团)股份有限公司           DE  1992-06-25      ...
# 15           深康佳A           康佳集团股份有限公司            L  1992-03-27      ...
# 16           深中华A    深圳中华自行车(集团)股份有限公司            L  1992-03-31      ...
# 17           神州长城           神州长城股份有限公司            L  1992-06-16      ...
# 18           深深宝A        深圳市深宝实业股份有限公司            L  1992-10-12      ...
# 19           深华发A         深圳中恒华发股份有限公司            L  1992-04-28      ...
# 20            深科技       深圳长城开发科技股份有限公司            L  1994-02-02      ...
# 21           深赤湾A         深圳赤湾港航股份有限公司            L  1993-05-05      ...
# 22           深天地A      深圳市天地(集团)股份有限公司            L  1993-04-29      ...
# 23           招商地产        招商局地产控股股份有限公司           DE  1993-06-07      ...
# 24            特力A      深圳市特力(集团)股份有限公司            L  1993-06-21      ...
# 25           飞亚达A        飞亚达(集团)股份有限公司            L  1993-06-03      ...
# 26           深圳能源         深圳能源集团股份有限公司            L  1993-09-03      ...
# 27           国药一致       国药集团一致药业股份有限公司            L  1993-08-09      ...
# 28           深深房A  深圳经济特区房地产(集团)股份有限公司            L  1993-09-15      ...
# 29           富奥股份        富奥汽车零部件股份有限公司            L  1993-09-29      ...
# ...           ...                  ...          ...         ...      ...
# 3644         丽岛新材        江苏丽岛新材料股份有限公司            L  2017-11-02      ...
# 3645         三孚股份         唐山三孚硅业股份有限公司            L  2017-06-28      ...
# 3646         益丰药房        益丰大药房连锁股份有限公司            L  2015-02-17      ...
# 3663                从事医用穿刺器械的研发、生产和销售,主要产品为医用穿刺针和医用穿刺器。  2018-09-30
# 3664                              大中型交、直流电机的研发设计、生产和销售。  2018-09-30
# 3665                               生产销售电容器、电容器原材料及相关设备。  2018-09-30
# 3666               以临床医疗管理信息系统系列应用软件产品和临床信息化整体解决方案为核心业务  2018-09-30
# 3667                     电线电缆、光缆用绿色环保型聚烯烃高分子材料的研发、生产和销售  2018-09-30
# 3668  主要从事钼、钨及黄金等稀贵金属的开采、选冶、深加工、贸易、科研等。生产所需原辅材料、机械设备...  2018-09-30
# 3669                                平板电视及平板电脑的研发、生产和销售。  2018-09-30
# 3670  公司的主要客户为汽车整车厂、大型座椅制造厂和头枕制造厂等,公司主要的配套品牌和车型有宝马3系...  2018-09-30
# 3671  集新药研发、成药生产和销售于一体的综合性制药企业。公司经营范围为片剂(含头孢菌素类)、硬胶囊...  2018-09-30
# 3672                        期刊、图书(含教材教辅及一般图书)出版物的出版和发行。  2018-09-30
# 3673  集装箱装卸、储存、拆装箱;水陆运输、中转、多式联运;货运代理、船务代理;信息及管理;工程技术...         NaN
#
#          TShEquity
# 0     2.352310e+11
# 1     2.158918e+11
# 2     7.572070e+07
# 3     1.977834e+08
# 4     1.412948e+09
# 5     6.008350e+09
# 6     3.817229e+08
# 7     7.178919e+09
# 8     9.977625e+09
# 9     1.129931e+09
# 10    2.886102e+09
# 11    9.296581e+09
# 12   -3.301858e+09
# 13    7.998676e+08
# 14    2.248312e+09
# 15    9.439687e+09
# 16    2.009722e+07
# 17    2.200317e+09
# 18    9.316229e+08
# 19    3.211705e+08
# 20    6.259710e+09
# 21    5.609926e+09
# 22    4.799268e+08
# 23    4.816938e+10
# 24    1.048659e+09
# 25    2.551136e+09
# 26    2.445492e+10
# 27    1.355238e+10
# 28    3.070228e+09
# 29    6.919697e+09
# ...            ...
# 3644  1.291449e+09
# 3645  1.035587e+09
# 3646  3.630283e+09
# 3647  1.244394e+09
# 3648  1.095463e+09
# 3649  1.045267e+09
# 3650  5.516613e+08
# 3651  4.588333e+08
# 3652  8.790393e+08
# 3653  1.398197e+09
# 3654  1.674305e+09
# 3655  9.299815e+08
# 3656  9.712756e+08
# 3657  1.098119e+09
# 3658  1.368605e+09
# 3659  4.037803e+09
# 3660  4.211095e+09
# 3661  1.069843e+09
# 3662  1.910878e+09
# 3663  1.404538e+09
# 3664  6.625242e+08
# 3665  2.023621e+09
# 3666  4.331383e+08
# 3667  4.760800e+08
# 3668  4.996737e+10
# 3669  1.570665e+09
# 3670  1.858168e+09
# 3671  1.095419e+09
# 3672  1.749377e+09
# 3673           NaN
#
# [3674 rows x 22 columns]

# %%
DataAPI.EquGet(secID=u"",ticker=u"000001",equTypeCD=u"A",listStatusCD=u"",field=u"",pandas="1")
# Out:
#          secID  ticker exchangeCD  ListSectorCD ListSector transCurrCD  \
# 0  000001.XSHE  000001       XSHE             1         主板         CNY
#
#   secShortName secFullName listStatusCD    listDate      ...       equType  \
# 0         平安银行  平安银行股份有限公司            L  1991-04-03      ...          沪深A股
#
#   exCountryCD partyID  totalShares  nonrestFloatShares  nonrestfloatA  \
# 0         CHN       2  17170411400         17170246800    17170246800
#
#            officeAddr                                    primeOperating  \
# 0  广东省深圳市罗湖区深南东路5047号  人民币、外币存贷款;国际、国内结算;票据贴现;外汇买卖;提供担保及信用证服务;提供保管箱服务等。
#
#       endDate     TShEquity
# 0  2018-03-31  223391000000
#
# [1 rows x 22 columns]

# %% [raw]
# start = '2017-01-01'                       # 回测起始时间
# end = '2018-01-01'                         # 回测结束时间
# universe = DynamicUniverse('HS300')        # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):
#     pass
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     previous_date = context.previous_date.strftime('%Y-%m-%d')
#
#     # 获取因子PE的的历史数据集，截止到前一个交易日
#     hist = context.history(symbol=context.get_universe(exclude_halt=True), attribute='PE', time_range=1, style='tas')[previous_date]
#
#     # 将因子值从小到大排序，并取前100支股票作为目标持仓
#     signal = hist['PE'].order(ascending=True)
#     target_position = signal[:100].index
#
#     # 获取当前账户信息
#     account = context.get_account('fantasy_account')
#     current_position = account.get_positions(exclude_halt=True)
#
#     # 卖出当前持有，但目标持仓没有的部分
#     for stock in set(current_position).difference(target_position):
#         account.order_to(stock, 0)
#
#     # 根据目标持仓权重，逐一委托下单
#     for stock in target_position:
#         account.order(stock, 10000)

# %% [raw]
# start = '2017-01-01'                       # 回测起始时间
# end = '2018-01-01'                         # 回测结束时间
# universe = DynamicUniverse('HS300')        # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):
#     pass
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     previous_date = context.previous_date.strftime('%Y-%m-%d')
#
#     # 获取因子PE的的历史数据集，截止到前一个交易日
#     hist = context.history(symbol=context.get_universe(exclude_halt=True), attribute='PE', time_range=1, style='tas')[previous_date]
#
#     # 将因子值从小到大排序，并取前100支股票作为目标持仓
#     signal = hist['PE'].order(ascending=True)
#     target_position = signal[:100].index
#
#     # 获取当前账户信息
#     account = context.get_account('fantasy_account')
#     current_position = account.get_positions(exclude_halt=True)
#
#     # 卖出当前持有，但目标持仓没有的部分
#     for stock in set(current_position).difference(target_position):
#         account.order_to(stock, 0)
#
#     # 根据目标持仓权重，逐一委托下单
#     for stock in target_position:
#         account.order(stock, 10000)
