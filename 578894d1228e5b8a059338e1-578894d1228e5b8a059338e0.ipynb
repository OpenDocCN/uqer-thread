# %% [markdown]
# #

# %%
list1={}
#list1={'600519.XSHG'}
bonus = DataAPI.EquDivGet(eventProcessCD = '6',secID= list1 ,beginDate = '20150701' ,endDate='20160701' ,field=['secID','perCashDiv','recordDate'],pandas="1") 
print list1
print bonus
# Out:
# {}
#             secID  perCashDiv  recordDate
# 0     000001.XSHE    0.153000  2016-06-15
# 1     000006.XSHE    0.120000  2016-06-16
# 2     000009.XSHE    0.070000  2016-07-20
# 3     000011.XSHE    0.080000  2016-05-23
# 4     000012.XSHE    0.300000  2016-05-18
# 5     000014.XSHE    0.037000  2016-06-17
# 6     000018.XSHE         NaN  2016-06-06
# 7     000019.XSHE         NaN  2016-06-21
# 8     000021.XSHE    0.050000  2016-06-15
# 9     000026.XSHE    0.100000  2016-06-23
# 10    000027.XSHE    0.200000  2016-06-27
# 11    000028.XSHE    0.300000  2016-05-27
# 12    000030.XSHE    0.150000  2016-06-27
# 13    000032.XSHE    0.020000  2016-06-15
# 14    000033.XSHE         NaN  2016-04-14
# 15    000035.XSHE         NaN  2016-05-26
# 16    000039.XSHE    0.220000  2016-07-19
# 17    000040.XSHE    0.010000  2016-04-26
# 18    000042.XSHE    0.200072  2016-06-17
# 19    000043.XSHE    0.050000  2016-05-17
# 20    000046.XSHE    0.150000  2016-06-23
# ...
