# %% [markdown]
# # 透视表&5月9日的习题

# %%
a=DataAPI.MktIdxdGet(indexID=u"",ticker=u"399006",tradeDate=u"",beginDate=u"20160103",endDate=u"20171231",exchangeCD=u"XSHE,XSHG",field=u"ticker,CHGPct",pandas="1")
a.to_excel('a.xlsx')

# %%
import numpy as np
import pandas as pd
a='000001,000016,399005,399006,399300'
b=DataAPI.MktIdxdGet(indexID=u"",ticker=a,tradeDate=u"",beginDate=u"19901231",endDate=u"20180506",exchangeCD=u"XSHE,XSHG",field=u"ticker,secShortName,tradeDate,CHGPct",pandas="1")
# b.to_excel('b.xlsx')
c=b.pivot(index='tradeDate',columns='ticker',values='CHGPct')
print c
# Out:
# ticker        000001    000016    399005    399006    399300
# tradeDate
# 1990-12-31  0.009174       NaN       NaN       NaN       NaN
# 1991-01-02  0.009639       NaN       NaN       NaN       NaN
# 1991-01-03  0.010090       NaN       NaN       NaN       NaN
# 1991-01-04  0.009989       NaN       NaN       NaN       NaN
# 1991-01-07  0.004717       NaN       NaN       NaN       NaN
# 1991-01-08  0.004695       NaN       NaN       NaN       NaN
# 1991-01-09  0.004974       NaN       NaN       NaN       NaN
# 1991-01-10  0.004725       NaN       NaN       NaN       NaN
# 1991-01-11  0.004703       NaN       NaN       NaN       NaN
# 1991-01-14  0.000520       NaN       NaN       NaN       NaN
# 1991-01-15  0.000520       NaN       NaN       NaN       NaN
# 1991-01-16 -0.003711       NaN       NaN       NaN       NaN
# 1991-01-17  0.000074       NaN       NaN       NaN       NaN
# 1991-01-18 -0.000074       NaN       NaN       NaN       NaN
# 1991-01-21  0.000000       NaN       NaN       NaN       NaN
# 1991-01-22 -0.003874       NaN       NaN       NaN       NaN
# 1991-01-23 -0.004113       NaN       NaN       NaN       NaN
# 1991-01-24 -0.004205       NaN       NaN       NaN       NaN
# 1991-01-25 -0.004223       NaN       NaN       NaN       NaN
# 1991-01-28 -0.004468       NaN       NaN       NaN       NaN
# 1991-01-29 -0.003880       NaN       NaN       NaN       NaN
# 1991-01-30 -0.003895       NaN       NaN       NaN       NaN
# 1991-01-31 -0.003603       NaN       NaN       NaN       NaN
# 1991-02-01 -0.003539       NaN       NaN       NaN       NaN
# 1991-02-04 -0.003552       NaN       NaN       NaN       NaN
# 1991-02-05 -0.003642       NaN       NaN       NaN       NaN
# 1991-02-06  0.004355       NaN       NaN       NaN       NaN
# 1991-02-07  0.005033       NaN       NaN       NaN       NaN
# 1991-02-08  0.004546       NaN       NaN       NaN       NaN
# 1991-02-11  0.004525       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...
# 2018-03-20  0.003473  0.002465 -0.000206  0.011775  0.000849
# 2018-03-21 -0.002944 -0.003517 -0.006610 -0.018614 -0.004084
# 2018-03-22 -0.005325 -0.009506 -0.008508 -0.006932 -0.010022
# 2018-03-23 -0.033927 -0.026234 -0.040879 -0.050190 -0.028707
# 2018-03-26 -0.006039 -0.018843  0.017115  0.031627 -0.006413
# 2018-03-27  0.010507  0.003184  0.023995  0.035989  0.008602
# 2018-03-28 -0.014008 -0.019203 -0.015961 -0.005171 -0.018029
# 2018-03-29  0.012248  0.016314  0.003111  0.003833  0.013359
# 2018-03-30  0.002647 -0.006075  0.011156  0.031644  0.001142
# 2018-04-02 -0.001804 -0.003960 -0.006338 -0.000119 -0.002970
# 2018-04-03 -0.008392 -0.005201 -0.006907 -0.014621 -0.006288
# 2018-04-04 -0.001760  0.001890 -0.008845 -0.019043 -0.001972
# 2018-04-09  0.002294  0.004945 -0.004056  0.002636 -0.000501
# 2018-04-10  0.016578  0.023961  0.013114 -0.003330  0.019269
# 2018-04-11  0.005567  0.001631  0.004114 -0.000488  0.002845
# 2018-04-12 -0.008704 -0.012796 -0.007516 -0.004217 -0.010082
# 2018-04-13 -0.006637 -0.008475 -0.003876 -0.001256 -0.007051
# 2018-04-16 -0.015322 -0.022627 -0.004315  0.007735 -0.016089
# 2018-04-17 -0.014097 -0.010883 -0.030236 -0.029895 -0.015811
# 2018-04-18  0.008022  0.006854  0.011776  0.021597  0.004706
# 2018-04-19  0.008403  0.010846  0.008280 -0.001089  0.012097
# 2018-04-20 -0.014703 -0.013113 -0.016400 -0.020586 -0.013376
# 2018-04-23 -0.001149  0.006626 -0.012451 -0.016693  0.001455
# 2018-04-24  0.019855  0.021738  0.019640  0.030697  0.020488
# 2018-04-25 -0.003501 -0.007296 -0.000044  0.006944 -0.003847
# 2018-04-26 -0.013773 -0.013672 -0.024385 -0.020957 -0.019121
# 2018-04-27  0.002342 -0.004681  0.008368  0.013653  0.000368
# 2018-05-02 -0.000342 -0.000306  0.005640 -0.002229  0.001802
# 2018-05-03  0.006388  0.004239  0.009361  0.013999  0.007799
# 2018-05-04 -0.003169 -0.006614  0.003548 -0.006534 -0.004852
#
# [6685 rows x 5 columns]

# %%
import numpy as np
import pandas as pd
from pandas import Series
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
from sklearn.linear_model import LinearRegression
import scipy.optimize as sco

pd.options.display.width = 2000
secid ='601857,600036'
return_mat=DataAPI.MktEqudAdjGet(ticker=secid,beginDate='20130506', endDate='20180506', field=u"ticker,tradeDate,closePrice",pandas="1").pivot(index='tradeDate',columns='ticker',values='closePrice').pct_change().dropna()                                                                                                                      
means=return_mat.mean()*252
print'means:'
print means
cov=return_mat.cov()*252
print'cov:'
print cov
port_returns = []
port_variance = []

for p in range(4000):
        weights = np.random.random(2)
        weights /=np.sum(weights)
        port_returns.append(np.sum(means*weights))
        port_variance.append(np.sqrt(np.dot(weights.T, np.dot(cov, weights))))
port_returns3 = np.array(port_returns)
port_variance3 = np.array(port_variance)
plt.figure(figsize = (8,4))
print plt.scatter(port_variance3, port_returns3,color='b',marker='o')
risk_free = 0.04
sec_num = len(means)
def random_combination():
    sec_num = len(means)
    random_rets = []
    random_stds = []
    for i in range(40000):
        weights = np.random.random(sec_num)
        weights = weights / np.sum(weights)
        ret, std, _ = statistic(weights)
        random_rets.append(ret)
        random_stds.append(std)
    return(random_rets, random_stds)
def statistic(weights, means=means, cov=cov):
    sec_num = len(means)
    weights = np.asmatrix(weights).T
    means = np.asmatrix(means).T
    cov = np.asmatrix(cov)
    ret = float(weights.T * means)
    std = float(np.sqrt(weights.T * cov * weights))
    sharpe = (ret - risk_free) / std
    return(ret, std, sharpe)
def efficiency_frontier(means=means, cov=cov):
    sec_num = len(means)
    min_ret = means.min()
    max_ret = means.max()
    rets = []
    stds = []
    for ret_level in np.linspace(min_ret, max_ret, 200):
        P = matrix(2 * cov.values)
        q = matrix(np.zeros(sec_num))
        G = matrix(-np.eye(sec_num))
        h = matrix(np.zeros(sec_num))
        A = matrix(np.array([np.ones(sec_num),means.values]))
        b = matrix([1.0,ret_level])
        solvers.options['show_progress'] = False
        sol = solvers.qp(P,q,G,h,A,b)
        rets.append(ret_level)
        stds.append(np.sqrt(sol['primal objective']))
    return(rets, stds)
def min_sharpe(weights):
    return(-statistic(weights)[2])
from cvxopt import solvers, matrix
cons = {'type':'eq', 'fun':lambda x:np.sum(x) - 1.0}
bnds = sec_num * ((0,1),)
opts = sco.minimize(min_sharpe, sec_num*[1.0/sec_num], method='SLSQP', bounds=bnds, constraints=cons)
orp_ret, orp_std, orp_sharpe = statistic(opts['x'])
rets, stds= efficiency_frontier()
random_rets, random_stds=random_combination()

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
plt.plot(0,risk_free,'k*',markersize=10)              #无风险资产
ax.plot(stds,rets)                                    #有效边界
ax.plot(orp_std,orp_ret,'r*',markersize=10)           #最优风险组合
plt.scatter(random_stds, random_rets, c=np.array(random_rets)/np.array(random_stds),color='b')  #随机组合
plt.colorbar(label='Sharpe Ratio')
plt.plot((0,orp_std),(risk_free,orp_ret),c='r')
ax.set_xlim(0,0.5)
plt.show()
# Out:
# means:
# ticker
# 600036    0.266059
# 601857    0.040580
# dtype: float64
# cov:
# ticker    600036    601857
# ticker
# 600036  0.089809  0.042545
# 601857  0.042545  0.077779
# <matplotlib.collections.PathCollection object at 0xaa35790>
