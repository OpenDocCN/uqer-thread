# %% [markdown]
# # 简单预计盈增买入

# %% [markdown]
# 选取A股中所有业绩预告是盈增的股票，每只股票持有20天，保持组合内各股票等权。

# %% [raw]
# import numpy as np
# import pandas as pd
# from CAL.PyCAL import *
# start = '2013-01-01'                       # 回测起始时间
# end = '2016-03-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('A')               #证券池，支持股票和基金
# capital_base = 100000000                    # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# cal = Calendar('China.SSE')
# period = '-1B'
# day_count = {}
# for stk in universe:
#     day_count[stk] = 0
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     yestoday = cal.advanceDate(account.current_date, period, BizDayConvention.Unadjusted)
#     begin_date = cal.advanceDate(account.current_date, '-1Y', BizDayConvention.Unadjusted)
#     profit_up = DataAPI.FdmtEfGet(secID=account.universe,publishDateBegin=begin_date.strftime('%Y%m%d'),publishDateEnd=account.current_date.strftime('%Y%m%d'),forecastType="21",field=['secID','actPubtime',],pandas="1")
#
#     fil_profit = profit_up[profit_up['actPubtime'].map(lambda x: x[0:10]) == yestoday.strftime('%Y-%m-%d')]
#
#     buy_list = fil_profit['secID'].tolist()
#
#     total_money = account.referencePortfolioValue
#     prices = account.referencePrice
#     reserve_stk = account.avail_secpos.keys()
#
#     for stk in account.avail_secpos:
#         if stk not in buy_list and day_count[stk] == 20:      #每只股票持有20天
#
#             order_to(stk,0)
#             day_count[stk] = 0
#
#             reserve_stk.remove(stk)
#
#     buylist = buy_list + reserve_stk
#     #所有股票一起等权
#     for stk in reserve_stk:
#
#         if np.isnan(prices[stk]) or prices[stk] == 0:  # 停牌或是还没有上市等原因不能交易
#             continue
#         order_to(stk,total_money / prices[stk] /len(buylist)) #等权买入
#         day_count[stk] = day_count[stk] + 1
#
#     for stk in buy_list:
#
#         if np.isnan(prices[stk]) or prices[stk] == 0:  # 停牌或是还没有上市等原因不能交易
#             continue
#         order_to(stk,total_money / prices[stk] /len(buylist)) #等权买入
#         day_count[stk] = day_count[stk] + 1
