# %% [markdown]
# #  ‘双均线策略回测模板’ - StudyQuant

# %% [raw]
# #当5日均线上穿30日均线，买入
# #当5日均线下穿30日均线，卖出
#
# start = '2017-01-01'                       # 回测起始时间
# end = '2017-12-28'                         # 回测结束时间
# universe = ['000513.XSHE']        # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 1                           # 执行handle_data的时间间隔
#
# commission = Commission(buycost=0.0003, sellcost=0.0013, unit='perValue')
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=20000,commission=commission)
# }
#
#
#
# def initialize(context):                   # 初始化策略运行环境
#     context.account = context.get_account('fantasy_account')
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#
#     hist5=context.history(symbol=universe[0],attribute='closePrice',time_range=5,freq='1d',rtype='array', style='sat' )['000513.XSHE']['closePrice']
#     hist30=context.history(symble=universe[0],attribute='closePrice',time_range=30,freq='1d',rtype='array',style='sat')['000513.XSHE']['closePrice']
#     MA5=hist5.mean()
#     MA30=hist30.mean()
#     if MA5>MA30:
#         context.account.order(symbol=universe[0], amount=100, otype='market')
#     if MA5<MA30:
#         context.account.order_to(symbol=universe[0], amount=0, otype='market')

# %% [markdown]
# ## 更多量化学习资源
# ![介绍.png](http://storage-uqer.datayes.com/5a7d387d678b4b0114b180e2/097fc006-fe1d-11e8-9ee0-0242ac140002)
# 扫上方二维码，关注公众账号 量化投资学院 ，获取下列免费资源
# - 回复**“热点研报”**，获取近年热点券商金融工程研究报告
# - 回复**“Python3”**，获取Python免费学习教程
# - 回复**“Python”**，获取免费Python量化投资入门课程
#
# *   [更多福利请点击此链接](https://www.jianshu.com/p/2ffb29f1a1aa)
#
#
# ## 关注StudyQuant
# *   [课程](http://study.163.com/provider/400000000342001/index.htm?share=2&shareId=400000000342001)
# --[量化投资与数据分析实战](http://study.163.com/course/introduction/1004855008.htm?share=2&shareId=400000000342001)
# --[量化投资与数字货币实战](http://study.163.com/course/courseMain.htm?courseId=1005630014&share=2&shareId=400000000342001#/courseDetail?tab=1)
# --[免费Python及量化投资公开课](https://www.jianshu.com/p/0342b36433f7)
#
# *   [知乎](https://zhuanlan.zhihu.com/studyquant)
# *   [简书](https://www.jianshu.com/u/495eda774816)
# *   [公众号](https://mp.weixin.qq.com/s__biz=MzU5NzU5NjIwMQ==&mid=100000028&idx=1&sn=2f8c053849f296455ec85406e80b2a2d&chksm=7e50405a4927c94c18ba438e0c309a7d13883621ddf02904266026556e9994ad1c3f8558327d&mpshare=1&scene=1&srcid=0810AEevB9zID4Ywzl1icPfA#rd)
