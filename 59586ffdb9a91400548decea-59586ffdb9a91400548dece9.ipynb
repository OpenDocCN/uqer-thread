# %% [markdown]
# # Notebook

# %% [raw]
# import quartz
# import CAL.PyCAL as cal
# import numpy as np
# start = '2016-01-01' #回测开始时间
# end = '2017-06-20'  # 回测结束时间
# from matplotlib import pylab
# import seaborn as sns
# from CAL.PyCAL import *
# cal = Calendar('China.SSE')
# period = Period('-1B')
# benchmark = "HS300"                  # 策略对标标的
# universe = set_universe('SH50',date='20160105')
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# period1 = 5
# period2 = 30
# commission = Commission(buycost=0.0003, sellcost=0.0013, unit='perValue')
# max_history_window = 100                 #设定调取历史价格区间最大为100个交易日
#
#
# def initialize(account):
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#    today = account.current_date
#    today = Date.fromDateTime(account.current_date)
#    yesterday=cal.advanceDate(today, period)
#    buylist = []
#    selllist = []
#    addlist = []
#    pricedict={}
#    for s in account.universe:
#         try:
#            factorDataframe1=DataAPI.MktEqudGet(tradeDate=yesterday,secID=s,field=u"closePrice",pandas="1")
#            factorDataframe2=DataAPI.MktStockFactorsOneDayGet(tradeDate=yesterday,secID=s,field=u"secID,EMA10,EMA60,HSIGMA",pandas="1")
#            closeprice=factorDataframe1['closePrice'][0]
#            pricedict[s]=closeprice
#            EMA10=factorDataframe2['EMA10'][0]
#            EMA60=factorDataframe2['EMA60'][0]
#            if closeprice>EMA10*1.03 and EMA10>EMA60*1.03 :
#               addlist.append(s)
#            if closeprice>EMA10*1.01 and EMA10>EMA60*1.01 :
#               buylist.append(s)
#            elif closeprice*1.01<EMA10 and EMA10*1.01<EMA60 :
#               selllist.append(s)
#         except:
#             print "error"
#    for s in selllist:
#        if s in account.security_position:
#          account.order_pct_to(s, 0)
#    if len(buylist)>0:
#        print(pricedict[s])
#        ordernumber=min(round(5000/pricedict[s]),1000)
#        ordernumber=max(ordernumber,100)
#        for s in buylist:
#          if s  not in account.security_position:
#            account.order(s,ordernumber)
#        for s in addlist:
#          if s in account.security_position:
#            account.order(s,ordernumber)
#    print(account.current_date)
#    print(account.cash)
