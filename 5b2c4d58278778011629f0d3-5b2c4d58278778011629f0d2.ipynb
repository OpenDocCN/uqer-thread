# %% [markdown]
# # 测试策略1

# %% [raw]
# import pandas as pd
# start = '2017-09-01'                     # 回测起始时间
# end = '2018-01-01'                       # 回测结束时间
# universe = ['YZ0','MZ0'] # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                       # 策略参考基准
# freq = 'd'                               # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 5                       # 执行handle_data的时间间隔
# max_history_window = 100
#
# accounts = {
#     'futures_account': AccountConfig(account_type='futures', capital_base=10000000)
# }
#
# def initialize(context):                 # 初始化策略运行环境
#     context.amount = 1
#
# def handle_data(context):                # 核心策略逻辑
#     futures_account = context.get_account('futures_account')
#     current_universe = context.get_universe('futures')
#     current_positions = futures_account.get_positions()
#     history = context.history(symbol='all', time_range=40, attribute='closePrice', freq='d', style='ast')['closePrice']
#
#     print history
