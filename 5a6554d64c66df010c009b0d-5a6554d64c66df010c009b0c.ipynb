# %% [markdown]
# # Test

# %%
#pure test
import pandas as pd
import numpy as np
import talib
import time
import datetime as dt
from CAL.PyCAL import *
import lib.report as report
import matplotlib as mpl  
import matplotlib.pyplot as plt  

yesterday = "20180119"
dayBeforeYesterday = "20180118"

XQ_data1 = DataAPI.SocialDataXQGet(ticker="",beginDate=yesterday,endDate=yesterday,field=u"",pandas="1")
print XQ_data1
#XQ_data2 = DataAPI.SocialDataXQGet(ticker="",beginDate=dayBeforeYesterday,endDate=dayBeforeYesterday,field=u"",pandas="1")  
#print XQ_data2
#XQ_data1['Diff'] = XQ_data1['postPercent'] - XQ_data2['postPercent']

#XQ_data1 = XQ_data1.sort(columns='Diff',ascending=False)
#print XQ_data1.head(20)

#Guba_data1 = DataAPI.SocialDataGubaGet(ticker="",beginDate=yesterday,endDate=yesterday,field=u"",pandas="1")
#Guba_data2 = DataAPI.SocialDataGubaGet(ticker="",beginDate=dayBeforeYesterday,endDate=dayBeforeYesterday,field=u"",pandas="1")  
#Guba_data1['Diff'] =  Guba_data1['postPercent'] - Guba_data2['postPercent']

#Guba_data1 = Guba_data1.sort(columns='Diff',ascending=False)
#print Guba_data1.head(20)

#XQ_change = XQ_data1['Diff']
##Guba_change = Guba_data1['Diff']
#all_change = XQ_change + Guba_change


#themeData = DataAPI.TkgThemeHotGet(themeID=u"",beginDate=u"20171230",endDate=u"20180110",field=u"",pandas="1")
#print themeData[themeData['hotScore']>0.99].sort(columns=['hotScore','newsThemeMatchChgPct'],ascending=[False,False])


#themeStock = DataAPI.TkgThemeTickerRelGet(themeID=u"279",secID=u"",ticker=u"",exchangeCD=u"",field=u"",pandas="1")
#print themeStock
# Out:
#       ticker       statisticsDate  postNum  postPercent           insertTime  \
# 0     000001  2018-01-19 00:00:00      NaN            0  2018-01-20 07:04:13
# 1     000002  2018-01-19 00:00:00      NaN            0  2018-01-20 07:04:13
# 2     000004  2018-01-19 00:00:00      NaN            0  2018-01-20 07:04:13
# 3     000005  2018-01-19 00:00:00      NaN            0  2018-01-20 07:04:13
# 4     000006  2018-01-19 00:00:00      NaN            0  2018-01-20 07:04:13
# 5     000007  2018-01-19 00:00:00      NaN            0  2018-01-20 07:04:13
# 6     000008  2018-01-19 00:00:00      NaN            0  2018-01-20 07:04:13
# 7     000009  2018-01-19 00:00:00      NaN            0  2018-01-20 07:04:13
# 8     000010  2018-01-19 00:00:00      NaN            0  2018-01-20 07:04:13
# 9     000011  2018-01-19 00:00:00      NaN            0  2018-01-20 07:04:13
# 10    000012  2018-01-19 00:00:00      NaN            0  2018-01-20 07:04:13
# ...
