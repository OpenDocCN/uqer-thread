# %% [markdown]
# # 关于新闻热度API的一个疑问

# %% [markdown]
# 请问历史上某天新闻热度API里的sentimentIndex或heatIndex，获取的值是insertTime当时的值还是updateTime那个时间点的值？
# insertTime一般都是当天早上或者之前一天，updateTime都是未来的时间，如果获取的是updateTime，那不是用到了未来数据？

# %%
DataAPI.NewsSentimentIndexGet(exchangeCD=u"",ticker=u"600000",secShortName=u"",beginDate=u"20160406",endDate=u"20160406",secID="",field=u"",pandas="1")
# Out:
#          secID exchangeCD exchangeName  ticker secShortName newsPublishDate  \
# 0  600000.XSHG       XSHG      上海证券交易所  600000         浦发银行      2016-04-06
#
#    sentimentIndex           insertTime           updateTime
# 0       -0.004434  2016-04-06 08:33:44  2016-04-08 08:31:25

# %%
DataAPI.NewsHeatIndexGet(exchangeCD=u"",ticker=u"600000",secShortName=u"",beginDate=u"20160406",endDate=u"20160406",secID="",field=u"",pandas="1")
# Out:
#          secID exchangeCD exchangeName  ticker secShortName newsPublishDate  \
# 0  600000.XSHG       XSHG      上海证券交易所  600000         浦发银行      2016-04-06
#
#    heatIndex           insertTime           updateTime
# 0   2.089069  2016-04-06 08:33:44  2016-04-08 08:31:25
