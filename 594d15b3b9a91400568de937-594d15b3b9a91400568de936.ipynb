# %% [markdown]
# # 答辩_pearson回测

# %% [markdown]
# 导入因子数据

# %%
import pandas as pd
import numpy as np
fac1 = pd.read_csv('cap_0716.csv')
fac2 = pd.read_csv('pearson_0716.csv')
fac3 = pd.read_csv('R_07_17.csv')

# %% [markdown]
# 因子数据样式

# %%
print fac1.head()
print fac2.head()
print fac3.head()
# Out:
#    Unnamed: 0   tradeDate   000001.XSHE   000002.XSHE   000004.XSHE  \
# 0           0  2007-01-04  2.745555e+10  6.764603e+10  3.409453e+08
# 1           1  2007-01-05  2.541244e+10  6.489300e+10  3.384260e+08
# 2           2  2007-01-08  2.601564e+10  6.681575e+10  3.485032e+08
# 3           3  2007-01-09  2.685235e+10  6.817042e+10  3.560611e+08
# 4           4  2007-01-10  2.739718e+10  7.498746e+10  3.535418e+08
#
#     000005.XSHE   000006.XSHE   000007.XSHE   000008.XSHE   000009.XSHE  \
# 0  2.258404e+09  3.474205e+09  4.365183e+08  3.063973e+08  4.055766e+09
# 1  2.294977e+09  3.568034e+09  4.494658e+08  3.115531e+08  4.036590e+09
# 2  2.368124e+09  3.677079e+09  4.698120e+08  3.203915e+08  4.113295e+09
# 3  2.432127e+09  3.765836e+09  4.753610e+08  3.226011e+08  4.314645e+09
# 4  2.550991e+09  3.808946e+09  4.827596e+08  3.550085e+08  4.400938e+09
#
#       ...       603987.XSHG  603988.XSHG  603989.XSHG  603990.XSHG  \
# 0     ...               NaN          NaN          NaN          NaN
# 1     ...               NaN          NaN          NaN          NaN
# 2     ...               NaN          NaN          NaN          NaN
# 3     ...               NaN          NaN          NaN          NaN
# 4     ...               NaN          NaN          NaN          NaN
#
#    603991.XSHG  603993.XSHG  603996.XSHG  603997.XSHG  603998.XSHG  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    603999.XSHG
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 3268 columns]
#    Unnamed: 0   tradeDate  000001.XSHE  000002.XSHE  000004.XSHE  000005.XSHE  \
# 0           0  2007-01-04          NaN          NaN          NaN          NaN
# 1           1  2007-01-05          NaN          NaN          NaN          NaN
# 2           2  2007-01-08          NaN          NaN          NaN          NaN
# 3           3  2007-01-09          NaN          NaN          NaN          NaN
# 4           4  2007-01-10          NaN          NaN          NaN          NaN
#
#    000006.XSHE  000007.XSHE  000008.XSHE  000009.XSHE     ...       \
# 0          NaN          NaN          NaN          NaN     ...
# 1          NaN          NaN          NaN          NaN     ...
# 2          NaN          NaN          NaN          NaN     ...
# 3          NaN          NaN          NaN          NaN     ...
# 4          NaN          NaN          NaN          NaN     ...
#
#    603987.XSHG  603988.XSHG  603989.XSHG  603990.XSHG  603991.XSHG  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    603993.XSHG  603996.XSHG  603997.XSHG  603998.XSHG  603999.XSHG
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 3265 columns]
#    Unnamed: 0   tradeDate  000001.XSHE  000002.XSHE  000004.XSHE  000005.XSHE  \
# 0           0  2007-01-04          NaN          NaN          NaN          NaN
# 1           1  2007-01-05          NaN          NaN          NaN          NaN
# 2           2  2007-01-08          NaN          NaN          NaN          NaN
# 3           3  2007-01-09          NaN          NaN          NaN          NaN
# 4           4  2007-01-10          NaN          NaN          NaN          NaN
#
#    000006.XSHE  000007.XSHE  000008.XSHE  000009.XSHE     ...       \
# 0          NaN          NaN          NaN          NaN     ...
# 1          NaN          NaN          NaN          NaN     ...
# 2          NaN          NaN          NaN          NaN     ...
# 3          NaN          NaN          NaN          NaN     ...
# 4          NaN          NaN          NaN          NaN     ...
#
#    603987.XSHG  603988.XSHG  603989.XSHG  603990.XSHG  603991.XSHG  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    603993.XSHG  603996.XSHG  603997.XSHG  603998.XSHG  603999.XSHG
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 3265 columns]

# %% [markdown]
# 得到各因子的五分位回测效果，并且保存，具体做法在上一帖子

# %% [raw]
# import pandas as pd
# #调仓周期5天，最大百分位
#
#
# start = '2007-01-01'                       # 回测起始时间
# end = '2013-12-31'                         # 回测结束时间
# benchmark = 'SHCI'                        # 策略参考标准
# universe = set_universe('A')               # 证券池，支持股票和基金
# capital_base = 100000000                    # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测
# refresh_rate =  20                       # 调仓频率，表示执行handle_data的时间间隔
#
# p_data = pd.read_csv('R_SY_07_17.csv')
# #p_data2 = pd.read_csv('zengliang5.csv')
#
# p_data = p_data[p_data.columns[1:]].set_index('tradeDate')
# #p_data2 = p_data2[p_data2.columns[1:]].set_index('tradeDate')
#
# #p_data = p_data1*p_data2
#
# #p_data = p_data[973:]        #：1457 是09-1-5    1000: 是130219开始至今
# p_dates = p_data.index.values
# result=pd.DataFrame()
# commission = Commission(0.0002,0.0002)     # 交易费率设为双边万分之二
#
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     pre_date = account.previous_date.strftime("%Y-%m-%d")
#     if pre_date not in p_dates:           # Q因子只在每个月底计算，所以调仓也在每月最后一个交易日进行
#         return
#
#         # 拿取调仓日前一个交易日的Q因子，并按照相应十分位选择股票
#     p = p_data.ix[pre_date].dropna()
#     p_min = p.quantile(0)     #乘以 0.9-1 1和5 不行，   乘以 0.1-0 5 不行，
#     p_max = p.quantile(0.2)
#     my_univ = p[p>=p_min][p<p_max].index.values
#
#         # 调仓逻辑
#     univ = [x for x in my_univ if x in account.universe]
#
#         # 不在股票池中的，清仓
#     for stk in account.valid_secpos:    #valid_secpos
#         if stk not in univ:
#             order_to(stk, 0)
#         # 在目标股票池中的，等权买入
#     for stk in univ:
#         order_pct_to(stk, 1.1/len(univ))
#
# #注意！回测后会得到三个重要文件，最有用的为bt！

# %% [markdown]
# 回测结果指标

# %%
print perf['benchmark_annualized_return']
print perf['annualized_return']
print perf['treasury_return']
print perf['excess_return']
print perf['alpha']
print perf['beta']
print perf['sharpe']
print perf['volatility']
print perf['max_drawdown']
print perf['information_coefficient']
print perf['information_ratio']
print perf['turnover_rate']
# Out:
# 0.139565649166
# 0.223531432305
# 0.04606
# 0.177471432305
# 0.0915701598296
# 0.918674681604
# 0.545505525481
# 0.325333885754
# 0.492846537008
# 0.000283396962304
# 0.422555134544
# 23.8833298921

# %%
bt.to_csv('R_bt_1416_2.csv')

# %%
print bt.loc[0,'security_position'].keys()[0]
# Out:
# 002233.XSHE

# %% [markdown]
# 下面是三因子筛选法策略效果，print出来的结果显示，优矿的account不是买卖后立刻更新的，是调用完handle_data后更新的

# %% [raw]
# import pandas as pd
# start = '2007-01-01'                       # 回测起始时间
# end = '2013-12-30'                         # 回测结束时间
# benchmark = 'SHCI'                        # 策略参考标准
# universe = set_universe('A')               # 证券池，支持股票和基金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测
# refresh_rate =  20                       # 调仓频率，表示执行handle_data的时间间隔
# #capital_base=10000000
# accounts = {'stock_account': AccountConfig(account_type='security', capital_base=10000000)}
#
# p_data = pd.read_csv('pearson_0716.csv')
# r_data = pd.read_csv('R_07_17.csv')
# c_data = pd.read_csv('cap_0716.csv')
# p_data = p_data[p_data.columns[1:]].set_index('tradeDate')
# r_data = r_data[r_data.columns[1:]].set_index('tradeDate')
# c_data = c_data[c_data.columns[1:]].set_index('tradeDate')
#
# p_dates = p_data.index.values
# commission = Commission(0.0002,0.0002)     # 交易费率设为双边万分之二
#
#
# def initialize(context):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(context):                  # 每个交易日的买入卖出指令
#     account = context.get_account('stock_account')
#
#     pre_date = context.previous_date.strftime("%Y-%m-%d")
#     if pre_date not in p_dates:           # Q因子只在每个月底计算，所以调仓也在每月最后一个交易日进行
#         return
#
#         # 拿取调仓日前一个交易日的Q因子，并按照相应十分位选择股票
#     p = p_data.ix[pre_date].dropna()
#     r = r_data.ix[pre_date].dropna()
#     c = c_data.ix[pre_date].dropna()
#
#     p_min = p.quantile(0)     #乘以 0.9-1 1和5 不行，   乘以 0.1-0 5 不行，
#     p_max = p.quantile(0.2)
#
#     r_min = r.quantile(0.8)
#     r_max = r.quantile(1)
#
#     c_min = c.quantile(0)
#     c_max = c.quantile(0.4)
#
#     my_univ1 = p[p>=p_min][p<p_max].index.values
#     my_univ2 = r[r>=r_min][r<r_max].index.values
#     my_univ3 = c[c>=c_min][c<c_max].index.values
#
#     my_univ4 = [stk for stk in my_univ2 if stk in my_univ1]
#     univ = [stk for stk in my_univ4 if stk in my_univ3]
#     print '-------------------------符合条件的个股------------------------------'
#     print len(univ)
#
#         # 调仓逻辑
#     #univ = [x for x in my_univ if x in account.universe]
#
#     # 不在股票池中的，清仓
#     sell_list = account.get_positions() #获取stock_account账户的股票持仓
#     print '------------------------仍然在仓的个股数，全清仓--------------------------'
#     print len(sell_list.keys())
#     for stk1 in sell_list.keys():
#         account.order_to(stk1, 0) #将所有股票逐一卖出
#         # 在目标股票池中的，等权买入
#     print '-----------------------全卖出后的仓位个股数量-----------------------------'
#     print len(sell_list.keys())
#     for stk2 in univ:
#         order_pct_to(stk2, 1.1/len(univ))
#     print '-----------------------调仓后的个股数量-----------------------------------'
#     print len(sell_list.keys())
#
# #注意！回测后会得到三个重要文件，最有用的为bt！

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from CAL.PyCAL import *    # CAL.PyCAL中包含font

fig = plt.figure(figsize=(10,8))
fig.set_tight_layout(True)
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)
ax1.grid()
ax2.grid()


A = pd.read_csv('R_bt_1416_2.csv')
B = pd.read_csv('R_bt_1416_4.csv')
C = pd.read_csv('R_bt_1416_6.csv')
D = pd.read_csv('R_bt_1416_8.csv')
E = pd.read_csv('R_bt_1416_10.csv')


A = A[A.columns[1:]]
B = B[B.columns[1:]]
C = C[C.columns[1:]]
D = D[D.columns[1:]]
E = E[E.columns[1:]]

all_data = {}
all_data[0] = A
all_data[1] = B
all_data[2] = C
all_data[3] = D
all_data[4] = E


for i in all_data:
    
    all_data[i]['portfolio_return'] = all_data[i].portfolio_value/all_data[i].portfolio_value.shift(1) - 1.0
    all_data[i]['portfolio_return'].ix[0] = all_data[i]['portfolio_value'].ix[0]/10000000.0 - 1.0
    all_data[i]['excess_return'] = all_data[i].portfolio_return - A.benchmark_return                 # 总头寸每日超额回报率
    all_data[i]['excess'] = all_data[i].excess_return + 1.0
    all_data[i]['excess'] = all_data[i].excess.cumprod()                # 总头寸对冲指数后的净值序列
    all_data[i]['portfolio'] = all_data[i].portfolio_return + 1.0     
    all_data[i]['portfolio'] = all_data[i].portfolio.cumprod()          # 总头寸不对冲时的净值序列
    all_data[i]['benchmark'] = all_data[i].benchmark_return + 1.0
    all_data[i]['benchmark'] = all_data[i].benchmark.cumprod()          # benchmark的净值序列
    all_data[i].tradeDate= pd.to_datetime(all_data[i].tradeDate)  #把日期变成plot可以识别的日期形式，改变前为str

    ax1.plot(all_data[i]['tradeDate'], all_data[i][['portfolio']], label=str(i+1))
    ax2.plot(all_data[i]['tradeDate'], all_data[i][['excess']], label=str(i+1))

ax1.plot(all_data[i]['tradeDate'], all_data[i][['benchmark']], label='b')

    
    

ax1.legend(loc=0, fontsize=12)
ax2.legend(loc=0, fontsize=12)
ax1.set_ylabel(u"净值", fontproperties=font, fontsize=16)
ax2.set_ylabel(u"对冲净值", fontproperties=font, fontsize=16)
ax1.set_title(u"五分位的走势", fontproperties=font, fontsize=16)
ax2.set_title(u"五分位对冲全A股指数后净值走势", fontproperties=font, fontsize=16)

#最后运行出R和P百分位与大盘收盘价的对比图     和     某个股P因子与股价的对比图   R因子与股价的对比图
#需要 两个IC图  IC均值 中位数 


#为什么要选流通市值小的股票呢？不用考虑小市值暴露的风险吗？
#因为R平方因子和P因子选出来的股票是代表着有资金量进场的，而同样的资金量进入小市值的股票，其能拉升的幅度越大。
#所以我们就选取了市值小的股票，这策略在最近小市值因子失效的市场中，应该还是表现不错的。
#因为我们不是看重了小市值这个策略万金油，而是为了使P因子和R因子更有效。

# %%
import datetime

def plot_return(bt, title):
    bt['portfolio_return'] = bt['portfolio_value']/bt['portfolio_value'].shift(1) - 1.0
    bt['excess_return'] = bt.portfolio_return - bt.benchmark_return                 # 总头寸每日超额回报率
    bt['excess'] = bt.excess_return + 1.0
    bt['excess'] = bt.excess.cumprod()                # 总头寸对冲指数后的净值序列
       
    month_date = [bt.ix[0,'tradeDate']]
    
    portfolio_value = [bt.ix[0, 'portfolio_value']]
    portfolio_excess= [bt.ix[0, 'excess']]
    for i in range(len(bt)-1):
        date1 = datetime.datetime.strptime(bt.ix[i+1,'tradeDate'], '%Y-%m-%d')
        date1_mon = date1.month
        date2 = datetime.datetime.strptime(month_date[-1],'%Y-%m-%d')
        date2_mon = date2.month
        if date1_mon != date2_mon :
            month_date.append(bt.ix[i+1,'tradeDate'])
            portfolio_value.append(bt.ix[i+1, 'portfolio_value'])
            portfolio_excess.append(bt.ix[i+1, 'excess'])
    results = pd.DataFrame(data=portfolio_value, columns=['portfolio_value'])
    results['monthly_return'] = results['portfolio_value']/results['portfolio_value'].shift(1)-1
    results['cumulative_return'] = portfolio_excess
    results['monthly_return_1'] = results['cumulative_return']/results['cumulative_return'].shift(1)-1
    
    right = 0
    for ind in results.index:
        if results.ix[ind,'monthly_return_1']>0:
            right = right+1
    print '胜利月数：'
    print right
    print '总月度数:'
    print results.shape[0]
          
        
    month_date = [datetime.datetime.strptime(m,'%Y-%m-%d')  for m in month_date]
    results.index = month_date
    results.dropna(inplace=True)
    
    fig = plt.figure(figsize=(14, 5))
    ax1 = fig.add_subplot(111)
    ax2 = ax1.twinx()
    lns2 = ax1.plot(results.index, results['cumulative_return'], 'r')
    lns1 = ax2.bar(results.index, results['monthly_return_1'], align='center', width=10, color='b')
    ax2.legend(lns1, ['monthly return(right axis)'], loc=1, fontsize=12)
    ax1.legend(lns2, ['excess return(left axis)'], loc=2, fontsize=12)
    ax1.set_ylabel(u'组合净值/基准净值', fontproperties=font, fontsize=16)
    ax2.set_ylabel(u'月度收益率', fontproperties=font, fontsize=16)
    ax1.set_xlabel(u'时间', fontproperties=font, fontsize=16)
    ax2.set_yticklabels([str(x*100)+'0%' for x in ax2.get_yticks()], fontproperties=font, fontsize=14)
    s = ax1.set_title(title, fontproperties=font, fontsize=16)
    
    return ax1, ax2


hh = pd.read_csv('pearson_bt_0713.csv')
hh = hh[hh.columns[1:]]
s = plot_return(hh, u'P因子10%~20%百分位数07年到13年月度表现')
# Out:
# 胜利月数：
# 54
# 总月度数:
# 84

# %%
import datetime

def plot_return(bt, title):
    bt['portfolio_return'] = bt['portfolio_value']/bt['portfolio_value'].shift(1) - 1.0
    bt['excess_return'] = bt.portfolio_return - bt.benchmark_return                 # 总头寸每日超额回报率
    bt['excess'] = bt.excess_return + 1.0
    bt['excess'] = bt.excess.cumprod()                # 总头寸对冲指数后的净值序列
       
    month_date = [bt.ix[0,'tradeDate']]
    
    portfolio_value = [bt.ix[0, 'portfolio_value']]
    portfolio_excess= [bt.ix[0, 'excess']]
    for i in range(len(bt)-1):
        date1 = datetime.datetime.strptime(bt.ix[i+1,'tradeDate'], '%Y-%m-%d')
        date1_mon = date1.month
        date2 = datetime.datetime.strptime(month_date[-1],'%Y-%m-%d')
        date2_mon = date2.month
        if date1_mon != date2_mon :
            month_date.append(bt.ix[i+1,'tradeDate'])
            portfolio_value.append(bt.ix[i+1, 'portfolio_value'])
            portfolio_excess.append(bt.ix[i+1, 'excess'])
    results = pd.DataFrame(data=portfolio_value, columns=['portfolio_value'])
    results['monthly_return'] = results['portfolio_value']/results['portfolio_value'].shift(1)-1
    results['cumulative_return'] = portfolio_excess
    results['monthly_return_1'] = results['cumulative_return']/results['cumulative_return'].shift(1)-1
    month_date = [datetime.datetime.strptime(m,'%Y-%m-%d')  for m in month_date]
    results.index = month_date
    results.dropna(inplace=True)
    
    right = 0
    for ind in results.index:
        if results.ix[ind,'monthly_return_1']>0:
            right = right+1
    print '胜利月数：'
    print right
    print '总月度数:'
    print results.shape[0]
    
    
    fig = plt.figure(figsize=(14, 5))
    ax1 = fig.add_subplot(111)
    ax2 = ax1.twinx()
    lns2 = ax1.plot(results.index, results['cumulative_return'], 'r')
    lns1 = ax2.bar(results.index, results['monthly_return_1'], align='center', width=10, color='b')
    ax2.legend(lns1, ['monthly return(right axis)'], loc=1, fontsize=12)
    ax1.legend(lns2, ['excess return(left axis)'], loc=2, fontsize=12)
    ax1.set_ylabel(u'组合净值/基准净值', fontproperties=font, fontsize=16)
    ax2.set_ylabel(u'月度收益率', fontproperties=font, fontsize=16)
    ax1.set_xlabel(u'时间', fontproperties=font, fontsize=16)
    ax2.set_yticklabels([str(x*100)+'0%' for x in ax2.get_yticks()], fontproperties=font, fontsize=14)
    s = ax1.set_title(title, fontproperties=font, fontsize=16)
    return ax1, ax2


hh = pd.read_csv('pearson_bt_1416.csv')
hh = hh[hh.columns[1:]]
s = plot_return(hh, u'P因子10%~20%百分位数14年到16年月度表现')
# Out:
# 胜利月数：
# 20
# 总月度数:
# 34

# %%
from quartz.api import *
dir(quartz.api)
# Out:
# ['AccountConfig',
#  'Commission',
#  'DynamicUniverse',
#  'Factor',
#  'IdxCN',
#  'IndSW',
#  'IndZJH',
#  'IndZZ',
#  'Logger',
#  'Monthly',
#  'OrderState',
#  'OrderStatus',
#  'Signal',
#  'SignalGenerator',
#  'Slippage',
#  'StockScreener',
#  'Weekly',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  'api_method',
#  'cancel_order',
#  'clear_account_instance',
#  'contest',
#  'gen_drawdown_table',
#  'get_account',
#  'get_account_instance',
#  'get_asset',
#  'get_order',
#  'get_orders',
#  'get_symbol_history',
#  'get_universe',
#  'history',
#  'is_pro_user',
#  'json',
#  'local_thread',
#  'log',
#  'long_only',
#  'neutralize',
#  'normalize_code',
#  'normalize_l1',
#  'observe',
#  'order',
#  'order_pct',
#  'order_pct_to',
#  'order_to',
#  'os',
#  'perf_parse',
#  'plot_drawdown_periods',
#  'plot_drawdown_underwater',
#  'plot_monthly_returns_dist',
#  'plot_monthly_returns_heatmap',
#  'plot_pure_alpha',
#  'register_account',
#  'set_account_instance',
#  'set_universe',
#  'simple_long_only',
#  'standardize',
#  'sys',
#  'threading',
#  'winsorize',
#  'wraps']
