# %% [markdown]
# #

# %% [markdown]
# 停牌数据获取条件定义有疑惑？

# %%
date0="2013-04-16"
DataAPI.SecHaltGet(beginDate=date0,endDate=date0,field=u"").head()  ##000001.XSHE 在
# Out:
#          secID        haltBeginTime          haltEndTime  ticker secShortName  \
# 0  000010.XSHE  2012-12-17 09:30:00  2013-04-17 15:00:00  000010         美丽生态
# 1  000017.XSHE  2012-11-13 09:30:00  2013-12-30 15:00:00  000017         深中华A
# 2  000035.XSHE  2011-11-09 09:30:00  2013-09-16 15:00:00  000035         中国天楹
# 3  000522.XSHE  2013-03-14 09:30:00                  NaN  000522         白云山A
# 4  000526.XSHE  2013-03-25 09:30:00  2013-08-27 15:00:00  000526         紫光学大
#
#   exchangeCD listStatusCD  delistDate assetClass
# 0       XSHE            L         NaN          E
# 1       XSHE            L         NaN          E
# 2       XSHE            L         NaN          E
# 3       XSHE           DE  2013-04-26          E
# 4       XSHE            L         NaN          E

# %%
date0="2013-04-17"
DataAPI.SecHaltGet(beginDate=date0,endDate=date0,field=u"").head()  ##000001.XSHE 没有？？
# Out:
#          secID        haltBeginTime          haltEndTime  ticker secShortName  \
# 0  000017.XSHE  2012-11-13 09:30:00  2013-12-30 15:00:00  000017         深中华A
# 1  000035.XSHE  2011-11-09 09:30:00  2013-09-16 15:00:00  000035         中国天楹
# 2  000522.XSHE  2013-03-14 09:30:00                  NaN  000522         白云山A
# 3  000526.XSHE  2013-03-25 09:30:00  2013-08-27 15:00:00  000526         紫光学大
# 4  000545.XSHE  2012-04-26 09:30:00  2013-07-25 15:00:00  000545         金浦钛业
#
#   exchangeCD listStatusCD  delistDate assetClass
# 0       XSHE            L         NaN          E
# 1       XSHE            L         NaN          E
# 2       XSHE           DE  2013-04-26          E
# 3       XSHE            L         NaN          E
# 4       XSHE            L         NaN          E
