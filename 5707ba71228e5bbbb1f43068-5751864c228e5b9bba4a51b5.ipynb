# %% [markdown]
# # 日记第一天——操作

# %%
2+6*5
# Out:
# 32

# %% [markdown]
# 简单的运算没问题。

# %%
import math
math.sqrt(81)
# Out:
# 9.0

# %%
from math import sqrt
sqrt(144)
sqrt(100)
sqrt(169)
# Out:
# 13.0

# %% [markdown]
# 连续输入函数只会运算最后一个函数的结果

# %%
from math import *
print floor (56.8)
print sqrt(121)
print sqrt(100)
# Out:
# 56.0
# 11.0
# 10.0

# %% [markdown]
# 使用print 可以连续输出多个结果。

# %%
a=[2,8,9,6,4]
print a[2]
print a[1]
print a[0]
print a[3]
print a[4]
print a[-1]
print a[5]
print a[6]
# Out:
# 9
# 8
# 2
# 6
# 4
# 4
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <mercury-input-16-fd885979f594> in <module>()
#       6 print a[4]
#       7 print a[-1]
# ----> 8 print a[5]
#       9 print a[6]
#
# IndexError: list index out of range

# %% [markdown]
# 所以list的index shi 从0开始的，超出部分无法计算。

# %%
b=(1,6,8,9)
b[1]
b[3]
# Out:
# 9

# %%
c='youcanyouup'
print c
print c[0:3]
print c[0:5]
print c[0:11]
print c[0:0]
c[11]
# Out:
# youcanyouup
# you
# youca
# youcanyouup
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <mercury-input-27-4114195c7abc> in <module>()
#       5 print c[0:11]
#       6 print c[0:0]
# ----> 7 c[11]
#
# IndexError: string index out of range

# %% [markdown]
# 切片的话，要往后多推移一个值……直接取11超出范围，但要取出全部字符串则要取到末位。

# %%
d={1:'garon',2:'vn',3:'fizz'}
d[2]
# Out:
# 'vn'

# %%
print [4,5,6]+[8,9,10]
'abc'+'5,8,7'
# Out:
# [4, 5, 6, 8, 9, 10]
# 'abc5,8,7'

# %%
a='hello'
print 'o' in a
print 't' in a
# Out:
# True
# False

# %%
list('second')
# Out:
# ['s', 'e', 'c', 'o', 'n', 'd']

# %%
list(c)
# Out:
# ['y', 'o', 'u', 'c', 'a', 'n', 'y', 'o', 'u', 'u', 'p']

# %% [markdown]
# 这里的c即是这篇notebook中最后出现的c

# %%
a=list(c)
del a[2]
a
# Out:
# ['y', 'o', 'c', 'a', 'n', 'y', 'o', 'u', 'u', 'p']

# %%
a[9]='q'
a
# Out:
# ['y', 'o', 'c', 'a', 'n', 'y', 'o', 'u', 'u', 'q']

# %%
a.index('c')
# Out:
# 2
