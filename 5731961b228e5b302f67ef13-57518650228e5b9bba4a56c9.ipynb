# %% [markdown]
# # 净利润增长率选股 + 根据10日动量因子进行没有调仓买卖

# %% [markdown]
# 先用股票筛选器选出每次调仓时的股票池，选股依据是净利润增长率最高的150只股票
# 然后在回测过程中，根据10日动量因子（股价10日收益率），每次调仓在股票池中选出30只股票进行组合买进，卖出上次持有的且今次调仓时未被选出的股票

# %% [raw]
# from CAL.PyCAL import *
# import numpy as np
# from pandas import DataFrame
#
# start = '2012-01-01'                       # 回测起始时间
# end = '2016-05-10'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = StockScreener(Factor.NetProfitGrowRate.nlarge(150))  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 20                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     cal = Calendar('China.SSE')
#     period = Period('-1B')
#     today = account.current_date         # current_date返回的是datetime类型
#     # 向前移动一个工作日
#     today = Date.fromDateTime(account.current_date)  # 将datetime类型转换成CAL中的Date类型
#     yesterday = cal.advanceDate(today, period)   # 向前移动一个工作日
#
#     yesterday = yesterday.toDateTime()  # 将前一个工作日的类型再次转换成datetime类型
#
#     # 10日股价收益率（10日动量因子）
#     zf = DataAPI.MktStockFactorsOneDayGet(tradeDate=yesterday.strftime('%Y%m%d'),secID=account.universe,field=u"secID,ticker,REVS10",pandas="1")
#     zf.set_index('secID',inplace=True)
#     zf = zf.dropna()
#     zf = zf.sort(columns = 'REVS10', ascending = False)
#     zf = zf[0:30]
#     buyList = zf.index
#     # 先卖出
#     sell_list = account.valid_secpos
#     for stk in sell_list:
#         order_to(stk, 0)
#
#     prices = account.referencePrice
#     for s in buyList:
#         if np.isnan(prices[s]) or prices[s] == 0:  # 停牌或是还没有上市等原因不能交易
#             continue
#         order_pct_to(s, 0.0333)
#     return

# %%
import pandas
neutralize?
