# %% [markdown]
# # Notebook3

# %%
DataAPI.MktEqudGet(secID=u"",ticker=u"",tradeDate=u"",beginDate=u"20160101",endDate=u"20170101",isOpen="",field=[u"secID",u"chgPct"],pandas="1")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <mercury-input-13-FDEB2D5FBD9E4C1881C677C7489D95A7> in <module>()
# ----> 1 DataAPI.MktEqudGet(secID=u"",ticker=u"",tradeDate=u"",beginDate=u"20160101",endDate=u"20170101",isOpen="",field=[u"secID",u"chgPct"],pandas="1")
#
# /home/ipython/anaconda/lib/python2.7/site-packages/DataAPI/DATAYES.pyc in MktEqudGet(secID, ticker, tradeDate, beginDate, endDate, isOpen, field, pandas)
#    1483         csvString = api_base.__getCSV__(''.join(requestString), httpClient, gw=False)
#    1484         if csvString is None or len(csvString) == 0 or (csvString[0] == '-' and not api_base.is_no_data_warn(csvString, False)) or csvString[0] == '{':
# -> 1485             api_base.handle_error(csvString, 'MktEqudGet')
#    1486         elif csvString[:2] == '-1':
#    1487             csvString = ''
#
# ...
