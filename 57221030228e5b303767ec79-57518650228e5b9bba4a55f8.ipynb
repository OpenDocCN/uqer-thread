# %% [markdown]
# # 定投-有限限价值平均法

# %% [raw]
# #!/usr/bin/env python
# # -*- coding: utf-8 -*-
#
# '''
# 定投
# 受限价值平均法
# 价值平均法会自然的在高位减仓和再低位加仓
# 但如果在长期熊市情况下，每月需要补仓的金额越来越大，不可承受
# '''
#
# # 第一步：设置基本参数
# start = '2012-10-08'
# end   = '2016-04-28'
# capital_base = 10000
# refresh_rate = 1
# benchmark = '399006.ZICN'
# freq = 'd'
#
# # 第二步：选择主题，设置股票池
# universe = ['159915.XSHE', ]
#
# def initialize(account):
#     account.has_buy = {}
#     #每月定投金额
#     account.step_value = 1000.0
#     #每月价值增长比率
#     account.step_ratio = 0.01
#     #最大补仓金额
#     account.max_value = 5000.0
#     #最大卖出金额
#     account.min_value = -5000.0
#
#
# def handle_data(account):
#     # 本策略将使用account的以下属性：
#     # account.universe表示当天，股票池中可以进行交易的证券池，剔除停牌退市等股票。
#     # account.referencePrice表示股票的参考价，一般使用的是上一日收盘价。
#
#     c_month = account.current_date.strftime("%Y-%m")
#     #本月买过了
#     if c_month in account.has_buy :
#         return
#
#     #当前价值
#     c_value = account.referencePortfolioValue - account.cash
#
#     #期望价值
#     e_value = (len(account.has_buy) + account.step_ratio + 1) * account.step_value
#
#     buy_value = e_value - c_value
#     if buy_value > account.max_value :
#         buy_value = account.max_value
#     elif buy_value < account.min_value :
#         buy_value = account.min_value
#
#     for stock in account.universe:
#         try :
#             buy_num = int(buy_value / (account.referencePrice[stock] * 100)) * 100
#
#         except :
#             return
#         order(stock, buy_num)
#
#         account.has_buy[c_month] = 1
#         log.info('日期:%s\t持仓价值:%.2f\t期望价值:%.2f\t买入数量:%d\t买入金额:%.2f\t现金:%.2f\t总资产:%.2f' % (c_month, c_value, e_value,  buy_num, buy_value, account.cash,account.referencePortfolioValue))

# %%
DataAPI.SecIDGet(ticker=u"399006")
# Out:
#          secID  ticker secShortName cnSpell exchangeCD assetClass  \
# 0  399006.ZICN  399006         创业板指    CYBZ       XSHE        IDX
#
#    listStatusCD  listDate  transCurrCD  ISIN  partyID
# 0           NaN       NaN          NaN   NaN    17765
