# %% [markdown]
# # 获取期货历史数据

# %% [raw]
# universe ='RBN0'                           # 策略期货合约
# start = '2011-01-01'                       # 回测开始时间
# end  = '2011-04-01'                        # 回测结束时间
# capital_base = 20000000                    # 初试可用资金
# look_back=100
# holding=21
# refresh_rate = holding                     # 调仓周期
# freq = 'd'                                 # 调仓频率：m-> 分钟；d-> 日
#
#
# def initialize(futures_account):           # 初始化虚拟期货账户，一般用于设置计数器，回测辅助变量等。
#     pass
#
#
# def handle_data(futures_account):          # 回测调仓逻辑，每个调仓周期运行一次，可在此函数内实现信号生产，生成调仓指令。
#         history_data_main = get_symbol_history(symbol = universe, field='closePrice', time_range = look_back+1)[universe]
#         print universe
#         print history_data_main
