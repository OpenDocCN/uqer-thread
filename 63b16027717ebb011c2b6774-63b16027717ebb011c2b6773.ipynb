# %% [markdown]
# # 画收益率图

# %%
from scipy import  stats
import statsmodels.api as sm  # 统计相关的库
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

rawdata=pd.read_csv('策略收益.csv',encoding='gbk', dtype={"ticker": np.str})  #读取数据
rawdata = rawdata.set_index(rawdata['date'])
data= np.array(rawdata['profit'])
rawdata['profit'].plot(figsize=(15,5))     #画出收益率图
