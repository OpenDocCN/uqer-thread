# %% [markdown]
# # 各位高人！这是什么情况？

# %%
DataAPI.MktEqudAdjAfGet(secID=u"",ticker=u"600000",tradeDate=u"",isOpen="",beginDate=u"20060701",endDate=u"20150720",field=u"",pandas="1")
# Out:
#             secID  ticker secShortName exchangeCD secShortNameEn   tradeDate  \
# 0     600000.XSHG  600000         浦发银行       XSHG     Pudong Dev  2015-07-20
# 1     600000.XSHG  600000         浦发银行       XSHG     Pudong Dev  2015-07-17
# 2     600000.XSHG  600000         浦发银行       XSHG     Pudong Dev  2015-07-16
# 3     600000.XSHG  600000         浦发银行       XSHG     Pudong Dev  2015-07-15
# 4     600000.XSHG  600000         浦发银行       XSHG     Pudong Dev  2015-07-14
# 5     600000.XSHG  600000         浦发银行       XSHG     Pudong Dev  2015-07-13
# 6     600000.XSHG  600000         浦发银行       XSHG     Pudong Dev  2015-07-10
# 7     600000.XSHG  600000         浦发银行       XSHG     Pudong Dev  2015-07-09
# 8     600000.XSHG  600000         浦发银行       XSHG     Pudong Dev  2015-07-08
# 9     600000.XSHG  600000         浦发银行       XSHG     Pudong Dev  2015-07-07
# 10    600000.XSHG  600000         浦发银行       XSHG     Pudong Dev  2015-07-06
# ...

# %% [raw]
# start = '2014-01-01'                       # 回测起始时间
# end = '2015-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['000001.XSHE', '600000.XSHG']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                    # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):
#     hist= account.get__symbol__history('closeprice',4)
#     for s in account.universe:
#         if hist[s][3]>hist[s][0] and hist[s][3]>hist[s][1] and hist[s][3]>hist[s][2] and s not in account.valid_secpos:
#             oder(s,10000)
#         elif hist[s][3]<hist[s][2] and s in account.valid_secpos:
#             oder_to(s,0)
#
#     return
