# %% [markdown]
# # 分级a轮动模型

# %% [raw]
# import pandas as pd
#
# start = '2015-01-01'                       # 回测起始时间
# end = '2015-12-30'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['150217.XSHE','150283.XSHE','150259.XSHE','150186.XSHE','150329.XSHE','150209.XSHE','150184.XSHE',
#             '150209.XSHE','150243.XSHE','150249.XSHE','150315.XSHE','150241.XSHE','150171.XSHE','150227.XSHE',
#             '150179.XSHE','150305.XSHE','150173.XSHE','150018.XSHE','150235.XSHE','150205.XSHE','150177.XSHE',
#             '150194.XSHE','150269.XSHE','150169.XSHE','150229.XSHE','150273.XSHE','150181.XSHE','150200.XSHE',
#             '150275.XSHE','150231.XSHE','150203.XSHE','150100.XSHE','150051.XSHE','150018.XSHE']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     history = pd.DataFrame(columns=['ticker','Nav','closePrice','Off']) # 新建数据框存储单日的分级A净值和收盘价，计算折价率Off
#     today = account.current_date
#     for fund_A in account.universe:
#         fund_A_ID = fund_A[0:6] #分级A的ID为交易编码前六位
#         net_value = DataAPI.FundNavGet(ticker=fund_A_ID, dataDate=today, field='ticker,NAV', pandas='1') #取净值
#         price = DataAPI.MktFunddGet(ticker=fund_A_ID, field='ticker,closePrice', tradeDate=today, pandas='1') #取收盘价
#         off = (float(net_value['NAV'].values)-float(price['closePrice'].values))/float(net_value['NAV'].values) #计算折价率
#         history =history.append({'ticker':fund_A_ID,'Nav':float(net_value['NAV'].values),
#                                  'closePrice':float(price['closePrice'].values),'Off':off},ignore_index=True)
#     history = history.sort(columns='Off',ascending=False) #按折价率排序
#     target_index = history.idxmax()['Off'] #取折价率最高一行序号
#     target_fund_A = str(history.loc[target_index]['ticker'])
#     target_fund_A = target_fund_A + '.XSHE'
#     print today
#     print history
#     if  target_fund_A not in account.avail_security_position :
#         for i in account.avail_security_position:
#             order_to(i,0)
#         order(target_fund_A,round(account.reference_portfolio_value/float(history.loc[target_index]['closePrice'])))
#     return

# %%
net_value = DataAPI.FundNavGet(ticker="150209", dataDate="20150105", field='ticker,NAV', pandas='1') #取净值
price = DataAPI.MktFunddGet(ticker="150209", field='ticker,,openPrice,closePrice', tradeDate="20150105", pandas='1') #取开盘价
print net_value
print price
# Out:
#    ticker    NAV
# 0  150209  1.003
#    ticker  openPrice  closePrice
# 0  150209      0.821        0.82
