# %% [markdown]
# # 数据错误反馈

# %% [markdown]
# # 反馈一个数据错误
#
# secID=004345.OFCN的基金，成立日期不对。下为验证，并附其他网站的数据校对。
#
# http://stock.finance.sina.com.cn/fundInfo/view/FundInfo_JJGK.php?symbol=004345

# %%
DataAPI.FundGet(etfLof=u"",secID=u"004345.OFCN",ticker=u"",category=u"E",idxID=u"",idxTicker=u"",listStatusCd=u"",operationMode=u"",field=u"",pandas="1").T
# Out:
#                                                                     0
# secID                                                     004345.OFCN
# ticker                                                         004345
# secShortName                                            南方深证成份ETF联接-C
# tradeAbbrName                                                     NaN
# category                                                            E
# operationMode                                                       O
# indexFund                                                           I
# etfLof                                                            NaN
# isQdii                                                              0
# isFof                                                               0
# isGuarFund                                                          0
# guarPeriod                                                        NaN
# ...

# %%
DataAPI.FundNavGet(dataDate=u"",secID=u'004345.OFCN',ticker='',beginDate='',endDate=u"",field=u"",pandas="1")
# Out:
#           secID  ticker   secShortName     endDate     NAV publishDate  \
# 0   004345.OFCN  004345  南方深证成份ETF联接-C  2017-02-23  1.0000  2017-02-24
# 1   004345.OFCN  004345  南方深证成份ETF联接-C  2017-02-27  0.8449  2017-03-01
# 2   004345.OFCN  004345  南方深证成份ETF联接-C  2017-02-28  0.8479  2017-03-01
# 3   004345.OFCN  004345  南方深证成份ETF联接-C  2017-03-01  0.8500  2017-03-01
# 4   004345.OFCN  004345  南方深证成份ETF联接-C  2017-03-02  0.8461  2017-03-02
# 5   004345.OFCN  004345  南方深证成份ETF联接-C  2017-03-03  0.8484  2017-03-03
# 6   004345.OFCN  004345  南方深证成份ETF联接-C  2017-03-06  0.8581  2017-03-06
# 7   004345.OFCN  004345  南方深证成份ETF联接-C  2017-03-07  0.8605  2017-03-07
# 8   004345.OFCN  004345  南方深证成份ETF联接-C  2017-03-08  0.8565  2017-03-08
# 9   004345.OFCN  004345  南方深证成份ETF联接-C  2017-03-09  0.8505  2017-03-09
# 10  004345.OFCN  004345  南方深证成份ETF联接-C  2017-03-10  0.8529  2017-03-10
# 11  004345.OFCN  004345  南方深证成份ETF联接-C  2017-03-13  0.8614  2017-03-13
# ...
