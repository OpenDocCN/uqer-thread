# %% [markdown]
# # 300310.XSHE 停牌数据有误（续）

# %% [markdown]
# 300310.XSHE 在3/10/2016-3/17/2016停牌，但是DataAPI.SecHaltGet获得的数据为L，表示期间还在交易.调用account.get_daily_symbol_history的时候程序报错。而且这个错误是个block级的错误，我试了几种work arround，都无法绕过。

# %% [raw]
# start = '2016-03-09'                       # 回测起始时间
# end = '2016-03-20'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['300310.XSHE', '000001.XSHE']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     print account.current_date
#     for x in universe:
#         if DataAPI.SecHaltGet(secID=x,endDate=account.current_date,listStatusCD="",field=u"",pandas="1")['listStatusCD'].tolist()[-1] == "L":
#             print x
#             print account.get_daily_symbol_history(x,1)['openPrice'][-1]
#
#     return
