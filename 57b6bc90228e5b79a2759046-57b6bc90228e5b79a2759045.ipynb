# %% [markdown]
# #

# %% [markdown]
# 加仓测试

# %% [markdown]
# 策略思路 亏损1%加仓300股 平均盈利1%清仓。请教高手该如何编写？

# %% [raw]
# start = '2015-01-01'                       # 回测起始时间
# end = '2016-08-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = [ '603808.XSHG']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，由于freq = 'd'，时间间隔的单位为交易日
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     hist = account.get_attribute_history('closePrice', 3)
#     for s in account.universe:
#         if hist[s][0]/hist[s][2]-1 <- 0.01 and s not in account.valid_secpos:
#             order(s, 300)
#         elif  account.referencePrice< account.valid_seccost  and s in account.valid_secpos:
#         #elif  account.referencePrice< account.valid_seccost*0.99  and s in account.valid_secpos:
#             order(s, 300)
#         elif account.referencePrice> account.valid_seccost  and s in account.valid_secpos:
#             order_to(s, 0)
