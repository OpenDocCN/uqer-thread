# %% [markdown]
# # Official_Demo1

# %% [markdown]
# # 常用链接
# - 策略手册 https://uqer.datayes.com/help/strategyManualV3/
# - 基本介绍 https://uqer.datayes.com/help/introduction/#开始研究
# - https://uqer.datayes.com/help/research
# - 核心API 见 https://uqer.datayes.com/help/researchV3/ （包含股票，基金，期货，指数）

# %% [markdown]
# # Official_Demo1_Quartz2

# %% [raw]
# # 官方demo 地址 https://uqer.datayes.com/study/getting-started/3
# # 把上面的合起来就完成了一个最简单的策略，从沪深300中任意挑选一只股票，涨到1.25倍后卖出。
#
# # 如何设置回测时间区间（无需将时间带入任何函数）
# start = '2014-01-01' # 回测的起止时间是2015年7月1日至2016年7月1日
# end= '2015-06-01'
#
# # 如何设置对比基准
# # 1. HS300表示沪深300，其他常见的还有SHCI（上证综指）、SH50（上证50）、SH180（上证180）和ZZ500（中证500）
# # benchmark = 'HS300'
# # 2. 直接用指数的代码，构建对比基准 https://uqer.datayes.com/labs/notebooks/Indices_Found.nb
# # benchmark = '399006.ZICN'  # 策略参考标准为创业板指
# # 3. 使用某只个股作为对比基准
# # benchmark = '000001.XSHE'   # 策略参考标准为平安银行
# benchmark = 'HS300'
#
# # 如何设置初始资金
# capital_base = 100000  #初始资金有10万
#
#
# # 如何选择数据频率
# # 'd'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# freq = 'd'
# # 调仓频率，表示执行策略运行条件的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# refresh_rate = 1
#
#
# # 构建股票池来做回测
# # 1. 将指数成分股作为股票池： HS300，SHCI（上证综指）、SH50（上证50）、SH180（上证180）和ZZ500（中证500）
# # universe = set_universe('SH50')  股票池里包含了最近一个交易日的上证50的成份股
# # 2. 构建自己的股票池
# # universe = ['000001.XSHE', '600000.XSHG']  XSHE，表示深交所；XSHG，表示上交所
# # 通过股票名称来查找股票代码和交易所代码
# # 见https://uqer.datayes.com/labs/notebooks/Find_StockID_fromName.nb
# # 3. 用StockScreener帮助筛选股票池
# # 如何使用 见 https://uqer.datayes.com/help/quartzExt/#StockScreener
# # universe = StockScreener(Factor.PE.nlarge(10)) #这里筛选的因子factor是股票的PE值，筛选的方法是最大的10支。
# # 股票筛选器所使用的筛选因子都可以通过 Factor. 的方法获得，在优矿中通过代码补全可以很容易地输入所需要的因子。
# # universe = StockScreener(Factor.PE.nlarge(10)) + ['000001.XSHE', '600000.XSHG']  # 设置证券池为PE值最大的10个股票，并加上平安银行和浦发银行
#
# universe = set_universe('HS300')      # 股票池为沪深300的成份股
# capital_base = 100000             # 起始本金为10万元
#
#
# # 初始化回测帐户
# # 1. 如果是从零开始的空白帐户
# def initialize(account):           # 初始化了一个全新的帐户
#     pass
# # 2. 用户可以自己定义各种函数，之后很多的高级策略里都会用到。比如一个策略设定为某些股票在连续出现3次下跌之后买入，那么就需要在这个account里定义一个计数器，每天运行策略的时候，都会检测股票是否下跌，一旦出现，就会在计数器里加1，累积到3次之后就会出发买入的指令
#
#
#
# # 如何买卖股票
# # 每只股票买1手（100股）
# """
# def handle_data(account):
#     for s in account.universe:
#         order(s,100)
# """
# # 每只股票买至持仓1手（100股）
# """
# def handle_data(account):
#     for s in account.universe:
#         order_to(s,100)
# """
# # 每只股票买入价值为虚拟账户当前总价值的10%
# """
# def handle_data(account):
#     for s in account.universe:
#         order_pct(s,0.1)
# """
# # 每只股票买入卖出至价值为虚拟账户当前总价值的10%
# """
# def handle_data(account):
#     for s in account.universe:
#         order_pct_to(s,0.1)
# """
#
#
# def handle_data(account):
#     for stock in account.universe:         # 股票是股票池中的股票，并且优矿帮你自动剔除了当天停牌退市的股票
#         p = account.reference_price[stock]        # 股票前一天的收盘价
#         cost = account.security_cost.get(stock)  # 股票的平均持仓成本
#         # print(stock+":"+str(cost))
#         if 0 < p < 4 and not cost:                        # 判断这个价格小于4，并且当前没有买入该股票
#             order_pct_to(stock, 0.1)          # 将满足条件的股票买入，总价值占虚拟帐户的10%
#         elif cost and p >= cost * 1.25:        # 卖出条件，当p这个价格涨幅到买入价的1.25倍；
#             order_to(stock, 0)        # 将满足条件的股票卖到剩余0股，即全部卖出

# %% [raw]
# start = '2016-01-01'                       # 回测起始时间
# end = '2017-01-01'                         # 回测结束时间
# universe = DynamicUniverse('HS300')        # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 1                           # 执行handle_data的时间间隔
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#     account = context.get_account('fantasy_account')

# %% [raw]
# # 官方demo 地址 https://uqer.datayes.com/study/getting-started/3
# # 把上面的合起来就完成了一个最简单的策略，从沪深300中任意挑选一只股票，涨到1.25倍后卖出。
#
# # 如何设置回测时间区间（无需将时间带入任何函数）
# start = '2014-01-01' # 回测的起止时间是2015年7月1日至2016年7月1日
# end= '2015-06-01'
#
# # 如何设置对比基准
# # 1. HS300表示沪深300，其他常见的还有SHCI（上证综指）、SH50（上证50）、SH180（上证180）和ZZ500（中证500）
# # benchmark = 'HS300'
# # 2. 直接用指数的代码，构建对比基准 https://uqer.datayes.com/labs/notebooks/Indices_Found.nb
# # benchmark = '399006.ZICN'  # 策略参考标准为创业板指
# # 3. 使用某只个股作为对比基准
# # benchmark = '000001.XSHE'   # 策略参考标准为平安银行
# benchmark = 'HS300'
#
# # 如何设置初始资金
# capital_base = 100000  #初始资金有10万
#
#
# # 如何选择数据频率
# # 'd'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# freq = 'd'
# # 调仓频率，表示执行策略运行条件的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# refresh_rate = 1
#
#
# # 构建股票池来做回测
# # 1. 将指数成分股作为股票池： HS300，SHCI（上证综指）、SH50（上证50）、SH180（上证180）和ZZ500（中证500）
# # universe = set_universe('SH50')  股票池里包含了最近一个交易日的上证50的成份股
# # 2. 构建自己的股票池
# # universe = ['000001.XSHE', '600000.XSHG']  XSHE，表示深交所；XSHG，表示上交所
# # 通过股票名称来查找股票代码和交易所代码
# # 见https://uqer.datayes.com/labs/notebooks/Find_StockID_fromName.nb
# # 3. 用StockScreener帮助筛选股票池
# # 如何使用 见 https://uqer.datayes.com/help/quartzExt/#StockScreener
# # universe = StockScreener(Factor.PE.nlarge(10)) #这里筛选的因子factor是股票的PE值，筛选的方法是最大的10支。
# # 股票筛选器所使用的筛选因子都可以通过 Factor. 的方法获得，在优矿中通过代码补全可以很容易地输入所需要的因子。
# # universe = StockScreener(Factor.PE.nlarge(10)) + ['000001.XSHE', '600000.XSHG']  # 设置证券池为PE值最大的10个股票，并加上平安银行和浦发银行
#
# universe = DynamicUniverse('HS300')      # 股票池为沪深300的成份股
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
#
#
#
# # 初始化回测帐户
# # 1. 如果是从零开始的空白帐户
# def initialize(context):           # 初始化了一个全新的帐户
#     pass
# # 2. 用户可以自己定义各种函数，之后很多的高级策略里都会用到。比如一个策略设定为某些股票在连续出现3次下跌之后买入，那么就需要在这个account里定义一个计数器，每天运行策略的时候，都会检测股票是否下跌，一旦出现，就会在计数器里加1，累积到3次之后就会出发买入的指令
#
#
#
# # 如何买卖股票
# # 每只股票买1手（100股）
# """
# def handle_data(account):
#     for s in account.universe:
#         order(s,100)
# """
# # 每只股票买至持仓1手（100股）
# """
# def handle_data(account):
#     for s in account.universe:
#         order_to(s,100)
# """
# # 每只股票买入价值为虚拟账户当前总价值的10%
# """
# def handle_data(account):
#     for s in account.universe:
#         order_pct(s,0.1)
# """
# # 每只股票买入卖出至价值为虚拟账户当前总价值的10%
# """
# def handle_data(account):
#     for s in account.universe:
#         order_pct_to(s,0.1)
# """
#
#
# def handle_data(context):
#     account = context.get_account('fantasy_account')
#
#     universe = context.get_universe(asset_type='stock', exclude_halt=False)
#     for stock in universe:         # 股票是股票池中的股票，并且优矿帮你自动剔除了当天停牌退市的股票
#         p = account.reference_price[stock]        # 股票前一天的收盘价
#         cost = account.security_cost.get(stock)  # 股票的平均持仓成本
#         # print(stock+":"+str(cost))
#         if 0 < p < 4 and not cost:                        # 判断这个价格小于4，并且当前没有买入该股票
#             order_pct_to(stock, 0.1)          # 将满足条件的股票买入，总价值占虚拟帐户的10%
#         elif cost and p >= cost * 1.25:        # 卖出条件，当p这个价格涨幅到买入价的1.25倍；
#             order_to(stock, 0)        # 将满足条件的股票卖到剩余0股，即全部卖出
