# %% [markdown]
# # Notebook2

# %%
DataAPI.SysCodeGet(codeTypeID=u"70006",valueCD=u"",field=u"",pandas="1")
# Out:
#     codeTypeID valueCD   valueName
# 0        70006      11        预计亏损
# 1        70006      12        亏损减少
# 2        70006      13        业绩下降
# 3        70006      14        亏损增加
# 4        70006      15      亏损大幅增加
# 5        70006      16      亏损大幅减少
# 6        70006      17      业绩大幅下降
# 7        70006      18  业绩下降(<50%)
# 8        70006      19        下降减缓
# 9        70006      21        预计盈利
# 10       70006      22        盈利增加
# 11       70006      23        业绩上升
# 12       70006      24        盈利减少
# 13       70006      25      盈利大幅增加
# 14       70006      26      盈利大幅减少
# 15       70006      27      业绩大幅上升
# 16       70006      28  业绩上升(<50%)
# 17       70006      29        上升减缓
# 18       70006      31       业绩不确定
# 19       70006      32        业绩预警
# 20       70006      41        基本持平
# 21       70006      42        扭亏为盈
# 22       70006      43        大幅扭亏
# 23       70006      51     经营预期及其他
# 24       70006      52        提前披露
# 25       70006      53        经营计划
# ...

# %% [markdown]
# 请问一下，这些事件有什么量化的标准嘛？具体怎么看？
