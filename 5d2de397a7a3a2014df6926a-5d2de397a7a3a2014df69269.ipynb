# %% [markdown]
# # 海康威视均线

# %% [raw]
# start = '2017-01-01'                       # 回测起始时间
# end = '2019-01-01'                         # 回测结束时间
# universe = ['002415.XSHE']          # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = '002415.XSHE'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):
#     pass
#
# def handle_data(context):
#     account = context.get_account('fantasy_account')
#     history=context.history(universe,'closePrice',30,rtype='array')
#     MA30=history['002415.XSHE']['closePrice'][-30:].mean()
#     security_position = account.get_positions()
#     current_price=context.current_price('002415.XSHE')
#     if current_price>MA30 and '002415.XSHE' not in security_position:
#         amount=int((account.portfolio_value/current_price)/100)*100
#         account.order('002415.XSHE',amount)
#     elif current_price<MA30 and '002415.XSHE' in security_position:
#         account.order_to('002415.XSHE',0)
