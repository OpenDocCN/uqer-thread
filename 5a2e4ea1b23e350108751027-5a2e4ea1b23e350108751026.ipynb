# %% [markdown]
# # K-means and SVR

# %%
from numpy import *
import pandas as pd

#欧氏距离
def distEclud(vecA, vecB):
    return sqrt(sum(power(vecA - vecB, 2))) #la.norm(vecA-vecB)
    
def randCent(dataSet, k):
    n = shape(dataSet)[1]
    centroids = mat(zeros((k,n)))#create centroid mat
    for j in range(n):#create random cluster centers, within bounds of each dimension
        minJ = min(dataSet[:,j])
        rangeJ = max(dataSet[:,j]) - minJ
        centroids[:,j] = mat(minJ + rangeJ[0,0] * random.rand(k,1))
    return centroids

def kMeans(dataSet, k, distMeas=distEclud, createCent=randCent):
    m = shape(dataSet)[0]
    clusterAssment = mat(zeros((m,2)))#create mat to assign data points 
                                      #to a centroid, also holds SE of each point
    centroids = createCent(dataSet, k)
    clusterChanged = True
    while clusterChanged:
        clusterChanged = False
        for i in range(m):#for each data point assign it to the closest centroid
            minDist = inf; minIndex = -1
            for j in range(k):
                distJI = distMeas(centroids[j,:],dataSet[i,:])
                if distJI < minDist:
                    minDist = distJI; minIndex = j
            if clusterAssment[i,0] != minIndex: clusterChanged = True
            clusterAssment[i,:] = minIndex,minDist**2
        for cent in range(k):#recalculate centroids
            ptsInClust = dataSet[nonzero(clusterAssment[:,0].A==cent)[0]]#get all the point in this cluster
            centroids[cent,:] = mean(ptsInClust, axis=0) #assign centroid to mean 
    return centroids, clusterAssment

def biKmeans(dataSet, k, distMeas=distEclud):
    m = shape(dataSet)[0]
    clusterAssment = mat(zeros((m,2)))
    centroid0 = mean(dataSet, axis=0).tolist()[0]
    centList =[centroid0] #create a list with one centroid
    for j in range(m):#calc initial Error
        clusterAssment[j,1] = distMeas(mat(centroid0), dataSet[j,:])**2
    while (len(centList) < k):
        lowestSSE = inf
        for i in range(len(centList)):
            ptsInCurrCluster = dataSet[nonzero(clusterAssment[:,0].A==i)[0],:]
            centroidMat, splitClustAss = kMeans(ptsInCurrCluster, 2, distMeas)
            sseSplit = sum(splitClustAss[:,1])
            sseNotSplit = sum(clusterAssment[nonzero(clusterAssment[:,0].A!=i)[0],1])
            if (sseSplit + sseNotSplit) < lowestSSE:
                bestCentToSplit = i
                bestNewCents = centroidMat
                bestClustAss = splitClustAss.copy()
                lowestSSE = sseSplit + sseNotSplit
        bestClustAss[nonzero(bestClustAss[:,0] == 1)[0],0] = len(centList) 
        bestClustAss[nonzero(bestClustAss[:,0] == 0)[0],0] = bestCentToSplit
        centList[bestCentToSplit] = bestNewCents[0,:].tolist()[0]#replace a centroid with two best centroids 
        centList.append(bestNewCents[1,:].tolist()[0])
        clusterAssment[nonzero(clusterAssment[:,0] == bestCentToSplit)[0],:]= bestClustAss#reassign new clusters, and SSE
    return mat(centList), clusterAssment

# %%
universe = set_universe(IndSW.ShiYouHuaGongL2)
prc_obs = DataAPI.MktEqudAdjGet(secID=universe, beginDate='20130101', endDate='20151231', field=['secID','tradeDate','closePrice'], pandas='1')
prc_merge = list(prc_obs.groupby('secID'))[0][1][['tradeDate','closePrice']]
for i in range(1, shape(list(prc_obs.groupby('secID')))[0]):
    prc_merge = pd.merge(prc_merge, 
                         list(prc_obs.groupby('secID'))[i][1][['tradeDate','closePrice']], 
                         on='tradeDate', how = 'outer')
columns = ['tradeDate']
for i in range(0, shape(list(prc_obs.groupby('secID')))[0]):
    columns.append(list(prc_obs.groupby('secID'))[i][0])
prc_merge.columns = columns

# %%
prc_merge.dropna(axis=1, inplace=True)
prc_mat = mat(prc_merge.drop('tradeDate', axis=1)).T
label_mat = biKmeans(prc_mat, shape(prc_mat)[0]-1, distMeas=distEclud)[1]
label = {}
j = 0
for secID in prc_merge.columns[1:]:
    label[secID] = label_mat[j, 0]
    j += 1

for i in label:
    for j in label:
        if (i != j) & (label[i] == label[j]):
            universe = [i,j]
print('the matched stocks are %s'% universe)
# Out:
# the matched stocks are ['000637.XSHE', '002377.XSHE']

# %%
prc_merge.ix[:,1:].plot(figsize=(12,6))
plt.legend(loc='right', bbox_to_anchor=(1.2,0.6))

# %%
prc_merge[['000698.XSHE', '600688.XSHG']].plot(figsize=(12,6))
pd.DataFrame(prc_merge['000698.XSHE'].describe())
pd.DataFrame(prc_merge['600688.XSHG'].describe())
# Out:
#        600688.XSHG
# count   727.000000
# mean      4.172927
# std       1.970375
# min       2.077000
# 25%       2.692500
# 50%       3.362000
# 75%       5.416500
# max      11.288000

# %%
base = ['000698.XSHE', '600688.XSHG']
obs1 = DataAPI.MktEqudAdjGet(secID=base[0], beginDate='20130101', endDate='20151231', field=['secID','tradeDate','closePrice'], pandas='1')
obs2 = DataAPI.MktEqudAdjGet(secID=base[1], beginDate='20130101', endDate='20151231', field=['secID','tradeDate','closePrice'], pandas='1')
obs = pd.merge(obs1, obs2, on='tradeDate', how='outer')
obs.plot(figsize=(12, 6))

# %%
cor = prc_merge.drop('tradeDate', axis=1).corr()
cor.to_excel('correlation.xlsx')

# %%
print('the correlation coefficient is %s'% prc_merge.drop('tradeDate', axis=1).corr()[universe[0]][universe[1]])
# Out:
# the correlation coefficient is 0.937306778414

# %%
import matplotlib.pyplot as plt
from sklearn import svm

X = []
for i in prc_merge[universe[0]]:
    X.append([i])
y = prc_merge[universe[1]]
svr_rbf = svm.SVR(kernel='rbf', C=1e3, gamma=0.1).fit(X,y)
svr_lin = svm.SVR(kernel='linear', C=1e3).fit(X,y)
y_rbf = svr_rbf.predict(X)
y_lin = svr_lin.predict(X)

# %%
plt.scatter(X, y, c='k', label='data')
plt.plot(X, y_rbf, c='g', label='RBF model')
plt.plot(X, y_lin, c='r', label='linear model')
plt.xlabel('Close price of stock %s'% universe[0])
plt.ylabel('Close price of stock %s'% universe[1])
plt.legend(loc='upper left')
plt.show()

# %%
re = pd.DataFrame(y - y_rbf)
s1 = pd.Series(mean, index=range(len(re.ix[:,0])))
s2 = pd.Series(mean+sd, index=range(len(re.ix[:,0])))
s3 = pd.Series(mean-sd, index=range(len(re.ix[:,0])))
all = pd.concat([re,s1,s2,s3], axis=1)
all.plot(figsize=(12,6))

# %%
re.ix[:,0]
# Out:
# 0      0.144118
# 1      0.234425
# 2      0.273540
# 3      0.246602
# 4      0.294288
# 5     -0.123864
# 6      0.143357
# 7      0.284288
# 8      0.241686
# 9      0.183631
# 10     0.333707
# 11     0.395322
# 12     0.213627
# 13     0.241925
# 14    -0.055373
# 15     0.099852
# 16     0.263362
# 17     0.372686
# 18     0.353925
# 19     0.498570
# 20     0.269008
# 21    -0.408544
# 22    -0.145415
# 23    -0.267200
# 24    -1.333809
# 25    -1.717584
# 26    -1.150405
# 27    -1.387007
# 28    -1.396196
# 29    -1.013104
#          ...
# 697    0.319097
# 698    1.030684
# 699    0.905245
# 700    1.018792
# 701    0.992649
# 702    1.013715
# 703    1.075654
# 704    0.803384
# 705    0.421732
# 706    0.148352
# 707    0.182057
# 708    0.073550
# 709    0.796245
# 710    1.078992
# 711    0.823995
# 712    0.560808
# 713    0.319335
# 714    0.226357
# 715   -0.067676
# 716    0.215739
# 717    0.684623
# 718    0.802920
# 719    0.680393
# 720    0.575649
# 721    0.630786
# 722    0.525526
# 723    0.817253
# 724    1.066978
# 725    1.215978
# 726    0.936191
# Name: 002377.XSHE, dtype: float64

# %%
std = (y - y_rbf).var()
sd = sqrt(std)
mean = (y - y_rbf).mean()
sst = sum((y - y.mean()) ** 2)
ssr = sum((y - y_rbf)**2)
rsq = 1 - ssr/sst
mean
# Out:
# 0.14039690972315211

# %% [raw]
# start = '2016-01-01'
# end = '2017-06-30'
# benchmark = '000001.ZICN'
# capital_base = 1000000
# #commission = Commission(buycost=0.001, sellcost=0.002, unit='perValue')
# #slippage = Slippage(value=0.01, unit='perValue')
# freq = 'd'
# refresh_date = 1
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     if len(account.universe) < 2:
#         return
#
#     prc1 = account.referencePrice[universe[1]]
#     prc0 = account.referencePrice[universe[0]]
#     bias = prc1 - svr_rbf.predict(prc0)
#     bias_std = (bias - mean)/std
#
#     if bias_std > 0.1:
#         order_to(universe[1], 0)
#         order(universe[0], account.referencePortfolioValue/prc0)
#         return
#
#     if bias_std < -0.1:
#         order_to(universe[0], 0)
#         order(universe[1], account.referencePortfolioValue/prc1)
#         return
#
#     else:
#         return
