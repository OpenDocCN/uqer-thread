# %% [markdown]
# # 量化入门：练习python简单编程练习例子

# %%
例子40：将一个数组逆序输出(三种方法)

# %%
#用第一个与最后一个交换。
if __name__ == '__main__':
    a1 = [9,6,5,4,1]
    N = len(a1)
    print a1 
    for i in range(len(a1)/2):
        a1[i], a1[N - i - 1] = a1[N - i - 1],a1[i]
    print "a1:{}".format(a1)
    
#将一个数组逆序输出：
if __name__ == '__main__':
	a2 = [9,6,5,4,1]
	print "a2:{}".format(a2[::-1])
    
#使用 reverse() 函数   
a3 = [9,6,5,4,1]
a3.reverse()
print "a3:{}".format(a3)
# Out:
# [9, 6, 5, 4, 1]
# a1:[1, 4, 5, 6, 9]
# a2:[1, 4, 5, 6, 9]
# a3:[1, 4, 5, 6, 9]

# %% [markdown]
# 例子41：模仿静态变量的用法。

# %%
def varfunc():
    var = 0
    print 'var = %d' % var
    var += 1
if __name__ == '__main__':
    for i in range(3):
        varfunc()

# 类的属性
# 作为类的一个属性吧
class Static:
    StaticVar = 5
    def varfunc(self):
        self.StaticVar += 1
        print self.StaticVar

print Static.StaticVar
a = Static()
for i in range(3):
    a.varfunc()
# Out:
# var = 0
# var = 0
# var = 0
# 5
# 6
# 7
# 8

# %% [markdown]
# 例子42：学习使用auto定义变量的用法。

# %%
num = 2
def autofunc():
    num = 1
    print 'internal block num = %d' % num
    num += 1
for i in range(3):
    print 'The num = %d' % num
    num += 1
    autofunc()
# Out:
# The num = 2
# internal block num = 1
# The num = 3
# internal block num = 1
# The num = 4
# internal block num = 1

# %% [markdown]
# 例子43：模仿静态变量(static)另一案例。

# %%
class Num:
    nNum = 1
    def inc(self):
        self.nNum += 1
        print 'nNum = %d' % self.nNum

if __name__ == '__main__':
    nNum = 2
    inst = Num()
    for i in range(3):
        nNum += 1
        print 'The num = %d' % nNum
        inst.inc()
# Out:
# The num = 3
# nNum = 2
# The num = 4
# nNum = 3
# The num = 5
# nNum = 4

# %% [markdown]
# 例子44：两个 3 行 3 列的矩阵，实现其对应位置的数据相加，并返回一个新矩阵：

# %%
X = [[12,7,3],
    [4 ,5,6],
    [7 ,8,9]]
 
Y = [[5,8,1],
    [6,7,3],
    [4,5,9]]
 
result = [[0,0,0],
         [0,0,0],
         [0,0,0]]
 
# 迭代输出行
for i in range(len(X)):
   # 迭代输出列
   for j in range(len(X[0])):
       result[i][j] = X[i][j] + Y[i][j]
 
for r in result:
   print(r)
# Out:
# [17, 15, 4]
# [10, 12, 9]
# [11, 13, 18]

# %% [markdown]
# 例子45：统计 1 到 100 之和。

# %%
tmp = 0
for i in range(1,101):
    tmp += i
print 'The sum is %d' % tmp
# Out:
# The sum is 5050
