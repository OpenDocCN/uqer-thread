# %% [markdown]
# # test

# %% [raw]
# start = '2012-09-07'                       # 回测起始时间
# end = '2019-02-21'                         # 回测结束时间
# universe = ['100032.OFCN','000478.OFCN','270048.OFCN']
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     's': AccountConfig(account_type='otc_fund', capital_base=10000000)
# }
#
# def initialize(context):
#     account = context.get_account('s')
#     account.targets = [{'code':'100032.OFCN','pct':0.1},
#                        {'code':'000478.OFCN','pct':0.1},
#                        {'code':'270048.OFCN','pct':0.8}]
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     account = context.get_account('s')
#     if account.cash > 0:
#         for target in account.targets:
#             account.purchase(target['code'], account.cash * target['pct'])
