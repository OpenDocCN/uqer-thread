# %% [markdown]
# # 股债平衡

# %% [raw]
# start = '2014-1-1'                       # 回测起始时间
# end = '2016-11-12'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准，沪深300
# universe = ['510300.XSHG','511010.XSHG']  # 证券池，支持股票和基金,华泰柏瑞沪深300ETF
# capital_base = 1000000                       # 起始资金100W
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#   #  log.info(account.current_date.strftime('%Y%m%d'))
#
#     positons = []
#     for position in account.security_position:
#         positons.append(position)
#
#     for stock in account.universe:
#         if stock not in positons:
#             order_pct_to(stock,0.5)
#             log.info(stock)
#         else:
#             num = account.security_position[stock]
#             percent = num * account.reference_price[stock] /account.reference_portfolio_value
#             if percent>0.55 or percent<0.45:
#                 log.info(stock)
#                 log.info(percent)
#                 order_pct_to(stock,0.5)
#     return
