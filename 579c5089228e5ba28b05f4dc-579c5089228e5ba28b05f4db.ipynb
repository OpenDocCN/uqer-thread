# %% [markdown]
# #

# %% [markdown]
# ##因子：

# %% [markdown]
# #买入指令，每天相对于开盘价跌一元买入（或者跌2个百分点买入）；
# #卖出指令，涨2元或者亏百分之5卖出。

# %% [raw]
# start = '2014-01-01'                       # 回测起始时间
# end = '2015-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['000001.XSHE', '600000.XSHG']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     openPrice=account.get_attribute_history('openPrice',5)     #获取之前5日的历史开盘价
#     closePrice=account.get_attribute_history('closePrice',5)    #获取之前5日的历史收盘价
#     for stk in account.universe:
#         if openPrice[stk][-1]-closePrice[stk][-1]>=1 or openPrice[stk][-1]/closePrice[stk][-1]-1>=0.02:    #当前一天的收盘价低于开盘价1元或者跌幅超过2%就买入
#             order(stk,10000)
#         if closePrice[stk][-1]-openPrice[stk][-1]>=2 or openPrice[stk][-1]/closePrice[stk][-1]-1>=0.05:    #当前一天的收盘价高于开盘价2元或者跌幅超过5%就卖出
#             order_to(stk,0)
#     return
