# %% [markdown]
# #

# %% [raw]
# import numpy as np
#
# start = '2012-05-01'
# end = '2015-05-01'
# benchmark = 'HS300'
# capital_base = 100000
# freq = 'd'
# refresh_rate = 1
#
# # 设置股票池
# universe = StockScreener( Factor.LCAP.num_range(1,500) & Factor.VOL10.num_range(1,300) & Factor.PE.value_range(1,50) )
#
# def foo(data, dependencies=['closePrice'], max_window=12):
#     bias = (data['closePrice'].ix[-1] - data['closePrice'].mean())/data['closePrice'].mean()
#     return  bias
#
# def initialize(account):
#     a = Signal('bias', foo)
#     account.signal_generator = SignalGenerator(a)
#
# def handle_data(account):
#     # 生成买入列表
#     print account.signal_result['bias']
#     newpool = account.signal_result['bias']
#     newpool = newpool[newpool<-0.045]
#     newpool = newpool.replace([np.inf, -np.inf], np.nan).dropna()
#     buylist = newpool.index
#     sell_list = account.valid_secpos
#     #buypool = newpool[newpool<-0.045]
#     #sellpool = newpool[newpool>0.05]
#     #buypool = buypool.replace([np.inf, -np.inf], np.nan).dropna()
#     #sellpool = sellpool.replace([np.inf, -np.inf], np.nan).dropna()
#     #buylist = buypool.index
#     #sell_list = sellpool.index
#     v = account.referencePortfolioValue
#     d = len(buylist)
#     last_date = account.previous_date.strftime("%Y-%m-%d")
#     last_screener = universe.preview(last_date)
#
#     # 卖出不在买入列表中的股票，估计持仓价值
#     for stock in account.valid_secpos:
#         if stock not in buylist:
#             if stock in account.universe:
#                 order_to(stock, 0)
#         #if stock in sell_list:
#             #order_to(stock, 0)
#
#     prices = account.referencePrice
#     for stk in buylist:
#         if stk not in prices:
#             continue
#         if np.isnan(prices[stk]) or prices[stk] == 0:  # 停牌或是还没有上市等原因不能交易
#             continue
#         order_num = int(v/d/prices[stk] /100)*100
#         if order_num < 100:
#             order_num = 100
#             order_to(stk, order_num)
