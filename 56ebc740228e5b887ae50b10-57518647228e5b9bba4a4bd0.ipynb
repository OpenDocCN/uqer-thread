# %% [markdown]
# # 暴跌中的机遇

# %% [raw]
# start = '2015-06-15'                       # 回测起始时间
# end = '2016-03-18'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = DataAPI.SecIDGet(partyID=u"",assetClass=u"E",ticker=u"",cnSpell=u"",field=u"",pandas="1").secID         # 证券池
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 用日线回测的策略
# refresh_rate = 2                           # 每天调一次仓，即每个交易日都会运行第三部分的handle_data函数
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     # account.universe：当前交易日的证券池，已经从全局变量universe中剔除了当天停牌、退市和数据缺失证券的证券池。
#     # 推荐您下单的股票都来自于account.universe
#     stocks = account.get_attribute_history('closePrice', 4)
#     #过去三天涨幅超过25%的股票
#     lists = {}
#     for stock,val in stocks.items():
#         priceRent = (val[3] - val[0])/val[0]
#         if priceRent >= 0.27:
#             if len(lists) == 0 or lists['priceRent'] <priceRent:
#                 lists['stock'] = stock
#                 lists['priceRent'] = priceRent
#
#     szzsPre = DataAPI.MktIdxdGet(tradeDate=account.previous_date,indexID=u"000001.ZICN",ticker=u"",beginDate=u"",endDate=u"",field=u"CHGPct",pandas="1")
#
#     if len(lists) > 1:
#         #卖掉当前持仓股票
#         valid_stocks  = account.valid_seccost
#         if len(valid_stocks) == 0:
#             order(lists['stock'],account.referencePortfolioValue)
#         else:
#             for stock,val in valid_stocks.items():
#                 if stock is not lists['stock']:
#                     order_to(stock, 0)
#                     break
