# %% [markdown]
# #

# %%
ticker = ['600321', '603393']
ThemeData = DataAPI.SectorThemesByTickersGet(secShortName=u"",ticker=ticker,exchangeCD=u"",beginDate=u"",endDate=u"",field=u"",pandas="1")
print(ThemeData)
ThemeData2 = DataAPI.ThemesByTickersGet(ticker = ticker)
print(ThemeData2)
# Out:
#          secID exchangeCD exchangeName  ticker secShortName  themeID  \
# 0  600321.XSHG       XSHG      上海证券交易所  600321         国栋建设     1638
# 1  600321.XSHG       XSHG      上海证券交易所  600321         国栋建设     2462
# 2  600321.XSHG       XSHG      上海证券交易所  600321         国栋建设   120981
#
#   themeName   beginDate  endDate  returnScore  textContributionScore  \
# 0      建筑建材  2014-12-26      NaN            1               0.000000
# 1      其他建材  2014-12-26      NaN            1               0.000000
# 2      建筑材料  2015-02-12      NaN            1               0.008772
#
#    industryScore           insertTime           updateTime
# 0       0.778788  2014-12-26 00:00:00  2016-11-10 10:08:56
# 1       0.809917  2014-12-26 00:00:00  2016-11-10 10:11:10
# 2       0.778788  2015-02-12 17:29:29  2016-11-10 10:16:42
#           secID exchangeCD exchangeName  ticker secShortName  themeID  \
# 0   600321.XSHG       XSHG      上海证券交易所  600321         国栋建设     1638
# ...
