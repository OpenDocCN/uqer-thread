# %% [markdown]
# # 新版本没有account.universe_all了吗？

# %% [markdown]
# 最近无法使用account.universe_all了
# 今后还会恢复吗？

# %%
dir(account)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'avail_secpos',
#  'blotter',
#  'cash',
#  'current_date',
#  'current_minute',
#  'get_attribute_history',
#  'get_daily_attribute_history',
#  'get_daily_history',
#  'get_daily_symbol_history',
#  'get_history',
#  'get_symbol_history',
#  'pending_blotter',
#  'previous_date',
#  'referencePortfolioValue',
#  'referencePrice',
#  'referenceReturn',
#  'signal_generator',
#  'signal_result',
#  'universe',
#  'valid_seccost',
#  'valid_secpos']
