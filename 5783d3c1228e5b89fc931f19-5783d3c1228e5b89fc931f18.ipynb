# %% [markdown]
# #

# %% [markdown]
# ## 一直感觉`均线金叉`不是很靠谱，金叉出现之后容易出现粘合，后市震荡的也很多。
# ### 但是有一种金叉准确率个人感觉比较高，没有经过验证，今天晚上花点时间验证一下。
#
# ## 快线一直在慢线下方，下跌到一定位置后，快线穿过慢线。
# ![tup](http://g3.hexunimg.cn/2012-11-29/148490070.jpg)
# ### 类似这种比较可靠。
#
#
# ![fanm](http://g0.hexunimg.cn/2012-11-07/m_147678852.jpg)
# ### 而这种金叉就没什么意义，一般都粘合了。（找的图好像不太有说服力，有交易经验的人应该明白我的意思）
# ### 这个代码很渣，半夜写的，不过思路基本实现了。
#
# ### 止损策略是，买入的股票如果在10天内从最高点下跌超过8%，就平仓。
# ### 每日调仓，如果有新买入股票，那么和原有持仓的订单一起调整，等仓位买入，或者买入10%仓位（防止仅有一两只股票，大仓位买入造成风险上升）。

# %% [raw]
# from CAL.PyCAL import *
# start = '2012-12-01'                       # 回测起始时间
# end = '2016-06-10'                         # 回测结束时间
# benchmark = 'SH50'                        # 策略参考标准
# universe = set_universe('SH50')  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# cal=Calendar('China.SSE')
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     buylist=[]
#     sellist=[]
#     last10day=cal.advanceDate(account.previous_date,'-10B')
#     for stk in account.universe :
#         if stk not in account.valid_secpos:
#             ma=DataAPI.MktStockFactorsDateRangeGet(secID=stk,beginDate=last10day,endDate=account.previous_date,field=u"secID,MA5,MA20,MA10",pandas="1")
#             ma5=ma['MA5']
#             ma10=ma['MA10']
#
#             if ma5[0]<ma10[0] and ma5[1]<ma10[1] and ma5[2]<ma10[2] and ma5[3]<ma10[3] and ma5[4]<ma10[4] and ma5[5]<ma10[5] and ma5[6]<ma10[6] and ma5[7]<ma10[7] and ma5[8]>=ma10[8] and ma5[9]>ma10[9] and stk not in account.valid_secpos.keys():
#                 buylist.append(stk)
#     for stock in account.valid_secpos.keys():
#         last10day=cal.advanceDate(account.previous_date,'-10B')
#         price=DataAPI.MktEqudAdjGet(beginDate=last10day,endDate=account.previous_date,secID=stock,field=u"closePrice",pandas="1")
#         maxprice=max(price['closePrice'].tolist())
#         if account.referencePrice[stock]<maxprice*0.92:
#             sellist.append(stock)
#         else:
#             buylist.append(stock)
#     for stk in sellist:
#         order_to(stk,0)
#     for stk in buylist:
#         minpct=min(0.1,0.95/len(buylist))
#         order_pct_to(stk,minpct)

# %% [markdown]
# ## 再用前20个交易日的均线来验证一下。

# %% [raw]
# from CAL.PyCAL import *
# start = '2012-12-01'                       # 回测起始时间
# end = '2016-06-10'                         # 回测结束时间
# benchmark = 'SH50'                        # 策略参考标准
# universe = set_universe('SH50')  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# cal=Calendar('China.SSE')
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     buylist=[]
#     sellist=[]
#     last10day=cal.advanceDate(account.previous_date,'-20B')
#     for stk in account.universe :
#         if stk not in account.valid_secpos:
#             ma=DataAPI.MktStockFactorsDateRangeGet(secID=stk,beginDate=last10day,endDate=account.previous_date,field=u"secID,MA5,MA20,MA10",pandas="1")
#             ma5=ma['MA5']
#             ma10=ma['MA10']
#
#             if ma5[0]<ma10[0] and ma5[1]<ma10[1] and ma5[2]<ma10[2] and ma5[3]<ma10[3] and ma5[4]<ma10[4] and ma5[5]<ma10[5] and ma5[6]<ma10[6] and ma5[7]<ma10[7] and ma5[8]<ma10[8] and ma5[9]<ma10[9] and ma5[10]<ma10[10] and ma5[11]<ma10[11] and ma5[12]<ma10[12] and ma5[13]<ma10[13] and ma5[14]<ma10[14] and ma5[15]<ma10[15] and ma5[16]<ma10[16] and ma5[17]<ma10[17] and ma5[18]>=ma10[18] and ma5[19]>ma10[19] and ma5[20]>ma10[20] and stk not in account.valid_secpos.keys():
#                 buylist.append(stk)
#     for stock in account.valid_secpos.keys():
#         last10day=cal.advanceDate(account.previous_date,'-10B')
#         price=DataAPI.MktEqudAdjGet(beginDate=last10day,endDate=account.previous_date,secID=stock,field=u"closePrice",pandas="1")
#         maxprice=max(price['closePrice'].tolist())
#         if account.referencePrice[stock]<maxprice*0.92:
#             sellist.append(stock)
#         else:
#             buylist.append(stock)
#     for stk in sellist:
#         order_to(stk,0)
#     for stk in buylist:
#         minpct=min(0.1,0.95/len(buylist))
#         order_pct_to(stk,minpct)

# %% [markdown]
# # 因为时间原因，就用了SH50来测试，明天再试试全A股
