# %% [markdown]
# # 基于收益率分布探讨量化择时

# %% [markdown]
# 择时是一直很让人头疼的问题，有时候觉得股票涨势良好，刚建仓追涨没过多久就跌了，有时候觉得股票跌的够多了，建仓抄底，最终发现这不是‘底’，只是‘腰’。南方航空600029.XSHG是我一直关注的股票，本文就以它为例，简单讨论一下买卖时机的问题。首先，处理一下数据，把2017-07-01至2018-02-14大约半年时间里每日最高收益率和最低收益率及触发的时间整理出来做成散点图。

# %% [raw]
# start = '2017-07-01'
# end = '2018-02-14'
# universe= ['600029.XSHG']
# freq = 'm'
# refresh_rate = (1,1)
#
# def initialize(context):
#     context.start_time=570
#
#     context.list_T=[] #接受时间的容器
#     context.list_R=[] #接受收益率的容器
#
#     context.list_HRS=[] #接受当日最高收益率的容器
#     context.list_HTS=[] #接受触发最高收益率的时间的容器
#     context.list_LRS=[] #接受当日最低收益率的容器
#     context.list_LTS=[] #接受触发最低收益率的时间的容器
#
# def handle_data(context):
#     universe = context.get_universe(exclude_halt=True)
#     data_day = context.history(universe, attribute='closePrice', freq='d',style='sat', retype='frame')
#     data_minute = context.history(universe, attribute='closePrice', freq='1m',style='sat', retype='frame')
#
#     T=int(context.now.strftime('%H'))*60+int(context.now.strftime('%M'))-context.start_time
#
#     context.list_T.append(T)
#     context.list_R.append(data_minute[universe[0]].closePrice[-1]/data_day[universe[0]].closePrice[-1] -1)
#
#     HR=max(context.list_R)
#     HT=context.list_T[context.list_R.index(HR)]
#     LR=min(context.list_R)
#     LT=context.list_T[context.list_R.index(LR)]
#
#     if context.now.strftime('%H%M')=='1459':
#         context.list_HRS.append(HR)
#         context.list_HTS.append(HT)
#         context.list_LRS.append(LR)
#         context.list_LTS.append(LT)
#         context.list_T=[]
#         context.list_R=[]
#
#     if  context.now.strftime('%Y%m%d%H%M')=='201802141459':
#         print 'list_HRS'
#         print context.list_HRS
#         print 'list_HTS'
#         print context.list_HTS
#         print 'list_LRS'
#         print context.list_LRS
#         print 'list_LTS'
#         print context.list_LTS

# %% [markdown]
# 上面这个回测是没作用的，主要是为了获得四个list，分别是2017-07-01至2018-02-14中的每日最高收益率、每日最高收益率触发时间、每日最低收益率和每日最低收益率触发时间。

# %%
list_HRS=[-0.0022632372090751751, 0.0012073240350340964, 0.006918694857714458, 0.0069256336486076542, 0.0023181994149485963, 0.00113607517624148, 0.0072023100027813758, -0.0035609859300639313, 0.014472712002683075, 0.027275933070681546, 0.0070308790400142041, 0.0093954602633639084, 0.0069410259473312585, 0.0034938013377903143, 0.011765653403702503, 0.0081765592092939432, -0.0011434714563234305, -0.0036540803897686658, 0.0087719298245614308, 0.0037313432835821558, 0.004993757802746579, 0.019875776397515477, 0.0073710073710071544, 0.0, 0.0075376884422109214, 0.0037641154328733606, 0.0050062578222778154, 0.0012484394506866447, 0.044303797468354444, 0.0061349693251533388, 0.0024420024420026554, 0.0061349693251533388, 0.019536019536019467, 0.025240384615384581, 0.013110846245530272, 0.0095011876484560887, 0.0059880239520959666, 0.0071856287425149379, -0.0011990407673860837, 0.013530135301353052, 0.024301336573511412, 0.027446300715990191, 0.085409252669039315, 0.0022598870056496079, 0.0, 0.032369942196531776, 0.023917995444191487, -0.0079185520361991779, -0.0011350737797957144, 0.057670126874279193, 0.018763796909492259, -0.0055432372505541672, -0.0045045045045045695, -0.0034168564920272759, 0.0, 0.0011494252873565092, 0.0023068050749710522, 0.0, -0.0011778563
# %% [markdown]
# 这里作出两张散点图，分别是半年里最高收益率和最低收益率一天中的分布图，可以发现最高收益率主要在0-4%范围内，最低收益率主要在-4-0%范围内，同时可以发现上半场最高点和最低点的数量明显多于下半场，且相对集中在开盘0-50分钟内，也就是说如果开盘涨势较好或者直接高开，在9:50之前极有可能触发最高价，之后应该反向操作，做空这只股票，及时止盈；如果开盘走弱或者直接低开，在9:50之前极有可能触发最低价，之后应该反向操作，持有这只股票，以期上涨。

# %%
from matplotlib import pyplot as plt
plt.scatter(list_HTS,list_HRS,s=30,c='red',marker='o')

# %%
plt.scatter(list_LTS,list_LRS,s=30,c='green',marker='o')

# %% [markdown]
# 根据以上思路，这里对南方航空过去半年的数据进行回测。这里先做一个相对稳定的策略，如果在9:50股价下跌大于1%，满仓；如果9:50股价上涨大于1%，空仓。最终年化收益率24.2%比基准高，且回撤也比基准要小，但总体来说还是差别不大。

# %% [raw]
# start = '2017-07-01'
# end = '2018-02-14'
# universe= ['600029.XSHG']
# freq = 'm'
# refresh_rate = (1,1)
#
# accounts = {
# 'self_account':AccountConfig(account_type='security',capital_base=10000000,commission=Commission(buycost=0.001,sellcost=0.002,unit='perValue'),slippage=Slippage(value=0.01,unit='perShare'))}
#
# def initialize(context):
#     context.start_time=570
#     context.R=0.01
#     context.T=50
#
# def handle_data(context):
#     account = context.get_account('self_account')
#     universe = context.get_universe(exclude_halt=True)
#     data_day = context.history(universe, attribute='closePrice', freq='d',style='sat', retype='frame')
#     data_minute = context.history(universe, attribute='closePrice', freq='1m',style='sat', retype='frame')
#
#     T=int(context.now.strftime('%H'))*60+int(context.now.strftime('%M'))-context.start_time
#     R=data_minute[universe[0]].closePrice[-1]/data_day[universe[0]].closePrice[-1] -1
#
#     if T==context.T and R<-context.R:
#         account.order_pct(universe[0],1)
#     if T==context.T and R>context.R:
#         account.order_pct(universe[0],-1)

# %% [markdown]
# 这里做一个相对暴力的策略，当前一日股价下跌大于2%时，满仓；当日9:50股价上涨大于2%，空仓。最终年化收益率为115.1%，相当不错，且有较高的换手率15.31，说明每次策略触发的买卖点都十分准确。当然，这里的策略只是针对南方航空这只股票，其他同学可以改一下参数试试看其他股票结果。

# %% [raw]
# start = '2017-07-01'
# end = '2018-02-14'
# universe= ['600029.XSHG']
# freq = 'm'
# refresh_rate = (1,1)
#
# accounts = {
# 'self_account':AccountConfig(account_type='security',capital_base=10000000,commission=Commission(buycost=0.001,sellcost=0.002,unit='perValue'),slippage=Slippage(value=0.01,unit='perShare'))}
#
# def initialize(context):
#     context.start_time=570
#     context.R=0.02
#     context.T=50
#
# def handle_data(context):
#     account = context.get_account('self_account')
#     universe = context.get_universe(exclude_halt=True)
#     data_day = context.history(universe, attribute='closePrice', freq='d',style='sat', retype='frame')
#     data_minute = context.history(universe, attribute='closePrice', freq='1m',style='sat', retype='frame')
#
#     T=int(context.now.strftime('%H'))*60+int(context.now.strftime('%M'))-context.start_time
#     R=data_minute[universe[0]].closePrice[-1]/data_day[universe[0]].closePrice[-1] -1
#
#     if R<-context.R:
#         account.order_pct(universe[0],1)
#     if T==context.T and R>context.R:
#         account.order_pct(universe[0],-1)
