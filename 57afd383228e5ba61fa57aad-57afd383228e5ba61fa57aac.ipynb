# %% [markdown]
# #

# %%
#data=DataAPI.MktEqudGet(tradeDate=u"20080513",secID=u"",ticker=u"",beginDate=u"",endDate=u"",isOpen="",field=u"",pandas="1")

#universe = DataAPI.EquGet(equTypeCD='A')['ticker']
import pandas as pd
import time,datetime
df = pd.DataFrame()
OneDay = pd.DataFrame()
datelist = []

begin = datetime.date(2003,3,3)
end = datetime.date(2003,3,10)

for i in range((end - begin).days+1):
    day = begin + datetime.timedelta(days=i)
    dayStr = str(day.strftime("%Y%m%d"))  
    OneDay = DataAPI.MktEqudGet(tradeDate=dayStr,secID=u"",ticker=u"",beginDate=u"",endDate=u"",isOpen="",field=u"",pandas="1")
    df = df.append(OneDay)
    #print df   

df.to_excel('test/沪深股票日行情'+'.xlsx','Sheet1',)
