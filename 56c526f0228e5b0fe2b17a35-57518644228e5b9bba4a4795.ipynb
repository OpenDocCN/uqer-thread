# %% [markdown]
# # 画一只股票的某个因子的历史走势

# %%
import seaborn
ticker = '000001'
start = '20070101'
end = '20160217'
df = DataAPI.MktStockFactorsDateRangeGet(ticker=ticker, beginDate=start, endDate=end, field='tradeDate,PE')
df.plot(x='tradeDate')
