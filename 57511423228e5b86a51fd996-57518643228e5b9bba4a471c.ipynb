# %% [markdown]
# # 『06.02 公开课』3. First Show of Numpy

# %% [markdown]
# # `Numpy`

# %%
from pandas import Series, DataFrame
import pandas as pd
import numpy as np

# %% [markdown]
# * contigious block of memory which stores a collection of data (generally numeric)
#   * compact memory representation--- not a list of pointers to python objects (ints)
#
# <img src="https://raw.github.com/andrewgiessel/pydata_bos_2013_intro_to_numpy/master/linear_memory.png">
#
# * each element of the collection has the same data type (signed integer, floats, unsigned integers, booleans)
# * array is a python object which is a *view* on this section of memory
#
# <img src="https://raw.github.com/andrewgiessel/pydata_bos_2013_intro_to_numpy/master/ndarray.png">
#
# * Attributes
#   * data - memory location
#   * shape - size of each dimension (3,3)
#   * strides - how to move in memory for each dimension (row to row, column to column) (3, 1)
#   * dtype - data type of the elements - affects the size of the stride and the shape
#
# * The ndarray object allows for different views (sub sections, reshaping, transposition, etc) without actually changing anything in memory- just the interpretation of the stored memory changes.
#
# * All interfaces with this data structure are written in C and accessing/modifying the data structures are therefore **fast**

# %% [markdown]
# ## `Array construction`
# ---

# %%
# np.array() - takes a list or tuple and makes an array.  core creation function
a = np.array([1, 2, 3, 4, 5])
print a

b = np.array([[5.,6.,7.],[8.,9.,10.]])
print b

print '\ndata type:'
print b.dtype

print '\nshape:'
print b.shape

print '\nadd two array:'
print a + a

print '\nsubtract two array:'
print a - a

print '\nscalar multiplication: '
print a * 100

print '\nelement-wise multiplication: '
print a * a

print '\nsum : '
print b.sum()

print '\nsum by each row : '
print b.sum(axis=1)

print '\nsum by each column : '
print b.sum(axis=0)

print '\nmax : '
print b.max()

print '\nmax by each row : '
print b.max(axis=1)

print '\nmax by each column : '
print b.max(axis=0)

print '\nmean : '
print b.mean()

print '\nmean by each row : '
print b.mean(axis=1)

print '\nmean by each column : '
print b.mean(axis=0)
# Out:
# [1 2 3 4 5]
# [[  5.   6.   7.]
#  [  8.   9.  10.]]
#
# data type:
# float64
#
# shape:
# (2, 3)
#
# add two array:
# [ 2  4  6  8 10]
#
# subtract two array:
# [0 0 0 0 0]
#
# scalar multiplication:
# [100 200 300 400 500]
#
# element-wise multiplication:
# [ 1  4  9 16 25]
#
# sum :
# 45.0
#
# sum by each row :
# [ 18.  27.]
#
# sum by each column :
# [ 13.  15.  17.]
#
# max :
# 10.0
#
# max by each row :
# [  7.  10.]
#
# max by each column :
# [  8.   9.  10.]
#
# mean :
# 7.5
#
# mean by each row :
# [ 6.  9.]
#
# mean by each column :
# [ 6.5  7.5  8.5]

# %%
b.max?
