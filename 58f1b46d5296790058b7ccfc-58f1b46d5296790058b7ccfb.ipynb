# %% [markdown]
# # 中小市值因子策略-20170415

# %% [raw]
# start = '2011-01-01'                       # 回测起始时间
# end = '2017-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# #universe = DynamicUniverse('A').apply_filter(Factor.LFLO.nsmall(10))  # 证券池，支持股票和基金. LFLO表示流通市值
# universe = DynamicUniverse('A').apply_filter(Factor.LCAP.nsmall(10))  # 证券池，支持股票和基金. LCAP表示绝对市值
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 30                          # 调仓频率，表示执行handle_data的时间间隔
# commission = Commission(buycost=0.0003, sellcost=0.0013, unit='perValue')  # 手续费
#
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     for stock in account.universe:
#         if stock not in account.current_universe:
#             order_to(stock,0)
#
#     for stock in account.current_universe:
#         order_pct_to(stock,1.0/10)
