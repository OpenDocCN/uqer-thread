# %% [markdown]
# # 600050

# %% [raw]
# start = '2016-01-01'                       # 回测起始时间
# end = '2017-11-01'                         # 回测结束时间
# universe = DynamicUniverse('600050.XSHG')        # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 1                           # 执行handle_data的时间间隔
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=100000)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#     s='600050.XSHG'
#     date=context.current_date
#     previous_date=context.previous_date
#     price = context.current_price('600050.XSHG')
#     account = context.get_account('fantasy_account')
#     position = account.get_position('600050.XSHG')
#     profit,value = 0,0
#     if position:
#         #print position
#         profit = position.profit
#         value = position.value
#
#     data = context.history(['600050.XSHG'], ['closePrice','turnoverValue'], 20, freq='1d', rtype='frame',   style='sat')
#     priceColum = data['600050.XSHG']['closePrice']
#     if len(priceColum) >= 2:
#        lcg_price= (priceColum[-1]-priceColum[-2])/priceColum[-2]*100
#        lcg_price10= (priceColum[-1]-priceColum[-10])/priceColum[-10]*100
#        lcg_price20= (priceColum[-1]-priceColum[-20])/priceColum[-20]*100
#        bs=lcg_price10/lcg_price
#        if lcg_price < -3 and lcg_price10 < -6 and lcg_price20 < 100:
#             #order_pct_to('600050.XSHG', 0.1)
#             account.order(s, 2000*bs,price=priceColum[-1])
#             #print("当前可用余额：%8.2f 当前价格:%8.2f" % (available_funds, close_price))
#             print ('date: %s lcg:%f price:%f last_price %f profit %f value %f lcg_price20 %f' %(date,lcg_price,price,priceColum[-1],profit,value,lcg_price20 ))
#        elif lcg_price > 3 and position and position.available_amount > 2000:
#             cost = position.cost
#             yl= (price-cost)/cost*100
#             print('price %f,cost %f'%(price,cost))
#             if yl > 15:
#                 print('aaaaa')
#                 account.order(s, -position.available_amount)
