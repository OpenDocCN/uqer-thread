# %% [markdown]
# # hs300保守

# %% [raw]
# start = '2017-07-01'                       # 回测起始时间
# end = '2017-11-09'                         # 回测结束时间
# universe = DynamicUniverse('HS300')        # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 1                           # 执行handle_data的时间间隔
# from time import sleep
#
# lcg_price_gap=-3
# pb_gap=2
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=1000000)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     a = Signal('PE')
#     b = Signal('PB')
#     context.signal_generator = SignalGenerator(a, b)
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#     global lcg_price_gap,pb_gap
#     account = context.get_account('fantasy_account')
#     cur_date=context.current_date
#     universe = context.get_universe(exclude_halt=True)
#     data = context.history(universe, ['closePrice','PB','PE'], 20, freq='1d', rtype='frame',   style='sat')
#     #priceColum = data['600050.XSHG']['closePrice']
#     for stock in universe:
#         priceColum = data[stock]['closePrice']
#         pb = data[stock]['PB']
#         lcg_price=(priceColum[-1]-priceColum[-2])/priceColum[-2]*100
#         lcg_price5=(priceColum[-1]-priceColum[-5])/priceColum[-5]*100
#         bs=lcg_price5/lcg_price
#         if lcg_price<lcg_price_gap and lcg_price5<1 and pb[-1]<pb_gap:
#             account.order(stock, 2000*bs)
#             #cur_price = context.current_price(stock)
#             print('cur_date %s stock %s lcg_price %f pb %f lcg_price5 %f' %(cur_date,stock,lcg_price,pb[-1],lcg_price5))
