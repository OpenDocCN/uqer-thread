# %% [markdown]
# # HS300_ZZ500 MA20PK

# %% [raw]
# # 策略
# # 请将中证500和沪深300组成一个组合，观察他们与各自20日线的关系。以当日价格对比20日线，持仓比价高者。
# # 例如，如果沪深300当日价格比20日线高5%，而中证500当日价格比20日线高10%，则持仓中证500。
# # 如果两者当日价格都比20日线低，则空仓。请利用提供的指数价格数据进行每日调仓，并分析回测结果及该策略的适用情况。
#
# start = '2010-01-04'                              # 回测起始时间
# end = '2020-12-30'                                # 回测结束时间
# benchmark = 'SH50'                                # 策略参考标准
# universe = ['000300.SH'  '000905.SH']             # 证券池，也可以在这里添加多个证券
# capital_base = 10000                              # 起始资金
# freq = 'd'                                        # 日线策略
# refresh_rate = 1                                  # 每个交易日调仓
#
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     # account.get_attribute_history：表示获取所有证券过去20天的closePrice数据，返回数据类型为 dict，键为每个证券的secID
#     hist20 = account.get_attribute_history('closePrice', 20)
#     hist1  =  account.get_attribute_history('closePrice', 1)
#     for stk in account.universe:
#
#         # 计算股票过去20天收盘平均值
#         ma20 = hist20[stk][:].mean()
#         zz_diff = (hist1['000300.SH'] -ma20['000300.SH'])/hist1['000300.SH']
#         sh_diff = (hist1['000905.SH'] -ma20['000905.SH'])/hist1['000905.SH']
#
#         # 如果5日均线大于20日均线，并且该股票当前没有持仓，则买入100手
#         # account.valid_secpos：表示当前交易日持有数量大于0的证券头寸。数据类型为字典，键为证券代码，值为头寸。
#
#         if zz_diff < 0 and sh_diff < 0 :
#             order_to('000905.SH', 0)
#             order_to('000300.SH', 0)
#
#         elif zz_diff > sh_diff :
#             order('000905.SH', 10000)
#             order_to('000300.SH', 0)
#
#         elif zz_diff <= sh_diff :
#             order('000300.SH', 10000)
#             order_to('000905.SH', 0)
