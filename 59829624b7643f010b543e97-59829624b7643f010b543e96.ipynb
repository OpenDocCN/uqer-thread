# %% [markdown]
# # Notebook1

# %%
import numpy as np
import pandas as pd

secIDs = DataAPI.EquGet(equTypeCD=u"A",secID=u"",ticker=u"",listStatusCD=u"L",field=u"secID",pandas="1") 
print secIDs
data=DataAPI.FdmtIndiGrowthPitGet(ticker=u"",secID="secIDs",endDate="",beginDate="",beginYear=u"2016",endYear=u"2017",reportType=u"A",publishDateEnd=u"",publishDateBegin=u"",field=u"secID,tRevenueYOY",pandas="1")
print data
data.tail()
data.to_excel(u'data2.xlsx')
# Out:
#             secID
# 0     000001.XSHE
# 1     000002.XSHE
# 2     000004.XSHE
# 3     000005.XSHE
# 4     000006.XSHE
# 5     000007.XSHE
# 6     000008.XSHE
# 7     000009.XSHE
# 8     000010.XSHE
# 9     000011.XSHE
# 10    000012.XSHE
# 11    000014.XSHE
# 12    000016.XSHE
# 13    000017.XSHE
# 14    000018.XSHE
# 15    000019.XSHE
# 16    000020.XSHE
# 17    000021.XSHE
# 18    000022.XSHE
# 19    000023.XSHE
# 20    000025.XSHE
# 21    000026.XSHE
# 22    000027.XSHE
# 23    000028.XSHE
# 24    000029.XSHE
# 25    000030.XSHE
# 26    000031.XSHE
# 27    000032.XSHE
# 28    000034.XSHE
# 29    000035.XSHE
# ...           ...
# 3280  603920.XSHG
# 3281  603926.XSHG
# 3282  603928.XSHG
# 3283  603929.XSHG
# 3284  603933.XSHG
# 3285  603936.XSHG
# 3286  603938.XSHG
# 3287  603939.XSHG
# 3288  603955.XSHG
# 3289  603958.XSHG
# 3290  603959.XSHG
# 3291  603960.XSHG
# 3292  603966.XSHG
# 3293  603968.XSHG
# 3294  603969.XSHG
# 3295  603977.XSHG
# 3296  603979.XSHG
# 3297  603980.XSHG
# ...
