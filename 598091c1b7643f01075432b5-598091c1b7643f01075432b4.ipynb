# %% [markdown]
# # up300

# %%
#coding=utf-8
from CAL.PyCAL import *
from sklearn import svm
from sklearn.linear_model import LogisticRegression
import pandas as pd
import numpy as np
import time as time
import random as random
import datetime,time

start = '2016-06-30'                       # 回测起始时间
end = '2017-06-30'                         # 回测结束时间
benchmark = 'HS300'                        # 策略参考标准
#universe = list(set(set_universe('HS300')+set_universe('ZXB')+set_universe('CYB')))
#universe = list(set(set_universe('ZXB')+set_universe('CYB')))
universe = set_universe('A')             # 证券池，支持股票和基金
capital_base = 1000000                     # 起始资金
freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟


p = DataAPI.MktEqumGet(secID='000018.XSHE', beginDate=start, endDate=end, field=['secID', 'highestPrice','lowestPrice'], pandas="1")
q = p.as_matrix(columns=None)
q
# Out:
# array([['000018.XSHE', 8.38, 7.11],
#        ['000018.XSHE', 10.09, 6.82],
#        ['000018.XSHE', 10.92, 8.7],
#        ['000018.XSHE', 11.18, 9.54],
#        ['000018.XSHE', 10.52, 9.72],
#        ['000018.XSHE', 10.67, 8.99],
#        ['000018.XSHE', 12.16, 9.6],
#        ['000018.XSHE', 11.1, 8.92],
#        ['000018.XSHE', 10.62, 9.3],
#        ['000018.XSHE', 12.18, 9.91],
#        ['000018.XSHE', 12.1, 10.36],
#        ['000018.XSHE', 12.88, 10.53],
#        ['000018.XSHE', 50.63, 9.87]], dtype=object)
