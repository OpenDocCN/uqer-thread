# %% [markdown]
# # 获取某日涨停板的列表

# %% [raw]
# #练手之作。输出某日涨停的股票列表，不含st。
#
# from CAL.PyCAL import Date
# import pandas as pd
# from CAL.PyCAL import Calendar
# from CAL.PyCAL import BizDayConvention
# start = '2016-02-02'                       # 回测起始时间
# end = '2016-02-26'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('A') # 证券池，支持所有a股
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#   pass
#
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     #print universe
#     dic_close =account.get_attribute_history('closePrice', 1)
#     dic_open = account.get_attribute_history('openPrice', 1)
#     dic_zhangting ={}
#     for stock in dic_close:
#       if ((dic_close[stock] - dic_open[stock])/dic_open[stock]>0.099) and dic_open[stock] != 0: #排除停牌的
#         #print account.current_date
#         # print '收盘价'+str(dic_close[stock])
#         # print '开盘价'+str(dic_open[stock])
#         dic_zhangting[stock] = dic_close[stock]
#     cal = Calendar('China.SSE')
#     dt = Date.fromDateTime(account.current_date)
#     print cal.advanceDate(dt,'-1B',BizDayConvention.Preceding)  #打印日期
#     print dic_zhangting  #打印那天涨停的股票代码
