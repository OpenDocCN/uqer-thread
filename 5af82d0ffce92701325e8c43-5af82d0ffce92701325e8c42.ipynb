# %% [markdown]
# # dataframe改值问题

# %%
import pandas as pd

x = 2
df1 = pd.DataFrame({'a':(0, 1, 2, 3, 4), 'b':0, 'c':1}) # 新建表格 DataFrame
print df1

df1[df1['a']==x]['b'] = 1  # 更改第x行第b列的值

print '更改第x行第b列的值:'
print df1[df1['a']==x]['b']
# Out:
#    a  b  c
# 0  0  0  1
# 1  1  0  1
# 2  2  0  1
# 3  3  0  1
# 4  4  0  1
# 更改第x行第b列的值:
# 2    0
# Name: b, dtype: int64
