# %% [markdown]
# # 【寻找Alpha】--收益波动比

# %% [markdown]
# 作为多因子模型的核心， alpha 因子的探索和应用一直都是Quanter关注的核心。 本文试图构建一个基于收益率和波动率的因子，并检验其有效性。

# %% [markdown]
# ## 因子名称：收益波动比

# %% [markdown]
# 因子逻辑与定义
#     - 收益率：收益率是一个典型因子，对收益率因子的典型应用包括动量模型、动量反转模型及Fama-French三因子模型等，该因子作为经典因子，已在各类研究中证实有效。
#     - 波动率：波动率是来反应市场波动幅度的大小，现代投资组合理论认为，带有系统风险的市场组合应该获得更高的风险收益，即波动率越高，收益率可能越大。波动率也被用于股价预测。
#     - 有鉴于此，本文构建收益波动比因子，rwR = (closePrice-openPrice)/(highPrice-lowPrice),式中：open为开盘买入价格，close为卖出价格，high为持有期内最高价，low为持有期内最低价。

# %% [markdown]
# 研究方法
#     - 1、按照收益波动比因子排序，计算十分位组合的收益率，进行分析比对。本文设定持有期为5日，等权重买入，到期卖出。
#     - 2、比较Top5%组合及But5%组合的相对收益，验证因子有效性。

# %% [raw]
# import numpy as np
# import pandas as pd
# from CAL.PyCAL import *
# from pandas import DataFrame,Series
# from datetime import datetime, timedelta
#
# start = '2012-01-01'                       # 回测起始时间
# end = '2016-01-12'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')
# capital_base = 100000                         # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 5                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# cal = Calendar('China.SSE')
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令          # 包含stk 和benchmark
#     clsp = account.get_attribute_history('closePrice', 20)
#     opep = account.get_attribute_history('openPrice', 20)
#     higp = account.get_attribute_history('highPrice', 20)
#     lowp = account.get_attribute_history('lowPrice',20)
#
#     buylist = []
#     selllist = []
#
#     paral = []
#
#     aa = {}
#     totalmoney = account.referencePortfolioValue
#     prices = account.referencePrice
#
#     for stk in account.universe:
#
#         clsps = clsp[stk]
#         opeps = opep[stk]
#         higps = higp[stk]
#         lowps = lowp[stk]
#
#         high = max(higps[-6:-1])
#         low  = min(lowps[-6:-1])
#
#         aa[stk] = (clsps[-1]-opeps[-5])*1.0/(high - low+0.0001)
#
#     med =  np.median(aa.values())
#     top10value = np.percentile(aa.values(),90)
#     top20value = np.percentile(aa.values(),80)
#     top30value = np.percentile(aa.values(),70)
#     top40value = np.percentile(aa.values(),60)
#     top50value = np.percentile(aa.values(),50)
#     top60value = np.percentile(aa.values(),40)
#     top70value = np.percentile(aa.values(),30)
#     top80value = np.percentile(aa.values(),20)
#     top90value = np.percentile(aa.values(),10)
#
#     buylist = []
#
#     for stk in aa.keys():
#         # if aa[stk] > top10value:
#         # if top20value<=aa[stk]<top10value:
#         # if top30value<=aa[stk]<top20value:
#         # if top40value<=aa[stk]<top30value:
#         # if top50value<=aa[stk]<top40value:
#         # if top60value<=aa[stk]<top50value:
#         # if top70value<=aa[stk]<top60value:
#         # if top80value<=aa[stk]<top70value:
#         # if top90value<=aa[stk]<top80value:
#         if aa[stk] < top90value:
#             buylist.append(stk)
#
#     for stk in account.valid_secpos:
#
#         order_to(stk,0)
#
#     for stk in buylist:
#
#         if np.isnan(prices[stk]) or prices[stk] == 0:  # 停牌或是还没有上市等原因不能交易
#              continue
#         else:
#             order(stk,totalmoney/prices[stk]/len(buylist))

# %%
Revene = pd.DataFrame()

# %%
top = (bt['portfolio_value']/bt['portfolio_value'][0] - 1)

# %%
data = pd.DataFrame(top)

data.rename(columns={'portfolio_value': 'But10%'}, inplace=True)

Revene = pd.concat([Revene, data], axis=1)
Revene
# Out:
#        Top10%  Top10%-20%  Top20%-30%  Top30%-40%  Top40%-50%  Top50%-60%  \
# 0    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 1    0.001465    0.003103    0.002413    0.004957    0.005102    0.006160
# 2    0.011453    0.004913    0.000722    0.004961    0.004595    0.008144
# 3    0.022500    0.013141    0.010523    0.018890    0.012706    0.010778
# 4    0.016194    0.008549    0.012873    0.020936    0.012933    0.008967
# 5    0.033517    0.018637    0.024965    0.032612    0.028000    0.019813
# 6    0.027443    0.016698    0.021720    0.030065    0.021312    0.018179
# 7    0.026935    0.017736    0.021186    0.027596    0.028109    0.015474
# 8    0.028240    0.020575    0.020228    0.027690    0.027847    0.019501
# 9    0.037527    0.033842    0.029812    0.037654    0.036234    0.030403
# 10   0.054940    0.049177    0.043334    0.050187    0.045887    0.047429
# 11   0.056390    0.042211    0.042355    0.054382    0.048017    0.047905
# 12   0.066345    0.057672    0.055966    0.073462    0.060985    0.061249
# 13   0.078038    0.059731    0.058356    0.079756    0.063868    0.067116
# 14   0.077117    0.054735    0.056004    0.079328    0.067446    0.068338
# 15   0.064309    0.033231    0.039369    0.060617    0.052368    0.052677
# 16   0.064283    0.034678    0.040582    0.060434    0.054114    0.052862
# 17   0.079800    0.055235    0.059205    0.080298    0.074354    0.076585
# 18   0.073016    0.051894    0.053969    0.076424    0.073072    0.071837
# 19   0.062093    0.041484    0.045180    0.064755    0.062845    0.055171
# 20   0.055926    0.036761    0.039743    0.061304    0.056341    0.046807
# 21   0.068045    0.048939    0.056660    0.076298    0.072009    0.063428
# 22   0.076382    0.059305    0.068945    0.085412    0.088299    0.076227
# 23   0.082670    0.058340    0.076499    0.085995    0.093017    0.078410
# 24   0.082147    0.066128    0.084188    0.091731    0.100522    0.088862
# 25   0.040577    0.023228    0.046227    0.055454    0.065598    0.049672
# 26   0.040330    0.019344    0.046989    0.051714    0.056655    0.034261
# 27   0.059672    0.042593    0.067955    0.072965    0.073644    0.050712
# 28   0.061476    0.054412    0.073052    0.081485    0.082084    0.062512
# 29   0.038717    0.032802    0.054786    0.062013    0.059239    0.044323
# ..        ...         ...         ...         ...         ...         ...
# 927 -0.114540    0.126816    0.272262    0.474000    0.346663    0.629537
# 928 -0.105602    0.138820    0.286157    0.511072    0.381759    0.667420
# 929 -0.102636    0.153667    0.306755    0.529113    0.395597    0.678815
# 930 -0.117864    0.143019    0.288031    0.507372    0.367638    0.651334
# 931 -0.116411    0.144627    0.287091    0.514111    0.381113    0.651607
# 932 -0.124425    0.130942    0.262828    0.494827    0.365066    0.610021
# 933 -0.113877    0.129903    0.261791    0.497616    0.362357    0.609417
# 934 -0.121999    0.122600    0.263044    0.498453    0.356715    0.610421
# 935 -0.130642    0.123976    0.255939    0.498573    0.355416    0.604180
# 936 -0.123315    0.147517    0.283464    0.561163    0.393367    0.644315
# 937 -0.120035    0.154122    0.290316    0.549794    0.383060    0.635392
# 938 -0.119917    0.147368    0.291768    0.547077    0.384146    0.638235
# 939 -0.109791    0.171218    0.308920    0.570920    0.402501    0.671958
# 940 -0.114651    0.162602    0.304804    0.560461    0.394722    0.676737
# 941 -0.104240    0.186257    0.328241    0.584226    0.414348    0.711294
# 942 -0.100351    0.194521    0.341105    0.601616    0.420558    0.710037
# 943 -0.107589    0.189110    0.328164    0.589151    0.423306    0.695541
# 944 -0.112490    0.171935    0.310133    0.575266    0.404755    0.678287
# 945 -0.109508    0.170699    0.311001    0.579661    0.398602    0.676327
# 946 -0.129995    0.144613    0.276829    0.544185    0.369167    0.639138
# 947 -0.126558    0.152044    0.286082    0.556836    0.380139    0.649520
# 948 -0.126921    0.154161    0.290390    0.559930    0.381459    0.649471
# 949 -0.132696    0.148123    0.277955    0.550412    0.370683    0.635745
# 950 -0.169639    0.082931    0.189938    0.436296    0.276986    0.518207
# 951 -0.169295    0.078902    0.191034    0.443689    0.269525    0.528053
# 952 -0.160613    0.096038    0.221250    0.482063    0.292574    0.563984
# 953 -0.197531    0.036642    0.144447    0.384056    0.208877    0.459406
# 954 -0.191845    0.049847    0.174027    0.424565    0.230918    0.501489
# 955 -0.227433    0.016773    0.125751    0.365762    0.169871    0.432455
# 956 -0.242833    0.030389    0.133800    0.377864    0.178281    0.447330
#
#      Top60%-70%  Top70%-80%  Top80%-90%    But10%
# 0      0.000000    0.000000    0.000000  0.000000
# 1      0.003428   -0.001587    0.002557 -0.001087
# 2      0.006019   -0.000600    0.010593  0.004763
# 3      0.006881    0.002665    0.009052  0.004784
# 4      0.002809   -0.000734    0.006538  0.004246
# 5      0.014141    0.010767    0.015283  0.003393
# 6      0.011309    0.003899    0.014833  0.004550
# 7      0.007392    0.003261    0.016016  0.006470
# 8      0.010470    0.009638    0.016498  0.009642
# 9      0.024687    0.015347    0.025770  0.014480
# 10     0.041654    0.030164    0.039845  0.030561
# 11     0.042520    0.037896    0.044231  0.033705
# 12     0.057838    0.056172    0.059900  0.045527
# 13     0.065781    0.071994    0.063963  0.047787
# 14     0.060230    0.072178    0.059007  0.044768
# 15     0.046002    0.054666    0.044179  0.038253
# 16     0.049987    0.055637    0.046818  0.047287
# 17     0.066261    0.075558    0.063889  0.063240
# 18     0.067183    0.069888    0.061199  0.064288
# 19     0.060599    0.057160    0.052741  0.053136
# 20     0.046909    0.047502    0.042949  0.041779
# 21     0.061748    0.056634    0.055975  0.049594
# 22     0.073294    0.070386    0.066632  0.059856
# 23     0.077235    0.075451    0.067166  0.056364
# 24     0.087554    0.085655    0.077261  0.070184
# 25     0.048284    0.049012    0.040405  0.035038
# 26     0.030447    0.036274    0.030679  0.020752
# 27     0.045619    0.046519    0.038034  0.032352
# 28     0.056153    0.048601    0.035987  0.034284
# 29     0.040092    0.035784    0.022234  0.019055
# ..          ...         ...         ...       ...
# 927    0.689464    0.697062    1.345629  1.123216
# 928    0.735854    0.751045    1.404024  1.178691
# 929    0.742588    0.753188    1.422078  1.185804
# 930    0.709978    0.717533    1.368631  1.146690
# 931    0.723505    0.728643    1.389603  1.166525
# 932    0.692244    0.685352    1.333933  1.102401
# 933    0.694966    0.678173    1.324675  1.092604
# 934    0.697309    0.677067    1.319770  1.082778
# 935    0.685528    0.667972    1.304710  1.064589
# 936    0.732346    0.712019    1.365201  1.124488
# 937    0.723403    0.713101    1.349489  1.112570
# 938    0.736716    0.710266    1.348460  1.118281
# 939    0.776508    0.744680    1.390074  1.170520
# 940    0.762984    0.745117    1.384462  1.173425
# 941    0.797433    0.767530    1.449381  1.221464
# 942    0.800615    0.767316    1.451566  1.217849
# 943    0.795935    0.759816    1.443766  1.205786
# 944    0.781425    0.751887    1.437112  1.190896
# 945    0.778693    0.750721    1.432855  1.196008
# 946    0.732426    0.714944    1.363371  1.155208
# 947    0.754108    0.730295    1.383576  1.170176
# 948    0.757598    0.733393    1.391862  1.183779
# 949    0.732648    0.715353    1.368578  1.160656
# 950    0.596085    0.589308    1.195269  1.019450
# 951    0.599286    0.587195    1.194841  1.007912
# 952    0.649092    0.612793    1.260469  1.046773
# 953    0.523614    0.503883    1.080343  0.913353
# 954    0.574967    0.537742    1.132230  0.953178
# 955    0.477868    0.448818    0.995271  0.818781
# 956    0.493273    0.464160    1.023810  0.837636
#
# [957 rows x 10 columns]

# %%
Revene.plot(figsize = (14,8))

# %% [markdown]
# 上图表明，波动收益比因子越大，相应组合的收益率越小。波动收益比是一个反向因子。
# 下面研究因子的区分度，计算Top5%组合和But5%组合之间的收益差。

# %% [raw]
# import numpy as np
# import pandas as pd
# from CAL.PyCAL import *
# from pandas import DataFrame,Series
# from datetime import datetime, timedelta
#
# start = '2012-01-01'                       # 回测起始时间
# end = '2016-01-12'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')
# capital_base = 100000                         # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 5                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# cal = Calendar('China.SSE')
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令          # 包含stk 和benchmark
#     clsp = account.get_attribute_history('closePrice', 20)
#     opep = account.get_attribute_history('openPrice', 20)
#     higp = account.get_attribute_history('highPrice', 20)
#     lowp = account.get_attribute_history('lowPrice',20)
#
#     buylist = []
#     selllist = []
#
#     paral = []
#
#     aa = {}
#     totalmoney = account.referencePortfolioValue
#     prices = account.referencePrice
#
#     for stk in account.universe:
#
#         clsps = clsp[stk]
#         opeps = opep[stk]
#         higps = higp[stk]
#         lowps = lowp[stk]
#
#         high = max(higps[-6:-1])
#         low  = min(lowps[-6:-1])
#
#         aa[stk] = (clsps[-1]-opeps[-5])*1.0/(high - low+0.0001)
#
#     med =  np.median(aa.values())
#     top5value = np.percentile(aa.values(),95)
#     but5value = np.percentile(aa.values(),5)
#
#     buylist = []
#
#     for stk in aa.keys():
#
#         if aa[stk] > top5value:
#         # if aa[stk] < but5value:
#
#             buylist.append(stk)
#
#     for stk in account.valid_secpos:
#
#         order_to(stk,0)
#
#     for stk in buylist:
#
#         if np.isnan(prices[stk]) or prices[stk] == 0:  # 停牌或是还没有上市等原因不能交易
#              continue
#         else:
#             order(stk,totalmoney/prices[stk]/len(buylist))

# %%
top = (bt['portfolio_value']/bt['portfolio_value'][0] - 1)

# %% [raw]
# import numpy as np
# import pandas as pd
# from CAL.PyCAL import *
# from pandas import DataFrame,Series
# from datetime import datetime, timedelta
#
# start = '2012-01-01'                       # 回测起始时间
# end = '2016-01-12'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')
# capital_base = 100000                         # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 5                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# cal = Calendar('China.SSE')
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令          # 包含stk 和benchmark
#     clsp = account.get_attribute_history('closePrice', 20)
#     opep = account.get_attribute_history('openPrice', 20)
#     higp = account.get_attribute_history('highPrice', 20)
#     lowp = account.get_attribute_history('lowPrice',20)
#
#     buylist = []
#     selllist = []
#
#     paral = []
#
#     aa = {}
#     totalmoney = account.referencePortfolioValue
#     prices = account.referencePrice
#
#     for stk in account.universe:
#
#         clsps = clsp[stk]
#         opeps = opep[stk]
#         higps = higp[stk]
#         lowps = lowp[stk]
#
#         high = max(higps[-6:-1])
#         low  = min(lowps[-6:-1])
#
#         aa[stk] = (clsps[-1]-opeps[-5])*1.0/(high - low+0.0001)
#
#     med =  np.median(aa.values())
#     top5value = np.percentile(aa.values(),95)
#     but5value = np.percentile(aa.values(),5)
#
#     buylist = []
#
#     for stk in aa.keys():
#
#         # if aa[stk] > top5value:
#         if aa[stk] < but5value:
#
#             buylist.append(stk)
#
#     for stk in account.valid_secpos:
#
#         order_to(stk,0)
#
#     for stk in buylist:
#
#         if np.isnan(prices[stk]) or prices[stk] == 0:  # 停牌或是还没有上市等原因不能交易
#              continue
#         else:
#             order(stk,totalmoney/prices[stk]/len(buylist))

# %%
but = (bt['portfolio_value']/bt['portfolio_value'][0] - 1)

# %%
(but-top).plot(figsize = (14,8))

# %% [markdown]
# #### 结论：
# ###### 1、收益波动比因子表现比较稳健，区分度明显，可以用于构建多因子模型。
# ###### 2、由于因子收益与波动率正相关，收益波动率因子组合在股灾期间发生了较大回撤，在其他时间，因子表现比较稳健。
# ###### 3、后续研究可以分析收益率和波动率哪个对组合的影响更大， 通过为收益率和波动率附加系数对因子进行优化。
# ###### 4、基于量价的市场类因子有必要进行深入研究。
