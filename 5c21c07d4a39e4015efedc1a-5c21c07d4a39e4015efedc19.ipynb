# %% [markdown]
# # 唐奇安通道(日线）主连向前复权

# %% [raw]
# import numpy as np
# import pandas as pd
# import talib
#
# start = '2018-7-15'                       # 回测起始时间
# end = '2018-8-15'                         # 回测结束时间
# universe = ['RB1810']
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate =1
# max_history_window = 60
# high_time_range = 20
# low_time_range = 10
# order_amount = 3
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'futures_account': AccountConfig(account_type='futures', capital_base=50000,margin_rate = 0.15)
# }
#
# def initialize(context):
#     pass
#
# def handle_data(context):
#     account = context.get_account('futures_account')
#     # print context.now
#
#     universe = context.get_universe()
#     symbol = context.get_symbol('RBM0')
#
#
#     data = context.history(symbol,attribute = ['highPrice','lowPrice'],freq = '60m',time_range = 30,rtype = 'array')
#
#     # log.info(data)
#     # log.info(symbol)
#
#     high_price =data[symbol]['highPrice']
#
#     # log.info(high_price[-1])
#
#     low_price = data[symbol]['lowPrice']
#
#     current_price = context.current_price(symbol)
#     position = account.get_position(symbol)
#
#     # log.info(current_price)
#
#
#     #期货操作系统
#     if not position:
#         if current_price > high_price[-high_time_range:-1].max():
#
#             account.order(universe[0],order_amount,'open')
#
#         if current_price < low_price[-high_time_range:-1].min():
#             account.order(universe[0],-order_amount,'open')
#
#     else:
#         if position.long_amount > 0:
#             if current_price < low_price[-low_time_range:-1].min():
#                 account.close_all_positions()
#
#         if position.short_amount > 0:
#             if current_price > high_price[-low_time_range:-1].max():
#                 account.close_all_positions()
