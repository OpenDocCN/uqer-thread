# %% [markdown]
# #

# %% [markdown]
# ## 弱势情况：a(9:31<0)&a(9:40<0)  a(9:31>0)&a(9:40<0)
# ### 弱势策略：
#     - 买入信号：1.5日线在10日线之上
#               2.下跌1%买入十分之一，下跌2%加仓十分之一，下跌百分之3加仓十分之一，下跌百分之4加仓十分之一。
#
#     - 卖出信号：1.上涨1%卖出30%，上涨2%清仓。
#               2.5日线下穿10日线

# %% [markdown]
# # 修正版

# %% [raw]
# start = '2016-01-01'                       # 回测起始时间
# end = '2016-09-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['002142.XSHE']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# commission = Commission(buycost=0.0003, sellcost=0.002, unit='perValue')   #手续费，买入万三，卖出千二，按股价百分比收费
#
# MA5=0
# MA10=0
# a30=0
# a31=0
# a40=0
# buy={'one':'0','two':'0','three':'0','four':'0'}
# sell={'one':'0','two':'0','three':'0','four':'0'}
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     now_day=account.previous_date.strftime('%Y%m%d')  # 获取上一个交易日
#     # now_day=account.current_date.strftime('%Y%m%d')
#     global MA5,MA10,a30,a31,a40,buy,sell
#     # 获取日线信息
#     if account.current_minute=='09:30':
#         # 重置全局变量
#         MA5=0
#         MA10=0
#         a30=0
#         a31=0
#         a40=0
#         buy={'one':'0','two':'0','three':'0','four':'0'}
#         sell={'one':'0','two':'0','three':'0','four':'0'}
#
#         now_data=DataAPI.MktStockFactorsOneDayGet(tradeDate=now_day,secID=account.universe,ticker=u"",field=u"MA5,MA10",pandas="1").dropna()
#         if now_data is not None:
#             MA5=now_data['MA5'][0]
#             MA10=now_data['MA10'][0]
#     if account.current_minute=='09:31':
#         for s in account.universe:
#             a30=account.get_attribute_history('closePrice',1)[s][0]
#     if account.current_minute=='09:32':
#         for s in account.universe:
#             a31=account.get_attribute_history('closePrice',1)[s][0]
#     if account.current_minute=='09:41':
#         for s in account.universe:
#             a40=account.get_attribute_history('closePrice',1)[s][0]
#     if account.current_minute>'09:41':
#         for s in account.universe:
#             now_price=account.get_attribute_history('closePrice',1)[s][0]
#         # 如果为弱势期
#             cp= account.get_daily_attribute_history('closePrice', 1)[s][0]
#             #print account.current_date,now_price
#             #print account.previous_date,cp
#         if (a31-a30<0 and a40-a30<0) or (a31-a30>0 and a40-a30<0):
#             for s in account.universe:
#                 if MA5>MA10:
#                     wave=now_price/cp-1
#
#                     if -0.01<=wave<-0.02 and buy['one']=='0':
#                         order_pct(s,0.1)
#                         buy['one']='1'
#                     elif -0.02<=wave<-0.03 and buy['two']=='0':
#                         order_pct(s,0.1)
#                         buy['two']='1'
#                     elif -0.03<=wave<-0.04 and buy['three']=='0':
#                         order_pct(s,0.1)
#                         buy['three']='1'
#                     elif -0.04<=wave<-0.05 and buy['four']=='0':
#                         order_pct(s,0.1)
#                         buy['four']='1'
#             for s in account.avail_secpos:
#                 if MA5<MA10:
#                     up=now_price/account.valid_seccost[s]-1
#                     if 0.01<=up<0.02 and sell['one']=='0':
#                         order_pct_to(s,0.7)
#                         sell['one']='1'
#                     elif up>=0.02 and sell['two']=='0':
#                         order_pct_to(s,0)
#                         sell['two']='1'
#
#         # 如果为强势期
#         if (a31-a30>0 and a40-a30>0) or (a31-a30<0 and a40-a30>0):
#             for s in account.universe:
#                 if MA5>MA10:
#                     wave=now_price/cp-1
#                     if -0.01<=wave<-0.02 and buy['one']=='0':
#                         order_pct(s,0.3)
#                         buy['one']='1'
#                     elif -0.02<=wave<-0.03 and buy['two']=='0':
#                         order_pct(s,0.03)
#                         buy['two']='1'
#             for s in account.avail_secpos:
#                 if MA5<MA10:
#                     up=now_price/account.valid_seccost[s]-1
#                     if 0.01<=up<0.02 and sell['one']=='0':
#                         order_pct_to(s,0.3)
#                         sell['one']='1'
#                     elif 0.02<=up<0.03 and sell['two']=='0':
#                         order_pct_to(s,0.7)
#                         sell['two']='1'
#                     elif 0.03<=up<0.04 and sell['three']=='0':
#                         order_pct_to(s,0)
#                         sell['three']='1'
#                     elif 0.04<=up and sell['four']=='0':
#                         order_pct_to(s,0)
#                         sell['four']='1'

# %% [raw]
# start = '2016-01-01'                       # 回测起始时间
# end = '2016-08-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['002142.XSHE']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     print account.current_date,account.get_attribute_history('openPrice',1)['002142.XSHE'][0]

# %% [raw]
# start = '2016-01-01'                       # 回测起始时间
# end = '2016-08-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['002142.XSHE']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     if account.current_minute=='09:31':
#         print account.previous_date.strftime('%Y%m%d'),account.get_attribute_history('openPrice',1)['002142.XSHE'][0]
