# %% [markdown]
# # 一字跌停板博弈

# %%
#去除St股的高换手率的跌停股，赌打开跌停 #20190606 金逸影视

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

startDate='20190604'
finalDate='20190605'
newDate='20190606' #剔除当天的新股
#过滤st股
st=DataAPI.SecSTGet(beginDate=startDate,endDate=finalDate,secID=u"",ticker=u"",field=u"",pandas="1")
st=set(st.secID)
new=DataAPI.EquIPOGet(secID=u"",ticker=u"",eventProcessCD=u"",beginDate=newDate,endDate=newDate,field=u"",pandas="1")
new=set(new['secID'])
tmp=DataAPI.EquGet(secID=u"",ticker=u"",equTypeCD=u"A",listStatusCD=u"L",field=['secID'],pandas="1")

pool=set(tmp['secID'])
#print(len(pool)) #3614
pool=pool-st-new
#print(len(pool)) #3481
out=[]
for i in pool:
    tmp=DataAPI.MktEqudGet(secID=i,ticker=u"",tradeDate=finalDate,beginDate=u"",endDate=u"",isOpen="",field=u"",pandas="1")
    
    t1=tmp.openPrice[0]
    
    t2=tmp.closePrice[0]
    t3=tmp.turnoverRate[0]
    t4=tmp.chgPct[0]
    if (t1==t2 and t4<=-0.095):
        if (t3>=0.1):
            out.append(i)
print(out)
# Out:
# ['002905.XSHE']
