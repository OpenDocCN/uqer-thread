# %% [markdown]
# #

# %% [raw]
# import numpy as np
# start = '2009-01-01'                       # 回测起始时间
# end = '2016-06-16'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('A',date=end)  # 证券池，支持股票和基金
# capital_base = 1000000                     # 起始资金
# commission = Commission(buycost=0.0008, sellcost=0.0018)  # 佣金万八
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 15                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def st(date,account):#选出市值最小的10个ST股票
#     univ=account.universe
#     df_ST = DataAPI.SecSTGet(secID=univ, beginDate=date, endDate=date, field=['secID'],pandas='1')
#     df_ST.dropna
#     stID=df_ST['secID'].values
#     value1=DataAPI.MktEqudGet(tradeDate=date,secID=stID,beginDate=date,endDate=date,field=['secID','marketValue'],pandas='1')
#     value=value1.sort(columns='marketValue').head(10)
#     stock_list=[]  #定义一个列表
#     for stock,marketvalue in zip(value['secID'].values,value['marketValue'].values):
#             stock_list.append((stock, marketvalue))
#     return stock_list
#
#
# def handle_data(account): # 每个交易日的买入卖出指令
#
#     i=0
#     current_date = account.current_date
#     current_date = current_date.strftime('%Y%m%d')
#     date=account.previous_date
#     stocklist=dict(st(date,account))
#     last_screener = stocklist.keys()
#     buylist = [sec for sec in last_screener if sec in account.universe]
#     v = account.referencePortfolioValue
#     d = len(buylist)
#
#     # 卖出不在买入列表中的股票，估计持仓价值
#     for stock in account.valid_secpos:
#         if stock not in buylist:
#             if stock in account.universe:
#                 order_to(stock, 0)
#             else:
#                 v -= account.valid_secpos[stock] * account.referencePrice[stock]
#
#     # 获得调仓数量
#     change = {}
#     for stock in buylist:
#         p = account.referencePrice[stock]
#         if p and not np.isnan(p):
#             change[stock] = int(v / d / p) - account.valid_secpos.get(stock, 0)
#
#     # 按先卖后买的顺序发出指令
#     for stock in sorted(change, key=change.get):
#         if change[stock] <= -100 or change[stock] >= 100:
#             order(stock, change[stock])
#
#
#     return
