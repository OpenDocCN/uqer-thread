# %% [markdown]
# # 分享_策略尝试_10日高低点突破_搭配策略

# %% [raw]
# #上证50结果
# start = '2010-01-01'                       # 回测起始时间
# end = '2016-01-01'                         # 回测结束时间
# benchmark = 'SH50'                        # 策略参考标准
# universe = ['510050.XSHG', '159919.XSHE']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# stockSecID='510050.XSHG'
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     global stockSecID
#     stock_prices=account.get_history(10)
#     if stock_prices[stockSecID]['closePrice'][-1]==stock_prices[stockSecID]['closePrice'].max():
#         order(stockSecID,account.referencePortfolioValue / account.referencePrice[stockSecID])
#     elif  stock_prices[stockSecID]['closePrice'][-1]==stock_prices[stockSecID]['closePrice'].min():
#         order_to(stockSecID,0)

# %% [raw]
# #HS300结果
# start = '2013-01-01'                       # 回测起始时间
# end = '2016-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['510050.XSHG', '159919.XSHE']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# stockSecID='159919.XSHE'
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     global stockSecID
#     stock_prices=account.get_history(10)
#     if stock_prices[stockSecID]['closePrice'][-1]==stock_prices[stockSecID]['closePrice'].max():
#         order(stockSecID,account.referencePortfolioValue / account.referencePrice[stockSecID])
#     elif  stock_prices[stockSecID]['closePrice'][-1]==stock_prices[stockSecID]['closePrice'].min():
#         order_to(stockSecID,0)
