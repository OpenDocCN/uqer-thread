# %% [markdown]
# #

# %%
DataAPI.EquGet(equTypeCD=u"A",secID=u"",ticker=u"DY600018",listStatusCD=u"",pandas="1")
# Out:
#            secID    ticker exchangeCD  ListSectorCD ListSector transCurrCD  \
# 0  DY600018.XSHG  DY600018       XSHG             1         主板         CNY
#
#   secShortName   secFullName listStatusCD    listDate    ...    equType  \
# 0         上港集箱  上海港集装箱股份有限公司           DE  2000-07-19    ...       沪深A股
#
#   exCountryCD partyID totalShares  nonrestFloatShares  nonrestfloatA  \
# 0         CHN     618  1804400000           538157900      538157900
#
#              officeAddr                                     primeOperating  \
# 0  上海市军工路4049号(吉发大厦15楼)  集装箱装卸、储存、拆装箱;水陆运输、中转、多式联运;货运代理、船务代理;信息及管理;工程技术...
#
#   endDate TShEquity
# 0     NaN       NaN
#
# [1 rows x 22 columns]
