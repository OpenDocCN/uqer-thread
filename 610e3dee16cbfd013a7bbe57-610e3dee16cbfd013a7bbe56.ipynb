# %% [markdown]
# # 0513

# %%
# -------1.债券违约BondDefaultAct---------

# %%
DataAPI.IdxGet(secID=u"",ticker=u"000001",indexGroup=u"",consType=u"",consMkt=u"",returnType=u"",indexTypeCD=u"",porgFullName=u"",secShortName=u"",wMethodCD="",pubName=u"",industryID=u"",sortID=u"",field=u"",pandas="1")
# Out:
#          secID publishDate secShortName  ticker indexTypeCD indexType  \
# 0  000001.ZICN  1991-07-14         上证综指  000001          01      股票指数
#
#    pubOrgCD porgFullName    baseDate  basePoint   ...     consType consMkt  \
# 0     17764      上海证券交易所  1990-12-19        100   ...            E    XSHG
#
#   returnType wMethodCD           updateTime   pubName industryID industryName  \
# 0          P       I43  2021-07-30 14:38:17  中证指数有限公司        NaN          NaN
#
#             sortID sortName
# 0  101007001001001   上证规模指数
#
# [1 rows x 22 columns]
#          secID publishDate secShortName  ticker indexTypeCD indexType  \
# 0  000001.ZICN  1991-07-14         上证综指  000001          01      股票指数
#
#    pubOrgCD porgFullName    baseDate  basePoint   ...     consType consMkt  \
# 0     17764      上海证券交易所  1990-12-19        100   ...            E    XSHG
#
#   returnType wMethodCD           updateTime   pubName industryID industryName  \
# ...

# %%
# 检查字段筛选
DataAPI.BondDefaultActGet(ticker=u"",secID=u"150570.XSHG",endDate=u"2021-07-25",beginDate=u"2020-07-25",field=u"",pandas="1")
# Out:
# Empty DataFrame
# Columns: [secID, ticker, exchangeCD, secShortName, bondID, defaultDate, defaultMode, defaultPayment, defaultInterest, publishDate, annoTitle]
# Index: []
# Empty DataFrame
# Columns: [secID, ticker, exchangeCD, secShortName, bondID, defaultDate, defaultMode, defaultPayment, defaultInterest, publishDate, annoTitle]
# Index: []

# %%
#必填项为空
DataAPI.BondDefaultActGet(ticker=u"",secID=u"",endDate=u"",beginDate=u"",field=u"",pandas="1")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <mercury-input-13-610DF2AF07E6426FAA8C8911133DC972> in <module>()
#       1 #必填项为空
# ----> 2 DataAPI.BondDefaultActGet(ticker=u"",secID=u"",endDate=u"",beginDate=u"",field=u"",pandas="1")
#
# /home/ipython/anaconda/lib/python2.7/site-packages/DataAPI/DATAYES.pyc in BondDefaultActGet(ticker, secID, endDate, beginDate, field, pandas)
#   74423         csvString = api_base.__getCSV__(''.join(requestString), httpClient, gw=True)
#   74424         if csvString is None or len(csvString) == 0 or (csvString[0] == '-' and not api_base.is_no_data_warn(csvString, False)) or csvString[0] == '{':
# > 74425             api_base.handle_error(csvString, 'BondDefaultActGet')
#   74426         elif csvString[:2] == '-1':
#   74427             csvString = ''
#
# ...

# %%
#-----------------2.债券发行人股东getBondIssuerSh-------------------

# %%
DataAPI.BondIssuerShGet(partyID=u"38268",partyFullName=u"",beginDate=u"",endDate=u"",field=u"",pandas="1")

# %%
DataAPI.BondIssuerShGet(partyID=u"",partyFullName=u"上饶市城市建设投资开发集团有限公司",beginDate=u"2017-12-30"
                        ,endDate=u"2017-12-30",field=u"",pandas="1")

# %%
DataAPI.BondIssuerShGet(partyID=u"",partyFullName=u"",beginDate=u"",endDate=u"",field=u"",pandas="1")

# %%
#------------------3.债券财务指标getBondFdmtIndilt-------------

# %%
DataAPI.BondFdmtIndiltGet(partyID=u"3",partyFullName=u"",beginDate=u"",endDate=u"",reportType=u"A",field=u"",pandas="1")

# %%
DataAPI.BondFdmtIndiltGet(partyID=u"",partyFullName=u"万科"	,beginDate=u"2019-12-31",endDate=u"2020-10-31",reportType=u"",field=u"",pandas="1")

# %%
#------------------4.债券主营业务构成(基础数据)BondFdmtMainOperGet------------------

# %%
DataAPI.BondFdmtMainOperGet(ticker=u"122837",secID=u"",endDate=u"",beginDate=u"",exchangeCD=u"",partyID=u"",field=u"",pandas="1")

# %%
DataAPI.BondFdmtMainOperGet(ticker=u"",secID=u"",endDate=u"",beginDate=u"",exchangeCD=u"",partyID=u"",field=u"",pandas="1")

# %%
#------------------5.期货品种信息FutuStandCont--------------

# %%
DataAPI.FutuStandContGet(exchangeCD=u"XZCE",contractObject=u"AP",objectName=u"",prodID=u"",field=u"",pandas="1")

# %%
# objectName模糊查询
DataAPI.FutuStandContGet(exchangeCD=u"",contractObject=u"",objectName=u"鲜",prodID=u"",field=u"",pandas="1")

# %%
# 按期货品种编码prodID查询

# df=DataAPI.FutuStandContGet(exchangeCD=u"",contractObject=u"",objectName=u"鲜",prodID=u"",field=u"",pandas="1")
# df.prodID
DataAPI.FutuStandContGet(exchangeCD=u"XZCE",contractObject=u"AP",objectName=u"",prodID=u"222",field=u"",pandas="1")

# %%
# exchangeCD、contractObject、objectName至少选择一个，均为空
DataAPI.FutuStandContGet(exchangeCD=u"",contractObject=u"",objectName=u"",prodID=u"",field=u"",pandas="1")

# %%
# -------------6.新闻关联标签行业表NewsTagIndGet------------------

# %%
DataAPI.NewsTagIndGet(newsID=u"",beginEffTime=u"20201230090000",endEffTime=u"20201230093000",newsGenre=u"",field=u"",pandas="1")

# %%
#------------------------7.公司新闻指数统计表NewsStockIndexWV2----------------

# %%
DataAPI.NewsStockIndexWV2Get(secID=u"",ticker=u"600000",beginDate=u"20200701",endDate=u"20200731",field=u"",pandas="1")
