# %% [markdown]
# # Notebook

# %% [raw]
# universe = 'IF1601'                          # 策略期货合约
# start = '2016-06-01'                       # 回测开始时间
# end  = '2016-12-01'                        # 回测结束时间
# capital_base = 999999999                     # 初试可用资金
# refresh_rate = 1                          # 调仓周期
# freq = 'd'                                 # 调仓频率：m-> 分钟；d-> 日
#
# def initialize(futures_account):           # 初始化虚拟期货账户，一般用于设置计数器，回测辅助变量等。
#     pass
#
# def handle_data(futures_account):          # 回测调仓逻辑，每个调仓周期运行一次，可在此函数内实现信号生产，生成调仓指令。
#     try:
#         order('IF1606',1,'open')
#     except:
#         pass
