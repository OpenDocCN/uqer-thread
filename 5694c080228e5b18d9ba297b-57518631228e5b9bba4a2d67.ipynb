# %% [markdown]
# # 更新版ETF行业轮动

# %% [raw]
# import pandas as pd
# import scipy.stats as stats
# from pandas import DataFrame
#
# start = '2015-01-01'                       # 回测起始时间
# end = '2015-11-19'                         # 回测结束时间
# benchmark = 'HS300'                         # 策略参考标准
# universe = ['510610.XSHG','510650.XSHG', '512620.XSHG', '512630.XSHG'][0:3]          # 证券池，支持股票和基金:能源，金额，材料，消费
# capital_base = 100000                       # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
#
# global bond
# global n
# data=pd.read_excel('BOND.xlsx')
# index=data['DATE'].values
# num=range(len(index))
# d={'num':num}
# dat=DataFrame(d,index=index)
# s=['ENERGY','FINANCE','INDUSTRY','CONSUME']
# dat1=data[s].values
# dat1=DataFrame(dat1,index=index,columns=s)
#
# bond=pd.concat([dat1,dat],axis=1)
# n=30
#
# global dic
# j=0
# dic={}
# for stk in universe:
#     dic[stk]=s[j]
#     j+=1
#
#
# def signal(bond,n,stkpos,hist,date):
#     rnum=int(bond.T[date].iloc[4])
#     bond=bond[rnum+1:rnum+n+2]
#     signal={}
#     for s in stkpos:
#         a, b, c, d, std_err = stats.linregress(bond[dic[s]][1:n+1],hist[s][0:n])
#         dif=hist[s][n]-a*bond[dic[s]][0]-b
#         if dif<0:
#             signal[s]=1
#         else:
#             signal[s]=0
#     return signal
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     # 每周一更新仓位
#     if  account.current_date.weekday() != 1 :
#         return
#     #获取当前的持仓信息和历史数据
#     date=account.current_date
#     hist=account.get_attribute_history('closePrice',n+1)
#     stkpos=account.universe
#     #返回购买信号1：买 0：卖
#     sig=signal(bond,n,stkpos,hist,date)
#
#
#     for s in stkpos:
#         if sig[s]==0 and s in account.avail_secpos:
#             order_to(s,0)
#     num1=(3-len(account.valid_secpos))
#     if num1>0:
#         cash=account.cash/num1
#         for s in stkpos:
#             if sig[s]==1 and s not in account.avail_secpos:
#                 order(s,cash)
