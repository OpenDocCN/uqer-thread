# %% [markdown]
# # 生命1号

# %% [raw]
# import numpy as np
# import pandas as pd
# from pandas import DataFrame,Series
# import talib
# import time
# start = '2016-01-01'                       # 回测起始时间
# end = '2017-01-01'                         # 回测结束时间
# universe = DynamicUniverse('SH50')     # 证券池，支持股票和基金、期货
# benchmark = 'HS300'
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 66                          # 执行handle_data的时间间隔
# max_history_window=600
# L=60
# i=1
# # 执行handle_data的时间间隔
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=1000000)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):
#     # 核心策略逻辑
#
#     data=DataAPI.MktEqumAdjGet(secID=universe,field=u"monthEndDate,closePrice",beginDate=start,endDate=end,pandas="1")
#     #DataAPI.MktEqumAdjGet(secID=u"",ticker=u"000001",monthEndDate=u"",isOpen=u"",beginDate=u"",endDate=u"",field=u"",pandas="1")
#     data2=DataAPI.MktEqudGet(secID=universe,field=u"tradeday,closePrice",beginDate=start,endDate=end,pandas="1")
#     #DataAPI.MktEqudGet(tradeDate=u"20150513",secID=u"",ticker=u"",beginDate=u"",endDate=u"",isOpen="",field=u"",pandas="1")
#     if data2['tradeday'] in data['monthEndDate']:
#         data['L_average'] = np.round(pd.rolling_mean(data2['closePrice'], window=L), 2)/data2['closePrice']
#         data[['closePrice', 'monthEndDate', 'L_average']].tail()
#     else:
#         pass
