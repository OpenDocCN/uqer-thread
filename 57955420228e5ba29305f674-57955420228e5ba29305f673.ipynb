# %% [markdown]
# #

# %%
import matplotlib.pyplot as plt
import pandas as pd 
from CAL.PyCAL import * #里面含有字体，绘制中文字符时需要
ZXZQD=DataAPI.MktEqudAdjGet(tradeDate=u"",secID=u"",ticker=u"600030",isOpen="",beginDate=u"20140513",endDate=u"20160713",field=u"ticker,tradeDate,secShortName,openPrice,lowestPrice,closePrice",pandas="1")
print ZXZQD.head(5)
plt.plot(ZXZQD.openPrice)
#plt.title(ZXZQD['ticker'][2],fontproperties = font)
plt.title(ZXZQD['secShortName'][2],fontproperties = font)
# Out:
#    ticker   tradeDate secShortName  openPrice  lowestPrice  closePrice
# 0  600030  2014-05-13         中信证券     11.645       11.518      11.567
# 1  600030  2014-05-14         中信证券     11.616       11.528      11.635
# 2  600030  2014-05-15         中信证券     11.635       11.264      11.352
# 3  600030  2014-05-16         中信证券     11.362       11.030      11.069
# 4  600030  2014-05-19         中信证券     10.952       10.737      10.796
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <mercury-input-1-df542ad18ecc> in <module>()
#       5 print ZXZQD.head(5)
#       6 plt.plot(ZXZQD.openPrice)
# ----> 7 plt.title(ZXZQD['secShortName'][2],fontproperties = font)
#
# python2.7/site-packages/matplotlib/pyplot.pyc in title(s, *args, **kwargs)
#    1436
#    1437     """
# -> 1438     return gca().set_title(s, *args, **kwargs)
#    1439
#    1440 ## Axis ##
#
# ...
