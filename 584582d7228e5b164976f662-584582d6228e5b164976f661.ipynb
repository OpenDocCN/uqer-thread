# %% [markdown]
# # 求助，源数据有错误！

# %%
zhishu=DataAPI.MktIdxdGet(beginDate=u"20161201",endDate=u"20161205",ticker=u"000001,399001",field=u"tradeDate,secShortName,preCloseIndex,closeIndex,CHG,turnoverValue",pandas="1")
print zhishu.set_index('secShortName')
# Out:
#                tradeDate  preCloseIndex  closeIndex      CHG  turnoverValue
# secShortName
# 上证综指          2016-12-01       3250.034    3273.309   23.275   2.615539e+11
# 上证综指          2016-12-02       3273.309    3243.843  -29.466   2.815591e+11
# 上证综指          2016-12-05       3243.843    3204.709  -39.134   2.385980e+11
# 深证成指          2016-12-01      11012.192   11088.156   75.964   1.385487e+11
# 深证成指          2016-12-02      11088.156   10912.627 -175.529   1.390992e+11
# 深证成指          2016-12-05      10912.627   10784.331 -128.296   1.244592e+11
