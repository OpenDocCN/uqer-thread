# %% [markdown]
# # 同行业数据对比

# %%
# 输入需要研究的股票及同行业股票代码，然后点击“全部运行”查看数据即可对比：资源占用情况、毛利率、净利率、三费占比、ROIC、ROE、ROA等数据。
# 第一个代码为所研究的股票，其他代码为同行业代码
list_ticker = ['000848','000019','002387','600300','600962','600238']

# %%
import pandas as pd
import numpy as np

# 资源占用情况
def compareByOccupation(list_ticker):
    df = DataAPI.FdmtBSAllLatestGet(ticker=list_ticker,secID=u"",reportType=u"A",endDate=u"",beginDate=u"",year="",field=u"",pandas="1")
    df_result = 1
    
    dict_stock = {}
    for ticker in df.groupby('ticker'):
        df_temp = ticker[1][:10]
        stockcode =  ticker[0]
        stockname =  df_temp.secShortName.tolist()[0]
        dict_stock[stockcode] = stockname
        df_temp['occupation'] = (np.nan_to_num(df_temp['AP']) + np.nan_to_num(df_temp['advanceReceipts']) + np.nan_to_num(df_temp['othPayable'])) -  (np.nan_to_num(df_temp['AR']) + np.nan_to_num(df_temp['prepayment']) + np.nan_to_num(df_temp['othReceiv'])) 
        df_temp['assets'] = (np.nan_to_num(df_temp['TShEquity'])+ np.nan_to_num(df_temp['STBorr'])+ np.nan_to_num(df_temp['NCLWithin1Y'])+ np.nan_to_num(df_temp['LTBorr'])+ np.nan_to_num(df_temp['bondPayable'])+ np.nan_to_num(df_temp['LTPayable']))
        ratio = 'occupation_pct'
        df_temp[ratio] = np.round(df_temp['occupation'] / df_temp['assets'] * 100,2)
        
        
        if type(df_result) == int:
            df_result = df_temp[['endDate',ratio]]
        else:
            df_result = df_result.merge(df_temp[['endDate',ratio]], on=['endDate'], how='inner')
        df_result.rename(columns={ratio: stockcode}, inplace=True)
        
        


    df_result = df_result.sort(columns=['endDate'], ascending=[True])
    df_result['endDate'] = df_result['endDate'].astype(str).str[:4] + "年"
    df_result.rename(columns={'endDate': "资源占用(%)"}, inplace=True)
    df_result = df_result.set_index("资源占用(%)")
    #df_result = df_result.dropna()
    
      
    df_result = df_result[list_ticker]
    for k,v in dict_stock.items():
        df_result.rename(columns={k: v}, inplace=True)

    return df_result

# 盈利率比较
def compareByRatio(list_ticker, ratio = 'ROIC'):
    df = DataAPI.FdmtIndiRtnGet(ticker=list_ticker,secID="",endDate="",beginDate="",beginYear=u"",endYear=u"",reportType=u"A",field=u"",pandas="1")
    df_result = 1
    
    dict_stock = {}
    for ticker in df.groupby('ticker'):
        df_temp = ticker[1][:10]
        stockcode =  ticker[0]
        stockname =  df_temp.secShortName.tolist()[0]
        dict_stock[stockcode] = stockname

        df_temp[ratio] = np.round(df_temp[ratio],2)
        if type(df_result) == int:
            df_result = df_temp[['endDate',ratio]]
        else:
            df_result = df_result.merge(df_temp[['endDate',ratio]], on=['endDate'], how='inner')
        df_result.rename(columns={ratio: stockcode}, inplace=True)


    df_result = df_result.sort(columns=['endDate'], ascending=[True])
    df_result['endDate'] = df_result['endDate'].astype(str).str[:4] + "年"

    if ratio == 'grossMARgin':
        ratio = "毛利率"
    if ratio == 'npMARgin':
        ratio = "净利率"

    df_result.rename(columns={'endDate': ratio + "(%)"}, inplace=True)
    df_result = df_result.set_index(ratio + "(%)")
    df_result = df_result.dropna()
    
      
    df_result = df_result[list_ticker]
    for k,v in dict_stock.items():
        df_result.rename(columns={k: v}, inplace=True)

    return df_result

# 三费占比
def compareByThreeFee(list_ticker, ratio = "三费占比"):
    df = DataAPI.FdmtISAllLatestGet(ticker=list_ticker,secID=u"",reportType=u"A",year="",endDate=u"",beginDate=u"",field=u"",pandas="1")
    df_result = 1
    
    dict_stock = {}
    for ticker in df.groupby('ticker'):
        df_temp = ticker[1][:10]
        stockcode =  ticker[0]
        stockname =  df_temp.secShortName.tolist()[0]
        dict_stock[stockcode] = stockname
        
        if ratio == '三费占比':
            df_temp[ratio]  = (df_temp['sellExp'] + df_temp['adminExp'] + df_temp['finanExp']) / df_temp['revenue'] * 100
        if ratio =='销售费用占比':
            df_temp[ratio]  = df_temp['sellExp'] / df_temp['revenue'] * 100
        if ratio =='管理费用占比':
            df_temp[ratio]  = df_temp['adminExp'] / df_temp['revenue'] * 100
        if ratio =='财务费用占比':
            df_temp[ratio]  = df_temp['finanExp'] / df_temp['revenue'] * 100
            
        df_temp[ratio] = np.round(df_temp[ratio],2)
        if type(df_result) == int:
            df_result = df_temp[['endDate',ratio]]
        else:
            df_result = df_result.merge(df_temp[['endDate',ratio]], on=['endDate'], how='inner')
        df_result.rename(columns={ratio: stockcode}, inplace=True)


    df_result = df_result.sort(columns=['endDate'], ascending=[True])
    df_result['endDate'] = df_result['endDate'].astype(str).str[:4] + "年"
    df_result.rename(columns={'endDate': ratio + "(%)"}, inplace=True)
    df_result = df_result.set_index(ratio + "(%)")
    df_result = df_result.dropna()
    
      
    df_result = df_result[list_ticker]
    for k,v in dict_stock.items():
        df_result.rename(columns={k: v}, inplace=True)

    return df_result

def getRanks(df_result, ascending = False):
    
    avg_total = df_result.mean()
    avg_five = df_result.tail(5).mean()
    
    df_result_T = df_result.T
    
    df_result_T['rank'] = 1
    df_result_T['rank'] =pd.rolling_sum(df_result_T['rank'], window = len(df_result_T),min_periods = 1)
    df_result_T['rank'] = df_result_T['rank'].astype(int)

    df_result_T['平均'] = avg_total
    df_result_T['平均'] = np.round(df_result_T['平均'],2)
    df_result_T = df_result_T.sort(columns=['平均'],ascending=[ascending])
    df_result_T['排名'] = 1
    df_result_T['排名'] =pd.rolling_sum(df_result_T['排名'], window = len(df_result_T),min_periods = 1)
    df_result_T['排名'] = df_result_T['排名'].astype(int)
    
    df_result_T['近5年平均'] = avg_five
    df_result_T['近5年平均'] = np.round(df_result_T['近5年平均'],2)
    df_result_T = df_result_T.sort(columns=['近5年平均'],ascending=[ascending])
    df_result_T['近5年排名'] = 1
    df_result_T['近5年排名'] =pd.rolling_sum(df_result_T['近5年排名'], window = len(df_result_T),min_periods = 1)
    df_result_T['近5年排名'] = df_result_T['近5年排名'].astype(int)
  
    df_result_T = df_result_T.sort(columns=['rank'],ascending=[True])
    df_result_T.drop(['rank'], axis=1, inplace=True)

    return df_result_T

from CAL.PyCAL import *    # CAL.PyCAL中包含font
from matplotlib import pylab
def drawByDF(df, title = "ROIC"):
    ax = df.plot(figsize=(15,6))
    patches, labels = ax.get_legend_handles_labels()
    font.set_size(15)
    ax.legend(patches, labels, loc='best', prop = font )  # 使用font
    ax.set_title(title, fontproperties = font, fontsize = 15)  # 使用font
    ax.set_xlabel(u'时间', fontproperties = font, fontsize = 15)  # 使用font 
    
    xlabellist = [u'%s年' % x[:4] for x in df.index.tolist()]

    ax.set_xticklabels(xlabellist, fontproperties = font, fontsize=15)  
    ax.axhline(y=0,linewidth=0.5, color='black',ls='--')


# 三费占比（先详细）
def getThreeFee(list_ticker):
    df = DataAPI.FdmtISAllLatestGet(ticker=list_ticker,secID=u"",reportType=u"A",year="",endDate=u"",beginDate=u"",field=u"",pandas="1")
    
    df['销售费用占比']  = np.round(df['sellExp'] / df['revenue'] * 100,2).astype(str) + "%"
    df['管理费用占比']  = np.round(df['adminExp'] / df['revenue'] * 100,2).astype(str) + "%"
    df['财务费用占比']  = np.round(df['finanExp'] / df['revenue'] * 100,2).astype(str) + "%"
    df['三费占比']  = np.round((df['sellExp'] + df['adminExp'] + df['finanExp']) / df['revenue'] * 100,2).astype(str) + "%"
    df['sellExp'] = np.round(df['sellExp'] / 1000000,2).astype(str) + "(百万)"
    df['adminExp'] = np.round(df['adminExp'] / 1000000,2).astype(str) + "(百万)"
    df['finanExp'] = np.round(df['finanExp'] / 1000000,2).astype(str) + "(百万)"
    df['revenue'] = np.round(df['revenue'] / 1000000,2).astype(str) + "(百万)"
    
    stockname =  df.secShortName.tolist()[0]
    
    df = df.sort(columns=['endDate'], ascending=[True])
    df['endDate'] = df['endDate'].astype(str).str[:4] + "年"
    df.rename(columns={'endDate': stockname}, inplace=True)
    df = df.set_index(stockname)
    
    df.rename(columns={'sellExp':'销售费用','adminExp':'管理费用','finanExp':'财务费用','revenue':'营业收入'}, inplace=True)
    
    df = df[['营业收入','销售费用','管理费用','财务费用','销售费用占比','管理费用占比','财务费用占比','三费占比']]
    df = df.dropna()
    

    return df.T

# %%
# 资源占用相对投入资本比例
df = compareByOccupation(list_ticker)
drawByDF(df, title = u"资源占用相对投入资本比例")
getRanks(df)
# Out:
# 资源占用(%) 2007年  2008年  2009年  2010年  2011年  2012年  2013年  2014年  2015年  2016年  \
# 承德露露    -12.03  41.23  50.29  64.03  71.78  69.37  58.23  17.98  26.08  43.87
# 深深宝A     -7.15  -5.13  -0.79  -1.10   0.01   4.16  -7.60  -6.38  -6.73  -2.59
# 黑牛食品      9.28  20.25  25.59   2.95   1.02   0.63   0.68  -1.98  11.39  32.03
# 维维股份     -3.40  -0.40  10.37   9.03   5.28   2.71   6.94   8.49   5.76 -10.41
# 国投中鲁     -9.48  -0.03  -3.83 -16.62  -2.87  -6.08  -8.68  -2.26 -16.30 -13.43
# 海南椰岛    -23.35  -6.16   0.96   4.44  13.54  29.38  24.37  28.71  19.91   8.47
#
# 资源占用(%)    平均  排名  近5年平均  近5年排名
# 承德露露     43.08   1  43.11      1
# 深深宝A     -3.33   5  -3.83      5
# 黑牛食品     10.18   2   8.55      3
# 维维股份      3.44   4   2.70      4
# 国投中鲁     -7.96   6  -9.35      6
# 海南椰岛     10.03   3  22.17      2

# %%
# 毛利率
ratio = "grossMARgin"
df = compareByRatio(list_ticker,ratio)
drawByDF(df, title = u"毛利率")
getRanks(df)
# Out:
# 毛利率(%) 2007年  2008年  2009年  2010年  2011年  2012年  2013年  2014年  2015年  2016年  \
# 承德露露    30.60  28.98  34.15  34.22  33.62  38.22  38.18  41.54  43.49  43.94
# 深深宝A    19.39  21.94  25.80  22.77  19.10  17.16  16.14  37.78  26.84  25.14
# 黑牛食品    29.38  31.71  32.43  33.10  34.68  34.34  35.30  39.04   9.71  24.60
# 维维股份    17.35  17.30  27.85  30.88  31.75  30.19  31.17  34.86  32.92  28.61
# 国投中鲁    21.43  30.49  19.64  14.28  26.38  16.42  10.29  16.30  20.82  19.96
# 海南椰岛    29.77  25.09  22.45  18.35  14.14  37.48  46.85  42.48  40.99  27.99
#
# 毛利率(%)    平均  排名  近5年平均  近5年排名
# 承德露露    36.69   1  41.07      1
# 深深宝A    23.21   5  24.61      5
# 黑牛食品    30.43   3  28.60      4
# 维维股份    28.29   4  31.55      3
# 国投中鲁    19.60   6  16.76      6
# 海南椰岛    30.56   2  39.16      2

# %%
# 净利率
ratio = "npMARgin"
df = compareByRatio(list_ticker,ratio)
drawByDF(df, title = u"净利率")
getRanks(df)
# Out:
# 净利率(%) 2007年  2008年  2009年  2010年  2011年  2012年  2013年  2014年   2015年  2016年  \
# 承德露露     6.59   7.65  10.65   9.85  10.04  10.65  13.05  16.65   17.31  18.08
# 深深宝A    23.22  10.60  -5.36   3.91   3.03  23.83  10.32   3.84  -12.70  32.97
# 黑牛食品    11.28  11.22  11.47  12.67  12.00   7.25   2.09   2.11 -149.03  16.45
# 维维股份     2.79   1.54   8.37   4.28   4.11   2.66   1.79   4.01    1.78   1.45
# 国投中鲁     6.48   4.94   0.27  -5.74   6.33   3.38  -7.98 -14.68    4.36   0.94
# 海南椰岛     5.02 -21.18   7.81  12.18  -3.07  13.14  14.78   8.63    3.03  -4.20
#
# 净利率(%)    平均  排名  近5年平均  近5年排名
# 承德露露    12.05   1  15.15      1
# 深深宝A     9.37   2  11.65      2
# 黑牛食品    -6.25   6 -24.23      6
# 维维股份     3.28   4   2.34      4
# 国投中鲁    -0.17   5  -2.80      5
# 海南椰岛     3.61   3   7.08      3

# %%
df = compareByThreeFee(list_ticker)
drawByDF(df, title = u"三费占比")
getRanks(df, ascending = True)
# Out:
# 三费占比(%) 2007年  2008年  2009年  2010年  2011年  2012年  2013年  2014年  2015年  2016年  \
# 承德露露     16.32  17.67  17.83  20.07  19.69  22.87  20.54  18.92  19.84  18.38
# 深深宝A     27.28  31.71  30.32  26.47  21.03  26.68  21.63  29.69  36.84  47.29
# 黑牛食品     14.60  17.75  17.37  16.94  18.88  24.50  32.59  39.00  66.22  63.28
# 维维股份     13.21  15.97  26.10  24.58  24.44  24.89  30.73  27.81  27.31  24.45
# 国投中鲁     14.44  17.69  17.48  17.29  18.32  14.15  18.70  27.76  19.15  18.00
# 海南椰岛     16.53  27.32  19.90  16.52  18.06  21.19  21.40  35.66  37.43  25.79
#
# 三费占比(%)    平均  排名  近5年平均  近5年排名
# 承德露露     19.21   2  20.11      2
# 深深宝A     29.89   5  32.43      5
# 黑牛食品     31.11   6  45.12      6
# 维维股份     23.95   3  27.04      3
# 国投中鲁     18.30   1  19.55      1
# 海南椰岛     23.98   4  28.29      4

# %%
getThreeFee(list_ticker[0])
# Out:
# 承德露露       2007年        2008年        2009年        2010年        2011年  \
# 营业收入    1394.12(百万)  1516.79(百万)  1328.68(百万)  1816.44(百万)  1937.31(百万)
# 销售费用      172.3(百万)   191.15(百万)   190.39(百万)   312.87(百万)   330.93(百万)
# 管理费用       42.9(百万)    69.25(百万)    47.81(百万)    55.09(百万)    55.96(百万)
# 财务费用      12.35(百万)     7.57(百万)    -1.25(百万)    -3.48(百万)    -5.42(百万)
# 销售费用占比       12.36%        12.6%       14.33%       17.22%       17.08%
# 管理费用占比        3.08%        4.57%         3.6%        3.03%        2.89%
# 财务费用占比        0.89%         0.5%       -0.09%       -0.19%       -0.28%
# 三费占比         16.32%       17.67%       17.83%       20.07%       19.69%
#
# 承德露露       2012年        2013年        2014年        2015年       2016年
# 营业收入    2137.83(百万)  2632.56(百万)  2702.79(百万)  2706.24(百万)  2520.9(百万)
# 销售费用     428.74(百万)   489.96(百万)   457.52(百万)    483.4(百万)  421.23(百万)
# 管理费用      65.85(百万)    59.84(百万)    66.94(百万)    72.04(百万)   62.24(百万)
# 财务费用       -5.7(百万)    -9.16(百万)   -13.07(百万)   -18.64(百万)  -20.25(百万)
# 销售费用占比       20.05%       18.61%       16.93%       17.86%      16.71%
# 管理费用占比        3.08%        2.27%        2.48%        2.66%       2.47%
# 财务费用占比       -0.27%       -0.35%       -0.48%       -0.69%       -0.8%
# 三费占比         22.87%       20.54%       18.92%       19.84%      18.38%

# %%
ratio = "销售费用占比"
df = compareByThreeFee(list_ticker,ratio)
drawByDF(df, title = u'销售费用占比')
getRanks(df, ascending = True)
# Out:
# 销售费用占比(%) 2007年  2008年  2009年  2010年  2011年  2012年  2013年  2014年  2015年  \
# 承德露露       12.36  12.60  14.33  17.22  17.08  20.05  18.61  16.93  17.86
# 深深宝A        5.17   6.65   5.29   5.15   5.17   6.37   7.82   9.42  13.62
# 黑牛食品       11.28  12.29  12.56  12.17  15.84  18.36  22.14  23.45  34.68
# 维维股份        8.24   9.13  18.10  18.32  16.19  14.65  19.05  15.65  13.91
# 国投中鲁        6.82   8.04   9.64   8.60   7.97   6.44   8.36  13.66   9.49
# 海南椰岛       10.79  18.40  13.55   9.96  10.19  11.85  11.72  17.29  19.75
#
# 销售费用占比(%) 2016年     平均  排名  近5年平均  近5年排名
# 承德露露       16.71  16.38   5  18.03      5
# 深深宝A       16.22   8.09   1  10.69      2
# 黑牛食品       18.73  18.15   6  23.47      6
# 维维股份       12.58  14.58   4  15.17      3
# 国投中鲁        9.89   8.89   2   9.57      1
# 海南椰岛       15.68  13.92   3  15.26      4

# %%
ratio = "管理费用占比"
df = compareByThreeFee(list_ticker,ratio)
drawByDF(df, title = u'管理费用占比')
getRanks(df, ascending = True)
# Out:
# 管理费用占比(%) 2007年  2008年  2009年  2010年  2011年  2012年  2013年  2014年  2015年  \
# 承德露露        3.08   4.57   3.60   3.03   2.89   3.08   2.27   2.48   2.66
# 深深宝A       19.78  21.93  21.10  17.04  14.93  20.46  13.83  20.55  23.81
# 黑牛食品        2.72   4.06   3.61   5.77   4.67   7.05   8.85  12.17  26.20
# 维维股份        3.73   4.71   6.71   5.46   6.63   6.82   8.23   8.37   9.42
# 国投中鲁        3.33   4.74   6.28   5.87   5.36   4.77   5.00   8.07   7.25
# 海南椰岛        3.88   6.01   4.95   5.29   6.87   7.48   8.63  17.28  16.42
#
# 管理费用占比(%) 2016年     平均  排名  近5年平均  近5年排名
# 承德露露        2.47   3.01   1   2.59      1
# 深深宝A       31.50  20.49   6  22.03      6
# 黑牛食品       36.38  11.15   5  18.13      5
# 维维股份        7.81   6.79   3   8.13      3
# 国投中鲁        7.08   5.78   2   6.43      2
# 海南椰岛        8.68   8.55   4  11.70      4

# %%
ratio = "财务费用占比"
df = compareByThreeFee(list_ticker,ratio)
drawByDF(df, title = u'财务费用占比')
getRanks(df, ascending = True)
# Out:
# 财务费用占比(%) 2007年  2008年  2009年  2010年  2011年  2012年  2013年  2014年  2015年  \
# 承德露露        0.89   0.50  -0.09  -0.19  -0.28  -0.27  -0.35  -0.48  -0.69
# 深深宝A        2.33   3.13   3.93   4.28   0.93  -0.16  -0.03  -0.28  -0.58
# 黑牛食品        0.60   1.41   1.21  -1.00  -1.63  -0.92   1.60   3.38   5.34
# 维维股份        1.24   2.14   1.30   0.80   1.62   3.42   3.45   3.79   3.98
# 国投中鲁        4.29   4.91   1.56   2.83   4.99   2.93   5.34   6.03   2.41
# 海南椰岛        1.87   2.91   1.40   1.27   1.00   1.86   1.05   1.09   1.26
#
# 财务费用占比(%) 2016年    平均  排名  近5年平均  近5年排名
# 承德露露       -0.80 -0.18   1  -0.52      1
# 深深宝A       -0.43  1.31   2  -0.30      2
# 黑牛食品        8.18  1.82   4   3.52      4
# 维维股份        4.06  2.58   5   3.74      6
# 国投中鲁        1.03  3.63   6   3.55      5
# 海南椰岛        1.42  1.51   3   1.34      3

# %%
# ROIC
ratio = "ROIC"
df = compareByRatio(list_ticker,ratio = ratio)
drawByDF(df, title = ratio)
getRanks(df)
# Out:
# ROIC(%)  2008年  2009年  2010年  2011年  2012年  2013年  2014年  2015年  2016年     平均  \
# 承德露露     17.58  21.34  24.67  24.71  27.96  36.18  37.02  29.89  23.76  27.01
# 深深宝A      4.73  -0.88   3.07   1.59   7.39   4.17   1.30  -4.50   8.89   2.86
# 黑牛食品     20.52  19.14   9.32   7.26   3.60   1.40   1.63 -42.61   4.00   2.70
# 维维股份      3.06   7.78   6.23   5.94   4.71   2.51   4.78   2.19   2.24   4.38
# 国投中鲁      5.49   0.41  -2.32   5.21   4.08  -2.92  -3.96   4.19   1.52   1.30
# 海南椰岛    -25.60  15.82  22.30  -3.58  17.30  13.76   4.58   1.70  -2.22   4.90
#
# ROIC(%)  排名  近5年平均  近5年排名
# 承德露露      1  30.96      1
# 深深宝A      4   3.45      3
# 黑牛食品      5  -6.40      6
# 维维股份      3   3.29      4
# 国投中鲁      6   0.58      5
# 海南椰岛      2   7.02      2

# %%
# ROE
df_ROE = compareByRatio(list_ticker,ratio = "ROE")
drawByDF(df_ROE, title = "ROE")
df_ROE.T
# Out:
# ROE(%)  2007年  2008年  2009年  2010年  2011年  2012年  2013年  2014年  2015年  2016年
# 承德露露    15.94  18.89  21.54  23.91  25.54  27.90  33.04  33.74  27.63  22.79
# 深深宝A    13.65   3.80  -4.03   1.75   0.78   7.73   4.55   1.37  -3.77   9.36
# 黑牛食品    23.35  26.28  23.88   6.61   7.82   4.05   1.07   0.90 -88.22   3.48
# 维维股份     5.72   2.30   9.17   6.26   6.24   3.15   3.30   7.65   3.77   2.64
# 国投中鲁    14.06   7.37   0.71  -6.15   4.53   3.30 -10.46 -14.17   3.92   0.11
# 海南椰岛     9.79 -53.97  18.08  26.67  -7.20  19.80  15.23   4.72   1.46  -4.08

# %%
# ROA
df_ROA = compareByRatio(list_ticker,ratio = "ROA")
drawByDF(df_ROA, title = "ROA")
df_ROA.T
# Out:
# ROA(%)  2008年  2009年  2010年  2011年  2012年  2013年  2014年  2015年  2016年
# 承德露露    11.17  13.27  14.38  13.57  14.95  20.07  24.16  21.58  16.31
# 深深宝A     3.20  -1.71   1.40   1.12   6.48   3.85   1.24  -3.88   8.05
# 黑牛食品    13.71  13.03   8.43   7.30   3.64   0.86   0.62 -37.71   2.03
# 维维股份     1.32   5.61   4.02   3.56   2.04   1.19   2.44   0.89   0.79
# 国投中鲁     3.28   0.14  -2.93   3.54   2.21  -4.15  -5.72   2.33   0.50
# 海南椰岛   -22.01   9.67  14.86  -3.48  10.78   8.70   2.99   0.97  -2.31
