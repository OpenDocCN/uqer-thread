# %% [markdown]
# # 分级基金

# %%
import pandas as pd
import numpy as np
# 获取沪深两市的分级基金信息
fund_lvg_df = DataAPI.FundLeverageInfoGet(secID=u"",ticker=u"",exchangeCDLeverage=u"XSHG,XSHE",field=u"",pandas="1")
lvg_b_secids = fund_lvg_df[(fund_lvg_df['shareType']=='B')&(~ fund_lvg_df['splitNote'].str.contains('无下折').fillna(False))].secIDLeverage.values
df  = DataAPI.FundHoldingsGet(secID=lvg_b_secids,ticker=u"",beginDate=u"20160301",endDate=u"",secType="",field=u"",pandas="1")
lsw_df = df[df['holdingsecShortName']=='乐视网'][['ticker', 'secID', 'marketValue', 'ratioInNa']]
lsw_df.head()
lsw_b_fund_df = DataAPI.MktFunddGet(secID=lsw_df.secID, tradeDate='20160602')
lsw_b_fund_df = lsw_b_fund_df[lsw_b_fund_df['turnoverValue']>1e7][['ticker', 'secShortName', 'tradeDate', 'closePrice', 'turnoverValue']]
pd.merge(lsw_df, lsw_b_fund_df, on=['ticker'])
# Out:
#    ticker        secID   marketValue  ratioInNa     secShortName   tradeDate  \
# 0  150304  150304.XSHE  2.138421e+07     3.7900    华安创业板50指数分级-B  2016-06-02
# 1  150244  150244.XSHE  2.705578e+07     5.4200      鹏华创业板指数分级-B  2016-06-02
# 2  150195  150195.XSHE  7.586197e+07     1.7900  富国中证移动互联网指数分级-B  2016-06-02
# 3  150308  150308.XSHE  2.116045e+07     4.9571   富国中证体育产业指数分级-B  2016-06-02
# 4  150153  150153.XSHE  3.602143e+08     4.5700      富国创业板指数分级-B  2016-06-02
# 5  150204  150204.XSHE  7.092683e+07     6.0200     鹏华中证传媒指数分级-B  2016-06-02
# 6  150248  150248.XSHE  1.763580e+07     5.2000     工银中证传媒指数分级-B  2016-06-02
#
#    closePrice  turnoverValue
# 0       0.704   3.810736e+07
# 1       1.017   2.723694e+07
# 2       0.521   3.866131e+08
# 3       0.606   1.089702e+07
# 4       0.968   6.580119e+08
# 5       1.292   1.237057e+07
# 6       0.588   1.221308e+07
