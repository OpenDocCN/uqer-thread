# %% [markdown]
# # 小白初学之一百问之第六问，AH溢价指数套利

# %% [markdown]
# 这个策略呢很简单很简单，据我所知有不少的公司在用这个策略。HSAHP=AH溢价指数，HSAHP<135，买入300ETF,HSAHP>140，买入恒生ETF
# 照例问问题：希望有大大来指点下仓位管理~

# %% [raw]
# from matplotlib import pylab
# import numpy as np
# import pandas as pd
# import DataAPI
# import seaborn as sns
# start = '2015-07-11'
# end = u''
# benchmark ='HS300'       # 策略参考标准
# universe = '159920.XSHE','510300.XSHG'
# capital_base = 1000000
# refresh_rate = 1
# def initialize(account):
#     pass
# def handle_data(account):
#     hsa=DataAPI.MktIdxdGet(indexID=u"",ticker="hsahp",beginDate="20150710",endDate=account.previous_date,field=("closeIndex"),pandas="1")
#     if hsa['closeIndex'].iloc[-1]<135:
#         order_pct_to('159920.XSHE',0)
#         order_pct_to('510300.XSHG',1)
#     if hsa['closeIndex'].iloc[-1]>140:
#         order_pct_to('510300.XSHG',0)
#         order_pct_to('159920.XSHE',1)
