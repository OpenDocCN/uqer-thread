# %% [markdown]
# # 最新的

# %% [raw]
# # 第一步：设置基本参数
# start = '2011-01-04'
# end = '2016-05-12'
# benchmark = 'HS300'
# capital_base = 100000
# freq = 'd'
# refresh_rate = 1
#
# # 第二步：选择因子，设置股票池
# universe = StockScreener( Factor.RSI.value_range(0,20) & Factor.LCAP.nsmall(30) & Factor.NetProfitGrowRate.pct_range(0.1,0.6) )
# import numpy as np
# def initialize(account):
#     pass
#
# def handle_data(account):
#     # 生成买入列表
#     last_date = account.previous_date.strftime("%Y-%m-%d")
#     last_screener = universe.preview(last_date)
#     buylist = [sec for sec in last_screener if sec in account.universe]
#     d = len(buylist)
#
#     # 卖出不在买入列表中的股票，估计持仓价值
#     v = account.cash
#     for stock in account.valid_secpos:
#         if stock not in buylist and stock in account.universe:
#             order_to(stock, 0)
#             v += account.referencePrice[stock] * account.valid_secpos[stock]
#
#     # 获得调仓数量
#     change = {}
#     for stock in buylist:
#         p = account.referencePrice[stock]
#         if p and not np.isnan(p):
#             change[stock] = int(v / d / p) - account.valid_secpos.get(stock, 0)
#
#     # 按先卖后买的顺序发出指令
#     for stock in sorted(change, key=change.get):
#         order(stock, change[stock])
