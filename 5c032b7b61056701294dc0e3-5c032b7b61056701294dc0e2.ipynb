# %% [markdown]
# # Notebook0

# %% [raw]
# import talib
#
# start = '2018-01-01'
# end = '2018-06-01'
# universe = set_universe('600030.XSHG')
# benchmard = 'HS300'
# freq = 'm'
# refresh_rate = (1,['14:45:00'])
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=1000000)
# }
#
# def initialize(context):
#     pass
#
# def handle_data(context):
#     account = context.get_account('fantasy_account')
#     previous_date = context.previous_date.strftime('%Y-%m-%d')
#     current_position = account.get_positions(exclude_halt=True)
#
#     MA_L = talib.MA('closePrice',timeperiod = 25)
#
#     for stock in account.universe:
#             if close_price > MA_L[-1]:
#                 order_pct_to(stock,1)
#             if MA_L[-1] > close_price:
#                 order_pct_to(stock,0)
