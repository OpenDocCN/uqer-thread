# %% [markdown]
# # 请教pandas中的索引和列处理问题

# %% [markdown]
#     数据结构如下面所示，我的问题是：
#
# 1.列可以变为行s如果想让索引date转换为数据列，简单的方法是什么？
# 2.如果想添加idx列与现在的索引date变为层次化行索引，应该如何操作？
# 3.如果想将数据转化为宽格式，即date为索引，idx列变为列索引，那么使用pivot命令能实现吗？
#
#     我能够想到的解决上面三个问题的办法，都非常麻烦。应该有简便方法的，只是我不知道。我查了手上的工具书和网络，都没有查到。困惑了一个晚上，非常感谢！

# %%
# 导入包
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
pd.read_csv('NIncome.csv',index_col=['date']).head()
# Out:
#                NIncome          idx
# date
# 20091231  3.787853e+09  399330.ZICN
# 20101231  3.231050e+09  399330.ZICN
# 20111230  3.828420e+09  399330.ZICN
# 20121231  4.402417e+09  399330.ZICN
# 20131231  4.620334e+09  399330.ZICN
