# %% [markdown]
# # [转]许老板选股策略曝光

# %% [markdown]
# 转自https://uqer.datayes.com/community/share/5819b619228e5b43fd5c2ef2

# %% [raw]
# import talib
# import numpy as np
# import pandas as pd
# from CAL.PyCAL import *
# cal = Calendar('China.SSE')
#
# start = '2015-2-17'                       # 回测起始时间
# end = '2017-6-26'                         # 回测结束时间
# universe = StockScreener(Factor.LCAP.value_range(21,23)&Factor.PB.value_range(1,5))
#
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 5                        # 执行handle_data的时间间隔
# stock_commission = Commission(buycost=0.0032, sellcost=0.001, unit='perValue')
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000,commission=stock_commission)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#     pday = context.previous_date.strftime('%Y%m%d')
#
#
#     bgnDate = cal.advanceDate(pday,'-3m').strftime('%Y%m%d')
#
#
#     stockpool = universe.preview(pday)
#     # print pday,bgnDate
#
#
#     df=DataAPI.EquShTenGet(secID=stockpool,ticker=u"",beginDate=bgnDate,endDate=pday,field=u"",pandas="1")
#     df = df[df['shNum']==1][df['holdPct']<10]
#     # print df
#
#     prebuylist = df['secID'].tolist()
#
#     # print len(prebuylist)
#     account = context.get_account('fantasy_account')
#
#
#     currentHolds = context.avail_security_position
#     for sec in currentHolds:
#         if not sec in prebuylist:
#
#             account.order_to(sec,0)
#
#     for sec in prebuylist:
#
#         account.order_pct_to(sec,1.0/len(prebuylist))
