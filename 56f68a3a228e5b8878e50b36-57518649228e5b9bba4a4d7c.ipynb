# %% [markdown]
# # 【每周一策略】每年五月份等权再平衡

# %% [markdown]
# 当我试着把“五穷六绝七翻身”这个策略叠加到另外一个无关的有效策略后，我发现绩效不但没有提高，反而有下降。
# 所以我就思考“五穷”策略到底什么地方出了问题。
#
# 根因就在benchmark“沪深300”是以市值加权的方式编制的，大盘股的比重大，小盘股的比重小，
# 而我的策略是用的等权的方式，所有股票同比例买入，相当于是每年做了一次等权的再平衡。
#
# 现在这个策略就是验证等权再平衡的效果，
#
# 结果表明，“五穷”策略超额收益就是来自于等权再平衡。
#
# 这里头对于我们购买指数基金的时候，是否也表明，等权的指数基金好于市值加权的指数基金？

# %% [raw]
# start = '2011-03-01'                       # 回测起始时间
# end = '2016-03-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')           # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 20                          # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     curr_date = account.current_date
#     if curr_date.month == 5:
#         for stock in account.valid_secpos:
#             order_to(stock, 0)
#         for stock in account.universe:
#             order_pct_to(stock, 0.02)
