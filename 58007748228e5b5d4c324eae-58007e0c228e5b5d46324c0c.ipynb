# %% [markdown]
# #

# %% [raw]
# start = '2011-01-01'                       # 回测起始时间
# end = '2016-09-01'                         # 回测结束时间
# benchmark = '600030.XSHG'                        # 策略参考标准
# universe  = [benchmark] # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     pricedata=account.get_attribute_history('closePrice',30)#$数据的时间跨度非常重要，这是获得均线的重要数据基础
#     for s in pricedata:
#         closeprice=pricedata[s][-1]
#         ma2=pricedata[s][-20:].mean()
#         ma1=pricedata[s][-10:].mean()
#         if ma1>ma2 and s not in account.valid_secpos:
#             amount = int(account.cash/closeprice/100) * 100
#             order(s,amount)
#         elif ma1<ma2 and s in account.valid_secpos:
#             order_to(s,0)
#
#     return
