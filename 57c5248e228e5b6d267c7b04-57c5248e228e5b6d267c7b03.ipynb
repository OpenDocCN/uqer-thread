# %% [markdown]
# #

# %%
from numpy import nan,array
import numpy as np
import datetime as dt
from datetime import datetime
from datetime import timedelta
import matplotlib.pyplot as plt
import matplotlib as mat

import seaborn as sns

now=datetime.now()
before=now-timedelta(19)
enddate=now.strftime("%Y%m%d")
startdate=before.strftime("%Y%m%d")

stock='159919.XSHE'
indexs='000300'
DataAPI.FundETFPRListGet(secID=stock,beginDate=startdate,endDate=enddate,field=u"tradeDate,NAV",pandas="1").sort('tradeDate')
# Out:
#      tradeDate     NAV
# 13  2016-08-11  3.4889
# 12  2016-08-12  3.4798
# 11  2016-08-15  3.5452
# 10  2016-08-16  3.6522
# 9   2016-08-17  3.6358
# 8   2016-08-18  3.6300
# 7   2016-08-19  3.6206
# 6   2016-08-22  3.6229
# 5   2016-08-23  3.5929
# 4   2016-08-24  3.5980
# 3   2016-08-25  3.5862
# 2   2016-08-26  3.5637
# 1   2016-08-29  3.5621
# 0   2016-08-30  3.5625
