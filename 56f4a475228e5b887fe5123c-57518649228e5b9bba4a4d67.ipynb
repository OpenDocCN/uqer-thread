# %% [markdown]
# # Zura论文附录中WorldQuant的Alpha#12

# %% [markdown]
# 好多人都在写这个呀，我也分享一个简单的练练手！
#
# **Alpha#12**
# $$(sign(delta(volume, 1)) * (-1 * delta(close, 1)))$$
#
# 公式的策略思想很简洁，买入昨日价格与交易量变化方向相反的股票。即价格相比昨日有上涨，交易量也上涨的卖空，交易量下跌的买入；价格相比昨日有下跌，若交易量也下跌则卖空，交易量上涨则买入。大概就是底背离和顶背离之类的意思吧。
#
# 因为我们不好做空，所以下面策略就是等权买入了要买的股票。

# %% [raw]
# import numpy as np
# import pandas as pd
# start = '2013-01-01'
# end = '2016-01-01'
# benchmark = 'HS300'
# universe = set_universe("HS300", end)
# capital_base = 100000000
# refresh_rate = 20
#
#
# def foo(data, dependencies=['closePrice','turnoverVol'], max_window=2):
#     alpha_12 = -1*data['closePrice'].diff() * data['turnoverVol'].diff()
#     alpha_12 = alpha_12.ix[max_window-1]
#
#     return alpha_12
#
# def initialize(account):
#     a = Signal('Alpha#12', foo)
#     account.signal_generator = SignalGenerator(a)
#
# # 使用信号数据
# def handle_data(account):
#     signal_result = account.signal_result['Alpha#12']
#     signal_result = signal_result[signal_result>0]
#
#     buylist = list(signal_result.index)
#
#     total_money = account.referencePortfolioValue
#     prices = account.referencePrice
#
#     for stk in account.valid_secpos:
#         if stk not in buylist:
#             order_to(stk, 0)
#
#     for stk in buylist:
#         if stk not in account.valid_secpos:
#             if np.isnan(prices[stk]) or prices[stk] == 0:  # 停牌或是还没有上市等原因不能交易
#                 continue
#             order_to(stk,total_money / prices[stk] /len(buylist)) #等权买入
