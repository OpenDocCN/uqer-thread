# %% [markdown]
# # 草稿

# %% [markdown]
# get_position 之后利用.value 报错

# %% [raw]
# # 第一步：设置基本参数
# start = '2013-05-01'
# end = '2013-07-01'
# capital_base = 12000000  # 初始资金
#
# refresh_rate = 1  # 执行handle_data的时间间隔
# benchmark = 'HS300'
# freq = 'd'  # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
#
# # 第二步：选择主题，设置股票池
# universe = ['510300.XSHG', '511880.XSHG']
#
# # 获取季末交易日
# # data = DataAPI.TradeCalGet(exchangeCD=u"XSHG",beginDate=start,endDate=end,field=u"calendarDate,isYearEnd",pandas="1") #年末
# data = DataAPI.TradeCalGet(exchangeCD=u"XSHG", beginDate=start, endDate=end, field=u"calendarDate,isQuarterEnd",
#                            pandas="1")  # 季末
# # data = DataAPI.TradeCalGet(exchangeCD=u"XSHG",beginDate=start,endDate=end,field=u"calendarDate,isMonthEnd",pandas="1") # 月末
# # data = DataAPI.TradeCalGet(exchangeCD=u"XSHG",beginDate=start,endDate=end,field=u"calendarDate,isWeekEnd",pandas="1") # 周末
# data = data[data['isQuarterEnd'] == 1]
# Dates = data['calendarDate'].values.tolist()
# # print Dates
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
#
# def initialize(context):  # 初始化策略运行环境
#     context.has_buy = {}
#     context.step_money = 100000.0
#
#
# def handle_data(context):
#     # 本策略将使用account的以下属性：
#     # account.universe表示当天，股票池中可以进行交易的证券池，剔除停牌退市等股票。
#     # account.referencePrice表示股票的参考价，一般使用的是上一日收盘价。
#     # -----------------------没钱了-----------------------
#     if context.cash < context.step_money :
#         print 'No money!'
#         return
#
#     c_month = context.current_date.strftime("%Y-%m")  # c_month为表示年月的字符串
#     account = context.get_account('fantasy_account')
#     universe = context.get_universe('exchange_fund', exclude_halt=False)
#     # 每个月第一交易日买入
#     if c_month in context.has_buy:
#         return
#     for stock in universe:
#         try:
#             buy_num = int(context.step_money / (account.reference_price[stock]) / 100) * 100
#         except:
#             return
#         order(stock, buy_num)
#         context.has_buy[c_month] = 1
#         # print context.current_date.strftime("%Y-%m-%d"), stock, buy_num
#         # print account.get_positions()
#     # -----------------------债股平衡-----------------------
#         stock_per = 0.5
#         bonds_per = 0.5
#         # if context.current_date.strftime('%Y-%m-%d') in Dates:#调仓时间，年末，季度末，月末，周末
#         stock_share = account.get_position('510300.XSHG')
#         # print(type (stock_share))
#         # print (dir(stock_share))
#         print(stock_share.value)
#         # bonds_share = account.get_position('511880.XSHG')
#
#
#         # order_pct_to(stock,0.50)#股债平衡75%股
#         #     if stock == '511880.XSHG':
#         #         order_pct_to(stock,0.50)#股债平衡25%债
#     # print account.security_position
#     return
