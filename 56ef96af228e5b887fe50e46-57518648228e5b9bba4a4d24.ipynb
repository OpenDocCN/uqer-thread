# %% [markdown]
# # 多因子100

# %% [raw]
# import numpy as np
# import pandas as pd
# from pandas import DataFrame
# import datetime
# import json
# start = '2009-03-31'
# end   = '2011-03-31'
# capital_base = 10000000
# refresh_rate = 1
# benchmark = 'HS300'
# freq = 'd'
#
# stock = pd.read_csv("xuangu.csv")
# index_list = stock.index
# date_dict = {}
#
# def code_change(stk):
#     if stk[0] == "6":
#         stk = stk+".XSHG"
#     else:
#         stk = stk+".XSHE"
#     return stk
#
# universe = []
# for idx in index_list:
#     date = stock["date"].loc[idx]
#     list_str = stock["date_value"].loc[idx]
#     if list_str == "[]":
#         date_value = []
#     else:
#         date_value =  stock["date_value"].loc[idx].replace("[","").replace("]","").split(',')
#         for stk in date_value:
#             try:
#                 stk = code_change(stk[-7:-1])
#             except:
#                 print stk[-7:-1],"!!!!!!!!!!!!"
#             universe.append(stk)
#     date_dict[date] = date_value
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     date = str(account.current_date)
#     date = date[0:4]+date[5:7]+date[8:10]
#     if int(date) in date_dict.keys():
#         stock_list = date_dict[int(date)]
#         if not stock_list:
#             for stk in account.valid_secpos.keys():
#                 order_to(stk,0)
#         else:
#             for stk in stock_list:
#                 try:
#                     stk = code_change(stk[-7:-1])
#                 except:
#                     continue
#                 try:
#                     order_pct_to(stk,0.01)
#                 except:
#                     print stk,"%%%%%%%%%%"

# %% [raw]
# import numpy as np
# import pandas as pd
# from pandas import DataFrame
# import datetime
# import json
# start = '2011-03-31'
# end   = '2013-03-31'
# capital_base = 10000000
# refresh_rate = 1
# benchmark = 'HS300'
# freq = 'd'
#
# stock = pd.read_csv("xuangu.csv")
# index_list = stock.index
# date_dict = {}
#
# def code_change(stk):
#     if stk[0] == "6":
#         stk = stk+".XSHG"
#     else:
#         stk = stk+".XSHE"
#     return stk
#
# universe = []
# for idx in index_list:
#     date = stock["date"].loc[idx]
#     list_str = stock["date_value"].loc[idx]
#     if list_str == "[]":
#         date_value = []
#     else:
#         date_value =  stock["date_value"].loc[idx].replace("[","").replace("]","").split(',')
#         for stk in date_value:
#             try:
#                 stk = code_change(stk[-7:-1])
#             except:
#                 print stk[-7:-1],"!!!!!!!!!!!!"
#             universe.append(stk)
#     date_dict[date] = date_value
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     date = str(account.current_date)
#     date = date[0:4]+date[5:7]+date[8:10]
#     if int(date) in date_dict.keys():
#         stock_list = date_dict[int(date)]
#         if not stock_list:
#             for stk in account.valid_secpos.keys():
#                 order_to(stk,0)
#         else:
#             for stk in stock_list:
#                 try:
#                     stk = code_change(stk[-7:-1])
#                 except:
#                     continue
#                 try:
#                     order_pct_to(stk,0.01)
#                 except:
#                     print stk,"%%%%%%%%%%"

# %% [raw]
# import numpy as np
# import pandas as pd
# from pandas import DataFrame
# import datetime
# import json
# start = '2013-03-31'
# end   = '2015-03-31'
# capital_base = 10000000
# refresh_rate = 1
# benchmark = 'HS300'
# freq = 'd'
#
# stock = pd.read_csv("xuangu.csv")
# index_list = stock.index
# date_dict = {}
#
# def code_change(stk):
#     if stk[0] == "6":
#         stk = stk+".XSHG"
#     else:
#         stk = stk+".XSHE"
#     return stk
#
# universe = []
# for idx in index_list:
#     date = stock["date"].loc[idx]
#     list_str = stock["date_value"].loc[idx]
#     if list_str == "[]":
#         date_value = []
#     else:
#         date_value =  stock["date_value"].loc[idx].replace("[","").replace("]","").split(',')
#         for stk in date_value:
#             try:
#                 stk = code_change(stk[-7:-1])
#             except:
#                 print stk[-7:-1],"!!!!!!!!!!!!"
#             universe.append(stk)
#     date_dict[date] = date_value
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     date = str(account.current_date)
#     date = date[0:4]+date[5:7]+date[8:10]
#     if int(date) in date_dict.keys():
#         stock_list = date_dict[int(date)]
#         if not stock_list:
#             for stk in account.valid_secpos.keys():
#                 order_to(stk,0)
#         else:
#             for stk in stock_list:
#                 try:
#                     stk = code_change(stk[-7:-1])
#                 except:
#                     continue
#                 try:
#                     order_pct_to(stk,0.01)
#                 except:
#                     print stk,"%%%%%%%%%%"

# %% [raw]
# import numpy as np
# import pandas as pd
# from pandas import DataFrame
# import datetime
# import json
# start = '2015-03-31'
# end   = '2016-03-20'
# capital_base = 10000000
# refresh_rate = 1
# benchmark = 'HS300'
# freq = 'd'
#
# stock = pd.read_csv("xuangu.csv")
# index_list = stock.index
# date_dict = {}
#
# def code_change(stk):
#     if stk[0] == "6":
#         stk = stk+".XSHG"
#     else:
#         stk = stk+".XSHE"
#     return stk
#
# universe = []
# for idx in index_list:
#     date = stock["date"].loc[idx]
#     list_str = stock["date_value"].loc[idx]
#     if list_str == "[]":
#         date_value = []
#     else:
#         date_value =  stock["date_value"].loc[idx].replace("[","").replace("]","").split(',')
#         for stk in date_value:
#             try:
#                 stk = code_change(stk[-7:-1])
#             except:
#                 print stk[-7:-1],"!!!!!!!!!!!!"
#             universe.append(stk)
#     date_dict[date] = date_value
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     date = str(account.current_date)
#     date = date[0:4]+date[5:7]+date[8:10]
#     if int(date) in date_dict.keys():
#         stock_list = date_dict[int(date)]
#         if not stock_list:
#             for stk in account.valid_secpos.keys():
#                 order_to(stk,0)
#         else:
#             for stk in stock_list:
#                 try:
#                     stk = code_change(stk[-7:-1])
#                 except:
#                     continue
#                 try:
#                     order_pct_to(stk,0.01)
#                 except:
#                     print stk,"%%%%%%%%%%"

# %% [raw]
# import numpy as np
# import pandas as pd
# from pandas import DataFrame
# import datetime
# import json
# start = '2009-03-31'
# end   = '2016-03-20'
# capital_base = 10000000
# refresh_rate = 1
# benchmark = 'HS300'
# freq = 'd'
#
# stock = pd.read_csv("xuangu.csv")
# index_list = stock.index
# date_dict = {}
#
# def code_change(stk):
#     if stk[0] == "6":
#         stk = stk+".XSHG"
#     else:
#         stk = stk+".XSHE"
#     return stk
#
# universe = []
# for idx in index_list:
#     date = stock["date"].loc[idx]
#     list_str = stock["date_value"].loc[idx]
#     if list_str == "[]":
#         date_value = []
#     else:
#         date_value =  stock["date_value"].loc[idx].replace("[","").replace("]","").split(',')
#         for stk in date_value:
#             try:
#                 stk = code_change(stk[-7:-1])
#             except:
#                 print stk[-7:-1],"!!!!!!!!!!!!"
#             universe.append(stk)
#     date_dict[date] = date_value
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     date = str(account.current_date)
#     date = date[0:4]+date[5:7]+date[8:10]
#     if int(date) in date_dict.keys():
#         stock_list = date_dict[int(date)]
#         if not stock_list:
#             for stk in account.valid_secpos.keys():
#                 order_to(stk,0)
#         else:
#             for stk in stock_list:
#                 try:
#                     stk = code_change(stk[-7:-1])
#                 except:
#                     continue
#                 try:
#                     order_pct_to(stk,0.01)
#                 except:
#                     print stk,"%%%%%%%%%%"
