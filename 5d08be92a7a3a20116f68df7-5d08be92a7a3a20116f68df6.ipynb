# %% [markdown]
# # 贝塔大小与股票涨幅

# %%
#2015年暴涨阶段最大贝塔组合与最小贝塔组合的表现
sec=set_universe('HS300')
df=DataAPI.MktStockFactorsOneDayGet(tradeDate=u"20141231",secID=sec,field=u"ticker,HBETA",pandas="1").set_index('ticker').sort_values('HBETA')
#贝塔最小的20只股票组合平均收益
a=df['HBETA'].dropna().head(20).index.tolist()
df1=DataAPI.MktEqudGet(ticker=a,beginDate=u"20150101",endDate=u"20150615",isOpen="",field=u"tradeDate,ticker,chgPct",pandas="1")
print df1.set_index('tradeDate').groupby('ticker').cumsum().loc['2015-06-15'].mean()
#贝塔最大的20只股票组合平均收益
a=df['HBETA'].dropna().tail(20).index.tolist()
df1=DataAPI.MktEqudGet(ticker=a,beginDate=u"20150101",endDate=u"20150615",isOpen="",field=u"tradeDate,ticker,chgPct",pandas="1")
print df1.set_index('tradeDate').groupby('ticker').cumsum().loc['2015-06-15'].mean()
#2019年暴涨阶段最大贝塔组合与最小贝塔组合的表现
df=DataAPI.MktStockFactorsOneDayGet(tradeDate=u"20181228",secID=sec,field=u"ticker,HBETA",pandas="1").set_index('ticker').sort_values('HBETA')
##贝塔最小的20只股票组合平均收益
a=df['HBETA'].dropna().head(20).index.tolist()
df1=DataAPI.MktEqudGet(ticker=a,beginDate=u"20190101",endDate=u"20190515",isOpen="",field=u"tradeDate,ticker,chgPct",pandas="1")
print df1.set_index('tradeDate').groupby('ticker').cumsum().loc['2019-05-15'].mean()
#贝塔最大的20只股票组合平均收益
a=df['HBETA'].dropna().tail(20).index.tolist()
df1=DataAPI.MktEqudGet(ticker=a,beginDate=u"20190101",endDate=u"20190515",isOpen="",field=u"tradeDate,ticker,chgPct",pandas="1")
print df1.set_index('tradeDate').groupby('ticker').cumsum().loc['2019-05-15'].mean()
##2016年1月27日-2017年12月31日期间
df=DataAPI.MktStockFactorsOneDayGet(tradeDate=u"20160127",secID=sec,field=u"ticker,HBETA",pandas="1").set_index('ticker').sort_values('HBETA')
##贝塔最小的20只股票组合平均收益
a=df['HBETA'].dropna().head(20).index.tolist()
df1=DataAPI.MktEqudGet(ticker=a,beginDate=u"20160128",endDate=u"20171229",isOpen="",field=u"tradeDate,ticker,chgPct",pandas="1")
print df1.set_index('tradeDate').groupby('ticker').cumsum().loc['2017-12-29'].mean()
#贝塔最大的20只股票组合平均收益
a=df['HBETA'].dropna().tail(20).index.tolist()
df1=DataAPI.MktEqudGet(ticker=a,beginDate=u"20160128",endDate=u"20171229",isOpen="",field=u"tradeDate,ticker,chgPct",pandas="1")
print df1.set_index('tradeDate').groupby('ticker').cumsum().loc['2017-12-29'].mean()
# Out:
# chgPct    0.753075
# dtype: float64
# chgPct    0.251195
# dtype: float64
# chgPct   -0.00263
# dtype: float64
# chgPct    0.1862
# dtype: float64
# chgPct    0.443605
# dtype: float64
# chgPct    0.085805
# dtype: float64
