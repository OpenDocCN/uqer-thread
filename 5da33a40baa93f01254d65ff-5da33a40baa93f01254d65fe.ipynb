# %% [markdown]
# # Notebook0

# %%
1:Quantopian是一个众包的量化投资平台，目标是让每个人都可以成为宽客，平台为宽客们提供了数据及研究开发环境，你可以自己设计交易算法，对策略测试调优、并接入实盘完成交易。目前Quantopian中无A股数据。
2:WorldQuant（世坤）是一家成立于2007年的量化投 资管理公司，主要致力于量化交易策略的开发工作。
3:优矿起点于研究环境，让用户可以在自己的研究环境里验证自己的想法，写分析报告，甚至于可以做衍生品定价分析等，降低了量化投资的门槛，让每一个人都有机会成为宽客。提供高质量的金融大数据与高效的云计算系统研究，复杂交易策略亦可轻松程序化构建、回测并模拟。
4:掘金专门针对散户研发的产品，产品集合众多国际研究成果模型，其“数据化，模型化，智能化”理念充分而客观地揭示个股内在价值与市场状态，为个人投资者提供：追踪板块资金变化；识破主力操作意图；把握个股操作趋势；解析资金流向数据；寻找热点潜力个股；捕捉主力活动状况等主要功能。
5:聚宽，专业的量化交易&量化投资平台；免费提供数据获取、研究环境、策略回测、实盘连接、发送交易信号，学习交流等
6:BigQuant帮助每一位投资者具备应用人工智能技术进行投资交易的能力，去实现机器代替人脑进行数据挖掘和分析，在海量金融数据中识别出影响股价变动的潜在模式，进而进行理性科学投资。
7:vn.py对于想做量化交易的投资者来说，vnpy的功能相比其他框架更全，版本更新快，使用人数多，可能出现的bug会被及时的修复。封装了多种交易API，包括国内股票、期货、期权，国外股票，比特币，火币等等。
