# %% [markdown]
# # StockScreener数据有误？

# %% [markdown]
# 主要是想获得当天A股的10只市值最小的股票，排序。 方法1用的是传统API做的，并且排序，输出结果与12.4日结果比较，数据正确。但策略2用的stockScreener后，发现拿不到10只，数据也不正确。是因为提取的是对数市值，还是其他的原因吗？
# 另外，如果将策略1中的CYB改为A会提示目标股票太多，那有没有更好的办法才能获得整个沪深股市的市值呢？非常感谢

# %% [raw]
# start = '2015-12-01'                       # 回测起始时间
# end = '2015-12-04'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('CYB',date =end)   # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# n=10
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     buy_list=[]
#     sell_list=[]
#     current_date = account.current_date
#     current_date = current_date.strftime('%Y%m%d')
#     Market_Value=DataAPI.MktEqudGet(secID=account.universe,tradeDate=account.current_date,field="tradeDate,secID,negMarketValue,closePrice",pandas="1")
#
#     Market_Value_50=Market_Value.sort(columns='negMarketValue')[0:50]
#     Market_Value_10=Market_Value_50[0:10]
#     print Market_Value_10
#     for stk in Market_Value_10.secID :
#         print stk
#         if len(buy_list)==n:
#             order_to(stk,10)
#             buy_list.append(stk)
#             print buy_list

# %% [raw]
# start = '2015-12-01'
# end = '2015-12-06'
# benchmark = 'HS300'
# universe = StockScreener(Factor.LCAP.nsmall(10))
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     print "current_date = %s"%(account.current_date.strftime('%Y%m%d'))
#     print account.universe
#
#
#     return
