# %% [markdown]
# # Notebook

# %% [raw]
# import pandas as pd
# start = '2018-12-01'                       # 回测起始时间
# end = '2019-12-13'                         # 回测结束时间
# universe = DynamicUniverse('HS300')        # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'HS300'                        # 策略参考标准
#
# #freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 60                         # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# max_history_window=60
# # 配置账户信息，支持多资产多账户
# accounts ={'fantasy_account': AccountConfig(account_type='security', capital_base=50000, commission = Commission(buycost=0.001,sellcost=0.002,unit='perValue'),slippage = Slippage(value=0.00,unit='perValue'))
# }
# def initialize(context):
#     pass
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     account= context.get_account('fantasy_account')
#     print(context.get_universe (exclude_halt=True))#获取当前交易曰证券池
#     history=context.history(universe,'closePrice',60)
#     momentum = {'symbol':[],'c_ret':[]}
#     for stk in history.keys():
#         momentum['symbol'].append(stk)
#         momentum['c_ret'].appand(history[stk]['closePrice'][-1]/history[stk]['closePrice'][0])
#     #按期过去60日收益率排序，并且选择前60只的股票为买入候选
#     momentum=pd.DataFrame(momentum).sort(columns='c_ret',ascending=False).reset_index()
#     # print panentun
#     momentum=momentum[:60]#选择
#     buylist=momentum['symbol'].tolist()
#     for stk in account.get_positions():
#         if stk not in buyllst:
#             order_to(stk,0)
#     #等权重买人所股票
#     portfolio_value=account.portfolio_value
#     for stk in buylist:
#         order_pct_to(stk,1.0/len(buyl1st))
