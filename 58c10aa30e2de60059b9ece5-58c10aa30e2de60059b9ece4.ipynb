# %% [markdown]
# # Notebook3

# %% [raw]
# # 近期反向操作策略
# import pandas as pd
# import numpy as np
# start = '2017-02-27'                  # 回测起始时间
# end = '2017-03-08'                   # 回测结束时间
# benchmark = 'HS300'                   # 策略参考标准
# universe =  set_universe('HS300')            # 证券池，也可以在这里添加多个证券
# capital_base = 1000000                 # 起始资金
# freq = 'd'                         # 日线策略
# refresh_rate = 1                     #回测频率
# commission = Commission(buycost=0.0003, sellcost=0.0013, unit='perValue') # 每个交易日调仓
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     # account.get_attribute_history：表示获取所有证券过去2天的closePrice数据，返回数据类型为 dict，键为每个证券的secID
#     hist = account.get_attribute_history('closePrice', 2)
#     print hist
#     for stk in account.universe:
#         # 前一日的股票跌幅超过2%，则买入该股票1000股
#         if (hist[stk][1]-hist[stk][0])/hist[stk][0]<=-0.02 and stk not in account.valid_secpos:
#             order(stk, 1000)
#         # 前一日的股票涨幅超过2%，则卖出全部该股票
#         elif (hist[stk][1]-hist[stk][0])/hist[stk][0]>=0.02 and stk in account.valid_secpos:
#             order_to(stk, 0)
