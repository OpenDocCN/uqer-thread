# %% [markdown]
# # 发帖

# %% [raw]
# import datetime
# import numpy as np
#
#
# df = DataAPI.EquGet(ticker=u"000001",listStatusCD=u"",field="listDate",pandas="1")
# start_date =df.iloc[0,0] # 股票上市时间
#
# factor = ['tradeDate','ADX','ADXR','ARBR','ASI','ATR14','ATR6','BBI','BIAS10'] # 技术指标
#
# df = DataAPI.MktStockFactorsDateRangeGet(ticker=u"000001",beginDate=start_date, endDate=u"20171216",field=factor,pandas="1")
# print(df)
