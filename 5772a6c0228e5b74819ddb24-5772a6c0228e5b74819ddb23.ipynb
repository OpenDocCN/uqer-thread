# %% [markdown]
# #

# %% [markdown]
# 策略新手：基因编辑技术前景广阔，在国家政策的推动下有望迎来黄金发展期，此外，精准医学2016年已入选“十三五”项目，上升为国家战略也为我国基因编辑技术的发展带来强有力的催化作用，在国家看好精准医疗的大背景下，市场对基因治疗相关公司充满了信心。
# 因此，个股的选取主要是基因测序的相关概念股。

# %%
DataAPI.TickersByThemesGet(themeID=u"",themeName=u"基因测序",beginDate=u"",endDate=u"",isNew=u"",field=u"",pandas="1")
# Out:
#     themeID themeName        secID  ticker secShortName exchangeCD  \
# 0    120142      基因测序  002022.XSHE  002022         科华生物       XSHE
# 1    120142      基因测序  002030.XSHE  002030         达安基因       XSHE
# 2    120142      基因测序  002118.XSHE  002118         紫鑫药业       XSHE
# 3    120142      基因测序  002642.XSHE  002642          荣之联       XSHE
# 4    120142      基因测序  300016.XSHE  300016         北陆药业       XSHE
# 5    120142      基因测序  300109.XSHE  300109          新开源       XSHE
# 6    120142      基因测序  300216.XSHE  300216         千山药机       XSHE
# 7    120142      基因测序  300244.XSHE  300244         迪安诊断       XSHE
# 8    120142      基因测序  300254.XSHE  300254         仟源医药       XSHE
# 9    120142      基因测序  600127.XSHG  600127         金健米业       XSHG
# 10   120142      基因测序  600645.XSHG  600645         中源协和       XSHG
# 11   120143    基因测序板块  002642.XSHE  002642          荣之联       XSHE
# 12   122247    周五基因测序  002131.XSHE  002131         利欧股份       XSHE
# ...

# %% [markdown]
# 股票池：300109新开源（权重10%）；002030达安基因（权重10%）；002022科华生物（权重20%）；600645中源协和（权重25%）；002118紫鑫药业（权重15%）；300244迪安诊断（权重10%）；300216千山药机（权重10%）。

# %% [raw]
# import numpy as np
#
# # 设置基本参数
# start = '2015-01-01'
# end   = '2016-01-01'
# capital_base = 100000
# refresh_rate = 5
# benchmark = 'HS300'
# freq = 'd'
#
# # 设置股票池
# universe = ['600993.XSHG', '300109.XSHE', '600645.XSHG', '002022.XSHE', '300244.XSHE', '002030.XSHE', '002118.XSHE', '300216.XSHE', ]
#
# def initialize(account):
#     # 调整股票权重，权重列表序号与股票池列表序号对应
#     account.weight = [0, 0.1, 0.1, 0.2, 0.25, 0.15, 0.1, 0.1, ]
#     account.weightmap = dict(zip(universe, account.weight))
#
# def handle_data(account):
#     # 本策略将使用account的以下属性：
#     # account.referencePortfolioValue表示根据前收计算的当前持有证券市场价值与现金之和。
#     # account.universe表示当天，股票池中可以进行交易的证券池，剔除停牌退市等股票。
#     # account.referencePrice表示股票的参考价，一般使用的是上一日收盘价。
#     # account.valid_secpos字典，键为证券代码，值为虚拟账户中当前所持有该股票的数量。
#
#     c = account.referencePortfolioValue
#
#     # 计算调仓数量
#     change = {}
#     for stock in account.universe:
#         w = account.weightmap.get(stock, 0)
#         p = account.referencePrice[stock]
#         if p and not np.isnan(p):
#             change[stock] = int(c * w / p) - account.valid_secpos.get(stock, 0)
#
#     # 按先卖后买的顺序发出指令
#     for stock in sorted(change, key=change.get):
#         order(stock, change[stock])
