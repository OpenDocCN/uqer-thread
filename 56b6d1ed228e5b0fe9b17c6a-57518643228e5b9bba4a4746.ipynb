# %% [markdown]
# # 沪深300等权重策略 修改版

# %% [markdown]
# 策略介绍：最简单的沪深300等权重策略，每20个交易日做一次rebalance，若可交易的股票数量为N，N小于300，那么每个股票的权重为1/N。看上去效果比我想的要好很多，估计是因为300里面有很多权重股，权重股的股息率较高，所以股息再投资的影响较大。
#
# 疑问：1.根据大神的意见修改了卖出部分，不过调仓记录里面还有很多未成交的情况，我看这些股票的每日成交是可以覆盖我的买入的，还有些是因为新股刚刚上市，虽然有行情，但未纳入沪深300成分股？还有些其他什么原因？
#     2.由于这个沪深300的池子是现有的股票，所以在回测时会发现，2006年的时候只能买入100多只股票，如何可以将沪深300的股票池子随着日期按照实际情况动态调整？
#     3.最后我想写入每日的净值，但是发现write函数要求数据的格式，不知道怎么写入?主要以前没玩过python。。。
#     4.我感觉效果应该没这么好，不知道是否哪里出错了？
#     以上问题希望有大神能解答~
# 很早就接触通联数据，最近才开始接触优矿网，很不错的平台。第一次写一个简单的策略，mark一下！~~

# %% [raw]
# # 导入包
# from CAL.PyCAL import *
# import numpy as np
# import pandas as pd
# from pandas import DataFrame,Series
#
# # 第一步：设置基本参数
# start = '2009-12-31'
# end   = '2016-01-31'
# capital_base = 100000000
# refresh_rate = 20
# benchmark = 'HS300'
# freq = 'd'
# commission = Commission(buycost=0.0003, sellcost=0.0004, unit='perValue')
# slippage = Slippage(value=0.003, unit='perValue')
#
# # 第二步：选择主题，设置股票池
# universe = set_universe('HS300')
#
# def initialize(account):
#     # 第三步：调整股票权重，权重列表序号与股票池列表序号对应
#    pass
#
# def handle_data(account):
#     # 本策略将使用account的以下属性：
#     # account.referencePortfolioValue表示根据前收计算的当前持有证券市场价值与现金之和。
#     # account.universe表示当天，股票池中可以进行交易的证券池，剔除停牌退市等股票。
#     # account.referencePrice表示股票的参考价，一般使用的是上一日收盘价。
#     # account.valid_secpos字典，键为证券代码，值为虚拟账户中当前所持有该股票的数量。
#
#     portfolio_value = account.referencePortfolioValue
#     buylist = account.universe
#     for stock in account.valid_secpos:
#         if stock in buylist:
#             order_to(stock, int(portfolio_value /account.referencePrice[stock] / 100/len(buylist))*100)  # 等权重分配原有股票
#
#     # 等权重买入所选股票
#     filteredBuylist = []
#     for stock in buylist:
#         p = account.referencePrice[stock]
#         if not np.isnan(p):
#             filteredBuylist.append(stock)
#
#     for stock in filteredBuylist:
#         if stock not in account.valid_secpos:
#             order_to(stock, int(portfolio_value /account.referencePrice[stock] / 100/len(buylist))*100)

# %%
((bt['portfolio_value']/bt['portfolio_value'][0] - 1) - ((1 + bt['benchmark_return']).cumprod() - 1)).plot(figsize=(14,7))

# %%
pv=pd.DataFrame(bt['portfolio_value'])
pv
write('portfoli_value.csv',pv)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <mercury-input-45-f6b0249c843a> in <module>()
#       1 pv=pd.DataFrame(bt['portfolio_value'])
#       2 pv
# ----> 3 write('portfoli_value.csv',pv)
#
# /home/ipython/abe10f7e5afbbb3a79ce619739541149/.ipython/profile_nbserver/startup/patch.py in write(name, data, encoding)
#     102         raise IOError(error_msg)
#     103     f = open(name, "w")
# --> 104     f.write(data.encode(encoding))
#     105     f.close()
#     106     return len(data)
#
# python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1976                 return self[name]
#    1977             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1978                                  (type(self).__name__, name))
#    1979
#    1980     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'encode'
