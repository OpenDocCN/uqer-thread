# %% [markdown]
# # Jegedeesh & Titman 1993

# %% [raw]
# import pandas as pd
# import numpy as np
# import datetime
# date_format = "%Y%m%d"
# start = '20100101'                       # 回测起始时间
# end = '20170425'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ["HS300"]                    # 证券池，支持股票和基金
# capital_base = 10000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 21                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# buylist=[]
#
# def initialize(account):# 初始化虚拟账户状态
#     pass
#
#
# def handle_data(account):# 每个交易日的买入卖出指令
#     now= account.current_date
#     print now,(now-datetime.timedelta(days=180))
#     momentum = {'symbol':[],'name':[],'c_ret':[]}
#     for stk in account.universe:
#         history = DataAPI.MktEqudAdjGet(secID=stk,isOpen="",beginDate=(now-datetime.timedelta(days=125)),endDate=(now-datetime.timedelta(days=5)),field=[u'closePrice','secShortName'],pandas="1")
#         if history['closePrice'].empty:
#             print stk,'is an empty Security ID'
#             continue
#         shortname=DataAPI.SecIDGet(assetClass=u"E",ticker=stk[:6],cnSpell=u"",field=u"",pandas="1")['secShortName'][0]
#         #currentdate = datetime.strptime(account.now,'%Y%m%d')
#         listdate = datetime.datetime.strptime(DataAPI.SecIDGet(assetClass=u"E",ticker=stk[:6],cnSpell=u"",field=u"",pandas="1")['listDate'][0],'%Y-%m-%d')
#         if ((now-datetime.timedelta(days=125))-listdate).days < 0:
#             #print stk,shortname,'是次新股'
#             continue
#         momentum['symbol'].append(stk)
#         momentum['name'].append(shortname)
#         momentum['c_ret'].append(history['closePrice'].tolist()[-1]/history['closePrice'][0])
#     momentum = pd.DataFrame(momentum).sort(columns='c_ret').reset_index()
#     momentum = momentum[len(momentum)*9/10:len(momentum)]   # 选择
#     #print momentum
#
#
#     global buylist
#     buylist.append(momentum['symbol'].tolist())
#     print buylist[-1]
#     print len(buylist), len(buylist[-1])
#
#     if len(buylist) >=6:
#         for stk in account.security_position:
#             if stk in buylist[-6]:
#                 order_pct(stk,-float(1)/6/len(buylist[-6]))
#
#     portfolio_value = account.reference_portfolio_value
#
#     filteredBuylist = []
#     for stk in buylist[-1]:
#         if not np.isnan(account.reference_price[stk]) and account.reference_price[stk] > 0:
#             filteredBuylist.append(stk)
#     print len(filteredBuylist),filteredBuylist
#     for stk in filteredBuylist:
#          order_pct(stk,float(1)/6/len(filteredBuylist))
#
#     return

# %%
1
