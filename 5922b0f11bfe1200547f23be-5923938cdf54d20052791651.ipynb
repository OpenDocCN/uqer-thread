# %% [markdown]
# # 测试外部策略系统

# %% [raw]
# import pandas as pd
# def ticker2secID(ticker):
#     """
#     给定股票代码转化为股票内部编码
#     Args:
#         tickers (list): 需要转化的股票代码列表
#     Returns:
#         list: 转化为内部编码的股票编码列表
#
#     Examples:
#         >> tickers = ['600000','000001']
#         >> secIDs = ticker2secID(tickers)
#     """
#     universe = DataAPI.EquGet(equTypeCD=u"A",listStatusCD="L,S,DE,UN",field=u"ticker,secID",pandas="1") # 获取所有的A股（包括已退市）
#     universe = dict(universe.set_index('ticker')['secID'])
#     if isinstance(ticker, list):
#         res = []
#         for i in ticker:
#             if i in universe:
#                 res.append(universe[i])
#             else:
#                 print i, ' 在universe中不存在，没有找到对应的secID！'
#         return res
#     else:
#         raise ValueError('ticker should be list！')
# data=pd.read_excel('logistic_goldencut.xlsx')
# data.reset_index(drop=True,inplace=True)
# start = data['opendate'][0]                       # 回测起始时间
# end = data['closedate'][len(data)-1]                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('hs300')  # 证券池，支持股票和基金
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     today=account.current_date.strftime('%Y-%m-%d')
#     if today in data['opendate'].tolist() or today in data['closedate'].tolist() :
#         dat=data[['stockcode','weights']][data['opendate'].isin([today])].reset_index(drop=True)
#         buylist={}
#         for i in range(len(dat)):
#             if dat.loc[i]['stockcode'][:6]=='000300':continue
#             buylist[ticker2secID([dat.loc[i][0][:6]])[0]]=dat.loc[i][1]
#         closeprice=DataAPI.MktEqudGet(tradeDate=today,secID=u"",ticker=u"",beginDate=u"",endDate=u"",isOpen="",field=u"secID,preClosePrice",pandas="1")
#         v=account.reference_portfolio_value
#         for stk in account.valid_secpos:
#             if stk not in buylist:
#                 order_to(stk, 0)
#         for stk in buylist.keys():
#             order(stk,v*buylist[stk]/closeprice['preClosePrice'][closeprice['secID']==stk].values[0])
