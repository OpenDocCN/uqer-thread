# %% [markdown]
# # 神与你同在

# %% [raw]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
#
# MarketEqud=DataAPI.MktIdxdGet(ticker=u"000300",exchangeCD=u"XSHG,XSHG",beginDate=u"20150101",endDate=u"20220101",field=u"preCloseIndex,OpenIndex,lowestIndex,highestIndex,closeIndex,turnoverVol,turnoverValue,CHG,CHGPct",pandas="1")
# closeIndex = MarketEqud['closeIndex']
# logReturn1 = np.array(np.diff(np.log(closeIndex)))
# df1 = pd.DataFrame(logReturn1)
# df1.to_csv('logReturn1.csv')
# #DataAPI.MktIdxdGet(indexID=u"",ticker=u"",tradeDate=u"20161219",beginDate=u"",endDate=u"",exchangeCD=u"XSHE,XSHG",field=u"",pandas="1")

# %%
date = pd.read_csv('logReturn1.csv')
logreturn11 = date['0']
	#observe('logReturn1', logReturn1)
	#bt = bt.set_index('tradeDate')
plt.hist(logreturn11,bins=40,normed=1)
plt.show()
