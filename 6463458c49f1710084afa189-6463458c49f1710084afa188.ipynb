# %% [markdown]
# # Notebook605

# %%
data=DataAPI.PfundGet(secID=u"",secIDInt=u"",secFullName=u"",pfStyleCD=u"1",statusCD=u"",invStgyCD=u"",
                 invConCD="",amacFullNameCN="",partyRegCD="",mainFundTypeCD="",partyStatusCD="",instType="",
                 amacInstID="",recordStatusCD="",partyRcDateBEG="",partyRcDateEND="",establishDateBEG="",
                 establishDateEND="",recordCD="",field=u"",pandas="1")
data.to_csv('私募基金.csv',encoding='gbk')
