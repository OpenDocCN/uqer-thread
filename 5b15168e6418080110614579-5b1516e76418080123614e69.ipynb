# %% [markdown]
# # python语法问题

# %%
import datetime
import pandas as pd
d = {'col1': [1, 2], 'col2': [3, 4]}
df = pd.DataFrame(data=d)
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
tickers = ['col1', 'col2']
df1=df;
for index in tickers:
    df1[index] = df1[index] *3
df_returns = df1
df_returns.head()
df
# Out:
#    col1  col2
# 0     3     9
# 1     6    12
