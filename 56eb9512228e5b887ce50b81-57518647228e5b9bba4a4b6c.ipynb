# %% [markdown]
# # 【每周一策略】五穷六绝七翻身

# %% [markdown]
# 股市彦语有云，“五穷六绝七翻身”，这个策略就是用来验证这个彦语是否属实。
#
# 逻辑：
# 1、每年5月份，第一个交易日，清空所有股票。
# 2、每年7月份，每一个交易日，再满仓上股票。
# 每次买入任意沪深300的50支股票
#
# 实测数据表明，每年都能够跑赢：），希望能够帮助到大家。

# %% [raw]
# start = '2011-03-01'                       # 回测起始时间
# end = '2016-03-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')           # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                          # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     account.if_clear = True#是否空仓
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     curr_date = account.current_date
#     if curr_date.month == 5 and account.if_clear == False:
#         for stock in account.valid_secpos:
#             order_to(stock, 0)
#         account.if_clear = True
#
#     if curr_date.month == 7 and account.if_clear == True:
#         for stock in account.universe:
#             order_pct_to(stock, 0.01)
#         account.if_clear = False
