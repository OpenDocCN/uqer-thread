# %% [markdown]
# # [简单易读]小市值均线策略降回撤版

# %% [raw]
# import pandas as pd
# import numpy as np
#
# start = '2015-01-01'
# end = '2016-10-20'
# benchmark = 'HS300'
# universe = StockScreener(Factor.LCAP.nsmall(100)) # 选取100只市值最小的股票
# capital_base = 100000
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     #提取数据，并转化为DataFrame
#     hist = account.get_attribute_history('highPrice',6)
#     close = account.get_attribute_history('highPrice',1)
#     hist = pd.DataFrame(hist)
#     close = pd.DataFrame(close) # dataframe, 按行排列
#
#     #利用DataFrame切片，计算5日、10日、20日均线
#     ma6  = hist.tail(6).mean()
#     close.ix['ma6'] = pd.Series(ma6,index=close.columns) # 将均线数据整合为一个dataframe
#     data = close.T #转置，使列头为股票代码
#     #print(data)
#     #筛选出标的中站上5日均线、10日均线,且5日均线上穿10日均线的股票
#     #筛选出股价向下跌破20日均线的99%的股票
#     call = data[data[0]>data.ma6+0.01]
#     call_basket = list(call.index)
#     put = data[data[0]<data.ma6-0.71]
#     put_basket = list(put.index)
#
#     for stk in call_basket:
#             if stk not in account.avail_security_position:
#                 order_pct_to(stk, 1.0/len(call_basket)) #均匀持仓
#
#     for stk in put_basket:
#          order_to(stk,0)

# %% [markdown]
# 看了zeeu的[简单易读]小市值均线策略https://uqer.datayes.com/community/share/5811e77e228e5b43f85c20f8改进了一点回撤希望大家喜欢
