# %% [markdown]
# #

# %% [raw]
# import numpy as np
#
# start = '2015-06-12'                       # 回测起始时间
# end = '2016-09-09'                        # 回测结束时间
# benchmark = 'HS300'                    # 策略参考标准
#
# universe = ['510050.XSHG','510300.XSHG','510500.XSHG','150131.XSHE', '150201.XSHE','150206.XSHE','150195.XSHE','150252.XSHE','150228.XSHE',] # 证券池，支持股票和基金
# #从左至右：50ETF、300ETF、500ETF、医药B、券商B、国防B、互联网B、煤炭B、银行B
# #多好的分级B，可惜没的玩了
# #食品B '150199.XSHE' ，不好意思往里加了，2016年的行情变数太大
#
# capital_base = 100000           # 起始资金
# freq = 'd'                                # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                     # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                     # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):
#     try:
#         for i in account.universe:
#             # 定义短期、长期收盘高值
#             high_short = np.max(account.get_attribute_history('closePrice', 3)[i])
#             high_long = np.max(account.get_attribute_history('closePrice', 10)[i])
#
#             # 仓位策略：短期、长期收盘持续新高持股
#             if high_short/high_long >= 0.99:
#                     order_pct_to(i, 1.0/len(universe))
#             else:
#                     order_pct_to(i, 0)
#     except:
#         pass
#
#
#     return
