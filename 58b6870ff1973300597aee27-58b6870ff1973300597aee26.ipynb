# %% [markdown]
# # account.history函数问题

# %% [raw]
# import numpy as np      #导入pyton计算模块
# import math
#
# start = '2017-02-23'                       # 回测起始时间
# end = '2017-02-27'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# max_history_window=70
#
# highcap=100*10**8       #小市值范围30亿到100亿
# lowcap=30*10**8
#
# highpe=40               #TTM pe 范围
# lowpe=10
#
# stoploss=-0.06                  #单支股票止损比例
# limit_stock_to_buy=8            #一天最多同时下单股票个数
# holding_limits=20               #最多持仓股票个数
# stock_amount_limits=50000       #单支股票买入金额限制
# holding_limit_days=50
# windows=60
# universe = StockScreener( Factor.LCAP.value_range(math.log(lowcap),math.log(highcap))
#                          & Factor.PE.value_range(lowpe,highpe)
#                         ) #用选股器选择股票池
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     last_date = account.previous_date.strftime("%Y-%m-%d")
#     seclist=universe.preview(last_date)
#     history_data = account.history(attribute='closePrice', symbol=seclist, time_range=10,style="ast")["closePrice"]
#     print  last_date,"history_data stks:",len(history_data.columns),"factors stks:",len(seclist)
#     print [s for s in seclist if s not in history_data.columns]    # "bug" 股票存在seclist 但没有返回行情数据
