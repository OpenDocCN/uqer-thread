# %% [markdown]
# # dataapi中的问题

# %%
DataAPI.MktBarRTIntraDayGet(securityID=u"000016.XSHG",startTime=u"",endTime=u"",unit=u"5",field=u"barTime,totalVolume"pandas="1")
# Out:
#   File "<mercury-input-1-1ca092bc70b6>", line 1
#     DataAPI.MktBarRTIntraDayGet(securityID=u"000016.XSHG",startTime=u"",endTime=u"",unit=u"5",field=u"barTime,totalVolume"pandas="1")
#                                                                                                                                ^
# SyntaxError: invalid syntax
