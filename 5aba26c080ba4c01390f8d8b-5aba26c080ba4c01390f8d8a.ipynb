# %% [markdown]
# # PB个股策策略修改回测

# %% [raw]
# import pandas as pd
# import numpy as np
# start = '2013-01-01'                       # 回测起始时间
# end = '2018-03-20'                         # 回测结束时间
# # end = '2015-07-01'
# stk='000001.XSHE'
# name='平安银行'
# universe = DynamicUniverse(stk)        # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = stk                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# # refresh_rate = Monthly(2)
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):
#     context.stk=stk
#     # name=DataAPI.SecIDGet(ticker= context.stk.split('.'),field=u"secShortName",pandas="1").values[0][0]
#     print name
#     data=pd.read_csv('./银行详细因子/'+name+'_PB等.csv',index_col=0)
#     #---------------------------------------------------
#     #参数
#     context.pbegin=0.45
#     context.pend=0.25
#     context.bk_len=1000
#     ####################################################
#     pbegin=context.pbegin
#     pend=context.pend
#     data['R']=data.PB/(data.NPParentCompanyGrowRate+1.)
#     # data['R']=data.PB/(data.OperatingRevenueGrowRate+1.)/(data.NPParentCompanyGrowRate+1.)
#     #---------------------------------------------------
#
#     bk_len=context.bk_len
#     data['Rmax']=None
#     data['Rmin']=None
#     data
#     x0=np.array(data.R)
#     x=np.array(data.R)
#     xmin=np.array(data.R)
#     xmax=np.array(data.R)
#     for i in range(len(data.index)-bk_len-1):
#         x=x0[i:i+bk_len]
#         x=x.copy()
#         x.sort()
#         xmin[i+bk_len+1]=x[int(len(x)*pbegin)]
#         xmax[i+bk_len+1]=x[int(len(x)*(1.-pend))]
#     data['Rmin']=xmin
#     data['Rmax']=xmax
#     context.data=data
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     previous_date = context.previous_date.strftime('%Y-%m-%d')
#     data=context.data
#     p=1.-(data.R[previous_date]-data.Rmin[previous_date])/(data.Rmax[previous_date]-data.Rmin[previous_date])
#     if p>1:
#         p=1.
#     if p<0:
#         p=0.
#     print p
#     account = context.get_account('fantasy_account')
#     account.order_pct_to(context.stk, p)
