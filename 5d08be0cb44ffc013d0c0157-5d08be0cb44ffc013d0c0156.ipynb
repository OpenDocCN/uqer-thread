# %% [markdown]
# # 日历效应

# %%
#1991-2018上证指数月度效应
df=DataAPI.MktIdxmGet(beginDate=u"19910131",endDate=u"20181231",indexID=u"000001.ZICN",ticker=u"",field=u"endDate,chgPct",pandas="1")
df['m']=map(lambda x: x[5:7],df['endDate'])
##12月上涨概率
df1=df[df['m']=='12']
print df1['chgPct'].count()
print df1[df1['chgPct']>0]['chgPct'].count()
print 12/28.0
##2月上涨概率
df1=df[df['m']=='02']
print df1['chgPct'].count()
print df1[df1['chgPct']>0]['chgPct'].count()
print 19/27.0
##3月上涨概率
df1=df[df['m']=='03']
print df1['chgPct'].count()
print df1[df1['chgPct']>0]['chgPct'].count()
print 16/27.0
##4月上涨概率
df1=df[df['m']=='04']
print df1['chgPct'].count()
print df1[df1['chgPct']>0]['chgPct'].count()
print 15/27.0
##5月上涨概率
df1=df[df['m']=='05']
print df1['chgPct'].count()
print df1[df1['chgPct']>0]['chgPct'].count()
print 14/27.0
##6月上涨概率
df1=df[df['m']=='06']
print df1['chgPct'].count()
print df1[df1['chgPct']>0]['chgPct'].count()
print 13/27.0
##7月上涨概率
df1=df[df['m']=='07']
print df1['chgPct'].count()
print df1[df1['chgPct']>0]['chgPct'].count()
print 13/28.0
##8月上涨概率
df1=df[df['m']=='08']
print df1['chgPct'].count()
print df1[df1['chgPct']>0]['chgPct'].count()
print 15/28.0
##9月上涨概率
df1=df[df['m']=='09']
print df1['chgPct'].count()
print df1[df1['chgPct']>0]['chgPct'].count()
print 13/28.0
##10月上涨概率
df1=df[df['m']=='10']
print df1['chgPct'].count()
print df1[df1['chgPct']>0]['chgPct'].count()
print 13/28.0
##11月上涨概率
df1=df[df['m']=='11']
print df1['chgPct'].count()
print df1[df1['chgPct']>0]['chgPct'].count()
print 18/28.0
# Out:
# 28
# 12
# 0.428571428571
# 27
# 19
# 0.703703703704
# 27
# 16
# 0.592592592593
# 27
# 15
# 0.555555555556
# 27
# 14
# 0.518518518519
# 27
# 13
# 0.481481481481
# 28
# 13
# 0.464285714286
# 28
# 15
# 0.535714285714
# 28
# 13
# 0.464285714286
# 28
# 13
# 0.464285714286
# 28
# 18
# 0.642857142857
