# %% [markdown]
# # 获取交易数据的代码

# %%
data=DataAPI.SecIDGet(partyID=u"",assetClass=u"",ticker=u"",cnSpell=u"",field=u"",pandas="1")
print data
# Out:
#               secID  ticker    secShortName         cnSpell exchangeCD  \
# 0       000000.XIBE  000000         00定向国债2         00DXGZ2       XIBE
# 1       000001.OFCN  000001          华夏成长混合          HXCCHH        NaN
# 2       000001.XIBE  000001          00国债01          00GZ01       XIBE
# 3       000001.XSHE  000001            平安银行            PAYH       XSHE
# 4       000001.ZICN  000001            上证综指            SZZZ       XSHG
# 5       000002.XIBE  000002          00国债02          00GZ02       XIBE
# 6       000002.XSHE  000002             万科A             WKA       XSHE
# 7       000002.ZICN  000002            A股指数            AGZS       XSHG
# 8       000003.OFCN  000003       中海可转换债券-A       ZHKZHZQ-A        NaN
# 9       000003.XIBE  000003          00国债03          00GZ03       XIBE
# 10      000003.XSHE  000003           PT金田A             NaN       XSHE
# 11      000003.ZICN  000003            B股指数            BGZS       XSHG
# ...

# %%
data.to_excel('代码.xlsx')
