# %% [markdown]
# # DIFF-DEA-1

# %% [raw]
# import pandas as pd
# start = '2010-01-06'                       # 回测起始时间
# end = '2010-10-01'                         # 回测结束时间
# universe = DynamicUniverse('HS300')        # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'm'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = (1,240)               # 执行handle_data的时间间隔
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='index', capital_base=10000000)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#     account = context.get_account('fantasy_account')
#     currentPrice=context.current_price('000300.ZICN')
#     amountbuy=int(account.cash/currentPrice)
#     IndexData=DataAPI.MktIdxdGet(tradeDate=u"",indexID=u"",ticker=u"000300",beginDate=u"",endDate=context.now,exchangeCD=u"",field=[u'tradeDate',u"closeIndex",],pandas="1")#tradeDate=u"20161219",,exchangeCD=u"XSHE,XSHG"
#     Data=IndexData.set_index('tradeDate')
#     EDA12=pd.ewma(Data,span=12)
#     EDA26=pd.ewma(Data,span=26)
#     DIF= EDA12- EDA26
#     DEA=pd.ewma(DIF,span=9)
#     Bar= DIF- DEA
#     pre2DIF=DIF.iloc[-2].values[0]
#     pre1DIF=DIF.iloc[-1].values[0]
#     #print "DIF:",pre2DIF,pre1DIF
#     pre2DEA=DEA.iloc[-2].values[0]
#     pre1DEA=DEA.iloc[-1].values[0]
#     #print "DEA:",pre2DEA,pre1DEA
#     pre2Bar=Bar.iloc[-2].values[0]
#     pre1Bar=Bar.iloc[-1].values[0]
#     #print "Bar:",pre2Bar,pre1Bar
#     #print context.now
#     if pre2Bar>0 and pre1Bar<0 and account.get_positions():
#         amountsell=account.get_positions().get('000300.ZICN').long_amount
#         account.order('000300.ZICN',-amountsell,'close')
#     if pre2Bar<0 and pre1Bar>0 and not account.get_positions() and amountbuy>=1:
#         account.order('000300.ZICN',amountbuy,'open')
