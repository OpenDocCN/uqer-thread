# %% [markdown]
# # 条件选股

# %%
a=DataAPI.MktStockFactorsOneDayGet(tradeDate=u"20150612",secID=u"",ticker=u"",field=u"ticker,secShortName,tradeDate,PE,ROE",pandas="1")
a.sort_values(by='PE',ascending=False)
b=a[((a.PE)<50)&((a.PE)>20)&(a.ROE>0.20)&(a.ROE<0.50)]
b.sort_values(by='PE',ascending=False)
# Out:
#       ticker   tradeDate       PE     ROE
# 1440  002127  2015-06-12  49.3232  0.2862
# 2557  300360  2015-06-12  48.9899  0.2766
# 1576  002236  2015-06-12  48.3497  0.2097
# 390   001896  2015-06-12  47.8357  0.2363
# 889   600511  2015-06-12  46.8123  0.2092
# 2509  603288  2015-06-12  46.6603  0.3211
# 1304  002038  2015-06-12  46.1733  0.2388
# 2419  601515  2015-06-12  45.5886  0.2668
# 936   600566  2015-06-12  45.5818  0.2637
# 704   600273  2015-06-12  45.2123  0.3512
# 1602  002271  2015-06-12  45.1258  0.2177
# 2532  603699  2015-06-12  44.7215  0.2461
# 360   000848  2015-06-12  43.3943  0.3500
# 532   600081  2015-06-12  43.1304  0.2624
# 2007  002595  2015-06-12  42.8324  0.2253
# 910   600535  2015-06-12  40.7147  0.3116
# 865   600483  2015-06-12  39.8019  0.2148
# 1585  002241  2015-06-12  39.4292  0.2283
# 1857  002415  2015-06-12  38.4363  0.3914
# 1422  002116  2015-06-12  37.9770  0.2519
# 136   000540  2015-06-12  37.8823  0.3817
# ...
