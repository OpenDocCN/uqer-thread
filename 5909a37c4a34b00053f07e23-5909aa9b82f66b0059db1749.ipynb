# %% [markdown]
# # 网格交易

# %% [raw]
# start = '2016-05-03'                       # 回测起始时间
# end = '2017-05-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['162411.XSHE']  # 证券池，支持股票和基金
# security_base = {'162411.XSHE':0} #起始仓位
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#      return
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     latest_price = account.reference_price
#     if (latest_price['162411.XSHE'] == 0.579):
#        order_pct_to(universe[0], 0.65)
#     elif (latest_price['162411.XSHE'] == 0.563):
#        order_pct_to(universe[0], 0.7)
#     elif (latest_price['162411.XSHE'] == 0.547):
#        order_pct_to(universe[0], 0.75)
#     elif (latest_price['162411.XSHE'] == 0.532):
#        order_pct_to(universe[0], 0.8)
#     elif (latest_price['162411.XSHE'] == 0.517):
#        order_pct_to(universe[0], 0.85)
#     elif (latest_price['162411.XSHE'] == 0.502):
#        order_pct_to(universe[0], 0.9)
#     elif (latest_price['162411.XSHE'] == 0.488):
#        order_pct_to(universe[0], 0.95)
#     elif (latest_price['162411.XSHE'] == 0.474):
#        order_pct_to(universe[0], 1)
#     elif (latest_price['162411.XSHE'] == 0.596):
#        order_pct_to(universe[0], 0.6)
#     elif (latest_price['162411.XSHE'] == 0.613):
#        order_pct_to(universe[0], 0.55)
#     elif (latest_price['162411.XSHE'] == 0.631):
#        order_pct_to(universe[0], 0.5)
#     elif (latest_price['162411.XSHE'] == 0.649):
#        order_pct_to(universe[0], 0.45)
#     elif (latest_price['162411.XSHE'] == 0.668):
#        order_pct_to(universe[0], 0.4)
#     elif (latest_price['162411.XSHE'] == 0.688):
#        order_pct_to(universe[0], 0.35)
#     elif (latest_price['162411.XSHE'] == 0.708):
#        order_pct_to(universe[0], 0.3)
#     elif (latest_price['162411.XSHE'] == 0.728):
#        order_pct_to(universe[0], 0.25)
#     elif (latest_price['162411.XSHE'] == 0.749):
#        order_pct_to(universe[0], 0.2)
#     elif (latest_price['162411.XSHE'] == 0.771):
#        order_pct_to(universe[0], 0.15)
#     elif (latest_price['162411.XSHE'] == 0.793):
#        order_to(universe[0], 0.1)
#     elif (latest_price['162411.XSHE'] == 0.816):
#        order_pct_to(universe[0], 0.05)
#     elif (latest_price['162411.XSHE'] == 0.840):
#        order_pct_to(universe[0], 0)
