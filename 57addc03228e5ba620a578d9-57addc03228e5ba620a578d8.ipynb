# %% [markdown]
# #

# %%
#data=DataAPI.MktEqudGet(tradeDate=u"20080513",secID=u"",ticker=u"",beginDate=u"",endDate=u"",isOpen="",field=u"",pandas="1")

#universe = DataAPI.EquGet(equTypeCD='A')['ticker']

import time,datetime
datelist = []

begin = datetime.date(2015,6,1)
end = datetime.date(2015,6,7)

for i in range((end - begin).days+1):
    day = begin + datetime.timedelta(days=i)
    dayStr = str(day.strftime("%Y%m%d"))  
    data = DataAPI.MktEqudGet(tradeDate=dayStr,secID=u"",ticker=u"",beginDate=u"",endDate=u"",isOpen="",field=u"",pandas="1")
    data.to_excel('沪深股票日行情'+dayStr+'.xlsx','Sheet1',)
