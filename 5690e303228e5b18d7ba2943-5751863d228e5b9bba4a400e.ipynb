# %% [markdown]
# # ETF轮动

# %% [raw]
# from datetime import timedelta, datetime
# from CAL.PyCAL import *
# cal = Calendar('China.SSE')
# start = '2014-1-1'                       # 回测起始时间
# end = '2015-12-1'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['510500.XSHG', '510310.XSHG']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     monthago = cal.advanceDate(account.current_date, '-22B', BizDayConvention.Following)
#     yesterday = cal.advanceDate(account.current_date, '-1B', BizDayConvention.Following)
#     zx = list(DataAPI.MktIdxdGet(indexID="399905.ZICN",beginDate=monthago.strftime("%Y%m%d"),endDate=yesterday.strftime("%Y%m%d"),field="closeIndex",pandas="1").closeIndex)
#     dp = list(DataAPI.MktIdxdGet(indexID="399300.ZICN",beginDate=monthago.strftime("%Y%m%d"),endDate=yesterday.strftime("%Y%m%d"),field="closeIndex",pandas="1").closeIndex)
#     zx_return = (zx[-1] - zx[0])/zx[0]
#     dp_return = (dp[-1] - dp[0])/dp[0]
#     choose = max(zx_return, dp_return, 0)
#     if choose == 0:
#         for stock in account.valid_secpos.keys():
#             order_to(stock, 0)
#     elif choose == zx_return:
#         if "510500.XSHG" not in account.valid_secpos.keys():
#             for stock in account.valid_secpos.keys():
#                 order_to(stock, 0)
#             order_pct("510500.XSHG" , 1)
#     elif choose == dp_return:
#         if "510310.XSHG" not in account.valid_secpos.keys():
#             for stock in account.valid_secpos.keys():
#                 order_to(stock, 0)
#             order_pct("510310.XSHG" , 1)
#     return

# %% [raw]
# from datetime import timedelta, datetime
# from CAL.PyCAL import *
# cal = Calendar('China.SSE')
# start = '2014-1-1'                       # 回测起始时间
# end = '2015-12-1'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['510500.XSHG', '510310.XSHG', '159915.XSHE']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     monthago = cal.advanceDate(account.current_date, '-22B', BizDayConvention.Following)
#     yesterday = cal.advanceDate(account.current_date, '-1B', BizDayConvention.Following)
#     zx = list(DataAPI.MktIdxdGet(indexID="399905.ZICN",beginDate=monthago.strftime("%Y%m%d"),endDate=yesterday.strftime("%Y%m%d"),field="closeIndex",pandas="1").closeIndex)
#     dp = list(DataAPI.MktIdxdGet(indexID="399300.ZICN",beginDate=monthago.strftime("%Y%m%d"),endDate=yesterday.strftime("%Y%m%d"),field="closeIndex",pandas="1").closeIndex)
#     cyb = list(DataAPI.MktIdxdGet(indexID="399006.ZICN",beginDate=monthago.strftime("%Y%m%d"),endDate=yesterday.strftime("%Y%m%d"),field="closeIndex",pandas="1").closeIndex)
#     zx_return = (zx[-1] - zx[0])/zx[0]
#     dp_return = (dp[-1] - dp[0])/dp[0]
#     cyb_return = (cyb[-1] - cyb[0])/cyb[0]
#     choose = max(zx_return, dp_return, cyb_return, 0)
#     if choose == 0:
#         for stock in account.valid_secpos.keys():
#             order_to(stock, 0)
#     elif choose == zx_return:
#         if "510500.XSHG" not in account.valid_secpos.keys():
#             for stock in account.valid_secpos.keys():
#                 order_to(stock, 0)
#             order_pct("510500.XSHG" , 1)
#     elif choose == cyb_return:
#         if "159915.XSHE" not in account.valid_secpos.keys():
#             for stock in account.valid_secpos.keys():
#                 order_to(stock, 0)
#             order_pct("159915.XSHE" , 1)
#     elif choose == dp_return:
#         if "510310.XSHG" not in account.valid_secpos.keys():
#             for stock in account.valid_secpos.keys():
#                 order_to(stock, 0)
#             order_pct("510310.XSHG" , 1)
#     return
