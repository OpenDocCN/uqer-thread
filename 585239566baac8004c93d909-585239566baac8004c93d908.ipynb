# %% [markdown]
# # 净利润增加

# %% [raw]
# #归属母公司净利润增幅,大于40%，涨幅大于40%或者跌幅大于10%卖出，1日调仓
# start = '2010-01-25'                       # 回测起始时间
# end = '2016-11-10'                        # 回测结束时间
# benchmark = 'HS300'                    # 策略参考标准
# universe=set_universe('A')             #证券池，支持股票和基金
# capital_base = 200000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# import datetime
# import lib.poolstock as po
# import pandas as pd
#
# from CAL.PyCAL import *
# cal = Calendar('China.SSE')
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     today=account.current_date
#     yesterday = cal.advanceDate(today,Period('-1B')).toDateTime().strftime('%Y-%m-%d')
#     date_40=  cal.advanceDate(today,Period('-40B')).toDateTime().strftime('%Y-%m-%d')
#     date_10= cal.advanceDate(today,Period('-10B')).toDateTime().strftime('%Y-%m-%d')
#     date_30= cal.advanceDate(today,Period('-10B')).toDateTime().strftime('%Y-%m-%d')
#
#     gpc=po.stockpool(yesterday,date_40)
#
#
#     yjyq=(DataAPI.FdmtEfGet(secID=gpc.secID,reportType=u"Q1,S1,Q3,CQ3,A",publishDateEnd=yesterday,
#     publishDateBegin=yesterday,field=u"secID,secShortName,forecastType,NIncAPChgrLL,reportType,fiscalPeriod,actPubtime",pandas="1"))
#     #yjyq=yjyq.dropna()  #NIncomeChgrLL,NIncomeChgrUPL
#     yjyq=yjyq.sort(columns='NIncAPChgrLL',ascending=False)
#     yjyq=yjyq[[True if i in account.universe else False for i in yjyq['secID']]]
#
#     n=5-len(account.security_position.keys())
#
#
#
#     if len(yjyq)>0:
#         yjyq=yjyq[yjyq['NIncAPChgrLL']>40]
#         yjyq=yjyq.head(n)
#         tic=list(yjyq.secID.unique())
#     else:tic=[]
#     #print yjyq.head(1)
#
#     for stock in account.security_position:
#
#
#         rangevalue=(account.reference_price[stock]-account.security_cost[stock])/account.security_cost[stock]
#         if (rangevalue>0.4) or (rangevalue<-0.1):
#             order_to(stock, 0)
#         else:pass
#     for stock1 in tic:
#         amount=(account.cash/n)/account.reference_price[stock1]
#         order_to(stock1,amount)
#
#
#
#
#     return
