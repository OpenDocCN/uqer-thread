# %% [markdown]
# # create_datasets

# %%
DataAPI.EquGet(field=["secID","secShortName","listDate",'totalShares'],pandas="1")
# Out:
#               secID secShortName    listDate   totalShares
# 0       000001.XSHE         平安银行  1991-04-03  1.940592e+10
# 1       000002.XSHE          万科A  1991-01-29  1.161773e+10
# 2       000003.XSHE        PT金田A  1991-07-03  3.334336e+08
# 3       000004.XSHE         国农科技  1991-01-14  1.650526e+08
# 4       000005.XSHE         世纪星源  1990-12-10  1.058537e+09
# 5       000006.XSHE         深振业A  1992-04-27  1.349995e+09
# 6       000007.XSHE          全新好  1992-04-13  3.464480e+08
# 7       000008.XSHE         神州高铁  1992-05-07  2.780795e+09
# 8       000009.XSHE         中国宝安  1991-06-25  2.579214e+09
# 9       000010.XSHE         美丽生态  1995-10-27  8.198547e+08
# 10      000011.XSHE         深物业A  1992-03-30  5.959791e+08
# 11      000012.XSHE          南玻A  1992-02-28  3.070692e+09
# 12      000013.XSHE       *ST石化A  1992-05-06  3.033550e+08
# 13      000014.XSHE         沙河股份  1992-06-02  2.017052e+08
# 14      000015.XSHE        PT中浩A  1992-06-25  1.572134e+08
# ...

# %%
stocks = DataAPI.EquGet(field=["secID","secShortName","listDate",'totalShares'],pandas="1")

# %%
stocks.to_csv("stocks.csv",encoding = 'gbk')

# %%
stocks.head()
# Out:
#          secID secShortName    listDate   totalShares
# 0  000001.XSHE         平安银行  1991-04-03  1.940592e+10
# 1  000002.XSHE          万科A  1991-01-29  1.161773e+10
# 2  000003.XSHE        PT金田A  1991-07-03  3.334336e+08
# 3  000004.XSHE         国农科技  1991-01-14  1.650526e+08
# 4  000005.XSHE         世纪星源  1990-12-10  1.058537e+09

# %%
Industry = DataAPI.EquIndustryGet(field=["tradeDate","secID",'industryName1','industryName2'],pandas="1")

# %%
Industry.to_csv("Industry.csv",encoding = 'gbk')

# %%
market2019_1 = DataAPI.MktEqudAdjGet(beginDate=u"20190101",endDate=u"20190630",field=["tradeDate","secID","closePrice","marketValue"],pandas="1")
market2019_2 = DataAPI.MktEqudAdjGet(beginDate=u"20190701",endDate=u"20191231",field=["tradeDate","secID","closePrice","marketValue"],pandas="1")
market2019   = market2019_1.append(market2019_2)
market2019.to_csv("market2019.csv",encoding = 'gbk')
