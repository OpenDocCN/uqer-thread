# %% [markdown]
# #

# %% [raw]
# start = '2015-01-01'
# end = '2016-01-10'
# benchmark = 'HS300'
# capital_base = 100000
# freq = 'd'
# refresh_rate = 1
#
# universe = StockScreener(Factor.ACCA.nlarge(1))
#
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     for stock in account.security_position:
#         if stock not in account.current_universe:
#             order_pct_to(stock, 0)
#     for stock in account.current_universe:
#         if stock not in account.security_position:
#             order_pct_to(stock, 1)
