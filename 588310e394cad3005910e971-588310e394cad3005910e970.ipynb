# %% [markdown]
# # Notebook0

# %% [raw]
# import numpy as np
# start = '2015-01-04'                       # 回测起始时间
# end = '2016-01-5'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account): # 每个交易日的买入卖出指令
#     buylist = []
#     selist = []
#     stock_list=account.universe
#     date=account.previous_date.strftime('%Y%m%d')
#     cal = DataAPI.TradeCalGet(exchangeCD=u"XSHG",beginDate='20110101',endDate=date,field=u"prevTradeDate",pandas="1")
#     daysAhead = cal['prevTradeDate'].values[-20].replace('-','')
#     date = cal['prevTradeDate'].values[-1].replace('-','')
#     #print daysAhead
#     #print date
#     eq_open_close_high = DataAPI.MktEqudAdjGet(secID=stock_list, beginDate=daysAhead, endDate=date ,field=['secID', 'openPrice', 'closePrice', 'highestPrice','lowestPrice'],pandas="1")
#     #print eq_open_close_high
#
#     closePrices = eq_open_close_high['closePrice'].values
#     #print closePrices
#     openPrices = eq_open_close_high['openPrice'].values
#     highestPrices = eq_open_close_high['highestPrice'].values
#     lowestPrices = eq_open_close_high['lowestPrice'].values
#     closePrice1 = closePrices[-1]
#     closePrice2 = closePrices[-2]
#     openPrice1 = openPrices[-1]
#     openPrice2 = openPrices[-2]
#     openPrice5 = openPrices[-5]
#     lowestPrice1 = lowestPrices[-1]
#     lowestPrice2 = lowestPrices[-2]
#     highestPrice1 = highestPrices[-1]
#     highestPrice2 = highestPrices[-2]
#
#     for stock in account.avail_security_position.keys():
#         if closePrice1<openPrice1:
#             selist.append(stock)
#     for stock in selist:
#         #sell_value = account.referencePrice[stock]*account.valid_secpos[stock]
#         order_to(stock, 0)
#
#     for stock in account.universe:
#         if (closePrice1/openPrice5)<0.95 and abs(lowestPrice1-lowestPrice2)<0.01 and highestPrice1>highestPrice2 and closePrice2<openPrice2 and closePrice1>openPrice1:
#             buylist.append(stock)
#     for stock in buylist:
#          order_pct_to(stock, 0.1) #int(account.reference_portfolio_value * 0.95/100 / account.reference_price[stock] /100)*100)
#     return

# %% [markdown]
# 一个简单的选股买卖股票的程序，符合条件就买入，不符合就卖出，结果始终没有买入卖出操作，请问大神们是怎么回事，谢谢！
