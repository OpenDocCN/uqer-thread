# %% [markdown]
# # DataAPI获取的510050的前复权数据不对

# %% [markdown]
# 从DataAPI获取的510050的前复权数据不对，2013年11月14日的前复权价应该为1.526，而不是1.531

# %%
from datetime import *

s = '510050.XSHG'
# today = datetime.today()
# begin = today - timedelta(120)         
# end = today - timedelta(1)   
markets = DataAPI.MktFunddGet(tradeDate=u"",secID=s,ticker=u"",beginDate='2013-11-14',endDate='',field=u"",pandas="1")
# markets.to_csv('510050-begin-to-20160314.csv')
markets.head(3)
# markets.tail(20)
# Out:
#          secID  ticker exchangeCD secShortName   tradeDate  preClosePrice  \
# 0  510050.XSHG  510050       XSHG    华夏上证50ETF  2013-11-14          1.621
# 1  510050.XSHG  510050       XSHG    华夏上证50ETF  2013-11-15          1.569
# 2  510050.XSHG  510050       XSHG    华夏上证50ETF  2013-11-18          1.600
#
#    openPrice  highestPrice  lowestPrice  closePrice    CHG  CHGPct  \
# 0      1.621         1.628        1.611       1.622  0.001  0.0006
# 1      1.571         1.620        1.571       1.600  0.031  0.0198
# 2      1.615         1.676        1.608       1.675  0.075  0.0469
#
#    turnoverVol  turnoverValue  discount  discountRatio  circulationShares  \
# 0    366697447      593427742     0.001       0.000616        13010000000
# 1    613483303      981966486     0.002       0.001248        12825000000
# 2    695942246     1137665940    -0.004      -0.002394        12713000000
#
#    accumAdjFactor
# 0        1.141401
# 1        1.179957
# 2        1.179957

# %%
from datetime import *

s = '510050.XSHG'
# today = datetime.today()
# begin = today - timedelta(120)         
# end = today - timedelta(1)   
markets = DataAPI.MktFunddAdjBfGet(secID=s,ticker=u"",beginDate='2013-11-14',endDate='',field=u"",pandas="1")
# markets.to_csv('510050-adjbf-begin-to-20160318.csv')
markets.head(3)
# Out:
#          secID  ticker secShortName  secShortNameEn exchangeCD   tradeDate  \
# 0  510050.XSHG  510050    华夏上证50ETF             NaN       XSHG  2013-11-14
# 1  510050.XSHG  510050    华夏上证50ETF             NaN       XSHG  2013-11-15
# 2  510050.XSHG  510050    华夏上证50ETF             NaN       XSHG  2013-11-18
#
#    preClosePrice  openPrice  highestPrice  lowestPrice  closePrice  \
# 0         1.5300     1.5300        1.5366       1.5206      1.5310
# 1         1.5310     1.5329        1.5807       1.5329      1.5612
# 2         1.5612     1.5759        1.6354       1.5690      1.6344
#
#    turnoverVol  turnoverValue
# 0    366697447      593427742
# 1    613483303      981966486
# 2    695942246     1137665940
