# %% [markdown]
# #

# %%
import pandas as pd

universe = set_universe('HS300')
fd = pd.DataFrame()
for s in universe:
    data1 = DataAPI.NewsSentimentIndexGet(beginDate='20160621', endDate='20160621',secID=s,field="secID,sentimentIndex",pandas="1")
    fd = pd.concat([fd,data1],axis=0)
print fd
# Out:
#           secID sentimentIndex
# 0   000001.XSHE            NaN
# 0   000002.XSHE            NaN
# 0   000009.XSHE            NaN
# 0   000039.XSHE            NaN
# 0   000061.XSHE            NaN
# 0   000063.XSHE            NaN
# 0   000069.XSHE            NaN
# 0   000568.XSHE            NaN
# 0   000625.XSHE            NaN
# 0   000651.XSHE            NaN
# 0   000792.XSHE            NaN
# 0   000800.XSHE            NaN
# 0   000858.XSHE            NaN
# 0   600000.XSHG            NaN
# 0   600009.XSHG            NaN
# 0   600010.XSHG            NaN
# 0   600015.XSHG            NaN
# 0   600016.XSHG            NaN
# 0   600019.XSHG            NaN
# 0   600028.XSHG            NaN
# 0   600030.XSHG            NaN
# 0   600031.XSHG            NaN
# 0   600036.XSHG            NaN
# 0   600050.XSHG            NaN
# 0   600100.XSHG            NaN
# 0   600104.XSHG            NaN
# 0   600153.XSHG            NaN
# 0   600188.XSHG            NaN
# 0   600196.XSHG            NaN
# ...
