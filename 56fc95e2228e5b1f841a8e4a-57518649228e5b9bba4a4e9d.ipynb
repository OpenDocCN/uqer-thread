# %% [markdown]
# # 小白策略，但不能运行，是啥问题啊

# %% [raw]
# start='2014-01-01'
# end='2015-12-01'
# benchmark='HS300'
# universe=['000568.XSHE']
# capital_base=100000
# refresh_rate=1
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     hist=account.get_attribute_history('closePrice',15)    #获取近15天收盘数据
#
#     for s in account.universe:
#         five=hist[s][-5:-1]     #近五天数据
#         forefive=hist[s][-6:-2]    #上个近五天数据
#         ten=hist[s][-10:-1]    #近十天数据
#         foreten=hist[s][-11:-2]    #上个近十天数据
#         if sum(five)/5>sum(ten)/10 and sum(forefive)/5<=sum(foreten)/10:
#             order(s,100)    #若五日均线上穿十日均线，买入
#         elif sum(five)/5<sum(ten)/10 and sum(forefive)/5>=sum(foreten)/10:
#             order(s,-100)   #若五日均线上穿十日均线，卖出
