# %% [markdown]
# # Notebook0

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
dates = pd.date_range('20170101', periods=9)
df = pd.DataFrame(np.random.randn(9, 4),index=dates,columns=list('ABCD'))
print df
# Out:
#                    A         B         C         D
# 2017-01-01 -0.703712  0.318119 -0.458575 -0.572458
# 2017-01-02  0.044510 -1.013686 -0.065238 -0.107926
# 2017-01-03 -0.723212  1.460746 -0.449365 -0.660829
# 2017-01-04  0.461508  0.793403  0.964487 -1.337056
# 2017-01-05 -0.088854  1.274728  0.133557 -2.307136
# 2017-01-06 -0.996357 -2.925543 -0.488467  0.886734
# 2017-01-07  1.407125  0.198329 -0.180785 -0.351184
# 2017-01-08  0.268096 -0.785353  0.021348  1.121574
# 2017-01-09 -0.071096  1.732104 -0.785471 -0.564084
