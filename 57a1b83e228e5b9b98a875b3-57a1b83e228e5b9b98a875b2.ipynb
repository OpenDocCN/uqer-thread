# %% [markdown]
# #

# %% [markdown]
# ## 买入指令：
# - 1.选择A股中换手率前10的股票涨幅5%以上买入。
# - 2.每只股票买入十分之一的仓位。
# ## 卖出指令：
# - 1.盈利百分之25卖出。
# - 2.亏损百分之10卖出

# %% [raw]
# import pandas as pd
# start = '2014-01-01'                       # 回测起始时间
# end = '2016-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = StockScreener(Factor.VOL5.nlarge(10))     # 证券池，支持股票和基金
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 5                        # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     closeP=account.get_attribute_history('closePrice',5)  #获取前5个交易日的收盘价
#     temp={'symbol':[],'zf':[]}               #定义一个空的字典，symbol表示股票代码，zf表示储存涨幅的数组
#
#     for stk in account.universe:
#         if stk not in closeP:
#             continue
#         if closeP[stk][-1]/closeP[stk][-2]-1>=0.05:         #如果涨幅大于等于0.05,就存储在temp字典里面
#             temp['symbol'].append(stk)
#             temp['zf'].append(closeP[stk][-1]/closeP[stk][-2]-1)
#     temp=pd.DataFrame(temp).sort(columns='zf').reset_index()    #将temp字典重新按照涨幅排序
#     buylist=temp['symbol'].tolist()                     #将temp字典的股票项转化为将要购买的股票列表
#     for stk in buylist:
#         if stk not in account.valid_secpos:              #如果股仓里没有持有将要购买的股票就购买到10%
#             order_pct(stk,0.1)
#     for stk in account.valid_secpos:
#         if account.valid_seccost[stk]/closeP[stk][-1]-1>=0.1 or closeP[stk][-1]/account.valid_seccost[stk]-1>=0.25:    #如果盈利25%或者亏损10%就把这只股票全部卖出
#             order_to(stk,0)
