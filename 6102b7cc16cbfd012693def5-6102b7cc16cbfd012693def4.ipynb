# %% [markdown]
# # Notebook13

# %%
#北向资金数据
secID=u"688185.XSHG"
import datetime
import time
endDate = datetime.datetime.now().strftime("%Y-%m-%d")
beginDate= datetime.datetime.now()+datetime.timedelta(days=-20)
beginDate= beginDate.strftime("%Y-%m-%d")
print beginDate,endDate
# partyVol 融资买入股数
# partyPct 融资买入比=每日融资买入的成交额占总成交额的比例
gpScore= DataAPI.HKshszHoldGet(secID=secID,tradeCD=u"1,2",ticketCode=u"",partyName=u"",beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
gpScore
# Out:
# 2021-07-09
#  2021-07-29
#    tradeCD     endDate        secID  ticker ticketCode partyName  partyVol  \
# 0        1  2021-07-28  688185.XSHG  688185      30185     康希诺-U   1628747
# 1        1  2021-07-27  688185.XSHG  688185      30185     康希诺-U   1631384
# 2        1  2021-07-26  688185.XSHG  688185      30185     康希诺-U   1702998
# 3        1  2021-07-24  688185.XSHG  688185      30185     康希诺-U   1668897
# 4        1  2021-07-23  688185.XSHG  688185      30185     康希诺-U   1668897
# 5        1  2021-07-22  688185.XSHG  688185      30185     康希诺-U   1599898
# 6        1  2021-07-21  688185.XSHG  688185      30185     康希诺-U   1611283
# 7        1  2021-07-20  688185.XSHG  688185      30185     康希诺-U   1592724
# 8        1  2021-07-19  688185.XSHG  688185      30185     康希诺-U   1594519
# 9        1  2021-07-17  688185.XSHG  688185      30185     康希诺-U   1721148
# 10       1  2021-07-16  688185.XSHG  688185      30185     康希诺-U   1721148
# ...
