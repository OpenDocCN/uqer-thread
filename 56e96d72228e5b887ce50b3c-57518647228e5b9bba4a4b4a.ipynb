# %% [markdown]
# # 深成指、创业板的成交额错误，上证综指、创业板正确

# %% [raw]
# start = '2016-01-01'                       # 回测起始时间
# end = '2016-01-04'                         # 回测结束时间
# index_list = ['399006.ZICN','399001.ZICN','000001.ZICN','399300.ZICN','399101.ZICN']                      # 策略参考标准
# universe = ['000001.XSHE', '600000.XSHG']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):
#     turnoverValue_all=0
#     for index in index_list:
#         ma20=DataAPI.MktIdxdGet(tradeDate='',indexID=index,ticker=u"",beginDate='', endDate=account.current_date,field=u"",pandas="1")
#         ma20=ma20.turnoverValue[-20:].mean()           # ma20.turnoverValue.value(-2)  倒数第二天成交额    ma20.turnoverValue[-20:].mean()
#         print ma20 ,'  ',index,'  ',account.current_date
#         #turnoverValue_all=ma20+turnoverValue_all
#     #print turnoverValue_all
#     return
