# %% [markdown]
# # 均线角度策略股票-年化收益率 65.6%

# %% [raw]
# import math
# start = '2014-01-01'
# end = '2017-01-01'
# benchmark = 'HS300'
# universe = StockScreener( Factor.LCAP.nsmall(10) )
# capital_base = 1000000
# freq = 'd'
# refresh_rate = 5
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#
#     hist = account.get_attribute_history('closePrice', 8)
#     for stk in account.universe:
#         ma6 = hist[stk][-6:].mean()
#         ma6_ref1 = hist[stk][-7:-2].mean()
#
#         if (math.atan((ma6/ma6_ref1 -1)*100*180/3.1416) >= 1) and (stk not in account.security_position): #
#             order(stk, account.cash)
#
#         else:
#             order_to(stk, 0)
