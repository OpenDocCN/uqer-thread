# %% [markdown]
# # 小市值 + 低换手率

# %% [markdown]
# ## 策略思路
# ----
# #### 总是持有流通市值最小的10%与20日平均换手率最低的10%的股票的交集

# %% [raw]
# import numpy as np
# from CAL.PyCAL import *
#
# start = '2013-01-05'
# end = '2015-12-22'
# benchmark = 'HS300'
# universe = StockScreener(Factor.LFLO.nsmall(300) & Factor.VOL20.nsmall(300))    # LFLO 为流通市值对数，VOL20 为20日平均换手率
# capital_base = 1000000
# refresh_rate = 5
# stk_num_max = 40    # 持仓股票数量上限
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     open_price = account.get_attribute_history('openPrice', 1)    # 前一日开盘价
#     close_price = account.referencePrice                   # 前一日收盘价
#
#     #  获取回测当日的前一天日期
#     dt = Date.fromDateTime(account.current_date)
#     cal = Calendar('China.SSE')
#     last_day = cal.advanceDate(dt,'-1B',BizDayConvention.Preceding)            #计算出倒数第一个交易日
#     last_day_str = last_day.strftime("%Y%m%d")
#
#     # 市值排序，最多取市值最小的 stk_num_max 只股票
#     mkt_value = DataAPI.MktEqudGet(secID=account.universe,tradeDate=last_day_str,field="secID,negMarketValue",pandas="1")
#     sec_list = mkt_value.sort('negMarketValue').secID.head(stk_num_max).tolist()
#     buylist = {sec: 0 for sec in sec_list}
#
#     for s in account.valid_secpos:
#         if s not in buylist:
#             order_to(s, 0)
#
#     v = account.referencePortfolioValue / len(buylist)
#     for s in buylist:
#         buylist[s] = v / close_price[s] - account.valid_secpos.get(s, 0)
#
#     for s in sorted(buylist, key=buylist.get):
#         order(s, buylist[s])

# %% [markdown]
# #### 回测详情或者bt打印出来，都可以看到我们维护了一个总是持有小流通市值、低换手率的股票的持仓；偶尔持仓股票数目不超过上限

# %%
bt
# Out:
#      tradeDate          cash  \
# 0   2013-01-08    10111.1000
# 1   2013-01-09    10111.1000
# 2   2013-01-10    10111.1000
# 3   2013-01-11    10111.1000
# 4   2013-01-14    10111.1000
# 5   2013-01-15     1226.2240
# 6   2013-01-16     1226.2240
# 7   2013-01-17     1226.2240
# 8   2013-01-18     1226.2240
# 9   2013-01-21     1226.2240
# 10  2013-01-22     1226.2240
# 11  2013-01-23     1226.2240
# 12  2013-01-24     1226.2240
# 13  2013-01-25     1226.2240
# 14  2013-01-28     1226.2240
# 15  2013-01-29     1226.2240
# 16  2013-01-30     1226.2240
# 17  2013-01-31     1226.2240
# 18  2013-02-01     1226.2240
# 19  2013-02-04     1226.2240
# 20  2013-02-05     1226.2240
# 21  2013-02-06     1226.2240
# 22  2013-02-07     1226.2240
# 23  2013-02-08     1226.2240
# 24  2013-02-18     1226.2240
# 25  2013-02-19     1226.2240
# 26  2013-02-20     1226.2240
# 27  2013-02-21     1226.2240
# 28  2013-02-22     1226.2240
# 29  2013-02-25     1226.2240
# ..         ...           ...
# 688 2015-11-11      269.5668
# 689 2015-11-12      269.5668
# 690 2015-11-13      795.6668
# 691 2015-11-16      795.6668
# 692 2015-11-17      795.6668
# 693 2015-11-18      795.6668
# 694 2015-11-19      795.6668
# 695 2015-11-20    61663.2058
# 696 2015-11-23    61663.2058
# 697 2015-11-24    61663.2058
# 698 2015-11-25    61663.2058
# 699 2015-11-26    61663.2058
# 700 2015-11-27     1071.0698
# 701 2015-11-30     1071.0698
# 702 2015-12-01     1071.0698
# 703 2015-12-02     1071.0698
# 704 2015-12-03     1071.0698
# 705 2015-12-04    25155.0948
# 706 2015-12-07    25155.0948
# 707 2015-12-08    25155.0948
# 708 2015-12-09    25155.0948
# 709 2015-12-10    25155.0948
# 710 2015-12-11  2128039.8968
# 711 2015-12-14  2128039.8968
# 712 2015-12-15  2128039.8968
# 713 2015-12-16  2128039.8968
# 714 2015-12-17  2128039.8968
# 715 2015-12-18  2038341.9318
# 716 2015-12-21  2038341.9318
# 717 2015-12-22  2038341.9318
#
#                                      security_position  portfolio_value  \
# 0    {u'600892.XSHG': {u'amount': 77500, u'cost': 1...     1002886.1000
# 1    {u'600892.XSHG': {u'amount': 77500, u'cost': 1...     1002111.1000
# 2    {u'600892.XSHG': {u'amount': 77500, u'cost': 1...      999011.1000
# 3    {u'600892.XSHG': {u'amount': 77500, u'cost': 1...      986611.1000
# 4    {u'600892.XSHG': {u'amount': 77500, u'cost': 1...      996686.1000
# 5    {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1024082.2240
# 6    {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1010788.2240
# 7    {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1006878.2240
# 8    {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1012352.2240
# 9    {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1041286.2240
# 10   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1037376.2240
# 11   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1035812.2240
# 12   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1017044.2240
# 13   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1019390.2240
# 14   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1045196.2240
# 15   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1049888.2240
# 16   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1042068.2240
# 17   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1055362.2240
# 18   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1060836.2240
# 19   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1055362.2240
# 20   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1063182.2240
# 21   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1069438.2240
# 22   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1086642.2240
# 23   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1095244.2240
# 24   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1088206.2240
# 25   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1085078.2240
# 26   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1090552.2240
# 27   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1082732.2240
# 28   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1090552.2240
# 29   {u'600892.XSHG': {u'amount': 78200, u'cost': 1...     1094462.2240
# ..                                                 ...              ...
# 688  {u'300419.XSHE': {u'amount': 2200, u'cost': 11...     9517764.5668
# 689  {u'300419.XSHE': {u'amount': 2200, u'cost': 11...    10007681.5668
# 690  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     9310754.6668
# 691  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     9373845.6668
# 692  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     9177539.6668
# 693  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     8873873.6668
# 694  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     9371955.6668
# 695  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     9481668.2058
# 696  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     9353270.2058
# 697  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     9931079.2058
# 698  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...    10028185.2058
# 699  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     9894437.2058
# 700  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     9583326.0698
# 701  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...    10040743.0698
# 702  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     9720207.0698
# 703  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     9479497.0698
# 704  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     9903449.0698
# 705  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     9944520.0948
# 706  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     9987149.0948
# 707  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     9958717.0948
# 708  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     9566847.0948
# 709  {u'300419.XSHE': {u'amount': 1800, u'cost': 87...     9325853.0948
# 710  {u'300419.XSHE': {u'amount': 1300, u'cost': 38...     9187233.8968
# 711  {u'300419.XSHE': {u'amount': 1300, u'cost': 38...     9336085.8968
# 712  {u'300419.XSHE': {u'amount': 1300, u'cost': 38...     9370581.8968
# 713  {u'300419.XSHE': {u'amount': 1300, u'cost': 38...     9482864.8968
# 714  {u'300419.XSHE': {u'amount': 1300, u'cost': 38...     9764295.8968
# 715  {u'300419.XSHE': {u'amount': 1300, u'cost': 38...     9680579.9318
# 716  {u'300419.XSHE': {u'amount': 1300, u'cost': 38...     9660917.9318
# 717  {u'300419.XSHE': {u'amount': 1300, u'cost': 38...     9759452.9318
#
#      benchmark_return                                            blotter
# 0           -0.004200  [Order(order_time: 2013-01-08 09:30, symbol: 6...
# 1            0.000313                                                 []
# 2            0.001758                                                 []
# 3           -0.018703                                                 []
# 4            0.038051                                                 []
# 5            0.007033  [Order(order_time: 2013-01-15 09:30, symbol: 6...
# 6           -0.007227                                                 []
# 7           -0.009445                                                 []
# 8            0.016719                                                 []
# 9            0.005957                                                 []
# 10          -0.005362  [Order(order_time: 2013-01-22 09:30, symbol: 6...
# 11           0.004066                                                 []
# 12          -0.009473                                                 []
# 13          -0.004290                                                 []
# 14           0.031182                                                 []
# 15           0.009050  [Order(order_time: 2013-01-29 09:30, symbol: 6...
# 16           0.004802                                                 []
# 17          -0.000681                                                 []
# 18           0.021006                                                 []
# 19           0.001713                                                 []
# 20           0.008606  [Order(order_time: 2013-02-05 09:30, symbol: 6...
# 21           0.001505                                                 []
# 22          -0.005753                                                 []
# 23           0.004294                                                 []
# 24          -0.012357                                                 []
# 25          -0.018948  [Order(order_time: 2013-02-19 09:30, symbol: 6...
# 26           0.006341                                                 []
# 27          -0.034074                                                 []
# 28          -0.005340                                                 []
# 29           0.003220                                                 []
# ..                ...                                                ...
# 688          0.000106                                                 []
# 689         -0.009996                                                 []
# 690         -0.012932  [Order(order_time: 2015-11-13 09:30, symbol: 0...
# 691          0.004774                                                 []
# 692         -0.001525                                                 []
# 693         -0.011390                                                 []
# 694          0.015984                                                 []
# 695         -0.000155  [Order(order_time: 2015-11-20 09:30, symbol: 3...
# 696         -0.005577                                                 []
# 697          0.000148                                                 []
# 698          0.007384                                                 []
# 699         -0.005865                                                 []
# 700         -0.053848  [Order(order_time: 2015-11-27 09:30, symbol: 3...
# 701          0.002648                                                 []
# 702          0.007089                                                 []
# 703          0.036267                                                 []
# 704          0.007347                                                 []
# 705         -0.019125  [Order(order_time: 2015-12-04 09:30, symbol: 3...
# 706          0.002723                                                 []
# 707         -0.017515                                                 []
# 708          0.003566                                                 []
# 709         -0.003535                                                 []
# 710         -0.004147  [Order(order_time: 2015-12-11 09:30, symbol: 3...
# 711          0.028620                                                 []
# 712         -0.004563                                                 []
# 713         -0.002422                                                 []
# 714          0.019115                                                 []
# 715          0.003202  [Order(order_time: 2015-12-18 09:30, symbol: 3...
# 716          0.026023                                                 []
# 717          0.002785                                                 []
#
# [718 rows x 6 columns]
