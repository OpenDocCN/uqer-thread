# %% [markdown]
# # 获取某只股票PB因子例子

# %%
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
y=DataAPI.MktStockFactorsDateRangeGet(secID=u"",ticker=u"000538",beginDate=u"19991231",endDate=u"20180309",field=u"PB",pandas="1")
x=DataAPI.MktStockFactorsDateRangeGet(secID=u"",ticker=u"000538",beginDate=u"19991231",endDate=u"20180309",field=u"tradedate",pandas="1")
s = Series(x.tradeDate, index=y.PB)
s.plot()
