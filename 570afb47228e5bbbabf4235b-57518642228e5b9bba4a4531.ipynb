# %% [markdown]
# # 求大神指教，我想用PB因子做一个回测，为什么策略没有交易？

# %% [raw]
# start = '2015-04-10'                       # 回测起始时间
# end = '2016-04-10'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['601009.XSHG']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate =20                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):
#      # 市净率
#     PB =DataAPI.MktStockFactorsDateRangeGet( ticker = 601009,beginDate=start, endDate=end, field=u"tradeDate,PB",pandas="1")
#     PB = PB['PB'].dropna().to_dict()
#     for s in account.universe:
#         if  PB<= 1.0:
#             order_pct_to(s,1.0)
#         elif 1<PB<=1.1:
#             order_pct_to(s,0.9)
#         elif 1.1<PB<=1.2:
#             order_pct_to(s,0.8)
#         elif 1.2<PB<=1.3:
#             order_pct_to(s,0.7)
#         elif 1.3<PB<=1.4:
#             order_pct_to(s,0.6)
#         elif 1.4<PB<=1.5:
#             order_pct_to(s,0.5)
#         elif 1.5<PB<=1.6:
#             order_pct_to(s, 0.4)
#         elif 1.6<PB<=1.7:
#             order_pct_to(s,0.3)
#         elif 1.7<PB<=1.8:
#             order_pct_to(s,0.2)
#         elif 1.8<PB<=1.9:
#             order_pct_to(s,0.1)
#         else:
#             order_pct_to(s,0.0)
#     return

# %%
PB =DataAPI.MktStockFactorsDateRangeGet( ticker = 601009,beginDate=start, endDate=end, field=u"PB",pandas="1")
PB = PB['PB'].dropna().to_dict()  
print PB
# Out:
# {0: 1.1412, 1: 1.1725000000000001, 2: 1.1474, 3: 1.1436999999999999, 4: 1.1436999999999999, 5: 1.1123000000000001, 6: 1.1599999999999999, 7: 1.1561999999999999, 8: 1.1386000000000001, 9: 1.155, 10: 1.1851, 11: 1.1900999999999999, 12: 1.2278, 13: 1.2353000000000001, 14: 1.2353000000000001, 15: 1.2504, 16: 1.3044, 17: 1.3056000000000001, 18: 1.2855000000000001, 19: 1.2843, 20: 1.3257000000000001, 21: 1.3257000000000001, 22: 1.3030999999999999, 23: 1.2992999999999999, 24: 1.2654000000000001, 25: 1.2766999999999999, 26: 1.2617, 27: 1.2867999999999999, 28: 1.2654000000000001, 29: 1.2115, 30: 1.2089000000000001, 31: 1.2164999999999999, 32: 1.2152000000000001, 33: 1.2391000000000001, 34: 1.2805, 35: 1.2617, 36: 1.1876, 37: 1.2491000000000001, 38: 1.2516, 39: 1.2077, 40: 1.2190000000000001, 41: 1.2101999999999999, 42: 1.1688000000000001, 43: 1.1561999999999999, 44: 1.1575, 45: 1.165, 46: 1.1335999999999999, 47: 1.1498999999999999, 48: 1.2001999999999999, 49: 1.2039, 50: 1.214, 51: 1.21269999
# ...
