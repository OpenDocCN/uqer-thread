# %% [markdown]
# # 并购事件研究

# %%
import pandas as pd
import numpy as np
import datetime
from dateutil.parser import parse
import scipy.stats as ss
import matplotlib.pyplot as plt
from CAL.PyCAL import *
cal = Calendar('China.SSE')
font.set_size(15)

# %% [markdown]
# ## 一、事件列表获取
# ---获取并购事件数据，包括股票代码、事件发生的时间和并购是否成功。

# %%
def get_events(begin_date,end_date,universe):
    events =DataAPI.EquRestructuringGet(secID=universe,beginDate=begin_date,
                               endDate=end_date,field=u"secID,iniPublishDate,isSucceed",pandas="1")
    events['iniPublishDate'] = events['iniPublishDate'].map(lambda x : x[0:10] if cal.isBizDay(x) else cal.advanceDate(x[0:10], '-1B',BizDayConvention.Unadjusted).strftime('%Y-%m-%d'))
    events = events[events['iniPublishDate'] < parse(end_date).strftime('%Y-%m-%d')]
    events['secID_iniPublishDate'] = events['secID'] +'_'+ events['iniPublishDate']
    events = events.drop_duplicates()
    return events

# %%
events = get_events('20080101','20160520',set_universe('A'))

# %%
events.head()
# Out:
#          secID iniPublishDate  isSucceed    secID_iniPublishDate
# 0  000001.XSHE     2012-01-20          1  000001.XSHE_2012-01-20
# 1  000001.XSHE     2010-09-02          1  000001.XSHE_2010-09-02
# 2  000001.XSHE     2009-06-16          1  000001.XSHE_2009-06-16
# 3  000001.XSHE     2008-09-26          1  000001.XSHE_2008-09-26
# 5  000002.XSHE     2015-12-25          1  000002.XSHE_2015-12-25

# %% [markdown]
# ## 二、行情数据获取
# -----
# 事件分析需要用到一个窗口内的行情数据，但通过离散的时间点反推拿数据调用API太多，并且也是会冗余的。故我们先将所有可能用到的行情数据全部拿出，生产一张日期-股票的二维表。

# %%
def get_quotation(start_date,end_date,universe):
    df_eq = pd.DataFrame()
    for i in range(30,len(universe),30):
        df_tmp = DataAPI.MktEqudAdjGet(secID=universe[i-30:i],beginDate=start_date,endDate=end_date,
                                    field=u"secID,tradeDate,openPrice",isOpen=1,pandas="1")#股票行情（开盘，前复权）
        df_eq = pd.concat([df_eq,df_tmp],axis=0)
    df_tmp = DataAPI.MktEqudAdjGet(secID=universe[i:],beginDate=start_date,endDate=end_date,
                                field=u"secID,tradeDate,openPrice",isOpen=1,pandas="1")
    df_eq = pd.concat([df_eq,df_tmp],axis=0)
    return df_eq

# %%
df_eq = get_quotation('20071101','20160920',set_universe('A'))

# %%
df_eq_unstack = df_eq.set_index(['tradeDate','secID']).unstack()

# %% [markdown]
# 业绩预告公布通常是收盘后发生，此处我们计算每日收益采用的更接近实际的开盘至开盘的收益。

# %%
open2open_yield = df_eq_unstack['openPrice'].pct_change().dropna(how='all')

# %%
open2open_yield.head()
# Out:
# secID       000001.XSHE  000002.XSHE  000004.XSHE  000005.XSHE  000006.XSHE  \
# tradeDate
# 2007-11-02    -0.019267    -0.007657    -0.073746    -0.016667    -0.033055
# 2007-11-05    -0.025999     0.002589     0.029724    -0.011299    -0.000169
# 2007-11-06    -0.042228    -0.092815     0.010309     0.002857    -0.052302
# 2007-11-07     0.019715     0.032680    -0.021429     0.007123     0.009466
# 2007-11-08     0.006855     0.000000     0.027112    -0.032532    -0.012208
#
# secID       000007.XSHE  000008.XSHE  000009.XSHE  000010.XSHE  000011.XSHE  \
# tradeDate
# 2007-11-02          NaN    -0.002465    -0.017686          NaN     0.049630
# 2007-11-05          NaN    -0.043657     0.033951          NaN    -0.045938
# 2007-11-06          NaN     0.079242    -0.010945          NaN    -0.006459
# 2007-11-07          NaN     0.017558    -0.017606          NaN     0.008747
# 2007-11-08          NaN    -0.015686     0.029186          NaN     0.040192
#
# secID          ...       603969.XSHG  603979.XSHG  603986.XSHG  603988.XSHG  \
# tradeDate      ...
# 2007-11-02     ...               NaN          NaN          NaN          NaN
# 2007-11-05     ...               NaN          NaN          NaN          NaN
# 2007-11-06     ...               NaN          NaN          NaN          NaN
# 2007-11-07     ...               NaN          NaN          NaN          NaN
# 2007-11-08     ...               NaN          NaN          NaN          NaN
#
# secID       603989.XSHG  603993.XSHG  603996.XSHG  603997.XSHG  603998.XSHG  \
# tradeDate
# 2007-11-02          NaN          NaN          NaN          NaN          NaN
# 2007-11-05          NaN          NaN          NaN          NaN          NaN
# 2007-11-06          NaN          NaN          NaN          NaN          NaN
# 2007-11-07          NaN          NaN          NaN          NaN          NaN
# 2007-11-08          NaN          NaN          NaN          NaN          NaN
#
# secID       603999.XSHG
# tradeDate
# 2007-11-02          NaN
# 2007-11-05          NaN
# 2007-11-06          NaN
# 2007-11-07          NaN
# 2007-11-08          NaN
#
# [5 rows x 2921 columns]

# %% [markdown]
# ## 三、基准收益选取
# ----
# 我们分析结果是要看最后事件是否具有超额收益，故要设置一个基准收益，看处于事件的股票的收益是否比基准收益更高。此处我们将股票同行业的平均收益做为基准收益，更细致的分析，可以将市值因素考虑进来，出于运算时间的考虑此处没有加上。

# %%
def get_industry(into_date,universe):
    df_industry = DataAPI.EquIndustryGet(industryVersionCD=u"010303",secID=universe,
                                         intoDate=into_date,field=u"secID,industryName1",pandas="1")
    return df_industry

# %%
df_industry = get_industry('20161101',set_universe('A'))

# %%
ind_ret_list = []
for ind in df_industry.industryName1.drop_duplicates().tolist():
    ind_ret = open2open_yield.ix[:,df_industry[df_industry['industryName1']==ind]['secID'].tolist()].mean(axis=1)
    ind_ret.name = ind
    ind_ret_list.append(ind_ret)
ind_ret_df = pd.concat(ind_ret_list,axis=1)

# %%
def get_benchmark(x):
    ind = df_industry[df_industry['secID']==x]['industryName1'].values[0]
    return ind_ret_df[ind]

# %%
benchmarkYield = open2open_yield.apply(lambda x: get_benchmark(x.name))

# %%
benchmarkYield.head()
# Out:
# secID       000001.XSHE  000002.XSHE  000004.XSHE  000005.XSHE  000006.XSHE  \
# tradeDate
# 2007-11-02    -0.017546    -0.016811    -0.051130    -0.016811    -0.016811
# 2007-11-05    -0.018049    -0.015504    -0.018099    -0.015504    -0.015504
# 2007-11-06    -0.017540     0.000187     0.024189     0.000187     0.000187
# 2007-11-07     0.010064     0.009101     0.012529     0.009101     0.009101
# 2007-11-08     0.006341    -0.007068    -0.014728    -0.007068    -0.007068
#
# secID       000007.XSHE  000008.XSHE  000009.XSHE  000010.XSHE  000011.XSHE  \
# tradeDate
# 2007-11-02    -0.039808    -0.053692    -0.045627    -0.049102    -0.016811
# 2007-11-05    -0.017482    -0.032228    -0.008261    -0.012655    -0.015504
# 2007-11-06     0.029417     0.006818     0.016963     0.012485     0.000187
# 2007-11-07     0.017999     0.006393     0.009249     0.002552     0.009101
# 2007-11-08    -0.006427    -0.006782    -0.000872    -0.010548    -0.007068
#
# secID          ...       603969.XSHG  603979.XSHG  603986.XSHG  603988.XSHG  \
# tradeDate      ...
# 2007-11-02     ...         -0.046313    -0.030608    -0.050597    -0.055473
# 2007-11-05     ...         -0.014320    -0.029596    -0.003469    -0.012385
# 2007-11-06     ...          0.025508    -0.007664     0.033139     0.018416
# 2007-11-07     ...          0.004404     0.025582     0.008580     0.005651
# 2007-11-08     ...         -0.015342    -0.001818    -0.017614    -0.008494
#
# secID       603989.XSHG  603993.XSHG  603996.XSHG  603997.XSHG  603998.XSHG  \
# tradeDate
# 2007-11-02    -0.050597    -0.053692    -0.055693    -0.053342    -0.051130
# 2007-11-05    -0.003469    -0.032228    -0.004131    -0.016401    -0.018099
# 2007-11-06     0.033139     0.006818     0.033480     0.025543     0.024189
# 2007-11-07     0.008580     0.006393     0.007299     0.009932     0.012529
# 2007-11-08    -0.017614    -0.006782    -0.006326    -0.008892    -0.014728
#
# secID       603999.XSHG
# tradeDate
# 2007-11-02    -0.049206
# 2007-11-05    -0.010033
# 2007-11-06     0.024068
# 2007-11-07     0.012566
# 2007-11-08    -0.009898
#
# [5 rows x 2921 columns]

# %% [markdown]
# ## 四、时间窗口分析
# ---
# 事件驱动分析将时间发生点设置为T+0，将所有事件发生对齐到T+0点，并设置T-n到T+n为事件影响期，看事件的超额收益情况。

# %%
def get_window_yield(unstack_yield,events,window):
    #获取事件窗口收益
    events = events.reset_index()
    def get_time_list(window,events):
    # 得到每个事件的时间窗口
        minus_period = '-' + str(window) + 'B'
        period = str(window) + 'B'
        time_list = [[cal.advanceDate(events['iniPublishDate'][i],minus_period,BizDayConvention.Unadjusted),cal.advanceDate(events['iniPublishDate'][i],period,BizDayConvention.Unadjusted)] for i in range(len(events['iniPublishDate']))]
        return time_list
    
    time_list = get_time_list(window,events)
    offset = range(-1*window,window+1,1)
    event_equity_list = []
    for i in range(len(events)):
        df_tmp = pd.DataFrame(unstack_yield.ix[time_list[i][0].strftime('%Y-%m-%d'):time_list[i][1].strftime('%Y-%m-%d'),events.iloc[i]['secID']].values,columns=[events.iloc[i]['secID_iniPublishDate']],index = offset)
        event_equity_list.append(df_tmp)
    event_equity_window  = pd.concat(event_equity_list,axis=1)
    return event_equity_window

# %%
def get_mean_outperform_yield(event_equity_window_yield,event_benchmark_window_yield):
    #获取窗口内平均超额收益
    cols = list(event_equity_window_yield[(event_equity_window_yield > 0.8) | (event_equity_window_yield < -0.3)].dropna(how='all',axis=1).columns) #删除异常值，一天内的open2open收益最高也就是30%多点，存在借壳上市的公司会有很高的收益，删除这样的样本点
    for col in cols:
        del event_equity_window_yield[col]
        del event_benchmark_window_yield[col]
    event_equity_window_cumyield = (1 + event_equity_window_yield).cumprod(axis=0) / (1 + event_equity_window_yield).cumprod(axis=0).ix[0] # 累计收益，对齐T+0点（这里之前的版本把event_equity_window_yield写成了event_benchmark_window_yield，导致了后面的分析结果不对）
    event_benchmark_window_cumyield = (1 + event_benchmark_window_yield).cumprod(axis=0) / (1 + event_benchmark_window_yield).cumprod(axis=0).ix[0]
    event_outperform_window_yield = (event_equity_window_cumyield - event_benchmark_window_cumyield).mean(axis=1) #超额收益累计平均值
    return event_outperform_window_yield

# %%
events['isSucceed'].value_counts()
# Out:
# 1    36571
# 0      746
# Name: isSucceed, dtype: int64

# %% [markdown]
# 大部分的并购事件成功

# %%
def event_window_plot(open2open_yield,benchmarkYield,events,isSucceed,window,legend):
    ## 画出各事件时间窗口收益
    event_equity_window_yield = get_window_yield(open2open_yield,events[events['isSucceed']==isSucceed],window)
    event_benchmark_window_yield = get_window_yield(benchmarkYield,events[events['isSucceed']==isSucceed],window)
    event_outperform_window_yield = get_mean_outperform_yield(event_equity_window_yield,event_benchmark_window_yield)
    fig = plt.figure(figsize=(10,6))
    ax = fig.add_subplot(111)
    ax.plot(event_outperform_window_yield.index,event_outperform_window_yield.values,'dodgerblue',linewidth=2.5)
    plt.xlim(-25,25)
    plt.ylim(event_outperform_window_yield.min(),event_outperform_window_yield.max())
    ax.plot([0,0],[event_outperform_window_yield.min(),event_outperform_window_yield.max()],'crimson',linewidth=1.5,linestyle ='--')
    ax.plot([1,1],[event_outperform_window_yield.min(),event_outperform_window_yield.max()],'crimson',linewidth=1.5,linestyle ='--')
    ax.set_title(legend, fontproperties=font, fontsize=18)

# %%
event_window_plot(open2open_yield,benchmarkYield,events,1,25,u"并购成功事件时间窗口分析")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <mercury-input-35-7E896E3946134C629D5CF8AE970F46ED> in <module>()
# ----> 1 event_window_plot(open2open_yield,benchmarkYield,events,1,25,u"并购成功事件时间窗口分析")
#
# <mercury-input-32-7C6ED65609DF4F128C28538AC223420D> in event_window_plot(open2open_yield, benchmarkYield, events, isSucceed, window, legend)
#       1 def event_window_plot(open2open_yield,benchmarkYield,events,isSucceed,window,legend):
#       2     ## 画出各事件时间窗口收益
# ----> 3     event_equity_window_yield = get_window_yield(open2open_yield,events[events['isSucceed']==isSucceed],window)
#       4     event_benchmark_window_yield = get_window_yield(benchmarkYield,events[events['isSucceed']==isSucceed],window)
#       5     event_outperform_window_yield = get_mean_outperform_yield(event_equity_window_yield,event_benchmark_window_yield)
#
# <mercury-input-21-E308467306D949A6BE55AB01716B133F> in get_window_yield(unstack_yield, events, window)
#      13     event_equity_list = []
#      14     for i in range(len(events)):
# ---> 15         df_tmp = pd.DataFrame(unstack_yield.ix[time_list[i][0].strftime('%Y-%m-%d'):time_list[i][1].strftime('%Y-%m-%d'),events.iloc[i]['secID']].values,columns=[events.iloc[i]['secID_iniPublishDate']],index = offset)
#      16         event_equity_list.append(df_tmp)
#      17     event_equity_window  = pd.concat(event_equity_list,axis=1)
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     253             else:
#     254                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 255                                          copy=copy)
#     256         elif isinstance(data, (list, types.GeneratorType)):
#     257             if isinstance(data, types.GeneratorType):
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _init_ndarray(self, values, index, columns, dtype, copy)
#     430             values = _possibly_infer_to_datetimelike(values)
#     431
# --> 432         return create_block_manager_from_blocks([values], [columns, index])
#     433
#     434     @property
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in create_block_manager_from_blocks(blocks, axes)
#    3991         blocks = [getattr(b, 'values', b) for b in blocks]
#    3992         tot_items = sum(b.shape[0] for b in blocks)
# -> 3993         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    3994
#    3995
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in construction_error(tot_items, block_shape, axes, e)
#    3966         raise e
#    3967     if block_shape[0] == 0:
# -> 3968         raise ValueError("Empty data passed with indices specified.")
#    3969     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
#    3970         passed, implied))
#
# ValueError: Empty data passed with indices specified.

# %%
event_window_plot(open2open_yield,benchmarkYield,events,0,25,u"并购失败事件时间窗口分析")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <mercury-input-21-8DEB278E585648BC86673CE6B524382C> in <module>()
# ----> 1 event_window_plot(open2open_yield,benchmarkYield,events,0,25,u"预计亏损事件时间窗口分析")
#
# <mercury-input-19-3F16A91AEFD0409F84326B8621D28EAC> in event_window_plot(open2open_yield, benchmarkYield, events, isSucceed, window, legend)
#       1 def event_window_plot(open2open_yield,benchmarkYield,events,isSucceed,window,legend):
#       2     ## 画出各事件时间窗口收益
# ----> 3     event_equity_window_yield = get_window_yield(open2open_yield,events[events['isSucceed']==isSucceed],window)
#       4     event_benchmark_window_yield = get_window_yield(benchmarkYield,events[events['isSucceed']==isSucceed],window)
#       5     event_outperform_window_yield = get_mean_outperform_yield(event_equity_window_yield,event_benchmark_window_yield)
#
# <mercury-input-16-E308467306D949A6BE55AB01716B133F> in get_window_yield(unstack_yield, events, window)
#      13     event_equity_list = []
#      14     for i in range(len(events)):
# ---> 15         df_tmp = pd.DataFrame(unstack_yield.ix[time_list[i][0].strftime('%Y-%m-%d'):time_list[i][1].strftime('%Y-%m-%d'),events.iloc[i]['secID']].values,columns=[events.iloc[i]['secID_iniPublishDate']],index = offset)
#      16         event_equity_list.append(df_tmp)
#      17     event_equity_window  = pd.concat(event_equity_list,axis=1)
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     253             else:
#     254                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 255                                          copy=copy)
#     256         elif isinstance(data, (list, types.GeneratorType)):
#     257             if isinstance(data, types.GeneratorType):
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _init_ndarray(self, values, index, columns, dtype, copy)
#     430             values = _possibly_infer_to_datetimelike(values)
#     431
# --> 432         return create_block_manager_from_blocks([values], [columns, index])
#     433
#     434     @property
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in create_block_manager_from_blocks(blocks, axes)
#    3991         blocks = [getattr(b, 'values', b) for b in blocks]
#    3992         tot_items = sum(b.shape[0] for b in blocks)
# -> 3993         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    3994
#    3995
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in construction_error(tot_items, block_shape, axes, e)
#    3966         raise e
#    3967     if block_shape[0] == 0:
# -> 3968         raise ValueError("Empty data passed with indices specified.")
#    3969     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
#    3970         passed, implied))
#
# ValueError: Empty data passed with indices specified.

# %% [raw]
# import numpy as np
# import pandas as pd
# from CAL.PyCAL import *
# start = '2007-12-27'                       # 回测起始时间
# end = '2016-11-03'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('A')               #证券池，支持股票和基金
# capital_base = 100000000                    # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# cal = Calendar('China.SSE')
# period = '-1B'
#
# def initialize(account):                   # 初始化虚拟账户状态
#     account.day_count ={}
#     for stk in universe:
#         account.day_count[stk] = 0
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     yestoday = cal.advanceDate(account.current_date, period, BizDayConvention.Unadjusted)
#     begin_date = cal.advanceDate(account.current_date, '-1Y', BizDayConvention.Unadjusted)
#     profit_up = DataAPI.FdmtEfGet(secID=account.universe,publishDateBegin=begin_date.strftime('%Y%m%d'),publishDateEnd=account.current_date.strftime('%Y%m%d'),
#                                   forecastType="22",field=['secID','actPubtime',],pandas="1")
#
#     fil_profit = profit_up[profit_up['actPubtime'].map(lambda x: x[0:10]) == yestoday.strftime('%Y-%m-%d')]
#
#     buy_list = fil_profit['secID'].tolist()
#
#     total_money = account.reference_portfolio_value
#     prices = account.reference_price
#
#     for stk in account.avail_security_position:
#         if account.day_count[stk] == 5:
#             order_to(stk,0)
#             account.day_count[stk] = 0
#
#     for stk in buy_list:
#         if stk not in account.security_position:
#             if np.isnan(prices[stk]) or prices[stk] == 0:
#                 continue
#             order_pct_to(stk,1.0/355)
#
#     for stk in account.security_position:
#         account.day_count[stk] = account.day_count[stk] + 1
