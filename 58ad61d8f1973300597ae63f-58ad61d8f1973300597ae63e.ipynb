# %% [markdown]
# # debug

# %%
factors=DataAPI.MktStockFactorsOneDayGet(tradeDate='20160104',secID=u'000006.XSHE',field=u'',pandas="1")
print("with field empty: get ", len(factors.columns))
factors=DataAPI.MktStockFactorsOneDayGet(tradeDate='20160104',secID=u'000006.XSHE',field=factors.columns,pandas="1")
print("with field > 100: get", len(factors.columns))
