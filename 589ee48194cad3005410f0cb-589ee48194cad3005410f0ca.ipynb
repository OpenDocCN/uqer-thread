# %% [markdown]
# # Notebook60

# %%
import pandas as pd
import numpy
a=pd.read_excel('up.xlsx','up')
 # 绘制返回的数据
import seaborn
a.plot(x='barTime', y='closePrice',title=u'daliy line',figsize=(15,6))
# Out:
# [RangeIndex(start=0, stop=241, step=1),
#  Index([u'barTime', u'closePrice'], dtype='object')]
