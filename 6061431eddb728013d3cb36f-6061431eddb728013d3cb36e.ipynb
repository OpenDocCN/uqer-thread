# %% [markdown]
# # Notebook

# %%
DataAPI.MktHKEqudGet(secID=u"",ticker=u"00493",tradeDate=u"",beginDate=u"20071003",endDate=u"20080213",field=u"",pandas="1")
# Out:
#          secID ticker exchangeCD secShortName   tradeDate  preClosePrice  \
# 0   00493.XHKG  00493       XHKG         国美零售  2007-10-03          15.92
# 1   00493.XHKG  00493       XHKG         国美零售  2007-10-04          15.08
# 2   00493.XHKG  00493       XHKG         国美零售  2007-10-05          14.70
# 3   00493.XHKG  00493       XHKG         国美零售  2007-10-08          15.00
# 4   00493.XHKG  00493       XHKG         国美零售  2007-10-09          15.20
# 5   00493.XHKG  00493       XHKG         国美零售  2007-10-10          15.20
# 6   00493.XHKG  00493       XHKG         国美零售  2007-10-11          15.48
# 7   00493.XHKG  00493       XHKG         国美零售  2007-10-12          16.80
# 8   00493.XHKG  00493       XHKG         国美零售  2007-10-15          17.98
# 9   00493.XHKG  00493       XHKG         国美零售  2007-10-16          17.60
# 10  00493.XHKG  00493       XHKG         国美零售  2007-10-17          16.94
# 11  00493.XHKG  00493       XHKG         国美零售  2007-10-18          17.04
# ...
