# %% [markdown]
# # 银行翻倍策略平均

# %% [raw]
# import numpy as np
# import pandas as pd
# import datetime
# from CAL.PyCAL import *
# import math
# cal = Calendar('China.SSE')
#
#
# start = '2012-01-01'                       # 回测起始时间
# end = '2017-12-31'                         # 回测结束时间
# universe = DynamicUniverse('HS300')        # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = Monthly (1)  # 调仓频率，表示执行handle_data的时间间隔
# capital_base=10000000
# commission = Commission(buycost=0.0003, sellcost=0.0013)            # 设置手续费买入手续费万三，卖出手续费万十三
# slippage = Slippage(value=0.02, unit='perShare')  # 设置滑点0.02
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
#
# def initialize(context):
#     pass
# def handle_data(context):                  # 每个交易日的买入卖出指令
#
#     buylist = check_stock(context)
#
#     for stock in context.security_position.keys():
#         if stock not in buylist:
#             order_pct_to(stock,0)
#
#     for stock in buylist:
#         order_pct_to(stock, 1.0/len(buylist))
#
# def check_stock(context):
#     #stock_list = set_universe(IndSW.YinHangL1)
#     Today=context.previous_date
#     ind = DataAPI.EquIndustryGet(industryVersionCD=u"010303",industry=u"",
#                              secID=u"",ticker=u"",intoDate=u"",field=u"",pandas="1")
#     ind = ind[ind['outDate'].isnull()]
#     stock_list = ind[ind['industryName1'] == '银行']["secID"].tolist() # 用于银行翻倍策略
#     #
#     df=pd.DataFrame(index =stock_list, columns =['ROE','PB'])
#
#     for stk1 in stock_list:
#         df0=DataAPI.MktStockFactorsDateRangeGet(secID=stk1,\
#                                                 beginDate=cal.advanceDate(Today,'-12M'),\
#                                                 endDate=Today,field=u"ROE,PB,tradeDate",pandas="1")
#         df['ROE'][stk1]=df0['ROE'].mean()
#         df['PB'][stk1] = df0['PB'].mean()
#         #if np.isnan(df['ROE'][stk1]) == False :
#         #    df['PB'][stk1]=df0['PB'].values[-1]
#
#     df = df[df["ROE"] > -1]
#     #计算翻倍期
#     df["double_time"] =  df.apply(lambda row: round(math.log(2.0 * row['PB'] , (1.0+row['ROE'])),2), axis=1)
#     #翻倍期最小的银行股
#     df = df.sort("double_time")
#
#     print context.current_date.strftime('%Y-%m-%d') +' 选股为 '+ str(df.index[:5].values)[1:-1]
#     return df.index[:5]#这里的数字表示买入的标的 数量，默认是5

# %%
df0=DataAPI.MktStockFactorsDateRangeGet(secID='600519.XSHG',\
                                                beginDate='20180101',\
                                                endDate='20180107',field=u"ROE,PB,tradeDate",pandas="1")
df['ROE']['600519.XSHG']=df0['ROE'].mean()
print df0['PB']
print df0['PB'].values[-1]
# Out:
# 0    10.4814
# 1    10.6603
# 2    10.9761
# 3    10.9954
# Name: PB, dtype: float64
# 10.9954
