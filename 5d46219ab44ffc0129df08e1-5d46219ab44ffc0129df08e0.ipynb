# %% [markdown]
# # ETF300MA40策略

# %% [raw]
# from CAL.PyCAL import *
# start = '2013-01-01'                       # 回测起始时间
# end = '2019-07-25'                         # 回测结束时间
# universe = ['510300.XSHG']        # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'HS300'                        # 策略参考标准
# ETF300='510300.XSHG'
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的
# commission = Commission(buycost=0.0003, sellcost=0.0003)
# cal = Calendar('China.SSE')
#
# accounts = {
#     'stock_account': AccountConfig(account_type='security', capital_base=1000000)
# }
#
# def initialize(context):
#     pass
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#
#     account = context.get_account('stock_account')
#     #if len(account.universe) < 1: return
#
#     MA= cal.advanceDate(context.current_date, '-62B').strftime('%Y%m%d')
#     HS300=DataAPI.MktIdxdGet(indexID=u"000300.ZICN",beginDate=MA,endDate=context.current_date,pandas="1")['closeIndex']
#     #HS300.iloc[-2]表示的是前收盘价；HS300.iloc[-1]表示今天收盘价，如果当天还未收盘，这个数值是什么？
#     MA30=HS300[-41:-1].mean()
#     current_position=account.get_positions()
#     if HS300.iloc[-2]>MA30 and ETF300 not in current_position:
#         print 'buy',MA30,HS300.iloc[-2],HS300.iloc[-1]
#         order_pct_to(ETF300,0.99)
#     elif HS300.iloc[-2]<MA30 and ETF300 in current_position:
#         print 'sell',MA30,HS300.iloc[-2],HS300.iloc[-1]
#         order_pct_to(ETF300,0)
