# %% [markdown]
# # 四大期货交易所多头rank20

# %%
##四大期货交易所
import datetime
import pandas as pd
oneday=datetime.timedelta(days=1)
today=datetime.date.today()
yesterday=today-oneday
beginDate='20170615'
endDate='20170615'
###################################################################################################################
#大连商品期货交易所ticker=['a1709','c1709','m1709','y1709','p1709','cs1709','pp1709','v1709','l1709','i1709','j1709','jm1709','jd1709']
####################################################################################################################
ticker=['a1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
a=CL.iloc[:20]
#####################################################################################################################
ticker=['c1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
c=CL.iloc[:20]
#####################################################################################################################
ticker=['m1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
m=CL.iloc[:20]
#####################################################################################################################
ticker=['y1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
y=CL.iloc[:20]
#####################################################################################################################
ticker=['p1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
p=CL.iloc[:20]
#####################################################################################################################
ticker=['cs1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
cs=CL.iloc[:20]
#####################################################################################################################
ticker=['pp1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
pp=CL.iloc[:20]
#####################################################################################################################
ticker=['v1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
v=CL.iloc[:20]
#####################################################################################################################
ticker=['l1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
l=CL.iloc[:20]
#####################################################################################################################
ticker=['i1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
i=CL.iloc[:20]
#####################################################################################################################
ticker=['j1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
j=CL.iloc[:20]
#####################################################################################################################
ticker=['jm1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
jm=CL.iloc[:20]
#####################################################################################################################
ticker=['jd1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
jd=CL.iloc[:20]
###################################################################################################################
#################################################################################################################
x=jd['longVol']
jd=sum(x)
############
x=a['longVol']
a=sum(x)
############
x=c['longVol']
c=sum(x)
############
x=m['longVol']
m=sum(x)
############
x=cs['longVol']
cs=sum(x)
############
x=y['longVol']
y=sum(x)
############
x=p['longVol']
p=sum(x)
############
x=pp['longVol']
pp=sum(x)
############
x=l['longVol']
l=sum(x)
#############
x=v['longVol']
v=sum(x)
############
x=i['longVol']
i=sum(x)
############
x=j['longVol']
j=sum(x)
############
x=jm['longVol']
jm=sum(x)
############
##################################################################################################################################################
#上海期货交易所ticker=['bu1709','cu1709','al1709','ni1709','zn1709','rb1710','hc1710','ru1709','ag1712','au1712'
##################################################################################################################################################

###################################################################################################################
ticker=['bu1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
bu=CL.iloc[:20]
###################################################################################################################
ticker=['cu1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
cu=CL.iloc[:20]
###################################################################################################################
ticker=['al1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
al=CL.iloc[:20]
###################################################################################################################
ticker=['ni1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
ni=CL.iloc[:20]
###################################################################################################################
ticker=['zn1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
zn=CL.iloc[:20]
###################################################################################################################
ticker=['rb1710']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
rb=CL.iloc[:20]
###################################################################################################################
ticker=['hc1710']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
hc=CL.iloc[:20]
###################################################################################################################
ticker=['ru1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
ru=CL.iloc[:20]
###################################################################################################################
ticker=['ag1712']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
ag=CL.iloc[:20]
###################################################################################################################
ticker=['au1712']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
au=CL.iloc[:20]
###################################################################################################################
x=cu['longVol']
cu=sum(x)
############
x=al['longVol']
al=sum(x)
############
x=zn['longVol']
zn=sum(x)
############
x=ni['longVol']
ni=sum(x)
############
x=rb['longVol']
rb=sum(x)
############
x=hc['longVol']
hc=sum(x)
############
x=bu['longVol']
bu=sum(x)
############
x=ru['longVol']
ru=sum(x)
############
x=au['longVol']
au=sum(x)
############
x=ag['longVol']
ag=sum(x)
############
##########################################################################################################################################
#郑州商品期货交易所ticker=['ma1709','sr709','cf709','fg709','ta709','oi709','rm709','zc709']
##########################################################################################################################################

###################################################################################################################
ticker=['ma709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
ma=CL.iloc[:20]
###################################################################################################################
ticker=['sr709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
sr=CL.iloc[:20]
###################################################################################################################
ticker=['cf709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
cf=CL.iloc[:20]
###################################################################################################################
ticker=['fg709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
fg=CL.iloc[:20]
###################################################################################################################
ticker=['ta709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
ta=CL.iloc[:20]
###################################################################################################################
ticker=['oi709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
oi=CL.iloc[:20]
###################################################################################################################
ticker=['rm709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
rm=CL.iloc[:20]
###################################################################################################################
ticker=['zc709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
zc=CL.iloc[:20]
####################################################################################################################
x=ma['longVol']
ma=sum(x)
############
x=sr['longVol']
sr=sum(x)
############
x=cf['longVol']
cf=sum(x)
############
x=fg['longVol']
fg=sum(x)
############
x=ta['longVol']
ta=sum(x)
############
x=oi['longVol']
oi=sum(x)
############
x=rm['longVol']
rm=sum(x)
############
x=zc['longVol']
zc=sum(x)
############
#######################################################################################################
#中金期货交易所ticker=['if1707','ic1707','ih1707','tf1709','t1709']
#########################################################################################################

########################################################################################################
ticker=['if1707']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
IF=CL.iloc[:20]
########################################################################################################
ticker=['ic1707']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
IC=CL.iloc[:20]
########################################################################################################
ticker=['ih1707']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
IH=CL.iloc[:20]
########################################################################################################
ticker=['tf1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
TF=CL.iloc[:20]
########################################################################################################
ticker=['t1709']
DL=DataAPI.MktFutMLRGet(secID=u"",ticker=ticker,beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
CL=DL.sort(['rank'])
T=CL.iloc[:20]
#############
x=IF['longVol']
IF=sum(x)
############
############
x=IC['longVol']
IC=sum(x)
############
############
x=IH['longVol']
IH=sum(x)
############
############
x=TF['longVol']
TF=sum(x)
############
x=T['longVol']
T=sum(x)
############
PZ_sum=[cu,al,zn,ni,rb,hc,bu,ru,au,ag,a,c,cs,y,p,m,pp,l,v,i,j,jm,jd,ma,sr,cf,fg,ta,oi,rm,zc,IF,IC,IH,TF,T]
index=['cu','al','zn','ni','rb','hc','bu','ru','au','ag','a','c','cs','y','p','m','pp','l','v','i','j','jm','jd','ma','sr','cf','fg','ta','oi','rm','zc','IF','IC','IH','TF','T']
D_ALL_SUM=pd.Series(PZ_sum,index=index)
D_ALL_SUM
# Out:
# cu      35933
# al      42602
# zn      49443
# ni     151404
# rb    1270530
# hc     193178
# bu     179752
# ru     108893
# au     101414
# ag     136371
# a       70257
# c      496749
# cs     235934
# y      237942
# p      162631
# m      796698
# pp     202331
# l      137754
# v       45526
# i      683952
# j       68961
# jm      78605
# jd      75477
# ma     165623
# sr     231998
# cf      69478
# fg     102237
# ta     508722
# oi      75890
# rm     218920
# zc     177204
# IF      15547
# IC      14079
# IH      10254
# TF      39417
# T       42850
# dtype: int64
