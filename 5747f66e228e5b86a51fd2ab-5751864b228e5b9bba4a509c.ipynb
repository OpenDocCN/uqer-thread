# %% [markdown]
# # help:这个指数该怎么取到日行情

# %%
DataAPI.IdxGet(secID=u"",ticker=u"hsahp",field=u"",pandas="1")
# Out:
#       secID publishDate secShortName ticker  indexTypeCD indexType  pubOrgCD  \
# 0  AHP.XHKG  2007-07-09    恒生AH股溢价指数  HSAHP         2100      基准指数     31576
#
#   porgFullName    baseDate  basePoint  endDate
# 0     恒生指数有限公司  2006-01-03        100      NaN
