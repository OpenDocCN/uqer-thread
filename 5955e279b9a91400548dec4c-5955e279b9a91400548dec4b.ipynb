# %% [markdown]
# # 新闻热度情感指数

# %% [raw]
# ###    最热0.1同时最利好0.1   ###
# import pandas as pd
#
#
# start = '2015-05-01'                       # 回测起始时间
# end = '2017-06-29'                         # 回测结束时间
# universe = DynamicUniverse('A')        # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 2                           # 执行handle_data的时间间隔
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#
#     account = context.get_account('fantasy_account')
#
#     pday = context.previous_date.strftime('%Y-%m-%d')
#
#     stockList = context.universe
#
#     heatIdx = DataAPI.NewsHeatIndexV2Get(secID=stockList, field=['secID', 'heatIndex'], beginDate=pday,endDate=pday)
#
#     sentiIdx = DataAPI.NewsSentimentIndexV2Get(secID=stockList,beginDate=pday,endDate=pday,field=u"secID,sentimentIndex",pandas="1")
#
#     heatIdx.set_index('secID',inplace=True)
#     sentiIdx.set_index('secID',inplace=True)
#
#     newsIdx = pd.concat([heatIdx,sentiIdx],axis = 1)
#
#     newsIdx = newsIdx[newsIdx['heatIndex']>newsIdx.heatIndex.quantile(0.9)][newsIdx['sentimentIndex']>newsIdx.sentimentIndex.quantile(0.9)]
#
#     buylist = newsIdx.index.tolist()
#     selllist = context.avail_security_position
#
#     lenbuy = len(buylist)
#     print lenbuy
#
#     for sec in selllist:
#         if sec not in buylist:
#             account.order_to(sec,0)
#     for sec in buylist:
#         if sec not in selllist:
#
#             account.order_pct_to(sec,1.0/lenbuy)

# %% [raw]
# ###    最不热0.1同时最利好0.1   ###
# import pandas as pd
#
#
# start = '2015-05-01'                       # 回测起始时间
# end = '2017-06-29'                         # 回测结束时间
# universe = DynamicUniverse('A')        # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 3                           # 执行handle_data的时间间隔
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#
#     account = context.get_account('fantasy_account')
#
#     pday = context.previous_date.strftime('%Y-%m-%d')
#
#     stockList = context.universe
#
#     heatIdx = DataAPI.NewsHeatIndexV2Get(secID=stockList, field=['secID', 'heatIndex'], beginDate=pday,endDate=pday)
#
#     sentiIdx = DataAPI.NewsSentimentIndexV2Get(secID=stockList,beginDate=pday,endDate=pday,field=u"secID,sentimentIndex",pandas="1")
#
#     heatIdx.set_index('secID',inplace=True)
#     sentiIdx.set_index('secID',inplace=True)
#
#     newsIdx = pd.concat([heatIdx,sentiIdx],axis = 1)
#
#     newsIdx = newsIdx[newsIdx['heatIndex']<newsIdx.heatIndex.quantile(0.4)][newsIdx['sentimentIndex']>newsIdx.sentimentIndex.quantile(0.6)]
#
#     buylist = newsIdx.index.tolist()
#     selllist = context.avail_security_position
#
#     lenbuy = len(buylist)
#     print lenbuy
#
#     for sec in selllist:
#         if sec not in buylist:
#             account.order_to(sec,0)
#     for sec in buylist:
#         if sec not in selllist:
#
#             account.order_pct_to(sec,1.0/lenbuy)

# %% [raw]
# ###    最不热0.1同时最不利好0.1   ###
# import pandas as pd
#
#
# start = '2015-05-01'                       # 回测起始时间
# end = '2017-06-29'                         # 回测结束时间
# universe = DynamicUniverse('A')        # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 3                           # 执行handle_data的时间间隔
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#
#     account = context.get_account('fantasy_account')
#
#     pday = context.previous_date.strftime('%Y-%m-%d')
#
#     stockList = context.universe
#
#     heatIdx = DataAPI.NewsHeatIndexV2Get(secID=stockList, field=['secID', 'heatIndex'], beginDate=pday,endDate=pday)
#
#     sentiIdx = DataAPI.NewsSentimentIndexV2Get(secID=stockList,beginDate=pday,endDate=pday,field=u"secID,sentimentIndex",pandas="1")
#
#     heatIdx.set_index('secID',inplace=True)
#     sentiIdx.set_index('secID',inplace=True)
#
#     newsIdx = pd.concat([heatIdx,sentiIdx],axis = 1)
#
#     newsIdx = newsIdx[newsIdx['heatIndex']<newsIdx.heatIndex.quantile(0.1)][newsIdx['sentimentIndex']<newsIdx.sentimentIndex.quantile(0.1)]
#
#     buylist = newsIdx.index.tolist()
#     selllist = context.avail_security_position
#
#     lenbuy = len(buylist)
#     print lenbuy
#
#     for sec in selllist:
#         if sec not in buylist:
#             account.order_to(sec,0)
#     for sec in buylist:
#         if sec not in selllist:
#
#             account.order_pct_to(sec,1.0/lenbuy)

# %% [raw]
# ###    最热0.1同时最不利好0.1   ###
# import pandas as pd
#
#
# start = '2015-05-01'                       # 回测起始时间
# end = '2017-06-29'                         # 回测结束时间
# universe = DynamicUniverse('A')        # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 3                           # 执行handle_data的时间间隔
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#
#     account = context.get_account('fantasy_account')
#
#     pday = context.previous_date.strftime('%Y-%m-%d')
#
#     stockList = context.universe
#
#     heatIdx = DataAPI.NewsHeatIndexV2Get(secID=stockList, field=['secID', 'heatIndex'], beginDate=pday,endDate=pday)
#
#     sentiIdx = DataAPI.NewsSentimentIndexV2Get(secID=stockList,beginDate=pday,endDate=pday,field=u"secID,sentimentIndex",pandas="1")
#
#     heatIdx.set_index('secID',inplace=True)
#     sentiIdx.set_index('secID',inplace=True)
#
#     newsIdx = pd.concat([heatIdx,sentiIdx],axis = 1)
#
#     newsIdx = newsIdx[newsIdx['heatIndex']>newsIdx.heatIndex.quantile(0.9)][newsIdx['sentimentIndex']<newsIdx.sentimentIndex.quantile(0.1)]
#
#     buylist = newsIdx.index.tolist()
#     selllist = context.avail_security_position
#
#     lenbuy = len(buylist)
#     print lenbuy
#
#     for sec in selllist:
#         if sec not in buylist:
#             account.order_to(sec,0)
#     for sec in buylist:
#         if sec not in selllist:
#
#             account.order_pct_to(sec,1.0/lenbuy)

# %%
# import pandas as pd

# stockList = set_universe('A')

# heatIdx = DataAPI.NewsHeatIndexV2Get(secID=stockList, field=['secID', 'heatIndex'], beginDate='20170629',endDate='20170629')

# sentiIdx = DataAPI.NewsSentimentIndexV2Get(secID=stockList,beginDate='20170629',endDate='20170629',field=u"secID,sentimentIndex",pandas="1")

# heatIdx.set_index('secID',inplace=True)
# sentiIdx.set_index('secID',inplace=True)
# newsIdx = pd.concat([heatIdx,sentiIdx],axis = 1)
# newsIdx = newsIdx[newsIdx['heatIndex']>newsIdx.heatIndex.quantile(0.9)]
# newsIdx = newsIdx[newsIdx['sentimentIndex']>newsIdx.sentimentIndex.quantile(0.9)]
# newsIdx
# Out:
#              heatIndex  sentimentIndex
# secID
# 000156.XSHE   0.328947        0.153955
# 000401.XSHE   0.328947        0.120960
# 000786.XSHE   0.386156        0.152641
# 000961.XSHE   0.414760        0.134248
# 001979.XSHE   0.729405        0.134049
# 002051.XSHE   0.343249        0.119419
# 002205.XSHE   0.343249        0.128407
# 002236.XSHE   0.357551        0.142672
# 002238.XSHE   0.343249        0.156178
# 002253.XSHE   0.543478        0.128792
# 300264.XSHE   0.457666        0.143009
# 600011.XSHG   0.328947        0.144886
# 600507.XSHG   0.529176        0.136494
# 600634.XSHG   0.529176        0.128964
# 600718.XSHG   0.371854        0.127283
# 600728.XSHG   0.328947        0.164428
# 600831.XSHG   0.357551        0.153280
# 600997.XSHG   0.328947        0.126803
# 601929.XSHG   0.400458        0.156598
