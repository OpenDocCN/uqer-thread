# %% [markdown]
# # 测试

# %% [raw]
# import pandas as pd
# import numpy as np
# import talib as ta
#
# start = '2020-01-01'                       # 回测起始时间
# end = '2021-05-21'                         # 回测结束时间
# universe = DynamicUniverse('000906.ZICN')        # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=100000)
# }
#
# def initialize(context):
#     context.data = pd.read_csv('0521ma02.csv')
#     # context.short_ma = 5
#     # context.middl_ma = 10
#     # context.long_ma = 30
#     max_history_window = 30
#
# def handle_data(context):
#     buy_list = []
#     account = context.get_account('fantasy_account')
#     current_universe = context.get_universe(exclude_halt=True) # 返回股票池列表,不包括停牌的。
#     position  = account.get_positions()
#
#     # 获取回测当天的数据 context.current_date 回测当天的日期
#     data = context.data.set_index('time')
#     trade_time = context.current_date.strftime('%Y-%m-%d')
#     previous_date = context.previous_date.strftime('%Y-%m-%d')
#     data = data.loc[trade_time]
#
#     # 获取position列为1的code
#     data_position = data.loc[data['position'] == 1]
#     data_position_list = data_position['code'].tolist()
#
#     # data_roe = context.history(data_position_list,attribute='ROE',freq='d',style='tas',retype='frame')[previous_date]
#     data_roe = DataAPI.MktStockFactorsOneDayGet(tradeDate=previous_date,secID=data_position_list,ticker=u"",field=["secID","ROE"],pandas="1")
#     data_roe = data_roe.sort_values('ROE')
#     data_roe.dropna(axis=0, how='all')
#     # log.info(data_roe['secID'])
#     buy_list = data_roe['secID'].iloc[-1][:]
#     # log.info(data_roe)
#
#     if position:
#         log.info(position.keys())  # 返回 ['002957.XSHE'] 列表
#         values = position.values()[0]
#         # symbol = position.symbol
#         # amount = position.amount
#         log.info(values['cost'])
#         # log.info(symbol)
#         # log.info(amount)
#         account.close_all_positions()
#
#         # 如果没有持仓，则检测是否符合开仓条件，如果符合就买
#     order_id = account.order_pct(buy_list, 1)
#     # log.info(account.get_orders(order_id))
#     # log.info(order_id)
#
#         # log.info(account.get_position(current_universe))
