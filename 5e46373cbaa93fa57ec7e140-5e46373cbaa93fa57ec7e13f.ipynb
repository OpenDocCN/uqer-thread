# %% [markdown]
# # Notebook0

# %% [raw]
# import pandas as pd
# import numpy as np
# from CAL.PyCAL import Calendar
# from CAL.PyCAL import BizDayConvention
# cal = Calendar('China.SSE')
#
# start = '2013-01-01'                       # 回测起始时间
# end = '2019-10-01'                         # 回测结束时间
# universe = DynamicUniverse('HS300')        # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# ceshi=pd.read_csv('ceshi_13.csv',converters={'ticker':str})
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):
#     context.dd='0'
#     pass
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     previous_date = context.previous_date.strftime('%Y-%m-%d')
#     yesterday=cal.advanceDate(context.current_date, '-1B', BizDayConvention.Preceding).strftime('%Y-%m-%d')
#     cut_date=cal.advanceDate(context.current_date, '0B', BizDayConvention.Preceding).strftime('%Y-%m-%d')
#     tar=ceshi[ceshi['tradeDate']==yesterday]
#     tar1=tar.sort_values(by='p',ascending=False)
#     tar1=list(tar1.iloc[:20]['ticker'])
#     setc=list(DataAPI.MktEqudAdjGet(secID=u'',ticker=tar1,
#                                     tradeDate=yesterday,beginDate=u'',endDate=u'',
#                                     isOpen="",field=['secID'],pandas="1")['secID'])
#
#     if len(tar)>0:
#         target_position=setc
#
#     else:
#          target_position=[]
#     account = context.get_account('fantasy_account')
#     current_position = account.get_positions(exclude_halt=True)
#
#     if  context.dd!='0':
#         for stock in set(current_position):
# 			p1=DataAPI.MktEqudAdjGet(secID=stock,ticker=u'',tradeDate=yesterday,beginDate=u'',endDate=u'',isOpen="",field=['closePrice'],pandas="1")['closePrice'].values[0]
# 			p0=DataAPI.MktEqudAdjGet(secID=stock,ticker=u'',tradeDate=context.dd,beginDate=u'',endDate=u'',isOpen="",field=['closePrice'],pandas="1")['closePrice'].values[0]
# 			try:
# 				if   float(p1)/p0<0.85:
# 					account.order_to(stock, 0)
# 			except:
# 				pass
#
#     if len(tar)>0:
#         for stock  in set(current_position):
#             if stock  not in target_position:
#                 account.order_to(stock, 0)
#         for stock in target_position:
#             if stock not in current_position:
#                     try:
#                             aa=min(1.0/len(target_position),0.2)
#                             account.order_pct_to(stock,aa)
#                     except:
#                         pass
#     if str(cut_date)[:-2]=='01':
#         context.dd=cut_date
