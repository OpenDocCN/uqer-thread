# %% [markdown]
# # PE最小10只股票

# %% [markdown]
# - PE大于0的股票中的PE最小10只股票
# - 5日一调仓

# %% [raw]
# from CAL.PyCAL import *
#
# start = '2013-01-01'
# end = '2016-01-21'
# benchmark = 'HS300'
# universe = StockScreener(Factor.PE.value_range(0,10))    # 取PE介于0和10之间的股票
# capital_base = 1000000
# freq = 'd'
# refresh_rate = 5
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#
#     cal = Calendar('China.SSE')   # 上交所交易日历
#     last_day = cal.advanceDate(Date.fromDateTime(account.current_date),'-1B',BizDayConvention.Preceding)   # 计算前一个交易日
#     last_day_str = last_day.strftime("%Y%m%d")
#
#     # 使用DataAPI.MktStockFactorsOneDayGet拿取PE数据
#     pe_data = DataAPI.MktStockFactorsOneDayGet(tradeDate=last_day_str,secID=account.universe,field='secID,PE').sort('PE')
#     pe_data = pe_data[pe_data.PE>0]  # 取PE大于0的
#     my_universe = pe_data.head(10).secID.values  # 取PE大于0的其中的10只
#
#     for stk in account.valid_secpos:
#         if stk not in my_universe:
#             order_to(stk, 0)
#     for stk in my_universe:
#         order_pct_to(stk, 0.1)
