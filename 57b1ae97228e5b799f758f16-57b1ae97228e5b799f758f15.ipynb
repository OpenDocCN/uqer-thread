# %% [markdown]
# #

# %% [markdown]
# ## 这是按一个行业的所有股票，然后按每股收益排序选择前5的买入，然后做一个长线，但是呢，发现代码运行过程中存在一个问题就是买入命令不能使用order_pct，不知道为什么报错了。。。

# %% [raw]
# start = '2014-05-07'                       # 回测起始时间
# end = '2016-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('A')  # 证券池，支持股票和基金
# capital_base = 10000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# import math
# import pandas as pd
# def IndustryGet(bgday,IndustryName='银行'):
#     bob=DataAPI.EquIndustryGet(industryVersionCD=u"010303",industry=u"",secID=u"",ticker=u"",intoDate=u"",field=u"secID,industryName2,secShortName",pandas="1")
#     bobo=bob[bob.industryName2==IndustryName].secID
#     c={'symbol':[],'mgsy':[]}
#     for tic in bobo:
#         if tic not in c['symbol']:
#             c['symbol'].append(tic)
#     ##print len(c['symbol'])
#     mgsytmp=DataAPI.MktStockFactorsOneDayGet(tradeDate=bgday,secID=c['symbol'],ticker=u"",field=u"EPS",pandas="1")
#     for tic in mgsytmp.EPS:
#         if math.isnan(tic)==True:
#             c['mgsy'].append(0)
#         else:
#             c['mgsy'].append(tic)
#     ##print len(c['mgsy'])
#     ##print len(c['symbol'])
#     c['symbol']=c['symbol'][:len(c['mgsy'])]
#     mgsyfl=pd.DataFrame(c).sort(columns='mgsy',ascending=False)
#     mgsylist=mgsyfl['symbol'].tolist()
#     return mgsylist
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     buylist=IndustryGet(start.replace('-',''),'房地产开发')
#     buylist=buylist[0:5]
#     for tic in buylist:
#         order(tic,100000)
#         ##order_pct(tic,0.2)
