# %% [markdown]
# # 关于EPS的数值，在3月21号到23号发生了什么

# %% [markdown]
# 关于EPS的数值，在3月21号到23号发生了什么，有两个问题想请教一下大神们：
#
# 1. 20160321、20160322、20160323号，为什么300026.XSHE的eps都不一样，优矿上eps的更新时间一般有什么规律吗；
#
# 2. 有些股，比如603558.XSHG、603898.XSHG，为什么21号到22号eps的变化会这么大，TTM值也会有这么大波动吗

# %%
for t in ["20160104","20160201","20160321","20160322","20160323"]:
    eq_EPS_EGRO = DataAPI.MktStockFactorsOneDayGet(tradeDate=t,secID=['600016.XSHG','603898.XSHG','603558.XSHG','300026.XSHE'],field=['secID','EPS','DilutedEPS'],pandas="1")
    print '\n'+t
    print eq_EPS_EGRO
# Out:
# 20160104
#          secID   EPS  DilutedEPS
# 0  300026.XSHE  0.87        0.87
# 1  600016.XSHG  1.33        1.28
# 2  603558.XSHG  1.35        1.35
# 3  603898.XSHG  1.92        1.92
#
# 20160201
#          secID   EPS  DilutedEPS
# 0  300026.XSHE  0.87        0.87
# 1  600016.XSHG  1.33        1.28
# 2  603558.XSHG  1.35        1.35
# 3  603898.XSHG  1.92        1.92
#
# 20160321
#          secID   EPS  DilutedEPS
# 0  300026.XSHE  0.87        0.87
# 1  600016.XSHG  1.33        1.28
# 2  603558.XSHG  1.35        1.35
# 3  603898.XSHG  1.92        1.92
#
# 20160322
#          secID   EPS  DilutedEPS
# 0  300026.XSHE  0.48        0.48
# 1  600016.XSHG  1.10        1.06
# 2  603558.XSHG  0.30        0.30
# 3  603898.XSHG  0.38        0.38
#
# 20160323
#          secID   EPS  DilutedEPS
# 0  300026.XSHE  0.60        0.59
# 1  600016.XSHG  1.10        1.06
# 2  603558.XSHG  0.30        0.30
# 3  603898.XSHG  0.38        0.38
