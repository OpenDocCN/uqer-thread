# %% [markdown]
# # 测试setuniverse发现的问题

# %% [markdown]
# 发现set_universe 函数中的date参数不管用啊，无论设置成什么都是取的最近日期的股票池。是我搞错了吗还是函数问题，麻烦大家看一下...............

# %%
from CAL.PyCAL import *
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
index='CYB'
start_date = '20090505'  # 开始日期

end_date = (datetime.today() - timedelta(days=1)).strftime('%Y%m%d')  # 截止日期
#end_date='20121231'
data = DataAPI.TradeCalGet(exchangeCD=u"XSHG",beginDate=start_date,endDate=end_date,field=u"calendarDate,isOpen",pandas="1")
data = data[data['isOpen'] == 1]
Dates = map(lambda x: x[0:4]+x[5:7]+x[8:10], data['calendarDate'].values.tolist())
PB_PE = pd.DataFrame(index=Dates, data=0, columns=['total PB','total PE'])

for date in Dates:  
    universe = set_universe(index, date)
    print date,len(universe )
# Out:
# 20090505
#  506
# 20090506 506
# 20090507 506
# 20090508
#  506
# 20090511 506
# 20090512 506
# 20090513
#  506
# 20090514 506
# 20090515 506
# 20090518
#  506
# 20090519 506
# 20090520 506
# 20090521
#  506
# 20090522 506
# 20090525 506
# 20090526
#  506
# 20090527 506
# 20090601 506
# 20090602
#  506
# 20090603 506
# 20090604 506
# 20090605
#  506
# 20090608 506
# 20090609 506
# 20090610
#  506
# 20090611 506
# 20090612 506
# 20090615
#  506
# 20090616 506
# 20090617 506
# 20090618
#  506
# 20090619 506
# 20090622 506
# 20090623
#  506
# 20090624 506
# 20090625 506
# 20090626
#  506
# 20090629 506
# 20090630 506
# 20090701
#  506
# 20090702 506
# 20090703 506
# 20090706
#  506
# 20090707 506
# 20090708 506
# 20090709
#  506
# 20090710 506
# 20090713 506
# 20090714
#  506
# 20090715 506
# 20090716 506
# 20090717
#  506
# 20090720 506
# 20090721 506
# 20090722
#  506
# 20090723 506
# 20090724 506
# 20090727
#  506
# 20090728 506
# 20090729 506
# 20090730
#  506
# 20090731 506
# ...

# %%
universe = set_universe('A', date='20090101')

# %%
len(universe)
# Out:
# 2847
