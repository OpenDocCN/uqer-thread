# %% [markdown]
# # 关于history函数的测试及问题

# %% [markdown]
# 用 account.get_attribute_history 函数或另外两个常用 history 函数取数据，若 time_range 参数大于1，会出现回测的前几天（天数等于 time_range 的值）会得不到数据
# 下面三个例子 time_range 分别为 10、1、5，则回测前10天、1天、5天得不到数据（至少打印不出来）
# 这样对一些想取前面一段时间的历史数据做一些运算（如取均值等）再用的策略，会造成一定困扰
#
# 请问：
# 是什么机制导致这样的结果？
# 有什么解决办法？（除了DataAPI）

# %% [raw]
# from CAL.PyCAL import *
# from numpy import *
#
# start = '2015-08-10'
# end = '2015-08-25'
# benchmark = 'HS300'
# universe =  ['600000.XSHG']
# capital_base = 1000000
# freq = 'd'
# refresh_rate = 1
# commission = Commission(buycost=0.0008, sellcost=0.0018)
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     today = account.current_date
#     today_str = today.strftime("%Y%m%d")
#
#     close = account.get_attribute_history('closePrice', 10)
#     print today_str, close['600000.XSHG']

# %% [raw]
# from CAL.PyCAL import *
# from numpy import *
#
# start = '2015-08-10'
# end = '2015-08-25'
# benchmark = 'HS300'
# universe =  ['600000.XSHG']
# capital_base = 1000000
# freq = 'd'
# refresh_rate = 1
# commission = Commission(buycost=0.0008, sellcost=0.0018)
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     today = account.current_date
#     today_str = today.strftime("%Y%m%d")
#
#     close = account.get_attribute_history('closePrice', 1)
#     print today_str, close['600000.XSHG']

# %% [raw]
# from CAL.PyCAL import *
# from numpy import *
#
# start = '2015-08-10'
# end = '2015-08-25'
# benchmark = 'HS300'
# universe =  ['600000.XSHG']
# capital_base = 1000000
# freq = 'd'
# refresh_rate = 1
# commission = Commission(buycost=0.0008, sellcost=0.0018)
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     today = account.current_date
#     today_str = today.strftime("%Y%m%d")
#
#     close = account.get_attribute_history('closePrice', 5)
#     print today_str, close['600000.XSHG']
