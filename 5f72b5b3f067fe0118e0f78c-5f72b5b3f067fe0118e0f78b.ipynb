# %% [markdown]
# # test

# %%
DataAPI.MktEqudGet(secID=u"",ticker=u"000001",tradeDate=u"20190723",beginDate=u"",endDate=u"",isOpen="",field=u"",pandas="1")
# Out:
#          secID  ticker secShortName exchangeCD   tradeDate  preClosePrice  \
# 0  000001.XSHE  000001         平安银行       XSHE  2019-07-23          13.85
#
#    actPreClosePrice  openPrice  highestPrice  lowestPrice   ...    \
# 0             13.85      13.86         13.87        13.65   ...
#
#    turnoverRate  accumAdjFactor  negMarketValue   marketValue  chgPct      PE  \
# 0        0.0029        0.983231    236262595968  236264860864 -0.0065  9.2043
#
#       PE1      PB  isOpen    vwap
# 0  7.9326  0.9415       1  13.737
#
# [1 rows x 24 columns]

# %%
DataAPI.MktEqudGet(ticker=u"000001",tradeDate='2019-07-23',isOpen="1",field=u"",pandas="1")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <mercury-input-5-995416CA0AD34B188E2009C098FB367F> in <module>()
# ----> 1 DataAPI.MktEqudGet(ticker=u"000001",tradeDate='2019-07-23',isOpen="1",field=u"",pandas="1")
#
# /home/ipython/anaconda/lib/python2.7/site-packages/DataAPI/DATAYES.py in MktEqudGet(secID, ticker, tradeDate, beginDate, endDate, isOpen, field, pandas)
#    2387         csvString = api_base.__getCSV__(''.join(requestString), httpClient, gw=False)
#    2388         if csvString is None or len(csvString) == 0 or (csvString[0] == '-' and not api_base.is_no_data_warn(csvString, False)) or csvString[0] == '{':
# -> 2389             api_base.handle_error(csvString, 'MktEqudGet')
#    2390         elif csvString[:2] == '-1':
#    2391             csvString = ''
#
# ...
