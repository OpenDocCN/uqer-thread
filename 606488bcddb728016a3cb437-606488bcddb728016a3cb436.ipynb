# %% [markdown]
# # 行业分类_CSRC

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt
import CAL.PyCAL as C_cal # CAL provides classes and functions dealing with date, time, and calendars. 

sns.set_style('white')

matplotlib.rc('axes', labelsize=14)
matplotlib.rc('xtick', labelsize=12)
matplotlib.rc('ytick', labelsize=12)

pd.set_option('display.width', 200)

cal = C_cal.Calendar('China.SSE')

# %%
"""
行业分类标准
[通联数据] - DataAPI.IndustryGet
DataAPI.IndustryGet(industryVersion=u"SW",industryVersionCD=u"",industryLevel=u"1",isNew=u"1",prntIndustryID=u"",field=u"",pandas="1")
名称	              类型	 描述
industryVersion 	str	    行业分类标准。SW- 申万行业分类,industryVersion、industryVersionCD至少选择一个
industryVersionCD	list	行业分类标准数字编码。010301-证监会行业V2012、010303-申万行业、010308-中证行业,可以是列表,industryVersion、industryVersionCD至少选择一个
                            （！补充内容：010306-恒生行业  010314-中证行业分类（2016版）  010317-中信行业分类  # 010319-战略性新兴产业(2018) ， 没有和 同花顺上(66个) 相同的分类；）
industryLevel	    int	    输入数字如1,2,3,4，可指定查询的第几级行业,可以是列表,可空
isNew	            int	    是否最新，1表示是，0表示否,可空
prntIndustryID	    list	上级行业数字编码，通联赋予，输入可查询该分类下所有子分类情况,可以是列表,可空
field	            list	所需字段,可以是列表,可空
pandas	            str	    1表示返回 pandas data frame，0表示返回csv,可空
"""

pd_xyfl=DataAPI.IndustryGet(industryVersionCD=u"010301",isNew=u"1",pandas="1") # 010301-证监会行业V2012
pd_xyfl.rename(columns={'industryVersionCD':'1行业分类标准数字编码',
                             'industryVersion':'2行业分类标准(字母缩写)',
                             'industry':'3行业分类标准名称',
                             'industryID':'4行业划分数字编码，通联赋予',
                             'industrySymbol':'5行业划分(编制机构)',
                             'industryName':'6行业名称',
                             'industryLevel':'7行业划分所属级别',
                             'isNew':'8是否最新',
                             'indexSymbol':'9对应行业指数代码(编制机构)',
                             'prntIndustryID':'10上级行业数字编码，通联赋予，与industryID对应',
                             'beginDate':'11分类生效日期',
                             'endDate':'12分类截止日期',
                             'updateTime':'13最近的一次更新时间'},inplace=True)
# pd_xyfl.to_excel("证监会行业V2012_20210331.xlsx")
pd_xyfl.head(5).append(pd_xyfl.tail(5))
# Out:
#     1行业分类标准数字编码 2行业分类标准(字母缩写)   3行业分类标准名称 4行业划分数字编码，通联赋予 5行业划分(编制机构)      6行业名称  7行业划分所属级别  8是否最新 9对应行业指数代码(编制机构) 10上级行业数字编码，通联赋予，与industryID对应  11分类生效日期  12分类截止日期          13最近的一次更新时间
# 0        010301         V2012  证监会行业V2012         010301         NaN  证监会行业2012        NaN      1             NaN                          0103       NaN       NaN  2018-10-26 14:46:11
# 1        010301         V2012  证监会行业V2012       01030101           A   农、林、牧、渔业        1.0      1             NaN                        010301       NaN       NaN  2015-03-13 10:59:03
# 2        010301         V2012  证监会行业V2012     0103010101         A01         农业        2.0      1             NaN                      01030101       NaN       NaN  2015-03-13 10:59:42
# 3        010301         V2012  证监会行业V2012     0103010102         A02         林业        2.0      1             NaN                      01030101       NaN       NaN  2017-12-04 16:53:15
# 4        010301         V2012  证监会行业V2012     0103010103         A03        畜牧业        2.0      1             NaN                      01030101       NaN       NaN  2017-12-04 16:53:15
# 105      010301         V2012  证监会行业V2012     0103011803         R87      文化艺术业        2.0      1             NaN                      01030118       NaN       NaN  2015-03-13 10:59:04
# 106      010301         V2012  证监会行业V2012     0103011804         R88         体育        2.0      1             NaN                      01030118       NaN       NaN  2015-03-13 10:59:04
# 107      010301         V2012  证监会行业V2012     0103011805         R89        娱乐业        2.0      1             NaN                      01030118       NaN       NaN  2015-03-13 10:59:04
# 108      010301         V2012  证监会行业V2012       01030119           S         综合        1.0      1             NaN                        010301       NaN       NaN  2015-03-13 10:59:04
# 109      010301         V2012  证监会行业V2012     0103011901         S90         综合        2.0      1             NaN                      01030119       NaN       NaN  2015-03-13 10:59:04

# %%
"""
 股票行业分类
[通联数据] - DataAPI.EquIndustryGet 

DataAPI.EquIndustryGet(secID=u"",ticker=u"688005,600001",industryVersionCD=u"010303",industry=u"",industryID=u"",
    industryID1=u"",industryID2=u"",industryID3=u"",intoDate=u"",equTypeID=u"",field=u"",pandas="1")
    
名称 	               类型 	 描述
secID 	            list 	通联编制的证券编码，可在DataAPI.SecIDGet获取到。 可以是列表,secID、ticker、industryVersionCD、industry、industryID至少选择一个
ticker 	            list 	通用交易代码 可以是列表,secID、ticker、industryVersionCD、industry、industryID至少选择一个
industryVersionCD 	str 	行业分类标准数字编码，建议用此参数确定行业类别，010301-证监会行业V2012；010303-申万行业分类；010306-恒生行业；010314-中证行业分类（2016版）；010317-中信行业分类；010319-战略性新兴产业(2018),secID、ticker、industryVersionCD、industry、industryID至少选择一个
industry 	        str 	行业分类标准名称，可模糊查询,secID、ticker、industryVersionCD、industry、industryID至少选择一个
industryID 	        str 	通联编制的行业分类编码，可以通过getIndustry获取。,secID、ticker、industryVersionCD、industry、industryID至少选择一个
industryID1 	    list 	一级行业编码 可以是列表,可空
industryID2 	    list 	二级行业编码 可以是列表,可空
industryID3 	    list 	三级行业编码 可以是列表,可空
intoDate 	        str 	输入一个日期，可以获取该日期下的股票所属行业信息，输入格式“YYYYMMDD”。例如输入"20190722"，获取这一天当时生效的行业成分信息。,可空
equTypeID 	        list 	股票类型代码 可以是列表,可空
field 	            list 	所需字段 可以是列表,可空
pandas 	            str 	1表示返回 pandas data frame，0表示返回csv,可空
"""

DataAPI.EquIndustryGet(industryVersionCD=u"010301",industryID=u"0103010313",pandas="1")

"""
结论 : 经测试 ， 使用 “010301-证监会行业V2012” 查询出的 股票列表 和 2020年4季度上市公司行业分类结果.pdf(CSRC网站下载)中的内容 不同！！(20210331)  
       如：000835 *ST长动  于  “”103010313	C25	石油加工、炼焦和核燃料加工业“(010301-证监会行业V2012)  和  “64 互联网和相关服务”(2020年4季度上市公司行业分类结果.pdf)  中 ；
"""
# Out:
#           secID  ticker exchangeCD secShortName       secFullName  partyID industryVersionCD    industry  industryID industrySymbol   ...   isNew industryID1  industryName1 industryID2  \
# 0   000059.XSHE  000059       XSHE         华锦股份    北方华锦化学工业股份有限公司       53            010301  证监会行业V2012  0103010313            C25   ...       1    01030103            制造业  0103010313
#