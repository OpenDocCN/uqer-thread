# %% [markdown]
# # 6.多元回归分析-机器学习入门

# %%
from numpy import genfromtxt
import numpy as np
from sklearn import datasets, linear_model

dataPath = r"deliveryDummy.csv"
deliveryData = genfromtxt(dataPath, delimiter=',')

print "data"
print deliveryData

X = deliveryData[:, :-1]
Y = deliveryData[:, -1]

print "X:"
print X
print "Y: "
print Y

regr = linear_model.LinearRegression()  #建立模型

regr.fit(X, Y)

print "coefficients"
print regr.coef_     #计算系数，b0,b1
print "intercept: "
print regr.intercept_   #计算截距b2

xPred = [102, 6]
yPred = regr.predict(xPred)
print "predicted y: "
print yPred
# Out:
# data
# [[ 100.     4.     0.     1.     0.     9.3]
#  [  50.     3.     1.     0.     0.     4.8]
#  [ 100.     4.     0.     1.     0.     8.9]
#  [ 100.     2.     0.     0.     1.     6.5]
#  [  50.     2.     0.     0.     1.     4.2]
#  [  80.     2.     0.     1.     0.     6.2]
#  [  75.     3.     0.     1.     0.     7.4]
#  [  65.     4.     1.     0.     0.     6. ]
#  [  90.     3.     1.     0.     0.     7.6]]
# X:
# [[ 100.    4.    0.    1.    0.]
#  [  50.    3.    1.    0.    0.]
#  [ 100.    4.    0.    1.    0.]
#  [ 100.    2.    0.    0.    1.]
#  [  50.    2.    0.    0.    1.]
#  [  80.    2.    0.    1.    0.]
#  [  75.    3.    0.    1.    0.]
#  [  65.    4.    1.    0.    0.]
#  [  90.    3.    1.    0.    0.]]
# Y:
# [ 9.3  4.8  8.9  6.5  4.2  6.2  7.4  6.   7.6]
# coefficients
# [ 0.05553544  0.69257631 -0.17013278  0.57040007 -0.40026729]
# intercept:
# 0.199956889119
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <mercury-input-26-96B78738223448639519F046E03A6088> in <module>()
#      27
#      28 xPred = [102, 6]
# ---> 29 yPred = regr.predict(xPred)
#      30 print "predicted y: "
#      31 print yPred
#
# /home/ipython/anaconda/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in predict(self, X)
#     198             Returns predicted values.
#     199         """
# --> 200         return self._decision_function(X)
#     201
#     202     _center_data = staticmethod(center_data)
#
# /home/ipython/anaconda/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in _decision_function(self, X)
#     183         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     184         return safe_sparse_dot(X, self.coef_.T,
# --> 185                                dense_output=True) + self.intercept_
#     186
#     187     def predict(self, X):
#
# /home/ipython/anaconda/lib/python2.7/site-packages/sklearn/utils/extmath.pyc in safe_sparse_dot(a, b, dense_output)
#     182         return ret
#     183     else:
# --> 184         return fast_dot(a, b)
#     185
#     186
#
# ValueError: shapes (1,2) and (5,) not aligned: 2 (dim 1) != 5 (dim 0)
