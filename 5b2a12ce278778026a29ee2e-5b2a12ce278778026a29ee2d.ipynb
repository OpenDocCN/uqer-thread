# %% [markdown]
# # 个股和指数的回归 简单版

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm 
b=DataAPI.MktIdxdGet(indexID=u"",ticker=u"000001",beginDate=u"20080101",endDate=u"20171231",exchangeCD=u"XSHE,XSHG",field=u"ticker,tradeDate,CHGPct",pandas="1")#指数日行情数据
a=DataAPI.MktEqudGet(secID=u"",ticker=u"000858",tradeDate=u"",beginDate=u"20080101",endDate=u"20171231",isOpen="",field=u"ticker,tradeDate,chgPct",pandas="1")#个股数据，以五粮液为例
y=a.chgPct
x=sm.add_constant(b.CHGPct)
res=sm.OLS(y,x).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 chgPct   R-squared:                       0.405
# Model:                            OLS   Adj. R-squared:                  0.405
# Method:                 Least Squares   F-statistic:                     1658.
# Date:                Wed, 20 Jun 2018   Prob (F-statistic):          7.78e-277
# Time:                        12:46:24   Log-Likelihood:                 6280.8
# No. Observations:                2434   AIC:                        -1.256e+04
# Df Residuals:                    2432   BIC:                        -1.255e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.0006      0.000      1.699      0.089     -9.74e-05     0.001
# CHGPct         0.9126      0.022     40.718      0.000         0.869     0.957
# ==============================================================================
# Omnibus:                      265.833   Durbin-Watson:                   1.865
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              838.823
# Skew:                           0.552   Prob(JB):                    7.11e-183
# Kurtosis:                       5.655   Cond. No.                         60.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
