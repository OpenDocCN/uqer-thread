# %% [markdown]
# # Notebook

# %%
data=DataAPI.SecSTGet(beginDate=u"20020101",endDate=u"20200725",secID=u"",ticker=u"600518",field=u"",pandas="1")

# %%
DataAPI.MktRepodGet(secID=u"",ticker=u"",tradeDate=u"20150513",beginDate=u"",endDate=u"",field=u"",pandas="1")
# Out:
#           secID  ticker secShortName exchangeCD   tradeDate  preCloseRate  \
# 0   131800.XSHE  131800        R-003       XSHE  2015-05-13        1.1000
# 1   131801.XSHE  131801        R-007       XSHE  2015-05-13        1.0100
# 2   131802.XSHE  131802        R-014       XSHE  2015-05-13        2.0510
# 3   131803.XSHE  131803        R-028       XSHE  2015-05-13        2.2110
# 4   131805.XSHE  131805        R-091       XSHE  2015-05-13        2.0100
# 5   131806.XSHE  131806        R-182       XSHE  2015-05-13        1.0100
# 6   131809.XSHE  131809        R-004       XSHE  2015-05-13        0.8050
# 7   131810.XSHE  131810        R-001       XSHE  2015-05-13        0.3050
# 8   131811.XSHE  131811        R-002       XSHE  2015-05-13        0.4000
# 9   202001.XSHG  202001        RC001       XSHG  2015-05-13        1.9750
# 10  202003.XSHG  202003        RC003       XSHG  2015-05-13        1.8000
# 11  202007.XSHG  202007        RC007       XSHG  2015-05-13        2.2000
# ...

# %%
DataAPI.EquGet(secID=u"OR001.XIBE",ticker=u"",equTypeCD=u"A",listStatusCD=u"",exchangeCD="",ListSectorCD=u"",field=u"",pandas="1")
# Out:
# Empty DataFrame
# Columns: [secID, ticker, exchangeCD, ListSectorCD, ListSector, transCurrCD, secShortName, secFullName, listStatusCD, listDate, delistDate, equTypeCD, equType, exCountryCD, partyID, totalShares, nonrestFloatShares, nonrestfloatA, officeAddr, primeOperating, endDate, TShEquity]
# Index: []
#
# [0 rows x 22 columns]

# %%
import numpy as np
import pandas as pd
from CAL.PyCAL import *
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import matplotlib as mpl

stk = u"002572"

aa = DataAPI.MktStockFactorsDateRangeGet(secID=u"",ticker=stk,beginDate=u"20000101",endDate=u"",field=u"tradeDate,NetProfitGrowRate,NPParentCompanyGrowRate",pandas="1")
aa.columns = [u"日期",u"净利润增长率",u"归属母公司股东净利增长率"]
bb = aa.dropna()
bb = bb.set_index(u"日期")

fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(111)
ax = bb.plot(ax=ax)

labels = [label.decode("utf-8") for label in bb.index.values]
ax.set_xticklabels(labels, fontproperties=font, fontsize=15)
ax.legend(prop=font)
ax.set_title(stk + u'历史净利增长率', fontproperties=font, fontsize=15)
ax.set_xlabel(u'日期', fontproperties=font, fontsize=15)

# %%
DataAPI.MktLimitGet(secID=u"",ticker=u"000001",tradeDate=u"",exchangeCD=u"",beginDate=u"",endDate=u"",field=u"",pandas="1")
# Out:
#             secID  ticker secShortName secShortNameEn exchangeCD   tradeDate  \
# 0     000001.XSHE  000001         平安银行            PAB       XSHE  2007-01-04
# 1     000001.XSHE  000001         平安银行            PAB       XSHE  2007-01-05
# 2     000001.XSHE  000001         平安银行            PAB       XSHE  2007-01-08
# 3     000001.XSHE  000001         平安银行            PAB       XSHE  2007-01-09
# 4     000001.XSHE  000001         平安银行            PAB       XSHE  2007-01-10
# 5     000001.XSHE  000001         平安银行            PAB       XSHE  2007-01-11
# 6     000001.XSHE  000001         平安银行            PAB       XSHE  2007-01-12
# 7     000001.XSHE  000001         平安银行            PAB       XSHE  2007-01-15
# 8     000001.XSHE  000001         平安银行            PAB       XSHE  2007-01-16
# 9     000001.XSHE  000001         平安银行            PAB       XSHE  2007-01-17
# 10    000001.XSHE  000001         平安银行            PAB       XSHE  2007-01-18
# ...

# %%
data=DataAPI.MktLimitGet(secID=u"",ticker=u"000001",tradeDate=u"",exchangeCD=u"",beginDate=u"",endDate=u"",field=u"",pandas="1")
data.to_csv('baitian/baitian.csv')
