# %% [markdown]
# # Close price(HK&CN)

# %%
df = DataAPI.MktEqudGet(tradeDate=u"20170804",secID=u"",ticker=u"000001,601288,600036,000001,600000,601939,601166,601398,601988,601998,601328,601818,600016,601009,600015,002142",beginDate=u"",endDate=u"",field=u"",pandas="1")

# %%
df1 = DataAPI.MktHKEqudGet(tradeDate=u"20170804",secID=u"",ticker=u"03618,03968,00939,01398,01288,03988,00998,03328,06818,01988",beginDate=u"",endDate=u"",field=u"",pandas="1")

# %%
df2 = DataAPI.MktStockFactorsOneDayGet(tradeDate=u"20170804",secID=u"",ticker=u"000001,601288,600036,000001,600000,601939,601166,601398,601988,601998,601328,601818,600016,601009,600015,002142,03618,03968,00939,01398,01288,03988,00998,03328,06818,01988",field=u"ticker,tradeDate,pe,eps",pandas="1")

# %%
df.to_csv("priceCN.csv",encoding="gbk")
df1.to_csv("priceHK.csv",encoding="gbk")
df2.to_csv("PECN.csv",encoding="gbk")
df
df1
df2
# Out:
#     ticker   tradeDate       PE   EPS
# 0   000001  2017-08-04   8.4390  0.31
# 1   600000  2017-08-04   6.7431  0.63
# 2   600015  2017-08-04   6.3772  0.34
# 3   600016  2017-08-04   6.4613  0.39
# 4   600036  2017-08-04  10.1025  0.79
# 5   601988  2017-08-04   7.2073  0.15
# 6   601398  2017-08-04   7.2361  0.21
# 7   601166  2017-08-04   6.6433  0.88
# 8   601998  2017-08-04   7.6062  0.23
# 9   601328  2017-08-04   7.1217  0.26
# 10  002142  2017-08-04   9.5298  0.60
# 11  601009  2017-08-04   7.7757  0.40
# 12  601939  2017-08-04   7.3444  0.28
# 13  601288  2017-08-04   6.6025  0.16
# 14  601818  2017-08-04   6.4206  0.18
