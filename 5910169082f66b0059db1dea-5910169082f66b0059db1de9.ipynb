# %% [markdown]
# # 事件驱动策略————“分析师评级之首次低位覆盖”

# %% [markdown]
# 本篇研究分析事件驱动策略————“分析师评级之首次低位覆盖”
# 本篇参考长江证券2017-04-27日发布的《分析师行为解析之低位首次覆盖》，研报数据来源于wind底层数据库，我也从Wind底层数据库中去提取的数据，但是获取的数据跟研报上的有出入，但是不影响按它的思路方法进行分析。下文概述部分引用该研报的阐述。

# %% [markdown]
#    行业分析师依靠平台优势，掌握行业动态处于市场前沿，同时具有较好的财务基础和专业判断能力，可将多重数据信息进行整合。其评级或者预测数据代表的是对该股票后市的预期，以及预期背后的一系列逻辑支撑。
# 首次覆盖构成事件型机会
#    长期无人问津股票开始被提及，代表当前时点分析师对公司未来的股价表现比较确定，这种信心往往基于较强的专业判断，分析师数据质量较高，基于首次覆盖这种行为，构成券商首次覆盖和全市场首次覆盖两种事件机会。

# %% [markdown]
#    分析师预期数据即常说到的证券研究行业分析师对公司估值、盈利方面所做的预测和公司评级，利用分析师数据也成为量化的一个思路，在无法获得或整理大面积数据的前提下，间接利用分析师数据是一个捷径，这类数据主要包括连续数据和离散数据两种类型。
#     连续数据基本是数值类数据，有盈利预测、估值一致预期等，基于数据的连续性，可构建一系列因子，在原有的多因子框架之上加入一些新的增量信息，目前比较典型的因子选股模型有盈利预测上调、一致预期因子等。
#     离散数据是指那些不易连续化的数据，只能在某些时间点得到分析师数据的0-1变量，包括是否推荐、评级类别等，一般这类信息的处理结果是事件驱动框架，目前典型的分析师事件有评级上调、行业分析师交叉覆盖等。
#     实际上，连续性数据和离散化数据均有自己的特点，前者虽然信息量多，但因为都是根据不同模型估算而出，冗杂信息干扰性也会比较强，而离散化数据一般都代表是否变量，分析师在考虑问题时会更为慎重，估计因素较少，故离散化数据代表的事件驱动也往往比较有效。
#    本报告则是根据分析师评级的离散化数据，来观察分析师推荐报告这种行为。以分析师推荐时间节点为突破点解析分析师行为，构建首次覆盖事件型机会，包括单个券商首次覆盖以及全市场首次覆盖两种类型。

# %% [markdown]
# 券商首次覆盖

# %% [markdown]
#    覆盖是指行业分析师对一只股票有关注，表现形式为对该公司有相关报告并提示评级，包括深度报告或者点评报告等，报告发布时点即该股票的覆盖时间。
#     市场上常说的首次覆盖是指一个券商研究所第一次对某个股票进行推荐，后续的报告均为跟踪报告。券商研究所人员流动性较大，可能之前有人关注，但在很长一段时间之后由新的团队来覆盖。考虑到这种情况，将券商研究所近期推荐等级为1而之前较长一段时间未被覆盖的股票称为券商首次覆盖股票，其中剔除新股、长期停牌股的干扰。
#     跟踪报告往往会基于时点数据对公司进行点评，一般不怎么关注报告发布的时点，旨在解读公司的近期行为或股价表现。而首次推荐报告则意义较为深重，券商第一次对一只股票进行推荐，往往是分析师对公司未来的股价表现比较有信心，而且也会更为慎重，因而首次覆盖传递出的分析师预期数据信息质量更高。这里导入的数据都是选择的券商首次评级事件。

# %% [markdown]
# 根据长江金工的分析，券商首次覆盖的收益不突出。第一该事件数量很多，而且月度调仓组合年化收益18.47%，超额基准4.22%。研报也分析了券商首次覆盖的收益之所以不突出，在于券商首次覆盖的信息比较冗杂，券商首次覆盖股票有可能是卖方市场跟风所致。在市场推票比较集中的情况下，小券商由于研究人员少，报告积累不多，其推荐的股票很容易成为券商首次推荐股票，即该事件自带小券商倾向，会存在信息偏离。因而这里不再讨论券商首次覆盖的事件机会，而是重点讨论全市场首次覆盖的情况。

# %% [markdown]
# 全市场首次覆盖

# %% [markdown]
#    全市场首次覆盖则是券商首次覆盖的加强版本，其基本定义为在相对较长的一段时间之内，全市场都没有券商分析师对该股票进行覆盖，但在近期有分析师撰写相关研报覆盖的股票标的。
#     同券商首次覆盖不同，全市场首次覆盖的本质在于寻找长时间无人关注近期又被提及的标的。前者针对每家券商，后者则是各个券商之间首次覆盖的交集。
#     对于全市场首次推荐而言，其逻辑主要有两点：反转可能和推荐质量。
#     反转可能：分析师推荐股票往往比较分散，一般来说很少有股票不被所有券商关注和提及，若长期无人问津，则代表公司可能在遭遇某些困境，引起股价下行，在较长一段时间内不存在值得被推荐的理由。而一旦突然被关注，则往往意味着该股票可能已经达到股价的低位或者触碰到比较大的市场热点，面临大幅反转的可能。
#     推荐质量：分析师推荐股票往往是一系列信息的整合，其推荐很长一段时间无人推荐的股票，占据股票推荐的全市场首位，本身就面临着多方的质疑和压力，而这也往往代表该分析师对股价未来的增长比较确信，而大预期一般基于专业判断，由此来看首次推荐的数据质量相对较高。

# %% [markdown]
# 先导入数据（数据导取自Wind底层数据库，后清洗整理截取其部分有用信息）

# %%
import seaborn
from matplotlib import pylab
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
from CAL.PyCAL import *    # CAL.PyCAL中包含font
from datetime import timedelta,datetime
import pandas as pd
from string import zfill
import quartz as qz
from CAL.PyCAL import *   


raw_df=pd.read_csv('data.csv',encoding='gbk')
##
raw_df['ticker'] = raw_df['ticker'].apply(str).apply(lambda x: zfill(x, 6))
raw_df['secID'] =raw_df['ticker'].map(lambda x: x + '.XSHG' if x[0] == '6' else x + '.XSHE')
##

raw_df_new=raw_df[raw_df['level']==1] 
raw_df_new=raw_df_new.reset_index(drop=True)

# %% [markdown]
# 先看全样本，即全部的券商首次覆盖事件

# %%
raw_df['year']=raw_df['date'].apply(lambda x:int(x[0:4]))

# %%
raw_df.head()
# Out:
#    ticker security  name        date  level        secID  year
# 0  000527     东海证券   刘俊'  2007-11-04      2  000527.XSHE  2007
# 1  002005     东海证券   刘俊'  2007-11-09      1  002005.XSHE  2007
# 2  000401     东海证券  缪亚美'  2007-11-12      1  000401.XSHE  2007
# 3  000651     东海证券   刘俊'  2007-11-13      1  000651.XSHE  2007
# 4  600410     东海证券   姚军'  2007-11-13      2  600410.XSHG  2007

# %%
sum_se = raw_df.groupby(raw_df['year']).size()
sum_security=raw_df.groupby(raw_df['security']).size()

# %%
sum_security.sort(ascending=False)

# %%
fig = plt.figure(figsize=(12, 6))
ax1 = fig.add_subplot(111)


rects=ax1.bar(sum_se.index, sum_se.values, color='r', width=0.5)
ax1.set_xticks(range(2007,2018))
ax1.set_xticklabels([int(x) for x in ax1.get_xticks()], fontproperties=font, fontsize=14)
ax1.set_title(u'历年分析师首次评级事件次数', fontproperties=font, fontsize=16)
def autolabel(rects):  #在图片中加入数量的统计
    for rect in rects:
        h = rect.get_height()
        ax1.text(rect.get_x()+rect.get_width()/2., 1.03*h, '%d'%int(h),
                ha='center', va='bottom')
autolabel(rects)
plt.show()

# %%
font.set_size(13)

# %%
fig = plt.figure(figsize=(50,5))
ax = fig.add_subplot(111)
ax = sum_security[0:50].plot(kind='bar',color='r')
ax.set_xticklabels(sum_security[0:50].index,rotation=0,fontproperties=font);
ax.set_ylabel(u'各券商分析师首次评级次数',fontproperties=font)
ax.set_title(u'各券商分析师首次评级次数',fontproperties=font)

# %%
pie=np.zeros(5)

df_1 = raw_df[raw_df['level']==1]  
df_2=raw_df[raw_df['level']==2]  
df_3 = raw_df[raw_df['level']==3]  
df_4=raw_df[raw_df['level']==4]  
df_5 = raw_df[raw_df['level']==5]
for i in range(1,6):
    pie[i-1]=(len(raw_df[raw_df['level']==i]))
sum_1 = df_1.groupby(df_1['year'])['ticker'].count()
sum_2 = df_2.groupby(df_2['year'])['ticker'].count()
sum_3 =df_3.groupby(df_3['year'])['ticker'].count()
sum_4 =df_4.groupby(df_4['year'])['ticker'].count()
sum_5 =df_5.groupby(df_5['year'])['ticker'].count()

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
ax=plt.pie(pie,labels=['1','2','3','4','5'],autopct='%1.2f%%')
plt.title(u'首次不同评级等级份额比例',fontproperties=font)

# %%
count_1 = df_1.groupby(df_1['year']).size()
count_2 = df_2.groupby(df_2['year']).size()
count_3 = df_3.groupby(df_3['year']).size()
count_4 = df_4.groupby(df_4['year']).size()
count_5 = df_5.groupby(df_5['year']).size()

for i  in count_1.index:
    if i  not in count_5.index:
        count_4[i]=0
for i  in count_1.index:
    if i  not in count_5.index:
        count_5[i]=0
ind =count_1.index
width = 0.2       # the width of the bars

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111)

rects1 = ax.bar(ind-2*width, count_1.values, width, color='r')
rects2 = ax.bar(ind-width, count_2.values, width, color='royalblue')
rects3 = ax.bar(ind, count_3.values, width, color='pink')
rects4 = ax.bar(ind+width, count_4.values, width, color='k')
rects5 = ax.bar(ind+2*width, count_5.values, width, color='orange')


ax.set_xticks(count_1.index)
ax.set_xticklabels( [int(x) for x in ax.get_xticks()], fontproperties=font, fontsize=14)
ax.set_title(u"各年首次评级事件数量统计", fontproperties=font, fontsize=16)
ax.legend( (rects1[0], rects2[0], rects3[0],rects4[0],rects5[0]) ,(u'评级1', u'评级2', u'评级3',u'评级4',u'评级5'), prop=font)
def autolabel(rects):  #在图片中加入数量的统计
    for rect in rects:
        h = rect.get_height()
        ax.text(rect.get_x()+rect.get_width()/2., 1.03*h, '%d'%int(h),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)

plt.show()

# %%
count_1 = df_1.groupby(df_1['year'])['secID'].nunique()
count_2 = df_2.groupby(df_2['year'])['secID'].nunique()
count_3 = df_3.groupby(df_3['year'])['secID'].nunique()
count_4 = df_4.groupby(df_4['year'])['secID'].nunique()
count_5 = df_5.groupby(df_5['year'])['secID'].nunique()

for i  in count_1.index:
    if i  not in count_5.index:
        count_4[i]=0
for i  in count_1.index:
    if i  not in count_5.index:
        count_5[i]=0
ind =count_1.index
width = 0.2       # the width of the bars

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111)

rects1 = ax.bar(ind-2*width, count_1.values, width, color='r')
rects2 = ax.bar(ind-width, count_2.values, width, color='royalblue')
rects3 = ax.bar(ind, count_3.values, width, color='pink')
rects4 = ax.bar(ind+width, count_4.values, width, color='k')
rects5 = ax.bar(ind+2*width, count_5.values, width, color='orange')


ax.set_xticks(count_1.index)
ax.set_xticklabels( [int(x) for x in ax.get_xticks()], fontproperties=font, fontsize=14)
ax.set_title(u"各年首次评级涉及股票数量统计", fontproperties=font, fontsize=16)
ax.legend( (rects1[0], rects2[0], rects3[0],rects4[0],rects5[0]) ,(u'评级1', u'评级2', u'评级3',u'评级4',u'评级5'), prop=font)
def autolabel(rects):  #在图片中加入数量的统计
    for rect in rects:
        h = rect.get_height()
        ax.text(rect.get_x()+rect.get_width()/2., 1.02*h, '%d'%int(h),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)

plt.show()

# %% [markdown]
# 可以看到历年首次评级为1的股票数量也不少，比如2016年数量为1614个，所以股票样本太大，这也是为什么下一步要优选半年以及更长时间首次覆盖的事件股票（即如果之前半年全部券商推荐为1的股票池子中没有该股票，则把该股票纳为全券商半年首次覆盖股票）作为进一步的分析样本

# %% [markdown]
# 评级为1的深入分析

# %% [markdown]
# 看一下评级为一的股票的行业分布（##申万一级分类）

# %%
industry=DataAPI.EquIndustryGet(industryVersionCD=u"010303",industry=u"",secID=list((raw_df_new.secID).unique()),ticker=u"",intoDate=u"",field=u"",pandas="1")

# %%
industry_now=industry[industry['isNew']==1]

# %%
sum_industry=industry_now.groupby(industry_now['industryName1']).size()
sum_industry.sort(ascending=False)

# %%
sum_industry.index = [x.decode('utf8') for x in sum_industry.index]

# %%
fig = plt.figure(figsize=(30,5))
ax = fig.add_subplot(111)
ax = sum_industry.plot(kind='bar',color='r')
ax.set_xticklabels(sum_industry.index,rotation=0,fontproperties=font)
ax.set_ylabel(u'各券商分析师首次评级行业分布情况',fontproperties=font)
ax.set_title(u'各券商分析师首次评级行业分布情况',fontproperties=font)

# %% [markdown]
# 可见，机械、化工、医药、IT类等行业内股票被评级为1的次数相对较多，而钢铁、综合、银行等则相反

# %%
raw_df_new['is_first']=np.zeros(len(raw_df_new))

# %%
def is_first(time):
    for i in range(11,len(raw_df_new)):   ##第11个开始,09年5月份前的样本太少，07年11月份到09年5月份才只有10个样本，予以剔除
        this_stock=raw_df_new.ix[i,'secID']
        this_day=raw_df_new.ix[i,'date']       
        half_year_early_date= Calendar('China.SSE').advanceDate(this_day,Period(str(time)+str('B'))).strftime("%Y-%m-%d")
        secID_list=list(raw_df_new[(raw_df_new['date']>=half_year_early_date)&(raw_df_new['date']<this_day)]['secID'])
        
        if this_stock not in secID_list:
             raw_df_new.ix[i,'is_first']=1

# %% [markdown]
# 全部券商首次覆盖（时间范围选为半年，即大概为252/2个交易日，约126个交易日）

# %%
is_first(-126)

# %% [markdown]
# 筛选出全部券商中的首次覆盖

# %%
raw_df_new_new=raw_df_new[raw_df_new['is_first']==1].reset_index(drop=True)

# %% [markdown]
# 看一下，是评级为1的全券商首次覆盖的比例

# %%
float(len(raw_df_new_new))/float(len(raw_df_new))
# Out:
# 0.47873002697655115

# %% [markdown]
# 可见约一半的是全券商半年首次覆盖

# %% [markdown]
# 下一步，标记是否为ST，以及是否为新股或者次新股

# %%
raw_df_new_new['is_ST']=np.zeros(len(raw_df_new_new))
raw_df_new_new['is_new']=np.zeros(len(raw_df_new_new))

# %%
for i in range(len(raw_df_new_new)):
    stockset_STflg = DataAPI.SecSTGet(beginDate=datetime.strptime(raw_df_new_new.ix[i,'date'],'%Y-%m-%d'),endDate=datetime.strptime(raw_df_new_new.ix[i,'date'],'%Y-%m-%d'),ticker=u'', field=u"secID",pandas="1")
    stockset_STflg_list=list(stockset_STflg)
    if raw_df_new_new.ix[i,'secID']  in  stockset_STflg_list:
        raw_df_new_new.ix[i,'is_ST']=1

# %%
raw_df_new_new.is_ST.describe()
# Out:
# count    6921.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: is_ST, dtype: float64

# %% [markdown]
# 可见，券商首次推荐等级为1的股票中没有ST类股！

# %% [markdown]
# 在判断是否为新股或者次新股这里，时间的选择是评级日前360个自然日还没上市的就归为'is_new'=1

# %%
for i in range(len(raw_df_new_new)):
    
    stock_listDate = DataAPI.SecIDGet(ticker=raw_df_new_new.ix[i,0],assetClass='E',field=u"listDate",pandas="1")      
    if (datetime.strptime(stock_listDate.ix[0,0],'%Y-%m-%d')+timedelta(days=360)).strftime('%Y-%m-%d')>=raw_df_new_new.ix[i,'date']:
        raw_df_new_new.ix[i,'is_new']=1

# %%
len(raw_df_new_new[raw_df_new_new['is_new']==1])
# Out:
# 875

# %% [markdown]
# 875个新股或者次新股

# %% [markdown]
# 再下一步，去掉ST类以及新股

# %%
raw_df_new_new_new=raw_df_new_new[(raw_df_new_new['is_ST']!=1)&(raw_df_new_new['is_new']!=1)].reset_index(drop=True)

# %% [markdown]
# 这里，新命名一列为‘月涨跌幅’，以观察推荐日前一个月（大概20个交易日）该股票价格涨跌幅

# %%
raw_df_new_new_new['month_pct_change']=np.zeros(len(raw_df_new_new_new))

# %%
for i in range(len(raw_df_new_new_new)):
    this_day=raw_df_new_new_new.ix[i,'date']
    stock_month_early_closeprice = DataAPI.MktEqudGet(tradeDate=Calendar('China.SSE').advanceDate(this_day,Period(str(-21)+str('B'))).strftime("%Y%m%d"),secID=raw_df_new_new_new.ix[i,'secID'],field=u"closePrice",pandas="1")
    stock_this_day_closeprice = DataAPI.MktEqudGet(tradeDate=Calendar('China.SSE').advanceDate(this_day,Period(str(-1)+str('B'))).strftime("%Y%m%d"),secID=raw_df_new_new_new.ix[i,'secID'],field=u"closePrice",pandas="1")
    
    raw_df_new_new_new.ix[i,'month_pct_change']=(stock_this_day_closeprice.ix[0,0]-stock_month_early_closeprice.ix[0,0])/stock_month_early_closeprice.ix[0,0]

# %% [markdown]
# 再下一步，评级日以及评级日前半年累计停牌时间超过3个月的去除

# %%
raw_df_new_new_new['is_tingpai']=np.zeros(len(raw_df_new_new_new))
for i in range(len(raw_df_new_new_new)):
    this_day=raw_df_new_new_new.ix[i,'date']
    stock_monthly_isopen_series = DataAPI.MktEqudGet(beginDate=Calendar('China.SSE').advanceDate(this_day,Period(str(-127)+str('B'))).strftime("%Y%m%d"),endDate=Calendar('China.SSE').advanceDate(this_day,Period(str(-1)+str('B'))).strftime("%Y%m%d"),secID=raw_df_new_new_new.ix[i,'secID'],field=u"isOpen",pandas="1")
    if  stock_monthly_isopen_series.ix[len(stock_monthly_isopen_series)-1,'isOpen']==0 and float(len(stock_monthly_isopen_series[stock_monthly_isopen_series['isOpen']==0]))/float(len(stock_monthly_isopen_series))>=0.5:
    
        raw_df_new_new_new.ix[i,'is_tingpai']=1

# %%
len(raw_df_new_new_new[raw_df_new_new_new['is_tingpai']==1])
# Out:
# 173

# %%
raw_df_new_new_new=raw_df_new_new_new[raw_df_new_new_new['is_tingpai']!=1].reset_index(drop=True)

# %%
raw_df_new_new_new.to_csv('raw_df_new_new_new.csv',encoding='gbk')

# %% [markdown]
# 生成的文件保存为raw_df_new_new_new.csv，重新开启notebook,可以直接调用这个文件，不需要跑前面的代码

# %%
import pandas as pd

# %%
raw_df_new_new_new=pd.read_csv('raw_df_new_new_new.csv',encoding='gbk')

# %% [markdown]
# 下面，构建该事件指数（等权）,每月月初调仓，卖出股票池股票，同时买入上月发生的事件股票

# %%
import seaborn
from matplotlib import pylab
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
from CAL.PyCAL import *    # CAL.PyCAL中包含font
from datetime import timedelta,datetime
import pandas as pd
from string import zfill
import quartz as qz

# %% [raw]
# start = '2009-06-01'                       # 回测起始时间,大约事件首个交易日
# end = '2017-05-02'                         # 回测结束时间
# benchmark = 'ZZ500' # 策略参考标准,中证500
#
# universe =  DynamicUniverse('A')  # 证券池，支持股票和基金
# capital_base = 10000000                     # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# commission = Commission(buycost=0.0000, sellcost=0.0000)
#
# def initialize(account):                   # 初始化虚拟账户状态
#         account.day_counter = {}  #用于记录持仓天数
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#         if account.current_date.month!=account.previous_date.month:
#
#
#     ##需买进
#             univ_df = raw_df_new_new_new[(raw_df_new_new_new['t_plus_1']<=account.current_date.strftime('%Y-%m-%d'))&(raw_df_new_new_new['t_plus_1']>=datetime(account.previous_date.year,account.previous_date.month,1).strftime('%Y-%m-%d'))]
#
#             for stk in account.security_position.keys():
#
#                      order_to(stk,0)
#
#
#
#
#
#             if len(univ_df )>0: # 上月有事件发生
#                 univ = univ_df ['secID'].tolist()
#                 univ = list(univ)  # 已经持有的股票不再重新下单
#                 need_buy_stock_number=len(univ)##需要新进买入股票的数量
#                 number=need_buy_stock_number
#
#
#                 for stk in univ:
#                     order_pct_to(stk,1.0/number)

# %%
fig = plt.figure(figsize=(12,10))
fig.set_tight_layout(True)
ax1 = fig.add_subplot(211)
ax2 = ax1.twinx()
ax1.grid()
data = bt[[u'tradeDate',u'portfolio_value',u'benchmark_return']]
data['portfolio_return'] = data.portfolio_value/data.portfolio_value.shift(1) - 1.0
data['portfolio_return'].ix[0] = data['portfolio_value'].ix[0]/	10000000.0 - 1.0
data['excess_return'] = data.portfolio_return - data.benchmark_return
data['excess'] = data.excess_return + 1.0
data['excess'] = data.excess.cumprod()
data['portfolio'] = data.portfolio_return + 1.0
data['portfolio'] = data.portfolio.cumprod()
data['benchmark'] = data.benchmark_return + 1.0
data['benchmark'] = data.benchmark.cumprod()
data['excess_back']=([1 - v/max(1, max(data['excess'][:i+1])) for i,v in enumerate(data['excess'])])
#
# ax.plot(data[['portfolio','benchmark','excess']], label=str(qt))
ax1.plot(data['tradeDate'], data['portfolio'], label='portfolio(left)')
ax1.plot(data['tradeDate'], data['benchmark'], label='benchmark(left)')
ax2.plot(data['tradeDate'], data['excess'], label='hedged(right)', color='r')

ax1.legend(loc=2)
ax2.legend(loc=0)
ax2.set_ylim(bottom=0.5, top=2.5)
ax1.set_ylabel(u"全券商分析师评级首次覆盖指数净值", fontproperties=font, fontsize=16)
ax2.set_ylabel(u"对冲指数净值", fontproperties=font, fontsize=16)
ax2.set_ylabel(u"对冲指数净值", fontproperties=font, fontsize=16)
ax1.set_title(u"全券商分析师评级首次覆盖", fontproperties=font, fontsize=16)
ax3 = fig.add_subplot(212)
ax3.plot(data['tradeDate'], data['excess_back'], label='excess_back',color='r')
ax3.legend(loc=2)

ax3.set_ylabel(u"超额净值回撤", fontproperties=font, fontsize=16)
ax3.set_title(u"全券商分析师评级首次覆盖指数超额净值回撤情况", fontproperties=font, fontsize=16)

# %%
bt_analysis = {}
bt_analysis['annualized_return'] = perf['annualized_return']
bt_analysis['volatility'] = perf['volatility']
bt_analysis['max_drawdown'] = perf['max_drawdown']
bt_analysis['alpha'] = perf['alpha']
bt_analysis['beta'] = perf['beta']
bt_analysis['sharpe'] = perf['sharpe']
bt_analysis['information_ratio'] = perf['information_ratio']
data = bt[[u'tradeDate',u'portfolio_value',u'benchmark_return']]
data['portfolio_return'] = data.portfolio_value/data.portfolio_value.shift(1) - 1.0   # 总头寸每日回报率
data['portfolio_return'].ix[0] = data['portfolio_value'].ix[0]/    10000000.0 - 1.0
data['excess_return'] = data.portfolio_return - data.benchmark_return                 # 总头寸每日超额回报率
data['excess'] = data.excess_return + 1.0
data['excess'] = data.excess.cumprod()                # 总头寸对冲指数后的净值序列
data['portfolio'] = data.portfolio_return + 1.0
data['portfolio'] = data.portfolio.cumprod()          # 总头寸不对冲时的净值序列
data['benchmark'] = data.benchmark_return + 1.0
data['benchmark'] = data.benchmark.cumprod()          # benchmark的净值序列
bt_analysis['hedged_max_drawdown'] = max([1 - v/max(1, max(data['excess'][:i+1])) for i,v in enumerate(data['excess'])])  # 对冲后净值最大回撤
bt_analysis['hedged_volatility'] = np.std(data['excess_return'])*np.sqrt(252)
bt_analysis['hedged_annualized_return'] = (data['excess'].values[-1])**(252.0/len(data['excess'])) - 1.0

import pandas
results_pd = pandas.DataFrame(bt_analysis, index=[u'事件指数效益'])

results_pd = results_pd[[u'alpha', u'beta', u'information_ratio', u'sharpe',
                        u'annualized_return', u'max_drawdown', u'volatility',
                         u'hedged_annualized_return', u'hedged_max_drawdown', u'hedged_volatility']]

for col in results_pd.columns:
    results_pd[col] = [np.round(x, 3) for x in results_pd[col]]

cols = [(u'风险指标', u'Alpha'), (u'风险指标', u'Beta'), (u'风险指标', u'信息比率'), (u'风险指标', u'夏普比率'),
        (u'纯股票多头时', u'年化收益'), (u'纯股票多头时', u'最大回撤'), (u'纯股票多头时', u'收益波动率'),
        (u'对冲后', u'年化收益'), (u'对冲后', u'最大回撤'),
        (u'对冲后', u'收益波动率')]
results_pd.columns = pd.MultiIndex.from_tuples(cols)
results_pd
# Out:
#          风险指标                      纯股票多头时                  对冲后
#         Alpha   Beta   信息比率   夏普比率   年化收益   最大回撤  收益波动率   年化收益   最大回撤  收益波动率
# 事件指数效益  0.134  0.947  1.451  0.658  0.218  0.522  0.283  0.116  0.127  0.078

# %%
def plot_return(bt, title):
    bt['portfolio_return'] = bt['portfolio_value']/bt['portfolio_value'].shift(1) - 1.0
    bt['excess_return'] = bt.portfolio_return - bt.benchmark_return                 # 总头寸每日超额回报率
    bt['excess'] = bt.excess_return + 1.0
    bt['excess'] = bt.excess.cumprod()                # 总头寸对冲指数后的净值序列
    month_date = [bt.ix[0, 0].date()]
    portfolio_value = [bt.ix[0, 'portfolio_value']]
    portfolio_excess= [bt.ix[0, 'excess']]
    for i in range(len(bt)-1):
        if bt.ix[i+1, 0].month != month_date[-1].month:
            month_date.append(bt.ix[i+1, 0].date())
            portfolio_value.append(bt.ix[i+1, 'portfolio_value'])
            portfolio_excess.append(bt.ix[i+1, 'excess'])
    results = pd.DataFrame(data=portfolio_value, columns=['portfolio_value'])
    results['monthly_return'] = results['portfolio_value']/results['portfolio_value'].shift(1)-1
    results['cumulative_return'] = portfolio_excess
    results['monthly_return_1'] = results['cumulative_return']/results['cumulative_return'].shift(1)-1
    results.index = month_date
    results.dropna(inplace=True)
    
    fig = plt.figure(figsize=(14, 10))
    ax1 = fig.add_subplot(211)
    ax2 = ax1.twinx()
    lns2 = ax1.plot(results.index, results['cumulative_return'], 'r')
    lns1 = ax2.bar(results.index, results['monthly_return_1'], align='center', width=10, color='b')
    ax2.legend(lns1, ['excess monthly return(right axis)'], loc=1, fontsize=12)
    ax1.legend(lns2, ['excess return(left axis)'], loc=2, fontsize=12)
    ax1.set_ylabel(u'组合净值/基准净值', fontproperties=font, fontsize=16)
    ax2.set_ylabel(u'超额月度收益率', fontproperties=font, fontsize=16)
    ax1.set_xlabel(u'时间', fontproperties=font, fontsize=16)
    ax2.set_yticklabels([str(x*100)+'0%' for x in ax2.get_yticks()], fontproperties=font, fontsize=14)
    s = ax1.set_title(title, fontproperties=font, fontsize=16)
    f1=float(len(results[results['monthly_return_1']>0]))/float(len(results))
    f2=float(len(results[results['monthly_return']>0]))/float(len(results))
    ax1.text(datetime(2016,01,05),1.1,u'超额月度胜率:%0.2f'%f1,fontproperties=font,fontsize=16)
    ax1.text(datetime(2016,01,05),1.3,u'绝对月度胜率:%0.2f'%f2,fontproperties=font,fontsize=16)
  
    return ax1, ax2
    

s = plot_return(bt, u'事件指数月度表现')

# %% [markdown]
# 设置不同的首次覆盖的时间，分别是半年、一年、一年半、两年，观察效果

# %%
import seaborn
from matplotlib import pylab
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
from CAL.PyCAL import *    # CAL.PyCAL中包含font
from datetime import timedelta,datetime
import pandas as pd
from string import zfill
import quartz as qz
from CAL.PyCAL import *

# %%
def is_first_yearly():
    for i in range(len(raw_df_new_new_new)):   ##第11个开始,09年5月份前的样本太少，07年11月份到09年5月份才只有10个样本，予以剔除
        this_stock=raw_df_new_new_new.ix[i,'secID']
        this_day=raw_df_new_new_new.ix[i,'date']       
        year_early_date= Calendar('China.SSE').advanceDate(this_day,Period(str(-252)+str('B'))).strftime("%Y-%m-%d")
        secID_list=list(raw_df_new_new_new[(raw_df_new_new_new['date']>=year_early_date)&(raw_df_new_new_new['date']<this_day)]['secID'])
        
        if this_stock not in secID_list:
             raw_df_new_new_new.ix[i,'is_first_yearly']=1
def is_first_onehalf_yearly():
    for i in range(len(raw_df_new_new_new)):   ##第11个开始,09年5月份前的样本太少，07年11月份到09年5月份才只有10个样本，予以剔除
        this_stock=raw_df_new_new_new.ix[i,'secID']
        this_day=raw_df_new_new_new.ix[i,'date']       
        onehalf_yearly_early= Calendar('China.SSE').advanceDate(this_day,Period(str(-378)+str('B'))).strftime("%Y-%m-%d")
        secID_list=list(raw_df_new_new_new[(raw_df_new_new_new['date']>=onehalf_yearly_early)&(raw_df_new_new_new['date']<this_day)]['secID'])
        
        if this_stock not in secID_list:
             raw_df_new_new_new.ix[i,'is_first_onehalf_yearly']=1  
def is_first_two_yearly():
    for i in range(len(raw_df_new_new_new)):  
        this_stock=raw_df_new_new_new.ix[i,'secID']
        this_day=raw_df_new_new_new.ix[i,'date']       
        two_yearly_early= Calendar('China.SSE').advanceDate(this_day,Period(str(-504)+str('B'))).strftime("%Y-%m-%d")
        secID_list=list(raw_df_new_new_new[(raw_df_new_new_new['date']>=two_yearly_early)&(raw_df_new_new_new['date']<this_day)]['secID'])
        
        if this_stock not in secID_list:
             raw_df_new_new_new.ix[i,'is_first_two_yearly']=1

# %%
is_first_yearly()
is_first_onehalf_yearly()
is_first_two_yearly()

# %%
raw_df_new_new_new.head()
# Out:
#    Unnamed: 0  ticker security  name        date  level        secID  \
# 0           0     895     中原证券   刘冉'  2009-05-08      1  000895.XSHE
# 1           1    2143     中原证券   刘冉'  2009-05-08      1  002143.XSHE
# 2           2    2201     中信建投  田东红'  2009-05-24      1  002201.XSHE
# 3           3  600327     东方证券   王佳'  2009-05-25      1  600327.XSHG
# 4           4     157     中原证券  路永光'  2009-05-25      1  000157.XSHE
#
#    is_first  is_ST  is_new  month_pct_change  is_tingpai    t_plus_1  \
# 0       1.0    0.0     0.0          0.034873         0.0  2009-05-11
# 1       1.0    0.0     0.0          0.084052         0.0  2009-05-11
# 2       1.0    0.0     0.0          0.092437         0.0  2009-05-25
# 3       1.0    0.0     0.0          0.050995         0.0  2009-05-26
# 4       1.0    0.0     0.0         -0.010289         0.0  2009-05-26
#
#    is_first_yearly  is_first_onehalf_yearly  is_first_two_yearly
# 0              1.0                      1.0                  1.0
# ...

# %%
raw_df_new_new_new.to_csv('raw_df_new_new_new.csv',encoding='gbk')

# %% [markdown]
# 生成的文件保存为raw_df_new_new_new.csv，重新开启notebook,可以直接调用这个文件，不需要跑前面的代码

# %%
import pandas as pd
raw_df_new_new_new=pd.read_csv('raw_df_new_new_new.csv',encoding='gbk')

# %%
import seaborn
from matplotlib import pylab
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
from CAL.PyCAL import *    # CAL.PyCAL中包含font
from datetime import timedelta,datetime
import pandas as pd
from string import zfill
import quartz as qz
from CAL.PyCAL import *

# %%
raw_df_new_new_new.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ticker security  name        date  level  \
# 0           0             0     895     中原证券   刘冉'  2009-05-08      1
# 1           1             1    2143     中原证券   刘冉'  2009-05-08      1
# 2           2             2    2201     中信建投  田东红'  2009-05-24      1
# 3           3             3  600327     东方证券   王佳'  2009-05-25      1
# 4           4             4     157     中原证券  路永光'  2009-05-25      1
#
#          secID  is_first  is_ST  is_new  month_pct_change  is_tingpai  \
# 0  000895.XSHE       1.0    0.0     0.0          0.034873         0.0
# 1  002143.XSHE       1.0    0.0     0.0          0.084052         0.0
# 2  002201.XSHE       1.0    0.0     0.0          0.092437         0.0
# 3  600327.XSHG       1.0    0.0     0.0          0.050995         0.0
# 4  000157.XSHE       1.0    0.0     0.0         -0.010289         0.0
#
#      t_plus_1  is_first_yearly  is_first_onehalf_yearly  is_first_two_yearly
# ...

# %%
def backtese(i):
    data=raw_df_new_new_new[raw_df_new_new_new.ix[:,i]==1]
    start = '2009-06-01'                       # 回测起始时间,大约事件首个交易日
    end = '2017-05-02'                         # 回测结束时间
    benchmark = 'ZZ500' # 策略参考标准,中证500
    
    universe =  DynamicUniverse('A')  # 证券池，支持股票和基金
    capital_base = 10000000                     # 起始资金
    freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
    refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
    commission = Commission(buycost=0.0000, sellcost=0.0000)

    def initialize(account):                   # 初始化虚拟账户状态
        account.day_counter = {}  #用于记录持仓天数

    def handle_data(account):                  # 每个交易日的买入卖出指令
        if account.current_date.month!=account.previous_date.month:
            
            univ_df = data[(data['t_plus_1']<=account.current_date.strftime('%Y-%m-%d'))&(data['t_plus_1']>=datetime(account.previous_date.year,account.previous_date.month,1).strftime('%Y-%m-%d'))]
     
            for stk in account.security_position.keys():
               
                     order_to(stk,0)
            if len(univ_df )>0: # 上月有事件发生
                univ = univ_df ['secID'].tolist()      
                univ = list(univ)  # 已经持有的股票不再重新下单
                need_buy_stock_number=len(univ)##需要新进买入股票的数量
                number=need_buy_stock_number
                for stk in univ:
                    order_pct_to(stk,1.0/number)
    bt, perf = qz.backtest(universe=universe, start=start, end=end,
                                initialize=initialize, handle_data=handle_data,
                                capital_base=capital_base, refresh_rate=refresh_rate,
                                freq=freq)           
    return bt,perf

# %%
z1=backtese(8)
z2=backtese(14)
z3=backtese(15)
z4=backtese(16)
# Out:
# No valid reference price of 600087.XSHG at 2009-08-03! It might be a newly-issued security. This order is ignored.
# No valid reference price of 600263.XSHG at 2009-09-01! It might be a newly-issued security. This order is ignored.
# No valid reference price of 600832.XSHG at 2009-09-01! It might be a newly-issued security. This order is ignored.
# No valid reference price of 000522.XSHE at 2009-11-02! It might be a newly-issued security. This order is ignored.
# No valid reference price of 600253.XSHG at 2009-12-01! It might be a newly-issued security. This order is ignored.
# No valid reference price of 600253.XSHG at 2010-01-04! It might be a newly-issued security. This order is ignored.
# No valid reference price of 000602.XSHE at 2010-02-01! It might be a newly-issued security. This order is ignored.
# No valid reference price of 000024.XSHE at 2010-04-01! It might be a newly-issued security. This order is ignored.
# ...

# %%
results={}
tmp1 = {}
tmp1['bt'] = z1[0]
tmp1['annualized_return'] = z1[1]['annualized_return']
tmp1['volatility'] = z1[1]['volatility']
tmp1['max_drawdown'] = z1[1]['max_drawdown']
tmp1['alpha'] = z1[1]['alpha']
tmp1['beta'] = z1[1]['beta']
tmp1['sharpe'] = z1[1]['sharpe']
tmp1['information_ratio'] = z1[1]['information_ratio']
results[0] = tmp1
#
tmp2 = {}
tmp2['bt'] = z2[0]
tmp2['annualized_return'] = z2[1]['annualized_return']
tmp2['volatility'] = z2[1]['volatility']
tmp2['max_drawdown'] = z2[1]['max_drawdown']
tmp2['alpha'] = z2[1]['alpha']
tmp2['beta'] = z2[1]['beta']
tmp2['sharpe'] = z2[1]['sharpe']
tmp2['information_ratio'] = z2[1]['information_ratio']
results[1] = tmp2
#
tmp3 = {}
tmp3['bt'] = z3[0]
tmp3['annualized_return'] = z3[1]['annualized_return']
tmp3['volatility'] = z3[1]['volatility']
tmp3['max_drawdown'] = z3[1]['max_drawdown']
tmp3['alpha'] = z3[1]['alpha']
tmp3['beta'] = z3[1]['beta']
tmp3['sharpe'] = z3[1]['sharpe']
tmp3['information_ratio'] = z3[1]['information_ratio']
results[2] = tmp3
#
tmp4 = {}
tmp4['bt'] = z4[0]
tmp4['annualized_return'] = z4[1]['annualized_return']
tmp4['volatility'] = z4[1]['volatility']
tmp4['max_drawdown'] = z4[1]['max_drawdown']
tmp4['alpha'] = z4[1]['alpha']
tmp4['beta'] = z4[1]['beta']
tmp4['sharpe'] = z4[1]['sharpe']
tmp4['information_ratio'] = z4[1]['information_ratio']
results[3] = tmp4

# %%
fig = plt.figure(figsize=(10,8))
fig.set_tight_layout(True)
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)
ax1.grid()
ax2.grid()

for qt in results:
    bt = results[qt]['bt']
    data = bt[[u'tradeDate',u'portfolio_value',u'benchmark_return']]
    data['portfolio_return'] = data.portfolio_value/data.portfolio_value.shift(1) - 1.0   # 总头寸每日回报率
    data['portfolio_return'].ix[0] = data['portfolio_value'].ix[0]/	10000000.0 - 1.0
    data['excess_return'] = data.portfolio_return - data.benchmark_return                 # 总头寸每日超额回报率
    data['excess'] = data.excess_return + 1.0
    data['excess'] = data.excess.cumprod()                # 总头寸对冲指数后的净值序列
    data['portfolio'] = data.portfolio_return + 1.0     
    data['portfolio'] = data.portfolio.cumprod()          # 总头寸不对冲时的净值序列
    data['benchmark'] = data.benchmark_return + 1.0
    data['benchmark'] = data.benchmark.cumprod()          # benchmark的净值序列
    results[qt]['hedged_max_drawdown'] = max([1 - v/max(1, max(data['excess'][:i+1])) for i,v in enumerate(data['excess'])])  # 对冲后净值最大回撤
    results[qt]['hedged_volatility'] = np.std(data['excess_return'])*np.sqrt(252)
    results[qt]['hedged_annualized_return'] = (data['excess'].values[-1])**(252.0/len(data['excess'])) - 1.0
    
    # data[['portfolio','benchmark','excess']].plot(figsize=(12,8))
    # ax.plot(data[['portfolio','benchmark','excess']], label=str(qt))
    ax1.plot(data['tradeDate'], data[['portfolio']], label=str(qt))
    ax2.plot(data['tradeDate'], data[['excess']], label=str(qt))
    

ax1.legend(loc=0)
ax2.legend(loc=0)
ax1.set_ylabel(u"净值", fontproperties=font, fontsize=16)
ax2.set_ylabel(u"对冲净值", fontproperties=font, fontsize=16)
ax1.set_title(u"不同覆盖时间净值走势", fontproperties=font, fontsize=16)
ax2.set_title(u"不同覆盖时间对冲中证500指数后净值走势", fontproperties=font, fontsize=16)

# results 转换为 DataFrame
import pandas
results_pd = pandas.DataFrame(results).T.sort_index()

results_pd = results_pd[[u'alpha', u'beta', u'information_ratio', u'sharpe', 
                        u'annualized_return', u'max_drawdown', u'volatility', 
                         u'hedged_annualized_return', u'hedged_max_drawdown', u'hedged_volatility']]

for col in results_pd.columns:
    results_pd[col] = [np.round(x, 3) for x in results_pd[col]]
    
cols = [(u'风险指标', u'Alpha'), (u'风险指标', u'Beta'), (u'风险指标', u'信息比率'), (u'风险指标', u'夏普比率'),
        (u'纯股票多头时', u'年化收益'), (u'纯股票多头时', u'最大回撤'), (u'纯股票多头时', u'收益波动率'), 
        (u'对冲后', u'年化收益'), (u'对冲后', u'最大回撤'), 
        (u'对冲后', u'收益波动率')]
results_pd.columns = pd.MultiIndex.from_tuples(cols)
results_pd.index.name = u'4个覆盖时间'
results_pd
# Out:
#          风险指标                      纯股票多头时                  对冲后
#         Alpha   Beta   信息比率   夏普比率   年化收益   最大回撤  收益波动率   年化收益   最大回撤  收益波动率
# 4个覆盖时间
# 0       0.149  0.906  0.849  0.516  0.177  0.525  0.283  0.139  0.351  0.170
# 1       0.154  0.912  0.864  0.528  0.183  0.525  0.286  0.145  0.351  0.173
# 2       0.158  0.908  0.874  0.542  0.187  0.532  0.286  0.149  0.351  0.175
# 3       0.179  0.900  0.960  0.616  0.208  0.523  0.287  0.169  0.344  0.178

# %% [markdown]
# 可见，覆盖时间越长，效果相对越明显，下面按照研报上的，选择覆盖时间为一年的进行选股策略回测

# %%
data=raw_df_new_new_new[raw_df_new_new_new.ix[:,14]==1].reset_index(drop=True)

# %% [markdown]
# 构建的按月度调仓的事件指数超额收益明显，接下来，构建日度调仓模式下的选股策略，这里设置手续费单边为万分之五，最大持股数量为50

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ticker security  name        date  level  \
# 0           0             0     895     中原证券   刘冉'  2009-05-08      1
# 1           1             1    2143     中原证券   刘冉'  2009-05-08      1
# 2           2             2    2201     中信建投  田东红'  2009-05-24      1
# 3           3             3  600327     东方证券   王佳'  2009-05-25      1
# 4           4             4     157     中原证券  路永光'  2009-05-25      1
#
#          secID  is_first  is_ST  is_new  month_pct_change  is_tingpai  \
# 0  000895.XSHE       1.0    0.0     0.0          0.034873         0.0
# 1  002143.XSHE       1.0    0.0     0.0          0.084052         0.0
# 2  002201.XSHE       1.0    0.0     0.0          0.092437         0.0
# 3  600327.XSHG       1.0    0.0     0.0          0.050995         0.0
# 4  000157.XSHE       1.0    0.0     0.0         -0.010289         0.0
#
#      t_plus_1  is_first_yearly  is_first_onehalf_yearly  is_first_two_yearly
# ...

# %% [markdown]
# 在最终的策略环节前，插入一个子环节，研究全券商一年首次覆盖事件中的股票在评级前一个月以及评级后一个月的超额收益情况，以为日度调仓模式下的股票优选提供依据

# %%
data2=data[['date','secID']]

# %%
data2['one_month_plus_pct_change_before']=np.NAN
data2['one_month_plus_pct_change_after']=np.NAN

# %% [markdown]
# 先看一下，以月为维度，一年全券商首次覆盖股票数量

# %%
data2['year_month']=data['date'].apply(lambda x: x[0:7])
data2['year']=data['date'].apply(lambda x: x[0:4])

# %%
sum_yearly2=data2.groupby(data2['year'])['secID'].nunique()
sum_monthly=data2.groupby(data2['year_month'])['secID'].nunique()

# %%
font.set_size(8)
fig = plt.figure(figsize=(60,5))
ax1 = fig.add_subplot(111)
ax1 = sum_monthly.plot(kind='bar',color='r')
ax1.set_xticklabels(sum_monthly.index,rotation=0,fontproperties=font)
ax1.set_ylabel(u'全券商分析师首次评级一年首次覆盖事件股票数量时间分布情况（月度）',fontproperties=font,fontsize=13)
ax1.set_title(u'全券商分析师首次评级一年首次覆盖事件股票数量时间分布情况（月度）',fontproperties=font,fontsize=13)
font.set_size(13)

# %%
fig = plt.figure(figsize=(10,5))
ax2 = fig.add_subplot(111)
ax2=sum_yearly2.plot(kind='bar',color='r')
ax2.set_xticklabels(sum_yearly2.index,rotation=0,fontproperties=font)
ax2.set_ylabel(u'全券商分析师首次评级一年首次覆盖事件股票数量时间分布情况(年度)',fontproperties=font,fontsize=13)
ax2.set_title(u'全券商分析师首次评级一年首次覆盖事件股票数量时间分布情况（年度）',fontproperties=font,fontsize=13)

# %%
sum_monthly.describe()
# Out:
# count     97.000000
# mean      47.804124
# std       25.706127
# min        2.000000
# 25%       31.000000
# 50%       41.000000
# 75%       59.000000
# max      133.000000
# Name: secID, dtype: float64

# %% [markdown]
# 可见，通过筛选全券商分析师首次评级之一年首次覆盖的优选股票事件，大大降低了样本股票数量,月度来看，每月事件股票平均47个左右，比较理想

# %%
for i in range(len(data2)):
    this_day=data2.ix[i,'date']
    stock_month_early_closeprice = DataAPI.MktEqudAdjGet(tradeDate=Calendar('China.SSE').advanceDate(this_day,Period(str(-21)+str('B'))).strftime("%Y%m%d"),secID=data2.ix[i,'secID'],field=u"closePrice",pandas="1")
    zz500_month_early_closeprice = DataAPI.MktIdxdGet(tradeDate=Calendar('China.SSE').advanceDate(this_day,Period(str(-21)+str('B'))).strftime("%Y%m%d"),ticker=u"000905",exchangeCD=u"XSHE,XSHG",field=u"closeIndex",pandas="1")
    stock_month_after_closeprice = DataAPI.MktEqudAdjGet(tradeDate=Calendar('China.SSE').advanceDate(this_day,Period(str(20)+str('B'))).strftime("%Y%m%d"),secID=data2.ix[i,'secID'],field=u"closePrice",pandas="1")
    zz500_month_after_closeprice = DataAPI.MktIdxdGet(tradeDate=Calendar('China.SSE').advanceDate(this_day,Period(str(20)+str('B'))).strftime("%Y%m%d"),ticker=u"000905",exchangeCD=u"XSHE,XSHG",field=u"closeIndex",pandas="1")
    stock_this_day_closeprice = DataAPI.MktEqudAdjGet(tradeDate=Calendar('China.SSE').advanceDate(this_day,Period(str(-1)+str('B'))).strftime("%Y%m%d"),secID=data2.ix[i,'secID'],field=u"closePrice",pandas="1")
    zz500_this_day_closeprice = DataAPI.MktIdxdGet(tradeDate=Calendar('China.SSE').advanceDate(this_day,Period(str(-1)+str('B'))).strftime("%Y%m%d"),ticker=u"000905",exchangeCD=u"XSHE,XSHG",field=u"closeIndex",pandas="1")
    if len(stock_month_early_closeprice)>0 and len(stock_this_day_closeprice)>0 and stock_month_early_closeprice.ix[0,0]!=stock_this_day_closeprice.ix[0,0]: 
        data2.ix[i,'one_month_plus_pct_change_before']=((stock_this_day_closeprice.ix[0,0]-stock_month_early_closeprice.ix[0,0])/stock_month_early_closeprice.ix[0,0])-((zz500_this_day_closeprice.ix[0,0]-zz500_month_early_closeprice.ix[0,0])/zz500_month_early_closeprice.ix[0,0])
    if len(stock_month_after_closeprice)>0 and len(stock_this_day_closeprice)>0 and stock_month_after_closeprice.ix[0,0]!=stock_this_day_closeprice.ix[0,0]:   ###停牌不考虑，这里武断地把20日后的股价和当日一样，理解为股票停牌（停牌股价不变），股价正好一样的小概率事件应该极少吧
        data2.ix[i,'one_month_plus_pct_change_after']=((stock_month_after_closeprice.ix[0,0]-stock_this_day_closeprice.ix[0,0])/stock_this_day_closeprice.ix[0,0])-((zz500_month_after_closeprice.ix[0,0]-zz500_this_day_closeprice.ix[0,0])/zz500_this_day_closeprice.ix[0,0])

# %% [markdown]
# 上一部过程花费了很长的时间，不想运行的话可以直接下载，这里先保存data2再读取它

# %%
data2.to_csv('data2.csv')

# %% [markdown]
# 读取data2

# %%
import pandas as pd

# %%
data2=pd.read_csv('data2.csv')

# %%
data2_dropna=data2.dropna().reset_index(drop=True)
data2_dropna.head()
# Out:
#    Unnamed: 0        date        secID  one_month_plus_pct_change_before  \
# 0           0  2009-05-08  000895.XSHE                         -0.077534
# 1           1  2009-05-08  002143.XSHE                         -0.047013
# 2           2  2009-05-24  002201.XSHE                          0.028719
# 3           3  2009-05-25  600327.XSHG                         -0.012679
# 4           4  2009-05-25  000157.XSHE                         -0.073943
#
#    one_month_plus_pct_change_after year_month  year
# 0                         0.040613    2009-05  2009
# 1                        -0.008403    2009-05  2009
# 2                         0.027996    2009-05  2009
# 3                         0.011864    2009-05  2009
# 4                         0.128365    2009-05  2009

# %%
data2_dropna['one_month_plus_pct_change_before'].describe()
# Out:
# count    4470.000000
# mean        0.055256
# std         0.215375
# min        -0.382784
# 25%        -0.031219
# 50%         0.028476
# 75%         0.109191
# max         9.748005
# Name: one_month_plus_pct_change_before, dtype: float64

# %%
data2_dropna['one_month_plus_pct_change_after'].describe()
# Out:
# count    4470.000000
# mean        0.036493
# std         0.147722
# min        -0.447810
# 25%        -0.048869
# 50%         0.013615
# 75%         0.093281
# max         2.046738
# Name: one_month_plus_pct_change_after, dtype: float64

# %% [markdown]
# 再删除极值，取双边10%（单边5%）删除

# %%
data2_dropna_2=data2_dropna[(data2_dropna['one_month_plus_pct_change_after']>=np.percentile(data2_dropna['one_month_plus_pct_change_after'],5))&(data2_dropna['one_month_plus_pct_change_after']<=np.percentile(data2_dropna['one_month_plus_pct_change_after'],95))&(data2_dropna['one_month_plus_pct_change_before']<=np.percentile(data2_dropna['one_month_plus_pct_change_before'],95))&(data2_dropna['one_month_plus_pct_change_before']>=np.percentile(data2_dropna['one_month_plus_pct_change_before'],5))]

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(121)
ax1.hist(data2_dropna_2['one_month_plus_pct_change_before'],bins=30,normed=True)
ax1.set_title(u'one_month_plus_pct_change_before')
ax2 = fig.add_subplot(122)
ax2.hist(data2_dropna_2['one_month_plus_pct_change_after'],bins=40,normed=True)
ax2.set_title(u'one_month_plus_pct_change_after')

# %%
from scipy import stats

# %%
info = stats.describe(data2_dropna_2['one_month_plus_pct_change_before'])
print "one_month_plus_pct_change_before_Data size is: " + str(info[0])
print "one_month_plus_pct_change_before_Minimum value is: " + str(info[1][0])
print "one_month_plus_pct_change_before_Maximum value is: " + str(info[1][1])
print "one_month_plus_pct_change_before_Arithmetic mean is: " + str(info[2])
print "one_month_plus_pct_change_before_Unbiased variance is: " + str(info[3])
print "one_month_plus_pct_change_before_Biased skewness is: " + str(info[4])
print "one_month_plus_pct_change_before_Biased kurtosis is: " + str(info[5])
# Out:
# one_month_plus_pct_change_before_Data size is: 3672
# one_month_plus_pct_change_before_Minimum value is: -0.116719860734
# one_month_plus_pct_change_before_Maximum value is: 0.301111212504
# one_month_plus_pct_change_before_Arithmetic mean is: 0.0386974665386
# one_month_plus_pct_change_before_Unbiased variance is: 0.00775603663838
# one_month_plus_pct_change_before_Biased skewness is: 0.618103560049
# one_month_plus_pct_change_before_Biased kurtosis is: -0.123776193587

# %%
info2 = stats.describe(data2_dropna_2['one_month_plus_pct_change_after'])
print "one_month_plus_pct_change_after_Data size is: " + str(info2[0])
print "one_month_plus_pct_change_after_Minimum value is: " + str(info2[1][0])
print "one_month_plus_pct_change_after_Maximum value is: " + str(info2[1][1])
print "one_month_plus_pct_change_after_Arithmetic mean is: " + str(info2[2])
print "one_month_plus_pct_change_after_Unbiased variance is: " + str(info2[3])
print "one_month_plus_pct_change_after_Biased skewness is: " + str(info2[4])
print "one_month_plus_pct_change_after_Biased kurtosis is: " + str(info2[5])
# Out:
# one_month_plus_pct_change_after_Data size is: 3672
# one_month_plus_pct_change_after_Minimum value is: -0.135003084605
# one_month_plus_pct_change_after_Maximum value is: 0.274511528332
# one_month_plus_pct_change_after_Arithmetic mean is: 0.0246978746995
# one_month_plus_pct_change_after_Unbiased variance is: 0.00804778582553
# one_month_plus_pct_change_after_Biased skewness is: 0.588940985341
# one_month_plus_pct_change_after_Biased kurtosis is: -0.161847854412

# %% [markdown]
# 通过hist图以及检验得到skewness都表明，两个“右偏”现象都比较显著，表明评级时间前后都存在超额收益

# %% [markdown]
# 下面看一下评级前后超额收益率分布的散点图

# %%
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111)
result_ols = pd.ols(y=data2_dropna_2['one_month_plus_pct_change_after'],x=data2_dropna_2['one_month_plus_pct_change_before'])
ax.plot(data2_dropna_2['one_month_plus_pct_change_before'].values,data2_dropna_2['one_month_plus_pct_change_after'].values,linestyle='None',marker ='s',color = 'crimson')
plt.xlim(np.percentile(data2_dropna['one_month_plus_pct_change_before'],5)-0.01,np.percentile(data2_dropna['one_month_plus_pct_change_before'],95)+0.01)
plt.ylim(np.percentile(data2_dropna['one_month_plus_pct_change_after'],5)-0.01,np.percentile(data2_dropna['one_month_plus_pct_change_after'],95)+0.01)
ax.plot(data2_dropna_2['one_month_plus_pct_change_before'].values,result_ols.y_predict.values,color='royalblue',linewidth=1.5)
ax.plot([np.percentile(data2_dropna['one_month_plus_pct_change_before'],5)-0.01,np.percentile(data2_dropna['one_month_plus_pct_change_before'],95)+0.01],[0,0],color='black')
ax.plot([0,0],[np.percentile(data2_dropna['one_month_plus_pct_change_after'],5)-0.01,np.percentile(data2_dropna['one_month_plus_pct_change_after'],95)+0.01],color='black')
ax.set_title(u"评级前后超额收益率关系", fontproperties=font, fontsize=25)

# %%
result_ols
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <x> + <intercept>
#
# Number of Observations:         3672
# Number of Degrees of Freedom:   2
#
# R-squared:         0.0007
# Adj R-squared:     0.0005
#
# Rmse:              0.0897
#
# F-stat (1, 3670):     2.6721, p-value:     0.1022
#
# Degrees of Freedom: model 1, resid 3670
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#              x    -0.0275     0.0168      -1.63     0.1022    -0.0604     0.0055
#      intercept     0.0258     0.0016      15.93     0.0000     0.0226     0.0289
# ---------------------------------End of Summary---------------------------------

# %% [markdown]
# 可见，相对来说，前期超跌幅度越大的股票，后期超额收益可能越大，所以在优选股票时可以比较前期pct_change,选择小的

# %% [markdown]
# 先测试 评级后1日入场，最大持股天数为1个月（20个交易日），限仓50股，先不添加止盈止损，每日调仓中如果待选股票数量大于需求数，则优选“低位”的股票（即前一个月pct_change小的）进入股票池如下：

# %% [markdown]
# （这里入场时间以及最大持股天数和限仓数量都是参考长江证券的研报，我这里就没像之前那样进行入场时间点以及最大持股时间的参数优化，也没有设置止盈止损），有兴趣的话可以参考之前的做法再进行参数优化

# %%
data2.head()
# Out:
#    Unnamed: 0        date        secID  one_month_plus_pct_change_before  \
# 0           0  2009-05-08  000895.XSHE                         -0.077534
# 1           1  2009-05-08  002143.XSHE                         -0.047013
# 2           2  2009-05-24  002201.XSHE                          0.028719
# 3           3  2009-05-25  600327.XSHG                         -0.012679
# 4           4  2009-05-25  000157.XSHE                         -0.073943
#
#    one_month_plus_pct_change_after year_month  year
# 0                         0.040613    2009-05  2009
# 1                        -0.008403    2009-05  2009
# 2                         0.027996    2009-05  2009
# 3                         0.011864    2009-05  2009
# 4                         0.128365    2009-05  2009

# %%
data2['t_plus_1'] = data2['date'].apply(lambda x: Calendar('China.SSE').advanceDate(x,Period(str(1)+str('B'))).strftime("%Y-%m-%d"))

# %% [raw]
# start = '2009-05-08'                       # 回测起始时间,大约事件首个交易日
# end = '2017-05-02'                         # 回测结束时间
# benchmark = 'ZZ500'                        # 策略参考标准,中证500
# universe = set_universe('A')  # 证券池，支持股票和基金
# capital_base = 10000000                     # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# commission = Commission(buycost=0.0005, sellcost=0.0005)
#
# def initialize(account):                   # 初始化虚拟账户状态
#         account.day_counter = {}  #用于记录持仓天数
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#         for stk in account.avail_security_position:  # 记录持仓的天数
#             if account.day_counter.has_key(stk):
#                      account.day_counter[stk] += 1
#             else:
#                      account.day_counter[stk] = 1
#       ##止盈止损,先不用
#         for stk in account.avail_security_position:
#             if (account.reference_price[stk])/account.security_cost[stk]>=1000 or (account.reference_price[stk])/account.security_cost[stk]<=0.001:
#                      order_to(stk,0)
#         for stk in (set(account.day_counter.keys())-set(account.security_position.keys())):
#                      del account.day_counter[stk]
#
#    ##卖出，最大到20日 卖出
#         for stk in account.security_position:
#             if(account.day_counter[stk]>20):   #持仓超过20天，卖出
#                      order_to(stk,0)
#         for stk in (set(account.day_counter.keys())-set(account.security_position.keys())):
#                      del account.day_counter[stk]
#
#     ##判断当前持股数量
#         current_stock_number=len(account.avail_security_position.keys())
#
#     ##买进
#         univ_df = data2[(data2['t_plus_1']==account.current_date.strftime('%Y-%m-%d'))].sort_values(by='one_month_plus_pct_change_before')
#
#         max_number=50
#
#     ##如果当日股票持仓数量少于max_number个，则增仓买入新股票
#         if current_stock_number<max_number:
#             if len(univ_df )>0: # 当天有事件发生
#                 need_buy_number=max_number-current_stock_number
#                 univ_df=univ_df.head(need_buy_number)
#                 univ = univ_df ['secID'].tolist()
#                 univ = list(set(univ) - set(account.security_position))  # 已经持有的股票不再重新下单
#                 need_buy_stock_number=len(univ)##需要新进买入股票的数量
#                 number=current_stock_number+need_buy_stock_number
#
#
#                 for stk in univ:
#                     order_pct_to(stk,1.0/number)
#                 for stk in account.security_position:
#                     order_pct_to(stk,1.0/number)

# %%
fig = plt.figure(figsize=(12,10))
fig.set_tight_layout(True)
ax1 = fig.add_subplot(211)
ax2 = ax1.twinx()
ax1.grid()
data = bt[[u'tradeDate',u'portfolio_value',u'benchmark_return']]
data['portfolio_return'] = data.portfolio_value/data.portfolio_value.shift(1) - 1.0
data['portfolio_return'].ix[0] = data['portfolio_value'].ix[0]/	10000000.0 - 1.0
data['excess_return'] = data.portfolio_return - data.benchmark_return
data['excess'] = data.excess_return + 1.0
data['excess'] = data.excess.cumprod()
data['portfolio'] = data.portfolio_return + 1.0
data['portfolio'] = data.portfolio.cumprod()
data['benchmark'] = data.benchmark_return + 1.0
data['benchmark'] = data.benchmark.cumprod()
data['excess_back']=([1 - v/max(1, max(data['excess'][:i+1])) for i,v in enumerate(data['excess'])])
#
# ax.plot(data[['portfolio','benchmark','excess']], label=str(qt))
ax1.plot(data['tradeDate'], data['portfolio'], label='portfolio(left)')
ax1.plot(data['tradeDate'], data['benchmark'], label='benchmark(left)')
ax2.plot(data['tradeDate'], data['excess'], label='hedged(right)', color='r')

ax1.legend(loc=2)
ax2.legend(loc=0)

ax1.set_ylabel(u"全券商分析师评级一年首次覆盖策略净值", fontproperties=font, fontsize=16)
ax2.set_ylabel(u"对冲指数净值", fontproperties=font, fontsize=16)
ax2.set_ylabel(u"对冲指数净值", fontproperties=font, fontsize=16)
ax1.set_title(u"全券商分析师评级一年首次覆盖", fontproperties=font, fontsize=16)
ax3 = fig.add_subplot(212)
ax3.plot(data['tradeDate'], data['excess_back'], label='excess_back',color='r')
ax3.legend(loc=2)

ax3.set_ylabel(u"超额净值回撤", fontproperties=font, fontsize=16)
ax3.set_title(u"全券商分析师评级一年首次覆盖策略超额净值回撤情况", fontproperties=font, fontsize=16)

# %%
bt_analysis = {}
bt_analysis['annualized_return'] = perf['annualized_return']
bt_analysis['volatility'] = perf['volatility']
bt_analysis['max_drawdown'] = perf['max_drawdown']
bt_analysis['alpha'] = perf['alpha']
bt_analysis['beta'] = perf['beta']
bt_analysis['sharpe'] = perf['sharpe']
bt_analysis['information_ratio'] = perf['information_ratio']
data = bt[[u'tradeDate',u'portfolio_value',u'benchmark_return']]
data['portfolio_return'] = data.portfolio_value/data.portfolio_value.shift(1) - 1.0   # 总头寸每日回报率
data['portfolio_return'].ix[0] = data['portfolio_value'].ix[0]/    10000000.0 - 1.0
data['excess_return'] = data.portfolio_return - data.benchmark_return                 # 总头寸每日超额回报率
data['excess'] = data.excess_return + 1.0
data['excess'] = data.excess.cumprod()                # 总头寸对冲指数后的净值序列
data['portfolio'] = data.portfolio_return + 1.0
data['portfolio'] = data.portfolio.cumprod()          # 总头寸不对冲时的净值序列
data['benchmark'] = data.benchmark_return + 1.0
data['benchmark'] = data.benchmark.cumprod()          # benchmark的净值序列
bt_analysis['hedged_max_drawdown'] = max([1 - v/max(1, max(data['excess'][:i+1])) for i,v in enumerate(data['excess'])])  # 对冲后净值最大回撤
bt_analysis['hedged_volatility'] = np.std(data['excess_return'])*np.sqrt(252)
bt_analysis['hedged_annualized_return'] = (data['excess'].values[-1])**(252.0/len(data['excess'])) - 1.0

import pandas
results_pd = pandas.DataFrame(bt_analysis, index=[u'全券商分析师评级一年首次覆盖策略'])

results_pd = results_pd[[u'alpha', u'beta', u'information_ratio', u'sharpe',
                        u'annualized_return', u'max_drawdown', u'volatility',
                         u'hedged_annualized_return', u'hedged_max_drawdown', u'hedged_volatility']]

for col in results_pd.columns:
    results_pd[col] = [np.round(x, 3) for x in results_pd[col]]

cols = [(u'风险指标', u'Alpha'), (u'风险指标', u'Beta'), (u'风险指标', u'信息比率'), (u'风险指标', u'夏普比率'),
        (u'纯股票多头时', u'年化收益'), (u'纯股票多头时', u'最大回撤'), (u'纯股票多头时', u'收益波动率'),
        (u'对冲后', u'年化收益'), (u'对冲后', u'最大回撤'),
        (u'对冲后', u'收益波动率')]
results_pd.columns = pd.MultiIndex.from_tuples(cols)
results_pd
# Out:
#                    风险指标                      纯股票多头时                  对冲后  \
#                   Alpha   Beta   信息比率   夏普比率   年化收益   最大回撤  收益波动率   年化收益
# 全券商分析师评级一年首次覆盖策略  0.251  0.941  2.501  1.077  0.335  0.498  0.282  0.224
#
#
#                    最大回撤  收益波动率
# 全券商分析师评级一年首次覆盖策略  0.147  0.082

# %%
def plot_return(bt, title):
    bt['portfolio_return'] = bt['portfolio_value']/bt['portfolio_value'].shift(1) - 1.0
    bt['excess_return'] = bt.portfolio_return - bt.benchmark_return                 # 总头寸每日超额回报率
    bt['excess'] = bt.excess_return + 1.0
    bt['excess'] = bt.excess.cumprod()                # 总头寸对冲指数后的净值序列
    month_date = [bt.ix[0, 0].date()]
    portfolio_value = [bt.ix[0, 'portfolio_value']]
    portfolio_excess= [bt.ix[0, 'excess']]
    for i in range(len(bt)-1):
        if bt.ix[i+1, 0].month != month_date[-1].month:
            month_date.append(bt.ix[i+1, 0].date())
            portfolio_value.append(bt.ix[i+1, 'portfolio_value'])
            portfolio_excess.append(bt.ix[i+1, 'excess'])
    results = pd.DataFrame(data=portfolio_value, columns=['portfolio_value'])
    results['monthly_return'] = results['portfolio_value']/results['portfolio_value'].shift(1)-1
    results['cumulative_return'] = portfolio_excess
    results['monthly_return_1'] = results['cumulative_return']/results['cumulative_return'].shift(1)-1
    results.index = month_date
    results.dropna(inplace=True)
    
    fig = plt.figure(figsize=(14, 10))
    ax1 = fig.add_subplot(211)
    ax2 = ax1.twinx()
    lns2 = ax1.plot(results.index, results['cumulative_return'], 'r')
    lns1 = ax2.bar(results.index, results['monthly_return_1'], align='center', width=10, color='b')
    ax2.legend(lns1, ['excess monthly return(right axis)'], loc=1, fontsize=12)
    ax1.legend(lns2, ['excess return(left axis)'], loc=2, fontsize=12)
    ax1.set_ylabel(u'组合净值/基准净值', fontproperties=font, fontsize=16)
    ax2.set_ylabel(u'超额月度收益率', fontproperties=font, fontsize=16)
    ax1.set_xlabel(u'时间', fontproperties=font, fontsize=16)
    ax2.set_yticklabels([str(x*100)+'0%' for x in ax2.get_yticks()], fontproperties=font, fontsize=14)
    s = ax1.set_title(title, fontproperties=font, fontsize=16)
    f1=float(len(results[results['monthly_return_1']>0]))/float(len(results))
    f2=float(len(results[results['monthly_return']>0]))/float(len(results))
    ax1.text(datetime(2016,01,01),1.15,u'超额月度胜率:%0.2f'%f1,fontproperties=font,fontsize=16)
    ax1.text(datetime(2016,01,01),1.45,u'绝对月度胜率:%0.2f'%f2,fontproperties=font,fontsize=16)
  
    return ax1, ax2
    

s = plot_return(bt, u'全券商分析师评级一年首次覆盖策略月度表现')

# %% [markdown]
# 综上，虽然近年来分析师评级事件较多，但是通过构建“首次覆盖”的方法来优选股票后的事件指数明显跑赢大盘,日度调仓模式下的选股策略（一年首次覆盖+‘低位’）表现也不错。
