# %% [markdown]
# # FENICE01

# %% [raw]
# start = '2014-01-01'                       # 回测起始时间
# end = '2015-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['000898.XSHE' ,'000725.XSHE', '600016.XSHG', '600036.XSHG', '601169.XSHG', '601009.XSHG', '600048.XSHG', '000002.XSHE', '600159.XSHG', '600219.XSHG', '600547.XSHG', '600766.XSHG', '600988.XSHG', '601600.XSHG']  # 证券池，回测支持股票和基金
# capital_base = 100000                      # 起始资金
# refresh_rate = 1                           # 调仓频率，即每 refresh_rate 个交易日执行一次 handle_data() 函数
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     hist = account.get_attribute_history('closePrice', 60)
#     for s in account.universe:
#         sum30 = 0
#         for i in range(-30, -1):
#             sum30 = sum30 + hist[s][i]
#
#         sum30 = sum30 / 30
#
#         sum20 = 0
#         for i in range(-20, -1):
#             sum20 = sum20 + hist[s][i]
#
#         sum20 = sum20 / 20
#
#         if hist[s][-1] >= sum30 and s not in account.valid_secpos:
#             order(s, 10000)
#         elif hist[s][-1] < sum20 and s in account.valid_secpos:
#             order_to(s, 0)
#     return
