# %% [markdown]
# # 用StockScreener(Factor.VOL10.nsmall(300)) 得到的换手率不太正确

# %% [raw]
# import numpy as np
# from CAL.PyCAL import *
#
# start = '2016-01-15'
# end = '2016-01-19'
# benchmark = 'HS300'
# universe = StockScreener(Factor.VOL10.nsmall(300))    # LFLO 为流通市值对数，VOL20 为20日平均换手率
# capital_base = 1000000
# refresh_rate = 1
# stk_num_max = 5    # 持仓股票数量上限
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     print account.universe
