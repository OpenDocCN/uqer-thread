# %% [markdown]
# # 单均线择时股票

# %% [raw]
# start = '2014-01-01'
# end = '2017-01-01'
# benchmark = 'HS300'
# universe = StockScreener( Factor.LCAP.nsmall(10) )
# capital_base = 1000000
# freq = 'd'
# refresh_rate = 1
# commission = Commission(buycost=0.0002, sellcost=0.0002, unit='perValue')
# period = 10
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     hist = account.get_attribute_history('closePrice', period)
#     for s in account.universe:
#         close_price = hist[s][-1]
#         ma = hist[s].mean()
#
#         if close_price > ma and s not in account.security_position:
#
#             amount = int(account.cash / account.reference_price[s] / 100) * 100
#             order(s, amount)
#         elif close_price < ma and s in account.security_position:
#             order_to(s, 0)
