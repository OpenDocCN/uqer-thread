# %% [markdown]
# # Notebook29

# %% [raw]
# import pandas as pd
# pd.set_option('precision', 2)
# pd.set_option('display.width', 800)
# import numpy as np
# import datetime as dt
# import math
# import DataAPI
# DataAPI.settings.cache_enabled = True
#
#
# from collections import deque
#
# start = '2015-01-01'                       # 回测起始时间
# end = '2015-01-10'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['600000.XSHG']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 15                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# class incre_ment(object):
#
#     def __init__(self, account):
#         self.account = account
#
#     def get_bar(self, barLength = None):
#         account.data = account.get_symbol_history(symbol = self, time_range = barLength)
#         print account.equity
#         print self
#         print account.data
#         #account.close = account.data['closePrice'].tolist()
#         #print account.close
#         barsFrame = pd.DataFrame()
#         #for future in data.keys():
#
#         #bar = {'closePrice': round(data['closePrice'].tolist()),'openPrice': round(data['openPrice'].tolist()),'highPrice': round(data['highPrice'].tolist()),'lowPrice': round(data['lowPrice'].tolist()),'volume': round(data['volume'].tolist())}
#         #print bar
#         #barsFrame = pd.concat([barsFrame,pd.DataFrame(bar,index = [future])])
#         #print barsFrame
#         # barsFrame =closePrice  highPrice  lowPrice  openPrice    volume
#         #rb1610      2580.0     2587.0    2566.0     2571.0  599016.0
#         return barsFrame
#
#
#
#
#
# def initialize(account):                   # 初始化虚拟账户状态
#     account.equity = universe[0]
#     account.signal = pd.DataFrame({'long': False, 'short': False, 'stopLoss': False, 'stopWin': False}, index = universe)
#     account.increment = incre_ment(account)
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     account.bar = account.increment.get_bar(barLength = refresh_rate)
#     return
