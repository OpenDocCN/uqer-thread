# %% [markdown]
# #

# %% [raw]
# #盘中急速拉升
#
# start = '2016-03-01'                       # 回测起始时间
# end = '2016-04-01'                         # 回测结束时间
# benchmark = 'ZZ500'                        # 策略参考标准
# universe = set_universe('ZZ500')  # 证券池，支持股票和基金
# # universe=['600570.XSHG']
# capital_base = 1000000                      # 起始资金
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# commission = Commission(buycost=0.0004, sellcost=0.0015, unit='perValue')
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     #cp=account.get_attribute_history('closePrice',3)
#     cp = account.get_daily_attribute_history('closePrice', 1)
#     # print account.referencePortfolioValue
#     # print account.universe
#     # print account.current_date,cp
#     # print str(account.current_date)+str(account.current_minute)
#
#     for sec in account.universe:
#         if account.referencePrice[sec]>0:
#            buyTotal=int(20000/account.referencePrice[sec])
# #           buyTotal = 20000
#            validpos=account.valid_secpos.get(sec,0)
#         else:
#            continue
#         if account.referencePrice[sec]/cp[sec][-1] >1.09:
#             order(sec,buyTotal-validpos)
# #        if (cp[sec][4]-cp[sec][0])/cp[sec][0]<-0.05 and sec in account.avail_secpos:
#         if account.current_minute == '09:32' and sec in account.avail_secpos:
#             order_to(sec,0)

# %% [raw]
# import numpy as np
# import pandas as pd
# start = '2015-05-01'                       # 回测起始时间
# end = '2016-06-21'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')           # 证券池，支持股票和基金
# capital_base = 1000000                      # 起始资金
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     for stk in account.valid_seccost:
#         if account.referencePrice[stk] == 0 or np.isnan(account.referencePrice[stk]):
#             continue
#         if day_count[stk] > 2401 or account.valid_seccost[stk] * 1.1 < account.referencePrice[stk]:
#             order_to(stk,0)
#             day_count[stk] = 0
#     if  account.current_minute == '09:31':
#         for stk in account.valid_seccost:
#             if account.referencePrice[stk] == 0 or np.isnan(account.referencePrice[stk]):
#                 continue
#             order_to(stk,0)
#     if  account.current_minute == '14:45':
#         buylist = []
#
#         eq_closeprice1d = account.get_daily_attribute_history('closePrice',1)
#         total_money = account.cash
#         prices = account.referencePrice
#
#         for stk in account.universe:
#             if 1.03 < prices[stk] / eq_closeprice1d[stk][0] < 1.098 : #and eq20_ret[stk] < eq20_ret.quantile(0.3): #涨停了的就别下单了
#                 buylist.append(stk)
#
#         for stk in buylist:
#             if stk not in account.valid_secpos:
#                 if np.isnan(prices[stk]) or prices[stk] == 0:  # 停牌或是还没有上市等原因不能交易
#                     continue
#                 order_to(stk,0.1*total_money / prices[stk]) #等权买入
