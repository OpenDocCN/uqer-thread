# %% [markdown]
# # 实现稳定增值，成功逃离股灾！

# %% [markdown]
# 挑选基本面好的便宜股票
# -----------
# >
# > 策略基本思路是：选出总资产小，净利润增长率高的一个股票池，购买价格低于X的股票，在价格超过1.25X后卖出，重新补入价格低于X的股票。
# >
# > 这是对之前混沌骑士“专选便宜货”策略的一个改进。
# >
# > 实现稳定增长，成功逃离股灾！

# %% [raw]
# from __future__ import division
# start = '2012-01-01'                       # 回测起始时间
# end = '2016-05-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = StockScreener(Factor.ASSI.nsmall(300) & Factor.NetProfitGrowRate.value_range(0.1,None))   # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     account.piece=0
#     pass
#
# pos_piece=15
# price_flag=10
# sell_flag=price_flag*1.25
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     pct=1/pos_piece
#     for stock in account.universe:
#         try:
#             if (stock in account.valid_secpos) and (account.referencePrice[stock]>sell_flag):
#                 order_pct_to(stock,0)
#                 account.piece-=1
#             elif (not stock in account.valid_secpos) and account.referencePrice[stock]<price_flag and account.piece<pos_piece:
#                 order_pct_to(stock,pct)
#                 account.piece+=1
#         except:
#             return
#     return
