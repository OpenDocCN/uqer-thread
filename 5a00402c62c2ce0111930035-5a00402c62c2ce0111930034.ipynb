# %% [markdown]
# # 成分股数据有问题

# %% [markdown]
# 获取成分股数据时，未显示上港集箱已退市。

# %%
data = DataAPI.IdxConsGet(secID='000002.ZICN', intoDate='2017-11-06')
data[data.consID == 'DY600018.XSHG']
# Out:
#            secID    intoDate secShortName  ticker         consID  \
# 447  000002.ZICN  2000-07-19         A股指数  000002  DY600018.XSHG
#
#     consShortName consTickerSymbol consExchangeCD  outDate  isNew
# 447          上港集箱         DY600018           XSHG      NaN      1

# %%
DataAPI.EquGet(ticker="DY600018").T
# Out:
#                                                                     0
# secID                                                   DY600018.XSHG
# ticker                                                       DY600018
# exchangeCD                                                       XSHG
# ListSectorCD                                                        1
# ListSector                                                         主板
# transCurrCD                                                       CNY
# secShortName                                                     上港集箱
# secFullName                                              上海港集装箱股份有限公司
# listStatusCD                                                       DE
# listDate                                                   2000-07-19
# delistDate                                                 2006-10-20
# equTypeCD                                                           A
# ...
