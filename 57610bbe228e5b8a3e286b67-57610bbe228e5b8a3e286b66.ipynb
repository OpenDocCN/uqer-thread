# %% [markdown]
# #

# %%
bt
# Out:
#    tradeDate       cash                                  security_position  \
# 0 2016-01-04  987988.00  {u'000001.XSHE': {u'amount': 1000, u'cost': 12...
# 1 2016-01-05  976706.73  {u'000001.XSHE': {u'amount': 2000, u'cost': 11...
#
#    portfolio_value  benchmark_return  \
# 0        999318.00         -0.070206
# 1        999506.73          0.002800
#
#                                              blotter
# 0  [Order(order_time: 2016-01-04 09:30, symbol: 0...
# 1  [Order(order_time: 2016-01-05 09:30, symbol: 0...

# %% [raw]
# start = '2016-01-04'
# end = '2016-01-05'
# benchmark = 'HS300'
# capital_base = 1000000
# freq = 'd'
# refresh_rate = 1
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     order('000001.XSHE', 1000)
#     qdate = account.current_date.strftime('%Y-%m-%d')
#     print(qdate, account.valid_secpos, account.cash)
#     # print(qdate, account.valid_secpos, account.cash, bt[bt.tradeDate == qdate]['cash'])
