# %% [markdown]
# # Test

# %% [raw]
# ########################### 初始化配置 ###########################
# start = '2016-06-01'                       # 回测起始时间
# end = '2017-06-01'                         # 回测结束时间
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = Monthly(1)                  # 执行handle_data的时间间隔
#
# universe = DynamicUniverse('ZZ500')  # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                        # 策略参考基准
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# ############################ 策略逻辑 ############################
# def initialize(context):                   # 初始化策略运行环境
#     signal = Signal('MktValue')
#     context.signal_generator = SignalGenerator(signal)
#
# def handle_data(context):                  # 核心策略逻辑
#     now = context.previous_date.strftime('%Y-%m-%d')
#     current_universe = context.get_universe(exclude_halt=True)
#     data = context.history(current_universe, 'MktValue', 1, freq='1d', style='tas')
#
#     cross_sectional_data = data[now]
#     ordered = cross_sectional_data['MktValue'].order(ascending=False)
#     target_portfolio = ordered[:20].index
#
#     account = context.get_account('fantasy_account')
#     positions = account.get_positions()
#
#     for stock in positions:
#         account.order_to(stock, 0)
#
#     for stock in target_portfolio:
#         amount = account.portfolio_value/context.current_price(stock)/20
#         account.order(stock, amount)
