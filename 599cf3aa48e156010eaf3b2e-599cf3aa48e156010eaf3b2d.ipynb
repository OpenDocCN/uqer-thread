# %% [markdown]
# # Notebook

# %%
S1 = DataAPI.MktLimitGet(tradeDate='20170809',field=u"ticker,limitUpPrice,upLimitReachedTimes")
S1 = S1[S1['upLimitReachedTimes']>0]
print S1

S2 = DataAPI.MktLimitGet(tradeDate='20170814',field=u"ticker,limitUpPrice,upLimitReachedTimes")
S2 = S2[S2['upLimitReachedTimes']>0]
print S2.head(10)
# Out:
# Empty DataFrame
# Columns: [ticker, limitUpPrice, upLimitReachedTimes]
# Index: []
#      ticker  limitUpPrice  upLimitReachedTimes
# 14   000018          7.92                   13
# 19   000023         27.48                    1
# 173  000595          4.71                    1
# 190  000615         15.95                   20
# 305  000786         17.80                   29
# 514  002054         15.81                   22
# 523  002063         11.19                   12
# 573  002113         13.56                    3
# 588  002128          9.57                    1
# 595  002135          8.11                  148
