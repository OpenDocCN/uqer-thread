# %% [markdown]
# # 请帮我看一下代码有什么问题

# %% [raw]
# start = '2014-01-01'
# end = '2015-01-01'
# benchmark = 'HS300'
# capital_base = 100000
# refresh_rate = 1
# longest_history = 2
#
# def initialize(account):
#     account.Equities    = ['002561.XSHE','000002.XSHE']
# def handle_data(account):
#
#     for stock in account.Equities:
#         hist_prices = account.get_attribute_history('closePrice', 2)
#         current_price = hist_prices[stock][0]
