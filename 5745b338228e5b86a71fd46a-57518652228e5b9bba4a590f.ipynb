# %% [markdown]
# # 恒生电子资金流入

# %%
import pandas 
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
HSDZFlow=DataAPI.MktEquFlowGet(tradeDate=u"",secID=u"",ticker=u"600570",beginDate=u"20160215",endDate=u"",field=u"",pandas="1")
data=HSDZFlow.groupby('tradeDate').sum()
dataSum=data.cumsum()/10**8
dataSum.netMoneyInflow.plot( figsize=(14, 7), title=u'600570 netMoneyInflow cumsum RMB 10^9')
