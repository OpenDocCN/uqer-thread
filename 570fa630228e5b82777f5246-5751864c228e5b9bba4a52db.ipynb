# %% [markdown]
# # 实现大V股社区的渔盆模型

# %% [raw]
# import numpy as np
# import pandas as pd
# import talib
# from CAL.PyCAL import *
#
# # 第一步：设置基本参数
# start = '2015-04-01'
# end   = '2016-04-12'
# capital_base =50000
# refresh_rate = 1
# benchmark = 'HS300'
# freq = 'd'
#
# # 第二步：选择主题，设置股票池
# universe = ['159915.XSHE', ]
#
# def initialize(account):
#     # 第三步：调整股票权重，权重列表序号与股票池列表序号对应
#     pass
#
# def handle_data(account):
#     d=account.previous_date
#     ud=unicode(d.strftime("%Y%m%d"))
#     cal = Calendar('China.SSE')
#     day1 = cal.advanceDate(d,'-120B',BizDayConvention.Preceding)
#     for stock in account.universe:
#         df=DataAPI.MktIdxdGet(ticker='399006',beginDate=day1.strftime("%Y%m%d"),endDate=ud,pandas="1")
#         lowest=np.array(df['lowestIndex'])
#         vol=np.array(df['turnoverValue'])
#         #MA_Type: 0=SMA, 1=EMA, 2=WMA, 3=DEMA, 4=TEMA, 5=TRIMA, 6=KAMA, 7=MAMA, 8=T3 (Default=SMA)
#         EMA20 = talib.MA(lowest,20,matype=0)
#         vMA20 = talib.MA(vol,20,matype=1)
#         # 20均线，量价齐升开始买入
#         if lowest[-1] >= EMA20[-1] and vol[-1] > vMA20[-1]:
#             if account.referencePrice[stock]:
#                 amount = int(account.cash / account.referencePrice[stock])
#                 if amount >= 100:
#                     order(stock,amount)
#         #20均线下，卖出
#         elif  lowest[-1] < EMA20[-1] :
#                 order_to(stock,0)
