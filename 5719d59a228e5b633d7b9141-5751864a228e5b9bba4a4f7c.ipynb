# %% [markdown]
# # 请问分钟策略回测不了？

# %% [raw]
# import numpy as np
#
# start = '2015-01-01'                       # 回测起始时间
# end = '2016-04-15'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')           # 证券池，支持股票和基金
# capital_base = 10000000                     # 起始资金
# freq = 'm'                              # 策略类型，'m'表示日内策略使用分钟线回测
# refresh_rate = 60                           # 调仓频率，表示执行handle_data的时间间隔，由于freq = 'm'，时间间隔的单位为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     # dp=account.referencePrice
#     # dpvalue=account.get_attribute_history('turnoverValue',10)
#
#     for stock in account.universe:
#         # 获取成交量
#         amount=account.get_daily_symbol_history(stock, 5)['turnoverVol']
#         yesterday_amount=amount[-1] #昨天成交量
#         yesterday_amount_1=amount[-2] #前天成交量
#         yesterday_amount_5=np.mean( amount[0:-1]) #过去5天成交量均值
#         # 获取价格
#         hist = account.get_attribute_history('closePrice', 2)
#         now_close= hist[stock][-1] #即时价格
#         yesterday_close=account.get_daily_symbol_history(stock, 1)['closePrice'][-1] #昨天收盘价
#
#         if (yesterday_amount> yesterday_amount_1) and (yesterday_amount>yesterday_amount_5):
#             order(stock,10000) #  买入，当昨天成交量大于前天 and 昨天大于前五日平均成交量
#
#         if ( now_close - yesterday_close)/yesterday_close-1>0.05  and stock in account.avail_secpos:
#             order_to(stock, 0)#卖出，当价格涨幅>0.05
