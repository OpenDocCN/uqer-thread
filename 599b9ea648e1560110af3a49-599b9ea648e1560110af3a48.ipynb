# %% [markdown]
# # Notebook6

# %%
import pandas as pd
from pandas import Series, DataFrame

test_CSV= 'test_a.csv'
if test_CSV in list_files():
    delete_files([test_CSV])
list1=['300044.XSHE', u'赛为智能', 20.08,11.38,5000]
list2=['600562.XSHG', u'国睿科技', 27.33,23.20,6000]
df1= pd.DataFrame([list1,list2])
df1.columns=['secID','SecName','price','cost','amount']
df1.set_index('secID',inplace=False)
print 'df1'
print df1
print
df1.to_csv(test_CSV,index=False,mode='a',header='False',encoding='GB18030')
df1.to_csv(test_CSV,index=False,mode='a',header='False',encoding='GB18030')

df2= pd.read_csv(test_CSV,encoding='GB18030')
print 'df2'
print df2
# Out:
# df1
#          secID SecName  price   cost  amount
# 0  300044.XSHE    赛为智能  20.08  11.38    5000
# 1  600562.XSHG    国睿科技  27.33  23.20    6000
#
# df2
#          secID  SecName  price   cost  amount
# 0  300044.XSHE     赛为智能  20.08  11.38    5000
# 1  600562.XSHG     国睿科技  27.33   23.2    6000
# 2        secID  SecName  price   cost  amount
# 3  300044.XSHE     赛为智能  20.08  11.38    5000
# 4  600562.XSHG     国睿科技  27.33   23.2    6000
