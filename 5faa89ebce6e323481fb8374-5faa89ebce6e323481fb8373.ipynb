# %% [markdown]
# # my_boll

# %%
import talib as ta
import math
import pandas as pd
import numpy as np
import quartz_futures as qf
from quartz_futures.api import *
from datetime import datetime

# %% [raw]
# start = '2018-01-01'                       # 回测起始时间
# end = '2018-12-31'                         # 回测结束时间
# universe = ['IFM0']          # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                        # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
#
# # symbol = 'IFM0'
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'futures_account': AccountConfig(account_type='futures', capital_base=1000000)
# }
#
# N = 20
# k1 = 0.07
# k2 = 0.07
# def initialize(context):
#     pass
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     symbol = context.get_symbol(universe[0])
#     futures_account = context.get_account('futures_account') #获取仓位信息
#
#     history_data = context.history(universe[0],attribute=['openPrice','closePrice','highPrice','lowPrice'], time_range=N, freq='1m', style='sat', rtype='frame')
#     # df_data = context.get_symbol_history(symbol, time_range=60, attribute=['openPrice','closePrice','highPrice','lowPrice'], freq='5m', style='sat', rtype='frame')
#     # print(history_data)
#     my_data = history_data[universe[0]]
#     open_price = my_data['openPrice'][-1]
#     close_price = my_data['closePrice'][-1]
#     t = list(my_data['closePrice'].index)[-1]
#     # print(my_data.tail(20))
#     # print(open_price)
#
#
#     max_h = my_data.loc[:,'highPrice'].max()#最高价
#     min_c = my_data.loc[:,'closePrice'].min()#最低收盘价
#
#     max_c = my_data.loc[:,'closePrice'].max()#最高收盘价
#     min_l = my_data.loc[:,'lowPrice'].min()#最低价
#
#     range_value = max(max_h-min_c,max_c-min_l)#取通道宽度系数
#     up_load = open_price + k1*range_value#上轨
#     down_load = open_price - k2*range_value#下轨
#     # print(t,up_load,down_load,close_price,open_price)
#
#     # 限制买卖数量为1手
#     amount = 1 #买卖数量控制为1手
#
#     # 持仓情况
#     current_long = futures_account.get_positions().get(symbol, dict()).get('long_amount', 0) # 获取当前账户多头持仓数量
#     current_short = futures_account.get_positions().get(symbol, dict()).get('short_amount', 0) # 获取当前账户空头持仓数量
#
# #     if close_price > up_load and current_long < amount:
# #         futures_account.order(symbol,amount,'open')#开多
#
# #     if close_price < down_load and current_short < amount:
# #         futures_account.order(symbol,-amount,'open')#开空
#
# #     if close_price < down_load and current_long > 0:
# #         futures_account.order(symbol,-current_long,'close')#平多
#
# #     if close_price > up_load and current_short > 0:
# #         futures_account.order(symbol,current_short,'close')#平空
# #     # print(context.now)
# #     if context.current_minute>="14:59":
# #         if current_short > 0:
# #             futures_account.order(symbol,current_short,'close')
# #         if current_long > 0:
# #             futures_account.order(symbol, -current_long, 'close')
# #         return
#
#
#
# #反过来做
#     if close_price > up_load and current_short < amount:
#         futures_account.order(symbol,-amount,'open')#开空
#
#     if close_price < down_load and current_long < amount:
#         futures_account.order(symbol,amount,'open')#开多
#
#     if close_price < down_load and current_short > 0:
#         futures_account.order(symbol,current_short,'close')#平空
#
#     if close_price > up_load and current_long > 0:
#         futures_account.order(symbol,-current_long,'close')#平多
#
# # #只做上轨
# #     if close_price < up_load and current_long < amount:
# #         futures_account.order(symbol,amount,'open')#开多
#
# #     if close_price > up_load and current_short < amount:
# #         futures_account.order(symbol,-amount,'open')#开空
#
# #     if close_price > up_load and current_long > 0:
# #         futures_account.order(symbol,-current_long,'close')#平多
#
# #     if close_price < up_load and current_short > 0:
# #         futures_account.order(symbol,current_short,'close')#平空
#
# # 不持仓过夜
#
# def main_contract_mapping_changed(context,futures_account):
#     '''
#         处理移仓换月的情况
#     '''
#     if context.mapping_changed(symbol):
#         symbol_before, symbol_after = context.get_rolling_tuple(symbol)
#         if futures_account.get_position(symbol_before):
#             futures_account.switch_position(symbol_before, symbol_after)
#             return True
#
#     return False
