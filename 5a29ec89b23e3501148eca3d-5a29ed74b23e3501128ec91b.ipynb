# %% [markdown]
# # set_universe_and_dynamicuniverse

# %% [raw]
# start = '2016-01-01'                       # 回测起始时间
# end = '2016-01-10'                         # 回测结束时间
# universe = set_universe('HS300')        # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 10                          # 执行handle_data的时间间隔
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#     account = context.get_account('fantasy_account')
#
#     # 分别通过两种方式获取股票池, 并获取其中每只股票的PE
#     u_set_universe = context.get_universe(exclude_halt=True)                                        # set_universe('HS300')
#     f_set_universe = DataAPI.MktStockFactorsOneDayGet(secID=u_set_universe,tradeDate=context.previous_date,field='secID,PE,tradeDate',pandas="1")
#     l_set_universe = f_set_universe.secID.tolist()
#
#     u_dynamic_universe = DynamicUniverse('HS300').preview(context.previous_date, skip_halted=True)  # DynamicUniverse('HS300')
#     f_dynamic_universe = DataAPI.MktStockFactorsOneDayGet(secID=u_dynamic_universe,tradeDate=context.previous_date,field='secID,PE,tradeDate',pandas="1")
#     l_dynamic_universe = f_dynamic_universe.secID.tolist()
#
#     in_set_universe_only = [X for X in l_set_universe if X not in l_dynamic_universe]
#     in_dynamic_universe_only = [X for X in l_dynamic_universe if X not in l_set_universe]
#
#     print u"set_universe('HS300')中有, DynamicUniverse('HS300')中没有: %s个\n" %(len(in_set_universe_only)), in_set_universe_only
#     print u"\nDynamicUniverse('HS300')中有, set_universe('HS300')中没有:  %s个\n" %(len(in_dynamic_universe_only)), in_dynamic_universe_only
