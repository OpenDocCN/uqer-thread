# %% [markdown]
# # Notebook

# %%
DataAPI.EquGet(secID=u"000001.XSHE",ticker=u"",equTypeCD=u"A",listStatusCD=u"",exchangeCD="",ListSectorCD=u"",field=u"",pandas="1")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <mercury-input-1-F56D781C246B49A498DC93829E47B6D3> in <module>()
# ----> 1 DataAPI.EquGet(secID=u"000001.XSHE",ticker=u"",equTypeCD=u"A",listStatusCD=u"",exchangeCD="",ListSectorCD=u"",field=u"",pandas="1")
#
# AttributeError: 'module' object has no attribute 'EquGet'
