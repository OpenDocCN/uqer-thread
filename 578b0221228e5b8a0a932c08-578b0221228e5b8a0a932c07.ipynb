# %% [markdown]
# #

# %%
startdate = '20160714'
J = DataAPI.MktMFutdGet(contractObject='NI',startDate=startdate).loc[:,('secID', 'closePrice','turnoverVol','tradeDate','contractMark','mainCon')]
J
# Out:
#           secID  closePrice  turnoverVol   tradeDate contractMark  mainCon
# 0   NI1607.XSGE       79300          408  2016-07-14           L0        0
# 1   NI1607.XSGE       79300            0  2016-07-15           L0        0
# 2   NI1608.XSGE       81170           48  2016-07-14           L1        0
# 3   NI1608.XSGE       80390           62  2016-07-15           L1        0
# 4   NI1609.XSGE       81770      1085930  2016-07-14           L2        1
# 5   NI1609.XSGE       81200       977862  2016-07-15           L2        1
# 6   NI1610.XSHG       82980          208  2016-07-14           L3        0
# 7   NI1610.XSHG       81440          110  2016-07-15           L3        0
# 8   NI1611.XSGE       82010           16  2016-07-14           L4        0
# 9   NI1611.XSGE       81840            0  2016-07-15           L4        0
# 10  NI1612.XSGE       83010           22  2016-07-14          NaN        0
# ...
