# %% [markdown]
# # 市净率、市盈率选股

# %% [raw]
# import numpy as np
# import pandas as pd
# from pandas import DataFrame,Series
# import talib
# import time
# start = '2007-01-01'                       # 回测起始时间
# end = '2017-01-01'                         # 回测结束时间
# universe = DynamicUniverse('A')     # 证券池，支持股票和基金、期货
# benchmark = 'HS300'
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 66                          # 执行handle_data的时间间隔
# max_history_window=600
# # 执行handle_data的时间间隔
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=1000000)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):
#     # 核心策略逻辑
#     account = context.get_account('fantasy_account')
#     day=context.current_date
#     print day
#
#     data=DataAPI.MktStockFactorsOneDayGet(tradeDate=day,secID=u'',ticker=u"",field=u"secID,PE,PB",pandas="1")
#     data=data[data['PE']<20]
#     data=data[data['PE']>0]
#     data=data.sort(["PB"],ascending=False)
#
#     universe1=list(data['secID'])
#     if len(universe1)>10:
#         universe=universe1[:10]
#     else:
#         universe=universe1
#     per=1/len(universe)
#     orders=account.get_positions().keys()
#     print orders
#     for stk1 in orders:
#         order_pct_to(stk1,0)
#     for stock in universe:
#         order_pct_to(stock,0.1)
