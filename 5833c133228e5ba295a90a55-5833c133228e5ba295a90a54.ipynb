# %% [markdown]
# #

# %% [raw]
# import numpy as np              # 引入n库进行工作?
# from heapq import nlargest, nsmallest    # 多元素求极值
# from CAL.PyCAL import *     # 基本库
# import operator             # 操作符库，加减乘除等
#
# start = '2016-11-18'                       # 回测起始时间
# end = '2016-11-18'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['002233.XSHE','300191.XSHE','300269.XSHE','300119.XSHE','300423.XSHE','600687.XSHG'] # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = (1,['09:45'])               # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     cal = Calendar('China.SSE')            #上交所工作日历
#
#     day_C = account.get_daily_attribute_history('closePrice', 1)
#
#     m_O = account.get_attribute_history('openPrice', 16)#分钟线收盘价
#     for x in account.universe:
#             print x,day_C.get(x,0)[0],m_O.get(x,0)[0]
#     print m_O
#     print day_C
#     return
