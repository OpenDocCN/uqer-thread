# %% [markdown]
# # 简单缩量上涨策略-2十年22倍

# %% [raw]
# import numpy as np
# start = '2006-01-01'                       # 回测起始时间
# end = '2016-04-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe("HS300") # 证券池，支持股票和基金
# capital_base = 10000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# stockList = {}
# def PHG(data, dependencies=['closePrice'], max_window=2):
#     PHG = (data['closePrice'].ix[-1]-data['closePrice'].ix[-2])/data['closePrice'].ix[-2]
#     return PHG
# def VOLR(data, dependencies=['turnoverVol'], max_window=2):
#     VOL =  data['turnoverVol'].ix[0:max_window-1].mean()
#     VOLRATE = (VOL - data['turnoverVol'].ix[-1])/VOL
#     return VOLRATE
#
# def initialize(account):                   # 初始化虚拟账户状态
#     a = Signal('phg',PHG)
#     b = Signal('volrate',VOLR)
#     account.signal_generator=SignalGenerator(a,b)
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     ## 分别建立两个因子
#     signal1=account.signal_result['phg']
#     signal2=account.signal_result['volrate']
#     ## 将两个因子分开判断
#     buyList=signal1[signal1>=0.01].index  &  signal1[signal1<=0.05].index & signal2[signal2>=0.4].index
#     sellList=[]
#     ## 建立证券持仓时间dict
#     for stk in account.valid_secpos.keys():
#         if stk in stockList:
#             stockList[stk] += 1
#         else:
#             stockList[stk] = 1
#     for stk in stockList.keys():
#         if account.referencePrice[stk]/account.valid_seccost[stk]>=1.15 or account.referencePrice[stk]/account.valid_seccost[stk]<=0.85:
#         ## if stockList[stk] >= 18
#             sellList.append(stk)
#     for stk in sellList:
#         if stk not in buyList:
#             order_to(stk, 0)
#             del stockList[stk]
#     for stk in buyList :
#         if stk not in sellList:
#             order_pct(stk, 6.0/300)
#     return
