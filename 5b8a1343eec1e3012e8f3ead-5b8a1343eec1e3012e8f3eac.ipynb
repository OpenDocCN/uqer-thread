# %% [markdown]
# # Notebook1

# %% [raw]
# # 均线策略
# start = '2018-07-30'                  # 回测起始时间
# end = '2018-08-30'                   # 回测结束时间
# benchmark = 'SH50'                   # 策略参考标准
# universe = ['601012.XSHG']              # 证券池，也可以在这里添加多个证券
# capital_base = 50000                  # 起始资金
# freq = 'd'                         # 日线策略
#
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     for stk in universe:
#         account.order(stk,amount=3000,order_type='limit',price=16)
