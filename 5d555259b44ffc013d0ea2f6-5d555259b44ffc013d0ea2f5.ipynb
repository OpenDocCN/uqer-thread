# %% [markdown]
# # 报告策略

# %% [raw]
# import datetime
# import time
#
# start = '2018-04-20'                       # 回测起始时间
# end = '2019-03-31'                         # 回测结束时间
# thisyear = '2018'
# tickers = '000632,300024,300329,002461,300409,002127,300470,002773,300015,300316,300482,300481,002803,000661,300168,002332,300416,300114,300003,300177,603993,000596,002620,600277,300137,000906,200596,300176,000040'
#
# tickers_list = tickers.split(',')
# print tickers_list
# PE_E = '19.48,21.67,17.07,34.55,19.84,19.48,21.67,29.33,46.21,21.67,46.21,19.84,19.84,29.33,44.68,29.33,33.84,33.84,46.21,21.67,19.84,34.55,21.67,19.84,33.84,19.48,34.55,15.01,19.19'
#
# PE_LIST = PE_E.split(',')
# print PE_LIST
#
# stock_pe = {}
#
# for i in range(len(tickers_list)):
#     stock_pe[tickers_list[i]] = PE_LIST[i]
#
# print stock_pe
#
#
# universe =  DataAPI.EquGet(secID=u"",ticker=tickers,equTypeCD=u"A",listStatusCD=u"",field=u"secID",pandas="1")['secID'].values.tolist()       # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=1000000)
# }
#
# buylist = []
#
#
# def initialize(context):
#     pass
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     now_date = context.current_date.strftime('%Y%m%d')
#     previous_date = context.previous_date.strftime('%Y%m%d')
#     current_universe = context.get_universe(exclude_halt=True)
#     # report_stock = DataAPI.FdmtISGet(ticker=u"",secID=current_universe,reportType=u"S1",endDate=u"",beginDate=u"",publishDateEnd=now_date,publishDateBegin=now_date,endDateRep="",beginDateRep="",beginYear=thisyear,endYear=thisyear,fiscalPeriod="",field=u"secID",pandas="1")['secID']
#     report_stock = DataAPI.FdmtEfGet(ticker=u"",secID=current_universe,reportType=u"S1",endDate=u"",beginDate=u"",publishDateEnd=now_date,publishDateBegin=now_date,forecastType="",field=u"",pandas="1")['secID']
#     # 获取当前账户信息
#     account = context.get_account('fantasy_account')
#     current_position = account.get_positions(exclude_halt=True)
#
#     # if context.current_date.date().__gt__(datetime.date(2018,10,31)):
#     if len(current_position) > 0:
#         for stock in set(current_position):
#             # MktEqud = DataAPI.MktEqudGet(secID=stock,ticker=u"",tradeDate=now_date,beginDate=u"",endDate=u"",isOpen="",field=u"ticker,PE1",pandas="1")
#             # ticker = MktEqud['ticker'].values[0]
#             # PE = MktEqud['PE1'].values[0]
#             # # print PE
#             # # print stock_pe[ticker]
#             # if float(PE) > float(stock_pe[ticker]):
#             #     account.order_to(stock, 0)
#
#             if current_position.get(stock).profit/current_position.get(stock).value > 0.1:
#                 MktEqud = DataAPI.MktEqudGet(secID=stock,ticker=u"",tradeDate=now_date,beginDate=u"",endDate=u"",isOpen="",field=u"ticker,PE1",pandas="1")
#                 ticker = MktEqud['ticker'].values[0]
#                 PE = MktEqud['PE1'].values[0]
#                 # print PE
#                 # print stock_pe[ticker]
#                 if float(PE) > float(stock_pe[ticker]):
#                     account.order_to(stock, 0)
#
#
#     if len(report_stock) > 0:
#
#         stocknum = len(report_stock) + len(current_position)
#
#         # for stock in set(current_position):
#         #     price = context.current_price(stock)
#         #     amount = int(account.portfolio_value/stocknum/price/100)*100
#         #     account.order_to(stock, amount)
#
#         for stock in report_stock:
#             price = context.current_price(stock)
#             # amount = int(account.portfolio_value/stocknum/price/100)*100
#             amount = int(1000000/len(tickers_list))
#             account.order(stock, amount)
