# %% [markdown]
# # 数据bug报告

# %%
security2 = DataAPI.MktFutdGet(ticker = u'rb1610', beginDate=u'20160420', endDate=u'20160420')
security2
# Out:
#          secID  ticker exchangeCD secShortName   tradeDate contractObject  \
# 0  RB1610.XSHG  rb1610       XSGE      沪螺钢1610  2016-04-20             RB
#
#    contractMark  preSettlePrice  preClosePrice  openPrice    ...     \
# 0           NaN            2446           2494       2501    ...
#
#    closePrice  settlePrice  turnoverVol  turnoverValue  openInt  CHG  CHG1  \
# 0        2592         2561     15687854   4.017828e+11  3329118  146   115
#
#      CHGPct  mainCon  smainCon
# 0  0.059689        1         0
#
# [1 rows x 22 columns]
