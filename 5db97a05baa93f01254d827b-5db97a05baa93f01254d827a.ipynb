# %% [markdown]
# # quartz3回测框架中002587.XSHE 20170606除权日未进行复权

# %% [raw]
# start = '2019-01-01'                       # 回测起始时间
# end = '2019-07-01'                         # 回测结束时间
# universe = ['600570.XSHG']       # 证券池，支持股票和基金、期货
# benchmark = '600570.XSHG'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 1                           # 执行handle_data的时间间隔
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#     account = context.get_account('fantasy_account')
#
#     account.order_pct_to('600570.XSHG', 1)
