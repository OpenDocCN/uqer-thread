# %% [markdown]
# # 简单的缩量上涨策略

# %% [raw]
# import numpy as np
# start = '2006-01-01'                       # 回测起始时间
# end = '2016-04-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe("HS300") # 证券池，支持股票和基金
# capital_base = 10000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# stockList = {}
# def rateandvol(data, dependencies=['closePrice','openPrice','turnoverVol'], max_window=2):
#     PHG = (data['closePrice'].ix[-1]-data['closePrice'].ix[-2])/data['closePrice'].ix[-2]
#     VOL =  data['turnoverVol'].ix[0:max_window-1].mean()
#     VOLRATE = (VOL - data['turnoverVol'].ix[-1])/data['turnoverVol'].ix[-1]
#     PHG[PHG<=0] = 0
#     PHG[PHG>=0.095] = 0
#     return PHG * VOLRATE
#
# def initialize(account):                   # 初始化虚拟账户状态
#     a = Signal('alpha',rateandvol)
#     account.signal_generator=SignalGenerator(a)
#     pass
#
# def handle_data(account):                 # 每个交易日的买入卖出指令
#     ## 建立缩量上涨因子
#     signal=account.signal_result['alpha']
#     #signal=signal.rank()
#     buyList=signal[signal>=0.006].index
#     sellList=[]
#     ## 利用stockList判断每只股票的持有天数
#     for stk in account.valid_secpos.keys():
#         if stk in stockList:
#             stockList[stk] += 1
#         else:
#             stockList[stk] = 1
#     ## 先对需要卖出的股票进行判断
#     for stk in stockList.keys():
#         if account.referencePrice[stk]/account.valid_seccost[stk]>=1.15 or account.referencePrice[stk]/account.valid_seccost[stk]<=0.85:
#         ## if stockList >= 12:
#             sellList.append(stk)
#     for stk in sellList:
#         if stk not in buyList:
#             order_to(stk, 0)
#             del stockList[stk]
#     ##建仓
#     for stk in buyList :
#         if stk not in sellList:
#             order_pct(stk, 0.01)
#     return
