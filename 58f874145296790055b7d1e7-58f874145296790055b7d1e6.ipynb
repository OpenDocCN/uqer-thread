# %% [markdown]
# # 赚钱效应

# %% [raw]
# start = '2015-01-01'                       # 回测起始时间
# end = '2015-01-10'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# #universe = 'A'  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# import numpy as np
# import pandas as pd
# from CAL.PyCAL import *
# import time
#
# def de_new(tradeDate):
#     de_new=[]
#     cal = Calendar('China.SSE')
#     last_day = cal.advanceDate(tradeDate,'-1B',BizDayConvention.Preceding)
#     tmp = DataAPI.EquGet(equTypeCD="A", field=['ticker', 'secID', "listDate"])
#     tmp.dropna(inplace=True)
#     for i in tmp.index:
#         if tmp.listDate[i][:4] < '2017':
#             de_new.append(tmp.secID[i])
#             continue
#
#         equ_pool = DataAPI.MktEqudGet(tradeDate=u"",secID=tmp.secID[i], ticker=u"",beginDate=tmp.listDate[i],endDate=last_day,isOpen="",
#                                       field=u"highestPrice,lowestPrice",pandas="1")
#         equ_pool['dif'] = equ_pool['highestPrice'] - equ_pool['lowestPrice']
#         if equ_pool['dif'].sum() != 0:
#             de_new.append(tmp.secID[i])
#     return de_new
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     today=account.current_date
#     time1=time.time()
#     df=de_new(today)
#     time2=time.time()
#     print time2-time1
#
#     #print df
#     return
