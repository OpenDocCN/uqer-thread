# %% [markdown]
# # 均线系统3.0

# %% [raw]
# import numpy as np
# import pandas as pd
# import talib
#
# start = '2018-02-01'
# end = '2018-10-01'
# universe = ['RB1901']
# benchmark = 'HS300'
# freq = 'd'
# refresh_rata = 1
# margin_rate = 0.2
#
# accounts = {
#     'self_account':AccountConfig(account_type = 'futures',capital_base = 100000)
# }
#
# def initialize(context):
#     pass
#
# def handle_data(context):
#     account = context.get_account('self_account')
#     universe = context.get_universe()
#     data = context.history(universe,'closePrice',15,retype = 'array')
#     log.info(data[universe[0]])
#     close_price = np.array(data[universe[0]]['closePrice'])
#     position = account.get_position(universe[0])
#     short_MA = talib.MA(close_price,5)
#     long_MA = talib.MA(close_price,10)
#
#     # log.info(short_MA)
#     # log.info(universe)
#
#     if not position:
#         if short_MA[-2]<long_MA[-2] and short_MA[-1] > long_MA[-1]:
#             account.order_pct(universe[0],1)
#     else:
#         if short_MA[-2]>long_MA[-2] and short_MA[-1] <long_MA[-1]:
#             account.order_pct_to(universe[0],0)
