# %% [markdown]
# # 数据获取以及转存

# %% [markdown]
# 1. 获取数据
# --------------------
# ***

# %% [markdown]
# 我们提供了``DataAPI``帮助你获取各种行情，基本面数据。

# %%
data = DataAPI.MktEqudAdjGet(ticker = '600000')

# %%
data.tail()
# Out:
#             secID  ticker exchangeCD secShortName secShortNameEn   tradeDate  \
# 2268  600000.XSHG  600000       XSHG         浦发银行       SPD Bank  2015-05-11
# 2269  600000.XSHG  600000       XSHG         浦发银行       SPD Bank  2015-05-12
# 2270  600000.XSHG  600000       XSHG         浦发银行       SPD Bank  2015-05-13
# 2271  600000.XSHG  600000       XSHG         浦发银行       SPD Bank  2015-05-14
# 2272  600000.XSHG  600000       XSHG         浦发银行       SPD Bank  2015-05-15
#
#       preClosePrice  openPrice  highestPrice  lowestPrice  closePrice  \
# 2268          17.11      16.98         17.31        16.79       17.27
# 2269          17.27      17.25         17.40        17.04       17.24
# 2270          17.24      17.33         17.39        16.90       17.07
# 2271          17.07      17.10         17.25        16.94       16.99
# 2272          16.99      16.91         17.07        16.59       16.78
#
#       turnoverVol  turnoverValue
# 2268    277153427     4711900631
# ...

# %% [markdown]
# 2. 存储数据
# ------------------
# ***

# %% [markdown]
# 数据保存只需要一行代码：

# %%
data.to_csv(u'spd_data.csv')

# %% [markdown]
# 接着就可以在你的``data``页下看到你保存的数据。

# %% [markdown]
# ![image](http://ww2.sinaimg.cn/large/63ef6a8dgw1es8b86zblyj21g30oswpx.jpg)
