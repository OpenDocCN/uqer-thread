# %% [markdown]
# # BOLL

# %% [markdown]
# 布林线策略，当股价低于布林线下限时买进股票，当股票高于布林线上限时，卖出股票。
# 增加来对股票市盈率的限制<0,30>
# 回测来16年到今天的数据，长期由于HS300基准。

# %% [raw]
# import numpy as np
#
# start = '2016-01-01'                       # 回测起始时间
# end = '2018-03-28'                         # 回测结束时间
# universe = DynamicUniverse('HS300')        # 证券池，支持股票、基金、期货、指数四种资产
# #universe = ['000002.XSHE','000001.XSHE']
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，
# atr = ['PE','BollDown','BollUp','preClosePrice','closePrice']
# aberro = 0.015
# capital_base=1000000
# commission = Commission(buycost = 0.0003, sellcost = 0.002, unit = 'perValue')
#
# accounts = {
#     'layne': AccountConfig(account_type='security',capital_base=capital_base,commission=commission)
# }
#
# def initialize(context):
#     pass
#     #atr = ['PE', 'PB','BollDown','BollUp','NetProfitGrowRate']
#
# def handle_data(context):
#     universe=context.get_universe(exclude_halt=True)
#     data = context.history(universe, atr, 1, freq='1d', rtype='frame', style='sat')
#     account = context.get_account('layne')
#     #help(account)
#     for stk in universe:
#         bd = data[stk]['BollDown'].values
#         bu = data[stk]['BollUp'].values
#         pp = data[stk]['preClosePrice'].values
#         cp = data[stk]['closePrice'].values
#         pe = data[stk]['closePrice'].values[0]
#         #print bd,bu,pp,cp
#         if np.sum(pp < bd)==1 & np.sum(cp > bd)==1 & (pe<np.float64(30)) & (pe > np.float64(0.5)):
#             account.order_pct(stk, 0.1)
#         if np.sum(pp > bu)==1 & np.sum(cp < bu)==1:
#             if stk in account.get_positions():
#                 account.order_to(stk, 0)
