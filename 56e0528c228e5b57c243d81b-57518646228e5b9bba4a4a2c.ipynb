# %% [markdown]
# # 10日 240日量线

# %% [raw]
# from CAL.PyCAL import *
# import operator
# start = '2016-03-06'
# end = '2016-03-07'
# benchmark = 'HS300'
# universe = set_universe('A')
# #universe = ['000001.XSHE']
# capital_base = 1000000
# freq = 'd'
# refresh_rate = 1
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     cal = Calendar('China.SSE')   # 上交所交易日历
#     last_day = cal.advanceDate(Date.fromDateTime(account.current_date),'-1B',BizDayConvention.Preceding)   # 计算前一个交易日
#     last_day_str = last_day.strftime("%Y%m%d")
#
#     # 使用DataAPI.MktStockFactorsOneDayGet拿取PE数据
#     vol5 = DataAPI.MktStockFactorsOneDayGet(tradeDate=last_day_str,secID=account.universe,field='secID,VOL5').sort('secID')
#     vol10 = DataAPI.MktStockFactorsOneDayGet(tradeDate=last_day_str,secID=account.universe,field='secID,VOL5').sort('secID')
#     vol240 = DataAPI.MktStockFactorsOneDayGet(tradeDate=last_day_str,secID=account.universe,field='secID,VOL120').sort('secID')
#     lflo=DataAPI.MktStockFactorsOneDayGet(tradeDate=last_day_str,secID=account.universe,field='secID,LCAP').sort('secID')
#     #print lflo
#     print '*************************************'
#     print account.current_date
#     #print vol5
#     print '*************************************'
#     #print vol240
#     #for i in vol5.secID:
#         #print i
#     count=0
#     list=[]
#     list2=[]
#     for i in xrange(0,  len(account.universe)-1  ):
#         #print vol10.loc[1689][0]
#         #print len(account.universe)-1
#         #print vol10.loc[i][0]
#         #print vol240.loc[i][0]
#         #print vol10.loc[i][1]
#         #print vol240.loc[i][1]
#         if( vol10.loc[i][1]>2*vol240.loc[i][1]  ):
#             #print '________________________________'
#             #print vol10.loc[i][0]+str(vol10.loc[i][1])
#             #print vol240.loc[i][0]+str(vol240.loc[i][1])
#             ratio=vol10.loc[i][1]/vol240.loc[i][1]
#             #print ratio
#             list.append( [ vol5.loc[i][0] , vol5.loc[i][1] , vol10.loc[i][1] ,vol240.loc[i][1] , ratio ] )
#             count+=1
#         list2.append( [lflo.loc[i][0],lflo.loc[i][1]] )
#
#     print count
#     print list
#     list.sort(key=operator.itemgetter(4),reverse=1)
#     list2.sort(key=operator.itemgetter(1),reverse=0)
#     for i in xrange(0,len(list)-1):
#         print str(list[i][0])+' '+str(list[i][1])+' '+str(list[i][2])+' '+str(list[i][3])+' '+str(list[i][4])
#     print list2
#     for j in xrange(0,len(list2)-1):
#         print str(list2[j][0])+' '+str(list2[j][1])
