# %% [markdown]
# #

# %% [raw]
# start = '2016-1-28'                       # 回测起始时间
# end = '2016-9-14'
# benchmark = '002142.XSHE'                        # 策略参考标准
# universe = ['002142.XSHE']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 60
# commission = Commission(buycost=0.0003, sellcost=0.0001)
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
# def handle_data(account):
#     cp= account.get_daily_attribute_history('closePrice', 1)['002142.XSHE'][0]
#     op = account.get_attribute_history('openPrice', 1)['002142.XSHE'][0]
#     np=account.get_attribute_history('closePrice',1)['002142.XSHE'][0]
#     up=np/cp-1
#     down=cp/np-1
#     for s in account.universe:
#         if 0.01<=down<0.02:
#             order_pct(s,0.1)
#         elif 0.02<=down<0.03:
#             order_pct(s,0.2)
#         if 0.03<=down<0.04:
#             order_pct(s,0.4)
#
#     for s in account.avail_secpos:
#         if 0.01<=up<0.02:
#             order_pct_to(s,0.6)
#         elif 0.03<=up<0.04:
#             order_pct_to(s,0)
