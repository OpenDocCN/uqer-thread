# %% [markdown]
# # Notebook

# %% [raw]
# import pandas as pd
# import numpy as np
#
# ########################### 初始化配置 ###########################
# start = '2010-01-20'                     # 回测起始时间
# end = '2010-01-23'                         # 回测结束时间
#
# n=5
#
# ########################
# freq = 'm'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = (1,n)                  # 执行handle_data的时间间隔
# benchmark = 'HS300'                        # 策略参考基准
# universe = DynamicUniverse('A')
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=60000,
#                                      commission = Commission(buycost=0.001, sellcost=0.002, unit='perValue'))
# }
#
# ############################ 策略逻辑 ############################
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#     current_universe = context.get_universe(exclude_halt=True)
#     date_yesterday = context.previous_date.strftime('%Y-%m-%d')
#     date_today = context.current_date.strftime('%Y-%m-%d')
#     time_now = context.now.strftime('%Y-%m-%d %H-%M-%S')
#     hour_minute = time_now[11:16]
#     log.info(hour_minute)
#     if hour_minute == '09-30':
#         target_symbol_list_1=['002178.XSHE']
#         open_today_dict = context.history(target_symbol_list_1, ['closePrice'], 1, freq='5m', style='sat', rtype='frame')
#         num_target_symbol_list_1 = len(target_symbol_list_1)
#         ###########################   交易执行   ####################
#         ##账户状态查询
#         account = context.get_account('fantasy_account')
#         positions = account.get_positions()
#         log.info(positions)
#         ###买入进入list的股票
#         if account.cash / account.portfolio_value >=0.1:  ##账户现金仓位较大时买入
#             if num_target_symbol_list_1 > 0:   ##有买入标的时买入
#                 for stock in target_symbol_list_1:
#                     log.info(stock)
#                     open_price = open_today_dict[stock]['closePrice'][0]  ##当日开盘价
#                     log.info(open_price)
#                     weight = 1.0 / num_target_symbol_list_1    ##个股买入比例
#                     cash_each_symbol = weight * account.cash   ##个股买入资金
#                     volume = cash_each_symbol / open_price   ##个股买入股数
#                     account.order_to(stock, volume, price=open_price, order_type='limit')  ##限价单买入
