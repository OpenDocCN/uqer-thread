# %% [markdown]
# # get_symbol_history 函数在获取部分股票的价格时会返回0

# %% [markdown]
# account.get_symbol_history 函数在获取部分股票的价格时会返回0.参考代码如下：

# %% [raw]
# start = '2014-01-01'                       # 回测起始时间
# end = '2015-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['HS300']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# longest_history = 30
# max_history_window = 300
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     for stock in account.universe:
#         sym = account.get_symbol_history(stock, longest_history)
#         # log.info(sym)
#         if sym['openPrice'][-1] == 0:
#             log.info('Get Open Price failed' + stock + str(sym['openPrice']))
#         if sym['highPrice'][-1] == 0:
#             log.info('Get High Price failed' + stock + str(sym['highPrice']))
#         if sym['lowPrice'][-1] == 0:
#             log.info('Get Low Price failed' + stock + str(sym['lowPrice']))
#         if sym['closePrice'][-1] == 0:
#             log.info('Get Close Price failed' + stock + str(sym['closePrice']))
#     return
