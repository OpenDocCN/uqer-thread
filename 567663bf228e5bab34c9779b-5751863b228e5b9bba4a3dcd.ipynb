# %% [markdown]
# # 博客_生存者偏差对策略评价的影响_消除生存者偏差问题

# %% [markdown]
# 接前一篇文章：博客_生存者偏差对策略评价的影响
# url:https://uqer.datayes.com/community/share/567524b9228e5bab34c97782
# 参考：jiang.wei意见
# 使用set_universe('HS300',date)方式消除生存者误差带来的指数跟踪影响
#
# 通过模拟hs300和sh50可以发现，消除了生存者偏差后，和真实指数已经很接近了，
# 牛市时依然会有较大偏差，原因应该在权重了

# %% [raw]
# #先测试hs300
#
# import math
# start = '2011-01-01'                       # 回测起始时间
# end = '2015-12-15'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe =set_universe('HS300',start)          # 证券池，支持股票和基金
# capital_base = 10000000                     # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 80                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# commission=Commission(buycost=0.000, sellcost=0.000, unit='perValue')
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     universe=set_universe('SH50',account.current_date)
#     stocks_prices=account.get_attribute_history('closePrice',2)
#
#     for stockSecID in account.valid_secpos.keys():
#         order_to(stockSecID,0)
#     for stockSecID in account.universe:
#         if  math.isnan(account.referencePrice[stockSecID]):
#             continue
#         order(stockSecID,account.referencePortfolioValue/len(account.universe)/account.referencePrice[stockSecID])

# %% [raw]
# #再测试sh50
#
# import math
# start = '2011-01-01'                       # 回测起始时间
# end = '2015-12-15'                         # 回测结束时间
# benchmark = 'SH50'                        # 策略参考标准
# universe =set_universe('SH50',start)          # 证券池，支持股票和基金
# capital_base = 10000000                     # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 80                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# commission=Commission(buycost=0.000, sellcost=0.000, unit='perValue')
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     universe=set_universe('SH50',account.current_date)
#     stocks_prices=account.get_attribute_history('closePrice',2)
#
#     for stockSecID in account.valid_secpos.keys():
#         order_to(stockSecID,0)
#     for stockSecID in account.universe:
#         if  math.isnan(account.referencePrice[stockSecID]):
#             continue
#         order(stockSecID,account.referencePortfolioValue/len(account.universe)/account.referencePrice[stockSecID])

# %% [markdown]
# 从上面来看震荡市时已经很接近指数了，在大牛或者大熊是旧会有偏差，原因在于采用了等权方式
