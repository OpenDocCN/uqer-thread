# %% [markdown]
# # 戴维·波伦投资

# %% [raw]
# start = '2018-05-14'                       # 回测起始时间
# end = '2018-05-17'                         # 回测结束时间
# universe = DynamicUniverse('HS300')        # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = Monthly(1)                  # 执行handle_data的时间间隔
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=5000)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#     account = context.get_account('fantasy_account')
#     current_universe = context.get_universe(exclude_halt=True)
#     df_factor= context.history(current_universe, ['LCAP','DebtEquityRatio','PCF','ROE','NetProfitGrowRate','ROIC'], 1, freq='1d', rtype='frame',style='tas')
#
#     yesterday = context.previous_date.strftime('%Y-%m-%d')
#     df_factor = df_factor[yesterday]
#     #筛选条件满足：
#     #总市值大于市场平均值
#     #产权比率小于市场平均值
#     #市现率大于0且小于市场均值的三分之二
#     #ROE大于市场平均值
#     #净利润同比增长率大于市场平均值
#     #投入资本回报率大于市场平均值
#     #投入资本回报率大于市场基准利率（此处取3.5%）
#     df_factor = df_factor[df_factor['PCF'] > 0]
#     df_factor = df_factor[(df_factor['LCAP'] > df_factor['LCAP'].mean())
#                           & (df_factor['DebtEquityRatio'] < df_factor['DebtEquityRatio'].mean())
#                           & (df_factor['PCF'] < 2.0/3*df_factor['PCF'].mean())
#                           & (df_factor['ROE'] > df_factor['ROE'].mean())
#                           & (df_factor['NetProfitGrowRate'] > df_factor['NetProfitGrowRate'].mean())
#                           & (df_factor['ROIC'] > df_factor['ROIC'].mean())
#                           & (df_factor['ROIC'] > 0.035)]
#
#     account = context.get_account('fantasy_account')
#
#     # 确定目标仓位
#     target_position = list(df_factor.index)
#
#     # 计算权重
#     if len(target_position) > 0:
#         weight = min(0.1, 1.0/len(target_position))
#     else:
#         weight = 0
#
#     current_position = account.get_positions(exclude_halt=True)
#
#     # 卖出当前持有，但目标持仓没有的部分
#     for stk in set(current_position).difference(target_position):
#         account.order_to(stk, 0)
#
#     for stk in target_position:
#         account.order_pct_to(stk,weight)
