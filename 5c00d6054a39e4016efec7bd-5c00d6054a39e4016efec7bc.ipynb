# %% [markdown]
# # 货币基金购买

# %% [raw]
# start = '2017-01-01'                       # 回测起始时间
# end = '2018-01-01'                         # 回测结束时间
# universe = ['511690.OFCN']        # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
#
# accounts = {
#     'fantasy_account': AccountConfig('otc_fund', capital_base=10000,
#                                       commission=Commission(buycost=0.001, sellcost=0.001, unit='perValue'),
#                                       dividend_method='cash_bonus'),
# }
# def initialize(context):
#     pass
#
#
# def handle_data(context):
#
#     account = context.get_account('fantasy_account')
#     current_position = account.get_positions()
#     if len(current_position) == 0:
#         account.purchase('511690.OFCN', 10000)
