# %% [markdown]
# # Notebook0

# %% [raw]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from datetime import datetime
#
# universe = set_universe('A')
# #日期列表
# date=DataAPI.TradeCalGet(exchangeCD=u"XSHG,XSHE",beginDate=u"20150101",endDate=u"20161222",field=u"calendarDate,isOpen,isMonthEnd",pandas="1")
# date=date[date['isOpen']==1]
# date=date[date['isMonthEnd']==1]
# date=date['calendarDate']
# datelist=date.tolist()
# datelist=[v.replace('-','') for v in datelist]
# retnmean_main=[]
# for dt in datelist:
#     retnmean_body=[]
#
#  #数据处理
#
#     data=DataAPI.MktEqudAdjGet(tradeDate=dt,secID=universe,ticker=u"",field=u"secID,secShortName,tradeDate,marketValue,openPrice,highestPrice,lowestPrice,turnoverVol,isOpen",pandas="1")
#     data=data[data['turnoverVol']>0][~(data['lowestPrice']==data['highestPrice'])][~(data['openPrice']==data['highestPrice'])]
#     data=data.dropna()
#     data=data.sort(columns='marketValue',ascending=True)
#     data.index=range(len(data))
#     #print data
# #分成十组
#     data1=data[:int(len(data)*0.1)]
#     data2=data[int(len(data)*0.1):int(len(data)*0.2)]
#     data3=data[int(len(data)*0.2):int(len(data)*0.3)]
#     data4=data[int(len(data)*0.3):int(len(data)*0.4)]
#     data5=data[int(len(data)*0.4):int(len(data)*0.5)]
#     data6=data[int(len(data)*0.5):int(len(data)*0.6)]
#     data7=data[int(len(data)*0.6):int(len(data)*0.7)]
#     data8=data[int(len(data)*0.7):int(len(data)*0.8)]
#     data9=data[int(len(data)*0.8):int(len(data)*0.9)]
#     data10=data[int(len(data)*0.9):]
#     #print data1,data2
# #计算平均收益
#
# retn1=DataAPI.MktEqumAdjGet(secID=data1.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"",beginDate=u"",endDate=u"",field=u"secID,endDate,return",pandas="1")
# #retnmean1=retn1['return'].mean()
# #retnmean_body.append(retnmean1)
#
# #retn2=DataAPI.MktEqumAdjGet(secID=data2.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"",beginDate=u"",endDate=u"",field=u"secID,endDate,return",pandas="1")
# #retnmean2=retn2['return'].mean()
# #retnmean_body.append(retnmean2)
#
# #retn3=DataAPI.MktEqumAdjGet(secID=data3.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"",beginDate=u"",endDate=u"",field=u"secID,endDate,return",pandas="1")
# #retnmean3=retn3['return'].mean()
# #retnmean_body.append(retnmean3)
#
# #retn4=DataAPI.MktEqumAdjGet(secID=data4.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"",beginDate=u"",endDate=u"",field=u"secID,endDate,return",pandas="1")
# #retnmean4=retn4['return'].mean()
# #retnmean_body.append(retnmean4)
#
# #retn5=DataAPI.MktEqumAdjGet(secID=data5.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"",beginDate=u"",endDate=u"",field=u"secID,endDate,return",pandas="1")
# #retnmean5=retn5['return'].mean()
# #retnmean_body.append(retnmean5)
#
# #retn6=DataAPI.MktEqumAdjGet(secID=data6.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"",beginDate=u"",endDate=u"",field=u"secID,endDate,return",pandas="1")
# #retnmean6=retn6['return'].mean()
# #retnmean_body.append(retnmean6)
#
# #retn7=DataAPI.MktEqumAdjGet(secID=data7.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"",beginDate=u"",endDate=u"",field=u"secID,endDate,return",pandas="1")
# #retnmean7=retn7['return'].mean()
# #retnmean_body.append(retnmean7)
#
# #retn8=DataAPI.MktEqumAdjGet(secID=data8.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"",beginDate=u"",endDate=u"",field=u"secID,endDate,return",pandas="1")
# #retnmean8=retn8['return'].mean()
# #retnmean_body.append(retnmean8)
#
# #retn9=DataAPI.MktEqumAdjGet(secID=data9.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"",beginDate=u"",endDate=u"",field=u"secID,endDate,return",pandas="1")
# #retnmean9=retn9['return'].mean()
# #retnmean_body.append(retnmean9)
#
# #retn10=DataAPI.MktEqumAdjGet(secID=data10.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"",beginDate=u"",endDate=u"",field=u"secID,endDate,return",pandas="1")
# #retnmean10=retn10['return'].mean()
# #retnmean_body.append(retnmean10)
#
# #retn0=DataAPI.MktEqumAdjGet(secID=universe,ticker=u"",monthEndDate=dt,isOpen=u"",beginDate=u"",endDate=u"",field=u"secID,endDate,return",pandas="1")
# #retnmean0=retn0['return'].mean()
# #retnmean_body.append(retnmean0)
# #retnmean_main.append(retnmean_body)
# #new_mean = pd.DataFrame(retnmean_main,index=datelist,columns=['retnmean1','retnmean2','retnmean3','retnmean4','retnmean5','retnmean6','retnmean7','retnmean8','retnmean9','retnmean10','retnmean0'])
# #print dt,retnmean1,retnmean2,retnmean3,retnmean4,retnmean5,retnmean6,retnmean7,retnmean8,retnmean9,retnmean10,retnmean0
# print retn1
# #new_mean.at(datelist[0],'retnmean1')#<pandas.core.indexing._AtIndexer at 0x5897e10>
# #第二步：计算月平均收益率差——TOP 20%（第一档）- BOTTOM 20%（第五档），TOP 40%（第一、二档）- BOTTOM 40%（第四、五档）
