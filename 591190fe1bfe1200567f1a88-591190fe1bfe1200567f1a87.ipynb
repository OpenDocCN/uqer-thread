# %% [markdown]
# # 期权交易

# %% [raw]
# universe ='SRL1'                          # 策略期货合约'510050.XSHG' #
# start = '2017-04-25'                       # 回测开始时间
# end  = '2017-04-28'                        # 回测结束时间
# capital_base = 1000000                     # 初试可用资金
# refresh_rate = 1                          # 调仓周期
# freq = 'd'                                 # 调仓频率：m-> 分钟；d-> 日
#
# def initialize(futures_account):           # 初始化虚拟期货账户，一般用于设置计数器，回测辅助变量等。
#     pass
#
# def handle_data(futures_account):          # 回测调仓逻辑，每个调仓周期运行一次，可在此函数内实现信号生产，生成调仓指令。
#     dat=futures_account.current_date.replace('-', '')
#     d=DataAPI.MktOptdGet(tradeDate=dat,secID=u"",optID=u"",ticker=u"510050P1709M02300",field=u"",pandas="1")  #SR707C6800,M1709-P-2700,openPrice,closePrice,510050P1709M02300.XSHG  10000849
#
#     print d
#     order('SR707C6800', 1,'open')
#     order('510050P1709M02300.XSHG', 1,'open')
#     order('M1709-P-2700', -1,'open')
#     return
