# %% [markdown]
# # 区间交易

# %% [raw]
# import pandas as pd
#
# start = '2016-12-22'
# end   = '2016-12-29'
# benchmark = 'SH50'
# universe = ['002346.XSHE']
# capital_base = 100000
# fre='m'
# refresh_rate = 1
#
# def initialize(account):
#     account.i=0
#     pass
#
# def handle_data(account):
#     account.i=account.i+1
#     print(account.i)
#     for s in account.universe:
#         order_to(s,1000,price=30.2,otype='limit')
#     orderHis=get_orders(OrderStatus.FILLED,'002346.XSHE')
#     print(orderHis)
