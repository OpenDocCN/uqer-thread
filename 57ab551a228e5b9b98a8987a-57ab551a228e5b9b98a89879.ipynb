# %% [markdown]
# #

# %%
import pandas as pd
import numpy as np
import random
import datetime


start = '2016-08-01'                       # 回测起始时间
end = '2016-08-09'                         # 回测结束时间
#benchmark = 'HS300'                        # 策略参考标准
universe = set_universe('A')                  #StockScreener(Factor.LFLO.value_range(1,np.log(3e9)))
capital_base = 1000000000                      # 起始资金
freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
stk_num = 5

def initialize(account):                   # 初始化虚拟账户状态
    print 'now initialize'
    
def handle_data(account):
    buy_list = {}
    print 'now now'
    print 'now now now'
