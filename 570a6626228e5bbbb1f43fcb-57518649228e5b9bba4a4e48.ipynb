# %% [markdown]
# # 银行日内轮动-测试版

# %% [raw]
# import pandas as pd
# start = '2011-02-15'                       # 回测起始时间
# end = '2012-04-08'                         # 回测结束时间
# benchmark = '000947.ZICN'                        # 策略参考标准
# universe = set_universe('000947.ZICN')  # 证券池，支持股票和基金
# capital_base = 1000000                      # 起始资金
# commission = Commission(buycost=0.0008, sellcost=0.0018)  # 佣金万八
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 235                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
# def signle(account):
#     c = {'stock':[], 'openPrice':[],'1455closePrice':[],'stop':[]}
#     stockAll = DataAPI.IdxConsGet(secID=u"",ticker=u"000947",intoDate=u"",isNew=u"",field=u"consID",pandas="1")
#     for stock in stockAll['consID']:
#         d = account.get_symbol_history(stock,235)
#         a = DataAPI.MktTickRTSnapshotGet(securityID=stock,exchangeCD="",assetClass="",field=u"suspension",pandas="1")
#         c['stock'].append(stock)    #表示字典c的键增加元素stock
#         c['openPrice'].append(d['openPrice'][0])
#         c['1455closePrice'].append(d['closePrice'][-1])
#         c['stop'].append(a['suspension'][0])
#     iAll = pd.DataFrame(c, columns=['stock', 'openPrice','1455closePrice','stop'])
#     iAll = iAll.dropna(axis=0)
#     iAll = iAll[iAll['stop']==0]    #判断是否停盘，停盘就不要
#     iAll['rate']=((iAll['1455closePrice']-iAll['openPrice'])/iAll['openPrice'])
#
#     selllist=iAll[iAll['rate']==max(iAll['rate'])]
#     buylist=iAll[iAll['rate']!=max(iAll['rate'])]
#     return selllist,buylist
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     if account.current_minute == '14:55':
#         selllist,buylist = signle(account)
#         for stock in selllist['stock']:
#             if stock in account.valid_secpos.keys():
#                 order_to(stock, 0)    #将可卖头寸中进入selist的头寸清空
#             #print selllist,buylist
#         for stock in buylist['stock']:
#             order_pct(stock, 0.004)
