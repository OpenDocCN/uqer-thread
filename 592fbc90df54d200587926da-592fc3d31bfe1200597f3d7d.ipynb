# %% [markdown]
# # 优矿策略学习笔记整理02

# %% [markdown]
# ## 接上一篇帖子《优矿策略学习笔记整理01》
#
# ------------------
#
# **01.alpha-smart-dog_三个臭皮匠-集成算法框架上手**
# 地址：https://uqer.datayes.com/community/share/58562a9f6a5e6d0052291ebe?source=weeklyol20
# 简述：
# 用机器学习预测涨跌，这个个人感觉有点问题，
# 1，长期信号不适合预测短期波动
# 2，样本内外表现差异大，不具有合计操作性（类似死记硬背机制）
#
# **02.zhongliang.zhou_算法交易入门（04：HS300主成份统计分析）**
# 地址：https://uqer.datayes.com/community/share/57578626228e5b8a3e285dd1
# 主成分分析HS300，
# 不过PCA使用的部分函数没看太懂
#
# **03.minghong_蛋卷安睡全天候(海外)**
# 地址：https://uqer.datayes.com/community/share/57aaf134228e5b9b95a88a2b
# 不同资产组合和对应收益率信息
# 蛋卷安睡全天候(海外)，等权组合，波动率倒数加权，最小VaR
# 量化分析师的Python日记【第15天：如何在优矿上搞一个wealthfront出来】:https://uqer.datayes.com/community/share/5670da3c228e5b8d81f00a87
# 在险价值(Value at Risk)风险度量下的资产组合前沿：https://uqer.datayes.com/community/share/57aa83f8228e5b9b95a88894
# 类似的：优矿(uqer)团队_独家重磅：Smart Beta洪荒之力全解析:https://xueqiu.com/4105947155/73151817
#
# **04.jiang.wei_【资产配置】风险平价组合(risk parity)理论与实践**
# 地址：https://uqer.datayes.com/community/share/58071f49228e5b1627bc33a8
# 不同资产组合方式(min variance,risk parity,max diversification,equal weight)，以及新增资产标的对组合影响。的分析比对
#
# **05.摘帽预期下的ST投资策略**
# 地址：https://uqer.datayes.com/community/share/58b8ceede9aebf0057330380
# 提前预测摘帽，这个思路个人感觉非常好
#
# **06.minghong_沉浮股海之涨停板分析**
# 地址：https://uqer.datayes.com/community/share/577b147c228e5b195111f7e8
# 涨停板与打板    1
# 一.涨停板次日表现分析    2
# 二.涨停板次日开盘涨幅对其最高价和收盘价涨幅的影响    11
# 1.开盘涨幅在2%-4%时，最高价和收盘价涨幅的情况    11
# 5.开盘涨幅在-4%以下时，最高价和收盘价涨幅的情况    17
# 思考：
# 1，涨停时当日一般买不到了
# 2，次日何时出比较合适（或挂哪一档价位合适）？，统计的概率数据和当时市场牛熊关系比较大吧
# 3，代码不太容易读懂，分析思路非常好，分析次日的开收盘，最高低价。
#
# **07.Dinker_股票暴涨的频繁模式识别**
# 地址：https://uqer.datayes.com/community/share/587257bd23a7d6004aa35b6e?source=weeklyol23
# 将每日涨跌转换为1234序列，对应跌->涨
# 找出大涨(5)前的patter：xxxx
# 大涨前的patter是频繁项集合(0.006）
# 输出序列和支持度，置信度
#
# **08.minghong_5217策略**
# 地址：https://uqer.datayes.com/community/share/57a85107228e5b9b96a8863f
# 每年5月，10月第一个交易日调仓
# 每次选取连续5季，营业收入和净利润增长率均大于17%的5217股（增长率使用同比）
# 财务数据选取累计的，也就是3月是一个季度的，6月是两个季度的，9月是三个季度的，12月是四个季度的
#
# **09.minghong_基于时间序列的协整关系的配对交易**
# 地址：https://uqer.datayes.com/community/share/576a49f7228e5b819ba5607e
# 疑问：
# 1，testStationarity，中pvalue含义，为何一阶差分pvalue低就可以配对
# 2，此处的函数的含义coint（x,y)
# from statsmodels.tsa.stattools import coint
# a,pvalue,b = coint(x,y)
# print pvalue
# 0.00132789174842
# p值低于临界值，所以拒绝原假设，两者存在协整关系
#
# **10.jiang.wei_【alpha+打新】教你一个稳健的生财之道**
# 地址：https://uqer.datayes.com/community/share/5853a04f6a5e6d0050dc3307
# 打新收益分析
# 没看太懂的地方：
# “策略收益就是沪深300指数涨幅 + 20%的alpha收益 + 20%的打新收益”，貌似此篇文章只讲解了打新的20%收益，沪深300指数涨幅 是说“打新持股条件要求持有的市值类比为沪深300”么？还有20%alpha哪里来的？
#
# **11.脑洞:把上证指数分时行情浓缩为一天**
# 地址：https://uqer.datayes.com/community/share/5715a2e9228e5b827d7f53ed
#
# **12.isaac。pg_整理形态之上升三角形**
# 地址：https://uqer.datayes.com/community/user/57d0aeec228e5b0493fb8552/shares
# 上升三角形判断方法
#  1.峰值、谷底计算
# 我们以某点为参考，与 包含本日、前后各两日共计5日的数据比较。
# 如果该日的最高值为5日最大值最大，则该日的最高值为峰值，local_high；如果该日的最低值为5日最低值最小，则该日的最低值为谷底,local_low。
#  2.水平阻力线
# 最近一个月的所有峰值的平均值称为该上升三角形的水平阻力线, mean(local_high)。
# 为了保证水平的稳定性，要求最近一个月所有峰值在一定范围，如最大峰值和最小峰值相差在10%以内.仅考虑后3个.
# max(local_high)-min(local_high)< 0.15* max(local_high)
# 3.上升趋势线
# 该趋势线由所有的谷底链接而成。 为了保证上升, 要求local_low逐渐增大，即
# sorted(local_low)==local_low
#
# 突破判断
# 突破判断要求价格的突破，同时也需要成交量的增加，否则可能继续维持盘整。
# 1. 价格突破 close_price > mean(local_high) × r1
# 2. 成交量突破volume > mean(volume[:-1]) × r2
#
# 买入择时
# 买入有两种方法，一种是突破即买入。第二种是突破后，价格回踩仍在阻力线上方.
#
# **13.国信动态多因子算法的实现**
# 地址：https://uqer.datayes.com/community/share/58ea0fc1d8c05b0058d80244
# 周期：3工组日
# 定义：
# 因子贡献度：
#     1.首先将股票池中的股票按因子进行排名，分别选出排名靠前的20%和排名靠后的20%股票构成两个组合；
#     2.我们将两个组合的平均收益差和股票池中所有股票前后20%股票的平均收益差相除，得到的比值即为因子贡献度；
#     3.两个组合的收益率相差越大，则说明该时点此因子对股票的区分度越大；对于正的贡献度，因子值越大，平均收益率越小；对于负的贡献度，因子值越大，平均收益率越大。
# 思路：
# 因子贡献的选股的策略：
#     1.首先计算股票池中各个因子的数值（标准化，中性化，去极值）；
#     2.然后计算各个因子的贡献度；
#     3.通过因子的大小对于股票进行排序，序号大的股票理论上上涨的可能性越大；
#     4.如果因子贡献度小于门限menTH则舍弃该因子；
#     5.通过以下公式计算股票池中股票的得分：
#
# 其中stockpointi rankij derrj 分别代表第i支股票的得分，第i支股票第j个因子的排名，第j个因子的贡献度；
#     6.选取得分最高的stocknum支股票；
# 对于策略进行总体的实现，为了减少回撤，我们引入二八大小盘轮动策略，具体如下：
#     1.计算沪深300和创业板的20天收益率：
#     2.1如果沪深300和创业板的20天收益率小于0，则清盘；
#     2.2如果沪深300的20天收益率大于创业板的20天收益，则在沪深300中得到动态多因子打分的股票num支，如果打分所得的股票与持有的股票有60%的不同则换仓；
#     2.3如果沪深300的20天收益率小于创业板的20天收益，则在创业板中得到动态多因子打分的股票num支，如果打分所得的股票与持有的股票有60%的不同则换仓；
# 其中每3个工作日判断大小盘风格轮动的状况，创业板每6个工作日进行一次换仓判断，沪深300每9个工作日进行一次换仓判断。
#
# **14.【量化课堂】手把手教你如何应用机器学习**
# 地址：来自joinquant，自行搜索
# 算法：机器学习_SVM
# 因子：SMA，WMA，MOM，STCK，STCD，MACD，RSI，WILLR，CCI，MFI，OBV，ROC，CMO等技术指标
# 思路：
# 调仓周期：无
# 模型训练：
# a. 使用2010年-〉T-1日因子数据作为训练集合
# b. 因子做离散化，二元离散为1和-1，不同因子阀值不同，需分别作离散
# c. 最终结果为涨True跌False
# 模型预测：昨日因子=〉今日涨跌
# 买卖策略：无
#
# **15.米筐聚类-特征扩展和聚类**
# 米筐科技（RiceQuant）策略研究：沪深300指数的特征工程和聚类分析-以WorldQuant Formulaic 101 Alphas为例
# 地址：自己查下把，非优矿文章，雪球的，避免广告嫌疑
# 1，选择基本特征
# 2，基本特征扩展，移动平均，前20日突破等
# 1，    相关系数，筛选重要特征
# 2，    K-mean聚类，2类（可理解为涨跌）
# 3，    样本内回测
# 个人理解：2000多天内对高噪声做聚类，可以理解为退化为择时（不同市场下因子风格不同），聚类结果应该是xx时间-xx时间基本在一起，这段时间可能是震荡或者熊市/牛市。
#
# **16.米筐聚类-特征打分集成**
# 米筐科技（RiceQuant）策略研究报告：特征选择方法探析—沪深300指数的集成特征选择和聚类分析
# 地址：自己查下把，非优矿文章，知乎的，避免广告嫌疑
# 1，    整体思路同上一步骤，也是特征选择和聚类
# 2，    特征筛选变化a，特征筛选，采用多种方式打分，皮尔逊，lasso系数等，最大的前5为1，其他0-1均匀分布，b最终得分求和在均值，大于0.35的作为筛选出的因子，参与聚类。
