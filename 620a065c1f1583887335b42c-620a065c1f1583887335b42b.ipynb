# %% [markdown]
# # FT220213 Test Notebook

# %% [markdown]
# 第三部分：因子测试

# %% [markdown]
# 导读

# %% [markdown]
# -研究目的：
#
#
# -研究结论

# %% [markdown]
# 二、模型构建

# %% [markdown]
# 2.1 基础：可持续增长
# 	-保持稳定且可持续增长的公司所需要满足的条件：
#     	1）单季度利润同比增速为正、前期净利润大于300万
#         2）上一期单季度的同比增速为正
#  		3）2 个季度的利润加速增长
#         4）上一期单季营收为正
#     -回测参数设置如下:
# 		1）回测期间:2010 年至 2017 年 5 月 31 日;
# 		2）交易成本:买入 0.1%，卖出 0.2%;
# 		3）单只股票权重上限:10%;
# 		4）基准:中证 500 指数×仓位。

# %% [markdown]
# 2.2 低估值限制
# 	基于戴维斯双击策略中为保障安全边际和超预期潜力的依据，缩小样本至仅估值小于50倍的股票：

# %% [markdown]
# 2.3 持续性增长
# 	-剔除部分因特殊性事件或非经常性损益造成的超高增速增长的样本；
#     -筛选设置如下：
#     	1）保留当期单季度净利润同比增速大于20%且小于100%的前 25 个样本；
#         2）若满足条件的样本不足 25 个，则将单季增速大于100%的样本根据单季增速升序排列，按需补充样本；

# %% [markdown]
# 三、样本持有期内的收益分析

# %% [markdown]
# 3.1	相对于中证500指数的超额收益分析

# %% [markdown]
# 3.2	绝对收益分析

# %% [markdown]
# 3.3 相对于中信一级行业的超额收益分析

# %% [markdown]
# 3.4 相对于同等市值组合的超额收益分析
# 	选择与最近50只股票构建同等市值组合后比较分析：

# %% [markdown]
# 四、大消费类样本分析

# %% [markdown]
# 4.1 行业分布概览

# %% [markdown]
# 4.2 大消费类样本分布状况

# %% [markdown]
# 4.3 大消费类样本回测测试

# %% [markdown]
# 4.4 大消费类样本持有期内收益分析
