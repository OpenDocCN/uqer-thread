# %% [markdown]
# # Notebook0

# %% [raw]
# import pandas as pd
#
# # 第一步：设置基本参数
# start = '2013-01-01'
# end = '2019-01-01'
# benchmark = 'HS300'
# capital_base = 10000000
# freq = 'd'
# refresh_rate = 1
#
# # 第二步：选择因子，设置股票池，寻找五年平均ROE大于15% 的股票
# universe = DynamicUniverse('HS300').apply_filter(Factor.ROE5.value_range(0.15,10)  )
#
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     # 生成买入列表
#     today = account.current_date
#
#     # 计算ROE/PE，作为 buffet指标
#     buffet = DataAPI.MktStockFactorsOneDayGet(tradeDate= today,secID=account.universe,pandas="1")['ROE5'] /                        DataAPI.MktStockFactorsOneDayGet(tradeDate=today,secID=account.universe,	pandas="1")['PE']
#
#     prelist=buffet.to_frame("buffet")
#     #print(len(prelist))
#     #print(len(account.universe))
#     prelist["stock"]= account.universe
#     #print(prelist)
#
#
#     # 基于buffet指标的排序。排名前%25作为买入列表，后%25作为卖出列表
#     prebuylist = prelist.sort_values(by=["buffet"] ,ascending= False)
#     preselllist =prelist.sort_values(by=["buffet"] ,ascending= True)
#
#
#     l = len(prelist)
#     i = int(0.15 * l)
#
#     buylist = prebuylist.head(i)["stock"]
#     selllist = preselllist.head(i*3)["stock"]
#
#
#
#     v = account.reference_portfolio_value
#     d = len(buylist)
#
#     # 卖出在卖出列表中的股票，估计持仓价值
#     for stock in account.security_position:
#         if stock in selllist:
#             if stock in account.universe:
#                 account.order_to(stock, 0)
#             else:
#                 v -= account.security_position[stock] * account.reference_price[stock]
#
#     # 获得调仓数量
#     change = {}
#     for stock in buylist:
#         p = account.reference_price[stock]
#         if p:
#             change[stock] = int(v / d / p) - account.security_position.get(stock, 0)
#
#     # 按先卖后买的顺序发出指令
#     for stock in sorted(change, key=change.get):
#         if change[stock] <= -100 or change[stock] >= 100:
#             account.order(stock, change[stock])

# %% [raw]
# import pandas as pd
#
# # 第一步：设置基本参数
# start = '2013-01-01'
# end = '2019-01-01'
# benchmark = 'HS300'
# capital_base = 10000000
# freq = 'd'
# refresh_rate = 1
#
# # 第二步：选择因子，设置股票池，寻找五年平均ROE大于15% 的股票
# universe = StockScreener (Factor.ROE5.value_range(0.20,10)  )
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     # 生成买入列表
#     today = account.current_date
#
#     # 计算ROE/PE，作为 buffet指标
#     buffet = DataAPI.MktStockFactorsOneDayGet(tradeDate= today,secID=account.universe,pandas="1")['ROE5'] /                        DataAPI.MktStockFactorsOneDayGet(tradeDate=today,secID=account.universe,	pandas="1")['PE']
#
#     prelist=buffet.to_frame("buffet")
#     #print(len(prelist))
#     #print(len(account.universe))
#     prelist["stock"]= account.universe
#     #print(prelist)
#
#
#     # 基于buffet指标的排序。排名前%25作为买入列表，后%25作为卖出列表
#     prebuylist = prelist.sort_values(by=["buffet"] ,ascending= False)
#     preselllist =prelist.sort_values(by=["buffet"] ,ascending= True)
#
#
#     l = len(prelist)
#     i = int(0.2 * l)
#
#     buylist = prebuylist.head(i)["stock"]
#     selllist = preselllist.head(i*1.5)["stock"]
#
#
#
#     v = account.reference_portfolio_value
#     d = len(buylist)
#
#     # 卖出在卖出列表中的股票，估计持仓价值
#     for stock in account.security_position:
#         if stock in selllist:
#             if stock in account.universe:
#                 account.order_to(stock, 0)
#             else:
#                 v -= account.security_position[stock] * account.reference_price[stock]
#
#     # 获得调仓数量
#     change = {}
#     for stock in buylist:
#         p = account.reference_price[stock]
#         if p:
#             change[stock] = int(v / d / p) - account.security_position.get(stock, 0)
#
#     # 按先卖后买的顺序发出指令
#     for stock in sorted(change, key=change.get):
#         if change[stock] <= -100 or change[stock] >= 100:
#             account.order(stock, change[stock])
