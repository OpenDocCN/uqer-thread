# %% [markdown]
# # 海龟交易法则 定时退出

# %% [markdown]
# 海龟交易法则  定时退出
# 中线策略是盘中股价突破20日最高价就买，买入80天后卖出，不管中间涨跌
# 这体现了价格仓位，时间退出的彪悍思想！背后的原理是数据统计的优势率，也就是买入80天后的优势最大
# 我简单测试了下，几个ETF60天后卖出结果都可以接受。

# %% [raw]
# import datetime
# import numpy as np
#
# #start = '2006-01-01'
# #start = '2011-12-09'
# start = '2012-05-28'
# end = (datetime.date.today() - datetime.timedelta(days=1)).strftime("%Y-%m-%d")  # 回测结束时间
# #secID = '510050.XSHG'
# #secID = '159915.XSHE'
# secID = '159919.XSHE'
#
# benchmark = secID                  # 策略参考标准
# universe = [secID]                 # 证券池，支持股票和基金
# capital_base = 100000                     # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# enter_window = 20 + 1
# exit_window = 60
#
# def initialize(account):                   # 初始化虚拟账户状态
#     account.day_count = {}
#     account.high_list = []
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     highest_price = account.get_attribute_history('highPrice', 1)
#     close_price  = account.get_attribute_history('closePrice', 1)
#     for s in account.universe:
#         cp = close_price[s][-1]              #account.referencePrice[stock]
#         hp = highest_price[s][-1]
#         account.high_list.append(hp)
#
#         if len(account.high_list) < enter_window:
#             break
#         else:
#             account.high_list = account.high_list[-enter_window:]
#
#         if s in account.day_count:
#             account.day_count[s] += 1
#
#         if cp > np.array(account.high_list[:-1]).max() and s not in account.valid_secpos:
#             account.day_count[s] = 1
#             order(s, account.cash/cp)
#         elif s in account.valid_secpos and account.day_count[s] == exit_window:
#             del account.day_count[s]
#             order_to(s, 0)
