# %% [markdown]
# # 04.多因子选股（多因子筛选）

# %% [markdown]
# # ③ 量化多因子策略选择股票：
#
# 收集股票收益影响因素数据，按照规范要求生成Excel数据文件，在“量化投资模型”菜单下的“多因子策略模型原理与实现” 模块中上传数据文件;根据收集的股票收益影响因素数据，采用多因子模型计算股票收益与影响因素的拟合优度， 生成因子综合得分图，选取在各个因子上综合得分较高的股票构建投资组合。

# %%
import numpy as np
import pandas as pd


#通联库
from CAL.PyCAL import *
cal = Calendar('China.SSE')

import numpy as np
import pandas as pd

import scipy
import math


#Ours
from lib.Alpha101Factor import *
from lib.data_loader import load_market_data,TickerSector

# %% [markdown]
# ## （一） 定义股票池

# %%
# 将上证50、上证180和沪深300成分股合成为股票池
universe50 = set_universe('SH50') 
universe180 = set_universe('SH180')
universe300 = set_universe('HS300')
securities  = list(set(universe50 + universe180 + universe300))
print len(securities),securities
# Out:
# 329
#  ['000630.XSHE', '300033.XSHE', '002007.XSHE', '600291.XSHG', '601857.XSHG', '601238.XSHG', '601108.XSHG', '002001.XSHE', '601577.XSHG', '600111.XSHG', '601066.XSHG', '600340.XSHG', '601117.XSHG', '600438.XSHG', '000876.XSHE', '002558.XSHE', '002555.XSHE', '002602.XSHE', '601788.XSHG', '002065.XSHE', '600872.XSHG', '600547.XSHG', '603858.XSHG', '002938.XSHE', '002202.XSHE', '601985.XSHG', '600066.XSHG', '601088.XSHG', '600733.XSHG', '600900.XSHG', '002008.XSHE', '600498.XSHG', '000425.XSHE', '002415.XSHE', '000961.XSHE', '000069.XSHE', '002271.XSHE', '600489.XSHG', '001979.XSHE', '600332.XSHG', '300408.XSHE', '601377.XSHG', '601699.XSHG', '600048.XSHG', '600977.XSHG', '601992.XSHG', '600516.XSHG', '002601.XSHE', '600406.XSHG', '002594.XSHE', '000553.XSHE', '601229.XSHG', '300433.XSHE', '000768.XSHE', '601155.XSHG', '600010.XSHG', '600637.XSHG', '002032.XSHE', '600741.XSHG', '000100.XSHE', '002422.XSHE', '000725.XSHE', '603833.XSHG', '002179.XSHE', '002044.XSHE', '002673.XSHE', '000338.XSHE', '600663.XSHG', '000415.XSHE', '601860.XSHG', '300296.XSHE', '600690.XSHG', '601009.XSHG', '002081.XSHE', '600816.XSHG', '600535.XSHG', '600019.XSHG', '000703.XSHE', '600809.XSHG', '603986.XSHG', '000568.XSHE', '600699.XSHG', '601919.XSHG', '600436.XSHG', '601166.XSHG', '601618.XSHG', '300142.XSHE', '600893.XSHG', '600176.XSHG', '002027.XSHE', '603589.XSHG', '002925.XSHE', '601212.XSHG', '600926.XSHG', '600519.XSHG', '600909.XSHG', '600760.XSHG', '600104.XSHG', '601939.XSHG', '600298.XSHG', '000786.XSHE', '002739.XSHE', '002460.XSHE', '601288.XSHG', '600887.XSHG', '601818.XSHG', '601006.XSHG', '000402.XSHE', '002311.XSHE', '600018.XSHG', '000538.XSHE', '600089.XSHG', '002050.XSHE', '603288.XSHG', '601319.XSHG', '000625.XS
# %% [markdown]
# 现在，通过优矿来为我们股票池中的所有股票提取因子值，也可以自定义因子。

# %% [markdown]
# ## （三）从通联数据库提取因子

# %% [markdown]
# - 通联数据库因子

# %% [markdown]
# 以下是通联数据库提取因子分类，请同学们参考：
#
# u'偿债能力和资本结构类因子',
# u'超买超卖型因子',
# u'成交量型因子',
# u'成长能力类因子',
# u'分析师预期类因子',
# u'估值与市值类因子',
# u'均线型因子',
# u'每股指标因子',
# u'能量型因子',
# u'趋势型因子',
# u'现金流指标因子',
# u'盈利能力和收益质量类因子',
# u'营运能力类因子'

# %%
# 来自优矿：获取多只股票历史上某一天的因子数据
#普通版
uqer101s = list(DataAPI.MktStockFactorsOneDayGet(tradeDate=end,secID=u"",ticker=u"000001,600000",field=u"",pandas="1").columns)
# #专业版
# uqer101s = list(DataAPI.MktStockFactorsOneDayProGet(tradeDate=end,secID=u"",ticker=u"000001,600000",field=u"",pandas="1").columns)

del uqer101s[0:3]

# %%
#列示所有因子
for uqer in uqer101s:
    print "'"+uqer + "'," ,# end="" 可使输出不换行。双引号之间的内容就是结束的内容
# Out:
# 'AccountsPayablesTDays',
#  'AccountsPayablesTRate', 'AdminiExpenseRate', 'ARTDays', 'ARTRate', 'ASSI', 'BLEV', 'BondsPayableToAsset', 'CashRateOfSales', 'CashToCurrentLiability', 'CMRA', 'CTOP', 'CTP5', 'CurrentAssetsRatio', 'CurrentAssetsTRate', 'CurrentRatio', 'DAVOL10', 'DAVOL20', 'DAVOL5', 'DDNBT', 'DDNCR', 'DDNSR', 'DebtEquityRatio', 'DebtsAssetRatio', 'DHILO', 'DilutedEPS', 'DVRAT', 'EBITToTOR', 'EGRO', 'EMA10', 'EMA120', 'EMA20', 'EMA5', 'EMA60', 'EPS', 'EquityFixedAssetRatio', 'EquityToAsset', 'EquityTRate', 'ETOP', 'ETP5', 'FinancialExpenseRate', 'FinancingCashGrowRate', 'FixAssetRatio', 'FixedAssetsTRate', 'GrossIncomeRatio', 'HBETA', 'HSIGMA', 'IntangibleAssetRatio', 'InventoryTDays', 'InventoryTRate', 'InvestCashGrowRate', 'LCAP', 'LFLO', 'LongDebtToAsset', 'LongDebtToWorkingCapital', 'LongTermDebtToAsset', 'MA10', 'MA120', 'MA20', 'MA5', 'MA60', 'MAWVAD', 'MFI', 'MLEV', 'NetAssetGrowRate', 'NetProfitGrowRate', 'NetProfitRatio', 'NOCFToOperatingNI', 'NonCurrentAssetsRatio', 'NPParentCompanyGrowRate', 'NPToTOR', 'OperatingExpenseRate', 'OperatingProfitGrowRate', 'OperatingProfitRatio', 'OperatingProfitToTOR', 'OperatingRevenueGrowRate', 'OperCashGrowRate', 'OperCashInToCurrentLiability', 'PB', 'PCF', 'PE', 'PS', 'PSY', 'QuickRatio', 'REVS10', 'REVS20', 'REVS5', 'ROA', 'ROA5', 'ROE', 'ROE5', 'RSI', 'RSTR12', 'RSTR24', 'SalesCostRatio', 'SaleServiceCashToOR', 'SUE', 'TaxRatio', 'TOBT', 'TotalAssetGrowRate', 'TotalAssetsTRate', 'TotalProfitCostRatio', 'TotalProfitGrowRate', 'VOL10', 'VOL120', 'VOL20', 'VOL240', 'VOL5', 'VOL60', 'WVAD', 'REC', 'DAREC', 'GREC', 'FY12P', 'DAREV', 'GREV', 'SFY12P', 'DASREV', 'GSREV', 'FEARNG', 'FSALESG', 'TA2EV', 'CFO2EV', 'ACCA', 'DEGM', 'SUOI', 'EARNMOM', 'FiftyTwoWeekHigh', 'Volatility', 'Skewness', 'ILLIQUIDITY', 'BackwardADJ', 'MACD', 'ADTM', 'ATR14', 'ATR6', 'BIAS10', 'BIAS20', 'BIAS5', 'BIAS60', 'BollDown', 'BollUp', 'CCI10', 'CCI20', 'CCI5', 'CCI88', 'KDJ_K', 'KDJ_D', 'KDJ_J', 'ROC6', 'ROC20', 'SBM', 'STM', 'UpRVI', 'DownRVI', 'RVI', 'SRMI', 'ChandeSD', 'ChandeSU', 'CMO', 'DBCD', 'ARC', 'OBV', 'OBV6', 'OBV20', 'TVMA20', 'TVMA6', 'TVSTD20', 'TVSTD6', 'VDEA', 'VDIFF', 'VEMA10', 'VEMA12', 'VEMA26', 'VEMA5', 'VMACD', 'VOSC', 'VR', 'VROC12', 'VROC6', 'VSTD10', 'VSTD20', 'KlingerOscillator', 'MoneyFlow20', 'AD', 'AD20', 'AD6', 'CoppockCurve', 'ASI', 'ChaikinOscillator', 'ChaikinVolatility', 'EMV14', 'EMV6', 'plusDI', 'minusDI', 'ADX', 'ADXR', 'Aroon', 'AroonDown', 'AroonUp', 'DEA', 'DIFF', 'DDI', 'DIZ', 'DIF', 'MTM', 'MTMMA', 'PVT', 'PVT6', 'PVT12', 'TRIX5', 'TRIX10', 'UOS', 'MA10RegressCoeff12', 'MA10RegressCoeff6', 'PLRC6', 'PLRC12', 'SwingIndex', 'Ulcer10', 'Ulcer5', 'Hurst', 'ACD6', 'ACD20', 'EMA12', 'EMA26', 'APBMA', 'BBI', 'BBIC', 'TEMA10', 'TEMA5', 'MA10Close', 'AR', 'BR', 'ARBR', 'CR20', 'MassIndex', 'BearPower', 'BullPower', 'Elder', 'NVI', 'PVI', 'RC12', 'RC24', 'JDQS20',

# %%
factors = ['MLEV','FixAssetRatio','EquityFixedAssetRatio','BLEV','LongDebtToAsset']

factor_data = load_uqer101_factors(securities,start,end,factors)
factor_data
# Out:
#                           BLEV  EquityFixedAssetRatio  FixAssetRatio  \
# Date       secID
# 2018-09-28 000001.XSHE     NaN                26.7457         0.0025
#            000002.XSHE  2.2573                20.8561         0.0073
#            000063.XSHE  1.7084                 3.2711         0.0854
#            000069.XSHE  2.4970                 4.1598         0.0642
#            000100.XSHE  2.3941                 1.0914         0.3110
#            000157.XSHE  1.5318                 6.1327         0.0702
#            000166.XSHE     NaN                49.6407         0.0041
#            000333.XSHE  1.4903                 3.6919         0.0949
#            000338.XSHE  2.4629                 2.0745         0.1431
#            000333.XSHE           0.1206  1.1456
#            000338.XSHE           0.0700  1.7910
#            000402.XSHE           0.2587  4.2834
#            000408.XSHE           0.0000  1.0013
#            000413.XSHE           0.0573  1.4432
#            000415.XSHE           0.3567  9.1968
#            000423.XSHE           0.0000  1.0021
#            000425.XSHE           0.0222  1.2229
#            000538.XSHE           0.0001  1.0277
#            000553.XSHE           0.0077  1.3000
#            000568.XSHE           0.0000  1.0009
#            000596.XSHE           0.0000  1.0035
#            000625.XSHE           0.0000  1.1891
#            000627.XSHE           0.0007  4.8072
#            000629.XSHE           0.0212  1.0176
#            000630.XSHE           0.0897  1.2680
#            000651.XSHE           0.0000  1.0029
#            000656.XSHE           0.2296  3.0032
#            000661.XSHE           0.0015  1.0042
#            000671.XSHE           0.2430  4.1489
#            000703.XSHE           0.0048  1.0885
#            000709.XSHE           0.0733  1.9116
#            000725.XSHE           0.3014  2.0477
# ...                                 ...     ...
# 2019-09-27 601881.XSHG           0.0000     NaN
#            601888.XSHG           0.0000  1.0017
#            601898.XSHG           0.1244  2.1769
#            601899.XSHG           0.1130  1.4823
#            601901.XSHG           0.0000     NaN
#            601919.XSHG           0.2519  2.8604
#            601933.XSHG           0.0000  1.0036
#            601939.XSHG           0.0000     NaN
#            601985.XSHG           0.5441  3.5844
#            601988.XSHG           0.0000     NaN
#            601989.XSHG           0.1069  1.2028
#            601990.XSHG           0.0000     NaN
#            601992.XSHG           0.1354  3.4083
#            601997.XSHG           0.0000     NaN
#            601998.XSHG           0.0000     NaN
#            603013.XSHG           0.0960  1.1048
#            603019.XSHG           0.0175  1.1808
#            603156.XSHG           0.0000  1.0034
#            603160.XSHG           0.0000  1.0003
#            603259.XSHG           0.0006  1.0100
#            603260.XSHG           0.0357  1.0617
#            603288.XSHG           0.0000  1.0005
#            603369.XSHG           0.0000  1.0004
#            603486.XSHG           0.0000  1.0013
#            603589.XSHG           0.0000  1.0024
#            603799.XSHG           0.0234  1.0400
#            603833.XSHG           0.0190  1.0112
#            603858.XSHG           0.0433  1.0600
#            603986.XSHG           0.0191  1.0051
#            603993.XSHG           0.1787  1.4060
#
# [79535 rows x 5 columns]

# %% [markdown]
# ## （四）从Alpha101提取因子

# %% [markdown]
# 我们自定义因子都存放于Alpha101因子库，请同学们自行研究。

# %%
#为Alpha101因子准备数据
window_length = 256
TradeCal = DataAPI.TradeCalGet(exchangeCD=u"XSHG,XSHE",endDate=start,field="calendarDate,isOpen,prevTradeDate",pandas="1")
TradeCal = list(TradeCal[TradeCal['isOpen'] == 1]["calendarDate"])
data_start = sorted(list(set(TradeCal)))[-window_length]

market_data = load_market_data(securities, data_start,end,adjust= 1)

# %%
alpha_generator = Alphas101(market_data) 
alpha101s = [alpha for alpha in dir(alpha_generator) if alpha.startswith('alpha')]
alpha101s = sorted(alpha101s)

# %%
#列示所有因子
for alpha in alpha101s:
    print "'"+alpha + "'," ,# end="" 可使输出不换行。双引号之间的内容就是结束的内容
# Out:
# 'alpha001',
#  'alpha002', 'alpha003', 'alpha004', 'alpha005', 'alpha006', 'alpha007', 'alpha008', 'alpha009', 'alpha010', 'alpha011', 'alpha012', 'alpha013', 'alpha014', 'alpha015', 'alpha016', 'alpha017', 'alpha018', 'alpha019', 'alpha020', 'alpha021', 'alpha022', 'alpha023', 'alpha024', 'alpha025', 'alpha026', 'alpha028', 'alpha029', 'alpha030', 'alpha031', 'alpha033', 'alpha034', 'alpha035', 'alpha037', 'alpha038', 'alpha039', 'alpha040', 'alpha041', 'alpha042', 'alpha043', 'alpha044', 'alpha045', 'alpha046', 'alpha049', 'alpha050', 'alpha051', 'alpha052', 'alpha053', 'alpha054', 'alpha055', 'alpha056', 'alpha060', 'alpha101', 'alpha102', 'alpha103', 'alpha104', 'alpha105', 'alpha106', 'alpha107', 'alpha108', 'alpha109', 'alpha110', 'alpha111', 'alpha112', 'alpha113', 'alpha114', 'alpha115', 'alpha116', 'alpha117', 'alpha118', 'alpha119', 'alpha120', 'alpha121', 'alpha122', 'alpha123', 'alpha124', 'alpha125', 'alpha126', 'alpha127', 'alpha128', 'alpha129', 'alpha130', 'alpha131', 'alpha132', 'alpha133', 'alpha134', 'alpha135', 'alpha136', 'alpha137', 'alpha139', 'alpha140', 'alpha141', 'alpha142', 'alpha143',

# %%
custom_factors =  ['alpha004','alpha044','alpha131','alpha111','alpha130','alpha038','alpha041']
for alpha_name in custom_factors:
    custom_factor = alpha101_fun(alpha_name,market_data)() 
    custom_factor = custom_factor.loc[start:end].copy()
    custom_factor = custom_factor.stack()
    custom_factor.index = custom_factor.index.set_names([u'Date', 'secID'])
    custom_factor.name = alpha_name
    if factor_data is None:
        factor_data = pd.DataFrame(custom_factor)
    else:
        factor_data = factor_data.join(custom_factor,how='inner')
factor_data
# Out:
#                           BLEV  EquityFixedAssetRatio  FixAssetRatio  \
# Date       secID
# 2018-09-28 000001.XSHE     NaN                26.7457         0.0025
#            000002.XSHE  2.2573                20.8561         0.0073
#            000063.XSHE  1.7084                 3.2711         0.0854
#            000069.XSHE  2.4970                 4.1598         0.0642
#            000100.XSHE  2.3941                 1.0914         0.3110
#            000157.XSHE  1.5318                 6.1327         0.0702
#            000166.XSHE     NaN                49.6407         0.0041
#            000338.XSHE  2.4629                 2.0745         0.1431
#            000402.XSHE  3.3375                13.1077         0.0188
#            000413.XSHE  1.4410                 1.9593         0.2448
#            000423.XSHE  1.0063                 5.0480         0.1622
#            000425.XSHE  1.3121                 3.2542         0.1411
#            000553.XSHE  1.4334                 3.0683         0.1689
#            000568.XSHE  1.0039                 5.6324         0.1356
#            000596.XSHE  1.0215                 4.0198         0.1599
#            000625.XSHE  1.1397                 2.0353         0.2309
#            000627.XSHE  7.2738                34.2208         0.0045
#            000630.XSHE  1.3528                 0.9048         0.4195
#            000651.XSHE  1.0090                 4.3148         0.0843
#            000656.XSHE  4.1377                 7.5873         0.0200
#            000661.XSHE  1.0349                 4.2432         0.1654
#            000671.XSHE  5.7527                 8.8095         0.0162
#            601985.XSHG  145.526906  0.035272 -0.149343   -4.333424
#            601988.XSHG  181.861555  0.047222 -0.276425   -2.594679
#            601989.XSHG   72.176399  0.164376 -0.208590   -4.531350
#            601990.XSHG   32.390429 -0.024000 -0.045048   -7.774098
#            601992.XSHG   85.875048  0.132931 -0.149343   -2.316874
#            601997.XSHG  103.988620  0.047841 -0.661080   -7.536055
#            601998.XSHG  138.213391  0.021853 -0.164069   -4.710429
#            603013.XSHG   51.983510  0.133427 -0.251679  -13.243634
#            603019.XSHG   36.932954  0.040606 -0.192921  -34.108594
#            603156.XSHG  118.272250  0.291578 -0.090095  -27.261995
#            603160.XSHG   22.795097 -0.384112 -0.869860 -219.290920
#            603259.XSHG   48.571372 -0.242877 -0.814155  -85.563127
#            603260.XSHG   54.545999  0.022647 -0.951876  -31.698895
#            603288.XSHG   52.538649 -0.068618 -0.179045 -108.922887
#            603369.XSHG   41.737185 -0.165304 -0.091564  -32.038615
#            603486.XSHG   34.186130  0.425513 -0.061696  -21.022458
#            603589.XSHG   65.888395  0.081651 -0.028400  -55.655231
#            603799.XSHG   50.482184 -0.209012 -0.242459  -28.096466
#            603833.XSHG   72.077931  0.003404 -0.032317 -111.480943
#            603858.XSHG   75.347656  0.023433 -0.237969  -17.839596
#            603986.XSHG   19.277710 -0.368666 -0.090257 -148.263030
#            603993.XSHG   77.307201  0.095368 -0.256885   -2.679510
#
# [75308 rows x 12 columns]

# %% [markdown]
# ## （五） 完美因子定义

# %% [markdown]
# 完美因子实际上市计算各股票历史区间前瞻回报率，未来n_fwd_days天的收益率。

# %%
lookahead_bias_days = 5

Returns = market_data.minor_xs('Open')
Returns = Returns.pct_change(lookahead_bias_days).fillna(0.)
# introduce look-ahead bias and make the factor predictive
Returns = Returns.shift(-lookahead_bias_days) #计算未来五日内收益为完美有效因子

Returns = Returns.stack()
Returns.index = Returns.index.set_names([u'Date', 'secID'])
Returns.name = "Returns"
Returns.tail()
# Out:
# Date        secID
# 2019-09-20  603799.XSHG    0.073704
#             603833.XSHG   -0.059644
#             603858.XSHG   -0.064064
#             603986.XSHG   -0.010122
#             603993.XSHG   -0.016043
# Name: Returns, dtype: float64

# %%
factor_data = factor_data.join(Returns)
factor_data
# Out:
#                           BLEV  EquityFixedAssetRatio  FixAssetRatio  \
# Date       secID
# 2018-09-28 000001.XSHE     NaN                26.7457         0.0025
#            000002.XSHE  2.2573                20.8561         0.0073
#            000063.XSHE  1.7084                 3.2711         0.0854
#            000069.XSHE  2.4970                 4.1598         0.0642
#            000100.XSHE  2.3941                 1.0914         0.3110
#            000157.XSHE  1.5318                 6.1327         0.0702
#            000166.XSHE     NaN                49.6407         0.0041
#            000338.XSHE  2.4629                 2.0745         0.1431
#            000402.XSHE  3.3375                13.1077         0.0188
#            000413.XSHE  1.4410                 1.9593         0.2448
#            000423.XSHE  1.0063                 5.0480         0.1622
#            000425.XSHE  1.3121                 3.2542         0.1411
#            000768.XSHE   38.818127 -0.013248 -0.061182  -14.823239 -0.094687
#            000776.XSHE  162.518449 -0.077040 -0.441082  -12.809765 -0.056645
#            000783.XSHE  104.471369 -0.003146 -0.133846   -4.092513 -0.118684
#            000786.XSHE   36.272997  0.072952 -0.289685  -15.509157 -0.099072
# ...                            ...       ...       ...         ...       ...
# 2019-09-27 601881.XSHG   58.785143  0.077957 -0.246783  -10.160650       NaN
#            601888.XSHG   75.839401 -0.104397 -0.118495  -92.054498       NaN
#            601898.XSHG   64.985038 -0.006695 -0.041130   -3.804732       NaN
#            601899.XSHG   86.114137  0.099088 -0.103805   -2.290046       NaN
#            601901.XSHG   83.148754  0.019628 -0.070509   -6.002228       NaN
#            601919.XSHG   63.294849  0.024000 -0.047893   -4.024852       NaN
#            601933.XSHG   82.427773  0.121652 -0.378507   -7.931253       NaN
#            601939.XSHG  131.059636  0.016407 -0.458532   -6.030975       NaN
#            601985.XSHG  145.526906  0.035272 -0.149343   -4.333424       NaN
#            601988.XSHG  181.861555  0.047222 -0.276425   -2.594679       NaN
#            601989.XSHG   72.176399  0.164376 -0.208590   -4.531350       NaN
#            601990.XSHG   32.390429 -0.024000 -0.045048   -7.774098       NaN
#            601992.XSHG   85.875048  0.132931 -0.149343   -2.316874       NaN
#            601997.XSHG  103.988620  0.047841 -0.661080   -7.536055       NaN
#            601998.XSHG  138.213391  0.021853 -0.164069   -4.710429       NaN
#            603013.XSHG   51.983510  0.133427 -0.251679  -13.243634       NaN
#            603019.XSHG   36.932954  0.040606 -0.192921  -34.108594       NaN
#            603156.XSHG  118.272250  0.291578 -0.090095  -27.261995       NaN
#            603160.XSHG   22.795097 -0.384112 -0.869860 -219.290920       NaN
#            603259.XSHG   48.571372 -0.242877 -0.814155  -85.563127       NaN
#            603260.XSHG   54.545999  0.022647 -0.951876  -31.698895       NaN
#            603288.XSHG   52.538649 -0.068618 -0.179045 -108.922887       NaN
#            603369.XSHG   41.737185 -0.165304 -0.091564  -32.038615       NaN
#            603486.XSHG   34.186130  0.425513 -0.061696  -21.022458       NaN
#            603589.XSHG   65.888395  0.081651 -0.028400  -55.655231       NaN
#            603799.XSHG   50.482184 -0.209012 -0.242459  -28.096466       NaN
#            603833.XSHG   72.077931  0.003404 -0.032317 -111.480943       NaN
#            603858.XSHG   75.347656  0.023433 -0.237969  -17.839596       NaN
#            603986.XSHG   19.277710 -0.368666 -0.090257 -148.263030       NaN
#            603993.XSHG   77.307201  0.095368 -0.256885   -2.679510       NaN
#
# [75308 rows x 13 columns]

# %% [markdown]
# ## （六）因子之间的相关性

# %%
import seaborn as sns
sns.heatmap(factor_data.sample(frac = 1, axis = 1).corr(), xticklabels=False, yticklabels=False)

# %%
corr_df = factor_data.corr()
s = corr_df.unstack()
corr_pairs = s.order(kind="quicksort")
corr_pairs = corr_pairs.drop_duplicates()
corr_pairs = corr_pairs.dropna(axis = 0)
corr_pairs = corr_pairs[corr_pairs<1.]

# %%
corr_df.sort(columns=['Returns'],ascending=False)
# Out:
#                            BLEV  EquityFixedAssetRatio  FixAssetRatio  \
# Returns               -0.005710               0.017202      -0.008006
# alpha131              -0.042776              -0.000853       0.042827
# EquityFixedAssetRatio  0.037140               1.000000      -0.279268
# alpha130              -0.013667              -0.016907       0.022063
# MLEV                   0.899147               0.051424       0.074974
# BLEV                   1.000000               0.037140       0.073617
# FixAssetRatio          0.073617              -0.279268       1.000000
# LongDebtToAsset        0.689972              -0.108256       0.375644
# alpha041               0.148512               0.046586       0.043649
# alpha111               0.121563              -0.092255       0.044993
# alpha044              -0.014973              -0.046645       0.034374
# alpha004               0.009268               0.000880       0.008655
# alpha038               0.010377               0.005623       0.001679
#
#                        LongDebtToAsset      MLEV  alpha004  alpha044  \
# Returns                      -0.011655 -0.004049 -0.061364 -0.039143
# alpha131                      0.018342 -0.007187  0.085683  0.035655
# EquityFixedAssetRatio        -0.108256  0.051424  0.000880 -0.046645
# alpha130                      0.023816  0.021850  0.138570  0.081591
# MLEV                          0.633808  1.000000  0.021774 -0.004112
# BLEV                          0.689972  0.899147  0.009268 -0.014973
# FixAssetRatio                 0.375644  0.074974  0.008655  0.034374
# LongDebtToAsset               1.000000  0.633808  0.020687  0.000985
# alpha041                      0.124903  0.163187  0.025136 -0.060464
# alpha111                      0.086210  0.186891  0.035470  0.044640
# alpha044                      0.000985 -0.004112  0.180449  1.000000
# alpha004                      0.020687  0.021774  1.000000  0.180449
# alpha038                      0.011264  0.017112  0.480792  0.232529
#
#                        alpha131  alpha111  alpha130  alpha038  alpha041  \
# Returns                0.042291 -0.015528  0.013445 -0.189482 -0.013577
# alpha131               1.000000  0.020548  0.626629  0.096736  0.120774
# EquityFixedAssetRatio -0.000853 -0.092255 -0.016907  0.005623  0.046586
# alpha130               0.626629  0.145339  1.000000  0.151556  0.101433
# MLEV                  -0.007187  0.186891  0.021850  0.017112  0.163187
# BLEV                  -0.042776  0.121563 -0.013667  0.010377  0.148512
# FixAssetRatio          0.042827  0.044993  0.022063  0.001679  0.043649
# LongDebtToAsset        0.018342  0.086210  0.023816  0.011264  0.124903
# alpha041               0.120774  0.088207  0.101433  0.047176  1.000000
# alpha111               0.020548  1.000000  0.145339  0.001946  0.088207
# alpha044               0.035655  0.044640  0.081591  0.232529 -0.060464
# alpha004               0.085683  0.035470  0.138570  0.480792  0.025136
# alpha038               0.096736  0.001946  0.151556  1.000000  0.047176
#
#                         Returns
# Returns                1.000000
# alpha131               0.042291
# EquityFixedAssetRatio  0.017202
# alpha130               0.013445
# MLEV                  -0.004049
# BLEV                  -0.005710
# FixAssetRatio         -0.008006
# LongDebtToAsset       -0.011655
# alpha041              -0.013577
# alpha111              -0.015528
# alpha044              -0.039143
# alpha004              -0.061364
# alpha038              -0.189482

# %% [markdown]
# 从上面看出alpha131因子具有一定的正相关性，alpha038有一定的负相关性。

# %% [markdown]
# ## （七）因子的重要性分析（通过机器学习方法研究）

# %%
def shift_mask_data(X, Y, upper_percentile=70, lower_percentile=30, n_fwd_days=1):
    # Shift X to match factors at t to returns at t+n_fwd_days (we want to predict future returns after all)
    shifted_X = np.roll(X, n_fwd_days, axis=0)
    
    # Slice off rolled elements
    X = shifted_X[n_fwd_days:]
    Y = Y[n_fwd_days:]
    
    n_time, n_stocks, n_factors = X.shape
    
    # Look for biggest up and down movers
    upper = np.nanpercentile(Y, upper_percentile, axis=1)[:, np.newaxis]
    lower = np.nanpercentile(Y, lower_percentile, axis=1)[:, np.newaxis]
  
    upper_mask = (Y >= upper)
    lower_mask = (Y <= lower)
    
    mask = upper_mask | lower_mask # This also drops nans
    mask = mask.flatten()
    
    # Only try to predict whether a stock moved up/down relative to other stocks
    Y_binary = np.zeros(n_time * n_stocks)
    Y_binary[upper_mask.flatten()] = 1
    Y_binary[lower_mask.flatten()] = -1
    
    # Flatten X
    X = X.reshape((n_time * n_stocks, n_factors))

    # Drop stocks that did not move much (i.e. are in the 30th to 70th percentile)
    X = X[mask]
    Y_binary = Y_binary[mask]
    
    return X, Y_binary
def get_last_values(input_data):
    last_values = []
    for dataset in input_data:
        last_values.append(dataset[-1])
    return np.vstack(last_values).T

# %% [markdown]
# - 数据准备

# %%
results_wo_returns = factor_data.copy()
returns = results_wo_returns.pop('Returns') #收益
# 对缺失的因子数据处理

results_wo_returns = results_wo_returns.replace([np.inf, -np.inf], np.nan)
results_wo_returns = results_wo_returns.dropna(axis=0)
results_wo_returns.head()
# Out:
#                           BLEV  EquityFixedAssetRatio  FixAssetRatio  \
# Date       secID
# 2018-09-28 000002.XSHE  2.2573                20.8561         0.0073
#            000063.XSHE  1.7084                 3.2711         0.0854
#            000069.XSHE  2.4970                 4.1598         0.0642
#            000100.XSHE  2.3941                 1.0914         0.3110
#            000157.XSHE  1.5318                 6.1327         0.0702
#
#                         LongDebtToAsset    MLEV  alpha004  alpha044  alpha131  \
# Date       secID
# 2018-09-28 000002.XSHE           0.0954  1.6323      -2.0 -0.499261  0.252269
#            000063.XSHE           0.0212  1.2035      -5.0 -0.943074  0.637158
#            000069.XSHE           0.2591  2.5596      -3.0 -0.552386  0.205600
#            000100.XSHE           0.1693  2.0837      -7.0 -0.445221  0.171595
#            000157.XSHE           0.0674  1.6749      -1.0 -0.626329  0.056189
#
#                           alpha111  alpha130  alpha038   alpha041
# Date       secID
# 2018-09-28 000002.XSHE   33.902783 -0.087158 -0.032841 -23.460649
#            000063.XSHE   35.241969 -0.289617 -0.012457 -17.267903
#            000069.XSHE   45.593694 -0.006461 -0.173213  -5.304377
#            000100.XSHE   78.044205 -0.042716 -0.252539  -1.803129
#            000157.XSHE  112.925159  0.028095 -0.118923  -2.742771

# %%
Y = returns.unstack().values
X = results_wo_returns.to_panel() 
X = X.swapaxes(2, 0).swapaxes(0, 1).values # (factors, time, stocks) -> (time, stocks, factors)

# %%
results_wo_returns.shape,X.shape,Y.shape
# Out:
# ((61470, 12), (243, 329, 12), (243, 329))

# %%
n_fwd_days = 5 # 前瞻性天数

# Train-test split
train_size_perc = 0.8
n_time, n_stocks, n_factors = X.shape

train_size = np.int16(np.round(train_size_perc * n_time))
X_train, Y_train = X[:train_size, ...], Y[:train_size]
X_test, Y_test = X[(train_size+n_fwd_days):, ...], Y[(train_size+n_fwd_days):]

# %%
X_train_shift, Y_train_shift = shift_mask_data(X_train, Y_train, n_fwd_days=n_fwd_days)
X_test_shift, Y_test_shift = shift_mask_data(X_test, Y_test, n_fwd_days=n_fwd_days, 
                                             lower_percentile=30, 
                                             upper_percentile=70)

# %%
X_train_shift.shape, X_test_shift.shape
# Out:
# ((34877, 12), (6628, 12))

# %% [markdown]
# - model 1: AdaBoostClassifier

# %%
from time import time
from sklearn import linear_model, decomposition, ensemble, preprocessing, isotonic, metrics
start = time()

# Train classifier
imputer = preprocessing.Imputer()
scaler = preprocessing.MinMaxScaler()
clf = ensemble.AdaBoostClassifier(n_estimators=150) # n_estimators controls how many weak classifiers are fi

X_train_trans = imputer.fit_transform(X_train_shift)
X_train_trans = scaler.fit_transform(X_train_trans)
clf.fit(X_train_trans, Y_train_shift)

end = time()
print "Time to train full ML pipline: %0.2f secs" % (end - start)
# Out:
# Time to train full ML pipline: 7.87 secs

# %%
Y_pred = clf.predict(X_train_trans)
print('Accuracy on train set = {:.2f}%'.format(metrics.accuracy_score(Y_train_shift, Y_pred) * 100))
# Out:
# Accuracy on train set = 56.98%

# %%
# Transform test data
X_test_trans = imputer.transform(X_test_shift)
X_test_trans = scaler.transform(X_test_trans)

# %%
X_test_shift.shape,X_test_trans.shape
# Out:
# ((6628, 12), (6628, 12))

# %%
# Predict!
Y_pred = clf.predict(X_test_trans)

Y_pred_prob = clf.predict_proba(X_test_trans)

# %%
print 'Predictions:', Y_pred
print 'Probabilities of class == 1:', Y_pred_prob[:, 1] * 100
# Out:
# Predictions:
#  [ 1. -1.  1. ..., -1. -1. -1.]
# Probabilities of class == 1: [ 50.00969212  49.94803433  50.00193484 ...,  49.99851319  49.98547248
#   49.97108628]

# %%
print('Accuracy on test set = {:.2f}%'.format(metrics.accuracy_score(Y_test_shift, Y_pred) * 100))
print('Log-loss = {:.5f}'.format(metrics.log_loss(Y_test_shift, Y_pred_prob)))
# Out:
# Accuracy on test set = 52.41%
# Log-loss = 0.69294

# %%
feature_importances = pd.Series(clf.feature_importances_, index=results_wo_returns.columns)
feature_importances.sort(ascending=False)
ax = feature_importances.plot(kind='bar')
ax.set(ylabel='Importance (Gini Coefficient)', title='Feature importances');

# %% [markdown]
# ## （八）Alphalens 分析

# %%
pricing = market_data.minor_xs('Open')  #以开盘价为计算收益的标准
pricing = pricing.iloc[1:]
pricing.tail()
# Out:
#             000001.XSHE  000002.XSHE  000063.XSHE  000069.XSHE  000100.XSHE  \
# Date
# 2019-09-23        15.34        26.49        33.99         7.10         3.78
# 2019-09-24        15.47        26.24        33.71         6.98         3.82
# 2019-09-25        15.20        26.09        34.10         7.13         3.78
# 2019-09-26        15.86        26.10        34.06         7.14         3.65
# 2019-09-27        15.85        26.21        32.51         7.20         3.61
#
#             000157.XSHE  000166.XSHE  000333.XSHE  000338.XSHE  000402.XSHE  \
# Date
# 2019-09-23         5.88         4.94        52.64       11.610         7.86
# 2019-09-24         5.72         4.86        52.04       11.531         7.74
# 2019-09-25         5.75         4.85        52.00       11.492         7.80
# 2019-09-26         5.78         4.87        51.19       11.452         7.72
# 2019-09-27         5.72         4.80        51.00       11.107         7.65
#
#                ...       603260.XSHG  603288.XSHG  603369.XSHG  603486.XSHG  \
# Date           ...
# 2019-09-23     ...             30.40       111.32        33.19        24.49
# 2019-09-24     ...             29.81       111.00        33.91        23.91
# 2019-09-25     ...             29.76       110.70        33.48        23.62
# 2019-09-26     ...             30.91       111.62        33.90        23.10
# 2019-09-27     ...             31.60       109.78        33.47        22.10
#
#             603589.XSHG  603799.XSHG  603833.XSHG  603858.XSHG  603986.XSHG  \
# Date
# 2019-09-23        60.40        26.69       118.80        19.68       167.00
# 2019-09-24        59.29        26.90       116.48        19.28       176.00
# 2019-09-25        58.60        27.43       116.42        19.32       171.00
# 2019-09-26        58.10        28.55       115.00        18.90       161.00
# 2019-09-27        57.80        28.99       113.20        18.70       149.63
#
#             603993.XSHG
# Date
# 2019-09-23         3.72
# 2019-09-24         3.67
# 2019-09-25         3.67
# 2019-09-26         3.75
# 2019-09-27         3.68
#
# [5 rows x 329 columns]

# %%
from lib.lensutils import *
from lib.lensplotting import *
from lib.lensperformance import *
from lib.lenstears import *

# %%
create_factor_tear_sheet(factor=factor_data['MLEV'],
                         prices=pricing,
                         groupby=ticker_sector,
                         show_groupby_plots=True,
                         periods=(1,3,5,10),
                         quantiles=5,
                         filter_zscore=10,
                         groupby_labels=sector_names,
                         long_short=True,
                         avgretplot=(5, 15),
                         turnover_for_all_periods=True )
# Out:
# Quantiles statistics
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>min</th>
#       <th>max</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>count</th>
#       <th>count %</th>
#     </tr>
#     <tr>
#       <th>quantile</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0.8997</td>
#       <td>1.0126</td>
#       <td>1.001609</td>
#       <td>0.011169</td>
#       <td>11634</td>
#       <td>19.839362</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0090</td>
#       <td>1.0653</td>
#       <td>1.029376</td>
#       <td>0.012254</td>
#       <td>11722</td>
#       <td>19.989427</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.0468</td>
#       <td>1.1976</td>
#       <td>1.104064</td>
#       <td>0.032770</td>
#       <td>11735</td>
#       <td>20.011596</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.1429</td>
#       <td>1.7313</td>
#       <td>1.333320</td>
#       <td>0.129281</td>
#       <td>11717</td>
#       <td>19.980901</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1.4596</td>
#       <td>10.6879</td>
#       <td>2.647291</td>
#       <td>1.070650</td>
#       <td>11833</td>
#       <td>20.178715</td>
#     </tr>
#   </tbody>
# </table>
# Returns Analysis
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1</th>
#       <th>3</th>
#       <th>5</th>
#       <th>10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Ann. alpha</th>
#       <td>-0.053</td>
#       <td>-0.023</td>
#       <td>-0.023</td>
#       <td>-0.023</td>
#     </tr>
#     <tr>
#       <th>beta</th>
#       <td>-0.050</td>
#       <td>-0.057</td>
#       <td>-0.030</td>
#       <td>-0.005</td>
#     </tr>
#     <tr>
#       <th>Mean Period Wise Return Top Quantile (bps)</th>
#       <td>-3.436</td>
#       <td>-1.795</td>
#       <td>-1.412</td>
#       <td>-1.258</td>
#     </tr>
#     <tr>
#       <th>Mean Period Wise Return Bottom Quantile (bps)</th>
#       <td>5.695</td>
#       <td>4.975</td>
#       <td>5.129</td>
#       <td>5.280</td>
#     </tr>
#     <tr>
#       <th>Mean Period Wise Spread (bps)</th>
#       <td>-8.805</td>
#       <td>-6.373</td>
#       <td>-6.136</td>
#       <td>-6.105</td>
#     </tr>
#   </tbody>
# </table>
# Information Analysis
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1</th>
#       <th>3</th>
#       <th>5</th>
#       <th>10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>IC Mean</th>
#       <td>-0.013</td>
#       <td>-0.028</td>
#       <td>-0.037</td>
#       <td>-0.046</td>
#     </tr>
#     <tr>
#       <th>IC Std.</th>
#       <td>0.162</td>
#       <td>0.179</td>
#       <td>0.177</td>
#       <td>0.173</td>
#     </tr>
#     <tr>
#       <th>t-stat(IC)</th>
#       <td>-1.267</td>
#       <td>-2.348</td>
#       <td>-3.183</td>
#       <td>-4.070</td>
#     </tr>
#     <tr>
#       <th>p-value(IC)</th>
#       <td>0.206</td>
#       <td>0.020</td>
#       <td>0.002</td>
#       <td>0.000</td>
#     </tr>
#     <tr>
#       <th>IC Skew</th>
#       <td>0.312</td>
#       <td>0.417</td>
#       <td>0.413</td>
#       <td>0.269</td>
#     </tr>
#     <tr>
#       <th>IC Kurtosis</th>
#       <td>0.168</td>
#       <td>-0.208</td>
#       <td>-0.267</td>
#       <td>-0.802</td>
#     </tr>
#     <tr>
#       <th>Ann. IR</th>
#       <td>-1.318</td>
#       <td>-2.442</td>
#       <td>-3.310</td>
#       <td>-4.232</td>
#     </tr>
#   </tbody>
# </table>
# Turnover Analysis
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1</th>
#       <th>3</th>
#       <th>5</th>
#       <th>10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Quantile 1 Mean Turnover</th>
#       <td>0.010</td>
#       <td>0.018</td>
#       <td>0.026</td>
#       <td>0.042</td>
#     </tr>
#     <tr>
#       <th>Quantile 2 Mean Turnover</th>
#       <td>0.018</td>
#       <td>0.030</td>
#       <td>0.041</td>
#       <td>0.060</td>
#     </tr>
#     <tr>
#       <th>Quantile 3 Mean Turnover</th>
#       <td>0.022</td>
#       <td>0.040</td>
#       <td>0.052</td>
#       <td>0.081</td>
#     </tr>
#     <tr>
#       <th>Quantile 4 Mean Turnover</th>
#       <td>0.021</td>
#       <td>0.038</td>
#       <td>0.049</td>
#       <td>0.072</td>
#     </tr>
#     <tr>
#       <th>Quantile 5 Mean Turnover</th>
#       <td>0.010</td>
#       <td>0.017</td>
#       <td>0.023</td>
#       <td>0.032</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1</th>
#       <th>3</th>
#       <th>5</th>
#       <th>10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Mean Factor Rank Autocorrelation</th>
#       <td>1.0</td>
#       <td>0.999</td>
#       <td>0.998</td>
#       <td>0.997</td>
#     </tr>
#   </tbody>
# </table>
