# %% [markdown]
# # 因子ATR计算有误

# %%
print DataAPI.MktStockFactorsOneDayGet(tradeDate="2014-08-19",secID="600816.XSHG",field="SecID,tradeDate,ATR6,ATR14",pandas="1")
DataAPI.MktEqudAdjGet(secID="600816.XSHG",beginDate="2014-07-30",endDate ="2014-08-19",field =["tradeDate","PreClosePrice","actPreClosePrice","closePrice","lowestPrice","highestPrice","isOpen"],pandas='1')
# Out:
#          secID   tradeDate    ATR6   ATR14
# 0  600816.XSHG  2014-08-19  3.9566  3.8301
#      tradeDate  preClosePrice  actPreClosePrice  closePrice  lowestPrice  \
# 0   2014-07-30          2.966             17.27       2.965        2.927
# 1   2014-07-31          2.965             17.26       3.073        2.937
# 2   2014-08-01          3.073             17.89       3.049        3.016
# 3   2014-08-04          3.049             17.75       3.088        3.040
# 4   2014-08-05          3.088             17.98       3.037        2.997
# 5   2014-08-06          3.037             17.68       3.026        2.982
# 6   2014-08-07          3.026             17.62       2.982        2.971
# 7   2014-08-08          2.982             17.36       2.973        2.956
# 8   2014-08-11          2.973             17.31       3.044        2.971
# 9   2014-08-12          3.044             17.72       3.037        2.997
# 10  2014-08-13          3.037             17.68       2.973        2.934
# ...

# %%
t=DataAPI.MktStockFactorsDateRangeGet(secID=u"",ticker=u"600816",beginDate="2014-07-30",endDate ="2017-08-19",field=u"ticker,tradeDate,ATR6,ATR14",pandas="1")
t.plot(y=["ATR6"],x="tradeDate",figsize=(16,6))
