# %% [markdown]
# # 通联杯2015量化投资策略大赛

# %% [markdown]
# 通联杯2015量化投资策略大赛于2015年6月23日开始，今天(2015年7月24日)正式结束。虽然只有短短的一个月，却是中国股市上最跌宕起伏的日子。
#
# 在最艰难的时候，98%以上的非空仓策略都存在一定程度的亏损，但最终还是有很多选手取得了优秀成绩，让我们恭喜他们吧！

# %% [markdown]
# 今天收盘后最新的排名：

# %%
import pandas as pd
df = pd.read_csv('contest2.csv')[:100][['group_name', 'strategy_name', 'bt_score', 'pt_score', 'school']]
print df.rename(columns = { 'group_name':'团队名称', 'strategy_name':'策略名称', 'bt_score': '回测得分', 'pt_score':'模拟盘得分', 'school':'学校'}).to_html()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>团队名称</th>
#       <th>策略名称</th>
#       <th>回测得分</th>
#       <th>模拟盘得分</th>
#       <th>学校</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0 </th>
#       <td>     PKU_SS</td>
#       <td>                   Study_1</td>
#       <td> 64.355469</td>
#       <td> 85.546875</td>
#       <td>                  北京大学;北京大学</td>
#     </tr>
#     <tr>
#       <th>1 </th>
#       <td>     PKU_SS</td>
#       <td>                   Study_2</td>
#       <td> 64.355469</td>
#       <td> 84.960938</td>
#       <td>                  北京大学;北京大学</td>
#     </tr>
#     <tr>
#       <th>2 </th>
#       <td>     winner</td>
#       <td>                 quantumk2</td>
#       <td> 64.453125</td>
#       <td> 83.496094</td>
#       <td>                   中国科学技术大学</td>
#     </tr>
#     <tr>
#       <th>3 </th>
#       <td>   宇宙很大生活更大</td>
# ...

# %% [markdown]
# 我们的工作人员正准备联系相关选手，在下周会公布获奖选手，获奖策略。

# %% [markdown]
# 最后，激动的透露一下接下来的活动：500万实盘量化大赛。
#
# 只要参赛策略获得一定名次或者足够优秀，就可以瓜分这500万无息资金，收益请你带走，亏损我们承担！
#
# are you ready？
#
# ![](https://uqer.datayes.com/img/contest/mBanner2.jpg)
