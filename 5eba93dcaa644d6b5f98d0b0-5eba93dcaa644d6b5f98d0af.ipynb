# %% [markdown]
# # Notebook

# %% [markdown]
# 只买入获奖者，由于有时没有，买入上一年的获奖者

# %% [raw]
# from datetime import datetime,date,timedelta,time
#
# start = '2009-03-04'        #起始时间
# end = '2020-5-11'         #终止时间
# benchmark = 'HS300'
#
# uni=[['163402.OFCN','270002.OFCN'],
#                  ['000011.OFCN','163402.OFCN','377010.OFCN','450002.OFCN',
#                   '110009.OFCN','002001.OFCN','050007.OFCN'],
#                  ['180012.OFCN','000011.OFCN','070002.OFCN'],
#                  ['450004.OFCN','020001.OFCN','519692.OFCN','070010.OFCN','110010.OFCN','121002.OFCN'],
#                 ['162204.OFCN','000011.OFCN','070002.OFCN'],
#                 ['630002.OFCN','180012.OFCN','090007.OFCN','450004.OFCN','163302.OFCN',
#                  '161005.OFCN','100029.OFCN'],
#                 ['340006.OFCN','002031.OFCN','121006.OFCN'],
#                  ['530006.OFCN','070099.OFCN','288002.OFCN','160505.OFCN','100022.OFCN','050001.OFCN'],
#                 ['450002.OFCN','163801.OFCN','002001.OFCN'],
#                 ['160505.OFCN','519692.OFCN','519069.OFCN','070013.OFCN','070011.OFCN','121006.OFCN'],
#                 ['450002.OFCN','163801.OFCN','002001.OFCN'],
#                 ['020010.OFCN','070013.OFCN','470009.OFCN','377020.OFCN','260104.OFCN','163804.OFCN',
#                  '070006.OFCN','151001.OFCN','100029.OFCN'],
#                 ['519093.OFCN','630001.OFCN','320006.OFCN'],
#                 ['630001.OFCN','270025.OFCN','202011.OFCN','530005.OFCN','040004.OFCN'],
#      ['519093.OFCN','630001.OFCN','320006.OFCN'],
#     ['163406.OFCN', '180031.OFCN', '166011.OFCN', '161005.OFCN',  '470009.OFCN','070001.OFCN','110001.OFCN'],
#     ['166001.OFCN', '270002.OFCN'],
#     ['090001.OFCN', '519702.OFCN', '163415.OFCN', '180012.OFCN', '320006.OFCN'],
#     ['180012.OFCN', '260103.OFCN'],
#     ['000619.OFCN', '040008.OFCN', '519066.OFCN', '110011.OFCN', '202023.OFCN', '270002.OFCN'],
#     ['163402.OFCN', '270002.OFCN'],
#     ['519736.OFCN', '519069.OFCN', '481008.OFCN', '450002.OFCN', '519697.OFCN'],
#     ['110011.OFCN', '202023.OFCN'],
#     ['001811.OFCN', '166006.OFCN', '040005.OFCN', '260108.OFCN', '519732.OFCN']]
# universe = []
# for i in uni:
#     for fund in i:
#         if(not fund in universe):
#             universe.append(fund)
# print(universe)
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='otc_fund', capital_base=100000, dividend_method='reinvestment')
# }
# def initialize(context):             # 初始化策略运行环境
#     context.flag = 0
#     context.uni=uni
#     context.day=[date(2009,3,4),date(2010,6,21),date(2011,4,22),date(2012,3,27),
#                  date(2013,3,28),date(2014,3,26),date(2015,3,27),date(2016,2,23),date(2017,3,29),
#                 date(2018,3,27),date(2019,3,1),date(2020,3,24),date(2022,1,1)]
#     #需要买入的list
#     context.buylist=[]
#     #现在持有基金的list
#     context.contextlist=[]
#     #需要卖出的list
#     context.rmlist=[]
#
# def handle_data(context):
#     account = context.get_account('fantasy_account')
#     if(context.current_date.date()>context.day[context.flag]):
#         templist = context.uni[context.flag*2]
#         context.buylist=[]
#         #print('context.contextlist',context.contextlist)
#         context.rmlist=[]
#         for sec in context.contextlist:
#             if(context.contextlist==[]):
#                 break
#             if(not sec in templist):
#                 if(account.get_position(sec)):
#                     #print('account.get_position(sec)',account.get_position(sec))
#                     #print('account.get_position(sec).amount',account.get_position(sec).available_amount)
#                     holding=account.get_position(sec).available_amount
#                     account.redeem(sec, holding)
#                     context.rmlist.append(sec)
#         for rm in context.rmlist:
#             context.contextlist.remove(rm)
#         for se in templist:
#             if(not se in context.contextlist):
#                 context.buylist.append(se)
#                 context.contextlist.append(se)
#         context.flag+=1
#     cash = account.cash
#     #当有新的现金到达账户，再次买入
#     if(cash>100):
#         #print("context.buylist",context.buylist)
#         #print('cash',cash)
#         for se in context.buylist:
#             #tem=uni[0]+uni[1]
#             fs=cash/len(context.buylist)-1
#             account.purchase(se, fs)

# %% [markdown]
# 买入全部2009-2020

# %% [raw]
# from datetime import datetime,date,timedelta,time
#
# start = '2009-03-04'        #起始时间
# end = '2020-5-11'         #终止时间
# benchmark = 'HS300'
#
# uni=[[],
#                  ['000011.OFCN','163402.OFCN','377010.OFCN','450002.OFCN',
#                   '110009.OFCN','002001.OFCN','050007.OFCN'],
#                  ['180012.OFCN','000011.OFCN','070002.OFCN'],
#                  ['450004.OFCN','020001.OFCN','519692.OFCN','070010.OFCN','110010.OFCN','121002.OFCN'],
#                 ['162204.OFCN','000011.OFCN','070002.OFCN'],
#                 ['630002.OFCN','180012.OFCN','090007.OFCN','450004.OFCN','163302.OFCN',
#                  '161005.OFCN','100029.OFCN'],
#                 ['340006.OFCN','002031.OFCN','121006.OFCN'],
#                  ['530006.OFCN','070099.OFCN','288002.OFCN','160505.OFCN','100022.OFCN','050001.OFCN'],
#                 ['450002.OFCN','163801.OFCN','002001.OFCN'],
#                 ['160505.OFCN','519692.OFCN','519069.OFCN','070013.OFCN','070011.OFCN','121006.OFCN'],
#                 [],
#                 ['020010.OFCN','070013.OFCN','470009.OFCN','377020.OFCN','260104.OFCN','163804.OFCN',
#                  '070006.OFCN','151001.OFCN','100029.OFCN'],
#                 ['519093.OFCN','630001.OFCN','320006.OFCN'],
#                 ['630001.OFCN','270025.OFCN','202011.OFCN','530005.OFCN','040004.OFCN'],
#      [],
#     ['163406.OFCN', '180031.OFCN', '166011.OFCN', '161005.OFCN',  '470009.OFCN','070001.OFCN','110001.OFCN'],
#     ['166001.OFCN', '270002.OFCN'],
#     ['090001.OFCN', '519702.OFCN', '163415.OFCN', '180012.OFCN', '320006.OFCN'],
#     ['180012.OFCN', '260103.OFCN'],
#     ['000619.OFCN', '040008.OFCN', '519066.OFCN', '110011.OFCN', '202023.OFCN', '270002.OFCN'],
#     ['163402.OFCN', '270002.OFCN'],
#     ['519736.OFCN', '519069.OFCN', '481008.OFCN', '450002.OFCN', '519697.OFCN'],
#     ['110011.OFCN', '202023.OFCN'],
#     ['001811.OFCN', '166006.OFCN2', '040005.OFCN', '260108.OFCN', '519732.OFCN']]
# universe = []
# for i in uni:
#     for fund in i:
#         if(not fund in universe):
#             universe.append(fund)
# print(universe)
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='otc_fund', capital_base=100000, dividend_method='reinvestment')
# }
# def initialize(context):             # 初始化策略运行环境
#     context.flag = 0
#     context.uni=uni
#     context.day=[date(2009,3,4),date(2010,6,21),date(2011,4,22),date(2012,3,27),
#                  date(2013,3,28),date(2014,3,26),date(2015,3,27),date(2016,2,23),date(2017,3,29),
#                 date(2018,3,27),date(2019,3,1),date(2020,3,24),date(2022,1,1)]
#     #需要买入的list
#     context.buylist=[]
#     #现在持有基金的list
#     context.contextlist=[]
#     #需要卖出的list
#     context.rmlist=[]
#
# def handle_data(context):
#     account = context.get_account('fantasy_account')
#     if(context.current_date.date()>context.day[context.flag]):
#         templist = context.uni[context.flag*2]+context.uni[context.flag*2+1]
#         context.buylist=[]
#         #print("templist",templist)
#         #print('context.contextlist',context.contextlist)
#         context.rmlist=[]
#         for sec in context.contextlist:
#             if(context.contextlist==[]):
#                 break
#             if(not sec in templist):
#                 #print('sec',sec)
#                 if(account.get_position(sec)):
#                     #print('account.get_position(sec)',account.get_position(sec))
#                     #print('account.get_position(sec).amount',account.get_position(sec).available_amount)
#                     holding=account.get_position(sec).available_amount
#                     account.redeem(sec, holding)
#                     context.rmlist.append(sec)
#         for rm in context.rmlist:
#             context.contextlist.remove(rm)
#         for se in templist:
#             if(not se in context.contextlist):
#                 context.buylist.append(se)
#                 context.contextlist.append(se)
#         context.flag+=1
#     cash = account.cash
#     #当有新的现金到达账户，再次买入
#     if(cash>100):
#         #print("context.buylist",context.buylist)
#         #print('cash',cash)
#         for se in context.buylist:
#             #tem=uni[0]+uni[1]
#             fs=cash/len(context.buylist)-1
#             account.purchase(se, fs)

# %%
买入全部2008-2020

# %% [raw]
# from datetime import datetime,date,timedelta,time
#
# start = '2008-04-03'        #起始时间
# end = '2020-5-11'         #终止时间
# benchmark = 'HS300'
# #flag = 0
# #print(day[context.flag])
# uni=[['163402.OFCN','270002.OFCN'],
#      ['000011.OFCN','270005.OFCN','040005.OFCN','450002.OFCN','070003.OFCN','340001.OFCN'],
#                  [],
#                  ['000011.OFCN','163402.OFCN','377010.OFCN','450002.OFCN',
#                   '110009.OFCN','002001.OFCN','050007.OFCN'],
#                  ['180012.OFCN','000011.OFCN','070002.OFCN'],
#                  ['450004.OFCN','020001.OFCN','519692.OFCN','070010.OFCN','110010.OFCN','121002.OFCN'],
#                 ['162204.OFCN','000011.OFCN','070002.OFCN'],
#                 ['630002.OFCN','180012.OFCN','090007.OFCN','450004.OFCN','163302.OFCN',
#                  '161005.OFCN','100029.OFCN'],
#                 ['340006.OFCN','002031.OFCN','121006.OFCN'],
#                  ['530006.OFCN','070099.OFCN','288002.OFCN','160505.OFCN','100022.OFCN','050001.OFCN'],
#                 ['450002.OFCN','163801.OFCN','002001.OFCN'],
#                 ['160505.OFCN','519692.OFCN','519069.OFCN','070013.OFCN','070011.OFCN','121006.OFCN'],
#                 [],
#                 ['020010.OFCN','070013.OFCN','470009.OFCN','377020.OFCN','260104.OFCN','163804.OFCN',
#                  '070006.OFCN','151001.OFCN','100029.OFCN'],
#                 ['519093.OFCN','630001.OFCN','320006.OFCN'],
#                 ['630001.OFCN','270025.OFCN','202011.OFCN','530005.OFCN','040004.OFCN'],
#      [],
#     ['163406.OFCN', '180031.OFCN', '166011.OFCN', '161005.OFCN',  '470009.OFCN','070001.OFCN','110001.OFCN'],
#     ['166001.OFCN', '270002.OFCN'],
#     ['090001.OFCN', '519702.OFCN', '163415.OFCN', '180012.OFCN', '320006.OFCN'],
#     ['180012.OFCN', '260103.OFCN'],
#     ['000619.OFCN', '040008.OFCN', '519066.OFCN', '110011.OFCN', '202023.OFCN', '270002.OFCN'],
#     ['163402.OFCN', '270002.OFCN'],
#     ['519736.OFCN', '519069.OFCN', '481008.OFCN', '450002.OFCN', '519697.OFCN'],
#     ['110011.OFCN', '202023.OFCN'],
#     ['001811.OFCN', '166006.OFCN', '040005.OFCN', '260108.OFCN', '519732.OFCN']]
# universe = []
# for i in uni:
#     for fund in i:
#         if(not fund in universe):
#             universe.append(fund)
# print(universe)
# #universe = {0: ['163402.OFCN','270002.OFCN'], 1: ['000011.OFCN','270005.OFCN','040005.OFCN','450002.OFCN','070003.OFCN','340001.OFCN']}
# #universe.append(['163402.OFCN','270002.OFCN'])
# #universe.append(['000011.OFCN','270005.OFCN','040005.OFCN','450002.OFCN','070003.OFCN','340001.OFCN'])
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='otc_fund', capital_base=100000, dividend_method='reinvestment')
# }
# def initialize(context):             # 初始化策略运行环境
#     context.flag = 0
#     context.uni=[['163402.OFCN','270002.OFCN'],
#                  ['000011.OFCN','270005.OFCN','040005.OFCN','450002.OFCN','070003.OFCN','340001.OFCN'],
#                  [],
#                  ['000011.OFCN','163402.OFCN','377010.OFCN','450002.OFCN',
#                   '110009.OFCN','002001.OFCN','050007.OFCN'],
#                  ['180012.OFCN','000011.OFCN','070002.OFCN'],
#                  ['450004.OFCN','020001.OFCN','519692.OFCN','070010.OFCN','110010.OFCN','121002.OFCN'],
#                 ['162204.OFCN','000011.OFCN','070002.OFCN'],
#                 ['630002.OFCN','180012.OFCN','090007.OFCN','450004.OFCN','163302.OFCN',
#                  '161005.OFCN','100029.OFCN'],
#                 ['340006.OFCN','002031.OFCN','121006.OFCN'],
#                  ['530006.OFCN','070099.OFCN','288002.OFCN','160505.OFCN','100022.OFCN','050001.OFCN'],
#                 ['450002.OFCN','163801.OFCN','002001.OFCN'],
#                 ['160505.OFCN','519692.OFCN','519069.OFCN','070013.OFCN','070011.OFCN','121006.OFCN'],
#                 [],
#                 ['020010.OFCN','070013.OFCN','470009.OFCN','377020.OFCN','260104.OFCN','163804.OFCN',
#                  '070006.OFCN','151001.OFCN','100029.OFCN'],
#                 ['519093.OFCN','630001.OFCN','320006.OFCN'],
#                 ['630001.OFCN','270025.OFCN','202011.OFCN','530005.OFCN','040004.OFCN'],
#                 [],
#     ['163406.OFCN', '180031.OFCN', '166011.OFCN', '161005.OFCN',  '470009.OFCN','070001.OFCN','110001.OFCN'],
#     ['166001.OFCN', '270002.OFCN'],
#     ['090001.OFCN', '519702.OFCN', '163415.OFCN', '180012.OFCN', '320006.OFCN'],
#     ['180012.OFCN', '260103.OFCN'],
#     ['000619.OFCN', '040008.OFCN', '519066.OFCN', '110011.OFCN', '202023.OFCN', '270002.OFCN'],
#     ['163402.OFCN', '270002.OFCN'],
#     ['519736.OFCN', '519069.OFCN', '481008.OFCN', '450002.OFCN', '519697.OFCN'],
#     ['110011.OFCN', '202023.OFCN'],
#     ['001811.OFCN', '166006.OFCN', '040005.OFCN', '260108.OFCN', '519732.OFCN']]
#     context.day=[date(2008,4,3),date(2009,3,4),date(2010,6,21),date(2011,4,22),date(2012,3,27),
#                  date(2013,3,28),date(2014,3,26),date(2015,3,27),date(2016,2,23),date(2017,3,29),
#                 date(2018,3,27),date(2019,3,1),date(2020,3,24),date(2022,1,1)]
#     #需要买入的list
#     context.buylist=[]
#     #现在持有基金的list
#     context.contextlist=[]
#     #需要卖出的list
#     context.rmlist=[]
#     context.rmflag=10
#
# def handle_data(context):
#     account = context.get_account('fantasy_account')
#     if(context.current_date.date()>context.day[context.flag]):
#         #print(context.current_date.date(),context.day[context.flag])
#         #context.contextlist = context.get_universe('otc_fund')
#         #context.rmflag=10
#         templist = context.uni[context.flag*2]+context.uni[context.flag*2+1]
#         context.buylist=[]
#         #print("templist",templist)
#         #print('context.contextlist',context.contextlist)
#         context.rmlist=[]
#         for sec in context.contextlist:
#             if(context.contextlist==[]):
#                 break
#             if(not sec in templist):
#                 #print('sec',sec)
#                 if(account.get_position(sec)):
#                     #print('account.get_position(sec)',account.get_position(sec))
#                     #print('account.get_position(sec).amount',account.get_position(sec).available_amount)
#                     holding=account.get_position(sec).available_amount
#                     account.redeem(sec, holding)
#                     context.rmlist.append(sec)
#         for rm in context.rmlist:
#             context.contextlist.remove(rm)
#         for se in templist:
#             if(not se in context.contextlist):
#                 context.buylist.append(se)
#                 context.contextlist.append(se)
#         context.flag+=1
#     '''
#     #防止当时无法卖出，多卖出几次
#     if(context.rmflag>0):
#         context.rmflag-=1
#         for sec in context.rmlist:
#             if(account.get_position(sec)):
#                         holding=account.get_position(sec).available_amount
#                         account.redeem(sec, holding)
#     '''
#     cash = account.cash
#     #当有新的现金到达账户，再次买入
#     if(cash>100):
#         #print("context.buylist",context.buylist)
#         #print('cash',cash)
#         for se in context.buylist:
#             #tem=uni[0]+uni[1]
#             fs=cash/len(context.buylist)-1
#             account.purchase(se, fs)
