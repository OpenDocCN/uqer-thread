# %% [markdown]
# # 基本面分析 - 数据获取

# %% [markdown]
# 使用如下的股票代码作为示例:
#
# ```ticker = 600118```: 中国卫星

# %%
ticker = '600118'

# %% [markdown]
# 营业利润率
# ------------

# %%
DataAPI.MktStockFactorsDateRangeGet(ticker=ticker, beginDate='20140101',  field=['tradeDate', 'secID', 'OperatingProfitRatio']).tail()
# Out:
#       tradeDate        secID  OperatingProfitRatio
# 368  2015-07-07  600118.XSHG                0.0867
# 369  2015-07-08  600118.XSHG                0.0867
# 370  2015-07-09  600118.XSHG                0.0867
# 371  2015-07-10  600118.XSHG                0.0867
# 372  2015-07-13  600118.XSHG                0.0867

# %% [markdown]
# 净资产收益率
# ---------------

# %%
DataAPI.MktStockFactorsDateRangeGet(ticker='600118', beginDate='20140101',  field=['tradeDate','secID', 'ROE']).tail()
# Out:
#       tradeDate        secID     ROE
# 368  2015-07-07  600118.XSHG  0.0472
# 369  2015-07-08  600118.XSHG  0.0472
# 370  2015-07-09  600118.XSHG  0.0472
# 371  2015-07-10  600118.XSHG  0.0472
# 372  2015-07-13  600118.XSHG  0.0472

# %% [markdown]
# 存货周转率
# ---------------

# %%
DataAPI.MktStockFactorsDateRangeGet(ticker='600118', beginDate='20140101',  field=['tradeDate', 'secID', 'InventoryTRate']).tail()
# Out:
#       tradeDate        secID  InventoryTRate
# 368  2015-07-07  600118.XSHG          6.2144
# 369  2015-07-08  600118.XSHG          6.2144
# 370  2015-07-09  600118.XSHG          6.2144
# 371  2015-07-10  600118.XSHG          6.2144
# 372  2015-07-13  600118.XSHG          6.2144

# %% [markdown]
# 应收账款周转率
# -------------------

# %%
DataAPI.MktStockFactorsDateRangeGet(ticker='600118', beginDate='20140101',  field=['tradeDate', 'secID', 'ARTRate']).tail()
# Out:
#       tradeDate        secID  ARTRate
# 368  2015-07-07  600118.XSHG    1.742
# 369  2015-07-08  600118.XSHG    1.742
# 370  2015-07-09  600118.XSHG    1.742
# 371  2015-07-10  600118.XSHG    1.742
# 372  2015-07-13  600118.XSHG    1.742

# %% [markdown]
# 总资产周转率
# ---------------

# %%
DataAPI.MktStockFactorsDateRangeGet(ticker='600118', beginDate='20140101',  field=['tradeDate', 'secID', 'TotalAssetsTRate']).tail()
# Out:
#       tradeDate        secID  TotalAssetsTRate
# 368  2015-07-07  600118.XSHG            0.5108
# 369  2015-07-08  600118.XSHG            0.5108
# 370  2015-07-09  600118.XSHG            0.5108
# 371  2015-07-10  600118.XSHG            0.5108
# 372  2015-07-13  600118.XSHG            0.5108

# %% [markdown]
# 主营收入增长率
# -------------------

# %%
DataAPI.MktStockFactorsDateRangeGet(ticker='600118', beginDate='20140101',  field=['tradeDate', 'secID', 'OperatingRevenueGrowRate']).tail()
# Out:
#       tradeDate        secID  OperatingRevenueGrowRate
# 368  2015-07-07  600118.XSHG                   -0.0525
# 369  2015-07-08  600118.XSHG                   -0.0525
# 370  2015-07-09  600118.XSHG                   -0.0525
# 371  2015-07-10  600118.XSHG                   -0.0525
# 372  2015-07-13  600118.XSHG                   -0.0525

# %% [markdown]
# 营业利润增长率
# ------------------

# %%
DataAPI.MktStockFactorsDateRangeGet(ticker='600118', beginDate='20140101',  field=['tradeDate', 'secID', 'OperatingProfitGrowRate']).tail()
# Out:
#       tradeDate        secID  OperatingProfitGrowRate
# 368  2015-07-07  600118.XSHG                   0.2786
# 369  2015-07-08  600118.XSHG                   0.2786
# 370  2015-07-09  600118.XSHG                   0.2786
# 371  2015-07-10  600118.XSHG                   0.2786
# 372  2015-07-13  600118.XSHG                   0.2786

# %% [markdown]
# 净利润增长率
# -------------

# %%
DataAPI.MktStockFactorsDateRangeGet(ticker='600118', beginDate='20140101',  field=['tradeDate', 'secID', 'NetProfitGrowRate']).tail()
# Out:
#       tradeDate        secID  NetProfitGrowRate
# 368  2015-07-07  600118.XSHG             0.1357
# 369  2015-07-08  600118.XSHG             0.1357
# 370  2015-07-09  600118.XSHG             0.1357
# 371  2015-07-10  600118.XSHG             0.1357
# 372  2015-07-13  600118.XSHG             0.1357

# %% [markdown]
# 净资产增长率
# -----------------

# %%
DataAPI.MktStockFactorsDateRangeGet(ticker='600118', beginDate='20140101',  field=['tradeDate', 'secID', 'NetAssetGrowRate']).tail()
# Out:
#       tradeDate        secID  NetAssetGrowRate
# 368  2015-07-07  600118.XSHG            0.1001
# 369  2015-07-08  600118.XSHG            0.1001
# 370  2015-07-09  600118.XSHG            0.1001
# 371  2015-07-10  600118.XSHG            0.1001
# 372  2015-07-13  600118.XSHG            0.1001

# %% [markdown]
# 资产负债率
# ----------------

# %%
DataAPI.MktStockFactorsDateRangeGet(ticker='600118', beginDate='20140101',  field=['tradeDate', 'secID', 'DebtsAssetRatio']).tail()
# Out:
#       tradeDate        secID  DebtsAssetRatio
# 368  2015-07-07  600118.XSHG           0.4457
# 369  2015-07-08  600118.XSHG           0.4457
# 370  2015-07-09  600118.XSHG           0.4457
# 371  2015-07-10  600118.XSHG           0.4457
# 372  2015-07-13  600118.XSHG           0.4457

# %% [markdown]
# 流动比率
# --------------

# %%
DataAPI.MktStockFactorsDateRangeGet(ticker='600118', beginDate='20140101',  field=['tradeDate', 'secID', 'CurrentRatio']).tail()
# Out:
#       tradeDate        secID  CurrentRatio
# 368  2015-07-07  600118.XSHG        1.9336
# 369  2015-07-08  600118.XSHG        1.9336
# 370  2015-07-09  600118.XSHG        1.9336
# 371  2015-07-10  600118.XSHG        1.9336
# 372  2015-07-13  600118.XSHG        1.9336

# %% [markdown]
# 速动比率
# ------------------

# %%
DataAPI.MktStockFactorsDateRangeGet(ticker='600118', beginDate='20140101',  field=['tradeDate', 'secID', 'QuickRatio']).tail()
# Out:
#       tradeDate        secID  QuickRatio
# 368  2015-07-07  600118.XSHG      1.7582
# 369  2015-07-08  600118.XSHG      1.7582
# 370  2015-07-09  600118.XSHG      1.7582
# 371  2015-07-10  600118.XSHG      1.7582
# 372  2015-07-13  600118.XSHG      1.7582
