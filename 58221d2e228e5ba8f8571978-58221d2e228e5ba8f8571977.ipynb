# %% [markdown]
# #

# %% [markdown]
# #### 执行出错，用了黄金au1612，我还特地看了一下，2015年11月17号开始到现在都是有效的，那么为什么会出错？确实不明白
# #### 难不成拿不到商品期货的分钟数据？还是什么其他原因？敢望赐教，感谢！
# @taotao.li

# %% [raw]
# # 执行出错，用了黄金au1612，我还特地看了一下，2015年11月17号开始到现在都是有效的，那么为什么会出错？确实不明白
# universe = ['au1612']                          # 策略期货合约
# start = '2016-01-05'                       # 回测开始时间
# end  = '2016-06-01'                        # 回测结束时间
# capital_base = 1000000                     # 初试可用资金
# refresh_rate = 1                          # 调仓周期
# freq = 'm'                                 # 调仓频率：m-> 分钟；d-> 日
#
# def initialize(futures_account):           # 初始化虚拟期货账户，一般用于设置计数器，回测辅助变量等。
#     pass
#
# def handle_data(futures_account):          # 回测调仓逻辑，每个调仓周期运行一次，可在此函数内实现信号生产，生成调仓指令。
#     close_hist1 = get_symbol_history(symbol='au1612', field=['closePrice'], time_range=1)
#     return
