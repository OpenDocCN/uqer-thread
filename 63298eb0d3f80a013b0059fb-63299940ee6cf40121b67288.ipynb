# %% [markdown]
# # 极速版上线通知

# %% [markdown]
# <br/>
# 各位矿友，大家好！
# 为了满足各个层次矿友的需求，优矿推出极速版啦！除了基本量化回测的必要数据和200个基础量化因子外，极速版还额外增加了如下部分：
# <br/>
#
#  - **数据方面**
# 增加沪深高频分钟线、多频度复权行情、资金面及市场统计衍生数据、深度公司行为数据、指数成分权重、沪深港通数据用于量化研究；
# - **常用指标**
# 囊括了**可转债、基金、期货、港股** 等其他资产种类以及**宏观** 分析的常用指标；
# - **30个精选因子**
# 除了基础的200个量化因子外，极速版还额外增加了 **`30`** 个精品因子供矿友们使用；
# - **功能丰富**
# 具有超大内存研究空间，涵盖多维度的因子分析报告、因子分析类库和基金分析类库、模拟信号的微信推送等强大功能；
# - **灵活性**
# 若您有更高阶的需求，在极速版自带的功能和数据的基础上，您只需要购买相应的数据包和对应的功能模块即可，可谓一键组装，灵活变身。

# %% [markdown]
# 极速版和社区版几点重要区别如下：
# |  功能配置   | 社区免费版  | 极速版|
# |  ----      | ----  |----  |
# | 因子分析报告  | - |√  |
# | 因子分析类库  | - |√  |
# | 基金分析类库  | - |√  |
# | 策略模拟交易个数  | 3 |5  |
# | 模拟交易信号微信推送  | - |√  |
# | 研究环境内存  | 1G |4G  |
# | notebook运行个数  | 5 |10  |
# | 数据接口数量  | 120+ |270+  |

# %% [markdown]
# **申请专业版权限路径**：
#
# - 客户服务邮箱：service.uqer@datayes.com
# - 电话：4000-820-386
# - 网址：https://uqer.datayes.com/pro/#form
