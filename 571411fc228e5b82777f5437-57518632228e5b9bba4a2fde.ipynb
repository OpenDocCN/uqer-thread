# %% [markdown]
# # 小市值择时（RSI）策略

# %% [markdown]
# 最小市值选股、相对强弱指标RSI择时

# %% [raw]
# from datetime import datetime
# from CAL.PyCAL import *
# import talib
# import numpy as np
# import pandas as pd
#
# start = '2015-1-1'
# #end = '2015-12-31'
# end = datetime.today()
#
# benchmark = 'HS300'                # 策略参考标准
# capital_base = 1000000              # 起始资金
# freq = 'd'                      # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                  # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# universe = StockScreener(Factor.LCAP.nsmall(10)) #因子选股
#
# def initialize(account):
#     account.limit = 4
#
# def handle_data(account):
#     cal = Calendar('China.SSE')
#     day1 = cal.advanceDate(account.current_date, '-30B', BizDayConvention.Preceding)
#     df = DataAPI.MktIdxdGet(tradeDate=u"", indexID=u"", ticker="000300", beginDate=day1, endDate=account.current_date, field=["preCloseIndex"], pandas="1")
#     close = np.array(df["preCloseIndex"])
#
#     rsi = talib.RSI(close, 5)[-1]
#     stocks = account.universe[:account.limit]
#     buylist = {s:0 for s in stocks}
#
#     # 等权买入
#     for s in buylist:
#         buylist[s] = account.referencePortfolioValue/len(buylist)
#
#     # RSI择时
#     if rsi > 80:
#         for s in account.valid_secpos:
#             order_to(s, 0)
#     elif rsi < 40:
#         # 卖出不在买入列表内的
#         for s in account.valid_secpos:
#             if s not in buylist:
#                 order_to(s, 0)
#
#         # 买入，限制在limit只以内
#         for s in buylist:
#             if len(account.valid_secpos) < account.limit:
#                 order(s, buylist[s])
