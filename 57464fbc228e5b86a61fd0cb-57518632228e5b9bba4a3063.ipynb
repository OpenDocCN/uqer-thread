# %% [markdown]
# # 20均线（error）

# %% [raw]
# import numpy as np
# import pandas as pd
# from pandas import DataFrame,Series
# start = '2014-01-01'                       # 回测起始时间
# end = '2015-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['000030.XSHE']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     hist = account.get_attribute_history('closePrice',20)
#     hist = DataFrame(hist)
#
#     for s in account.universe:
#         MA20 = pd.rolling_mean(hist[s],20)
#         if  list(hist[s])[-1] > MA20 and s not in account.valid_secpos:
#             order(s, 20)
#         elif list(hist[s])[-1] < MA20 and s in account.valid_secpos:
#             order_to(s, 0)
#     return
