# %% [markdown]
# #

# %% [raw]
# import time
# import datetime
# import pandas as pd
#
# start = '2010-01-01'                       # 回测起始时间
# end = '2016-06-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['150019.XSHE']
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# error_list = []
# print_flag = False
#
# def foooo(data, dependencies=['closePrice'], max_window=20):
#     start_ = data['closePrice'].index[0]
#     end_ = data['closePrice'].index[-1]
#     val_1 = DataAPI.MktIdxdGet(indexID='000001.ZICN',beginDate = start_,endDate=end_,field=u"tradeDate,closeIndex",pandas="1")
#     val_2 = {}
#     for i in range(0,len(universe)):
#         val_2[str(universe[i])] = True if val_1['closeIndex'][val_1.index[-1]] > val_1['closeIndex'].mean() else False
#     val_3 = pd.Series(val_2)
#     return val_3
#
# def initialize(account):                   # 初始化虚拟账户状态
#     account.testval = 1
#     account.fund = universe[0]
#     a = Signal('MYMA',foooo)
#     account.signal_generator = SignalGenerator(a)
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     global error_list,print_flag
#     #print str(account.current_date)[0:10]
#     #print account.signal_result
#     #return
#     hist = account.get_history(1)
#     fund = account.fund
#     if universe[0] in account.signal_result['MYMA']:
#         flag = True if account.signal_result['MYMA'][universe[0]] else False
#     else:
#         flag = False
#         error_list.append(str(account.current_date)[0:10]+ ' ' +str(universe[0])+u' suspended ')
#         print_flag = True
#
#     #flag = True if hist[fund]['closePrice'][-1] > account.signal_result['MA20'][0] else False
#     if flag:
#         if account.position.secpos.get(fund, 0) == 0:
#             # 空仓时全仓买入，买入股数为100的整数倍
#             approximationAmount = int(account.cash / hist[fund]['closePrice'][-1]/100.0) * 100
#             order(fund, approximationAmount)
#     else:
#         # 卖出时，全仓清空
#         if account.position.secpos.get(fund, 0) >= 0:
#             order_to(fund, 0)
#
#     #if print_flag:
#         #print error_list
#     print_flag = False
#     return
