# %% [markdown]
# # Smart beta基金VS 股市宽基指数:实证对比分析

# %% [markdown]
# 引言
# ---
#  在《指数增强基金VS指数基金》notebook中提到，按照投资方式来划分，投资可分为主动投资和被动投资是两种最基本的投资策略。指数基
#   金（ETF）是最常见的一种被动投资策略产品，指数基金近几年发展非常迅速，特别是在欧美市场，已成为基金行业发展的大趋势。指数基金再细分下，smart beta基金是细分产品种最最火热的一类。本文就来分析smart beta基金。 主要分以下几方面内容：smart beta基金定义；smart beta基金的分类；smart beta基金的发展情况；smart beta基金与指数增强基金的区别；smart beta基金与A股各大指数的实证对比分析。

# %% [markdown]
# 一、smart beta基金？
# ---
# “smart beta”基金这个概念也是来自美国市场， 从字面理解它是相对于传统贝塔基金来说的，基于沪深300、中证500、上证指数等指数的指数基金就属于传统贝塔基金。这些指数基金是按照证券市值加权来构建投资组合的，而smart beta就聪明在它是按非市值加权和按固化规则选股的被动投资策略，是把主动投资确定规则化的被动投资策略，因为还是一种贝塔，所以这种策略本质上还是某种系统风险，而不是阿尔法。
#  在《指数增强基金VS指数基金》文中我们介绍了主动投资和被动投资策略，像指数增强一样smart beta策略是介于两种策略之间的。一方面在策略固化前，像主动投资策略一样，投资经理依据自己对市场的观点对基于市值投资的被动型策略进行改进，从而获取相对传统贝塔的超额收益 。另一方面在策略固化后，像被动型策略一样，smart beta遵循确定、透明、规则化的投资策略，交易纪律化、被动化，其管理费也一般较低；
#  ![图片注释](http://storage-uqer.datayes.com/59fc254cf2342d010d516471/ee75e810-acd9-11e8-bd3c-0242ac140002)
#  资料来源：晨星
#  有时smart beta又被称为另类贝塔或者因子投资，说到因子投资，做量化投资的投资者可能就比较熟悉了，在这里我们不做具体分析，后期会专门写文章来讨论， 这里要强调的是我们用的比较多的单因子策略和多因子策略都是smart beta策略的一种，把单因子或多因子策略固化，进行被动投资，把传统阿尔法收益，转变为贝塔收益。当然有时smart beta并不一定聪明，把smart beta产品称为因子投资产品或更合适。

# %% [markdown]
# ![图片注释](http://storage-uqer.datayes.com/59fc254cf2342d010d516471/52b6e3a6-acda-11e8-b634-0242ac140002)
# 资料来源：中泰证券

# %% [markdown]
# 二、smart beta的分类：
# ---
# 目前国内外市场存在的smart beta策略多种多样，其基本包含在以下三类美国（晨星公司对smart beta 策略的分类）：
#  （1）基于风险的策略：包括风险加权、等权重、等风险贡献、最小 方差、最大分散度等策略指数；
# （2）基于收益的策略：包括价值加权（成长、价值、盈利、多因子、 基本面加权）、价格加权（比如动量加权）等；
# （3）其他类型：非传统商品、固定收益以及多资产等。

# %% [markdown]
# 三、smart beta基金的发展情况
# ---
# Smart Beta 是近十几年来在全球市场中发展迅速的一种新型投资策略，越来越受到投资者的关注，规模和产品数量增加很快，特别是在美国市场，发展更为迅猛，其中股息、单因子、多因子和非市值加权是最受欢迎的策略，其四个策略的产品规模如下图。
#
#
#
# 一鉴开:
# ![图片注释](http://storage-uqer.datayes.com/59fc254cf2342d010d516471/235b1784-acdb-11e8-bd3c-0242ac140002)
# 一鉴开:
# ![![图片注释](http://storage-uqer.datayes.com/59fc254cf2342d010d516471/f2bc68ee-acda-11e8-b634-0242ac140002)]
#
#
# 资料来源：花旗银行，bloomgerm
#  Smart Beta 在美国市场已发展多年趋于成熟，但在国内 Smart Beta 却处于发展早期阶段，是一片全新的蓝海市场。从2006年第一只smart beta产品华泰柏瑞红利 ETF发行以来， 随着国内Smart Beta 指数体系的不断完善，各大基金公司新推出的Smart Beta 基金产品不断，根据优矿量化投资平台的数据， 截至2018年8月31日，我国已发行了60只smart beta产品，规模最大的 Smart Beta 基金为嘉实基本面 50，当前规模已达 16.46 亿元。从各大基金公司所布局的 Smart Beta 基金产品跟踪指数的类型来看，主要集中在等权指数、风格指数（以价值、成长为主）、高分红指数和基本面指数。其中风格指数smart beta产品占比最高，和美国分红smart beta占据主导地位不同，这主要是因为我国市场分红对股价影响还不大，风格特征明显原因造成的。相信随着中国价值投资和长期投时代的来临，中国红利指数smart beta等产品会迎来跃迁式发展。

# %% [markdown]
# 四、smart beta基金与指数增强基金的区别
# ---
# 《指数增强基金VS指数基金》文中介绍了指数增强基金的概念，我们对比下发行smart beta和指数增强有点相似，都是被动与主动的结合，都是追求超越传统指数贝塔收益的超额收益的，因子投资策略都是它们的主要策略， 但它们是有区别的：
# 从非投资运营方式角度来看，指数增强基金更倾向于属于主动投资基金，而smart beta基金 则更倾向于属于指数基金。
# smart beta基金各种费用要远低于指数增强基金，策略更透明。
# 指数增强基金的增强策略是可以不规则化、固定化的，是可以不断调整的，更灵活，而smart beta 基金的聪明策略是规则化的，是固定化的，交易是纪律化的，是被动化的。
# smart beta基金很多是ETF产品，而指数增强则不是ETF。
# 指数增强基金的策略更多的是战术上的，可以偏向中短期的，而smart beta基金的策略更多是战略上的，是长期的。

# %% [markdown]
# 1)	筛选出成立5年以上的smart beta 基金, 共有41只基金。

# %%
#加包
import pandas as pd
import numpy as np
import datetime as dt 
import matplotlib.pyplot as plt

# %%
#取出基金基本信息，剔除分级基金、封闭基金、FOF基金、QDII基金
fund_sec = DataAPI.SecIDGet(assetClass=u"F",pandas="1")
fund_info = DataAPI.FundGet(secID=fund_sec.secID,pandas="1")
fund_leverage = DataAPI.FundLeverageInfoGet(secID=u"",ticker=u"",exchangeCDLeverage=u"XSHG,XSHE",field=u"",pandas="1")
fund_info = fund_info[[x not in fund_leverage.secIDLeverage.values for x in fund_info.secID.values]]
fund_info = fund_info[[x not in ['C'] for x in fund_info.operationMode]]
fund_info = fund_info[(fund_info.isFof==0) & (fund_info.isQdii==0) & (fund_info.isGuarFund==0)]
fund_info1=fund_info

# %%
fund_info.head()
# Out:
#          secID  ticker    secShortName tradeAbbrName category operationMode  \
# 0  000001.OFCN  000001            华夏成长           NaN        H             O
# 1  000003.OFCN  000003       中海可转债债券-A           NaN        B             O
# 2  000004.OFCN  000004       中海可转债债券-C           NaN        B             O
# 4  000007.OFCN  000007       鹏华国有企业债债券           NaN        B             O
# 5  000008.OFCN  000008  嘉实中证500ETF联接基金           NaN        E             O
#
#   indexFund etfLof  isQdii  isFof        ...          \
# 0       NaN    NaN       0      0        ...
# 1       NaN    NaN       0      0        ...
# 2       NaN    NaN       0      0        ...
# 4       NaN    NaN       0      0        ...
# 5         I    NaN       0      0        ...
#
#                                          investField  \
# 0  本基金的投资范围限于具有良好流动性的金融工具，包括国内依法公开发行上市的股票、债券及中国证监...
# 1  本基金主要投资于具有良好流动性的金融工具，包括国内依法发行上市的股票（包含中小板、创业板及其...
# 2  本基金主要投资于具有良好流动性的金融工具，包括国内依法发行上市的股票（包含中小板、创业板及其...
# ...

# %%
#筛选出中国公募基金中的smart beta基金,95只，有些是重合的，场内和场外都有代码的要删除一个。
fund_info =fund_info[fund_info.indexFund=='I']
fund_smartbeta_info = fund_info[[('动量' in x or '低波动' in x or '价值' in x or '红利' in x or '质量' in x or '红利' in x or '等权' in x or '基本' in x  or '盈利' in x  or '央视' in x or '成长' in x  or '大盘' in x or '高贝塔' in x  ) for x in fund_info.secShortName]]
fund_smartbeta_info
# Out:
#             secID  ticker           secShortName          tradeAbbrName  \
# 52    000062.OFCN  000062    银华中证成长股债恒定组合30/70指数                    NaN
# 3206  003318.OFCN  003318     景顺长城中证500行业中性低波动指数                    NaN
# 3254  003366.OFCN  003366           浙商汇金中证转型成长指数                    NaN
# 3437  003548.OFCN  003548         泰达宏利中证财富大盘指数-C                    NaN
# 4273  004410.OFCN  004410           招商央视财经50指数-C                    NaN
# 4824  005051.OFCN  005051      上投摩根标普港股通低波红利指数-A                    NaN
# 4825  005052.OFCN  005052      上投摩根标普港股通低波红利指数-C                    NaN
# 4894  005125.OFCN  005125  华宝标普中国A股红利机会指数(LOF)-C                    NaN
# 5032  005279.OFCN  005279          华泰紫金中证红利低波动指数                    NaN
# 5286  005561.OFCN  005561        创金合信中证红利低波动指数-A                    NaN
# 5287  005562.OFCN  005562        创金合信中证红利低波动指数-C                    NaN
# 5416  005702.OFCN  005702        恒生前海港股通高股息低波动指数                    NaN
# ...

# %%
fund_smartbeta_info.to_csv('fund_smartbeta_info.csv',encoding='GBK')

# %%
#筛选出中国公募基金中的smart beta基金,95只，有些是重合的，场内和场外都有代码的要删除一个，有60个了。
fund_smartbeta_info = fund_smartbeta_info[[( '分级' not in x) for x in fund_smartbeta_info.secShortName]]
fund_smartbeta_info= fund_smartbeta_info.drop_duplicates(subset=['secShortName'],keep="last")
fund_smartbeta_info
# Out:
#             secID  ticker              secShortName             tradeAbbrName  \
# 52    000062.OFCN  000062       银华中证成长股债恒定组合30/70指数                       NaN
# 3206  003318.OFCN  003318        景顺长城中证500行业中性低波动指数                       NaN
# 3254  003366.OFCN  003366              浙商汇金中证转型成长指数                       NaN
# 3437  003548.OFCN  003548            泰达宏利中证财富大盘指数-C                       NaN
# 4273  004410.OFCN  004410              招商央视财经50指数-C                       NaN
# 4824  005051.OFCN  005051         上投摩根标普港股通低波红利指数-A                       NaN
# 4825  005052.OFCN  005052         上投摩根标普港股通低波红利指数-C                       NaN
# 4894  005125.OFCN  005125     华宝标普中国A股红利机会指数(LOF)-C                       NaN
# 5032  005279.OFCN  005279             华泰紫金中证红利低波动指数                       NaN
# 5286  005561.OFCN  005561           创金合信中证红利低波动指数-A                       NaN
# 5287  005562.OFCN  005562           创金合信中证红利低波动指数-C                       NaN
# ...

# %%
#筛选出基金成立时间大于5年的，41个
fund_smartbeta_info ['establishDate'] = fund_smartbeta_info ['establishDate'].apply(pd.to_datetime)
lag = pd.DateOffset(months=60)
current = dt.datetime.now()
fund_smartbeta_info1 = fund_smartbeta_info [fund_smartbeta_info ['establishDate'] < current - lag]
fund_smartbeta_info1
# Out:
#             secID  ticker          secShortName         tradeAbbrName  \
# 52    000062.OFCN  000062   银华中证成长股债恒定组合30/70指数                   NaN
# 5850  020025.OFCN  020025       国泰中小板300成长ETF联接                   NaN
# 5919  050013.OFCN  050013         博时上证超级大盘ETF联接                   NaN
# 5926  050021.OFCN  050021       博时深证基本面200ETF联接                   NaN
# 5967  070023.OFCN  070023     嘉实深证基本面120ETF联接-A                   NaN
# 6011  090010.OFCN  090010              大成中证红利指数                   NaN
# 6013  090012.OFCN  090012         大成深证成长40ETF联接                   NaN
# 6817  159905.XSHE  159905           工银瑞信深证红利ETF           工银瑞信深证红利ETF
# 6819  159906.XSHE  159906           大成深证成长40ETF           大成深证成长40ETF
# 6823  159908.XSHE  159908           深证基本面200ETF           深证基本面200ETF
# 6827  159910.XSHE  159910         嘉实深证基本面120ETF         嘉实深证基本面120ETF
# 6833  159913.XSHE  159913          交银深证300价值ETF          交银深证300价值ETF
# ...

# %%
#获得smart beta 场内和场外基金净值
beginDate="20130829"
endDate="20180829"
#获取聪明贝塔基金
data_smartbeta =DataAPI.FundNavGet(dataDate=u"",secID=fund_smartbeta_info1['secID'],beginDate=beginDate,endDate=endDate,field=u"",pandas="1")

fund_smartbeta = set(list(data_smartbeta ['secID']))  #smart beta基金，有净值基金代码

# %%
#取出沪深300指数、上证指数、深证指数、中证500指数、上证50、中证800、上证180
start = '20130829'
end = '20180829'
indices = ['000300', '000001', '399001','000905','000016','000906','000010']
data_index = DataAPI.MktIdxdGet(ticker=indices, beginDate=start, endDate=end, field="tradeDate,indexID,closeIndex,secShortName")
data_index.rename(columns={'tradeDate':'endDate','closeIndex':'ADJUST_NAV','indexID':"secID"}, inplace = True)
fund_index = set(list(data_index ["secID"]))

# %%
fund_index
# Out:
# {'000001.ZICN',
#  '000010.ZICN',
#  '000016.ZICN',
#  '000300.ZICN',
#  '000905.ZICN',
#  '000906.ZICN',
#  '399001.ZICN',
#  '399550.ZICN'}

# %%
data_index
data_smartbeta
# Out:
#          endDate        secID  ADJUST_NAV secShortName
# 0     2013-08-29  000001.ZICN    2097.227         上证综指
# 1     2013-08-30  000001.ZICN    2098.382         上证综指
# 2     2013-09-02  000001.ZICN    2098.448         上证综指
# 3     2013-09-03  000001.ZICN    2123.112         上证综指
# 4     2013-09-04  000001.ZICN    2127.618         上证综指
# 5     2013-09-05  000001.ZICN    2122.430         上证综指
# 6     2013-09-06  000001.ZICN    2139.993         上证综指
# 7     2013-09-09  000001.ZICN    2212.516         上证综指
# 8     2013-09-10  000001.ZICN    2237.984         上证综指
# 9     2013-09-11  000001.ZICN    2241.268         上证综指
# 10    2013-09-12  000001.ZICN    2255.605         上证综指
# 11    2013-09-13  000001.ZICN    2236.217         上证综指
# 12    2013-09-16  000001.ZICN    2231.401         上证综指
# 13    2013-09-17  000001.ZICN    2185.560         上证综指
# 14    2013-09-18  000001.ZICN    2191.851         上证综指
# 15    2013-09-23  000001.ZICN    2221.044         上证综指
# ...

# %%
#计算收益率

def CalcReturns(fundpool,data):
    returns = {}
    for fund in fundpool:
        temp = data[data['secID']==fund]
        temp = temp.set_index('endDate')
        value = temp['ADJUST_NAV']
        new_index = value.index[1:]
        diff = value.diff()[1:]
        diff = np.array(diff)
        pre_value = np.array(value[:-1])
        ret = diff/pre_value
        ret = pd.Series(ret,index=new_index)
        returns.update({fund:ret})
    return returns

# %%
returns_smartbeta= CalcReturns(fund_smartbeta ,data_smartbeta)
returns_index= CalcReturns(fund_index ,data_index)

# %% [markdown]
# **二、计算基金的指标：基金表现的几乎所有信息包含在其复权净值变化中，对于复权净值的变化，有收益类评价指标，有风险类评价指标，也有风险调整后收益类评价指标。后者为前两者的结合，用于衡量单位风险下基金的收益水平。具体参考前面的notebook**

# %%
# 各指标计算函数
# HR 历史收益率
def CalcHR(fundRet):
    n = len(fundRet)
    endValue =1
    for i in range(n):
        endValue *= (1+fundRet[i])
    # 年化：
    annReturn = endValue**(250.00/n) -1
    return annReturn
        
# Alpha    
def CalcAlpha(fundRet,indexRet):
    n = len(fundRet)
    beta = float(((fundRet*indexRet).sum() - n*(fundRet.mean())*(indexRet.mean()))) / ((indexRet**2).sum() - n*((indexRet.mean())**2))
    alpha = fundRet.mean() - beta*indexRet.mean()
    return alpha

# MVaR
def CalcMVaR(fundRet,level):
    mu = fundRet.mean()
    sigma = fundRet.std()
    S = fundRet.skew()
    K = fundRet.kurtosis()
    z = fundRet.quantile(level)
    MVaR = mu + (z + (1.00/6)*(z**2 -1)*S + (1.00/24)*(z**3-3*z)*K - (1.00/36)*(2*(z**3)-5*z)*(S**2))*sigma
    return MVaR

# 最大回撤 MD
def CalcMD(netvalue):
    netvalue = np.array(netvalue)
    length = len(netvalue)
    drawdown = []
    py =netvalue[0]
    for i in range(1,length):
        px = netvalue[i]
        py = max(netvalue[:i])
        drawdown.append(1-(px/py))
    return max(drawdown)

# 平均回撤 AD
def CalcAD(netvalue):
    netvalue = np.array(netvalue)
    N = len(netvalue)
    AD = 0
    py =netvalue[0]
    for i in range(1,N):
        px = netvalue[i]
        py = max(netvalue[:i])
        DD = (1-(float(px)/py))
        AD += DD*(0.9**(N-i))
    return AD

# 负向收益波动率(年化)LPM
def CalcLPM(fundRet):
    fundRet = fundRet[fundRet<0]
    LPM = fundRet.std()*np.sqrt(250)
    return LPM

# 收益波动率（年化）SIGMA
def CalcSIGMA(fundRet):
    return fundRet.std()*np.sqrt(250)


# 自动计算基础指标并返回所有指标
def AutoCalculate(fundRet,indexRet,netvalue,level):
    ret = {}
    HR = CalcHR(fundRet)
    Alpha = CalcAlpha(fundRet,indexRet)
    MVaR = CalcMVaR(fundRet,level)
    MD = CalcMD(netvalue)
    AD = CalcAD(netvalue)
    LPM = CalcLPM(fundRet)
    SIGMA = CalcSIGMA(fundRet)
    #由于风险类指标是小，基金表现越优，要转换成其倒数
    dMVaR=np.exp( MVaR*-1.0)
    dMD=np.exp( MD*-1.0)
    dAD=np.exp( AD*-1.0)
    dLPM=np.exp(LPM*-1.0)
    dSIGMA=np.exp(SIGMA*-1.0)
    
    ret.update({'HR':HR,'Alpha':Alpha,'dMVaR':dMVaR,'dMD':dMD,'dAD':dAD,'dLPM':dLPM,'dSIGMA':dSIGMA})
    H_Mvar =  HR/(np.exp(MVaR))
    CR = HR/np.abs(MD)
    H_Ad = HR/np.abs(AD)
    SoR = HR/LPM
    SR = HR/SIGMA
    A_Mvar = Alpha/(np.exp(MVaR))
    A_Md = Alpha/np.abs(MD)
    A_Ad = Alpha/np.abs(AD)
    XR = Alpha/LPM
    IR = Alpha/SIGMA
    ret.update({'H_Mvar': H_Mvar,'CR':CR,'H_Ad':H_Ad,'SoR':SoR,'SR':SR,'A_Mvar':A_Mvar,'A_Md':A_Md,'A_Ad':A_Ad,'XR':XR,'IR':IR})
    return ret

# %%
# 计算smart bete 基金和各宽基指数的指数
def CalcFundIndex(data):
    datelist = list(pd.Series(list(set(list(data['endDate'])))).sort_values())
    IndexValue = {}
    for date in datelist:
        temp = data[data['endDate']==date]
        IndexValue.update({date:temp['ADJUST_NAV'].mean()})  # 等权合成基金指数
    IndexValue = pd.Series(IndexValue)
    IndexValue = IndexValue/IndexValue.iloc[0]
    return IndexValue

# %%
Indextype_index= CalcFundIndex(data_index)
Indextype_smartbeta= CalcFundIndex(data_smartbeta)

# %%
#计算smart bete 基金和各宽基指数收益，计算指标时需要
def CalcIndexReturns(IndexData):
    new_index = IndexData.index[1:]
    diff = IndexData.diff()[1:]
    diff = np.array(diff)
    pre_value = np.array(IndexData[:-1])
    ret = diff/pre_value
    ret = pd.Series(ret,index=new_index)
    return ret

# %%
returns_Index_smartbeta = CalcIndexReturns(Indextype_smartbeta)
returns_Index_index = CalcIndexReturns(Indextype_index)

# %%
#计算指数的各指标，并保存为pd.dataframe
retindex = {}                                           
for fund in fund_index:
    try:
        fundRet = returns_index[fund]
        temp = data_index[data_index['secID']==fund]
        temp = temp.set_index('endDate')
        netvalue = temp['ADJUST_NAV']
        calc = AutoCalculate(fundRet,returns_Index_index,netvalue,0.05) # 计算各指标
        retindex.update({fund:calc})
    except:  # 如果可观测的数据不够
        pass
retindex= pd.DataFrame(retindex) #转换成pd数据框
retindex= retindex .transpose() #转值
retindex
# Out:
#                  A_Ad      A_Md    A_Mvar     Alpha        CR        HR  \
# 000001.ZICN  0.000004  0.000038  0.000018  0.000018  0.120617  0.058616
# 000010.ZICN  0.000038  0.000260  0.000125  0.000125  0.176659  0.084766
# 000016.ZICN  0.000078  0.000451  0.000201  0.000202  0.218682  0.097747
# 000300.ZICN  0.000030  0.000212  0.000099  0.000099  0.172937  0.080755
# 000905.ZICN  0.000007  0.000059  0.000035  0.000035  0.104519  0.061040
# 000906.ZICN  0.000018  0.000145  0.000071  0.000071  0.153907  0.075390
# 399001.ZICN -0.000037 -0.000324 -0.000174 -0.000174  0.021028  0.011318
#
#                  H_Ad    H_Mvar        IR        SR       SoR        XR  \
# 000001.ZICN  0.013975  0.058447  0.000079  0.252212  0.282812  0.000088
# 000010.ZICN  0.025469  0.084554  0.000522  0.354382  0.418360  0.000616
# 000016.ZICN  0.038017  0.097581  0.000815  0.395111  0.495496  0.001021
# 000300.ZICN  0.024125  0.080552  0.000413  0.337130  0.395104  0.000485
# ...

# %%
retindex=retindex.drop('A_Ad', 1)
retindex=retindex.drop('A_Md', 1)
retindex=retindex.drop('H_Ad', 1)
retindex=retindex.drop('Alpha', 1)
retindex=retindex.drop('H_Mvar', 1)
retindex=retindex.drop('dAD', 1)
retindex=retindex.drop('dMVaR', 1)
retindex=retindex.drop('A_Mvar', 1)
retindex
# Out:
#                    CR        HR        IR        SR       SoR        XR  \
# 000001.ZICN  0.120617  0.058616  0.000079  0.252212  0.282812  0.000088
# 000010.ZICN  0.176659  0.084766  0.000522  0.354382  0.418360  0.000616
# 000016.ZICN  0.218682  0.097747  0.000815  0.395111  0.495496  0.001021
# 000300.ZICN  0.172937  0.080755  0.000413  0.337130  0.395104  0.000485
# 000905.ZICN  0.104519  0.061040  0.000123  0.216141  0.242685  0.000138
# 000906.ZICN  0.153907  0.075390  0.000293  0.310894  0.357197  0.000337
# 399001.ZICN  0.021028  0.011318 -0.000646  0.041962  0.050119 -0.000772
#
#                  dLPM       dMD    dSIGMA
# 000001.ZICN  0.812807  0.615101  0.792623
# 000010.ZICN  0.816593  0.618890  0.787263
# 000016.ZICN  0.820967  0.639554  0.780834
# 000300.ZICN  0.815145  0.626904  0.786992
# 000905.ZICN  0.777619  0.557660  0.753967
# 000906.ZICN  0.809725  0.612723  0.784668
# 399001.ZICN  0.797861  0.583774  0.763596

# %%
retindex.sort_values(by = 'HR',axis = 0,ascending = False)
# Out:
#                    CR        HR        IR        SR       SoR        XR  \
# 000016.ZICN  0.218682  0.097747  0.000815  0.395111  0.495496  0.001021
# 000010.ZICN  0.176659  0.084766  0.000522  0.354382  0.418360  0.000616
# 000300.ZICN  0.172937  0.080755  0.000413  0.337130  0.395104  0.000485
# 000906.ZICN  0.153907  0.075390  0.000293  0.310894  0.357197  0.000337
# 000905.ZICN  0.104519  0.061040  0.000123  0.216141  0.242685  0.000138
# 000001.ZICN  0.120617  0.058616  0.000079  0.252212  0.282812  0.000088
# 399001.ZICN  0.021028  0.011318 -0.000646  0.041962  0.050119 -0.000772
#
#                  dLPM       dMD    dSIGMA
# 000016.ZICN  0.820967  0.639554  0.780834
# 000010.ZICN  0.816593  0.618890  0.787263
# 000300.ZICN  0.815145  0.626904  0.786992
# 000906.ZICN  0.809725  0.612723  0.784668
# 000905.ZICN  0.777619  0.557660  0.753967
# 000001.ZICN  0.812807  0.615101  0.792623
# 399001.ZICN  0.797861  0.583774  0.763596

# %%
#计算smart beta 基金各指标，并保存为pd.dataframe
retsmartbeta  = {}                                           
for fund in fund_smartbeta:
    try:
        fundRet = returns_smartbeta[fund]
        temp = data_smartbeta[data_smartbeta['secID']==fund]
        temp = temp.set_index('endDate')
        netvalue = temp['ADJUST_NAV']
        calc = AutoCalculate(fundRet,returns_Index_smartbeta,netvalue,0.05) # 计算各指标
        retsmartbeta .update({fund:calc})
    except:  # 如果可观测的数据不够
        pass
retsmartbeta  = pd.DataFrame(retsmartbeta ) #转换成pd数据框
retsmartbeta  = retsmartbeta .transpose() #转值
retsmartbeta
# Out:
#                  A_Ad      A_Md    A_Mvar     Alpha        CR        HR  \
# 000062.OFCN  0.000164  0.001268  0.000245  0.000246  0.471364  0.091321
# 020025.OFCN  0.000544  0.003995  0.001001  0.001004  1.221133  0.306770
# 050013.OFCN -0.000002 -0.000009 -0.000004 -0.000004  0.217685  0.095019
# 050021.OFCN  0.000024  0.000158  0.000061  0.000061  0.318276  0.123402
# 070023.OFCN  0.000049  0.000293  0.000115  0.000115  0.355736  0.139526
# 090010.OFCN  0.000082  0.000388  0.000178  0.000179  0.343780  0.158145
# 090012.OFCN -0.000076 -0.000652 -0.000324 -0.000325  0.021900  0.010902
# 159905.XSHE  0.000069  0.000452  0.000187  0.000188  0.399044  0.165768
# 159906.XSHE -0.000067 -0.000581 -0.000293 -0.000293  0.029249  0.014772
# 159908.XSHE  0.000032  0.000194  0.000079  0.000079  0.325195  0.132816
# 159910.XSHE  0.000054  0.000329  0.000132  0.000133  0.370490  0.149229
# 159913.XSHE  0.000001  0.000006  0.000003  0.000003  0.262325  0.115044
# ...

# %%
retsmartbeta.sort_values(by = 'HR',axis = 0,ascending = False)
# Out:
#                  A_Ad      A_Md    A_Mvar     Alpha        CR        HR  \
# 519714.OFCN  0.001626  0.005760  0.001248  0.001252  1.832477  0.398157
# 320022.OFCN  0.025726  0.008958  0.001250  0.001253  2.671295  0.373623
# 160716.XSHE  0.000183  0.000815  0.000316  0.000317  0.482677  0.187572
# 159916.XSHE  0.000068  0.000434  0.000168  0.000168  0.438236  0.170024
# 159905.XSHE  0.000055  0.000360  0.000149  0.000150  0.399044  0.165768
# 310398.OFCN  0.000122  0.000505  0.000203  0.000203  0.408831  0.164572
# 519671.OFCN  0.000121  0.000487  0.000200  0.000201  0.396555  0.163429
# 510030.XSHG  0.000125  0.000571  0.000225  0.000226  0.411224  0.162467
# 530015.OFCN  0.000066  0.000409  0.000154  0.000154  0.424575  0.160366
# 090010.OFCN  0.000065  0.000310  0.000142  0.000142  0.343780  0.158145
# 481012.OFCN  0.000054  0.000343  0.000138  0.000138  0.390430  0.157330
# 159910.XSHE  0.000039  0.000240  0.000096  0.000096  0.370490  0.149229
# ...

# %%
retsmartbeta=retsmartbeta.drop('A_Ad', 1)
retsmartbeta=retsmartbeta.drop('A_Md', 1)
retsmartbeta=retsmartbeta.drop('H_Ad', 1)
retsmartbeta=retsmartbeta.drop('Alpha', 1)
retsmartbeta=retsmartbeta.drop('H_Mvar', 1)
retsmartbeta=retsmartbeta.drop('dAD', 1)
retsmartbeta=retsmartbeta.drop('dMVaR', 1)
retsmartbeta=retsmartbeta.drop('A_Mvar', 1)
retsmartbeta
# Out:
#                    CR        HR        IR        SR       SoR        XR  \
# 000062.OFCN  0.471364  0.091321  0.002625  0.976156  1.122167  0.003018
# 020025.OFCN  1.221133  0.306770  0.004131  1.262651  1.696372  0.005550
# 050013.OFCN  0.217685  0.095019 -0.000017  0.419317  0.507145 -0.000020
# 050021.OFCN  0.318276  0.123402  0.000264  0.532250  0.637512  0.000316
# 070023.OFCN  0.355736  0.139526  0.000489  0.593205  0.719990  0.000593
# 090010.OFCN  0.343780  0.158145  0.000743  0.657796  0.720095  0.000813
# 090012.OFCN  0.021900  0.010902 -0.001229  0.041256  0.050626 -0.001508
# 159905.XSHE  0.399044  0.165768  0.000715  0.631878  0.798608  0.000904
# 159906.XSHE  0.029249  0.014772 -0.001155  0.058126  0.073970 -0.001469
# 159908.XSHE  0.325195  0.132816  0.000324  0.543447  0.650397  0.000388
# 159910.XSHE  0.370490  0.149229  0.000533  0.600539  0.732811  0.000651
# 159913.XSHE  0.262325  0.115044  0.000010  0.450219  0.537244  0.000012
# ...

# %% [markdown]
# 加上基金的中文名字
# ---

# %%
fund_smartbeta= data_smartbeta.drop_duplicates(subset=['secShortName'],keep="last")

fund_index=data_index.drop_duplicates(subset=['secShortName'],keep="last")

# %%
fund_index.set_index("secID")
# Out:
#                 endDate  ADJUST_NAV secShortName
# secID
# 000001.ZICN  2018-08-29   2769.2947         上证综指
# 000010.ZICN  2018-08-29   7465.7409        上证180
# 000016.ZICN  2018-08-29   2503.4801         上证50
# 000300.ZICN  2018-08-29   3386.5736        沪深300
# 000905.ZICN  2018-08-29   4941.9607        中证500
# 000906.ZICN  2018-08-29   3645.4240        中证800
# 399001.ZICN  2018-08-29   8678.2620         深证成指

# %%
fund_smartbeta=fund_smartbeta.set_index("secID")

# %%
retindex.index.name="secID"
retindex
# Out:
#                    CR        HR        IR        SR       SoR        XR  \
# secID
# 000001.ZICN  0.120617  0.058616  0.000079  0.252212  0.282812  0.000088
# 000010.ZICN  0.176659  0.084766  0.000522  0.354382  0.418360  0.000616
# 000016.ZICN  0.218682  0.097747  0.000815  0.395111  0.495496  0.001021
# 000300.ZICN  0.172937  0.080755  0.000413  0.337130  0.395104  0.000485
# 000905.ZICN  0.104519  0.061040  0.000123  0.216141  0.242685  0.000138
# 000906.ZICN  0.153907  0.075390  0.000293  0.310894  0.357197  0.000337
# 399001.ZICN  0.021028  0.011318 -0.000646  0.041962  0.050119 -0.000772
#
#                  dLPM       dMD    dSIGMA
# secID
# 000001.ZICN  0.812807  0.615101  0.792623
# 000010.ZICN  0.816593  0.618890  0.787263
# 000016.ZICN  0.820967  0.639554  0.780834
# 000300.ZICN  0.815145  0.626904  0.786992
# 000905.ZICN  0.777619  0.557660  0.753967
# 000906.ZICN  0.809725  0.612723  0.784668
# 399001.ZICN  0.797861  0.583774  0.763596

# %%
fund_index=fund_index.set_index("secID")

# %%
tt=pd.concat([retsmartbeta, fund_smartbeta["secShortName"]], axis=1)
tt
# Out:
#                    CR        HR        IR        SR       SoR        XR  \
# secID
# 000062.OFCN  0.471364  0.091321  0.002625  0.976156  1.122167  0.003018
# 020025.OFCN  1.221133  0.306770  0.004131  1.262651  1.696372  0.005550
# 050013.OFCN  0.217685  0.095019 -0.000017  0.419317  0.507145 -0.000020
# 050021.OFCN  0.318276  0.123402  0.000264  0.532250  0.637512  0.000316
# 070023.OFCN  0.355736  0.139526  0.000489  0.593205  0.719990  0.000593
# 090010.OFCN  0.343780  0.158145  0.000743  0.657796  0.720095  0.000813
# 090012.OFCN  0.021900  0.010902 -0.001229  0.041256  0.050626 -0.001508
# 159905.XSHE  0.399044  0.165768  0.000715  0.631878  0.798608  0.000904
# 159906.XSHE  0.029249  0.014772 -0.001155  0.058126  0.073970 -0.001469
# 159908.XSHE  0.325195  0.132816  0.000324  0.543447  0.650397  0.000388
# 159910.XSHE  0.370490  0.149229  0.000533  0.600539  0.732811  0.000651
# 159913.XSHE  0.262325  0.115044  0.000010  0.450219  0.537244  0.000012
# ...

# %%
uu=pd.concat([retindex, fund_index["secShortName"]], axis=1)
uu
# Out:
#                    CR        HR        IR        SR       SoR        XR  \
# secID
# 000001.ZICN  0.120617  0.058616  0.000079  0.252212  0.282812  0.000088
# 000010.ZICN  0.176659  0.084766  0.000522  0.354382  0.418360  0.000616
# 000016.ZICN  0.218682  0.097747  0.000815  0.395111  0.495496  0.001021
# 000300.ZICN  0.172937  0.080755  0.000413  0.337130  0.395104  0.000485
# 000905.ZICN  0.104519  0.061040  0.000123  0.216141  0.242685  0.000138
# 000906.ZICN  0.153907  0.075390  0.000293  0.310894  0.357197  0.000337
# 399001.ZICN  0.021028  0.011318 -0.000646  0.041962  0.050119 -0.000772
#
#                  dLPM       dMD    dSIGMA secShortName
# secID
# 000001.ZICN  0.812807  0.615101  0.792623         上证综指
# 000010.ZICN  0.816593  0.618890  0.787263        上证180
# 000016.ZICN  0.820967  0.639554  0.780834         上证50
# 000300.ZICN  0.815145  0.626904  0.786992        沪深300
# 000905.ZICN  0.777619  0.557660  0.753967        中证500
# ...

# %% [markdown]
# 选出各指数相关的SMART BETA ,好对比
# ---

# %%
tt1= tt[[( '300' in x  ) for x in tt.secShortName]]

# %%
tt1
# Out:
#                    CR        HR        IR        SR       SoR        XR  \
# secID
# 020025.OFCN  1.221133  0.306770  0.004131  1.262651  1.696372  0.005550
# 159913.XSHE  0.262325  0.115044  0.000010  0.450219  0.537244  0.000012
# 159917.XSHE  0.945995  0.314967  0.003773  1.164311  1.515511  0.004911
# 159924.XSHE  0.205422  0.102103  0.000023  0.403497  0.447659  0.000025
# 163821.XSHE  0.093872  0.047539 -0.000944  0.195278  0.220803 -0.001068
# 310398.OFCN  0.408831  0.164572  0.001029  0.720562  0.859804  0.001228
# 519671.OFCN  0.396555  0.163429  0.001017  0.716711  0.854303  0.001212
# 519706.OFCN  0.240971  0.104085 -0.000073  0.434622  0.516512 -0.000087
# 519714.OFCN  1.832477  0.398157  0.005503  1.737731  2.145107  0.006793
#
#                  dLPM       dMD    dSIGMA       secShortName
# secID
# 020025.OFCN  0.834570  0.777853  0.784305    国泰中小板300成长ETF联接
# 159913.XSHE  0.807238  0.644968  0.774507       交银深证300价值ETF
# ...

# %%
tt2= tt[[( '上证50' in x  ) for x in tt.secShortName]]
tt2
# Out:
#                    CR        HR        IR        SR       SoR        XR  \
# secID
# 180033.OFCN  0.093487  0.045638 -0.000856  0.205992  0.243647 -0.001012
# 510430.XSHG  0.141852  0.070221 -0.000497  0.290916  0.346842 -0.000593
#
#                  dLPM       dMD    dSIGMA    secShortName
# secID
# 180033.OFCN  0.829184  0.613744  0.801273  银华上证50等权重ETF联接
# 510430.XSHG  0.816720  0.609552  0.785543    银华上证50等权重ETF

# %%
tt3= tt[[( '上证180' in x  ) for x in tt.secShortName]]
tt3
# Out:
#                    CR        HR        IR        SR       SoR        XR  \
# secID
# 240016.OFCN  0.385251  0.146976  0.000973  0.660963  0.813615  0.001197
# 240019.OFCN  0.279081  0.112820  0.000269  0.506217  0.617222  0.000328
# 263001.OFCN  0.165377  0.080384 -0.000275  0.340104  0.374190 -0.000303
# 510030.XSHG  0.411224  0.162467  0.001079  0.686551  0.849627  0.001335
# 510280.XSHG  0.285512  0.120845  0.000303  0.509736  0.620094  0.000369
# 510420.XSHG  0.101674  0.052789 -0.000879  0.211999  0.238195 -0.000988
# 510450.XSHG  0.210993  0.108925  0.000431  0.331625  0.402191  0.000523
#
#                  dLPM       dMD    dSIGMA       secShortName
# secID
# 240016.OFCN  0.834731  0.682831  0.800622     华宝上证180价值ETF联接
# 240019.OFCN  0.832946  0.667474  0.800220     华宝上证180成长ETF联接
# 263001.OFCN  0.806687  0.615042  0.789504  景顺长城上证180等权重ETF联接
# 510030.XSHG  0.825950  0.673626  0.789274       华宝上证180价值ETF
# 510280.XSHG  0.822933  0.654911  0.788934       华宝上证180成长ETF
# ...

# %%
tt4= tt[[( '上证' in x and '上证50' not in x and '上证180' not in x ) for x in tt.secShortName]]
tt4
# Out:
#                    CR        HR        IR        SR       SoR        XR  \
# secID
# 050013.OFCN  0.217685  0.095019 -0.000017  0.419317  0.507145 -0.000020
# 510020.XSHG  0.222738  0.100705  0.000015  0.422918  0.512339  0.000018
# 510880.XSHG  0.269616  0.126386  0.000312  0.526732  0.592679  0.000351
#
#                  dLPM       dMD    dSIGMA   secShortName
# secID
# 050013.OFCN  0.829144  0.646296  0.797236  博时上证超级大盘ETF联接
# 510020.XSHG  0.821553  0.636276  0.788109     博时上证超大盘ETF
# 510880.XSHG  0.807958  0.625777  0.786673    华泰柏瑞上证红利ETF

# %%
tt5= tt[[( '深证' in x  ) for x in tt.secShortName]]
tt5
# Out:
#                    CR        HR        IR        SR       SoR        XR  \
# secID
# 050021.OFCN  0.318276  0.123402  0.000264  0.532250  0.637512  0.000316
# 070023.OFCN  0.355736  0.139526  0.000489  0.593205  0.719990  0.000593
# 090012.OFCN  0.021900  0.010902 -0.001229  0.041256  0.050626 -0.001508
# 159905.XSHE  0.399044  0.165768  0.000715  0.631878  0.798608  0.000904
# 159906.XSHE  0.029249  0.014772 -0.001155  0.058126  0.073970 -0.001469
# 159908.XSHE  0.325195  0.132816  0.000324  0.543447  0.650397  0.000388
# 159910.XSHE  0.370490  0.149229  0.000533  0.600539  0.732811  0.000651
# 159913.XSHE  0.262325  0.115044  0.000010  0.450219  0.537244  0.000012
# 159916.XSHE  0.438236  0.170024  0.000815  0.674259  0.838297  0.001013
# 481012.OFCN  0.390430  0.157330  0.000702  0.633690  0.797793  0.000884
# 519706.OFCN  0.240971  0.104085 -0.000073  0.434622  0.516512 -0.000087
# 530015.OFCN  0.424575  0.160366  0.000796  0.673988  0.837212  0.000989
#
# ...

# %% [markdown]
# 通过对比有以下结论：
# ---
# 1、	沪深300、上证180、上证指数和深证指数相关smart beta 基金比指数在收益和风险调整收益方面都更有优势。
# 2、	中证50相关smart beta 基金比指数在收益和风险调整收益方面没有优势。
# 3、	和深证指数相关smart beta 基金相对传统指数在收益和风险调整收益优势更明显些。
# 4、	整体上看，smart beta 基金大概率比传统指数更聪明。
# 5、	但并不是smart beta 基金，不一定比传统指数在收益和风险调整收益方面更有优势。就是说不一定更聪明。所以叫smart beta不太合适。因子投资产品更准确些。

# %% [markdown]
# **由上面的实证分析可以，在中国smart beta 还是很聪明的，因为中国资本市场是一个新兴市场，市场有效性比较弱，有些因子的超额收益还是很明显的。下面我们把成立5年以上的smart beta 基金和各大指数，依据等权原则编制各类型基金净值指数，下面的图更直观的展示了smart beta 还是很smart 的**

# %%
a=pd.concat([Indextype_smartbeta,Indextype_index],axis=1)
a.columns=["Indextype_smartbeta","Indextype_index"]
a.plot()
