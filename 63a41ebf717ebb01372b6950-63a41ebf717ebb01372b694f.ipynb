# %% [markdown]
# # Notebook0

# %%
import pandas as pd

# %%
t=DataAPI.EquShareholderNumGet(beginDate=u"20210912",endDate=u"20221201",beginPublishDate=u"20210912",endPublishDate=u"20221201",pandas="1")

# %%
t['股东人数涨跌幅']=t.groupby('secID').apply(lambda x:x.iloc[0]['shNum']/x.iloc[-1]['shNum'])

# %%
print(t)
# Out:
#              secID  ticker secShortName exchangeCD publishDate     endDate  \
# 0      000001.XSHE  000001         平安银行       XSHE  2022-10-25  2022-09-30
# 1      000001.XSHE  000001         平安银行       XSHE  2022-08-18  2022-06-30
# 2      000001.XSHE  000001         平安银行       XSHE  2022-04-27  2022-03-31
# 3      000001.XSHE  000001         平安银行       XSHE  2022-03-10  2022-02-28
# 4      000001.XSHE  000001         平安银行       XSHE  2022-03-10  2021-12-31
# 5      000001.XSHE  000001         平安银行       XSHE  2021-10-21  2021-09-30
# 6      000002.XSHE  000002          万科A       XSHE  2022-10-29  2022-09-30
# 7      000002.XSHE  000002          万科A       XSHE  2022-08-31  2022-07-31
# 8      000002.XSHE  000002          万科A       XSHE  2022-08-31  2022-06-30
# 9      000002.XSHE  000002          万科A       XSHE  2022-04-29  2022-03-31
# 10     000002.XSHE  000002          万科A       XSHE  2022-03-31  2022-02-28
# ...
