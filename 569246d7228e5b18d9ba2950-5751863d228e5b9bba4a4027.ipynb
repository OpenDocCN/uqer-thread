# %% [markdown]
# # MA_20151203_i_pd模拟盘交易比回测晚一天

# %% [markdown]
# 为啥这个策略模拟盘的交易总是要比回测的晚一天呢；
# 回测详情里交易时间和预期一致，但是模拟的时候总是晚一天
# 回测在2016-01-06卖出
# 但是在模拟盘跑的时候0107才执行卖出的；
# 是不是系统有bug

# %% [raw]
# import math
# import numpy as np
# import pandas as pd
# from pandas import Series,DataFrame
# from datetime import timedelta,date
#
# start = '20120101'                       # 回测起始时间
# end =   '20160106'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# #benchmark = '399006.ZICN'
# universe = ['159915.XSHE']  # 证券池，支持股票和基金
# #universe = ['510050.XSHG']
# commission = Commission(0.0,0.0)
#
#
#
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# #self defined data
# #最优参数，ma_short=8 ma_long=26;当开盘MA3和MA23金叉时买入，MA3和MA23死叉时卖出
# #(8 9 10 11) (25 26 27 28)
# window_short = 8
# window_long = 26
# universe_tuple = tuple(universe)
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     hist = account.get_attribute_history('closePrice',window_long)
#     fund = universe_tuple[0]
#     today = account.current_date
#     preday = today + timedelta(days = -100)
#     #print today
#     #print preday
#
#     cIndex = DataAPI.MktIdxdGet(ticker='399006',beginDate=preday,endDate=today,field=["tradeDate","closeIndex"],pandas="1")
#     #print cIndex
#     maIndexShort  = np.round(pd.rolling_mean(cIndex['closeIndex'],window=window_short),2)
#     maIndexLong  = np.round(pd.rolling_mean(cIndex['closeIndex'],window=window_long),2)
#
#     if maIndexShort.values[-2] >= maIndexLong.values[-2]:
#         if account.position.secpos.get(fund, 0) == 0:
#             approximationAmount = int(account.cash / (hist[universe_tuple[0]][-1]*1.02)/100.0) * 100
#             order(universe_tuple[0],approximationAmount)
#     elif maIndexShort.values[-2] < maIndexLong.values[-2]:
#         if account.position.secpos.get(fund, 0) > 0:
#             order_to(universe_tuple[0],0)
#     else :
#         if isnan(maIndexShort.values[-1]) or isnan(maIndexLong.values[-1]) :
#             print 'Warning : MA is NaN.'
#         pass

# %%
print 'window windows  annualized_return     sharpe    max_drawdown'
for window_long in range(19,31,1):
    for window_short in range(6,15,1):
        sim_params = quartz.sim_condition.env.SimulationParameters(start, end, benchmark, universe, capital_base)
        strategy = quartz.sim_condition.strategy.TradingStrategy(initialize, handle_data) 
        idxmap_all, data_all = quartz.sim_condition.data_generator.get_daily_data(sim_params)
        bt_test, acct = quartz.quick_backtest(sim_params, strategy, idxmap_all, data_all)
        perf = quartz.perf_parse(bt_test, acct)
        print '{0:2d}    {1:2d}          {2:>7.4}%           {3:>7.4}      {4:>7.4}'.format(window_long,window_short,perf['annualized_return']*100, perf['sharpe'], perf['max_drawdown'])
# Out:
# window windows  annualized_return     sharpe    max_drawdown
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <mercury-input-1-e1399efbcae3> in <module>()
#       2 for window_long in range(19,31,1):
#       3     for window_short in range(6,15,1):
# ----> 4         sim_params = quartz.sim_condition.env.SimulationParameters(start, end, benchmark, universe, capital_base)
#       5         strategy = quartz.sim_condition.strategy.TradingStrategy(initialize, handle_data)
#       6         idxmap_all, data_all = quartz.sim_condition.data_generator.get_daily_data(sim_params)
#
# NameError: name 'start' is not defined

# %%
b = bt['blotter']
print type(b.values)
c=b.values
#print c[:5]
#print c['Order']
#print c['transact_price']
c=b[[x for x in b.index if len(b[x]) > 0]]
print c.values[:5]
print c.values[-10:]
# Out:
# <type 'numpy.ndarray'>
# [ [Order(order_time: 2012-02-16 09:30, symbol: 159915.XSHE, direction: 1, order_amount: 135000, state: Normal, filled_time: 2012-02-16 09:30, filled_amount: 135000, transact_price: 0.7230, slippage: 0.0000, commission: 0.0000)]
#  [Order(order_time: 2012-03-27 09:30, symbol: 159915.XSHE, direction: -1, order_amount: 135000, state: Normal, filled_time: 2012-03-27 09:30, filled_amount: 135000, transact_price: 0.7460, slippage: -0.0000, commission: -0.0000)]
#  [Order(order_time: 2012-05-10 09:30, symbol: 159915.XSHE, direction: 1, order_amount: 139600, state: Normal, filled_time: 2012-05-10 09:30, filled_amount: 139600, transact_price: 0.7250, slippage: 0.0000, commission: 0.0000)]
#  [Order(order_time: 2012-07-04 09:30, symbol: 159915.XSHE, direction: -1, order_amount: 139600, state: Normal, filled_time: 2012-07-04 09:30, filled_amount: 139600, transact_price: 0.7520, slippage: -0.0000, commission: -0.0000)]
#  [Order(order_time: 2012-07-10 09:30, symbol: 159915.XSHE, direction: 1, order_amount: 144500, state: Normal, filled_time: 2012-07-10 09:30, filled_amount: 144500, transact_price: 0.7240, slippage: 0.0000, commission: 0.0000)]]
# [ [Order(order_time: 2014-11-27 09:30, symbol: 159915.XSHE, direction: 1, order_amount: 106200, state: Normal, filled_time: 2014-11-27 09:30, filled_amount: 106200, transact_price: 1.5080, slippage: 0.0000, commission: 0.0000)]
#  [Order(order_time: 2014-12-29 09:30, symbol: 159915.XSHE, direction: -1, order_amount: 106200, state: Normal, filled_time: 2014-12-29 09:30, filled_amount: 106200, transact_price: 1.4890, slippage: -0.0000, commission: -0.0000)]
#  [Order(order_time: 2015-01-16 09:30, symbol: 159915.XSHE, direction: 1, order_amount: 103200, state: Normal, filled_time: 2015-01-16 09:30, filled_amount: 103200, transact_price: 1.5280, slippage: 0.0000, commission: 0.0000)]
#  [Order(order_time: 2015-06-24 09:30, symbol: 159915.XSHE, direction: -1, order_amount: 103200, state: Normal, filled_time: 2015-06-24 09:30, filled_amount: 103200, transact_price: 3.2200, slippage: -0.0000, commission: -0.0000)]
#  [Order(order_time: 2015-07-28 09:30, symbol: 159915.XSHE, direction: 1, order_amount: 133600, state: Normal, filled_time: 2015-07-28 09:30, filled_amount: 133600, transact_price: 2.3800, slippage: 0.0000, commission: 0.0000)]
#  [Order(order_time: 2015-08-05 09:30, symbol: 159915.XSHE, direction: -1, order_amount: 133600, state: Normal, filled_time: 2015-08-05 09:30, filled_amount: 133600, transact_price: 2.4170, slippage: -0.0000, commission: -0.0000)]
#  [Order(order_time: 2015-09-29 09:30, symbol: 159915.XSHE, direction: 1, order_amount: 169000, state: Normal, filled_time: 2015-09-29 09:30, filled_amount: 169000, transact_price: 1.9350, slippage: 0.0000, commission: 0.0000)]
#  [Order(order_time: 2015-12-08 09:30, symbol: 159915.XSHE, direction: -1, order_amount: 169000, state: Normal, filled_time: 2015-12-08 09:30, filled_amount: 169000, transact_price: 2.5560, slippage: -0.0000, commission: -0.0000)]
#  [Order(order_time: 2015-12-21 09:30, symbol: 159915.XSHE, direction: 1, order_amount: 163900, state: Normal, filled_time: 2015-12-21 09:30, filled_amount: 163900, transact_price: 2.6540, slippage: 0.0000, commission: 0.0000)]
#  [Order(order_time: 2016-01-06 09:30, symbol: 159915.XSHE, direction: -1, order_amount: 163900, state: Normal, filled_time: 2016-01-06 09:30, filled_amount: 163900, transact_price: 2.2910, slippage: -0.0000, commission: -0.0000)]]
