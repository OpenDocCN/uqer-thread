# %% [markdown]
# #

# %% [markdown]
# 以深证成指为参考标的，筛选前十个交易日内相对399001，1、十个交易日相对跌幅不超过5% 2、十个交易日内至少有三个交易日相对涨幅大于5%。筛选出的股票选取换手率前三的股票买入，已剔除40个工作日内上市的新股及300372这只黑天鹅。回测结果如下：

# %% [raw]
# #强势跟踪
# start = '2015-09-21'                       # 回测起始时间
# end = '2016-09-21'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('A')           # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 5                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
#
# import pandas as pd
# import lib.poolstock as po
# from CAL.PyCAL import *
# cal = Calendar('China.SSE')
#
#
# def relativereturn(begindate,enddate,days,ticker,e,lower,relative,per):
#     szcz=DataAPI.MktIdxdGet(beginDate=begindate,endDate=enddate,indexID=u"",ticker=e,field=u"tradeDate,chgPct",pandas="1")
#     dailyreturnselect=pd.DataFrame(columns=['secShortName','secID','tradeDate','dailyReturnNoReinv','CHGPct','relative'])
#     for x in ticker:
#         dailyreturn=(DataAPI.EquRetudGet(ticker=x,beginDate=begindate,
#         endDate=enddate,isChgPctl=u"",field=u"secShortName,secID,tradeDate,dailyReturnNoReinv",pandas="1"))
#         dailyreturn=pd.merge(left=dailyreturn,right=szcz,left_on='tradeDate',right_on='tradeDate')
#         dailyreturn['relative']=100*(dailyreturn['dailyReturnNoReinv']-dailyreturn['CHGPct'])
#         if  (float(len(dailyreturn[dailyreturn['relative']>relative]))/days)<per:
#            # if (float(len(dailyreturn[dailyreturn['relative']>relative]))/days)<per:
#             pass
#         elif len(dailyreturn[dailyreturn['relative']>lower])==days:
#             dailyreturnselect=dailyreturnselect.append(dailyreturn)
#         else: dailyreturnselect=dailyreturnselect
#     return dailyreturnselect
#
#
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     today=account.current_date
#     yesterday = cal.advanceDate(today,Period('-1B')).toDateTime().strftime('%Y-%m-%d')
#     date_40= cal.advanceDate(today,Period('-40B')).toDateTime().strftime('%Y-%m-%d')
#     date_10= cal.advanceDate(today,Period('-10B')).toDateTime().strftime('%Y-%m-%d')
#     gpc=po.stockpool(yesterday,date_40)
#
#     gpc=gpc.drop(gpc[gpc['secID']=='300372.XSHE'].index)
#     gpc=gpc[[True if i in account.universe else False for i in gpc['secID']]]
#
#     gpc= gpc.sort(columns='turnoverRate',ascending=False)
#     tic=gpc['ticker']
#     ree=relativereturn(date_10,yesterday,10,tic,'399001',-5,5,0.3)
#
#     if len(ree)>1:
#         stocktobuy=list(ree['secID'].unique())
# #        print today
# #        print len(stocktobuy)
#         stocktobuy1=stocktobuy[0:3]
#     else:stocktobuy1= ['000001.XSHE']
#
#     for stock in account.valid_secpos:
#         if stock in stocktobuy1:
#             pass
#         else:order_to(stock, 0)
#
#     for x in stocktobuy1:
#         if x in account.valid_secpos:
#             pass
#         else:   order_pct_to(x, 0.99/len(stocktobuy1))
#
#
#     return

# %% [markdown]
# 以深证成指为参考标的，筛选前十个交易日内相对399001，1、十个交易日相对涨幅不超过1% 2、十个交易日内至少有五个交易日相对跌幅大于1%。筛选出的股票选取换手率最低的三只股票买入，已剔除40个工作日内上市的新股及300372这只黑天鹅。回测结果如下：

# %% [raw]
# #弱势跟踪
# start = '2015-09-21'                       # 回测起始时间
# end = '2016-09-21'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('A')           # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 5                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
#
# import pandas as pd
# import lib.poolstock as po
# from CAL.PyCAL import *
# cal = Calendar('China.SSE')
#
#
# def relativereturn(begindate,enddate,days,ticker,e,lower,relative,per):
#     szcz=DataAPI.MktIdxdGet(beginDate=begindate,endDate=enddate,indexID=u"",ticker=e,field=u"tradeDate,chgPct",pandas="1")
#     dailyreturnselect=pd.DataFrame(columns=['secShortName','secID','tradeDate','dailyReturnNoReinv','CHGPct','relative'])
#     for x in ticker:
#         dailyreturn=(DataAPI.EquRetudGet(ticker=x,beginDate=begindate,
#         endDate=enddate,isChgPctl=u"",field=u"secShortName,secID,tradeDate,dailyReturnNoReinv",pandas="1"))
#         dailyreturn=pd.merge(left=dailyreturn,right=szcz,left_on='tradeDate',right_on='tradeDate')
#         dailyreturn['relative']=100*(dailyreturn['dailyReturnNoReinv']-dailyreturn['CHGPct'])
#         if  (float(len(dailyreturn[dailyreturn['relative']<relative]))/days)<per:
#             pass
#         elif len(dailyreturn[dailyreturn['relative']<lower])==days:
#             dailyreturnselect=dailyreturnselect.append(dailyreturn)
#         else: dailyreturnselect=dailyreturnselect
#     return dailyreturnselect
#
#
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     today=account.current_date
#     yesterday = cal.advanceDate(today,Period('-1B')).toDateTime().strftime('%Y-%m-%d')
#     date_40= cal.advanceDate(today,Period('-40B')).toDateTime().strftime('%Y-%m-%d')
#     date_10= cal.advanceDate(today,Period('-10B')).toDateTime().strftime('%Y-%m-%d')
#     gpc=po.stockpool(yesterday,date_40)
#
#     gpc=gpc.drop(gpc[gpc['secID']=='300372.XSHE'].index)
#     gpc=gpc[[True if i in account.universe else False for i in gpc['secID']]]
#
#     gpc= gpc.sort(columns='turnoverRate')
#     tic=gpc['ticker']
#     ree=relativereturn(date_10,yesterday,10,tic,'399001',1,-1,0.5)
#
#     if len(ree)>0:
#         stocktobuy=list(ree['secID'].unique())
#         stocktobuy1=stocktobuy[0:3]
#         print today
#         print len(stocktobuy)
#     else:stocktobuy1= gpc['secID'].head(3)
#
#
#
#     for stock in account.valid_secpos:
#         if stock in stocktobuy1:
#             pass
#         else:order_to(stock, 0)
#
#     for s in stocktobuy1:
#         if s in account.valid_secpos:
#             pass
#         else:   order_pct_to(s, 0.99/len(stocktobuy1))
#
#
#     return
