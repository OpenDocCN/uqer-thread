# %% [markdown]
# # 3.5pandas

# %%
#3.5pandas储存和调用
#可存储和调用的文件格式有：csv,excel,hdf,sql,json,html,stata,sas,clipboard,pickle
import pandas as pd

data=pd.read_csv('student.csv')#读取一个名称为student,格式为csv的文件
print(data)

data.to_pickle('student.pickle')#将上面这个data文件存储为名为student，格式为pickle的文件
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <mercury-input-1-D7EB1CEB819C4F5E8373F0648E6FE4C3> in <module>()
#       2 import pandas as pd
#       3
# ----> 4 data=pd.read_csv('student.csv')
#       5 print(data)
#
# ...

# %% [markdown]
# 实操过程中，读取文件在括号中需要加r才能运行

# %%
import pandas as pd

data=pd.read_csv(r'C:\Users\huasheng\Desktop\RB2005_5m.csv')
print(data)
