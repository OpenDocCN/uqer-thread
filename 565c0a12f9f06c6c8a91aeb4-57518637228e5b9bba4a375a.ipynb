# %% [markdown]
# # NO1

# %% [raw]
# import numpy as np
# start = '2012-01-01'                       # 回测起始时间
# end = '2015-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['600022.XSHG', '600569.XSHG']  # 证券池，支持股票和基金
# capital_base = 10000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# p=DataAPI.MktEqudGet(secID=u"",ticker=u"600022",tradeDate=u"",beginDate=u"20120101",endDate=u"20150101",field=u"",pandas="1")
# s0=p.closePrice[0]
# q=DataAPI.MktEqudGet(secID=u"",ticker=u"600569",tradeDate=u"",beginDate=u"20120101",endDate=u"20150101",field=u"",pandas="1")
# a0=q.closePrice[0]
#
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#      s=account.referencePrice[0]/s0
#      a=account.referencePrice[1]/a0
#      w=s-a
#     if  w > 0.005:
#         amounta=account.cash/ (account.referencePrice[1])
#         order_to('600569.XSHG',amounta)
#         order_to('600022.XSHG',0)
#     elif w < -0.005:
#         amounts=account.cash/ (account.referencePrice[0])
#         order_to('600022.XSHG',amounts)
#         order_to('600569.XSHG',0)
#
#     return
