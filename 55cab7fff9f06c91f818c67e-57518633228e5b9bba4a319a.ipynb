# %% [markdown]
# # 股票停牌数据问题

# %% [markdown]
# 问题描述：
# 我想在strategy里获得除去停牌的数据集上的前几天数据.
# 停牌那天account.universe直接去掉了停牌股票
# 然后get-attribute-history 那天得到空集，如果是closePrice就是昨日收盘价
# get-history 那天就只返回benchmark
# get-symbol-history 直接报错了
#
# #所以如果想像看盘软件那样自动把停牌前后的数据连接起来，还要单独检测是否停牌？
# #有没有直接得到去除停牌的数据的方法？

# %%
DataAPI.MktEqudAdjGet(ticker='002424', beginDate='20131209', endDate='20131214')
# 20131212停牌
# Out:
#          secID  ticker exchangeCD secShortName secShortNameEn   tradeDate  \
# 0  002424.XSHE  002424       XSHE         贵州百灵           GZBL  2013-12-09
# 1  002424.XSHE  002424       XSHE         贵州百灵           GZBL  2013-12-10
# 2  002424.XSHE  002424       XSHE         贵州百灵           GZBL  2013-12-11
# 3  002424.XSHE  002424       XSHE         贵州百灵           GZBL  2013-12-12
# 4  002424.XSHE  002424       XSHE         贵州百灵           GZBL  2013-12-13
#
#    preClosePrice  openPrice  highestPrice  lowestPrice  closePrice  \
# 0         20.106     19.968        20.452       19.780      20.235
# 1         20.235     20.146        20.393       19.889      20.067
# 2         20.067     19.948        21.648       19.948      21.194
# 3         21.194      0.000         0.000        0.000      21.194
# 4         21.194     21.747        23.012       21.203      21.975
#
#    turnoverVol  turnoverValue
# 0      2212204       45141696
# 1      1974225       40217624
# ...

# %% [raw]
# start = '2013-12-05'                       # 回测起始时间
# end = '2013-12-18'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['002424.XSHE']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     print account.current_date, account.universe
#     print account.get_attribute_history('turnoverValue', 3)
#     print account.get_history(3)
#     print account.get_symbol_history('002424.XSHE', 3)
