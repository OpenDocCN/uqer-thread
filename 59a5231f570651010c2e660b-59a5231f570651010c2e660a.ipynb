# %% [markdown]
# # Notebook24

# %%
import datetime
import numpy as np
import pandas as pd
data=pd.DataFrame(np.random.randn(7,3))
data.ix[:4,1]='Nan'
data.ix[:2,2]='Nan'
print(data)
# Out:
#           0        1         2
# 0 -0.863044      Nan       Nan
# 1  0.635820      Nan       Nan
# 2  1.078470      Nan       Nan
# 3  0.886158      Nan -0.266589
# 4  0.918128      Nan -0.677452
# 5 -0.153770  0.82593  -1.18477
# 6 -1.480204 -1.57409 -0.419448

# %%
data.dropna(axis=0)
# Out:
#           0        1         2
# 0 -0.863044      Nan       Nan
# 1  0.635820      Nan       Nan
# 2  1.078470      Nan       Nan
# 3  0.886158      Nan -0.266589
# 4  0.918128      Nan -0.677452
# 5 -0.153770  0.82593  -1.18477
# 6 -1.480204 -1.57409 -0.419448
