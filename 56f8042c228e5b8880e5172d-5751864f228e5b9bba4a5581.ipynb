# %% [markdown]
# # 小白初学100问之第三问。蛋卷斗牛二八轮动

# %% [markdown]
# 雪球上蛋卷斗牛二八轮动挺有意思，实现起来也比较简单，作为菜鸟的我，忍不住来实现一下
# 本指数根据广泛传播于互联网的「二八轮动」趋势跟随策略编制，成分标的为沪深300指数、中证500指数和国债指数。本指数对比当前交易日收盘数据与二十个交易日前的收盘数据，选择沪深300指数和中证500指数中涨幅较大的一个，于下一个交易日收盘时切换为持有该指数；若两个指数均为下跌，则于下个交易日收盘时切换为持有国债指数。

# %% [raw]
# import pandas as pd
# import numpy as np
# start = '2013-05-01'
# end = u''
# benchmark ='HS300'       # 策略参考标准
# universe = '159919.XSHE','159922.XSHE'
# capital_base = 1000000
# refresh_rate = 1
# def initialize(account):
#     pass
# def handle_data(account):
#     info_1=DataAPI.MktIdxdGet(ticker='000300',beginDate='20130301',endDate=account.current_date,field='secShortName,tradeDate,closeIndex,',pandas='1')
#     info_2=DataAPI.MktIdxdGet(ticker='000905',beginDate='20130301',endDate=account.current_date,field='secShortName,tradeDate,closeIndex',pandas='1')
#     signal_1=(info_1['closeIndex'].iloc[-2]-info_1['closeIndex'].iloc[-21])/info_1['closeIndex'].iloc[-21]
#     signal_2=(info_2['closeIndex'].iloc[-2]-info_2['closeIndex'].iloc[-21])/info_2['closeIndex'].iloc[-21]
#     for stock in universe:
#             if signal_1<0 and signal_2<0:
#                     order_to(stock,0)
#             else:
#                 if signal_1>signal_2:
#                     if '159919.XSHE' not in account.avail_secpos:
#                        order_to(stock,0)
#                        order_pct_to( '159919.XSHE',1)
#                 if signal_2>signal_1:
#                     if'159922.XSHE' not in account.avail_secpos:
#                        order_to(stock,0)
#                        order_pct_to( '159922.XSHE',1)

# %% [markdown]
# 作为新人当然要问几个问题的啦
# #1、回测起来和雪球有一点点不一致，看起来好像是空仓的时间点。不知道哪里出错了
# #2、如何让闲置资金购买银华日利
# #3、下一步应该要实现闲置资金购买分级A。。
