# %% [markdown]
# # Notebook36

# %%
import numpy as np
import pandas as pd
universe = ['002806.XSHE']
dataday=DataAPI.MktEqudGet(secID=universe[0],ticker=u"",beginDate=u"",endDate=u"",isOpen="",field=u"",pandas="1")
dataday['label'] = pd.qcut(dataday['chgPct'],4,labels = ['1','2','3','4'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <mercury-input-4-F29A279FCF644E4187686D75BE3E8239> in <module>()
#       3 universe = ['002806.XSHE']
#       4 dataday=DataAPI.MktEqudGet(secID=universe[0],ticker=u"",beginDate=u"",endDate=u"",isOpen="",field=u"",pandas="1")
# ----> 5 dataday['label'] = pd.qcut(dataday['chgPct'],4,labels = ['1','2','3','4'])
#       6
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/tools/tile.pyc in qcut(x, q, labels, retbins, precision)
#     171     bins = algos.quantile(x, quantiles)
#     172     return _bins_to_cuts(x, bins, labels=labels, retbins=retbins,
# --> 173                          precision=precision, include_lowest=True)
#     174
#     175
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/tools/tile.pyc in _bins_to_cuts(x, bins, right, labels, retbins, precision, name, include_lowest)
#     190
# ...
