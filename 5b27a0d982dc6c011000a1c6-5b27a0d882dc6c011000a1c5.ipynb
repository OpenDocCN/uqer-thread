# %% [markdown]
# # 三因子

# %%
import numpy as np
import pandas as pd 
from CAL.PyCAL import *
Year = 2007
data = DataAPI.TradeCalGet(exchangeCD=u"XSHG",beginDate=str(Year*10000+1201),endDate=str((Year+10)*10000+1231),field=['calendarDate','isMonthEnd'])
data = data[data['isMonthEnd'] == 1]
date= map(lambda x: x[0:4]+x[5:7]+x[8:10], data['calendarDate'].values.tolist())
monthdate = list(data.calendarDate)
def Areturn(i = 0):
    breakpoint = date[i]                      
    #取沪深300
    universe = set_universe('HS300',date=breakpoint)
    ##SMB股票选取市场规模因子
    ME = DataAPI.MktEqudGet(tradeDate=breakpoint,secID=universe,field=u"ticker,marketValue").dropna()   
    ME30 = np.percentile(ME['marketValue'],30) 
    ME70 = np.percentile(ME['marketValue'],70)
    SM = ME[ME['marketValue']<=ME30]['ticker'].tolist()                               
    BM = ME[ME['marketValue']>ME70]['ticker'].tolist()
    ##HML股票选取市账率因子
    BP = DataAPI.MktStockFactorsOneDayGet(tradeDate=breakpoint,secID=universe,field=u"ticker,PB").dropna() 
    BP = BP[BP>0].dropna()                                                
    BP[['PB']]=1/BP[['PB']]                                                
    BP30 = np.percentile(BP['PB'],30)
    BP70 = np.percentile(BP['PB'],70)
    LP = BP[BP['PB']<=BP30]['ticker'].tolist()                                      
    HP = BP[BP['PB']>BP70]['ticker'].tolist()
    tickerlist = [SM,BM,LP,HP]
    tickername = ['SM','BM','LP','HP']
    #取出选择股票计算收益率
    cfrm = pd.DataFrame()
    for n,j in zip(tickername,tickerlist):
        a = DataAPI.MktEqudGet(tradeDate=date[i],secID=u"",ticker= j ,beginDate=u"",endDate=u"",isOpen="",field=u"ticker,	tradeDate,accumAdjFactor,closePrice",pandas="1")
        a['price'] = a['closePrice'] * a['accumAdjFactor']
        b = DataAPI.MktEqudGet(tradeDate=date[i+1],secID=u"",ticker= j ,beginDate=u"",endDate=u"",isOpen="",field=u"ticker,	tradeDate,accumAdjFactor,closePrice",pandas="1")
        b['price'] = b['closePrice'] * b['accumAdjFactor']
        c = ((b['price'] - a['price'])/a['price']).mean()
        cfrm[n] = [c]
    return cfrm
Returnfrm = pd.DataFrame()
for t in range(len(monthdate)-1):
    x = Areturn(t)
    Returnfrm = pd.concat([Returnfrm,x])
Returnfrm.index = monthdate[1:]
SMB = Returnfrm['SM'] - Returnfrm['BM']
HML = Returnfrm['LP'] - Returnfrm['HP']
#大盘指数
Rc = DataAPI.MktIdxdGet(tradeDate=u"",indexID=u"",ticker=u"000001",beginDate=date[0],endDate=date[-1],field=u"tradeDate,closeIndex",pandas="1")
Rc.index = list(Rc.tradeDate)
Rc['Index'] = Rc.ix[list(monthdate)]['closeIndex']
Rc = Rc.dropna()
Rturn = Rc['Index'].pct_change().dropna()-0.0025
choosedata = pd.concat([Rturn,SMB,HML],axis = 1).dropna()
choosedata = choosedata.rename_axis({0:'SMB',1:'HML'}, axis='columns')
choosedata.to_excel('三因子收益数据.xlsx')
print choosedata
# Out:
#                Index       SMB       HML
# 2008-01-31 -0.169403  0.091787 -0.035652
# 2008-02-29 -0.010450  0.057206 -0.026307
# 2008-03-31 -0.203908  0.015264 -0.014680
# 2008-04-30  0.060964 -0.075171 -0.003785
# 2008-05-30 -0.072834  0.033236 -0.011654
# 2008-06-30 -0.205582 -0.039363  0.044672
# 2008-07-31  0.011978  0.091693 -0.035896
# 2008-08-29 -0.138806 -0.066661 -0.038793
# 2008-09-26 -0.045708 -0.010739 -0.038807
# 2008-10-31 -0.248817 -0.007521 -0.019668
# 2008-11-28  0.079853  0.089571 -0.067321
# 2008-12-31 -0.029409  0.042653  0.032455
# 2009-01-23  0.090784  0.104616 -0.063740
# 2009-02-27  0.043814  0.064151 -0.033511
# 2009-03-31  0.136905  0.031756  0.015711
# 2009-04-30  0.041472 -0.004092  0.018080
# 2009-05-27  0.060207  0.019417 -0.020080
# 2009-06-30  0.121481 -0.063112 -0.020292
# 2009-07-31  0.150472  0.039024 -0.057866
# 2009-08-31 -0.220643  0.064581  0.007232
# 2009-09-30  0.039363 -0.021114  0.041077
# 2009-10-30  0.075366  0.035444  0.019930
# 2009-11-30  0.064076  0.055721 -0.014270
# 2009-12-31  0.023112  0.111342 -0.217595
# 2010-01-29 -0.090335  0.074178 -0.011516
# 2010-02-26  0.018458  0.032197  0.004143
# 2010-03-31  0.016230 -0.004942 -0.001694
# 2010-04-30 -0.079208  0.024343  0.061473
# 2010-05-31 -0.099505 -0.006583  0.048079
# 2010-06-30 -0.077255 -0.024435 -0.032858
# ...              ...       ...       ...
# 2015-07-31 -0.145933  0.029314  0.051326
# 2015-08-31 -0.127438  0.003324 -0.033425
# 2015-09-30 -0.050287 -0.013745 -0.003314
# 2015-10-30  0.105526  0.084791  0.061380
# 2015-11-30  0.016079  0.043179  0.010644
# 2015-12-31  0.024718 -0.672828 -0.010343
# 2016-01-29 -0.228988 -0.046936 -0.057716
# 2016-02-29 -0.020626  0.020087 -0.036750
# 2016-03-31  0.115037  0.059304  0.041827
# 2016-04-29 -0.024335  0.007590 -0.011289
# 2016-05-31 -0.009888 -0.004163  0.014937
# 2016-06-30  0.001954  0.000322  0.024376
# 2016-07-29  0.014476 -0.004043 -0.034416
# 2016-08-31  0.033129  0.005574 -0.024678
# 2016-09-30 -0.028683 -0.004613 -0.005052
# 2016-10-31  0.029380  0.000658 -0.023818
# 2016-11-30  0.045732 -0.014685 -0.077311
# 2016-12-30 -0.047545  0.006508 -0.020419
# 2017-01-26  0.015392 -0.043488 -0.055269
# 2017-02-28  0.023636  0.020415 -0.338610
# 2017-03-31 -0.008429 -0.032060  0.006697
# 2017-04-28 -0.023557 -0.028290 -0.019173
# 2017-05-31 -0.014381 -0.097930 -0.053768
# 2017-06-30  0.021640  0.004836  0.031791
# 2017-07-31  0.022748 -0.015798 -0.065970
# 2017-08-31  0.024320  0.011242  0.027460
# 2017-09-29 -0.006031  0.003953  0.035255
# 2017-10-31  0.010757 -0.058613  0.037341
# 2017-11-30 -0.024942 -0.048863 -0.045294
# 2017-12-29 -0.005520 -0.014834  0.037061
#
# [120 rows x 3 columns]
