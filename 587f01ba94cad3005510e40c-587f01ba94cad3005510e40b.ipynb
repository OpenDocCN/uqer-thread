# %% [markdown]
# # Notebook3

# %% [raw]
# import numpy as np
# import pandas as pd
# import statsmodels.api as sm
# from pandas import DataFrame,Series
# import math
# import time
# import matplotlib.pyplot as plt
#
#
# def yinzi_test(data,t,n):
#     #定义一个函数yinzi_test，作用为对因子进行分层测试，输入参数包括因子数值data,data为DataFrame 格式，第一列为trade_time,后面为股票代码以及相应的因子值,分层数为n，调仓周期为t个交易日
#     trade_time = list(data['trade_time'])#获取交易的总体时间序列
#     benefit = [[] for i in range(n)] #构造一个收益存储参数
#     start_list =[],end_list=[] #构造一个开始和结束日期储存参数
#     trade_t = 0                       #初始化交易日期
#     stock_list= list(data.columns)[1:] #第一列为日期序列股剔除
#     while trade_t<=(len(trade_time)): #进入时间循环,为了避免最后一个调仓错误,我们将日期提前一个t
#         if trade_t+t<=len(trade_time):
#             start_time,end_time = trade_time[trade_t],trade_time[trade_t+t] #获取本次调仓的开始和结束日期
#         else:
#             start_time,end_time = trade_time[trade_t],trade_time[-1]
#         #为了对因子进行排序，构造一个DataFrame
#         new_Data = DataFrame()
#         new_data['stock'] = stock_list
#         new_data['value_yinzi'] = list(data.iloc[:,trade_t])[1:]
#         stock_name = list(new_data.sort(columns= ['value_yinzi'],ascending=True)['stock'])#对因子进行升序排列,并获取排序好后的股票代码命名为stock_name
#         floor_num = len(stock_list)/n #获取每层股票的只数
#         for i in range(n):
#             if i<(n-1):
#                 stock_i = stock_name[i*floor_num:(i+1)*floor_num]
#             else:
#                 stock_i = stock_name[i*floor_num:]
#             start_stock = DataAPI.MktEqudGet(tradeDate=start_time,secID=stock_i,field=['isOpen','preClosePrice','openPrice','closePrice','secID'],pandas="1")
#                 #剔除开盘涨停股，以及停牌股
#             start_stock['openrise'] = start_stock['openPrice']/start_stock['preClosePrice']
#             start_stock = start_stock[(start_stock['openrise']<=1.098).values & (start_stock['isOpen'] ==1).values]
#                 #h获取结束日期的个股票情况
#             end_stock = DataAPI.MktEqudGet(tradeDate=end_time,secID=list(start_stock['secID']),field=['closePrice','secID'],pandas="1")
#             end_stock['end_closePrice'] = end_stock['clsoePrice']
#             end_stock.drop(['closePrice'],axis=1)
#             new_data = pd.merge(start_stock,end_stock,on=['secID'],how='inner')#将两者进行合并，并使用交集,排除获不到的情况
#             benefit[i].append(np.mean(new_data['end_closePrice']/new_data['closePrice'])-1)
#         start_list.append(start_time)
#         end_list.append(end_time)
#         trade_t +=t
#     #将所有的收益情况放入一个表格p_data中，并输出
#     p_data = DataFrame()
#     p_data['start_time'] =start_list
#     p_data['end_time'] =end_list
#     for p in range(n):
#         p_data['第%d层收益情绪'%p] = benefit[p]
#     return p_data
#     print start_time
