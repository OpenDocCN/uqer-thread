# %% [markdown]
# # Notebook1

# %%
df = DataAPI.MktEqudAdjGet(secID='300062.XSHE',beginDate='20170501',endDate='20170530',field=u"secID,tradeDate,openPrice,highestPrice,lowestPrice,closePrice,turnoverRate",pandas="1")
df
# Out:
#           secID   tradeDate  openPrice  highestPrice  lowestPrice  closePrice  \
# 0   300062.XSHE  2017-05-02     11.913        11.972       11.649      11.654
# 1   300062.XSHE  2017-05-03     11.778        11.778       11.400      11.505
# 2   300062.XSHE  2017-05-04     11.619        11.639       11.430      11.569
# 3   300062.XSHE  2017-05-05     11.624        12.077       11.480      11.948
# 4   300062.XSHE  2017-05-08     11.908        11.908       11.281      11.425
# 5   300062.XSHE  2017-05-09     11.380        11.400       11.012      11.400
# 6   300062.XSHE  2017-05-10     11.410        11.760       11.100      11.110
# 7   300062.XSHE  2017-05-11     10.820        11.110       10.000      10.400
# 8   300062.XSHE  2017-05-12     10.330        11.300       10.130      10.650
# 9   300062.XSHE  2017-05-15     10.650        10.750       10.160      10.180
# 10  300062.XSHE  2017-05-16     10.080        10.470        9.700      10.430
# ...
