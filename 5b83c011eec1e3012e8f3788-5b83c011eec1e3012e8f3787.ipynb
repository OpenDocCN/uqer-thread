# %% [markdown]
# # 特质波动率与特异度

# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import copy
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression 
import statsmodels.api as sm
import scipy.stats as st
import seaborn as sns
import lib.Uqer as uq
sns.set_style('white')
from CAL.PyCAL import *    # CAL.PyCAL中包含font
universe = set_universe('A')

# %%
def plot_under_water(bt):
    bt1 = bt
    bt_quantile_ten = bt1
    data = bt_quantile_ten[[u'tradeDate',u'portfolio_value',u'benchmark_return']]
    data['portfolio_return'] = data.portfolio_value/data.portfolio_value.shift(1) - 1.0
    data['portfolio_return'].ix[0] = data['portfolio_value'].ix[0]/	10000000.0 - 1.0
    data['excess_return'] = data.portfolio_return - data.benchmark_return
    data['excess'] = data.excess_return + 1.0
    data['excess'] = data.excess.cumprod()

    df_cum_rets = data['excess']
    running_max = np.maximum.accumulate(df_cum_rets)
    underwater = -((running_max - df_cum_rets) / running_max)
    underwater.index = data['tradeDate']

    fig = plt.figure(figsize=(12, 5))
    fig.set_tight_layout(True)
    ax1 = fig.add_subplot(111)
    ax2 = ax1.twinx()
    x = range(len(underwater))
    ax1.grid(True)
    ax1.set_ylim(-0.20, 0)
    ax1.fill_between(underwater.index, 0, np.array(underwater), color='#000066', alpha=1)

    ax2.plot(data['tradeDate'], data[['excess']], label='hedged(right)', color='r')
    ax2.set_ylim(bottom=0.9, top=5)
    s = ax1.set_title(u"股票月度调仓走势", fontproperties=font, fontsize=16)
    return fig

# 去极值，标准化，中性化
def pretreat_factor(factor_df, neu=True):
    pretreat_data = factor_df.copy(deep=True)
    for dt in pretreat_data.index:
        dt_str1 = dt.strftime('%Y-%m-%d')
        dt_str2 = dt.strftime('%Y%m%d')
        try:
            factor_dt = pretreat_data.ix[dt].dropna()
            factor_dt_dict = factor_dt.to_dict()
            if neu:
                pretreat_data.ix[dt_str1] = pd.Series(neutralize(standardize(winsorize(factor_df.ix[dt_str1].to_dict())), target_date=dt_str2))
            else:
                pretreat_data.ix[dt] = pd.Series(standardize(winsorize(factor_dt_dict)))
        except Exception as excp:
            print dt
            print excp
            continue
    return pretreat_data

# %% [markdown]
# **1. 因子构建**
# --
# 个股的投机最后必然会表现在股票的交易层面，我们通过波动率高低、个股收益能否被市场风格解释、股价能否及时反应市场公共信息、以及股票的换手程度等四个维度来刻画个股的投机性程度。我们认为被过度投机的股票一般具有下述特征：
# * `高波动性`：被投机的股票一般多空分歧较大，多空博弈的结果导致大的波动。由于个股的某些波动是由市场风格变动引起的，所以我们用剔除市场风格波动后的特质波动率来衡量个股的波动程度。
# * `风格独立`：一般而言，被过度投机的个股在交易时多依赖于其自身的私有信息，无视市场的涨跌或风格，以此投机性强的股票与市场风格关联性差，市场风格对其收益的解释程度弱。我们构建了特异度指标用来度量个股收益中不能被市场风格解释的成分占比。
# * `价格时滞`：正常情况下个股的股价能够及时的反应市场公共信息（市场指数），但是当个股被过度投机时可能会过度关注个股层面的信息，导致市场层面的消息可能反应不足。我们通过**价格时滞**因子度量个股是否及时反应了市场公共信息。
# * `高换手`：换手率是交易员常用的用来甄别投机性股票的指标，投资者投机股票时一般追求的短期收益，成交频繁，博取短期收益，因此股票投机性强时自然伴随着较高的换手率。考虑到市值和换手的相关性，我们用市值调整后的换手率来度量个股的换手特征。
#
# 文章使用了过去36个月的月度数据：
# * 第一步：回归如下方程：
# $$R_{i,t}-R_{f,t}=\alpha_{i}+\beta_{mkt,i}(R_{mkt,t}-R_{f,t})+\beta_{hml,i}R_{hml,t}+\beta_{smb,i}R_{smb,t}+\epsilon_{i,t}$$
# * 第二步：计算特质收益：
# $$e_{i,t}$$
# * 第三步：计算特质动量：
# $$IdiosyncraticMomentum_{i,t}=\frac{\sum_{t-12}^{t-2}e_{i,t}}{\sqrt{\sum_{t-12}^{t-2}(e_{i,t}-{\overline{e}_{i}}^{2})}}$$
#
# 文章并没有交代市场收益率，估值因子收益率以及市值因子收益率的计算方式。考虑到A股仍然是短线投资者众多，本文对上面的公式进行了如下改进。使用过去一个月的月度数据：
# * 第一步：回归如下方程
# $$R_{i,t}=\alpha_{i}+\beta_{mkt,i}R_{mkt,t}+\beta_{hml,i}R_{hml,t}+\beta_{smb,i}R_{smb,t}+\epsilon_{i,t}$$
# * 第二步：计算特质收益：
# $$e_{i,t}$$
# * 第三部：计算特质动量：
# $$IdiosyncraticMomentum_{i,t}=\frac{\prod_{t}(1+e_{i,t})-1}{\sigma(e_{i, t})}$$
#
# 我们的目标是选择过去`高特质收益，低特质波动`的股票。
# 市场收益率使用了全市场流通市值加权后的收益率，因子收益率为样本空间内因子值最小的$\frac{1}{3}$股票构建的因子加权组合与最大$\frac{1}{3}$股票组合收益率之差（每月调仓，估值因子收益率为账面市值比因子最大组合与最小组合收益率之差）。

# %% [markdown]
# **2. 数据准备**
# --
# 数据长度：2007-01-01 ~ 2017-07-31，宽度：全A
# * 股票日度收益数据（前复权）
# * 流通市值
# * 总市值
# * PB

# %% [markdown]
# **2.1 获得因子数据**

# %%
start_date = '2007-01-05'
end_date = '2008-01-10'
cal_dates = DataAPI.TradeCalGet(exchangeCD=u"XSHG", beginDate=start_date, endDate=end_date).sort('calendarDate')
cal_dates = cal_dates[cal_dates['isOpen']==1]
trade_date_list = cal_dates['calendarDate'].values.tolist()#交易日
cal_dates = cal_dates[cal_dates['isMonthEnd']==1]
trade_month_list = cal_dates['calendarDate'].values.tolist()#月末的交易日
trade_month_list
# Out:
# ['2007-01-31',
#  '2007-02-28',
#  '2007-03-30',
#  '2007-04-30',
#  '2007-05-31',
#  '2007-06-29',
#  '2007-07-31',
#  '2007-08-31',
#  '2007-09-28',
#  '2007-10-31',
#  '2007-11-30',
#  '2007-12-28']

# %%
data = DataAPI.MktEqudAdjGet(secID=set_universe('HS300'), isOpen=u"1", beginDate=start_date, endDate=end_date,
                   field=u"tradeDate,secID,closePrice,negMarketValue,marketValue",pandas="1")

# %%
closePrice = data.pivot(index='tradeDate', columns='secID', values='closePrice')#收盘价
negMarketValue = data.pivot(index='tradeDate', columns='secID', values='negMarketValue')#流通市值
marketValue = data.pivot(index='tradeDate', columns='secID', values='marketValue')#总市值

# %%
PB = pd.DataFrame()
for date in trade_date_list:
    tmp = DataAPI.MktStockFactorsOneDayGet(tradeDate=date, secID=set_universe('HS300'), field=[u'secID', 'PB', 'tradeDate'], pandas="1")
    tmp = tmp.pivot(index='tradeDate', columns='secID', values='PB')
    PB = PB.append(tmp)

# %%
PB.to_csv('PB.csv', index_col=0)

# %%
PB = pd.read_csv('PB.csv', index_col=0)

# %%
BP = PB.copy(deep=True)
for date in trade_date_list:
    tmp_BP = PB.loc[date, :].dropna()
    tmp_BP = 1/(pd.Series(winsorize(tmp_BP, win_type='QuantileDraw', pvalue=0.05)))
    tmp_BP.replace([np.inf, -np.inf], 0, inplace=True)
    BP.loc[date, tmp_BP.index]=tmp_BP

# %%
SIZE = np.log(marketValue)
for date in trade_date_list:
    tmp_size = SIZE.loc[date, :].dropna()
    tmp_size = pd.Series(winsorize(tmp_size, win_type='QuantileDraw', pvalue=0.05))
    SIZE.loc[date, tmp_size.index]=tmp_size

# %%
SIZE
# Out:
# secID       000001.XSHE  000002.XSHE  000060.XSHE  000063.XSHE  000069.XSHE  \
# tradeDate
# 2007-01-05    23.958505    24.896006    23.159325    24.342168    23.908325
# 2007-01-08    23.981964    24.925205    23.189691    24.370825    23.910621
# 2007-01-09    24.013619    24.945277    23.221351    24.375812    23.866065
# 2007-01-10    24.033706    25.040587    23.263113    24.408121    23.863664
# 2007-01-11    24.082225    24.997115    23.219162    24.404018    23.877984
# 2007-01-12    24.131080    24.976825    23.170892    24.350622    23.865105
# 2007-01-15    24.180116    25.072135    23.207034    24.390382    23.928803
# 2007-01-16    24.223340    25.152916    23.249917    24.441050    24.006765
# 2007-01-17    24.223340    25.047555    23.195879    24.412686    23.901404
# 2007-01-18    24.172726    25.029453    23.227347    24.474509    23.796044
# 2007-01-19    24.219218    25.042333    23.313226    24.532093    23.751873
# 2007-01-22    24.265899    25.048712    23.371354    24.532093    23.767873
# 2007-01-23    24.284862    25.027093    23.401483    24.533156    23.741062
# 2007-01-24    24.263080    25.084481    23.390926    24.510587    23.741062
# 2007-01-25    24.245421    25.068741    23.334446    24.439884    23.756700
# 2007-01-26    24.294211    25.120091    23.406039    24.457003    23.765224
# 2007-01-29    24.342818    25.090043    23.498038    24.502949    23.839824
# 2007-01-30    24.391658    25.025319    23.469441    24.470444    23.736158
# 2007-01-31    24.340208    24.926512    23.386764    24.433330    23.661336
# 2007-02-01    24.304557    24.948477    23.406039    24.429565    23.667790
# 2007-02-02    24.253434    24.866622    23.344164    24.407639    23.621715
# 2007-02-05    24.203760    24.885853    23.295615    24.372324    23.632071
# 2007-02-06    24.252294    24.878342    23.331022    24.353170    23.613722
# 2007-02-07    24.301301    24.929772    23.351391    24.390628    23.610631
# 2007-02-08    24.338639    24.927165    23.364270    24.385467    23.588721
# 2007-02-09    24.300757    24.908719    23.363796    24.383247    23.601300
# 2007-02-12    24.349574    24.964954    23.418686    24.425076    23.654841
# 2007-02-13    24.367537    24.985483    23.427623    24.459751    23.750258
# 2007-02-14    24.411811    25.031219    23.447443    24.501414    23.745941
# 2007-02-15    24.409863    25.045818    23.493051    24.527829    23.794499
# ...                 ...          ...          ...          ...          ...
# 2007-11-28    24.991103    26.050585    24.012539    24.575804    24.901723
# 2007-11-29    25.071146    26.093061    24.073356    24.593968    24.927493
# 2007-11-30    25.044616    26.102296    24.027690    24.571723    24.927297
# 2007-12-03    25.104328    26.132885    24.035714    24.571723    24.985466
# 2007-12-04    25.109016    26.144802    24.077963    24.566803    25.022625
# 2007-12-05    25.132643    26.165248    24.144160    24.587548    25.027595
# 2007-12-06    25.128319    26.162267    24.131412    24.593968    25.019060
# 2007-12-07    25.142745    26.162864    24.154858    24.592768    24.990072
# 2007-12-10    25.125512    26.150255    24.187884    24.620416    24.986389
# 2007-12-11    25.114717    26.125789    24.168013    24.629336    24.944952
# 2007-12-12    25.069255    26.085354    24.137926    24.662001    24.875272
# 2007-12-13    25.061382    26.031717    24.076429    24.646181    24.795023
# 2007-12-14    25.077871    26.050251    24.099186    24.678493    24.817774
# 2007-12-17    25.023327    25.950256    24.056018    24.726750    24.795470
# 2007-12-18    25.034588    25.955775    24.064336    24.709081    24.813616
# 2007-12-19          NaN    25.975758    24.100436    24.759144    24.848102
# 2007-12-20    25.061654    25.996407    24.118744    24.754385    24.862406
# 2007-12-21    25.063016    25.993584    24.156275    24.738934    24.848102
# 2007-12-24    25.097779    26.006224    24.165676    24.763205    24.862824
# 2007-12-25    25.097779    25.976477    24.168712    24.763880    24.808780
# 2007-12-26    25.088538    25.973597    24.194497    24.764555    24.817337
# 2007-12-27    25.122439    26.028651    24.208713    24.835973    24.891632
# 2007-12-28    25.206557    26.012485    24.204447          NaN    24.910719
# 2008-01-02    25.190364    26.024548    24.176610    24.826666    24.918450
# 2008-01-03    25.173637    26.000275    24.191766    24.825239    24.900115
# 2008-01-04    25.200580    26.026260    24.249974    24.862926    24.945144
# 2008-01-07    25.221216    26.057901    24.266817    24.853251    24.943027
# 2008-01-08    25.251887    26.047911    24.252766    24.792819    24.923571
# 2008-01-09    25.269556    26.057901    24.291665    24.811496    24.944952
# 2008-01-10    25.289783    26.070087    24.316915    24.871600    24.997398
#
# secID       000100.XSHE  000157.XSHE  000338.XSHE  000402.XSHE  000413.XSHE  \
# tradeDate
# 2007-01-05    22.569594    23.173848          NaN    23.568251    20.800282
# 2007-01-08    22.632856    23.153083          NaN    23.558802    20.855469
# 2007-01-09    22.640490    23.172535          NaN    23.594853    20.862158
# 2007-01-10    22.724328    23.179516          NaN    23.666691    20.852107
# 2007-01-11    22.772118    23.155312          NaN    23.613602    20.914118
# 2007-01-12    22.666758    23.133699          NaN    23.580712    20.875403
# 2007-01-15    22.720825    23.201873          NaN    23.602153    20.904579
# 2007-01-16    22.772118    23.227063          NaN    23.655262    20.910948
# 2007-01-17    22.772118    23.145014          NaN    23.553726    20.881960
# 2007-01-18    22.858296    23.086160          NaN    23.547984    20.901379
# 2007-01-19    22.861350    23.125932          NaN    23.565740    20.948336
# 2007-01-22    22.897282    23.221242          NaN    23.549263    20.993186
# 2007-01-23    22.954440    23.250420          NaN    23.533809    21.010578
# 2007-01-24    22.943267    23.224157          NaN    23.562592    21.041698
# 2007-01-25    22.911880    23.130965          NaN    23.578232    20.966518
# 2007-01-26    22.923408    23.125932          NaN    23.658132    20.996106
# 2007-01-29    22.973698    23.098023          NaN    23.660993    21.044479
# 2007-01-30    22.929122    23.193333          NaN    23.583803    20.993186
# 2007-01-31    22.861350    23.088068          NaN    23.479814    21.058273
# 2007-02-01    22.920538    23.069798          NaN    23.472251    21.087965
# 2007-02-02    22.873471    23.025148          NaN    23.386556    21.050020
# 2007-02-05    22.873471    23.014436          NaN    23.366047    20.993186
# 2007-02-06    22.906066    23.078975          NaN    23.373692    21.041698
# 2007-02-07          NaN    23.107412          NaN    23.391057    21.055529
# 2007-02-08    22.954440    23.153083          NaN    23.356019    21.061009
# 2007-02-09    22.931967    23.139147          NaN    23.355244    21.052778
# 2007-02-12    22.934804    23.161971          NaN    23.450625    21.066458
# 2007-02-13    22.917661    23.201022          NaN    23.534458    21.098547
# 2007-02-14    22.926269    23.234498          NaN    23.528604    21.106410
# 2007-02-15    23.008507    23.317386          NaN    23.568878    21.121955
# ...                 ...          ...          ...          ...          ...
# 2007-11-28          NaN    24.275080    24.393137    24.033541    21.665653
# 2007-11-29          NaN    24.295370    24.425893    24.111887    21.700847
# 2007-11-30          NaN    24.288509    24.406447    24.075559    21.665653
# 2007-12-03    23.294873    24.277693    24.420486    24.114069    21.678996
# 2007-12-04    23.310559    24.300698    24.431143    24.140947    21.695067
# 2007-12-05    23.318311    24.342531    24.454870    24.152199    21.705161
# 2007-12-06    23.312503    24.357502    24.443834    24.123828    21.699405
# 2007-12-07    23.318311    24.357100    24.459970    24.138114    21.696515
# 2007-12-10    23.327917    24.371460    24.477315    24.159168    21.712309
# 2007-12-11    23.350603    24.390680    24.486057    24.142714    21.717991
# 2007-12-12    23.348732    24.391068    24.495442    24.090918    21.765026
# 2007-12-13    23.326004    24.317558    24.439790    24.041775    21.723640
# 2007-12-14    23.329828    24.341919    24.448865    24.056889    21.720819
# 2007-12-17    23.337432    24.351459    24.427304    23.980174    21.729258
# 2007-12-18          NaN    24.353276    24.440043    23.976429    21.715154
# 2007-12-19    23.348732    24.370073    24.466525    23.997465    21.727857
# 2007-12-20          NaN    24.415050    24.476705    24.056889    21.733451
# 2007-12-21    23.358052    24.419779    24.500817    24.076314    21.741785
# 2007-12-24    23.367285    24.450802          NaN    24.087194    21.765026
# 2007-12-25    23.359905    24.467670    24.513247    24.078951    21.767725
# 2007-12-26    23.385501    24.464608    24.536159    24.088685    21.816386
# 2007-12-27    23.427910    24.485496    24.538570    24.149398    21.865238
# 2007-12-28    23.438237    24.500402    24.531895    24.141654    21.885807
# 2008-01-02    23.461927    24.506475    24.511834    24.211589    21.889393
# 2008-01-03    23.485068    24.526007    24.501412    24.205972    21.897712
# 2008-01-04    23.468593    24.513372    24.529236    24.216191    21.946220
# 2008-01-07    23.451843    24.513372    24.520398    24.261398    21.932599
# 2008-01-08    23.438237    24.527194    24.596722    24.246237    21.881005
# 2008-01-09    23.461927    24.508031    24.629722    24.232134    21.916470
# 2008-01-10    23.446762    24.486732    24.632858    24.248780    21.922260
#
# secID          ...       601607.XSHG  601628.XSHG  601808.XSHG  601857.XSHG  \
# tradeDate      ...
# 2007-01-05     ...         21.944486          NaN          NaN          NaN
# 2007-01-08     ...         22.040431          NaN          NaN          NaN
# 2007-01-09     ...         22.102027    26.662590          NaN          NaN
# 2007-01-10     ...         22.112722    26.703532          NaN          NaN
# 2007-01-11     ...         22.125641    26.661785          NaN          NaN
# 2007-01-12     ...         22.099635    26.684802          NaN          NaN
# 2007-01-15     ...         22.195489    26.696071          NaN          NaN
# 2007-01-16     ...         22.265859    26.674444          NaN          NaN
# 2007-01-17     ...         22.278958    26.576844          NaN          NaN
# 2007-01-18     ...         22.368885    26.536982          NaN          NaN
# 2007-01-19     ...         22.349484    26.638024          NaN          NaN
# 2007-01-22     ...         22.367053    25.993490          NaN          NaN
# 2007-01-23     ...         22.340112    26.708176          NaN          NaN
# 2007-01-24     ...         22.347617    26.645487          NaN          NaN
# 2007-01-25     ...         22.276954    26.659636          NaN          NaN
# 2007-01-26     ...         22.247435    26.731678          NaN          NaN
# 2007-01-29     ...         22.254641    26.748298          NaN          NaN
# 2007-01-30     ...         22.296815    26.692743          NaN          NaN
# 2007-01-31     ...         22.225502    26.614892          NaN          NaN
# 2007-02-01     ...         22.207388    26.603901          NaN          NaN
# 2007-02-02     ...         22.176818    26.551832          NaN          NaN
# 2007-02-05     ...         22.218083    26.635945          NaN          NaN
# 2007-02-06     ...         22.274946    26.549492          NaN          NaN
# 2007-02-07     ...         22.305626    26.537827          NaN          NaN
# 2007-02-08     ...         22.309517    26.498121          NaN          NaN
# 2007-02-09     ...         22.303675    26.524051          NaN          NaN
# 2007-02-12     ...         22.355993    26.546647          NaN          NaN
# 2007-02-13     ...         22.373449    26.583283          NaN          NaN
# 2007-02-14     ...         22.377085    26.638173          NaN          NaN
# 2007-02-15     ...         22.472230    26.650960          NaN          NaN
# ...            ...               ...          ...          ...          ...
# 2007-11-28     ...         22.486972    28.033283    25.701989    28.092533
# 2007-11-29     ...         22.516768    28.097881    25.743207    28.144001
# 2007-11-30     ...         22.570237    28.069117    25.690475    28.121300
# 2007-12-03     ...         22.582726    28.113529    25.681357    28.129812
# 2007-12-04     ...         22.585382    28.127906    25.676925    28.142794
# 2007-12-05     ...         22.593308    28.150352    25.698580    28.160902
# 2007-12-06     ...         22.582726    28.155885    25.692039    28.156076
# 2007-12-07     ...         22.603779    28.166697    25.702298    28.166697
# 2007-12-10     ...         22.614142    28.176573    25.726440    28.183872
# 2007-12-11     ...         22.640426    28.149006    25.731259    28.160378
# 2007-12-12     ...         22.663587    28.114053    25.701989    28.141770
# 2007-12-13     ...         22.647098    28.105999    25.662545    28.106412
# 2007-12-14     ...         22.662769    28.139095    25.668322    28.139095
# 2007-12-17     ...         22.677391    28.067657    25.626166    28.095743
# 2007-12-18     ...         22.654552    28.071485    25.638770    28.094530
# 2007-12-19     ...         22.673351    28.101419    25.658353    28.115894
# 2007-12-20     ...         22.698142    28.113529    25.689535    28.120756
# 2007-12-21     ...         22.698142    28.135480    25.697959    28.135480
# 2007-12-24     ...         22.702870    28.162220    25.793297    28.167040
# 2007-12-25     ...         22.710701    28.132538    25.799771    28.137636
# 2007-12-26     ...         22.747459    28.117186    25.811487    28.134455
# 2007-12-27     ...         22.791584    28.142756    25.805367    28.154288
# 2007-12-28     ...         22.782913    28.124288    25.762614    28.146124
# 2008-01-02     ...         22.828311    28.098766          NaN    28.144932
# 2008-01-03     ...         22.832463    28.081083    25.815086    28.142286
# 2008-01-04     ...         22.810822    28.102125    25.819772    28.145108
# 2008-01-07     ...         22.811527    28.088444    25.819772    28.147970
# 2008-01-08     ...         22.763125    28.127562    25.799210    28.158623
# 2008-01-09     ...         22.778549    28.109158    25.800052    28.150296
# 2008-01-10     ...         22.769765    28.132880    25.803133    28.152028
#
# secID       601866.XSHG  601919.XSHG  601939.XSHG  601988.XSHG  601991.XSHG  \
# tradeDate
# 2007-01-05          NaN          NaN          NaN    25.913718    24.824629
# 2007-01-08          NaN          NaN          NaN    25.966142    24.828371
# 2007-01-09          NaN          NaN          NaN    26.662590    24.842279
# 2007-01-10          NaN          NaN          NaN    26.703532    24.841358
# 2007-01-11          NaN          NaN          NaN    26.661785    24.878450
# 2007-01-12          NaN          NaN          NaN    26.684802    24.824629
# 2007-01-15          NaN          NaN          NaN    26.696071    24.840436
# 2007-01-16          NaN          NaN          NaN    26.674444    24.835813
# 2007-01-17          NaN          NaN          NaN    26.576844    24.817103
# 2007-01-18          NaN          NaN          NaN    26.536982    24.820873
# 2007-01-19          NaN          NaN          NaN    26.638024    24.834886
# 2007-01-22          NaN          NaN          NaN    25.993490    24.869529
# 2007-01-23          NaN          NaN          NaN    26.708176    24.855088
# 2007-01-24          NaN          NaN          NaN    26.645487    24.902145
# 2007-01-25          NaN          NaN          NaN    26.659636    24.875782
# 2007-01-26          NaN          NaN          NaN    26.731678    24.874891
# 2007-01-29          NaN          NaN          NaN    26.748298    24.884647
# 2007-01-30          NaN          NaN          NaN    26.692743    24.863237
# 2007-01-31          NaN          NaN          NaN    26.614892    24.837665
# 2007-02-01          NaN          NaN          NaN    26.603901    24.830237
# 2007-02-02          NaN          NaN          NaN    26.551832    24.792245
# 2007-02-05          NaN          NaN          NaN    26.635945    24.782518
# 2007-02-06          NaN          NaN          NaN    26.549492    24.799960
# 2007-02-07          NaN          NaN          NaN    26.537827    24.802838
# 2007-02-08          NaN          NaN          NaN    26.498121    24.821813
# 2007-02-09          NaN          NaN          NaN    26.524051    24.855997
# 2007-02-12          NaN          NaN          NaN    26.546647    24.871319
# 2007-02-13          NaN          NaN          NaN    26.583283    24.863237
# 2007-02-14          NaN          NaN          NaN    26.638173    24.868632
# 2007-02-15          NaN          NaN          NaN    26.650960    24.877561
# ...                 ...          ...          ...          ...          ...
# 2007-11-28          NaN    26.649871    28.092533    28.092533    25.849207
# 2007-11-29          NaN          NaN    28.144001    28.144001    25.887359
# 2007-11-30          NaN    26.636217    28.121300    28.121300    25.860944
# 2007-12-03          NaN    26.602864    28.129812    28.129812    25.858195
# 2007-12-04          NaN    26.606100    28.142794    28.142794    25.858883
# 2007-12-05          NaN    26.627982    28.160902    28.160902    25.926040
# 2007-12-06          NaN    26.634043    28.156076    28.156076    25.952065
# 2007-12-07          NaN    26.675706    28.166697    28.160581    25.954568
# 2007-12-10          NaN    26.711237    28.183872    28.160581    25.980479
# 2007-12-11          NaN    26.707875    28.160378    28.156086    25.978651
# 2007-12-12    25.629827    26.663576    28.141770    28.141770    25.958311
# 2007-12-13    25.570174    26.602365    28.106412    28.106412    25.920882
# 2007-12-14    25.534690    26.590569    28.139095    28.128687    25.944098
# 2007-12-17    25.469897    26.524835    28.095743    28.095743    25.920371
# 2007-12-18    25.496913    26.557198    28.094530    28.094530    25.939015
# 2007-12-19    25.494936    26.686836    28.115894    28.115894    25.969130
# 2007-12-20    25.550720    26.733996    28.120756    28.120756    25.972832
# 2007-12-21    25.582030    26.740691    28.135480    28.130229    25.989321
# 2007-12-24    25.583842    26.786116    28.167040    28.145520    26.004946
# 2007-12-25    25.569256    26.765407    28.137636    28.137636    26.036639
# 2007-12-26    25.664650    26.758407    28.134455    28.134455    26.118679
# 2007-12-27    25.668815    26.819549    28.154288    28.154288    26.211616
# 2007-12-28    25.678740    26.800510    28.146124    28.146124          NaN
# 2008-01-02    25.678740    26.862980    28.144932    28.144932          NaN
# 2008-01-03    25.657950    26.874149    28.142286    28.142286          NaN
# 2008-01-04    25.671306    26.923229    28.145108    28.145108          NaN
# 2008-01-07    25.696686    26.906714    28.147970    28.147970          NaN
# 2008-01-08    25.655426    26.914483    28.158623    28.158623          NaN
# 2008-01-09    25.657950    26.899096    28.150296    28.150296          NaN
# 2008-01-10    25.641855    26.928605    28.152028    28.152028    26.284052
#
# secID       601998.XSHG
# tradeDate
# 2007-01-05          NaN
# 2007-01-08          NaN
# 2007-01-09          NaN
# 2007-01-10          NaN
# 2007-01-11          NaN
# 2007-01-12          NaN
# 2007-01-15          NaN
# 2007-01-16          NaN
# 2007-01-17          NaN
# 2007-01-18          NaN
# 2007-01-19          NaN
# 2007-01-22          NaN
# 2007-01-23          NaN
# 2007-01-24          NaN
# 2007-01-25          NaN
# 2007-01-26          NaN
# 2007-01-29          NaN
# 2007-01-30          NaN
# 2007-01-31          NaN
# 2007-02-01          NaN
# 2007-02-02          NaN
# 2007-02-05          NaN
# 2007-02-06          NaN
# 2007-02-07          NaN
# 2007-02-08          NaN
# 2007-02-09          NaN
# 2007-02-12          NaN
# 2007-02-13          NaN
# 2007-02-14          NaN
# 2007-02-15          NaN
# ...                 ...
# 2007-11-28    26.674138
# 2007-11-29    26.708107
# 2007-11-30    26.691267
# 2007-12-03    26.701207
# 2007-12-04    26.705156
# 2007-12-05    26.718855
# 2007-12-06    26.714960
# 2007-12-07    26.716909
# 2007-12-10    26.719826
# 2007-12-11    26.721766
# 2007-12-12    26.703183
# 2007-12-13    26.689267
# 2007-12-14    26.695255
# 2007-12-17    26.660838
# 2007-12-18    26.663923
# 2007-12-19    26.692265
# 2007-12-20    26.699227
# 2007-12-21    26.700218
# 2007-12-24    26.709089
# 2007-12-25    26.697243
# 2007-12-26    26.700218
# 2007-12-27    26.713984
# 2007-12-28    26.705156
# 2008-01-02    26.719826
# 2008-01-03    26.719826
# 2008-01-04    26.723702
# 2008-01-07    26.728526
# 2008-01-08    26.731409
# 2008-01-09    26.728526
# 2008-01-10    26.723702
#
# [248 rows x 180 columns]

# %%
negMarketValue = negMarketValue.fillna(method='ffill')
negMarketValue_ = negMarketValue.fillna(method='bfill')

# %% [markdown]
# **2.2 计算因子收益**

# %%
def cal_factor_return(factor):
    factor_return = pd.Series(index=trade_date_list[1:])
    for i in range(len(factor.index)-1):
        date = factor.index[i]
        q = factor.ix[i].dropna()
        q_min = q.quantile(0.33)
        q_max = q.quantile(0.66)
        q_min_univ = q[q<=q_min].index.values
        q_max_univ = q[q>=q_max].index.values

        date_1 = factor.index[i+1]
        q_min_weight = negMarketValue_.loc[date, q_min_univ]/sum(negMarketValue_.loc[date, q_min_univ])
        q_max_weight = negMarketValue_.loc[date, q_max_univ]/sum(negMarketValue_.loc[date, q_max_univ])
        
        factor_return.loc[date_1] = (q_min_weight * sec_return.loc[date_1, q_min_univ]).sum() - (q_max_weight * sec_return.loc[date_1, q_max_univ]).sum()
    return factor_return

# %%
sec_return = closePrice.pct_change()
negMarketValue_weight = negMarketValue.apply(lambda x: x/sum(x.dropna()), axis=1)
mkt_return = (sec_return * negMarketValue_weight).sum(axis=1)
mkt_return = mkt_return.dropna()
mkt_return.index = negMarketValue.index[1:]

# %%
smb_return = cal_factor_return(SIZE)
hml_return = cal_factor_return(-BP)

# %% [markdown]
# **2.3 计算特质收益**
# 每支股票基于前12-2个月进行回归，获得残差后，进行调整得到特质动量

# %%
trade_month_list.insert(0, '2006-12-31')

# %%
imom_factor = pd.DataFrame(index=trade_month_list[1:], columns=sec_return.columns)
ivol_factor = pd.DataFrame(index=trade_month_list[1:], columns=sec_return.columns)
for i in range(len(trade_month_list)-1):
    start = trade_month_list[i]
    end = trade_month_list[i+1]
    smb_current = smb_return[(smb_return.index > start) & (smb_return.index <= end)]
    hml_current = hml_return[(hml_return.index > start) & (hml_return.index <= end)]
    mkt_current = mkt_return[(mkt_return.index > start) & (mkt_return.index <= end)]
    
    current_universe = list(sec_return.ix[end, :].dropna().index)
    for sec in current_universe:
        try:
            returns = sec_return.loc[sec_return.index[(sec_return.index > start) & (sec_return.index <= end)], sec]
            returns = returns.dropna()
            x1 = np.array(smb_current.loc[returns.index])
            x2 = np.array(hml_current.loc[returns.index])
            x3 = np.array(mkt_current.loc[returns.index])
            x = np.array(np.vstack([x1, x2, x3]).T)
            y = np.array(returns)
            linreg = LinearRegression()
            model=linreg.fit(x, y)
            y_pre = model.predict(x)
            residual = y-y_pre
            i_mom = (np.cumprod(residual+1)[-1]-1)/np.std(residual)
            imom_factor.ix[i, sec] = i_mom
            ivol_factor.ix[i, sec] = np.std(residual)
        except:
            pass

# %%
imom_factor.to_csv('imom.csv')
ivol_factor.to_csv('ivol.csv')

# %% [markdown]
# 中性化，中性掉行业和市值

# %%
factor = copy.deepcopy(imom_factor)
factor.index = pd.to_datetime(factor.index)
factor = pretreat_factor(factor, neu=True)
factor.index = factor.index.strftime("%Y-%m-%d")
factor.to_csv('imom_pure.csv')
# Out:
# 2007-01-31 00:00:00
# Neutralize input not-None value is not enough
# 2007-02-28 00:00:00
# Neutralize input not-None value is not enough
# 2007-03-30 00:00:00
# Neutralize input not-None value is not enough
# 2007-04-30 00:00:00
# Neutralize input not-None value is not enough
# 2007-05-31 00:00:00
# Neutralize input not-None value is not enough
# 2007-06-29 00:00:00
# Neutralize input not-None value is not enough
# 2007-07-31 00:00:00
# Neutralize input not-None value is not enough

# %%
factor = pd.read_csv('imom_pure.csv', index_col=0)

# %%
fig = plt.figure(figsize=(12, 5))
ax1 = fig.add_subplot(111)
n,bins,patches=ax1.hist(factor.mean(axis=0).dropna(), 20, normed=1, facecolor='#000066', alpha=0.9)  
# sns.kdeplot(cgo_mid, ax=ax1, color='b')
ax1.grid()
s = ax1.set_title(u"横截面CGO中位数分布", fontproperties=font, fontsize=16)

# %% [markdown]
# **3. 单因子分析**
# --

# %%
forward_20d_return_data = closePrice.shift(-20)/closePrice-1
forward_20d_return_data = forward_20d_return_data.ix[trade_month_list, :]
forward_20d_return_data.index = pd.to_datetime((forward_20d_return_data.index))
backward_20d_return_data = closePrice /closePrice.shift(20) - 1.0
backward_20d_return_data = backward_20d_return_data.ix[trade_month_list, :]
backward_20d_return_data.index = pd.to_datetime((backward_20d_return_data.index))

# %% [markdown]
# **3.1 分组超额收益**

# %%
n_quantile = 10
# 统计十分位数
cols_mean = [i+1 for i in range(n_quantile)]
cols = cols_mean

excess_returns_means = pd.DataFrame(index=factor.index, columns=cols)

# 计算因子分组的超额收益平均值
for dt in excess_returns_means.index:
    qt_mean_results = []
    
    # ILLIQ去掉nan
    tmp_factor = factor.ix[dt].dropna()
    tmp_return = forward_20d_return_data.ix[dt].dropna()
    tmp_return = tmp_return[tmp_return<0.6]
    tmp_return_mean = tmp_return.mean()
    
    pct_quantiles = 1.0/n_quantile
    for i in range(n_quantile):
        down = tmp_factor.quantile(pct_quantiles*i)
        up = tmp_factor.quantile(pct_quantiles*(i+1))
        i_quantile_index = tmp_factor[(tmp_factor<=up) & (tmp_factor>=down)].index
        mean_tmp = tmp_return[i_quantile_index].mean() - tmp_return_mean
        qt_mean_results.append(mean_tmp)
        
    excess_returns_means.ix[dt] = qt_mean_results

excess_returns_means.dropna(inplace=True)

# 因子分组的超额收益作图
fig = plt.figure(figsize=(12, 6))
ax1 = fig.add_subplot(111)

excess_returns_means_dist = excess_returns_means.mean()
excess_dist_plus = excess_returns_means_dist[excess_returns_means_dist>0]
excess_dist_minus = excess_returns_means_dist[excess_returns_means_dist<0]
lns2 = ax1.bar(excess_dist_plus.index, excess_dist_plus.values, align='center', color='r', width=0.35)
lns3 = ax1.bar(excess_dist_minus.index, excess_dist_minus.values, align='center', color='g', width=0.35)

ax1.set_xlim(left=0.5, right=len(excess_returns_means_dist)+0.5)
# ax1.set_ylim(-0.008, 0.008)
ax1.set_ylabel(u'超额收益', fontproperties=font, fontsize=16)
ax1.set_xlabel(u'十分位分组', fontproperties=font, fontsize=16)
ax1.set_xticks(excess_returns_means_dist.index)
ax1.set_xticklabels([int(x) for x in ax1.get_xticks()], fontproperties=font, fontsize=14)
ax1.set_yticklabels([str(x*100)+'0%' for x in ax1.get_yticks()], fontproperties=font, fontsize=14)
ax1.set_title(u"因子超额收益", fontproperties=font, fontsize=16)
ax1.grid()

# %% [markdown]
# **3.2 分组市值暴露**

# %%
factor = pd.read_csv('imom.csv', index_col=0)

# %%
n_quantile = 10
# 统计十分位数
cols_mean = [i+1 for i in range(n_quantile)]
cols = cols_mean

mkt_value_means = pd.DataFrame(index=factor.index, columns=cols)

# 计算因子分组的市值分布特征
for dt in mkt_value_means.index:
    qt_mean_results = []
    
    # ILLIQ去掉nan
    tmp_factor = factor.ix[dt].dropna()
    tmp_mkt_value = marketValue.ix[dt].dropna()
    tmp_mkt_value = tmp_mkt_value.rank()/len(tmp_mkt_value)
    
    pct_quantiles = 1.0/n_quantile
    for i in range(n_quantile):
        down = tmp_factor.quantile(pct_quantiles*i)
        up = tmp_factor.quantile(pct_quantiles*(i+1))
        i_quantile_index = tmp_factor[(tmp_factor<=up) & (tmp_factor>=down)].index
        mean_tmp = tmp_mkt_value[i_quantile_index].mean()
        qt_mean_results.append(mean_tmp)
        
    mkt_value_means.ix[dt] = qt_mean_results

mkt_value_means.dropna(inplace=True)

# 因子的市值分布特征作图
fig = plt.figure(figsize=(12, 6))
ax1 = fig.add_subplot(111)
ax2 = ax1.twinx()

mkt_value_means_dist = mkt_value_means.mean()
lns1 = ax1.bar(mkt_value_means_dist.index, mkt_value_means_dist.values, align='center', width=0.35)
lns2 = ax2.plot(excess_returns_means_dist.index, excess_returns_means_dist.values, 'o-r')

ax1.legend(lns1, ['market value(left axis)'], loc=2, fontsize=12)
ax2.legend(lns2, ['excess return(right axis)'], fontsize=12)
ax1.set_xlim(left=0.5, right=len(mkt_value_means_dist)+0.5)
ax1.set_ylabel(u'市值百分位数', fontproperties=font, fontsize=16)
ax2.set_ylabel(u'超额收益', fontproperties=font, fontsize=16)
ax1.set_xlabel(u'十分位分组', fontproperties=font, fontsize=16)
ax1.set_xticks(mkt_value_means_dist.index)
ax1.set_xticklabels([int(x) for x in ax1.get_xticks()], fontproperties=font, fontsize=14)
ax1.set_yticklabels([str(x*100)+'%' for x in ax1.get_yticks()], fontproperties=font, fontsize=14)
ax2.set_yticklabels([str(x*100)+'0%' for x in ax2.get_yticks()], fontproperties=font, fontsize=14)
ax1.set_title(u"因子市值分布特征", fontproperties=font, fontsize=16)
ax1.grid()

# %% [markdown]
# **3.3 因子与反转因子的关系**

# %%
ic_data = pd.DataFrame(index=forward_20d_return_data.index, columns=['IC','pValue'])
ic_data
# Out:
#              IC pValue
# tradeDate
# 2006-12-31  NaN    NaN
# 2007-01-31  NaN    NaN
# 2007-02-28  NaN    NaN
# 2007-03-30  NaN    NaN
# 2007-04-30  NaN    NaN
# 2007-05-31  NaN    NaN
# 2007-06-29  NaN    NaN
# 2007-07-31  NaN    NaN
# 2007-08-31  NaN    NaN
# 2007-09-28  NaN    NaN
# 2007-10-31  NaN    NaN
# 2007-11-30  NaN    NaN
# 2007-12-28  NaN    NaN

# %%
# 计算了每一个月的**因子**和**之后20日收益**的秩相关系数
factor.index = pd.to_datetime(factor.index)
ic_data = pd.DataFrame(index=forward_20d_return_data.index, columns=['IC','pValue'])

# 计算相关系数
for dt in ic_data.index.tolist()[1:]:
    tmp_factor = factor.ix[dt]
    tmp_ret = forward_20d_return_data.ix[dt]
    cor = pd.DataFrame(tmp_factor)
    ret = pd.DataFrame(tmp_ret)
    cor.columns = ['corr']
    ret.columns = ['ret']
    cor['ret'] = ret['ret']
    cor = cor[~np.isnan(cor['corr'])][~np.isnan(cor['ret'])]
    if len(cor) < 5:
        continue

    ic, p_value = st.spearmanr(cor['corr'],cor['ret'])   # 计算秩相关系数 RankIC
    ic_data['IC'][dt] = ic
    ic_data['pValue'][dt] = p_value
    
print 'mean of IC: ', ic_data['IC'].mean(), '；',
print 'median of IC: ', ic_data['IC'].median()
print 'the number of IC(all, plus, minus): ', (len(ic_data), len(ic_data[ic_data.IC>0]), len(ic_data[ic_data.IC<0]))


# 每一天的**因子**和**之前20日收益**的秩相关系数作图

fig = plt.figure(figsize=(16, 6))
ax1 = fig.add_subplot(111)

lns1 = ax1.plot(ic_data[ic_data>0].index, ic_data[ic_data>0].IC, '.r', label='IC(plus)')
lns2 = ax1.plot(ic_data[ic_data<0].index, ic_data[ic_data<0].IC, '.b', label='IC(minus)')

lns = lns1+lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, bbox_to_anchor=[0.6, 0.1], loc='best', ncol=2, mode="", borderaxespad=0., fontsize=12)
ax1.set_ylabel(u'相关系数', fontproperties=font, fontsize=16)
ax1.set_xlabel(u'日期', fontproperties=font, fontsize=16)
ax1.set_title(u"特质动量因子与之后一个月收益月度IC", fontproperties=font, fontsize=16)
ax1.grid()
# Out:
# -c:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# mean of IC:
#  0.130755207456 ； median of IC:  0.134614793139
# the number of IC(all, plus, minus):  (13, 3, 1)
# -c:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
# 计算了每一个月的**因子**和**之前20日收益**的秩相关系数
factor.index = pd.to_datetime(factor.index)
marketValue.index = pd.to_datetime(marketValue.index)
ic_data = pd.DataFrame(index=backward_20d_return_data.index, columns=['IC','pValue'])

# 计算相关系数
for dt in ic_data.index.tolist()[1:]:
    tmp_factor = factor.ix[dt]
    tmp_ret = backward_20d_return_data.ix[dt]
    cor = pd.DataFrame(tmp_factor)
    ret = pd.DataFrame(tmp_ret)
    cor.columns = ['corr']
    ret.columns = ['ret']
    cor['ret'] = ret['ret']
    # print cor
    cor = cor[~np.isnan(cor['corr'])][~np.isnan(cor['ret'])]
    if len(cor) < 5:
        continue

    ic, p_value = st.spearmanr(cor['corr'],cor['ret'])   # 计算秩相关系数 RankIC
    ic_data['IC'][dt] = ic
    ic_data['pValue'][dt] = p_value
    
print 'mean of IC: ', ic_data['IC'].mean(), '；',
print 'median of IC: ', ic_data['IC'].median()
print 'the number of IC(all, plus, minus): ', (len(ic_data), len(ic_data[ic_data.IC>0]), len(ic_data[ic_data.IC<0]))


# 每一天的**因子**和**之前20日收益**的秩相关系数作图

fig = plt.figure(figsize=(16, 6))
ax1 = fig.add_subplot(111)

lns1 = ax1.plot(ic_data[ic_data>0].index, ic_data[ic_data>0].IC, '.r', label='IC(plus)')
lns2 = ax1.plot(ic_data[ic_data<0].index, ic_data[ic_data<0].IC, '.b', label='IC(minus)')

lns = lns1+lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, bbox_to_anchor=[0.6, 0.1], loc='best', ncol=2, mode="", borderaxespad=0., fontsize=12)
ax1.set_ylabel(u'相关系数', fontproperties=font, fontsize=16)
ax1.set_xlabel(u'日期', fontproperties=font, fontsize=16)
ax1.set_title(u"特质动量因子与过去一个月收益月度IC", fontproperties=font, fontsize=16)
ax1.grid()
# Out:
#              corr  ret
# 000001.XSHE   NaN  NaN
# 000002.XSHE   NaN  NaN
# 000060.XSHE   NaN  NaN
# 000063.XSHE   NaN  NaN
# 000069.XSHE   NaN  NaN
# 000100.XSHE   NaN  NaN
# 000157.XSHE   NaN  NaN
# 000338.XSHE   NaN  NaN
# 000402.XSHE   NaN  NaN
# 000413.XSHE   NaN  NaN
# 000415.XSHE   NaN  NaN
# 000423.XSHE   NaN  NaN
# 000425.XSHE   NaN  NaN
# 000503.XSHE   NaN  NaN
# 000538.XSHE   NaN  NaN
# 000540.XSHE   NaN  NaN
# 000559.XSHE   NaN  NaN
# 000568.XSHE   NaN  NaN
# 000623.XSHE   NaN  NaN
# 000625.XSHE   NaN  NaN
# 000627.XSHE   NaN  NaN
# 000630.XSHE   NaN  NaN
# 000651.XSHE   NaN  NaN
# 000671.XSHE   NaN  NaN
# 000709.XSHE   NaN  NaN
# 000723.XSHE   NaN  NaN
# 000725.XSHE   NaN  NaN
# 000728.XSHE   NaN  NaN
# 000768.XSHE   NaN  NaN
# 000783.XSHE   NaN  NaN
# ...           ...  ...
# 600837.XSHG   NaN  NaN
# 600867.XSHG   NaN  NaN
# 600886.XSHG   NaN  NaN
# 600887.XSHG   NaN  NaN
# 600893.XSHG   NaN  NaN
# 600900.XSHG   NaN  NaN
# 601006.XSHG   NaN  NaN
# 601009.XSHG   NaN  NaN
# 601088.XSHG   NaN  NaN
# 601099.XSHG   NaN  NaN
# 601111.XSHG   NaN  NaN
# 601166.XSHG   NaN  NaN
# 601169.XSHG   NaN  NaN
# 601318.XSHG   NaN  NaN
# 601328.XSHG   NaN  NaN
# 601333.XSHG   NaN  NaN
# 601390.XSHG   NaN  NaN
# 601398.XSHG   NaN  NaN
# 601600.XSHG   NaN  NaN
# 601601.XSHG   NaN  NaN
# 601607.XSHG   NaN  NaN
# 601628.XSHG   NaN  NaN
# 601808.XSHG   NaN  NaN
# 601857.XSHG   NaN  NaN
# 601866.XSHG   NaN  NaN
# 601919.XSHG   NaN  NaN
# 601939.XSHG   NaN  NaN
# 601988.XSHG   NaN  NaN
# 601991.XSHG   NaN  NaN
# 601998.XSHG   NaN  NaN
#
# [180 rows x 2 columns]
#              corr       ret
# 000001.XSHE   NaN  0.075591
# 000002.XSHE   NaN -0.177864
# 000060.XSHE   NaN  0.166588
# 000063.XSHE   NaN  0.012603
# 000069.XSHE   NaN -0.057546
# 000100.XSHE   NaN  0.168297
# 000157.XSHE   NaN  0.064497
# 000338.XSHE   NaN       NaN
# 000402.XSHE   NaN -0.121116
# 000413.XSHE   NaN  0.147569
# 000415.XSHE   NaN  0.620714
# 000423.XSHE   NaN       NaN
# 000425.XSHE   NaN  0.159516
# 000503.XSHE   NaN  0.062124
# 000538.XSHE   NaN -0.193249
# 000540.XSHE   NaN       NaN
# 000559.XSHE   NaN  0.056128
# 000568.XSHE   NaN -0.063914
# 000623.XSHE   NaN  0.029586
# 000625.XSHE   NaN  0.127174
# 000627.XSHE   NaN  0.231400
# 000630.XSHE   NaN  0.286951
# 000651.XSHE   NaN -0.080208
# 000671.XSHE   NaN  0.056452
# 000709.XSHE   NaN -0.021776
# 000723.XSHE   NaN       NaN
# 000725.XSHE   NaN  0.337509
# 000728.XSHE   NaN       NaN
# 000768.XSHE   NaN  0.127649
# 000783.XSHE   NaN       NaN
# ...           ...       ...
# 600837.XSHG   NaN  0.886446
# 600867.XSHG   NaN  0.175341
# 600886.XSHG   NaN  0.103777
# 600887.XSHG   NaN -0.098651
# 600893.XSHG   NaN       NaN
# 600900.XSHG   NaN  0.111474
# 601006.XSHG   NaN  0.030322
# 601009.XSHG   NaN       NaN
# 601088.XSHG   NaN       NaN
# 601099.XSHG   NaN       NaN
# 601111.XSHG   NaN -0.075064
# 601166.XSHG   NaN       NaN
# 601169.XSHG   NaN       NaN
# 601318.XSHG   NaN       NaN
# 601328.XSHG   NaN       NaN
# 601333.XSHG   NaN -0.065418
# 601390.XSHG   NaN       NaN
# 601398.XSHG   NaN -0.113846
# 601600.XSHG   NaN       NaN
# 601601.XSHG   NaN       NaN
# 601607.XSHG   NaN  0.091460
# 601628.XSHG   NaN -0.182918
# 601808.XSHG   NaN       NaN
# 601857.XSHG   NaN       NaN
# 601866.XSHG   NaN       NaN
# 601919.XSHG   NaN       NaN
# 601939.XSHG   NaN       NaN
# 601988.XSHG   NaN -0.049556
# 601991.XSHG   NaN  0.002592
# 601998.XSHG   NaN       NaN
#
# [180 rows x 2 columns]
# -c:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#              corr       ret
# 000001.XSHE   NaN  0.037987
# 000002.XSHE   NaN  0.152753
# 000060.XSHE   NaN  0.141540
# 000063.XSHE   NaN       NaN
# 000069.XSHE   NaN  0.105992
# 000100.XSHE   NaN  0.171577
# 000157.XSHE   NaN  0.061590
# 000338.XSHE   NaN       NaN
# 000402.XSHE   NaN  0.079734
# 000413.XSHE   NaN  0.174146
# 000415.XSHE   NaN  0.263577
# 000423.XSHE   NaN       NaN
# 000425.XSHE   NaN  0.097650
# 000503.XSHE   NaN  0.206691
# 000538.XSHE   NaN  0.021180
# 000540.XSHE   NaN       NaN
# 000559.XSHE   NaN  0.474003
# 000568.XSHE   NaN  0.062550
# 000623.XSHE   NaN  0.165708
# 000625.XSHE   NaN -0.040666
# 000627.XSHE   NaN  0.166441
# 000630.XSHE   NaN  0.107162
# 000651.XSHE   NaN  0.070260
# 000671.XSHE   NaN  0.245614
# 000709.XSHE   NaN  0.149234
# 000723.XSHE   NaN       NaN
# 000725.XSHE   NaN  0.274680
# 000728.XSHE   NaN       NaN
# 000768.XSHE   NaN -0.107496
# 000783.XSHE   NaN       NaN
# ...           ...       ...
# 600837.XSHG   NaN  0.111774
# 600867.XSHG   NaN  0.028359
# 600886.XSHG   NaN  0.011356
# 600887.XSHG   NaN -0.001641
# 600893.XSHG   NaN       NaN
# 600900.XSHG   NaN  0.126173
# 601006.XSHG   NaN  0.144268
# 601009.XSHG   NaN       NaN
# 601088.XSHG   NaN       NaN
# 601099.XSHG   NaN       NaN
# 601111.XSHG   NaN  0.166197
# 601166.XSHG   NaN  0.139933
# 601169.XSHG   NaN       NaN
# 601318.XSHG   NaN  0.013796
# 601328.XSHG   NaN       NaN
# 601333.XSHG   NaN  0.116171
# 601390.XSHG   NaN       NaN
# 601398.XSHG   NaN  0.143921
# 601600.XSHG   NaN       NaN
# 601601.XSHG   NaN       NaN
# 601607.XSHG   NaN  0.030959
# 601628.XSHG   NaN  0.042298
# 601808.XSHG   NaN       NaN
# 601857.XSHG   NaN       NaN
# 601866.XSHG   NaN       NaN
# 601919.XSHG   NaN       NaN
# 601939.XSHG   NaN       NaN
# 601988.XSHG   NaN  0.178493
# 601991.XSHG   NaN       NaN
# 601998.XSHG   NaN       NaN
#
# [180 rows x 2 columns]
#              corr       ret
# 000001.XSHE   NaN       NaN
# 000002.XSHE   NaN  0.059138
# 000060.XSHE   NaN       NaN
# 000063.XSHE   NaN  0.054135
# 000069.XSHE   NaN  0.380690
# 000100.XSHE   NaN       NaN
# 000157.XSHE   NaN  0.485859
# 000338.XSHE   NaN       NaN
# 000402.XSHE   NaN  0.196395
# 000413.XSHE   NaN       NaN
# 000415.XSHE   NaN  0.265734
# 000423.XSHE   NaN       NaN
# 000425.XSHE   NaN       NaN
# 000503.XSHE   NaN  0.184342
# 000538.XSHE   NaN  0.225021
# 000540.XSHE   NaN       NaN
# 000559.XSHE   NaN  0.430921
# 000568.XSHE   NaN       NaN
# 000623.XSHE   NaN  0.854545
# 000625.XSHE   NaN  0.052530
# 000627.XSHE   NaN  0.469403
# 000630.XSHE   NaN  0.399424
# 000651.XSHE   NaN  0.459156
# 000671.XSHE   NaN  0.012158
# 000709.XSHE   NaN  0.360881
# 000723.XSHE   NaN       NaN
# 000725.XSHE   NaN  0.186061
# 000728.XSHE   NaN       NaN
# 000768.XSHE   NaN  0.415567
# 000783.XSHE   NaN       NaN
# ...           ...       ...
# 600837.XSHG   NaN  0.814720
# 600867.XSHG   NaN  0.188549
# 600886.XSHG   NaN  0.357888
# 600887.XSHG   NaN  0.104362
# 600893.XSHG   NaN       NaN
# 600900.XSHG   NaN  0.117897
# 601006.XSHG   NaN  0.116986
# 601009.XSHG   NaN       NaN
# 601088.XSHG   NaN       NaN
# 601099.XSHG   NaN       NaN
# 601111.XSHG   NaN  0.202786
# 601166.XSHG   NaN       NaN
# 601169.XSHG   NaN       NaN
# 601318.XSHG   NaN  0.360855
# 601328.XSHG   NaN       NaN
# 601333.XSHG   NaN  0.085759
# 601390.XSHG   NaN       NaN
# 601398.XSHG   NaN -0.030441
# 601600.XSHG   NaN       NaN
# 601601.XSHG   NaN       NaN
# 601607.XSHG   NaN  0.344218
# 601628.XSHG   NaN  0.171563
# 601808.XSHG   NaN       NaN
# 601857.XSHG   NaN       NaN
# 601866.XSHG   NaN       NaN
# 601919.XSHG   NaN       NaN
# 601939.XSHG   NaN       NaN
# 601988.XSHG   NaN -0.005183
# 601991.XSHG   NaN  0.375092
# 601998.XSHG   NaN       NaN
#
# [180 rows x 2 columns]
#              corr       ret
# 000001.XSHE   NaN  0.105508
# 000002.XSHE   NaN  0.579295
# 000060.XSHE   NaN  0.107591
# 000063.XSHE   NaN  0.146393
# 000069.XSHE   NaN  0.466433
# 000100.XSHE   NaN  0.334658
# 000157.XSHE   NaN  0.409912
# 000338.XSHE   NaN       NaN
# 000402.XSHE   NaN  0.702148
# 000413.XSHE   NaN       NaN
# 000415.XSHE   NaN  0.009201
# 000423.XSHE   NaN       NaN
# 000425.XSHE   NaN  0.060360
# 000503.XSHE   NaN  0.021241
# 000538.XSHE   NaN  0.087929
# 000540.XSHE   NaN       NaN
# 000559.XSHE   NaN -0.080982
# 000568.XSHE   NaN       NaN
# 000623.XSHE   NaN  0.427734
# 000625.XSHE   NaN  0.005551
# 000627.XSHE   NaN  0.298478
# 000630.XSHE   NaN  0.260474
# 000651.XSHE   NaN       NaN
# 000671.XSHE   NaN  0.073550
# 000709.XSHE   NaN  0.099129
# 000723.XSHE   NaN       NaN
# 000725.XSHE   NaN       NaN
# 000728.XSHE   NaN       NaN
# 000768.XSHE   NaN       NaN
# 000783.XSHE   NaN       NaN
# ...           ...       ...
# 600837.XSHG   NaN -0.036453
# 600867.XSHG   NaN  0.158636
# 600886.XSHG   NaN -0.072448
# 600887.XSHG   NaN  0.188562
# 600893.XSHG   NaN       NaN
# 600900.XSHG   NaN -0.036145
# 601006.XSHG   NaN -0.007919
# 601009.XSHG   NaN       NaN
# 601088.XSHG   NaN       NaN
# 601099.XSHG   NaN       NaN
# 601111.XSHG   NaN  0.089851
# 601166.XSHG   NaN -0.074283
# 601169.XSHG   NaN       NaN
# 601318.XSHG   NaN  0.041542
# 601328.XSHG   NaN       NaN
# 601333.XSHG   NaN -0.053524
# 601390.XSHG   NaN       NaN
# 601398.XSHG   NaN -0.008923
# 601600.XSHG   NaN       NaN
# 601601.XSHG   NaN       NaN
# 601607.XSHG   NaN       NaN
# 601628.XSHG   NaN -0.056125
# 601808.XSHG   NaN       NaN
# 601857.XSHG   NaN       NaN
# 601866.XSHG   NaN       NaN
# 601919.XSHG   NaN       NaN
# 601939.XSHG   NaN       NaN
# 601988.XSHG   NaN -0.001501
# 601991.XSHG   NaN  0.228075
# 601998.XSHG   NaN       NaN
#
# [180 rows x 2 columns]
#              corr       ret
# 000001.XSHE   NaN       NaN
# 000002.XSHE   NaN  0.050572
# 000060.XSHE   NaN -0.086432
# 000063.XSHE   NaN  0.077241
# 000069.XSHE   NaN  0.019956
# 000100.XSHE   NaN -0.271240
# 000157.XSHE   NaN  0.133041
# 000338.XSHE   NaN       NaN
# 000402.XSHE   NaN  0.006915
# 000413.XSHE   NaN       NaN
# 000415.XSHE   NaN -0.023386
# 000423.XSHE   NaN -0.073768
# 000425.XSHE   NaN -0.152466
# 000503.XSHE   NaN -0.185010
# 000538.XSHE   NaN -0.013248
# 000540.XSHE   NaN  0.048583
# 000559.XSHE   NaN -0.130061
# 000568.XSHE   NaN       NaN
# 000623.XSHE   NaN -0.154070
# 000625.XSHE   NaN  0.023753
# 000627.XSHE   NaN -0.314298
# 000630.XSHE   NaN  0.013425
# 000651.XSHE   NaN       NaN
# 000671.XSHE   NaN -0.211988
# 000709.XSHE   NaN  0.080950
# 000723.XSHE   NaN       NaN
# 000725.XSHE   NaN -0.361222
# 000728.XSHE   NaN       NaN
# 000768.XSHE   NaN       NaN
# 000783.XSHE   NaN       NaN
# ...           ...       ...
# 600837.XSHG   NaN       NaN
# 600867.XSHG   NaN -0.280696
# 600886.XSHG   NaN -0.006978
# 600887.XSHG   NaN -0.097573
# 600893.XSHG   NaN       NaN
# 600900.XSHG   NaN  0.089754
# 601006.XSHG   NaN  0.008805
# 601009.XSHG   NaN       NaN
# 601088.XSHG   NaN       NaN
# 601099.XSHG   NaN       NaN
# 601111.XSHG   NaN -0.084897
# 601166.XSHG   NaN  0.173289
# 601169.XSHG   NaN       NaN
# 601318.XSHG   NaN  0.184566
# 601328.XSHG   NaN -0.155310
# 601333.XSHG   NaN -0.129075
# 601390.XSHG   NaN       NaN
# 601398.XSHG   NaN -0.073645
# 601600.XSHG   NaN       NaN
# 601601.XSHG   NaN       NaN
# 601607.XSHG   NaN  0.066344
# 601628.XSHG   NaN  0.108666
# 601808.XSHG   NaN       NaN
# 601857.XSHG   NaN       NaN
# 601866.XSHG   NaN       NaN
# 601919.XSHG   NaN       NaN
# 601939.XSHG   NaN       NaN
# 601988.XSHG   NaN -0.106957
# 601991.XSHG   NaN       NaN
# 601998.XSHG   NaN -0.122996
#
# [180 rows x 2 columns]
#              corr       ret
# 000001.XSHE   NaN  0.330499
# 000002.XSHE   NaN  0.457998
# 000060.XSHE   NaN  0.243082
# 000063.XSHE   NaN  0.087825
# 000069.XSHE   NaN  0.249346
# 000100.XSHE   NaN  0.077578
# 000157.XSHE   NaN  0.033525
# 000338.XSHE   NaN  0.040138
# 000402.XSHE   NaN  0.152768
# 000413.XSHE   NaN  0.227659
# 000415.XSHE   NaN  0.091091
# 000423.XSHE   NaN  0.093663
# 000425.XSHE   NaN  0.294388
# 000503.XSHE   NaN  0.218562
# 000538.XSHE   NaN -0.016491
# 000540.XSHE   NaN  0.190601
# 000559.XSHE   NaN  0.218427
# 000568.XSHE   NaN  0.195193
# 000623.XSHE   NaN  0.299271
# 000625.XSHE   NaN  0.128701
# 000627.XSHE   NaN  0.295860
# 000630.XSHE   NaN  0.132022
# 000651.XSHE   NaN  0.045158
# 000671.XSHE   NaN  0.317857
# 000709.XSHE   NaN  0.232846
# 000723.XSHE   NaN       NaN
# 000725.XSHE   NaN  0.235778
# 000728.XSHE   NaN       NaN
# 000768.XSHE   NaN       NaN
# 000783.XSHE   NaN       NaN
# ...           ...       ...
# 600837.XSHG   NaN  0.308253
# 600867.XSHG   NaN  0.154796
# 600886.XSHG   NaN  0.073746
# 600887.XSHG   NaN  0.008623
# 600893.XSHG   NaN       NaN
# 600900.XSHG   NaN  0.146209
# 601006.XSHG   NaN  0.031439
# 601009.XSHG   NaN       NaN
# 601088.XSHG   NaN       NaN
# 601099.XSHG   NaN       NaN
# 601111.XSHG   NaN  0.289518
# 601166.XSHG   NaN  0.195363
# 601169.XSHG   NaN       NaN
# 601318.XSHG   NaN  0.161661
# 601328.XSHG   NaN  0.107329
# 601333.XSHG   NaN  0.077124
# 601390.XSHG   NaN       NaN
# 601398.XSHG   NaN  0.103977
# 601600.XSHG   NaN  0.083933
# 601601.XSHG   NaN       NaN
# 601607.XSHG   NaN -0.098271
# 601628.XSHG   NaN  0.147547
# 601808.XSHG   NaN       NaN
# 601857.XSHG   NaN       NaN
# 601866.XSHG   NaN       NaN
# 601919.XSHG   NaN       NaN
# 601939.XSHG   NaN       NaN
# 601988.XSHG   NaN  0.065013
# 601991.XSHG   NaN  0.422292
# 601998.XSHG   NaN  0.126746
#
# [180 rows x 2 columns]
#                  corr       ret
# 000001.XSHE -0.172315 -0.028399
# 000002.XSHE -0.219985  0.000000
# 000060.XSHE -0.263227  0.111840
# 000063.XSHE -0.192932  0.044035
# 000069.XSHE -0.391985  0.029720
# 000100.XSHE -0.199525  0.072127
# 000157.XSHE -0.247659  0.086015
# 000338.XSHE -0.299942  0.291414
# 000402.XSHE -0.253947 -0.075527
# 000413.XSHE -0.373344  0.185511
# 000415.XSHE -0.320054  0.352941
# 000423.XSHE -0.281679 -0.056696
# 000425.XSHE -0.342775  0.011042
# 000503.XSHE -0.214431  0.045020
# 000538.XSHE -0.192053  0.056963
# 000540.XSHE -0.297484  0.143478
# 000559.XSHE -0.442494  0.415261
# 000568.XSHE -0.325915  0.008205
# 000623.XSHE -0.353556  0.229185
# 000625.XSHE -0.312292  0.162317
# 000627.XSHE -0.329769  0.163478
# 000630.XSHE -0.345984  0.197807
# 000651.XSHE -0.257940  0.056845
# 000671.XSHE -0.334904  0.194293
# 000709.XSHE -0.233074  0.176128
# 000723.XSHE       NaN       NaN
# 000725.XSHE -0.082379  0.344141
# 000728.XSHE       NaN       NaN
# 000768.XSHE -0.324017  0.157766
# 000783.XSHE       NaN       NaN
# ...               ...       ...
# 600837.XSHG -0.198960 -0.004063
# 600867.XSHG -0.233977  0.106649
# 600886.XSHG -0.182231  0.174199
# 600887.XSHG -0.192082  0.029195
# 600893.XSHG       NaN       NaN
# 600900.XSHG -0.182006  0.095902
# 601006.XSHG -0.226667  0.175124
# 601009.XSHG -0.208213 -0.131303
# 601088.XSHG       NaN       NaN
# 601099.XSHG       NaN       NaN
# 601111.XSHG -0.395360  0.451225
# 601166.XSHG -0.257709  0.240432
# 601169.XSHG       NaN       NaN
# 601318.XSHG -0.221499  0.149905
# 601328.XSHG -0.158435  0.063920
# 601333.XSHG -0.162724  0.127141
# 601390.XSHG       NaN       NaN
# 601398.XSHG -0.248734  0.175306
# 601600.XSHG -0.564705  0.880456
# 601601.XSHG       NaN       NaN
# 601607.XSHG -0.255490  0.149500
# 601628.XSHG -0.297767  0.104729
# 601808.XSHG       NaN       NaN
# 601857.XSHG       NaN       NaN
# 601866.XSHG       NaN       NaN
# 601919.XSHG       NaN       NaN
# 601939.XSHG       NaN       NaN
# 601988.XSHG -0.230613  0.106103
# 601991.XSHG -0.336003  0.134087
# 601998.XSHG -0.276118  0.132866
#
# [180 rows x 2 columns]
#                  corr       ret
# 000001.XSHE -0.165621  0.052055
# 000002.XSHE -0.175760 -0.106525
# 000060.XSHE -0.357425  0.316849
# 000063.XSHE -0.208138 -0.042545
# 000069.XSHE -0.262217 -0.016714
# 000100.XSHE -0.164548  0.108073
# 000157.XSHE -0.204145 -0.073079
# 000338.XSHE -0.190248 -0.110918
# 000402.XSHE -0.165961 -0.151616
# 000413.XSHE -0.270806 -0.078064
# 000415.XSHE -0.295510  0.016398
# 000423.XSHE -0.280709  0.083411
# 000425.XSHE -0.444424  0.394612
# 000503.XSHE -0.323467  0.085992
# 000538.XSHE -0.129883 -0.103611
# 000540.XSHE -0.186181 -0.119772
# 000559.XSHE -0.207388 -0.136299
# 000568.XSHE -0.257915  0.061346
# 000623.XSHE -0.252639 -0.013761
# 000625.XSHE -0.353816  0.286687
# 000627.XSHE -0.283652 -0.082039
# 000630.XSHE -0.296238  0.124714
# 000651.XSHE -0.203708  0.110535
# 000671.XSHE -0.309133  0.179750
# 000709.XSHE -0.330213  0.254508
# 000723.XSHE -1.421527       NaN
# 000725.XSHE -0.276123  0.401230
# 000728.XSHE       NaN       NaN
# 000768.XSHE -0.336227  0.247287
# 000783.XSHE       NaN       NaN
# ...               ...       ...
# 600837.XSHG -0.282015  0.004791
# 600867.XSHG -0.126850 -0.069840
# 600886.XSHG -0.195100  0.156577
# 600887.XSHG -0.196306  0.000493
# 600893.XSHG       NaN       NaN
# 600900.XSHG -0.159962 -0.000563
# 601006.XSHG -0.330487  0.390281
# 601009.XSHG -0.160298 -0.065786
# 601088.XSHG       NaN       NaN
# 601099.XSHG       NaN       NaN
# 601111.XSHG -0.433262  0.228698
# 601166.XSHG -0.133209 -0.032069
# 601169.XSHG -0.149682       NaN
# 601318.XSHG -0.236937  0.324338
# 601328.XSHG -0.205992 -0.015220
# 601333.XSHG -0.286762  0.087563
# 601390.XSHG       NaN       NaN
# 601398.XSHG -0.111517 -0.033697
# 601600.XSHG -0.274290 -0.082612
# 601601.XSHG       NaN       NaN
# 601607.XSHG -0.204839 -0.010370
# 601628.XSHG -0.180302  0.108138
# 601808.XSHG       NaN       NaN
# 601857.XSHG       NaN       NaN
# 601866.XSHG       NaN       NaN
# 601919.XSHG -0.502731       NaN
# 601939.XSHG  0.000000       NaN
# 601988.XSHG -0.088685 -0.018110
# 601991.XSHG -0.217309 -0.122010
# 601998.XSHG -0.096740 -0.087525
#
# [180 rows x 2 columns]
# -c:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                  corr       ret
# 000001.XSHE -0.243110  0.263756
# 000002.XSHE -0.259309  0.303787
# 000060.XSHE -0.277128  0.090774
# 000063.XSHE -0.239045  0.079409
# 000069.XSHE       NaN       NaN
# 000100.XSHE -0.161047 -0.121284
# 000157.XSHE -0.253503  0.294245
# 000338.XSHE -0.228708  0.116217
# 000402.XSHE       NaN       NaN
# 000413.XSHE -0.174968 -0.148163
# 000415.XSHE       NaN       NaN
# 000423.XSHE -0.189271 -0.153348
# 000425.XSHE -0.329425  0.031742
# 000503.XSHE -0.140668 -0.248144
# 000538.XSHE -0.172513 -0.067863
# 000540.XSHE -0.165974  0.007821
# 000559.XSHE -0.151078 -0.153611
# 000568.XSHE -0.253779  0.195335
# 000623.XSHE -0.334893  0.215603
# 000625.XSHE -0.213852 -0.190262
# 000627.XSHE -0.269653  0.052453
# 000630.XSHE -0.222121  0.145277
# 000651.XSHE -0.203352 -0.020652
# 000671.XSHE -0.312509 -0.134134
# 000709.XSHE -0.190252 -0.138418
# 000723.XSHE -0.356155  0.128536
# 000725.XSHE -0.257381       NaN
# 000728.XSHE  2.000000       NaN
# 000768.XSHE -0.291708  0.014790
# 000783.XSHE       NaN       NaN
# ...               ...       ...
# 600837.XSHG -0.364346  0.306219
# 600867.XSHG -0.209600 -0.105981
# 600886.XSHG -0.166744 -0.115467
# 600887.XSHG -0.139667 -0.097670
# 600893.XSHG       NaN       NaN
# 600900.XSHG -0.169135  0.126899
# 601006.XSHG -0.278977 -0.046944
# 601009.XSHG -0.204538  0.019113
# 601088.XSHG -0.272324       NaN
# 601099.XSHG       NaN       NaN
# 601111.XSHG -0.363766 -0.016947
# 601166.XSHG -0.160569  0.248571
# 601169.XSHG -0.170788  0.084299
# 601318.XSHG -0.168900  0.110355
# 601328.XSHG -0.200779  0.337291
# 601333.XSHG -0.220063 -0.023608
# 601390.XSHG       NaN       NaN
# 601398.XSHG -0.189125  0.372272
# 601600.XSHG -0.224914  0.066823
# 601601.XSHG       NaN       NaN
# 601607.XSHG -0.135276 -0.174073
# 601628.XSHG -0.179689  0.283835
# 601808.XSHG -0.318193       NaN
# 601857.XSHG       NaN       NaN
# 601866.XSHG       NaN       NaN
# 601919.XSHG -0.416714  0.422804
# 601939.XSHG -0.152735  0.281701
# 601988.XSHG -0.197760  0.239395
# 601991.XSHG -0.303973 -0.143449
# 601998.XSHG -0.180326  0.086962
#
# [180 rows x 2 columns]
#                  corr       ret
# 000001.XSHE -0.148287 -0.206816
# 000002.XSHE -0.159554 -0.192033
# 000060.XSHE -0.210976 -0.307575
# 000063.XSHE -0.197837 -0.022932
# 000069.XSHE -0.396996       NaN
# 000100.XSHE       NaN       NaN
# 000157.XSHE -0.254664 -0.106261
# 000338.XSHE -0.325131 -0.220665
# 000402.XSHE -0.309165 -0.265790
# 000413.XSHE -0.284096 -0.044000
# 000415.XSHE -0.200777 -0.006572
# 000423.XSHE       NaN       NaN
# 000425.XSHE -0.279357 -0.180449
# 000503.XSHE -0.216137 -0.056219
# 000538.XSHE -0.240483  0.011202
# 000540.XSHE -0.215511 -0.234428
# 000559.XSHE -0.306620  0.026380
# 000568.XSHE -0.245785 -0.014145
# 000623.XSHE -0.216438 -0.293886
# 000625.XSHE -0.281441  0.158449
# 000627.XSHE -0.350653 -0.156486
# 000630.XSHE -0.260864 -0.219961
# 000651.XSHE -0.157323  0.033249
# 000671.XSHE       NaN       NaN
# 000709.XSHE -0.341415 -0.079196
# 000723.XSHE       NaN       NaN
# 000725.XSHE -0.292718 -0.167764
# 000728.XSHE -0.262179 -0.226077
# 000768.XSHE -0.319968  0.074501
# 000783.XSHE       NaN       NaN
# ...               ...       ...
# 600837.XSHG -0.203921 -0.190534
# 600867.XSHG -0.112636 -0.000522
# 600886.XSHG -0.147723 -0.024852
# 600887.XSHG -0.215654 -0.096499
# 600893.XSHG       NaN       NaN
# 600900.XSHG -0.141148 -0.191376
# 601006.XSHG -0.299463 -0.019756
# 601009.XSHG -0.130329 -0.065708
# 601088.XSHG -0.256465 -0.165146
# 601099.XSHG       NaN       NaN
# 601111.XSHG -0.276460  0.192639
# 601166.XSHG -0.170490 -0.110416
# 601169.XSHG -0.180894 -0.130064
# 601318.XSHG -0.165258 -0.174354
# 601328.XSHG -0.199298 -0.085730
# 601333.XSHG -0.131712 -0.061584
# 601390.XSHG       NaN       NaN
# 601398.XSHG -0.113154 -0.076411
# 601600.XSHG -0.353108 -0.205871
# 601601.XSHG       NaN       NaN
# 601607.XSHG -0.259347  0.083576
# 601628.XSHG -0.152226 -0.223363
# 601808.XSHG -0.321775 -0.295938
# 601857.XSHG -0.230499       NaN
# 601866.XSHG       NaN       NaN
# 601919.XSHG -0.328967 -0.188806
# 601939.XSHG -0.101067 -0.091677
# 601988.XSHG -0.141979 -0.137766
# 601991.XSHG -0.308465 -0.117493
# 601998.XSHG -0.147901 -0.150312
#
# [180 rows x 2 columns]
#                  corr       ret
# 000001.XSHE -0.125918  0.069836
# 000002.XSHE -0.110103 -0.085935
# 000060.XSHE -0.157048  0.193375
# 000063.XSHE       NaN       NaN
# 000069.XSHE -0.271666 -0.016502
# 000100.XSHE -0.127492       NaN
# 000157.XSHE -0.155436  0.236189
# 000338.XSHE -0.104101  0.133781
# 000402.XSHE -0.152599  0.068333
# 000413.XSHE -0.171685  0.245932
# 000415.XSHE -0.274866  0.284819
# 000423.XSHE -0.203064       NaN
# 000425.XSHE -0.109604  0.106705
# 000503.XSHE -0.134202  0.175182
# 000538.XSHE -0.131555  0.169277
# 000540.XSHE -0.280511  0.147929
# 000559.XSHE -0.209402  0.315580
# 000568.XSHE -0.198655  0.185097
# 000623.XSHE -0.217025  0.122143
# 000625.XSHE -0.139404  0.083157
# 000627.XSHE -0.183793  0.206957
# 000630.XSHE -0.115682  0.083314
# 000651.XSHE -0.215277  0.256948
# 000671.XSHE       NaN       NaN
# 000709.XSHE -0.230202  0.460832
# 000723.XSHE       NaN       NaN
# 000725.XSHE -0.159647  0.220890
# 000728.XSHE -0.110231  0.135684
# 000768.XSHE -0.155352  0.113122
# 000783.XSHE -2.000000       NaN
# ...               ...       ...
# 600837.XSHG -0.144057  0.056970
# 600867.XSHG -0.175249  0.268688
# 600886.XSHG -0.164839  0.113066
# 600887.XSHG -0.103309  0.143276
# 600893.XSHG       NaN       NaN
# 600900.XSHG -0.136745  0.161541
# 601006.XSHG -0.161045  0.197761
# 601009.XSHG -0.108729  0.076099
# 601088.XSHG -0.099745  0.019584
# 601099.XSHG       NaN       NaN
# 601111.XSHG -0.226077  0.169119
# 601166.XSHG -0.088824 -0.082120
# 601169.XSHG -0.116819  0.076130
# 601318.XSHG -0.136929 -0.024183
# 601328.XSHG -0.080850  0.076467
# 601333.XSHG -0.080897  0.119127
# 601390.XSHG -0.284069       NaN
# 601398.XSHG -0.066717  0.017607
# 601600.XSHG -0.175106  0.064879
# 601601.XSHG  0.000000       NaN
# 601607.XSHG -0.121673  0.237068
# 601628.XSHG -0.144289  0.056712
# 601808.XSHG -0.208401  0.074821
# 601857.XSHG -0.145611 -0.017769
# 601866.XSHG -0.210455       NaN
# 601919.XSHG -0.201159  0.028952
# 601939.XSHG -0.049815 -0.034363
# 601988.XSHG -0.034499  0.024907
# 601991.XSHG       NaN       NaN
# 601998.XSHG -0.058437  0.013977
#
# [180 rows x 2 columns]
# mean of IC:  -0.353808680844 ； median of IC:  -0.39743545512
# the number of IC(all, plus, minus):  (13, 0, 5)
# -c:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# -c:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
ivol = pd.read_csv('ivol.csv', index_col=0)
ivol.index = pd.to_datetime(ivol.index)

# %%
# 计算了每一个月的**因子**和**之前20日收益**的秩相关系数
factor.index = pd.to_datetime(factor.index)
ic_data = pd.DataFrame(index=ivol.index, columns=['IC','pValue'])

# 计算相关系数
for dt in ic_data.index:
    tmp_factor = factor.ix[dt]
    tmp_ret = ivol.ix[dt]
    cor = pd.DataFrame(tmp_factor)
    ret = pd.DataFrame(tmp_ret)
    cor.columns = ['corr']
    ret.columns = ['ret']
    cor['ret'] = ret['ret']
    cor = cor[~np.isnan(cor['corr'])][~np.isnan(cor['ret'])]
    if len(cor) < 5:
        continue

    ic, p_value = st.spearmanr(cor['corr'],cor['ret'])   # 计算秩相关系数 RankIC
    ic_data['IC'][dt] = ic
    ic_data['pValue'][dt] = p_value
    
print 'mean of IC: ', ic_data['IC'].mean(), '；',
print 'median of IC: ', ic_data['IC'].median()
print 'the number of IC(all, plus, minus): ', (len(ic_data), len(ic_data[ic_data.IC>0]), len(ic_data[ic_data.IC<0]))


# 每一天的**因子**和**之前20日收益**的秩相关系数作图

fig = plt.figure(figsize=(16, 6))
ax1 = fig.add_subplot(111)

lns1 = ax1.plot(ic_data[ic_data>0].index, ic_data[ic_data>0].IC, '.r', label='IC(plus)')
lns2 = ax1.plot(ic_data[ic_data<0].index, ic_data[ic_data<0].IC, '.b', label='IC(minus)')

lns = lns1+lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, bbox_to_anchor=[0.6, 0.1], loc='', ncol=2, mode="", borderaxespad=0., fontsize=12)
ax1.set_ylabel(u'相关系数', fontproperties=font, fontsize=16)
ax1.set_xlabel(u'日期', fontproperties=font, fontsize=16)
ax1.set_title(u"特质动量因子与月度IC", fontproperties=font, fontsize=16)
ax1.grid()

# %%
factor = pd.read_csv('imom_pure.csv', index_col=0)

# %%
factor.index = factor.index.strftime("%Y-%m-%d")

# %% [raw]
# start = '2007-01-31'                       # 回测起始时间
# end = '2017-07-30'                         # 回测结束时间
#
# benchmark = 'ZZ500'                        # 策略参考标准
# universe = DynamicUniverse('A')        # 证券池，支持股票和基金
# capital_base = 10000000                    # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔
#
# factor_dates = factor.index.values
#
# commission = Commission(0.001, 0.001)     # 交易费率设为双边千分之二
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     pre_date = account.previous_date.strftime("%Y-%m-%d")
#     if pre_date not in factor_dates:            # 因子只在每个月底计算，所以调仓也在每月最后一个交易日进行
#         return
#
#     # 拿取调仓日前一个交易日的因子，并按照相应十分位选择股票
#     q = factor.ix[pre_date, account.universe].dropna()
#     q_min = q.quantile(0.8)
#     q_max = q.quantile(1)
#     my_univ = q[q>=q_min][q<q_max].index.values
#
#     # 调仓逻辑
#     univ = [x for x in my_univ if x in account.universe]
#
#     if len(univ) < 10:
#         return
#
#     # 不在目标股票池中的，卖出
#     for s in account.valid_secpos:
#         if s not in univ:
#             order_to(s, 0)
#
#     # 在目标股票池中的，等权买入
#     buylist = {}
#     v = account.reference_portfolio_value  * 1.05 / len(univ)
#     for s in univ:
#         buylist[s] = v / account.reference_price[s] - account.security_position.get(s, 0)
#
#     for s in sorted(buylist, key=buylist.get):
#         order(s, buylist[s])

# %%
bt1 = bt
bt_quantile_ten = bt1
data = bt_quantile_ten[[u'tradeDate',u'portfolio_value',u'benchmark_return']]
data['portfolio_return'] = data.portfolio_value/data.portfolio_value.shift(1) - 1.0
data['portfolio_return'].ix[0] = data['portfolio_value'].ix[0]/	10000000.0 - 1.0
data['excess_return'] = data.portfolio_return - data.benchmark_return
data['excess'] = data.excess_return + 1.0
data['excess'] = data.excess.cumprod()

df_cum_rets = data['excess']
running_max = np.maximum.accumulate(df_cum_rets)
underwater = -((running_max - df_cum_rets) / running_max)
underwater.index = data['tradeDate']
data = data.merge(pd.DataFrame(underwater), how='inner', left_on='tradeDate', right_index=True)
data.rename(columns={'excess_x':'Alpha', 'excess_y':'Maximum Drawdown'}, inplace=True)
data.to_csv('signal_ana/backtest.csv')
