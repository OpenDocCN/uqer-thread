# %% [markdown]
# # 海龟交易法则V2.1 把突破价是收盘价改为最高价和最低价

# %% [markdown]
# 海龟交易法则
# 系统I：中线策略是盘中股价突破20日最高价就买，跌破10日最低价就卖；
# 系统II：长线策略是盘中股价突破55日最高价就买，跌破20日最低价就卖。
# 另外有一个屏蔽器，当55日线在300日线下方的时候，意味这长线趋势不对，所以就算发出买入信号也不买。
# 止损条件：买入价格跌破2N就快速止损，这个N跟TR有关。TR是真实波动幅度的缩写，公式是=max(H-L，H-PDC，PDC-L)：
# H=今日最高价，L=今日最低价，PDC=昨日收盘价
# 3者取其大，N值就是过去20天的TR加起来除以20（均值）。
# 但是日线回测有比较严重的问题在于，这个海龟交易系统讲求盘中突破或者跌破，等到收盘突破并第二天开盘才动作的话，已经晚很多了，会造成偏差。
# V2.0来实现系统I的突破附加处理：
# 1.上一次是盈利性突破，信号将被忽略（不管交易者当时是采取了突破交易，还是根据这一法则忽略了那次突破），直到如果能突破55日（保障性突破点）最高价入市，以避免错过重大趋势。
# 2.如果上一次是亏损性突破（发生了2N幅度的不利变动），目前的新突破视为有效
# V2.1把突破价是收盘价改为最高价和最低价，更符合原版的思想
#
# 海龟交易法则还有很有技术含量的地方在于分散投资与关联品种控制，仓位控制、止损，这些都没有实现（另外最好要分时级别回测了，才能更精细控制）。
# 取数部分写得比较复杂是因为要避免整个回测从300天后才开始。

# %% [raw]
# import datetime
# import numpy as np
#
# #start = '2006-01-01'
# #start = '2011-12-09'
# start = '2012-05-28'
# end = (datetime.date.today() - datetime.timedelta(days=1)).strftime("%Y-%m-%d")  # 回测结束时间
# #secID = '510050.XSHG'
# #secID = '159915.XSHE'
# secID = '159919.XSHE'
# benchmark = secID                  # 策略参考标准
# universe = [secID]                 # 证券池，支持股票和基金
# capital_base = 1000000                     # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# enter_window = 20 + 1
# exit_window = 10 + 1
# enter_last_window = 55 + 1
# #enter_window = 55 + 1
# #exit_window = 20 + 1
# period_mid = 55
# period_long = 300
#
# def initialize(account):                   # 初始化虚拟账户状态
#     account.cp_slist = []
#     account.cp_mlist = []
#     account.cp_llist = []
#     account.high_list = []
#     account.low_list = []
#     account.tr_list = []
#     account.pb_flag = False                #是否开启屏蔽器
#     account.loss_flag = True               #是否亏损性突破
#     account.stop_loss = 1000
#     account.N = 1000
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     highest_price = account.get_attribute_history('highPrice', 1)
#     lowest_price  = account.get_attribute_history('lowPrice', 1)
#     close_price  = account.get_attribute_history('closePrice', 1)
#     for s in account.universe:
#         cp = close_price[s][-1]              #account.referencePrice[stock]
#         hp = highest_price[s][-1]
#         lp = lowest_price[s][-1]
#         account.cp_slist.append(cp)
#         account.cp_mlist.append(cp)
#         account.cp_llist.append(cp)
#         account.high_list.append(hp)
#         account.low_list.append(lp)
#         if len(account.cp_slist) >= 2:
#             tr = np.array([hp-lp, hp-account.cp_slist[-2], account.cp_slist[-2]-lp]).max()
#             account.tr_list.append(tr)
#             if len(account.tr_list) >= enter_window:
#                 account.tr_list = account.tr_list[-enter_window:]
#
#         if len(account.high_list) < enter_last_window:
#             break
#         else:
#             account.high_list = account.high_list[-enter_last_window:]
#
#         if len(account.low_list) >= exit_window:
#             account.low_list = account.low_list[-exit_window:]
#         if len(account.cp_slist) >= enter_window:
#             account.cp_slist = account.cp_slist[-enter_window:]
#         if len(account.cp_mlist) >= period_mid:
#             account.cp_mlist = account.cp_mlist[-period_mid:]
#         if len(account.cp_llist) >= period_long:
#             account.cp_llist = account.cp_llist[-period_long:]
#             account.pb_flag = True
#
#         if hp > np.array(account.high_list[-enter_window:-1]).max() and account.loss_flag == True and s not in account.valid_secpos:
#             account.N = np.array(account.tr_list[:-1]).mean()
#             account.stop_loss = cp - 2 * account.N
#             if account.pb_flag == False:
#                 order(s, account.cash/cp)
#             elif account.pb_flag == True and np.array(account.cp_mlist).mean() >= np.array(account.cp_llist).mean():
#                 order(s, account.cash/cp)
#         elif hp > np.array(account.high_list[:-1]).max() and account.loss_flag == False and s not in account.valid_secpos:
#             account.N = np.array(account.tr_list[:-1]).mean()
#             account.stop_loss = cp - 2 * account.N
#             if account.pb_flag == False:
#                 order(s, account.cash/cp)
#             elif account.pb_flag == True and np.array(account.cp_mlist).mean() >= np.array(account.cp_llist).mean():
#                 order(s, account.cash/cp)
#         elif lp < account.stop_loss and s in account.valid_secpos:
#             account.loss_flag == True
#             print account.current_date
#             order_to(s, 0)
#         elif lp < np.array(account.low_list[:-1]).min() and s in account.valid_secpos:
#             account.loss_flag == False
#             order_to(s, 0)
