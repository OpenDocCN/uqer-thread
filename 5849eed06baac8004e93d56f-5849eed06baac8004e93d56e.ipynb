# %% [markdown]
# # 2016-12 第一个策略

# %% [markdown]
# 第一个策略

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <mercury-input-8-948F17A3073E4C0E91662EABC33286DF> in <module>()
#       1 universe = ['000001.XSHE', '600000.XSHG']  # 证券池，支持股票和基金
#       2 hist = account.get_attribute_history('closePrice',20)
# ----> 3 print (hist['000001.XSHE'][-1])
#
# TypeError: 'NoneType' object has no attribute '__getitem__'

# %% [raw]
# start = '2014-01-01'                       # 回测起始时间
# end = '2015-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['000001.XSHE', '600000.XSHG']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# print(account.previous_date)
# def GetVolRat(stock,date):
#
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     return

# %%
DataAPI.MktEqudAdjGet(secID=u"",ticker=u"",isOpen="",beginDate=u"",endDate=u"",field=u"",pandas="1")
# Out:
#             secID  ticker secShortName exchangeCD    secShortNameEn  \
# 0     000001.XSHE  000001         平安银行       XSHE               NaN
# 1     000002.XSHE  000002          万科A       XSHE             Vanke
# 2     000004.XSHE  000004         国农科技       XSHE    Cau Technology
# 3     000005.XSHE  000005         世纪星源       XSHE     Fountain Hold
# 4     000006.XSHE  000006         深振业A       XSHE         Sz Zhenye
# 5     000007.XSHE  000007          全新好       XSHE               NaN
# 6     000008.XSHE  000008         神州高铁       XSHE               NaN
# 7     000009.XSHE  000009         中国宝安       XSHE  S Sz Baoan Enter
# 8     000010.XSHE  000010         美丽生态       XSHE               NaN
# 9     000011.XSHE  000011         深物业A       XSHE   S Sz Properties
# 10    000012.XSHE  000012          南玻A       XSHE       CSG Holding
# 11    000014.XSHE  000014         沙河股份       XSHE         Shahe Ind
# 12    000016.XSHE  000016         深康佳A       XSHE             Konka
# ...

# %% [markdown]
# 本策略是买入前一日换手最高的10只股
# 将使用到的API
# DataAPI.MktEqudAdjGet(tradeDate=u"20150513",secID=u"",ticker=u"",isOpen="",beginDate=u"",endDate=u"",field=u"",pandas="1")

# %% [raw]
# start = '2014-01-01'                       # 回测起始时间
# end = '2015-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['000001.XSHE', '600000.XSHG']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     hist = account.get_attribute_history('closePrice',10)
#     for s in account.universe:
#         if hist[s][-1] / hist[s][0]-1 > 0.05 and s not in account.security_position:
#             order(s,100000)
#         elif hist[s][-1] / hist[s][0]-1 < -0.05 and s in account.security_position:
#             order_to(s,0)
#     return

# %% [raw]
# start = '2014-01-01'                       # 回测起始时间
# end = '2015-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['000001.XSHE', '600000.XSHG']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):   # 每个交易日的买入卖出指令
#     for stock in account.universe:
#         if account.security_position.get(stock,0) > 1000:
#             order_to(stock,0)
#         else:
#             order(stock,100)
#     return
