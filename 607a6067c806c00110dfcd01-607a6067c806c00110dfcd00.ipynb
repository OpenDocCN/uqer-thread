# %% [markdown]
# # 获取全部Stock_A

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt
import CAL.PyCAL as C_cal # CAL provides classes and functions dealing with date, time, and calendars. 

sns.set_style('white')

matplotlib.rc('axes', labelsize=14)
matplotlib.rc('xtick', labelsize=12)
matplotlib.rc('ytick', labelsize=12)

pd.set_option('display.width', 200)

cal = C_cal.Calendar('China.SSE')

# %%
pd_stock_A=DataAPI.EquGet(secID=u"",ticker=u"",equTypeCD=u"A",listStatusCD=u"",exchangeCD="",ListSectorCD=u"",field=u"",pandas="1")
pd_stock_A
# Out:
#               secID    ticker exchangeCD  ListSectorCD ListSector transCurrCD secShortName          secFullName listStatusCD    listDate      ...      equType exCountryCD  partyID   totalShares  \
# 0       000001.XSHE    000001       XSHE             1         主板         CNY         平安银行           平安银行股份有限公司            L  1991-04-03      ...         沪深A股         CHN        2  1.940592e+10
# 1       000002.XSHE    000002       XSHE             1         主板         CNY          万科A           万科企业股份有限公司            L  1991-01-29      ...         沪深A股         CHN        3  1.161773e+10
# 2       000003.XSHE    000003       XSHE             1         主板         CNY        PT金田A       金田实业(集团)股份有限公司           DE  1991-07-03      ...         沪深A股         CHN        4  3.334336e+08
# 3       000004.XSHE    000004       XSHE             1         主板         CNY         国华网安       深圳国华网安科技股份有限公司            L  1991-01-14      ...         沪深A股         CHN        5  1.650526e+08
# ...

# %%
"""
secID 	          str 	证券ID
ticker 	          str 	交易代码
exchangeCD 	      str 	交易市场。例如，XSHG-上海证券交易所；XSHE-深圳证券交易所。对应DataAPI.SysCodeGet.codeTypeID=10002。
ListSectorCD 	  int 	上市板块编码。例如，1-主板；2-创业板；3-中小板；4-科创板。
ListSector 	      str 	上市板块。
transCurrCD 	  str 	交易货币。例如，CNY-人民币元；USD-美元。对应DataAPI.SysCodeGet.codeTypeID=10004。
secShortName 	  str 	证券简称
secFullName 	  str 	证券全称
listStatusCD 	  str 	上市状态。L-上市；S-暂停；DE-终止上市；UN-未上市。对应DataAPI.SysCodeGet.codeTypeID=10005。
listDate 	      str 	上市日期
delistDate 	      str 	摘牌日期
equTypeCD 	      str 	股票分类编码。例如，A-A股；B-B股。
equType 	      str 	股票类别
exCountryCD 	  str 	交易市场所属地区。例如，CHN-中国大陆；HKG-香港。对应DataAPI.SysCodeGet.codeTypeID=10002。
partyID 	      int 	机构内部ID
totalShares 	    float 	总股本(最新)
nonrestFloatShares 	float 	公司无限售流通股份合计(最新)
nonrestfloatA 	    float 	无限售流通股本(最新)。如果为A股，该列为最新无限售流通A股股本数量；如果为B股，该列为最新流通B股股本数量
officeAddr 	        str 	办公地址
primeOperating    	str 	主营业务范围
endDate 	        str 	财务报告日期
TShEquity 	        float 	所有者权益合计
"""
pd_stock_A.rename(columns={'secID':'证券ID','ticker':'交易代码','exchangeCD':'交易市场','ListSectorCD':'上市板块编码','ListSector':'上市板块','transCurrCD':'交易货币','secShortName':'证券简称','secFullName':'证券全称','listStatusCD':'上市状态','listDate':'上市日期','delistDate':'摘牌日期','equTypeCD':'股票分类编码','equType':'股票类别','exCountryCD':'交易市场所属地区','partyID':'机构内部ID','totalShares':'总股本(最新)','nonrestFloatShares':'公司无限售流通股份合计(最新)','nonrestfloatA':'无限售流通股本(最新)','officeAddr':'办公地址','primeOperating':'主营业务范围','endDate':'财务报告日期','TShEquity':'所有者权益合计',},inplace=True) 
pd_stock_A
# Out:
#                证券ID      交易代码  交易市场  上市板块编码 上市板块 交易货币    证券简称                 证券全称 上市状态        上市日期      ...       股票类别 交易市场所属地区   机构内部ID       总股本(最新)  公司无限售流通股份合计(最新)   无限售流通股本(最新)  \
# 0       000001.XSHE    000001  XSHE       1   主板  CNY    平安银行           平安银行股份有限公司    L  1991-04-03      ...       沪深A股      CHN        2  1.940592e+10     1.940575e+10  1.940575e+10
# 1       000002.XSHE    000002  XSHE       1   主板  CNY     万科A           万科企业股份有限公司    L  1991-01-29      ...       沪深A股      CHN        3  1.161773e+10     1.161109e+10  9.717553e+09
# 2       000003.XSHE    000003  XSHE       1   主板  CNY   PT金田A       金田实业(集团)股份有限公司   DE  1991-07-03      ...       沪深A股      CHN        4  3.334336e+08     2.660457e+08  1.918089e+08
# 3       000004.XSHE    000004  XSHE       1   主板  CNY    国华网安       深圳国华网安科技股份有限公司    L  1991-01-14      ...       沪深A股      CHN        5  1.650526e+08     1.151256e+08  1.151256e+08
# ...

# %%
# render dataframe as html
__ExcelWriter = pd.ExcelWriter((str)(dt.date.today().year)+'年'+(str)(dt.date.today().month)+'月'+(str)(dt.date.today().day)+'日_优矿'+'.xlsx')
pd_stock_A.to_excel(__ExcelWriter)
__ExcelWriter.save()
print('DataFrame is written successfully to the Excel File.')
# Out:
# DataFrame is written successfully to the Excel File.
