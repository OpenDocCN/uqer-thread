# %% [markdown]
# # Notebook2

# %% [raw]
# start = '2017-08-01'                       # 回测起始时间
# end = '2017-10-30'                         # 回测结束时间
# universe = ['IFM0']        # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 1                           # 执行handle_data的时间间隔
#
#
# # 设置股指期货交易手续费，设置价格滑点百分比
# commission = Commission(buycost=0.001, sellcost=0.02, unit='perValue')
# slippage = Slippage(value=0.0004, unit='perValue')
# capital_base = 1000000
#
# #设置虚拟期货账户
# accounts = {
#     'fantasy_account': AccountConfig(account_type='futures', capital_base=capital_base,     commission=commission, slippage=slippage)
# }
#
# def initialize(context): # 初始化虚拟账户状态
#     pass
#
# def handle_data(context): # 每个交易日的买入卖出指令
#     futures_account = context.get_account('fantasy_account')
#     nowDate= context.now.strftime('%Y-%m-%d')
#
#     mainSymbol = 'IFM0' #用IFM0时，mapping_changed等函数是有效的，但用IFL0,则无效。
#     nowSymbol  = context.get_symbol(mainSymbol) #取当前主力合约
#     print nowDate, nowSymbol
#     #Position = futures_account.get_position(symbol_before)
#     if context.mapping_changed(mainSymbol):
#         symbol_before, symbol_after = context.get_rolling_tuple(mainSymbol)
#         print nowDate,symbol_before, 'changed to', symbol_after
#         Position = futures_account.get_position(symbol_before)
#         # print Position
#         if Position == None:
#             print nowDate, '买入开仓',symbol_after
#             futures_account.order(symbol_after, 1, 'open')
#         elif Position['long_amount'] > 0:
#             print nowDate, '移仓', symbol_before, symbol_after
#             futures_account.switch_position(symbol_before, symbol_after) #移仓指令
#         #end if
#     #end if
# #end
