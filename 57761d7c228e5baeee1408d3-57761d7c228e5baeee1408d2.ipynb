# %% [markdown]
# #

# %%
DataAPI.MktIdxdGet(tradeDate=u"20160630",indexID=u"",ticker=u"399006,399005",beginDate=u"",endDate=u"",field=u"",pandas="1")
# Out:
#        indexID  ticker porgFullName secShortName exchangeCD   tradeDate  \
# 0  399005.ZICN  399005      深圳证券交易所         中小板指       XSHE  2016-06-30
# 1  399006.ZICN  399006      深圳证券交易所         创业板指       XSHE  2016-06-30
#
#    preCloseIndex  openIndex  lowestIndex  highestIndex  closeIndex  \
# 0       6886.861   6890.347     6864.138      6917.306     6892.73
# 1       2209.788   2213.602     2206.805      2233.279     2227.79
#
#    turnoverVol  turnoverValue     CHG   CHGPct
# 0   1939349535   3.455408e+10   5.869  0.00085
# 1   1794150873   4.157074e+10  18.002  0.00815
