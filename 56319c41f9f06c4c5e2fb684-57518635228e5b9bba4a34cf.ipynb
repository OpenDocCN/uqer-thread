# %% [markdown]
# # 【学酥小白Q&A】修改

# %% [markdown]
# ### 策略思路：
# - 当价格上涨，突破长期移动平均线一定比例时买入：Pt > [1+threshold]\* MA\_t(60)，其中threshold为过去60日对数价格的标准差std(lnPt(60))
# - 当价格下跌，突破中期移动平均线时卖出：Pt < MA\_t(20)

# %% [markdown]
# ### 学酥小白提问环节：
# - 不知道为什么策略跑出来是直线。。应该如何改正？以及不美观的`for i in range(x)`模式能不能去掉？
# - 以\#打码的部分为一个简单MA策略，line32-33中使用的`.mean`是否会导致diff是一个定值？若不是，line32-33保证不同时点moving average的机制是什么？

# %% [markdown]
# ### 为各位高手献上膝盖。。orz

# %% [raw]
# # 1.框架是按refresh_rate的时间运行handle_data的，每次你只需要处理当天的指标，不需要一次处理完所有回测区间的数据
# # 2.account.get_history 取出来的数据是字典结构不是pandas
# import numpy as np
# import pandas as pd
# from pandas import DataFrame,Series
#
# start = '2013-01-01'                       # 回测起始时间
# end = '2015-10-26'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['000001.XSHE', '600000.XSHG']  # 证券池，支持股票和基金
# capital_base = 10000                       # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# window_short = 20
# window_long = 60
#
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     hist = account.get_history(window_long)
#     for stk in account.universe:
#         ma_short = np.mean(hist[stk]['closePrice'][-window_short:])
#         ma_long =  np.mean(hist[stk]['closePrice'][-window_long:])
#         threshold =  np.std(np.log(Series(hist[stk]['closePrice']).pct_change().dropna() + 1))
#         Pt = hist[stk]['closePrice'][-1]
#
#         if Pt > (1+threshold)* ma_long :
#             order(stk, 100)
#         if Pt < ma_short:
#             order_to(stk, 0)
#
#
# # 原帖
#
# # import numpy as np
# # import pandas as pd
#
# # start = '2014-01-01'                       # 回测起始时间
# # end = '2015-01-01'                         # 回测结束时间
# # benchmark = 'HS300'                        # 策略参考标准
# # universe = ['000001.XSHE', '600000.XSHG']  # 证券池，支持股票和基金
# # capital_base = 100000                      # 起始资金
# # freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# # refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# # longest_hist = 200
# # window_short = 20
# # window_long = 60
#
# # def initialize(account):                   # 初始化虚拟账户状态
# #     pass
#
# # def handle_data(account):                  # 每个交易日的买入卖出指令
# #     hist = account.get_history(longest_hist)
# #     for stk in account.universe:
# #         ma_short = pd.rolling_mean(hist[stk]['closePrice'], window=window_short)
# #         ma_long = pd.rolling_mean(hist[stk]['closePrice'], window=window_long)
# #         threshold = pd.rolling_std(hist[stk]['closePrice'], window=window_long)
# #         for i in range(0, longest_hist):
# #             if hist[stk]['closePrice'][i] > (1+threshold[i])*ma_long[i]:
# #                 order(stk, 100)
# #             elif hist[stk]['closePrice'][i] < ma_short[i]:
# #                 order_to(stk, 0)
#
# # #  hist = account.get_history(10)
# # #      for stk in account.universe:
# # #          ma5 = hist[stk]['closePrice'][-5:].mean()
# # #          ma10 = hist[stk]['closePrice'][:].mean()
# # #          diff = ma5 - ma10
# # #          if diff > 0 and stk not in account.valid_secpos:
# # #              order(stk, 8000)
# # #          elif diff < 0 and stk in account.valid_secpos:
# # #              order_to(stk, 0)
