# %% [markdown]
# # Notebook7

# %%
A=DataAPI.MktMFutdGet(tradeDate=u"20171026",mainCon=u"1",contractMark=u"",contractObject=u"A",startDate=u"",endDate=u"",field=u"secID,secShortName,contractObject,tradeDate,turnoverVol,openInt",pandas="1")
A
# Out:
#         secID secShortName contractObject   tradeDate  turnoverVol  openInt
# 0  A1801.XDCE      连豆一1801              A  2017-10-26       124556   370674

# %%
B=DataAPI.MktMFutdGet(tradeDate=u"20171026",mainCon=u"1",contractMark=u"",contractObject=u"A,AG",startDate=u"",endDate=u"",field=u"secID,secShortName,contractObject,tradeDate,turnoverVol,openInt",pandas="1")
B
# Out:
# Empty DataFrame
# Columns: [secID, secShortName, contractObject, tradeDate, turnoverVol, openInt]
# Index: []
