# %% [markdown]
# # 【python学习问题】两个c为什么会不一样？我想保留第一个c该怎么做？

# %%
import pandas as pd
from pandas import DataFrame
df = DataFrame()
index = ['alpha', 'beta', 'gamma', 'delta', 'eta']
for i in range(5):
    a = DataFrame([np.linspace(i, 5*i, 5)], index=[index[i]])
    df = pd.concat([df, a], axis=0)

c=df
print c
df[df[1] == 0]= np.nan
print c
# Out:
#        0  1   2   3   4
# alpha  0  0   0   0   0
# beta   1  2   3   4   5
# gamma  2  4   6   8  10
# delta  3  6   9  12  15
# eta    4  8  12  16  20
#         0   1   2   3   4
# alpha NaN NaN NaN NaN NaN
# beta    1   2   3   4   5
# gamma   2   4   6   8  10
# delta   3   6   9  12  15
# eta     4   8  12  16  20
