# %% [markdown]
# #

# %% [markdown]
# 相对于上一篇文章：https://uqer.datayes.com/community/share/582eba1b228e5ba297a9074d的PE择时，这篇文章使用了简单的趋势择时，发现效果不是很理想O(∩_∩)O哈哈~，感觉ETF不适合使用趋势，因为ETF的变化幅度比较小。

# %% [raw]
# import pandas as pd
# from datetime import datetime, timedelta
# from pandas import DataFrame,Series
#
# start = '2013-01-17'                       # 回测起始时间
# end = '2016-11-18'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准，沪深300
# universe = ['510500.XSHG','511990.XSHG']  # 证券池，支持股票和基金,华泰柏瑞沪深300ETF
# capital_base = 100000                      # 起始资金10W
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# max_history_window = 60
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     hist=account.get_attribute_history('closePrice',60)
#     hist=DataFrame(hist)#字典转为DF,0为前第60天收盘价，59为前一天收盘价）
#     ma_list=[5,10,30]
#     ma = DataFrame()
#     #计算在当日的5、10、30日均值
#     for m in ma_list:
#         ma['MA'+str(m)] = pd.rolling_mean(hist['510500.XSHG'],m)
#     #ma是一个列名为5、10、30日均值的由远及近的DataFrame
#     b=0.01#突破幅度参数
#     #突破买入条件：5日线突破10日线5%，突破30日线5%；前期较长盘整，过去30天，5，10，30日线之间的差距不超过a
#     #Series没有-1的访问方法，所以必须转换成list
#     break_condition_buy=((list(ma['MA5'])[-1]/list(ma['MA10'])[-1]-1>b) and (list(ma['MA5'])[-1]/list(ma['MA30'])[-1]-1>b))
#
#     #突破卖出条件:5日线跌破30日线
#     c=0.01#有效突破条件参数
#     break_condition_sell=( list(ma['MA5'])[-1]/list(ma['MA30'])[-1]-1<-c )
#
# #    print break_condition_buy,break_condition_sell
#     #买入
#     if break_condition_buy and '510500.XSHG' not in account.security_position:
#         order_pct_to('510500.XSHG',1)#股债平衡
#         order_pct_to('511990.XSHG',0)#股债平衡
#     #卖出
#     if break_condition_sell and '510500.XSHG' in account.security_position:
#         order_pct_to('510500.XSHG',0)#股债平衡
#         order_pct_to('511990.XSHG',1)#股债平衡
#     return
