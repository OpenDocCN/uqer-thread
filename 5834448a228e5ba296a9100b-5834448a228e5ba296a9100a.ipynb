# %% [markdown]
# #

# %% [markdown]
# 计算交易日前一天的沪深300市值最低的五只股票，每个季度末进行调仓轮动

# %% [raw]
# start = '2013-02-05'                        # 回测起始时间
# end = '2016-11-21'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = DynamicUniverse('HS300')  # 证券池，沪深300
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# #获取交易日:isYearEnd,isQuarterEnd,isMonthEnd,isWeekEnd,isOpen
# data = DataAPI.TradeCalGet(exchangeCD=u"XSHG",beginDate=start,endDate=end,field=u"calendarDate,isQuarterEnd",pandas="1")
# data = data[data['isQuarterEnd'] == 1]
# Dates = map(lambda x: x[0:4]+x[5:7]+x[8:10], data['calendarDate'].values.tolist())
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     #获取上一个交易日
#     date = account.previous_date.strftime('%Y%m%d')
#     if date in Dates or date == '20130204':#调仓时间季度末
#         #获取上一个交易日所以股票的PE
#         #total = DataAPI.MktStockFactorsOneDayGet(tradeDate=date,secID=account.current_universe,field=['secID','PB'],pandas="1").set_index('secID')
#         total = DataAPI.MktEqudGet(tradeDate=date,secID=account.current_universe,field=u"secID,negMarketValue",pandas="1").set_index('secID')
#         #选出PE大于0的
#         total0 = total[total['negMarketValue'] > 0]
#         #排序取出最小的5个PE
#         total5 = total0.sort(columns='negMarketValue').ix[:5]
#         for stock in total5.index:
#             order_pct_to(stock,0.2)#平均每只20%
#     return
