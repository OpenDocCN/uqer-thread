# %% [markdown]
# # Notebook8

# %%
factor_list = ['secID','ticker','ACD20','ACD6','AD','AD20','AD6','ADTM','ADX','ADXR','APBMA',
'AR','ARBR','ARC','Aroon','AroonDown','AroonUp','ASI','ATR14','ATR6',
'BBI','BBIC','BearPower','BIAS10','BIAS20','BIAS5','BIAS60','BollDown',
'BollUp','BR','BullPower','CCI10','CCI20','CCI5','CCI88','CFO2EV',
'ChaikinOscillator','ChaikinVolatility','ChandeSD','ChandeSU','CMO',
'CMRA','CoppockCurve','CR20','DAREC','DAREV','DAVOL10','DAVOL5','DBCD',
'DDI','DDNCR','DDNSR','DEA','DIF','DIFF','DIZ','DownRVI','Elder',
'EMA10','EMA12','EMA120','EMA20','EMA26','EMA5','EMA60','EMV14','EMV6',
'ETOP','FiftyTwoWeekHigh','FY12P','GREC','GSREV','HBETA','Hurst',
'ILLIQUIDITY','JDQS20','KDJ_D','KDJ_J','KDJ_K','KlingerOscillator','LCAP',
'LFLO','MA10','MA10Close','MA10RegressCoeff12','MA10RegressCoeff6','MA120',
'MA20','MA5','MA60','MACD','MassIndex','MAWVAD','MFI','minusDI','MLEV',
'MoneyFlow20','MTM','MTMMA','NVI','OBV','OBV20','OBV6','PB','PCF','PE',
'PLRC12','PLRC6','plusDI','PS','PVT','PVT12','PVT6','RC12','RC24','REC',
'REVS10','REVS20','REVS5','ROC20','ROC6','RSI','RSTR12','RSTR24','RVI',
'SBM','SFY12P','Skewness','SRMI','STM','SwingIndex','TA2EV','TEMA10','TEMA5',
'TOBT','TRIX10','TRIX5','TVMA20','TVMA6','TVSTD20','TVSTD6','Ulcer10',
'Ulcer5','UOS','UpRVI','VDEA','VDIFF','VEMA10','VEMA12','VEMA26','VEMA5',
'VMACD','VOL10','VOL120','VOL20','VOL5','VOL60','Volatility','VOSC','VR',
'VROC12','VROC6','WVAD']
t = DataAPI.MktStockFactorsOneDayGet(tradeDate='20160615',secID=u"",ticker=u"000001",field=factor_list,pandas="1")
t
# Out:
#          secID         ticker         ACD20    ACD6         AD       AD20  \
# 0  000001.XSHE         000001  3.040000e-01  0.0750  4371.6689  4268.3366
# 1  16200652909  16111873033.7  1.617326e+10  0.7964     3.2512     6.6922
#
#          AD6    ADTM      ADX     ADXR  ...      MACD  MassIndex   MAWVAD  \
# 0  4356.5243  0.2919  37.6860  36.6042  ...    0.0206    23.4693  41.9564
# 1     0.0049 -0.0206  28.6197   1.4500  ...       NaN        NaN      NaN
#
#        MFI  minusDI  MLEV   MoneyFlow20    MTM   MTMMA    NVI
# 0  71.9296   8.9239   0.0  5.848397e+09  0.131  0.1682  2.148
# 1      NaN      NaN   NaN           NaN    NaN     NaN    NaN
#
# [2 rows x 100 columns]
