# %% [markdown]
# # 简单均线策略

# %% [raw]
# start = '2010-02-01'                       # 回测起始时间
# end = '2018-02-01'                         # 回测结束时间
# universe = ['600376.XSHG']        # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'm'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = (1,30)                         # 执行handle_data的时间间隔
# max_history_window = (60,300)
# commission = Commission(buycost=0.0003, sellcost=0.0013, unit='perValue')
# capital_base = 100000
#
#
# # 均线周期
# period = 240
#
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#     current_universe = context.get_universe('stock', exclude_halt=True)
#
#     data = context.history(current_universe, 'closePrice', period, freq='30m', style='sat', rtype='frame')
#
#
#     for s in current_universe:
#         closePrice = data[s]['closePrice'][-1]
#         MA120 = data[s]['closePrice'][-120:].mean()
#         MA200 = data[s]['closePrice'][-200:].mean()
#         MA5 = data[s]['closePrice'][-5:].mean()
#         MA80 = data[s]['closePrice'][-80:].mean()
#
#         preMA120 = data[s]['closePrice'][-121:-1].mean()
#         preMA200 = data[s]['closePrice'][-201:-1].mean()
#         preMA5 = data[s]['closePrice'][-6:-1].mean()
#         preMA80 = data[s]['closePrice'][-81:-1].mean()
#
#         if MA120 < MA200:
#             if MA5 <= MA80 and preMA5 >= preMA80:
#                 if s in context.avail_security_position:
#                     order_to(s,0)
#
#             elif MA5 >= MA120 and preMA5 <= MA120:
#                 if s not in context.avail_security_position:
#                     amount = int(context.cash/ context.referencePrice[s] / 100) * 100
#                     order(s, amount)
