# %% [markdown]
# # 小市值因子

# %% [markdown]
# 选择市值最小的20个股票，每个个股为其分配5%的仓位，每隔20个交易日进行一次调仓

# %% [raw]
# start = '2011-12-31'
# end   = u''
# capital_base = 1000000
# refresh_rate = 20
# benchmark = 'HS300'
# freq = 'd'
# commission = Commission(buycost=0.0005, sellcost=0.0015, unit='perValue')
# universe = StockScreener(Factor.LCAP.nsmall(20))#选择市值对数最小的20个个股，市值对数最小，当然也就是市值最小了
# def initialize(account):#此处可以设置全局变量
#     pass
#
# def handle_data(account):
#     #先卖股票，若有停牌股卖不出
#     for stock in account.valid_secpos:
#         if stock not in account.universe:
#             order_pct_to(stock,0)
#     #再买股票，每个股票仓位设置为5%
#     for stock in account.universe:
#         if stock not in account.valid_secpos:
#             order_pct_to(stock,0.05)
