# %% [markdown]
# # 问题

# %%
universe2 = set_universe('A', date='20070621')
universe3 = set_universe('A', date='20170621')

# %%
print(len(universe2), len(universe3))
# Out:
# (3271, 3271)

# %%
counter = 0
for s in universe2:
    if s in universe3:
        counter += 1

# %%
print counter
# Out:
# 3271
