# %% [markdown]
# #

# %% [raw]
# # 均线策略
# start = '2015-03-20'                  # 回测起始时间
# end = '2015-03-28'                   # 回测结束时间
# benchmark = 'SH50'                   # 策略参考标准
# universe = ['000001.XSHE', '000002.XSHE', '000568.XSHE', '000625.XSHE', '000768.XSHE', '600028.XSHG', '600030.XSHG', '601111.XSHG', '601390.XSHG', '601998.XSHG']              # 证券池，也可以在这里添加多个证券
# capital_base = 10000                  # 起始资金
# freq = 'd'                         # 日线策略
# refresh_rate = 1                     # 每个交易日调仓
#
#
# date = '20150609'
#
# data = DataAPI.MktStockFactorsOneDayGet(tradeDate=date,secID=universe,field=['PB','PE'],pandas="1")
# print(data)
# data.plot()
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     pass
