# %% [markdown]
# # Notebook

# %% [raw]
# start = '2012-06-01'                       #回测开始时间
# end = '2017-06-01'                         # 回测结束时间
# secID = '601318.XSHG'                      #中国平安
#
# benchmark = secID                          # 策略对标标的
# universe = [secID]                         # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔
# period1 = 20
# period2 = 5
# period3 = 60
# commission = Commission(buycost=0.0003, sellcost=0.0013, unit='perValue')
# max_history_window = 100                   #设定调取历史价格区间最大为100个交易日
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     history1 = account.get_attribute_history('closePrice', period1)      #获取过去 period1 个交易日的收盘价
#     temp = account.get_attribute_history('closePrice', 1)                #获取当天收盘价
#     history2 = account.get_attribute_history('closePrice', period2)      #获取过去 period2 个交易日的收盘价
#     history3 = account.get_attribute_history('closePrice', period3)      #获取过去 period3 个交易日的收盘价
#     for s in account.universe:
#         mean1 = history1[s].mean()                                       #计算过去 period1 个交易日均价
#         mean2 = history2[s].mean()                                       #计算过去 period2 个交易日均价
#         mean3 = history3[s].mean()                                       #计算过去 period3 个交易日均价
#
#         if temp[s] > mean1 and s not in account.security_position:       #收盘价上穿 period1 日均线时买入
#             amount = int(account.cash / account.reference_price[s] / 100) * 100
#             order(s, amount)
#         elif mean2 < mean3 and s in account.security_position:           # period2 日均线下穿 period3 日均线时卖出
#             order_to(s, 0)
