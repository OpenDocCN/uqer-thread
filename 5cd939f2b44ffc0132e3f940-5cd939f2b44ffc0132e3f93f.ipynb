# %% [markdown]
# # Notebook

# %% [markdown]
# 计算的数据对象为上证50ETF（选取的时间段是从2019年1月4日至2019年3月31日），先是计算出上证50ETF的对数收益率，然后再通过AR(1)对收益率进行处理，得出残差序列，最终对残差序列进行处理，这是为了消除短期的依赖。

# %%
DataAPI.MktFunddGet(ticker=indexLabel,beginDate=beginDate,endDate=endDate,field=["tradeDate","closePrice"],pandas="1")
# Out:
#      tradeDate  closePrice
# 0   2019-01-04       2.310
# 1   2019-01-07       2.307
# 2   2019-01-08       2.300
# 3   2019-01-09       2.325
# 4   2019-01-10       2.328
# 5   2019-01-11       2.347
# 6   2019-01-14       2.325
# 7   2019-01-15       2.370
# 8   2019-01-16       2.374
# 9   2019-01-17       2.365
# 10  2019-01-18       2.409
# 11  2019-01-21       2.424
# 12  2019-01-22       2.396
# 13  2019-01-23       2.392
# 14  2019-01-24       2.403
# 15  2019-01-25       2.433
# 16  2019-01-28       2.430
# 17  2019-01-29       2.448
# 18  2019-01-30       2.437
# 19  2019-01-31       2.474
# 20  2019-02-01       2.492
# 21  2019-02-11       2.516
# 22  2019-02-12       2.524
# 23  2019-02-13       2.571
# 24  2019-02-14       2.567
# 25  2019-02-15       2.511
# 26  2019-02-18       2.571
# 27  2019-02-19       2.567
# 28  2019-02-20       2.577
# 29  2019-02-21       2.566
# 30  2019-02-22       2.618
# 31  2019-02-25       2.816
# 32  2019-02-26       2.728
# 33  2019-02-27       2.736
# 34  2019-02-28       2.736
# 35  2019-03-01       2.802
# 36  2019-03-04       2.815
# 37  2019-03-05       2.813
# 38  2019-03-06       2.820
# 39  2019-03-07       2.773
# 40  2019-03-08       2.675
# 41  2019-03-11       2.690
# 42  2019-03-12       2.701
# 43  2019-03-13       2.706
# 44  2019-03-14       2.710
# 45  2019-03-15       2.740
# 46  2019-03-18       2.812
# 47  2019-03-19       2.790
# 48  2019-03-20       2.794
# 49  2019-03-21       2.784
# 50  2019-03-22       2.777
# 51  2019-03-25       2.702
# 52  2019-03-26       2.692
# 53  2019-03-27       2.723
# 54  2019-03-28       2.718
# 55  2019-03-29       2.819

# %%
indexPrice=DataAPI.MktFunddGet(ticker=indexLabel,beginDate=beginDate,endDate=endDate,field=["tradeDate","closePrice"],pandas="1")
price = np.array(indexPrice.loc[:,'closePrice'])
price
# Out:
# array([ 2.31 ,  2.307,  2.3  ,  2.325,  2.328,  2.347,  2.325,  2.37 ,
#         2.374,  2.365,  2.409,  2.424,  2.396,  2.392,  2.403,  2.433,
#         2.43 ,  2.448,  2.437,  2.474,  2.492,  2.516,  2.524,  2.571,
#         2.567,  2.511,  2.571,  2.567,  2.577,  2.566,  2.618,  2.816,
#         2.728,  2.736,  2.736,  2.802,  2.815,  2.813,  2.82 ,  2.773,
#         2.675,  2.69 ,  2.701,  2.706,  2.71 ,  2.74 ,  2.812,  2.79 ,
#         2.794,  2.784,  2.777,  2.702,  2.692,  2.723,  2.718,  2.819])

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from datetime import timedelta
from statsmodels import regression

#设置时间
beginDate = '20190104' 
endDate = '20190331'

#设置研究对象股票名
indexLabel = '510050'

#读取指数
indexPrice=DataAPI.MktFunddGet(ticker=indexLabel,beginDate=beginDate,endDate=endDate,field=["tradeDate","closePrice"],pandas="1")
price = np.array(indexPrice.loc[:,'closePrice'])

#计算对数收益
back_price = np.append(price[0],price.copy())   
back_price = back_price[:-1] 
return_price = np.log(price) - np.log(back_price)

#计算收益率AR(1)的残差序列
r2 = back_price[1:]
r1 = back_price[:-1]
R = regression.linear_model.OLS(r2,r1).fit()
X = R.resid

# %%
RS = np.zeros(18)      #array
RS1 = np.zeros(18)      #array
RS2 = np.zeros(18)      #array
V = np.zeros(18)       #array
logRS = np.zeros(18)   #array
logn = np.zeros(18)   #array
X = np.array(X)    #读入时间序列,一维矩阵
T = X.shape[0]     #读取时间序列的总长度，
for n in xrange(10,18):  #每个长度计算一次
    a = int(T/n) 
    x1 = X[0:n*a].reshape(n,a)   #正向分段,n行a列，每一列为一个子序列
    x2 = X[(T - a * n): T].reshape(n,a)  #反向分段,n行a列，每一列为一个子序列
    m1 = np.mean(x1,axis=0)     #按列取均值，1行a列
    m2 = np.mean(x2,axis=0)     #按列取均值，1行a列
    p = np.ones((n,1))              #n行，1列
    y1 = x1 - p * m1                  #n行，a列，对每一列求离差
    y2 = x2 - p * m2                  #n行，a列，对每一列求离差       
    sig1 = np.std(x1,axis=0)             #1行，a列，对每一列求标准差
    sig2 = np.std(x2,axis=0)             #1行，a列，对每一列求标准差
    sum1 = np.cumsum(y1,axis=0)          #n行，a列，求累计离差
    sum2 = np.cumsum(y2,axis=0)          #n行，a列，求累计离差
    r1 = np.max(sum1,axis=0) - np.min(sum1,axis=0)      #%1行，a列
    r2 = np.max(sum2,axis=0) - np.min(sum2,axis=0)      #%1行，a列        
    RS1[n] = np.mean(r1 / sig1,axis=0)        #1行，1列
    RS2[n] = np.mean(r2 / sig2,axis=0)        #1行，1列    
    RS[n] = 0.5*RS1[n] + 0.5*RS2[n]
    logRS[n] = np.log(RS[n])
    V[n] = RS[n] * (pow(n,-0.5))
    logn[n] = np.log(n)
R = regression.linear_model.OLS(logRS[10:18],logn[10:18]).fit()
R.params[0]
# Out:
# 0.44977594836714929

# %%
plt.plot(V)
np.argmax(V)
# Out:
# 13

# %% [markdown]
# V统计量在13的时候出现最大值，姑且可以认为上证50ETF有一个平均循环周期，长度为13个交易日，所以我们接下来进行滚动Hurst指数计算的时候，滚动窗口定为13日

# %%
def Hurst(XX,T):  
    XX = np.array(XX)    #读入时间序列,一维矩阵
    Lenth = XX.shape[0]     #读取时间序列的总长度，
    hurst = np.zeros(Lenth)
    for i in xrange(T,Lenth):
        X=XX[i-T:i+1]
        RS = np.zeros(T)      #array
        logRS = np.zeros(T)   #array
        logn = np.zeros(T)   #array        
        for n in xrange(10,T):  #每个长度计算一次
            a = int(T/n) 
            x1 = X[0:n*a].reshape(n,a)   #正向分段,n行a列，每一列为一个子序列
            x2 = X[(T - a * n): T].reshape(n,a)  #反向分段,n行a列，每一列为一个子序列
            m1 = np.mean(x1,axis=0)     #按列取均值，1行a列
            m2 = np.mean(x2,axis=0)     #按列取均值，1行a列
            p = np.ones((n,1))              #n行，1列
            y1 = x1 - p * m1                  #n行，a列，对每一列求离差
            y2 = x2 - p * m2                  #n行，a列，对每一列求离差       
            sig1 = np.std(x1,axis=0)             #1行，a列，对每一列求标准差
            sig2 = np.std(x2,axis=0)             #1行，a列，对每一列求标准差
            sum1 = np.cumsum(y1,axis=0)          #n行，a列，求累计离差
            sum2 = np.cumsum(y2,axis=0)          #n行，a列，求累计离差
            r1 = np.max(sum1,axis=0) - np.min(sum1,axis=0)      #%1行，a列
            r2 = np.max(sum2,axis=0) - np.min(sum2,axis=0)      #%1行，a列        
            RS1[n] = np.mean(r1 / sig1,axis=0)        #1行，1列
            RS2[n] = np.mean(r2 / sig2,axis=0)        #1行，1列    
            RS[n] = 0.5*RS1[n] + 0.5*RS2[n]
            logRS[n] = np.log(RS[n])
            logn[n] = np.log(n)
        R = regression.linear_model.OLS(logRS[10:T],logn[10:T]).fit()
        hurst[i] = R.params[0]
    return hurst

# %% [markdown]
# 时间窗口取为13，从第13个交易日开始，每个交易日都计算出一个Hurst指数的值，这个值是以该交易日和之前的13个交易日为基础算出来的。

# %%
hurst = Hurst(X,T=13)
plt.plot(hurst)

# %%
hurst
hurst.shape[0]
# Out:
# 55

# %%
indexPrice['Hurst'] = pd.DataFrame(np.array([0] * len(indexPrice)))
indexPrice.loc[1:,'Hurst'] = hurst
ma_hurst = pd.rolling_mean(hurst, 240)
ma_hurst
ma_hurst.shape[0]
indexPrice['MA_Hurst'] = pd.DataFrame(np.array([0] * len(indexPrice)))
indexPrice.loc[1:,'MA_Hurst'] = ma_hurst
indexPrice['MA_SSE'] = pd.DataFrame(np.array([0] * len(indexPrice)))
indexPrice.loc[1:,'MA_SSE'] = pd.rolling_mean(indexPrice['closePrice'], 5)   #大盘5日均线
indexPrice.index = indexPrice['tradeDate'][0:len(indexPrice)]

# %%
fig,ax1=plt.subplots()
indexPrice['closePrice'][14:56].plot(figsize=(10,4),color='red',linewidth=1)
plt.grid(True)
plt.ylabel("SSE Index")
plt.axis('tight')
ax2=ax1.twinx()
indexPrice['Hurst'][14:56].plot(figsize=(10,4),color='green',linewidth=1,marker='.')
plt.grid(True)
plt.ylabel('Hurst Index')
plt.axis('tight')
# Out:
# (0.0, 41.0, 0.35673857025125005, 0.54766741327705326)
