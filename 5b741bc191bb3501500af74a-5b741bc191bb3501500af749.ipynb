# %% [markdown]
# # 捡烟屁交易方法

# %% [raw]
# start = '2012-01-03'                       # 回测起始时间
# end = '2018-08-10'
# universe = DynamicUniverse('HS300')        # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'HS300'                        # 策略参考标准
# # capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 30
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
# def initialize(context):                   # 初始化策略运行环境
#     pass
# def handle_data(context):
#     previous_date = context.previous_date.strftime('%Y-%m-%d')
#     df=DataAPI.MktStockFactorsOneDayGet(tradeDate=previous_date,secID=u"",ticker=u"",field=u"",pandas="1")
#
#     dpe = df[df['PE']<=10][df['PE']>1][df['MLEV']>=0.2][df['MLEV']<=0.5][df['NetProfitGrowRate']>0.3][df['ATR14']<0.6]    #选取市盈率小于十，杠杆率0.2-0.5，最近净资产增长率0.3，14日波动率小于0.6
#
#     for index, row in dpe.iterrows():
#         df2=DataAPI.SecSTGet(beginDate=u"20100101",endDate=previous_date,secID=u"",ticker=row['ticker'],field=u"",pandas="1")                 #剔除ST股
#         df3=DataAPI.EquDivGet(secID=u"",ticker=row['ticker'],eventProcessCD=u"",exDivDate="",beginDate=u"20100101",endDate=previous_date,beginPublishDate=u"",endPublishDate=u"",beginRecordDate=u"",endRecordDate=u"",field=u"",pandas="1")         #选择可以长期分红的股票
#         if df2.empty==False or df3.empty:
#             dpe.drop(index, axis=0, inplace=True)
#
#
#
#
#     target_position = dpe.sort(columns = ['ASSI'],axis = 0,ascending = False).iloc[:5,:5]['secID']
#
#
#
#     account = context.get_account('fantasy_account')
#     current_position = account.get_positions(exclude_halt=True)
#     for stock in set(current_position).difference(target_position):
#         syl = DataAPI.MktStockFactorsOneDayGet(tradeDate=previous_date,secID=stock,ticker=u"",field=u"",pandas="1")
#         # print(syl['PE'][0])
#         if syl['PE'][0]>=18:                     #在市盈率大于18时卖出
#             account.order_to(stock, 0)
#     for stock in target_position:
#         # print(stock)
#         account.order_pct_to(stock, 0.33)
