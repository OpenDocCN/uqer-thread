# %% [markdown]
# # 协整配对2

# %% [raw]
# import numpy as np
# import pandas as pd
# start = '2016-01-01'
# end = '2019-11-01'
#
# benchmark = 'HS300'
# freq = 'd'
# refresh_rate = 1
# universe = ['000615.XSHE','600791.XSHG']
# commission = Commission(buycost = 0.0005, sellcost = 0.002, unit = 'perValue')
# slippage = Slippage(value=0.001, unit='perValue')  # 滑点设置成百分比滑点0.001
# accounts = {
#     'stock_account': AccountConfig(account_type='security', commission =commission,
#            slippage = slippage, capital_base=10000000)
# }
#
#
# def initialize(context):
#     return
#
# def handle_data(context):
#     current_universe = context.get_universe(exclude_halt=True)
#     data1 = context.history(current_universe, 'closePrice', 1, rtype='frame',style='ast')
#     data2 = context.history(current_universe, 'closePrice', 2, rtype='frame',style='ast')
#     #if pd.isnull(data1.iloc[0, 0])
#     account = context.get_account('stock_account')
#     current_positions = account.get_positions()
#     cash = account.cash
#     buylist = []
#     #prices = account.get_attribute_history('closePrice', longest_history)
#     closedata1=data1['closePrice']
#     closedata2=data2['closePrice']
#     print(closedata1)
#     if  pd.isnull(closedata1.iloc[0,0]) or :
#         closedata1.iloc[0,0]=closedata2.iloc[0,0]
#     if  pd.isnull(closedata1.iloc[0,1]):
#         closedata1.iloc[0,1]=closedata2.iloc[0,1]
#     closedata1['minus']=closedata1['000615.XSHE']-closedata1['600791.XSHG']
#     stock_spread=closedata1.iloc[0,2]
#     print(stock_spread)
#
#     account.order_pct_to('000615.XSHE',1)

# %%
,0
