# %% [markdown]
# #

# %%
import numpy as np
import pandas as pd
a = np.array([1,2,3,1,2,4,1,2,5])
a = a.reshape(3,3)
df = pd.DataFrame(a)
df.columns=['a','b','c']
df1 = df.drop_duplicates(cols='a')
print df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <mercury-input-1-912804c68042> in <module>()
#       5 df = pd.DataFrame(a)
#       6 df.columns=['a','b','c']
# ----> 7 df1 = df.drop_duplicates(cols='a')
#       8 print df1
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/util/decorators.pyc in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# TypeError: drop_duplicates() got an unexpected keyword argument 'cols'
