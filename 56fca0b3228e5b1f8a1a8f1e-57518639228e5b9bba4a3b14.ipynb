# %% [markdown]
# # 因子筛选-为什么1G内存这个程序都跑不了

# %% [raw]
# from datetime import *
# import scipy as sp
# import quartz
# import numpy as np
# import pandas as pd
# import talib as tb
# from CAL.PyCAL import *
# start = '2012-01-06'                       # 回测起始时间
# end = '2016-03-08'                         # 回测结束时间
# benchmark = 'SHCI'                        # 策略参考标准
# universe = set_universe('A')  # 证券池，支持股票和基金
# #Commission = (0.00008, )
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 5                          # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# fields = ['closeIndex', 'tradeDate','highestIndex','lowestIndex','turnoverVol']
# def ma5(data, dependencies = ['closePrice'], max_window = 6):
#     return data['closePrice'][0:5].mean()
# def ma60(data, dependencies = ['closePrice'], max_window = 61):
#     return data['closePrice'][0:61].mean()
#
# def initialize(account):                   # 初始化虚拟账户状态
#     #a = Signal('MA_5', ma5)
#     #b = Signal('MA_60', ma60)
#     #account.signal_generator = SignalGenerator(a,b)
#     pass
# #netInflowM  netInflowL  netInflowXl closePrice  negMarketValue            tradeDate  netInflowS
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     #stocksPrice = account.get_history(60)
#     stocks = StockScreener(Factor.DEGM.nlarge(100) & Factor.FEARNG.nlarge(100))
#     #print stocks.preview('2015-01-06').values()[0]
#     cal = Calendar('China.SSE')
#     date = Date(account.current_date.year, account.current_date.month, account.current_date.day)
#     yestday = cal.advanceDate(date, '-1B', BizDayConvention.Following)
#     beginDay = cal.advanceDate(date, '-2B', BizDayConvention.Following)
#     fields = ['negMarketValue','closePrice','turnoverRate','secID']        #beginDate=beginDay.strftime('%Y%m%d'),endDate=yestday.strftime('%Y%m%d'),
#     data = DataAPI.MktEqudAdjAfGet(secID=stocks.preview(yestday.strftime('%Y-%m-%d')).values()[0],tradeDate=yestday.strftime('%Y%m%d'),isOpen="",field=fields,pandas="1")
#     print data.head()
#     data.sort('negMarketValue', inplace = True, ascending = True)
#     buyList = data.secID.tolist()[0:4]
#     #buyList = []
#     #holdList = []
#     for stock in account.valid_secpos:
#         if stock not in buyList:
#             order_to(stock, 0)
#
#     for stock in buyList:
#         order(stock, account.referencePortfolioValue / len(buyList) / account.referencePrice[stock])
