# %% [markdown]
# #

# %%
import numpy as np
import pandas as pd
from pandas import *
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import coint
stk_a='601288'
stk_b='601328'
tmp=[]
tmp1=[]
ShenWanL1={'银行':IndSW.YinHangL1}
for stk in ShenWanL1.values():
    tmp+=set_universe(stk)
universe = list(set(tmp).intersection(set(universe)))
for stk in universe:
    tmp1.append(stk[:6])
 
for stk1 in tmp1:
    stk_a = stk1
    for stk2 in tmp1:
        stk_b=stk2
        
        print stk_a,stk_b 



        beginDate="20130101"
        endDate="20140101"   
        data1=DataAPI.MktEqudAdjGet(tradeDate=u"",secID=u"",ticker=stk_a,beginDate=beginDate,endDate=endDate,isOpen="",field=u"closePrice",pandas="1")
        data2=DataAPI.MktEqudAdjGet(tradeDate=u"",secID=u"",ticker=stk_b,beginDate=beginDate,endDate=endDate,isOpen="",field=u"closePrice",pandas="1")
        z=pd.concat([data1,data2],axis=1)
        x=np.array(data1)
        y=np.array(data2)
        x=x.T[0];y=y.T[0]
        a,pvalue,b = coint(x,y)
        print pvalue

def testStationarity(data):
    adftest = adfuller(data)
    result = pd.Series(adftest[0:4], index=['Test Statistic','p-value','Lags Used','Number of Observations Used'])
    for key,value in adftest[4].items():
        result['Critical Value (%s)'%key] = value
    return result
# Out:
# 600016
#  600016
# 1.0
# 600016 601166
# 0.240664129504
# 600016 600036
# 0.108565209886
# 600016 601288
# 0.168619108822
# 600016 601818
# 0.0891561380728
# 600016 601169
# 0.0238916923343
# 600016 601988
# 0.204780029233
# 600016 600000
# 0.525131989127
# 600016 601328
# 0.0217240028
# 600016 601398
# 0.12022995751
# 600016 601998
# 0.253384569762
# 601166 600016
# 0.350440265802
# 601166 601166
# 0.0
# 601166 600036
# 0.461950455373
# 601166 601288
# 0.273066238275
# 601166 601818
# 0.41652925237
# 601166 601169
# 0.0725512609719
# 601166 601988
# 0.206657642126
# 601166 600000
# 0.494794536615
# 601166 601328
# 0.0380780837215
# 601166 601398
# 0.558976906394
# 601166 601998
# 0.285577310096
# 600036 600016
# 0.102891102125
# 600036 601166
# 0.361283030561
# 600036 600036
# 0.0
# 600036 601288
# 0.299302422202
# 600036 601818
# 0.084886935568
# 600036 601169
# 0.293800241702
# 600036 601988
# 0.463320183387
# 600036 600000
# 0.539014836392
# 600036 601328
# 0.197713628679
# 600036 601398
# 0.465360172043
# 600036 601998
# 0.24989379645
# 601288 600016
# 0.138505231699
# 601288 601166
# 0.155112865227
# 601288 600036
# 0.221642405323
# 601288 601288
# 0.0
# 601288 601818
# 0.0665500488414
# 601288 601169
# 0.117164706582
# 601288 601988
# 0.38899524618
# 601288 600000
# 0.287056115394
# 601288 601328
# 0.174616420819
# 601288 601398
# 0.617769482727
# 601288 601998
# 0.0691102172844
# 601818 600016
# 0.257236897013
# 601818 601166
# 0.647577888902
# 601818 600036
# 0.21293101493
# 601818 601288
# 0.231664903434
# 601818 601818
# 0.0
# 601818 601169
# 0.234515979323
# 601818 601988
# 0.637844779494
# 601818 600000
# 0.896199078171
# 601818 601328
# 0.125759144146
# 601818 601398
# 0.697151745265
# 601818 601998
# 0.512591615888
# 601169 600016
# 0.0318102255566
# 601169 601166
# 0.0757147378253
# 601169 600036
# 0.390676899112
# 601169 601288
# 0.227113782677
# 601169 601818
# 0.136782150124
# 601169 601169
# 0.0
# 601169 601988
# 0.319963805211
# 601169 600000
# 0.660191998271
# 601169 601328
# 0.00134906629909
# 601169 601398
# 0.557038430077
# 601169 601998
# 0.216125460981
# 601988 600016
# 0.167593554678
# 601988 601166
# 0.0981458310969
# 601988 600036
# 0.307754491396
# 601988 601288
# 0.335821058653
# 601988 601818
# 0.217399989276
# 601988 601169
# 0.14502625439
# 601988 601988
# 0.0
# 601988 600000
# 0.0760744541354
# 601988 601328
# 0.0788412307687
# 601988 601398
# 0.442515612006
# 601988 601998
# 0.189703233298
# 600000 600016
# 0.684970273082
# 600000 601166
# 0.511658208906
# 600000 600036
# 0.645341083726
# 600000 601288
# 0.471787252845
# 600000 601818
# 0.716813374817
# 600000 601169
# 0.630068603516
# 600000 601988
# 0.18339902134
# 600000 600000
# 0.0
# 600000 601328
# 0.497836042599
# 600000 601398
# 0.601445607332
# 600000 601998
# 0.504058051196
# 601328 600016
# 0.0233932386199
# 601328 601166
# 0.0555752854717
# 601328 600036
# 0.405047524261
# 601328 601288
# 0.475681249688
# 601328 601818
# 0.0985891844236
# 601328 601169
# 0.00250177961735
# 601328 601988
# 0.277430277183
# 601328 600000
# 0.690160736914
# 601328 601328
# 0.0
# 601328 601398
# 0.671338447707
# 601328 601998
# 0.314424501731
# 601398 600016
# 0.202611478434
# 601398 601166
# 0.494098837411
# 601398 600036
# 0.444353386714
# 601398 601288
# 0.712984973332
# 601398 601818
# 0.411558412744
# 601398 601169
# 0.442577328968
# 601398 601988
# 0.650311630916
# 601398 600000
# 0.504645718846
# 601398 601328
# 0.404863074066
# 601398 601398
# 0.0
# 601398 601998
# 0.510434405796
# 601998 600016
# 0.516302791711
# 601998 601166
# 0.431426217785
# 601998 600036
# 0.464784009681
# 601998 601288
# 0.206698096555
# 601998 601818
# 0.478808143674
# 601998 601169
# 0.306593221327
# 601998 601988
# 0.547337604513
# 601998 600000
# 0.673048176397
# 601998 601328
# 0.291422094104
# 601998 601398
# 0.776569129856
# 601998 601998
# 0.0

# %% [raw]
# import numpy as np
#
# start = '2014-01-01'
# end   = '2015-01-01'
# capital_base = 1000000
# refresh_rate = 1
# benchmark = 'HS300'
# freq = 'd'
# universe = ['601169.XSHG', '601328.XSHG']
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#
#     longest_history = 1
#     prices = account.get_attribute_history('closePrice', longest_history)
#     stk1, stk2 = universe
#     price1= prices[stk1][-1]
#     price2= prices[stk2][-1]
#
#     buy_list = []
#     sell_list = []
#
#     if price1-price2 > 1.7452:
#         buy_list.append(stk2)
#         sell_list.append(stk1)
#     if price1-price2 < 1.4573:
#         buy_list.append(stk1)
#         sell_list.append(stk2)
#     if price1-price2 < 0.01 and price1-price2 > -0.01 :
#         sell_list.append(stk1)
#         sell_list.append(stk2)
#     hold = []
#     buy = []
#
#
#     for stk in account.valid_secpos:
#         if stk in sell_list:
#             order_to(stk, 0)
#         else:
#             hold.append(stk)
#
#     buy = hold
#     for stk in buy_list:
#         if stk not in hold:
#             buy.append(stk)
#
#     if len(buy) > 0:
#         # 等仓位买入
#         amout = account.referencePortfolioValue/len(buy) # 每只股票买入数量
#         for stk in buy:
#             num = int(amout/account.referencePrice[stk] / 100.0) * 100
#             order_to(stk, num)
#
#     return
