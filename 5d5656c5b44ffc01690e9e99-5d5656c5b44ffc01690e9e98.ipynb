# %% [markdown]
# # Notebook9

# %%
import pandas as pd

test = [1,2,3,4]
test = pd.DataFrame(test)
test.to_excel('test.xls')

# %%
sample  = pd.read_excel('test1.xls')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <mercury-input-1-FC140F46471C42B58824E3E59CD0B84D> in <module>()
# ----> 1 sample  = pd.read_excel('test1.xls')
#
# NameError: name 'pd' is not defined

# %%
sample1 = pd.read_excel('文件夹1/关键词信息.xls')

# %%
sample
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
