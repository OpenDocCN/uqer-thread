# %% [markdown]
# # 股价&市盈率&kdj&换手率

# %% [raw]
# import pandas as pd
# start = '2015-01-01'                       # 回测起始时间
# end = '2016-12-31'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe =  set_universe('A') # 证券池，支持股票和基金
# capital_base = 10000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account): # 每个交易日的买入卖出指令
#     pcp = DataAPI.MktEqudGet(tradeDate=account.previous_date,secID=account.universe,isOpen="1",field=u"secID,negMarketValue,closePrice",pandas="1")
#     pcp.set_index('secID',inplace=True)
#     pcp = pcp[pcp.negMarketValue<4000000000].dropna()
#     pcp = pcp[pcp.closePrice<=10].dropna()
#     #print pcp
#     data = DataAPI.MktStockFactorsOneDayGet(tradeDate=account.previous_date,secID=account.universe,field=u"secID,KDJ_K,KDJ_J,PE,VOL5",pandas="1")
#     data.set_index('secID',inplace=True)
#     data = data[data.KDJ_K<60].dropna()
#     data = data[data.KDJ_J<80].dropna()
#     data = data[data.PE<30].dropna()
#     #print data
#     isst = DataAPI.SecSTGet(beginDate=account.current_date,endDate=account.current_date,secID=account.universe,field=u"secID,STflg",pandas="1")
#     isst.set_index('secID',inplace=True)
#     #print isst
#     buylist = []
#     for s in list(data.index):
#         if s in list(pcp.index):
#             if s not in list(isst.index):
#                 buylist.append(s)
#     #print buylist
#
#     for s in account.security_position:
#         if (account.reference_price[s]/account.security_cost[s]>1.3) or (account.reference_price[s]/account.security_cost[s]<0.9):
#             order_to(s, 0)
#     for s in buylist:
#         if s not in account.security_position:
#             order(s, (round((1*account.cash/len(buylist)/account.reference_price[s])/100)+1)*100)
#     return
#     #data = DataAPI.MktEqudGet(secID = '000001.XSHE',field = ['secID','tradeDate','closePrice','turnoverVol'], beginDate = '2015-01-01', endDate = '2015-01-10')
#     #ma5= data['closePrice'].iloc[[0,1,2]].min()
#     #print data
#     #print ma5
#     #return
