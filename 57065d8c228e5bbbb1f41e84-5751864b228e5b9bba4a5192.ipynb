# %% [markdown]
# # 双低择时策略

# %% [markdown]
# 低PE，低PB，指数高于4000点退出市场休息

# %% [raw]
# start = "2015-01-01"                # 回测起始时间
# end = "2015-12-31"
#
# benchmark = 'HS300'                # 策略参考标准
# capital_base = 1000000              # 起始资金
# freq = 'd'                      # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 5                  # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# universe = StockScreener(Factor.PE.value_range(0, 20)&Factor.PB.value_range(0, 5)) #因子选股
#
# def initialize(account):
#     account.limit = 10
#
# def handle_data(account):
#     index = DataAPI.MktIdxdGet(tradeDate=account.current_date, ticker="000300")["preCloseIndex"].tolist()[0]
#     stocks = account.universe[:account.limit]
#     buylist = {s:0 for s in stocks}
#
#     #等权买入
#     for s in buylist:
#         buylist[s] = account.referencePortfolioValue/len(buylist)
#
#     if index > 4000: #指数超过4000点，休息
#         for s in account.valid_secpos:
#             order_to(s, 0)
#     else:
#         #卖出不在买入列表内的
#         for s in account.valid_secpos:
#             if s not in buylist:
#                 order_to(s, 0)
#
#         #买入，限制在limit只以内
#         for s in buylist:
#             if len(account.valid_secpos) < account.limit:
#                 order(s, buylist[s])
