# %% [markdown]
# # Test

# %% [raw]
# import numpy as np
# import pandas as pd
#
# C=DataAPI.MktEqudGet(ticker=u"000906",beginDate=u"20090601",endDate=u"20170630",field=u"", pandas="1")
# data_df=pd.DataFrame(C)
# data_df.to_csv('file.csv')
