# %% [markdown]
# # Notebook

# %%
class human:
        def man(a,b):
        a=0
        b=0
        print a+b
# Out:
#   File "<mercury-input-13-0DC90202C5504319ACF1CB56D66F0467>", line 7
#     a=0
#     ^
# IndentationError: expected an indented block
