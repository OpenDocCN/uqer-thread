# %% [markdown]
# # MACD系统2.0

# %% [raw]
# import numpy as np
# import pandas as pd
# import talib
#
# start = '2015-06-01'
# end = '2018-06-01'
# universe = ['600030.XSHA']
# benchmark = 'HS300'
# freq = 'd'
# refresh_data = 1
# max_history_window = 60
#
# accounts = {
#     'self_account':AccountConfig(account_type = 'security',capital_base = 1000000)
# }
#
# def initialize(context):
#     pass
#
# def handle_data(context):
#     account = context.get_account('self_account')
#     universe = context.get_universe()
#     data = context.history(universe,'closePrice',30,rtype = 'array')
#     close_price = np.array(data[universe[0]]['closePrice'])
#     # log.info(close_price)
#     position = account.get_posion(universe[0])
