# %% [markdown]
# # MACD系统2.0

# %% [raw]
# import numpy as np
# import pandas as pd
# import talib
#
# start = '2012-06-01'
# end = '2016-06-01'
# universe = ['600030.XSHG']
# benchmark = 'HS300'
# freq = 'd'
# refresh_data = 1
# max_history_window = 60
#
# accounts = {
#     'self_account':AccountConfig(account_type = 'security',capital_base = 1000000)
# }
#
# def initialize(context):
#     pass
#
# def handle_data(context):
#     account = context.get_account('self_account')
#     universe = context.get_universe()
#     data = context.history(universe,'closePrice',40,rtype = 'array')
#     close_price = np.array(data[universe[0]]['closePrice'])
#     # log.info(close_price)
#     macd,signal,hist = talib.MACD(close_price,12,26,9)
#     # log.info(signal)
#     position = account.get_position(universe[0])
#
#     if not position:
#         if macd[-2] < signal[-2] and macd[-1] > signal[-1]:
#             account.order_pct(universe[0],0.5)
#     else:
#         if macd[-2] > signal[-2] and macd[-1] > signal[-1]:
#             account.order_pct_to(universe[0],0)
