# %% [markdown]
# # BaseSpread_20170410

# %%
import datetime, time
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn

# %%
# 设定常数
SYMBOL='IF'
TICKER='000300'
BeginDate=u"20130101"
EndDate=u"20201212"
EndDate=datetime.datetime.today().strftime("%Y%m%d")

# 抓取数据
Ind_df=DataAPI.MktIdxdGet(tradeDate=u"",indexID=u"",ticker=TICKER,
                          beginDate=BeginDate,endDate=EndDate,exchangeCD=u"XSHE,XSHG",
                          field=u"tradeDate,indexID,ticker,openIndex,closeIndex")

L0_df=DataAPI.MktMFutdGet(tradeDate=u"",mainCon=u"",contractMark=u"L0",contractObject=SYMBOL,
                          startDate=BeginDate,endDate=EndDate,
                          field=u"tradeDate,secID,ticker,openPrice,closePrice")

L1_df=DataAPI.MktMFutdGet(tradeDate=u"",mainCon=u"",contractMark=u"L1",contractObject=SYMBOL,
                          startDate=BeginDate,endDate=EndDate,
                          field=u"tradeDate,secID,ticker,openPrice,closePrice")

L3_df=DataAPI.MktMFutdGet(tradeDate=u"",mainCon=u"",contractMark=u"L3",contractObject=SYMBOL,
                          startDate=BeginDate,endDate=EndDate,
                          field=u"tradeDate,secID,ticker,openPrice,closePrice")

L6_df=DataAPI.MktMFutdGet(tradeDate=u"",mainCon=u"",contractMark=u"L6",contractObject=SYMBOL,
                          startDate=BeginDate,endDate=EndDate,
                          field=u"tradeDate,secID,ticker,openPrice,closePrice")

print "不同连续月份的股指期货合约日期数目是否相同？", len(Ind_df)==len(L0_df) and len(L1_df)==len(L3_df) and len(L3_df)==len(L6_df)
Dayslen=len(Ind_df)
# Out:
# 不同连续月份的股指期货合约日期数目是否相同？
#  True

# %%
# 计算基差
BaseSread_L0=pd.DataFrame()
BaseSread_L0['tradeDate']=Ind_df['tradeDate']
BaseSread_L0['openBaseSpread']=L0_df['openPrice']-Ind_df['openIndex']
BaseSread_L0['closeBaseSpread']=L0_df['closePrice']-Ind_df['closeIndex']

BaseSread_L1=pd.DataFrame()
BaseSread_L1['tradeDate']=Ind_df['tradeDate']
BaseSread_L1['openBaseSpread']=L1_df['openPrice']-L0_df['openPrice']
BaseSread_L1['closeBaseSpread']=L1_df['closePrice']-L0_df['closePrice']

BaseSread_L3=pd.DataFrame()
BaseSread_L3['tradeDate']=Ind_df['tradeDate']
BaseSread_L3['openBaseSpread']=L3_df['openPrice']-L0_df['openPrice']
BaseSread_L3['closeBaseSpread']=L3_df['closePrice']-L0_df['closePrice']

BaseSread_L6=pd.DataFrame()
BaseSread_L6['tradeDate']=Ind_df['tradeDate']
BaseSread_L6['openBaseSpread']=L6_df['openPrice']-L0_df['openPrice']
BaseSread_L6['closeBaseSpread']=L6_df['closePrice']-L0_df['closePrice']

BaseSread_L=pd.DataFrame()
BaseSread_L['tradeDate']=Ind_df['tradeDate']
BaseSread_L['openBaseSpread']=L6_df['openPrice']-L3_df['openPrice']
BaseSread_L['closeBaseSpread']=L6_df['closePrice']-L3_df['closePrice']

#print BaseSread_L1

# %%
df_toplot=BaseSread_L0
#df_toplot=df_toplot[(df_toplot['tradeDate']>='2014-09-01') & (df_toplot['tradeDate']<'2020-12-01')]
ax=df_toplot.plot(figsize=(18,9),x=['tradeDate'])

# 交割日期序列，画上黑色竖直线
PromptDays=['2015-01-16','2015-02-20','2015-03-20','2015-04-17','2015-05-15','2015-06-29',
            '2015-07-17','2015-08-21','2015-09-18','2015-10-16','2015-11-20','2015-12-18',
            '2016-01-15','2016-02-19','2016-03-18','2016-04-15','2016-05-20','2016-06-17',
            '2016-07-15','2016-08-19','2016-09-19','2016-10-21','2016-11-18','2016-12-16',
            '2017-01-20','2017-02-17','2017-03-17','2017-04-21','2017-05-19','2017-06-16',
            '2017-07-21','2017-08-18','2017-09-15','2017-10-20','2017-11-17','2017-12-15',
            '2018-01-19','2018-02-17','2018-03-17','2018-04-21','2018-05-19','2018-06-16',
            '2018-07-21','2018-08-18','2018-09-15','2018-10-20','2018-11-17','2018-12-15']
PromptDays=[]
minV=min(df_toplot['openBaseSpread'].tolist()+df_toplot['closeBaseSpread'].tolist())
maxV=max(df_toplot['openBaseSpread'].tolist()+df_toplot['closeBaseSpread'].tolist())
for i,tradeDate in enumerate(df_toplot['tradeDate']):
    if tradeDate in PromptDays:
        ax.plot([i,i],[minV,maxV],'-k')

# %%
print "交易日序列"
print df_toplot['tradeDate'].tolist()
# Out:
# 交易日序列
# ...
