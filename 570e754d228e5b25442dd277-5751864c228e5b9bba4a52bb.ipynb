# %% [markdown]
# # 有写GFTD高频策略的朋友吗？我现在遇到点瓶颈可以指导一下吗

# %% [raw]
# from __future__ import division
# import numpy as np
# import pandas as pd
# from pandas import Series, DataFrame
# import talib
# from talib import func
# import matplotlib
# from CAL.PyCAL import *
# import datetime
# from math import *
# start = '2013-01-04'                       # 回测起始时间
# end = '2016-04-12'                         # 回测结束时间
#
# benchmark = '600519.XSHG'                  # 策略参考标准
# universe = ['600519.XSHG']                 # 证券池，支持股票和基金
#
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 5                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# ud = []  #ud是全局变量所以要在这里定义，否则无法运行
# low_price  = []    #当买入启动后，记录最低价序列
# lowest_percent = 0.005
# commission = Commission(buycost=0.0003, sellcost=0.0013, unit='perValue')
#
#
# def initialize(account):					# 初始化虚拟账户状态
#
#     pass
#
# def handle_data(account):                   # 每个交易日的买入卖出指令
#     c = account.get_attribute_history('closePrice', 20)  #为日K 线的收盘价序列
#     h = account.get_attribute_history('highPrice', 20)   #为日K 线的最高价序列
#     l = account.get_attribute_history('lowPrice', 20)    #为日K 线的最低价序列
#     n1 = -4          #n1  为模型买入启动或卖出启动形态形成时的价格比较滞后期数
#     n2 = 4          #n2 为模型买入启动或卖出启动形态形成的价格关系单向连续个数
#     n3 = 3          #n3 为模型计数阶段的最终信号发出所需的计数值
#     tmp_c = c['600519.XSHG']
#     tmp_h = h['600519.XSHG']
#     tmp_l = l['600519.XSHG']
#
# #    print   account.current_date
# #    print "前一日收盘价:"+str(tmp_c[-1])
# #    print "前四日收盘价:"+str(tmp_c[n1])
# #    print "前一日最高价:"+str(tmp_h[-1])
# #    print "前四日最高价:"+str(tmp_h[n1])
# #    print "前一日最低价:"+str(tmp_l[-1])
# #    print "前四日最低价:"+str(tmp_l[n1])
#     if  tmp_c[-1]>tmp_c[-4]:
#         ud.append(1)
#     elif tmp_c[-1]<tmp_c[-4]:
#         ud.append(-1)
#     else:
#         ud.append(0)
# #    print "ud="+str(ud)
#     udi = 0
#     mai_count = 0
#     for i in ud:
#         udi=i+udi
#         if udi ==n2:
#             print str(account.current_date)+"卖出启动(只要符合三个条件就马上卖出)"
#             #回测基本上没有符合三个条件的时候
#             if (tmp_c[1]<=tmp_l[-2])&(tmp_l[-1]<tmp_l[-2])&(tmp_c[-1]<tmp_c[-2]):
#                 order('600519.XSHG',0)
#         if udi ==-4:
#             print str(account.current_date)+"形成买入启动(只要符合三个条件就马上买入)"
#             #-----------这一段代码暂时没用 上 -----
#             if tmp_c[-1] >=  tmp_c[0]*(1+lowest_percent):
#                 low_price = False
#                 #print"昨天不是近期最低价"+str(tmp_c[-1])
#             elif tmp_c[-1] < tmp_c[0]*(1+lowest_percent):
#                 low_price = True
#                 #print"昨天是近期最低价"+str(tmp_c[-1])
#              #-----------这一段代码暂时没用 上 -----
#             if tmp_c[-1]>tmp_h[-2]:
#                 mai_count =  mai_count+1
#                 print "买入计数:"+str(mai_count)
#                 if mai_count==n3:
#                     print "收盘价大于两天收盘价 买入："+str(account.current_date)
#                     print ud
#                     print "前一日收盘价:"+str(tmp_c[-1])
#                     print "前两日收盘价:"+str(tmp_c[-2])
#                     print "前一日最高价:"+str(tmp_h[-1])
#                     print "前两日最高价:"+str(tmp_h[-2])
#                     print "前一日最低价:"+str(tmp_l[-1])
#                     print "前两日最低价:"+str(tmp_l[-2])
#                     print "-----------"
#                     order('600519.XSHG',100)
