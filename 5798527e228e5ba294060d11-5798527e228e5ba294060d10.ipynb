# %% [markdown]
# #

# %%
DataAPI.SecIDGet(partyID=u"",assetClass=u"",ticker=u"150019",cnSpell=u"",field=u"",pandas="1")
# Out:
#          secID  ticker    secShortName         cnSpell exchangeCD assetClass  \
# 0  150019.OFCN  150019  银华深证100指数分级-积极  YHSZ100ZSFJ-JJ        NaN          F
# 1   150019.OTC  150019        15附息国债19        15FXGZ19        OTC          B
# 2  150019.XIBE  150019        15附息国债19        15FXGZ19       XIBE          B
# 3  150019.XSHE  150019  银华深证100指数分级-积极  YHSZ100ZSFJ-JJ       XSHE          F
#
#   listStatusCD    listDate transCurrCD          ISIN  partyID
# 0           UN         NaN         CNY           NaN    26938
# 1            L  2015-09-14         CNY           NaN    11327
# 2            L  2015-09-14         CNY  CND100008S85    11327
# 3            L  2010-06-07         CNY  CNE100000RS1    26938

# %%
reload(lib.lib_for_macd_bl)   #修改lib里面函数后需要reload

# %% [raw]
# from datetime import datetime,timedelta
# from dateutil.parser import parse
# import pandas as pd
# import talib
# import numpy as np
# import lib.lib_for_macd_bl
#
# start = '2010-01-01'                       # 回测起始时间
# end = '2016-7-25'                         # 回测结束时间
# benchmark = 'SHCI'                        # 策略参考标准
# universe = ['150019.XSHE']
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                          # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
#
#
# def initialize(account):                   # 初始化虚拟账户状态
#     DataAPI.settings.cache_enabled = True
#     account.fund = universe[0]
#     a = Signal('MACD_BL',lib.lib_for_macd_bl.Macd_BL)
#     account.signal_generator = SignalGenerator(a)
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     today = str(account.current_date)[0:10]
#     hist = account.get_history(1)
#     fund = account.fund
#     if universe[0] in account.signal_result['MACD_BL']:
#         buy_flag = True if account.signal_result['MACD_BL'][universe[0]] == 1 else False
#         sell_flag = True if account.signal_result['MACD_BL'][universe[0]] == -1 else False
#     else:
#         buy_flag = False
#         sell_flag = False
#
#     stop_lo_flag = False    #stop loss order 止损之意
#
#     if universe[0] in account.valid_seccost:
#         if hist[universe[0]]['closePrice'][0] < 0.95 * account.valid_seccost[fund]:
#             if account.position.secpos.get(fund, 0) >= 0:
#                 order_to(fund, 0)           #止损，全仓出
#                 #print today,'\nSeccost:',account.valid_seccost[fund],'\nPresent price:',hist[universe[0]]['closePrice'][0],'\nstopped loss order'  #止损提示
#     if buy_flag:
#         if account.position.secpos.get(fund, 0) == 0:            # 空仓时全仓买入，买入股数为100的整数倍
#             approximationAmount = int(account.cash / hist[fund]['closePrice'][-1]/100.0) * 100
#             order(fund, approximationAmount)
#     elif sell_flag:        # 卖出时，全仓清空
#         if account.position.secpos.get(fund, 0) >= 0:
#             order_to(fund, 0)
#     return
