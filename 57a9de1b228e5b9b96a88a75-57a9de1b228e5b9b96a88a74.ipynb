# %% [markdown]
# #

# %%
universe = DataAPI.EquGet(equTypeCD='A')['ticker']

mylist = []
count = 0
for ticker in universe:
    if ticker <= '001000':
        mylist.append(ticker)
        count += 1
print count
data = DataAPI.FdmtISAllLatestGet(ticker=mylist,secID=u"",reportType=u"",year="",endDate=u"",beginDate=u"",field=u"",pandas="1")
data.to_excel('000000-001000IS.xlsx','Sheet1',)
# Out:
# 462
