# %% [markdown]
# # Notebook7

# %% [raw]
# # 测试程序
# import numpy as np
# import pandas as pd
# from pandas import Series, DataFrame
#
# start = '2017-01-01'
# end   = '2017-01-03'
# universe = DynamicUniverse('A')
# benchmark = 'HS300'
# freq = 'd'
# refresh_rate = 1
# cols2 = ['secID','tradeDate','openPrice','closePrice']
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):
#     pass
#
# def handle_data(context):
#     current_date = context.current_date.strftime('%Y-%m-%d') #回测日期
#
#     secIDs = context.get_universe(exclude_halt=True) #取回测日的所有开盘A股代码
#     symbols =secIDs[:2]+secIDs[-2:] #测试，只取首尾各两个股票
#     print symbols
#     gp = DataAPI.MktEqudAdjGet(secID=symbols,isOpen="1",tradeDate=current_date,field=cols2,pandas="1")
#     gp.set_index('secID',inplace=True)
#     print gp
#     print
#
#     hist = context.history(symbol=symbols, attribute=['openPrice','closePrice'],time_range=3, freq='1d', rtype='frame', style='sat')
#     print hist
#     print hist.keys()
#     df= pd.DataFrame.from_dict(hist,orient='index') #如何将字典的数据转换成DataFrame格式？
#     print '--------'
#     print df
