# %% [markdown]
# # 【50ETF期权】 期权择时日报 2015-12-24

# %% [markdown]
# ## 期权择时信号：
# -----
# - `期权总成交量/总成交额 PCR 上升`
# - `次月期权 PCIVD 上升`
# - `iVIX 略降至 24.6%`
# - 期权市场对标的 50ETF 在短期的走势判断`中性`
#
# ----
#
# 择时信号，均来自于期权市场数据，无主观干预，仅供参考！ 具体信号详情，请见下文分解
#
# ----
# 我们使用华夏上证50ETF期权的行情数据，回顾计算上一交易日几项指标，尝试追踪市场情绪走势，初步讨论只包括两个指标 PCR 和 PCIVD (均为`反向指标`)，另中国波指 iVIX 指数作为参考
#
# - 成交量(成交额) `PCR`：Put Call Ratio 看跌看涨期权的成交量(成交额)比率
# - `PCIVD`：Put Call Implied Volatility Difference 看跌看涨期权隐含波动率差
# - 中国波指 `iVIX`： 用于衡量上证50ETF未来30日的预期波动
#
# 选择期权市场作为择时研究的原因
#
# - 目前期权市场的主要参与者为机构投资者，相对散户他们的投资逻辑更加科学独立
# - 期权，交易的是远期的权利，相比于直接研究股票现货市场，期权更具前瞻性
#
# ---

# %%
# 导入自定义opt模块，其中包括本文需要用到的所有工具
import lib.opt as opt

# %% [markdown]
# ### 1. 期权择时日报回顾
#
# 截至今天，此日报已经跟踪市场多日，取得的效果如下：

# %%
opt.plotOptionTimingHist().tail(12)
# Out:
#             走势预测 当日50ETF真实走势
# 2015-12-04  谨慎乐观      -2.52%
# 2015-12-07    中性      -0.33%
# 2015-12-08    中性      -1.00%
# 2015-12-09    悲观      +0.13%
# 2015-12-10    乐观      -0.59%
# 2015-12-11    中性      -0.47%
# 2015-12-14    中性      +3.03%
# 2015-12-15    中性      -1.37%
# 2015-12-16  谨慎乐观      -0.42%
# 2015-12-17    中性      +1.22%
# 2015-12-18    中性      +0.87%
# 2015-12-21    中性           ?

# %% [markdown]
# ##### 从上表看，择时效果符合预期，值得参考

# %% [markdown]
# ### 2. PCIVD 择时效果回测
#
# - 我们好奇上文选用的择时指标到底效果如何
# - 此处我们以PCIVD为例产生信号，买卖50ETF，观察回测结果
# - 具体信号为：当月/次月期权PCIVD均减小，则买入；否则，卖出

# %% [raw]
# from CAL.PyCAL import *
#
# start = datetime(2015, 2, 9)				# 回测起始时间
# end  = datetime(2015, 12, 2)				# 回测结束时间
# benchmark = '510050.XSHG'			    	# 策略参考标准
# universe = ['510050.XSHG']	                # 股票池
#
# capital_base = 100000                       # 起始资金
# commission = Commission(0.0,0.0)
# refresh_rate = 1
#
# def initialize(account):					# 初始化虚拟账户状态
#     account.fund = universe[0]
#     account.pcivd = opt.histPCIVD50ETF(start, end)
#
# def handle_data(account):             # 每个交易日的买入卖出指令
#     fund = account.fund
#     #  获取回测当日的前一天日期
#     dt = Date.fromDateTime(account.current_date)
#     cal = Calendar('China.SSE')
#     last_day = cal.advanceDate(dt,'-1B',BizDayConvention.Preceding)            #计算出倒数第一个交易日
#     last_day_str = last_day.strftime("%Y-%m-%d")
#
#     # 计算买入卖出信号
#     try:
#         # 拿取PCIVD数据
#         pcivd_near = account.pcivd.nearDiff.loc[last_day_str]
#         pcivd_next = account.pcivd.nextDiff.loc[last_day_str]
#         long_flag = True if pcivd_near < 0.00 and pcivd_next < 0.00 else False
#     except:
#         long_flag = False
#
#     if long_flag:
#         # 买入时，全仓杀入
#         try:
#             approximationAmount = int(account.cash / account.referencePrice[fund] / 100.0) * 100
#             order(fund, approximationAmount)
#         except:
#             return
#     else:
#         # 卖出时，全仓清空
#         order_to(fund, 0)

# %% [markdown]
# ##### 虽然回测时间短，PCIVD 的良好择时效果表明，它可以通过期权市场的信息来给出在现货市场的买卖择时信号，必要时建议我们空仓

# %% [markdown]
# ----
# 下面我们详细展示 PCR、PCIVD、iVIX 近期走势

# %% [markdown]
# ### 3. PCR
#
# - 重点关注期权合约 PCR 指标变动情况

# %%
# 画出前10个交易日的PCR变化图
opt.plotPCR()
# Out:
#             putVol  callVol  putValue  callValue  volPCR  valuePCR
# date
# 2015-12-10   78467   124402  78469612   96572416  0.6308    0.8125
# 2015-12-11   88427   106090  78417285   75650201  0.8335    1.0366
# 2015-12-14   97810   127661  88376600   85182104  0.7662    1.0375
# 2015-12-15   76715   115241  55621614   77275500  0.6657    0.7198
# 2015-12-16   73482    92863  59311568   60170091  0.7913    0.9857
# 2015-12-17   96346   144953  63978207  121538233  0.6647    0.5264
# 2015-12-18  118468   148968  63910223  106440345  0.7953    0.6004
# 2015-12-21  102949   176205  66189572  146124441  0.5843    0.4530
# 2015-12-22   59752    98899  32035327   98207894  0.6042    0.3262
# 2015-12-23   93682   153072  60056612  137813013  0.6120    0.4358

# %% [markdown]
# - 表中数据展示看跌看涨期权成交量和成交额，已经相应的PCR
# - 上图中直观显示出看跌看涨期权成交量成交额的近期走势
# - 下图中展示成交量/成交额 PCR 指标走势
#
# #### 图中，`期权总成交量/总成交额 PCR 上升`

# %% [markdown]
# ### 4. PCIVD
#
# - 关注当月合约和次月合约看跌看涨期权隐含波动率差

# %% [markdown]
# ##### 昨日期权合约隐含波动率微笑
#
# - 另：下文所谓 PCIVD，就是波动率微笑中，平值附近看跌、看涨期权隐含波动率之间 gap 大小

# %%
opt.plot2DaysSmileIV('2015-12-23')
# Out:
# lib/opt.py:397: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   opt_call[('Call-Put', 'strike')] = opt_call[('Call', 'strike')]
# lib/opt.py:398: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   opt_call[('Call-Put', 'spot')] = opt_call[('Call', 'spot')]
# lib/opt.py:399: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   opt_call[('Call-Put', 'forward')] = opt_call[('Call', 'forward')]
# python2.7/site-packages/matplotlib/figure.py:1595: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# - 上图为近月期权，下图为次月期权
# - 图中灰色表示倒数第二个交易日的隐含波动率微笑，亮色表示上一交易日情况
# - 其中的竖虚线表示当日的50ETF价格位置
# - 根据此图，可以清晰看到两日之间看跌看涨期权隐含波动率的变动情况

# %% [markdown]
# #### PCIVD计算

# %%
# 画出前10个交易日的PCIVD变化图
opt.plotPCIVD()
# Out:
# lib/opt.py:457: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   opt_epd[('Call-Put', 'diffKF')] = np.abs(opt_epd[('Call-Put', 'strike')] - opt_epd[('Call-Put', 'spot')])

# %% [markdown]
# ### 上图可见， `次月期权 PCIVD 上升`

# %% [markdown]
# ### 5. 中国波指 iVIX
#
# - 波动率VIX指数是跟踪市场波动性的指数，一般通过标的期权的隐含波动率计算得来。当VIX越高，表示市场参与者预期后市波动程度会更加激烈，同时也反映其不安的心理状态；相反，VIX越低时，则反映市场参与者预期后市波动程度会趋于缓和。因此，VIX又被称为投资人恐慌指标（The Investor Fear Gauge）
#
# - 中国波指 iVIX 用于衡量上证50ETF未来30日的预期波动。该指数是根据方差互换的原理，通过对上证所交易的50ETF期权价格的计算编制而得

# %%
# 画出iVIX走势图
opt.plotIVIX()
# Out:
# lib/opt.py:689: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   opt_otm['price'][strike_ref] = (opt_call['price'][strike_ref] + opt_call['price'][strike_ref])/2.0
#                  iVIX
# tradeDate
# 2015-12-10  28.586866
# 2015-12-11  28.644706
# 2015-12-14  28.655571
# 2015-12-15  27.912686
# 2015-12-16  27.782614
# 2015-12-17  26.798869
# 2015-12-18  23.890695
# 2015-12-21  24.315198
# 2015-12-22  25.583808
# 2015-12-23  24.608130

# %% [markdown]
# ### 上图可见，`iVIX 略降至 24.6%`

# %% [markdown]
# ----
# 感谢优矿量化平台，此日报会每天运行发表
# https://uqer.datayes.com/home/
