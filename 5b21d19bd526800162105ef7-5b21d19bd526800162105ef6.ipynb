# %% [markdown]
# # 某只股票区间涨幅（以年为例）

# %%
a=DataAPI.EquRetudGet(secID=u"",ticker=u"300450",listStatusCD=u"",beginDate=u"20170610",endDate=u"20180610",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
print a.describe()
print '日回报率均值：'
b=a.describe().loc['mean','dailyReturnReinv']
print b
print '年回报率：'
print b*252
# Out:
#        dailyReturnReinv
# count        245.000000
# mean           0.002528
# std            0.034341
# min           -0.100013
# 25%           -0.020243
# 50%            0.000000
# 75%            0.019620
# max            0.100098
# 日回报率均值：
# 0.00252820816327
# 年回报率：
# 0.637108457143
