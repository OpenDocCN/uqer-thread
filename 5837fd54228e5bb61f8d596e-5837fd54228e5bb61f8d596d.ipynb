# %% [markdown]
# # 11.25更新日志

# %% [markdown]
# 本次新增内容
# * 支持期货策略回测详情展示
# * 新增在线debug功能
# * 支持查看notebook历史版本
# * 社区帖回复支持插入文件及notebook

# %% [markdown]
# * 期货策略回测详情展示，祝各位矿友净值都能一飞冲天和太阳肩并肩～
#
# ![期货策略回测详情展示](http://storage-uqer.datayes.com/54806799f9f06c8e773366fe/a160da84-b2db-11e6-8780-f8bc124ed898)<p><p><p>
# * 在线debug功能，支持console和watch。优矿可以在线断点调试啦，这个功能让小矿不由的回忆起了那些年帮女同学装过的visualstudio，不知各位矿友用过的编译器是哪一款呢。
#
# ![debug功能](http://storage-uqer.datayes.com/54806799f9f06c8e773366fe/a68dcbe8-b2db-11e6-9640-f8bc124ed898)<p>
# <p>
# <p>
# * 新增notebook历史版本功能,不小心改动不要慌，优矿时钟帮你忙。
# <p>
# <p>
# <p>
# ![notebook历史版本功能](http://storage-uqer.datayes.com/54806799f9f06c8e773366fe/b1833678-b2db-11e6-b29a-f8bc124ed898)
# <p>
# <p>
# <p>
# * 社区回复支持文件以及notebook，这个不用多说，老哥，稳！
# ![社区回复](http://storage-uqer.datayes.com/54806799f9f06c8e773366fe/b68fcbc2-b2db-11e6-8d41-f8bc124ed898)
# <p>
# <p>
# <p>
# <p>
# 喜欢本次的功能就给工程师点个赞吧
