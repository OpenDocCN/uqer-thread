# %% [markdown]
# # 两点半策略

# %% [markdown]
# 一个小练习
#
# 两点半策略：到了下午两点半临近收市时，股票的走势已经明朗，大幅下跌的可能性小，所以做短线的很多会在下午两点半开始进行选股、买入。这个策略就是在下午两点半时进行买入，第二天开盘卖出的分钟策略。
#
# 回测结果不理想，还应结合选股来看。

# %% [raw]
# start = '2020-01-01'                       # 回测起始时间
# end = '2020-06-01'                         # 回测结束时间
# universe = ['510300.XSHG']        # 还是买指数
# ETF300 = '510300.XSHG'
# benchmark = 'HS300'                        # 策略参考标准
# capital_base = 10000000
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                          # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):
#     account.if_clear = True
#     pass
#
# def handle_data(account):
#
#     # 开仓
#     if account.current_minute == '14:30' and account.if_clear == True:
#         account.order_pct_to(ETF300, 1)
#     account.if_clear = False
#
#     # 平仓
#     if account.current_minute == '09:30' and account.if_clear == False:
#         account.order_pct_to(ETF300, 0)
#     account.if_clear = True
