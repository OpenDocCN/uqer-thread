# %% [markdown]
# #

# %% [raw]
# import quartz
# from CAL.PyCAL import *
# import numpy as np
# start = '2012-01-01'                       # 回测起始时间
# end = '2016-07-06'
# universe =set_universe('SH50')+['600007.XSHG','600004.XSHG','600028.XSHG','600050.XSHG','600016.XSHG','600018.XSHG','600085.XSHG','600654.XSHG','600031.XSHG','600030.XSHG'\
# '000157.XSZG','000651.XSZG','000063.XSZG']
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# cal=Calendar('China.SSE')
# from matplotlib import pylab
# import seaborn as sns
#
# def initialize(account):
#  pass
#
# def handle_data(account):
#      last10day=cal.advanceDate(account.previous_date,'-10B')
#      for s in account.universe:
#        a = DataAPI.MktIdxdGet(ticker = u'000001',tradeDate=account.previous_date,field = u'tradeDate,closeIndex,CHGPct',pandas="1")
#        b=a['CHGPct'][0]
#        ma=DataAPI.MktStockFactorsDateRangeGet(secID=s,beginDate=last10day,endDate=account.previous_date,field=u"secID,MA20,MA10",pandas="1")
#        hist=account.get_attribute_history('closePrice',10)
#        ma10=ma['MA10']
#        ma20=ma['MA20']
#        try:
#           if ma20[0]<ma10[0] and ma10[0]<hist[s][-1] and s not in account.valid_secpos:
#             order(s,6000)
#           elif ma10[0]*0.98>hist[s][-1] and b<-0.03 and s in account.valid_secpos:
#             order(s,-3000)
#           elif b<-0.05:
#             order_to(s,0)
#             refresh_rate=3
#           elif b>0.05:
#             refresh_rate=1
#        except:
#           pass
#
#
# bt,acct=quartz.backtest(start=start,
#             end=end,
#             benchmark=benchmark,
#             universe=universe,
#             capital_base=capital_base,
#             initialize=initialize,
#             handle_data=handle_data,
#             refresh_rate=refresh_rate)
#
# perf=quartz.perf_parse(bt,acct)
#
# out_keys=['annualized_return','volatility','information_ratio',
#     'sharpe','max_drawdown','alpha','beta']
#
# for k in out_keys:
#     print'%s:%s'%(k,perf[k])
#
# perf['cumulative_returns'].plot()
# perf['benchmark_cumulative_returns'].plot()
# pylab.legend(['current_strategy','HS300'])
