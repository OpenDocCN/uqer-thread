# %% [markdown]
# # TA

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.nonparametric.kernel_regression import KernelReg
import seaborn as sns

# %%
DataAPI.MktStockFactorsOneDayGet(tradeDate=u"20150227",ticker=u"000001,600000",field=u"secID,PE")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <mercury-input-1-E250A7D04DA943E7A694F9A0ABC50B90> in <module>()
# ----> 1 DataAPI.MktStockFactorsOneDayGet(tradeDate=u"20150227",ticker=u"000001,600000",field=u"secID,PE")
#
# NameError: name 'DataAPI' is not defined
