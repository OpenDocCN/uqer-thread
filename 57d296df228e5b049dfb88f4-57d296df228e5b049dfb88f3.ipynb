# %% [markdown]
# #

# %% [markdown]
# 简单均线适合学习

# %% [raw]
# start = '2015-02-01'                       # 回测起始时间
# end = '2016-09-06'                         # 回测结束时间
# benchmark = '000001.XSHE'                      # 策略参考标准
# #universe = ['000001.XSHE', '600000.XSHG']  # 证券池，支持股票和基金
# universe = ['000001.XSHE' ]                 # 证券池，支持股票和基金
# capital_base = 200000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# period=20
#
#
# # 交易损失 印花税0.003放在买入端，交易手续0.0003
# commission = Commission(buycost=0.003, sellcost=0.0003, unit='perValue')
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     hist = account.get_attribute_history('closePrice', period)   #返回值与universe有关
#     for stock in account.universe:
#
#         close_price = hist[stock][-1]   #-1表示数组倒数第一个。 数组从0开始
#         ma = hist[stock].mean()         #均线包括当天
#
#
#
#         if close_price > ma and stock not in account.valid_secpos:
#             # 空仓时全仓买入，买入股数为100的整数倍
#             amount = int(account.cash / account.referencePrice[stock] / 100) * 100
#             order(stock, amount)
#             log.debug(amount)
#         elif close_price < ma and stock in account.valid_secpos:
#             order_to(stock, 0)     #注意为orderto，买入或卖出到一定数量
#         log.debug(account.avail_secpos)
#
#
#
#     return
# def after_trading_end(context):
# 	print '===============今日信息==================='
