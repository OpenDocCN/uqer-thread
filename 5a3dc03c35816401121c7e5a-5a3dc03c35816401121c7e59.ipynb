# %% [markdown]
# # 基金策略

# %%
import pandas as pd
import numpy as np

# %% [raw]
# start = '2009-01-01'        #起始时间
# end = '2017-12-18'         #终止时间
# fund_tick='110011.OFCN'
# universe = [fund_tick]
# benchmark='HS300'
# max_history_window = 252
# accounts = {
#     'fantasy_account': AccountConfig(account_type='otc_fund', capital_base=100000)
# }
#
# def handle_data(context):
#     account = context.get_account('fantasy_account')
#
#     nav_history = context.history(fund_tick, 'adjustNav', 251)
#     nav_fund=np.array(nav_history[fund_tick])
#     mean30=nav_fund[:-1].mean()
#
#     if account.get_position(fund_tick) <100:
#         if nav_fund[-1]>mean30:
#             try:
#                 account.purchase(fund_tick, account.cash)
#             except:
#                 pass
#     try:
#         if nav_fund[-1]<mean30 and account.get_position(fund_tick) >0:
#                 account.close_all_positions(fund_tick)
#     except:
#         pass
