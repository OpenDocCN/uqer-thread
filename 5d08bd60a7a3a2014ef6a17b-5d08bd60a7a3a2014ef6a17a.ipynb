# %% [markdown]
# # 相对估值法

# %%
##1.相对估值法
sec=set_universe('A')
df=DataAPI.MktStockFactorsOneDayGet(tradeDate=u"20190531",secID=sec,field=u"ticker,PB,PE,PS,PCF,ROE,ROA",pandas="1")
df1=DataAPI.EquIndustryGet(secID=sec,industryVersionCD=u"010303",industry=u"",industryID=u"",industryID1=u"",industryID2=u"",industryID3=u"",intoDate=u"",field=u"ticker,industryName1",pandas="1")
df=df.merge(df1)
print df[df['industryName1']=='银行'].describe()
print df[df['industryName1']=='计算机'].describe()
print df[df['industryName1']=='食品饮料'].describe()
print df[df['industryName1']=='医药生物'].describe()
# Out:
#               PB         PE         PS         PCF        ROE        ROA
# count  53.000000  53.000000  53.000000   53.000000  53.000000  53.000000
# mean    0.928534   7.827826   2.493436   -0.241268   0.124617   0.008987
# std     0.350179   3.320029   0.993318   18.259592   0.022326   0.001495
# min     0.597400   5.227200   1.521900 -110.306100   0.085000   0.006500
# 25%     0.682000   5.932300   1.793100   -1.762000   0.110300   0.008000
# 50%     0.850000   6.274200   2.200300    1.171500   0.119300   0.008800
# 75%     0.981400   8.147400   2.624600    3.178000   0.135800   0.009700
# max     2.032800  20.081300   5.882000   30.564200   0.181700   0.012800
#               PB            PE          PS          PCF         ROE  \
# count  417.00000    417.000000  417.000000   417.000000  415.000000
# mean     4.15904     74.643823    5.942838    24.803913    0.049526
# std      3.63030    674.179497    6.724744   519.442644    0.151437
# ...
