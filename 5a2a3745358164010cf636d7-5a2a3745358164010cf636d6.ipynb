# %% [markdown]
# # 股票池

# %%
#汽车推荐
# universe = ['601965.XSHG','601799.XSHG','601689.XSHG','300100.XSHE','000581.XSHE','000030.XSHE']
#医药表现
# universe = ['000661.XSHE','000999.XSHE','002007.XSHE','300003.XSHE','600518.XSHG']
#房地产
# universe = ['000534.XSHE','000736.XSHE','000863.XSHE','002133.XSHE','002208.XSHE','600208.XSHG','600223.XSHG'， '600683.XSHG','600773.XSHG', '601588.XSHG']
#电信行业
#universe = ['600406.XSHG','000400.XSHE','002358.XSHE','300091.XSHE','600312.XSHG']
#化工行业
# universe = ['002165.XSHE','002206.XSHE','300121.XSHE','300218.XSHE','601678.XSHG']
#建材行业
# universe = ['000401.XSHE','000877.XSHE','002323.XSHE','300160.XSHE','600585.XSHG','601636.XSHG']
#建筑工程
# universe = ['002482.XSHE','002775.XSHE','300495.XSHE','300495.XSHE','601668.XSHG','601886.XSHG']
#军工行业
# universe = ['000065.XSHE','000881.XSHE','002013.XSHE','002366.XSHE','300455.XSHE','600038.XSHG',
#             '600416.XSHG','600522.XSHG','600565.XSHG','600893.XSHG','600967.XSHG']

#环保行业
# universe = ['000820.XSHE','000967.XSHE','300070.XSHE','300156.XSHE','300203.XSHE']
#电子行业
# universe = ['002245.XSHE','002384.XSHE','002449.XSHE','002636.XSHE','300007.XSHE','300007.XSHE','300373.XSHE','600183.XSHG','600261.XSHG']

# %%
#电气设备新能源
# universe = ['000400.XSHE','002358.XSHE','300091.XSHE','600312.XSHG','600406.XSHG']

# %%
#纺织服装
universe = ['002042.XSHE','002083.XSHE','002563.XSHE','601566.XSHG','603808.XSHG']

# %%
#社会服务业
# universe = ['000978.XSHE','300144.XSHE']

# %%
universe = ['601965.XSHG','601799.XSHG','601689.XSHG','300100.XSHE','000581.XSHE','000030.XSHE','000661.XSHE','000999.XSHE','002007.XSHE','300003.XSHE','600518.XSHG'
           ,'000534.XSHE','000736.XSHE','000863.XSHE','002133.XSHE','002208.XSHE','600208.XSHG','600223.XSHG', '600683.XSHG','600773.XSHG', '601588.XSHG','600406.XSHG','000400.XSHE','002358.XSHE','300091.XSHE','600312.XSHG','002165.XSHE','002206.XSHE','300121.XSHE','300218.XSHE','601678.XSHG','000401.XSHE','000877.XSHE','002323.XSHE','300160.XSHE','600585.XSHG','601636.XSHG'
            ,'002482.XSHE','002775.XSHE','300495.XSHE','300495.XSHE','601668.XSHG','601886.XSHG','000065.XSHE','000881.XSHE','002013.XSHE','002366.XSHE','300455.XSHE','600038.XSHG',
            '600416.XSHG','600522.XSHG','600565.XSHG','600893.XSHG','600967.XSHG','000978.XSHE','300144.XSHE','000820.XSHE','000967.XSHE','300070.XSHE','300156.XSHE','300203.XSHE',
            '002042.XSHE','002083.XSHE','002563.XSHE','601566.XSHG','603808.XSHG','002245.XSHE','002384.XSHE','002449.XSHE','002636.XSHE','300007.XSHE','300007.XSHE','300373.XSHE','600183.XSHG','600261.XSHG',
            '000400.XSHE','002358.XSHE','300091.XSHE','600312.XSHG','600406.XSHG'
           ]
