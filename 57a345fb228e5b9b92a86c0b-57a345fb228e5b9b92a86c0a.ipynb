# %% [markdown]
# #

# %% [raw]
# # Logistic Regression Classifier #logistic回归分类器
# from sklearn.linear_model import LogisticRegression
# import numpy as np
# import math
# from sklearn import preprocessing
# #Index=DataAPI.MktIdxdGet(tradeDate=u"",indexID=u"",ticker=u"000001",beginDate=u"20110101",endDate=u"20120115",field=u"preCloseIndex,openIndex,closeIndex",pandas="1")
# price=DataAPI.MktEqudGet(tradeDate=u"",secID=u"",ticker=u"600085",beginDate=u"20110104",endDate=u"20110615",isOpen="",field=u"preClosePrice,closePrice",pandas="1")
# factor=DataAPI.MktStockFactorsDateRangeGet(secID=u"",ticker=u"600085",beginDate=u"20110103",endDate=u"20110615",field=u"ticker,tradeDate,ROC20,RVI,Elder",pandas="1")
#
# z=factor[['ROC20','RVI','Elder']].values
# z_scaled=preprocessing.scale(z)
#
# ja=z.mean(axis=0)[0]
# jb=z.mean(axis=0)[1]
# jc=z.mean(axis=0)[2]
#
# ka=z.std(axis=0)[0]
# kb=z.std(axis=0)[1]
# kc=z.std(axis=0)[2]
#
# print(ja,ka)
# print(jb,kb)
# print(jc,kc)
#
# #z1=factor[['ROC6']].values
# #z2=factor[['RVI']].values
#
# x=price[['preClosePrice','closePrice']].values
# y=(price['preClosePrice']<price['closePrice']*0.99).values #隔夜差价与当日涨跌的关系
# #print(y)
# lr = LogisticRegression(C = 1.0)
# m=[]
# for i in z_scaled:
#  m.append([1.0,i[0],i[1],i[2]])
#
# #print(m)
#
# #print(m,y)
# lr.fit(m, y)
# a=lr.coef_.tolist()[0][0]
# b=lr.coef_.tolist()[0][1]
# c=lr.coef_.tolist()[0][2]
# d=lr.coef_.tolist()[0][3]
# #print(a,b,c,d)
#
#
#
# import quartz
# from CAL.PyCAL import *
# import pandas as pd
# start = '2012-01-06'                       # 回测起始时间
# end = '2016-07-09'
# universe=['600085.XSHG']
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate =1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# benchmark='600085.XSHG'
# from matplotlib import pylab
# cal=Calendar('China.SSE')
# commission = Commission(buycost=0.0008, sellcost=0.0018)
#
# mk=[]
# def initialize(account):
#    pass
#
#
# def handle_data(account):
#      factors=DataAPI.MktStockFactorsDateRangeGet(secID=u"",ticker=u"600148",beginDate=account.previous_date,\
# endDate=account.previous_date,field=u"ticker,tradeDate,ROC20,RVI,Elder",pandas="1")
#      #factors=DataAPI.MktStockFactorsOneDayGet(tradeDate=account.previous_date,ticker=u'',field=u"ticker,ROC6,RVI",pandas="1") ['ROC6','RVI']
#      ta=factors['ROC20'][0]
#      taa=(ta-ja)/(ka/math.sqrt(107))
#      tb=factors['RVI'][0]
#      tbb=(tb-jb)/(kb/math.sqrt(107))
#      tc=factors['Elder'][0]
#      tcc=(tc-jc)/(kc/math.sqrt(107))
#      s=a+b*taa+c*tbb+d*tcc
#      f=1/(1+math.exp(-s))
#      #print(f)
#      for s in account.universe:
#        if f>0.99:
#          order_pct_to(s,0.70)
#          refresh_rate=1
#        elif f<0.01:
#          order_pct_to(s,0.30)
#          refresh_rate=1
#
# bt,acct=quartz.backtest(start=start,
#             end=end,
#             benchmark=benchmark,
#             universe=universe,
#             capital_base=capital_base,
#             initialize=initialize,
#             handle_data=handle_data,
#             refresh_rate=refresh_rate)
#
# perf=quartz.perf_parse(bt,acct)
#
# out_keys=['annualized_return','volatility','information_ratio',
#     'sharpe','max_drawdown','alpha','beta']
#
# for k in out_keys:
#     print'%s:%s'%(k,perf[k])
#
# perf['cumulative_returns'].plot()
# perf['benchmark_cumulative_returns'].plot()
# pylab.legend(['current_strategy','600085'])
