# %% [markdown]
# #

# %% [raw]
# from CAL.PyCAL import *
# import numpy as np
# from pandas import DataFrame,Series
#
# start = '2016-01-01'                       # 回测起始时间
# end = '2016-9-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['300287.XSHE']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):   # 每个交易日的买入卖出指令
#     his=account.get_symbol_history('300287.XSHE', 5)
#     his=his['closePrice'][0]
#     for s in account.universe:
#         if his < 10.0:
#             order_pct_to(s,1.0)
#         elif his > 14.0:
#             order_pct_to(s,0)

# %%
from CAL.PyCAL import *
import numpy as np
from pandas import DataFrame

data=DataAPI.TradeCalGet(exchangeCD=u"XSHG",beginDate=u"20110801",endDate=u"20161027",field=['calendarDate','isMonthEnd'],pandas="1")
data=data[data['isMonthEnd'] == 1]
date_list=data['calendarDate'].values.tolist()
print date_list

cal=Calendar('China.SSE')
period=Period('-1B')
print period

data1=DataAPI.MktEqudGet(tradeDate=u"20161026",secID=set_universe('A'))
data2=data1.sort(columns='marketValue',ascending=True)
print data2.head()

flx=DataAPI.MktEqudGet(ticker=u"300287",beginDate=u"20160101",endDate=u"20161020",isOpen="",field=u"",pandas="1")
close=DataAPI.MktEqudAdjGet(tradeDate=u'20161027',ticker=u"300287",isOpen="",beginDate=u"",endDate=u"",field=u"preClosePrice",pandas="1")
print close,type(close),close['preClosePrice']
# Out:
# ['2011-08-31', '2011-09-30', '2011-10-31', '2011-11-30', '2011-12-30', '2012-01-31', '2012-02-29', '2012-03-30', '2012-04-27', '2012-05-31', '2012-06-29', '2012-07-31', '2012-08-31', '2012-09-28', '2012-10-31', '2012-11-30', '2012-12-31', '2013-01-31', '2013-02-28', '2013-03-29', '2013-04-26', '2013-05-31', '2013-06-28', '2013-07-31', '2013-08-30', '2013-09-30', '2013-10-31', '2013-11-29', '2013-12-31', '2014-01-30', '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-30', '2014-06-30', '2014-07-31', '2014-08-29', '2014-09-30', '2014-10-31', '2014-11-28', '2014-12-31', '2015-01-30', '2015-02-27', '2015-03-31', '2015-04-30', '2015-05-29', '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-30', '2015-11-30', '2015-12-31', '2016-01-29', '2016-02-29', '2016-03-31', '2016-04-29', '2016-05-31', '2016-06-30', '2016-07-29', '2016-08-31', '2016-09-30']
# -1B
#             secID  ticker secShortName exchangeCD   tradeDate  preClosePrice  \
# ...
