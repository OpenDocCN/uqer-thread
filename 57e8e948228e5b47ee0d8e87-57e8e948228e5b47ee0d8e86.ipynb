# %% [markdown]
# #

# %%
indexTicker = u'HSI'
bdate = '2006-04-01'
edate = '2006-12-31'
indexDf = DataAPI.MktIdxdGet(ticker=indexTicker,beginDate=bdate,endDate=edate,
                                 field=['ticker', 'tradeDate','closeIndex','CHGpct'],
                                 pandas="1")
indexDf
# Out:
#    ticker   tradeDate  closeIndex   CHGPct
# 0     HSI  2006-04-04    16100.09  0.00226
# 1     HSI  2006-04-21    16912.15 -0.00190
# 2     HSI  2006-06-12    15621.44 -0.00046
# 3     HSI  2006-06-14    15247.92  0.00089
# 4     HSI  2006-06-23    15808.81 -0.00113
# 5     HSI  2006-06-26    15804.81 -0.00025
# 6     HSI  2006-06-27    15774.70 -0.00191
# 7     HSI  2006-07-04    16368.98  0.00259
# 8     HSI  2006-07-07    16459.78  0.00114
# 9     HSI  2006-07-18    16043.94 -0.00130
# 10    HSI  2006-07-21    16464.18 -0.00051
# 11    HSI  2006-07-24    16480.59  0.00100
# 12    HSI  2006-07-26    16617.24  0.00201
# 13    HSI  2006-07-28    16955.04  0.00226
# 14    HSI  2006-07-31    16971.34  0.00096
# 15    HSI  2006-08-03    17048.42  0.00092
# 16    HSI  2006-08-11    17249.95  0.00161
# 17    HSI  2006-08-14    17290.01  0.00232
# 18    HSI  2006-08-15    17274.07 -0.00092
# 19    HSI  2006-08-18    17330.70 -0.00244
# 20    HSI  2006-08-28    16922.29 -0.00196
# ...
