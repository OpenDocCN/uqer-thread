# %% [markdown]
# # 自己做-策略1

# %% [raw]
# import talib
# import pandas as pd
# import numpy as np
#
# ### 策略初始化函数
# universe = ['RBM0']                  # 策略交易的期货合约，此处选择螺纹钢主力合约
# start = "2016-01-01"                 # 回测开始时间
# end   = "2016-02-01"                 # 回测结束时间
# capital_base = 1000000               # 初始可用资金
# refresh_rate = 1                     # 算法调用周期
# freq = 'd'                           # 算法调用频率：m-> 分钟；d-> 日；
#
# def Moving_Average(futlist):
#     sum=0
#     for i in futlist:
#         sum=sum+i
#     return round(sum/len(futlist),2)
#
# def initialize(futures_account):
#     pass
#
# def handle_data(futures_account):
#     future_his=get_symbol_history(symbol=universe, field=u'closePrice', time_range=5)
#     MA05=Moving_Average(future_his)
