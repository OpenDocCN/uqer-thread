# %% [markdown]
# # 崔夫人也能写代码之Test2

# %%
print "hello world"
# Out:
# hello world

# %%
a = 3+2
print a
# Out:
# 5

# %%
a = 3+2
b = a+5
c = a+b
print c
# Out:
# 15

# %% [raw]
# start = '2015-01-01'                       # 回测起始时间
# end = '2015-06-30'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['600683.XSHG', '000002.XSHE']         # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# refresh_rate = 1                           # 调仓频率，即每refresh_rate个交易日执行一次handle_data函数
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     for stock in account.universe:
#         order(stock,5000)
