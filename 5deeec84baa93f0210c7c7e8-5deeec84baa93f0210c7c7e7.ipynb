# %% [markdown]
# # data-ag1506

# %%
DataAPI.MktFutdGet(secID=u"",ticker=u"ag1506",tradeDate=u"",beginDate=u"",endDate=u"",exchangeCD="",field=u"",pandas="1")
# Out:
#            secID  ticker exchangeCD secShortName   tradeDate contractObject  \
# 0    AG1506.XSGE  ag1506       XSGE      沪白银1506  2014-06-17             AG
# 1    AG1506.XSGE  ag1506       XSGE      沪白银1506  2014-06-18             AG
# 2    AG1506.XSGE  ag1506       XSGE      沪白银1506  2014-06-19             AG
# 3    AG1506.XSGE  ag1506       XSGE      沪白银1506  2014-06-20             AG
# 4    AG1506.XSGE  ag1506       XSGE      沪白银1506  2014-06-23             AG
# 5    AG1506.XSGE  ag1506       XSGE      沪白银1506  2014-06-24             AG
# 6    AG1506.XSGE  ag1506       XSGE      沪白银1506  2014-06-25             AG
# 7    AG1506.XSGE  ag1506       XSGE      沪白银1506  2014-06-26             AG
# 8    AG1506.XSGE  ag1506       XSGE      沪白银1506  2014-06-27             AG
# 9    AG1506.XSGE  ag1506       XSGE      沪白银1506  2014-06-30             AG
# 10   AG1506.XSGE  ag1506       XSGE      沪白银1506  2014-07-01             AG
# ...
