# %% [markdown]
# # 大盘股技术惯性研究

# %% [raw]
# import pandas as pd
#
# start = '2015-01-01'                       # 回测开始时间
# end = '2017-06-01'                         # 回测结束时间
# benchmark = "SH50"                        # 策略对标标的
# universe = set_universe('HS300')
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# commission = Commission(buycost=0.0003, sellcost=0.0013, unit='perValue')
# max_history_window = 100                 #设定调取历史价格区间最大为100个交易日
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     data = DataAPI.MktStockFactorsOneDayGet(tradeDate=account.previous_date,secID=universe,field=u"secID,tradeDate,LCAP",pandas="1")
#     data = data.set_index('secID')
#     data = data.dropna()
#     data = data.sort('LCAP')   # 市值排序
#     # 取流通市值最大的30只股票
#     univ = list(data.index)[-30:-1]
#
#     hist_ma20 = account.get_attribute_history('closePrice', 20)      #获取过去20个交易日的收盘价
#     hist_ma40 = account.get_attribute_history('closePrice', 40)     #获取过去40个交易日的收盘价
#
#     for s in account.universe:
#         MA5 = hist_ma20[s].mean()                                    #计算过去20个交易日及过去40个交易日的均价
#         MA10 = hist_ma40[s].mean()
#         if s in account.avail_security_position:
#             if s not in univ or MA5<MA10:
#                 order_pct_to(s,0)
#
#         #买股票，每个股票仓位设置为5%
#         if s in univ and s not in account.security_position and MA5>MA10:
#             if len(account.security_position) >= 20:
#                 break
#             order_pct_to(s, 0.05)
