# %% [markdown]
# #

# %%
universe0 = set_universe("A")

r_d = DataAPI.EquGet(equTypeCD='A', secID='', ticker='', listStatusCD='', field='', pandas='1')
r_d = r_d[r_d["listStatusCD"]=="L"]
stk = r_d["secID"].tolist()

for i in range(len(stk)):
    if stk[i] not in universe0:
        print(stk[i])

r_d[r_d["secID"]=="X15030.XSHG"]
# Out:
# X15030.XSHG
#             secID  ticker exchangeCD  ListSectorCD ListSector transCurrCD  \
# 3067  X15030.XSHG  603393       XSHG             1         主板         CNY
#
#      secShortName    secFullName listStatusCD    listDate     ...       \
# 3067         新天然气  新疆鑫泰天然气股份有限公司            L  2016-09-12     ...
#
#      equType exCountryCD partyID  totalShares  nonrestFloatShares  \
# 3067    沪深A股         CHN  923379  160000000.0          40000000.0
#
#       nonrestfloatA                                officeAddr  \
# 3067     40000000.0  新疆维吾尔自治区乌鲁木齐市高新区阿勒泰路蜘蛛山巷179号楼兰新城25栋1层商铺2
#
#                                          primeOperating     endDate  \
# 3067  天然气(二类1项)的批发、零售(有效期至2015年12月30日)。对城市供热行业的投资；燃气...  2016-06-30
#
#         TShEquity
# 3067  641938400.0
#
# [1 rows x 22 columns]
