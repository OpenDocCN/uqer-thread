# %% [markdown]
# #

# %%
stk = '000050'
today = '2016-08-30'
tradeday = '20160829'
factors =['DIFF','DEA','MACD']

oneday=DataAPI.MktStockFactorsOneDayGet(tradeDate=tradeday, ticker=stk, field=[u'secID,ticker,secShortName,tradeDate']+factors, pandas='1')
print oneday
multi = DataAPI.MktStockFactorsDateRangeGet(ticker=stk,beginDate=tradeday,endDate=tradeday,field=[u"ticker,tradeDate,secShortName"]+factors,pandas="1")
print multi
# Out:
#          secID  ticker   tradeDate    DIFF     DEA    MACD
# 0  000050.XSHE  000050  2016-08-29 -0.4288 -0.4537  0.0498
#    ticker   tradeDate    DIFF     DEA    MACD
# 0  000050  2016-08-29 -0.4288 -0.4537  0.0498
