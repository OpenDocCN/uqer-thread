# %% [markdown]
# # 练习-1

# %% [raw]
# start='2015-01-01'
# end='2015-08-15'
# benchmark="HS300"
# capital_base=1000000
# universe=['002095.XSHE','300238.XSHE']
# refresh_rate=1
#
# def initialize(account):
#     return
# def handle_data(account):
#     hist=account.get_attribute_history('closePrice',10)
#
#     for s in account.universe:
#         if hist[s][-1]/hist[s][0]-1>0.01 and s not in account.valid_secpos:
#             order(s,1000)
#         elif hist[s][-1]/hist[s][0]-1<0 and s in account.valid_secpos:
#             order_to(s,0)

# %%
bt[:10]
# Out:
#    tradeDate        cash                             security_position  \
# 0 2015-01-19  940156.216  {u'300238.XSHE': 1000, u'002095.XSHE': 1000}
# 1 2015-01-20  940156.216  {u'300238.XSHE': 1000, u'002095.XSHE': 1000}
# 2 2015-01-21  940156.216  {u'300238.XSHE': 1000, u'002095.XSHE': 1000}
# 3 2015-01-22  940156.216  {u'300238.XSHE': 1000, u'002095.XSHE': 1000}
# 4 2015-01-23  940156.216  {u'300238.XSHE': 1000, u'002095.XSHE': 1000}
# 5 2015-01-26  940156.216  {u'300238.XSHE': 1000, u'002095.XSHE': 1000}
# 6 2015-01-27  940156.216  {u'300238.XSHE': 1000, u'002095.XSHE': 1000}
# 7 2015-01-28  940156.216  {u'300238.XSHE': 1000, u'002095.XSHE': 1000}
# 8 2015-01-29  940156.216  {u'300238.XSHE': 1000, u'002095.XSHE': 1000}
# 9 2015-01-30  940156.216  {u'300238.XSHE': 1000, u'002095.XSHE': 1000}
#
#    portfolio_value  benchmark_return  \
# 0      1002978.216         -0.077023
# 1      1008498.216          0.012241
# 2      1011710.216          0.044950
# 3      1011539.216          0.005278
# 4      1010882.216          0.001155
# 5      1011363.216          0.010149
# 6      1012355.216         -0.009160
# 7      1010006.216         -0.013877
# 8      1014637.216         -0.012348
# 9      1009906.216         -0.013614
#
#                                              blotter
# 0  [Order(order_time: 2015-01-19, symbol: 300238....
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8                                                 []
# 9                                                 []

# %%
account.get_symbol_history('002094.XSHE',10)
