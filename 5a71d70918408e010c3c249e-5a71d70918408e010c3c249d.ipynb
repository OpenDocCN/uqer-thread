# %% [markdown]
# # turnover

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
dt=DataAPI.MktIdxdGet(tradeDate=u"",indexID=u"",ticker=u"000001",beginDate=u"20170131",endDate=u"20180131",exchangeCD=u"XSHE,XSHG",field=u"",pandas="1")
dt[['tradeDate','turnoverVol','turnoverValue']]
# Out:
#       tradeDate  turnoverVol  turnoverValue
# 0    2017-02-03   9222473600   1.080237e+11
# 1    2017-02-06  12719828300   1.500677e+11
# 2    2017-02-07  12833744200   1.525591e+11
# 3    2017-02-08  14492018700   1.708541e+11
# 4    2017-02-09  19164032700   2.097232e+11
# 5    2017-02-10  23934891300   2.457722e+11
# 6    2017-02-13  22019150800   2.361588e+11
# 7    2017-02-14  18879808800   2.042538e+11
# 8    2017-02-15  24150770600   2.579652e+11
# 9    2017-02-16  21695594200   2.265876e+11
# 10   2017-02-17  22622817700   2.485728e+11
# 11   2017-02-20  23215209600   2.502761e+11
# 12   2017-02-21  21167306600   2.335512e+11
# 13   2017-02-22  20745377600   2.348153e+11
# 14   2017-02-23  20917980000   2.368226e+11
# 15   2017-02-24  18640636200   2.138390e+11
# 16   2017-02-27  18258107100   2.113957e+11
# 17   2017-02-28  15124431800   1.860193e+11
# 18   2017-03-01  19067755000   2.259410e+11
# 19   2017-03-02  18121507600   2.230440e+11
# ...

# %%
x=dt['turnoverVol']
y=dt['turnoverValue']
plt.plot(y)

# %%
plt.plot(x)
