# %% [markdown]
# # 五日均线策略

# %% [raw]
# from CAL.PyCAL import Date
# from CAL.PyCAL import Calendar
# from CAL.PyCAL import BizDayConvention
#
# start = '2013-01-01'                       # 回测起始时间
# end = '2018-01-01'                         # 回测结束时间
# universe = set_universe('HS300')        # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):
#     pass
#
# def handle_data(context):
#     account = context.get_account('fantasy_account')
#     universe = context.get_universe(exclude_halt=True)
#     buylist=[]
#     selllist=[]
# #时间以及其格式
#     currentdate = Date.fromDateTime(context.current_date)
#     cal = Calendar('China.SSE') #上海证券交易所交易日历
#     yesterdate = cal.advanceDate(currentdate, '-1B',BizDayConvention.Preceding)
#     currentdate = currentdate.strftime('%y/%m/%d')
#     yesterdate = yesterdate.strftime('%y/%m/%d')
# #调用数据库
#     currentdate_data = DataAPI.MktStockFactorsOneDayGet(tradeDate=currentdate,secID=universe,ticker=u"",field=['MA5','MA10','NetProfitGrowRate'],pandas="1")
#     yesterdate_data =DataAPI.MktStockFactorsOneDayGet(tradeDate=yesterdate,secID=list(currentdate_data.index),ticker=u"",field=['MA5','MA10','NetProfitGrowRate'],pandas="1")
#     currentdate_data.set_index('secID',inplace=True)
#     yesterdate_data.set_index('secID', inplace=True)
#     currentdate_data = currentdate_data[currentdate_data.NetProfitGrowRate>=1.0].dropna() #选取净利润增长率大于等于1的股票并删除na项
#     currentdate_data = currentdate_data.sort(columns='NetProfitGrowRate',ascending=False)
#     currentdate_data = currentdate_data.head(20)
#
#     for stock in list(currentdate_date.index):
#         if (currentdate_data['MA5'][stock]>currentdate_data['MA10'])&(yesterdate_data['MA5'][stock]<yersterdate_data['MA10'][stock]):
#             buylist.append(stock)
#
#     for stock in list(currentdate_data.index):
#         if (currentdate_data['MA5'][stock]<=currentdate_data['MA10'])&(yesterdate_data['MA5'][stock]>=yersterdate_data['MA10'][stock]):
#             selllist.append(stock)
#
#
#     for stk in buylist:
#         account.order(stk, 100)
#     for stk in selllist:
#         account.order(stk,0)
