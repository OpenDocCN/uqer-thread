# %% [markdown]
# # MACD平滑异同移动平均线方法

# %% [raw]
# from CAL.PyCAL import Date
# from CAL.PyCAL import Calendar
# from CAL.PyCAL import BizDayConvention
# start = '2022-01-01'                       # 回测起始时间
# end = '2022-07-25'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')  # 证券池，支持股票和基金
# be_overdue = ["688012.XSHG","688008.XSHG","688169.XSHG","688396.XSHG","300077.XSHE","600958.XSHG","300450.XSHE","601211.XSHG","000166.XSHE","688981.XSHG","300888.XSHE"]
# for i in be_overdue:
#     if i in universe:
#         universe.remove(i)
# # universe = ["002594.XSHE"]
#
#
# capital_base = 1000000                     # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                          # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# commission = Commission(buycost=0.0003, sellcost=0.002, unit='perValue')
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     buylist=[]
#     selist=[]
#     dt = Date.fromDateTime(account.current_date)
#     cal = Calendar('China.SSE')
#     lastTDay = cal.advanceDate(dt,'-1B',BizDayConvention.Preceding)
#     current_date=dt.strftime('%Y%m%d')
#     last_date=lastTDay.strftime('%Y%m%d')
#
#     getData_current_date=DataAPI.MktStockFactorsOneDayGet(tradeDate=current_date,secID=account.universe,field=['secID','DEA','DIFF','NetProfitGrowRate'],pandas="1")
#     getData_current_date.set_index('secID',inplace=True)
#     getData_current_date=getData_current_date[getData_current_date.NetProfitGrowRate>=1.0].dropna()
#     getData_current_date=getData_current_date.sort(columns='NetProfitGrowRate',ascending=False)
#     getData_current_date=getData_current_date.head(20)
#     getData_last_date=DataAPI.MktStockFactorsOneDayGet(tradeDate=last_date,secID=list(getData_current_date.index),field=['secID','DEA','DIFF','NetProfitGrowRate'],pandas="1")
#     getData_last_date.set_index('secID',inplace=True)
#
#     for stock in list(getData_current_date.index):
#         if((getData_current_date['DIFF'][stock]>getData_current_date['DEA'][stock])&(getData_last_date['DIFF'][stock]<=getData_last_date['DEA'][stock])):
#             buylist.append(stock)
#
#     for stock in list(getData_current_date.index):
#         if((getData_current_date['DIFF'][stock]<=getData_current_date['DEA'][stock])&(getData_last_date['DIFF'][stock]>getData_last_date['DEA'][stock])):
#             selist.append(stock)
#
#
#     for stock in selist:  #股票卖出
#         if(stock in account.security_position):
#             account.order_to(stock,0)
#         else:
#             pass
#
#     for stock in buylist:
#         if(stock in account.security_position):
#             pass
#         else:   #股票买入
#             if(len(buylist)>=5):
#                 account.order(stock,account.cash/account.reference_price[stock]/len(buylist))
#             else:
#                 account.order(stock,account.cash/account.reference_price[stock]/5)
