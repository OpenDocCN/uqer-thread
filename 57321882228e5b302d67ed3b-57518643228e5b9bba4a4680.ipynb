# %% [markdown]
# # 这个是不是回测系统的bug？

# %% [markdown]
# 用户实现 handle_data 函数，函数中设置策略每个调仓周期的下单逻辑，是策略的核心部分，该函数每个调仓周期都会调用一次；但是下面的代码从2015-02-02直接就到2015-02-16了并不是调仓周期都调用一次

# %% [raw]
# from CAL.PyCAL import *
# #from datetime import datetime
# start = '2015-02-01'                       # 回测起始时间
# end = '2015-03-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['000001.XSHE', '600000.XSHG']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，由于freq = 'd'，时间间隔的单位为交易日
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     cal = Calendar('China.SSE')
#     date = account.current_date
#     print str(date)+"应该是一天出现一次吧，怎么2015-02-02直接就到2015-02-16了，中间没有了10天"
#
# #出现问题的代码，不加下面代码就不会出现问题
#     data_close = account.get_attribute_history('closePrice', 10)
#
#
#     for stock in account.universe:
#         order(stock,100)
