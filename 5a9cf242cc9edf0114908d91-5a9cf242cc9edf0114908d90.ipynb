# %% [markdown]
# # Notebook

# %% [raw]
# import pandas as pd
# import numpy as np
# from CAL.PyCAL import *
# from datetime import datetime
# import functools
# from pandas import DataFrame
# import talib as ta
#
# start='20150101'
# end='20180101'
# benchmark='HS300'
# capital_base=1200000000
# freq='d'
# refresh_rate=15
# universe=set_universe('A')
# commission = Commission(buycost=0.0003, sellcost=0.0013, unit='perValue')##手续费，卖出印花税，10%%
# max_history_window = 100
#
# #构建日期函数
# date=DataAPI.TradeCalGet(exchangeCD=u"XSHG,XSHE",beginDate=u"20150101",endDate=u"20180101",field=u"calendarDate,isOpen",pandas="1")
# date=date[date['isOpen']==1]
# date=date['calendarDate']
# datelist=date.tolist()#结果['2007-08-01', '2007-08-02', '2007-08-03',
# datelist=[v.replace('-', '') for v in datelist]#把日期中间的'-'去掉
#
# cal = Calendar('China.SSE')
# period = Period('-1B')
#
# def initialize(account):
#     account.has_buy = {}
#     account.step_money = 100000.0
#
# def handle_data(account):
#     currentdate=account.current_date
#     currentdate=Date.fromDateTime(account.current_date)
#     lastdate=cal.advanceDate(currentdate,period)
#     lastdate=lastdate.toDateTime()
#
#     #factordata_body=[]
#     if lastdate.strftime('%Y%m%d') in datelist:
#
#     #先取因子
#         factor_name = ['ROE5']#5年权益回报率（Five-year average return on equity）
#         factordata2     =DataAPI.FdmtISQPITGet(ticker=u"",secID=universe,endDate="",beginDate="",beginYear=u"2012",endYear=u"2017",reportType=u"Q4",isNew=u"1",isCalc=u"1",field=['endDate','secID','NIncome'],pandas="1")##取12年净值
#         grouped=factordata2['NIncome'].groupby(factordata2['secID'])#分组
#         factordata2=grouped.mean()#求分组后均值
#         factordata2= DataFrame(factordata2)#转化为dataframe格式
#         #factordata2=factordata2.groupby('secID').mean()#替换上面3个步骤
#         factordata_NIncome=factordata2[factordata2.NIncome>1e+09]##净值大于1亿
#         factordata_secID=factordata_NIncome.index
#         factordata      =DataAPI.MktStockFactorsOneDayGet(tradeDate=lastdate.strftime('%Y%m%d'),secID=factordata_secID,ticker=u"",field=['secID','tradeDate'] + factor_name,pandas="1")#取因子
#         factordata=factordata.dropna()
#         factor_data=factordata.sort_index(by='ROE5',ascending=False)#降序排序
#         dealdata=factor_data.head(20)#取前20只
#         dealdata_secID=dealdata['secID']
#         buylist=dealdata_secID.tolist()
#
#     #没钱了
#     if account.cash < account.step_money :
#         return
#
#     c_month = account.current_date.strftime("%Y-%m")
#     #本月买过了
#     if c_month in account.has_buy :
#         return
#     prices = account.reference_price
#     for stock in account.buylist:
#         try :
#             buy_num = int(account.step_money / (prices[stock] * 100)) * 100
#         except :
#             return
#         order(stock, buy_num)
#         account.has_buy[c_month] = 1
