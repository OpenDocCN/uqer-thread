# %% [markdown]
# # 简单的外部数据复制000803三百波动

# %% [markdown]
#     本文对000803沪深300波动指数进行回测，使用从WIND计算的权重外部文档，实现指数跟踪。

# %%
# -*- coding:utf-8 -*-
import numpy as np
import pandas as pd

data=pd.read_csv('weight/WEIGHT.csv',index_col='date')
data.stockcode=normalize_code(list(data.stockcode),target_type = 'secID')

# %% [raw]
# start = '2010-02-01'                       # 回测起始时间
# end = '2019-03-01'                         # 回测结束时间
# benchmark = '000803.ZICN'                  # 策略参考标准
# #benchmark = 'HS300'
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# universe = DynamicUniverse('HS300')         # 动态证券池，策略框架会根据实际情况，调整当天股票池的内容
# #universe = DynamicUniverse('000300.ZICN')
# #universe=set_universe('000001.ZICN') + set_universe('399001.ZICN')
# capital_base = 10000000                     # 起始资金
# refresh_rate = Monthly(1)                   # 调仓频率，即每 refresh_rate 个交易日执行一次 handle_data() 函数
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     previous_date = context.previous_date.strftime('%Y-%m-%d')
#
#     # 获取前一个交易日的因子数据集
#     hist = data.loc[previous_date]
#     target_position = hist['stockcode']
#     hist.set_index(['stockcode'],inplace=True) #将股票代码设为索引
#
#     # 获取当前账户信息
#     account = context.get_account('fantasy_account')
#     current_position = account.get_positions(exclude_halt=True)
#
#     # 卖出当前持有，但目标持仓没有的部分
#     for stock in set(current_position).difference(target_position):
#         account.order_to(stock, 0)
#
#     # 根据目标持仓权重，逐一委托下单
#     for stock in target_position:
#         if stock not in current_position:
#             wei=float(hist.loc[stock][['weight']].values[0])
#         #    stockID=stockid.secID.values[0]
#             account.order_pct(stock,wei)
#
# '''
#     #根据目标持仓权重，逐一委托下单
#     for stock in target_position:
#         if stock not in current_position:
#             wei=float(hist.loc[stock][['weight']].values[0])
#             stockid=DataAPI.SecIDGet(ticker=str(stock))
#             if len(stockid)==1:
#                 stockID=stockid.secID.values[0]
#             else:
#                 for i in range(len(stockid)):
#                     if stockid.secID[i].split('.')[1]==('XSHE'or'XSHG'):
#                         stockID=stockid.secID[i]
#             account.order_pct(stockID,wei)
#  '''
