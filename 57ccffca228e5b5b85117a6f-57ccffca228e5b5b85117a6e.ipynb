# %% [markdown]
# #

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#画直线
X=np.linspace(-5,5,300,endpoint=True)   #生成一个数组作为X轴数据，起点0，终点100，分成300等分
Y=50*X+50
plt.plot(X,Y)
#画抛物线
Y2=5*X*X
plt.plot(X,Y2)
Y3=np.power(X,3)
plt.plot(X,Y3)
plt.show()
