# %% [markdown]
# # 39 事件驱动策略示例——盈利预增(转编)

# %%
"""
事件驱动策略示例——盈利预增
https://uqer.datayes.com/v3/community/share/54d972c1f9f06c276f651a72

策略思路
从DataAPI中获取沪深300成分股的盈利预增事件数据
每个交易日，将昨天发布盈利预增事件公司加入买入列表
根据调仓限制和买入列表进行调仓
调仓限制
(1) 股票持有不超过50只
(2) 一旦买入，持有40个交易日
(3) 仅当持有数量低于50只时才买入股票，补满50只
"""

"""
测试未全完成...
"""

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt
import CAL.PyCAL as C_cal # CAL provides classes and functions dealing with date, time, and calendars. 
from functools import partial

sns.set_style('white')
pd.set_option('display.width', 200)
cal = C_cal.Calendar('China.SSE')

# %%
"""
函数的partial应用
　　函数在执行时，要带上所有必要的参数进行调用。但是，有时参数可以在函数被调用之前提前获知。这种情况下，一个函数有一个或多个参数预先就能用上，以便函数能用更少的参数进行调用
"""
get_data = partial(DataAPI.FdmtEfGet, forecastType = 22, field = ['secID', 'publishDate'])  # forecastType 22: 盈利预增；返回函数指针get_data；

data_ef = []
for stock in set_universe('HS300'):
    try:
        if len(data_ef):
            data_ef = data_ef.append(get_data(secID = stock))
        else:
            data_ef = get_data(secID = stock)
    except:
        pass
    
data_ef['publishDate'] = pd.to_datetime(data_ef['publishDate'])
data_ef = data_ef.sort(columns = 'publishDate')
data_ef = data_ef[data_ef.publishDate >= dt.datetime(2018, 1, 1)]

data_ef.head().append(data_ef.tail())
# Out:
#          secID publishDate
# 1  601828.XSHG  2018-01-02
# 0  002925.XSHE  2018-01-03
# 6  300296.XSHE  2018-01-05
# 0  600705.XSHG  2018-01-05
# 3  300433.XSHE  2018-01-09
# 0  601319.XSHG  2019-07-31
# 0  601601.XSHG  2019-07-31
# 0  000858.XSHE  2019-08-06
# 0  601088.XSHG  2019-08-10
# 0  002236.XSHE  2019-08-17

# %% [raw]
# start = '2018-08-01' # 开始日期
# end = (dt.datetime.today() - dt.timedelta(days=1)).strftime('%Y-%m-%d') # 截止日期
# benchmark = 'HS300' # 策略参考标准
# universe = set_universe('HS300') # 证券池，支持股票和基金
# capital_base = 100000 # 起始资金
# freq = 'd' # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1 # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# longest_history = 1
# max_t   = 40      # 持仓时间
# max_n   = 50      # 持仓数量
#
# def initialize(account):
#     account.hold_period = {}
