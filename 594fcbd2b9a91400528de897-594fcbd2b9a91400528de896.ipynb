# %% [markdown]
# # Notebook0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('figure',figsize=(16,8))

# %%
universe=set_universe(IndSW.YinHangL1)
df=DataAPI.MktEqudGet(secID=universe,beginDate='20170101',endDate='20170625',field=['ticker','tradeDate','chgPct'])
df=df.set_index(df['tradeDate'])
dat=df[df['ticker']=='601288']
dat1=df[df['ticker']=='601328']
dat2=df[df['ticker']=='601988']
dat3=df[df['ticker']=='601998']
dat4=df[df['ticker']=='601398']
dat5=df[df['ticker']=='601939']
dat6=df[df['ticker']=='601166']
dat7=df[df['ticker']=='000001']
dat8=df[df['ticker']=='600036']
dat9=df[df['ticker']=='601818']
dat10=df[df['ticker']=='600015']
dat11=df[df['ticker']=='600016']

asset=dat['chgPct']
asset1=dat1['chgPct']
asset2=dat2['chgPct']
asset3=dat3['chgPct']
asset4=dat4['chgPct']
asset5=dat5['chgPct']
asset6=dat6['chgPct']
asset7=dat7['chgPct']
asset8=dat8['chgPct']
asset9=dat9['chgPct']
asset10=dat10['chgPct']
asset11=dat11['chgPct']

data=pd.DataFrame({'601288': asset,
                  '601328': asset1,
                  '601988': asset2,
                  '601998': asset3,
                  '601398': asset4,
                  '601939': asset5,
                  '601166': asset6,
                  '000001': asset7,
                  '600036': asset8,
                  '601818': asset9,
                  '600015': asset10,
                  '600016': asset11})
data.tail()
# Out:
#             000001  600015  600016  600036  601166  601288  601328  601398  \
# tradeDate
# 2017-06-19  0.0122  0.0009  0.0087  0.0168  0.0076 -0.0058  0.0033 -0.0079
# 2017-06-20 -0.0011 -0.0019  0.0000 -0.0038 -0.0019  0.0117  0.0033  0.0080
# 2017-06-21  0.0033  0.0019  0.0000  0.0109  0.0038  0.0000  0.0049  0.0020
# 2017-06-22  0.0109  0.0187  0.0049  0.0666  0.0157  0.0086  0.0049  0.0099
# 2017-06-23  0.0000  0.0092 -0.0037  0.0132  0.0068  0.0029  0.0033  0.0078
#
#             601818  601939  601988  601998
# tradeDate
# 2017-06-19  0.0051  0.0016 -0.0028  0.0065
# 2017-06-20  0.0000  0.0065  0.0028 -0.0049
# 2017-06-21  0.0025  0.0032  0.0000  0.0016
# 2017-06-22  0.0076  0.0129  0.0083  0.0065
# 2017-06-23  0.0025  0.0080  0.0055  0.0065

# %%
(1+data).cumprod().plot();

# %%
corr = data.corr()
corr
# Out:
#           000001    600015    600016    600036    601166    601288    601328  \
# 000001  1.000000  0.676472  0.716926  0.636083  0.750648  0.379689  0.570761
# 600015  0.676472  1.000000  0.697335  0.704593  0.778723  0.474557  0.690227
# 600016  0.716926  0.697335  1.000000  0.628116  0.808646  0.395474  0.649190
# 600036  0.636083  0.704593  0.628116  1.000000  0.770839  0.426619  0.578776
# 601166  0.750648  0.778723  0.808646  0.770839  1.000000  0.456082  0.674235
# 601288  0.379689  0.474557  0.395474  0.426619  0.456082  1.000000  0.651771
# 601328  0.570761  0.690227  0.649190  0.578776  0.674235  0.651771  1.000000
# 601398  0.405779  0.510954  0.413128  0.569489  0.518795  0.745884  0.686341
# 601818  0.727432  0.687473  0.664209  0.611509  0.738862  0.455295  0.754784
# 601939  0.577079  0.656432  0.542051  0.624509  0.637704  0.660458  0.718077
# 601988  0.579657  0.631961  0.598132  0.607907  0.656635  0.761315  0.802323
# ...

# %%
plt.imshow(corr, cmap='hot', interpolation='none')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns)
plt.yticks(range(len(corr)), corr.columns);

# %%
plt.scatter(data.mean(), data.std())
plt.xlabel('Expected returns')
plt.ylabel('Risk')
for label, x, y in zip(data.columns, data.mean(), data.std()):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (20, -20),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.5),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

# %%
pd.scatter_matrix(data, diagonal='kde');
