# %% [markdown]
# #

# %% [raw]
# import pandas as pd
# import numpy as np
# from CAL.PyCAL import *
#
# start = '2013-08-20'
# end = u''
# benchmark ='HS300'
#
# universe = ['510300.XSHG','510500.XSHG','511880.XSHG','150035.XSHE','160216.XSHE']
# capital_base = 10000
# refresh_rate = 1
# commission = Commission(0.0, 0.0)
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#
#     cal = Calendar('China.SSE')
#     dt = Date.fromDateTime(account.current_date)
#     last_day_str = cal.advanceDate(dt,'-1B',BizDayConvention.Preceding).strftime("%Y-%m-%d")  # 获取回测当日的前1天日期
#     last_20day_str = cal.advanceDate(dt,'-20B',BizDayConvention.Preceding).strftime("%Y-%m-%d") # 获取回测当日的前21天日期
#     max_signal = -1.0
#     max_sec = ""
#     print "current date ",account.current_date
#     for sec_id in universe:
#         info = DataAPI.MktFunddGet(secID=sec_id,beginDate=last_20day_str,endDate=last_day_str,field=u"tradeDate,closePrice,accumAdjFactor")
#         info['realClosePrice'] = info['closePrice']*info['accumAdjFactor']
#         if len(info) == 0:
#             continue
#         signal = (info['realClosePrice'].iloc[-1]-info['realClosePrice'].iloc[0])/info['realClosePrice'].iloc[0]
#         print "sec ",sec_id
#         print "signal ",signal
#         if signal > max_signal:
#             max_sec = sec_id
#             max_signal = signal
#     print "max signal ",max_signal
#     print "max sec ",max_sec
#     for sec_id in universe:
#         if sec_id not in account.referencePrice or account.referencePrice[sec_id]<=0 :
#             continue
#         if sec_id != max_sec:
#             order_pct_to(sec_id,0)
#         else:
#             if max_signal >0:
#                 order_pct_to(sec_id,0.95)
#             else:
#                 print "zero "
#                 order_pct_to(sec_id,0)
