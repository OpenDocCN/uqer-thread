# %% [markdown]
# #

# %% [markdown]
# ## 按因子选股 v1.0

# %% [markdown]
# ## 这是按一个行业的所有股票，然后按每股收益排序选择前5的买入，然后做一个长线，但是呢，发现代码运行过程中存在一个问题就是买入命令不能使用order_pct，不知道为什么报错了。。。

# %% [raw]
# start = '2014-05-07'                       # 回测起始时间
# end = '2016-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('A')  # 证券池，支持股票和基金
# capital_base = 10000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# import math
# import pandas as pd
# def IndustryGet(bgday,IndustryName='银行'):
#     bob=DataAPI.EquIndustryGet(industryVersionCD=u"010303",industry=u"",secID=u"",ticker=u"",intoDate=u"",field=u"secID,industryName2,secShortName",pandas="1")
#     bobo=bob[bob.industryName2==IndustryName].secID
#     c={'symbol':[],'mgsy':[]}
#     for tic in bobo:
#         if tic not in c['symbol']:
#             c['symbol'].append(tic)
#     ##print len(c['symbol'])
#     mgsytmp=DataAPI.MktStockFactorsOneDayGet(tradeDate=bgday,secID=c['symbol'],ticker=u"",field=u"EPS",pandas="1")
#     for tic in mgsytmp.EPS:
#         if math.isnan(tic)==True:
#             c['mgsy'].append(0)
#         else:
#             c['mgsy'].append(tic)
#     ##print len(c['mgsy'])
#     ##print len(c['symbol'])
#     c['symbol']=c['symbol'][:len(c['mgsy'])]
#     mgsyfl=pd.DataFrame(c).sort(columns='mgsy',ascending=False)
#     mgsylist=mgsyfl['symbol'].tolist()
#     return mgsylist
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     buylist=IndustryGet(start.replace('-',''),'房地产开发')
#     buylist=buylist[0:5]
#     for tic in buylist:
#         order(tic,100000)
#         ##order_pct(tic,0.2)

# %% [markdown]
# ## 按因子选股 v1.1

# %% [raw]
# start = '2014-05-07'                       # 回测起始时间
# end = '2016-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('A')  # 证券池，支持股票和基金
# capital_base = 10000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 150                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# import math
# import pandas as pd
#
# def xuanze(yz1,yz2,yz3,num):
#     bl=[]
#     # for stk1 in yz1[:num]:
#     #     for stk2 in yz2[:num]:
#     #         for stk3 in yz3[:num]:
#     #             if stk1==stk2 and stk1==stk3:
#     #                 bl.append(stk1)
#     for stk in yz1[:num]:
#         if stk in yz2[:num] and stk in yz3[:num]:
#             bl.append(stk)
#     return bl
#
# def IndustryGet(bgday,IndustryName='银行'):
#     bob=DataAPI.EquIndustryGet(industryVersionCD=u"010303",industry=u"",secID=u"",ticker=u"",intoDate=u"",field=u"secID,industryName2,secShortName",pandas="1")
#     bobo=bob[bob.industryName2==IndustryName].secID
#     c={'symbol':[],'mgsy':[],'xsml':[],'roa5':[]}
#     for tic in bobo:
#         if tic not in c['symbol']:
#             c['symbol'].append(tic)
#     ##print len(c['symbol'])
#     mgsytmp=DataAPI.MktStockFactorsOneDayGet(tradeDate=bgday,secID=c['symbol'],ticker=u"",field=u"EPS,GrossIncomeRatio,ROA5",pandas="1")
#     for tic in mgsytmp.EPS:
#         if math.isnan(tic)==True:
#             c['mgsy'].append(0)
#         else:
#             c['mgsy'].append(tic)
#     for tic in mgsytmp.GrossIncomeRatio:
#         if math.isnan(tic)==True:
#             c['xsml'].append(0)
#         else:
#             c['xsml'].append(tic)
#     for tic in mgsytmp.ROA5:
#         if math.isnan(tic)==True:
#             c['roa5'].append(0)
#         else:
#             c['roa5'].append(tic)
#     ##print len(c['mgsy'])
#     ##print len(c['symbol'])
#     ##minNum=min(len(c['mgsy']),len(c['xsml']),len(c['roa5']))
#     c['symbol']=c['symbol'][:min(len(c['mgsy']),len(c['xsml']),len(c['roa5']))]
#     mgsyfl=pd.DataFrame(c).sort(columns='mgsy',ascending=False)['symbol'].tolist()
#     xsmlfl=pd.DataFrame(c).sort(columns='xsml',ascending=False)['symbol'].tolist()
#     roa5=xsmlfl=pd.DataFrame(c).sort(columns='roa5',ascending=False)['symbol'].tolist()
#     return mgsyfl,xsmlfl,roa5
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     mgsylist,xsmlist,roalist=IndustryGet(str(account.current_date)[:10].replace('-',''),'房地产开发')
#     ##print xsmlist[0:5]
#     ##print mgsylist[0:5]
#     ##print roalist[0:5]
#     num=5
#     numfl=0
#     buylist=xuanze(mgsylist,xsmlist,roalist,num)
#     while len(buylist)<3:
#         numfl+=num+5
#         buylist=xuanze(mgsylist,xsmlist,roalist,numfl)
#     ##print numfl
#     ##print buylist
#     for tic in buylist:
#         order(tic,1000000)

# %% [markdown]
# ## 按因子选股 v1.2
# - EGRO 5年收益增长率（Five-year earnings growth）。计算方法：5 年收益增长率= 5年收益关于时间（年）进行线性回归的回归系数/5 年收益均值的绝对值。属于盈利能力和收益质量类因子。
# - CTOP 现金流市值比（Cash flow to price）。计算方法：现金流市值比=每股派现（税前）×分红前总股本/总市值。属于现金流指标因子。
# - MoneyFlow20 20日资金流量，用收盘价、最高价及最低价的均值乘以当日成交量即可得到该交易日的资金流量。属于成交量型因子

# %% [raw]
# start = '2014-05-07'                       # 回测起始时间
# end = '2016-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('A')  # 证券池，支持股票和基金
# capital_base = 10000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 100                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# buylist={'pre':[],'next':[]}
#
# import math
# import pandas as pd
#
# def xuanze(yz1,yz2,yz3,num):
#     bl=[]
#     # for stk1 in yz1[:num]:
#     #     for stk2 in yz2[:num]:
#     #         for stk3 in yz3[:num]:
#     #             if stk1==stk2 and stk1==stk3:
#     #                 bl.append(stk1)
#     for stk in yz1[:num]:
#         if stk in yz2[:num] and stk in yz3[:num]:
#             bl.append(stk)
#     return bl
#
# def IndustryGet(bgday,IndustryName='银行'):
#     bob=DataAPI.EquIndustryGet(industryVersionCD=u"010303",industry=u"",secID=u"",ticker=u"",intoDate=u"",field=u"secID,industryName2,secShortName",pandas="1")
#     bobo=bob[bob.industryName2==IndustryName].secID
#     c={'symbol':[],'mgsy':[],'xsml':[],'roa5':[]}
#     for tic in bobo:
#         if tic not in c['symbol']:
#             c['symbol'].append(tic)
#     ##print len(c['symbol'])
#     mgsytmp=DataAPI.MktStockFactorsOneDayGet(tradeDate=bgday,secID=c['symbol'],ticker=u"",field=u"EGRO,CTOP,MoneyFlow20",pandas="1")
#     for tic in mgsytmp.EGRO:
#         if math.isnan(tic)==True:
#             c['mgsy'].append(0)
#         else:
#             c['mgsy'].append(tic)
#     for tic in mgsytmp.CTOP:
#         if math.isnan(tic)==True:
#             c['xsml'].append(0)
#         else:
#             c['xsml'].append(tic)
#     for tic in mgsytmp.MoneyFlow20:
#         if math.isnan(tic)==True:
#             c['roa5'].append(0)
#         else:
#             c['roa5'].append(tic)
#     ##print len(c['mgsy'])
#     ##print len(c['symbol'])
#     ##minNum=min(len(c['mgsy']),len(c['xsml']),len(c['roa5']))
#     c['symbol']=c['symbol'][:min(len(c['mgsy']),len(c['xsml']),len(c['roa5']))]
#     mgsyfl=pd.DataFrame(c).sort(columns='mgsy',ascending=False)['symbol'].tolist()
#     xsmlfl=pd.DataFrame(c).sort(columns='xsml',ascending=False)['symbol'].tolist()
#     roa5=xsmlfl=pd.DataFrame(c).sort(columns='roa5',ascending=False)['symbol'].tolist()
#     return mgsyfl,xsmlfl,roa5
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     nowtime=str(account.current_date)[:10].replace('-','')
#     mgsylist,xsmlist,roalist=IndustryGet(nowtime,'房地产开发')
#     ##print xsmlist[0:5]
#     ##print mgsylist[0:5]
#     ##print roalist[0:5]
#     num=5
#     numfl=0
#     buylist['next']=xuanze(mgsylist,xsmlist,roalist,num)
#     while len(buylist['next'])<3:
#         numfl+=num+5
#         buylist['next']=xuanze(mgsylist,xsmlist,roalist,numfl)
#         for stkk in buylist['next']:
#             isOpen=DataAPI.MktEqudGet(tradeDate=nowtime,secID=stkk,ticker=u"",beginDate=u"",endDate=u"",isOpen="",field=u"isOpen",pandas="1")
#             if isOpen.empty:
#                 buylist['next'].remove(stkk)
#     ##print numfl
#     ##print buylist
#     if len(buylist['pre'])==0:
#         for tic in buylist['next']:
#             closeP=float(DataAPI.MktEqudGet(tradeDate=nowtime,secID=tic,ticker=u"",beginDate=u"",endDate=u"",isOpen="",field=u"closePrice",pandas="0")[11:15])
#             order(tic,account.cash/(len(buylist['next'])*closeP))
#     elif len(buylist['pre'])!=0:
#         # 不应该用这种方法卖出股票
#         # for stk1 in buylist['pre']:
#         #     if stk1 not in buylist['next']:
#         #         order_to(stk1,0)
#         for stk2 in buylist['next']:
#             if stk2 not in buylist['pre']:
#                 closeP2=float(DataAPI.MktEqudGet(tradeDate=nowtime,secID=stk2,ticker=u"",beginDate=u"",endDate=u"",isOpen="",field=u"closePrice",pandas="0")[11:15])
#                 if closeP2!=0:
#                     order(stk2,account.cash/(len(buylist['next'])*closeP2))
#     for stkkk in account.avail_secpos:
#         closePP=float(DataAPI.MktEqudGet(tradeDate=nowtime,secID=stkkk,ticker=u"",beginDate=u"",endDate=u"",isOpen="",field=u"closePrice",pandas="0")[11:15])
#         if closePP>account.valid_seccost[stkkk]*4:
#             order_to(stkkk,0)
#     buylist['pre']=buylist['next']
