# %% [markdown]
# # ETF轮动

# %% [raw]
# import pandas as pd
# from pandas import DataFrame
# import numpy as np
# import datetime as dt
# import scipy.stats as stats
#
# start = '2015-1-19'                       # 回测起始时间
# end = '2015-11-19'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['159929.XSHE','159928.XSHE','159930.XSHE','159932.XSHE']                   # 证券池，支持股票和基金
# capital_base = 100000                       # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# global bddata
# global n
# data=pd.read_excel('bd.xlsx')
# col=data.columns
# index=data[u'日期'].values
# value=data[col[4]].values
# num=range(len(index))
# d={'closePrice':value,'num':num}
# bddata=pd.DataFrame(d,index=index)
# n=15
#
#
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
#
#
#
# def signal(data,n,stkpos,hist,date):
#     rnum=int(data.T[date][1])
#     bd=data[rnum-n:rnum]['closePrice']
#     signal=[]
#     for s in stkpos:
#         a, b, c, d, std_err = stats.linregress(bd[0:n-1],hist[s][0:n-1])
#         dif=hist[s][n-1]-a*bd[n-1]-b
#         if dif<0:
#             signal.append(1)
#         else:
#             signal.append(0)
#
#     return signal
#
#
#
# def handle_data(account):
#     # 每周一更新仓位
#     if  account.current_date.weekday() != 1 :
#         return
#
#     #如果未停牌的股票为0，直接返回
#     if len(account.universe)==0:
#         return
#
#     date=account.current_date
#     hist=account.get_attribute_history('closePrice',n)
#     stkpos=account.universe
#
#
#     sig=signal(bddata,n,stkpos,hist,date)
#
#     i=0
#     for s in stkpos:
#         if sig[i]==0 and s in account.avail_secpos:
#             order_to(s,0)
#         i=i+1
#
#     cash=account.cash/3
#     i=0
#     for s in stkpos:
#         if sig[i]==1 and s not in account.avail_secpos:
#             order(s,cash)
#         i=i+1
