# %% [markdown]
# # 发现DataAPI.MktStockFactorsOneDayGet计算部分的M20出不来结果

# %% [raw]
# import numpy as np
# import pandas as pd
# import talib
# from CAL.PyCAL import *
#
# # 第一步：设置基本参数
# start = '2016-02-01'
# end   = '2016-04-13'
# capital_base =50000
# refresh_rate = 1
# benchmark = 'HS300'
# freq = 'd'
#
# # 第二步：选择主题，设置股票池
# universe = ['600028.XSHG', ]
#
# def initialize(account):
#     # 第三步：调整股票权重，权重列表序号与股票池列表序号对应
#     pass
#
# def handle_data(account):
#     d=account.previous_date
#     ud=unicode(d.strftime("%Y%m%d"))
#     for stock in account.universe:
#         df = DataAPI.MktStockFactorsOneDayGet(tradeDate=ud,secID=stock,ticker=u"",field=u"",pandas="1")
#         print'time %s,ma20 %s' %(ud,df['MA20'])
