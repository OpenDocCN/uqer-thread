# %% [markdown]
# # 突破

# %% [raw]
# #encoding utf-8
# import datetime
# import pandas
# start = '2020-01-01'                       # 回测起始时间
# end = '2020-07-15'                         # 回测结束时间
# universe = ['512500.XSHG']       # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'ZZ500'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000)
# }
#
# def initialize(context):
#     pass
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#
#     previous_date = context.previous_date.strftime('%Y-%m-%d')
#     last_date = (context.now + datetime.timedelta(days=-20)).strftime('%Y-%m-%d')
#
#     # 获取因子PE的的历史数据集，截止到前一个交易日
#     hist = DataAPI.MktIdxdGet(indexID=u"",ticker=u"399905",tradeDate=u"",beginDate=last_date,endDate=previous_date,exchangeCD=u"XSHE,XSHG",field=u"",pandas="1")
#     ma5=hist['closeIndex'][-5:].mean()
#     ma10=hist['closeIndex'][-10:].mean()
#
#
#     # 获取当前账户信息
#     account = context.get_account('fantasy_account')
#     current_position = account.get_positions(exclude_halt=True)
#     print("date {},ma5 {},ma10 {},positon {}".format(previous_date,ma5,ma10,current_position))
#
#
#     if ma5>ma10:
#         print('buy')
#         account.order_pct('512500.XSHG',1)
#     if ma5<ma10:
#         print('sell')
#         account.order_pct('512500.XSHG',-1)
#         print(account.get_positions())
