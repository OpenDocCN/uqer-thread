# %% [markdown]
# #

# %% [markdown]
# 技术指标：二十日布林带
# 卖出点：股价触碰布林带上轨（压力线）
# 买入点：股价触碰布林带下轨 （支撑线）

# %% [raw]
# import numpy as np
#
# start = '2015-08-01'                       # 回测起始时间
# end = '2016-08-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['600004.XSHG','600000.XSHG']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     #提取前20日的历史收盘价，用于计算布林带
#     #返回的是一个字典，key是证券名称，value是一np.array
#     all_hist  = account.get_attribute_history('closePrice', 21)
#
#     for s in account.universe:
#         hist = all_hist[s][:20]   #提取字典的value，截取前20个数据，返回一个np.array
#         current = all_hist[s][-1] #以当天收盘价作为当前价格
#         mean = np.mean(hist)
#         std = np.std(hist)
#         up = mean+2*std           #计算布林带上下轨
#         down = mean-2*std
#
#         if (current > up) and (s in account.security_position) :
#             order_to(s,0)
#         elif current < down:
#             order(s, account.cash/current)

# %%
小结：该策略比较适合熊市时价格波动较大的股票，从前一年的数据可以看到收益非常好。但是牛市时跑不赢大盘。此外策略比较简略，假定在每天收盘时检查价格是否触碰上下轨。可以修改为调用高频数据。
