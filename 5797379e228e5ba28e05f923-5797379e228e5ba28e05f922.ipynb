# %% [markdown]
# #

# %% [raw]
# import numpy as np
# import random
# # 第一步：设置基本参数
# start = '2006-01-01'
# end   = '2008-12-10'
# capital_base = 1000000
# refresh_rate = 13
# benchmark = 'HS300'
# freq = 'd'
#
# universe = set_universe('A')
#
# def initialize(account):
#     account.hold_num = 7
#     account._up_threshold = 1.10
#     account._down_threshold = 0.9
#     account.last_profio = 0
#
# def handle_data(account):
#     # 本策略将使用account的以下属性：
#     # account.referencePortfolioValue表示根据前收计算的当前持有证券市场价值与现金之和。
#     # account.universe表示当天，股票池中可以进行交易的证券池，剔除停牌退市等股票。
#     # account.referencePrice表示股票的参考价，一般使用的是上一日收盘价。
#     # account.valid_secpos字典，键为证券代码，值为虚拟账户中当前所持有该股票的数量。
#
#     account.last_profio = account.referencePortfolioValue
#
#     current_hold = account.valid_seccost
#     closeprice = account.get_attribute_history('closePrice',2)
#     reference_p = account.referencePrice
#
#     all_list = list(current_hold.keys())
#     sell_list = []
#     if all_list:
#         sell_list = random.sample(all_list, random.randint(0,3))
#
#     for stock, cost in current_hold.items():
#         if stock in sell_list:
#             all_list.remove(stock)
#             order_to(stock, 0)
#
#     need_buy = len(sell_list) if sell_list else 0
#     if len(all_list) <= 0:
#         need_buy = account.hold_num
#
#     if len(all_list) <  account.hold_num:
#         need_buy = account.hold_num - len(all_list)
#
#     buy_list = random.sample(account.universe, need_buy)
#
#     for stock in buy_list:
#         amout = account.cash / len(buy_list) / reference_p[stock]
#         order(stock, amout)
