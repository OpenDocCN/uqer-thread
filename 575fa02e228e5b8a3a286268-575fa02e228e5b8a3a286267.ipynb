# %% [markdown]
# #

# %% [markdown]
# 怎么把tmpdata那一列数加入data的后面啊？

# %%
data=DataAPI.MktEqudGet(tradeDate="20150430",secID=u"",isOpen="1",field=u"secID,secShortName,preClosePrice,openPrice,closePrice",pandas="1")
print data
for secID in data["secID"].values:
    tmpData=DataAPI.MktEquFlowOrderGet(secID=secID,beginDate="20150430",endDate="20150430",field=u"netInflowS,netInflowM,netInflowL,netInflowXl",pandas="1")
    print tmpData["netInflowS"]+tmpData["netInflowM"]+tmpData["netInflowL"]+tmpData["netInflowXl"]
# Out:
#             secID secShortName  preClosePrice  openPrice  closePrice
# 0     000001.XSHE         平安银行         16.650     16.830      16.700
# 1     000002.XSHE          万科A         14.240     14.330      14.600
# 2     000004.XSHE         国农科技         24.890     25.400      25.330
# 3     000006.XSHE         深振业A         11.230     11.430      11.680
# 4     000007.XSHE         零七股份         24.000     24.490      26.400
# 5     000009.XSHE         中国宝安         21.070     21.120      22.380
# 6     000011.XSHE         深物业A         14.400     14.400      14.630
# 7     000012.XSHE          南玻A         14.850     14.690      15.490
# 8     000014.XSHE         沙河股份         21.150     21.150      21.710
# 9     000016.XSHE         深康佳A         14.540     14.880      15.990
# 10    000017.XSHE         深中华A         13.860     13.860      15.250
# 11    000018.XSHE          中冠A         30.100     30.080      30.660
# 12    000019.XSHE         深深宝A         14.930     14.950      15.460
# ...
