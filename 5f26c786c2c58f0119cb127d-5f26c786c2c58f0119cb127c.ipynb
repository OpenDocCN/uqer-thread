# %% [markdown]
# # AH比

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
#df=DataAPI.IdxGet(secID=u"",indexGroup=u"HSI",secShortName=u"",wMethodCD="",pubName=u"",industryID=u"",sortID=u"",field=u"",pandas="1")
#print(df)
df1=DataAPI.MktIdxdGet(ticker=u"hsahp",beginDate=u"20060101",endDate=u"20200801",
                         field=u"",pandas="1")
s=df1[["tradeDate","preCloseIndex"]]
s=s.set_index("tradeDate")
s=s.dropna()
s.plot()
plt.show()
val=s["preCloseIndex"].values
val.sort()
si=val.size
print(si)
for i in range(10):
    print(i)
    print(val[si*i/10])
'''
df=DataAPI.MktIdxdGet(ticker=tic,beginDate=u"20000105",endDate=u"20000801",
                          exchangeCD=u"XSHE,XSHG",field=u"",pandas="1")
    pci=df.loc[0]["secShortName"]
    #pci="perincrease_"+tic
    startvalue=df.loc[0]["preCloseIndex"]
    df[pci]=(df["preCloseIndex"]-startvalue)/startvalue
    #ans=pd.DataFrame(df["perincrease"],index=df['tradeDate'])
    s=df[["tradeDate",pci]]
    #print(tic)
    #print(s)
    if(tic==industry[0]):
        ans=s
    else:
        ans=pd.merge(ans,s,on="tradeDate")
ans=ans.set_index("tradeDate")
print(ans)
ans["申万传媒Ⅰ"].plot(label=u'申万传媒Ⅰ')
ans["申万农林牧渔"].plot(label=u'申万农林牧渔')
plt.legend()
plt.show()
'''
# Out:
# 1245
# 0
# 113.78
# 1
# 118.39
# 2
# 120.91
# 3
# 123.3
# 4
# 125.28
# 5
# 126.91
# 6
# 128.14
# 7
# 129.47
# 8
# 131.82
# 9
# 136.31
# ...
