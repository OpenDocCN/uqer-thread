# %% [markdown]
# #

# %% [raw]
# #运行成功的策略
# start = '2014-01-01'                       # 回测起始时间
# end = '2016-07-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['000683.XSHE']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，由于freq = 'd'，时间间隔的单位为交易日
# commission = Commission(buycost=0.0008, sellcost=0.0018) # 佣金万八
# slippage = Slippage()
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     for stock in account.universe:
#         hist=DataAPI.MktEqudGet(tradeDate=account.current_date,secID=u"",ticker=u"000683",beginDate=u"",endDate=u"",isOpen="1",field=['closePrice', 'preClosePrice'],pandas="1")
#         if hist["closePrice"][0]-hist["preClosePrice"][0]>0:
#             order_pct_to(stock,1)
#         if hist["closePrice"][0]-hist["preClosePrice"][0]<0:
#             order_pct_to(stock,0)

# %% [raw]
# #试着把日期往前移一天，策略就只能运行到2014年7月1日了。
# from CAL.PyCAL import *
# from datetime import *
#
# start = '2014-01-01'                       # 回测起始时间
# end = '2016-07-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['000683.XSHE']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，由于freq = 'd'，时间间隔的单位为交易日
# commission = Commission(buycost=0.0008, sellcost=0.0018) # 佣金万八
# slippage = Slippage()
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     cal = Calendar('China.SSE')
#     period = Period('-1B')
#
#
#     referenceDate = account.current_date
#     referenceDate = Date.fromDateTime(account.current_date)
#     resDate1 = cal.advanceDate(referenceDate, period, BizDayConvention.Preceding)
#     resDate1 = resDate1.toDateTime().strftime('%Y%m%d')
#
#
#     for stock in account.universe:
#         hist=DataAPI.MktEqudGet(tradeDate=resDate1,secID=u"",ticker=u"000683",beginDate=u"",endDate=u"",isOpen="1",field=['closePrice', 'preClosePrice'],pandas="1")
#         if hist["closePrice"][0]-hist["preClosePrice"][0]>0:
#             order_pct_to(stock,1)
#         if hist["closePrice"][0]-hist["preClosePrice"][0]<0:
#             order_pct_to(stock,0)
