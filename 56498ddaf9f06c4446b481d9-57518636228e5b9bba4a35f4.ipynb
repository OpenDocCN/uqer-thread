# %% [markdown]
# # 第一小组

# %% [raw]
# import numpy as np
#
# start = '2013-11-15'				# 回测起始时间
# end  =  '2015-11-10'				# 回测结束时间
# benchmark = 'SH50'							# 策略参考标准
# universe = set_universe('SH50')	                # 股票池  中信证券
# capital_base = 100000000                       # 起始资金
# commission = Commission(0.000,0.000)
# freq = 'd'
#
# window_short = 5  # 短均线周期
# window_long = 10  # 长均线周期
#
# def initialize(account):					# 初始化虚拟账户状态
#     pass
#
# def handle_data(account):
#     print account.cash
#     for stock in account.universe:
#         cp_hist = account.get_attribute_history('closePrice',window_long)[stock]
#         long_mean = np.mean(cp_hist[-window_long:])
#         short_mean = np.mean(cp_hist[-window_short:])
#         derta = np.std(cp_hist)/10
#         if short_mean - long_mean - derta > 0:
#             if stock not in account.valid_secpos:
#                amount = account.cash /len(stock)/ account.referencePrice[stock]
#                order(stock,amount)
#         elif short_mean - long_mean - derta <= 0 and stock in account.valid_secpos:
#                order_to(stock,0)
