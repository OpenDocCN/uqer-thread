# %% [markdown]
# # Notebook564

# %%
DataAPI.SecHaltGet(secID=u"",ticker=u"300474",beginDate=u"",endDate=u"",listStatusCD="",assetClass="",field=u"",pandas="1")
# Out:
#          secID        haltBeginTime          haltEndTime  ticker secShortName  \
# 0  300474.XSHE  2016-03-31 09:32:00  2016-03-31 10:03:00  300474          景嘉微
# 1  300474.XSHE  2017-10-12 09:30:00  2017-10-20 15:00:00  300474          景嘉微
#
#   exchangeCD listStatusCD  delistDate assetClass
# 0       XSHE            L         NaN          E
# 1       XSHE            L         NaN          E

# %%
DataAPI.EquGet(secID=u"",ticker=u"300474",equTypeCD=u"A",listStatusCD=u"",exchangeCD="",ListSectorCD=u"",field=u"",pandas="1")
# Out:
#          secID  ticker exchangeCD  ListSectorCD ListSector transCurrCD  \
# 0  300474.XSHE  300474       XSHE             2        创业板         CNY
#
#   secShortName    secFullName listStatusCD    listDate      ...       equType  \
# 0          景嘉微  长沙景嘉微电子股份有限公司            L  2016-03-31      ...          沪深A股
#
#   exCountryCD partyID totalShares  nonrestFloatShares  nonrestfloatA  \
# 0         CHN   73097   455059140           317566233      317566233
#
#         officeAddr      primeOperating     endDate     TShEquity
# 0  湖南省长沙市岳麓区梅西湖路1号  高可靠军用电子产品的研发、生产和销售  2022-09-30  3.126269e+09
#
# [1 rows x 22 columns]
# Empty DataFrame
# Columns: [secID, ticker, exchangeCD, secShortName, tradeDate, contractObject, contractMark, preSettlePrice, preClosePrice, openPrice, highestPrice, lowestPrice, closePrice, settlePrice, turnoverVol, turnoverValue, openInt, CHG, CHG1, CHGPct, mainCon, smainCon]
# Index: []
#
# [0 rows x 22 columns]
