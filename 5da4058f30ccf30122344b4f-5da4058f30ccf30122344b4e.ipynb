# %% [markdown]
# # Notebook0

# %%
import numpy as np
import pandas as pd

df=DataAPI.MktEqudGet(secID=u"",ticker=u"",tradeDate="20191011",beginDate="20151010",endDate="20191011",isOpen="",field=u"",pandas="1")
df['ma60'] = np.round(pd.Series.rolling(df['closePrice'],window=60).mean(),2)
df['ma60']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
#         ...
# 3758    37.01
# 3759    36.64
# 3760    36.59
# 3761    36.51
# 3762    36.39
# 3763    36.29
# 3764    36.20
# 3765    35.45
# 3766    34.82
# 3767    34.22
# 3768    33.64
# 3769    32.89
# 3770    32.38
# 3771    31.36
# 3772    31.22
# 3773    30.40
# 3774    29.51
# 3775    28.38
# 3776    27.78
# 3777    25.54
# 3778    23.14
# 3779    21.01
# 3780    19.60
# 3781    18.75
# 3782    17.28
# 3783    14.81
# 3784    14.06
# 3785    13.52
# 3786    12.74
# 3787    12.01
# ...
