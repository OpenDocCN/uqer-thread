# %% [markdown]
# # 专捡便宜货

# %% [raw]
# start = datetime(2014, 8, 1)
# end   = datetime(2014, 12, 1)
#
# benchmark = 'HS300'
# universe = set_universe('HS300')
# capital_base = 1000000
#
# def initialize(account):
#     add_history('hist', 1)
#
# def handle_data(account, data):
#     for stock in universe:
#         if stock not in account.hist or stock not in data or data[stock]['openPrice']==0: continue
#
#         p = account.hist[stock]['closePrice'].iloc[0]
#         if   (p < 4): order(stock, 30000)
#         #and (account.position.stkpos.get(stock, 0) == 0):
#
#         elif (p >= 4) and (account.position.stkpos.get(stock, 0) > 0):
#             order_to(stock, 0)
