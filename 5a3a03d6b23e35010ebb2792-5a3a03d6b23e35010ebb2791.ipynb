# %% [markdown]
# # Notebook0

# %% [raw]
# ########################### 初始化配置 ###########################
# start = '2017-03-01'        # 起始时间
# end = '2017-06-30'          # 终止时间
# universe = ['000002.XSHE']  # 股票池
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=100000)
# }
#
# ############################ 策略逻辑 ############################
# def handle_data(context):
#     account = context.get_account('fantasy_account')
#
#     security_price = context.current_price('000002.XSHE')   # 获取万科A的价格
#     if security_price < 20.5:
#          account.order('000002.XSHE', 500)                  # 价格低于20.5元时买入1000股
