# %% [markdown]
# # Notebook0

# %% [raw]
# import numpy as np
#
# def guzhi(date, stocklist, overflow = 0.15):
#     eq_EPS_EGRO = DataAPI.MktStockFactorsOneDayGet(tradeDate=date,secID=stocklist,field=u"secID,EPS,EGRO",pandas="1")
#     eq_EPS_EGRO['Value'] = eq_EPS_EGRO['EPS']*(8.5+2*eq_EPS_EGRO['EGRO']/5)
#     closepirce = DataAPI.MktEqudAdjGet(tradeDate=date,field=['closePrice', ],pandas="1")
#     a= eq_EPS_EGRo.merge(closeprice)
#     a = a.dropna()
#
#     spread_rate = []
#     for stock, intrinsic_value, price in zip(a['secID'].values, a['Value'].values, a['closePrice'].values):
#         intrinsic_value = intrinsic_value*(1+overflow)
#         if intrinsic_value > price:
#             spread_rate.append(stock)
#     return spread_rate
#
# start = '2013-01-01'
# end = '2018-01-01'
# benchmark = 'HS300'
# capital_base = 100000
# freq = 'd'
# refresh_rate = 1
#
# universe = StockScreener( Factor.NetProfitRatio.nlarge(200) & Factor.ROE.nlarge(200) & Factor.ROE5.nlarge(200) )
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     lastday = account.previous_date.strftime('%Y-%M-%D')
#     last_screener = universe.preview(lastday)
#     stockbase = guzhi(lastday, last_screener, overflow = 0.2)
#     stockbase = stockbase.extend(account.universe)
#     stockbase = set(stockbase)
#     buylist = [sec for sec in stockbase]
#     v = account.referencePortfolioValue
#     d = len(buylist)
#     change = {}
#     for stock in account.valid_secpos:
#         if stock not in buylist:
#             order_to(stock, 0)
#         else:
#             v -= account.valid_secpos[stock] * account.referencePrice[stock]
#             p = account.referencePrice[stock]
#             if p and not np.isnan(p):
#                 change[stock] = int(v / d / p) - account.valid_secpos.get(stock, 0)
#
#     for stock in sorted(change, key=change.get):
#         if change[stock] <= -100 or change[stock] >= 100:
#             order_to(stock, change[stock])
