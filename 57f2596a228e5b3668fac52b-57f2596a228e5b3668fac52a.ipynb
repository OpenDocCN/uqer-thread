# %% [markdown]
# #

# %% [raw]
# #买点：股价从250天线下上穿250天买入
# #卖点1：股价跌破250天线
#
# start = '2011-01-01'                  # 回测起始时间
# end = '2016-09-01'                   # 回测结束时间
# benchmark = 'HS300'                   # 策略参考标准
# universe = set_universe('HS300')              # 证券池，也可以在这里添加多个证券
# capital_base = 1000000                  # 起始资金
# freq = 'd'                         # 日线策略
# refresh_rate = 1                     # 每个交易日调仓
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     # account.get_attribute_history：表示获取所有证券过去250天的closePrice数据，返回数据类型为 dict，键为每个证券的secID
#     hist = account.get_attribute_history('closePrice', 250)
#     for stk in account.universe:
#         # 计算股票过去1天收盘平均值
#         ma1 = hist[stk][-1:].mean()
#         # 计算股票过去250天收盘平均值
#         ma250 = hist[stk][:].mean()
#
#         # 如果今日收盘价大于250日均线，并且该股票当前没有持仓，则买入100手
#         # account.valid_secpos：表示当前交易日持有数量大于0的证券头寸。数据类型为字典，键为证券代码，值为头寸。
#         if ma1 > ma250 and stk not in account.valid_secpos:
#             order(stk, 10000)
#         # 如果今日收盘价小于250日均线，则该股票全部卖出
#         elif ma1 <= ma250:
#             order_to(stk, 0)
