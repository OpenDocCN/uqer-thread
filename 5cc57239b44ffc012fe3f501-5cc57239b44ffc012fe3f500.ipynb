# %% [markdown]
# # Notebook0

# %% [raw]
# import pandas as pd
# start = '2017-11-21'
# ss='20171130'
# end = '2019-02-14'                         # 回测结束时间
# universe = DynamicUniverse('HS300')        # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = Monthly(1)                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'xy_account': AccountConfig(account_type='security', capital_base=2000000)
# }
#
# def initialize(context):
#     pass
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     tmp={'ID':[],'price':[]}
#     current_universe=context.get_universe(exclude_halt=True)
#     STlist=DataAPI.SecSTGet(beginDate=start,endDate=ss,secID=current_universe)
#     valid_universe=set([s for s in current_universe if s not in STlist])
#     for i in valid_universe:
#         test=context.get_symbol_history(i,attribute=['closePrice'],time_range=1,freq='1d',rtype='array')
#         tmp.get('ID').append(i)
#
#         tmp.get('price').append(test['closePrice'])
#     out=pd.DataFrame(tmp)
#     out=(out.sort(columns=['price']))
#     buylist=out['ID'][:10]
#     #print(scope)
#     xy_account=context.get_account('xy_account')
#     current_positions=xy_account.get_positions(exclude_halt=True)
#     for stock in buylist:
#         if stock not in current_positions:
#             xy_account.order_to(stock,5000)#买500股
#     #print([i for i in current_positions]) #观测持股情况
#     for stock in current_positions:    #持有的股票
#         if stock not in buylist:        #持有的股票不在新的购买列表里
#             xy_account.order_to(stock,0)
