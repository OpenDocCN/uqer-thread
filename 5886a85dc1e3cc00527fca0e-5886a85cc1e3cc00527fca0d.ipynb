# %% [markdown]
# # Notebook4

# %% [raw]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from datetime import datetime
#
#
# universe = set_universe('A')
# #日期列表
# date=DataAPI.TradeCalGet(exchangeCD=u"XSHG,XSHE",beginDate=u"20160101",endDate=u"20170101",field=u"calendarDate,isOpen,,beginDate,isMonthEnd",pandas="1")
# date=date[date['isOpen']==1]
# date=date[date['isMonthEnd']==1]
# date=date['calendarDate']
# datelist=date.tolist()
# datelist=[v.replace('-','') for v in datelist]
# groupmean_main=[]
# #print date
# #print datelist
# for dt in datelist:
#     groupmean_body=[]
#
#  #数据处理
#
#     data=DataAPI.MktEqudAdjGet(tradeDate=dt,secID=universe,ticker=u"",field=u"secID,secShortName,tradeDate,marketValue,openPrice,highestPrice,lowestPrice,turnoverVol,isOpen",pandas="1")
#     data=data[data['turnoverVol']>0][~(data['lowestPrice']==data['highestPrice'])][~(data['openPrice']==data['highestPrice'])]
#     data=data.dropna()
#     data=data.sort(columns='marketValue',ascending=True)
#     data.index=range(len(data))
#     #print 'data'
#     #print data
#
# #分成十组
#     data1=data[:int(len(data)*0.1)]
#     data2=data[int(len(data)*0.1):int(len(data)*0.2)]
#     data3=data[int(len(data)*0.2):int(len(data)*0.3)]
#     data4=data[int(len(data)*0.3):int(len(data)*0.4)]
#     data5=data[int(len(data)*0.4):int(len(data)*0.5)]
#     data6=data[int(len(data)*0.5):int(len(data)*0.6)]
#     data7=data[int(len(data)*0.6):int(len(data)*0.7)]
#     data8=data[int(len(data)*0.7):int(len(data)*0.8)]
#     data9=data[int(len(data)*0.8):int(len(data)*0.9)]
#     data10=data[int(len(data)*0.9):]
#     #print "data1"
#     group1=DataAPI.MktEqumAdjGet(secID=data1.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"1",beginDate=u"",endDate=u"",field=u"secID,secShortName,endDate,tradeDays,chgPct",pandas="1")
#     #print 'group1'
#     #print group1
#     groupmean1=group1['chgPct'].mean()
#     groupmean_body.append(groupmean1)
#
#     group2=DataAPI.MktEqumAdjGet(secID=data2.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"1",beginDate=u"",endDate=u"",field=u"secID,secShortName,endDate,tradeDays,chgPct",pandas="1")
#     #print 'group2'
#     #print group2
#     groupmean2=group2['chgPct'].mean()
#     groupmean_body.append(groupmean2)
#     #print groupmean_body
#     #print "groupmean_body"
#     group3=DataAPI.MktEqumAdjGet(secID=data3.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"1",beginDate=u"",endDate=u"",field=u"secID,secShortName,endDate,tradeDays,chgPct",pandas="1")
#     #print 'group3'
#     #print group3
#     groupmean3=group3['chgPct'].mean()
#     groupmean_body.append(groupmean3)
#     #print groupmean_body
#     #print "groupmean_body"
#     group4=DataAPI.MktEqumAdjGet(secID=data4.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"1",beginDate=u"",endDate=u"",field=u"secID,secShortName,endDate,tradeDays,chgPct",pandas="1")
#     groupmean4=group4['chgPct'].mean()
#     groupmean_body.append(groupmean4)
#     group5=DataAPI.MktEqumAdjGet(secID=data5.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"1",beginDate=u"",endDate=u"",field=u"secID,secShortName,endDate,tradeDays,chgPct",pandas="1")
#     groupmean5=group5['chgPct'].mean()
#     groupmean_body.append(groupmean5)
#     group6=DataAPI.MktEqumAdjGet(secID=data6.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"1",beginDate=u"",endDate=u"",field=u"secID,secShortName,endDate,tradeDays,chgPct",pandas="1")
#     groupmean6=group6['chgPct'].mean()
#     groupmean_body.append(groupmean6)
#     group7=DataAPI.MktEqumAdjGet(secID=data7.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"1",beginDate=u"",endDate=u"",field=u"secID,secShortName,endDate,tradeDays,chgPct",pandas="1")
#     groupmean7=group7['chgPct'].mean()
#     groupmean_body.append(groupmean7)
#     group8=DataAPI.MktEqumAdjGet(secID=data8.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"1",beginDate=u"",endDate=u"",field=u"secID,secShortName,endDate,tradeDays,chgPct",pandas="1")
#     groupmean8=group8['chgPct'].mean()
#     groupmean_body.append(groupmean8)
#     group9=DataAPI.MktEqumAdjGet(secID=data9.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"1",beginDate=u"",endDate=u"",field=u"secID,secShortName,endDate,tradeDays,chgPct",pandas="1")
#     groupmean9=group9['chgPct'].mean()
#     groupmean_body.append(groupmean9)
#     group10=DataAPI.MktEqumAdjGet(secID=data10.secID.tolist(),ticker=u"",monthEndDate=dt,isOpen=u"1",beginDate=u"",endDate=u"",field=u"secID,secShortName,endDate,tradeDays,chgPct",pandas="1")
#     groupmean10=group10['chgPct'].mean()
#     groupmean_body.append(groupmean10)
#     group0=DataAPI.MktEqumAdjGet(secID=universe,ticker=u"",monthEndDate=dt,isOpen=u"1",beginDate=u"",endDate=u"",field=u"secID,secShortName,endDate,tradeDays,chgPct",pandas="1")
#     groupmean0=group0['chgPct'].mean()
#     groupmean_body.append(groupmean0)
#     groupmean_main.append(groupmean_body)
# new_mean=pd.DataFrame(groupmean_main,index=datelist,columns=['groupmean1','groupmean2','groupmean3','groupmean4','groupmean5','groupmean6','groupmean7','groupmean8','groupmean9','groupmean10','groupmean0'])
#
# print new_mean
#
# #retnmean_main.append(retnmean_body)
# #new_mean = pd.DataFrame(retnmean_main,index=datelist,columns=['retnmean1','retnmean2','retnmean3','retnmean4','retnmean5','retnmean0'])
# #print dt,retnmean1,retnmean2,retnmean3,retnmean4,retnmean5
# #print new_mean
#
#
#
#    # dataaa=pd.merge(data,dataa,on='secID')
#    # print 'dataaa'
#    # print dataaa
#    # datab=pd.DataFrame(dataaa,columns=['secID','secShortName_x','marketValue','chgPct'])
#     #print 'datab'
#   #  print datab
