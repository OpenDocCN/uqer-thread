# %% [markdown]
# # 调仓记录怎么没有卖出？

# %% [raw]
# import numpy as np
# start = '2015-01-01'                       # 回测起始时间
# end = '2016-04-27'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')  # 证券池，支持股票和基金
# capital_base = 3000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     for stock in account.universe:
#         hist = account.get_attribute_history('closePrice', 10)
#         amount=account.get_attribute_history('turnoverVol', 5)
#         yesterday_amount=amount[stock][-1] #昨天成交量
#         yesterday_amount_1=amount[stock][-2] #前天成交量
#         yesterday_amount_5=np.mean( amount[stock][0:4]) #过去5天成交量均值
#         if (yesterday_amount> yesterday_amount_1) or (yesterday_amount>yesterday_amount_5):
#             order(stock,1000)
#         if hist[stock][-1]/hist[stock][0]-1 > 0.01 and stock not in account.valid_secpos:
#             order_to(stock,0)
#
#     return
