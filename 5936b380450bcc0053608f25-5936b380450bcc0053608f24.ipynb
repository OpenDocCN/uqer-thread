# %% [markdown]
# # Notebook1

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
df = DataFrame(np.random.randn(9, 3))
df.columns = ['a', 'b', 'c']
df['d']= abs(df.a-df.b)
df['e']= pd.rolling_mean(df.d,5)
df['f']= pd.rolling_mean(abs(df.a-df.b),5)
print df

df.to_excel('test2.xlsx', 'data', encoding='GB18030') #excel表写在哪里？
print '如何将表写入到本地磁盘？'

df = DataFrame() #清空df表
print df
df=pd.read_excel('test2.xlsx', 'data') #从excel表中读入二维表
print df
# Out:
#           a         b         c         d         e         f
# 0 -0.224097 -1.495162  0.291116  1.271064       NaN       NaN
# 1 -0.527520 -0.778013 -0.046017  0.250494       NaN       NaN
# 2  0.030545 -1.076011  1.507410  1.106556       NaN       NaN
# 3 -1.181709  1.192570  0.632045  2.374279       NaN       NaN
# 4 -0.796632 -0.463170 -1.534019  0.333463  1.067171  1.067171
# 5 -1.229522  0.440151  0.170930  1.669673  1.146893  1.146893
# 6  0.898013 -0.263114 -1.773977  1.161127  1.329020  1.329020
# 7 -0.318415  0.012291  2.250941  0.330706  1.173850  1.173850
# 8  0.451347  0.815858 -0.310183  0.364511  0.771896  0.771896
# 如何将表写入到本地磁盘？
# Empty DataFrame
# Columns: []
# Index: []
#           a         b         c         d         e         f
# 0 -0.224097 -1.495162  0.291116  1.271064       NaN       NaN
# 1 -0.527520 -0.778013 -0.046017  0.250494       NaN       NaN
# 2  0.030545 -1.076011  1.507410  1.106556       NaN       NaN
# ...
