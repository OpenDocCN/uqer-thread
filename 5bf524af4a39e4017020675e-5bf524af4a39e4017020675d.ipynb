# %% [markdown]
# # 指数调样掘金，做优质剔除股的中长期反转

# %% [raw]
# import pandas as pd
# import numpy as np
# from CAL.PyCAL import *
# from datetime import datetime
# import functools
# import datetime
#
# start = '2010-07-01'                       # 回测起始时间
# end = '2018-10-31'                          # 回测结束时间
# benchmark = 'ZZ500'                        # 策略参考标准
# universe = DynamicUniverse('A')  # 证券池，支持股票和基金
# accounts = {
#     'stock_account': AccountConfig(account_type='security', capital_base=1000000, commission = Commission(buycost=0.0005, sellcost=0.0015, unit='perValue'), slippage = Slippage(value=0.00, unit='perShare'))
# }
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率
#
# cal = Calendar('China.SSE')
# period = Period('-1B')
#
# index500stklist = pd.read_csv(r'index500stklist.csv')
# index500stklist = index500stklist.set_index('tradeDate')
# universe2 = 'index500stklist'
#
# def initialize(context):
#     context.jsuniverse = []
#     context.stocks = index500stklist
#     pass
#
# def handle_data(context):
#     stock_account = context.get_account('stock_account')
#     current_position = stock_account.get_positions(exclude_halt=True)
#     today = context.current_date
#     yesterday = cal.advanceDate(today,period)
#
#     stklist = context.stocks.loc[str(yesterday), universe2]
#     stklist = stklist.split("', '")
#     stklist[0] = str(stklist[0])[2:]
#     stklist[-1] = str(stklist[-1])[:-2]
#
#     _universe = context.get_universe(exclude_halt=False)
#
#     if context.jsuniverse == []:
#         context.jsuniverse = stklist
#
#     else:
#         buylist = set(context.jsuniverse).difference(stklist)
#         if len(buylist) > 10:
#             print today
#             context.jsuniverse = stklist
#             for stock in set(current_position).difference(buylist):
#                 stock_account.order_to(stock, 0)
#
#             for stock in set(buylist).difference(current_position):
#                 stock_account.order_pct_to(stock, 1.0/len(buylist))
