# %% [markdown]
# # （选股）找到比一段时间最大值的35%还小的股票（2.0）

# %% [raw]
# #1.找到期间内最大值的
# #2.循环判断出小于最大值35%的票
#
# import pandas as pd
#
# start = '2015-01-01'                       # 回测起始时间
# end = '2015-01-30'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')               # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 30                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     #df = pd.DataFrame()
#     stock_list = universe                  #股票池
#     #Latehist = DataAPI.MktEqudLatelyGet(secID="600000.XSHG",ticker=u"",field=u"",pandas="1")
#     #Latehist2 = DataAPI.MktEqudLatelyGet(secID="",ticker=u"000001,000002,000004,000005,000006,600000,600004,600005,600006,600007,600008",field=u"",pandas="1")
#     #print Latehist
#     #print stock_list
#     for i in stock_list:
#     #    print i
#     #MktEqudAdjGet  MktEqudGet
#     #    raw_data = DataAPI.MktEqudGet(secID=i,ticker=u"",beginDate=u"20150101",endDate=u"20160401",isOpen="",field=u"secID,tradeDate,highestPrice",pandas="1")
#         raw_data = DataAPI.MktEqudAdjGet(secID=i, beginDate='20150101', endDate='20160401', pandas='1')
#         df = raw_data[['secID', 'tradeDate', 'highestPrice']]
#
#         #找到区间的最大值
#         MaxHighstPrice = df.describe().values[7]
#     #    print MaxHighstPrice
#
#         #获取沪深股票个股最近一次日行情，默认日期区间是过去1年，包含昨收价、开盘价、最高价、最低价、收盘价、成交量、成交金额等字段，每日15:30更新。
#         Latehist = DataAPI.MktEqudLatelyGet(secID=i,ticker=u"",field="",pandas="1")
#     #    print Latehist['highestPrice'][0]
#
#         #判断最新值是否小于历史区间最大值得35%
#         if Latehist['highestPrice'][0] < MaxHighstPrice * 0.35 :
#             print i
