# %% [markdown]
# # Notebook

# %%
API取得数据前复权的，context.history()取的也是前复权的，为啥这俩不一样

# %%
import numpy as np
import pandas as pd
from pandas import *
beginDate="20140101"
endDate="20140110"
data1=DataAPI.MktEqudAdjGet(tradeDate=u"",secID=u"",ticker=u"601169",beginDate=beginDate,endDate=endDate,isOpen="",field=['tradeDate',"closePrice"],pandas="1")
data1
# Out:
#     tradeDate  closePrice
# 0  2014-01-02       3.258
# 1  2014-01-03       3.206
# 2  2014-01-06       3.166
# 3  2014-01-07       3.162
# 4  2014-01-08       3.166
# 5  2014-01-09       3.162
# 6  2014-01-10       3.149

# %% [raw]
# start = '2014-01-03'                       # 回测起始时间
# end = '2014-01-10'                         # 回测结束时间
# universe = ['601169.XSHG']    # 证券池，支持股票、基金、期货、指数四种资产
# bj = ['601169.XSHG']
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=100000)
# }
# def initialize(context):
#     pass
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     previous_date = context.previous_date.strftime('%Y-%m-%d')
#     account = context.get_account('fantasy_account')
#     hist = context.history(symbol = 'all',time_range = 1,attribute = 'closePrice',freq = 'd',style = 'tas')[previous_date]['closePrice']
#     bj_price = hist[bj]
#     print previous_date,':   ',bj_price
