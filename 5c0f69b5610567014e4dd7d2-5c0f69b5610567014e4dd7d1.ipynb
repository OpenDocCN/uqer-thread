# %% [markdown]
# # 唐奇安通道

# %% [raw]
# import numpy as np
# import pandas as pd
# import talib
#
# start = '2017-06-01'                       # 回测起始时间
# end = '2018-01-01'                         # 回测结束时间
# universe = ['RB1801']
# benchmark = 'HS300'
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1
# max_history_window = 60
# high_time_range = 20
# low_time_range = 10
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'future_account': AccountConfig(account_type='futures', capital_base=1000000,margin_rate = 0.1)
# }
#
# def initialize(context):
#     pass
#
# def handle_data(context):
#     account = context.get_account('future_account')
#     universe = context.get_universe()
#     data = context.history(universe,['highPrice','lowPrice'],20,retype = 'array')
#     # log.info(data)
#     high_price = data[universe[0]]['highPrice']
#     # log.info(hight_price)
#     low_price = data[universe[0]]['lowPrice']
#
#     current_price = context.current_price(universe[0])
#     position = account.get_position(universe[0])
#     # log.info(position)
#
#     if not position:
#         if current_price > high_price[-20:-1].max():
#             account.order(universe[0],1)
#
#     else:
#         if current_price < low_price[-10:-1].min():
#             account.order_pct_to(universe[0],0)
