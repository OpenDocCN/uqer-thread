# %% [markdown]
# #

# %% [markdown]
# 这次分享下均线的一种买入策略，即
# 1）收盘价在30日线上方；
# 2）4日之前收盘价5日线下穿10日线死叉，二次握手再次上穿10日均线金叉买入；
# 3）破30日线卖出；

# %% [raw]
# # 导入包
# from CAL.PyCAL import *
# import numpy as np
# import pandas as pd
#
# universe = set_universe('A')
# freq = 'd'                              # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                          # 调仓频率
#
# start = '2014-1-1'
# end = '2016-7-1'
# benchmark = 'HS300'
# capital_base = 1000000
# commission = Commission(buycost=0.0008, sellcost=0.0018) # 佣金万八
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     hist = account.get_attribute_history('closePrice', 60)
#     for s in account.universe:
#         close_price = hist[s][-1]
#         ma30 = hist[s][-31:-1].mean()
#         ma10 = hist[s][-11:-1].mean()
#         ma5 = hist[s][-6:-1].mean()
#
#         if close_price > ma30 and s not in account.valid_secpos and ma5 > ma10:
#             len = 4
#             x = 0
#             while len>0:
#                 if hist[s][(-6-len):(-1-len)].mean()<hist[s][(-12-len):(-2-len)].mean():
#                     x+=1
#                 len-=1
#
#             if x == 4 and hist[s][(-7-4):(-2-4)].mean()>hist[s][(-12-4):(-2-4)].mean():
#                 position_per_stk = account.referencePortfolioValue/100
#                 amount = int(position_per_stk/account.referencePrice[s]/100.0) * 100
#                 order_to(s, amount)
#
#         elif close_price <= ma30 and s in account.valid_secpos:
#             order_to(s, 0)

# %%
    结果上可以看出策略在上涨时的速率还是比HS300快点；在行情较差时没有什么买入机会；震荡市策略表现较弱；
