# %% [markdown]
# # Notebook2

# %% [raw]
# import talib
# import pandas as pd
# import numpy as np
# start = '2017-02-01'                       # 回测起始时间
# end = '2017-05-24'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['RB1710']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 30                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# periodlong=40
# breakarange=5
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
# def handle_data(account):
#     all_data = get_symbol_history(universe[0], time_range=40)
#     if len(all_data) == 0:
#         return
#     close_price = np.array(all_data[universe[0]]['closePrice'])
#     if len(close_price) == 0:
#         return
#     current_data=get_symbol_history(universe[0],'1m', time_range=1)
#     current_price=np.array(current_data[universe[0]]['closePrice'])
#     #获取过去40个交易日的收盘价
#     MA = sum(close_price)/40
#
#
#     return
