# %% [markdown]
# #

# %%
x1 = DataAPI.MktEqumAdjGet(secID = '000301.XSHE' ,beginDate=u"20130101",field=u"secID,secShortName,endDate,highestPrice",pandas="1")
print x1.to_html()

x2 = DataAPI.MktEqumAdjGet(secID = '000100.XSHE' ,beginDate=u"20130101",field=u"secID,secShortName,endDate,highestPrice",pandas="1")
print x2.to_html()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>secID</th>
#       <th>secShortName</th>
#       <th>endDate</th>
#       <th>highestPrice</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>000301.XSHE</td>
#       <td>东方市场</td>
#       <td>2013-01-31</td>
#       <td>3.074</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>000301.XSHE</td>
#       <td>东方市场</td>
#       <td>2013-02-28</td>
#       <td>3.122</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>000301.XSHE</td>
#       <td>东方市场</td>
#       <td>2013-03-29</td>
#       <td>3.036</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>000301.XSHE</td>
#       <td>东方市场</td>
#       <td>2013-04-26</td>
#       <td>2.883</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>000301.XSHE</td>
#       <td>东方市场</td>
#       <td>2013-05-31</td>
#       <td>3.409</td>
#     </tr>
#     <tr>
# ...
