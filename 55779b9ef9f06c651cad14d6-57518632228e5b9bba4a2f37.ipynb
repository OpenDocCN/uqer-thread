# %% [markdown]
# # 求帮忙看下哪里出错

# %% [raw]
# from CAL.PyCAL import *
# from numpy import *
#
# start = '2014-12-01'                       # 回测起始时间
# end = '2015-05-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')  # 证券池，回测支持股票和基金
# capital_base = 1000000                      # 起始资金
# refresh_rate = 1                           # 调仓频率，即每 refresh_rate 个交易日执行一次 handle_data() 函数
# commission = Commission(buycost=0.0008, sellcost=0.0018)
#
# tickers = universe[:]
# for i in range(len(universe)):
#     tickers[i] = universe[i][0:6]
#
# used_factors = ['MA5', 'MA20']
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     today = account.current_date
#     today_str = today.strftime("%Y%m%d")
#
#     factor = DataAPI.MktStockFactorsOneDayGet(ticker=tickers, tradeDate=today_str, field=used_factors, pandas='1')
#     if(len(factor) == 0):
#         return
#     factor = factor.dropna()
#
#     for stock in account.universe:
#         stk = stock[0:5]
#         try:
#             ma5 = factor[factor.ticker == stk]['MA5'].iloc[0]
#             ma20 = factor[factor.ticker == stk]['MA20'].iloc[0]
#         except:
#             return
#
#         if ma5 > ma20 and stock not in account.valid_secpos:
#             order(stock, 100)
#         elif ma5 < ma20 and stock in account.valid_secpos:
#             order_to(stock, 0)
