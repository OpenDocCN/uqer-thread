# %% [markdown]
# # 定投-价值平均法

# %% [raw]
# #!/usr/bin/env python
# # -*- coding: utf-8 -*-
#
# '''
# 定投
# 价值平均法
# 每个月的第一个交易日加仓或减仓不定量股票，保证股票价值线性增长
# 比如第一个月价值10000,第二个月20000，第三个月30000
# 或按月增长1%，比如第一个月价值10100,第二个月20200，第三个月30300
# '''
#
# # 第一步：设置基本参数
# start = '2013-01-01'
# end   = '2016-04-01'
# capital_base = 360000
# refresh_rate = 1
# benchmark = 'HS300'
# freq = 'd'
#
# # 第二步：选择主题，设置股票池
# universe = ['510500.XSHG', ]
#
# def initialize(account):
#     account.has_buy = {}
#     account.step_value = 10000.0
#     account.step_ratio = 0.01
#
#
# def handle_data(account):
#     # 本策略将使用account的以下属性：
#     # account.universe表示当天，股票池中可以进行交易的证券池，剔除停牌退市等股票。
#     # account.referencePrice表示股票的参考价，一般使用的是上一日收盘价。
#
#     c_month = account.current_date.strftime("%Y-%m")
#     #本月买过了
#     if c_month in account.has_buy :
#         return
#
#     #当前价值
#     c_value = account.referencePortfolioValue - account.cash
#
#     #期望价值
#     e_value = (len(account.has_buy) + account.step_ratio + 1) * account.step_value
#
#     for stock in account.universe:
#         try :
#             buy_num = int((e_value - c_value) / (account.referencePrice[stock] * 100)) * 100
#             log.info('real:%.2f\texpect:%.2f\tmonth:%s\tbuy:%d\tprice:%.2f\tcash:%.2f' % (c_value, e_value, c_month, buy_num, account.referencePrice[stock], account.cash))
#         except :
#             return
#         order(stock, buy_num)
#
#         account.has_buy[c_month] = 1
