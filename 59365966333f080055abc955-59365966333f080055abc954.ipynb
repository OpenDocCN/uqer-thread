# %% [markdown]
# # Notebook0

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1,3,5,np.NAN,8,4])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    8.0
# 5    4.0
# dtype: float64

# %%
dates = pd.date_range('20170301',periods=6)
dates
# Out:
# DatetimeIndex(['2017-03-01', '2017-03-02', '2017-03-03', '2017-03-04',
#                '2017-03-05', '2017-03-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
data = pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))
data
# Out:
#                    A         B         C         D
# 2017-03-01  0.771640 -1.654628 -0.478172  0.368590
# 2017-03-02 -0.843155  0.284133 -0.107080  0.865098
# 2017-03-03  0.820202 -1.355505 -0.388932  0.332327
# 2017-03-04  1.145632 -0.097751 -0.220776  0.165702
# 2017-03-05  2.324077  0.982318 -1.563334 -0.215407
# 2017-03-06  1.724871  1.520556  0.327525  1.297468

# %%
data.shape
# Out:
# (6, 4)

# %%
data.values
# Out:
# array([[ 0.7716403 , -1.65462797, -0.47817247,  0.36859043],
#        [-0.84315536,  0.28413254, -0.10708015,  0.86509751],
#        [ 0.82020177, -1.35550481, -0.38893222,  0.33232719],
#        [ 1.14563162, -0.09775075, -0.22077558,  0.16570214],
#        [ 2.32407724,  0.98231784, -1.56333422, -0.21540674],
#        [ 1.72487142,  1.52055568,  0.32752491,  1.29746829]])

# %%
d = {'A':1,'B':pd.Timestamp('20170606'),'C':range(4),'D':np.arange(4)}
d
# Out:
# {'A': 1,
#  'B': Timestamp('2017-06-06 00:00:00'),
#  'C': [0, 1, 2, 3],
#  'D': array([0, 1, 2, 3])}

# %%
df = pd.DataFrame(d)
df
# Out:
#    A          B  C  D
# 0  1 2017-06-06  0  0
# 1  1 2017-06-06  1  1
# 2  1 2017-06-06  2  2
# 3  1 2017-06-06  3  3

# %%
df.dtypes
# Out:
# A             int64
# B    datetime64[ns]
# C             int64
# D             int64
# dtype: object

# %%
df.B
# Out:
# 0   2017-06-06
# 1   2017-06-06
# 2   2017-06-06
# 3   2017-06-06
# Name: B, dtype: datetime64[ns]

# %%
type(df.B)
# Out:
# pandas.core.series.Series

# %%
data.head()
data.head(2)
data.tail()
data.tail(2)
# Out:
#                    A         B         C         D
# 2017-03-05  2.324077  0.982318 -1.563334 -0.215407
# 2017-03-06  1.724871  1.520556  0.327525  1.297468

# %%
data.index
# Out:
# DatetimeIndex(['2017-03-01', '2017-03-02', '2017-03-03', '2017-03-04',
#                '2017-03-05', '2017-03-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
data.columns
# Out:
# Index([u'A', u'B', u'C', u'D'], dtype='object')

# %%
data.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.990544 -0.053480 -0.405128  0.468963
# std    1.075266  1.258996  0.633504  0.535241
# min   -0.843155 -1.654628 -1.563334 -0.215407
# 25%    0.783781 -1.041066 -0.455862  0.207358
# 50%    0.982917  0.093191 -0.304854  0.350459
# 75%    1.580061  0.807772 -0.135504  0.740971
# max    2.324077  1.520556  0.327525  1.297468

# %%
data.T
# Out:
#    2017-03-01  2017-03-02  2017-03-03  2017-03-04  2017-03-05  2017-03-06
# A    0.771640   -0.843155    0.820202    1.145632    2.324077    1.724871
# B   -1.654628    0.284133   -1.355505   -0.097751    0.982318    1.520556
# C   -0.478172   -0.107080   -0.388932   -0.220776   -1.563334    0.327525
# D    0.368590    0.865098    0.332327    0.165702   -0.215407    1.297468

# %%
data.T.shape
# Out:
# (4, 6)

# %%
data
# Out:
#                    A         B         C         D
# 2017-03-01  0.771640 -1.654628 -0.478172  0.368590
# 2017-03-02 -0.843155  0.284133 -0.107080  0.865098
# 2017-03-03  0.820202 -1.355505 -0.388932  0.332327
# 2017-03-04  1.145632 -0.097751 -0.220776  0.165702
# 2017-03-05  2.324077  0.982318 -1.563334 -0.215407
# 2017-03-06  1.724871  1.520556  0.327525  1.297468

# %%
 # 排序
data.sort_index(axis=1,ascending=False)
# Out:
#                    D         C         B         A
# 2017-03-01  0.368590 -0.478172 -1.654628  0.771640
# 2017-03-02  0.865098 -0.107080  0.284133 -0.843155
# 2017-03-03  0.332327 -0.388932 -1.355505  0.820202
# 2017-03-04  0.165702 -0.220776 -0.097751  1.145632
# 2017-03-05 -0.215407 -1.563334  0.982318  2.324077
# 2017-03-06  1.297468  0.327525  1.520556  1.724871

# %%
data.sort_index(axis=0,ascending=False)
# Out:
#                    A         B         C         D
# 2017-03-06  1.724871  1.520556  0.327525  1.297468
# 2017-03-05  2.324077  0.982318 -1.563334 -0.215407
# 2017-03-04  1.145632 -0.097751 -0.220776  0.165702
# 2017-03-03  0.820202 -1.355505 -0.388932  0.332327
# 2017-03-02 -0.843155  0.284133 -0.107080  0.865098
# 2017-03-01  0.771640 -1.654628 -0.478172  0.368590

# %%
data.sort_values(by='A')
# Out:
#                    A         B         C         D
# 2017-03-02 -0.843155  0.284133 -0.107080  0.865098
# 2017-03-01  0.771640 -1.654628 -0.478172  0.368590
# 2017-03-03  0.820202 -1.355505 -0.388932  0.332327
# 2017-03-04  1.145632 -0.097751 -0.220776  0.165702
# 2017-03-06  1.724871  1.520556  0.327525  1.297468
# 2017-03-05  2.324077  0.982318 -1.563334 -0.215407

# %%
# 数据选择
data['A']
# Out:
# 2017-03-01    0.771640
# 2017-03-02   -0.843155
# 2017-03-03    0.820202
# 2017-03-04    1.145632
# 2017-03-05    2.324077
# 2017-03-06    1.724871
# Freq: D, Name: A, dtype: float64

# %%
# 行
data[2:4]
# Out:
#                    A         B         C         D
# 2017-03-03  0.820202 -1.355505 -0.388932  0.332327
# 2017-03-04  1.145632 -0.097751 -0.220776  0.165702

# %%
data['20170303':'20170304']
# Out:
#                    A         B         C         D
# 2017-03-03  0.820202 -1.355505 -0.388932  0.332327
# 2017-03-04  1.145632 -0.097751 -0.220776  0.165702

# %%
# .loc(只认标签，效率较高)
data.loc['20170303':'20170304']
# Out:
#                    A         B         C         D
# 2017-03-03  0.820202 -1.355505 -0.388932  0.332327
# 2017-03-04  1.145632 -0.097751 -0.220776  0.165702

# %%
data.iloc[2:4]
# Out:
#                    A         B         C         D
# 2017-03-03  0.820202 -1.355505 -0.388932  0.332327
# 2017-03-04  1.145632 -0.097751 -0.220776  0.165702

# %%
data.loc[:,['B','C']]
# Out:
#                    B         C
# 2017-03-01 -1.654628 -0.478172
# 2017-03-02  0.284133 -0.107080
# 2017-03-03 -1.355505 -0.388932
# 2017-03-04 -0.097751 -0.220776
# 2017-03-05  0.982318 -1.563334
# 2017-03-06  1.520556  0.327525

# %%
data.loc['20170303':'20170304',['B','C']]
# Out:
#                    B         C
# 2017-03-03 -1.355505 -0.388932
# 2017-03-04 -0.097751 -0.220776

# %%
data.loc['20170303','B']
# Out:
# -1.3555048128748619

# %%
data.iloc[1]
# Out:
# A   -0.843155
# B    0.284133
# C   -0.107080
# D    0.865098
# Name: 2017-03-02 00:00:00, dtype: float64

# %%
data.iloc[1:3,2:4]
# Out:
#                    C         D
# 2017-03-02 -0.107080  0.865098
# 2017-03-03 -0.388932  0.332327

# %%
data.iloc[1,1]
# Out:
# 0.28413253755079904

# %%
data[data.A > 0]
# Out:
#                    A         B         C         D
# 2017-03-01  0.771640 -1.654628 -0.478172  0.368590
# 2017-03-03  0.820202 -1.355505 -0.388932  0.332327
# 2017-03-04  1.145632 -0.097751 -0.220776  0.165702
# 2017-03-05  2.324077  0.982318 -1.563334 -0.215407
# 2017-03-06  1.724871  1.520556  0.327525  1.297468

# %%
data[data > 0]
# Out:
#                    A         B         C         D
# 2017-03-01  0.771640       NaN       NaN  0.368590
# 2017-03-02       NaN  0.284133       NaN  0.865098
# 2017-03-03  0.820202       NaN       NaN  0.332327
# 2017-03-04  1.145632       NaN       NaN  0.165702
# 2017-03-05  2.324077  0.982318       NaN       NaN
# 2017-03-06  1.724871  1.520556  0.327525  1.297468

# %%
data2 = data.copy()
data2
# Out:
#                    A         B         C         D
# 2017-03-01  0.771640 -1.654628 -0.478172  0.368590
# 2017-03-02 -0.843155  0.284133 -0.107080  0.865098
# 2017-03-03  0.820202 -1.355505 -0.388932  0.332327
# 2017-03-04  1.145632 -0.097751 -0.220776  0.165702
# 2017-03-05  2.324077  0.982318 -1.563334 -0.215407
# 2017-03-06  1.724871  1.520556  0.327525  1.297468

# %%
tag = ['a']*2 + ['b']*2 + ['c']*2
tag
# Out:
# ['a', 'a', 'b', 'b', 'c', 'c']

# %%
data2['tag'] = tag
data2
# Out:
#                    A         B         C         D tag
# 2017-03-01  0.771640 -1.654628 -0.478172  0.368590   a
# 2017-03-02 -0.843155  0.284133 -0.107080  0.865098   a
# 2017-03-03  0.820202 -1.355505 -0.388932  0.332327   b
# 2017-03-04  1.145632 -0.097751 -0.220776  0.165702   b
# 2017-03-05  2.324077  0.982318 -1.563334 -0.215407   c
# 2017-03-06  1.724871  1.520556  0.327525  1.297468   c

# %%
data2[data2.tag.isin(['a','c'])]
# Out:
#                    A         B         C         D tag
# 2017-03-01  0.771640 -1.654628 -0.478172  0.368590   a
# 2017-03-02 -0.843155  0.284133 -0.107080  0.865098   a
# 2017-03-05  2.324077  0.982318 -1.563334 -0.215407   c
# 2017-03-06  1.724871  1.520556  0.327525  1.297468   c

# %%
# 元素修改
data
data.iloc[0,0] = 100
data
# Out:
#                      A         B         C         D
# 2017-03-01  100.000000 -1.654628 -0.478172  0.368590
# 2017-03-02   -0.843155  0.284133 -0.107080  0.865098
# 2017-03-03    0.820202 -1.355505 -0.388932  0.332327
# 2017-03-04    1.145632 -0.097751 -0.220776  0.165702
# 2017-03-05    2.324077  0.982318 -1.563334 -0.215407
# 2017-03-06    1.724871  1.520556  0.327525  1.297468

# %%
data.A = range(6)
data
# Out:
#             A         B         C         D
# 2017-03-01  0 -1.654628 -0.478172  0.368590
# 2017-03-02  1  0.284133 -0.107080  0.865098
# 2017-03-03  2 -1.355505 -0.388932  0.332327
# 2017-03-04  3 -0.097751 -0.220776  0.165702
# 2017-03-05  4  0.982318 -1.563334 -0.215407
# 2017-03-06  5  1.520556  0.327525  1.297468

# %%
data.B = 200
data
# Out:
#             A    B         C         D
# 2017-03-01  0  200 -0.478172  0.368590
# 2017-03-02  1  200 -0.107080  0.865098
# 2017-03-03  2  200 -0.388932  0.332327
# 2017-03-04  3  200 -0.220776  0.165702
# 2017-03-05  4  200 -1.563334 -0.215407
# 2017-03-06  5  200  0.327525  1.297468

# %%
data.iloc[:,2:4] = 1000
data
# Out:
#             A    B     C     D
# 2017-03-01  0  200  1000  1000
# 2017-03-02  1  200  1000  1000
# 2017-03-03  2  200  1000  1000
# 2017-03-04  3  200  1000  1000
# 2017-03-05  4  200  1000  1000
# 2017-03-06  5  200  1000  1000
