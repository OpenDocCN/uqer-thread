# %% [markdown]
# # 为什么交易基金会有这样的问题？

# %% [raw]
# from  CAL.PyCAL import *
# start = '2012-04-29'                       # 回测起始时间
# end = '2015-03-29'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['510210.XSHG']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     cal = Calendar('China.SSE')
#     today = Date(account.current_date.year, account.current_date.month, account.current_date.day)
#     yestday =  cal.advanceDate(today, '-1B', BizDayConvention.Following)
#     needDay = cal.advanceDate(today, '-200B', BizDayConvention.Following)
#     fields = ['closeIndex', 'openIndex', 'highestIndex', 'lowestIndex', 'ticker', 'preCloseIndex', 'tradeDate']
#     index = DataAPI.MktIdxdGet(ticker = '000001', beginDate=needDay.toISO().replace('-', ''),endDate = yestday.toISO().replace('-', ''), field = fields)
#     print ("------------------------today:%s")%(yestday)
#     get_stock_risk(index,account)
#     #print account.universe
#     #print ("今天市场状态:%f,    今天最终仓位:%f")%(account.marketState, account.todayPosition)
#     print ('--------------------------stock:%s')%(account.universe)
#     order_pct_to(account.universe[0], account.todayPosition)
#
#     return
