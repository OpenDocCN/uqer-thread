# %% [markdown]
# # Testing

# %% [raw]
# # 导入包
# from CAL.PyCAL import *
# import numpy as np
# import pandas as pd
#
# start = '2020-01-01'
# end = '2022-01-01'
# universe = set_universe('HS300')
# benchmark = 'HS300'
# capital_base = 10000000
# freq = 'd'
# refresh_rate = 122
# commission = Commission(buycost=0.0002, sellcost=0.0012, unit='perValue')
#
# # 日期处理相关
# cal = Calendar('China.SSE')
# period = Period('-1B')
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     HS300 = DataAPI.MktStockFactorsOneDayGet(tradeDate=account.current_date,secID=account.universe,field=['secID'],pandas="1")
#     HS300 = HS300.iloc[:50, :]
#
#     # 先卖出
#     #sell_list = account.security_position
#     #for stk in sell_list:
#     #    account.order_to(stk, 0)
#     account.close_all_positions()
#
#     # 再买入
#     buy_list = HS300['secID']
#     total_money = account.referencePortfolioValue
#     prices = account.referencePrice
#     for stk in buy_list:
#         if np.isnan(prices[stk]) or prices[stk] == 0:  # 停牌或是还没有上市等原因不能交易
#             continue
#         account.order(stk, 100)
