# %% [markdown]
# #

# %% [raw]
# # 第一步：设置基本参数
# start = '2015-05-12'
# end = '2016-05-16'
# benchmark = 'HS300'
# capital_base = 100000
# freq = 'd'
# refresh_rate = 1
#
# # 第二步：选择因子，设置股票池
# universe = StockScreener( Factor.DilutedEPS.num_range(1,200) & Factor.NetProfitGrowRate.num_range(1,300) & Factor.CurrentAssetsTRate.num_range(1,500) & Factor.FY12P.num_range(1,500) )
# import numpy as np
# def initialize(account):
#     pass
#
# def handle_data(account):
#     # 生成买入列表
#     last_date = account.previous_date.strftime("%Y-%m-%d")
#     last_screener = universe.preview(last_date)
#     buylist = [sec for sec in last_screener if sec in account.universe]
#     d = len(buylist)
#
#     print account.current_date, account.previous_date, buylist
#
#     # 卖出不在买入列表中的股票，估计持仓价值
#     for stock in account.valid_secpos:
#         if stock not in buylist and stock in account.universe:
#             order_to(stock, 0)
#
#     # 获得调仓数量
#     v = account.referencePortfolioValue
#     change = {}
#     for stock in buylist:
#         p = account.referencePrice[stock]
#         if p and not np.isnan(p):
#             change[stock] = int(v / d / p) - account.valid_secpos.get(stock, 0)
#
#     # 按先卖后买的顺序发出指令
#     for stock in sorted(change, key=change.get):
#         print stock, change[stock]
#         order(stock, change[stock])
