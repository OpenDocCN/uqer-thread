# %% [markdown]
# # Notebook0

# %%
nav1=DataAPI.FundNavGet(dataDate='',secID='210007.OFCN',ticker=u"",beginDate=u"20150702",endDate=u"20151201",field=[],pandas="1")
nav1
# Out:
#          secID  ticker  secShortName     endDate     NAV publishDate  \
# 0  210007.OFCN  210007  金鹰中证技术领先指数增强  2015-07-02  1.7475  2015-07-03
# 1  210007.OFCN  210007  金鹰中证技术领先指数增强  2015-07-03  1.6724  2015-07-04
# 2  210007.OFCN  210007  金鹰中证技术领先指数增强  2015-07-06  1.6390  2015-07-07
# 3  210007.OFCN  210007  金鹰中证技术领先指数增强  2015-07-07  1.5291  2015-07-08
# 4  210007.OFCN  210007  金鹰中证技术领先指数增强  2015-07-08  1.0000  2015-07-09
#
#    ACCUM_NAV currencyCd  ADJUST_NAV
# 0     1.7475        CNY      1.7475
# 1     1.6724        CNY      1.6724
# 2     1.6390        CNY      1.6390
# 3     1.5291        CNY      1.5291
# 4     1.4540        CNY      1.4535
