# %% [markdown]
# # Notebook0

# %%
from CAL.PyCAL import *
cal = Calendar('China.SSE')
period = Period('-10D')
end_Date=Date(2017,9,15)
begin_Date=cal.advanceDate(end_Date,period,BizDayConvention.Following)
begin_Date1=cal.advanceDate(end_Date,period)
begin_Date,begin_Date1
# Out:
# (Date(2017,9,5), Date(2017,9,5))
