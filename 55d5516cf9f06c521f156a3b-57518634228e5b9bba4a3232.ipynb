# %% [markdown]
# # 求教作图问题0

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
stock_list = ['000001.XSHE', '000002.XSHE', '000568.XSHE', '000625.XSHE', '000768.XSHE', '600028.XSHG', '600030.XSHG', '601111.XSHG', '601390.XSHG', '601998.XSHG']
raw_data = DataAPI.MktEqudGet(secID=stock_list, beginDate='20150101', endDate='20150731', pandas='1')
df = raw_data[['secID', 'tradeDate','closePrice']]
dat = df[df['secID'] == '600028.XSHG'].set_index('tradeDate')['closePrice']
dat1=df[df['secID']=='000001.XSHE'].set_index('tradeDate')['closePrice']
t=dat.plot('ZHSH')
s=dat1.plot('WK')
plot.title('ZHSH vs WK')
plot.xlable('tradeDate')
plot.ylable('closePrice')
plot.legend([t,s],('red','green'),'best',numpoints=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <mercury-input-9-21e1056076c4> in <module>()
#       9 t=dat.plot('ZHSH')
#      10 s=dat1.plot('WK')
# ---> 11 plot.title('ZHSH vs WK')
#      12 plot.xlable('tradeDate')
#      13 plot.ylable('closePrice')
#
# NameError: name 'plot' is not defined
