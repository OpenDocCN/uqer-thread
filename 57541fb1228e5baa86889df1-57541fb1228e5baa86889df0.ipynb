# %% [markdown]
# #

# %% [markdown]
# 今天想试试周五升级更新的技术因子们，结果老是报错：
# Exception: -4:Internal server Error for request: Please try again, or check the input parameters
# 导入之前那些因子倒是没什么问题，请问这是什么原因？

# %% [markdown]
# 首先尝试一下以前的因子，可以导出成功：

# %%
universe = set_universe("SH50")
field = ['secID', 'REC']
df = DataAPI.MktStockFactorsOneDayGet(tradeDate='20160601',secID=universe,field=field,pandas="1")
df.head()
# Out:
#          secID     REC
# 0  600000.XSHG  1.8540
# 1  600010.XSHG  1.8877
# 2  600015.XSHG  1.7013
# 3  600016.XSHG  1.8631
# 4  600028.XSHG  1.6319

# %% [markdown]
# 再尝试一下前两天升级增加的因子，报错：

# %%
universe = set_universe("SH50")
field = ['secID', 'Aroon']
df = DataAPI.MktStockFactorsOneDayGet(tradeDate='20160601',secID=universe,field=field,pandas="1")
df.head()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <mercury-input-26-79739d91a835> in <module>()
#       1 universe = set_universe("SH50")
#       2 field = ['secID', 'Aroon']
# ----> 3 df = DataAPI.MktStockFactorsOneDayGet(tradeDate='20160601',secID=universe,field=field,pandas="1")
#       4 df.head()
#
# python2.7/site-packages/DataAPI/DATAYES.pyc in MktStockFactorsOneDayGet(tradeDate, secID, ticker, field, pandas)
#    2920
#    2921         if csvString is None or len(csvString) == 0 or (csvString[0] == '-' and csvString[1] != '1') or csvString[0] == '{':
# -> 2922             raise Exception(('%s for request: %s' % (csvString if csvString is not None else 'Query Error', 'Please try again, or check the input parameters')))
#    2923         elif csvString[:2] == '-1':
#    2924             csvString = ''
#
# ...

# %% [markdown]
# 再尝试另外一个，同样报错：

# %%
universe = set_universe("SH50")
field = ['secID', 'PVT']
df = DataAPI.MktStockFactorsOneDayGet(tradeDate='20160601',secID=universe,field=field,pandas="1")
df.head()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <mercury-input-27-b031a573ad6f> in <module>()
#       1 universe = set_universe("SH50")
#       2 field = ['secID', 'PVT']
# ----> 3 df = DataAPI.MktStockFactorsOneDayGet(tradeDate='20160601',secID=universe,field=field,pandas="1")
#       4 df.head()
#
# python2.7/site-packages/DataAPI/DATAYES.pyc in MktStockFactorsOneDayGet(tradeDate, secID, ticker, field, pandas)
#    2920
#    2921         if csvString is None or len(csvString) == 0 or (csvString[0] == '-' and csvString[1] != '1') or csvString[0] == '{':
# -> 2922             raise Exception(('%s for request: %s' % (csvString if csvString is not None else 'Query Error', 'Please try again, or check the input parameters')))
#    2923         elif csvString[:2] == '-1':
#    2924             csvString = ''
#
# ...
