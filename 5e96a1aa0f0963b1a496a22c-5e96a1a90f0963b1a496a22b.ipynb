# %% [markdown]
# # 第一天

# %% [markdown]
# 一、熟悉基本

# %% [markdown]
# (1)基本的输入输出

# %%
1+3*3
# Out:
# 10

# %% [markdown]
# （2）导入模块,就可以使用模块下面的函数了

# %%
import math
math.sqrt(9)
# Out:
# 3.0

# %%
from math import sqrt
sqrt(9)
# Out:
# 3.0

# %%
from math import *
print sqrt(9)
print floor(32.9)
# Out:
# 3.0
# 32.0

# %% [markdown]
# 二、容器
# python中有一种名为容器的数据结构。容器就是装数据的器具，主要包括序列和词典，其中序列又主要包括列表、元组、字符串等。
# 列表的基本形式比如：[1,3,6,10]或者[‘yes’,’no’,’OK’]
# 元组的基本形式比如：(1,3,6,10)或者(‘yes’,’no’,’OK’)
# 字符串的基本形式比如：’hello’
# 以上几种属于序列，序列中的每一个元素都被分配一个序号——即元素的位置，也称为“索引”，第一个索引，即第一个元素的位置是0，第二个是1，依次类推。列表和元组的区别主要在于，列表可以修改，而元组不能（注意列表用中括号而元组用括号）。序列的这个特点，使得我们可以利用索引来访问序列中的某个或某几个元素，比如：

# %%
a=[1,3,6,10]
a[2]
# Out:
# 6

# %%
b=(1,3,6,10)
b[2]
# Out:
# 6

# %%
c='hello'
c[0:3]
# Out:
# 'hel'

# %% [markdown]
# 而与序列对应的“字典”则不一样，它是一个无序的容器，
# 它的基本形式比如：d={7:‘seven’,8:‘eight’,9:‘nine’}
# 这是一个“键—值”映射的结构，因此字典不能通过索引来访问其中的元素，而要根据键来访问其中的元素：

# %%
d={7:'seven',8:'eight',9:'nine'}
d[8]
# Out:
# 'eight'

# %%
[1,2,3]+[4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
'hello,'+'world!'
# Out:
# 'hello,world!'

# %% [markdown]
# 检查一个值是否在序列中，可以用in运算符

# %%
a='hello'
print 'o' in a
# Out:
# True

# %%
3、列表的操作

# %%
list函数可以把一个序列转换成一个列表

# %%
list('hello')
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
#元素赋值、删除
a
# Out:
# 'hello'

# %%
b=list(a)
b
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
del b[2]
b
# Out:
# ['h', 'e', 'l', 'o']

# %%
b[2]='t'
b
# Out:
# ['h', 'e', 't', 'o']

# %%
#分片赋值--a[开始索引号：结束索引号]=list(值)
a='hello'
b=list(a)
b
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
b[2:4]=list('yy')
b
# Out:
# ['h', 'e', 'y', 'y', 'o']

# %%
b.insert(2,'t')
b
# Out:
# ['h', 'e', 't', 'y', 'y', 'o']

# %%
b.append('m')
b
# Out:
# ['h', 'e', 't', 'y', 'y', 'o', 'm']

# %%
b.index('e')
# Out:
# 1

# %%
b.reverse()
b
# Out:
# ['m', 'o', 'y', 'y', 't', 'e', 'h']

# %%
b.sort()
b
# Out:
# ['e', 'h', 'm', 'o', 't', 'y', 'y']

# %% [markdown]
# 4.字符串操作
# （1）字符串的转换
# 主要指的是转换字符串的宽度（占多少位）、精度、类型。

# %%
print('%10.2f'%e)
print('%.5f'%e)
print('%-10.10f'%e)
# Out:
#       2.72
# 2.71828
# 2.7182818285

# %% [markdown]
# (2)字符串的方法

# %%
a='hello'
a.find('e')
# Out:
# 1

# %%
'+'.join(a)
# Out:
# 'h+e+l+l+o'

# %%
'TT'.lower()
# Out:
# 'tt'

# %%
a.title()
# Out:
# 'Hello'

# %%
a.replace('h','p')
# Out:
# 'pello'

# %% [markdown]
# 5.字典操作
# （1）dict函数创建字典

# %%
dict(name = 'jia',age=27)
# Out:
# {'age': 27, 'name': 'jia'}

# %%
a=[1,3,6,10]
f={'age':27,'name':'shushuo'}

# %%
len(a)
len(f)
# Out:
# 2

# %%
a[1]
f['age']
# Out:
# 27

# %%
f['age']=28
f
# Out:
# {'age': 28, 'name': 'shushuo'}

# %% [markdown]
# 第一天学习了python的基本页面，操作，以及几种主要的容器类型
