# %% [markdown]
# # sample

# %%
DataAPI.EquGet(secID=u"", ticker=u"000043,001914", equTypeCD=u"A", listStatusCD=u"", exchangeCD="", ListSectorCD=u"", field=u"secID,ticker,secShortName,exchangeCD,listDate,delistDate,listStatusCD",pandas="1")
# Out:
#           secID  ticker secShortName exchangeCD    listDate  delistDate  \
# 0   000043.XSHE  001914         招商积余       XSHE  1994-09-28         NaN
# 1  000043.XSHE2  000043         中航善达       XSHE  1994-09-28  2019-12-16
#
#   listStatusCD
# 0            L
# 1           DE

# %% [markdown]
# 股票代码变更

# %%
DataAPI.SecChgHistoryGet(secID=u"",ticker=u"000043,001914",endDate="",chgTypeCD=u"0111", history=u"", assetClass=u"E", exchangeCD=u"XSHG,XSHE",field=u"",pandas="1")
# Out:
#          secID  ticker changType   value   beginDate     endDate secShortName  \
# 0  000043.XSHE  001914      代码变更  000043  1994-09-28  2019-12-15         招商积余
# 1  000043.XSHE  001914      代码变更  001914  2019-12-16         NaN         招商积余
#
#   assetClass exchangeCD
# 0          E       XSHE
# 1          E       XSHE
