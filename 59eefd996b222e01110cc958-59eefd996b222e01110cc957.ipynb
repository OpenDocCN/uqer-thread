# %% [markdown]
# # Notebook6

# %%
from __future__ import division
import quartz_futures as qf
from quartz_futures.api import *
from CAL.PyCAL import *
import numpy as np
import math
import datetime
import talib
import matplotlib.pyplot as plt 
import pandas as pd
from statsmodels.tsa.stattools import adfuller
import re

data = DataAPI.MktMFutdGet(mainCon=1,contractObject=u"",startDate=u"20150101",endDate=u"20171023",field=u"",pandas="1")
data_y = data[data.contractObject=='CS'].closePrice.reset_index(drop=True)
data_p = data[data.contractObject=='C'].closePrice.reset_index(drop=True)
datep = data[data.contractObject=='C']['tradeDate']
datep = [datetime.datetime.strptime(x, "%Y-%m-%d").date() for x in datep]

# 回归分析
from sklearn import datasets,linear_model
from scipy import stats
slope, intercept, r_value, p_value, slope_std_error = stats.linregress(data_p.values, data_y.values)
predict_y = intercept + slope * data_p.values
pred_error = data_y.values - predict_y
dftest = adfuller(pred_error.diff(1)[1:])##残差不能做一阶差分吗
dftest
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <mercury-input-5-B9A8B273685F49CE8F11AC52BC80C401> in <module>()
#      24 predict_y = intercept + slope * data_p.values
#      25 pred_error = data_y.values - predict_y
# ---> 26 dftest = adfuller(pred_error.diff(1)[1:])
#      27 dftest
#
# AttributeError: 'numpy.ndarray' object has no attribute 'diff'
