# %% [markdown]
# # 连涨三天买，连跌三天卖行吗？

# %%
from CAL.PyCAL import  *
cal = Calendar('China.SSE')
import datetime

# %% [raw]
# start = '2012-07-01'                       # 回测起始时间
# end = '2020-01-01'                         # 回测结束时间
# universe = ['510300.XSHG']        # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
#
# Index300 = DataAPI.MktIdxdGet(indexID = '000300.ZICN', beginDate = cal.advanceDate(start,Period('-100B')).strftime('%Y-%m-%d'),
#                            endDate = datetime.datetime.strptime(end, '%Y-%m-%d'),
#                            field = ['tradeDate', 'closeIndex', 'openIndex', 'highestIndex', 'lowestIndex', 'CHGPct', 'turnoverVol'], pandas = "1").dropna()
# # 配置账户信息
# accounts = {
# 	'security_account': AccountConfig(account_type = 'security', capital_base = 500000,
#                                       commission = Commission(buycost = 0.001, sellcost = 0.002, unit = 'perValue'),
#                                       slippage = Slippage(value = 0.0001, unit = 'perValue'))
# }
#
# def initialize(context):
#     pass
#
# #每天调用一次
# def handle_data(context):
#     account = context.get_account('security_account')
#     now = str(context.current_date.date())
#     now_index = Index300.loc[Index300['tradeDate']==now].index.tolist()[0]
#     _1_now_pct = Index300[Index300.index == now_index - 1]['CHGPct'].tolist()[0]
#     _2_now_pct = Index300[Index300.index == now_index - 2]['CHGPct'].tolist()[0]
#     _3_now_pct = Index300[Index300.index == now_index - 3]['CHGPct'].tolist()[0]
#
#     for stk in universe:
#         if _1_now_pct < 0 and _2_now_pct < 0 and _3_now_pct < 0:
#             account.order_to(stk, 0)
#         if _1_now_pct > 0 and _2_now_pct > 0 and _3_now_pct > 0:
#             account.order_pct_to(stk, 1.0)
