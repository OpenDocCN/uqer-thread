# %% [markdown]
# #

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("data_test.csv")
del data['Unnamed: 0']

# %%
data.head()
# Out:
#          secID  tradeDate  FiftyTwoWeekHigh  DilutedEPS  FixAssetRatio  \
# 0  000001.XSHE  2015/4/30         -1.960999   -0.119958      -0.018429
# 1  000002.XSHE  2015/4/30          0.092464   -1.460257      -0.346811
# 2  000009.XSHE  2015/4/30          0.672171   -0.213034       0.586573
# 3  000039.XSHE  2015/4/30          0.166958    0.399965       0.559304
# 4  000060.XSHE  2015/4/30         -0.263445   -0.343835       0.433872
#
#    GrossIncomeRatio      MA10       MA5        PB       ROA     VOL20  \
# 0         -0.867305  0.336287  0.305621  0.114080 -0.045742 -0.182639
# 1         -0.348230 -0.036461 -0.025932  1.025448 -0.369725  0.230257
# 2          0.618431  0.250871  0.276322  1.136892 -0.048373 -0.100226
# 3         -0.657171  1.096844  1.086075 -0.504480 -0.279391  0.066908
# 4         -0.720072  0.148362  0.131073  0.196517 -0.019562  0.214868
#
#        VOL5     HBETA  Skewness     Yield  lables    proba0    proba1
# ...

# %%
from CAL.PyCAL import *

# %%
TradeDate=['2015/4/30','2015/5/29','2015/6/30', '2015/7/31','2015/8/31','2015/9/30','2015/10/30',
    '2015/11/30','2015/12/31','2016/1/29','2016/2/29','2016/3/31','2016/4/29','2016/5/31', 
    '2016/6/30','2016/7/29','2016/8/31']
buy_list=[]
for i in TradeDate:
    temp=data[data.tradeDate==i]
    proba_df = temp.sort(columns='proba1', ascending=False)[:10]
    buy_list.append(proba_df['secID'])

# %% [raw]
# start = '2015-03-29'                       # 回测起始时间
# end = '2016-10-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')           # 证券池，支持股票和基金
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate =1  # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# cal = Calendar('China.SSE')
# period = Period('-1B')
#
# commission = Commission(buycost=0.0008, sellcost=0.0018) # 佣金万八+印花税千一；滑点默认
# slippage = Slippage()
#
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
#
# date=DataAPI.TradeCalGet(exchangeCD=u"XSHG",beginDate=u"20150329",endDate=u"20161001",field=['calendarDate','isMonthEnd'],pandas="1")
# date = date[date['isMonthEnd'] == 1]
# date_list = date['calendarDate'].values.tolist()
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     yesterday = account.previous_date
#     if yesterday.strftime('%Y-%m-%d') in date_list:  #如果前天在date_list中，也就是在月末，相当于这个策略每个月末调整一次仓位
#         buylist=[]
#         for stock in buy_list[1]:
#             if stock in account.universe:
#                 buylist.append(stock)
#         for stock in account.avail_secpos.keys():
#             if stock in account.universe and stock not in buylist:
#                 order_to(stock,0)
#         for stock in buylist:
#             order_pct_to(stock,1./len(buylist))
#         return
