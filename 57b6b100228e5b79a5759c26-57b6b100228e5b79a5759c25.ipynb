# %% [markdown]
# #

# %%
DataAPI.MktIdxdGet(ticker=u"399001",beginDate=u"20160701",endDate=u"20160801",field=u"",pandas="1")
# Out:
#         indexID  ticker porgFullName secShortName exchangeCD   tradeDate  \
# 0   399001.ZICN  399001      深圳证券交易所         深证成指       XSHE  2016-07-01
# 1   399001.ZICN  399001      深圳证券交易所         深证成指       XSHE  2016-07-04
# 2   399001.ZICN  399001      深圳证券交易所         深证成指       XSHE  2016-07-05
# 3   399001.ZICN  399001      深圳证券交易所         深证成指       XSHE  2016-07-06
# 4   399001.ZICN  399001      深圳证券交易所         深证成指       XSHE  2016-07-07
# 5   399001.ZICN  399001      深圳证券交易所         深证成指       XSHE  2016-07-08
# 6   399001.ZICN  399001      深圳证券交易所         深证成指       XSHE  2016-07-11
# 7   399001.ZICN  399001      深圳证券交易所         深证成指       XSHE  2016-07-12
# 8   399001.ZICN  399001      深圳证券交易所         深证成指       XSHE  2016-07-13
# 9   399001.ZICN  399001      深圳证券交易所         深证成指       XSHE  2016-07-14
# 10  399001.ZICN  399001      深圳证券交易所         深证成指       XSHE  2016-07-15
# 11  399001.ZICN  399001      深圳证券交易所         深证成指       XSHE  2016-07-18
# ...

# %% [markdown]
# 如20160801查到的深证成指的成交金额为1219亿，但是同花顺显示的2551亿，感觉差的有些远啊，数据是不是有问题
