# %% [markdown]
# # 反转策略

# %% [raw]
# import numpy as np
# import pandas as pd
# start = '2015-01-01'                       # 回测起始时间
# end = '2016-5-02'                         # 回测结束时间
# universe = set_universe('HS300')         # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate =Monthly(1,-1)                     # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):
#     pass
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     # 获取股票的数据
#     universe=context.get_universe('stock',exclude_halt
# =True)
#     hist=DataAPI.MktEqumGet(secID=universe,beginDate=u"2015-01-01",endDate=u"",isOpen=u"",pandas="1")
#     sec_val = {'symbol':[], 'chgPct':[]}
#     for index,row in hist.iterrows():
#         sec_val['symbol'].append(row['secID'])
#         sec_val['chgPct'].append(row['chgPct'])
#     sec_val=pd.DataFrame(sec_val).sort(columns='chgPct').reset_index()
#     sec_val = sec_val.sort('chgPct',ascending=False)
#     sec_val = sec_val.tail(10)#得到一个DataFrame
#     buylist=list(sec_val.symbol)
#     # 获取当前账户信息
#     account = context.get_account('fantasy_account')
#     current_position = account.get_positions(exclude_halt=True)
#     prices = account.reference_price
#
#     # 卖出当前持有，但目标持仓没有的部分
#     for stock in set(current_position).difference(buylist):
#         account.order_to(stock, 0)
#
#     # 根据目标持仓权重，逐一委托下单
#     for stock in buylist:
#         account.order(stock, 10000)
