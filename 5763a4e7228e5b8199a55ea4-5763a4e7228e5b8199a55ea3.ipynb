# %% [markdown]
# #

# %%
import pandas as pd
import numpy as np
onegpdata=DataAPI.MktEqudGet(tradeDate=u"",secID=u"000001.XSHE",ticker=u"",beginDate="20150819",endDate="20150829",isOpen="",field=u"openPrice,closePrice,highestPrice,lowestPrice,turnoverVol,turnoverValue,turnoverRate",pandas="1")

a=list(onegpdata["openPrice"] )
b=list(onegpdata["closePrice"] )
c=list(onegpdata["highestPrice"])
d=list(onegpdata["lowestPrice"])
e=list(onegpdata["turnoverVol"])
f=list(onegpdata["turnoverValue"])
g=list(onegpdata["turnoverRate"])
a[len(a):len(a)] = b
a[len(a):len(a)] = c
a[len(a):len(a)] = d
a[len(a):len(a)] = e
a[len(a):len(a)] = f
a[len(a):len(a)] = g
print len(a)
a
# Out:
# 56
# [12.1,
#  12.17,
#  11.9,
#  11.1,
#  9.8499999999999996,
#  9.5999999999999996,
#  10.16,
#  10.890000000000001,
#  12.23,
#  12.050000000000001,
#  11.5,
#  10.35,
#  9.4600000000000009,
#  9.9100000000000001,
#  10.800000000000001,
#  10.83,
#  12.23,
#  12.17,
#  11.99,
#  11.17,
#  10.35,
#  10.23,
#  10.9,
#  11.09,
#  11.9,
#  11.9,
#  11.460000000000001,
#  10.35,
#  9.3200000000000003,
#  9.3000000000000007,
#  9.8599999999999994,
#  10.550000000000001,
#  95889423,
#  67763439,
#  93336784,
#  151802968,
#  219233375,
#  249191959,
#  184923565,
#  160802969,
#  1157078547.52,
#  815652760.53999996,
#  1095668267.9300001,
#  1601529034.6400001,
#  2122788584.79,
#  2460482141.29,
#  1912163265.5599999,
#  1728745630.4400001,
#  0.0080999999999999996,
#  0.0057000000000000002,
#  0.0079000000000000008,
#  0.0129,
#  0.018599999999999998,
#  0.021100000000000001,
#  0.015699999999999999,
#  0.013599999999999999]
