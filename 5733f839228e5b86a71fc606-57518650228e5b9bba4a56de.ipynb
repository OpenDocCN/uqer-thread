# %% [markdown]
# # 急速拉升+预期反转

# %% [markdown]
# 利用分钟线框架，捕捉具有反转预期，并急速拉升的股票；设置每只股票的止盈止损点。回测结果表明这类股票具有很高的beta，在抓反弹中非常有效。

# %% [raw]
# import numpy as np
# import pandas as pd
# start = '2016-01-01'                       # 回测起始时间
# end = '2016-05-11'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300',end)  # 证券池，支持股票和基金
# capital_base = 1000000                     # 起始资金
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# day_count = {}
# for stk in universe:
#     day_count[stk] = 0
#
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     for stk in account.valid_seccost:
#         if account.referencePrice[stk] == 0 or np.isnan(account.referencePrice[stk]):
#             continue
#         if day_count[stk] > 4801 or account.referencePrice[stk] < account.valid_seccost[stk] * 0.95 or account.referencePrice[stk] > account.valid_seccost[stk]*1.50:
#             order_to(stk,0)
#             day_count[stk] = 0
#
#     if account.current_minute > '09:32' and account.cash > 50000:
#         if account.cash > 10000:
#             buy_list = []
#             closeprice_m = account.get_attribute_history('closePrice',2)
#             closeprice_m = pd.DataFrame(closeprice_m)
#             closeprice_d = account.get_daily_attribute_history('closePrice',1)
#
#             closeprice_20 = account.get_daily_attribute_history('closePrice',20)
#             #symbol_closeprice_20 = account.get_daily_symbol_history('benchmark',20)
#             closeprice_20 = pd.DataFrame(closeprice_20)
#             #symbol_ret = symbol_closeprice_20['closePrice'][-1] / symbol_closeprice_20['closePrice'][0]
#
#             eq20_ret = closeprice_20.ix[len(closeprice_20)-1] / closeprice_20.ix[0]
#             #print eq20_ret
#             eq_ret = closeprice_m.ix[1] / closeprice_m.ix[0] - 1
#             eq_ret = eq_ret[eq_ret > 0.01]
#             buy_list_ret = eq_ret.index
#
#             total_money = account.referencePortfolioValue
#             prices = account.referencePrice
#
#             for stk in buy_list_ret:
#                 if prices[stk] < closeprice_d[stk]*1.01 and eq20_ret[stk] < eq20_ret.quantile(0.3) and prices[stk] > closeprice_d[stk]*0.99: #不追高，买入底部反转的股票
#                     buy_list.append(stk)
#
#             for stk in buy_list:
#                 if stk not in account.valid_secpos:
#                     if np.isnan(prices[stk]) or prices[stk] == 0:  # 停牌或是还没有上市等原因不能交易
#                         continue
#                     order(stk,0.1*total_money / prices[stk])
#
#     for stk in account.valid_secpos:
#         day_count[stk] =day_count[stk] + 1
