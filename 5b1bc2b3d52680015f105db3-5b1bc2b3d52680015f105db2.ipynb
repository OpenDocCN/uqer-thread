# %% [markdown]
# # 单日市盈率筛选，返回股票名

# %%
a=DataAPI.MktEqudGet(secID=u"",ticker=u"",tradeDate=u"20180427",beginDate=u"",endDate=u"",isOpen="",field=u"ticker,secShortName,tradeDate,PE,PB",pandas="1")
a.sort_values(by='PE',ascending=False)
b=a[(a['PE']<35)&(a['PE']>15)&(a['PB']<1)&(a['PB']>0)]
b.sort_values(by='PE',ascending=False)
# Out:
#       ticker secShortName   tradeDate       PE      PB
# 136   000543         皖能电力  2018-04-27  31.1773  0.8092
# 2891  600875         东方电气  2018-04-27  30.7962  0.9499
# 3106  601898         中煤能源  2018-04-27  27.4023  0.7433
# 2805  600780         通宝能源  2018-04-27  27.1769  0.9615
# 67    000157         中联重科  2018-04-27  24.5772  0.8711
# 252   000701         厦门信达  2018-04-27  24.4182  0.6825
# 258   000709         河钢股份  2018-04-27  22.6068  0.7540
# 250   000698         沈阳化工  2018-04-27  22.2175  0.8937
# 2833  600811         东方集团  2018-04-27  22.0304  0.8293
# 3128  601992         金隅集团  2018-04-27  20.4903  0.8810
# 154   000564         供销大集  2018-04-27  20.3666  0.9523
# 2745  600717          天津港  2018-04-27  19.6653  0.9690
# 2331  600219         南山铝业  2018-04-27  18.1422  0.8928
# 326   000809        *ST新城  2018-04-27  17.9133  0.9445
# 3609  900953          凯马B  2018-04-27  17.0400  0.5497
# 2896  600881         亚泰集团  2018-04-27  17.0180  0.9851
# ...
