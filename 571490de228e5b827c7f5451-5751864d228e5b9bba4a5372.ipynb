# %% [markdown]
# # 回测的疑问

# %%
import datetime as dt

start = dt.datetime(2016, 4, 1)				# 回测起始时间
end  = dt.datetime(2016, 4, 18)				# 回测结束时间
capital_base = 100000                       # 起始资金
commission = Commission(0.0,0.0)
refresh_rate = 1

def initialize(account):					# 初始化虚拟账户状态
    account.fund = universe[0]
        
def handle_data(account):             # 每个交易日的买入卖出指令
    print account.current_date

# %% [markdown]
# 今天是18号，日期打印出来只能打到15号，为什么current_date没有返回回测当天的，意思是今天没有执行代码？

# %%
2016-04-01 00:00:00
2016-04-05 00:00:00
2016-04-06 00:00:00
2016-04-07 00:00:00
2016-04-08 00:00:00
2016-04-11 00:00:00
2016-04-12 00:00:00
2016-04-13 00:00:00
2016-04-14 00:00:00
2016-04-15 00:00:00
