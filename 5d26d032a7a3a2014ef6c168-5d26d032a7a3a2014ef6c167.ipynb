# %% [markdown]
# # 14 HS300ETF套利(笔记P311)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt
from CAL.PyCAL import * # CAL provides classes and functions dealing with date, time, and calendars. 

sns.set()
pd.set_option('display.width', 200)
cal = Calendar('China.SSE')

# %%
df = DataAPI.MktFunddAdjGet(ticker='510300',field='tradeDate,closePrice') # 基金后复权行情
print('涨幅：%s%%' %(100*df.closePrice.iloc[-1] / df.closePrice.iloc[0]-100)) # %%    字符"%"
print('涨幅：%s%%' % ((df.closePrice.iloc[-1] -df.closePrice.iloc[0])/df.closePrice.iloc[0])) # %%    字符"%"

df.set_index('tradeDate',inplace=True)
df[['closePrice']].plot(figsize=(25,7))

df.head().append(df.tail())
# Out:
# 涨幅：63.4984639017%
# 涨幅：0.634984639017%
#             closePrice
# tradeDate
# 2012-05-28      2.6040
# 2012-05-29      2.6440
# 2012-05-30      2.6360
# 2012-05-31      2.6300
# 2012-06-01      2.6300
# 2019-07-04      4.3444
# 2019-07-05      4.3667
# 2019-07-08      4.2664
# 2019-07-09      4.2564
# 2019-07-10      4.2575
