# %% [markdown]
# # 分级基金api

# %%
def get_leverage_fund(show_type='B', order_by='discount_rate', order_method='desc', date=None):
    '''
    输入参数：
       show_type  str，展示/返回的数据，'T'为返回所有，'A'为返回A类相关，'B'为返回B类相关，'M'为返回母基金相关
       order_by  str，返回结果的排序属性列，可选的为'B_leverage'(B类价格杠杆),'ticker'(交易代码),'discount_rate'(整体溢价率)
       order_method  str，排序规则，降序（'desc'）,升序（'acd'）
    输出参数：
       计算好指标的dataframe，同时还将结果直接打印出来
    '''
    
    import pandas as pd
    import numpy as np
    from CAL.PyCAL import *

    if show_type not in ['T','A','B','M']:
        raise ValueError('show type 必须为T，A，B，M中的一个！')

    if order_by not in ['B_leverage','ticker','discount_rate']:
        raise ValueError('order_by 必须为B_leverage,ticker,discount_rate中的一个！')

    if order_method not in ['desc','acd']:
        raise ValueError('order_method 必须为desc,acd中的一个！')

    # 日期默认为前一个工作日
    if date is None:
        date = Date.todaysDate()
        cal = Calendar('China.SSE')
        period = Period('-1B')
        date = cal.advanceDate(date, period)
        date = date.toDateTime().strftime('%Y%m%d')
    elif not (isinstance(date, str) and len(date) == 8):
        raise ValueError('date必须为xxxxxxxx字符串类型日期格式！') 

    # 所有股票类分级基金ticker
    funds = DataAPI.FundLeverageInfoGet(exchangeCDLeverage=['XSHG','XSHE'], field='ticker,secShortName,tickerLeverage,shareType,category,,shareProp,idxCn,splitNote,downThrshold')
    funds_total = funds[funds['category']=='E']
    funds_total.drop('category', axis=1, inplace=True)
    funds_total.columns = ['母基金代码','母基金简称','子基金代码','份额类别','分拆比例A/B','跟踪指数','折算说明','下折B阈值']
    funds_total['子基金代码'] = funds_total['子基金代码'].apply(str)
    funds_total['分拆比例A/B'][funds_total['分拆比例A/B'] == 1] = 5.0

    # 加入子基金简称
    codes = funds_total.drop_duplicates('母基金代码')['母基金代码'].tolist()
    codes_leverage = map(str,funds_total['子基金代码'].tolist())
    short_names = DataAPI.FundGet(ticker=codes_leverage, listStatusCd=['L','UN'], field='ticker,tradeAbbrName,listStatusCd', pandas='1').drop_duplicates()
    funds_total = funds_total.merge(short_names, how='left', left_on='子基金代码', right_on='ticker').drop('ticker', axis=1).rename(columns={'tradeAbbrName':'子基金简称'})
    funds_total = funds_total[funds_total['listStatusCd']=='L']

    # 取净值
    net_values = DataAPI.FundNavGet(ticker=codes+codes_leverage, dataDate=date, field='ticker,NAV', pandas='1')
    funds_total = funds_total.merge(net_values, how='left', left_on='母基金代码', right_on='ticker').merge(net_values, how='left', left_on='子基金代码', right_on='ticker').drop(['ticker_x','ticker_y'], axis=1).rename(columns={'NAV_x':'母基金净值', 'NAV_y':'子基金净值'})

    # 取行情
    prices = DataAPI.MktFunddGet(ticker=codes+codes_leverage, field='ticker,closePrice', tradeDate=date, pandas='1')
    funds_total = funds_total.merge(prices, how='left', left_on='子基金代码', right_on='ticker').drop('ticker', axis=1).rename(columns={'closePrice':'子基金价格'})
    funds_total['子基金溢价率'] = funds_total['子基金价格'] / funds_total['子基金净值'] - 1

    # 计算相关指标，合并dataframe
    funds_A = funds_total[funds_total['份额类别'] == 'A']
    funds_A.drop('份额类别',axis=1, inplace=True)
    funds_B = funds_total[funds_total['份额类别'] == 'B'][['母基金代码','子基金代码','子基金简称','子基金净值','子基金价格','子基金溢价率']]
    funds_B.columns = [['母基金代码','B类代码','B类简称','B类净值','B类价格','B类溢价率']]
    funds_leverage = pd.merge(funds_A, funds_B, how='left', on='母基金代码')
    funds_leverage.rename(columns={'子基金代码':'A类代码', '子基金简称':'A类简称', '子基金净值':'A类净值', '子基金价格':'A类价格', '子基金溢价率':'A类溢价率'}, inplace=True)
    funds_leverage['整体溢价率'] = (funds_leverage['A类价格'] * (funds_leverage['分拆比例A/B'] / 10) + funds_leverage['B类价格'] * (1 - funds_leverage['分拆比例A/B'] / 10)) / funds_leverage['母基金净值'] -1
    funds_leverage['B类价格杠杆'] = (funds_leverage['A类价格'] * funds_leverage['分拆比例A/B'] / 10 + funds_leverage['B类价格'] * (1 - funds_leverage['分拆比例A/B'] / 10)) / funds_leverage['B类价格'] / (1 - funds_leverage['分拆比例A/B'] / 10)
    funds_leverage['下折母需跌'] = 1 - (funds_leverage['A类净值'] * funds_leverage['分拆比例A/B'] / 10 + funds_leverage['下折B阈值'] * (1 - funds_leverage['分拆比例A/B'] / 10)) / funds_leverage['母基金净值']
    funds_leverage = funds_leverage[['母基金代码','母基金简称','母基金净值','整体溢价率','跟踪指数','分拆比例A/B','下折母需跌','A类代码','A类简称','A类净值','A类价格','A类溢价率','B类代码','B类简称','B类净值','B类价格','B类溢价率','B类价格杠杆','下折B阈值','折算说明']]
    funds_leverage['B类价格杠杆'] = np.round(funds_leverage['B类价格杠杆'], 2)
    funds_leverage.dropna(how='all', inplace=True)
    funds_leverage['整体溢价率'] = pd.Series(["{0:.1f}%".format(val * 100) for val in funds_leverage['整体溢价率']], index = funds_leverage.index)
    funds_leverage['A类溢价率'] = pd.Series(["{0:.1f}%".format(val * 100) for val in funds_leverage['A类溢价率']], index = funds_leverage.index)
    funds_leverage['B类溢价率'] = pd.Series(["{0:.1f}%".format(val * 100) for val in funds_leverage['B类溢价率']], index = funds_leverage.index)
    funds_leverage['下折母需跌'] = pd.Series(["{0:.1f}%".format(val * 100) for val in funds_leverage['下折母需跌']], index = funds_leverage.index)

    # 返回类型
    if show_type == 'T':
        columns = funds_leverage.columns
    elif show_type == 'A':
        columns = ['A类代码','A类简称','A类净值','A类价格','A类溢价率','整体溢价率','跟踪指数']
    elif show_type == 'B':
        columns = ['B类代码','B类简称','B类净值','B类价格','B类溢价率','B类价格杠杆','下折B阈值','整体溢价率','跟踪指数']
    else:
        columns = ['母基金代码','母基金简称','母基金净值','整体溢价率','跟踪指数','分拆比例A/B','下折母需跌','折算说明']

    # 排序
    if order_by == 'B_leverage':
        order_by = 'B类价格杠杆'
    elif order_by == 'ticker':
        order_by = '母基金代码'
    else:
        order_by = '整体溢价率'

    if order_method == 'acd':
        res = funds_leverage.sort(columns=order_by, ascending=True)[columns]
    else:
        res = funds_leverage.sort(columns=order_by, ascending=False)[columns]
    res = res.reset_index().drop('index', axis=1)

    return res

df=DataAPI.MktFunddGet(secID=u"",ticker=u"",tradeDate=u"20180816",beginDate=u"",endDate=u"",field=u"",pandas="1")
df2=df[df['turnoverValue']>=1000000.0]
df1=get_leverage_fund()
df3=df1.merge(df2, left_on="B类代码", right_on="ticker", how="inner")
df3=df3[['B类代码','B类简称','B类净值','B类价格','B类溢价率','整体溢价率','跟踪指数','turnoverValue']]
df3[df3['turnoverValue']>=100000.0]
df4=df3.sort_index(by=['整体溢价率'],ascending=True)
df4
# Out:
#       B类代码                B类简称    B类净值   B类价格  B类溢价率  整体溢价率    跟踪指数  \
# 25  150304       华安创业板50指数分级-B  0.9909  1.036   4.6%  -0.2%   创业板50
# 24  150210    富国中证国有企业改革指数分级-B  0.5320  0.601  13.0%  -0.2%    国企改革
# 23  150270        招商中证白酒指数分级-B  1.0056  1.072   6.6%  -0.3%    中证白酒
# 22  150182        富国中证军工指数分级-B  0.2880  0.330  14.6%  -0.3%    中证军工
# 21  150118       国泰国证房地产行业指数-B  0.7882  0.829   5.2%  -0.5%    国证地产
# 20  150172  申万菱信中证申万证券行业指数分级-B  0.3816  0.430  12.7%  -0.6%  CSSW证券
# 19  150212     富国中证新能源汽车指数分级-B  0.9410  0.987   4.9%  -0.7%   CS新能车
# 18  150236    鹏华中证全指证券公司指数分级-B  0.9800  1.020   4.1%  -0.7%    证券公司
# 17  150290        中融中证煤炭指数分级-B  0.8340  0.869   4.2%  -0.9%    中证煤炭
# 16  150199      国泰国证食品饮料行业指数-B  1.2890  1.242  -3.6%  -1.1%    国证食品
# 15  150176  银华恒生国企指数分级(QDII)-B  0.9068  0.958   5.6%  -1.1%    恒生国企
# 14  150224    富国中证全指证券公司指数分级-B  0.2940  0.307   4.4%  -1.2%    证券公司
# 13  150195     富国中证移动互联网指数分级-B  0.6600  0.732  10.9%   0.0%    移动互联
# 12  150288      中融国证钢铁行业指数分级-B  0.5380  0.589   9.5%   0.1%    国证钢铁
# 10  150201    招商中证全指证券公司指数分级-B  0.5951  0.671  12.8%   0.2%    证券公司
# 9   150228        鹏华中证银行指数分级-B  0.6340  0.711  12.1%   0.2%    中证银行
# 8   150023             申万深成-进取  0.0819  0.158  92.9%   0.2%    深证成指
# 11  150153         富国创业板指数分级-B  0.9310  0.997   7.1%   0.2%    创业板指
# 7   150206        鹏华中证国防指数分级-B  0.3960  0.465  17.4%   0.4%    中证国防
# 6   502050       易方达上证50指数分级-B  0.5823  0.662  13.7%   0.5%    上证50
# 5   150052       信诚沪深300指数分级-B  0.5170  0.587  13.5%   0.6%   沪深300
# 4   150197    国泰国证有色金属行业指数分级-B  0.5286  0.593  12.2%   0.7%    国证有色
# 3   150222      前海开源中航军工指数分级-B  0.7800  0.794   1.8%   0.8%    军工指数
# 2   150131    国泰国证医药卫生行业指数分级-B  0.5186  0.596  14.9%   1.6%    国证医药
# 1   150019      银华深证100指数分级-积极  0.5940  0.692  16.5%   1.6%  深证100R
# 0   150244         鹏华创业板指数分级-B  0.2500  0.306  22.4%   1.8%    创业板指
#
#     turnoverValue
# 25   1.017766e+07
# 24   2.673453e+06
# 23   3.450864e+06
# 22   5.325752e+07
# 21   3.136759e+06
# 20   5.846374e+07
# 19   4.807254e+06
# 18   1.479806e+06
# 17   6.403033e+06
# 16   3.296800e+06
# 15   4.870836e+06
# 14   1.512110e+08
# 13   1.553835e+06
# 12   5.792449e+06
# 10   4.506566e+07
# 9    2.842364e+07
# 8    8.996444e+06
# 11   1.985207e+08
# 7    7.585214e+06
# 6    2.280605e+06
# 5    1.525850e+06
# 4    3.298121e+06
# 3    2.202341e+06
# 2    2.215449e+07
# 1    3.457912e+07
# 0    6.696536e+06

# %%
# Out:
# Empty DataFrame
# Columns: [B类代码, B类简称, B类净值, B类价格, B类溢价率, 整体溢价率, 跟踪指数, turnoverValue]
# Index: []
