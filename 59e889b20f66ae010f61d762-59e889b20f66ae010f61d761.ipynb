# %% [markdown]
# # Notebook

# %% [raw]
# import numpy as np
# from heapq import nlargest, nsmallest
# from CAL.PyCAL import *
# import operator
# import pandas as pd
# import talib as ta
# start = '2015-04-01'                       # 回测起始时间
# end = '2017-03-01'                                  # 回测结束时间
# universe = StockScreener(Factor.LFLO.nsmall(10))# 选取前10小市值的股票
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 1                           # 执行handle_data的时间间隔
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=100000)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
# def handle_data(context):                  # 核心策略逻辑
#     account = context.get_account('fantasy_account')
#     #取出相应的市值股票的数据（交易代码、五日均线、20日均线）
#     stock=DataAPI.MktStockFactorsOneDayGet(tradeDate=context.current_date,secID=context.get_universe()
# ,ticker=u"",field=u"secID,MA5,MA20",pandas="1")
#     #生成交易信号列 五日均线穿过二十日均线 标记为1 买入信号 否则，反之。
#     stock['signal']=np.where(stock['MA5']>stock['MA20'],1,0)
#     #买入信号列股票代码
#     buy_list=stock[stock.signal==1].secID
#     #卖出信号列股票代码
#     sell_list=stock[stock.signal==0].secID
#     for s in buy_list:
#             order(s,100)
#     for s in sell_list:
#             order_to(s,0)
