# %%
import datetime
import pandas as pd

# %%
trade_date = buy_list.keys()
trade_date = [datetime.datetime.strptime(x,'%Y-%m-%d').date() for x in trade_date]
print trade_date
# Out:
# [datetime.date(2005, 10, 10), datetime.date(2009, 7, 1), datetime.date(2002, 10, 8), datetime.date(2019, 4, 1), datetime.date(2020, 7, 1), datetime.date(2016, 4, 1), datetime.date(2006, 7, 3), datetime.date(2005, 1, 4), datetime.date(2000, 4, 3), datetime.date(2001, 1, 2), datetime.date(2004, 7, 1), datetime.date(2016, 7, 1), datetime.date(2017, 7, 3), datetime.date(2018, 7, 2), datetime.date(2010, 4, 1), datetime.date(2014, 1, 2), datetime.date(2008, 10, 6), datetime.date(2019, 1, 2), datetime.date(2016, 1, 4), datetime.date(2020, 1, 2), datetime.date(2012, 4, 5), datetime.date(2017, 4, 5), datetime.date(2012, 1, 4), datetime.date(2018, 4, 2), datetime.date(2004, 10, 8), datetime.date(2001, 7, 2), datetime.date(2015, 7, 1), datetime.date(2000, 10, 9), datetime.date(2003, 1, 2), datetime.date(2005, 4, 1), datetime.date(2013, 10, 8), datetime.date(2019, 7, 1), datetime.date(2010, 10, 8), datetime.date(2020, 4, 1), datetime.date(2017, 1, 3), datetime.date(2006, 4, 3), datetime.date(201
# ...

# %% [raw]
# start = '2008-01-01'                       # 回测起始时间
# end = '2014-12-31'                         # 回测结束时间
# universe = DynamicUniverse('HS300')        # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# commission = Commission(0.0013, 0.0013)
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):
#     pass
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     account = context.get_account('fantasy_account')
#     if context.current_date.date() in trade_date:
#         print context.current_date.date()
#         position = account.get_positions()
#         buy_list_current = buy_list[str(context.current_date.date())]
#         # 将股票代码数据向优矿方式对齐
#         stock_basic_info = DataAPI.EquGet(secID=u"",ticker=u"",equTypeCD=u"A",listStatusCD=u"",exchangeCD="",ListSectorCD=u"",field=u"",pandas="1")
#         buy_current = []
#         for stk in buy_list_current:
#             yyy = stock_basic_info['secID'][stock_basic_info['ticker']==stk].values[0]
#             buy_current.append(yyy)
#         print(buy_current)
#
#         # 判断账户持仓是否为空
#         if len(position) > 0:
#             # 获取持仓股停牌信息
#             notOpen = DataAPI.MktEqudGet(tradeDate=context.now,secID=position.keys(),isOpen='0',field=u'secID',pandas='1')
#             sum_ = 0
#             # 计算停牌secID的权益
#             for sec in notOpen.secID:
#                 tmp = account.get_position(sec).value
#                 sum_ = sum_ + tmp
#             buyweight = 1.0 - sum_ / account.portfolio_value
#         else:
#             buyweight = 1.0
#
#         # 踢除不在股票池的持仓
#         for stk in position:
#             if stk not in buy_current:
#                 account.order_to(stk, 0)
#
#         # 用账户现有资金等比买入
#         if len(buy_current) > 0:
#             weight = buyweight / len(buy_current)
#         else:
#             weight = 0
#         for stk in buy_current:
#             account.order_pct_to(stk, weight)
