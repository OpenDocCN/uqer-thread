# %% [markdown]
# # 请问股票成交价格怎么和智能数据库查的价格不一致？？

# %% [markdown]
# 我做了个最简单的交易，就是每天买进股票池里的10手股票，但是不知道这个买入价格是按照什么来买的？？？
# 我查了下浦发银行的股票价格，发现不一致？？
# 比如2014年1月2日9：30 ，按市价 / 8.40，买了10手，但是不知道这个8.40的价格是怎么来的？？
# 请高手指点下，谢谢
#
#
#
# 浦发银行 20140102 日线信息导出为csv文件
# 2014-01-02
# 证券简称	浦发银行
# 交易所代码	XSHG
# 实际昨收盘	9.43
# 今开盘价	9.44
# 最高价	9.45
# 最低价	9.29
# 今收盘价	9.33
# 成交量	69,821,040
# 成交金额	652,410,750
# 成交笔数	19,653
# 昨收盘价	9.43

# %% [raw]
# start = '2014-01-01'                       # 回测起始时间
# end = '2014-01-10'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['000001.XSHE', '600000.XSHG']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，由于freq = 'd'，时间间隔的单位为交易日
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     for stock in account.universe:
#         order(stock,1000)
