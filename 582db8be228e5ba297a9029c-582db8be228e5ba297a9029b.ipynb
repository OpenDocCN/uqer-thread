# %% [markdown]
# #

# %% [markdown]
# 题主刚刚开始学用Wind，想在这里请教一下各位：
#
# 1. 如何将导出的数据导入csv文件中？
# 2. 如何就Wind数据存储到list中？
#
# 虽然Wind数据库给了文档，但是真的不太会用啊。。。
#
# 求别喷。。。题主学生。。。要用Wind数据库。。。做作业。。。

# %%
# coding: UTF-8
# 导入包
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from WindPy import w
from datetime import *
# %matplotlib inline

# 连接windpy
w.start()

# 举个例子，导入中国平安：
data=w.wsd("000001.SZ", "trade_code,pre_close,open,high,low,close,volume,amt,dealnum,chg,pct_chg,swing,vwap,adjfactor", "2016-10-18", "2016-11-16", "Currency=CNY")

# 关闭windpy
w.stop()

# %% [markdown]
# 我的想法是这样的：

# %%
data

# %% [markdown]
# 这是输出：
#
#     .ErrorCode=0
#     .Codes=[000001.SZ]
#     .Fields=[TRADE_CODE,PRE_CLOSE,OPEN,HIGH,LOW,CLOSE,VOLUME,AMT,DEALNUM,CHG,...]
#     .Times=[20161018,20161019,20161020,20161021,20161024,20161025,20161026,20161027,20161028,20161031,...]
#     .Data=[[nan,nan,nan,nan,nan,nan,nan,nan,nan,nan,...],[9.05,9.09,9.08,9.07,9.13,9.24,9.21,9.15,9.16,9.17,...],[9.03,9.09,9.08,9.08,9.13,9.25,9.22,9.16,9.16,9.15,...],[9.09,9.11,9.09,9.13,9.3,9.26,9.22,9.17,9.23,9.16,...],[9.03,9.05,9.05,9.06,9.12,9.18,9.13,9.12,9.14,9.09,...],[9.09,9.08,9.07,9.13,9.24,9.21,9.15,9.16,9.17,9.15,...],[59373709.0,48263616.0,34284457.0,68389677.0,91567704.0,50075292.0,44045213.0,32414055.0,54199774.0,49359683.0,...],[537784120.4,438299029.5,310966016.7,621549845.0,844746080.6,461542701.1,403750809.1,296216914.8,497615050.8,450148883.0,...],[nan,nan,nan,nan,nan,nan,nan,nan,nan,nan,...],[0.04,-0.01,-0.01,0.06,0.11,-0.03,-0.06,0.01,0.01,-0.02,...],...]

# %% [markdown]
# plt.plot(data.Times,data.Data)

# %% [markdown]
# 结果是这样的：
#
# ValueError: x and y must have same first dimension

# %% [markdown]
# 求有相关的大神能帮解决问题。。。
