# %% [markdown]
# # 申万一级SVM多因子选股

# %%
from __future__ import print_function
import datetime
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
data=DataAPI.TradeCalGet(exchangeCD=u"XSHG",beginDate=u'20121101',endDate='20180331',field=['calendarDate','isMonthEnd'],pandas="1")
data = data[data['isMonthEnd'] == 1]
data_end = map(lambda x: x[0:4]+x[5:7]+x[8:10], data['calendarDate'].values.tolist())

# %%
data_end[0]
# Out:
# '20121130'

# %%
# 构建日期列表，取每月最后一个交易日
data=DataAPI.TradeCalGet(exchangeCD=u"XSHG",beginDate=u'20121101',endDate='20180331',field=['calendarDate','isWeekEnd','isMonthEnd'],pandas="1")
data = data[data['isMonthEnd'] == 1]
data_end = map(lambda x: x[0:4]+x[5:7]+x[8:10], data['calendarDate'].values.tolist())
    
#从Uqer导入数据'Aroon','PVT','CR20','REVS20','VOL20'
factor_names =['PE','ROA','ATR6','VOL5']
data0=pd.DataFrame()
for i in range(len(data_end)-1):
    factordata=DataAPI.MktStockFactorsOneDayGet(secID=set_universe('HS300'),tradeDate=data_end[i],ticker='',field=['secID','tradeDate',]+factor_names,pandas="1").set_index(['secID']) 
    
    for j in range(len(factor_names)):
        signal = standardize(neutralize(winsorize(factordata[factor_names[j]].dropna().to_dict()),data_end[i])) #去极值，标准化，中性化
        factordata[factor_names[j]][signal.keys()] = signal.values()
    data1 = factordata
    
    data2=DataAPI.MktEqumGet(secID=set_universe('HS300'),beginDate=data_end[i+1],endDate=data_end[i+1],
field=u"secID,return", pandas="1").set_index(['secID'])
                                                            
                                 
    data1=pd.concat([data1,data2],axis=1)
    data1['stock']=data1.index
    data1=data1.set_index(['tradeDate'])
    data0=pd.concat([data0,data1])

data0['tradeDate']=data0.index
data0=data0.reset_index(drop=True)
data0=data0.loc[data0['tradeDate'].dropna().index]
#按月分离交易日期，方便回测            
data0['y_m'] = data0.tradeDate.apply(lambda x: str(x[0:7]))   

data0=data0.dropna()

# %%
sns.heatmap(data0[factor_names].corr())

# %%
data0[factor_names].corr()
# Out:
#             PE       ROA      ATR6      VOL5
# PE    1.000000 -0.071390  0.052662  0.047061
# ROA  -0.071390  1.000000  0.259769  0.058811
# ATR6  0.052662  0.259769  1.000000  0.235839
# VOL5  0.047061  0.058811  0.235839  1.000000

# %%
data0[factor_names].corr().to_csv('corr333.csv')

# %%
#收益率分类 每个月末交易日，前30%为1 ，后30%为-1，中间为0
''''
rets=pd.DataFrame()
for d in data['calendarDate'].values[:]:
    
    
    dr=data0[data0['tradeDate']==d]['return']
   
    q07=dr.quantile(0.7)
    q03=dr.quantile(0.3)
    
    for i in range(len(dr)):
        if dr.iloc[i]>q07:
            dr.iloc[i]=1
        elif dr.iloc[i]<q03:
            dr.iloc[i]=-1
        else:
            dr.iloc[i]=0
    rets=pd.concat([rets,dr])
rets.columns=['rets']
data0=pd.concat([data0,rets],axis=1)'''
# Out:
# "'\nrets=pd.DataFrame()\nfor d in data['calendarDate'].values[:]:\n    \n    \n    dr=data0[data0['tradeDate']==d]['return']\n   \n    q07=dr.quantile(0.7)\n    q03=dr.quantile(0.3)\n    \n    for i in range(len(dr)):\n        if dr.iloc[i]>q07:\n            dr.iloc[i]=1\n        elif dr.iloc[i]<q03:\n            dr.iloc[i]=-1\n        else:\n            dr.iloc[i]=0\n    rets=pd.concat([rets,dr])\nrets.columns=['rets']\ndata0=pd.concat([data0,rets],axis=1)"

# %%
#收益率分类 每个月末交易日，前50%为1 ，后50%为0
rets=pd.DataFrame()
for d in data['calendarDate'].values[:]:
    
    
    
    lables = data0[data0['tradeDate']==d]['return']>=data0[data0['tradeDate']==d]['return'].mean()  #为分类处理数据，判断收盘价是否大于今日收盘价
    lables = lables.replace({True:'1',False:'0'})
    
    
    rets=pd.concat([rets,lables])
rets.columns=['rets']
data0=pd.concat([data0,rets],axis=1)    
df=data0
df.head()
# Out:
#          PE       ROA      ATR6      VOL5    return        stock   tradeDate  \
# 0  0.041111  0.307852  1.150019 -0.233941  0.251563  000001.XSHE  2012-11-30
# 1  0.421897 -0.283597  0.125359  0.318259  0.156571  000002.XSHE  2012-11-30
# 2 -2.605159 -0.584832 -0.794111 -0.484755  0.258065  000063.XSHE  2012-11-30
# 3  2.598912  0.892178 -1.411421 -0.034194  0.117057  000066.XSHE  2012-11-30
# 4  0.213534  0.142686 -0.478974  0.965553  0.311189  000069.XSHE  2012-11-30
#
#        y_m rets
# 0  2012-11    1
# 1  2012-11    0
# 2  2012-11    1
# 3  2012-11    0
# 4  2012-11    1

# %%
df
# Out:
#              PE       ROA      ATR6      VOL5    return        stock  \
# 0      0.041111  0.307852  1.150019 -0.233941  0.251563  000001.XSHE
# 1      0.421897 -0.283597  0.125359  0.318259  0.156571  000002.XSHE
# 2     -2.605159 -0.584832 -0.794111 -0.484755  0.258065  000063.XSHE
# 3      2.598912  0.892178 -1.411421 -0.034194  0.117057  000066.XSHE
# 4      0.213534  0.142686 -0.478974  0.965553  0.311189  000069.XSHE
# 5      0.427473 -0.219322 -0.272849  1.167748  0.037915  000100.XSHE
# 6     -0.592983  0.062954 -0.882623 -0.839170  0.158491  000157.XSHE
# 7     -0.130260 -0.431600  1.929037  0.025003  0.146806  000338.XSHE
# 8     -1.115269  0.176979  0.343165 -0.776237  0.146123  000425.XSHE
# 9     -0.044282  0.306514  2.119464 -0.366974  0.076120  000538.XSHE
# 10     0.178574  1.395996  0.246876 -0.039311  0.057032  000568.XSHE
# 11    -0.162494 -0.396155  0.298440 -0.743365  0.245187  000596.XSHE
# 12    -0.443448 -0.983758 -1.539873 -0.825443  0.298828  000625.XSHE
# 13    -2.788111 -2.642324 -0.863493 -0.171938  0.080769  000627.XSHE
# 14     0.280713 -1.146617  0.432574 -0.138008  0.086493  000651.XSHE
# 15    -0.548533  0.333822  0.632333  0.601106  0.373106  000656.XSHE
# 16    -0.387930 -0.002949  1.592956  0.176274  0.143124  000661.XSHE
# 17    -0.573554 -0.794310  0.050541  0.149911  0.255061  000671.XSHE
# 18     0.667578 -0.890433 -0.543532  1.811564  0.193998  000703.XSHE
# 19     1.201091  1.091036  1.617602  0.063832  0.193861  000708.XSHE
# 20    -1.596715 -1.126306  0.420714 -1.097635  0.247608  000723.XSHE
# 21    -0.089963  0.534430 -1.518195 -0.237227  0.101942  000725.XSHE
# 22    -0.794030  0.203160 -0.238587 -1.152118  0.247480  000728.XSHE
# 23     2.637278 -0.899735 -1.015687 -0.722854  0.230769  000768.XSHE
# 24    -0.521455 -0.411014 -0.332121 -1.195792  0.386691  000776.XSHE
# 25    -0.828169  0.693189 -0.366118 -0.668435  0.265141  000783.XSHE
# 26    -0.541585 -0.203956  0.079398 -1.014689  0.249286  000786.XSHE
# 27     0.058912  1.157310 -0.736481  0.441307  0.046719  000858.XSHE
# 28     0.311181  0.161956  1.531354  0.111575  0.392075  000860.XSHE
# 29    -0.402569  0.865643  0.322437 -0.595153  0.188392  000876.XSHE
# ...         ...       ...       ...       ...       ...          ...
# 15689  2.274496 -0.466731  1.895436  2.009159 -0.006451  300676.XSHE
# 15690  0.307847 -0.430014  0.062728  0.010030 -0.044594  600004.XSHG
# 15691 -3.351049  1.205707  1.244973 -0.030406  0.073446  600027.XSHG
# 15693 -1.873089  2.467592 -1.243196 -2.151005  0.074721  600161.XSHG
# 15694 -0.620348  0.124789 -0.885347  0.362612  0.023068  600183.XSHG
# 15695  0.177339 -0.984108  0.097220  0.316545  0.100572  600299.XSHG
# 15696  2.195797 -1.152111 -0.134618  1.237155  0.099090  600584.XSHG
# 15697  0.596777 -2.149140 -0.875831 -0.523168  0.060320  600600.XSHG
# 15698 -1.108932  0.900567  0.490102 -0.761485  0.057495  600655.XSHG
# 15699 -0.401381 -1.867192 -0.109276 -1.086854  0.029573  600745.XSHG
# 15700  2.283727 -0.676772 -0.006343  3.220599  0.178803  600760.XSHG
# 15701 -0.297362  0.782731 -0.131014 -0.515379  0.116216  600763.XSHG
# 15702 -1.194431 -0.166418 -0.072325  1.214653  0.125610  600845.XSHG
# 15703  0.025531 -1.422955 -1.306062 -1.585764  0.038301  600848.XSHG
# 15704  0.475547 -1.099811 -1.178516  0.326899 -0.126860  600872.XSHG
# 15705 -1.121034 -1.285958 -0.587295  0.681579  0.137668  600998.XSHG
# 15706  0.063946 -0.641157  0.325140 -0.490130 -0.038801  601100.XSHG
# 15707 -0.609335 -0.940287 -1.258446 -1.141400 -0.100704  601231.XSHG
# 15708 -0.573114  0.241293 -0.659754 -0.512590  0.027752  601238.XSHG
# 15709  2.170552 -1.025153  2.416944  1.330406 -0.256325  601360.XSHG
# 15710 -1.538112 -0.912291  0.298098 -0.557898  0.041513  601808.XSHG
# 15711 -0.345576 -0.902159 -0.857660  0.892951 -0.123016  601838.XSHG
# 15712  0.207587 -0.239729  0.503354  0.627736 -0.070000  601872.XSHG
# 15713  0.388730 -0.074109  0.081967  1.502584  0.269079  603019.XSHG
# 15714 -0.851814  2.130627  2.665054  3.644084 -0.120986  603156.XSHG
# 15715  0.220709  1.878790 -0.235998  0.751270  0.026401  603288.XSHG
# 15716 -0.085380 -0.313482 -2.139564 -0.581224 -0.008207  603369.XSHG
# 15717  1.002495 -0.683759 -0.782165  0.414136  0.211164  603501.XSHG
# 15718 -0.723591  2.086314  0.102217  0.231792  0.089552  603658.XSHG
# 15719 -0.480424  0.455647 -2.423688 -0.830981  0.099141  603899.XSHG
#
#         tradeDate      y_m rets
# 0      2012-11-30  2012-11    1
# 1      2012-11-30  2012-11    0
# 2      2012-11-30  2012-11    1
# 3      2012-11-30  2012-11    0
# 4      2012-11-30  2012-11    1
# 5      2012-11-30  2012-11    0
# 6      2012-11-30  2012-11    0
# 7      2012-11-30  2012-11    0
# 8      2012-11-30  2012-11    0
# 9      2012-11-30  2012-11    0
# 10     2012-11-30  2012-11    0
# 11     2012-11-30  2012-11    1
# 12     2012-11-30  2012-11    1
# 13     2012-11-30  2012-11    0
# 14     2012-11-30  2012-11    0
# 15     2012-11-30  2012-11    1
# 16     2012-11-30  2012-11    0
# 17     2012-11-30  2012-11    1
# 18     2012-11-30  2012-11    1
# 19     2012-11-30  2012-11    1
# 20     2012-11-30  2012-11    1
# 21     2012-11-30  2012-11    0
# 22     2012-11-30  2012-11    1
# 23     2012-11-30  2012-11    1
# 24     2012-11-30  2012-11    1
# 25     2012-11-30  2012-11    1
# 26     2012-11-30  2012-11    1
# 27     2012-11-30  2012-11    0
# 28     2012-11-30  2012-11    1
# 29     2012-11-30  2012-11    1
# ...           ...      ...  ...
# 15689  2018-02-28  2018-02    0
# 15690  2018-02-28  2018-02    0
# 15691  2018-02-28  2018-02    1
# 15693  2018-02-28  2018-02    1
# 15694  2018-02-28  2018-02    1
# 15695  2018-02-28  2018-02    1
# 15696  2018-02-28  2018-02    1
# 15697  2018-02-28  2018-02    1
# 15698  2018-02-28  2018-02    1
# 15699  2018-02-28  2018-02    1
# 15700  2018-02-28  2018-02    1
# 15701  2018-02-28  2018-02    1
# 15702  2018-02-28  2018-02    1
# 15703  2018-02-28  2018-02    1
# 15704  2018-02-28  2018-02    0
# 15705  2018-02-28  2018-02    1
# 15706  2018-02-28  2018-02    0
# 15707  2018-02-28  2018-02    0
# 15708  2018-02-28  2018-02    1
# 15709  2018-02-28  2018-02    0
# 15710  2018-02-28  2018-02    1
# 15711  2018-02-28  2018-02    0
# 15712  2018-02-28  2018-02    0
# 15713  2018-02-28  2018-02    1
# 15714  2018-02-28  2018-02    0
# 15715  2018-02-28  2018-02    1
# 15716  2018-02-28  2018-02    0
# 15717  2018-02-28  2018-02    1
# 15718  2018-02-28  2018-02    1
# 15719  2018-02-28  2018-02    1
#
# [14834 rows x 9 columns]

# %% [markdown]
# # **模型训练**
# -----
# 为了能让模型及时抓取到市场的变化，我们采用了滚动回测方法。模型训练区间为20070101至20171231，按月份划分（前12个月训练，本月测试），因此需要不断重复训练。
# get_train_val_test_data()：数据集划分函数
# format_feature_label()：特征划分函数
# pipeline():模型处理，包括因子选择，格点搜索等等
#
# 利用格点搜索做交叉验证，选择最好的模型，在测试集测试
#
# 注意：
# 	部分函数的编写参考Uqer社区的 华泰证券 《人工智能选股之 Boosting 模型》这篇文章

# %%
def get_train_val_test_data(date):
        #计算前12个月，采用365天
        d_12=(datetime.datetime.strptime(date, "%Y-%m") - datetime.timedelta(days=30)).strftime('%Y-%m')
        train_df=df[(df['y_m']>=d_12) & (df['y_m']<date)]
        #train_val_df = train_val_df.sample(frac=1).reset_index(drop=True)   
        #拆分训练集、验证集                                 
        test_df =df[df['y_m']==date]   
        return train_df,test_df

def format_feature_label(origin_df, is_filter=True):
    
    #if is_filter:
        #origin_df = origin_df[origin_df['rets']!=0]
    df_test= origin_df                
    feature = origin_df[factor_names]
    label = origin_df['rets']

    return feature, label,df_test

# %%
#def pipeline():
LR_model_list = []
accuracy=[]
classification=[]
final=pd.DataFrame()

for date in df['y_m'].drop_duplicates()[12:]:
    

    print('training model for %s' % date)
    train_df,test_df = get_train_val_test_data(date)
    train_feature, train_label,df_train = format_feature_label(train_df)       
    test_feature, test_label,df_test = format_feature_label(test_df)
    params1 = {'C':range(1,10,2),'gamma':[x /100. for x in range(1,10,2)],'kernel':['linear','poly','rbf','sigmoid']}
    clf_svm = svm.SVC(probability=True)
    clf_AdaBoost = AdaBoostClassifier(n_estimators = 350 , learning_rate = 1.53 ) 
    
    lr=LogisticRegression()           
    params={'C':np.arange(0.01,0.1,0.01)}
    #clf=GridSearchCV(lr,param_grid=params,)
    ada=AdaBoostClassifier( ) 
    params3={'n_estimators':[200,400,600,800,1000],'learning_rate':[0.5,1,1.5]}
    #clf=GridSearchCV(ada,param_grid=params3)
    
    clf= GridSearchCV(clf_svm, params1)
    clf.fit(train_feature,train_label)
    clf_best=clf.best_estimator_
    #clf_best=svm.SVC(C=9,gamma=0.09,kernel='rbf',probability=True)
    #clf_best=AdaBoostClassifier(n_estimators = 800 , learning_rate = 1.53 ) 
    print(clf_best)
    clf_best.fit(train_feature,train_label)
    predict_prob=clf_best.predict_proba(test_feature)[:,1] 
    accuracy.append(clf_best.score(test_feature,test_label))
    LR_model_list.append(clf_best)
    df_test['factor'] = predict_prob
    df_test = df_test[['stock', 'tradeDate', 'rets', 'factor']]
    
    final=pd.concat([final,df_test])
    #return LR_model_list,final,accuracy
print('accuracy=%f'% (pd.Series(accuracy).mean()))
plt.plot(accuracy,label='accuracy')
final.to_csv('svm333_final.csv')
# Out:
# training model for 2013-11
# SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.03, kernel='poly',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2013-12
# SVC(C=7, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.07, kernel='sigmoid',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2014-01
# SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='poly',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2014-02
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='linear',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2014-03
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.09, kernel='sigmoid',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2014-04
# SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.03, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2014-05
# training model for 2014-06
# SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='sigmoid',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2014-07
# SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.09, kernel='sigmoid',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2014-08
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.09, kernel='poly',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2014-09
# SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.07, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2014-10
# SVC(C=7, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.09, kernel='poly',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2014-11
# training model for 2014-12
# SVC(C=7, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.07, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2015-01
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.07, kernel='sigmoid',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2015-02
# SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.09, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2015-03
# SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.03, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2015-04
# SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.07, kernel='sigmoid',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2015-05
# SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.09, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2015-06
# training model for 2015-07
# SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2015-08
# SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.07, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2015-09
# SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.09, kernel='poly',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2015-10
# training model for 2015-11
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='poly',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2015-12
# SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='sigmoid',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2016-01
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.07, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2016-02
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.09, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2016-03
# training model for 2016-04
# SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.07, kernel='poly',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2016-05
# training model for 2016-06
# SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.07, kernel='sigmoid',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2016-07
# SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.09, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2016-08
# SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.07, kernel='poly',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2016-09
# training model for 2016-10
# training model for 2016-11
# training model for 2016-12
# SVC(C=7, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2017-01
# training model for 2017-02
# training model for 2017-03
# training model for 2017-04
# training model for 2017-05
# SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2017-06
# training model for 2017-07
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='poly',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2017-08
# SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.07, kernel='sigmoid',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2017-09
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.07, kernel='poly',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2017-10
# training model for 2017-11
# SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# training model for 2017-12
# training model for 2018-01
# training model for 2018-02
# SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.07, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# accuracy=0.549986

# %%
final
# Out:
#              stock   tradeDate rets    factor
# 2727   000001.XSHE  2013-11-29    0  0.399837
# 2728   000002.XSHE  2013-11-29    0  0.399675
# 2729   000063.XSHE  2013-11-29    0  0.411447
# 2730   000066.XSHE  2013-11-29    1  0.390517
# 2731   000069.XSHE  2013-11-29    1  0.399749
# 2732   000100.XSHE  2013-11-29    1  0.399881
# 2733   000157.XSHE  2013-11-29    0  0.399749
# 2734   000333.XSHE  2013-11-29    1  0.402051
# 2735   000338.XSHE  2013-11-29    0  0.398683
# 2736   000425.XSHE  2013-11-29    0  0.400839
# 2737   000538.XSHE  2013-11-29    1  0.417348
# 2738   000568.XSHE  2013-11-29    0  0.401025
# 2739   000596.XSHE  2013-11-29    1  0.399839
# 2740   000625.XSHE  2013-11-29    0  0.390911
# 2741   000627.XSHE  2013-11-29    0  0.393433
# 2742   000651.XSHE  2013-11-29    1  0.399272
# 2743   000656.XSHE  2013-11-29    0  0.416925
# 2744   000661.XSHE  2013-11-29    1  0.427458
# 2745   000671.XSHE  2013-11-29    0  0.395131
# 2746   000703.XSHE  2013-11-29    0  0.399952
# 2747   000708.XSHE  2013-11-29    0  0.400194
# 2749   000725.XSHE  2013-11-29    1  0.402731
# 2750   000728.XSHE  2013-11-29    1  0.401896
# 2751   000768.XSHE  2013-11-29    0  0.399309
# 2752   000776.XSHE  2013-11-29    1  0.400639
# 2753   000783.XSHE  2013-11-29    1  0.399793
# 2754   000786.XSHE  2013-11-29    1  0.396077
# 2755   000858.XSHE  2013-11-29    0  0.401193
# 2756   000860.XSHE  2013-11-29    0  0.401130
# 2757   000876.XSHE  2013-11-29    1  0.402028
# ...            ...         ...  ...       ...
# 15689  300676.XSHE  2018-02-28    0  0.649307
# 15690  600004.XSHG  2018-02-28    0  0.368262
# 15691  600027.XSHG  2018-02-28    1  0.386876
# 15693  600161.XSHG  2018-02-28    1  0.726484
# 15694  600183.XSHG  2018-02-28    1  0.392217
# 15695  600299.XSHG  2018-02-28    1  0.401792
# 15696  600584.XSHG  2018-02-28    1  0.592173
# 15697  600600.XSHG  2018-02-28    1  0.588821
# 15698  600655.XSHG  2018-02-28    1  0.429887
# 15699  600745.XSHG  2018-02-28    1  0.550827
# 15700  600760.XSHG  2018-02-28    1  0.578959
# 15701  600763.XSHG  2018-02-28    1  0.387344
# 15702  600845.XSHG  2018-02-28    1  0.361662
# 15703  600848.XSHG  2018-02-28    1  0.647292
# 15704  600872.XSHG  2018-02-28    0  0.438247
# 15705  600998.XSHG  2018-02-28    1  0.379209
# 15706  601100.XSHG  2018-02-28    0  0.392317
# 15707  601231.XSHG  2018-02-28    0  0.564047
# 15708  601238.XSHG  2018-02-28    1  0.426368
# 15709  601360.XSHG  2018-02-28    0  0.647567
# 15710  601808.XSHG  2018-02-28    1  0.402806
# 15711  601838.XSHG  2018-02-28    0  0.369095
# 15712  601872.XSHG  2018-02-28    0  0.365240
# 15713  603019.XSHG  2018-02-28    1  0.373698
# 15714  603156.XSHG  2018-02-28    0  0.409561
# 15715  603288.XSHG  2018-02-28    1  0.457804
# 15716  603369.XSHG  2018-02-28    0  0.524830
# 15717  603501.XSHG  2018-02-28    1  0.420182
# 15718  603658.XSHG  2018-02-28    1  0.566763
# 15719  603899.XSHG  2018-02-28    1  0.594498
#
# [12175 rows x 4 columns]

# %%
df[['stock', 'tradeDate', 'rets']]
# Out:
#              stock   tradeDate rets
# 0      000001.XSHE  2012-11-30    1
# 1      000002.XSHE  2012-11-30    0
# 2      000063.XSHE  2012-11-30    1
# 3      000066.XSHE  2012-11-30    0
# 4      000069.XSHE  2012-11-30    1
# 5      000100.XSHE  2012-11-30    0
# 6      000157.XSHE  2012-11-30    0
# 7      000338.XSHE  2012-11-30    0
# 8      000425.XSHE  2012-11-30    0
# 9      000538.XSHE  2012-11-30    0
# 10     000568.XSHE  2012-11-30    0
# 11     000596.XSHE  2012-11-30    1
# 12     000625.XSHE  2012-11-30    1
# 13     000627.XSHE  2012-11-30    0
# 14     000651.XSHE  2012-11-30    0
# 15     000656.XSHE  2012-11-30    1
# 16     000661.XSHE  2012-11-30    0
# 17     000671.XSHE  2012-11-30    1
# 18     000703.XSHE  2012-11-30    1
# 19     000708.XSHE  2012-11-30    1
# 20     000723.XSHE  2012-11-30    1
# 21     000725.XSHE  2012-11-30    0
# 22     000728.XSHE  2012-11-30    1
# 23     000768.XSHE  2012-11-30    1
# 24     000776.XSHE  2012-11-30    1
# 25     000783.XSHE  2012-11-30    1
# 26     000786.XSHE  2012-11-30    1
# 27     000858.XSHE  2012-11-30    0
# 28     000860.XSHE  2012-11-30    1
# 29     000876.XSHE  2012-11-30    1
# ...            ...         ...  ...
# 15689  300676.XSHE  2018-02-28    0
# 15690  600004.XSHG  2018-02-28    0
# 15691  600027.XSHG  2018-02-28    1
# 15693  600161.XSHG  2018-02-28    1
# 15694  600183.XSHG  2018-02-28    1
# 15695  600299.XSHG  2018-02-28    1
# 15696  600584.XSHG  2018-02-28    1
# 15697  600600.XSHG  2018-02-28    1
# 15698  600655.XSHG  2018-02-28    1
# 15699  600745.XSHG  2018-02-28    1
# 15700  600760.XSHG  2018-02-28    1
# 15701  600763.XSHG  2018-02-28    1
# 15702  600845.XSHG  2018-02-28    1
# 15703  600848.XSHG  2018-02-28    1
# 15704  600872.XSHG  2018-02-28    0
# 15705  600998.XSHG  2018-02-28    1
# 15706  601100.XSHG  2018-02-28    0
# 15707  601231.XSHG  2018-02-28    0
# 15708  601238.XSHG  2018-02-28    1
# 15709  601360.XSHG  2018-02-28    0
# 15710  601808.XSHG  2018-02-28    1
# 15711  601838.XSHG  2018-02-28    0
# 15712  601872.XSHG  2018-02-28    0
# 15713  603019.XSHG  2018-02-28    1
# 15714  603156.XSHG  2018-02-28    0
# 15715  603288.XSHG  2018-02-28    1
# 15716  603369.XSHG  2018-02-28    0
# 15717  603501.XSHG  2018-02-28    1
# 15718  603658.XSHG  2018-02-28    1
# 15719  603899.XSHG  2018-02-28    1
#
# [14834 rows x 3 columns]

# %%
LR_model_list
# Out:
# [SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.03, kernel='poly',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=7, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.07, kernel='sigmoid',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.05, kernel='poly',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.01, kernel='linear',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.09, kernel='sigmoid',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.03, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=7, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.07, kernel='sigmoid',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.05, kernel='sigmoid',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.09, kernel='sigmoid',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.09, kernel='poly',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.07, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=7, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.09, kernel='poly',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.05, kernel='sigmoid',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=7, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.07, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.07, kernel='sigmoid',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.09, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.03, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.07, kernel='sigmoid',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.09, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.09, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.07, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.09, kernel='poly',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.05, kernel='sigmoid',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.05, kernel='poly',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.05, kernel='sigmoid',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.07, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.09, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.07, kernel='sigmoid',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.07, kernel='poly',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.01, kernel='linear',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.07, kernel='sigmoid',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.09, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.07, kernel='poly',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.07, kernel='sigmoid',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.05, kernel='poly',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.09, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=7, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.09, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.03, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.07, kernel='sigmoid',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.09, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.09, kernel='poly',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.01, kernel='poly',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.07, kernel='sigmoid',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.07, kernel='poly',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.09, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=9, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.09, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma=0.07, kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False)]

# %% [markdown]
# # **结果分析**
# ------
# 对准确率画图，这里需要注意的是，在训练中对收益率进行了划分前30%和后30%，相当于略去了中间40%的数据，但是在测试集中我们无法知道哪些股票未来上涨高，哪些上涨低，所以无法删去数据，这就使得测试的时候，即使预测值为1，也无法保证一定是所有股票中上涨排名前30%的股票，不过在券商 华泰证券《人工智能选股》系列研报中均采用了此种方法，本文姑且认为这个方法可行

# %%
#运行模型


#LR_model_list,final,accuracy = pipeline()

#准确率分析
#accuracy=pd.DataFrame()
date_test=pd.DataFrame(data_end)
#对各阶段的准去率作图
print('accuracy=%f'% (pd.Series(accuracy).mean()))
plt.plot(accuracy,label='accuracy')
# Out:
# accuracy=0.549986

# %% [markdown]
# # **因子回测**
# 上述模型在测试的时候，为每个股票打了一个分数，可以认为是将输入的因子转换成了一个集成的“因子”，之后我们选取排名前30%的的因子进行选股。
# 考虑到Uqer回测和读取数据的速度问题，这里仅仅选取HS300的股票回测，读者自行可以选择ZZ500，或者全A股
# 回测：双边万分之三手续费，千分之一印花税，无滑点

# %%
final
# Out:
#              stock   tradeDate rets    factor
# 2727   000001.XSHE  2013-11-29    0  0.406718
# 2728   000002.XSHE  2013-11-29    0  0.406192
# 2729   000063.XSHE  2013-11-29    0  0.405126
# 2730   000066.XSHE  2013-11-29    1  0.388747
# 2731   000069.XSHE  2013-11-29    1  0.412898
# 2732   000100.XSHE  2013-11-29    1  0.391600
# 2733   000157.XSHE  2013-11-29    0  0.400554
# 2734   000333.XSHE  2013-11-29    1  0.409806
# 2735   000338.XSHE  2013-11-29    0  0.407239
# 2736   000425.XSHE  2013-11-29    0  0.387808
# 2737   000538.XSHE  2013-11-29    1  0.411051
# 2738   000568.XSHE  2013-11-29    0  0.406482
# 2739   000596.XSHE  2013-11-29    1  0.406476
# 2740   000625.XSHE  2013-11-29    0  0.408317
# 2741   000627.XSHE  2013-11-29    0  0.414524
# 2742   000651.XSHE  2013-11-29    1  0.406870
# 2743   000656.XSHE  2013-11-29    0  0.397659
# 2744   000661.XSHE  2013-11-29    1  0.340615
# 2745   000671.XSHE  2013-11-29    0  0.407879
# 2746   000703.XSHE  2013-11-29    0  0.429894
# 2747   000708.XSHE  2013-11-29    0  0.410874
# 2749   000725.XSHE  2013-11-29    1  0.407063
# 2750   000728.XSHE  2013-11-29    1  0.396496
# 2751   000768.XSHE  2013-11-29    0  0.406943
# 2752   000776.XSHE  2013-11-29    1  0.405340
# 2753   000783.XSHE  2013-11-29    1  0.406800
# 2754   000786.XSHE  2013-11-29    1  0.405705
# 2755   000858.XSHE  2013-11-29    0  0.415034
# 2756   000860.XSHE  2013-11-29    0  0.402990
# 2757   000876.XSHE  2013-11-29    1  0.406786
# ...            ...         ...  ...       ...
# 15689  300676.XSHE  2018-02-28    0  0.660114
# 15690  600004.XSHG  2018-02-28    0  0.388129
# 15691  600027.XSHG  2018-02-28    1  0.477552
# 15693  600161.XSHG  2018-02-28    1  0.477964
# 15694  600183.XSHG  2018-02-28    1  0.370646
# 15695  600299.XSHG  2018-02-28    1  0.475654
# 15696  600584.XSHG  2018-02-28    1  0.474903
# 15697  600600.XSHG  2018-02-28    1  0.376757
# 15698  600655.XSHG  2018-02-28    1  0.487654
# 15699  600745.XSHG  2018-02-28    1  0.472699
# 15700  600760.XSHG  2018-02-28    1  0.773119
# 15701  600763.XSHG  2018-02-28    1  0.432534
# 15702  600845.XSHG  2018-02-28    1  0.444917
# 15703  600848.XSHG  2018-02-28    1  0.432807
# 15704  600872.XSHG  2018-02-28    0  0.346224
# 15705  600998.XSHG  2018-02-28    1  0.519755
# 15706  601100.XSHG  2018-02-28    0  0.449330
# 15707  601231.XSHG  2018-02-28    0  0.531443
# 15708  601238.XSHG  2018-02-28    1  0.485378
# 15709  601360.XSHG  2018-02-28    0  0.770877
# 15710  601808.XSHG  2018-02-28    1  0.352841
# 15711  601838.XSHG  2018-02-28    0  0.375917
# 15712  601872.XSHG  2018-02-28    0  0.483260
# 15713  603019.XSHG  2018-02-28    1  0.348420
# 15714  603156.XSHG  2018-02-28    0  0.366023
# 15715  603288.XSHG  2018-02-28    1  0.658942
# 15716  603369.XSHG  2018-02-28    0  0.500000
# 15717  603501.XSHG  2018-02-28    1  0.656954
# 15718  603658.XSHG  2018-02-28    1  0.457703
# 15719  603899.XSHG  2018-02-28    1  0.402151
#
# [12178 rows x 4 columns]

# %%
#导入上述模型计算结果
signal_df =final
factor_data = signal_df[['stock', 'tradeDate', 'factor']]     # 读取因子数据
factor_data = factor_data.set_index('tradeDate', drop=True)
q_dates = factor_data.index.values

# %% [raw]
# start = '2018-03-01'                       # 回测起始时间
# end = '2020-03-31'                         # 回测结束时间
# benchmark = 'HS300'
# universe = DynamicUniverse(IndSW.JianZhuZhuangShiL1, IndSW.DianQiSheBeiL1, IndSW.QiCheL1, IndSW.JiaYongDianQiL1, IndSW.QingGongZhiZaoL1, IndSW.ShangYeMaoYiL1, IndSW.NongLinMuYuL1, IndSW.ShiPinYinLiaoL1, IndSW.XiuXianFuWuL1, IndSW.YiYaoShengWuL1, IndSW.GongYongShiYeL1, IndSW.JiaoTongYunShuL1, IndSW.DianZiL1, IndSW.ChuanMeiL1, IndSW.TongXinL1)
# freq = 'd'                                      # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = Monthly(1)                       # 执行handle_data的时间间隔
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000,commission = Commission(buycost=0.0003, sellcost=0.0013, unit='perValue'), slippage = Slippage(value=0.00))
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#     account = context.get_account('fantasy_account')
#     current_universe = context.get_universe('stock', exclude_halt=True)
#     pre_date = context.previous_date.strftime("%Y-%m-%d")
#     if pre_date in q_dates:
#         # 拿取调仓日前一个交易日的因子，并按照相应十分位选择股票
#         q = factor_data.ix[pre_date].dropna()
#         q = q.set_index('stock', drop=True)
#         q = q.ix[current_universe].dropna()
#         #q_max = q['factor'].quantile(0.8)
#         #my_univ = q[(q['factor']>q_max)].index.values
#         q_max = q['factor'].quantile(1)
#         q_min= q['factor'].quantile(0.5)
#
#         my_univ = q[(q['factor']>=q_min)&(q['factor']<q_max)].index.values
#         #print(context.current_date)
#         #print(my_univ)
#         # 交易部分
#         positions = account.get_positions()
#         #print(positions)
#         sell_list = [stk for stk in positions if stk not in my_univ]
#         for stk in sell_list:
#             account.order_to(stk,0)
#         #在目标股票池中的，等权买入
#         for stk in my_univ:
#             account.order_pct_to(stk, 1.0/len(my_univ))
