# %% [markdown]
# # 提问

# %% [raw]
# import numpy as np
# import pandas as pd
# from pandas import DataFrame,Series
# import talib
# import time
# start = '2016-06-01'                       # 回测起始时间
# end = '2016-07-01'                         # 回测结束时间
# universe = DynamicUniverse('SH50')     # 证券池，支持股票和基金、期货
# benchmark = 'HS300'
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 66                          # 执行handle_data的时间间隔
# max_history_window=600
# L=60
# i=1
# # 执行handle_data的时间间隔
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=1000000)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
# #获取收盘价数据且算出结果，可以直接获得当天的数据，
#
# def handle_data(context):
#     # 核心策略逻辑
#     universe = context.get_universe(exclude_halt=True)
#     MonthEndDate=DataAPI.TradeCalGet(exchangeCD=u"XSHE",beginDate=start,endDate=end,field=u"calendarDate,isMonthEnd",pandas="1")
#     MonthEndDate=MonthEndDate[MonthEndDate['isMonthEnd']==1]#获取月末日期
#     data2=DataAPI.MktEqudAdjGet(secID=universe,field=u"tradeDate,closePrice",beginDate=start,endDate=end,pandas="1")
#     for day in data2['tradeDate']:
#         if day in data2['tradeDate']:
#             print day
# #             # data2['L_average'] = np.round(pd.rolling_mean(data2['closePrice'], window=L), 2)
# #             # data2['L_average']=data2['L_average']/data2['closePrice']
# #             # print data2['L_average']
