# %% [markdown]
# # Notebook

# %% [raw]
# import pandas as pd
# start = '2019-01-01'                       # 回测起始时间
# end = '2019-07-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = DynamicUniverse('HS300')        # 证券池，回测支持股票和基金
# capital_base = 10000000                      # 起始资金
# freq = 'd'
# refresh_rate = 1                           # 调仓频率，即每 refresh_rate 个交易日执行一次 handle_data() 函数
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(context):                  # 每个refresh_rate的买入卖出指令
#     account = context.get_account('fantasy_account')
#     current_position = account.get_positions()
#     previous_date = context.previous_date.strftime('%Y%m%d') #获取前一天日期
#
#     factor_frame_list = DataAPI.MktStockFactorsOneDayGet(tradeDate=previous_date,secID=u"",ticker=u"000300",field=["ticker",'tradeDate','ROE', 'DAVOL10'],pandas="1")
#     factor_data = factor_frame_list[['ticker', 'tradeDate', 'ROE']]
#     factor_data.rename(columns={"ROE":'factor1'}, inplace=True)
#     factor_data = factor_data.set_index('tradeDate', drop=True)
#     factor_data.dropna(inplace=True)
#     if previous_date not in factor_data.index.values:
#         return
#
#     q = factor_data.ix[previous_date].dropna()
#
#     q = q.set_index('ticker', drop=True)
#     target_position = q[q['factor1']>=q['factor1'].quantile(0.8)].index.values
#
#     for stock in set(current_position).difference(target_position):
#         account.order_to(stock, 0)
#
#     for stock in target_position:
#         account.order_pct_to(stock, 1.0/len(target_position))
