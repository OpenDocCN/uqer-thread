# %% [markdown]
# # 16 策略思路(笔记P352)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt
from CAL.PyCAL import * # CAL provides classes and functions dealing with date, time, and calendars. 

sns.set()
pd.set_option('display.width', 200)
cal = Calendar('China.SSE')

# %%
# 这个函数的作用就是：预先设置参数，使得之后调用的时候，减少函数的参数
from functools import partial

# %%
fields_ef = ['secID', 'publishDate']
get_data = partial(DataAPI.FdmtEfGet, forecastType = 22, field =fields_ef) # 业绩预告 (Point in time) , forecastType 22: 盈利预增

data_ef = []
for stock in set_universe('HS300'):
    try:
        if len(data_ef):
            data_ef = data_ef.append(get_data(secID = stock))
        else:
            data_ef = get_data(secID = stock)
    except:
        pass
    
data_ef['publishDate'] = pd.to_datetime(data_ef['publishDate'])
data_ef = data_ef.sort(columns = 'publishDate')
data_ef = data_ef[data_ef.publishDate >= dt.datetime(2010, 1, 1)]

data_ef
# Out:
#           secID publishDate
# 14  300033.XSHE  2010-01-11
# 13  000661.XSHE  2010-01-20
# 5   000961.XSHE  2010-01-20
# 4   000627.XSHE  2010-01-21
# 16  000338.XSHE  2010-01-21
# 5   000001.XSHE  2010-01-27
# 36  300024.XSHE  2010-01-27
# 34  300015.XSHE  2010-01-27
# 18  000625.XSHE  2010-01-28
# 4   000963.XSHE  2010-01-28
# 8   000876.XSHE  2010-01-29
# 28  002294.XSHE  2010-01-30
# 12  000063.XSHE  2010-01-30
# 12  000157.XSHE  2010-02-02
# 23  002236.XSHE  2010-03-24
# 9   000596.XSHE  2010-03-26
# 3   000627.XSHE  2010-03-31
# 12  000596.XSHE  2010-04-07
# 3   000423.XSHE  2010-04-07
# 17  000671.XSHE  2010-04-08
# 1   600760.XSHG  2010-04-13
# 11  000157.XSHE  2010-04-14
# 17  000625.XSHE  2010-04-15
# 12  002153.XSHE  2010-04-16
# 5   000425.XSHE  2010-04-17
# 11  000656.XSHE  2010-04-20
# 3   600339.XSHG  2010-04-22
# 1   600383.XSHG  2010-04-23
# 2   600704.XSHG  2010-04-26
# 15  000338.XSHE  2010-04-27
# ..          ...         ...
# 0   600031.XSHG  2019-04-15
# ...

# %%
order? # 订单委托.此函数是全局函数,委托的交易品种,可以是证券,基金,期货,期权等
