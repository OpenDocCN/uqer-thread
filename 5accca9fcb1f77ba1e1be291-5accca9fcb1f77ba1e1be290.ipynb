# %% [markdown]
# # pandas中Series数据结构创建方法汇总

# %%
#创建pandas的Series数据结构的方法1
from pandas import Series,DataFrame                  #前期导入库
import pandas as pd                                  #前期导入库
test=Series(["name","Baidu","BAT"])                  #Series之  列表式创建
print test
# Out:
# 0     name
# 1    Baidu
# 2      BAT
# dtype: object

# %%
#创建pandas的Series数据结构的方法2
from pandas import Series,DataFrame                  #前期导入库
import pandas as pd                                  #前期导入库
test=Series(["name","Baidu","BAT"],index=[1,2,3])    #Series结构之  列表式创建+自定义索引
print test
# Out:
# 1     name
# 2    Baidu
# 3      BAT
# dtype: object

# %%
#创建pandas的Series数据结构的方法3
from pandas import Series,DataFrame                  #前期导入库
import pandas as pd                                  #前期导入库
test1={1:"one",2:"two",3:"three"}                    #Series结构之  字典式创建+自定义索引（先创建字典）
test2=Series(test1)                                    #再把列表转化成Series结构
print test
# Out:
# 1      one
# 2      two
# 3    three
# dtype: object

# %%
#创建pandas的Series数据结构的方法4
from pandas import Series,DataFrame                  #前期导入库
import pandas as pd                                  #前期导入库
test1={1:"one",2:"two",3:"three"}                    #Series结构之  字典式创建+自定义索引 
test2=Series(test1,index=[1,2,3,4])                  #在原字典基础上修改检索
print test2
# Out:
# 1      one
# 2      two
# 3    three
# 4      NaN
# dtype: object
