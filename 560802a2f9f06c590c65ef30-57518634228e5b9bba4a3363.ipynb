# %% [markdown]
# # quantitative trade demo 1

# %% [raw]
# start = '2014-01-01'
# end = '2015-01-01'
# benchmark = 'HS300'
# universe = ['000001.XSHE', '600000.XSHG']
# capital_base = 100000
# fred = 'd'
# refresh_rate = 1
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     for stock in account.universe:
#         order(stock,100)
