# %% [markdown]
# # 新手求助：一个简单的策略，但是换了股票池就出问题

# %% [raw]
# #策略思路是选择股票池中pe值最低的5支股票，每30个交易日换仓一次
# #问题在于，股票池换成"SH50"这样的，就会报错，怀疑是有股票停牌？求助大神~~
# start = '2014-01-01'                       # 回测起始时间
# end = '2015-05-31'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ('000001.XSHE','601988.XSHG','600030.XSHG','600036.XSHG','600000.XSHG','601318.XSHG')
# #universe = set_universe('SH50')  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 30                         # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
#
# period=30        #周期
#
# #获取股票信息
# stock=[]
# for i in range(0,len(universe)):
#     stock.append([])
#     stock[i].append(universe[i])
#     stock[i].append(DataAPI.MktEqudGet(secID =universe[i],field =['closePrice','PE'],beginDate = '20140101',endDate = '20150531'))
# #print stock[0]
# #print stock[0][0]
# #print stock[0][1]
# #print stock[0][1]['closePrice'][0]
#
# n_days=len(stock[0][1]['PE'])               # 定义总天数
# n_stock=len(universe)                   #股票数目
# n_stock_selected=5                     #选股数目
# n_period=n_days/period                   #调仓次数
#
# #转化为某一天内所有股票
# stock_new=[]
# for i_day in range(0,n_days):
#     stock_new.append([])
#     for i_stock in range(0,n_stock):
#         stock_new[i_day].append([])
#         stock_new[i_day][i_stock].append(stock[i_stock][0])
#         stock_new[i_day][i_stock].append(stock[i_stock][1]['closePrice'][i_day])
#         stock_new[i_day][i_stock].append(stock[i_stock][1]['PE'][i_day])
#
# #print stock_new[第几天][第几个股票][股票的性质]
#
# #根据PE值对股票降序排列
# for i_day in range(0,n_days,period):
#     #for i_stock in range(0,n_stock_selected-1):
#     for i_stock in range(0,n_stock-1):
#         for j_stock in range(1+i_stock,n_stock):
#             if(stock_new[i_day][j_stock][2]<stock_new[i_day][i_stock][2]):
#                 for i_period in range(0,period):
#                     if((i_day+i_period)<n_days):
#                         tmp=copy.deepcopy(stock_new[i_day+i_period][j_stock])
#                         stock_new[i_day+i_period][j_stock]=copy.deepcopy(stock_new[i_day+i_period][i_stock])
#                         stock_new[i_day+i_period][i_stock]=copy.deepcopy(tmp)
# #降序后，print stock_new[第几天][第几个股票][股票的性质]
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# asd =0
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     global asd
#     #print stock_new[asd][0]
#     for i in range(0,n_stock_selected):
#         for stock_new[asd][i] in account.universe:
#             amount = account.cash /len(account.universe) /account.referencePrice[stock_new[asd][i]]
#             if asd==0:
#                 order(stock_new[asd][i], amount)
#             elif stock_new[asd-30][i] in account.valid_secpos:
#                 order_to(stock_new[asd-30][i], 0)
#                 order(stock_new[asd][i],amount)
#     asd=asd+30
#     return
