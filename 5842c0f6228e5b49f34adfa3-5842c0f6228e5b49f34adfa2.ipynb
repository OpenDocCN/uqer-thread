# %% [markdown]
# # PCF

# %%
DataAPI.FdmtCFInduGet(ticker=u"600887",secID=u"",reportType=u"CQ3",endDateRep="",beginDateRep="",beginYear="2016",endYear="2016",fiscalPeriod="",endDate=u"",beginDate=u"",publishDateEnd=u"20161029",publishDateBegin=u"20161029",field=u"publishDate,endDateRep,NCFOperateA",pandas="1")
# Out:
#   publishDate  endDateRep   NCFOperateA
# 0  2016-10-29  2016-09-30  1.229908e+10

# %%
DataAPI.MktStockFactorsDateRangeProGet(secID=u"",ticker=u"600887",beginDate=u"20161202",endDate=u"20161202",field=u"ticker,tradeDate,PCF,NetOperateCFTTM,MktValue",pandas="1")
# Out:
#    ticker   tradeDate     PCF  NetOperateCFTTM      MktValue
# 0  600887  2016-12-02  9.3916     1.241168e+10  116565457922
