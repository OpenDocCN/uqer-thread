# %% [markdown]
# # 翻译一篇，本宝宝打算去别的地方玩玩优矿限制有点多 好的策略拉长回测就会变差，感觉优矿这点做的不好 限制有点大

# %% [raw]
# import numpy as np
#
# # 第一步：设置基本参数
# start = '2011-11-30'
# end   = '2016-03-11'
# capital_base = 1000000
# refresh_rate = 5
# benchmark = 'HS300'
# freq = 'd'
#
# # 第二步：选择主题，设置股票池
# universe = ['600376.XSHG', '600266.XSHG', '601588.XSHG', '600340.XSHG', '600158.XSHG', '300005.XSHE', '300137.XSHE', '603099.XSHG', '000802.XSHE', ]
#
# def initialize(account):
#     # 第三步：调整股票权重，权重列表序号与股票池列表序号对应
#     account.weight = [0, 0, 0, 0, 0.09, 0.08, 0.07, 0.06, 0.08, ]         #一个列表
#
#     account.weightmap = dict(zip(universe, account.weight))        #zip(universe,account.weight)为一个zip格式 account.weightmap为一个字典
#     a=zip(universe,account.weight)
#     #print(a)
#     #print(account.weightmap)
#
# def handle_data(account):
#     toda_y=account.current_date
#     print(toda_y)
#     # 本策略将使用account的以下属性：
#     # account.referencePortfolioValue表示根据前收计算的当前持有证券市场价值与现金之和。
#     # account.universe表示当天，股票池中可以进行交易的证券池，剔除停牌退市等股票。
#     # account.referencePrice表示股票的参考价，一般使用的是上一日收盘价。
#     # account.valid_secpos字典，键为证券代码，值为虚拟账户中当前所持有该股票的数量。
#
#     c = account.referencePortfolioValue
#
#     # 计算调仓数量
#     change = {}
#     for stock in account.universe:
#         #print(stock)
#         w = account.weightmap.get(stock, 0)         #get 字典的get 查找account()这个字典中是否含有stock的股票 是的话就返回他的权重值 没有的话就返回0，简而言之就是获取账户中股票存在就获取他的权重值，没有就把权重设为0
#         #print(w)
#
#
#         p = account.referencePrice[stock]           #获取账户中这个stock股票的价格    ，如果stock未在账户列表中则报错
#
#         #print(p)
#         if not np.isnan(p):                        #np.isnan()为判断是否是nan不是数字 如果不是数字为true 所以 notnp.isnan()为判断当前股票价格时候有问题为nana 如果是数字的话执行下面的程序
#             change[stock] = int(c * w / p) - account.valid_secpos.get(stock, 0)  #资产按照权重保持，算出今天该减少还是增加多少
#             #print(change[stock])
#
#     # 按先卖后买的顺序发出指令
#     for stock in sorted(change, key=change.get):
#         order(stock, change[stock])

# %%
bt
# Out:
#       tradeDate          cash  \
# 0    2011-11-30   682580.8980
# 1    2011-12-01   682580.8980
# 2    2011-12-02   682580.8980
# 3    2011-12-05   682580.8980
# 4    2011-12-06   682580.8980
# 5    2011-12-07   671823.8517
# 6    2011-12-08   671823.8517
# 7    2011-12-09   671823.8517
# 8    2011-12-12   671823.8517
# 9    2011-12-13   671823.8517
# 10   2011-12-14   664989.3275
# 11   2011-12-15   664989.3275
# 12   2011-12-16   664989.3275
# 13   2011-12-19   664989.3275
# 14   2011-12-20   664989.3275
# 15   2011-12-21   666526.7443
# 16   2011-12-22   666526.7443
# 17   2011-12-23   666526.7443
# 18   2011-12-26   666526.7443
# 19   2011-12-27   666526.7443
# 20   2011-12-28   650722.6004
# 21   2011-12-29   650722.6004
# 22   2011-12-30   650722.6004
# 23   2012-01-04   650722.6004
# 24   2012-01-05   650722.6004
# 25   2012-01-06   636092.8843
# 26   2012-01-09   636092.8843
# 27   2012-01-10   636092.8843
# 28   2012-01-11   636092.8843
# 29   2012-01-12   636092.8843
# ...
