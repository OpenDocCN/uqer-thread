# %% [markdown]
# # 5日均线角度

# %% [raw]
# # 本策略纯是为了回答https://uqer.datayes.com/community/share/56d1ad58228e5b0fe9b18654 的问题，关于5日均线角度
# # 学习贴，请各位大神指正
# # 因为题主要求的策略是“策略就是5日均线角度大于45度就买入，角度小于45度就清仓。”，势必造成持仓时间极短，以至于最后绩效很差
# import math
# start = '2015-01-01'                  # 回测起始时间
# end = '2015-12-31'                   # 回测结束时间
# benchmark = 'SH50'                   # 策略参考标准
# universe = ['159919.XSHE']              # 证券池，这里取了沪深300基金
# capital_base = 100000                  # 起始资金
# freq = 'd'                         # 日线策略
# refresh_rate = 1                     # 每个交易日调仓
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     # account.get_attribute_history：表示获取所有证券过去6天的closePrice数据，返回数据类型为 dict，键为每个证券的secID
#     hist = account.get_attribute_history('closePrice', 6)
#     for stk in account.universe:
#         # 计算股票过去5天收盘平均值
#         ma5 = hist[stk][-5:].mean()
#         # 计算股票ref1的过去5天收盘平均值
#         ma5_ref1 = hist[stk][-6:-2].mean()
#
#
#
#         #如果5日均线角度大于45度，即反正切小于1，则全部买入股票
#         #account.valid_secpos：表示当前交易日持有数量大于0的证券头寸。数据类型为字典，键为证券代码，值为头寸。
#         if (math.atan((ma5/ma5_ref1 -1)*100*180/3.1416) >= 1) and (stk not in account.valid_secpos): #
#             order(stk, account.cash)
#         # 否则全部卖出
#         else:
#             order_to(stk, 0)

# %%
bt
# Out:
#      tradeDate         cash  \
# 0   2015-01-13  100000.0000
# 1   2015-01-14  100000.0000
# 2   2015-01-15  100000.0000
# 3   2015-01-16     127.7275
# 4   2015-01-19   94014.5775
# 5   2015-01-20   94014.5775
# 6   2015-01-21   94014.5775
# 7   2015-01-22   94014.5775
# 8   2015-01-23     151.6083
# 9   2015-01-26   93959.6163
# 10  2015-01-27     291.8421
# 11  2015-01-28   92063.6307
# 12  2015-01-29   92063.6307
# 13  2015-01-30   92063.6307
# 14  2015-02-02   92063.6307
# 15  2015-02-03   92063.6307
# 16  2015-02-04   92063.6307
# 17  2015-02-05   92063.6307
# 18  2015-02-06   92063.6307
# 19  2015-02-09   92063.6307
# 20  2015-02-10   92063.6307
# 21  2015-02-11   92063.6307
# 22  2015-02-12      20.4795
# 23  2015-02-13   92405.7387
# 24  2015-02-16     153.5787
# 25  2015-02-17   93278.9547
# 26  2015-02-25     171.1399
# 27  2015-02-26   91555.0059
# 28  2015-02-27     323.8659
# 29  2015-03-02   91599.4489
# ..         ...          ...
# 208 2015-11-20   70885.0918
# ...
