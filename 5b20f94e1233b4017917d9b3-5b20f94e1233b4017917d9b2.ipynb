# %% [markdown]
# # 股票PE 索引、制表、可视化

# %%
#笨方法：
import numpy as np
import pandas as pd
a=DataAPI.MktStockFactorsDateRangeGet(secID=u"",ticker=u"600887",beginDate=u"20120101",endDate=u"20180605",field=u"ticker,tradeDate,PE",pandas="1")
b=np.array(a[['PE']])
c=pd.DataFrame(a.PE)

df=pd.DataFrame(data=b,index=a.tradeDate,columns=c.columns)

df.plot()

# %%
A=DataAPI.MktStockFactorsDateRangeGet(secID=u"",ticker=u"600887",beginDate=u"20061001",endDate=u"20071001",field=u"ticker,tradeDate,PE",pandas="1").pivot(index='tradeDate',columns='ticker',values='PE')
B=DataAPI.MktStockFactorsDateRangeGet(secID=u"",ticker=u"600887",beginDate=u"20120101",endDate=u"20180605",field=u"ticker,tradeDate,PE",pandas="1").pivot(index='tradeDate',columns='ticker',values='PE')
B.plot()
