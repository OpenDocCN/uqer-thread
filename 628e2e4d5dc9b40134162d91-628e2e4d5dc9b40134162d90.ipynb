# %% [markdown]
# # KDJ指标

# %% [markdown]
# # 什么是随机指标（KDJ）
# 随机指标（KDJ）又称为随机指数（The Random Index），是一种用来分析市场中超买或者超卖现象的指标，它最早运用于期货市场，后来在股票分析中被众多投资者广泛使用。
#
# 从交易原理上来看，KDJ指标最基础的交易思想建立在威廉指标基础之上，这种思想提出，在分析资产的价格时，除了考虑资产每天闭市时的价格（收盘价）以外，还要综合分析资产从开市到收市期间价格的变化情况。威廉指标的计算首先选定一个特定的时间跨度（比如14日），然后找出这一特定区间的最高价和最低价，构成一个价格变化区间;然后分析这一时间跨度最后一个时间点的收盘价与期间最高价和最低价的相对位置，再根据此相对位置来衡量市场的超买或者超卖现象。**威廉指标**可以用公式表达为∶
#
# $ \frac{最近n天内的最高价-第n天的收盘价}{最近n天内的最高价一最近n天内的最低价}$

# %% [markdown]
# 随机震荡指标在收盘价与最高价和最低价的相对位置的比值上，又融合了**移动平均**的思想，用更多的信息来捕捉市场的超买、超卖现象。

# %% [markdown]
# KDJ指标则是在随机震荡指标K线和D线的基础上增添一条J线，进一步提高了随机震荡指标对市场买卖信号捕捉的周延。

# %% [markdown]
# ## 计算
# KDJ 指标计算方式有别于传统的指标计算,
# KDJ 指标的计算首先要计算周期(n 日、n 周等) 的 RSV 值。
# RSV 值是未成熟随机指标值，接着再计算 K 值、D 值、J 值等。
# 以 n 日 KDJ 数值的 计算为例，其计算公式为：
# 计算RSV的值是求KDJ指标的第一步，RSV的计算公式为∶
#
# $RSV = \frac{第n天的收盘价-最近n天内的最低价}{近n，天内的最高价-最近n天内的最低价}$

# %% [markdown]
# K 值 = 2/3 × 第 8 日 K 值 + 1/3 × 第 9 日 RSV
#
# D 值=2/3×第 8 日 D 值+1/3×第 9 日 K 值
#
# J 值=3×第 9 日 K 值-2×第 9 日 D 值

# %% [markdown]
# RSV就是当天收盘价在最近一段时间的百分位。和集思录按天去算不同，RSV只选取当前距低点的涨幅，直接除以整个区间的距离。背后的原理是，最近涨多了，这个百分比会高，可能不适合买入。最近跌多了，这个百分比会低，可能适合买入。K是RSV的均线，D是K的均线，J=3K-2D。D是K的均线，所以D和K相差不会太大，那3K-2D也就会接近于K。简单地看，可以把K、D、J都当成RSV的均线，当成一个股价的近期百分位。这个百分位，可以和集思录温度计一样，低于20认为超卖，高于80认为超买，超买就是买多了，表明最近市场在涨，可能有点热。为何是20和80？参考二八定律。D是K的均线，那就存在K上穿D，大于D，也就是金叉，表明当前市场在变热而已。反之存在死叉。而J呢，思考一下，在上涨趋势中，KD金叉，K大于D，那3K-2D就会比K大点，反之，下跌趋势K比D小点。这个放大作用使J敏感点，超买超卖点也不同，J小于10超卖，大于100超买。就是在二八基础上加点变化。

# %% [markdown]
# KDJ 指标应用 KDJ 指标中，
#
# K 值和 D 值的取值范围都是 0-100，
#
# 而 J 值的取值范围可以超过 100 和低于 0，
#
# 但在分析软件上 KDJ 的研判范围都是 0-100。
#
# 通常就敏感性而言，J 值最强，K 值次之，D 值最慢，
#
# 而就安全性而言，J 值最差，K 值次之，D 值最稳。
#
# 在 KDJ 指标的三条曲线中，波动最频繁的是 J 线，其次是 K 线，波动最不频繁的是 D 线。
#
# KDJ 指标在设计过程中主要是研究最高价、最低价和收盘价之间的关系，同时也融合了动量观念、强弱指标和移动平均线的一些优点。因此，能够比较迅速、快捷、直观地研判行情， 被广泛用于股市的中短期趋势分析，是期货和股票市场上最常用的技术分析工具。

# %% [markdown]
# ## 理论应用方向
#
# ①判定超买、超卖 KD 取值范围为 0 至 100，一般来说当 KD 值大于 80 标的股票的股价处于超买阶段，此时 的交易操作应为卖出；如当 KD 值小于 20 此时标的股票的股价处于超卖阶段，进行买进操作。 而当 KD 值处于中线附近即熟知为 50 左右时，市场趋势信号不明显，不宜进行操作。
#
# ②指标交叉判定趋势 当代表 K 值的曲线向上穿越 D 值曲线，预示多头市场，应进行买进并持有操作。反之应 采取卖出操作。
#
# ③转势预警：当随机指标与标的股价之间出现背离情况，预示着投资市场会反向运行。

# %% [raw]
# start = '2021-01-01'                       # 回测起始时间
# end = '2022-01-01'                         # 回测结束时间
# universe = set_universe('HS300')         # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):
#     pass
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     hist_close = context.history(symbol='all', time_range=9, \
#                            attribute='closePrice', freq='d',style='ast')['closePrice']
#     hist_high =  context.history(symbol='all', time_range=9, \
#                            attribute='highPrice', freq='d',style='ast')['highPrice']
#     hist_low = context.history(symbol='all', time_range=9, \
#                            attribute='lowPrice', freq='d',style='ast')['lowPrice']
#     rsv = (hist_close.iloc[-1,:] - hist_low.min())/(hist_high.max() - hist_low.min())
#     kdj_k = rsv.copy()
#     kdj_k[0]=0
#     for i in range(len(rsv)):
#         kdj_k[i] = 2/3*kdj_k[i-1] + 1/3*rsv[i]
#     kdj_d = rsv.copy()
#     kdj_d[0]=0
#     for i in range(len(rsv)):
#         kdj_d[i] = 2/3*kdj_d[i-1] + 1/3*kdj_k[i]
# # 买入信号： K 值低于 20； D 值小于 10。
#     current_universe = context.get_universe(exclude_halt=True)
#     buylist = []
#
#     for stk in current_universe:
#         if kdj_k[stk]<20 and kdj_d[stk]<10:
#             buylist.append(stk)
#     # 获取当前账户信息
#     account = context.get_account('fantasy_account')
#     current_position = account.get_positions()
#
#     # 卖出当前持有，但目标持仓没有的部分
#     for stock in current_position:
#         if stock not in buylist:
#             account.order_to(stock, 0)
#
#     # 根据目标持仓权重，逐一委托下单
#     for stock in current_position:
#         if stock in buylist:
#             account.order(stock, 10000)

# %% [raw]
# start = '2021-01-01'                       # 回测起始时间
# end = '2022-01-01'                         # 回测结束时间
# universe = set_universe('HS300')         # 证券池，支持股票、基金、期货、指数四种资产
# benchmark = 'HS300'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# # 配置账户信息，支持多资产多账户
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):
#     pass
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     hist_close = context.history(symbol='all', time_range=9, \
#                            attribute='closePrice', freq='d',style='ast')['closePrice']
#     hist_high =  context.history(symbol='all', time_range=9, \
#                            attribute='highPrice', freq='d',style='ast')['highPrice']
#     hist_low = context.history(symbol='all', time_range=9, \
#                            attribute='lowPrice', freq='d',style='ast')['lowPrice']
#     rsv = (hist_close.iloc[-1,:] - hist_low.min())/(hist_high.max() - hist_low.min())
#     kdj_k = rsv.copy()
#     kdj_k[0]=0
#     for i in range(len(rsv)):
#         kdj_k[i] = 2/3*kdj_k[i-1] + 1/3*rsv[i]
#     kdj_d = rsv.copy()
#     kdj_d[0]=0
#     for i in range(len(rsv)):
#         kdj_d[i] = 2/3*kdj_d[i-1] + 1/3*kdj_k[i]
#     kdj_j = rsv.copy()
#     kdj_j[0]=0
#     for i in range(len(rsv)):
#         kdj_j[i] = 3*kdj_k[i] + 1*kdj_d[i]
# # 买入信号： 指标交叉判定趋势 当代表 K 值的曲线向上穿越 D 值曲线，预示多头市场，应进行买进并持有操作。
#     current_universe = context.get_universe(exclude_halt=True)
#     buylist = []
#
#     for stk in current_universe:
#         if kdj_k[stk] > kdj_d[stk]:
#             buylist.append(stk)
#     # 获取当前账户信息
#     account = context.get_account('fantasy_account')
#     current_position = account.get_positions()
#
#     # 卖出当前持有，但目标持仓没有的部分
#     for stock in current_position:
#         if stock not in buylist:
#             account.order_to(stock, 0)
#
#     # 根据目标持仓权重，逐一委托下单
#     for stock in current_position:
#         if stock in buylist:
#             account.order(stock, 10000)
