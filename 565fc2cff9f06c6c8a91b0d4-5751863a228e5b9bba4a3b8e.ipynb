# %% [markdown]
# # 沪港通测试

# %%
#####importing package#######
import numpy as np
import pandas as pd
import datetime as dt
from datetime import timedelta
from matplotlib import pyplot as plt
from CAL.PyCAL import *
today = Date.todaysDate()
endDate = today.toDateTime().strftime('%Y%m%d')   
#得到每日沪股通的流入流出金额
def dailyVolumn(date):
    dailyQuota = 13000000000 #the quota is fixed
    dailyBalance = DataAPI.JY.HKSHKQuotaJYGet(endDate=date,tradingTypeCd=u"1",field=u"dailiBalance",pandas="1")
    dailyVolumn = np.array(dailyQuota - dailyBalance['dailiBalance'])
    return dailyVolumn
closeIndex = DataAPI.MktIdxdGet(ticker='000001',beginDate='20141117',endDate=endDate,field=["tradeDate","closeIndex"],pandas="1")
data = pd.DataFrame({'tradeDate':closeIndex['tradeDate'], 'indexPrice':closeIndex["closeIndex"], 'dailyVolumn':np.array([0] * len(closeIndex)),'accumVolumn':np.array([0] * len(closeIndex)),'dailyShare':np.array([0] * len(closeIndex)),'accumShare':np.array([0] * len(closeIndex)),'meanPrice':np.array([0] * len(closeIndex))})
#data.index = closeIndex['tradeDate']
for i in range(len(data)):
    date = data.loc[i,'tradeDate']
    try:
        dV = dailyVolumn(date.replace('-',''))
        data.loc[i,'dailyVolumn'] = dV
        if i==0:                
            data.loc[i,'accumVolumn'] = data.loc[i,'dailyVolumn']
            data.loc[i,'dailyShare'] = data.loc[i,'dailyVolumn'] / data.loc[i,'indexPrice']
            data.loc[i,'accumShare'] = data.loc[i,'dailyShare']
            data.loc[i,'meanPrice'] = data.loc[i,'accumVolumn'] / data.loc[i,'accumShare']
        else:                
            data.loc[i,'accumVolumn'] = data.loc[i,'dailyVolumn'] + data.loc[i-1,'accumVolumn']
            data.loc[i,'dailyShare'] = data.loc[i,'dailyVolumn'] / data.loc[i,'indexPrice']
            data.loc[i,'accumShare'] = data.loc[i,'dailyShare'] + data.loc[i-1,'accumShare']
            data.loc[i,'meanPrice'] = data.loc[i,'accumVolumn'] / data.loc[i,'accumShare']
    except:
        data.loc[i,'accumVolumn'] = data.loc[i,'dailyVolumn'] + data.loc[i-1,'accumVolumn']            
        data.loc[i,'dailyShare'] = data.loc[i,'dailyVolumn'] / data.loc[i,'indexPrice']
        data.loc[i,'accumShare'] = data.loc[i,'dailyShare'] + data.loc[i-1,'accumShare']
        data.loc[i,'meanPrice'] = data.loc[i,'accumVolumn'] / data.loc[i,'accumShare']
        continue
data.index = data['tradeDate']   
data.tail(10)
# Out:
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com 443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
# api.wmcloud.com
#  443
#                  accumShare   accumVolumn      dailyShare  dailyVolumn  \
# tradeDate
# 2015-11-19  51785447.034859  152954000000     -829.402427     -3000000
# 2015-11-20  51815745.891766  153064000000    30298.856907    110000000
# 2015-11-23  51822116.527015  153087000000     6370.635249     23000000
# 2015-11-24  51939369.500028  153511000000   117252.973013    424000000
# 2015-11-25  51981311.094302  153664000000    41941.594274    153000000
# 2015-11-26  52165602.228083  154334000000   184291.133781    670000000
# 2015-11-27  52242719.990981  154599000000    77117.762898    265000000
# 2015-11-30  53248987.759211  158066000000  1006267.768230   3467000000
# 2015-12-01  53467428.876600  158821000000   218441.117389    755000000
# 2015-12-02  53373844.231267  158490000000   -93584.645333   -331000000
#
#             indexPrice    meanPrice   tradeDate
# tradeDate
# 2015-11-19    3617.062  2953.609725  2015-11-19
# 2015-11-20    3630.500  2954.005532  2015-11-20
# 2015-11-23    3610.315  2954.086214  2015-11-23
# 2015-11-24    3616.113  2955.580737  2015-11-24
# 2015-11-25    3647.930  2956.139366  2015-11-25
# 2015-11-26    3635.552  2958.539601  2015-11-26
# 2015-11-27    3436.303  2959.244848  2015-11-27
# 2015-11-30    3445.405  2968.432014  2015-11-30
# 2015-12-01    3456.309  2970.425235  2015-12-01
# 2015-12-02    3536.905  2969.431981  2015-12-02

# %%
data[['indexPrice','meanPrice']].plot(figsize=(14,5),linewidth=2)
plt.figure(2)
data['accumShare'].plot(figsize=(14,3),color='red',title='accumShare',linewidth=2)
