# %% [markdown]
# # Python入门及数据处理的作业

# %% [markdown]
# # <center>《Python入门及数据处理》</center>
# ---
# ## 课程作业:
# 1. 建立一个包含list的tuple, 比如a = (1, 2, 3, [4,5])。尝试修改第4个元素[4, 5]里任意一个值，查看是否报错，比如a[3][0]=44。
# 2. 利用DataAPI.MktStockFactorsOneDayGet 取一天的某些感兴趣的因子值，对返回的DataFrame进行增删查改的操作。该API文档参见 https://uqer.datayes.com/data/search/MktStockFactorsOneDayGet
# 3. 对上述DataFrame进行缺失值处理，缺失值按照该股票申万一级行业的均值填充。

# %%
a=(1,2,3,[4,5])
a
a[3][1] = 6
a
# Out:
# (1, 2, 3, [4, 6])

# %%
aa = DataAPI.MktStockFactorsOneDayGet(tradeDate=u"20191115",secID=u"",ticker=u"600001,002035,600640,300136",field=u"",pandas="1")
bb=aa.head()
bb.loc[1]
dd=bb.loc[0:3,['PCF','ROE']]
dd.loc[4]=[4,9.6]
#del dd.loc[4] 这里如何删除掉这一行？会报错
dd.loc[4,'ROE']= 99.2
dd
# Out:
#         PCF      ROE
# 0   11.2370   0.2898
# 1   75.9518   0.2512
# 2 -855.4131   0.0372
# 4    4.0000  99.2000

# %%
import pandas as pd

aa = DataAPI.MktStockFactorsOneDayGet(tradeDate=u"20191115",secID=u"",ticker=u"",field=['ticker','PCF','ROE'],pandas="1") #取行情信息

bb=ticker_ind = DataAPI.EquIndustryGet(industryVersionCD=u"010303", field=[u"ticker", u"industryName1", u"isNew"] ,pandas="1") #取行业信息
cc = bb[bb['isNew'] ==1]#取最新的行业信息

aa=aa.set_index('ticker',drop='true')
cc=cc.set_index('ticker', drop='true')

aacc=pd.merge(aa,cc,how='inner',on='ticker')
aacc
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <mercury-input-114-AA22481097764A908D96C78E1F6A63FC> in <module>()
#       9 cc=cc.set_index('ticker', drop='true')
#      10
# ---> 11 aacc=pd.merge(aa,cc,how='inner',on='ticker')
#      12 aacc
#      13
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      36                          right_on=right_on, left_index=left_index,
#      37                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 38                          copy=copy, indicator=indicator)
#      39     return op.get_result()
#      40 if __debug__:
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     208         (self.left_join_keys,
#     209          self.right_join_keys,
# --> 210          self.join_names) = self._get_merge_keys()
#     211
#     212     def get_result(self):
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in _get_merge_keys(self)
#     432                 else:
#     433                     if not is_rkey(rk):
# --> 434                         right_keys.append(right[rk]._values)
#     435                         if lk == rk:
#     436                             # avoid key upcast in corner case (length-0)
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'ticker'

# %% [markdown]
# ---
# ## 如何提交作业？
#
# 1. 您可以在当前Notebook中，完成指定的课程作业，然后使用优矿的私密分享功能进行分享，操作见下图：
#     ![图片注释](http://storage-uqer.datayes.com/5485447af9f06c8e77336720/c0df404c-0b1f-11e8-b54b-0242ac140002)
#     ![图片注释](http://storage-uqer.datayes.com/5485447af9f06c8e77336720/c6dac4ee-0b1f-11e8-958b-0242ac140002)
#     ![图片注释](http://storage-uqer.datayes.com/5485447af9f06c8e77336720/8de59516-0b1e-11e8-958b-0242ac140002)
# 2. 把私密分享的链接粘贴到视频课程底部的提交作业对话框中，点击提交作业即可以完成课程作业的提交
#
# 	![图片注释](http://storage-uqer.datayes.com/5485447af9f06c8e77336720/c741f772-2b68-11e8-8ffb-0242ac140002)
#
# 3. 扫码加学习助手的微信，优矿讲师还会对您的课程作业进行点评，还有更多活动等着您！
#
# 	![图片注释](http://storage-uqer.datayes.com/5485447af9f06c8e77336720/0513690c-2b67-11e8-8ffb-0242ac140002)
