# %% [markdown]
# # Notebook4

# %% [markdown]
# 本文是基于净利润增长率和市盈率双因子数字的限定，从而选取出相应的股票，具体量化3条:
# 1.	公司的净利润增长率小于100%，大于45%是，其市盈率上限为50
# 2.	公司的净利润增长率大于15%，小于45%，其市盈率上限为40

# %% [raw]
# import pandas as pd
# import numpy as np
# start = '2013-04-04'
# end = '2017-04-30'                        # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('A')               # 证券池，为全部A股
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 6                 # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# def initialize(account):
#     pass
# def handle_data(account):   # 每个交易日的买入卖出指令
#     filename1='OperatingProfitGrowRate'  #营业利润增长率
#     filename2='PE'              #市盈率
#     filename3= 'LCAP'
#
#     previousdate=account.previous_date.strftime("%Y%m%d")    #上一个交易日时间
#     factor=DataAPI.MktStockFactorsOneDayGet(tradeDate=previousdate, secID=set_universe('A'), field=['secID',filename1,filename2,filename3], pandas='1').dropna().set_index('secID')
#     factor=factor[factor[filename1]<1]   #公司的净利润增长率小于110%
#
#     factor1=factor[factor[filename1]>0.45] #公司的净利润增长率大于48%
#
#     factor2=factor[(factor[filename1]<0.45)&(factor[filename1]>0.15)]   #公司的净利润增长率小于110%
#
#
#     factor3=factor1[factor1[filename2]<50]    #公司的市盈率小于45
#
#
#     factor4=factor2[factor2[filename2]<40]
#     factor= pd.concat([ factor3, factor4],axis=0)
#
#     for s in factor.index:  #等权买入买入清单上的股票
#         if s not in account.security_position.keys():
#             order_pct_to(s,float(1.0)/len(factor))
#     for s in account.security_position: #卖出不在买入清单的股票
#         if s not in factor.index:
#             order_pct_to(s,0)
