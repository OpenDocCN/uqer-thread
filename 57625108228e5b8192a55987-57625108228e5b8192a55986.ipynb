# %% [markdown]
# #

# %% [raw]
# start = '2012-08-01'
# end = '2012-11-10'
# #end = '2015-08-01'
# benchmark = 'HS300'
# capital_base = 1000000
# security_base = {}
# commission = Commission(buycost=0.0008, sellcost=0.0018)  # 佣金万八
# slippage = Slippage()
# universe=set_universe('SH50')
# freq='d'
# refresh_rate = 1
#
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):  # 每个交易日的买入卖出指令
#         history=account.get_attribute_history('closePrice', 60)
#
#         x=history.keys()
#         y=account.universe
#
#         print account.current_date
#         print "in history, not in account universe"
#         for i in x:
#             if i not in (y):
#                 print i
#
#         print "in account universe, not in history"
#         for i in y:
#             if i not in (x):
#                 print i
