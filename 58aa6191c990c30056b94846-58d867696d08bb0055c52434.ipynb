# %% [markdown]
# # 优矿日报 | 新版哦

# %% [markdown]
# # `更新日志`
#
# - 20170321:
# 	- 加入因子表现，银证转账信息
#
# - 20170220:
# 	- 新版上线了哦～～～
# 	- 新版尽量去掉不要的代码，详细实现代码，冗余文字，尽量一行代码一张图，给你最纯净的体验
# 	- 新版不再提供 daily_report 这个库了，大家可以参考之前的 report 库哈

# %%
import pandas as pd
from lib import daily_report, fresh_ticker, lib, index_trend, attributions, base_algorithm
reload(lib)
reload(daily_report)
reload(fresh_ticker)
reload(index_trend)
reload(attributions)
reload(base_algorithm)
daily_report.figsize = (14, 6)

REFRESH_NEW_TICKER = False

# %% [markdown]
# # `0. 指数模型`

# %%
df = daily_report.index_prediction()
# Out:
# 最近5个交易日预测数据
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>中文简称</th>
#       <th>tradeDate</th>
#       <th>收盘价</th>
#       <th>最高价</th>
#       <th>最低价</th>
#       <th>预测的最高价</th>
#       <th>预测的最低价</th>
#       <th>预测压力位</th>
#       <th>预测支撑位</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>上证综指</td>
#       <td>2017-03-20</td>
#       <td>3250.8080</td>
#       <td>3251.1270</td>
#       <td>3228.1180</td>
#       <td>3254.190340</td>
#       <td>3222.251029</td>
#       <td>3264.603150</td>
#       <td>3206.928836</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>上证综指</td>
#       <td>2017-03-21</td>
#       <td>3261.6108</td>
#       <td>3262.2209</td>
#       <td>3246.6959</td>
#       <td>3267.757713</td>
#       <td>3237.440678</td>
#       <td>3278.213937</td>
#       <td>3220.299167</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>上证综指</td>
# ...

# %% [markdown]
# # `1. 市场行情`

# %%
df, res = daily_report.index_info()
res
# Out:
#      指数    收盘价    涨跌幅   成交量  5日均量
# 0  上证综指   3269  0.64%  2670  2405
# 1  深证成指  10646   0.6%  1199  1126
# 2  创业板指   1965  0.86%   188   187
# 3  创业板综   2644  0.42%   812   871

# %%
df = daily_report.factor_perfomance(factors=[
                                'LCAP', 'PB', 'CurrentAssetsTRate', 
                                'GrossIncomeRatio', 'CurrentRatio', 'ROA', 
                                'SUE', 'EPS', 'CTOP'], x=3, y=3)

# %%
daily_report.money_trans()

# %%
df, ax = daily_report.rong_zi_rong_quan()

# %%
res = daily_report.hu_gang_tong()

# %%
df, ax = daily_report.dazong()

# %%
df, ax = daily_report.money_flow()

# %%
df, data, ax = daily_report.industry_change()

# %%
res, tmp, ax = daily_report.industry_money_flow()

# %%
df, df_group, ax = daily_report.ticker_change_dist()

# %%
df = daily_report.ticker_money_flow()
# Out:
# 2017-03-24 个股资金流入流出情况
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ticker</th>
#       <th>tradeDate</th>
#       <th>中文简称</th>
#       <th>市值(亿)</th>
#       <th>股本(亿)</th>
#       <th>净流入(亿)</th>
#       <th>大单净流入(亿)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>601668</td>
#       <td>2017-03-24</td>
#       <td>中国建筑</td>
#       <td>2865</td>
#       <td>300</td>
#       <td>37.45</td>
#       <td>34.97</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>600209</td>
#       <td>2017-03-24</td>
#       <td>罗顿发展</td>
#       <td>78</td>
#       <td>4</td>
#       <td>8.58</td>
#       <td>6.04</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>000903</td>
#       <td>2017-03-24</td>
#       <td>云内动力</td>
#       <td>93</td>
#       <td>8</td>
#       <td>7.69</td>
#       <td>3.99</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>002143</td>
# ...

# %%
df, df_ticker, df_netin, ax = daily_report.long_hu()
# Out:
# 2017-03-24 龙虎榜机构净买入个股
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ticker</th>
#       <th>中文简称</th>
#       <th>买</th>
#       <th>卖</th>
#       <th>净买</th>
#       <th>交易日</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>002040</td>
#       <td>南 京 港</td>
#       <td>580.0</td>
#       <td>0.0</td>
#       <td>580.0</td>
#       <td>2017-03-27</td>
#     </tr>
#   </tbody>
# </table>
# 2017-03-24 龙虎榜净买入个股
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ticker</th>
#       <th>中文简称</th>
#       <th>买</th>
#       <th>卖</th>
#       <th>净买</th>
#       <th>交易日</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>000672</td>
#       <td>上峰水泥</td>
#       <td>28079.0</td>
#       <td>8911.0</td>
#       <td>19167.0</td>
#       <td>2017-03-24</td>
#     </tr>
#     <tr>
# ...

# %%
df = daily_report.ticker_liang_rong()
# Out:
# 2017-03-24 个股两融数据【金额单位：万元】
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ticker</th>
#       <th>中文简称</th>
#       <th>交易日</th>
#       <th>融资买</th>
#       <th>融资偿还</th>
#       <th>融券卖</th>
#       <th>融券偿还</th>
#       <th>融资买-融券卖</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>601668</td>
#       <td>中国建筑</td>
#       <td>2017-03-24</td>
#       <td>17156</td>
#       <td>27</td>
#       <td>27</td>
#       <td>0</td>
#       <td>17129</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>000839</td>
#       <td>中信国安</td>
#       <td>2017-03-24</td>
#       <td>8050</td>
#       <td>3</td>
#       <td>3</td>
#       <td>0</td>
#       <td>8047</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>000725</td>
#       <td>京东方A</td>
#       <td>2017-03-24</td>
#       <td>6020</td>
#       <td>8</td>
#       <td>8</td>
#       <td>0</td>
#       <td>6012</td>
# ...
