# %% [markdown]
# #

# %%
import pandas as pd
import numpy as np
stockcode=pd.read_csv('stockcode.csv')
arr=np.array(stockcode['code'],dtype='S6')
listcode=list(arr)

date=pd.read_csv('date.csv')
arr2=np.array(date['date'])
listdate=list(arr2)
for i in range(0,1255,20):
    daily_data1=DataAPI.MktStockFactorsOneDayGet(tradeDate=listdate[i],ticker=listcode,field=u"",pandas="1")
    for each in listdate[i:i+20]:
        daily_data2=DataAPI.MktStockFactorsOneDayGet(tradeDate=each,ticker=listcode,field=u"",pandas="1")
        daily_data1 = pd.concat([daily_data1,daily_data2])
    file_name = 'all_data%d'%i+ '.csv'
    daily_data1.to_csv(file_name)
# Out:
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <mercury-input-3-a164c1eac6a8> in <module>()
#      11     daily_data1=DataAPI.MktStockFactorsOneDayGet(tradeDate=listdate[i],ticker=listcode,field=u"",pandas="1")
#      12     for each in listdate[i:i+20]:
# ---> 13         daily_data2=DataAPI.MktStockFactorsOneDayGet(tradeDate=each,ticker=listcode,field=u"",pandas="1")
#      14         daily_data1 = pd.concat([daily_data1,daily_data2])
#      15     file_name = 'all_data%d'%i+ '.csv'
#
# /home/ipython/anaconda/lib/python2.7/site-packages/DataAPI/DATAYES.pyc in MktStockFactorsOneDayGet(tradeDate, secID, ticker, field, pandas)
#    2911         for index, item in enumerate(p_list):
#    2912             requestString[split_index] = ','.join(item)
# -> 2913             temp_result = api_base.__getCSV__(''.join(requestString), httpClient, gw=False)
# ...
