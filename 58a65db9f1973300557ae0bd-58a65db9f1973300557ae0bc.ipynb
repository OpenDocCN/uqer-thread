# %% [markdown]
# # 低流通市值低价股

# %% [raw]
# from __future__ import division
# import pandas as pd
# import numpy as np
# start = '2012-05-01'                       # 回测起始时间
# end = '2017-02-13'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = StockScreener( Factor.LFLO.nsmall(300) )  # 最低流通市值证券池，支持股票和基金
# capital_base = 150000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     account.price_flag={}
#     account.piece=0
#     pass
#
# sell_return=0.2
# position_piece=10
#
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     hist_price=pd.Series(account.referencePrice )
#     hist_price.sort_values(inplace=True,ascending=True)
#     newUniverse=hist_price.index.values
#     for stock in account.avail_secpos:
#         if (stock in account.referencePrice) and (account.referencePrice[stock]>account.price_flag[stock]*(1+sell_return)):
#             order_to(stock,0)
#             account.piece-=1
#     for stock in newUniverse:
#         if account.piece<position_piece:
#             if (stock in account.universe) and (not stock in account.valid_secpos):
#                 try:
#                     order_pct_to(stock,1/position_piece)
#                 except:
#                     continue
#                 account.piece+=1
#                 account.price_flag[stock]=account.referencePrice[stock]
#     return
