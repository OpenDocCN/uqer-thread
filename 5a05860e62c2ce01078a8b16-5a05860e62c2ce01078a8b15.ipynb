# %% [markdown]
# # 获取交易数据的代码

# %%
data=DataAPI.SecIDGet(partyID=u"",assetClass=u"E",ticker=u"",cnSpell=u"",field=u"",pandas="1")

# %%
print data
# Out:
#              secID    ticker secShortName cnSpell exchangeCD assetClass  \
# 0      000001.XSHE    000001         平安银行    PAYH       XSHE          E
# 1      000002.XSHE    000002          万科A     WKA       XSHE          E
# 2      000003.XSHE    000003        PT金田A     NaN       XSHE          E
# 3      000004.XSHE    000004         国农科技    GNKJ       XSHE          E
# 4      000005.XSHE    000005         世纪星源    SJXY       XSHE          E
# 5      000006.XSHE    000006         深振业A    SZYA       XSHE          E
# 6      000007.XSHE    000007          全新好     QXH       XSHE          E
# 7      000008.XSHE    000008         神州高铁    SZGT       XSHE          E
# 8      000009.XSHE    000009         中国宝安    ZGBA       XSHE          E
# 9       00001.XHKG     00001           长和      CH       XHKG          E
# 10     000010.XSHE    000010         美丽生态    MLST       XSHE          E
# 11     000011.XSHE    000011         深物业A    SWYA       XSHE          E
# ...

# %%
data.to_excel('代码.xlsx')
