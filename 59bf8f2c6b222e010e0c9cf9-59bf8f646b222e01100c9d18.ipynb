# %% [markdown]
# # Notebook1

# %%
DataAPI.MktStockFactorsOneDayGet(tradeDate=u"20150227",secID=u"",ticker=u"000001,600000",field=u"secID,tradeDate,FY12P,SFY12P",pandas="1")
# Out:
#          secID   tradeDate   FY12P  SFY12P
# 0  000001.XSHE  2015-02-27  0.1379  0.5049
# 1  600000.XSHG  2015-02-27  0.1897  0.4848
