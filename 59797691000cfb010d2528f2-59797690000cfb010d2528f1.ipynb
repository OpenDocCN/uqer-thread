# %% [markdown]
# # 5支银行股配置策略

# %% [raw]
# import numpy as np
# import pandas as pd
# from datetime import datetime
# # 回测过程中用的是前复权价格
#
# start = '2013-01-01'                       # 回测起始时间
# end = '2017-06-30'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# #universe = [ '600519.XSHG','600036.XSHG',  '601166.XSHG']  # 证券池，支持股票和基金
# universe = [ '600036.XSHG',  '601166.XSHG', '600000.XSHG',  '600015.XSHG', '601169.XSHG']  # 证券池，支持股票和基金
# #universe = set_universe(IndSW.YinHangL1) + ['600519.XSHG']
# #universe = set_universe(IndSW.YinHangL1)
# #universe =  ['600519.XSHG']
# capital_base = 1000000                     # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = Monthly(1)                 # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# #refresh_rate = Weekly(1)                   # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     #取因子数据-PB和PBG
#     account.limit = {}
#     for stk in universe:
#         # 该行代码为获取20110101到现在测试时间段内的PB值，可以修改和设定PB统计的起始日期
#         df = DataAPI.MktStockFactorsDateRangeGet(secID=stk,beginDate="20110101",endDate=account.current_date,field=u"tradeDate,PB,NetAssetGrowRate")
#         #打印每支股票时间段内的PB和PBG
#         #print(stk,df)
#         #下面的代码使用PBG估值
#         #df["final_value"] =  df["PB"]/(df["NetAssetGrowRate"]+1)
#         df["final_value"] =  df["PB"]
#         #可以调整参数，0.1和0.5代表分位数，即在过去N年的最低十分位满仓，五十分位清仓，是一个非常保守的策略；0.2和0.8是指20%分位和80%分位。
#         QT = df["final_value"].quantile([.2, .8])
#         print QT
#         account.limit[stk] = (QT[0.2], QT[0.8])
#     #print(account.limit)
#         #if pd.to_datetime(df.tradeDate)>datetime(2017,1,1):
#        # print("this is stock ",stk," first:",df[pd.to_datetime(df.tradeDate)>datetime(2017,1,1)])
#
#     #当前时间标的的PB值和PBG值
#     df = DataAPI.MktStockFactorsOneDayGet(tradeDate=account.current_date,secID=account.universe,field=u"secID,PB,NetAssetGrowRate").set_index("secID")
#     #df["final_value"] =  df["PB"]/(df["NetAssetGrowRate"]+1)
#     df["final_value"] =  df["PB"]
#
#     #持股比例置0
#     df["hold_pct_ratio"] = np.zeros((len(df),1))
#
#     #calculate hold percent ratio for each stock
#     for stk in account.limit.keys():
#         if stk in df.index:
#             #first fetch the value for one stock
#             value = df["final_value"][stk]
#             #calcuate percentage of holding on this stock according to its factor value and limit bounds
#             percent = 1 - (value - account.limit[stk][0])/(account.limit[stk][1] - account.limit[stk][0])
#             #adjust the percent
#             if percent > 1: percent = 1
#             if percent < 0: percent = 0
#             #update percent in table
#             df["hold_pct_ratio"][stk] = percent
#     #print("this is the second:",df)
#
#     max_pct = df["hold_pct_ratio"].max(axis=0)
#     lower_pct = 1
#     if ((max_pct-0.1) >= 0): lower_pct = max_pct-0.1
#     print df
#
#     df=df[df["hold_pct_ratio"] >= lower_pct]
#     df["hold_pct_ratio_2"] = max_pct*df["hold_pct_ratio"]/df["hold_pct_ratio"].sum(axis=0, skipna=True)
#
#     df = df.dropna()
# #这行代码可以去掉输出结果
# #    print("this is the third:",df)
#
#     buy_list = df.index
# #这行代码可以控制输出
#     #print(buy_list)
#
#     #sell stocks
#     for stk in account.security_position.keys():
#         if stk not in buy_list:
#             account.order_pct_to(stk,  0)
#     #buy stocks
#     for stk in buy_list:
#         if len(buy_list) < 2:
#             account.order_pct_to(stk,  df["hold_pct_ratio"][stk])
#            # print "1 or less stocks: " + stk, str(df["hold_pct_ratio"][stk])
#         else:
#             account.order_pct_to(stk,  df["hold_pct_ratio_2"][stk])
#
#  #这行代码可以控制输出
#   #  print account.current_date.date(), " Num of stocks in holdings: " + str(len(account.security_position.keys()))

# %%
bt
