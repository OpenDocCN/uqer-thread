# %% [markdown]
# # 程序员学量化投资（一）：测试1

# %% [raw]
# #设置基本参数
# start = '2016-01-01'
# end   = '2016-12-31'
# capital_base = 4000000
# refresh_rate = 5
# benchmark = 'HS300'
# freq = 'm'
# buyNum = 2000
#
# #设置股票池 以平安证券为例
# universe = ['601318.XSHG', ]
#
# def initialize(account):
#     account.step = 0.15
#     account.ff = 16.25
#     pass
#
# def handle_data(account):
#     if (account.security_position.get('601318.XSHG') == None):
#         order(account.universe[0], 60000)  #初始买入操作
#         print(account.security_position)
#         print(account.reference_price[account.universe[0]])
#     global price1
#     try:
#         price1=account.reference_price[account.universe[0]]   # 股票参考价
#     except Exception, e:
#         pass    #存在历史数据出错的情况
#     #priceDict=account.get_attribute_history('highPrice',1)
#     #price2=priceDict.get('601318.XSHG')[0]
#     if None == price1:
#         print price1
#     else:
#         if account.ff - price1 >= account.step:
#             account.ff = account.ff-account.step
#             #print price1
#             #print('base-'account.ff)
#             #print account.universe
#             order('601318.XSHG', buyNum, price=account.ff)  #下跌step,买入操作
#         if price1 - account.ff >= account.step:
#             account.ff = account.ff+account.step
#             #print(price1)
#             #print('base-'+account.ff)
#             order('601318.XSHG', -buyNum, price=account.ff)   #上涨step,卖出操作
