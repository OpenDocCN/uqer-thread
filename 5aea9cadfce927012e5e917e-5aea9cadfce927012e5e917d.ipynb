# %% [markdown]
# # 基于主成分分析（  PCA)的筛选基金策略

# %% [markdown]
# 本文主要是给出基于主成分分析方法选基的方法，这里只已混合基金类型为例，主要步骤为：
# 一、基金池筛选：剔除以下基金：分级基金、封闭基金、FOF基金、QDII基金、保本基金。选出混合型基金。
# 二、计算基金的指标：收益类评价指标，有风险类评价指标，也有风险调整后收益类评价指标。后者为前两者的结合，用于衡量     单位风险下基金的收益水平。
# 三、主成分分析法的计算：（关于主成分分析的基础知识，请参考何晓群编著的《多元统计分析》，讲的清楚）
#           3.1、对原始数据进行标准化处理
#           3.2、对标准化后的数据求相关系数矩阵
#           3.3、求解相关系数矩阵的特征值和特征向量
#           3.4、根据特征值的大小确定主成分
#           3.5、将标准化后的指标变量转换为主成分
#           3.6、对选取的前M个主成分进行综合评价

# %%
#python常用库导入
import pandas as pd
import numpy as np
import datetime as dt 
import matplotlib.pyplot as plt

# %% [markdown]
# 一、基金池筛选：剔除以下基金：分级基金、封闭基金、FOF基金、QDII基金、保本基金。选出混合型基金。

# %%
#取出基金基本信息，剔除分级基金、封闭基金、FOF基金、QDII基金
fund_sec = DataAPI.SecIDGet(assetClass=u"F",pandas="1")
fund_info = DataAPI.FundGet(secID=fund_sec.secID,pandas="1")
fund_leverage = DataAPI.FundLeverageInfoGet(secID=u"",ticker=u"",exchangeCDLeverage=u"XSHG,XSHE",field=u"",pandas="1")
fund_info = fund_info[[x not in fund_leverage.secIDLeverage.values for x in fund_info.secID.values]]
fund_info = fund_info[[x not in ['C'] for x in fund_info.operationMode]]
fund_info = fund_info[(fund_info.isFof==0) & (fund_info.isQdii==0) & (fund_info.isGuarFund==0)]

# %%
#筛选出基金成立时间大于5年的
fund_info['establishDate'] = fund_info['establishDate'].apply(pd.to_datetime)
lag = pd.DateOffset(months=60)
current = dt.datetime.now()
fund_info = fund_info[fund_info['establishDate'] < current - lag]

# %%
fund_info
# Out:
#             secID  ticker       secShortName tradeAbbrName category  \
# 0     000001.OFCN  000001             华夏成长混合           NaN        H
# 1     000003.OFCN  000003          中海可转换债券-A           NaN        B
# 2     000004.OFCN  000004          中海可转换债券-C           NaN        B
# 4     000007.OFCN  000007            鹏华国企债债券           NaN        B
# 5     000008.OFCN  000008     嘉实中证500ETF联接基金           NaN        E
# 6     000009.OFCN  000009        易方达天天理财货币-A           NaN        M
# 7     000010.OFCN  000010        易方达天天理财货币-B           NaN        M
# 8     000011.OFCN  000011           华夏大盘精选混合           NaN        H
# 9     000013.OFCN  000013        易方达天天理财货币-R           NaN        M
# 11    000015.OFCN  000015           华夏纯债债券-A           NaN        B
# 12    000016.OFCN  000016           华夏纯债债券-C           NaN        B
# 13    000017.OFCN  000017        财通可持续发展主题混合           NaN        H
# 14    000020.OFCN  000020         景顺长城品质投资混合           NaN        H
# 15    000021.OFCN  000021           华夏优势增长混合           NaN        H
# 16    000022.OFCN  000022  南方中债中期票据指数债券发起式-A           NaN        B
# 17    000023.OFCN  000023  南方中债中期票据指数债券发起式-C           NaN        B
# 18    000024.OFCN  000024         大摩双利增强债券-A           NaN        B
# 19    000025.OFCN  000025         大摩双利增强债券-C           NaN        B
# 23    000029.OFCN  000029       富国宏观策略灵活配置混合           NaN        H
# 25    000031.OFCN  000031             华夏复兴混合           NaN        H
# 26    000032.OFCN  000032           易方达信用债-A           NaN        B
# 27    000033.OFCN  000033           易方达信用债-C           NaN        B
# 30    000039.OFCN  000039            农银高增长混合           NaN        H
# 32    000042.OFCN  000042       中证财通ESG100-A           NaN        E
# 35    000045.OFCN  000045           工银产业债券-A           NaN        B
# 36    000046.OFCN  000046           工银产业债券-B           NaN        B
# 37    000047.OFCN  000047           华夏双债债券-A           NaN        B
# 38    000048.OFCN  000048           华夏双债债券-C           NaN        B
# 40    000050.OFCN  000050             长盛纯债-A           NaN        B
# 41    000051.OFCN  000051     华夏沪深300ETF联接-A           NaN        E
# ...           ...     ...                ...           ...      ...
# 9176  690212.OFCN  690212       民生加银家盈理财7天-B           NaN       SB
# 9177  700001.OFCN  700001         平安大华行业先锋混合           NaN        H
# 9178  700002.OFCN  700002      平安大华深证300指数增强           NaN        E
# 9179  700003.OFCN  700003         平安大华策略先锋混合           NaN        H
# 9181  700005.OFCN  700005         平安大华添利债券-A           NaN        B
# 9182  700006.OFCN  700006         平安大华添利债券-C           NaN        B
# 9183  710001.OFCN  710001          富安达优势成长混合           NaN        H
# 9184  710002.OFCN  710002          富安达策略精选混合           NaN        H
# 9185  710301.OFCN  710301         富安达增强收益债-A           NaN        B
# 9186  710302.OFCN  710302         富安达增强收益债-C           NaN        B
# 9187  710501.OFCN  710501         富安达现金通货币-A           NaN        M
# 9188  710502.OFCN  710502         富安达现金通货币-B           NaN        M
# 9189  720001.OFCN  720001           财通价值动量混合           NaN        H
# 9190  720002.OFCN  720002      财通多策略稳健增长债券-A           NaN        B
# 9193  730001.OFCN  730001         方正富邦创新动力混合           NaN        H
# 9194  730002.OFCN  730002         方正富邦红利精选混合           NaN        H
# 9195  730003.OFCN  730003           方正富邦货币-A           NaN        M
# 9196  730103.OFCN  730103           方正富邦货币-B           NaN        M
# 9197  740001.OFCN  740001           长安宏观策略混合           NaN        H
# 9198  740101.OFCN  740101       长安沪深300非周期指数           NaN        E
# 9199  740601.OFCN  740601             长安货币-A           NaN        M
# 9200  740602.OFCN  740602             长安货币-B           NaN        M
# 9201  750001.OFCN  750001           安信灵活配置混合           NaN        H
# 9202  750002.OFCN  750002          安信目标收益债-A           NaN        B
# 9203  750003.OFCN  750003          安信目标收益债-C           NaN        B
# 9204  750005.OFCN  750005       安信平稳增长混合发起-A           NaN        H
# 9205  750006.OFCN  750006         安信现金管理货币-A           NaN        M
# 9206  750007.OFCN  750007         安信现金管理货币-B           NaN        M
# 9207  762001.OFCN  762001             国金囯鑫发起           NaN        H
# 9208  770001.OFCN  770001         德邦优化灵活配置混合           NaN        H
#
#      operationMode indexFund etfLof  isQdii  isFof     ...       custodian  \
# 0                O       NaN    NaN       0      0     ...            1667
# 1                O       NaN    NaN       0      0     ...           27303
# 2                O       NaN    NaN       0      0     ...           27303
# 4                O       NaN    NaN       0      0     ...            1867
# 5                O         I    NaN       0      0     ...            1667
# 6                O       NaN    NaN       0      0     ...            1867
# 7                O       NaN    NaN       0      0     ...            1867
# 8                O       NaN    NaN       0      0     ...            2035
# 9                O       NaN    NaN       0      0     ...            1867
# 11               O       NaN    NaN       0      0     ...            1667
# 12               O       NaN    NaN       0      0     ...            1667
# 13               O       NaN    NaN       0      0     ...            1867
# 14               O       NaN    NaN       0      0     ...           27303
# 15               O       NaN    NaN       0      0     ...            1667
# 16               O         I    NaN       0      0     ...            2035
# 17               O         I    NaN       0      0     ...            2035
# 18               O       NaN    NaN       0      0     ...            1667
# 19               O       NaN    NaN       0      0     ...            1667
# 23               O       NaN    NaN       0      0     ...            1667
# 25               O       NaN    NaN       0      0     ...           27303
# 26               O       NaN    NaN       0      0     ...            1867
# 27               O       NaN    NaN       0      0     ...            1867
# 30               O       NaN    NaN       0      0     ...            2274
# 32               O        EI    NaN       0      0     ...           27781
# 35               O       NaN    NaN       0      0     ...            2041
# 36               O       NaN    NaN       0      0     ...            2041
# 37               O       NaN    NaN       0      0     ...            2035
# 38               O       NaN    NaN       0      0     ...            2035
# 40               O       NaN    NaN       0      0     ...            2035
# 41               O         I    NaN       0      0     ...            1867
# ...            ...       ...    ...     ...    ...     ...             ...
# 9176             O       NaN    NaN       0      0     ...            1667
# 9177             O       NaN    NaN       0      0     ...            2035
# 9178             O        EI    NaN       0      0     ...            2035
# 9179             O       NaN    NaN       0      0     ...            2035
# 9181             O       NaN    NaN       0      0     ...            2035
# 9182             O       NaN    NaN       0      0     ...            2035
# 9183             O       NaN    NaN       0      0     ...            2274
# 9184             O       NaN    NaN       0      0     ...            2274
# 9185             O       NaN    NaN       0      0     ...            2274
# 9186             O       NaN    NaN       0      0     ...            2274
# 9187             O       NaN    NaN       0      0     ...            2274
# 9188             O       NaN    NaN       0      0     ...            2274
# 9189             O       NaN    NaN       0      0     ...            1867
# 9190             O       NaN    NaN       0      0     ...            1867
# 9193             O       NaN    NaN       0      0     ...            1667
# 9194             O       NaN    NaN       0      0     ...            1667
# 9195             O       NaN    NaN       0      0     ...            1667
# 9196             O       NaN    NaN       0      0     ...            1667
# 9197             O       NaN    NaN       0      0     ...           24215
# 9198             O         I    NaN       0      0     ...           12588
# 9199             O       NaN    NaN       0      0     ...           12588
# 9200             O       NaN    NaN       0      0     ...           12588
# 9201             O       NaN    NaN       0      0     ...            1667
# 9202             O       NaN    NaN       0      0     ...           27303
# 9203             O       NaN    NaN       0      0     ...           27303
# 9204             O       NaN    NaN       0      0     ...            1867
# 9205             O       NaN    NaN       0      0     ...            1667
# 9206             O       NaN    NaN       0      0     ...            1667
# 9207             O       NaN    NaN       0      0     ...           27523
# 9208             O       NaN    NaN       0      0     ...            2274
#
#       custodianFullName                                        investField  \
# 0          中国建设银行股份有限公司  本基金的投资范围限于具有良好流动性的金融工具，包括国内依法公开发行上市的股票、债券及中国证监...
# 11                             在控制风险的前提下，追求较高的当期收入和总回报。
# 12                             在控制风险的前提下，追求较高的当期收入和总回报。
# 13    本基金在可持续发展的投资理念下，通过系统化评估方法精选出可持续发展特征突出的上市公司进入投资...
# 14    通过采用品质投资(Quality investing)策略，投资于具备卓越企业品质资质的公司...
# 15                         追求在有效控制风险的前提下实现基金资产的稳健、持续增值。
# 16                         本基金追求取得在扣除各项费用之前与标的指数相似的总回报。
# 17                         本基金追求取得在扣除各项费用之前与标的指数相似的总回报。
# 18    本基金投资目标是在严格控制风险的前提下，通过积极主动的投资管理，合理配置债券等固定收益类金融...
# 19    本基金投资目标是在严格控制风险的前提下，通过积极主动的投资管理，合理配置债券等固定收益类金融...
# 23            本基金力争通过灵活合理的大类资产配置与专业的个券选择，实现基金资产较高的长期回报。
# 25    秉承长期投资理念和个股精选思路，以长期、全球视野考察我国经济、行业以及个股的成长前景，着眼于...
# 26                      本基金主要投资于信用债券，力争获得高于业绩比较基准的投资收益。
# 27                      本基金主要投资于信用债券，力争获得高于业绩比较基准的投资收益。
# 30    本基金将通过寻找某种程度上被市场低估的，同时又有较强的持续稳定增长潜力股票，优化投资组合，在...
# 32    本基金为股票指数增强型基金，在力求对中证财通中国可持续发展100（ECPI'ESG）指数进行...
# 35    本基金在追求资产长期稳健增值的基础上，通过对产业债券积极主动的投资管理，力争创造超过业绩比较...
# 36    本基金在追求资产长期稳健增值的基础上，通过对产业债券积极主动的投资管理，力争创造超过业绩比较...
# 37                             在控制风险的前提下，追求较高的当期收入和总回报。
# 38                             在控制风险的前提下，追求较高的当期收入和总回报。
# 40    在控制风险和保持资产流动性的基础上，积极主动调整投资组合，追求基金资产的长期稳定增值，并力争...
# 41       采用指数化投资方式，追求对标的指数的有效跟踪，获得与标的指数收益相似的回报及适当的其他收益。
# ...                                                 ...
# 9176  在综合考虑基金资产收益性、安全性和流动性的基础上，通过积极主动的投资管理，力争实现超过业绩比...
# 9177  深入研究中国宏观经济、证券市场发展过程中的结构性和趋势性规律，把握不同行业在此变化趋势中可行...
# 9178  本基金采用指数复制结合相对增强的投资策略，即通过指数复制的方法拟合、跟踪深证300指数，并在...
# 9179  通过积极进行资产配置和灵活运用多种投资策略，在有效控制风险的前提下，充分挖掘和利用市场中潜在...
# 9181           在严格控制投资风险的前提下，通过积极主动的投资管理，追求基金资产的长期稳定增值。
# 9182           在严格控制投资风险的前提下，通过积极主动的投资管理，追求基金资产的长期稳定增值。
# 9183  本基金定位为股票型证券投资基金。在充分控制风险的前提下，精选具有竞争优势及持续成长性的上市公...
# 9184  本基金紧跟中国经济发展趋势，在充分控制风险的前提下，通过投资具有持续增长潜力且具有合理估值的...
# 9185       本基金将在控制风险与保持资产流动性的基础上，力争为投资人获取超越业绩比较基准的投资回报。
# 9186       本基金将在控制风险与保持资产流动性的基础上，力争为投资人获取超越业绩比较基准的投资回报。
# 9187           本基金将在保持基金资产安全性和高流动性的基础上，追求超过业绩比较基准的稳定回报。
# 9188           本基金将在保持基金资产安全性和高流动性的基础上，追求超过业绩比较基准的稳定回报。
# 9189  本基金以价值投资为基础，辅以对市场运行规律的研判，动态调整投资组合，在严格控制风险并充分保证...
# 9190  本基金在有效控制风险的前提下，通过积极主动的投资管理，力争持续稳定地实现超越业绩比较基准的组...
# 9193  本基金的投资目标：本基金秉承精选个股和长期投资理念，寻找受益于中国经济战略转型，符合内需导向...
# 9194  在合理控制风险的基础上，本基金将通过对盈利增长稳定、有较强分红意愿的高分红类股票及其他有投资...
# 9195          在严格控制风险和维持资产较高流动性的基础上，力争获得超越业绩比较基准的投资收益率。
# 9196          在严格控制风险和维持资产较高流动性的基础上，力争获得超越业绩比较基准的投资收益率。
# 9197  本基金在宏观策略研判的基础上，通过强化配置景气行业及精选基本面良好、成长性突出的上市公司，在...
# 9198  本基金为股票型指数基金，力求通过对沪深300非周期行业指数进行完全复制，在严格控制跟踪误差的...
# 9199   在保持基金资产的安全性和流动性的前提下，通过主动式管理，力求获得超过基金业绩比较基准的稳定回报。
# 9200   在保持基金资产的安全性和流动性的前提下，通过主动式管理，力求获得超过基金业绩比较基准的稳定回报。
# 9201  灵活运用多种投资策略，深入挖掘和把握市场投资机会，分享中国经济增长和资本市场发展的成果，力争...
# 9202  在严格控制风险的前提下，以3个月期上海银行间同业拆放利率（Shibor 3M）为收益跟踪目标...
# 9203  在严格控制风险的前提下，以3个月期上海银行间同业拆放利率（Shibor 3M）为收益跟踪目标...
# 9204  通过稳健的资产配置策略，将基金资产在权益类资产和固定收益类资产之间灵活配置，并通过积极主动的...
# 9205  在严格控制风险和保持资产流动性的前提下，通过积极主动的投资组合，力求为投资者获得超过业绩比较...
# 9206  在严格控制风险和保持资产流动性的前提下，通过积极主动的投资组合，力求为投资者获得超过业绩比较...
# 9207     本基金通过合理的资产配置和积极的证券选择，追求在严格控制风险的前提下实现资本的长期稳健回报。
# 9208  本基金为混合型证券投资基金，依靠对宏观经济周期的判断，结合数量化投资模型，灵活配置基金资产于...
#
#                                           perfBenchmark circulationShares  \
# 0                                    根据基金合同，本基金暂无业绩比较基准               NaN
# 1          标普中国可转债指数×70%+上海证券交易所上证红利指数×10%+中证综合债券指数×20%               NaN
# 2          标普中国可转债指数×70%+上海证券交易所上证红利指数×10%+中证综合债券指数×20%               NaN
# 4                                           中债-总指数×100％               NaN
# 5                           活期存款利率(税后)×5％+中证小盘500指数×95％               NaN
# 6                                    活期存款基准利率×(1-利息税税率)               NaN
# 7                                    活期存款基准利率×(1-利息税税率)               NaN
# 8                         富时中国A200指数×80%+富时中国国债净价指数×20%               NaN
# 9                                    活期存款基准利率×(1-利息税税率)               NaN
# 11                                         中债-综合指数×100％               NaN
# 12                                         中债-综合指数×100％               NaN
# 13                          上海证券交易所国债指数×20％+沪深300指数×80％               NaN
# 14                               沪深300指数×80%+中证全债指数×20%               NaN
# 15                      富时中国A600指数×80%+中债-综合指数-财富指数×20%               NaN
# 16                        活期存款利率(税后)×5%+中债-新中期票据总指数×95%               NaN
# 17                        活期存款利率(税后)×5%+中债-新中期票据总指数×95%               NaN
# 18    中债-国债总指数-全价指数×20%+中债-企业债总指数-全价指数×40%+中证可转换债券指数...               NaN
# 19    中债-国债总指数-全价指数×20%+中债-企业债总指数-全价指数×40%+中证可转换债券指数...               NaN
# 23                              沪深300指数×65％+中债-综合指数×35％               NaN
# 25                          上海证券交易所国债指数×20％+沪深300指数×80％               NaN
# 26                                       中债-信用债总指数×100％               NaN
# 27                                       中债-信用债总指数×100％               NaN
# 30                               沪深300指数×75％+中证全债指数×25％               NaN
# 32         活期存款利率(税后)×5%+中证财通中国可持续发展100(ECPI ESG)指数×95%               NaN
# 35                                 三年定期存款利率(税后)×100%+1%               NaN
# 36                                 三年定期存款利率(税后)×100%+1%               NaN
# 37                                         中债-综合指数×100％               NaN
# 38                                         中债-综合指数×100％               NaN
# 40                                    中债-综合指数-全价指数×100％               NaN
# 41                                       沪深300指数×95%+1%               NaN
# ...                                                 ...               ...
# 9176                                  七天通知存款利率(税后)×100％               NaN
# 9177                             沪深300指数×85%+中证全债指数×15%               NaN
# 9178                          活期存款利率(税后)×5％+深证300指数×95％               NaN
# 9179                             沪深300指数×60％+中证全债指数×40％               NaN
# 9181                                        中证全债指数×100％               NaN
# 9182                                        中证全债指数×100％               NaN
# 9183                        上海证券交易所国债指数×25％+沪深300指数×75％               NaN
# 9184                        上海证券交易所国债指数×45％+沪深300指数×55％               NaN
# 9185                             中债-总指数×90％+沪深300指数×10％               NaN
# 9186                             中债-总指数×90％+沪深300指数×10％               NaN
# 9187                                    活期存款利率(税后)×100％               NaN
# 9188                                    活期存款利率(税后)×100％               NaN
# 9189                        上海证券交易所国债指数×40％+沪深300指数×60％               NaN
# 9190                             三年定期存款利率(税后)×100％+0.5%               NaN
# 9193                             沪深300指数×80％+中证全债指数×20％               NaN
# 9194                              中证全债指数×20%+中证红利指数×80%               NaN
# 9195                                  七天通知存款利率(税后)×100％               NaN
# 9196                                  七天通知存款利率(税后)×100％               NaN
# 9197                             沪深300指数×80％+中证全债指数×20％               NaN
# 9198                     活期存款利率(税后)×5%+沪深300非周期行业指数×95%               NaN
# 9199                                  七天通知存款利率(税后)×100％               NaN
# 9200                                  七天通知存款利率(税后)×100％               NaN
# 9201                             中债-总指数×40％+沪深300指数×60％               NaN
# 9202                               3个月期上海银行间同业拆放利率×100%               NaN
# 9203                               3个月期上海银行间同业拆放利率×100%               NaN
# 9204                        中证800指数×50%+中债-总指数-全价指数×50%               NaN
# 9205                                  七天通知存款利率(税后)×100％               NaN
# 9206                                  七天通知存款利率(税后)×100％               NaN
# 9207                                  三年定期存款利率(税后)×100％               NaN
# 9208                       一年定期存款利率(税后)×60％+沪深300指数×40％               NaN
#
#      isClass        idxID idxTicker idxShortName
# 0        0.0          NaN       NaN          NaN
# 1        0.0          NaN       NaN          NaN
# 2        0.0          NaN       NaN          NaN
# 4        0.0          NaN       NaN          NaN
# 5        0.0  000905.ZICN    000905        中证500
# 6        0.0          NaN       NaN          NaN
# 7        0.0          NaN       NaN          NaN
# 8        0.0          NaN       NaN          NaN
# 9        0.0          NaN       NaN          NaN
# 11       0.0          NaN       NaN          NaN
# 12       0.0          NaN       NaN          NaN
# 13       0.0          NaN       NaN          NaN
# 14       0.0          NaN       NaN          NaN
# 15       0.0          NaN       NaN          NaN
# 16       0.0          NaN       NaN          NaN
# 17       0.0          NaN       NaN          NaN
# 18       0.0          NaN       NaN          NaN
# 19       0.0          NaN       NaN          NaN
# 23       0.0          NaN       NaN          NaN
# 25       0.0          NaN       NaN          NaN
# 26       0.0          NaN       NaN          NaN
# 27       0.0          NaN       NaN          NaN
# 30       0.0          NaN       NaN          NaN
# 32       0.0  000846.ZICN    000846       ESG100
# 35       0.0          NaN       NaN          NaN
# 36       0.0          NaN       NaN          NaN
# 37       0.0          NaN       NaN          NaN
# 38       0.0          NaN       NaN          NaN
# 40       0.0          NaN       NaN          NaN
# 41       0.0  000300.ZICN    000300        沪深300
# ...      ...          ...       ...          ...
# 9176     0.0          NaN       NaN          NaN
# 9177     0.0          NaN       NaN          NaN
# 9178     0.0  399344.ZICN    399344       深证300R
# 9179     0.0          NaN       NaN          NaN
# 9181     0.0          NaN       NaN          NaN
# 9182     0.0          NaN       NaN          NaN
# 9183     0.0          NaN       NaN          NaN
# 9184     0.0          NaN       NaN          NaN
# 9185     0.0          NaN       NaN          NaN
# 9186     0.0          NaN       NaN          NaN
# 9187     0.0          NaN       NaN          NaN
# 9188     0.0          NaN       NaN          NaN
# 9189     0.0          NaN       NaN          NaN
# 9190     0.0          NaN       NaN          NaN
# 9193     0.0          NaN       NaN          NaN
# 9194     0.0          NaN       NaN          NaN
# 9195     0.0          NaN       NaN          NaN
# 9196     0.0          NaN       NaN          NaN
# 9197     0.0          NaN       NaN          NaN
# 9198     0.0  000969.ZICN    000969        300非周
# 9199     0.0          NaN       NaN          NaN
# 9200     0.0          NaN       NaN          NaN
# 9201     0.0          NaN       NaN          NaN
# 9202     0.0          NaN       NaN          NaN
# 9203     0.0          NaN       NaN          NaN
# 9204     0.0          NaN       NaN          NaN
# 9205     0.0          NaN       NaN          NaN
# 9206     0.0          NaN       NaN          NaN
# 9207     0.0          NaN       NaN          NaN
# 9208     0.0          NaN       NaN          NaN
#
# [1535 rows x 33 columns]

# %%
# 取出混合型基金
fund_commingle_info = fund_info[fund_info.category=='H']

# %%
fund_commingle_info.head()
# Out:
#           secID  ticker secShortName tradeAbbrName category operationMode  \
# 0   000001.OFCN  000001       华夏成长混合           NaN        H             O
# 8   000011.OFCN  000011     华夏大盘精选混合           NaN        H             O
# 13  000017.OFCN  000017  财通可持续发展主题混合           NaN        H             O
# 14  000020.OFCN  000020   景顺长城品质投资混合           NaN        H             O
# 15  000021.OFCN  000021     华夏优势增长混合           NaN        H             O
#
#    indexFund etfLof  isQdii  isFof     ...       custodian  custodianFullName  \
# 0        NaN    NaN       0      0     ...            1667       中国建设银行股份有限公司
# 8        NaN    NaN       0      0     ...            2035         中国银行股份有限公司
# 13       NaN    NaN       0      0     ...            1867       中国工商银行股份有限公司
# 14       NaN    NaN       0      0     ...           27303       中国农业银行股份有限公司
# 15       NaN    NaN       0      0     ...            1667       中国建设银行股份有限公司
#
#                                           investField  \
# 0   本基金的投资范围限于具有良好流动性的金融工具，包括国内依法公开发行上市的股票、债券及中国证监...
# 8   限于具有良好流动性的金融工具，包括国内依法公开发行上市的股票、债券及中国证监会允许基金投资的...
# 13  本基金的投资范围为具有良好流动性的金融工具，包括国内依法发行上市的股票（包括中小板、创业板及...
# 14  本基金投资范围包括国内依法发行上市的股票(包含中小板、创业板及其他经中国证监会核准上市的股票...
# 15  限于具有良好流动性的金融工具，包括国内依法公开发行上市的股票、权证、债券、资产支持证券及中国...
#
#                                          investTarget  \
# 0   本基金属成长型基金，主要通过投资于具有良好成长性的上市公司的股票，在保持基金资产安全性和流动...
# 8                                        追求基金资产的长期增值。
# 13  本基金在可持续发展的投资理念下，通过系统化评估方法精选出可持续发展特征突出的上市公司进入投资...
# 14  通过采用品质投资(Quality investing)策略，投资于具备卓越企业品质资质的公司...
# 15                       追求在有效控制风险的前提下实现基金资产的稳健、持续增值。
#
#                       perfBenchmark circulationShares isClass idxID idxTicker  \
# 0                根据基金合同，本基金暂无业绩比较基准               NaN     0.0   NaN       NaN
# 8     富时中国A200指数×80%+富时中国国债净价指数×20%               NaN     0.0   NaN       NaN
# 13      上海证券交易所国债指数×20％+沪深300指数×80％               NaN     0.0   NaN       NaN
# 14           沪深300指数×80%+中证全债指数×20%               NaN     0.0   NaN       NaN
# 15  富时中国A600指数×80%+中债-综合指数-财富指数×20%               NaN     0.0   NaN       NaN
#
#    idxShortName
# 0           NaN
# 8           NaN
# 13          NaN
# 14          NaN
# 15          NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# #本部分在fyiqi帖子上修改完成
# 二、计算基金的指标：基金表现的几乎所有信息包含在其复权净值变化中，对于复权净值的变化，有收益类评价指标，有风险类评价指标，也有风险调整后收益类评价指标。后者为前两者的结合，用于衡量单位风险下基金的收益水平。

# %% [markdown]
# ####  **2.2.1收益类指标**
#
# 1. **历史收益率（HR）**: 样本的年化收益率。
# 2. **超额收益率（Alpha）**： 基金的收益可以分解为市场收益和基金管理人创造的超额收益，我们利用基金指数或者基金基准的收益率对基金收益率进行OLS回归，得到基金对其基准的风险因子β，再用计算α： $$ Alpha = \mu - \beta * \mu_b   ,  \beta = \frac{\sum_{i=1}^N r_i * b_i - N \bar r \bar b}{\sum_{i=1}^N b_i^2-N \bar b^2}$$

# %% [markdown]
# ####  **2.2.2风险类指标**
#
# 1. **调整在险值（MVaR）**： 调整在险值是利用收益率偏度和峰度对传统在险值调整后的指标。传统的在险值（VaR）无法捕捉基金收益率肥尾属性，因此提出调整在险值。调整在险值的公式如下：$$ MVaR_\alpha  = \mu + ( z_c + \frac{1}{6}(z_c^2 -1)S + \frac{1}{24}(z_c^3 - 3z_c)K - \frac{1}{36}(2z_c^3 - 5z_c)S^2 )\sigma$$ 其中zc，是正态分布在置信度为α%下的临界值。而 μ、σ、S、K则为样本收益率分布的均值，标准差，偏度，峰度。此指标意味着在调整了收益率分布偏度和峰度后，未来有 α%的概率收益率不会低于MVaRα。
# 2. **最大回撤（MD）**: 净值历史回撤幅度最大值
# 3. **平均回撤（AD）** : 样本数据所有回撤加权平均值。 $$ AD = \sum_{i=0}^{N-1} DD_{N-1} * 0.9^i $$
# 4. **负向收益波动率（LPM）** : 仅计算样本负向收益的波动率。
# 5. **收益波动率（SIGMA）** : 样本收益率的波动率。

# %% [markdown]
# ####  **2.2.3 风险调整后收益类指标**
#
# 由上面的指标，收益类和风险类两两结合，可得 2*5 =10 个新指标，作为风险调整后的收益率指标：
#
# 1. **H_Mvar** (HR/exp(MVaR))
# 2. **CR** (卡玛比率, HR/abs(MD))
# 3. **H_Ad** (HR/abs(AD))
# 4. **SoR** (索提诺比率, HR/LPM)
# 5. **SR** (夏普比率, HR/SIGMA)
# 6. **A_Mvar** (Alpha/exp(MVaR))
# 7. **A_Md** (Alpha/abs(MD))
# 8. **A_Ad** (Alpha/abs(AD))
# 9. **XR** (X比率, Alpha/LPM)
# 10. **IR** (信息比率, Alpha/SIGMA)

# %%
#获得混合型基金净值
beginDate="20130502"
endDate="20180502"

data_H = DataAPI.FundNavGet(dataDate=u"",secID=fund_commingle_info['secID'],beginDate=beginDate,endDate=endDate,field=u"",pandas="1")
#获得有基金净值数据的基金代码
fund_H = set(list(data_H['secID']))

# %%
data_H.head()
# Out:
#          secID  ticker secShortName     endDate    NAV publishDate  ACCUM_NAV  \
# 0  000001.OFCN  000001       华夏成长混合  2013-05-02  1.024  2013-05-03      3.125
# 1  000001.OFCN  000001       华夏成长混合  2013-05-03  1.035  2013-05-04      3.136
# 2  000001.OFCN  000001       华夏成长混合  2013-05-06  1.044  2013-05-07      3.145
# 3  000001.OFCN  000001       华夏成长混合  2013-05-07  1.044  2013-05-08      3.145
# 4  000001.OFCN  000001       华夏成长混合  2013-05-08  1.052  2013-05-09      3.153
#
#   currencyCd  ADJUST_NAV
# 0        CNY      4.5435
# 1        CNY      4.5923
# 2        CNY      4.6322
# 3        CNY      4.6322
# 4        CNY      4.6677

# %%
fund_H
# Out:
# {'000001.OFCN',
#  '000011.OFCN',
#  '000017.OFCN',
#  '000020.OFCN',
#  '000021.OFCN',
#  '000029.OFCN',
#  '000031.OFCN',
#  '000039.OFCN',
#  '000057.OFCN',
#  '000061.OFCN',
#  '000083.OFCN',
#  '002001.OFCN',
#  '002011.OFCN',
#  '002021.OFCN',
#  '002031.OFCN',
#  '020001.OFCN',
#  '020003.OFCN',
#  '020005.OFCN',
#  '020009.OFCN',
#  '020010.OFCN',
#  '020015.OFCN',
#  '020023.OFCN',
#  '020026.OFCN',
#  '040001.OFCN',
#  '040004.OFCN',
#  '040005.OFCN',
#  '040007.OFCN',
#  '040008.OFCN',
#  '040011.OFCN',
#  '040015.OFCN',
#  '040016.OFCN',
#  '040020.OFCN',
#  '040025.OFCN',
#  '040035.OFCN',
#  '050001.OFCN',
#  '050004.OFCN',
#  '050007.OFCN',
#  '050008.OFCN',
#  '050009.OFCN',
#  '050010.OFCN',
#  '050012.OFCN',
#  '050014.OFCN',
#  '050018.OFCN',
#  '050022.OFCN',
#  '050026.OFCN',
#  '050201.OFCN',
#  '070001.OFCN',
#  '070002.OFCN',
#  '070003.OFCN',
#  '070006.OFCN',
#  '070010.OFCN',
#  '070011.OFCN',
#  '070013.OFCN',
#  '070017.OFCN',
#  '070018.OFCN',
#  '070019.OFCN',
#  '070021.OFCN',
#  '070022.OFCN',
#  '070027.OFCN',
#  '070032.OFCN',
#  '070099.OFCN',
#  '080001.OFCN',
#  '080002.OFCN',
#  '080005.OFCN',
#  '080007.OFCN',
#  '080012.OFCN',
#  '090001.OFCN',
#  '090003.OFCN',
#  '090004.OFCN',
#  '090006.OFCN',
#  '090007.OFCN',
#  '090009.OFCN',
#  '090011.OFCN',
#  '090015.OFCN',
#  '090016.OFCN',
#  '090018.OFCN',
#  '100016.OFCN',
#  '100020.OFCN',
#  '100022.OFCN',
#  '100026.OFCN',
#  '100029.OFCN',
#  '100039.OFCN',
#  '100056.OFCN',
#  '100060.OFCN',
#  '110001.OFCN',
#  '110002.OFCN',
#  '110005.OFCN',
#  '110009.OFCN',
#  '110010.OFCN',
#  '110011.OFCN',
#  '110012.OFCN',
#  '110013.OFCN',
#  '110015.OFCN',
#  '110023.OFCN',
#  '110025.OFCN',
#  '110029.OFCN',
#  '112002.OFCN',
#  '121002.OFCN',
#  '121003.OFCN',
#  '121005.OFCN',
#  '121006.OFCN',
#  '121008.OFCN',
#  '150103.OFCN',
#  '151001.OFCN',
#  '160105.XSHE',
#  '160106.XSHE',
#  '160211.XSHE',
#  '160212.XSHE',
#  '160215.XSHE',
#  '160311.XSHE',
#  '160314.XSHE',
#  '160505.XSHE',
#  '160512.XSHE',
#  '160603.OFCN',
#  '160605.OFCN',
#  '160607.XSHE',
#  '160610.XSHE',
#  '160611.XSHE',
#  '160613.XSHE',
#  '160805.XSHE',
#  '160910.XSHE',
#  '160916.XSHE',
#  '161005.XSHE',
#  '161219.XSHE',
#  '161601.OFCN',
#  '161605.OFCN',
#  '161606.OFCN',
#  '161609.OFCN',
#  '161610.XSHE',
#  '161611.OFCN',
#  '161616.OFCN',
#  '161706.XSHE',
#  '161810.XSHE',
#  '161818.OFCN',
#  '162006.XSHE',
#  '162102.OFCN',
#  '162201.OFCN',
#  '162202.OFCN',
#  '162203.OFCN',
#  '162204.OFCN',
#  '162205.OFCN',
#  '162207.XSHE',
#  '162209.OFCN',
#  '162211.OFCN',
#  '162212.OFCN',
#  '162214.OFCN',
#  '162605.XSHE',
#  '162607.XSHE',
#  '162703.XSHE',
#  '163302.XSHE',
#  '163402.XSHE',
#  '163406.OFCN',
#  '163409.XSHE',
#  '163412.XSHE',
#  '163415.XSHE',
#  '163503.XSHE',
#  '163801.XSHE',
#  '163803.OFCN',
#  '163804.OFCN',
#  '163805.OFCN',
#  '163807.OFCN',
#  '163809.OFCN',
#  '163810.OFCN',
#  '163818.OFCN',
#  '163822.OFCN',
#  '165313.XSHE',
#  '165508.XSHE',
#  '165512.XSHE',
#  '165516.XSHE',
#  '166001.XSHE',
#  '166002.OFCN',
#  '166005.OFCN',
#  '166009.XSHE',
#  '166011.XSHE',
#  '166801.OFCN',
#  '180001.OFCN',
#  '180010.OFCN',
#  '180012.OFCN',
#  '180013.OFCN',
#  '180018.OFCN',
#  '180020.OFCN',
#  '180031.OFCN',
#  '200001.OFCN',
#  '200006.OFCN',
#  '200007.OFCN',
#  '200008.OFCN',
#  '200010.OFCN',
#  '200011.OFCN',
#  '200012.OFCN',
#  '200015.OFCN',
#  '202001.OFCN',
#  '202002.OFCN',
#  '202003.OFCN',
#  '202005.OFCN',
#  '202007.OFCN',
#  '202009.OFCN',
#  '202011.OFCN',
#  '202019.OFCN',
#  '202023.OFCN',
#  '206001.OFCN',
#  '206002.OFCN',
#  '206007.OFCN',
#  '206009.OFCN',
#  '210001.OFCN',
#  '210002.OFCN',
#  '210003.OFCN',
#  '210004.OFCN',
#  '210005.OFCN',
#  '210008.OFCN',
#  '210009.OFCN',
#  '213001.OFCN',
#  '213002.OFCN',
#  '213003.OFCN',
#  '213006.OFCN',
#  '213008.OFCN',
#  '217001.OFCN',
#  '217002.OFCN',
#  '217005.OFCN',
#  '217009.OFCN',
#  '217010.OFCN',
#  '217012.OFCN',
#  '217013.OFCN',
#  '217021.OFCN',
#  '229002.OFCN',
#  '233001.OFCN',
#  '233006.OFCN',
#  '233007.OFCN',
#  '233008.OFCN',
#  '233009.OFCN',
#  '233011.OFCN',
#  '233015.OFCN',
#  '240001.OFCN',
#  '240002.OFCN',
#  '240004.OFCN',
#  '240008.OFCN',
#  '240009.OFCN',
#  '240010.OFCN',
#  '240011.OFCN',
#  '240017.OFCN',
#  '240020.OFCN',
#  '240022.OFCN',
#  '253010.OFCN',
#  '255010.OFCN',
#  '257010.OFCN',
#  '257020.OFCN',
#  '257030.OFCN',
#  '257040.OFCN',
#  '257050.OFCN',
#  '257070.OFCN',
#  '260101.OFCN',
#  '260103.OFCN',
#  '260104.OFCN',
#  '260108.OFCN',
#  '260109.OFCN',
#  '260110.OFCN',
#  '260111.OFCN',
#  '260112.OFCN',
#  '260115.OFCN',
#  '260116.OFCN',
#  '260117.OFCN',
#  '270001.OFCN',
#  '270002.OFCN',
#  '270005.OFCN',
#  '270006.OFCN',
#  '270007.OFCN',
#  '270008.OFCN',
#  '270021.OFCN',
#  '270022.OFCN',
#  '270025.OFCN',
#  '270028.OFCN',
#  '270041.OFCN',
#  '270050.OFCN',
#  '288001.OFCN',
#  '288002.OFCN',
#  '290002.OFCN',
#  '290004.OFCN',
#  '290005.OFCN',
#  '290006.OFCN',
#  '290008.OFCN',
#  '290011.OFCN',
#  '290014.OFCN',
#  '310308.OFCN',
#  '310318.OFCN',
#  '310328.OFCN',
#  '310358.OFCN',
#  '310368.OFCN',
#  '310388.OFCN',
#  '320001.OFCN',
#  '320003.OFCN',
#  '320005.OFCN',
#  '320006.OFCN',
#  '320007.OFCN',
#  '320011.OFCN',
#  '320012.OFCN',
#  '320016.OFCN',
#  '320018.OFCN',
#  '340001.OFCN',
#  '340007.OFCN',
#  '340008.OFCN',
#  '350001.OFCN',
#  '350002.OFCN',
#  '350005.OFCN',
#  '350007.OFCN',
#  '350008.OFCN',
#  '360005.OFCN',
#  '360006.OFCN',
#  '360007.OFCN',
#  '360010.OFCN',
#  '360011.OFCN',
#  '360012.OFCN',
#  '360016.OFCN',
#  '370024.OFCN',
#  '370027.OFCN',
#  '373010.OFCN',
#  '373020.OFCN',
#  '375010.OFCN',
#  '377010.OFCN',
#  '377020.OFCN',
#  '377150.OFCN',
#  '377240.OFCN',
#  '377530.OFCN',
#  '378010.OFCN',
#  '379010.OFCN',
#  '398001.OFCN',
#  '398011.OFCN',
#  '398021.OFCN',
#  '398031.OFCN',
#  '398041.OFCN',
#  '398051.OFCN',
#  '398061.OFCN',
#  '400001.OFCN',
#  '400003.OFCN',
#  '400007.OFCN',
#  '400011.OFCN',
#  '400015.OFCN',
#  '410001.OFCN',
#  '410003.OFCN',
#  '410006.OFCN',
#  '410007.OFCN',
#  '410009.OFCN',
#  '420001.OFCN',
#  '420003.OFCN',
#  '420005.OFCN',
#  '420009.OFCN',
#  '450001.OFCN',
#  '450002.OFCN',
#  '450003.OFCN',
#  '450004.OFCN',
#  '450007.OFCN',
#  '450010.OFCN',
#  '450011.OFCN',
#  '460001.OFCN',
#  '460002.OFCN',
#  '460005.OFCN',
#  '460007.OFCN',
#  '460009.OFCN',
#  '470006.OFCN',
#  '470008.OFCN',
#  '470009.OFCN',
#  '470028.OFCN',
#  '470098.OFCN',
#  '481001.OFCN',
#  '481004.OFCN',
#  '481006.OFCN',
#  '481008.OFCN',
#  '481010.OFCN',
#  '481013.OFCN',
#  '481015.OFCN',
#  '481017.OFCN',
#  '483003.OFCN',
#  '510081.OFCN',
#  '519001.OFCN',
#  '519003.OFCN',
#  '519005.OFCN',
#  '519007.OFCN',
#  '519008.OFCN',
#  '519011.OFCN',
#  '519013.OFCN',
#  '519015.OFCN',
#  '519017.OFCN',
#  '519018.OFCN',
#  '519019.OFCN',
#  '519020.OFCN',
#  '519021.OFCN',
#  '519025.OFCN',
#  '519026.OFCN',
#  '519029.OFCN',
#  '519033.OFCN',
#  '519035.OFCN',
#  '519039.OFCN',
#  '519066.OFCN',
#  '519068.OFCN',
#  '519069.OFCN',
#  '519087.OFCN',
#  '519089.OFCN',
#  '519091.OFCN',
#  '519093.OFCN',
#  '519095.OFCN',
#  '519097.OFCN',
#  '519099.OFCN',
#  '519110.OFCN',
#  '519113.OFCN',
#  '519115.OFCN',
#  '519120.OFCN',
#  '519150.OFCN',
#  '519181.OFCN',
#  '519183.OFCN',
#  '519185.OFCN',
#  '519668.OFCN',
#  '519670.OFCN',
#  '519672.OFCN',
#  '519674.OFCN',
#  '519678.OFCN',
#  '519679.OFCN',
#  '519688.OFCN',
#  '519690.OFCN',
#  '519692.OFCN',
#  '519694.OFCN',
#  '519697.OFCN',
#  '519698.OFCN',
#  '519700.OFCN',
#  '519702.OFCN',
#  '519704.OFCN',
#  '519712.OFCN',
#  '519908.OFCN',
#  '519979.OFCN',
#  '519983.OFCN',
#  '519987.OFCN',
#  '519991.OFCN',
#  '519993.OFCN',
#  '519994.OFCN',
#  '519996.OFCN',
#  '530001.OFCN',
#  '530003.OFCN',
#  '530005.OFCN',
#  '530006.OFCN',
#  '530011.OFCN',
#  '530016.OFCN',
#  '530019.OFCN',
#  '540002.OFCN',
#  '540003.OFCN',
#  '540004.OFCN',
#  '550001.OFCN',
#  '550002.OFCN',
#  '550003.OFCN',
#  '550008.OFCN',
#  '550009.OFCN',
#  '560002.OFCN',
#  '560003.OFCN',
#  '560006.OFCN',
#  '570001.OFCN',
#  '570005.OFCN',
#  '570006.OFCN',
#  '570007.OFCN',
#  '570008.OFCN',
#  '571002.OFCN',
#  '580001.OFCN',
#  '580002.OFCN',
#  '580003.OFCN',
#  '580005.OFCN',
#  '580006.OFCN',
#  '580007.OFCN',
#  '580008.OFCN',
#  '580009.OFCN',
#  '590001.OFCN',
#  '590002.OFCN',
#  '590003.OFCN',
#  '590005.OFCN',
#  '590006.OFCN',
#  '590008.OFCN',
#  '610001.OFCN',
#  '610002.OFCN',
#  '610004.OFCN',
#  '610005.OFCN',
#  '610006.OFCN',
#  '610007.OFCN',
#  '620001.OFCN2',
#  '620002.OFCN',
#  '620004.OFCN',
#  '620005.OFCN',
#  '620006.OFCN',
#  '620008.OFCN',
#  '630001.OFCN',
#  '630002.OFCN',
#  '630005.OFCN',
#  '630006.OFCN',
#  '630008.OFCN',
#  '630010.OFCN',
#  '630011.OFCN',
#  '630015.OFCN',
#  '630016.OFCN',
#  '660001.OFCN',
#  '660003.OFCN',
#  '660004.OFCN',
#  '660005.OFCN',
#  '660006.OFCN',
#  '660010.OFCN',
#  '660012.OFCN',
#  '660015.OFCN',
#  '671010.OFCN',
#  '673010.OFCN',
#  '688888.OFCN',
#  '690001.OFCN',
#  '690003.OFCN',
#  '690004.OFCN',
#  '690005.OFCN',
#  '690007.OFCN',
#  '690009.OFCN',
#  '690011.OFCN',
#  '700001.OFCN',
#  '700003.OFCN',
#  '710001.OFCN',
#  '710002.OFCN',
#  '720001.OFCN',
#  '730001.OFCN',
#  '730002.OFCN',
#  '740001.OFCN',
#  '750001.OFCN',
#  '750005.OFCN',
#  '762001.OFCN',
#  '770001.OFCN'}

# %%
#计算收益率

def CalcReturns(fundpool,data):
    returns = {}
    for fund in fundpool:
        temp = data[data['secID']==fund]
        temp = temp.set_index('endDate')
        value = temp['ADJUST_NAV']
        new_index = value.index[1:]
        diff = value.diff()[1:]
        diff = np.array(diff)
        pre_value = np.array(value[:-1])
        ret = diff/pre_value
        ret = pd.Series(ret,index=new_index)
        returns.update({fund:ret})
    return returns

returns_H = CalcReturns(fund_H,data_H)

# %%
#展示一下returns_H
n=1
for key, value in returns_H.items():
    n=n+1
    if n<3:
         print key, 'corresponds to', value
# Out:
# 610004.OFCN
#  corresponds to endDate
# 2013-05-03    0.019975
# 2013-05-06    0.017136
# 2013-05-07    0.006017
# 2013-05-08    0.008373
# 2013-05-09    0.000000
# 2013-05-10   -0.001186
# 2013-05-13    0.007126
# 2013-05-14   -0.008255
# 2013-05-15    0.020214
# 2013-05-16    0.009324
# 2013-05-17    0.020785
# 2013-05-20    0.004525
# 2013-05-21    0.020270
# 2013-05-22   -0.019868
# 2013-05-23    0.002252
# 2013-05-24    0.017978
# 2013-05-27    0.015453
# 2013-05-28   -0.009783
# 2013-05-29    0.004391
# 2013-05-30    0.005464
# 2013-05-31   -0.004348
# 2013-06-03   -0.009825
# 2013-06-04   -0.013230
# 2013-06-05    0.011173
# 2013-06-06   -0.013260
# 2013-06-07   -0.012318
# 2013-06-13   -0.017007
# 2013-06-14    0.032295
# 2013-06-17    0.007821
# 2013-06-18   -0.001109
#                 ...
# 2018-03-16   -0.008143
# 2018-03-19    0.000000
# 2018-03-20    0.002463
# 2018-03-21   -0.006552
# 2018-03-22   -0.008244
# 2018-03-23   -0.035744
# 2018-03-26    0.020690
# 2018-03-27    0.024493
# 2018-03-28   -0.009068
# 2018-03-29    0.002496
# 2018-03-30    0.019087
# 2018-04-02    0.004886
# 2018-04-03   -0.011345
# 2018-04-04   -0.008197
# 2018-04-09   -0.004959
# 2018-04-10    0.000000
# 2018-04-11    0.012458
# 2018-04-12   -0.004922
# 2018-04-13   -0.002473
# 2018-04-16    0.003306
# 2018-04-17   -0.014827
# 2018-04-18    0.011706
# 2018-04-19   -0.004132
# 2018-04-20   -0.018257
# 2018-04-23   -0.010144
# 2018-04-24    0.020495
# 2018-04-25    0.006695
# 2018-04-26   -0.016625
# 2018-04-27    0.003381
# 2018-05-02    0.002527
# dtype: float64

# %%
# 各指标计算函数
# HR 历史收益率
def CalcHR(fundRet):
    n = len(fundRet)
    endValue =1
    for i in range(n):
        endValue *= (1+fundRet[i])
    # 年化：
    annReturn = endValue**(250.00/n) -1
    return annReturn
        
# Alpha    
def CalcAlpha(fundRet,indexRet):
    n = len(fundRet)
    beta = float(((fundRet*indexRet).sum() - n*(fundRet.mean())*(indexRet.mean()))) / ((indexRet**2).sum() - n*((indexRet.mean())**2))
    alpha = fundRet.mean() - beta*indexRet.mean()
    return alpha

# MVaR
def CalcMVaR(fundRet,level):
    mu = fundRet.mean()
    sigma = fundRet.std()
    S = fundRet.skew()
    K = fundRet.kurtosis()
    z = fundRet.quantile(level)
    MVaR = mu + (z + (1.00/6)*(z**2 -1)*S + (1.00/24)*(z**3-3*z)*K - (1.00/36)*(2*(z**3)-5*z)*(S**2))*sigma
    return MVaR

# 最大回撤 MD
def CalcMD(netvalue):
    netvalue = np.array(netvalue)
    length = len(netvalue)
    drawdown = []
    py =netvalue[0]
    for i in range(1,length):
        px = netvalue[i]
        py = max(netvalue[:i])
        drawdown.append(1-(px/py))
    return max(drawdown)

# 平均回撤 AD
def CalcAD(netvalue):
    netvalue = np.array(netvalue)
    N = len(netvalue)
    AD = 0
    py =netvalue[0]
    for i in range(1,N):
        px = netvalue[i]
        py = max(netvalue[:i])
        DD = (1-(float(px)/py))
        AD += DD*(0.9**(N-i))
    return AD

# 负向收益波动率(年化)LPM
def CalcLPM(fundRet):
    fundRet = fundRet[fundRet<0]
    LPM = fundRet.std()*np.sqrt(250)
    return LPM

# 收益波动率（年化）SIGMA
def CalcSIGMA(fundRet):
    return fundRet.std()*np.sqrt(250)


# 自动计算基础指标并返回所有指标
def AutoCalculate(fundRet,indexRet,netvalue,level):
    ret = {}
    HR = CalcHR(fundRet)
    Alpha = CalcAlpha(fundRet,indexRet)
    MVaR = CalcMVaR(fundRet,level)
    MD = CalcMD(netvalue)
    AD = CalcAD(netvalue)
    LPM = CalcLPM(fundRet)
    SIGMA = CalcSIGMA(fundRet)
    #由于风险类指标是小，基金表现越优，要转换成其倒数
    dMVaR=np.exp( MVaR*-1.0)
    dMD=np.exp( MD*-1.0)
    dAD=np.exp( AD*-1.0)
    dLPM=np.exp(LPM*-1.0)
    dSIGMA=np.exp(SIGMA*-1.0)
    
    ret.update({'HR':HR,'Alpha':Alpha,'dMVaR':dMVaR,'dMD':dMD,'dAD':dAD,'dLPM':dLPM,'dSIGMA':dSIGMA})
    H_Mvar =  HR/(np.exp(MVaR))
    CR = HR/np.abs(MD)
    H_Ad = HR/np.abs(AD)
    SoR = HR/LPM
    SR = HR/SIGMA
    A_Mvar = Alpha/(np.exp(MVaR))
    A_Md = Alpha/np.abs(MD)
    A_Ad = Alpha/np.abs(AD)
    XR = Alpha/LPM
    IR = Alpha/SIGMA
    ret.update({'H_Mvar': H_Mvar,'CR':CR,'H_Ad':H_Ad,'SoR':SoR,'SR':SR,'A_Mvar':A_Mvar,'A_Md':A_Md,'A_Ad':A_Ad,'XR':XR,'IR':IR})
    return ret

# %%
# 计算混合型基金指数
def CalcFundIndex(data):
    datelist = list(pd.Series(list(set(list(data['endDate'])))).sort_values())
    IndexValue = {}
    for date in datelist:
        temp = data[data['endDate']==date]
        IndexValue.update({date:temp['ADJUST_NAV'].mean()})  # 等权合成基金指数
    IndexValue = pd.Series(IndexValue)
    IndexValue = IndexValue/IndexValue.iloc[0]
    return IndexValue
Indextype_H = CalcFundIndex(data_H)  # 混合型基金指数

# %%
Indextype_H
# Out:
# 2013-05-02    1.000000
# 2013-05-03    1.011035
# 2013-05-06    1.027740
# 2013-05-07    1.028199
# 2013-05-08    1.037539
# 2013-05-09    1.035588
# 2013-05-10    1.032025
# 2013-05-13    1.035255
# 2013-05-14    1.021995
# 2013-05-15    1.035516
# 2013-05-16    1.046814
# 2013-05-17    1.057112
# 2013-05-20    1.067893
# 2013-05-21    1.076274
# 2013-05-22    1.067906
# 2013-05-23    1.064146
# 2013-05-24    1.071850
# 2013-05-27    1.083198
# 2013-05-28    1.083669
# 2013-05-29    1.088010
# 2013-05-30    1.088303
# 2013-05-31    1.075874
# 2013-06-03    1.071102
# 2013-06-04    1.053938
# 2013-06-05    1.057946
# 2013-06-06    1.046079
# 2013-06-07    1.031863
# 2013-06-12    1.656352
# 2013-06-13    1.018154
# 2013-06-14    1.032572
#                 ...
# 2018-03-16    1.879625
# 2018-03-19    1.886047
# 2018-03-20    1.891191
# 2018-03-21    1.876185
# 2018-03-22    1.857162
# 2018-03-23    1.798681
# 2018-03-26    1.812720
# 2018-03-27    1.837912
# 2018-03-28    1.810957
# 2018-03-29    1.824210
# 2018-03-30    1.844901
# 2018-04-02    1.843066
# 2018-04-03    1.832047
# 2018-04-04    1.822663
# 2018-04-09    1.821039
# 2018-04-10    1.839635
# 2018-04-11    1.848353
# 2018-04-12    1.836615
# 2018-04-13    1.827639
# 2018-04-16    1.820177
# 2018-04-17    1.783441
# 2018-04-18    1.799461
# 2018-04-19    1.811070
# 2018-04-20    1.785069
# 2018-04-23    1.766145
# 2018-04-24    1.807920
# 2018-04-25    1.812588
# 2018-04-26    1.783373
# 2018-04-27    1.787514
# 2018-05-02    1.794490
# dtype: float64

# %%
#计算混合型基金指数收益，计算指标时需要
def CalcIndexReturns(IndexData):
    new_index = IndexData.index[1:]
    diff = IndexData.diff()[1:]
    diff = np.array(diff)
    pre_value = np.array(IndexData[:-1])
    ret = diff/pre_value
    ret = pd.Series(ret,index=new_index)
    return ret

returns_Index_H = CalcIndexReturns(Indextype_H)

# %%
returns_Index_H.head()
# Out:
# 2013-05-03    0.011035
# 2013-05-06    0.016523
# 2013-05-07    0.000447
# 2013-05-08    0.009083
# 2013-05-09   -0.001880
# dtype: float64

# %%
#计算各指标，并保存为pd.dataframe
ret = {}                                           
for fund in fund_H:
    try:
        fundRet = returns_H[fund]
        temp = data_H[data_H['secID']==fund]
        temp = temp.set_index('endDate')
        netvalue = temp['ADJUST_NAV']
        calc = AutoCalculate(fundRet,returns_Index_H,netvalue,0.05) # 计算各指标
        ret.update({fund:calc})
    except:  # 如果可观测的数据不够
        pass
ret = pd.DataFrame(ret) #转换成pd数据框
ret = ret.transpose() #转值

# %%
ret.sort_values(by = 'HR',axis = 0,ascending = False)
# Out:
#                  A_Ad      A_Md    A_Mvar     Alpha        CR        HR  \
# 213001.OFCN  0.000495  0.002738  0.001152  0.001156  0.798697  0.337270
# 163412.XSHE  0.001055  0.003304  0.001012  0.001014  1.074590  0.329896
# 180031.OFCN  0.000885  0.001860  0.000878  0.000881  0.625016  0.296046
# 040035.OFCN  0.000887  0.001963  0.000861  0.000863  0.653685  0.287601
# 519697.OFCN  0.006491  0.002437  0.000863  0.000865  0.806947  0.286338
# 163406.OFCN  0.000947  0.002798  0.000855  0.000857  0.929493  0.284642
# 000083.OFCN  0.000605  0.001578  0.000838  0.000840  0.512503  0.272959
# 020026.OFCN  0.000719  0.001627  0.000812  0.000814  0.544666  0.272572
# 040025.OFCN  0.001417  0.001689  0.000810  0.000813  0.563519  0.271029
# 160212.XSHE  0.000492  0.001729  0.000805  0.000807  0.578417  0.269895
# 570005.OFCN  0.002304  0.001879  0.000796  0.000798  0.624881  0.265378
# 100016.OFCN  0.000284  0.002119  0.000895  0.000897  0.623054  0.263718
# 162209.OFCN  0.007793  0.780459  0.535770  0.998008  0.731076
# 320007.OFCN  0.004346  0.762309  0.540067  0.997789  0.731895
# 398011.OFCN  0.012519  0.775487  0.546913  0.997618  0.739742
# 050201.OFCN  0.042716  0.834868  0.691789  0.997763  0.815316
# 310318.OFCN  0.999230  0.996183  0.999301  0.999954  0.997039
# 210009.OFCN  0.002732  0.743502  0.504230  0.997988  0.690020
# 162214.OFCN  0.004885  0.753958  0.511356  0.997778  0.714022
# 080007.OFCN  0.010894  0.769151  0.563407  0.996964  0.776294
# 519026.OFCN  0.005196  0.774577  0.529985  0.998568  0.726181
# 350002.OFCN  0.007403  0.790901  0.540143  0.998587  0.746968
# 580002.OFCN  0.003553  0.769645  0.511923  0.998117  0.723857
# 162211.OFCN  0.006255  0.793139  0.550831  0.998228  0.761984
# 481004.OFCN  0.002512  0.775508  0.510065  0.997830  0.740412
# 378010.OFCN  0.009236  0.784138  0.538444  0.997553  0.753054
# 350007.OFCN  0.228445  0.894365  0.783927  0.998957  0.882810
# 560002.OFCN  0.012056  0.804790  0.586298  0.998273  0.772381
# 160611.XSHE  0.015220  0.826728  0.616578  0.998817  0.793444
# 620004.OFCN  0.003225  0.786882  0.516284  0.997914  0.756169
# 519013.OFCN  0.013861  0.802456  0.613162  0.998245  0.769715
#
# [521 rows x 17 columns]

# %% [markdown]
# 三、主成分分析法的计算

# %%
     
# 标准化函数
scale_fun = lambda x: (x - x.mean(axis=0)) / x.std(axis=0)

# 归一化函数
norm_fun = lambda x: x/x.sum()

# 标准化处理
scoresDf = ret.apply(scale_fun)
scoresDf.head()
# Out:
#                  A_Ad      A_Md    A_Mvar     Alpha        CR        HR  \
# 000001.OFCN -0.084631 -0.507952 -0.969829 -0.969815 -0.533318 -0.956736
# 000011.OFCN -0.053557 -0.208424 -0.369013 -0.368919 -0.209808 -0.353472
# 000017.OFCN -0.061079  0.348809  1.017644  1.017819  0.322692  0.981998
# 000020.OFCN -0.025436  0.228322  0.632556  0.632829  0.246535  0.676582
# 000021.OFCN -0.083619 -0.480999 -0.907494 -0.907464 -0.469991 -0.816819
#
#                  H_Ad    H_Mvar        IR        SR       SoR        XR  \
# 000001.OFCN -0.092273 -0.956833 -0.742191 -0.585196 -0.641741 -0.779026
# 000011.OFCN -0.049326 -0.353684 -0.337665 -0.314635 -0.341922 -0.360415
# 000017.OFCN -0.069304  0.981865  0.910729  0.894151  0.879918  0.902804
# 000020.OFCN -0.021498  0.676281  0.456444  0.481446  0.512506  0.482371
# 000021.OFCN -0.090006 -0.816926 -0.830824 -0.760062 -0.786020 -0.853205
#
#                   dAD      dLPM       dMD     dMVaR    dSIGMA
# 000001.OFCN -0.630109  1.283967 -0.093487  0.103667  1.461502
# 000011.OFCN  0.659547  0.075658  0.091506 -0.334787  0.153819
# 000017.OFCN -0.654030  0.175412 -0.371446 -0.455528  0.207335
# 000020.OFCN  0.487948 -0.054981 -0.129708 -0.543697 -0.135060
# 000021.OFCN -0.612231 -0.136222 -0.130192 -0.012499 -0.043183

# %%
# 第二步，求解相关系数矩阵，对原始数据标准化后，协方差矩阵与相关系数矩阵是等价的
cov_mat = np.cov(scoresDf, rowvar=0)
cov_mat
# Out:
# array([[ 1.        ,  0.34935348,  0.12402665,  0.1238804 ,  0.34113976,
#          0.10182074,  0.99976   ,  0.10197374,  0.26287969,  0.2416459 ,
#          0.23952638,  0.26113422,  0.25599269,  0.13195906,  0.18945194,
#          0.04474151,  0.12733024],
#        [ 0.34935348,  1.        ,  0.59354004,  0.59336187,  0.99669637,
#          0.5902315 ,  0.34478414,  0.59046122,  0.77262045,  0.76722533,
#          0.73847316,  0.7404081 ,  0.29196404,  0.04392377,  0.22121023,
#         -0.16564458,  0.02335999],
#        [ 0.12402665,  0.59354004,  1.        ,  0.99999951,  0.63029514,
#          0.99553629,  0.13068527,  0.99557966,  0.88847542,  0.88829068,
#          0.90482627,  0.90644441,  0.4785677 ,  0.06190077,  0.31012382,
#         -0.35340966,  0.03721385],
#        [ 0.1238804 ,  0.59336187,  0.99999951,  1.        ,  0.63011114,
#          0.99557697,  0.1305383 ,  0.99561921,  0.88830456,  0.88813497,
#          0.90461867,  0.90623067,  0.47832293,  0.0614451 ,  0.30971577,
#         -0.35414358,  0.03688977],
#        [ 0.34113976,  0.99669637,  0.63029514,  0.63011114,  1.        ,
#          0.6281266 ,  0.33773948,  0.62836638,  0.80128692,  0.79953988,
#          0.77465161,  0.77319286,  0.33785173,  0.07716573,  0.27037249,
#         -0.16539541,  0.05593194],
#        [ 0.10182074,  0.5902315 ,  0.99553629,  0.99557697,  0.6281266 ,
#          1.        ,  0.10842435,  0.99999934,  0.86696092,  0.87215575,
#          0.88792953,  0.88407578,  0.45302609,  0.01117949,  0.2597672 ,
#         -0.39875983, -0.0102652 ],
#        [ 0.99976   ,  0.34478414,  0.13068527,  0.1305383 ,  0.33773948,
#          0.10842435,  1.        ,  0.10857866,  0.26773964,  0.2469433 ,
#          0.24555324,  0.26681628,  0.27172374,  0.13858116,  0.1980279 ,
#          0.04606709,  0.13394566],
#        [ 0.10197374,  0.59046122,  0.99557966,  0.99561921,  0.62836638,
#          0.99999934,  0.10857866,  1.        ,  0.86718512,  0.87236692,
#          0.88820659,  0.88435396,  0.45332603,  0.01172397,  0.26024391,
#         -0.39786904, -0.00989305],
#        [ 0.26287969,  0.77262045,  0.88847542,  0.88830456,  0.80128692,
#          0.86696092,  0.26773964,  0.86718512,  1.        ,  0.99637384,
#          0.98932957,  0.99415154,  0.59666372,  0.30947898,  0.49870827,
#         -0.16285002,  0.29396684],
#        [ 0.2416459 ,  0.76722533,  0.88829068,  0.88813497,  0.79953988,
#          0.87215575,  0.2469433 ,  0.87236692,  0.99637384,  1.        ,
#          0.99327298,  0.99097652,  0.60449021,  0.32726805,  0.50535412,
#         -0.17433173,  0.31523526],
#        [ 0.23952638,  0.73847316,  0.90482627,  0.90461867,  0.77465161,
#          0.88792953,  0.24555324,  0.88820659,  0.98932957,  0.99327298,
#          1.        ,  0.99634354,  0.61373514,  0.34233623,  0.51928436,
#         -0.13096355,  0.31212338],
#        [ 0.26113422,  0.7404081 ,  0.90644441,  0.90623067,  0.77319286,
#          0.88407578,  0.26681628,  0.88435396,  0.99415154,  0.99097652,
#          0.99634354,  1.        ,  0.60866747,  0.32527931,  0.51525025,
#         -0.12877278,  0.29531105],
#        [ 0.25599269,  0.29196404,  0.4785677 ,  0.47832293,  0.33785173,
#          0.45302609,  0.27172374,  0.45332603,  0.59666372,  0.60449021,
#          0.61373514,  0.60866747,  1.        ,  0.5305605 ,  0.69488674,
#          0.17261351,  0.52245777],
#        [ 0.13195906,  0.04392377,  0.06190077,  0.0614451 ,  0.07716573,
#          0.01117949,  0.13858116,  0.01172397,  0.30947898,  0.32726805,
#          0.34233623,  0.32527931,  0.5305605 ,  1.        ,  0.83721868,
#          0.59926185,  0.97308308],
#        [ 0.18945194,  0.22121023,  0.31012382,  0.30971577,  0.27037249,
#          0.2597672 ,  0.1980279 ,  0.26024391,  0.49870827,  0.50535412,
#          0.51928436,  0.51525025,  0.69488674,  0.83721868,  1.        ,
#          0.40087457,  0.82616651],
#        [ 0.04474151, -0.16564458, -0.35340966, -0.35414358, -0.16539541,
#         -0.39875983,  0.04606709, -0.39786904, -0.16285002, -0.17433173,
#         -0.13096355, -0.12877278,  0.17261351,  0.59926185,  0.40087457,
#          1.        ,  0.46392023],
#        [ 0.12733024,  0.02335999,  0.03721385,  0.03688977,  0.05593194,
#         -0.0102652 ,  0.13394566, -0.00989305,  0.29396684,  0.31523526,
#          0.31212338,  0.29531105,  0.52245777,  0.97308308,  0.82616651,
#          0.46392023,  1.        ]])

# %%
# 第三步，求解特征值和特征向量
eig_value, eig_vector = np.linalg.eig(cov_mat)
print ("eigenvalue: \n",eig_value )
print ("eigenvector: \n", eig_vector)
# Out:
# ('eigenvalue: \n', array([  9.51560946e+00,   3.44736182e+00,   1.97835251e+00,
#          9.17333055e-01,   4.73120807e-01,   3.95871657e-01,
#          1.70569083e-01,   7.90673703e-02,   1.21318632e-02,
#          7.02097226e-03,   3.08747373e-03,   2.36523812e-04,
#          1.87227955e-04,   4.47924212e-05,   5.16175996e-06,
#          2.24177721e-07,   7.56444190e-10]))
# ('eigenvector: \n', array([[ -9.81861291e-02,   1.22917881e-01,  -6.34224703e-01,
#           2.45593822e-01,   1.36906328e-02,  -1.11654142e-01,
#          -1.17122810e-02,  -4.28572537e-03,   6.58399320e-03,
#          -5.06501595e-03,  -1.74951407e-02,  -3.68648874e-02,
#          -1.02263542e-01,   6.98347169e-01,   1.69063370e-03,
#           4.36035411e-04,   4.26752106e-05],
#        [ -2.47518883e-01,  -7.83501376e-02,  -2.24838054e-01,
#          -5.50894936e-01,  -8.00541601e-02,   1.46095028e-01,
#          -8.96261873e-02,  -2.22765038e-01,   1.84910280e-01,
#           1.53034065e-01,  -4.39938053e-02,  -4.71714786e-01,
#          -4.47141172e-01,  -1.01588789e-01,   2.84878096e-02,
#          -4.48624665e-03,   1.20088499e-04],
#        [ -3.20438725e-01,   1.66723232e-02,   4.76907002e-02,
#          -4.47453177e-02,   2.75575738e-02,  -7.47691731e-02,
#           1.78706195e-01,   2.13430535e-01,  -5.39931866e-01,
#          -5.64472244e-02,   3.68855713e-01,  -3.55584845e-01,
#           9.58978020e-02,   1.32546548e-02,  -4.92253264e-01,
#           5.50342407e-03,  -1.64277409e-03],
#        [ -3.20319692e-01,   1.31256222e-02,   3.09883009e-02,
#          -3.64996075e-02,   5.14958312e-02,  -8.01332420e-02,
#           1.56972990e-01,   3.63970724e-01,  -2.03871990e-02,
#           3.34599067e-01,   4.54690151e-01,   2.96478334e-01,
#          -2.57366854e-01,  -2.45650591e-02,   5.04741524e-01,
#          -1.09116371e-02,   1.79803027e-03],
#        [ -2.04798130e-01,   2.50960522e-01,   5.38835411e-02,
#           2.77680610e-01,   1.75108294e-01,   8.46192588e-01,
#           2.12111394e-01,  -1.43923609e-01,   1.50790580e-02,
#           4.72873510e-02,   4.14496575e-03,  -2.20669983e-03,
#          -3.99274785e-03,   1.24521527e-02,  -3.30623714e-05,
#           6.82457241e-05,   8.41522102e-06],
#        [ -9.61518486e-02,   4.89051550e-01,   1.33952906e-01,
#          -3.06169061e-02,  -1.47223451e-01,  -2.50661960e-01,
#           1.70920501e-01,  -3.05951196e-01,  -3.44078629e-01,
#           4.96222589e-01,  -3.94108646e-01,   6.68602194e-02,
#          -1.03897307e-03,  -3.10683645e-03,   3.07594138e-02,
#           8.73767439e-04,   3.47714700e-05],
#        [ -1.67511972e-01,   4.06884578e-01,   1.18220258e-01,
#           5.59831730e-02,  -1.31929994e-01,   9.96305823e-02,
#          -8.09212770e-01,   3.14786073e-01,  -4.89034056e-02,
#          -3.80331224e-02,  -3.96572138e-02,  -4.05425667e-02,
#          -3.01358775e-02,  -7.97895957e-03,   8.62950542e-04,
#          -3.79110755e-04,   1.09904389e-05],
#        [  5.98797627e-02,   4.03763447e-01,   1.91007597e-02,
#          -2.66855474e-01,   8.26751648e-01,  -1.88326839e-01,
#           8.80066379e-03,  -2.09280078e-02,   1.09382962e-01,
#          -1.70823749e-01,   3.28105707e-02,  -7.49218534e-03,
#           5.59872390e-03,   1.22215455e-03,   5.35148182e-04,
#          -9.49144003e-04,  -1.11713523e-04],
#        [ -8.95775558e-02,   4.75634770e-01,   1.32271997e-01,
#           1.54569619e-02,  -4.16189224e-01,  -1.71290787e-01,
#           2.05457689e-01,  -2.49301836e-01,   3.79432017e-01,
#          -3.84911741e-01,   3.83751676e-01,  -5.20653136e-03,
#          -2.68441670e-02,   1.81143040e-04,  -3.09114381e-02,
#          -1.90640113e-04,   3.09104461e-05]]))

# %%
# 第四步，画出主成分的累积贡献率图以及碎石图
total = sum(eig_value)
contriRate = [(i/total) for i in sorted(eig_value, reverse=True)]
cumContriRate = np.cumsum(contriRate)

fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(np.arange(1, 18), cumContriRate)
ax[0].set_title("Cumulative Contribution Rate")
ax[0].set_ylabel("Explained Variance Ratio")

ax[1].plot(np.arange(1, 18), eig_value, 'm')
ax[1].set_title("Scree Plot")
ax[1].set_ylabel("Eigenvalue");

# %%
# 第五步，确定主成分表达式
# 选取使得累积贡献率达到85%以上的主成分，再根据碎石图，此处选取前6个主成分。

loadings1 = eig_vector[:, 0]     # 第一主成分
print ("y1 =" + str(loadings1[0]) + " x1 + " + str(loadings1[1]) + "x2 + " + str(loadings1[2]) + "x3 + "\
       + str(loadings1[3]) + "x4 + " + str(loadings1[4]) + "x5 + " + str(loadings1[5]) + "x6" )

loadings2 = eig_vector[:, 1]     # 第二主成分
print ("y2 =" + str(loadings2[0]) + "x1 + " + str(loadings2[1]) + "x2 + " + str(loadings2[2]) + "x3 + "\
       + str(loadings2[3]) + "x4 + " + str(loadings2[4]) + "x5 + " + str(loadings2[5]) + "x6" )

loadings3 = eig_vector[:, 2] 

print ("y3 =" + str(loadings3[0]) + "x1 + " + str(loadings3[1]) + "x2 + " + str(loadings3[2]) + "x3 + "\
       + str(loadings3[3]) + "x4 + " + str(loadings3[4]) + "x5 + " + str(loadings3[5]) + "x6" )

loadings4 = eig_vector[:, 3] 
print ("y4 =" + str(loadings4[0]) + "x1 + " + str(loadings4[1]) + "x2 + " + str(loadings4[2]) + "x3 + "\
       + str(loadings4[3]) + "x4 + " + str(loadings4[4]) + "x5 + " + str(loadings4[5]) + "x6" )

loadings5 = eig_vector[:, 4] 
print ("y5 =" + str(loadings5[0]) + "x1 + " + str(loadings5[1]) + "x2 + " + str(loadings5[2]) + "x3 + "\
       + str(loadings5[3]) + "x4 + " + str(loadings5[4]) + "x5 + " + str(loadings5[5]) + "x6" )

loadings6 = eig_vector[:, 5] 

print ("y6 =" + str(loadings6[0]) + "x1 + " + str(loadings6[1]) + "x2 + " + str(loadings6[2]) + "x3 + "\
       + str(loadings6[3]) + "x4 + " + str(loadings6[4]) + "x5 + " + str(loadings6[5]) + "x6" )
# Out:
# y1 =-0.0981861291145 x1 + -0.247518882967x2 + -0.299219226818x3 + -0.29916837326x4 + -0.258879675268x5 + -0.293909793171x6
# y2 =0.122917880743x1 + -0.0783501375558x2 + -0.143811002688x3 + -0.144081815356x4 + -0.06692837566x5 + -0.172481391558x6
# y3 =-0.634224703304x1 + -0.224838053849x2 + 0.113952992714x3 + 0.113987099111x4 + -0.200402600805x5 + 0.116792183063x6
# y4 =0.245593821821x1 + -0.550894935795x2 + 0.182712636001x3 + 0.183029786622x4 + -0.517373039537x5 + 0.181933472133x6
# y5 =0.0136906328226x1 + -0.0800541600621x2 + 0.120482795607x3 + 0.119719443858x4 + -0.0818013609426x5 + 0.102917674352x6
# y6 =-0.111654141922x1 + 0.146095028272x2 + -0.138976140403x3 + -0.138799776909x4 + 0.160029173849x5 + -0.110847346259x6

# %%
# 对选取的前6个主成分进行综合评价
scores_in_pca1 = np.sum(loadings1 * ret.ix[:, :17], axis=1)
scores_in_pca2 = np.sum(loadings2 * ret.ix[:, :17], axis=1)
scores_in_pca3 = np.sum(loadings3 * ret.ix[:, :17], axis=1)
scores_in_pca4 = np.sum(loadings4 * ret.ix[:, :17], axis=1)
scores_in_pca5 = np.sum(loadings5 * ret.ix[:, :17], axis=1)
scores_in_pca6 = np.sum(loadings6 * ret.ix[:, :17], axis=1)

x1, x2,x3,x4,x5,x6 = norm_fun(eig_value)[:6]
print (x1, x2, x3, x4,x5,x6)
adjScores = pd.DataFrame(x1 * scores_in_pca1 + x2 * scores_in_pca2+x3 * scores_in_pca3 + x4 * scores_in_pca4+x5 * scores_in_pca5 + x6 * scores_in_pca6, columns=["pca scores"]).sort_values(by="pca scores", ascending=False)
selectfund=adjScores.head()
selectfund
# Out:
# (0.55974173304792652, 0.20278598925943875, 0.11637367698640785, 0.053960767931268361, 0.027830635703763394, 0.023286568063975086)
#              pca scores
# 310318.OFCN    1.775952
# 519013.OFCN    0.320751
# 160611.XSHE    0.301366
# 620004.OFCN    0.289461
# 350007.OFCN    0.289052

# %%
#取出基金的信息
sec_info = DataAPI.FundGet(etfLof=u"",secID=list(selectfund.index),ticker=u"",category=u"",idxID=u"",idxTicker=u"",listStatusCd=u"",operationMode=u"",field=u"secID,secShortName,category,managerName,establishDate,investField,investTarget",pandas="1").set_index('secID')
result = selectfund.merge(sec_info,how='inner',left_index=True,right_index=True)
result.sort_values(by = 'pca scores',axis = 0,ascending = False)
# Out:
#              pca scores  secShortName category managerName establishDate  \
# 310318.OFCN    1.775952  申万菱信盛利强化配置混合        H         NaN    2004-11-29
# 519013.OFCN    0.320751     海富通风格优势混合        H     施敏佳、顾晓飞    2006-10-19
# 160611.XSHE    0.301366      鹏华优质治理混合        H         郑川江    2007-04-25
# 620004.OFCN    0.289461    金元顺安价值增长混合        H         贾丽杰    2009-09-11
# 350007.OFCN    0.289052      天治趋势精选混合        H         尹维国    2009-07-15
#
#                                                    investField  \
# 310318.OFCN  在中华人民共和国境内依法发行上市交易的股票和固定收益证券以及国务院证券监督管理机构规定的其他...
# 519013.OFCN  本基金的投资范围限于具有良好流动性的金融工具，包括国内依法公开发行上市的股票、国债、金融债、...
# 160611.XSHE  本基金的投资范围为具有良好流动性的金融工具，包括国内依法发行的各类股票、债券、权证、资产证券...
# 620004.OFCN  本基金的投资范围为具有良好流动性的金融工具，包括国内依法发行上市的股票、债券、货币市场工具、...
# 350007.OFCN  本基金投资范围为具有良好流动性的金融工具，包括国内依法发行上市的股票、国债、金融债、企业债、...
#
#                                                   investTarget
# 310318.OFCN  尽最大努力规避证券市场投资的系统性和波动性风险以尽可能保护投资本金安全，并分享股市上涨带来的...
# 519013.OFCN  在适度控制风险并保持资产良好流动性的前提下，通过积极选择不同风格优势的股票，力争为投资者寻求...
# 160611.XSHE  投资于具有相对完善的公司治理结构和良好成长性的优质上市公司，为基金份额持有人谋求长期、稳定的...
# 620004.OFCN  在GARP（Growth at reasonable price）策略指导下，本基金投资于具...
# 350007.OFCN  在灵活配置股票和债券资产的基础上，精选受益于重大人口趋势的优势行业中的领先企业，追求持续稳健...

# %% [markdown]
# 本文很多问题需进一步深入研究 文章中的错误与不当之处在所难免 恳请各位批评指正
