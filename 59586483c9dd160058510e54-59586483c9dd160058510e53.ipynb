# %% [markdown]
# # 请问一下为什么场外基金买入不了？哪里错了？

# %%
#筛选基金
def fund_buy(three,tod):
    f=DataAPI.FundAssetsGet(reportDate=u"",secID=u"",ticker=u"",updateTime=u"",beginDate=three,endDate=tod,field=u"",pandas="1")
    f=f[f['equityRatioInTa']>60]
    f=f.secID.head(3)
    return f

# %% [raw]
# from datetime import timedelta
# start = '2016-03-01'                       # 回测起始时间
# end = '2017-05-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 50                          # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# accounts = {'otc_fund': AccountConfig('otc_fund', capital_base=capital_base,
#                                       commission=Commission(buycost=0.001, sellcost=0.005, unit='perValue'),
#                                       dividend_method='cash_bonus')}
#
# def initialize(context):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(context):                  # 每个交易日的买入卖出指令
#     today = context.current_date
#     one_month_ago = today + timedelta(days = -15)
#     three_month_ago = today + timedelta(days = -100)
#
#
#     # 处理交易逻辑
#     account = context.get_account('otc_fund')
#     current_positions = account.get_positions()
#
#     funds_to_buy = fund_buy(three_month_ago,today)#需要买入的基金，函数
#     print funds_to_buy
#     #funds_to_buy = four_star_funds.difference(current_positions.keys())
#
#     #account.redeem(s, 100000)
#     for fund in funds_to_buy:
#         capital_to_purchase = account.cash / len(funds_to_buy)
#         account.purchase(fund, capital_to_purchase)
