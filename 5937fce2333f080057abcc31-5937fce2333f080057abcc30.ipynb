# %% [markdown]
# # Notebook1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dates = pd.date_range('20170606',periods=6)
df = pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2017-06-06 -0.860827 -1.286721 -0.517257 -0.508068
# 2017-06-07  0.963646  0.212454 -0.945365 -1.693426
# 2017-06-08 -2.057464 -0.549497 -0.416616  1.132755
# 2017-06-09  0.650343  0.043464 -0.415149 -0.823705
# 2017-06-10 -0.663587 -0.347158  0.576039  0.599729
# 2017-06-11 -0.114040 -0.767161 -0.184020  0.568981

# %%
df1 = df.reindex(index=dates[0:4],columns=list(df.columns)+['E'])
df1
# Out:
#                    A         B         C         D   E
# 2017-06-06 -0.860827 -1.286721 -0.517257 -0.508068 NaN
# 2017-06-07  0.963646  0.212454 -0.945365 -1.693426 NaN
# 2017-06-08 -2.057464 -0.549497 -0.416616  1.132755 NaN
# 2017-06-09  0.650343  0.043464 -0.415149 -0.823705 NaN

# %%
# 缺失值处理d
df1.loc[dates[1:3],'E'] = 2
df1
# Out:
#                    A         B         C         D    E
# 2017-06-06 -0.860827 -1.286721 -0.517257 -0.508068  NaN
# 2017-06-07  0.963646  0.212454 -0.945365 -1.693426  2.0
# 2017-06-08 -2.057464 -0.549497 -0.416616  1.132755  2.0
# 2017-06-09  0.650343  0.043464 -0.415149 -0.823705  NaN

# %%
df1.dropna()
# Out:
#                    A         B         C         D    E
# 2017-06-07  0.963646  0.212454 -0.945365 -1.693426  2.0
# 2017-06-08 -2.057464 -0.549497 -0.416616  1.132755  2.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C         D    E
# 2017-06-06 -0.860827 -1.286721 -0.517257 -0.508068  5.0
# 2017-06-07  0.963646  0.212454 -0.945365 -1.693426  2.0
# 2017-06-08 -2.057464 -0.549497 -0.416616  1.132755  2.0
# 2017-06-09  0.650343  0.043464 -0.415149 -0.823705  5.0

# %%
pd.isnull(df1)
# Out:
#                 A      B      C      D      E
# 2017-06-06  False  False  False  False   True
# 2017-06-07  False  False  False  False  False
# 2017-06-08  False  False  False  False  False
# 2017-06-09  False  False  False  False   True

# %%
pd.isnull(df1).any()
# Out:
# A    False
# B    False
# C    False
# D    False
# E     True
# dtype: bool

# %%
pd.isnull(df1).any().any()
# Out:
# True

# %%
# 缺失值不参与计算
df1.mean()
# Out:
# A   -0.326075
# B   -0.395075
# C   -0.573597
# D   -0.473111
# E    2.000000
# dtype: float64

# %%
df1.mean(axis=1)
# Out:
# 2017-06-06   -0.793218
# 2017-06-07    0.107462
# 2017-06-08    0.021836
# 2017-06-09   -0.136262
# Freq: D, dtype: float64

# %%
# 累加
df1.cumsum()
# Out:
#                    A         B         C         D    E
# 2017-06-06 -0.860827 -1.286721 -0.517257 -0.508068  NaN
# 2017-06-07  0.102820 -1.074266 -1.462622 -2.201494  2.0
# 2017-06-08 -1.954644 -1.623763 -1.879238 -1.068739  4.0
# 2017-06-09 -1.304302 -1.580299 -2.294387 -1.892444  NaN

# %%
s = pd.Series([1,3,5,np.NAN,6,8],index=dates).shift(2)
# .shift() 整体数据下移
s
# Out:
# 2017-06-06    NaN
# 2017-06-07    NaN
# 2017-06-08    1.0
# 2017-06-09    3.0
# 2017-06-10    5.0
# 2017-06-11    NaN
# Freq: D, dtype: float64

# %%
df
# Out:
#                    A         B         C         D
# 2017-06-06 -0.860827 -1.286721 -0.517257 -0.508068
# 2017-06-07  0.963646  0.212454 -0.945365 -1.693426
# 2017-06-08 -2.057464 -0.549497 -0.416616  1.132755
# 2017-06-09  0.650343  0.043464 -0.415149 -0.823705
# 2017-06-10 -0.663587 -0.347158  0.576039  0.599729
# 2017-06-11 -0.114040 -0.767161 -0.184020  0.568981

# %%
# 序列相减（axis=0/'index':行标签；axis=1/'columns'：列标签）;缺失值不参与计算
df.sub(s,axis='index')
# Out:
#                    A         B         C         D
# 2017-06-06       NaN       NaN       NaN       NaN
# 2017-06-07       NaN       NaN       NaN       NaN
# 2017-06-08 -3.057464 -1.549497 -1.416616  0.132755
# 2017-06-09 -2.349657 -2.956536 -3.415149 -3.823705
# 2017-06-10 -5.663587 -5.347158 -4.423961 -4.400271
# 2017-06-11       NaN       NaN       NaN       NaN

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C         D
# 2017-06-06 -0.860827 -1.286721 -0.517257 -0.508068
# 2017-06-07  0.102820 -1.074266 -1.462622 -2.201494
# 2017-06-08 -1.954644 -1.623763 -1.879238 -1.068739
# 2017-06-09 -1.304302 -1.580299 -2.294387 -1.892444
# 2017-06-10 -1.967889 -1.927457 -1.718348 -1.292715
# 2017-06-11 -2.081929 -2.694619 -1.902368 -0.723734

# %%
df.apply(lambda x : x.max() - x.min())
# Out:
# A    3.021110
# B    1.499175
# C    1.521404
# D    2.826181
# dtype: float64

# %%
def _sum(x):
    print(type(x))
    return x.sum()
df.apply(_sum)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# A   -2.081929
# B   -2.694619
# C   -1.902368
# D   -0.723734
# dtype: float64

# %%
s = pd.Series(np.random.randint(10,20,size=20))
s
# Out:
# 0     18
# 1     14
# 2     17
# 3     18
# 4     17
# 5     12
# 6     17
# 7     11
# 8     10
# 9     17
# 10    11
# 11    16
# 12    12
# 13    18
# 14    13
# 15    14
# 16    15
# 17    17
# 18    13
# 19    18
# dtype: int64

# %%
# 计数
s.value_counts()
# Out:
# 17    5
# 18    4
# 14    2
# 13    2
# 12    2
# 11    2
# 16    1
# 15    1
# 10    1
# dtype: int64

# %%
# 数量最多的
s.mode()
# Out:
# 0    17
# dtype: int64

# %%
df = pd.DataFrame(np.random.randn(10,4),columns=list('ABCD'))
df
# Out:
#           A         B         C         D
# 0 -0.137303  1.171769  0.274573  0.399917
# 1  1.173580 -1.060993 -0.677838  1.043599
# 2 -0.528126 -1.703482  0.571849  1.145503
# 3  0.250318 -0.379541  0.696846  0.017463
# 4 -0.317095 -0.220606 -2.127907  0.626812
# 5 -0.795980  0.103736  2.307983 -0.135649
# 6  0.177584  1.617713  0.586867  0.010041
# 7 -0.699434  0.956211  0.881476  1.907259
# 8  1.758003  0.401241 -0.149460 -0.119145
# 9  1.830858 -0.634444  0.880763  1.576691

# %%
df.iloc[:3]
# Out:
#           A         B         C         D
# 0 -0.137303  1.171769  0.274573  0.399917
# 1  1.173580 -1.060993 -0.677838  1.043599
# 2 -0.528126 -1.703482  0.571849  1.145503

# %%
df.iloc[3:7]
# Out:
#           A         B         C         D
# 3  0.250318 -0.379541  0.696846  0.017463
# 4 -0.317095 -0.220606 -2.127907  0.626812
# 5 -0.795980  0.103736  2.307983 -0.135649
# 6  0.177584  1.617713  0.586867  0.010041

# %%
df.iloc[7:]
# Out:
#           A         B         C         D
# 7 -0.699434  0.956211  0.881476  1.907259
# 8  1.758003  0.401241 -0.149460 -0.119145
# 9  1.830858 -0.634444  0.880763  1.576691

# %%
# 数据合并
df1 = pd.concat([df.iloc[:3],df.iloc[3:7],df.iloc[7:]])
df1
# Out:
#           A         B         C         D
# 0 -0.137303  1.171769  0.274573  0.399917
# 1  1.173580 -1.060993 -0.677838  1.043599
# 2 -0.528126 -1.703482  0.571849  1.145503
# 3  0.250318 -0.379541  0.696846  0.017463
# 4 -0.317095 -0.220606 -2.127907  0.626812
# 5 -0.795980  0.103736  2.307983 -0.135649
# 6  0.177584  1.617713  0.586867  0.010041
# 7 -0.699434  0.956211  0.881476  1.907259
# 8  1.758003  0.401241 -0.149460 -0.119145
# 9  1.830858 -0.634444  0.880763  1.576691

# %%
(df == df1).all().all()
# Out:
# True

# %%
left = pd.DataFrame({'key':['foo','foo'],'lval':[1,2]})
right = pd.DataFrame({'key':['foo','foo'],'rval':[4,5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left,right,on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
s = pd.DataFrame(np.random.randn(1,4),columns=list('ABCD'))
s
# Out:
#           A         B        C        D
# 0  0.084569 -0.307324  0.33772 -2.22752

# %%
# 插入一行
# pd.concat([df,s],ignore_index=True)
df.append(s,ignore_index=True)
# Out:
#            A         B         C         D
# 0  -0.137303  1.171769  0.274573  0.399917
# 1   1.173580 -1.060993 -0.677838  1.043599
# 2  -0.528126 -1.703482  0.571849  1.145503
# 3   0.250318 -0.379541  0.696846  0.017463
# 4  -0.317095 -0.220606 -2.127907  0.626812
# 5  -0.795980  0.103736  2.307983 -0.135649
# 6   0.177584  1.617713  0.586867  0.010041
# 7  -0.699434  0.956211  0.881476  1.907259
# 8   1.758003  0.401241 -0.149460 -0.119145
# 9   1.830858 -0.634444  0.880763  1.576691
# 10  0.084569 -0.307324  0.337720 -2.227520

# %%
# 数据分组
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                   'B' : ['one', 'one', 'two', 'three',
                          'two', 'two', 'one', 'three'],
                   'C' : np.random.randn(8),
                   'D' : np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one -0.513512 -0.243664
# 1  bar    one  1.157795 -0.758404
# 2  foo    two -0.889564 -0.028780
# 3  bar  three  0.314779  0.254278
# 4  foo    two -1.393181 -2.682431
# 5  bar    two  0.160997  0.438098
# 6  foo    one -0.941680 -1.182166
# 7  foo  three  0.512489 -0.792524

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  1.633572 -0.066028
# foo -3.225449 -4.929565

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    1.157795 -0.758404
#     three  0.314779  0.254278
#     two    0.160997  0.438098
# foo one   -1.455192 -1.425830
#     three  0.512489 -0.792524
#     two   -2.282745 -2.711212

# %%
df.groupby(['B','A']).sum()
# Out:
#                   C         D
# B     A
# one   bar  1.157795 -0.758404
#       foo -1.455192 -1.425830
# three bar  0.314779  0.254278
#       foo  0.512489 -0.792524
# two   bar  0.160997  0.438098
#       foo -2.282745 -2.711212
