# %% [markdown]
# # 场外基金买卖（风险平价资产配置）

# %% [markdown]
# 优矿的大多数策略是针对股票或期权的，对基金分析不多，场外基金买卖更少。但是优矿其实有丰富的场外基金数据。为模拟场外基金买卖，我尝试做了一个场外基金买卖策略。
# 策略标的是两个比较好的场外基金，以及黄金ETF、纳斯达克ETF，通过风险平价模型进行资产配置，每年调仓一次。感觉几年下来的收益其实还不错，关键是回撤小。
#
# 场外基金买卖最大的问题是，申购、赎回的结果不是立即体现的，即：申购后过几天才能查到申购成功，赎回后过几天资金才能到账。因此无法在一天内完成调仓。
# 策略是每年6月买卖的，分为几步：
# 首先是第一次买入时，直接申购，并记录状态为申购中。
# 然后每天监测申购状态，如果都买到了状态为满仓。
# 第二年调仓时，先提交赎回，状态为赎回中。
# 然后监测赎回状态，如果都卖完了，状态为空仓。第二天又可以执行申购。

# %% [markdown]
# # 风险平价计算

# %%
#coding=utf-8

import pandas as pd 
import numpy as np 
import scipy.optimize as sco
import seaborn as sns
import matplotlib.pyplot as plt
'''
风险平价计算
'''
def portfolio_optimize(ret_mat,cov_shrink=True,method='risk_parity',max_weight=0.4):
    
    #计算时间窗口长度，取1/4作为加权计算依据。
    T=len(ret_mat)
    t=int(T/4)
    
    #用日收益均值计算年化收益期望。
    exp_ret=ret_mat.mean()*252
    ret_mat=ret_mat.dropna()
    #print(ret_mat)
    #不加权计算协方差
    if cov_shrink==False:
        cov_mat=ret_mat.cov()*252
    #加权计算协方差。
    if cov_shrink==True:
        cov_mat=252*(ret_mat.iloc[:t].cov()*0.1+ret_mat.iloc[t+1:2*t].cov()*0.2
                     +ret_mat.iloc[2*t+1:3*t].cov()*0.3+ret_mat.iloc[3*t:].cov()*0.4)
    #print(cov_mat)
    
    #生成权重序列。初始为[1/k,1/k....1/k]共k个
    k=len(ret_mat.columns)
    if k!=len(cov_mat.columns):
        print(ret_mat,cov_mat)
    weights=np.array(k*[1/float(k)])
    #print(weights)
    #指定计算方程
    def risk_parity(weights):
        #weights向量乘以cov_mat矩阵
        risk_vector=np.dot(weights,cov_mat)
        #计算边际风险
        marginal_risk=weights*risk_vector/np.sqrt(np.dot(weights.T,np.dot(cov_mat,weights)))
        #计算各标的的风险贡献
        TRC=[np.sum((i-marginal_risk)**2) for i in marginal_risk]
        return np.sum(TRC)
    
    #设置范围条件。0,0.3表示每一标的的权重在0-30%之间。
    bnds=tuple((0,max_weight) for x in range(k))
    cons = ({'type':'eq', 'fun': lambda x: sum(x) - 1})
    #计算权重，使总风险最低。
    if method=='risk_parity':
        result=sco.minimize(risk_parity,weights,bounds=bnds,constraints=cons,method='SLSQP')
        
    optimal_weights=pd.Series(index=cov_mat.index,data=result['x'])
    
    return optimal_weights
import pandas as pd
def risk_banlance(start_date,end_date,assets,max_weight,tp='fund'):
    ret_result=pd.DataFrame()
    for asset in assets:
        ret=DataAPI.FundNavGet(secID=asset,beginDate=start_date,endDate=end_date,field=u"endDate,adjNavChgPct",pandas="1")
        ret=ret.set_index(keys='endDate')
        ret.columns=[asset]
        #print(ret)
        if len(ret_result)==0:
            ret_result=ret
        else:
            ret_result=pd.merge(ret_result,ret,left_index=True,right_index=True)
    return portfolio_optimize(ret_result,cov_shrink=True,max_weight=max_weight)


'''
输入：
last_day:datetime,由context.previous_date获得
delta_day:int.时间长度
输出：
start_day,end_day:str，格式：20200101
'''
from datetime import datetime
from datetime import timedelta
def cal_date_window(last_day,delta_day):
    previous_date = last_day.strftime('%Y-%m-%d')
    end_day=last_day.strftime('%Y%m%d')
    delta_day=timedelta(days=60)#计算波动率的日期窗口
    dt_start_day=last_day -delta_day
    start_day=datetime.strftime(dt_start_day,'%Y%m%d')
    return start_day,end_day

# %% [markdown]
# # 基金申购赎回程序

# %% [raw]
# from datetime import datetime
# start = '2016-06-01'                       # 回测起始时间
# end = '2020-10-05'                         # 回测结束时间
# universe = ['040040.OFCN','100066.OFCN','110037.OFCN','161726.OFCN','519736.OFCN','162605.OFCN','110020.OFCN','110011.OFCN',
#             '000834.OFCN','000217.OFCN']
# benchmark = '399006.ZICN'                        # 策略参考标准
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                         # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# capital_base = 10000
# commission = Commission(buycost=0.001, sellcost=0.002, unit='perValue')
#
# accounts = {
#     'otc_fund_account': AccountConfig(account_type='otc_fund', capital_base=capital_base, commission=commission)
# }
#
# def initialize(context):
#     account = context.get_account('otc_fund_account')
#     account.buy_status='空仓'                                #全局变量。状态有：空仓、满仓、申购中，赎回中。
#     account.buy_date=datetime.strptime(start,'%Y-%m-%d')      #记录上次买入时间
#     account.roll_type='year'             #调仓周期，可以是month，year。建议不要每月调仓，因为空仓时间会比较长。
#
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     #最大权重
#     max_weight=0.4
#     account = context.get_account('otc_fund_account')
#     current_position = account.get_positions()
#     #print(account.buy_status)
#     #用于计算权重的核心基金,分别是债券，沪深300，纳斯达克，黄金
#     assets=['519736.OFCN','110011.OFCN','110020.OFCN','000834.OFCN','000217.OFCN']#'040040.OFCN',
#     #判断是否该调仓
#     to_roll=False
#     if account.roll_type=='year' and context.current_date.year<>account.buy_date.year:
#         to_roll=True
#     if account.roll_type=='month' and context.current_date.month<>account.buy_date.month:
#         to_roll=True
#     if context.previous_date.month==6:#每年6月调仓
#         if account.buy_status=='空仓':
#             #计算样本时间窗口
#             previous_date = context.previous_date.strftime('%Y-%m-%d')
#             start_day,end_day=cal_date_window(context.previous_date,120)
#             #计算单个标的权重
#             weights=risk_banlance(start_day,end_day,assets,max_weight)
#             print(weights)
#             # 获取当前账户信息
#             account = context.get_account('otc_fund_account')
#             current_position = account.get_positions()
#             current_value=account.portfolio_value
#             # 买入
#             for fund in assets:
#                 nav_day_df = context.history(symbol=fund, attribute="nav", time_range=1, freq='1d')
#                 p=nav_day_df[fund]['nav'].values[0]
#                 amount=current_value*weights[fund]/p
#                 account.purchase(fund,amount)
#             account.buy_status='申购中'
#             account.buy_date=context.current_date
#         if account.buy_status=='申购中':
#             #判断是否买完
#             if len(current_position.keys())==len(assets):
#                 account.buy_status='满仓'
#         if account.buy_status=='满仓' and to_roll==True:
#             #卖出
#             for fund in current_position.keys():
#                 amount=current_position[fund].amount
#                 account.redeem(fund,amount)
#             account.buy_status='赎回中'
#         if account.buy_status=='赎回中':
#             #判断是否卖完
#             current_position = account.get_positions()
#             #print(current_position.keys())
#             if len(current_position.keys())==0:
#                 account.buy_status='空仓'
