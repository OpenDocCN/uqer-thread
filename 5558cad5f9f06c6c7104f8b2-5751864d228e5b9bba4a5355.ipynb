# %% [markdown]
# # 菜鸟学飞——追涨杀跌

# %% [markdown]
# 策略
# ------------------------
# ***
#
# - **投资域** ：沪深300成分股
# - **业绩基准** ：沪深300指数
# - **调仓频率** ：每个交易日
# - **开仓信号** ：比前一日上涨
# - **清仓信号** ：比前一日下跌
# - **买入方式** ：等额买入
# - **回测周期** ：2014年整年

# %% [raw]
# start = '2014-01-01'                       # 回测起始时间
# end = '2014-12-31'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe  = set_universe('HS300')               # 证券池，回测支持股票和基金
# capital_base = 1000000                      # 起始资金
# refresh_rate = 1                           # 调仓频率，即每 refresh_rate 个交易日执行一次 handle_data() 函数
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):
#     hist = account.get_attribute_history('closePrice', 2)
#     cash = account.cash
#     today = account.current_date
#     sell = []
#     buy = []
#
#     # 持有股票中下跌的
#     for stock in account.valid_secpos:
#         if hist[stock][-1] < hist[stock][0]:
#             sell.append(stock)
#     # 股票池中上涨的
#     for stock in account.universe:
#         if hist[stock][-1] > hist[stock][0]:
#             buy.append(stock)
#     # 先卖后买
#     if len(stock) > 0:
#         for stock in sell:
#             order_to(stock,0)
#     if len(buy) > 0:
#         for stock in buy:
#             order(stock,cash/len(buy)/hist[stock][-1])    # 等额买入

# %% [markdown]
# **看到结果时的我**
#
# ![cry](http://y0.ifengimg.com/news_spider/dci_2012/03/13ac0394948e2add9b6f02eaf67cef46.jpg)
