# %% [markdown]
# # 小白初学一百问之第五问=螺纹钢的快熊走完了嘛

# %% [markdown]
# 主要是学着https://uqer.datayes.com/community/share/5541f07af9f06c1c3d687ffa抄了一份。。谢谢大神

# %%
from matplotlib import pylab
import numpy as np
import pandas as pd
import DataAPI
import seaborn as sns
from matplotlib import pyplot as plt
import datetime as dt
import seaborn as sns
sns.set_style('white')
from matplotlib import pyplot as plt
from CAL.PyCAL import *
font.set_size(20)
old=DataAPI.MktMFutdGet(tradeDate=u"",mainCon="1",contractMark=u"",contractObject="rb",startDate="20090414",endDate="20091012",field=['closePrice','tradeDate'],pandas="1")
new=DataAPI.MktMFutdGet(tradeDate=u"",mainCon="1",contractMark=u"",contractObject="rb",startDate="20151218",endDate=u"",field=['closePrice'],pandas="1")
old=old.set_index('tradeDate')
old['tradeIndex']=np.nan
old['tradeIndex'][:len(new.closePrice.values)] = new.closePrice.values
old.plot(grid=True, figsize=(12,8))
plt.legend([u'09年牛市', u'16年牛市'], prop = font, loc = 'best')
sns.despine()
