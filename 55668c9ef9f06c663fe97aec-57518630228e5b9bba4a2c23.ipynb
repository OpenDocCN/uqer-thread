# %% [markdown]
# # Reference Return验证

# %% [raw]
# start = '2006-01-01'                       # 回测起始时间
# end = '2015-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['000630.XSHE', '600000.XSHG']  # 证券池，回测支持股票和基金
# capital_base = 100000                      # 起始资金
# refresh_rate = 1                           # 调仓频率，即每 refresh_rate 个交易日执行一次 handle_data() 函数
#
# def initialize(account):                   # 初始化虚拟账户状态
#     account.previous_price = {}
#     account.days = 0
#
# def handle_data(account):  # 每个交易日的买入卖出指令
#     for stk in account.universe :
#         if account.days!= 0:
#             print u"日期：%s,  股票：%s, 期望：%.5f, 计算：%.5f "% (account.current_date, stk, account.referenceReturn[stk], (account.referencePrice[stk] - account.previous_price[stk]) / account.previous_price[stk])
#         account.previous_price[stk] = account.referencePrice[stk]
#     account.days += 1
