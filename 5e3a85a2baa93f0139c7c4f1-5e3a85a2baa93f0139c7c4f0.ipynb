# %% [markdown]
# # 神奇公式PB+ROA

# %% [raw]
# start = '2015-01-11' #回测开始时间
# end = '2019-12-31'  # 回测结束时间
# benchmark = "HS300"                  # 策略对标标的
# universe = set_universe('HS300')
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate =60                          # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# commission = Commission(buycost=0.0003, sellcost=0.0013, unit='perValue')
# max_history_window = 1                 #设定调取历史价格区间最大为100个交易日
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     data = DataAPI.MktStockFactorsOneDayGet(tradeDate=account.previous_date,secID=universe,field=u"secID,tradeDate,pb,roa,DebtsAssetRatio",pandas="1")
#     data = data.set_index('secID')
#     data = data.dropna()
#
#     data_PB = data[data['PB']>0 ]
#     # data_PE = data_PE[data_PE['DebtsAssetRatio']<0.65] # 负债率小于0.65
#     data_PB = data_PB.sort('PB',ascending=True)        # pe升序排列
#     data_PB['PB_sort'] = range(0,len(data_PB))         #给PE排列标记排名
#
#     data_ROA = data_PB[data_PB['ROA']>0 ]           # ROE5大于0.1
#     # data_ROE = data_ROE[data_ROE['ROA']>0]          # ROA大于0.1
#     data_ROA = data_ROA.sort('ROA',ascending=False)   # ROE5降序排列
#     data_ROA['ROA_sort'] = range(0,len(data_ROA))      #给ROE5排列标记排名
#     data_ROA['shenqi_sort'] = data_ROA['ROA_sort'] + data_ROA['PB_sort']  #神奇公式排名
#     data_shenqi = data_ROA.sort('shenqi_sort',ascending=True)
#
#     # 取PE最小的10只股票
#     univ = list(data_shenqi.index[:20])
#     print univ
#
#     for s in account.universe:
#         if s in account.avail_security_position:
#             if s not in univ :
#                 account.order_pct_to(s,0)
#         #买股票，每个股票仓位设置为10%
#         if s in univ and s not in account.security_position:
#             account.order_pct_to(s,0.05)
