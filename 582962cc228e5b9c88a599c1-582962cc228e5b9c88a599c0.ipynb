# %% [markdown]
# #

# %% [raw]
# start = '2013-02-04'                       # 回测起始时间
# end = '2016-11-12'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准，沪深300
# universe = ['510300.XSHG','511990.XSHG']  # 证券池，支持股票和基金,华泰柏瑞沪深300ETF
# capital_base = 1000000                       # 起始资金100W
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# #获取年末交易日:isYearEnd,isQuarterEnd,isMonthEnd,isWeekEnd,isOpen
# data = DataAPI.TradeCalGet(exchangeCD=u"XSHG",beginDate=start,endDate=end,field=u"calendarDate,isQuarterEnd",pandas="1")
# data = data[data['isQuarterEnd'] == 1]
# Dates = map(lambda x: x[0:4]+x[5:7]+x[8:10], data['calendarDate'].values.tolist())
# #print Dates
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     for stock in account.universe:
#         #print account.current_date.strftime('%Y%m%d')
#         if account.current_date.strftime('%Y%m%d') == '20130204':#20130201第一次买入
#             if stock == '510300.XSHG':
#                 order_pct_to(stock,0.75)#股债平衡75%股
#             if stock == '511990.XSHG':
#                 order_pct_to(stock,0.25)#股债平衡25%债
#         if account.current_date.strftime('%Y%m%d') in Dates:#调仓时间，年末，季度末，月末，周末
#             if stock == '510300.XSHG':
#                 order_pct_to(stock,0.75)#股债平衡75%股
#             if stock == '511990.XSHG':
#                 order_pct_to(stock,0.25)#股债平衡25%债
#     return
