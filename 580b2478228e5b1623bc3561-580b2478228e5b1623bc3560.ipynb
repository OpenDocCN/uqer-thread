# %% [markdown]
# #

# %%
a=DataAPI.MktStockFactorsOneDayGet(tradeDate='20160222',secID='',field=['secID','PE','PB'])
a=a.dropna()    
i=0
for pe, pb in zip(a['PE'].values, a['PB'].values):
    pe=round(pe)
    pb=round(pb)
    a.loc[i,'PE*PB']= abs(pe*pb)
    i=i+1

a=a.dropna() 
a
# Out:
#             secID         PE        PB      PE*PB
# 0     000001.XSHE     6.7391    0.9370        7.0
# 1     000002.XSHE    16.7073    3.0327       51.0
# 2     000004.XSHE   230.5896   32.7356     7623.0
# 3     000005.XSHE   189.6083   13.4162     2470.0
# 4     000006.XSHE    21.6641    2.7780       66.0
# 5     000007.XSHE  -156.2218   16.1041     2496.0
# 6     000008.XSHE   252.6359    8.4128     2024.0
# 7     000009.XSHE    29.3044    4.7380      145.0
# 8     000010.XSHE  -136.1811   14.3722     1904.0
# 9     000011.XSHE    69.8269    4.9547      350.0
# 10    000012.XSHE    47.2633    3.2528      141.0
# 11    000014.XSHE    88.0973    6.1935      528.0
# 12    000016.XSHE   -14.7803    3.8692       60.0
# 13    000017.XSHE  3843.2621  628.8354  2417247.0
# 14    000018.XSHE   198.9105   26.8430     5373.0
# 15    000019.XSHE   169.6848    6.8683     1190.0
# 16    000020.XSHE   256.7299   22.7397     5911.0
# 17    000021.XSHE    75.6444    2.6935      228.0
# ...
