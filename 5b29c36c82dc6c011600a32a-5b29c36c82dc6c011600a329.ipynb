# %% [markdown]
# # 6月13号作业：条件选股3

# %%
a=DataAPI.MktStockFactorsOneDayGet(tradeDate=u"20150612",secID=u"",ticker=u"",field=u"ticker,tradeDate,PE,ROE",pandas="1")
b=a[((a.PE)<50)&((a.PE)>20)&(a.ROE>0.20)&(a.ROE<0.50)]
c=b.head(10)
d=c['ticker']
print d
# Out:
# 9      000011
# 73     000400
# 92     000423
# 134    000538
# 136    000540
# 148    000553
# 236    000671
# 317    000786
# 360    000848
# 389    000895
# Name: ticker, dtype: object

# %%
a1=DataAPI.EquRetudGet(secID=u"",ticker=u"000011",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
r1=a1.cumsum().iloc[-1,-1]
print r1
a2=DataAPI.EquRetudGet(secID=u"",ticker=u"000400",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
r2=a2.cumsum().iloc[-1,-1]
print r2
a3=DataAPI.EquRetudGet(secID=u"",ticker=u"000423",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
r3=a3.cumsum().iloc[-1,-1]
print r3
a4=DataAPI.EquRetudGet(secID=u"",ticker=u"000538",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
r4=a4.cumsum().iloc[-1,-1]
print r4
a5=DataAPI.EquRetudGet(secID=u"",ticker=u"000540",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
r5=a5.cumsum().iloc[-1,-1]
print r5
a6=DataAPI.EquRetudGet(secID=u"",ticker=u"000553",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
r6=a6.cumsum().iloc[-1,-1]
print r6
a7=DataAPI.EquRetudGet(secID=u"",ticker=u"000671",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
r7=a7.cumsum().iloc[-1,-1]
print r7
a8=DataAPI.EquRetudGet(secID=u"",ticker=u"000786",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
r8=a8.cumsum().iloc[-1,-1]
print r8
a9=DataAPI.EquRetudGet(secID=u"",ticker=u"000848",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
r9=a9.cumsum().iloc[-1,-1]
print r9
a10=DataAPI.EquRetudGet(secID=u"",ticker=u"000895",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
r10=a10.cumsum().iloc[-1,-1]
print r10
print ''
print '组合年化收益:'
print (r1+r2+r3+r4+r5+r6+r7+r8+r9+r10)/10
# Out:
# -0.022696
# -0.277805
# 0.155173
# 0.331262
# 0.111717
# 0.1244
# 0.410643
# 0.914279
# -0.103037
# 0.317394
#
# 组合年化收益:
# 0.196133
