# %% [markdown]
# # Zura论文附录中WorldQuant的Alpha#42

# %% [markdown]
# **Alpha#42**
# $$(rank((vwap - close)) / rank((vwap + close)))$$
#
# 从分子上看vwap - close越大越好，从分母上看价格越低越好；但价格越高波动的幅度也通常越大，即价格高的股票，vwap - close也会更大。

# %% [raw]
# import numpy as np
# import pandas as pd
# start = '2013-01-01'                       # 回测起始时间
# end = '2016-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')  # 证券池，支持股票和基金
# capital_base = 1000000                      # 起始资金
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 241                        # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     closeprice_m = account.get_attribute_history('closePrice',240)
#     turnover_m = account.get_attribute_history('turnoverVol',240)
#     closeprice_m =  pd.DataFrame(closeprice_m)
#     turnover_m = pd.DataFrame(turnover_m)
#
#     vwap = turnover_m / turnover_m.sum() * closeprice_m
#     vwap = vwap.sum()
#     numerator = vwap - closeprice_m.ix[len(closeprice_m)-1]
#     denominator = vwap + closeprice_m.ix[len(closeprice_m)-1]
#     alpha_42 = numerator.rank() / denominator.rank()
#     alpha_42 = alpha_42.dropna()
#     weight = alpha_42 / alpha_42.sum()
#
#     buylist = weight.index
#     total_money = account.referencePortfolioValue
#     prices = account.referencePrice
#
#     for stk in account.valid_secpos:
#         if stk not in buylist:
#             order_to(stk, 0)
#
#     for stk in buylist:
#         if stk not in prices:
#             continue
#         if np.isnan(prices[stk]) or prices[stk] == 0:  # 停牌或是还没有上市等原因不能交易
#             continue
#
#         order_num = int(total_money * weight.ix[stk] / prices[stk] /100)*100
#         if order_num < 100:
#             order_num = 100
#         order_to(stk, order_num)
