# %% [markdown]
# # Notebook

# %% [raw]
# import pandas as pd
#
# start = '2019-01-03'                       # 回测起始时间
# end = '2019-01-03'                         # 回测结束时间
# universe = ['IFL0']        # 当月,次月,当季,次季, IF可替换成IC\IH
# benchmark = 'HS300'                        # 策略参考标准, 建议IF用HS300, IC用ZZ500, IH用SZ50
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# max_history_window = 2640
# pd.options.display.max_rows = 100
# buycost = 0.00023
# dailyearn = 0.00017
#
# accounts = {
# 	'futures_account': AccountConfig(account_type='futures', capital_base=20000000, commission = Commission(buycost=buycost, sellcost=0.000, unit='perValue'), slippage = Slippage(value=0.000, unit='perValue'))
# }                                           #设置初始账户为期货型账户, 初始资金2000万, 交易成本设置买入成本2.3%%, 无其他成本
# date = []
# asset = []
# def initialize(context):
#     pass
#
# # 每个单位时间(如果按天回测,则每天调用一次,如果按分钟,则每分钟调用一次)调用一次
# def handle_data(context):
#     futu_account = context.get_account('futures_account')
#     current_universe = context.get_universe(exclude_halt=1)
#     current_date = context.current_date.strftime('%Y-%m-%d')
#     current_min = context.current_minute
#     c = futu_account.portfolio_value
#     target_r = 0.0005
#     if current_date == '2019-01-03' and current_min == '13:30':
#         IFL0_current_month = context.get_symbol('IFL0')
#         IFL0_price = context.current_price(IFL0_current_month)
#         IFL0_multiplier = get_asset(IFL0_current_month).multiplier
#         IFL0_amount = int(c / IFL0_price / IFL0_multiplier * 0.2)
#         print (current_date,current_min,'openlong',IFL0_current_month,IFL0_amount,(1-target_r)*IFL0_price)
#         futu_account.order(IFL0_current_month,IFL0_amount,'open',(1-target_r)*IFL0_price,'limit')
#     if current_date == '2019-01-03' and current_min == '13:59':
#         hist = context.history(current_universe, ['closePrice','highPrice','lowPrice'], time_range=60, freq='m')['IFL0']
#         print (hist)
