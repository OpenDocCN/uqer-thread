# %% [markdown]
# # 某一公司在一区间的涨跌幅

# %%
df=DataAPI.MktEqudGet(secID=u"",ticker=u"601857",tradeDate=u"",beginDate=u"20130101",endDate=u"20151231",isOpen="",field=u"ticker,tradeDate,closePrice",pandas="1").pivot(index='tradeDate',columns='ticker',values='closePrice')#根据题目具体要求填入公司代码，开始日期与结束日期，以茅台2015年涨跌幅为例
a=df.iloc[-1]/df.iloc[0]-1
print '中国石油在2013-2015年涨跌幅为'
print a.values
# Out:
# 中国石油在2013-2015年涨跌幅为
# [-0.07734807]
