# %% [markdown]
# #

# %% [raw]
# #量价上穿30均线达2%时进行3天短线操作。没啥用，练着玩
# #参考神作：https://uqer.datayes.com/community/share/554051bbf9f06c1c3d687fac
# import numpy as np
# import pandas as pd
# import DataAPI
# import time
# import datetime
# from CAL.PyCAL import *
# pd.set_option('display.width', 400)
#
# cal = Calendar('China.SSE')
# period1 = Period('1B')
# start = '2016-06-15'                       # 回测起始时间
# end = '2016-09-15'                         # 回测结束时间
#
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')           # 证券池，支持股票和基金
# #universe = ['600031.XSHG']
# capital_base = 100000     # 起始资金
#
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 3                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# window_short=refresh_rate                 #3个交易日短期
# period120 = Period('-30B')                #30个交易日长线
# SD = 0.02                                 #短期均线比长期均线增幅3%
#
# def initialize(account):					# 初始化虚拟账户状态
#     pass
#
# def handle_data(account):             # 每个交易日的买入卖出指令
#     yesterday = Date.fromDateTime(account.previous_date)
#     aendDate= yesterday.strftime("%Y%m%d")
#     day120 = cal.advanceDate(yesterday,period120)
#     abeginDate = day120.strftime("%Y%m%d")
#     fields="tradeDate,secID,closePrice,turnoverVol"
#     buy_list=[]
#     #print '%s %s %s'%(account.universe[0],abeginDate,endDate)
#     for asecID in account.universe:
#         security=DataAPI.MktEqudGet(secID=asecID,beginDate=abeginDate,endDate=aendDate,isOpen='1',field=fields,pandas="1")
#         short_Df=security[-window_short:]
#         short_mean_p = np.mean(short_Df.closePrice) # 计算收盘价短均线值
#         long_mean_p  = np.mean(security.closePrice)   #计算收盘价长均线值
#         short_mean_t = np.mean(short_Df.turnoverVol) # 计算成交量短均线值
#         long_mean_t  = np.mean(security.turnoverVol)   #计算成交量长均线值
#         # 计算买入卖出信号
#         flag_p = True if (short_mean_p - long_mean_p) >= SD * long_mean_p else False
#         flag_t = True if (short_mean_t - long_mean_t) >= SD * long_mean_t else False
#         if flag_p & flag_t:
#             buy_list.append(asecID)
#         #print security.info()
#         #print security.head()
#         #print security[-3:-1]
#         #print security.describe()
#         #print '股价120日均值：%f 股价%d日均值：%f 成交量120日均值：%f 成交量%d日均值：%f'%(long_mean_p,window_short,short_mean_p,long_mean_t,window_short,short_mean_t)
#         #break;
#
#
#     # 卖出时，全仓清空
#     for stk in account.security_position:
#         if stk not in buy_list:#持仓判断
#             order_to(stk, 0)
#     # 买入
#     today = Date.fromDateTime(account.current_date)
#     todayStr= today.strftime("%Y-%m-%d")
#     print '%s-%s 合格数量%d 交易日%s' %(abeginDate,aendDate,len(buy_list),todayStr)
#     for bstk in buy_list:
#         # 空仓时全仓买入，买入股数为100的整数倍
#         #approximationAmount = int(account.cash / item[1]['closePrice'][-1]/100.0) * 100
#         order(bstk, 2000)
