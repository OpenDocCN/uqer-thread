# %% [markdown]
# #

# %% [raw]
# from datetime import timedelta, datetime
# from CAL.PyCAL import *
# cal = Calendar('China.SSE')
# import numpy as np
# import pandas as pd
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                          # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# universe = ['510050.XSHG','159923.XSHE','159901.XSHE', '159902.XSHE']
# start = '2014-1-1'                       # 回测起始时间
# end = '2016-8-10'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# from matplotlib import pylab
# import seaborn as sns
# commission = Commission(buycost=0.0015, sellcost=0.0015)
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     monthago = cal.advanceDate(account.current_date, '-22B', BizDayConvention.Following)
#     yesterday = cal.advanceDate(account.current_date, '-1B', BizDayConvention.Following)
#     zzda=DataAPI.MktIdxdGet(indexID="000903.ZICN",beginDate=monthago.strftime("%Y%m%d"),\
# endDate=yesterday.strftime("%Y%m%d"),field="closeIndex",pandas="1")
#     zzdaa=(zzda['closeIndex'][21]+zzda['closeIndex'][20])/2
#     zzdat=(zzda['closeIndex'][0]+zzda['closeIndex'][1])/2
#     zzxiao=DataAPI.MktIdxdGet(indexID="000907.ZICN",beginDate=monthago.strftime("%Y%m%d"),\
# endDate=yesterday.strftime("%Y%m%d"),field="closeIndex",pandas="1")
#     zzxiaoa=(zzxiao['closeIndex'][21]+zzxiao['closeIndex'][20])/2
#     zzxiaot=(zzxiao['closeIndex'][0]+zzxiao['closeIndex'][1])/2
#     zzda_return = ((zzdaa - zzdat)/zzdat)
#     zzxiao_return = ((zzxiaoa - zzxiaot)/zzxiaot)
#     chooseb = max(zzda_return,zzxiao_return,-0.01)
#     if chooseb == -0.01:
#         for stock in account.valid_secpos.keys():
#             order_to(stock, 0)
#     elif chooseb ==zzda_return:
#         if "159923.XSHE" not in account.valid_secpos.keys():
#             for stock in account.valid_secpos.keys():
#                 order_to(stock, 0)
#             order_pct("159923.XSHE",0.5)
#             order_pct("510050.XSHG",0.5)
#     elif chooseb ==zzxiao_return:
#         if "159902.XSHE" not in account.valid_secpos.keys():
#             for stock in account.valid_secpos.keys():
#                 order_to(stock, 0)
#             order_pct("159902.XSHE" ,0.5)
#             order_pct("159901.XSHE" ,0.5)
#
# bt,acct=quartz.backtest(start=start,
#             end=end,
#             benchmark=benchmark,
#             universe=universe,
#             capital_base=capital_base,
#             initialize=initialize,
#             handle_data=handle_data,
#             refresh_rate=refresh_rate)
#
# perf=quartz.perf_parse(bt,acct)
#
# out_keys=['annualized_return','volatility','information_ratio',
#     'sharpe','max_drawdown','alpha','beta']
#
# for k in out_keys:
#     print'%s:%s'%(k,perf[k])
#
# perf['cumulative_returns'].plot()
# perf['benchmark_cumulative_returns'].plot()
# pylab.legend(['current_strategy','HS300'])
