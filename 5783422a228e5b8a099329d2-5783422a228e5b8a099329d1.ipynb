# %% [markdown]
# #

# %% [markdown]
# 我最近在做测试的时候，翻看调仓记录，发现自己设置的`买卖仓位`没有按照预期的执行

# %% [markdown]
# 下面用最简单的模板试了一下，就选2支股票，20日调仓，如果有订单，就全平，然后再买回来。
# 结果是奇数月买入正常的，偶数月就买了一点点。

# %% [raw]
# start = '2014-01-01'                       # 回测起始时间
# end = '2015-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['000001.XSHE', '600000.XSHG']  # 证券池，支持股票和基金
# capital_base = 1000000                     # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 20                          # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     #先把手上的订单全部清仓
#     for stock in account.valid_secpos.keys():
#         order_to(stock,0)
#
#
#     #再把股票买回来，买入百分比是0.95/一共多少支股票。如果2支，每支就是42.5%。
#     #看图形也可以看出，有几段时间走势相当平滑，说明买入的数量不对
#     for stock in account.universe:
#         order_pct_to(stock,0.95/len(account.universe))

# %% [markdown]
# 为什么会出现这样的情况。
# 如果是这样，那么我之前写的好多策略都是错的！懵逼了啊
