# %% [markdown]
# # 前一天信息暴露研究（2012-2018）

# %%
import numpy as  np
import scipy as sp
import pandas as pd
import datetime
from CAL.PyCAL import *
import os

# 股票池文件存放目录，如果目录不存在，程序自动新建一个
raw_data_dir = "./FR_factor"
if not os.path.exists(raw_data_dir):
    os.mkdir(raw_data_dir)

# %%
#定义几个需要的函数：

#定义时间转换函数  将日期由2018-03-12 转化为20180312
def time_change(x):
    y = datetime.datetime.strptime(x,'%Y-%m-%d')
    z = y.strftime('%Y%m%d')
    return z
#time_change('2018-09-23')

# 定义获取所有交易日历，月末一天，月初一天的list函数
def get_trade_list(start_date,end_date):
    cal = Calendar('China.SSE')
    all_day = DataAPI.TradeCalGet(exchangeCD=u"XSHG",beginDate=start_date,endDate=end_date,\
                                  isOpen=u"1",field=u"calendarDate,isOpen,isMonthEnd",pandas="1")
    
    #获取所有的交易日历 trade_list (list型)
    trade_list = all_day[all_day['isOpen']==1]['calendarDate'].tolist()
    trade_list = [time_change(x) for x in trade_list]
    
    #获取所有的交易月末最后一天 month_end (list型)
    month_end = all_day[all_day['isMonthEnd']==1]['calendarDate'].tolist()
    month_end = [time_change(x) for x in month_end]
    
    #获取所有的交易月初第一天  month_start (list型)
    month_start = [cal.advanceDate(x,'1B') for x in month_end]
    month_start = [x.strftime('%Y%m%d') for x in month_start]
    
    return trade_list,month_end,month_start

#get_trade_list('20071220','20180601')

#定义函数去掉ST股票
def st_remove(source_universe,st_date =None):
    st_date = st_date if st_date is not None else datetime.datetime.now().strftime('%Y%m%d')
    st_secid = DataAPI.SecSTGet(beginDate=st_date,endDate=st_date,secID=source_universe,field=u"secID",pandas="1")
    return [x for x in source_universe if x not in list(st_secid['secID'])]

#定义函数去掉新股  ticker为6位数值，没有后缀  注意日期之间的比较
def new_remove(ticker,trade_date =None,day=20):
    
    trade_date = trade_date if trade_date is not None else datetime.datetime.now().strftime('%Y%m%d')
    
    cal = Calendar('China.SSE')
    sta_date = cal.advanceDate(trade_date,str(str(day*(-1))+'B')).strftime('%Y-%m-%d')
    
    new_ticker = DataAPI.SecIDGet(assetClass=u"e",ticker = ticker,field=u"ticker,listDate",pandas="1")
    new_ticker=new_ticker[new_ticker['listDate']>sta_date]['ticker'].tolist()
    
    return [x for x in ticker if x not in new_ticker]


#将ticker转化为函数内部编码
def ticker2secID(ticker):
    
    #DateFrame生成字典的方式，标准
    all_a = DataAPI.EquGet(equTypeCD=u"A",field=u"secID,ticker",listStatusCD='L,S,DE,UN',pandas="1")
    all_a_dict = dict(all_a.set_index(all_a['ticker'])['secID'])
    
    if isinstance(ticker,list):
        secID_list = []
        for i in ticker:
            if i in all_a_dict.keys():
                secID_list.append(all_a_dict[i])
            else:
                print(str(i)+'不在字典中')
            
    else:
        print('输入的不是list形式')
    return secID_list

#定义函数，获取每月月初的股票代码，作为以后进行研究的股票代码基础
def get_stock_pool(date,n):  #date  每一个月月初的日期  n 界定新股时候的参数
    #该函数的目的为获得每个月第一个交易日的股票代码，加上那个日期，构成DF
    
    univ = DynamicUniverse('A')
    code = univ.preview(date,skip_halted='False') #返回list  
    code = st_remove(code,st_date =date)  #去掉ST
    code = [x[0:6] for x in code]  # 代码去掉后缀
    code = new_remove(code,trade_date =date,day=n)  #去掉新股
    code = ticker2secID(code) #加上后缀
    code_df = pd.DataFrame(dict({'code':code}))  # list 转化为字典  再转化为DF
    code_df['date']=date
    code_df = code_df[['date','code']]
    return code_df  # 为df形式

# %%
#获得整个研究区间每个月月初所有的股票
start_date = '20071220'
end_date = '20180601'
trade_list,month_end,month_start = get_trade_list(start_date,end_date)
n=180
all_stock = pd.DataFrame()
for date in month_start:
    stock = get_stock_pool(date,n)
    all_stock = pd.concat([all_stock,stock],axis = 0)
    #if i>'20150602':
    #   break
all_stock.head()
# Out:
#        date         code
# 0  20080102  600687.XSHG
# 1  20080102  600387.XSHG
# 2  20080102  600769.XSHG
# 3  20080102  600393.XSHG
# 4  20080102  000988.XSHE

# %%
all_stock.to_csv('FR_factor/stock_pool.csv', index=False)

# %%
#获取整个研究期间所有交易日的股票代码的日换手率以及涨跌幅
all_code = sorted(list(set(list(all_stock['code']))))
mkt_info_frame = DataAPI.MktEqudGet(secID=all_code,beginDate=u"20071220",endDate=u"20180601",isOpen=1,\
                                    field=u"tradeDate,secID,chgPct,turnoverRate",pandas="1")
mkt_info_frame['tradeDate']=map(time_change,mkt_info_frame['tradeDate'])
mkt_info_frame.columns = ['tradeDate','code','ret','to']
mkt_info_frame.head()
# Out:
#   tradeDate         code     ret      to
# 0  20071220  000001.XSHE  0.0274  0.0117
# 1  20071221  000001.XSHE  0.0014  0.0187
# 2  20071224  000001.XSHE  0.0354  0.0154
# 3  20071225  000001.XSHE  0.0000  0.0119
# 4  20071226  000001.XSHE -0.0092  0.0106

# %%
mkt_info_frame = mkt_info_frame.dropna()

# %%
# 构造下一个月的收益率以及三个因子
all_signal = pd.DataFrame()

for i in range(1,len(month_end)):
    
    #先构造下一个月的月度收益率
    #获取几个关键性的日期
    begin = month_start[i-1]  #该月的第一天
    start = month_start[i]    #下一个月的第一天
    end = month_end[i]        # 该月的最后一天
    if i < len(month_end)-1:
        next_end = month_end[i+1]   #下一个月的最后一天
    else:
        next_end = '20180629'
    
    #获取研究改节点的股票代码，下一个月第一天的代码集合
    code = all_stock[all_stock['date']==start]['code'].tolist()
    
    #这个月月底的收盘价  后复权
    inf1 = DataAPI.MktEqudAdjAfGet(secID=code,tradeDate=end,isOpen="",\
                                   field=u"secID,tradeDate,closePrice",pandas="1")
    inf1.columns = ['code','tradeDate1','closePrice1']
    #下一个月月底的收盘价
    inf2 = DataAPI.MktEqudAdjAfGet(secID=code,tradeDate=next_end,isOpen="",\
                                   field=u"secID,tradeDate,closePrice",pandas="1")
    inf2.columns = ['code','tradeDate2','closePrice2']
    
    #两个进行合并
    inf= pd.merge(inf1,inf2,on ='code',how = 'outer')
    inf['month_ret'] = inf['closePrice2']/inf['closePrice1']-1
    inf['date'] = end
    inf = inf[['date','code','month_ret']]  #获得下月的股票月度收益率 日期标记为本月最后一天
    
    #构造三个因子
    period_frame = mkt_info_frame[(mkt_info_frame['tradeDate']>=begin)&(mkt_info_frame['tradeDate']<=end)]
    period_frame = period_frame[period_frame['code'].isin(code)]  #.isin()的用法
    period_frame['next_return']  = period_frame.groupby('code')['ret'].shift(-1)
    period_frame['abs_next_return'] = abs(period_frame['next_return'])
    period_frame = period_frame.dropna()
    
    #FR因子
    trading_date = [x for x in trade_list if x>=begin and x<=end]
    n_days = len(trading_date)/2
    signal_fr = period_frame.groupby('code').apply(lambda df:df['to'].corr(df['abs_next_return'],method = 'pearson',min_periods=n_days))
    
    #FRu因子
    period_frame_positive = period_frame[period_frame['next_return']>0]
    signal_fru = period_frame_positive.groupby('code').apply(lambda df:df['to'].corr(df['next_return'],method = 'pearson',min_periods=5))
    
    #FRd因子
    period_frame_negative = period_frame[period_frame['next_return']<=0]
    signal_frd = period_frame_negative.groupby('code').apply(lambda df:df['to'].corr(df['next_return'],method = 'pearson',min_periods=5))
 
    #联合
    signal = pd.concat([signal_fr,signal_fru],axis = 1)
    signal = pd.concat([signal,signal_frd],axis = 1)
    signal.columns = ['fr','fru','frd']
    signal['code']=signal.index
    signal['date'] = end
    signal = signal[['date','code','fr','fru','frd']]
    signal.sort_values(by='code',inplace = True)
    signal.reset_index(drop = True,inplace=True)
    
    #与inf进行联合
    signal=pd.merge(inf,signal,on=['date','code'],how='right')
    
    all_signal=all_signal.append(signal)
    
all_signal
# Out:
#           date         code  month_ret        fr       fru       frd
# 0     20080131  000031.XSHE   0.007579 -0.437093 -0.622945  0.275552
# 1     20080131  000032.XSHE   0.153532  0.103079  0.558187  0.146952
# 2     20080131  000033.XSHE   0.124607  0.300709  0.344582 -0.311575
# 3     20080131  000039.XSHE   0.056397 -0.098604  0.533287  0.299034
# 4     20080131  000061.XSHE   0.013432 -0.382778 -0.385822  0.448880
# 5     20080131  000065.XSHE   0.092110 -0.150972  0.116040  0.236845
# 6     20080131  000155.XSHE   0.209642 -0.060223  0.177389  0.113608
# 7     20080131  000423.XSHE   0.075997 -0.188127  0.248766  0.783441
# 8     20080131  000515.XSHE   0.151328  0.030294  0.274927  0.119705
# 9     20080131  000541.XSHE   0.034759  0.360639  0.398755 -0.335160
# 10    20080131  000544.XSHE   0.196722 -0.437463 -0.033289  0.566135
# 11    20080131  000546.XSHE  -0.124480  0.284872 -0.105096 -0.468694
# 12    20080131  000551.XSHE   0.178200 -0.312760 -0.184386  0.442790
# 13    20080131  000590.XSHE   0.079997  0.055863 -0.220953 -0.167549
# 14    20080131  000591.XSHE   0.053121 -0.167232 -0.220769  0.275075
# 15    20080131  000593.XSHE   0.134302  0.071697 -0.033878 -0.006055
# 16    20080131  000596.XSHE  -0.045452 -0.064316 -0.370346 -0.023315
# 17    20080131  000669.XSHE   0.188910 -0.203062  0.134913  0.385383
# 18    20080131  000677.XSHE   0.129324  0.092180  0.690569  0.283239
# 19    20080131  000707.XSHE   0.120477 -0.025964  0.612581  0.648148
# 20    20080131  000729.XSHE   0.046427  0.291682  0.659663 -0.256272
# 21    20080131  000760.XSHE   0.038712  0.021947 -0.320946 -0.208922
# 22    20080131  000800.XSHE   0.038641 -0.123622 -0.280295 -0.134211
# 23    20080131  000821.XSHE   0.135222 -0.265905 -0.217509  0.336829
# 24    20080131  000850.XSHE   0.020309  0.241909 -0.029877 -0.431669
# 25    20080131  000852.XSHE   0.172517 -0.255342 -0.082399  0.323843
# 26    20080131  000859.XSHE   0.214378 -0.260043 -0.174558  0.498668
# 27    20080131  000882.XSHE   0.005778 -0.123829 -0.044778  0.339881
# 28    20080131  000901.XSHE   0.128629 -0.037022 -0.219019 -0.026140
# 29    20080131  000988.XSHE   0.151705  0.360655  0.332141 -0.480231
# ...        ...          ...        ...       ...       ...       ...
# 3023  20180531  600191.XSHG  -0.187405 -0.360127 -0.364085  0.369542
# 3024  20180531  600207.XSHG  -0.270674 -0.061868 -0.310280 -0.396031
# 3025  20180531  600215.XSHG  -0.104252  0.178624  0.692881 -0.047212
# 3026  20180531  600216.XSHG  -0.089150 -0.322503 -0.464084  0.316470
# 3027  20180531  600236.XSHG   0.031815 -0.203229 -0.325520  0.140133
# 3028  20180531  600299.XSHG  -0.083313  0.046464 -0.411869 -0.402723
# 3029  20180531  600348.XSHG   0.040759 -0.312089 -0.450227  0.300169
# 3030  20180531  600385.XSHG  -0.126365 -0.162694  0.117964  0.179214
# 3031  20180531  600487.XSHG  -0.058555 -0.113511  0.106229  0.466263
# 3032  20180531  600502.XSHG  -0.156702  0.224269  0.459745 -0.198259
# 3033  20180531  600511.XSHG  -0.040598 -0.102080 -0.244091 -0.061070
# 3034  20180531  600532.XSHG  -0.238923 -0.095794 -0.213903 -0.083381
# 3035  20180531  600570.XSHG  -0.082163 -0.180296  0.319214  0.466389
# 3036  20180531  600581.XSHG   0.199562  0.019672  0.409283  0.121916
# 3037  20180531  600642.XSHG  -0.066925 -0.215603 -0.105603  0.236593
# 3038  20180531  600679.XSHG  -0.127665  0.099487 -0.453229 -0.039410
# 3039  20180531  600765.XSHG  -0.161691  0.036562 -0.223757 -0.345858
# 3040  20180531  600826.XSHG  -0.101331 -0.193140 -0.314699 -0.100897
# 3041  20180531  600857.XSHG  -0.178647  0.048130  0.386949  0.055661
# 3042  20180531  600862.XSHG  -0.210525  0.329051  0.110389 -0.465052
# 3043  20180531  601020.XSHG  -0.114886 -0.247441 -0.493379  0.182811
# 3044  20180531  601166.XSHG  -0.057937  0.108183  0.641585  0.124453
# 3045  20180531  601186.XSHG  -0.059912 -0.071851  0.420257  0.181352
# 3046  20180531  601328.XSHG  -0.046449  0.409391 -0.002478 -0.757530
# 3047  20180531  603015.XSHG  -0.078737 -0.005143 -0.025419 -0.084505
# 3048  20180531  603085.XSHG  -0.088500 -0.029929  0.632624  0.266912
# 3049  20180531  603180.XSHG  -0.110561 -0.093163  0.324913 -0.011690
# 3050  20180531  603266.XSHG  -0.118759 -0.010493 -0.157037 -0.370875
# 3051  20180531  603617.XSHG  -0.161990  0.604214 -0.390664 -0.811524
# 3052  20180531  603833.XSHG  -0.110483  0.038603  0.133351  0.042321
#
# [252771 rows x 6 columns]

# %%
all_signal.to_csv('FR_factor/all_signal.csv', index=True)  # 保存数据，下一次继续使用节约时间

# %%
import pandas as pd
all_signal1 =pd.read_csv('FR_factor/all_signal.csv',index_col = 0)  # 输出数据，保存输出数据的方法

# %%
all_signal1
# Out:
#           date         code  month_ret        fr       fru       frd
# 0     20080131  000031.XSHE   0.007579 -0.437093 -0.622945  0.275552
# 1     20080131  000032.XSHE   0.153532  0.103079  0.558187  0.146952
# 2     20080131  000033.XSHE   0.124607  0.300709  0.344582 -0.311575
# 3     20080131  000039.XSHE   0.056397 -0.098604  0.533287  0.299034
# 4     20080131  000061.XSHE   0.013432 -0.382778 -0.385822  0.448880
# 5     20080131  000065.XSHE   0.092110 -0.150972  0.116040  0.236845
# 6     20080131  000155.XSHE   0.209642 -0.060223  0.177389  0.113608
# 7     20080131  000423.XSHE   0.075997 -0.188127  0.248766  0.783441
# 8     20080131  000515.XSHE   0.151328  0.030294  0.274927  0.119705
# 9     20080131  000541.XSHE   0.034759  0.360639  0.398755 -0.335160
# 10    20080131  000544.XSHE   0.196722 -0.437463 -0.033289  0.566135
# 11    20080131  000546.XSHE  -0.124480  0.284872 -0.105096 -0.468694
# 12    20080131  000551.XSHE   0.178200 -0.312760 -0.184386  0.442790
# 13    20080131  000590.XSHE   0.079997  0.055863 -0.220953 -0.167549
# 14    20080131  000591.XSHE   0.053121 -0.167232 -0.220769  0.275075
# 15    20080131  000593.XSHE   0.134302  0.071697 -0.033878 -0.006055
# 16    20080131  000596.XSHE  -0.045452 -0.064316 -0.370346 -0.023315
# 17    20080131  000669.XSHE   0.188910 -0.203062  0.134913  0.385383
# 18    20080131  000677.XSHE   0.129324  0.092180  0.690569  0.283239
# 19    20080131  000707.XSHE   0.120477 -0.025964  0.612581  0.648148
# 20    20080131  000729.XSHE   0.046427  0.291682  0.659663 -0.256272
# 21    20080131  000760.XSHE   0.038712  0.021947 -0.320946 -0.208922
# 22    20080131  000800.XSHE   0.038641 -0.123622 -0.280295 -0.134211
# 23    20080131  000821.XSHE   0.135222 -0.265905 -0.217509  0.336829
# 24    20080131  000850.XSHE   0.020309  0.241909 -0.029877 -0.431669
# 25    20080131  000852.XSHE   0.172517 -0.255342 -0.082399  0.323843
# 26    20080131  000859.XSHE   0.214378 -0.260043 -0.174558  0.498668
# 27    20080131  000882.XSHE   0.005778 -0.123829 -0.044778  0.339881
# 28    20080131  000901.XSHE   0.128629 -0.037022 -0.219019 -0.026140
# 29    20080131  000988.XSHE   0.151705  0.360655  0.332141 -0.480231
# ...        ...          ...        ...       ...       ...       ...
# 3023  20180531  600191.XSHG  -0.187405 -0.360127 -0.364085  0.369542
# 3024  20180531  600207.XSHG  -0.270674 -0.061868 -0.310280 -0.396031
# 3025  20180531  600215.XSHG  -0.104252  0.178624  0.692881 -0.047212
# 3026  20180531  600216.XSHG  -0.089150 -0.322503 -0.464084  0.316470
# 3027  20180531  600236.XSHG   0.031815 -0.203229 -0.325520  0.140133
# 3028  20180531  600299.XSHG  -0.083313  0.046464 -0.411869 -0.402723
# 3029  20180531  600348.XSHG   0.040759 -0.312089 -0.450227  0.300169
# 3030  20180531  600385.XSHG  -0.126365 -0.162694  0.117964  0.179214
# 3031  20180531  600487.XSHG  -0.058555 -0.113511  0.106229  0.466263
# 3032  20180531  600502.XSHG  -0.156702  0.224269  0.459745 -0.198259
# 3033  20180531  600511.XSHG  -0.040598 -0.102080 -0.244091 -0.061070
# 3034  20180531  600532.XSHG  -0.238923 -0.095794 -0.213903 -0.083381
# 3035  20180531  600570.XSHG  -0.082163 -0.180296  0.319214  0.466389
# 3036  20180531  600581.XSHG   0.199562  0.019672  0.409283  0.121916
# 3037  20180531  600642.XSHG  -0.066925 -0.215603 -0.105603  0.236593
# 3038  20180531  600679.XSHG  -0.127665  0.099487 -0.453229 -0.039410
# 3039  20180531  600765.XSHG  -0.161691  0.036562 -0.223757 -0.345858
# 3040  20180531  600826.XSHG  -0.101331 -0.193140 -0.314699 -0.100897
# 3041  20180531  600857.XSHG  -0.178647  0.048130  0.386949  0.055661
# 3042  20180531  600862.XSHG  -0.210525  0.329051  0.110389 -0.465052
# 3043  20180531  601020.XSHG  -0.114886 -0.247441 -0.493379  0.182811
# 3044  20180531  601166.XSHG  -0.057937  0.108183  0.641585  0.124453
# 3045  20180531  601186.XSHG  -0.059912 -0.071851  0.420257  0.181352
# 3046  20180531  601328.XSHG  -0.046449  0.409391 -0.002478 -0.757530
# 3047  20180531  603015.XSHG  -0.078737 -0.005143 -0.025419 -0.084505
# 3048  20180531  603085.XSHG  -0.088500 -0.029929  0.632624  0.266912
# 3049  20180531  603180.XSHG  -0.110561 -0.093163  0.324913 -0.011690
# 3050  20180531  603266.XSHG  -0.118759 -0.010493 -0.157037 -0.370875
# 3051  20180531  603617.XSHG  -0.161990  0.604214 -0.390664 -0.811524
# 3052  20180531  603833.XSHG  -0.110483  0.038603  0.133351  0.042321
#
# [252771 rows x 6 columns]

# %%
#定义生成IC值的函数
import numpy as np
import scipy.stats as st
def cal_ic(data,factor_name):   #factor_name 本身就是str
    IC = []
    Month_end = sorted(list(set(data['date'].tolist())))   #注意此时的Month_end和前面生成的month_end不一样，int  str
    for date in Month_end:
        
        tdata = data[data['date']==date]       #  必须使用新名称，注意循环
        
        #tdata.sort_values(by='code', inplace=True)  #不排序也可以，不影响结果
        #tdata.reset_index(drop=True, inplace=True)
        
        factor_array = np.array(tdata[factor_name])
        return_array = np.array(tdata['month_ret'])        #相关系数生成的方法
        
        #cor,pval = st.spearmanr(factor_array,return_array,nan_policy = 'omit')
        cor = tdata[factor_name].corr(tdata['month_ret'],method = 'spearman')
        IC.append(cor)
        
    IC_data = pd.DataFrame(dict({'date':Month_end,'IC':IC}))  #生成字典，字典再转化为df
    IC_data = IC_data[['date','IC']]
    
    return IC_data  # 返回的为DF

#分别计算三个因子的IC值
raw_IC_fr = cal_ic(all_signal1,'fr')
raw_IC_fr.columns = ['date','IC_fr']

raw_IC_fru = cal_ic(all_signal1,'fru')
raw_IC_fru.columns = ['date','IC_fru']

raw_IC_frd = cal_ic(all_signal1,'frd')
raw_IC_frd.columns = ['date','IC_frd']

raw_IC =pd.merge(raw_IC_fr,raw_IC_fru,on='date')
raw_IC =pd.merge(raw_IC,raw_IC_frd,on='date')

raw_IC
# Out:
#          date     IC_fr    IC_fru    IC_frd
# 0    20080131 -0.029037  0.001484  0.017714
# 1    20080229  0.018711  0.019908  0.006685
# 2    20080331  0.029928  0.082916 -0.023730
# 3    20080430  0.004761 -0.062456 -0.054328
# 4    20080530 -0.031018  0.048762  0.067642
# 5    20080630  0.055565 -0.105881 -0.063602
# 6    20080731 -0.139923 -0.051884  0.105842
# 7    20080829 -0.009911  0.023636  0.006942
# 8    20080926  0.173311  0.096378 -0.160933
# 9    20081031 -0.052367 -0.072964  0.026975
# 10   20081128  0.122298  0.164272  0.000877
# 11   20081231  0.068922  0.064371 -0.013749
# 12   20090123 -0.099414 -0.105780  0.040165
# 13   20090227 -0.159063 -0.030589  0.179722
# 14   20090331 -0.063497 -0.057053  0.025996
# 15   20090430 -0.043657 -0.009941  0.080000
# 16   20090527  0.008791 -0.000774 -0.039970
# 17   20090630 -0.057684 -0.023267  0.062765
# 18   20090731 -0.066839 -0.116722  0.040995
# 19   20090831 -0.077344 -0.093772  0.053214
# 20   20090930 -0.097025 -0.033455  0.108867
# 21   20091030  0.009708 -0.017602  0.050820
# 22   20091130 -0.157569 -0.111751  0.131918
# 23   20091231  0.093506  0.035495 -0.061774
# 24   20100129  0.000715  0.015635 -0.011475
# 25   20100226  0.026996 -0.000517 -0.016054
# 26   20100331  0.063299  0.066754 -0.003037
# 27   20100430 -0.040768 -0.021977  0.047326
# 28   20100531 -0.035407  0.052439  0.065128
# 29   20100630 -0.165459 -0.063230  0.155525
# ..        ...       ...       ...       ...
# 95   20151231 -0.052201 -0.015347  0.067365
# 96   20160129  0.074694  0.033501 -0.030043
# 97   20160229 -0.122062 -0.152998  0.133434
# 98   20160331  0.001135 -0.020039  0.003339
# 99   20160429  0.008668  0.023524  0.033066
# 100  20160531  0.022006 -0.044901 -0.025016
# 101  20160630 -0.052145 -0.056899  0.054436
# 102  20160729 -0.056202 -0.055888  0.045160
# 103  20160831 -0.079223 -0.040828  0.048226
# 104  20160930  0.033394  0.001490  0.027300
# 105  20161031 -0.031448 -0.014256  0.061296
# 106  20161130 -0.041692 -0.003508  0.045161
# 107  20161230  0.008492 -0.001461 -0.000035
# 108  20170126  0.014092  0.015984  0.014170
# 109  20170228 -0.011432  0.002030  0.025903
# 110  20170331 -0.021178  0.024741  0.021527
# 111  20170428  0.035016  0.024352 -0.038989
# 112  20170531 -0.087815 -0.045244  0.085151
# 113  20170630 -0.107529 -0.069600  0.074653
# 114  20170731 -0.034771 -0.085771  0.026669
# 115  20170831 -0.077045 -0.054173  0.059565
# 116  20170929 -0.068544 -0.067046  0.069077
# 117  20171031 -0.021488 -0.006997  0.023576
# 118  20171130 -0.021949 -0.003261  0.025810
# 119  20171229 -0.002206 -0.003453 -0.009773
# 120  20180131 -0.052995 -0.024341  0.054132
# 121  20180228 -0.143408 -0.040955  0.169111
# 122  20180330 -0.066187 -0.021656  0.079434
# 123  20180427 -0.044568 -0.019074  0.070708
# 124  20180531 -0.096073 -0.014644  0.104621
#
# [125 rows x 4 columns]

# %%
#计算三个因子的IC均值以及ICIR值
#FR
FR_IC = raw_IC['IC_fr'].mean()
FR_ICIR = raw_IC['IC_fr'].mean()/raw_IC['IC_fr'].std()*np.sqrt(12)
print('FR因子的IC和ICIR分别是：')
print(FR_IC,FR_ICIR)

#FRu
FRu_IC = raw_IC['IC_fru'].mean()
FRu_ICIR = raw_IC['IC_fru'].mean()/raw_IC['IC_fru'].std()*np.sqrt(12)
print('FRu因子的IC和ICIR分别是：')
print(FRu_IC,FRu_ICIR)

#FRd
FRd_IC = raw_IC['IC_frd'].mean()
FRd_ICIR = raw_IC['IC_frd'].mean()/raw_IC['IC_frd'].std()*np.sqrt(12)
print('FRd因子的IC和ICIR分别是：')
print(FRd_IC,FRd_ICIR)
# Out:
# FR因子的IC和ICIR分别是：
# (-0.023281275113347565, -1.1940768597430758)
# FRu因子的IC和ICIR分别是：
# (-0.014485347814856475, -0.87711618275287739)
# FRd因子的IC和ICIR分别是：
# (0.032327192836585965, 1.8213856580386587)

# %%
import statsmodels.api as sm
import pandas as pd
#第二部分，计算纯净因子的IC值
def get_industry(date,code):
    indu = DataAPI.MdSwBackGet(secID=code,field=u"secID,isNew,industryName1",pandas="1")
    indu = indu[indu['isNew']==1]
    indu.drop_duplicates(subset =['secID'],inplace = True)
    indu['date'] = date
    indu = indu[['date','secID','industryName1']]
    indu.columns = ['date','code','industryName']
    return indu
#code = ['600687.XSHG','000001.XSHE','600387.XSHG','600769.XSHG','600393.XSHG','000988.XSHE']    
#get_industry('20070401',code) 

#计算纯净因子

all_prue_fr = pd.DataFrame()
for date in month_end[1:]:
    
    #原计算出来的三个因子
    tdf =all_signal[all_signal['date']==date]
    code = list(tdf['code'])
    
    # 从平台上，获取其它的几个因子的数据
    factors = DataAPI.MktStockFactorsOneDayGet(tradeDate=date,secID=code,field=u"secID,tradeDate,LFLO,REVS20,VOL20,ATR14",pandas="1")
    factors['tradeDate'] = map(time_change,factors['tradeDate'])
    factors.columns = ['code','date','lflo','revs20','vol20','variance60']
    
    #获取行业的信息
    indu = get_industry(date,code)
    
    #三者链接起来
    tdf = pd.merge(tdf,factors,on=['date','code'])
    tdf = pd.merge(tdf,indu,on=['date','code'])
    tdf.dropna(inplace = True)
    
    
    # 对各因子进行标准化和去极值化
    tdf.set_index('code',inplace = True)
    for col in tdf.columns[2:-1]:
        temp = tdf[col]
        tdf[col] = standardize(winsorize(temp))
    
    #行业转化为哑变量
    indu_dummies = pd.get_dummies(tdf['industryName'])
    
    tdf.drop('industryName',axis = 1,inplace = True)
    
    #行业与tdf结合一起
    tdf = pd.merge(tdf,indu_dummies,left_index = True,right_index=True,how='outer')
    
    #对传统的三个因子做回归
    y1 = np.array(tdf['fr'])
    y2 = np.array(tdf['fru'])
    y3 = np.array(tdf['frd'])
    
    X = np.array(tdf[tdf.columns[5:]])
    X = sm.add_constant(X,has_constant='add')
    
    #回归，求prue_fr
    model = sm.OLS(y1,X,missing = 'drop')
    results = model.fit()
    tdf['fr'] = results.resid
    tdf['fr'] = standardize(winsorize(tdf['fr']))

    #回归，求prue_fru
    model = sm.OLS(y2,X,missing = 'drop')
    results = model.fit()
    tdf['fru'] = results.resid
    tdf['fru'] = standardize(winsorize(tdf['fru']))
    
    #回归，求prue_frd
    model = sm.OLS(y3,X,missing = 'drop')
    results = model.fit()
    tdf['frd'] = results.resid
    tdf['frd'] = standardize(winsorize(tdf['frd']))
    
    #对tdf获取需要的列，去掉没有用的列
    tdf['code'] = tdf.index
    tdf.reset_index(drop=True,inplace =True)
    tdf = tdf[['date','code','month_ret','fr','fru','frd']]
    tdf = tdf.sort_values(by=['date','code'])
    
    #增加到整个DF中
    all_prue_fr = all_prue_fr.append(tdf)
    

all_prue_fr
# Out:
#           date         code  month_ret        fr       fru       frd
# 294   20080131  000001.XSHE  -0.004504 -0.335874  0.406393  1.022769
# 584   20080131  000002.XSHE  -0.107486  0.409649 -0.081320 -0.548251
# 971   20080131  000006.XSHE   0.015001  0.551560  0.687355 -0.364473
# 391   20080131  000012.XSHE   0.252738  0.327208  0.657724 -0.100060
# 1068  20080131  000016.XSHE   0.056908  2.297096  1.465442 -1.648197
# 776   20080131  000019.XSHE   0.172780  0.142439  0.935451  0.035208
# 1069  20080131  000022.XSHE   0.051613  0.237696  0.245983 -0.332492
# 777   20080131  000023.XSHE   0.082060 -1.039382  0.237671  1.037571
# 972   20080131  000024.XSHE  -0.124279  1.919574  0.914120 -1.671672
# 99    20080131  000025.XSHE   0.012521  1.719840 -1.264231 -1.596508
# 681   20080131  000026.XSHE   0.136679 -0.180046 -0.940700 -0.420371
# 682   20080131  000027.XSHE   0.042690 -0.151308  0.076563  0.017425
# 295   20080131  000028.XSHE   0.115663 -0.277989  0.329414  0.950203
# 1070  20080131  000029.XSHE   0.005403 -0.080335 -1.028902 -0.598432
# 0     20080131  000031.XSHE   0.007579 -2.024171 -2.046952  0.707468
# 1     20080131  000032.XSHE   0.153532  0.823621  1.736793  0.107972
# 2     20080131  000033.XSHE   0.124607  1.961466  1.312771 -1.515867
# 585   20080131  000036.XSHE   0.028956  2.145693  0.158708 -1.676575
# 1071  20080131  000037.XSHE   0.091762 -2.071013 -1.728913  2.109299
# 3     20080131  000039.XSHE   0.056397 -0.067375  1.328528  0.354134
# 586   20080131  000040.XSHE   0.051116  0.799083  0.249927 -0.628433
# 683   20080131  000042.XSHE   0.079629  1.965708  0.814953 -2.076447
# 196   20080131  000045.XSHE   0.055185  1.852323  1.014334 -1.661108
# 488   20080131  000046.XSHE   0.006819  0.446377  0.455739 -0.404573
# 100   20080131  000049.XSHE   0.047800 -1.392708 -0.179546  0.957082
# 489   20080131  000050.XSHE   0.033770 -1.382148 -0.745543  1.327776
# 392   20080131  000055.XSHE   0.171002  0.894769  1.863082  0.088156
# 973   20080131  000056.XSHE   0.019532  0.205414  0.881520  0.096685
# 197   20080131  000059.XSHE   0.075405  0.298687  0.677230 -0.269379
# 4     20080131  000061.XSHE   0.013432 -1.379726 -1.422208  0.826279
# ...        ...          ...        ...       ...       ...       ...
# 1849  20180531  603920.XSHG  -0.126751 -0.425394 -0.876350  0.305505
# 482   20180531  603926.XSHG  -0.156561  1.146017  0.522420 -1.126315
# 483   20180531  603928.XSHG  -0.078188  0.126456 -0.175967 -0.577197
# 385   20180531  603929.XSHG  -0.134475  0.084504  0.488070  0.079819
# 1551  20180531  603933.XSHG  -0.125836 -0.598088 -0.950847  0.256525
# 1552  20180531  603936.XSHG  -0.137863  0.186402  0.909368  0.492857
# 2535  20180531  603938.XSHG  -0.072475 -1.239774 -0.910298  0.568235
# 2045  20180531  603955.XSHG  -0.124885 -1.841338 -0.375649  1.327319
# 1262  20180531  603958.XSHG  -0.223028 -0.319426 -0.365169  0.669936
# 2826  20180531  603959.XSHG  -0.174779 -1.404268 -0.896014  1.011015
# 2727  20180531  603960.XSHG   0.131082 -0.523691 -0.392074  0.267592
# 1649  20180531  603966.XSHG  -0.147845 -1.755960 -1.521177  0.793843
# 771   20180531  603968.XSHG  -0.120976  0.626153  0.619013 -0.555965
# 1359  20180531  603969.XSHG  -0.220693  0.190577  0.727503  0.757823
# 1650  20180531  603976.XSHG  -0.136788 -0.892454 -0.132452  1.056867
# 868   20180531  603977.XSHG  -0.043714 -0.233556 -0.273606  0.134341
# 772   20180531  603978.XSHG  -0.215434 -0.460531  0.393750  0.728884
# 1553  20180531  603979.XSHG  -0.169018  0.148652 -0.767485 -1.204844
# 1163  20180531  603980.XSHG  -0.104478 -0.350416 -0.239191  0.379366
# 2728  20180531  603985.XSHG  -0.169656 -1.630872 -0.756933  1.236347
# 2729  20180531  603986.XSHG   0.000646 -0.325090 -1.324956 -0.256646
# 2437  20180531  603987.XSHG  -0.141198  1.672273 -0.088956 -1.502774
# 2240  20180531  603988.XSHG  -0.169711 -0.924653  0.426030  1.318913
# 2339  20180531  603989.XSHG  -0.136285  2.042157  1.787383 -0.218219
# 2438  20180531  603990.XSHG  -0.044755 -1.157889 -0.427218  0.934785
# 869   20180531  603991.XSHG  -0.090797 -1.337433 -0.980262  1.244743
# 1263  20180531  603993.XSHG  -0.104679 -0.335360 -0.689983 -0.280697
# 1066  20180531  603996.XSHG  -0.470059 -0.897377 -0.502725  0.892941
# 2827  20180531  603998.XSHG  -0.196429 -0.141311 -0.323294 -0.275250
# 1164  20180531  603999.XSHG  -0.166514  0.008033  0.135199  0.048690
#
# [241128 rows x 6 columns]

# %%
all_prue_fr.to_csv('FR_factor/all_prue_fr.csv',index=True) 
all_prue_fr1 = pd.read_csv('FR_factor/all_prue_fr.csv',index_col=0)

# %%
prue_IC_fr = cal_ic(all_prue_fr,'fr')
prue_IC_fr.columns = ['date','prue_IC_fr']

prue_IC_fru = cal_ic(all_prue_fr,'fru')
prue_IC_fru.columns = ['date','prue_IC_fru']

prue_IC_frd = cal_ic(all_prue_fr,'frd')
prue_IC_frd.columns = ['date','prue_IC_frd']

prue_IC =pd.merge(prue_IC_fr,prue_IC_fru,on='date')
prue_IC =pd.merge(prue_IC,prue_IC_frd,on='date')

prue_IC
# Out:
#          date  prue_IC_fr  prue_IC_fru  prue_IC_frd
# 0    20080131   -0.035185     0.016273     0.026792
# 1    20080229    0.043676     0.053251     0.013692
# 2    20080331    0.005938     0.026961     0.002934
# 3    20080430    0.019255    -0.040695    -0.050244
# 4    20080530   -0.038741     0.036560     0.057334
# 5    20080630   -0.008277    -0.039677    -0.003918
# 6    20080731   -0.078243    -0.013251     0.079346
# 7    20080829   -0.009078     0.012666     0.003852
# 8    20080926    0.066454     0.028738    -0.052911
# 9    20081031   -0.076245    -0.074174     0.043847
# 10   20081128    0.030284     0.048570    -0.016281
# 11   20081231    0.031463     0.039033    -0.001489
# 12   20090123   -0.067048    -0.061974     0.048550
# 13   20090227   -0.110075    -0.017492     0.114122
# 14   20090331   -0.044850    -0.041873     0.007979
# 15   20090430   -0.031789    -0.005308     0.044912
# 16   20090527   -0.009443    -0.014049    -0.033331
# 17   20090630   -0.040778    -0.018825     0.015805
# 18   20090731   -0.063438    -0.074370     0.027459
# 19   20090831   -0.020113    -0.051462     0.013354
# 20   20090930   -0.098745    -0.023488     0.110286
# 21   20091030   -0.054285    -0.026956     0.087693
# 22   20091130   -0.126524    -0.099400     0.084591
# 23   20091231    0.013032     0.037675     0.014797
# 24   20100129   -0.029787    -0.021384     0.012501
# 25   20100226   -0.044509    -0.042894     0.033164
# 26   20100331    0.036588     0.054205     0.008284
# 27   20100430   -0.113563    -0.063246     0.085624
# 28   20100531   -0.055572    -0.000871     0.056668
# 29   20100630   -0.105635    -0.052935     0.102833
# ..        ...         ...          ...          ...
# 95   20151231   -0.039452     0.007802     0.049440
# 96   20160129    0.018723     0.010738    -0.006297
# 97   20160229   -0.063643    -0.031705     0.072575
# 98   20160331   -0.027779    -0.010484     0.051518
# 99   20160429   -0.010987     0.015136     0.031533
# 100  20160531    0.010844    -0.027128    -0.011917
# 101  20160630   -0.031552    -0.033450     0.011145
# 102  20160729   -0.024453    -0.012790     0.030642
# 103  20160831   -0.043335    -0.017610     0.029680
# 104  20160930    0.004456     0.003766     0.031619
# 105  20161031   -0.045049    -0.019404     0.067778
# 106  20161130   -0.027880     0.009530     0.031722
# 107  20161230   -0.012672     0.001232     0.016422
# 108  20170126   -0.011757     0.017041     0.023944
# 109  20170228   -0.008483     0.001882     0.007927
# 110  20170331   -0.021575     0.020033     0.035618
# 111  20170428    0.039148     0.032937    -0.026197
# 112  20170531   -0.086878    -0.026664     0.079222
# 113  20170630   -0.055957    -0.030180     0.051244
# 114  20170731   -0.015999    -0.020469     0.011380
# 115  20170831   -0.034245    -0.023208     0.030839
# 116  20170929   -0.021723    -0.024700     0.017681
# 117  20171031   -0.001173    -0.010370     0.012507
# 118  20171130   -0.019306     0.008173     0.032933
# 119  20171229    0.004820    -0.011993    -0.013858
# 120  20180131   -0.013647    -0.003734     0.004569
# 121  20180228   -0.050922    -0.025632     0.068281
# 122  20180330   -0.060525    -0.020025     0.072672
# 123  20180427   -0.026890    -0.019690     0.039176
# 124  20180531   -0.046268     0.010462     0.057710
#
# [125 rows x 4 columns]

# %%
#计算三个prue因子的IC均值以及ICIR值
#FR
prue_FR_IC = prue_IC['prue_IC_fr'].mean()
prue_FR_ICIR = prue_IC['prue_IC_fr'].mean()/prue_IC['prue_IC_fr'].std()*np.sqrt(12)
print('纯净FR因子的IC和ICIR分别是：')
print(prue_FR_IC,prue_FR_ICIR)

#FRu
prue_FRu_IC = prue_IC['prue_IC_fru'].mean()
prue_FRu_ICIR = prue_IC['prue_IC_fru'].mean()/prue_IC['prue_IC_fru'].std()*np.sqrt(12)
print('纯净FRu因子的IC和ICIR分别是：')
print(prue_FRu_IC,prue_FRu_ICIR)

#FRd
prue_FRd_IC = prue_IC['prue_IC_frd'].mean()
prue_FRd_ICIR = prue_IC['prue_IC_frd'].mean()/prue_IC['prue_IC_frd'].std()*np.sqrt(12)
print('纯净FRd因子的IC和ICIR分别是：')
print(prue_FRd_IC,prue_FRd_ICIR)
# Out:
# 纯净FR因子的IC和ICIR分别是：
# (-0.025622436027288108, -2.2555371756443767)
# 纯净FRu因子的IC和ICIR分别是：
# (-0.010527218308975014, -1.1051269615555463)
# 纯净FRd因子的IC和ICIR分别是：
# (0.02832104175641276, 2.7422756925896663)

# %%
prue_IC.to_csv('FR_factor/prue_IC.csv',index=True)

# %%
#ic序列图

import matplotlib.pyplot as plt
#fig = plt.figure(figsize=(16,7))
#ax = fig.add_subplot(111)
#ax.bar(prue_IC['prue_IC_frd'])

prue_IC['prue_IC_frd'].plot.bar(figsize=(15,7))

# %% [raw]
# #--------------- 回测参数 ---------------
# start = '2012-10-31'                       # 回测起始时间
# end = '2018-05-31'                         # 回测结束时间
# benchmark = 'ZZ500'                        # 策略参考标准
# universe = DynamicUniverse('A')            # 证券池，支持股票和基金
# capital_base = 100000000                   # 起始资金
# freq = 'd'                                 # 日行情
# refresh_rate = Monthly(1)                  # 每月第一个交易日进行调仓
#
# # 初始账户资金设为1亿元
# accounts = {
#     'security_account': AccountConfig(account_type='security', capital_base=100000000)
# }
#
#
# # 读入因子文件
# all_pure_fr = pd.read_csv('FR_factor/all_prue_fr.csv')
# all_pure_fr['date'] = map(str, all_pure_fr['date'])
# signal_df = all_pure_fr[['code', 'date', 'frd']]
# signal_df.columns = ['secID', 'tradeDate', 'frd']
#
# #自己增加的部分
#
# factor_data = signal_df[['secID', 'tradeDate', 'frd']]     # 读取因子数据
# factor_data = factor_data.set_index('tradeDate', drop=True)
# month_end_dates = factor_data.index.values
#
#
# # 初始化虚拟账户状态
# def initialize(context):
#     pass
#
# # 每个调仓期执行一次
# def handle_data(context):
#     account = context.get_account('security_account')
#     pre_date = context.previous_date.strftime("%Y%m%d")
#     current_universe = context.get_universe(exclude_halt=True)
#     #current_universe = st_remove(current_universe, st_date=pre_date)
#     #current_universe = new_remove(current_universe, trade_date= pre_date)
#     if pre_date not in month_end_dates:
#         return
#
#     # 拿取调仓日前一个交易日的因子，并按照大小排列取相应分位的股票代码
#     q = factor_data.ix[pre_date]
#     q = q.set_index('secID', drop=True)
#     q = q.ix[current_universe]
#     q.dropna(inplace=True)
#
#
#     q_min = q['frd'].quantile((5-1)*0.2)
#     q_max = q['frd'].quantile(5*0.2)
#     my_univ = q[(q['frd'] >= q_min) & (q['frd'] < q_max)].index.values
#
#     # 将不在目标持仓中的股票卖出
#     positions = account.get_positions()
#     sell_list = [stk for stk in positions if stk not in my_univ]
#     for stk in sell_list:
#         account.order_to(stk,0)
#
#     # 将在目标股票池中的股票，等权买入
#     for stk in my_univ:
#         account.order_pct_to(stk, 1.0/len(my_univ))
