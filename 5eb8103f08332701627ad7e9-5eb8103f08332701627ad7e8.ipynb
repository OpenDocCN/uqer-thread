# %% [markdown]
# # 趋势_动量_波动率优化,线性回归系数[博]

# %% [markdown]
# 基础动量策略
# 20天涨幅最高的入选（前10%），20天一次调仓
# 结论：
# 15年01月-17年01月：HS300不忍直视了，反向做空吧^_^
# 15年01月-17年01月：CYB还是无效
#
# 优化1，和波动率倒数（标准差衡量）加权，然后排序取最大
# 优化2，动量最大20%，波动率最小50%，效果较好，15-17年化约90%
# 优化3，线性回归的一次方系数作为”动量“的衡量，基本无效

# %%
15-17沪深300表现

# %% [raw]
# import pandas as pd
# import numpy as np
# from heapq import nlargest, nsmallest
# from CAL.PyCAL import *
#
# start = '2015-01-01'                       # 回测起始时间
# end = '2017-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = DynamicUniverse('HS300')  # 证券池，支持股票和基金
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 20                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# momentumLength=20#昨日/n日前价格作为动量
# max_history_windows=20#取历史信息的最大数据长度
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     #计算动量
#     price_map=account.get_attribute_history('closePrice',momentumLength)
#     #print '300268',price_map['300268.XSHE'][-1],price_map['300268.XSHE'][0],price_map['300268.XSHE'][-1]/price_map['300268.XSHE'][0]
#
#     price_mom={stk:price_map[stk][-1]/price_map[stk][0]-1 if price_map[stk][0] != 0 else -1.0 for stk in price_map.keys() }
#     #print 'price_mom before',price_mom
#
#     price_mom=sorted(price_mom.items(),key=lambda d: d[1])
#     #print 'price_mom after',price_mom
#
#     buylist = [x[0] for x in price_mom[int(len(price_mom)*9.0/10):]]#前10%
#     print account.current_date,[x for x in price_mom[len(price_mom)*9/10:]]
#
#     #今日真实卖出=当前持仓-今日计划买入
#     sellSet=set(account.valid_secpos)-set(buylist)
#     #今日真实买入=买入集合，由于部分股票可能需要调整份额，所以不去除account.valid_secpos
#     buySet=set(buylist)
#
#     #执行买入卖出操作
#     for stk in sellSet:
#         order_to(stk, 0)
#
#     if len(buySet) > 0:
#         # 无论buy_list中有多少只股票，都将仓位分成stk_num份，每份买入一只股票
#         amount_per_stk = account.referencePortfolioValue/(len(buySet)*0.8)
#         for stk in buySet :
#             if not account.referencePrice[stk]:
#                 continue
#             amount = int(amount_per_stk/account.reference_price[stk] / 100.0) * 100
#             order_to(stk, amount)

# %% [markdown]
# 1501-1701创业板上表现,

# %% [raw]
# import pandas as pd
# import numpy as np
# from heapq import nlargest, nsmallest
# from CAL.PyCAL import *
#
# start = '2015-01-01'                       # 回测起始时间
# end = '2017-01-01'                         # 回测结束时间
# benchmark = '399006.ZICN'                        # 策略参考标准
# universe = DynamicUniverse('CYB')  # 证券池，支持股票和基金
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 20                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# momentumLength=20#昨日/n日前价格作为动量
# max_history_windows=50#取历史信息的最大数据长度
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     #计算动量
#     price_map=account.get_attribute_history('closePrice',momentumLength)
#     price_mom={stk:price_map[stk][-1]/price_map[stk][0] if price_map[stk][0] != 0 else 0.0 for stk in price_map.keys() }
#
#     price_mom=sorted(price_mom.items(),key=lambda d: d[1])
#     buylist = [x[0] for x in price_mom[int(len(price_mom)*9.0/10):]]#前10%
#
#     #今日真实卖出=当前持仓-今日计划买入
#     sellSet=set(account.valid_secpos)-set(buylist)
#     #今日真实买入=买入集合，由于部分股票可能需要调整份额，所以不去除account.valid_secpos
#     buySet=set(buylist)
#
#     #执行买入卖出操作
#     for stk in sellSet:
#         order_to(stk, 0)
#
#     if len(buySet) > 0:
#         # 无论buy_list中有多少只股票，都将仓位分成stk_num份，每份买入一只股票
#         amount_per_stk = account.referencePortfolioValue/(len(buySet)*0.8)
#         for stk in buySet :
#             if not account.referencePrice[stk]:
#                 continue
#             amount = int(amount_per_stk/account.reference_price[stk] / 100.0) * 100
#             order_to(stk, amount)

# %%
虽然表现比较差，但是作为趋势中的经典策略，作为研究素材还是不错的，考虑进一步优化。
优化1，引入波动率(用标准差来衡量)作为选股参考
动量只是单纯考虑了涨幅情况，而投资者同样关心价格波动情况，如果只是单一某天的上涨，很难相信该股票会继续涨势
所以可以结合波动率因素进行考虑
1，涨幅和波动率倒数加权求和，取大
2，涨幅/波动率，取大
都需要考虑用归一化等方法处理

# %% [raw]
# #结合波动率(标准差来衡量)加权
# import pandas as pd
# import numpy as np
# from heapq import nlargest, nsmallest
# from CAL.PyCAL import *
#
# start = '2015-01-01'                       # 回测起始时间
# end = '2017-01-01'                         # 回测结束时间
# benchmark = '399006.ZICN'                        # 策略参考标准
# universe = DynamicUniverse('CYB')  # 证券池，支持股票和基金
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 20                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# momentumLength=20#昨日/n日前价格作为动量
# max_history_windows=20#取历史信息的最大数据长度
# debug_df1=pd.DataFrame()
# debug_df2=pd.DataFrame()
# debug_df3=pd.DataFrame()
#
# weight=pd.Series({'std':0.3,'mom':0.7})
# hold_rate=0.90 #持仓占比,0.9表示持有0.9-1.0的高位10%
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     global ii
#     today=account.current_date.strftime('%Y%m%d')
#     #获得价格信息
#     price_map=account.get_attribute_history('closePrice',momentumLength)
#     price_map={stk[:6]:price_map[stk] for stk in price_map.keys()}
#
#
#     #获取动量，空值动量-1.0排最后
#     price_mom={stk:price_map[stk][-1]/price_map[stk][0] if price_map[stk][0]!=0 else 0 for stk in price_map.keys()  }
#     price_mom_series=pd.Series(price_mom).fillna(-1.0)
#     st_mom=standardize(winsorize((price_mom_series/price_mom_series.mean()).fillna(-1.0).to_dict()))
#
#     #print 'price_mom_series',price_mom_series
#     #st_mom=price_mom_series.to_dict()
#
#
#     #获取标准差
#     price_std={stk:np.std(price_map[stk]) if np.std(price_map[stk])!=0.0 else 1.0 for stk in price_map.keys()}
#     price_std_series=pd.Series(price_std).fillna(1.0)
#     #上面是1.0下面是0.0注一下，原因是除法将本来期望的最大值修改为最小了
#
#     st_std=winsorize((1.0/(price_std_series+1)).fillna(0.0).to_dict())
#
#     #print 'price_std_series:',price_std_series[:5]
#
#     #存放到datefarme中
#     price_mix_df=pd.DataFrame(index=price_map.keys(),columns=['std','mom'])
#     price_mix_df['std'][st_std.keys()]=st_std.values()
#     price_mix_df['mom'][st_mom.keys()]=st_mom.values()
#     debug_df1[today]=pd.Series(st_mom)
#     debug_df2[today]=pd.Series(st_std)
#
#
#     price_mix_df['mix']=price_mix_df['std']*weight['std']/weight.sum()\
#     +price_mix_df['mom']*weight['mom']/weight.sum()
#
#     #排序
#     #print price_mix_df.sort(columns=['mix'])[int(len(price_mix_df)*hold_rate):]['mix'][0:10]
#     buylist=price_mix_df.sort(columns=['mix'])[int(len(price_mix_df)*hold_rate):].index.tolist()
#     #print 'buylist',buylist
#     #今日真实卖出=当前持仓-今日计划买入
#     sellSet=set(account.valid_secpos)-set(buylist)
#     #今日真实买入=买入集合，由于部分股票可能需要调整份额，所以不去除account.valid_secpos
#     buySet=set(buylist)
#
#     #执行买入卖出操作
#     for stk in sellSet:
#         order_to(stk, 0)
#
#     if len(buySet) > 0:
#         # 无论buy_list中有多少只股票，都将仓位分成stk_num份，每份买入一只股票
#         amount_per_stk = account.referencePortfolioValue/(len(buySet)*0.8)
#         for stk in buySet :
#             stk=stk+'.XSHE'
#             if not account.referencePrice[stk]:
#                 continue
#             amount = int(amount_per_stk/account.reference_price[stk] / 100.0) * 100
#             order_to(stk, amount)

# %% [markdown]
# 实际结果并不理想。动量这种策略可能已经被充分挖掘了，直接使用的话没有超额收益也不奇怪
#
# 优化2：
# 选择动量最大的20%，再次按照波动率排序，取最小的50%

# %% [raw]
# import pandas as pd
# import numpy as np
# from heapq import nlargest, nsmallest
# from CAL.PyCAL import *
#
# start = '2015-01-01'                       # 回测起始时间
# end = '2017-01-01'                         # 回测结束时间
# benchmark = '399006.ZICN'                        # 策略参考标准
# universe = DynamicUniverse('CYB')  # 证券池，支持股票和基金
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 20                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# momentumLength=20#昨日/n日前价格作为动量
# max_history_windows=100#取历史信息的最大数据长度
# debug_df1=pd.DataFrame()
# debug_df2=pd.DataFrame()
# debug_df3=pd.DataFrame()
#
# weight=pd.Series({'std':0.3,'mom':0.7})
# hold_rate=0.90 #持仓占比,0.9表示持有0.9-1.0的高位10%
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     global ii
#     today=account.current_date.strftime('%Y%m%d')
#     #获得价格信息
#     price_map=account.get_attribute_history('closePrice',momentumLength)
#     #price_map={stk[:6]:price_map[stk] for stk in price_map.keys()}
#
#
#     #获取动量，空值动量-1.0排最后
#     price_mom={stk:price_map[stk][-1]/price_map[stk][0] if price_map[stk][0]!=0 else 0 for stk in price_map.keys()  }
#     price_mom_series=pd.Series(price_mom).fillna(-1.0)
#
#
#     #获取标准差
#     price_std={stk:np.std(price_map[stk]) if np.std(price_map[stk])!=0.0 else 1.0 for stk in price_map.keys()}
#     price_std_series=pd.Series(price_std).fillna(1.0)
#     #上面是1.0下面是0.0注一下，原因是除法将本来期望的最大值修改为最小了
#
#     price_mix_df=pd.DataFrame(columns=['mom','std'])
#     price_mix_df['mom']=price_mom_series
#     price_mix_df['std']=price_std_series
#
#     #排序
#     #print price_mix_df.sort(columns=['mix'])[int(len(price_mix_df)*hold_rate):]['mix'][0:10]
#     mom_list=price_mix_df.sort(columns=['mom'])[int(len(price_mix_df)*0.8):]
#     buylist=mom_list.sort(columns=['std'])[:len(mom_list)/2].index.tolist()
#
#
#     tmpbuylist=[]
#     for stk in buylist:
#         if account.reference_price.get(stk,-1)>1:
#             tmpbuylist.append(stk)
#     buylist=tmpbuylist
#
#     #print 'buylist',buylist
#     #今日真实卖出=当前持仓-今日计划买入
#     sellSet=set(account.valid_secpos)-set(buylist)
#     #今日真实买入=买入集合，由于部分股票可能需要调整份额，所以不去除account.valid_secpos
#
#     buySet=set(buylist)
#
#     #执行买入卖出操作
#     for stk in sellSet:
#         order_to(stk, 0)
#
#     if len(buySet) > 0:
#         # 无论buy_list中有多少只股票，都将仓位分成stk_num份，每份买入一只股票
#         amount_per_stk = account.referencePortfolioValue/(len(buySet)*0.8)
#         for stk in buySet :
#             if not account.referencePrice[stk]:
#                 continue
#             amount = int(amount_per_stk/account.reference_price[stk] / 100.0) * 100
#             order_to(stk, amount)

# %% [markdown]
# 这个策略效果还是不错的，
# 牛市可以较好的抓住（没有超额收益，基本和大盘同步）
# 熊市表现也不错（尤其是15-06大跌时回撤很小）
# 震荡市也会有稳定收益（16年）
# 动量可能是调仓日前1-2天拉出一两个涨停板来实现的，不如每天均匀上涨的更可持续
# 可进一步优化下资金分配策略，加入止损策略方法等减少波动和回撤，感兴趣的矿友们自行尝试下，
#
# 优化3：线性回归系数
# 思路：按照动量来评估未来一段时间收益，其本质基于“价格趋势继续“的假设。所以，最能体现价格趋势是回归拟合价格信息的系数。此系数代替原来的动量，进行排名筛选，为了简单，线性回归的1次方系数代替动量
# 参考
# https://uqer.datayes.com/community/share/589ae6a094cad3005710f9d6
# http://blog.csdn.net/gamer_gyt/article/details/51232733

# %% [raw]
# import pandas as pd
# import numpy as np
# from heapq import nlargest, nsmallest
# from CAL.PyCAL import *
#
# start = '2015-01-01'                       # 回测起始时间
# end = '2017-01-01'                         # 回测结束时间
# benchmark = '399006.ZICN'                        # 策略参考标准
# universe =DynamicUniverse('CYB')  # 证券池，支持股票和基金
# #['000001.XSHE','000002.XSHE']
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 20                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# momentumLength=20#昨日/n日前价格作为动量
# max_history_windows=50#取历史信息的最大数据长度
# debug_df1=pd.DataFrame()
# debug_df2=pd.DataFrame()
# debug_df3=pd.DataFrame()
#
# weight=pd.Series({'std':0,'mom':1})
# hold_raten=0.90#持仓占比,0.9表示持有0.9-1.0的高位10%
#
# import numpy as np
#
# def fitSLR(x, y):
#     n = len(x)
#     dinominator = 0
#     numerator = 0
#     for i in range(0, n):
#         numerator += (x[i] - np.mean(x))*(y[i] - np.mean(y))
#         dinominator += (x[i] - np.mean(x))**2
#     b1 = numerator/float(dinominator)
#     b0 = np.mean(y)/float(np.mean(x))
#     return b0, b1
#
# def predict(x, b0, b1):
#     return b0 + x*b1
# def getMom(price):
#     #处理空值
#     for i in range(1,len(price)):
#         if price[i]<0.1:
#             price[i]=price[i-1]
#     x=range(1,len(price))
#     y=price
#     b0, b1 = fitSLR(x, y)
#     return b1
#
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     global ii
#     today=account.current_date.strftime('%Y%m%d')
#     #获得价格信息
#     price_map=account.get_attribute_history('closePrice',momentumLength)
#
#     #获取动量，空值动量-1.0排最后
#     price_mom={stk:getMom(price_map[stk]) for stk in price_map.keys()  }
#     price_mom_series=pd.Series(price_mom).fillna(-1.0)
#     st_mom=price_mom_series.to_dict()
#     #st_mom=standardize(winsorize((price_mom_series/price_mom_series.mean()).fillna(-1.0).to_dict()))
#
#
#     #存放到datefarme中
#     price_mix_df=pd.DataFrame(index=price_map.keys(),columns=['mom'])
#     price_mix_df['mom'][st_mom.keys()]=st_mom.values()
#     debug_df1.fillna(0)
#     debug_df1[today]=pd.Series(st_mom)
#
#     #排序
#     price_mix_df=price_mix_df.sort(columns=['mom'])[int(len(price_mix_df)*hold_rate):]
#     buylist=price_mix_df[price_mix_df['mom']>(0.001*refresh_rate)].index.tolist()
#
#     tmpbuylist=[]
#     for stk in buylist:
#         if account.reference_price.get(stk,-1)>1:
#             tmpbuylist.append(stk)
#     buylist=tmpbuylist
#
#     #今日真实卖出=当前持仓-今日计划买入
#     sellSet=set(account.valid_secpos)-set(buylist)
#     #今日真实买入=买入集合，由于部分股票可能需要调整份额，所以不去除account.valid_secpos
#     buySet=set(buylist)
#
#     #执行买入卖出操作
#     for stk in sellSet:
#         order_to(stk, 0)
#
#     if len(buySet) > 0:
#         # 无论buy_list中有多少只股票，都将仓位分成stk_num份，每份买入一只股票
#         amount_per_stk = account.referencePortfolioValue/(len(buySet)*0.8)
#         for stk in buySet :
#             if (not account.referencePrice.has_key(stk)) or account.reference_price[stk]<0.1:
#                 continue
#             amount = int(amount_per_stk/account.reference_price[stk] / 100.0) * 100
#             order_to(stk, amount)

# %% [markdown]
# 这个思路上感觉是最合理的，但效果上看貌似不怎么样
#
# 优化4：勘误，优化2，
# 优化2本来效果很好，后来矿友们发现其实是一部分代码写错导致，呃，让我哭一会。。
# 既然效果较好，不妨将错就错下，干脆改成波动率因子选股
# 纯波动率最小的20%

# %% [raw]
# import pandas as pd
# import numpy as np
# from heapq import nlargest, nsmallest
# from CAL.PyCAL import *
#
# start = '2015-01-01'                       # 回测起始时间
# end = '2017-01-01'                         # 回测结束时间
# benchmark = '399006.ZICN'                        # 策略参考标准
# universe = DynamicUniverse('CYB')  # 证券池，支持股票和基金
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 20                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# momentumLength=20#昨日/n日前价格作为动量
# max_history_windows=100#取历史信息的最大数据长度
# debug_df1=pd.DataFrame()
# debug_df2=pd.DataFrame()
# debug_df3=pd.DataFrame()
#
# weight=pd.Series({'std':0.3,'mom':0.7})
# hold_rate=0.90 #持仓占比,0.9表示持有0.9-1.0的高位10%
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     global ii
#     today=account.current_date.strftime('%Y%m%d')
#     #获得价格信息
#     price_map=account.get_attribute_history('closePrice',momentumLength)
#     #price_map={stk[:6]:price_map[stk] for stk in price_map.keys()}
#
#
#     #获取动量，空值动量-1.0排最后
#     price_mom={stk:price_map[stk][-1]/price_map[stk][0] if price_map[stk][0]!=0 else 0 for stk in price_map.keys()  }
#     price_mom_series=pd.Series(price_mom).fillna(-1.0)
#
#
#     #获取标准差
#     price_std={stk:np.std(price_map[stk]) if np.std(price_map[stk])!=0.0 else 1.0 for stk in price_map.keys()}
#     price_std_series=pd.Series(price_std).fillna(1.0)
#     #上面是1.0下面是0.0注一下，原因是除法将本来期望的最大值修改为最小了
#
#     price_mix_df=pd.DataFrame(columns=['mom','std'])
#     price_mix_df['mom']=price_mom_series
#     price_mix_df['std']=price_std_series
#
#     #排序
#     #print price_mix_df.sort(columns=['mix'])[int(len(price_mix_df)*hold_rate):]['mix'][0:10]
#     #mom_list=price_mix_df.sort(columns=['mom'])[int(len(price_mix_df)*0.8):]
#     buylist=price_mix_df.sort(columns=['std'])[:int(len(price_mix_df)*0.2)].index.tolist()
#
#
#     tmpbuylist=[]
#     for stk in buylist:
#         if account.reference_price.get(stk,-1)>1:
#             tmpbuylist.append(stk)
#     buylist=tmpbuylist
#
#     #print 'buylist',buylist
#     #今日真实卖出=当前持仓-今日计划买入
#     sellSet=set(account.valid_secpos)-set(buylist)
#     #今日真实买入=买入集合，由于部分股票可能需要调整份额，所以不去除account.valid_secpos
#
#     buySet=set(buylist)
#
#     #执行买入卖出操作
#     for stk in sellSet:
#         order_to(stk, 0)
#
#     if len(buySet) > 0:
#         # 无论buy_list中有多少只股票，都将仓位分成stk_num份，每份买入一只股票
#         amount_per_stk = account.referencePortfolioValue/(len(buySet)*0.8)
#         for stk in buySet :
#             if not account.referencePrice[stk]:
#                 continue
#             amount = int(amount_per_stk/account.reference_price[stk] / 100.0) * 100
#             order_to(stk, amount)

# %% [markdown]
# 进一步的：尝试参数优化
# 尝试了std最小的10%，年化70%
# std最小的10%-20%，年化100%
# std最小的5%-15%，年化83%
# 比较合理，毕竟波动率太低的，一般都是死水股，不涨不跌
# 参数优化后结果来看，std最小的10%-20%结果最好
#
# 优化5：既然波动率较好，就先波动率选择30%最小，其中在选择动量最大的1/3

# %% [raw]
# import pandas as pd
# import numpy as np
# from heapq import nlargest, nsmallest
# from CAL.PyCAL import *
#
# start = '2015-01-01'                       # 回测起始时间
# end = '2017-01-01'                         # 回测结束时间
# benchmark = '399006.ZICN'                        # 策略参考标准
# universe = DynamicUniverse('CYB')  # 证券池，支持股票和基金
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 20                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# momentumLength=20#昨日/n日前价格作为动量
# max_history_windows=100#取历史信息的最大数据长度
# debug_df1=pd.DataFrame()
# debug_df2=pd.DataFrame()
# debug_df3=pd.DataFrame()
#
# weight=pd.Series({'std':0.3,'mom':0.7})
# hold_rate=0.90 #持仓占比,0.9表示持有0.9-1.0的高位10%
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     global ii
#     today=account.current_date.strftime('%Y%m%d')
#     #获得价格信息
#     price_map=account.get_attribute_history('closePrice',momentumLength)
#     #price_map={stk[:6]:price_map[stk] for stk in price_map.keys()}
#
#
#     #获取动量，空值动量-1.0排最后
#     price_mom={stk:price_map[stk][-1]/price_map[stk][0] if price_map[stk][0]!=0 else 0 for stk in price_map.keys()  }
#     price_mom_series=pd.Series(price_mom).fillna(-1.0)
#
#
#     #获取标准差
#     price_std={stk:np.std(price_map[stk]) if np.std(price_map[stk])!=0.0 else 1.0 for stk in price_map.keys()}
#     price_std_series=pd.Series(price_std).fillna(1.0)
#     #上面是1.0下面是0.0注一下，原因是除法将本来期望的最大值修改为最小了
#
#     price_mix_df=pd.DataFrame(columns=['mom','std'])
#     price_mix_df['mom']=price_mom_series
#     price_mix_df['std']=price_std_series
#
#     #排序
#     #print price_mix_df.sort(columns=['mix'])[int(len(price_mix_df)*hold_rate):]['mix'][0:10]
#     #mom_list=price_mix_df.sort(columns=['mom'])[int(len(price_mix_df)*0.8):]
#     std_list=price_mix_df.sort(columns=['std'])[:int(len(price_mix_df)*0.3)]
#     buylist=std_list.sort(columns=['mom'])[int(len(std_list)*0.67):].index.tolist()
#
#
#     tmpbuylist=[]
#     for stk in buylist:
#         if account.reference_price.get(stk,-1)>1:
#             tmpbuylist.append(stk)
#     buylist=tmpbuylist
#
#     #print 'buylist',buylist
#     #今日真实卖出=当前持仓-今日计划买入
#     sellSet=set(account.valid_secpos)-set(buylist)
#     #今日真实买入=买入集合，由于部分股票可能需要调整份额，所以不去除account.valid_secpos
#
#     buySet=set(buylist)
#
#     #执行买入卖出操作
#     for stk in sellSet:
#         order_to(stk, 0)
#
#     if len(buySet) > 0:
#         # 无论buy_list中有多少只股票，都将仓位分成stk_num份，每份买入一只股票
#         amount_per_stk = account.referencePortfolioValue/(len(buySet)*0.8)
#         for stk in buySet :
#             if not account.referencePrice[stk]:
#                 continue
#             amount = int(amount_per_stk/account.reference_price[stk] / 100.0) * 100
#             order_to(stk, amount)

# %%
中间的回撤有点大，
整体来看，加入动量后结果又不怎么样了，还是波动率比较靠谱啊
