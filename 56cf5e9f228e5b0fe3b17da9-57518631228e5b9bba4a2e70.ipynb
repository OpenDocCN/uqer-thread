# %% [markdown]
# # 学习markdown

# %% [markdown]
# 这篇是散帖，为了学习markdown。
#
# 换行
#
# 再换行
#
# 首先是换行。<br/>
#     空两格换行。<br/>
#
# # 这是一篇文章
# ## 欢迎大家
# >引言我不明白，先试试
#
#
# *123
# *223
#
# *123
#
# *223
#
# 1.ok
#
# 2.ok
#
# 这是[markdown中文学习手册](http://www.appinn.com/markdown/ "Title") 。
