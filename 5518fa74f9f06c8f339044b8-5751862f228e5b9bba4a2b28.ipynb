# %% [markdown]
# # DataAPI测试

# %%
start = datetime(2011,1, 1)				# 回测起始时间
end   = datetime(2015, 3, 19)				# 回测结束时间
benchmark = 'HS300'							# 策略参考标准
universe = set_universe('HS300')	# 股票池


get_benchmark_data(benchmark, start=start, end=end)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-aa4fd3833be9> in <module>()
#       5
#       6
# ----> 7 get_benchmark_data(benchmark, start=start, end=end)
#
# NameError: name 'get_benchmark_data' is not defined

# %%
from CAL.PyCAL import *

today = Date.todaysDate()
calendar = Calendar('China.IB')
if calendar.isBizDay(today):
    print u'恩，今天是工作日。。。'
else:
    print u'哦也，今天放假！'

    
print DataAPI.MktEqudGet(secID = '600000.XSHG',
    field = '',#['secShortName', 'closePrice'],
    beginDate = '20140101',
    endDate = '20140131')


print DataAPI.EquGet(secID = '600000.XSHG', ticker = '', listStatusCD = '', field = '', pandas = '1')


#print DataAPI.EquAllotGet(secID = '', ticker =  '000002', beginDate = '20040101', endDate = '20140131', isAllotment = '1', field = '',pandas = '1')

print DataAPI.EquDivGet(secID =  '', ticker =  '000002', beginDate = '20040101', endDate ='20140131', eventProcessCD = '', field = '',pandas = '1')

print DataAPI.EquIndustryGet(secID =  '', ticker = '000002', industry = '',  field = '',pandas = '1') #intoDate = '20040101', outDate = '20140131',

print DataAPI.EquIPOGet(secID = '', ticker =  '000002', eventProcessCD = '', field = '', pandas = '1')

#print DataAPI.EquRetudGet(secID = '', ticker = '000002', beginDate = '', dailyReturnNoReinvLower = '', dailyReturnNoReinvUpper
#= '', dailyReturnReinvLower = '', dailyReturnReinvUpper = '',
#endDate = '', isChgPctl = '', listStatusCD = '', field = '', pandas = '1')

print DataAPI.FstDetailGet(secID = '', ticker = '000002', beginDate = '', endDate = '', field = '', pandas = '1') #不清楚干啥的。

DataAPI.EquShareGet(secID = '', ticker = '000002', beginDate = '', endDate = '', partyID = '', field = '', pandas
= '1')

DataAPI.FundNavGet(secID = '', ticker = '161720', beginDate = '', endDate = '', field = '', pandas = '1')
# Out:
# 恩，今天是工作日。。。
#           secID  ticker secShortName exchangeCD   tradeDate  preClosePrice  \
# 0   600000.XSHG  600000         浦发银行       XSHG  2014-01-02           9.43
# 1   600000.XSHG  600000         浦发银行       XSHG  2014-01-03           9.33
# 2   600000.XSHG  600000         浦发银行       XSHG  2014-01-06           9.14
# 3   600000.XSHG  600000         浦发银行       XSHG  2014-01-07           9.19
# 4   600000.XSHG  600000         浦发银行       XSHG  2014-01-08           9.14
# 5   600000.XSHG  600000         浦发银行       XSHG  2014-01-09           9.20
# 6   600000.XSHG  600000         浦发银行       XSHG  2014-01-10           9.29
# 7   600000.XSHG  600000         浦发银行       XSHG  2014-01-13           9.41
# 8   600000.XSHG  600000         浦发银行       XSHG  2014-01-14           9.39
# 9   600000.XSHG  600000         浦发银行       XSHG  2014-01-15           9.40
# 10  600000.XSHG  600000         浦发银行       XSHG  2014-01-16           9.23
# ...

# %%
DataAPI.FundGet(secID = '', ticker = '161720', field = '', pandas = '1')
# Out:
#          secID  ticker    secShortName category operationMode indexFund  \
# 0  161720.OFCN  161720  招商中证全指证券公司指数分级        E             O         I
#
#    etfLof  isQdii  isFof  isGuarFund     ...      establishDate  listDate  \
# 0     NaN       0      0           0     ...         2014-11-13       NaN
#
#    delistDate managementCompany managementFullName  custodian  \
# 0         NaN             27275         招商基金管理有限公司       2035
#
#    custodianFullName                                        investField  \
# 0         中国银行股份有限公司  本基金投资于具有良好流动性的金融工具，包括中证全指证券公司指数的成份股、备选成份股、股票、股...
#
#                                         investTarget  \
# 0  本基金进行被动式指数化投资，通过严格的投资纪律约束和数量化的风险管理手段，实现对标的指数的有...
#
#                       perfBenchmark
# 0  5.0％×活期存款利率(税后)+95.0％×中证全指证券公司指数
#
# [1 rows x 24 columns]

# %%
print DataAPI.MktEqudGet(secID = '', ticker = '000002', beginDate = '', endDate = '', field = '', pandas = '1')
# Out:
#            secID  ticker secShortName exchangeCD   tradeDate  preClosePrice  \
# 0    000002.XSHE  000002          万科A       XSHE  2014-03-24           8.01
# 1    000002.XSHE  000002          万科A       XSHE  2014-03-25           8.06
# 2    000002.XSHE  000002          万科A       XSHE  2014-03-26           7.98
# 3    000002.XSHE  000002          万科A       XSHE  2014-03-27           7.85
# 4    000002.XSHE  000002          万科A       XSHE  2014-03-28           7.98
# 5    000002.XSHE  000002          万科A       XSHE  2014-03-31           8.12
# 6    000002.XSHE  000002          万科A       XSHE  2014-04-01           8.09
# 7    000002.XSHE  000002          万科A       XSHE  2014-04-02           8.08
# 8    000002.XSHE  000002          万科A       XSHE  2014-04-03           8.29
# 9    000002.XSHE  000002          万科A       XSHE  2014-04-04           8.10
# 10   000002.XSHE  000002          万科A       XSHE  2014-04-08           8.11
# ...

# %%
DataAPI.MktTickRTSnapshotGet(securityID = '000002.XSHE', field = '', pandas = '1')
DataAPI.MktTickRTSnapshotIndexGet(securityID='000908.XSHG', field = '', pandas = '1')
DataAPI.MktTickRTIntraDayGet(securityID= '000002.XSHE', startTime = '', endTime = '', field = '', pandas = '1')
# Out:
#         dataDate  dataTime  secOffset  ticker exchangeCD shortNM currencyCD  \
# 0     2015-03-23  09:25:00       5100  000002       XSHE   万  科Ａ        CNY
# 1     2015-03-23  09:25:03       5103  000002       XSHE   万  科Ａ        CNY
# 2     2015-03-23  09:25:06       5106  000002       XSHE   万  科Ａ        CNY
# 3     2015-03-23  09:25:09       5109  000002       XSHE   万  科Ａ        CNY
# 4     2015-03-23  09:25:12       5112  000002       XSHE   万  科Ａ        CNY
# 5     2015-03-23  09:25:15       5115  000002       XSHE   万  科Ａ        CNY
# 6     2015-03-23  09:25:19       5119  000002       XSHE   万  科Ａ        CNY
# 7     2015-03-23  09:25:22       5122  000002       XSHE   万  科Ａ        CNY
# 8     2015-03-23  09:25:25       5125  000002       XSHE   万  科Ａ        CNY
# 9     2015-03-23  09:25:28       5128  000002       XSHE   万  科Ａ        CNY
# 10    2015-03-23  09:25:31       5131  000002       XSHE   万  科Ａ        CNY
# ...

# %%
#DataAPI.MktStockFactorsOneDayGet(secID ='000002.XSHE', date='20150101', field = '', pandas = '1')
print DataAPI.MktStockFactorsDateRangeGet(secID='000002.XSHE', field = '', pandas = '1')
# Out:
#             secID  ticker   tradeDate  AccountsPayablesTDays  \
# 0     000002.XSHE  000002  2011-01-04                     65
# 1     000002.XSHE  000002  2011-01-05                     65
# 2     000002.XSHE  000002  2011-01-06                     65
# 3     000002.XSHE  000002  2011-01-07                     65
# 4     000002.XSHE  000002  2011-01-10                     65
# 5     000002.XSHE  000002  2011-01-11                     65
# 6     000002.XSHE  000002  2011-01-12                     65
# 7     000002.XSHE  000002  2011-01-13                     65
# 8     000002.XSHE  000002  2011-01-14                     65
# 9     000002.XSHE  000002  2011-01-17                     65
# 10    000002.XSHE  000002  2011-01-18                     65
# 11    000002.XSHE  000002  2011-01-19                     65
# 12    000002.XSHE  000002  2011-01-20                     65
# 13    000002.XSHE  000002  2011-01-21                     65
# ...
