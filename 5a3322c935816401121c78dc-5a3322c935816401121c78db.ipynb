# %% [markdown]
# # 哈哈哈哈

# %% [raw]
# from __future__ import division
# start = '2017-01-01'                       # 回测起始时间
# end = '2017-12-12'                         # 回测结束时间
# universe = DynamicUniverse('A')        # 证券池，支持股票和基金、期货
# benchmark = 'ZZ500'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 1                      # 执行handle_data的时间间隔
# import datetime
# import numpy as np
# import pandas as pd
#
# def getuniverse(date,now):
#         list0 = ['secID','secShortName','newsPublishDate','heatIndex']
#         a = DataAPI.NewsHeatIndexV2Get(secID=u"",exchangeCD=u"",ticker=u"",secShortName=u"",beginDate=date,endDate= now,field=list0,pandas="1")
#         hotindex = np.array([float(a.heatIndex.tolist()[k]) for k in range(len(a))])
#         index = hotindex.argsort()
#         newshot = a.iloc[index[-20:]]
#         secID = newshot.secID
#         list1 = ['secID','secShortName','newsPublishDate','sentimentIndex']
#         qinggan = DataAPI.NewsSentimentIndexV2Get(secID=secID,exchangeCD=u"",ticker="",secShortName=u"",beginDate=date,endDate=now,field=list1,pandas="1")
#         data = pd.merge(newshot,qinggan)
#         data = data[data['sentimentIndex']>0]
#         return data
#
# accounts = {'fantasy_account': AccountConfig(account_type='security', capital_base=1000000,commission = Commission(buycost=0.001, sellcost=0.002, unit='perValue'),slippage = Slippage(value=0.0005 , unit='perValue'))}
#
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#     account = context.get_account('fantasy_account')
#     now = context.current_date.strftime("%Y%m%d")
#     pre_date = (datetime.datetime.strptime(now,'%Y%m%d')-datetime.timedelta(days=1)).strftime("%Y%m%d")
#     my_univ = getuniverse(pre_date,now)
#     if type(my_univ) != None:
#         if len(my_univ.secID)>0:
#             my_univ = my_univ.drop_duplicates(['secID'])
#             univ = my_univ['secID'].tolist()
#             v = 0.8 / len(univ)
#         else:
#             univ = []
#             v = 0
#         for s in account.valid_secpos:
#             if s not in univ:
#                 order_to(s, 0)
#         for s in univ:
#             order_pct_to(s,v)
