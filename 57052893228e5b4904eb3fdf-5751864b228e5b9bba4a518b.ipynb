# %% [markdown]
# # 全市场小市值策略

# %% [raw]
# import datetime as dt
# import pandas as pd
# import numpy as np
#
# from CAL.PyCAL import *
#
# # personal lib
# from lib import report
#
# start = dt.datetime(2014, 2, 9)
# end = dt.datetime(2016, 3, 31)
# benchmark =  'HS300'
# universe = set_universe('A')
# capital_base = 100000
# freq = 'd'
# refresh_rate = 10
# commission = Commission(buycost=0.0003, sellcost=0.0013)
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#
#     current_date = Date.fromDateTime(account.current_date)
#     cal = Calendar('China.SSE')
#     last_day = cal.advanceDate(current_date,'-1B',BizDayConvention.Preceding)            #计算出倒数第一个交易日
#     last_day_str = last_day.strftime("%Y-%m-%d")
#
#     data = DataAPI.MktEqudAdjGet(secID=set_universe("A"), tradeDate=last_day_str, field=["secID", "ticker", "negMarketValue", "marketValue"])
#     data.sort(columns=['marketValue'], inplace=True)
#     buy_list = data.head(100)
#
#     for stk in account.valid_secpos:
#         if stk not in buy_list['secID']:
#             order_to(stk, 0)
#
#     for stk in buy_list['secID']:
#         if stk not in account.avail_secpos:
#             if account.cash < 0:
#                 break
#             try:
#                 order_pct_to(stk, 0.05)
#             except:
#                 continue
