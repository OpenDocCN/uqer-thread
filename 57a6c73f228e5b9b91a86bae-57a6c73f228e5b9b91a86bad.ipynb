# %% [markdown]
# #

# %% [raw]
# # Logistic Regression Classifier #logistic回归分类器
# from sklearn.linear_model import LogisticRegression
# import numpy as np
# import math
# from sklearn import preprocessing
# import pandas as pd
# #Index=DataAPI.MktIdxdGet(tradeDate=u"",indexID=u"",ticker=u"000001",beginDate=u"20110101",endDate=u"20120115",field=u"preCloseIndex,openIndex,closeIndex",pandas="1")
# price=DataAPI.MktEqudGet(tradeDate=u"",secID=u"",ticker=u"600018",beginDate=u"20110103",endDate=u"20110615",isOpen="",field=u"closePrice",pandas="1")
# factor=DataAPI.MktStockFactorsDateRangeGet(secID=u"",ticker=u"600018",beginDate=u"20110103",endDate=u"20110615",field=u"ticker,tradeDate,ROC20,RVI,Elder",pandas="1")
#
# pricea=np.diff(price['closePrice'])
# factora=pd.concat([factor, pd.DataFrame(pricea,columns = ['pricea'])], axis = 1)
# factora['symbol'] = 0
# factora['symbol'] = factora['pricea'].apply(lambda x:1 if x>0.1 else 0)         ######symbol 就是我们要的label
# print(len(pricea),len(factora))
#
# factora=factora[1:len(factor)-1]
# factorb=factora.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
# print(factorb)
#
# z=factorb[['ROC20','RVI','Elder']].values
# y=factorb['symbol'].values
# #print(y)
# z_scaled=preprocessing.scale(z)
#
#
# ja=z.mean(axis=0)[0]
# jb=z.mean(axis=0)[1]
# jc=z.mean(axis=0)[2]
#
# ka=z.std(axis=0)[0]
# kb=z.std(axis=0)[1]
# kc=z.std(axis=0)[2]
#
# print(ja,ka)
# print(jb,kb)
# print(jc,kc)
#
# #z1=factor[['ROC6']].values
# #z2=factor[['RVI']].values
#
# #print(y)
# lr = LogisticRegression(C = 1.0)
# m=[]
# for i in z_scaled:
#  m.append([1.0,i[0],i[1],i[2]])
#
# #print(m)
#
# #print(m,y)
# lr.fit(m, y)
# a=lr.coef_.tolist()[0][0]
# b=lr.coef_.tolist()[0][1]
# c=lr.coef_.tolist()[0][2]
# d=lr.coef_.tolist()[0][3]
# #print(a,b,c,d)
#
# import quartz
# from CAL.PyCAL import *
# import pandas as pd
# start = '2012-01-06'                       # 回测起始时间
# end = '2016-07-09'
# universe=['600018.XSHG']
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate =1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# benchmark='600018.XSHG'
# from matplotlib import pylab
# cal=Calendar('China.SSE')
# commission = Commission(buycost=0.0008, sellcost=0.0018)
#
# mk=[]
# def initialize(account):
#    pass
#
# def handle_data(account):
#      factors=DataAPI.MktStockFactorsDateRangeGet(secID=u"",ticker=u"600018",beginDate=account.previous_date,\
# endDate=account.previous_date,field=u"ticker,tradeDate,ROC20,RVI,Elder",pandas="1")
#      ta=factors['ROC20'][0]
#      taa=(ta-ja)/(ka/math.sqrt(102))
#      tb=factors['RVI'][0]
#      tbb=(tb-jb)/(kb/math.sqrt(102))
#      tc=factors['Elder'][0]
#      tcc=(tc-jc)/(kc/math.sqrt(102))
#      s=a+b*taa+c*tbb+d*tcc
#      f=1/(1+math.exp(-s))
#      #print(f)
#      for s in account.universe:
#        if f>0.99:
#          order_pct_to(s,1)
#        elif f<0.01:
#          order_pct_to(s,0)
#
#
# bt,acct=quartz.backtest(start=start,
#             end=end,
#             benchmark=benchmark,
#             universe=universe,
#             capital_base=capital_base,
#             initialize=initialize,
#             handle_data=handle_data,
#             refresh_rate=refresh_rate)
#
# perf=quartz.perf_parse(bt,acct)
#
# out_keys=['annualized_return','volatility','information_ratio',
#     'sharpe','max_drawdown','alpha','beta']
#
# for k in out_keys:
#     print'%s:%s'%(k,perf[k])
#
# perf['cumulative_returns'].plot()
# perf['benchmark_cumulative_returns'].plot()
# pylab.legend(['current_strategy','600018'])
