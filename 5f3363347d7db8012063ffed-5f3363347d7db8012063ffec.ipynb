# %% [markdown]
# # 牛市策略

# %% [markdown]
# 思路：中国牛市周一涨，周五跌
# ∴ 买指数，周五买，周一卖，只看牛市

# %% [raw]
# #    依据百度到的第11次牛市：2014年3月12日1974-5166点2015年6月12日（一年三个月+162%），取中间半年2014.6.1-2014.12.31
# start = '2014-06-01'                       # 回测起始时间
# end = '2014-12-31'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['510300.XSHG']         # 证券池，回测支持股票和基金
# ETF300 ='510300.XSHG'
# capital_base = 100000                      # 起始资金
# refresh_rate = 1                          # 调仓频率，即每 refresh_rate 个交易日执行一次 handle_data() 函数
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#
#     today = account.current_date
#
#     # 开仓
#     if today.weekday() == 0:
#         account.order_pct_to(ETF300, 1)
#
#     # 平仓
#     if today.weekday() == 4:
#         account.order_pct_to(ETF300, 0)
