# %% [markdown]
# # 这是怎么个情况？

# %% [raw]
# start = '2006-01-01'                       # 回测起始时间
# end = '2016-01-19'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['000933.XSHE']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
# def handle_data(account):
#     histclose = account.get_attribute_history('closePrice', 4)
#     histopen = account.get_attribute_history('openPrice', 4)
#     global s
#     global o
#     for o  in account.universe:
#         if histopen[o][3]<histopen[o][0] and histopen[o][3]<histopen[o][1] and histopen[o][3]<histopen[o][2] and o not in account.valid_secpos:
#
#             for s  in account.universe:
#                 if histclose[s][3]>histclose[s][0] and histclose[s][3]>histclose[s][1] and histclose[s][3]>histclose[s][2] and s not in account.valid_secpos:
#                     order(s,10000)
#         elif histclose[s][3]/histclose[s][2]-1>0.1  and s in account.valid_secpos:
#             order_to(s,0)
#         elif 1-histclose[s][3]/histclose[s][2]<0.05  and s in account.valid_secpos:
#             order_to(s,0)
