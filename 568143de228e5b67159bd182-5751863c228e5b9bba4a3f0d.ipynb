# %% [markdown]
# # 这个奇葩错误

# %% [raw]
# # -*- coding: utf-8 -*-
# import numpy as np
# import pandas as pd
#
# dftmp=pd.read_csv('allbasics.csv').code
# i=0
# for s in dftmp:
#     if dftmp[i][0] == '9':
#         dftmp=dftmp.drop(i)#去除B股
#     i=i+1
#
# print dftmp
