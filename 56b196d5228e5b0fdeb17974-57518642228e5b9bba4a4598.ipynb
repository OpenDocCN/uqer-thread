# %% [markdown]
# # 短期微涨的价值股

# %% [markdown]
# ## 选股逻辑：
#
# - PE 大于0但小于40
# - 且 五日收益大于0.01但小于0.03（即五日涨幅在1%到3%之间的股票）
#
# ## 调仓逻辑：
#
# - 选出来的股票，平均持仓

# %% [raw]
# import numpy as np
# from CAL.PyCAL import *
#
# start = '2013-01-05'
# end = '2015-12-31'
# benchmark = 'HS300'
#
# universe = StockScreener(Factor.PE.value_range(0, 40))
# capital_base = 1000000
# refresh_rate = 5
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     close_price = account.referencePrice                   # 前一日收盘价
#
#     #  获取回测当日的前一天日期
#     dt = Date.fromDateTime(account.current_date)
#     cal = Calendar('China.SSE')
#     last_day = cal.advanceDate(dt,'-1B',BizDayConvention.Preceding)            #计算出倒数第一个交易日
#     last_day_str = last_day.strftime("%Y%m%d")
#
#     # PE: 市盈率； REVS5： 股票五日收益（1.01表示五日内涨了1%）
#     factor = DataAPI.MktStockFactorsOneDayGet(tradeDate=last_day_str,secID=account.universe,field=u"secID,PE,REVS5",pandas="1")
#
#     pe = factor[(factor.PE > 0) & (factor.PE < 40)]
#     revs5 = factor[(factor.REVS5 > 1.01) & (factor.REVS5 < 1.03)]
#
#     buylist = {stk:0 for stk in pe.secID.values if stk in revs5.secID.values}
#
#     for s in account.valid_secpos:
#         if s not in buylist:
#             order_to(s, 0)
#
#     v = account.referencePortfolioValue / len(buylist)
#     for s in buylist:
#         buylist[s] = v / close_price[s] - account.valid_secpos.get(s, 0)
#
#     for s in sorted(buylist, key=buylist.get):
#         order(s, buylist[s])

# %%
bt.cash.plot()
