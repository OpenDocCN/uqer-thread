# %% [markdown]
# # 每次在stockscreener上用超过两个factor就会出现这个问题

# %% [raw]
# universe = StockScreener((Factor.PE.value_range(0, 30)&Factor.PB.value_range(0, 2))&(Factor.DebtsAssetRatio.nsmall(100) & Factor.NetProfitGrowRate.pct_range(0.3,1))) #因子选股
