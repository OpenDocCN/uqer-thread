# %% [markdown]
# #

# %%
class Uqer101(object):
    def __init__(self, pn_data):
        """
        :type pn_data: pandas.Panel
        """
        self.pn_data = pn_data
    def CCI5(self): return self.pn_data.minor_xs('CCI5')   # 5日顺势指标（Commodity Channel Index），专门测量股价是否已超出常态分布范围。属于超买超卖型因子。
    def CCI88(self): return self.pn_data.minor_xs('CCI88')   # 88日顺势指标（Commodity Channel Index），专门测量股价是否已超出常态分布范围。属于超买超卖型因子。
    def KDJ_K(self): return self.pn_data.minor_xs('KDJ_K')   # 随机指标。它综合了动量观念、强弱指标及移动平均线的优点，用来度量股价脱离价格正常范围的变异程度。属于超买超卖型因子。
    def KDJ_D(self): return self.pn_data.minor_xs('KDJ_D')   # 随机指标。它综合了动量观念、强弱指标及移动平均线的优点，用来度量股价脱离价格正常范围的变异程度。属于超买超卖型因子。
    def KDJ_J(self): return self.pn_data.minor_xs('KDJ_J')   # 随机指标。它综合了动量观念、强弱指标及移动平均线的优点，用来度量股价脱离价格正常范围的变异程度。属于超买超卖型因子。
    def ROC6(self): return self.pn_data.minor_xs('ROC6')   # 6日变动速率（Price Rate of Change），以当日的收盘价和N天前的收盘价比较，通过计算股价某一段时间内收盘价变动的比例，应用价格的移动比较来测量价位动量。属于超买超卖型因子。
    def ROC20(self): return self.pn_data.minor_xs('ROC20')   # 6日变动速率（Price Rate of Change），以当日的收盘价和N天前的收盘价比较，通过计算股价某一段时间内收盘价变动的比例，应用价格的移动比较来测量价位动量。属于超买超卖型因子。
    def SBM(self): return self.pn_data.minor_xs('SBM')   # 计算ADTM因子的中间变量。属于超买超卖型因子。
    def STM(self): return self.pn_data.minor_xs('STM')   # 计算ADTM因子的中间变量。属于超买超卖型因子。
    def UpRVI(self): return self.pn_data.minor_xs('UpRVI')   # 计算RVI因子的中间变量。属于超买超卖型因子。
    def DownRVI(self): return self.pn_data.minor_xs('DownRVI')   # 计算RVI因子的中间变量。属于超买超卖型因子。
    def RVI(self): return self.pn_data.minor_xs('RVI')   # 相对离散指数（Relative Volatility Index），又称“相对波动性指标”，用于测量价格的发散趋势，主要用作辅助的确认指标，即配合均线系统、动量指标或其它趋势指标使用。属于超买超卖型因子。
    def SRMI(self): return self.pn_data.minor_xs('SRMI')   # 修正动量指标。属于超买超卖型因子。
    def ChandeSD(self): return self.pn_data.minor_xs('ChandeSD')   # 计算CMO因子的中间变量，SD是今日收盘价与昨日收盘价（下跌日）差值的绝对值加总。若当日上涨，则增加值为0。属于超买超卖型因子。
    def ChandeSU(self): return self.pn_data.minor_xs('ChandeSU')   # 计算CMO因子的中间变量，SU是今日收盘价与昨日收盘价（上涨日）差值加总。若当日下跌，则增加值为0。属于超买超卖型因子。
    def CMO(self): return self.pn_data.minor_xs('CMO')   # 钱德动量摆动指标（Chande Momentum Osciliator），与其他动量指标摆动指标如相对强弱指标（RSI）和随机指标（KDJ）不同，钱德动量指标在计算公式的分子中采用上涨日和下跌日的数据。属于超买超卖型因子。
    def DBCD(self): return self.pn_data.minor_xs('DBCD')   # 异同离差乖离率，先计算乖离率BIAS，然后计算不同日的乖离率之间的离差，最后对离差进行指数移动平滑处理。优点是能够保持指标的紧密同步，并且线条光滑，信号明确，能够有效的过滤掉伪信号。属于超买超卖型因子。
    def ARC(self): return self.pn_data.minor_xs('ARC')   # 变化率指数均值，股票的价格变化率RC指标的均值，用以判断前一段交易周期内股票的平均价格变化率。属于超买超卖型因子。
    def OBV(self): return self.pn_data.minor_xs('OBV')   # 能量潮指标（On Balance Volume，OBV），以股市的成交量变化来衡量股市的推动力，从而研判股价的走势。属于成交量型因子
    def OBV6(self): return self.pn_data.minor_xs('OBV6')   # 6日能量潮指标（On Balance Volume，OBV），以股市的成交量变化来衡量股市的推动力，从而研判股价的走势。属于成交量型因子
    def OBV20(self): return self.pn_data.minor_xs('OBV20')   # 20日能量潮指标（On Balance Volume，OBV），以股市的成交量变化来衡量股市的推动力，从而研判股价的走势。属于成交量型因子
    def TVMA20(self): return self.pn_data.minor_xs('TVMA20')   # 20日成交金额的移动平均值（Turnover Value Moving Average）。属于成交量型因子
    def TVMA6(self): return self.pn_data.minor_xs('TVMA6')   # 6日成交金额的移动平均值（Turnover Value Moving Average）。属于成交量型因子
    def TVSTD20(self): return self.pn_data.minor_xs('TVSTD20')   # 20日成交金额的标准差（Turnover Value Standard Deviation）。属于成交量型因子
    def TVSTD6(self): return self.pn_data.minor_xs('TVSTD6')   # 20日成交金额的标准差（Turnover Value Standard Deviation）。属于成交量型因子
    def VDEA(self): return self.pn_data.minor_xs('VDEA')   # 计算VMACD因子的中间变量（Volume Difference Exponential Average）。属于成交量型因子
    def VDIFF(self): return self.pn_data.minor_xs('VDIFF')   # 计算VMACD因子的中间变量。属于成交量型因子
    def VEMA10(self): return self.pn_data.minor_xs('VEMA10')   # 成交量的10日指数移动平均。属于成交量型因子
    def VEMA12(self): return self.pn_data.minor_xs('VEMA12')   # 成交量的12日指数移动平均。属于成交量型因子
    def VEMA26(self): return self.pn_data.minor_xs('VEMA26')   # 成交量的26日指数移动平均。属于成交量型因子
    def VEMA5(self): return self.pn_data.minor_xs('VEMA5')   # 成交量的5日指数移动平均。属于成交量型因子
    def VMACD(self): return self.pn_data.minor_xs('VMACD')   # 成交量量指数平滑异同移动平均线（Volume Moving Average Convergence and Divergence），VMACD的意义和MACD基本相同, 但VMACD取用的数据源是成交量，MACD取用的数据源是成交价格。属于成交量型因子
    def VOSC(self): return self.pn_data.minor_xs('VOSC')   # 成交量震荡（Volume Oscillator），又称移动平均成交量指标，但它并非仅仅计算成交量的移动平均线，而是通过对成交量的长期移动平均线和短期移动平均线之间的比较，分析成交量的运行趋势和及时研判趋势转变方向。属于成交量型因子
    def VR(self): return self.pn_data.minor_xs('VR')   # 成交量比率（Volume Ratio），通过分析股价上升日成交额（或成交量，下同）与股价下降日成交额比值，从而掌握市场买卖气势的中期技术指标。属于成交量型因子
    def VROC12(self): return self.pn_data.minor_xs('VROC12')   # 12日量变动速率指标（Volume Rate of Change），以今天的成交量和N天前的成交量比较，通过计算某一段时间内成交量变动的幅度，应用成交量的移动比较来测量成交量运动趋向，达到事先探测成交量供需的强弱，进而分析成交量的发展趋势及其将来是否有转势的意愿，属于成交量的反趋向指标。属于成交量型因子
    def VROC6(self): return self.pn_data.minor_xs('VROC6')   # 6日量变动速率指标（Volume Rate of Change），以今天的成交量和N天前的成交量比较，通过计算某一段时间内成交量变动的幅度，应用成交量的移动比较来测量成交量运动趋向，达到事先探测成交量供需的强弱，进而分析成交量的发展趋势及其将来是否有转势的意愿，属于成交量的反趋向指标。属于成交量型因子
    def VSTD10(self): return self.pn_data.minor_xs('VSTD10')   # 10日成交量标准差（Volume Standard Deviation），考察成交量的波动程度。属于成交量型因子
    def VSTD20(self): return self.pn_data.minor_xs('VSTD20')   # 20日成交量标准差（Volume Standard Deviation），考察成交量的波动程度。属于成交量型因子
    def KlingerOscillator(self): return self.pn_data.minor_xs('KlingerOscillator')   # 成交量摆动指标，该指标在决定长期资金流量趋势的同时保持了对于短期资金流量的敏感性，因而可以用于预测短期价格拐点。属于成交量型因子
    def MoneyFlow20(self): return self.pn_data.minor_xs('MoneyFlow20')   # 20日资金流量，用收盘价、最高价及最低价的均值乘以当日成交量即可得到该交易日的资金流量。属于成交量型因子
    def AD(self): return self.pn_data.minor_xs('AD')   # 累积/派发线（Accumulation / Distribution Line，该指标将每日的成交量通过价格加权累计，用以计算成交量的动量。属于趋势型因子
    def AD20(self): return self.pn_data.minor_xs('AD20')   # 累积/派发线（Accumulation / Distribution Line，该指标将每日的成交量通过价格加权累计，用以计算成交量的动量。属于趋势型因子
    def AD6(self): return self.pn_data.minor_xs('AD6')   # 累积/派发线（Accumulation / Distribution Line，该指标将每日的成交量通过价格加权累计，用以计算成交量的动量。属于趋势型因子
    def CoppockCurve(self): return self.pn_data.minor_xs('CoppockCurve')   # 估波指标（Coppock Curve），又称“估波曲线”，该指标通过计算月度价格的变化速率的加权平均值来测量市场的动量，属于长线指标，这里我们改为日间的指标。属于趋势型因子
    def ASI(self): return self.pn_data.minor_xs('ASI')   # 累计振动升降指标（Accumulation Swing Index），又称实质线，ASI企图以开盘、最高、最低、收盘价构筑成一条幻想线，以便取代目前的走势，形成最能表现当前市况的真实市场线（Real Market）。
    def ChaikinOscillator(self): return self.pn_data.minor_xs('ChaikinOscillator')   # 佳庆指标（Chaikin Oscillator），该指标基于AD曲线的指数移动均线而计算得到。属于趋势型因子
    def ChaikinVolatility(self): return self.pn_data.minor_xs('ChaikinVolatility')   # 佳庆离散指标（Chaikin Volatility，简称CVLT，VCI，CV），又称“佳庆变异率指数”，是通过测量一段时间内价格幅度平均值的变化来反映价格的离散程度。属于趋势型因子
    def EMV14(self): return self.pn_data.minor_xs('EMV14')   # 简易波动指标（Ease of Movement Value），EMV将价格与成交量的变化结合成一个波动指标来反映股价或指数的变动状况，由于股价的变化和成交量的变化都可以引发该指标数值的变动，EMV实际上也是一个量价合成指标。属于趋势型因子
    def EMV6(self): return self.pn_data.minor_xs('EMV6')   # 简易波动指标（Ease of Movement Value），EMV将价格与成交量的变化结合成一个波动指标来反映股价或指数的变动状况，由于股价的变化和成交量的变化都可以引发该指标数值的变动，EMV实际上也是一个量价合成指标。属于趋势型因子
    def plusDI(self): return self.pn_data.minor_xs('plusDI')   # 上升指标，DMI因子的构成部分。属于趋势型因子
    def minusDI(self): return self.pn_data.minor_xs('minusDI')   # 下降指标，DMI因子的构成部分。属于趋势型因子
    def ADX(self): return self.pn_data.minor_xs('ADX')   # 平均动向指数，DMI因子的构成部分。属于趋势型因子
    def ADXR(self): return self.pn_data.minor_xs('ADXR')   # 相对平均动向指数，DMI因子的构成部分。属于趋势型因子
    def Aroon(self): return self.pn_data.minor_xs('Aroon')   # Aroon通过计算自价格达到近期最高值和最低值以来所经过的期间数，帮助投资者预测证券价格从趋势到区域区域或反转的变化，Aroon指标分为Aroon、AroonUp和AroonDown3个具体指标。属于趋势型因子
    def AroonDown(self): return self.pn_data.minor_xs('AroonDown')   # 计算Aroon因子的中间变量。属于趋势型因子
    def AroonUp(self): return self.pn_data.minor_xs('AroonUp')   # 计算Aroon因子的中间变量。属于趋势型因子
    def DEA(self): return self.pn_data.minor_xs('DEA')   # 计算MACD因子的中间变量。属于趋势型因子
    def DIFF(self): return self.pn_data.minor_xs('DIFF')   # 计算MACD因子的中间变量。属于趋势型因子
    def DDI(self): return self.pn_data.minor_xs('DDI')   # 方向标准离差指数，观察一段时间内股价相对于前一天向上波动和向下波动的比例，并对其进行移动平均分析，DDI指标倾向于显示一种长波段趋势的方向改变。属于趋势型因子
    def DIZ(self): return self.pn_data.minor_xs('DIZ')   # 计算DDI因子的中间变量。属于趋势型因子
    def DIF(self): return self.pn_data.minor_xs('DIF')   # 计算DDI因子的中间变量。属于趋势型因子
    def MTM(self): return self.pn_data.minor_xs('MTM')   # 动量指标（Momentom Index），动量指数以分析股价波动的速度为目的，研究股价在波动过程中各种加速，减速，惯性作用以及股价由静到动或由动转静的现象。属于趋势型因子
    def MTMMA(self): return self.pn_data.minor_xs('MTMMA')   # 因子MTM的10日均值。属于趋势型因子
    def PVT(self): return self.pn_data.minor_xs('PVT')   # 价量趋势（Price and Volume Trend）指标，把能量变化与价格趋势有机地联系到了一起，从而构成了量价趋势指标。属于趋势型因子
    def PVT6(self): return self.pn_data.minor_xs('PVT6')   # 因子PVT的6日均值。属于趋势型因子
    def PVT12(self): return self.pn_data.minor_xs('PVT12')   # 因子PVT的12日均值。属于趋势型因子
    def TRIX5(self): return self.pn_data.minor_xs('TRIX5')   # 5日收盘价三重指数平滑移动平均指标（Triple Exponentially Smoothed Average），TRIX根据移动平均线理论，对一条平均线进行三次平滑处理，再根据这条移动平均线的变动情况来预测股价的长期走势。属于趋势型因子
    def TRIX10(self): return self.pn_data.minor_xs('TRIX10')   # 10日收盘价三重指数平滑移动平均指标（Triple Exponentially Smoothed Average），TRIX根据移动平均线理论，对一条平均线进行三次平滑处理，再根据这条移动平均线的变动情况来预测股价的长期走势。属于趋势型因子
    def UOS(self): return self.pn_data.minor_xs('UOS')   # 终极指标（Ultimate Oscillator），现行使用的各种振荡指标，对于周期参数的选择相当敏感，不同市况、不同参数设定的振荡指标，产生的结果截然不同，因此，选择最佳的参数组合，成为使用振荡指标之前最重要的一道手续。属于趋势型因子
    def MA10RegressCoeff12(self): return self.pn_data.minor_xs('MA10RegressCoeff12')   # 10日价格平均线12日线性回归系数。属于趋势型因子
    def MA10RegressCoeff6(self): return self.pn_data.minor_xs('MA10RegressCoeff6')   # 10日价格平均线6日线性回归系数。属于趋势型因子
    def PLRC6(self): return self.pn_data.minor_xs('PLRC6')   # 6日收盘价格线性回归系数（Price Linear Regression Coefficient）。属于趋势型因子
    def PLRC12(self): return self.pn_data.minor_xs('PLRC12')   # 12日收盘价格价格线性回归系数（Price Linear Regression Coefficient）。属于趋势型因子
    def SwingIndex(self): return self.pn_data.minor_xs('SwingIndex')   # 振动升降指标，计算ASI因子的中间变量。属于趋势型因子
    def Ulcer10(self): return self.pn_data.minor_xs('Ulcer10')   # 由Peter Martin于1987年提出，1989年发表于Peter Martin和Byron McCann的著作The Investors Guide to Fidelity Funds，用于考察向下的波动性。属于趋势型因子
    def Ulcer5(self): return self.pn_data.minor_xs('Ulcer5')   # 由Peter Martin于1987年提出，1989年发表于Peter Martin和Byron McCann的著作The Investors Guide to Fidelity Funds，用于考察向下的波动性。属于趋势型因子
    def Hurst(self): return self.pn_data.minor_xs('Hurst')   # 赫斯特指数（Hurst exponent）。是由英国水文专家H．E．Hurst提出了用重标极差(R/S)分析方法来建立赫斯特指数(H)，作为判断时间序列数据遵从随机游走还是有偏的随机游走过程的指标。属于趋势型因子
    def ACD6(self): return self.pn_data.minor_xs('ACD6')   # 6日收集派发指标（Accumulative Distribution）。将市场分为两股收集（买入）及派发（估出）的力量。属于均线型因子
    def ACD20(self): return self.pn_data.minor_xs('ACD20')   # 20日收集派发指标（Accumulative Distribution），将市场分为两股收集（买入）及派发（估出）的力量。属于均线型因子。
    def EMA12(self): return self.pn_data.minor_xs('EMA12')   # 12日指数移动均线（Exponential moving average）。属于均线型因子。
    def EMA26(self): return self.pn_data.minor_xs('EMA26')   # 26日指数移动均线（Exponential moving average）。属于均线型因子。
    def APBMA(self): return self.pn_data.minor_xs('APBMA')   # 绝对偏差移动平均（Absolute Price Bias Moving Average）。考察一段时期内价格偏离均线的移动平均。属于均线型因子。
    def BBI(self): return self.pn_data.minor_xs('BBI')   # 多空指数（Bull and Bear Index）。是一种将不同日数移动平均线加权平均之后的综合指标。属于均线型因子。
    def BBIC(self): return self.pn_data.minor_xs('BBIC')   # 因子BBI除以收盘价得到。属于均线型因子。
    def TEMA10(self): return self.pn_data.minor_xs('TEMA10')   # 10日三重指数移动平均线（Triple Exponential Moving Average），取时间N内的收盘价分别计算其一至三重指数加权平均。属于均线型因子。
    def TEMA5(self): return self.pn_data.minor_xs('TEMA5')   # 5日三重指数移动平均线（Triple Exponential Moving Average），取时间N内的收盘价分别计算其一至三重指数加权平均。属于均线型因子。
    def MA10Close(self): return self.pn_data.minor_xs('MA10Close')   # 均线价格比。由于股票的成交价格有响起均线回归的趋势，计算均线价格比可以预测股票在未来周期的运动趋势。属于均线型因子。
    def AR(self): return self.pn_data.minor_xs('AR')   # 人气指标，是以当天开市价为基础，即以当天市价分别比较当天最高，最低价，通过一定时期内开市价在股价中的地位，反映市场买卖人气。属于能量型因子。
    def BR(self): return self.pn_data.minor_xs('BR')   # 意愿指标，是以昨日收市价为基础，分别与当日最高，最低价相比，通过一定时期收市收在股价中的地位，反映市场买卖意愿的程度。属于能量型因子。
    def ARBR(self): return self.pn_data.minor_xs('ARBR')   # 人气指标（AR）和意愿指标（BR）都是以分析历史股价为手段的技术指标，ARBR使用AR减去BR得到的值。属于能量型因子。
    def CR20(self): return self.pn_data.minor_xs('CR20')   # CR指标以上一个计算周期（这里为20日）的中间价比较当前周期的最高价、最低价，计算出一段时期内股价的“强弱”。属于能量型因子。
    def MassIndex(self): return self.pn_data.minor_xs('MassIndex')   # 梅斯线（Mass Index），本指标是Donald Dorsey累积股价波幅宽度之后所设计的震荡曲线。其最主要的作用，在于寻找飙涨股或者极度弱势股的重要趋势反转点。属于能量型因子。
    def BearPower(self): return self.pn_data.minor_xs('BearPower')   # 空头力道，是计算Elder因子的中间变量。属于能量型因子。
    def BullPower(self): return self.pn_data.minor_xs('BullPower')   # 多头力道，是计算Elder因子的中间变量。属于能量型因子。
    def Elder(self): return self.pn_data.minor_xs('Elder')   # 艾达透视指标（Elder-ray Index），交易者可以经由该指标，观察市场表面之下的多头与空头力道。属于能量型因子。
    def NVI(self): return self.pn_data.minor_xs('NVI')   # 负成交量指标（Negative Volume Index），本指标的主要作用是辨别目前市场行情是处于多头行情还是空头行情，并追踪市场资金流向。属于能量型因子。
    def PVI(self): return self.pn_data.minor_xs('PVI')   # 正成交量指标（Positive Volume Index），本指标的主要作用是辨别目前市场行情是处于多头行情还是空头行情，并追踪市场资金流向。属于能量型因子。
    def RC12(self): return self.pn_data.minor_xs('RC12')   # 12日变化率指数（Rate of Change），类似于动力指数，如果价格始终是上升的，则变化率指数始终在100%线以上，且如果变化速度指数在向上发展时，说明价格上升的速度在加快。属于能量型因子。
    def RC24(self): return self.pn_data.minor_xs('RC24')   # 24日变化率指数（Rate of Change），类似于动力指数，如果价格始终是上升的，则变化率指数始终在100%线以上，且如果变化速度指数在向上发展时，说明价格上升的速度在加快。属于能量型因子。
    def JDQS20(self): return self.pn_data.minor_xs('JDQS20')   # 阶段强势指标，该指标计算一定周期N日内，大盘下跌时，个股上涨的比例。属于能量型因子。
    def ADTM(self): return self.pn_data.minor_xs('ADTM')   # 动态买卖气指标，用开盘价的向上波动幅度和向下波动幅度的距离差值来描述人气高低的指标。属于超买超卖型因子。
    def ATR14(self): return self.pn_data.minor_xs('ATR14')   # 14日均幅指标（Average TRUE Ranger），取一定时间周期内的股价波动幅度的移动平均值，是显示市场变化率的指标，主要用于研判买卖时机。属于超买超卖型因子。
    def ATR6(self): return self.pn_data.minor_xs('ATR6')   # 6日均幅指标（Average TRUE Ranger），取一定时间周期内的股价波动幅度的移动平均值，是显示市场变化率的指标，主要用于研判买卖时机。属于超买超卖型因子。
    def BIAS10(self): return self.pn_data.minor_xs('BIAS10')   # 10日乖离率，简称Y值，是移动平均原理派生的一项技术指标，表示股价偏离趋向指标斩百分比值。属于超买超卖型因子。
    def BIAS20(self): return self.pn_data.minor_xs('BIAS20')   # 20日乖离率，简称Y值，是移动平均原理派生的一项技术指标，表示股价偏离趋向指标斩百分比值。属于超买超卖型因子。
    def BIAS5(self): return self.pn_data.minor_xs('BIAS5')   # 5日乖离率，简称Y值，是移动平均原理派生的一项技术指标，表示股价偏离趋向指标斩百分比值。属于超买超卖型因子。
    def BIAS60(self): return self.pn_data.minor_xs('BIAS60')   # 60日乖离率，简称Y值，是移动平均原理派生的一项技术指标，表示股价偏离趋向指标斩百分比值。属于超买超卖型因子。
    def BollDown(self): return self.pn_data.minor_xs('BollDown')   # 下轨线（布林线）指标（Bollinger Bands），它是研判股价运动趋势的一种中长期技术分析工具。属于超买超卖型因子。
    def BollUp(self): return self.pn_data.minor_xs('BollUp')   # 上轨线（布林线）指标（Bollinger Bands），它是研判股价运动趋势的一种中长期技术分析工具。属于超买超卖型因子。
    def CCI10(self): return self.pn_data.minor_xs('CCI10')   # 10日顺势指标（Commodity Channel Index），专门测量股价是否已超出常态分布范围。属于超买超卖型因子。
    def CCI20(self): return self.pn_data.minor_xs('CCI20')   # 20日顺势指标（Commodity Channel Index），专门测量股价是否已超出常态分布范围。属于超买超卖型因子。
    def AccountsPayablesTDays(self): return self.pn_data.minor_xs('AccountsPayablesTDays')   # 应付账款周转天数（Accounts payable turnover days）。计算方法：应付账款周转天数=360/应付账款周转率。属于营运能力类因子。
    def AccountsPayablesTRate(self): return self.pn_data.minor_xs('AccountsPayablesTRate')   # 应付账款周转率（Accounts payable turnover rate）。计算方法：应付账款周转率=营业成本（TTM）/应付账款+应付票据+预付款项。属于营运能力类因子。
    def AdminiExpenseRate(self): return self.pn_data.minor_xs('AdminiExpenseRate')   # 管理费用与营业总收入之比（Administrative expense rate）。计算方法：管理费用与营业总收入之比=管理费用（TTM）/营业总收入（TTM）。属于盈利能力和收益质量类因子。
    def ARTDays(self): return self.pn_data.minor_xs('ARTDays')   # 应收账款周转天数（Accounts receivable turnover days）。计算方法：应收账款周转天数=360/应收账款周转率。属于营运能力类因子。
    def ARTRate(self): return self.pn_data.minor_xs('ARTRate')   # 应收账款周转率（Accounts receivable turnover rate）。计算方法：应收账款周转率=营业收入（TTM）/应收账款+应收票据+预收账款。属于营运能力类因子。
    def ASSI(self): return self.pn_data.minor_xs('ASSI')   # 对数总资产（Natural logarithm of total assets）。计算方法：对数总资产=总资产的对数。属于估值与市值类因子。
    def BLEV(self): return self.pn_data.minor_xs('BLEV')   # 账面杠杆（Book leverage）。计算方法：账面杠杆=非流动负债合计/股东权益。属于偿债能力和资本结构类因子。
    def BondsPayableToAsset(self): return self.pn_data.minor_xs('BondsPayableToAsset')   # 应付债券与总资产之比（Bonds payable to total assets）。计算方法：应付债券与总资产之比=应付债券/总资产。属于偿债能力和资本结构类因子。
    def CashRateOfSales(self): return self.pn_data.minor_xs('CashRateOfSales')   # 经营活动产生的现金流量净额与营业收入之比（Cash rate of sales）。计算方法：经营活动产生的现金流量净额与营业收入之比=经营活动产生的现金流量净额（TTM）/营业收入（TTM）。属于现金流指标因子。
    def CashToCurrentLiability(self): return self.pn_data.minor_xs('CashToCurrentLiability')   # 现金比率（Cash to current liability）。计算方法：现金比率=期末现金及现金等价物余额（TTM）/流动负债合计。属于现金流指标因子。
    def CMRA(self): return self.pn_data.minor_xs('CMRA')   # 24 月累计收益（Monthly cumulative return range over the past 24 months）。属于超买超卖型因子。
    def CTOP(self): return self.pn_data.minor_xs('CTOP')   # 现金流市值比（Cash flow to price）。计算方法：现金流市值比=每股派现（税前）×分红前总股本/总市值。属于现金流指标因子。
    def CTP5(self): return self.pn_data.minor_xs('CTP5')   # 5年平均现金流市值比（Five-year average cash flow to price）。计算方法：5年平均现金流市值比=近五年每股派现（税前）×分红前总股本/近五年总市值。属于现金流指标因子。
    def CurrentAssetsRatio(self): return self.pn_data.minor_xs('CurrentAssetsRatio')   # 流动资产比率（Current assets ratio）。计算方法：流动资产比率=流动资产合计/总资产。属于偿债能力和资本结构类因子。
    def CurrentAssetsTRate(self): return self.pn_data.minor_xs('CurrentAssetsTRate')   # 流动资产周转率（Current assets turnover rate）计算方法：流动资产周转率=营业收入（TTM）/流动资产合计。属于营运能力类因子。
    def CurrentRatio(self): return self.pn_data.minor_xs('CurrentRatio')   # 流动比率（Current ratio），计算方法：流动比率=流动资产合计/流动负债合计。属于偿债能力和资本结构类因子。
    def DAVOL10(self): return self.pn_data.minor_xs('DAVOL10')   # 10日平均换手率与120日平均换手率（Turnover Rate）之比。属于成交量型因子
    def DAVOL20(self): return self.pn_data.minor_xs('DAVOL20')   # 20日平均换手率与120日平均换手率（Turnover Rate）之比。属于成交量型因子
    def DAVOL5(self): return self.pn_data.minor_xs('DAVOL5')   # 5日平均换手率与120日平均换手率（Turnover Rate）之比。属于成交量型因子
    def DDNBT(self): return self.pn_data.minor_xs('DDNBT')   # 下跌贝塔（Downside beta），过往12 个月中，市场组合日收益为负时，个股日收益关于市场组合日收益的回归系数。属于超买超卖型因子。
    def DDNCR(self): return self.pn_data.minor_xs('DDNCR')   # 下跌相关系数（Downside correlation），过往12个月中，市场组合日收益为负时，个股日收益关于市场组合日收益的相关系数。属于超买超卖型因子。
    def DDNSR(self): return self.pn_data.minor_xs('DDNSR')   # 下跌波动（Downside standard deviations ratio），过往12个月中，市场组合日收益为负时，个股日收益标准差和市场组合日收益标准差之比。属于超买超卖型因子。
    def DebtEquityRatio(self): return self.pn_data.minor_xs('DebtEquityRatio')   # 产权比率（Debt equity ratio），计算方法：产权比率=负债合计/归属母公司所有者权益合计。属于偿债能力和资本结构类因子。
    def DebtsAssetRatio(self): return self.pn_data.minor_xs('DebtsAssetRatio')   # 债务总资产比（Debt to total assets）。计算方法：债务总资产比=负债合计/总资产。属于偿债能力和资本结构类因子。
    def DHILO(self): return self.pn_data.minor_xs('DHILO')   # 波幅中位数（median of volatility），每日对数最高价和对数最低价差值的3月内中位数。属于趋势型因子
    def DilutedEPS(self): return self.pn_data.minor_xs('DilutedEPS')   # 稀释每股收益（Diluted earnings per share）。属于每股指标因子
    def DVRAT(self): return self.pn_data.minor_xs('DVRAT')   # 收益相对波动（Daily returns variance ratio-serial dependence in daily returns）。属于超买超卖型因子。
    def EBITToTOR(self): return self.pn_data.minor_xs('EBITToTOR')   # 息税前利润与营业总收入之比。计算方法: 息税前利润与营业总收入之比=(利润总额+利息支出-利息收入)/ 营业总收入，如果没有利息支出，用财务费用代替，以上科目使用的都是TTM的数值。属于盈利能力和收益质量类因子。
    def EGRO(self): return self.pn_data.minor_xs('EGRO')   # 5年收益增长率（Five-year earnings growth）。计算方法：5 年收益增长率= 5年收益关于时间（年）进行线性回归的回归系数/5 年收益均值的绝对值。属于盈利能力和收益质量类因子。
    def EMA10(self): return self.pn_data.minor_xs('EMA10')   # 10日指数移动均线（Exponential moving average）。属于均线型因子。
    def EMA120(self): return self.pn_data.minor_xs('EMA120')   # 120日指数移动均线（Exponential moving average）。属于均线型因子。
    def EMA20(self): return self.pn_data.minor_xs('EMA20')   # 20日指数移动均线（Exponential moving average）。属于均线型因子。
    def EMA5(self): return self.pn_data.minor_xs('EMA5')   # 5日指数移动均线（Exponential moving average）。属于均线型因子。
    def EMA60(self): return self.pn_data.minor_xs('EMA60')   # 60日指数移动均线（Exponential moving average）。属于均线型因子。
    def EPS(self): return self.pn_data.minor_xs('EPS')   # 基本每股收益（Earnings per share）。属于每股指标因子
    def EquityFixedAssetRatio(self): return self.pn_data.minor_xs('EquityFixedAssetRatio')   # 股东权益与固定资产比率（Equity fixed assets ratio）。计算方法：股东权益与固定资产比率=股东权益/(固定资产+工程物资+在建工程)。属于偿债能力和资本结构类因子。
    def EquityToAsset(self): return self.pn_data.minor_xs('EquityToAsset')   # 股东权益比率（Equity to total assets）。计算方法：股东权益比率=股东权益/总资产。属于偿债能力和资本结构类因子。
    def EquityTRate(self): return self.pn_data.minor_xs('EquityTRate')   # 因子描述：股东权益周转率（Equity turnover rate）计算方式：股东权益周转率=营业收入/股东权益
    def ETOP(self): return self.pn_data.minor_xs('ETOP')   # 收益市值比（Earnings to price）。计算方法：收益市值比=净利润（TTM）/总市值。属于盈利能力和收益质量类因子。
    def ETP5(self): return self.pn_data.minor_xs('ETP5')   # 5年平均收益市值比（Five-year average earnings to price）。计算方法：5年平均收益市值比=近五年净利润（TTM）/近五年总市值。属于盈利能力和收益质量类因子。
    def FinancialExpenseRate(self): return self.pn_data.minor_xs('FinancialExpenseRate')   # 财务费用与营业总收入之比（Financial expense rate）。计算方法：财务费用与营业总收入之比=财务费用（TTM）/营业总收入（TTM）。属于盈利能力和收益质量类因子。
    def FinancingCashGrowRate(self): return self.pn_data.minor_xs('FinancingCashGrowRate')   # 筹资活动产生的现金流量净额增长率。计算方法：筹资活动产生的现金流量净额增长率=(今年筹资活动产生的现金流量净额（TTM）/去年筹资活动产生的现金流量净额（TTM）)-1。属于现金流指标因子。
    def FixAssetRatio(self): return self.pn_data.minor_xs('FixAssetRatio')   # 固定资产比率（Fixed assets ratio）。计算方法：固定资产比率=(固定资产+工程物资+在建工程)/总资产。属于偿债能力和资本结构类因子。
    def FixedAssetsTRate(self): return self.pn_data.minor_xs('FixedAssetsTRate')   # 固定资产周转率（Fixed assets turnover rate）。计算方法：固定资产周转率=营业收入（TTM）/固定资产+工程物资+在建工程。属于营运能力类因子。
    def GrossIncomeRatio(self): return self.pn_data.minor_xs('GrossIncomeRatio')   # 销售毛利率（Gross income ratio），计算方法：销售毛利率=(营业收入（TTM）-营业成本（TTM）)/营业收入（TTM）。属于盈利能力和收益质量类因子。
    def HBETA(self): return self.pn_data.minor_xs('HBETA')   # 历史贝塔（Historical daily beta），过往12个月中，个股日收益关于市场组合日收益的三阶自回归，市场组合日收益的系数。属于超买超卖型因子。
    def HSIGMA(self): return self.pn_data.minor_xs('HSIGMA')   # 历史波动（Historical daily sigma），过往12个月中，个股日收益关于市场组合日收益的三阶自回归，市场组合日收益的残差标准差。属于超买超卖型因子。
    def IntangibleAssetRatio(self): return self.pn_data.minor_xs('IntangibleAssetRatio')   # 无形资产比率（Intangible assets ratio）。计算方法：无形资产比率=(无形资产+研发支出+商誉)/总资产。属于偿债能力和资本结构类因子。
    def InventoryTDays(self): return self.pn_data.minor_xs('InventoryTDays')   # 存货周转天数（Inventory turnover days）。计算方法：存货周转天数=360/存货周转率。属于营运能力类因子。
    def InventoryTRate(self): return self.pn_data.minor_xs('InventoryTRate')   # 存货周转率（Inventory turnover rate）。计算方法：存货周转率=营业成本（TTM）/存货。属于营运能力类因子。
    def InvestCashGrowRate(self): return self.pn_data.minor_xs('InvestCashGrowRate')   # 投资活动产生的现金流量净额增长率（Growth rate of cash flows from investments）。计算方法：投资活动产生的现金流量净额增长率=(今年投资活动产生的现金流量净额（TTM）/去年投资活动产生的现金流量净额（TTM）)-1。属于现金流指标因子。
    def LCAP(self): return self.pn_data.minor_xs('LCAP')   # 对数市值（Natural logarithm of total market values）。计算方法：对数市值=市值的对数。属于估值与市值类因子。
    def LFLO(self): return self.pn_data.minor_xs('LFLO')   # 对数流通市值（Natural logarithm of float market values）。计算方法：对数流通市值=流通市值的对数。属于估值与市值类因子。
    def LongDebtToAsset(self): return self.pn_data.minor_xs('LongDebtToAsset')   # 长期借款与资产总计之比（Long term loan to total assets）。计算方法：长期借款与资产总计之比=长期借款/总资产。属于偿债能力和资本结构类因子。
    def LongDebtToWorkingCapital(self): return self.pn_data.minor_xs('LongDebtToWorkingCapital')   # 长期负债与营运资金比率（Long term debt to working capital）。计算方法：长期负债与营运资金比率=非流动负债合计/(流动资产合计-流动负债合计)。属于偿债能力和资本结构类因子。
    def LongTermDebtToAsset(self): return self.pn_data.minor_xs('LongTermDebtToAsset')   # 长期负债与资产总计之比（Long term debt to total assets）。计算方法：长期负债与资产总计之比=非流动负债合计/总资产。属于偿债能力和资本结构类因子。
    def MA10(self): return self.pn_data.minor_xs('MA10')   # 10日移动均线（Moving average）。取最近N天的前复权价格的均值。属于均线型因子。
    def MA120(self): return self.pn_data.minor_xs('MA120')   # 120日移动均线（Moving average）。取最近N天的前复权价格的均值。 属于均线型因子。
    def MA20(self): return self.pn_data.minor_xs('MA20')   # 20日移动均线（Moving average）。取最近N天的前复权价格的均值。属于均线型因子。
    def MA5(self): return self.pn_data.minor_xs('MA5')   # 5日移动均线（Moving average）。取最近N天的前复权价格的均值。属于均线型因子。
    def MA60(self): return self.pn_data.minor_xs('MA60')   # 60日移动均线（Moving average）。取最近N天的前复权价格的均值。属于均线型因子。
    def MAWVAD(self): return self.pn_data.minor_xs('MAWVAD')   # 因子WVAD的6日均值。属于超买超卖型因子。
    def MFI(self): return self.pn_data.minor_xs('MFI')   # 资金流量指标（Money Flow Index），该指标是通过反映股价变动的四个元素：上涨的天数、下跌的天数、成交量增加幅度、成交量减少幅度来研判量能的趋势，预测市场供求关系和买卖力道。属于超买超卖型因子。
    def MLEV(self): return self.pn_data.minor_xs('MLEV')   # 市场杠杆（Market leverage）。计算方法：市场杠杆=非流动负债合计/(非流动负债合计+总市值)。属于偿债能力和资本结构类因子。
    def NetAssetGrowRate(self): return self.pn_data.minor_xs('NetAssetGrowRate')   # 净资产增长率（Net assets growth rate）。计算方法：净资产增长率=(今年股东权益/去年股东权益)-1。属于成长能力类因子。
    def NetProfitGrowRate(self): return self.pn_data.minor_xs('NetProfitGrowRate')   # 净利润增长率（Net profit growth rate）。计算方法：净利润增长率=(今年净利润（TTM）/去年净利润（TTM）)-1。属于成长能力类因子。
    def NetProfitRatio(self): return self.pn_data.minor_xs('NetProfitRatio')   # 销售净利率（Net profit ratio），计算方法：销售净利率=净利润（TTM）/营业收入（TTM）。属于盈利能力和收益质量类因子。
    def NOCFToOperatingNI(self): return self.pn_data.minor_xs('NOCFToOperatingNI')   # 经营活动产生的现金流量净额与经营活动净收益之比。计算方法：经营活动产生的现金流量净额与经营活动净收益之比=经营活动产生的现金流量净额（TTM）/(营业总收入（TTM）-营业总成本（TTM）)。属于现金流指标因子。
    def NonCurrentAssetsRatio(self): return self.pn_data.minor_xs('NonCurrentAssetsRatio')   # 非流动资产比率（Non-current assets ratio）。计算方法：非流动资产比率=非流动资产合计/总资产。属于偿债能力和资本结构类因子。
    def NPParentCompanyGrowRate(self): return self.pn_data.minor_xs('NPParentCompanyGrowRate')   # 归属母公司股东的净利润增长率。计算方法：归属母公司股东的净利润增长率=(今年归属于母公司所有者的净利润（TTM）/去年归属于母公司所有者的净利润（TTM）)-1。属于成长能力类因子。
    def NPToTOR(self): return self.pn_data.minor_xs('NPToTOR')   # 净利润与营业总收入之比（Net profit to total operating revenues），计算方法：净利润与营业总收入之比=净利润（TTM）/营业总收入（TTM）。属于盈利能力和收益质量类因子。
    def OperatingExpenseRate(self): return self.pn_data.minor_xs('OperatingExpenseRate')   # 营业费用与营业总收入之比（Operating expense rate）。计算方法：营业费用与营业总收入之比=销售费用（TTM）/营业总收入（TTM）。属于盈利能力和收益质量类因子。
    def OperatingProfitGrowRate(self): return self.pn_data.minor_xs('OperatingProfitGrowRate')   # 营业利润增长率（Operating profit growth rate）。计算方法：营业利润增长率=(今年营业利润（TTM）/去年营业利润（TTM）)-1。属于成长能力类因子。
    def OperatingProfitRatio(self): return self.pn_data.minor_xs('OperatingProfitRatio')   # 营业利润率（Operating profit ratio），计算方法：营业利润率=营业利润（TTM）/营业收入（TTM）。属于盈利能力和收益质量类因子。
    def OperatingProfitToTOR(self): return self.pn_data.minor_xs('OperatingProfitToTOR')   # 营业利润与营业总收入之比（Operating profit to total operating revenues），计算方法：营业利润与营业总收入之比=营业利润（TTM）/营业总收入（TTM）。属于盈利能力和收益质量类因子。
    def OperatingRevenueGrowRate(self): return self.pn_data.minor_xs('OperatingRevenueGrowRate')   # 营业收入增长率（Operating revenue growth rate）。计算方法：营业收入增长率=（今年营业收入（TTM）/去年营业收入（TTM））-1。属于成长能力类因子。
    def OperCashGrowRate(self): return self.pn_data.minor_xs('OperCashGrowRate')   # 经营活动产生的现金流量净额增长率。计算方法：经营活动产生的现金流量净额增长率=(今年经营活动产生的现金流量净额（TTM）/去年经营活动产生的现金流量净额（TTM）)-1。属于现金流指标因子。
    def OperCashInToCurrentLiability(self): return self.pn_data.minor_xs('OperCashInToCurrentLiability')   # 现金流动负债比（Cash provided by operations to current liability）。计算方法：现金流动负债比=经营活动产生的现金流量净额（TTM）/流动负债合计。属于现金流指标因子。
    def PB(self): return self.pn_data.minor_xs('PB')   # 市净率（Price-to-book ratio）。计算方法：市净率=总市值/归属于母公司所有者权益合计。属于估值与市值类因子。
    def PCF(self): return self.pn_data.minor_xs('PCF')   # 市现率（Price-to-cash-flow ratio）。计算方法：总市值/经营活动产生的现金流量净额（TTM）。属于估值与市值类因子。
    def PE(self): return self.pn_data.minor_xs('PE')   # 市盈率（Price-earnings ratio）。使用TTM算法。市盈率=总市值/归属于母公司所有者的净利润（TTM）。属于估值与市值类因子。
    def PS(self): return self.pn_data.minor_xs('PS')   # 市销率（Price-to-sales ratio）。市销率=总市值/营业总收入（TTM）。属于估值与市值类因子。
    def PSY(self): return self.pn_data.minor_xs('PSY')   # 心理线指标（Psychological line index），是一定时期内投资者趋向买方或卖方的心理事实转的数值度量，用于判断股价的未来趋势。属于能量型因子。
    def QuickRatio(self): return self.pn_data.minor_xs('QuickRatio')   # 速动比率（Quick ratio）。计算方法：速动比率=(流动资产合计-存货)/ 流动负债合计。属于偿债能力和资本结构类因子。
    def REVS10(self): return self.pn_data.minor_xs('REVS10')   # 股票的10日收益。属于超买超卖型因子。
    def REVS20(self): return self.pn_data.minor_xs('REVS20')   # 股票的20日收益。属于超买超卖型因子。
    def REVS5(self): return self.pn_data.minor_xs('REVS5')   # 股票的5日收益。属于超买超卖型因子。
    def ROA(self): return self.pn_data.minor_xs('ROA')   # 资产回报率（Return on assets）。计算方法：资产回报率=净利润（TTM）/总资产。属于盈利能力和收益质量类因子。
    def ROA5(self): return self.pn_data.minor_xs('ROA5')   # 5年资产回报率（Five-year average return on assets）。计算方法：5年资产回报率=净利润（TTM）/总资产。属于盈利能力和收益质量类因子。
    def ROE(self): return self.pn_data.minor_xs('ROE')   # 权益回报率（Return on equity）。计算方法：权益回报率=净利润（TTM）/股东权益。属于盈利能力和收益质量类因子。
    def ROE5(self): return self.pn_data.minor_xs('ROE5')   # 因子描述：5 年权益回报率（Five-year average return on equity）计算方式：5 年权益回报率=净利润/股东权益
    def RSI(self): return self.pn_data.minor_xs('RSI')   # 相对强弱指标（Relative Strength Index），通过比较一段时期内的平均收盘涨数和平均收盘跌数来分析市场买沽盘的意向和实力，据此预测趋势的持续或者转向。属于超买超卖型因子。
    def RSTR12(self): return self.pn_data.minor_xs('RSTR12')   # 12月相对强势（Relative strength for the last 12 months）。属于能量型因子。
    def RSTR24(self): return self.pn_data.minor_xs('RSTR24')   # 12月相对强势（Relative strength for the last 24 months）。属于能量型因子。
    def SalesCostRatio(self): return self.pn_data.minor_xs('SalesCostRatio')   # 销售成本率（Sales cost ratio），计算方法：销售成本率=营业成本（TTM）/营业收入（TTM）。属于盈利能力和收益质量类因子。
    def SaleServiceCashToOR(self): return self.pn_data.minor_xs('SaleServiceCashToOR')   # 销售商品提供劳务收到的现金与营业收入之比（Sale service cash to operating revenues）。计算方法：销售商品提供劳务收到的现金与营业收入之比=销售商品和提供劳务收到的现金（TTM）/营业收入（TTM）。属于现金流指标因子。
    def SUE(self): return self.pn_data.minor_xs('SUE')   # 未预期盈余（Standardized unexpected earnings）。计算方法：未预期盈余=(最近一年净利润-除去最近一年的过往净利润均值)/ 除去最近一年的过往净利润标准差。属于盈利能力和收益质量类因子。
    def TaxRatio(self): return self.pn_data.minor_xs('TaxRatio')   # 销售税金率（Tax ratio），计算方法：销售税金率=营业税金及附加（TTM）/营业收入（TTM）。属于盈利能力和收益质量类因子。
    def TOBT(self): return self.pn_data.minor_xs('TOBT')   # 超额流动（Liquidity-turnover beta）。属于能量型因子。
    def TotalAssetGrowRate(self): return self.pn_data.minor_xs('TotalAssetGrowRate')   # 总资产增长率（Total assets growth rate）。计算方法：总资产增长率=(今年总资产/去年总资产)-1。属于成长能力类因子。
    def TotalAssetsTRate(self): return self.pn_data.minor_xs('TotalAssetsTRate')   # 因子描述：总资产周转率（Total assets turnover rate）计算方式：总资产周转率=营业收入/总资产
    def TotalProfitCostRatio(self): return self.pn_data.minor_xs('TotalProfitCostRatio')   # 成本费用利润率（Total profit cost ratio）。计算方法：成本费用利润率=利润总额/(营业成本+财务费用+销售费用+管理费用)，以上科目使用的都是TTM的数值。属于盈利能力和收益质量类因子。
    def TotalProfitGrowRate(self): return self.pn_data.minor_xs('TotalProfitGrowRate')   # 利润总额增长率（Total profit growth rate）。计算方法：利润总额增长率=(今年利润总额（TTM）/去年利润总额（TTM）)-1。属于成长能力类因子。
    def VOL10(self): return self.pn_data.minor_xs('VOL10')   # 10日平均换手率（Turnover Rate）。属于成交量型因子
    def VOL120(self): return self.pn_data.minor_xs('VOL120')   # 120日平均换手率（Turnover Rate）。属于成交量型因子
    def VOL20(self): return self.pn_data.minor_xs('VOL20')   # 20日平均换手率（Turnover Rate）。属于成交量型因子
    def VOL240(self): return self.pn_data.minor_xs('VOL240')   # 240日平均换手率（Turnover Rate）。属于成交量型因子
    def VOL5(self): return self.pn_data.minor_xs('VOL5')   # 5日平均换手率（Turnover Rate）。属于成交量型因子
    def VOL60(self): return self.pn_data.minor_xs('VOL60')   # 60日平均换手率（Turnover Rate）。属于成交量型因子
    def WVAD(self): return self.pn_data.minor_xs('WVAD')   # 威廉变异离散量（William's variable accumulation distribution），是一种将成交量加权的量价指标，用于测量从开盘价至收盘价期间，买卖双方各自爆发力的程度。属于超买超卖型因子。
    def REC(self): return self.pn_data.minor_xs('REC')   # 分析师推荐评级（Recommended rating score by analyst）。属于分析师预期类因子。
    def DAREC(self): return self.pn_data.minor_xs('DAREC')   # 分析师推荐评级变化（Changes of recommended rating score by analyst），相比于60 个交易日前。属于分析师预期类因子。
    def GREC(self): return self.pn_data.minor_xs('GREC')   # 分析师推荐评级变化趋势（Change tendency of recommended rating score by analyst），过去60 个交易日内的DAREC 符号加和。属于分析师预期类因子。
    def FY12P(self): return self.pn_data.minor_xs('FY12P')   # 分析师盈利预测（Forecast earnings by analyst to market values）。属于分析师预期类因子。
    def DAREV(self): return self.pn_data.minor_xs('DAREV')   # 分析师盈利预测变化（Changes of forecast earnings by analyst），相比于60个交易日前。属于分析师预期类因子。
    def GREV(self): return self.pn_data.minor_xs('GREV')   # 分析师盈利预测变化趋势（Change tendency of forecast earnings by analyst），过去60个交易日内的DAREV符号加和。属于分析师预期类因子。
    def SFY12P(self): return self.pn_data.minor_xs('SFY12P')   # 分析师营收预测（Forecast sales by analyst to market values）。属于分析师预期类因子。
    def DASREV(self): return self.pn_data.minor_xs('DASREV')   # 分析师盈收预测变化（Changes of forecast sales by analyst），相比于60 个交易日前。属于分析师预期类因子。
    def GSREV(self): return self.pn_data.minor_xs('GSREV')   # 分析师盈收预测变化趋势（Change tendency of forecast sales by analyst），过去60 个交易日内的DASREV 符号加和。属于分析师预期类因子。
    def FEARNG(self): return self.pn_data.minor_xs('FEARNG')   # 未来预期盈利增长（Growth of forecast earnings）。属于分析师预期类因子。
    def FSALESG(self): return self.pn_data.minor_xs('FSALESG')   # 未来预期盈收增长（Growth of forecast sales）。属于分析师预期类因子。
    def TA2EV(self): return self.pn_data.minor_xs('TA2EV')   # 资产总计与企业价值之比（Assets to enterprise value）。属于估值与市值类因子。
    def CFO2EV(self): return self.pn_data.minor_xs('CFO2EV')   # 经营活动产生的现金流量净额与企业价值之比（Cash provided by operations to enterprise value）。属于现金流指标因子。
    def ACCA(self): return self.pn_data.minor_xs('ACCA')   # 现金流资产比和资产回报率之差（Cash flow assets ratio minus return on assets）。计算方法：现金流资产比和资产回报率之差=（经营活动产生的金流量净额（TTM） - 净利润（TTM））/
    def DEGM(self): return self.pn_data.minor_xs('DEGM')   # 毛利率增长（Growth rate of gross income ratio），去年同期相比。计算方法：毛利率增长=(今年毛利率（TTM）/去年毛利率（TTM）)-1。属于成长能力类因子。
    def SUOI(self): return self.pn_data.minor_xs('SUOI')   # 未预期毛利（Standardized unexpected gross income）。属于盈利能力和收益质量类因子。
    def EARNMOM(self): return self.pn_data.minor_xs('EARNMOM')   # 八季度净利润变化趋势（Change tendency of net profit in the past eight quarters），前8个季度的净利润，如果同比（去年同期）增长记为+1，同比下滑记为-1，再将8 个值相加。属于成长能力类因子。
    def FiftyTwoWeekHigh(self): return self.pn_data.minor_xs('FiftyTwoWeekHigh')   # 当前价格处于过去1 年股价的位置（Price level during the pasted 52 weeks）。属于超买超卖型因子。
    def Volatility(self): return self.pn_data.minor_xs('Volatility')   # 换手率相对波动率（Volatility of daily turnover during the last N days）。属于超买超卖型因子。
    def Skewness(self): return self.pn_data.minor_xs('Skewness')   # 股价偏度（Skewness of price during the last N days），过去20个交易日股价的偏度。属于超买超卖型因子。
    def ILLIQUIDITY(self): return self.pn_data.minor_xs('ILLIQUIDITY')   # 收益相对金额比（Daily return to turnover value during the last N days），过去20个交易日收益相对金额的比例。属于超买超卖型因子。
    def BackwardADJ(self): return self.pn_data.minor_xs('BackwardADJ')   # 股价向后复权因子，复权是对股价和成交量进行权息修复。属于超买超卖型因子。
    def MACD(self): return self.pn_data.minor_xs('MACD')   # 平滑异同移动平均线（Moving Average Convergence Divergence）,又称移动平均聚散指标。属于趋势型因子

# %%
def uqer101_fun(x,data):
    uqer_generator   = Uqer101(data)
    alpha_factors    = {
            'CCI5' :uqer_generator.CCI5,
            'CCI88' :uqer_generator.CCI88,
            'KDJ_K' :uqer_generator.KDJ_K,
            'KDJ_D' :uqer_generator.KDJ_D,
            'KDJ_J' :uqer_generator.KDJ_J,
            'ROC6' :uqer_generator.ROC6,
            'ROC20' :uqer_generator.ROC20,
            'SBM' :uqer_generator.SBM,
            'STM' :uqer_generator.STM,
            'UpRVI' :uqer_generator.UpRVI,
            'DownRVI' :uqer_generator.DownRVI,
            'RVI' :uqer_generator.RVI,
            'SRMI' :uqer_generator.SRMI,
            'ChandeSD' :uqer_generator.ChandeSD,
            'ChandeSU' :uqer_generator.ChandeSU,
            'CMO' :uqer_generator.CMO,
            'DBCD' :uqer_generator.DBCD,
            'ARC' :uqer_generator.ARC,
            'OBV' :uqer_generator.OBV,
            'OBV6' :uqer_generator.OBV6,
            'OBV20' :uqer_generator.OBV20,
            'TVMA20' :uqer_generator.TVMA20,
            'TVMA6' :uqer_generator.TVMA6,
            'TVSTD20' :uqer_generator.TVSTD20,
            'TVSTD6' :uqer_generator.TVSTD6,
            'VDEA' :uqer_generator.VDEA,
            'VDIFF' :uqer_generator.VDIFF,
            'VEMA10' :uqer_generator.VEMA10,
            'VEMA12' :uqer_generator.VEMA12,
            'VEMA26' :uqer_generator.VEMA26,
            'VEMA5' :uqer_generator.VEMA5,
            'VMACD' :uqer_generator.VMACD,
            'VOSC' :uqer_generator.VOSC,
            'VR' :uqer_generator.VR,
            'VROC12' :uqer_generator.VROC12,
            'VROC6' :uqer_generator.VROC6,
            'VSTD10' :uqer_generator.VSTD10,
            'VSTD20' :uqer_generator.VSTD20,
            'KlingerOscillator' :uqer_generator.KlingerOscillator,
            'MoneyFlow20' :uqer_generator.MoneyFlow20,
            'AD' :uqer_generator.AD,
            'AD20' :uqer_generator.AD20,
            'AD6' :uqer_generator.AD6,
            'CoppockCurve' :uqer_generator.CoppockCurve,
            'ASI' :uqer_generator.ASI,
            'ChaikinOscillator' :uqer_generator.ChaikinOscillator,
            'ChaikinVolatility' :uqer_generator.ChaikinVolatility,
            'EMV14' :uqer_generator.EMV14,
            'EMV6' :uqer_generator.EMV6,
            'plusDI' :uqer_generator.plusDI,
            'minusDI' :uqer_generator.minusDI,
            'ADX' :uqer_generator.ADX,
            'ADXR' :uqer_generator.ADXR,
            'Aroon' :uqer_generator.Aroon,
            'AroonDown' :uqer_generator.AroonDown,
            'AroonUp' :uqer_generator.AroonUp,
            'DEA' :uqer_generator.DEA,
            'DIFF' :uqer_generator.DIFF,
            'DDI' :uqer_generator.DDI,
            'DIZ' :uqer_generator.DIZ,
            'DIF' :uqer_generator.DIF,
            'MTM' :uqer_generator.MTM,
            'MTMMA' :uqer_generator.MTMMA,
            'PVT' :uqer_generator.PVT,
            'PVT6' :uqer_generator.PVT6,
            'PVT12' :uqer_generator.PVT12,
            'TRIX5' :uqer_generator.TRIX5,
            'TRIX10' :uqer_generator.TRIX10,
            'UOS' :uqer_generator.UOS,
            'MA10RegressCoeff12' :uqer_generator.MA10RegressCoeff12,
            'MA10RegressCoeff6' :uqer_generator.MA10RegressCoeff6,
            'PLRC6' :uqer_generator.PLRC6,
            'PLRC12' :uqer_generator.PLRC12,
            'SwingIndex' :uqer_generator.SwingIndex,
            'Ulcer10' :uqer_generator.Ulcer10,
            'Ulcer5' :uqer_generator.Ulcer5,
            'Hurst' :uqer_generator.Hurst,
            'ACD6' :uqer_generator.ACD6,
            'ACD20' :uqer_generator.ACD20,
            'EMA12' :uqer_generator.EMA12,
            'EMA26' :uqer_generator.EMA26,
            'APBMA' :uqer_generator.APBMA,
            'BBI' :uqer_generator.BBI,
            'BBIC' :uqer_generator.BBIC,
            'TEMA10' :uqer_generator.TEMA10,
            'TEMA5' :uqer_generator.TEMA5,
            'MA10Close' :uqer_generator.MA10Close,
            'AR' :uqer_generator.AR,
            'BR' :uqer_generator.BR,
            'ARBR' :uqer_generator.ARBR,
            'CR20' :uqer_generator.CR20,
            'MassIndex' :uqer_generator.MassIndex,
            'BearPower' :uqer_generator.BearPower,
            'BullPower' :uqer_generator.BullPower,
            'Elder' :uqer_generator.Elder,
            'NVI' :uqer_generator.NVI,
            'PVI' :uqer_generator.PVI,
            'RC12' :uqer_generator.RC12,
            'RC24' :uqer_generator.RC24,
            'JDQS20' :uqer_generator.JDQS20,
            'ADTM' :uqer_generator.ADTM,
            'ATR14' :uqer_generator.ATR14,
            'ATR6' :uqer_generator.ATR6,
            'BIAS10' :uqer_generator.BIAS10,
            'BIAS20' :uqer_generator.BIAS20,
            'BIAS5' :uqer_generator.BIAS5,
            'BIAS60' :uqer_generator.BIAS60,
            'BollDown' :uqer_generator.BollDown,
            'BollUp' :uqer_generator.BollUp,
            'CCI10' :uqer_generator.CCI10,
            'CCI20' :uqer_generator.CCI20,
            'AccountsPayablesTDays' :uqer_generator.AccountsPayablesTDays,
            'AccountsPayablesTRate' :uqer_generator.AccountsPayablesTRate,
            'AdminiExpenseRate' :uqer_generator.AdminiExpenseRate,
            'ARTDays' :uqer_generator.ARTDays,
            'ARTRate' :uqer_generator.ARTRate,
            'ASSI' :uqer_generator.ASSI,
            'BLEV' :uqer_generator.BLEV,
            'BondsPayableToAsset' :uqer_generator.BondsPayableToAsset,
            'CashRateOfSales' :uqer_generator.CashRateOfSales,
            'CashToCurrentLiability' :uqer_generator.CashToCurrentLiability,
            'CMRA' :uqer_generator.CMRA,
            'CTOP' :uqer_generator.CTOP,
            'CTP5' :uqer_generator.CTP5,
            'CurrentAssetsRatio' :uqer_generator.CurrentAssetsRatio,
            'CurrentAssetsTRate' :uqer_generator.CurrentAssetsTRate,
            'CurrentRatio' :uqer_generator.CurrentRatio,
            'DAVOL10' :uqer_generator.DAVOL10,
            'DAVOL20' :uqer_generator.DAVOL20,
            'DAVOL5' :uqer_generator.DAVOL5,
            'DDNBT' :uqer_generator.DDNBT,
            'DDNCR' :uqer_generator.DDNCR,
            'DDNSR' :uqer_generator.DDNSR,
            'DebtEquityRatio' :uqer_generator.DebtEquityRatio,
            'DebtsAssetRatio' :uqer_generator.DebtsAssetRatio,
            'DHILO' :uqer_generator.DHILO,
            'DilutedEPS' :uqer_generator.DilutedEPS,
            'DVRAT' :uqer_generator.DVRAT,
            'EBITToTOR' :uqer_generator.EBITToTOR,
            'EGRO' :uqer_generator.EGRO,
            'EMA10' :uqer_generator.EMA10,
            'EMA120' :uqer_generator.EMA120,
            'EMA20' :uqer_generator.EMA20,
            'EMA5' :uqer_generator.EMA5,
            'EMA60' :uqer_generator.EMA60,
            'EPS' :uqer_generator.EPS,
            'EquityFixedAssetRatio' :uqer_generator.EquityFixedAssetRatio,
            'EquityToAsset' :uqer_generator.EquityToAsset,
            'EquityTRate' :uqer_generator.EquityTRate,
            'ETOP' :uqer_generator.ETOP,
            'ETP5' :uqer_generator.ETP5,
            'FinancialExpenseRate' :uqer_generator.FinancialExpenseRate,
            'FinancingCashGrowRate' :uqer_generator.FinancingCashGrowRate,
            'FixAssetRatio' :uqer_generator.FixAssetRatio,
            'FixedAssetsTRate' :uqer_generator.FixedAssetsTRate,
            'GrossIncomeRatio' :uqer_generator.GrossIncomeRatio,
            'HBETA' :uqer_generator.HBETA,
            'HSIGMA' :uqer_generator.HSIGMA,
            'IntangibleAssetRatio' :uqer_generator.IntangibleAssetRatio,
            'InventoryTDays' :uqer_generator.InventoryTDays,
            'InventoryTRate' :uqer_generator.InventoryTRate,
            'InvestCashGrowRate' :uqer_generator.InvestCashGrowRate,
            'LCAP' :uqer_generator.LCAP,
            'LFLO' :uqer_generator.LFLO,
            'LongDebtToAsset' :uqer_generator.LongDebtToAsset,
            'LongDebtToWorkingCapital' :uqer_generator.LongDebtToWorkingCapital,
            'LongTermDebtToAsset' :uqer_generator.LongTermDebtToAsset,
            'MA10' :uqer_generator.MA10,
            'MA120' :uqer_generator.MA120,
            'MA20' :uqer_generator.MA20,
            'MA5' :uqer_generator.MA5,
            'MA60' :uqer_generator.MA60,
            'MAWVAD' :uqer_generator.MAWVAD,
            'MFI' :uqer_generator.MFI,
            'MLEV' :uqer_generator.MLEV,
            'NetAssetGrowRate' :uqer_generator.NetAssetGrowRate,
            'NetProfitGrowRate' :uqer_generator.NetProfitGrowRate,
            'NetProfitRatio' :uqer_generator.NetProfitRatio,
            'NOCFToOperatingNI' :uqer_generator.NOCFToOperatingNI,
            'NonCurrentAssetsRatio' :uqer_generator.NonCurrentAssetsRatio,
            'NPParentCompanyGrowRate' :uqer_generator.NPParentCompanyGrowRate,
            'NPToTOR' :uqer_generator.NPToTOR,
            'OperatingExpenseRate' :uqer_generator.OperatingExpenseRate,
            'OperatingProfitGrowRate' :uqer_generator.OperatingProfitGrowRate,
            'OperatingProfitRatio' :uqer_generator.OperatingProfitRatio,
            'OperatingProfitToTOR' :uqer_generator.OperatingProfitToTOR,
            'OperatingRevenueGrowRate' :uqer_generator.OperatingRevenueGrowRate,
            'OperCashGrowRate' :uqer_generator.OperCashGrowRate,
            'OperCashInToCurrentLiability' :uqer_generator.OperCashInToCurrentLiability,
            'PB' :uqer_generator.PB,
            'PCF' :uqer_generator.PCF,
            'PE' :uqer_generator.PE,
            'PS' :uqer_generator.PS,
            'PSY' :uqer_generator.PSY,
            'QuickRatio' :uqer_generator.QuickRatio,
            'REVS10' :uqer_generator.REVS10,
            'REVS20' :uqer_generator.REVS20,
            'REVS5' :uqer_generator.REVS5,
            'ROA' :uqer_generator.ROA,
            'ROA5' :uqer_generator.ROA5,
            'ROE' :uqer_generator.ROE,
            'ROE5' :uqer_generator.ROE5,
            'RSI' :uqer_generator.RSI,
            'RSTR12' :uqer_generator.RSTR12,
            'RSTR24' :uqer_generator.RSTR24,
            'SalesCostRatio' :uqer_generator.SalesCostRatio,
            'SaleServiceCashToOR' :uqer_generator.SaleServiceCashToOR,
            'SUE' :uqer_generator.SUE,
            'TaxRatio' :uqer_generator.TaxRatio,
            'TOBT' :uqer_generator.TOBT,
            'TotalAssetGrowRate' :uqer_generator.TotalAssetGrowRate,
            'TotalAssetsTRate' :uqer_generator.TotalAssetsTRate,
            'TotalProfitCostRatio' :uqer_generator.TotalProfitCostRatio,
            'TotalProfitGrowRate' :uqer_generator.TotalProfitGrowRate,
            'VOL10' :uqer_generator.VOL10,
            'VOL120' :uqer_generator.VOL120,
            'VOL20' :uqer_generator.VOL20,
            'VOL240' :uqer_generator.VOL240,
            'VOL5' :uqer_generator.VOL5,
            'VOL60' :uqer_generator.VOL60,
            'WVAD' :uqer_generator.WVAD,
            'REC' :uqer_generator.REC,
            'DAREC' :uqer_generator.DAREC,
            'GREC' :uqer_generator.GREC,
            'FY12P' :uqer_generator.FY12P,
            'DAREV' :uqer_generator.DAREV,
            'GREV' :uqer_generator.GREV,
            'SFY12P' :uqer_generator.SFY12P,
            'DASREV' :uqer_generator.DASREV,
            'GSREV' :uqer_generator.GSREV,
            'FEARNG' :uqer_generator.FEARNG,
            'FSALESG' :uqer_generator.FSALESG,
            'TA2EV' :uqer_generator.TA2EV,
            'CFO2EV' :uqer_generator.CFO2EV,
            'ACCA' :uqer_generator.ACCA,
            'DEGM' :uqer_generator.DEGM,
            'SUOI' :uqer_generator.SUOI,
            'EARNMOM' :uqer_generator.EARNMOM,
            'FiftyTwoWeekHigh' :uqer_generator.FiftyTwoWeekHigh,
            'Volatility' :uqer_generator.Volatility,
            'Skewness' :uqer_generator.Skewness,
            'ILLIQUIDITY' :uqer_generator.ILLIQUIDITY,
            'BackwardADJ' :uqer_generator.BackwardADJ,
            'MACD' :uqer_generator.MACD,
          }
    return alpha_factors.get(x)

# %%
from functools import wraps
def wrapper_func_cache(func):
    @wraps(func)
    def wrapped(*args, **kwargs):
        if not hasattr(func, '__cache_result'):
            func.__cache_result = {}
        
        hash_key = [str(i) for i in args] + [str(j) for j in kwargs.iteritems()]
        cache_key = hash(tuple(hash_key))
        
        if cache_key not in func.__cache_result:
            func.__cache_result[cache_key] = func(*args, **kwargs)
            
        return func.__cache_result[cache_key]
    return wrapped

@wrapper_func_cache
def load_uqer_factor(tickers,start,end,factors):
    """
    out:pd.Panel
    Items axis: 600017.XSHG to 601008.XSHG
    Major_axis axis: 2010-11-22 00:00:00 to 2016-08-31 00:00:00
    Minor_axis axis: secID to VOL20
    """
    #一次性将回测数据全部取出
    all_data = {}  #record the return data; key:stock_id; value: factor value in trading_days (in Pandas)
    def factorAccess(ticker): 
        #--装载全部数据
        factor_data = pd.DataFrame()
        factor_data = DataAPI.MktStockFactorsDateRangeGet(secID=ticker,beginDate=start,endDate=end,field=["tradeDate","secID"]+factors,pandas="1")
        factor_data =  factor_data.rename(columns={'tradeDate':'Date'})
        factor_data['Date'] =  pd.to_datetime(factor_data['Date']) #因为DataAPI所有日期都是以字符串形式存储的，因此此处需要转换成日期时间型,这里很重要！
        factor_data =  factor_data.set_index('Date')#转换后index是DatetimeIndex型
        return factor_data 
    for ticker in tickers:
        all_data[ticker] = factorAccess(ticker)
    return pd.Panel.from_dict(all_data)

# %%
import numpy as np
import pandas as pd

securities = ['600017.XSHG', '601008.XSHG']
start ='20160801'
end   ='20161010'

#优矿因子
alpha_name = 'MACD'
# 调用合并财务报表数据
data = load_uqer_factor(securities,start,end,[alpha_name])
factor_df  = uqer101_fun(alpha_name,data)()
factor_df.head()
# Out:
#            600017.XSHG 601008.XSHG
# Date
# 2016-08-01     -0.0282     -0.0782
# 2016-08-02     -0.0314     -0.0806
# 2016-08-03     -0.0306     -0.0746
# 2016-08-04     -0.0282     -0.0658
# 2016-08-05      -0.025     -0.0546
