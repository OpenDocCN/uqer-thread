# %% [markdown]
# #

# %% [raw]
# import pandas as pd
# import numpy as np
# import talib as tb
# from CAL.PyCAL import *
#
#
# start = '2011-01-06'  # 回测起始时间
# end = '2016-08-10'   # 回测结束时间
# benchmark = '510050.XSHG' # 策略参考标准：华夏基金50ETF
# universe = ['510050.XSHG']  # 华夏基金50ETF
# capital_base = 100000                         # 起始资金
# freq = 'd'                                # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1  # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# commission = Commission(0.0, 0.0)  # 交易费率
#
# def initialize(account):   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):  # 每个交易日的买入卖出指令
#
#
#     hist = account.get_attribute_history('closePrice',300) #获取50etf，近300天的收盘数据
#     for s in account.universe:
#         macd_tmp = talib.MACD(hist[s], fastperiod=18, slowperiod=40, signalperiod=14)#选择macd参数，为避免太敏感，（12，26，9）*1.5倍
#         DIF = macd_tmp[0]
#         DEA = macd_tmp[1]
#         MACD = macd_tmp[2]
#
#     if MACD[-1] > 0 and MACD[-1]-max(MACD[-32:-2])*0.7 > 0:#从金叉买入时，假设前期macd为负，所以买入时不影响，主要影响卖出
#         order_pct(s,1)
#     elif MACD[-1] < 0 and MACD[-1]-max(MACD[-32:-2])*0.7 < 0: #由于基金是基于昨日收盘做今日操作，所以需要提前在死叉形成之前卖出
#         order_pct(s,-1)
