# %% [markdown]
# # ROE回测(更新版本)

# %% [raw]
# import numpy as np
# import pandas as pd
#
# start = '2013-04-01'                       # 回测起始时间
# end = '2018-04-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('HS300')           # 证券池，支持股票和基金
# capital_base = 10000000                    # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 246                         # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     factor = DataAPI.MktStockFactorsOneDayGet(secID=account.universe,tradeDate=account.previous_date,field='secID,ROE',pandas="1").dropna()    #获取所有股票的相关因子
#
#     sec_val = {'symbol':[], 'factor_value':[]}
#
#     for index, row in factor.iterrows():
#         sec_val['symbol'].append(row['secID'])
#         sec_val['factor_value'].append(row['ROE'])
#
#     sec_val = pd.DataFrame(sec_val).sort(columns='factor_value').reset_index()
#     sec_val = sec_val.sort('factor_value',ascending=False)
#     sec_val = sec_val.head(20)                                #排序并选择前20/50/100
#
#     buylist = list(sec_val.symbol)                              #买入股票列表
#
#
#     totalmoney = account.referencePortfolioValue                  #股票账户里面所有的钱
#     prices = account.referencePrice                               #股票的在当时的价格
#     for stock in account.valid_secpos:
#
#         order_to(stock,0)
#
#     for stock in buylist:
#
#         if np.isnan(prices[stock]) or prices[stock] == 0:  # 停牌或是还没有上市等原因不能交易
#              continue
#         else:
#             try:
#                 order(stock,totalmoney/prices[stock]/len(buylist))
#             except:
#                 pass
#
#     return
