# %% [markdown]
# # ♥ 有效边界上课问题

# %%
import numpy as np
import pandas as pd
from pandas import Series
import matplotlib.pyplot as plt
pd.options.display.width = 2000
a=[0.002352778	,0.009378788	,-0.001083333,	0.003802778	,-0.001266667	,0.0053	,-0.0000861111	,-0.001205556]
mean=Series(a)
cov=[[-0.00007476 ,	0.00009105 ,	0.00006241 	,0.00000801 ,	-0.00005325 ,	-0.00001005 ,	0.00001191 	,0.00000786 ],
 [0.00009105 ,	0.00093352 	,0.00005843 ,	0.00007616 ,	-0.00012383 	,-0.00009167 	,0.00010417 ,	0.00009435 
],[0.00006241 	,0.00005843 ,	0.00031993 ,	0.00017620 ,	-0.00016271 ,	-0.00011210 ,	0.00008136 	,0.00016546 
],[0.00000801 	,0.00007616 	,0.00017620 ,	0.00047396 	,-0.00002732 ,	0.00004383, 	0.00012675 ,	0.00016739 
],[-0.00005325 	,-0.00012383 ,	-0.00016271 ,	-0.00002732 	,0.00066924 ,	0.00009461 ,	-0.00001865 ,	0.00004162 
],[-0.00001005 ,	-0.00009167 ,	-0.00011210 	,0.00004383 ,	0.00009461 ,	0.00119218,	-0.00000470 ,	0.00004152 
],[0.00001191 ,	0.00010417 	,0.00008136 ,	0.00012675 ,	-0.00001865 ,	-0.00000470 ,	0.00011878 ,	0.00011133 
],[0.00000786 	,0.00009435 ,	0.00016546 ,	0.00016739 ,	0.00004162 ,	0.00004152 	,0.00011133 ,	0.00025972 
]]
port_returns = []
port_variance = []
for p in range(4000):
        weights = np.random.random(8)
        weights /=np.sum(weights)
        port_returns.append(np.sum(mean*weights))
        port_variance.append(np.sqrt(np.dot(weights.T, np.dot(cov, weights))))
port_returns1 = np.array(port_returns)
port_variance1= np.array(port_variance)
plt.figure(figsize = (32,16))
plt.scatter(port_variance1, port_returns1,color='b', marker = 'o')

#
a=[0.002352778	,0.009378788	,-0.001083333,	0.003802778	,-0.001266667	,0.0053	,-0.0000861111	,-0.001205556]
mean=Series(a)
cov=[[-0.00007476 ,	0.00009105 ,	0.00006241 	,0.00000801 ,	-0.00005325 ,	-0.00001005 ,	0.00001191 	,0.00000786 ],
 [0.00009105 ,	0.00093352 	,0.00005843 ,	0.00007616 ,	-0.00012383 	,-0.00009167 	,0.00010417 ,	0.00009435 
],[0.00006241 	,0.00005843 ,	0.00031993 ,	0.00017620 ,	-0.00016271 ,	-0.00011210 ,	0.00008136 	,0.00016546 
],[0.00000801 	,0.00007616 	,0.00017620 ,	0.00047396 	,-0.00002732 ,	0.00004383, 	0.00012675 ,	0.00016739 
],[-0.00005325 	,-0.00012383 ,	-0.00016271 ,	-0.00002732 	,0.00066924 ,	0.00009461 ,	-0.00001865 ,	0.00004162 
],[-0.00001005 ,	-0.00009167 ,	-0.00011210 	,0.00004383 ,	0.00009461 ,	0.00119218,	-0.00000470 ,	0.00004152 
],[0.00001191 ,	0.00010417 	,0.00008136 ,	0.00012675 ,	-0.00001865 ,	-0.00000470 ,	0.00011878 ,	0.00011133 
],[0.00000786 	,0.00009435 ,	0.00016546 ,	0.00016739 ,	0.00004162 ,	0.00004152 	,0.00011133 ,	0.00025972 
]]
port_returns = []
port_variance = []
for p in range(4000):
    weights = np.random.random(8)
    weights /=np.sum(weights)
    port_returns.append(np.sum(mean*weights))
    port_variance.append(np.sqrt(np.dot(weights.T, np.dot(cov, weights))))
port_returns2 = np.array(port_returns)
port_variance2 = np.array(port_variance)
plt.figure(figsize = (32,16))
plt.scatter(port_variance2, port_returns2,color='r', marker = 'o')

#
a=[0.002352778	,0.009378788	,-0.001083333,	0.003802778	,-0.001266667	,0.0053	,-0.0000861111	,-0.001205556]
mean=Series(a)
cov=[[-0.00007476 ,	0.00009105 ,	0.00006241 	,0.00000801 ,	-0.00005325 ,	-0.00001005 ,	0.00001191 	,0.00000786 ],
 [0.00009105 ,	0.00093352 	,0.00005843 ,	0.00007616 ,	-0.00012383 	,-0.00009167 	,0.00010417 ,	0.00009435 
],[0.00006241 	,0.00005843 ,	0.00031993 ,	0.00017620 ,	-0.00016271 ,	-0.00011210 ,	0.00008136 	,0.00016546 
],[0.00000801 	,0.00007616 	,0.00017620 ,	0.00047396 	,-0.00002732 ,	0.00004383, 	0.00012675 ,	0.00016739 
],[-0.00005325 	,-0.00012383 ,	-0.00016271 ,	-0.00002732 	,0.00066924 ,	0.00009461 ,	-0.00001865 ,	0.00004162 
],[-0.00001005 ,	-0.00009167 ,	-0.00011210 	,0.00004383 ,	0.00009461 ,	0.00119218,	-0.00000470 ,	0.00004152 
],[0.00001191 ,	0.00010417 	,0.00008136 ,	0.00012675 ,	-0.00001865 ,	-0.00000470 ,	0.00011878 ,	0.00011133 
],[0.00000786 	,0.00009435 ,	0.00016546 ,	0.00016739 ,	0.00004162 ,	0.00004152 	,0.00011133 ,	0.00025972 
]]
port_returns = []
port_variance = []
for p in range(4000):
        weights = np.random.random(8)
        weights /=np.sum(weights)
        port_returns.append(np.sum(mean*weights))
        port_variance.append(np.sqrt(np.dot(weights.T, np.dot(cov, weights))))
port_returns3 = np.array(port_returns)
port_variance3 = np.array(port_variance)
plt.figure(figsize = (32,16))
print plt.scatter(port_variance3, port_returns3,color='b',marker='o')
#
print plt.plot(port_variance1, port_returns1,'ks',port_variance2, port_returns2,'ks',port_variance3, port_returns3,color='b',marker='o')
# Out:
# ...
# [<matplotlib.lines.Line2D object at 0x8005550>, <matplotlib.lines.Line2D object at 0x8005450>, <matplotlib.lines.Line2D object at 0x8005bd0>]
