# %% [markdown]
# # StockScreener发现的问题

# %% [markdown]
# 使用StockScreener选股，从2016-02-04开始，会把600016.XSHG选出来，很奇怪。具体看下面2016-02-04的输出。
#
# 其他程序里面也用的这个条件，不单2016-02-04当天会有600016，以后的每天都能选出来600016

# %% [raw]
# import numpy as np
#
# # 第一步：设置基本参数
# start = '2016-02-03'
# end   = '2016-02-06'
# capital_base = 1000000
# refresh_rate = 1
# benchmark = 'HS300'
# freq = 'd'
#
# # 第二步：选择主题，设置股票池
# universe = StockScreener(Factor.LFLO.nsmall(50))
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     print account.current_date
#     print account.universe
#     print len(account.universe)
