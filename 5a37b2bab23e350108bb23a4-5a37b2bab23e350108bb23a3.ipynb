# %% [markdown]
# # c12

# %% [raw]
# import pandas as pd
# import numpy as np
# import talib
# start = '2014-01-01'                       # 回测起始时间
# end = '2017-08-19'                         # 回测结束时间
# universe = DynamicUniverse('HS300')        # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 1                           # 执行handle_data的时间间隔
# slippage = Slippage(value=0.0, unit='perValue')
# max_history_window = 100                 #设定调取历史价格区间最大为100个交易日
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=10000000)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):                  # 核心策略逻辑
#     account = context.get_account('fantasy_account')
#     universe = context.get_universe(exclude_halt = True)
#     positions = account.get_positions()
#
#     data = context.history(symbol = universe,attribute = ['openPrice','highPrice','lowPrice','closePrice'],time_range = 100, freq = '1d',rtype = 'array',style = 'sat')
#     for s in universe:
#         high1 = data[s]['highPrice']
#         low1 = data[s]['lowPrice']
#         close1 = data[s]['closePrice']
#         openprice1 = data[s]['openPrice']
#
#         high = data[s]['highPrice'][0:25]
#         low = data[s]['lowPrice'][0:25]
#         close = data[s]['closePrice'][0:25]
#         openprice = data[s]['openPrice'][0:25]
#
#         ATR = talib.ATR(high,low,close,timeperiod = 25)
#         MAC = close.mean()
#         UBand = MAC + 4 * ATR
#         DBand = MAC - 4 * ATR
#         HH1 = high.max()
#         LL1 = low.min()
#         HH2 = high1.max()
#         LL2 = low1.min()
#         HighAfterEntry = max(close[-1],openprice[-1])
#
#
#
#
# #         if high[-1] >= HH1:
# #             order(s,100)
# #         if low[-1] <= LL1:
# #             order_to(s,0)
# #         if close[-1] >= open[-1] * 1.02:
# #             order_to(s,0)
# #         if close[-1] <= open[-1] * 0.98:
# #             order_to(s,0)
#         # if High[-1AfterEntry
