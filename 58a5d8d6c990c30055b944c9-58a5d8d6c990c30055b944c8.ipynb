# %% [markdown]
# # Notebook33

# %%
import numpy as np
import pandas as pd
import datetime
import time
universe = StockScreener( Factor.TaxRatio.value_range(0.02,0.05) )
#universe = ['300368.XSHE']
begin = '20160201'
end = '20170214'

# %%
print universe
for stock in universe:
    print stock
    dataday = DataAPI.MktEqudGet(tradeDate=u"",secID=u"",ticker=stock,beginDate= begin,endDate= end,isOpen="1",field=u'',pandas="1")
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <mercury-input-117-F2A10020EAB04CA2AAD4C42AD602561E> in <module>()
#       1 print universe
# ----> 2 for stock in universe:
#       3     print stock
#       4     dataday = DataAPI.MktEqudGet(tradeDate=u"",secID=u"",ticker=stock,beginDate= begin,endDate= end,isOpen="1",field=u'',pandas="1")
#       5
#
# TypeError: 'StockScreener' object is not iterable
