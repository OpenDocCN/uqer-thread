# %% [markdown]
# # winsorize 不是 scipy包 ， 而是 uper_Biuldin包；

# %%
import numpy as np
import pandas as pd
# from scipy.stats.mstats import winsorize
import matplotlib.pyplot as plt

universe = set_universe('SH50') # 以上证50市盈率因子进行说明
# print(universe)
# MktStockFactorsOneDayGet ： 获取多只股票历史上某一天的因子数据
data = DataAPI.MktStockFactorsOneDayGet(tradeDate='20150916', secID=universe, field='ticker,PE',pandas='1').set_index('ticker')

"""
为缓解离群值对参数估计的影响，对属于连续型的解释变量在其分布的第1及99百分位上的观察值进行缩尾调整（Winsorize）处理。

    limits : {None, tuple of float}, optional
        Tuple of the percentages to cut on each side of the array, with respect
        to the number of unmasked data, as floats between 0. and 1.
        Noting n the number of unmasked data before trimming, the
        (n*limits[0])th smallest data and the (n*limits[1])th largest data are
        masked, and the total number of unmasked data after trimming
        is n*(1.-sum(limits)) The value of one limit can be set to None to
        indicate an open interval.
    inclusive : {(True, True) tuple}, optional
        Tuple indicating whether the number of data being masked on each side
        should be rounded (True) or truncated (False).
    inplace : {False, True}, optional
        Whether to winsorize in place (True) or to use a copy (False)
    axis : {None, int}, optional
        Axis along which to trim. If None, the whole array is trimmed, but its
        shape is maintained.
"""
data = data['PE'].to_dict()
# new_data = winsorize(data, limits=None, inclusive=(True, True), inplace=False,axis=None) # winsorize之后数据
new_data = winsorize(data) # winsorize之后数据
print(new_data)

df = pd.DataFrame(data=0, index=map(lambda x: x[:6], universe),columns=['before winsorize','after winsorize'])
# df

df['before winsorize'][data.keys()] = data.values() # 对比两者数据进行展示
df['after winsorize'][new_data.keys()] = new_data.values() # ！！原有的new_data.values()出错！！
df.reset_index(inplace=True)
# df
print(df)

df.plot(figsize=(14,7))

# winsorize?
# Out:
# {'600196': 23.231400000000001, '601766': 65.983400000000003, '600031': -36.143334973261652, '600030': 8.8612000000000002, '601186': 17.449000000000002, '601688': 10.9483, '600036': 7.7176999999999998, '601211': 10.1593, '601888': 32.219200000000001, '600837': 10.0223, '601288': 5.7281000000000004, '601939': 6.0465999999999998, '601818': 6.6162999999999998, '601111': 14.104000000000001, '601857': 24.874199999999998, '600703': 29.737100000000002, '601800': 13.6934, '600340': 15.0662, '600000': 5.9623999999999997, '600690': 12.359999999999999, '600104': 7.0826000000000002, '601328': 7.1577000000000002, '600276': 50.624299999999998, '600028': 14.9741, '600029': 12.019600000000001, '600309': 20.0549, '600048': 6.7609000000000004, '601988': 6.7981999999999996, '601989': 69.068426931686957, '601668': 7.6201999999999996, '600585': 10.3818, '601390': 23.043000000000003, '600050': 33.018099999999997, '601398': 5.8342000000000001, '600887': 21.806999999999999, '603993': 48.240499999999997, '600519': 16.051500000000001, '601628': 17.1175, '601336': 12.252800000000001, '600016': 7.1608999999999998, '601318': 10.624000000000001, '600019': 17.027999999999999, '601088': 11.7254, '601601': 13.976599999999999, '601166': 5.7557}
#      index  before winsorize  after winsorize
# 0   600016            7.1609         7.160900
# 1   600028           14.9741        14.974100
# 2   600030            8.8612         8.861200
# 3   600000            5.9624         5.962400
# 4   600036            7.7177         7.717700
# 5   600050           33.0181        33.018100
# 6   600104            7.0826         7.082600
# 7   600519           16.0515        16.051500
# 8   601398            5.8342         5.834200
# 9   600048            6.7609         6.760900
# 10  601628           17.1175        17.117500
# 11  601166            5.7557         5.755700
# 12  601318           10.6240        10.624000
# 13  601328            7.1577         7.157700
# 14  601088           11.7254        11.725400
# 15  601857           24.8742        24.874200
# 16  601601           13.9766        13.976600
# 17  601668            7.6202         7.620200
# 18  601288            5.7281         5.728100
# 19  601818            6.6163         6.616300
# 20  601989          167.9813        69.068427
# 21  601766           65.9834        65.983400
# 22  600887           21.8070        21.807000
# 23  601688           10.9483        10.948300
# 24  601800           13.6934        13.693400
# 25  601186           17.4490        17.449000
# 26  601988            6.7982         6.798200
# 27  601390           23.0430        23.043000
# 28  601211           10.1593        10.159300
# 29  601336           12.2528        12.252800
# 30  600029           12.0196        12.019600
# 31  601229            0.0000         0.000000
# 32  600340           15.0662        15.066200
# 33  603993           48.2405        48.240500
# 34  600019           17.0280        17.028000
# 35  600309           20.0549        20.054900
# 36  600276           50.6243        50.624300
# 37  600703           29.7371        29.737100
# 38  600690           12.3600        12.360000
# 39  600585           10.3818        10.381800
# 40  601138            0.0000         0.000000
# 41  601888           32.2192        32.219200
# 42  601939            6.0466         6.046600
# 43  603259            0.0000         0.000000
# 44  600196           23.2314        23.231400
# 45  601319            0.0000         0.000000
# 46  600031         -168.0175       -36.143335
# 47  601111           14.1040        14.104000
# 48  601066            0.0000         0.000000
# 49  600837           10.0223        10.022300
