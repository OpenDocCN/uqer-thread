# %% [markdown]
# # 交易流水分析

# %%
import pandas as pd

file_name = "blotter.csv"
records = pd.read_csv(file_name)
records.ticker = records.ticker.astype(str)
records['ticker'] = [str('{0:06d}'.format(int(a))) for a in records['ticker']]
records.head(10)
# Out:
#          date   time  ticker buy/sell  amount
# 0  2014-01-07  09:30  600136      buy   900.0
# 1  2014-01-07  09:30  600520      buy  1100.0
# 2  2014-01-07  09:30  000004      buy   800.0
# 3  2014-01-07  09:30  000546      buy  1600.0
# 4  2014-01-07  09:30  002374      buy  1300.0
# 5  2014-01-13  09:30  000004      buy   800.0
# 6  2014-01-17  14:58  000546     sell  1600.0
# 7  2014-01-20  09:30  000546      buy  1800.0
# 8  2014-01-20  14:58  600520     sell  1100.0
# 9  2014-01-24  14:58  000004     sell   800.0

# %% [raw]
# start = '2014-01-01'                       # 回测起始时间
# end = '2017-02-27'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = DynamicUniverse('A')               # 证券池，支持股票和基金
# capital_base = 1000000                     # 起始资金
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = (1,1)                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# commission = Commission(buycost=0.0003, sellcost=0.0013)
# slippage = Slippage(value=0.01, unit='perShare')
#
# def initialize(account):                   # 初始化虚拟账户状态
#     account.print_log = False
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     ### 获取本交易日，前一交易日
#     current_date = account.current_date.strftime('%Y-%m-%d')
#     previous_date = account.previous_date.strftime('%Y-%m-%d')
#     current_minute = account.current_minute
#     if current_minute!='09:30' and current_minute!='14:58':
#         return
#
#     ### 获取当日调仓记录
#     today_orders = records[records.date == current_date]
#     today_orders = today_orders[today_orders.time == current_minute]
#     if account.print_log and not today_orders.empty:
#         print '-' * 80
#         print u'调仓时间：{}T{}'.format(current_date, current_minute)
#         print today_orders.to_html()
#
#     ### 根据调仓记录下单
#     if not today_orders.empty:
#         n_orders = len(today_orders)
#         percent = 1.0/n_orders
#
#         for ticker, direction, amount in zip(today_orders.ticker, today_orders['buy/sell'], today_orders.amount):
#             ticker = '{:0>6}.XSHE'.format(ticker) if ticker[0] != 6 else '{:0>6}.XSHG'.format(ticker)
#             if direction == 'sell':
#                 # order(ticker, int(amount))  #在一定要按照amount下单时再使用，下同
#                 order_pct_to(ticker,0)
#
#         for ticker, direction, amount in zip(today_orders.ticker, today_orders['buy/sell'], today_orders.amount):
#             ticker = '{:0>6}.XSHE'.format(ticker) if ticker[0] != 6 else '{:0>6}.XSHG'.format(ticker)
#             if direction == 'buy':
#                 # order(ticker, int(amount))  #在一定要按照amount下单时再使用，下同
#                 order_pct_to(ticker,percent)
#     return
