# %% [markdown]
# # 量化代码

# %% [raw]
# 第四题代码
# c=DataAPI.MktEqudAdjGet(secID=u"",ticker=u"601857",tradeDate=u"",beginDate=u"20131231",endDate=u"20151231",isOpen="",field=u"ticker,secShortName,tradeDate,closePrice",pandas="1")
# print c
# a=df.iloc[0,-1]
# b=df.iloc[-1,-1]
# (b-a)/a#中国石油2013-2015收益率
# 第六题代码
# df=DataAPI.MktStockFactorsOneDayGet(tradeDate=u"20141231",secID=u"",ticker=u"",field=u"ticker,tradeDate,PE,ROE",pandas="1").fillna(value=0)
# df1=df.sort_values(by='PE')
# df2=df1[((df1.PE)>0)&((df1.ROE)>0.15)&((df1.ROE)<0.40)]
# df2.head(10)
# a1=DataAPI.EquRetudGet(secID=u"",ticker=u"601398",listStatusCD=u"",beginDate=u"20141231",endDate=u"20151231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r1=a1.cumsum().iloc[-1,-1]
# print r1
# a2=DataAPI.EquRetudGet(secID=u"",ticker=u"600000",listStatusCD=u"",beginDate=u"20141231",endDate=u"20151231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r2=a2.cumsum().iloc[-1,-1]
# print r2
# a3=DataAPI.EquRetudGet(secID=u"",ticker=u"601288",listStatusCD=u"",beginDate=u"20141231",endDate=u"20151231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r3=a3.cumsum().iloc[-1,-1]
# print r3
# a4=DataAPI.EquRetudGet(secID=u"",ticker=u"601166",listStatusCD=u"",beginDate=u"20141231",endDate=u"20151231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r4=a4.cumsum().iloc[-1,-1]
# print r4
# a5=DataAPI.EquRetudGet(secID=u"",ticker=u"600015",listStatusCD=u"",beginDate=u"20141231",endDate=u"20151231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r5=a5.cumsum().iloc[-1,-1]
# print r5
# a6=DataAPI.EquRetudGet(secID=u"",ticker=u"601988",listStatusCD=u"",beginDate=u"20141231",endDate=u"20151231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r6=a6.cumsum().iloc[-1,-1]
# print r6
# a7=DataAPI.EquRetudGet(secID=u"",ticker=u"600036",listStatusCD=u"",beginDate=u"20141231",endDate=u"20151231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r7=a7.cumsum().iloc[-1,-1]
# print r7
# a8=DataAPI.EquRetudGet(secID=u"",ticker=u"601939",listStatusCD=u"",beginDate=u"20141231",endDate=u"20151231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r8=a8.cumsum().iloc[-1,-1]
# print r8
# a9=DataAPI.EquRetudGet(secID=u"",ticker=u"601169",listStatusCD=u"",beginDate=u"20141231",endDate=u"20151231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r9=a9.cumsum().iloc[-1,-1]
# print r9
# a10=DataAPI.EquRetudGet(secID=u"",ticker=u"601328",listStatusCD=u"",beginDate=u"20141231",endDate=u"20151231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r10=a10.cumsum().iloc[-1,-1]
# print r10
# print ''
# print '组合年化收益:'
# print (r1+r2+r3+r4+r5+r6+r7+r8+r9+r10)/10
# df=DataAPI.MktStockFactorsOneDayGet(tradeDate=u"20151231",secID=u"",ticker=u"",field=u"ticker,tradeDate,PE,ROE",pandas="1").fillna(value=0)
# df1=df.sort_values(by='PE')
# df2=df1[((df1.PE)>0)&((df1.ROE)>0.15)&((df1.ROE)<0.40)]
# df2.head(10)
# a1=DataAPI.EquRetudGet(secID=u"",ticker=u"601288",listStatusCD=u"",beginDate=u"20151231",endDate=u"20161231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r1=a1.cumsum().iloc[-1,-1]
# print r1
# a2=DataAPI.EquRetudGet(secID=u"",ticker=u"601398",listStatusCD=u"",beginDate=u"20151231",endDate=u"20161231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r2=a2.cumsum().iloc[-1,-1]
# print r2
# a3=DataAPI.EquRetudGet(secID=u"",ticker=u"601939",listStatusCD=u"",beginDate=u"20151231",endDate=u"20161231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r3=a3.cumsum().iloc[-1,-1]
# print r3
# a4=DataAPI.EquRetudGet(secID=u"",ticker=u"601166",listStatusCD=u"",beginDate=u"20151231",endDate=u"20161231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r4=a4.cumsum().iloc[-1,-1]
# print r4
# a5=DataAPI.EquRetudGet(secID=u"",ticker=u"601818",listStatusCD=u"",beginDate=u"20151231",endDate=u"20161231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r5=a5.cumsum().iloc[-1,-1]
# print r5
# a6=DataAPI.EquRetudGet(secID=u"",ticker=u"600000",listStatusCD=u"",beginDate=u"20151231",endDate=u"20161231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r6=a6.cumsum().iloc[-1,-1]
# print r6
# a7=DataAPI.EquRetudGet(secID=u"",ticker=u"600015",listStatusCD=u"",beginDate=u"20151231",endDate=u"20161231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r7=a7.cumsum().iloc[-1,-1]
# print r7
# a8=DataAPI.EquRetudGet(secID=u"",ticker=u"600016",listStatusCD=u"",beginDate=u"20151231",endDate=u"20161231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r8=a8.cumsum().iloc[-1,-1]
# print r8
# a9=DataAPI.EquRetudGet(secID=u"",ticker=u"601668",listStatusCD=u"",beginDate=u"20151231",endDate=u"20161231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r9=a9.cumsum().iloc[-1,-1]
# print r9
# a10=DataAPI.EquRetudGet(secID=u"",ticker=u"600036",listStatusCD=u"",beginDate=u"20151231",endDate=u"20161231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r10=a10.cumsum().iloc[-1,-1]
# print r10
# print ''
# print '组合年化收益:'
# print (r1+r2+r3+r4+r5+r6+r7+r8+r9+r10)/10
# df=DataAPI.MktStockFactorsOneDayGet(tradeDate=u"20161230",secID=u"",ticker=u"",field=u"ticker,tradeDate,PE,ROE",pandas="1").fillna(value=0)
# df1=df.sort_values(by='PE')
# df2=df1[((df1.PE)>0)&((df1.ROE)>0.15)&((df1.ROE)<0.40)]
# df2.head(10)
# a1=DataAPI.EquRetudGet(secID=u"",ticker=u"601398",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r1=a1.cumsum().iloc[-1,-1]
# print r1
# a2=DataAPI.EquRetudGet(secID=u"",ticker=u"600000",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r2=a2.cumsum().iloc[-1,-1]
# print r2
# a3=DataAPI.EquRetudGet(secID=u"",ticker=u"000625",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r3=a3.cumsum().iloc[-1,-1]
# print r3
# a4=DataAPI.EquRetudGet(secID=u"",ticker=u"601166",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r4=a4.cumsum().iloc[-1,-1]
# print r4
# a5=DataAPI.EquRetudGet(secID=u"",ticker=u"600015",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r5=a5.cumsum().iloc[-1,-1]
# print r5
# a6=DataAPI.EquRetudGet(secID=u"",ticker=u"600100",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r6=a6.cumsum().iloc[-1,-1]
# print r6
# a7=DataAPI.EquRetudGet(secID=u"",ticker=u"600036",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r7=a7.cumsum().iloc[-1,-1]
# print r7
# a8=DataAPI.EquRetudGet(secID=u"",ticker=u"601939",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r8=a8.cumsum().iloc[-1,-1]
# print r8
# a9=DataAPI.EquRetudGet(secID=u"",ticker=u"600016",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r9=a9.cumsum().iloc[-1,-1]
# print r9
# a10=DataAPI.EquRetudGet(secID=u"",ticker=u"601009",listStatusCD=u"",beginDate=u"20161231",endDate=u"20171231",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",isChgPctl=u"",field=u"ticker,tradeDate,dailyReturnReinv",pandas="1").fillna(value=0)  #对空值NaN的填补
# r10=a10.cumsum().iloc[-1,-1]
# print r10
# print ''
# print '组合年化收益:'
# print (r1+r2+r3+r4+r5+r6+r7+r8+r9+r10)/10
# 第七题
# import numpy as np
# import matplotlib.pyplot as plt
# from matplotlib.font_manager import FontProperties
# from sklearn.linear_model import LinearRegression
#
# a=DataAPI.EquRetudGet(listStatusCD=u"",secID=u"",ticker=u"600276",beginDate=u"20080101",dailyReturnNoReinvLower=u"",dailyReturnNoReinvUpper=u"",dailyReturnReinvLower=u"",dailyReturnReinvUpper=u"",endDate=u"20171231",isChgPctl=u"",field=u"tradeDate,secShortName,dailyReturnReinv",pandas="1")  #dailyReturnReinv就是每天涨跌幅
#
# b=DataAPI.MktIdxdGet(indexID=u"",ticker=u"000001",tradeDate=u"",beginDate=u"20080101",endDate=u"20171231",exchangeCD=u"XSHE,XSHG",field=u"tradeDate,secShortName,CHGPct",pandas="1")
#
#
# x=np.array(a[['dailyReturnReinv']])       # X：股票日收益率作为二维数组
# y=np.array(b['CHGPct'])                   # Y：指数日收益率作为一维数组
#
# where_are_nan = np.isnan(x)               # 下面将数据中的空值NaN替换成 0
# where_are_inf = np.isinf(x)
# x[where_are_nan] = 0
# x[where_are_inf] = 0
#
# where_are_nan = np.isnan(y)
# where_are_inf = np.isinf(y)
# y[where_are_nan] = 0
# y[where_are_inf] = 0
#
# print 'X:'
# print x                                         # 完成x,y数据的处理，打印出数据
# print 'Y:'
# print y
#
# clf=LinearRegression()
# clf.fit(x,y)                                    # 将x,y代入线性回归模型，下面求出模型的关键参数
#
# print '斜率：'
# print clf.coef_
# print '截距:'
# print clf.intercept_
# print '判定系数R方:'
# print clf.score(x,y)
# print '输入自变量(0.006)预测因变量:'
# print clf.predict(0.006)
#
# plt.scatter(x,y,6,color='blue',marker='o',linewidth=0.1,alpha=0.8)
# plt.xlabel('000036')
# plt.ylabel('000001')
# plt.axis([-0.1 ,0.1, -0.1, 0.1])                # 做出x,y的散点图
#
# k=clf.coef_                                     # 下面画拟合直线
# b=clf.intercept_
# x1=np.linspace(-0.1,0.1,2500)
# y1=k*x1+b
# plt.plot(x1,y1,color='red',linewidth=5)
# plt.show()
# 第八题
# a=DataAPI.MktIdxdGet(indexID=u"",ticker=u"399001",tradeDate=u"",beginDate=u"20100101",endDate=u"20171231",exchangeCD=u"XSHE,XSHG",field=u"ticker,tradeDate,closeIndex,CHGPct",pandas="1")
# r=a.CHGPct.cumsum().iloc[-1]  #注释：iloc[-1]取得是最后一行数据
# print '年收益率：'
# print r
# print ''
# returns=a.pivot(index='tradeDate',columns='ticker',values='CHGPct')
# returns = returns.fillna(value=0)
# cov1 = returns.cov() * 244
# print '年标准差：'
# cov=cov1.iloc[-1]
# print cov
# print ''
#
# df1=DataAPI.MktIdxFactorDateRangeGet(secID=u"",ticker=u"399001",beginDate=u"20100101",endDate=u"20171231",field=u"ticker,tradeDate,PE1",pandas="1")
# print '深证综指市盈分布：'
# print df1.iloc[-1]
# print df1.describe()
# print ''
# 上一封 下一封« 返回
