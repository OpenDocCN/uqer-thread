# %% [markdown]
# # 关于advanceDate函数使用的一些疑问？

# %% [markdown]
# 请问一下大家：关于advanceDate这个函数，当Period为工作日时，没什么问题，但是将周期改为period = Period('-1D') 时运行的结果在周末时感觉有点奇怪，即为什么周六（20160409）周日（20160410）周一（20160411）的前一天都是周一（20160411）呢？

# %%
from CAL.PyCAL import *
cal = Calendar('China.SSE')
period = Period('-1D')   #B是工作日单位
day1 = Date(2016,4,8)
day2 =Date(2016,4,9)
day3 = Date(2016,4,10)
day4 =Date(2016,4,11)
day5 = Date(2016,4,12)
day6 =Date(2016,4,13)
print cal.advanceDate(day1, period) #CAL库的时间格式
print cal.advanceDate(day2, period) #CAL库的时间格式
print cal.advanceDate(day3, period) #CAL库的时间格式
print cal.advanceDate(day4, period) #CAL库的时间格式
print cal.advanceDate(day5, period) #CAL库的时间格式
print cal.advanceDate(day6, period) #CAL库的时间格式
# Out:
# 2016-04-07
# 2016-04-08
# 2016-04-11
# 2016-04-11
# 2016-04-11
# 2016-04-12
