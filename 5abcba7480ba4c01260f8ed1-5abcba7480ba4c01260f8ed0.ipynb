# %% [markdown]
# # Notebook

# %%
# a = (1,2,3,[4,5])
# a[3][0] = 11
# print(a)


pe = DataAPI.MktStockFactorsOneDayGet(secID='IndSW.JinRongFuWuL1',tradeDate="20180110",field="ticker,tradeDate,PE,PB,ROE,ROE5",pandas="1")
print(pe)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <mercury-input-19-69A8E3F5C43D4B158CDA302DA90364CB> in <module>()
#       4
#       5
# ----> 6 pe = DataAPI.MktStockFactorsOneDayGet(secID='IndSW.JinRongFuWuL1',tradeDate="20180110",field="ticker,tradeDate,PE,PB,ROE,ROE5",pandas="1")
#       7 print(pe)
#
# /home/ipython/anaconda/lib/python2.7/site-packages/DataAPI/DATAYES.pyc in MktStockFactorsOneDayGet(tradeDate, secID, ticker, field, pandas)
#    2142         csvString = api_base.__getCSV__(''.join(requestString), httpClient, gw=False)
#    2143         if csvString is None or len(csvString) == 0 or (csvString[0] == '-' and not api_base.is_no_data_warn(csvString, False)) or csvString[0] == '{':
# -> 2144             api_base.handle_error(csvString, 'MktStockFactorsOneDayGet')
#    2145         elif csvString[:2] == '-1':
#    2146             csvString = ''
#
# ...
