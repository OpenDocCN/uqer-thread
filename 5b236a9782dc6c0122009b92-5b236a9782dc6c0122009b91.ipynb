# %% [markdown]
# # 波动率研究之五_机器学习%28Lasso和Elasticnet模型%29与波动率预测

# %% [markdown]
# 本文是波动率研究第五篇, 介绍4种滚动波动率预测方法，包括机器学习算法（Lasso和Elasticnet模型)方法，首先简单解释下滚动波动率和机器学习算法（Lasso和Elasticnet模型）：
# ---
# **一、波动率从计算周期和方法角度可细分为：静态波动率、滚动波动率和动态波动率（自己定义的）**：
#        1.1、静态波动率是取上时间周期（上一年、上一月或一周、一天等）的数据度量的波动率；
#        1.2、滚动波动率是取最近一个时间周期（一年、最近一个月、最近一周或最近一分钟等）度量的波动率；
#        1.3、动态波动率（即为隐含波动率）及用期权或其他工具度量的波动率
#
# 用那种波动率作为预测波动率，要看具体情况，但一般滚动波动率适应性强些。

# %% [markdown]
# **二、Lasso和Elasticnet模型**
#    2.1、 LASSO是由1996年Robert Tibshirani首次提出，全称Least absolute shrinkage and selection operator。该方法是一种压缩估计。它通过构造一个惩罚函数得到一个较为精炼的模型，使得它压缩一些系数，同时设定一些系数为零。因此保留了子集收缩的优点，是一种处理具有复共线性数据的有偏估计。Lasso 是一种估计稀疏线性模型的方法.由于它倾向具有少量参数值的情况，对于给定解决方案是相关情况下，有效的减少了变量数量。
#    用数学形式表达，Lasso 包含一个使用 ell1 先验作为正则化因子的线性模型。其目标函数是最小化:
#       ![图片注释](http://storage-uqer.datayes.com/59fc254cf2342d010d516471/d2648d36-7064-11e8-87bb-0242ac140002)
#       ------
#    具体参考 Robert Tibshirani自己的lasso主页：  http://statweb.stanford.edu/~tibs/lasso.html
#    2.2、ElasticNet 是一种使用L1和L2先验作为正则化矩阵的线性回归模型.这种组合用于只有很少的权重非零的稀疏模型，比如:class:Lasso, 但是又能保持:class:Ridge 的正则化属性.我们可以使用 l1_ratio 参数来调节L1和L2的凸组合(一类特殊的线性组合)。 当多个特征和另一个特征相关的时候弹性网络非常有用。Lasso 倾向于随机选择其中一个，而弹性网络更倾向于选择两个。在实践中，Lasso 和 Ridge 之间权衡的一个优势是它允许在循环过程（Under rotate）中继承 Ridge 的稳定性。
# 弹性网络的目标函数是最小化：
#
# ![图片注释](http://storage-uqer.datayes.com/59fc254cf2342d010d516471/39c40eb4-7067-11e8-87bb-0242ac140002)
# Regularization and variable selection via the elastic net H Zou ， T Hastie，《Journal of the Royal Statistical Society》 , 2010 ，https://web.stanford.edu/~hastie/Papers/elasticnet.pdf

# %% [markdown]
# **三、预测波动率**
#  利用波动率第二篇给出的8个波动率估计量结果预测， 仍然采用沪深300指数数据计算：
#  3.1、取数据、计算度量8个波动率；
#  3.2、给出5种滚动波动率计算方法；
#  3.3、综合比较，画出图形。

# %%
import math
import os
import pdb
import re
import itertools
import numpy as np
import pandas as pd
import datetime as dt
import seaborn as sns
from arch import arch_model
import scipy.stats as stats
from statsmodels.tsa.ar_model import AR
from scipy.stats import kurtosis
import matplotlib.pyplot as plt
from dateutil.parser import parse
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from collections import defaultdict
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso, ElasticNet, ElasticNetCV, LinearRegression

# %% [markdown]
# 3.1、取数据、计算8个波动率
# ---

# %%
#8种波动率估计量函数

def Parkinson_get_estimator(price_data, window=30, trading_periods=252, clean=True):
    "Parkinson（1980）估计量采用了交易时段最高价和最低价两个价格数据，利用极差进行估计。该估计量使价格波动区间在一定假设下比基于收盘价的估计量更能有效地估计回报波动率。"

    rs = (1.0 / (4.0 * math.log(2.0))) * ((price_data['High'] / price_data['Low']).apply(np.log))**2.0

    def f(v):
        return trading_periods * v.mean()**0.5
    
    result = rs.rolling(
        window=window,
        center=False
    ).apply(func=f)
    
    if clean:
        return result.dropna()
    else:
        return result
    
def GarmanKlass_get_estimator(price_data, window=30, trading_periods=252, clean=True):
    "Garman-Klass（1980）利用了交易时段最高价、最低价和收盘价三个价格数据进行估计，该估计量通过将估计量除以调整 因子来纠正存在的偏差，以便得到方差的无偏估计。"
    log_hl = (price_data['High'] / price_data['Low']).apply(np.log)
    log_cc = (price_data['Close'] / price_data['Close'].shift(1)).apply(np.log)

    rs = 0.5 * log_hl**2 - (2*math.log(2)-1) * log_cc**2
    
    def f(v):
        return (trading_periods * v.mean())**0.5
    
    result = rs.rolling(window=window, center=False).apply(func=f)
    
    if clean:
        return result.dropna()
    else:
        return result


def RogersSatchell_get_estimator(price_data, window=30, trading_periods=252, clean=True):
    "Parkinson和Garman-Klass估计量之所以能提高估计效率，是因为它们依赖于一些不适用于真实市场的假设，尤其价格服从不带漂移项的几何布朗运动以及交易是连续的假设。Rogers –Satchell在一定程度上放宽了这些限制条件，引入带有漂移项的更优的估计量。"
    log_ho = (price_data['High'] / price_data['Open']).apply(np.log)
    log_lo = (price_data['Low'] / price_data['Open']).apply(np.log)
    log_co = (price_data['Close'] / price_data['Open']).apply(np.log)
    
    rs = log_ho * (log_ho - log_co) + log_lo * (log_lo - log_co)

    def f(v):
        return trading_periods * v.mean()**0.5
    
    result = rs.rolling(
        window=window,
        center=False
    ).apply(func=f)
    
    if clean:
        return result.dropna()
    else:
        return result
    

    
def YangZhang_get_estimator(price_data, window=30, trading_periods=252, clean=True):
    "　Garman-Klass（1980）估计量无法解决价格序列中存在跳空开盘的情况。Yang-Zhang（2000）推导出了适用于价格跳空开盘的估计量，本质上是各种估计量的加权平均。 "
    log_ho = (price_data['High'] / price_data['Open']).apply(np.log)
    log_lo = (price_data['Low'] / price_data['Open']).apply(np.log)
    log_co = (price_data['Close'] / price_data['Open']).apply(np.log)
    
    log_oc = (price_data['Open'] / price_data['Close'].shift(1)).apply(np.log)
    log_oc_sq = log_oc**2
    
    log_cc = (price_data['Close'] / price_data['Close'].shift(1)).apply(np.log)
    log_cc_sq = log_cc**2
    
    rs = log_ho * (log_ho - log_co) + log_lo * (log_lo - log_co)
    
    close_vol = log_cc_sq.rolling(
        window=window,
        center=False
    ).sum() * (1.0 / (window - 1.0))
    open_vol = log_oc_sq.rolling(
        window=window,
        center=False
    ).sum() * (1.0 / (window - 1.0))
    window_rs = rs.rolling(
        window=window,
        center=False
    ).sum() * (1.0 / (window - 1.0))

    k = 0.34 / (1 + (window + 1) / (window - 1))
    result = (open_vol + k * close_vol + (1 - k) * window_rs).apply(np.sqrt) * math.sqrt(trading_periods)

    if clean:
        return result.dropna()
    else:
        return result

    
    
def Raw_get_estimator(price_data, window=30, trading_periods=252, clean=True):
    "最经常用的收盘价方差计算的波动率"
    log_return = (price_data['Close'] / price_data['Close'].shift(1)).apply(np.log)

    result = log_return.rolling(
        window=window,
        center=False
    ).std() * math.sqrt(trading_periods)

    if clean:
        return result.dropna()
    else:
        return result


def Skew_get_estimator(price_data, window=30, clean=True):
    "偏度Skew代替波动率"
    log_return = (price_data['Close'] / price_data['Close'].shift(1)).apply(np.log)
    
    result = log_return.rolling(
        window=window,
        center=False
    ).skew()

    if clean:
        return result.dropna()
    else:
        return result

def Kurtosis_get_estimator(price_data, window=30, clean=True):
    "峰度Kurtosis代替波动率"
    log_return = (price_data['Close'] / price_data['Close'].shift(1)).apply(np.log)

    result = log_return.rolling(
        window=window,
        center=False
    ).kurt()

    if clean:
        return result.dropna()
    else:
        return result
    
    
def HodgesTompkins_get_estimator(price_data, window=30, trading_periods=252, clean=True):
    "参考文献：The Sampling Properties of Volatility Cones,  Stewart Hodges and Robert Tompkins, 《Journal of Derivatives》 , 2002：https://www.researchgate.net/publication/228431910_Volatility_Cones_and_Their_Sampling_Properties"
    
    log_return = (price_data['Close'] / price_data['Close'].shift(1)).apply(np.log)

    vol = log_return.rolling(
        window=window,
        center=False
    ).std() * math.sqrt(trading_periods)

    h = window
    n = (log_return.count() - h) + 1

    adj_factor = 1.0 / (1.0 - (h / n) + ((h**2 - 1) / (3 * n**2)))

    result = vol * adj_factor

    if clean:
        return result.dropna()
    else:
        return result

# %%
#取出深300指数,开盘价，最低价、最高价和收盘价、成交量和成交额
start = '20130501'
end = '20180501'
price_data = DataAPI.MktIdxdGet(ticker='000300', beginDate=start, endDate=end, field="tradeDate,openIndex,lowestIndex,highestIndex,closeIndex,turnoverVol,turnoverValue")
price_data=price_data.set_index('tradeDate')
price_data.columns=['Open', 'Low','High', 'Close','turnoverVol', 'turnoverValue']
price_data.head()
# Out:
#                Open      Low     High    Close  turnoverVol  turnoverValue
# tradeDate
# 2013-05-02  2434.60  2423.08  2453.75  2449.64   4701608800  47200448204.0
# 2013-05-03  2457.54  2457.54  2521.12  2492.91   6233009100  63267042656.0
# 2013-05-06  2502.98  2500.46  2533.86  2525.98   6041878000  61767951099.0
# 2013-05-07  2519.36  2507.76  2539.30  2529.94   5449064300  59244949469.0
# 2013-05-08  2542.27  2531.25  2562.01  2542.80   5955429400  60309148841.0

# %%
#计算、并把几个波动率综合在一起
ParkinsonVol=Parkinson_get_estimator(price_data)
GarmanKlassVol=GarmanKlass_get_estimator(price_data)
RogersSatchellVol=RogersSatchell_get_estimator(price_data)
YangZhangVol=YangZhang_get_estimator(price_data)
RawVol=Raw_get_estimator(price_data)
SkewVol=Skew_get_estimator(price_data)
KurtosisVol=Kurtosis_get_estimator(price_data)
HodgesTompkinsVol=HodgesTompkins_get_estimator(price_data)
#综合在一起对比下
zvol=pd.concat([ParkinsonVol,GarmanKlassVol,RogersSatchellVol,YangZhangVol,RawVol,SkewVol,KurtosisVol,HodgesTompkinsVol],axis = 1).dropna()
zvol.columns=['ParkinsonVol','GarmanKlassVol','RogersSatchellVol','YangZhangVol','RawVol','SkewVol','KurtosisVol','HodgesTompkinsVol']
zvol.index.name='tradeDate'

# %%
zvol.head()
# Out:
#             ParkinsonVol  GarmanKlassVol  RogersSatchellVol  YangZhangVol  \
# tradeDate
# 2013-06-18  2.4096892047    0.1369443333       2.3681419931  0.1685274409
# 2013-06-19  2.3545766373    0.1346227682       2.3529648625  0.1669138556
# 2013-06-20  2.4511038962    0.1325846848       2.3378637898  0.1709191308
# 2013-06-21  2.5428047418    0.1417598554       2.4257189719  0.1816253948
# 2013-06-24  3.0840110741    0.1521707565       2.4801230352  0.2001660044
#
#                   RawVol       SkewVol   KurtosisVol  HodgesTompkinsVol
# tradeDate
# 2013-06-18  0.1878136138 -0.6701852601  0.9921694832       0.1878136138
# 2013-06-19  0.1809139191 -0.6672511199  1.1742553514       0.1809139191
# 2013-06-20  0.1984144541 -0.7990356254  1.0315100760       0.1984144541
# 2013-06-21  0.1980101116 -0.7769527195  1.0343676771       0.1980101116
# 2013-06-24  0.2662278011 -1.7597405597  4.7685882766       0.2662278011

# %%
#把波动率和原数据合并
df = pd.concat([zvol, price_data],axis=1)  
df=df.dropna()
df.head()
# Out:
#             ParkinsonVol  GarmanKlassVol  RogersSatchellVol  YangZhangVol  \
# 2013-06-18  2.4096892047    0.1369443333       2.3681419931  0.1685274409
# 2013-06-19  2.3545766373    0.1346227682       2.3529648625  0.1669138556
# 2013-06-20  2.4511038962    0.1325846848       2.3378637898  0.1709191308
# 2013-06-21  2.5428047418    0.1417598554       2.4257189719  0.1816253948
# 2013-06-24  3.0840110741    0.1521707565       2.4801230352  0.2001660044
#
#                   RawVol       SkewVol   KurtosisVol  HodgesTompkinsVol  \
# 2013-06-18  0.1878136138 -0.6701852601  0.9921694832       0.1878136138
# 2013-06-19  0.1809139191 -0.6672511199  1.1742553514       0.1809139191
# 2013-06-20  0.1984144541 -0.7990356254  1.0315100760       0.1984144541
# 2013-06-21  0.1980101116 -0.7769527195  1.0343676771       0.1980101116
# 2013-06-24  0.2662278011 -1.7597405597  4.7685882766       0.2662278011
#
#                Open      Low     High    Close  turnoverVol  turnoverValue
# 2013-06-18  2413.09  2393.32  2424.20  2418.75   4863037900  48792090467.0
# 2013-06-19  2408.28  2366.35  2408.28  2400.76   5434626000  52979991053.0
# 2013-06-20  2386.10  2320.23  2386.10  2321.47   5520102000  52171735063.0
# 2013-06-21  2283.15  2269.57  2332.84  2317.39   5870579800  53486132980.0
# 2013-06-24  2308.07  2164.33  2308.07  2171.21   8659725900  73731930536.0

# %% [markdown]
# 3.2、给出5种滚动波动率计算方法
# --

# %%
# 定义需要的全局变量

ROLLING_WINDOW = 120                                                         # 用到的滚动周期
VOL_NAME = 'YangZhangVol'                                                    #计算的波动率名字，几个波动率都                                                                              可以试一下，YangZhangVol最常用

# %%
def predict_BM(df):
    """基准：利用当前波动率预测
    
    输入:
        df: DataFrame, 波动率原始数据
    输出:
        vols_pred: 时间序列, 预测波动率
    """
    vols_pred = df[VOL_NAME].shift(1)
    vols_pred = vols_pred.fillna(vols_pred.iloc[1])
    vols_pred.name = 'benchmark'
    print("Benchmark prediction finished.")
    return vols_pred

# %%
vols_pred_BM=predict_BM(df)
vols_pred_BM
# Out:
# Benchmark prediction finished.
# 2013-06-18    0.1685274409
# 2013-06-19    0.1685274409
# 2013-06-20    0.1669138556
# 2013-06-21    0.1709191308
# 2013-06-24    0.1816253948
# 2013-06-25    0.2001660044
# 2013-06-26    0.2635078021
# 2013-06-27    0.2672619356
# 2013-06-28    0.2698468133
# 2013-07-01    0.2766462797
# 2013-07-02    0.2798677911
# 2013-07-03    0.2789058232
# 2013-07-04    0.2818855403
# 2013-07-05    0.2864328190
# 2013-07-08    0.2875304452
# 2013-07-09    0.2935175986
# 2013-07-10    0.2919359767
# 2013-07-11    0.2934845162
# 2013-07-12    0.3047660649
# 2013-07-15    0.3056688250
# 2013-07-16    0.3102510203
# 2013-07-17    0.3112512779
# 2013-07-18    0.3126138182
# 2013-07-19    0.3136485056
# 2013-07-22    0.3156279336
# 2013-07-23    0.3173873337
# 2013-07-24    0.3208584102
# 2013-07-25    0.3217952940
# 2013-07-26    0.3143445242
# 2013-07-29    0.3151367106
#                   ...
# 2018-03-15    0.2368506310
# 2018-03-16    0.2358488428
# 2018-03-19    0.2356969804
# 2018-03-20    0.2335921283
# 2018-03-21    0.2330855922
# 2018-03-22    0.2336890077
# 2018-03-23    0.2332092754
# 2018-03-26    0.2546031530
# 2018-03-27    0.2538934547
# 2018-03-28    0.2451881810
# 2018-03-29    0.2455302679
# 2018-03-30    0.2480053986
# 2018-04-02    0.2132758258
# 2018-04-03    0.2124625622
# 2018-04-04    0.2096195716
# 2018-04-09    0.2095750992
# 2018-04-10    0.2044925558
# 2018-04-11    0.2051524214
# 2018-04-12    0.2011608416
# 2018-04-13    0.2004367849
# 2018-04-16    0.1976250528
# 2018-04-17    0.1982458079
# 2018-04-18    0.1975767907
# 2018-04-19    0.2043343521
# 2018-04-20    0.2024822312
# 2018-04-23    0.2029169756
# 2018-04-24    0.2037241989
# 2018-04-25    0.2055485530
# 2018-04-26    0.2053368442
# 2018-04-27    0.2075303020
# Name: benchmark, dtype: float64

# %%
def predict_AR(df,  window=ROLLING_WINDOW, p=1):
    """第一种方法： 在给定滚动周期下利用AR(P)模型预测
    
    输入:
        df:DataFrame, 波动率原始数据
        window: 整数滚动周期
        p: int, lag of AR model
    输出:
        vols_pred: 时间序列, 预测波动率
    """

    fit = lambda x: AR(x).fit(maxlag=p, disp=0).predict(start=x.size, end=x.size)
    vols_pred = df[VOL_NAME].rolling(window).apply(fit)
    vols_pred.name = 'AR' + '_' + repr(window) + '_' + repr(p)
    print(vols_pred.name + " prediction finished.")
    return vols_pred

# %%
vols_pred_AR=predict_AR(df).dropna()
vols_pred_AR
# Out:
# AR_120_1 prediction finished.
# 2013-12-11    0.1706274982
# 2013-12-12    0.1701241170
# 2013-12-13    0.1717016319
# 2013-12-16    0.1717306065
# 2013-12-17    0.1676531251
# 2013-12-18    0.1646382598
# 2013-12-19    0.1647943090
# 2013-12-20    0.1646674836
# 2013-12-23    0.1662438167
# 2013-12-24    0.1691825188
# 2013-12-25    0.1671416355
# 2013-12-26    0.1674230350
# 2013-12-27    0.1624918159
# 2013-12-30    0.1550867208
# 2013-12-31    0.1565892556
# 2014-01-02    0.1541847577
# 2014-01-03    0.1530302112
# 2014-01-06    0.1572287572
# 2014-01-07    0.1551258534
# 2014-01-08    0.1573135095
# 2014-01-09    0.1594663662
# 2014-01-10    0.1569933595
# 2014-01-13    0.1598496586
# 2014-01-14    0.1515188043
# 2014-01-15    0.1508384029
# 2014-01-16    0.1488757911
# 2014-01-17    0.1503226409
# 2014-01-20    0.1507996000
# 2014-01-21    0.1517247930
# 2014-01-22    0.1547310022
#                   ...
# 2018-03-15    0.2381683090
# 2018-03-16    0.2378856453
# 2018-03-19    0.2355572468
# 2018-03-20    0.2349429475
# 2018-03-21    0.2354928005
# 2018-03-22    0.2348937511
# 2018-03-23    0.2572102022
# 2018-03-26    0.2563051998
# 2018-03-27    0.2470055225
# 2018-03-28    0.2472655898
# 2018-03-29    0.2497636400
# 2018-03-30    0.2138577829
# 2018-04-02    0.2130963989
# 2018-04-03    0.2101979631
# 2018-04-04    0.2101420861
# 2018-04-09    0.2049894508
# 2018-04-10    0.2056488445
# 2018-04-11    0.2016186821
# 2018-04-12    0.2008838553
# 2018-04-13    0.1980530770
# 2018-04-16    0.1986728864
# 2018-04-17    0.1979970194
# 2018-04-18    0.2047699917
# 2018-04-19    0.2029033288
# 2018-04-20    0.2033324031
# 2018-04-23    0.2041355903
# 2018-04-24    0.2059571275
# 2018-04-25    0.2057431794
# 2018-04-26    0.2079376127
# 2018-04-27    0.2107456467
# Name: AR_120_1, dtype: float64

# %%
def predict_Reg(df,  X_col=None, model_name='Lasso', p=1, params_dict=dict()):
    """第二和第三种方法：利用Lasso和 ElasticNet模型预测
    
    输入
       df:DataFrame, 波动率原始数据
        X_col: str的list,用来预测波动率的dataframe的columns 
        model_name: str, 模型的名字： 'Lasso'或'ElasticNet'
        p: int, 在回归中的最大滞后期
        params_dict: dict, 初始化回归模型的参数
    输出:
         vols_pred: 时间序列, 预测波动率
    """
    
    if X_col is None:
        X_col = df.columns
    if model_name == 'Lasso':
        model = Lasso(**params_dict)
    elif model_name == 'ElasticNet':
        model = ElasticNet(**params_dict)
    else:
        raise NotImplementedError("{:s} model is not implemented".format(model_name))
    def fit_predict(df, p, X_col):
       """
        输入:
             df:DataFrame, 波动率原始数据
             X_col: str的list,用来预测波动率的dataframe的columns 
             p: int, 在回归中的最大滞后期
        输出
            vol: float, 预测最后一天的波动率
            coefs: np.array, 变量的系数
        """
        X = pd.concat([df[X_col].shift(i+1) for i in range(p)], axis=1).dropna()
        y = df[VOL_NAME].iloc[p:].values.ravel()
        model.fit(X, y)
        vol = model.predict(X.iloc[-1].values.reshape(1,-1))[0]
        coefs = model.coef_
        return vol, coefs
    N = len(df)
    vol_list = []
    coef_list = []
    for i in range(N):
        if (i < ROLLING_WINDOW):
            vol, coef = np.nan, [np.nan]*len(X_col)*p
        else:
            vol, coef = fit_predict(df.iloc[(i-ROLLING_WINDOW):i], p, X_col)
        vol_list.append(vol)
        coef_list.append(coef)
    vols_pred = pd.Series(vol_list, index=df.index)
    coef_columns = []
   
    for i in range(p):
        coef_columns += (df[X_col].columns + '_' + repr(i+1)).tolist()
    pd.set_option('precision', 10)
    coef_df = pd.DataFrame(np.vstack(coef_list), index=df.index, columns=coef_columns)
    vols_pred.name = model_name
    print(vols_pred.name + " prediction finished.")
    return vols_pred, coef_df

# %%
#LASSO模型预测
vols_pred_LASSO, coef_df=predict_Reg(df)
# Out:
# Lasso prediction finished.

# %%
coef_df.dropna().head()
# Out:
#             ParkinsonVol_1  GarmanKlassVol_1  RogersSatchellVol_1  \
# 2013-12-12             0.0               0.0                  0.0
# 2013-12-13             0.0               0.0                  0.0
# 2013-12-16             0.0               0.0                  0.0
# 2013-12-17             0.0               0.0                  0.0
# 2013-12-18             0.0               0.0                  0.0
#
#             YangZhangVol_1  RawVol_1  SkewVol_1  KurtosisVol_1  \
# 2013-12-12             0.0       0.0       -0.0            0.0
# 2013-12-13             0.0       0.0       -0.0            0.0
# 2013-12-16             0.0       0.0       -0.0            0.0
# 2013-12-17             0.0       0.0       -0.0            0.0
# 2013-12-18             0.0       0.0       -0.0            0.0
#
#             HodgesTompkinsVol_1        Open_1  Low_1  High_1       Close_1  \
# 2013-12-12                  0.0 -0.0001728033   -0.0    -0.0 -0.0002193808
# 2013-12-13                  0.0 -0.0001797738   -0.0    -0.0 -0.0002121429
# 2013-12-16                  0.0 -0.0001776311   -0.0    -0.0 -0.0002148685
# 2013-12-17                  0.0 -0.0001543039   -0.0    -0.0 -0.0002413660
# 2013-12-18                  0.0 -0.0001805972   -0.0    -0.0 -0.0002155420
#
#                turnoverVol_1   turnoverValue_1
# 2013-12-12 -7.7100481818e-14  4.7711597720e-13
# 2013-12-13 -3.6506708773e-13  5.0129299945e-13
# 2013-12-16 -6.1360040758e-13  5.3218966506e-13
# 2013-12-17 -1.0048137836e-12  5.8851265408e-13
# 2013-12-18 -4.3018235861e-13  5.1192754906e-13

# %%
vols_pred_LASSO.dropna().head()
# Out:
# 2013-12-12    0.1764317206
# 2013-12-13    0.1886463830
# 2013-12-16    0.1881904691
# 2013-12-17    0.1912920438
# 2013-12-18    0.2036029720
# Name: Lasso, dtype: float64

# %%
#ElasticNet模型预测
vols_pred_ElasticNet, coef_df_ElasticNet=predict_Reg(df,model_name='ElasticNet')
# Out:
# ElasticNet prediction finished.

# %%
vols_pred_ElasticNet.dropna().head()
# Out:
# 2013-12-12    0.1608123275
# 2013-12-13    0.1782466558
# 2013-12-16    0.1746894368
# 2013-12-17    0.1779367306
# 2013-12-18    0.2003823188
# Name: ElasticNet, dtype: float64

# %%
coef_df_ElasticNet.dropna().head()
# Out:
#             ParkinsonVol_1  GarmanKlassVol_1  RogersSatchellVol_1  \
# 2013-12-12             0.0               0.0                  0.0
# 2013-12-13             0.0               0.0                  0.0
# 2013-12-16             0.0               0.0                  0.0
# 2013-12-17             0.0               0.0                  0.0
# 2013-12-18             0.0               0.0                  0.0
#
#             YangZhangVol_1  RawVol_1  SkewVol_1  KurtosisVol_1  \
# 2013-12-12             0.0       0.0       -0.0            0.0
# 2013-12-13             0.0       0.0       -0.0            0.0
# 2013-12-16             0.0       0.0       -0.0            0.0
# 2013-12-17             0.0       0.0       -0.0            0.0
# 2013-12-18             0.0       0.0       -0.0            0.0
#
#             HodgesTompkinsVol_1        Open_1  Low_1  High_1       Close_1  \
# 2013-12-12                  0.0 -0.0001814376   -0.0    -0.0 -0.0003184769
# 2013-12-13                  0.0 -0.0001845477   -0.0    -0.0 -0.0003155379
# 2013-12-16                  0.0 -0.0001837863   -0.0    -0.0 -0.0003152222
# 2013-12-17                  0.0 -0.0001650014   -0.0    -0.0 -0.0003341559
# 2013-12-18                  0.0 -0.0001889317   -0.0    -0.0 -0.0003106564
#
#                turnoverVol_1   turnoverValue_1
# 2013-12-12 -9.1708847018e-12  1.7879552943e-12
# 2013-12-13 -9.3110996412e-12  1.8014656718e-12
# 2013-12-16 -9.3286348309e-12  1.7978904439e-12
# 2013-12-17 -9.3823587676e-12  1.8008671861e-12
# 2013-12-18 -8.8589987498e-12  1.7311312920e-12

# %%
#在支持python3.6版本的平台上是可以运行的，这里不能行！！！

def predict_GARCH(df,  params_dict=None):
    """ Forecast next step volatility with expanding window using GARCH model
    """
    
    rolling_window = ROLLING_WINDOW
    if params_dict is None:
        params_dict = {'vol': 'GARCH', 'p': 1, 'o': 0, 'q': 1}
    fit1 = lambda x: arch_model(x, **params_dict).fit(disp='off', show_warning=False) \
                    .forecast().residual_variance.ix[x.size-1, 'h.1']
    vols_pred = df[VOL_NAME].rolling(rolling_window).apply(fit1)
    vols_pred = vols_pred.clip(0, vols_pred.quantile(0.98))
    vols_pred.name = 'GARCH'
    print("GARCH prediction finished.")
    return vols_pred

# %%
vols_pred_GARCH=predict_GARCH(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <mercury-input-154-738529276DF84BE881004B8E22D3DABA> in <module>()
# ----> 1 vols_pred_GARCH=predict_GARCH(df)
#
# <mercury-input-152-3749EEDB60474DCE967D6A17934C630C> in predict_GARCH(df, params_dict)
#       9         params_dict = {'vol': 'GARCH', 'p': 1, 'o': 0, 'q': 1}
#      10     fit1 = lambda x: arch_model(x, **params_dict).fit(disp='off', show_warning=False)                     .forecast().residual_variance.ix[x.size-1, 'h.1']
# ---> 11     vols_pred = df[VOL_NAME].rolling(rolling_window).apply(fit1)
#      12     vols_pred = vols_pred.clip(0, vols_pred.quantile(0.98))
#      13     vols_pred.name = 'GARCH'
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/core/window.pyc in apply(self, func, args, kwargs)
#     861     @Appender(_shared_docs['apply'])
#     862     def apply(self, func, args=(), kwargs={}):
# --> 863         return super(Rolling, self).apply(func, args=args, kwargs=kwargs)
#     864
#     865     @Substitution(name='rolling')
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/core/window.pyc in apply(self, func, args, kwargs)
#     619
#     620         return self._apply(f, func, args=args, kwargs=kwargs,
# --> 621                            center=False)
#     622
#     623     def sum(self, **kwargs):
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/core/window.pyc in _apply(self, func, name, window, center, check_minp, how, **kwargs)
#     558                 result = np.apply_along_axis(calc, self.axis, values)
#     559             else:
# --> 560                 result = calc(values)
#     561
#     562             if center:
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/core/window.pyc in calc(x)
#     553
#     554                 def calc(x):
# --> 555                     return func(x, window, min_periods=self.min_periods)
#     556
#     557             if values.ndim > 1:
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/core/window.pyc in f(arg, window, min_periods)
#     616             minp = _use_window(min_periods, window)
#     617             return algos.roll_generic(arg, window, minp, offset, func, args,
# --> 618                                       kwargs)
#     619
#     620         return self._apply(f, func, args=args, kwargs=kwargs,
#
# /home/ipython/anaconda/lib/python2.7/site-packages/pandas/algos.so in pandas.algos.roll_generic (pandas/algos.c:51577)()
#
# <mercury-input-152-3749EEDB60474DCE967D6A17934C630C> in <lambda>(x)
#       8     if params_dict is None:
#       9         params_dict = {'vol': 'GARCH', 'p': 1, 'o': 0, 'q': 1}
# ---> 10     fit1 = lambda x: arch_model(x, **params_dict).fit(disp='off', show_warning=False)                     .forecast().residual_variance.ix[x.size-1, 'h.1']
#      11     vols_pred = df[VOL_NAME].rolling(rolling_window).apply(fit1)
#      12     vols_pred = vols_pred.clip(0, vols_pred.quantile(0.98))
#
# TypeError: fit() got an unexpected keyword argument 'show_warning'

# %%
def get_mse(vols_true, vols_pred):
    """计算MSE, root mean squared error.
    
    输入:
        vols_true: 时间序列, 基准波动率
        vols_pred: 时间序列, 预测波动率
    输出:
        error: float, MSE
    """
    vols_pred_drop = vols_pred.dropna()
    error = np.sqrt(mean_squared_error(vols_true[vols_pred_drop.index], vols_pred_drop))
    return error

# %% [markdown]
# 3.3、综合比较各预测，画出图形
# ---

# %%
# 对比各预测
plt.figure(figsize=(16, 9)) 
predictions = [vols_pred_BM, vols_pred_AR, vols_pred_LASSO,vols_pred_ElasticNet]
for vols_pred in predictions:
    mse = get_mse(vols_true, vols_pred)
    print('{:s}: {:.6f}'.format(vols_pred.name, mse))
    plt.plot((vols_pred - vols_true).values, label=vols_pred.name)
plt.legend()
# Out:
# benchmark: 0.008769
# AR_120_1: 0.003454
# Lasso: 0.085284
# ElasticNet: 0.084048

# %% [markdown]
# ***本文介绍的方法更适合利用高频数据预测波动率，本文是用沪深300的日数据，不是太适合，同时本文在做Lasso和Elasticnet模型回归时，所有预测波动率的变量没有经过分析的，时任意主观需求的，高频数据中的很多数据可以拿来预测***
