# %% [markdown]
# #

# %% [markdown]
# A tutorial on statistical-learning for scientific data processing¶
# 在科学数据处理¶统计学习教程
# Statistical learning
# 统计学习
# Machine learning is a technique with a growing importance, as the size of the datasets experimental sciences are facing is rapidly growing. Problems it tackles range from building a prediction function linking different observations, to classifying observations, or learning the structure in an unlabeled dataset.
# 机器学习是一种越来越重要的技术，作为数据集的实验科学的规模正面临着迅速增长。问题解决的范围从建设一个连接不同的观测值的预测功能，分类观察，或学习的结构在未标记的数据集。
# This tutorial will explore statistical learning, the use of machine learning techniques with the goal of statistical inference: drawing conclusions on the data at hand.
# 本教程将探索统计学习，使用机器学习技术的目标统计推断：在手头的数据上得出结论。
# Scikit-learn is a Python module integrating classic machine learning algorithms in the tightly-knit world of scientific Python packages (NumPy, SciPy, matplotlib).
# scikit学习是一个集经典的机器在紧密联系的世界科学Python包算法学习Python模块（NumPy、SciPy，matplotlib）。
# Statistical learning: the setting and the estimator object in scikit-learn
# 统计学习：设置和scikit估计对象学习
# Datasets
# 数据集集合
# Estimators objects
# 估计对象
# Supervised learning: predicting an output variable from high-dimensional observations
# 监督学习：预测一个高维观测的输出变量
# Nearest neighbor and the curse of dimensionality
# 最近邻和维数灾难
# Linear model: from regression to sparsity
# 线性模型：从回归到稀疏
# Support vector machines (SVMs)
# 支持向量机（支持向量机）
# Model selection: choosing estimators and their parameters
# 模型选择：选择估计及其参数
# Score, and cross-validated scores
# 得分和交叉验证的分数
# Cross-validation generators
# 交叉验证发电机
# Grid-search and cross-validated estimators
# 网格搜索和交叉验证估计
# Unsupervised learning: seeking representations of the data
# 无监督学习：求数据的表示
# Clustering: grouping observations together
# 聚类：分组观察在一起
# Decompositions: from a signal to components and loadings
# 分解：从信号元件和负荷
# Putting it all together
# 一起把它放在一起
# Pipelining
# 流水线
# Face recognition with eigenfaces
# 与特征脸的人脸识别
# Open problem: Stock Market Structure
# 公开问题：股票市场结构
#
# 看到这些眼睛一亮：
# Supervised learning: predicting an output variable from high-dimensional observations
# 监督学习：预测一个高维观测的输出变量
# The problem solved in supervised learning
# 监督学习中的问题解决
# Supervised learning consists in learning the link between two datasets: the observed data X and an external variable y that we are trying to predict, usually called “target” or “labels”. Most often, y is a 1D array of length n_samples.
# 监督学习包括在学习两个数据集之间的联系：所观察到的数据X和一个外部变量Y，我们试图预测，通常被称为“目标”或“标签”。通常，Y是一个一维数组的长度n_samples。
# All supervised estimators in scikit-learn implement a fit(X, y) method to fit the model and a predict(X) method that, given unlabeled observations X, returns the predicted labels y.
# 所有的监督估计scikit学习实施合适的（x，y）的方法对模型的拟合和预测（x）方法，观察了未标记的X，Y的回报预测的标签
# Vocabulary: classification and regression
# 词汇：分类与回归
# If the prediction task is to classify the observations in a set of finite labels, in other words to “name” the objects observed, the task is said to be a classification task. On the other hand, if the goal is to predict a continuous target variable, it is said to be a regression task.
# 如果预测任务是分类的观察在一组有限的标签，在其他的单词“名称”观察到的对象，该任务被称为是一个分类任务。另一方面，如果目标是预测一个连续的目标变量，它被称为一个回归任务。
# When doing classification in scikit-learn, y is a vector of integers or strings.
# 当scikit做分类学习，Y是一个整数或字符串向量。
# Note: See the Introduction to machine learning with scikit-learn Tutorial for a quick run-through on the basic machine
# 注：看介绍与scikit机器学习学习教程，快速完成基本的机器上
#
# The iris dataset is a classification task consisting in identifying 3 different types of irises (Setosa, Versicolour, and Virginica) from their petal and sepal length and width:
# IRIS数据集是一个分类任务包括确定虹膜的3种不同类型（粗糙、虹彩、和锦葵）从他们的花瓣和萼片长度和宽度：
#
# k-Nearest neighbors classifier¶
# 最近邻分类器¶
# The simplest possible classifier is the nearest neighbor: given a new observation X_test, find in the training set (i.e. the data used to train the estimator) the observation with the closest feature vector. (Please see the Nearest Neighbors section of the online Scikit-learn documentation for more information about this type of classifier.)
# 最简单的可能是最近邻分类器：给定一个新的观察x_test，发现在训练集（即数据用于训练估计）与最近的特征向量的观测。（请参阅在线scikit近邻学习文档部分关于这类分类器的更多信息。）
# Training set and testing set
# 训练集和测试集
# While experimenting with any learning algorithm, it is important not to test the prediction of an estimator on the data used to fit the estimator as this would not be evaluating the performance of the estimator on new data. This is why datasets are often split into train and test data.
# 在尝试任何学习算法，重要的是不要测试用于拟合估计的数据的估计量的预测，因为这将不会评估新的数据估计的性能。这就是为什么数据集往往被分成火车和测试数据。
#
# The curse of dimensionality¶
# 维¶诅咒
# For an estimator to be effective, you need the distance between neighboring points to be less than some value d, which depends on the problem. In one dimension, this requires on average n ~ 1/d points. In the context of the above k-NN example, if the data is described by just one feature with values ranging from 0 to 1 and with n training observations, then new data will be no further away than 1/n. Therefore, the nearest neighbor decision rule will be efficient as soon as 1/n is small compared to the scale of between-class feature variations.
# 对于一个估计是有效的，你需要相邻点之间的距离要小于某个值D，这取决于问题。在一个维度中，这需要平均n 1 / D点。在上述的例子中，如果K-NN，数据只有一个特征值的范围从0到1和N训练观察描述，然后新的数据将不远高于1，因此，最近邻决策规则将有效的只要1 / N是比较小的类别特征变化之间的尺度。
# If the number of features is p, you now require n ~ 1/d^p points. Let’s say that we require 10 points in one dimension: now 10^p points are required in p dimensions to pave the [0, 1] space. As p becomes large, the number of training points required for a good estimator grows exponentially.
# 如果功能的数量是P，你现在需要n 1╱点。让我们说，我们需要在一个维度中的10个点：现在10个P的点是需要在P的尺寸为铺就[ 0，1 ]空间。当P变大时，一个好的估计所需的训练点的数量呈指数增长。
# For example, if each point is just a single number (8 bytes), then an effective k-NN estimator in a paltry p~20 dimensions would require more training data than the current estimated size of the entire internet (±1000 Exabytes or so).
# 例如，如果每个点都只是一个数（8个字节），然后在一个小P ~ 20维度的有效k-NN估计将需要比目前的规模估计整个互联网更多的训练数据（±1000艾字节左右）。
# This is called the curse of dimensionality and is a core problem that machine learning addresses.
# 这就是所谓的维数灾难，是机器学习地址的一个核心问题。
#
# ogistic Regression (aka logit, MaxEnt) classifier.
# 多元回归（又名Logit、Maxent）分类器。
# In the multiclass case, the training algorithm uses the one-vs-rest (OvR) scheme if the ‘multi_class’ option is set to ‘ovr’ and uses the cross-entropy loss, if the ‘multi_class’ option is set to ‘multinomial’. (Currently the ‘multinomial’ option is supported only by the ‘lbfgs’ and ‘newton-cg’ solvers.)
# 在多的情况下，训练算法采用一对多（OVR）方案，如果“multi_class”选项设置为“改写”，利用交叉熵损失，如果“multi_class”选项设置为“多项式”。（目前的多项选择的只有“LBFGS '和'牛顿CG求解。支持）
# This class implements regularized logistic regression using the liblinear library, newton-cg and lbfgs solvers. It can handle both dense and sparse input. Use C-ordered arrays or CSR matrices containing 64-bit floats for optimal performance; any other input format will be converted (and copied).
# 这个类实现了正规化的logistic回归分析使用liblinear图书馆，牛顿CG和LBFGS算法。它可以处理密集和稀疏的输入。使用c-ordered阵列或企业社会责任矩阵含有64位浮点性能最优；任何其他输入格式将转换（复制）。
# The newton-cg and lbfgs solvers support only L2 regularization with primal formulation. The liblinear solver supports both L1 and L2 regularization, with a dual formulation only for the L2 penalty.
# 牛顿的CG和LBFGS求解器只支持L2正则化与原配方。该软件支持liblinear L1和L2正则化，只有L2惩罚双重配方。
#
# 终于见到类里面的函数了。
# class sklearn.linear_model.LogisticRegression(penalty='l2', dual=False, tol=0.0001, C=1.0, fit_intercept=True, intercept_scaling=1, class_weight=None, random_state=None, solver='liblinear', max_iter=100, multi_class='ovr', verbose=0, warm_start=False, n_jobs=1)

# %%
print(__doc__)


# Code source: Gaël Varoquaux
# Modified for documentation by Jaques Grobler
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model, datasets

# import some data to play with
iris = datasets.load_iris()
X = iris.data[:, :2]  # we only take the first two features.
Y = iris.target

h = .02  # step size in the mesh

logreg = linear_model.LogisticRegression(C=1e5)

# we create an instance of Neighbours Classifier and fit the data.
logreg.fit(X, Y)

# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, m_max]x[y_min, y_max].
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = logreg.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1, figsize=(4, 3))
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, edgecolors='k', cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm


def plot_decision_function(classifier, sample_weight, axis, title):
    # plot the decision function
    xx, yy = np.meshgrid(np.linspace(-4, 5, 500), np.linspace(-4, 5, 500))

    Z = classifier.decision_function(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # plot the line, the points, and the nearest vectors to the plane
    axis.contourf(xx, yy, Z, alpha=0.75, cmap=plt.cm.bone)
    axis.scatter(X[:, 0], X[:, 1], c=Y, s=100 * sample_weight, alpha=0.9,
                 cmap=plt.cm.bone)

    axis.axis('off')
    axis.set_title(title)


# we create 20 points
np.random.seed(0)
X = np.r_[np.random.randn(10, 2) + [1, 1], np.random.randn(10, 2)]
Y = [1] * 10 + [-1] * 10
sample_weight_last_ten = abs(np.random.randn(len(X)))
sample_weight_constant = np.ones(len(X))
# and bigger weights to some outliers
sample_weight_last_ten[15:] *= 5
sample_weight_last_ten[9] *= 15

# for reference, first fit without class weights

# fit the model
clf_weights = svm.SVC()
clf_weights.fit(X, Y, sample_weight=sample_weight_last_ten)

clf_no_weights = svm.SVC()
clf_no_weights.fit(X, Y)

fig, axes = plt.subplots(1, 2, figsize=(14, 6))
plot_decision_function(clf_no_weights, sample_weight_constant, axes[0],
                       "Constant weights")
plot_decision_function(clf_weights, sample_weight_last_ten, axes[1],
                       "Modified weights")

plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_digits
from sklearn.neighbors import KernelDensity
from sklearn.decomposition import PCA
from sklearn.grid_search import GridSearchCV

# load the data
digits = load_digits()
data = digits.data

# project the 64-dimensional data to a lower dimension
pca = PCA(n_components=15, whiten=False)
data = pca.fit_transform(digits.data)

# use grid search cross-validation to optimize the bandwidth
params = {'bandwidth': np.logspace(-1, 1, 20)}
grid = GridSearchCV(KernelDensity(), params)
grid.fit(data)

print("best bandwidth: {0}".format(grid.best_estimator_.bandwidth))

# use the best estimator to compute the kernel density estimate
kde = grid.best_estimator_

# sample 44 new points from the data
new_data = kde.sample(44, random_state=0)
new_data = pca.inverse_transform(new_data)

# turn data into a 4x11 grid
new_data = new_data.reshape((4, 11, -1))
real_data = digits.data[:44].reshape((4, 11, -1))

# plot real digits and resampled digits
fig, ax = plt.subplots(9, 11, subplot_kw=dict(xticks=[], yticks=[]))
for j in range(11):
    ax[4, j].set_visible(False)
    for i in range(4):
        im = ax[i, j].imshow(real_data[i, j].reshape((8, 8)),
                             cmap=plt.cm.binary, interpolation='nearest')
        im.set_clim(0, 16)
        im = ax[i + 5, j].imshow(new_data[i, j].reshape((8, 8)),
                                 cmap=plt.cm.binary, interpolation='nearest')
        im.set_clim(0, 16)

ax[0, 5].set_title('Selection from the input data')
ax[5, 5].set_title('"New" digits drawn from the kernel density model')

plt.show()
# Out:
# best bandwidth: 3.79269019073
