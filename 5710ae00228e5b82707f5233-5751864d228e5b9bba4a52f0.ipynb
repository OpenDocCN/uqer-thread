# %% [markdown]
# # StockScreener 三种筛选条件运行出错

# %%
universe = StockScreener((Factor.PE.nlarge(100) | Factor.PB.pct_range(0.95, 1)) & Factor.RSI.value_range(70, 100))
universe.preview('2015-12-17')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <mercury-input-9-4b04a16a6780> in <module>()
#       1 universe = StockScreener((Factor.PE.nlarge(100) | Factor.PB.pct_range(0.95, 1)) & Factor.RSI.value_range(70, 100))
# ----> 2 universe.preview('2015-12-17')
#
# python2.7/site-packages/quartz/screener/screener.pyc in preview(self, date)
#     199             temp_tree = deepcopy(tree)
#     200             if temp_tree is not None:
# --> 201                 data = self.get_ftree_info([date], stype, temp_tree, forward=False)
#     202                 for seclist in iter(data.values()):
#     203                     fct_seclist |= seclist
#
# python2.7/site-packages/quartz/screener/screener.pyc in get_ftree_info(self, trading_days, stype, ftree, forward)
#     114             ftree2.right = self.load_condition(trading_days, stype, ftree2.right, forward)
#     115         if isinstance(ftree2.left, factor.FTree):
# --> 116             ftree2.left = self.get_ftree2_info(trading_days, stype, ftree2.left, forward)
#     117         if isinstance(ftree2.right, factor.FTree):
#     118             ftree2.right = self.get_ftree2_info(trading_days, stype, ftree2.right, forward)
#
# AttributeError: 'StockScreener' object has no attribute 'get_ftree2_info'
