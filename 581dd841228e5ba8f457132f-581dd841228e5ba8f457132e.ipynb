# %% [markdown]
# #

# %%
data = DataAPI.MktEqudGet(tradeDate=u"20161102",secID=u"",ticker=u"300204",beginDate=u"",endDate=u"",isOpen="",field=u"",pandas="1")
marketval =  data.marketValue
print marketval

data = DataAPI.MktStockFactorsOneDayGet(tradeDate=u"20161102",secID=u"",ticker=u"300204",field=u"ticker,tradeDate,pe,ps,OperatingRevenueGrowRate",pandas="1")
pricesale = data.PS
print pricesale
print  marketval/pricesale
# Out:
# 0    9290545952
# Name: marketValue, dtype: int64
# 0    6.8099
# Name: PS, dtype: float64
# 0    1.364271e+09
# dtype: float64
