# %% [markdown]
# #

# %% [markdown]
# 报告来源：华泰联合20110620规模因子分析——数量化选股策略之4，研究范围中证500指数(原报告指数为中证800，但是这里的set_universe只有五个常用的，这里用500代替)成份股，研究期间为2005年1月至2011年5月。

# %% [raw]
# import pandas as pd
# import numpy as np
# #from datetime import datetime
# from CAL.PyCAL import *
#
# start = '2015-01-01'                       # 回测起始时间
# end = '2016-07-15'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe =set_universe('ZZ500')  # 证券池，支持股票和基金universe = set_universe('A')
# capital_base = 10000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 20                           # 调仓频率，一个月调仓一次
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):  # 每个交易日的买入卖出指令
#     #先看时间问题
#     cal = Calendar('China.SSE')
#     date=account.current_date
#     date = Date.fromDateTime(date)
#     yesterday = cal.advanceDate(date,'-1B',BizDayConvention.Preceding)            #计算出倒数第一个交易日
#     yesterday = yesterday.strftime("%Y-%m-%d")#法一
#     #yesterday=cal.advanceDate(date,BizDayConvention.Following)
#     #yesterday=datetime(yesterday.year(), yesterday.month(), yesterday.dayOfMonth()).strftime('%Y%m%d')#看到社区好多策略的时间都用这个，但是我调用这个总是提示错误···
#     #yesterday = account.previous_date.strftime('%Y%m%d')  #前一交易日，法二，这个也可以算
#
#     #清洗函数，见社区https://uqer.datayes.com/community/share/575ea8f1228e5b8a40286446
#     # 去除ST股
#     try:
#         STlist = DataAPI.SecSTGet(secID=account.universe, beginDate=yesterday, endDate=yesterday, field=['secID']).tolist()
#         account.universe = [s for s in account.universe if s not in STlist]
#     except:
#         pass
#
#     # 去除新上市或复牌的股票
#     openprice= account.get_attribute_history('openPrice', 1)
#     account_universe = [s for s in account.universe if not (np.isnan(openprice.get(s, 0)[0]) or openprice.get(s, 0)[0] == 0)]
#
#     #取交易数据
#     data=DataAPI.MktEqudGet(tradeDate=u"",secID=account_universe,ticker=u"",beginDate=yesterday,endDate=yesterday,isOpen="1",field=u"secID,marketValue",pandas="1")
#     data=data.sort().head(50)#选总市值从低到高排名后前50只股票
#     buy_list=data['secID']
#
#     for st in account.valid_secpos:
#         if st not in buy_list:
#             order_to(st,0)
#     money=account.referencePortfolioValue
#     price=account.referencePrice
#     for st in buy_list:
#         if account.cash < 0:
#             break
#         else:
#             ammount=money/len(buy_list)/price[st]
#             order_to(st,int(ammount))

# %%
bt
# Out:
#      tradeDate          cash  \
# 0   2016-01-05   541539.1882
# 1   2016-01-06   541539.1882
# 2   2016-01-07   541539.1882
# 3   2016-01-08   541539.1882
# 4   2016-01-11   541539.1882
# 5   2016-01-12   541539.1882
# 6   2016-01-13   541539.1882
# 7   2016-01-14   541539.1882
# 8   2016-01-15   541539.1882
# 9   2016-01-18   541539.1882
# 10  2016-01-19   541539.1882
# 11  2016-01-20   541539.1882
# 12  2016-01-21   541539.1882
# 13  2016-01-22   541539.1882
# 14  2016-01-25   541539.1882
# 15  2016-01-26   541539.1882
# 16  2016-01-27   541539.1882
# 17  2016-01-28   541539.1882
# 18  2016-01-29   541539.1882
# 19  2016-02-01   541539.1882
# 20  2016-02-02  6931265.7811
# 21  2016-02-03  6931265.7811
# 22  2016-02-04  6931265.7811
# 23  2016-02-05  6931265.7811
# 24  2016-02-15  6931265.7811
# 25  2016-02-16  6931265.7811
# 26  2016-02-17  6931265.7811
# 27  2016-02-18  6931265.7811
# 28  2016-02-19  6931265.7811
# 29  2016-02-22  6931265.7811
# ..         ...           ...
# ...
