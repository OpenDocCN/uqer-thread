# %% [markdown]
# # 量化投资菜鸟入门1

# %% [markdown]
# #熟悉Uqer功能
# 入门级功能：Uqer提供python2.7、quartz框架，轻松实现策略回测
# 任务简介：
# 1、进行数据分析
# 2、策略回测

# %% [raw]
# #策略参数
# start = '2008-01-01'     # 回测起始时间
# end = '2018-12-13'       # 回测结束时间
# bendmark = 'HS300' #沪指，作为收益参考基准
# universe = ['002236.XSHE'] #大华股票
# capital_base = 10000     #起始资金1万股
# freq = 'd'  #以日为单位操作
# refresh_rate = 1 #调仓频率
#
#
#
# # account是回测期间的虚拟交易账户，存储上述全局变量参数信息，并在整个策略执行期间更新并维护可用现金、证券的头寸、每日交易指令明细、历史行情数据等。
# def initialize(account):
#     pass
# # 这个函数在每个交易日开盘前被调用，模拟每个交易日开盘前，交易策略会根据历史数据或者其他信息进行交易判断，生成交易指令
# def handle_data(account):
#     hist = account.get_attribute_history('closePrice', 3)
#     for stock in account.universe:
#         prePrice = hist[stock][0]
#         lastPrice = hist[stock][1]
#         curPrice = hist[stock][2]
#         #追涨杀跌法
#         if (curPrice > lastPrice and lastPrice > prePrice) or (curPrice > 1.03*lastPrice):
#             # 买入1000股
#             account.order(stock,1000)
#         if (curPrice < lastPrice and lastPrice < prePrice) or (curPrice < 0.97*lastPrice):
#             # 买出
#             account.order_to(stock, 0)
#     return
