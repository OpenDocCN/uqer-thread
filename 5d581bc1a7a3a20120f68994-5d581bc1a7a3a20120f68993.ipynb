# %% [markdown]
# # 31 ROE选股指标(转编)

# %%
"""
https://uqer.datayes.com/v3/community/share/5668533af9f06c6c8a91b688

简单的ROE选股：
按ROE排序选前10%的股票，等权重买入
"""

"""

"""

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt
import CAL.PyCAL as C_cal # CAL provides classes and functions dealing with date, time, and calendars. 

sns.set_style('white')
pd.set_option('display.width', 200)
cal = C_cal.Calendar('China.SSE')

# %% [raw]
# start = '2018-08-01' # 开始日期
# end = (dt.datetime.today() - dt.timedelta(days=1)).strftime('%Y-%m-%d') # 截止日期
#
# benchmark = 'HS300' # 策略参考标准
# universe = set_universe('HS300') # 证券池，支持股票和基金
# capital_base = 10000 # 起始资金
# freq = 'd' # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 20 # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account): # 初始化虚拟账户状态
#     pass
#
# def handle_data(account): # 每个交易日的买入卖出指令
#
#     # ROE	float	权益回报率（Return on equity）。计算方法：权益回报率=净利润（TTM）/股东权益。属于质量类因子。数据更新时间：T日21点30分。
#     factor = DataAPI.MktStockFactorsOneDayGet(secID=account.universe,tradeDate=account.previous_date,field='secID,ROE',pandas="1").dropna()
#
#     sec_val = {'symbol':[], 'factor_value':[]}
#     for index, row in factor.iterrows():
#         sec_val['symbol'].append(row['secID'])
#         sec_val['factor_value'].append(row['ROE'])
#
#     sec_val = pd.DataFrame(sec_val).sort(columns='factor_value',ascending=False).reset_index()
#     sec_val = sec_val[int(len(sec_val)*0.9):] # 排序并选择前10%
#
#     buylist = list(sec_val.symbol) # 买入股票列表
#     for stock in account.security_position:
#         if stock not in buylist:
#             account.order_to(stock, 0)
#     for stock in buylist:
#         if stock not in account.security_position:
#             account.order(stock, account.cash/len(buylist))
#     return

# %%
factor = DataAPI.MktStockFactorsOneDayGet(secID=set_universe('HS300'),tradeDate='20190701',field='secID,ROE',pandas="1").dropna()
factor = factor.sort(columns='ROE',ascending=True)
factor
# Out:
#            secID     ROE
# 169  600816.XSHG -0.1852
# 44   600100.XSHG -0.1607
# 127  002456.XSHE -0.1121
# 55   600221.XSHG -0.0668
# 12   000625.XSHE -0.0593
# 146  300251.XSHE -0.0550
# 122  002252.XSHE -0.0538
# 2    000063.XSHE -0.0235
# 136  002714.XSHE -0.0127
# 143  300072.XSHE -0.0081
# 274  601212.XSHG  0.0057
# 66   600583.XSHG  0.0079
# 225  002625.XSHE  0.0089
# 198  601989.XSHG  0.0110
# 63   600489.XSHG  0.0126
# 189  601788.XSHG  0.0142
# 88   601600.XSHG  0.0197
# 60   600369.XSHG  0.0199
# 282  601808.XSHG  0.0221
# 183  601377.XSHG  0.0232
# 194  601901.XSHG  0.0247
# 240  300433.XSHE  0.0253
# 18   000783.XSHE  0.0259
# 73   600795.XSHG  0.0262
# 106  000725.XSHE  0.0287
# 273  601162.XSHG  0.0294
# 39   600050.XSHG  0.0318
# 201  000553.XSHE  0.0338
# 135  002673.XSHE  0.0354
# 243  600011.XSHG  0.0361
# ..           ...     ...
# 202  000596.XSHE  0.2655
# 130  002508.XSHE  0.2658
# 26   002304.XSHE  0.2669
# 36   600031.XSHG  0.2677
# 221  002468.XSHE  0.2679
# ...

# %%
factor = factor[int(len(factor)*0.9):] # 排序并选择前10%
factor
# Out:
#            secID     ROE
# 202  000596.XSHE  0.2655
# 130  002508.XSHE  0.2658
# 26   002304.XSHE  0.2669
# 36   600031.XSHG  0.2677
# 221  002468.XSHE  0.2679
# 110  000963.XSHE  0.2684
# 193  601888.XSHG  0.2730
# 262  600809.XSHG  0.2736
# 236  300142.XSHE  0.2830
# 252  600398.XSHG  0.2901
# 272  601138.XSHG  0.2993
# 156  600340.XSHG  0.3037
# 235  300136.XSHE  0.3042
# 213  002120.XSHE  0.3045
# 67   600585.XSHG  0.3063
# 292  603160.XSHG  0.3101
# 162  600570.XSHG  0.3104
# 211  002032.XSHE  0.3129
# 14   000651.XSHE  0.3214
# 126  002415.XSHE  0.3327
# 258  600566.XSHG  0.3462
# 21   000895.XSHE  0.3616
# 295  603288.XSHG  0.3628
# 294  603260.XSHG  0.3693
# 64   600519.XSHG  0.3712
# 113  002027.XSHE  0.3826
# 256  600516.XSHG  0.3888
# 176  601155.XSHG  0.4334
# 234  300122.XSHE  0.4639
# 203  000629.XSHE  0.5628
