# %% [markdown]
# # 新人练手 －－－ 蛋卷斗牛二八

# %% [raw]
# import pandas as pd
# import numpy as np
#
# start = '2013-04-05'                       # 回测起始时间
# end = '2016-04-06'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['159919.XSHE','510500.XSHG','511010.XSHG']    # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# window=20
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
# #获取行情
#
#     closeprice=account.get_attribute_history('closePrice',window)
#     cash=account.cash
#     date=account.current_date.strftime('%Y-%m-%d')
#
# #判断买入卖出
#     signal=[]
#     buylist=[]
#
#     for stk in account.universe:
#         tablePD=pd.DataFrame(closeprice)            # 20天收盘价放入DateFrame矩阵
#         signal.append(tablePD[stk][window-1]/tablePD[stk][0])
# #   print(closeprice)
# #   print(date,signal)
#     if signal[0]>signal[1] and signal[0]>=1:
#          buylist.append(universe[0])
# #         print(date,buylist)
#     elif signal[1]>signal[0] and signal[1]>=1 :
#          buylist.append(universe[1])
# #        print(date,buylist)
#     elif signal[0]<1 and signal[1]<1:
#          buylist.append(universe[2])
# #        print(date,buylist)
#
# #卖出持仓
#     for stk in account.avail_secpos:
#         if stk not in buylist:
#             order_to(stk,0)
#             print(date,"sell",stk)
#
# #买入仓位
#     for stk in buylist:
#         if stk not in account.avail_secpos:
#             order_pct(stk,1)
#             print(date,"buy",stk)
