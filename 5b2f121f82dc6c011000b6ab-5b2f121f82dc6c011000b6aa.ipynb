# %% [markdown]
# # Try

# %% [raw]
# import numpy as np
# import talib as ta
#
# start = '2016-01-01'                       # 回测起始时间
# end = '2017-01-01'                         # 回测结束时间
# universe = ['AM0']                        # 证券池，支持股票和基金、期货、指数
# benchmark = 'H11063.ZICN'                  # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 1                           # 执行handle_data的时间间隔
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='futures', capital_base=10000)
# }
#
# def handle_data(context):                  # 核心策略逻辑
#
#     close_pries_series = context.history('AM0', 'closePrice', 15, rtype='array', freq='1d')['AM0']['closePrice']
#
#     # 转换为talib需要的float类型
#     close_pries_series = np.array(close_pries_series, dtype=float)
#
#
#     # 计算MACD的三个观察值
#     macd_tmp = ta.MACD(close_pries_series, fastperiod=12, slowperiod=26, signalperiod=9)#使用自定义函数获取macd
#     DIF = macd_tmp[0]
#     DEA = macd_tmp[1]
#     MACD = macd_tmp[2]
#     print MACD
#
#     main_contract = context.get_symbol('AM0')
#     futures_account = context.get_account('fantasy_account')
#
#     if MACD[-1] > 0 and MACD[-2] < 0:
#         futures_account.order(main_contract, 1, 'open')
#
#     if MACD[-1] < 0 and MACD[-2] > 0:
#         futures_account.order(main_contract, -1, 'close')
