# %% [markdown]
# #

# %% [raw]
# from CAL.PyCAL import Date
# import pandas as pd
# import numpy as np
# import datetime
#
#
#
#
# start = '2007-01-01'                  # 回测起始时间
# end = '2016-10-13'                        # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['510180.XSHG']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
# commission = Commission(buycost=0.0008, sellcost=0.0018)  # 佣金万八
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):# 每个交易日的买入卖出指令
# #策略所用到的参数
#     k=5
#     N=20
#     B=90
#     kk=0.0
# #选取沪深300过去500天的数据
#     et=(account.previous_date)
#     st=et-datetime.timedelta(days=500)
#     date=DataAPI.MktIdxdGet(ticker=u"000300",beginDate=st,endDate=et,field=u"",pandas="1")['closeIndex']
# #根据收盘价计算每天收益率
#     ret=[date[x]/date[x-1]-1 for x in range(1,len(date))]
# #计算每天收益率的K阶原点矩，原点矩的计算用到了参数N
#     moment= [sum([y**k for y in ret[:x+1]])/N  for x in range(N,len(ret))]
# #计算k阶原点矩的EMA
# #EMA中含有参数alpha，这里采用对alpha寻优的方式来决定alpha的值。寻优的目标是使过去B天计收益率最高的alpha
#     df=pd.Series(index=range(5,55,5))  #alpha的取值在0.05到0.5，间隔为0.05
#     for ii in range(5,55,5):
#         alpha=float(ii)/100.0
# #        ema=[sum([ alpha*((1-alpha)**(i-1)) * moment[:-1-t][-i] for i in range(1,121)]) for t in range(B+10)]
#         ema=[moment[-120]]
#         for i in range(120-1):
#             ema.append(alpha*moment[-119+i]+(1-alpha)*ema[-1])
#         rrr=[]
#         for i in range(B):
#             if ema[-2-i]>ema[-2-i-1]:
#                 rrr.append(ret[-1-i])
#             elif  ema[-2-i]<ema[-2-i-1]:
#                 rrr.append(-ret[-1-i])
#         df.loc[ii]=sum(rrr)
#     alpha=float(df.sort_values().index[-1])/100.0  #把不同alpha所带来的累计收益排序，取最高的累计收益对应的alpha
# #根据确定的alpha计算EMA
#     ema=[moment[-120]]
#     for i in range(120-1):
#         ema.append(alpha*moment[-119+i]+(1-alpha)*ema[-1])
# #如果昨天的EMA大于昨前天的EMA，今天做多；否则就空仓
#     if ema[-1]>ema[-2]*(1+kk):
#        order_pct_to(universe[0], 1)
#     else:
#        order_pct_to(universe[0], 0)
#
#     return
