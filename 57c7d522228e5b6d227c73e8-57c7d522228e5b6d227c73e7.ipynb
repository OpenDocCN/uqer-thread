# %% [markdown]
# #

# %% [markdown]
# 以市盈率最高的100只股票为标的，进行价量分析，追涨杀跌。
# 买入点：股票成交量突破20日内最高，且股票价格向上突破10日均线；
# 卖出点：成交量创10日内新低 or 股价向下突破5日新低

# %% [raw]
# start = '2015-01-01'
# end = '2016-01-1'
# benchmark = 'HS300'
# universe = StockScreener(Factor.PE.nlarge(100))    # 筛选出市盈率最高的100只股票
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1
#
# def initialize(account):
#     pass
#
# def handle_data(account):
#     volume = account.get_attribute_history('turnoverValue',21)   # 取出前20日内成交量
#     price = account.get_attribute_history('closePrice',11)       # 取出前10日内股价，以收盘价为代表
#
#     for stk in account.universe:
#         max_vol20 = volume[stk][:20].max()
#         min_vol10 = volume[stk][10:20].min()
#         ma10 = price[stk][:10].mean()
#         ma5  = price[stk][5:10].mean()
#
#         vol = volume[stk][-1]           # 当天成交量
#         prz = price[stk][-1]            #
#
#         if (vol >= max_vol20) and (prz >= ma10) and (stk not in account.avail_secpos):
#             order_pct(stk,0.1)
#         elif (vol < min_vol10) or (prz < ma5):
#             order_to(stk,0)
