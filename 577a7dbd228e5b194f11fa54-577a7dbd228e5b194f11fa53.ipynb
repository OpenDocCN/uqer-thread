# %% [markdown]
# #

# %% [raw]
# from matplotlib import pylab
# start='2014-01-01'
# end='2016-07-01'
# benchmark='SH180'
# universe=['600007.XSHG','600004.XSHG','600028.XSHG','600050.XSHG','600016.XSHG','600018.XSHG','600085.XSHG','600654.XSHG','000557.XSHG']
# commission = Commission(buycost=0.0005, sellcost=0.0018)
# capital_base=1000000
# # refresh_rate=1
# # benchmark = 'HS300'                        # 策略参考标准
# # universe = set_universe('HS300')           # 证券池，支持股票和基金
# # capital_base = 1000000                     # 起始资金
# # freq = 'd'
# # refresh_rate=1
#
# def initialize(account):
#     return
#
# def handle_data(account):
# #    前10天内收盘价
#     hist=account.get_attribute_history('closePrice',10)
#     histVol=account.get_attribute_history('turnoverVol',10)
#     for s in account.universe:
# #      MA3 Gold Cross   buy it
#       if  (hist[s][-3]+hist[s][-2]+hist[s][-1])/3-(hist[s][-5]+hist[s][-4]+hist[s][-3]+hist[s][-2]+hist[s][-1])/5>0 and(hist[s][-3]+hist[s][-2]+hist[s][-4])/3-(hist[s][-5]+hist[s][-4]+hist[s][-3]+hist[s][-2] +hist[s][-6])/5<0 and histVol[s][-2]<0.5* histVol[s][-1] and s not in account.valid_secpos:
#         order(s,30000)
# #     MA3 Dead Cross    sell it
#       elif  (hist[s][-3]+hist[s][-2]+hist[s][-1])/3-(hist[s][-5]+hist[s][-4]+hist[s][-3]+hist[s][-2]+hist[s][-1])/5<0 and (hist[s][-3]+hist[s][-2]+hist[s][-4])/3-(hist[s][-5]+hist[s][-4]+hist[s][-3]+hist[s][-2]+hist[s][-6])/5>0 and s in account.valid_secpos:
#         if hist[s][-1]/hist[s][-2]-1<-0.04:
#             order_to(s,0)
