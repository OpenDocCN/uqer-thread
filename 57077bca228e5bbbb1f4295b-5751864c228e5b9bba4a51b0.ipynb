# %% [markdown]
# # 小市值,最简单的策略，大神们请来点评一下。

# %% [raw]
# import pandas as pd
# import numpy as np
# from CAL.PyCAL import *
# start = '2015-09-01'                       # 回测起始时间
# end = '2016-04-07'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = StockScreener(Factor.LCAP.nsmall(50))  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     choicenum = 7
#
# def handle_data(account):    # 每个交易日的买入卖出指令
#     choicenum = 7
#     open_price = account.get_attribute_history('openPrice', 1)    # 前一日开盘价
#     close_price = account.referencePrice                   # 前一日收盘价
#
#     date=account.current_date.strftime("%Y-%m-%d")
#     cal = Calendar('China.SSE')
#     last_day = cal.advanceDate(date,'-1B',BizDayConvention.Preceding).strftime("%Y%m%d")            #计算出倒数第一个交易日
#     mkt_value = DataAPI.MktEqudGet(secID=account.universe,tradeDate=last_day,field="secID,negMarketValue",pandas="1")
#     sec_list = mkt_value.sort('negMarketValue').secID.head(choicenum).tolist()
#     buylist = {sec: 0 for sec in sec_list}
#
#
#     for s in account.valid_secpos:
#         if s not in buylist:
#             order_to(s, 0)
#
#     v = account.cash / choicenum
#     for s in buylist:
#         buylist[s] = int(v / close_price[s])
#
#     for s in sorted(buylist, key=buylist.get):
#         order(s, buylist[s])

# %%
sorted?
