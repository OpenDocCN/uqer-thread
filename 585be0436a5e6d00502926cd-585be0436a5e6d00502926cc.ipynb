# %% [markdown]
# # Notebook

# %% [raw]
# start = '2016-01-01'                       # 回测起始时间
# end = '2016-12-12'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = set_universe('A')  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'm'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     for stk in account.avail_secpos:
#         order_to(stk,0)
#
#     df_price = DataAPI.MktEqudGet(tradeDate=account.current_date,secID=account.universe,field=u"secID,openPrice,closePrice,turnoverRate",pandas="1")
#     df_upLimit = DataAPI.MktLimitGet(secID=account.universe,tradeDate=account.current_date,field=u"secID,upLimitReachedTimes,limitUpPrice",pandas="1")
#     df_upLimit = df_upLimit[df_upLimit['upLimitReachedTimes'] >= 1]
#     df_flow=DataAPI.MktEquFlowGet(tradeDate=account.current_date,secID=account.universe,ticker=u"",beginDate=u"",endDate=u"",field=u"",pandas="1")
#     df_flow=df_flow[df_flow['netMoneyInflow']>0]
#     df_flow=df_flow.set_index(['secID'])
#     df_price = df_price.set_index(['secID'])
#     df_upLimit = df_upLimit.set_index(['secID'])
#
#     df_miprice=DataAPI.MktBarRTIntraDayGet(securityID=u"000001.XSHE",startTime=u"",endTime=u"",unit=u"",pandas="1")
#
#     buy_list = []
#     for stk in df_upLimit.index:
#         if stk in df_flow.index and df_price.ix[stk]['turnoverRate']<0.15 and df_price.ix[stk]['turnoverRate']>0.01:
#             buy_list.append(stk)
#
#     for stk in buy_list:
#         order_to(stk,int(account.referencePortfolioValue / len(buy_list) / account.referencePrice[stk] / 100)*100,price=df_upLimit.ix[stk]['limitUpPrice'])
