# %% [markdown]
# # Notebook1

# %%
data1 = DataAPI.MktIdxdGet(indexID=u"",ticker=u"399635",beginDate=u"20120812",endDate=u"2018-02-07",exchangeCD=u"XSHE,XSHG",field=u"",pandas="1")
data1['preCloseIndex'].plot(figsize=(14,8),color = 'y')
data2 = DataAPI.MktIdxdGet(indexID=u"",ticker=u"000016",beginDate=u"20120812",endDate=u"2018-02-07",exchangeCD=u"XSHE,XSHG",field=u"",pandas="1")
data2['preCloseIndex'].plot(figsize=(14,8))

# %% [markdown]
# 两个指数都是调整了四波，而且创业板创新低
# 突然感觉两把剪刀好对称
# 特作此图纪念今日上证50大跌/2018/2/7
