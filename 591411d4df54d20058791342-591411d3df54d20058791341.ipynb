# %% [markdown]
# # 数据问题

# %%
import numpy as np
import pandas as pd
import datetime
date = datetime.datetime.today()

# %%
universe = set_universe('A')

# %%
margin_factor = DataAPI.FdmtIndiRtnPitGet(secID=universe,endDate=date,reportType='A',field=['secID', 'endDate', 'grossMARgin'],pandas="1")

# %%
margin_factor
# Out:
#              secID     endDate  grossMARgin
# 0      000001.XSHE  2016-12-31      27.6461
# 1      000001.XSHE  2015-12-31      30.0479
# 2      000001.XSHE  2015-12-31      30.0479
# 3      000001.XSHE  2014-12-31      35.7541
# 4      000001.XSHE  2014-12-31      35.7541
# 5      000001.XSHE  2013-12-31      38.2360
# 6      000001.XSHE  2013-12-31      38.2360
# 7      000001.XSHE  2012-12-31      44.1344
# 8      000001.XSHE  2012-12-31      44.1315
# 9      000001.XSHE  2011-12-31      44.3028
# 10     000001.XSHE  2011-12-31      44.3028
# 11     000001.XSHE  2010-12-31      43.4011
# 12     000001.XSHE  2010-12-31      43.5547
# 13     000001.XSHE  2009-12-31      40.7500
# 14     000001.XSHE  2009-12-31      40.7500
# 15     000001.XSHE  2008-12-31       5.5359
# 16     000001.XSHE  2008-12-31       5.5359
# 17     000001.XSHE  2007-12-31      34.4385
# 18     000001.XSHE  2007-12-31      34.4385
# 19     000001.XSHE  2006-12-31      26.1073
# ...

# %%
margin_factor = DataAPI.FdmtIndiRtnGet(secID=universe,endDate=date,reportType='A',field=['secID', 'endDate', 'grossMARgin'],pandas="1")
margin_factor.pivot(index='endDate', columns='secID', values='grossMARgin')
# Out:
# secID       000001.XSHE  000002.XSHE  000004.XSHE  000005.XSHE  000006.XSHE  \
# endDate
# 2007-12-31      34.4385      41.9946      38.8608      62.9122      55.7061
# 2008-12-31       5.5359      38.9993      46.7251      56.4775      68.1430
# 2009-12-31      40.7500      29.3903      50.2098      19.5247      38.9411
# 2010-12-31      43.4011      40.6996      40.6024      43.2933      39.6105
# 2011-12-31      44.3028      39.7792      50.8275       4.8615      52.3737
# 2012-12-31      44.1344      36.5555      45.4831      35.4961      44.1615
# 2013-12-31      38.2360      31.4736      52.5037      25.3506      33.2134
# 2014-12-21          NaN          NaN          NaN          NaN          NaN
# 2014-12-27          NaN          NaN          NaN          NaN          NaN
# 2014-12-28          NaN          NaN          NaN          NaN          NaN
# 2014-12-31      35.7541      29.9416      38.7548      26.2421      36.5552
# ...

# %%
# Out:
#              secID     endDate  grossMARgin
# 0      000001.XSHE  2016-12-31      27.6461
# 1      000001.XSHE  2015-12-31      30.0479
# 2      000001.XSHE  2014-12-31      35.7541
# 3      000001.XSHE  2013-12-31      38.2360
# 4      000001.XSHE  2012-12-31      44.1344
# 5      000001.XSHE  2011-12-31      44.3028
# 6      000001.XSHE  2010-12-31      43.4011
# 7      000001.XSHE  2009-12-31      40.7500
# 8      000001.XSHE  2008-12-31       5.5359
# 9      000001.XSHE  2007-12-31      34.4385
# 10     000002.XSHE  2016-12-31      29.4144
# 11     000002.XSHE  2015-12-31      29.3525
# 12     000002.XSHE  2014-12-31      29.9416
# 13     000002.XSHE  2013-12-31      31.4736
# 14     000002.XSHE  2012-12-31      36.5555
# 15     000002.XSHE  2011-12-31      39.7792
# 16     000002.XSHE  2010-12-31      40.6996
# 17     000002.XSHE  2009-12-31      29.3903
# 18     000002.XSHE  2008-12-31      38.9993
# 19     000002.XSHE  2007-12-31      41.9946
# ...
