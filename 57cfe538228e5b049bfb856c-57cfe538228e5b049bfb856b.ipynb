# %% [markdown]
# #

# %% [markdown]
# ### 优矿的一些经典帖子整理哦，默认按照 克隆 -> 浏览数 排序的

# %%
import pandas as pd
pd.options.display.max_rows = 500
# Out:
# line_width has been deprecated, use display.width instead (currently both are
# identical)

# %%
file_name = '优矿好贴_你值得拥有哦～.xlsx'

# %%
df = pd.read_excel(file_name)
df.head(100)
# Out:
#           author  browse_count  collect_count  comment_count  \
# 29        linius         19283            325            165
# 37           孙新华          8653            121             80
# 2       薛昆Kelvin         60225            328             76
# 47           陈亚龙          6680             78            105
# 10           陈亚龙          6965             97            100
# 2       薛昆Kelvin         22100            143             82
# 40      薛昆Kelvin         31674            167             65
# 26    zbaxrl2000          4378             63             33
# 27          call          6501            123            130
# 48      薛昆Kelvin         13526            111             97
# 4       薛昆Kelvin         17551            139             39
# 3       薛昆Kelvin          2948             32             29
# 26      薛昆Kelvin         22988            139             43
# 47      薛昆Kelvin         18952            128             63
# ...

# %% [markdown]
# 数据文件：[优矿好贴_你值得拥有哦～.xlsx](https://pan.baidu.com/s/1geH8LNH)
