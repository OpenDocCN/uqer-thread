# %% [markdown]
# # Notebook3

# %% [raw]
# start = '2021-1-01'                       # 回测起始时间
# end = '2021-06-25'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['601899.XSHG']  # 证券池，支持股票和基金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=99999)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     pass
#
# def handle_data(context):                  # 每个交易日的买入卖出指令
#     account = context.get_account('fantasy_account')
#     hist = context.get_attribute_history('closePrice', 20)
#     print hist
#     for stk in context.universe:
#         ma5 = hist[stk][-5:].mean()
#         ma20 = hist[stk][:].mean()
#
#         if ma5 > ma20 and stk not in account.security_position:
#             order(stk, 10000)
#         elif ma5 < ma20 and stk in account.security_position:
#             order_to(stk, 0)
