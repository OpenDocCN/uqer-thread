# %% [markdown]
# # Notebook9

# %%
GDP = DataAPI.ChinaDataGDPGet(indicID=u"M010000004",indicName=u"",beginDate=u"",endDate=u"",field=u"",pandas="1")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <mercury-input-2-12AED24B0FD04E2BA7C6AAD3CB8EFAB8> in <module>()
# ----> 1 GDP = DataAPI.ChinaDataGDPGet(indicID=u"M010000004",indicName=u"",beginDate=u"",endDate=u"",field=u"",pandas="1")
#
# /home/ipython/anaconda/lib/python2.7/site-packages/DataAPI/DATAYES.pyc in ChinaDataGDPGet(indicID, indicName, beginDate, endDate, field, pandas)
#   52419         csvString = api_base.__getCSV__(''.join(requestString), httpClient, gw=False)
#   52420         if csvString is None or len(csvString) == 0 or (csvString[0] == '-' and not api_base.is_no_data_warn(csvString, False)) or csvString[0] == '{':
# > 52421             api_base.handle_error(csvString, 625)
#   52422         elif csvString[:2] == '-1':
#   52423             csvString = ''
#
# ...
