# %% [markdown]
# # hs300稳态价值投资

# %% [raw]
# start = '2016-01-01'                       # 回测起始时间
# end = '2017-11-09'                         # 回测结束时间
# universe = DynamicUniverse('HS300')        # 证券池，支持股票和基金、期货
# benchmark = 'HS300'                        # 策略参考基准
# freq = 'd'                                 # 'd'表示使用日频率回测，'m'表示使用分钟频率回测
# refresh_rate = 1                           # 执行handle_data的时间间隔
# from time import sleep
#
# lcg_price_gap=-3
# pb_gap=2
# stable_gap=1
#
# accounts = {
#     'fantasy_account': AccountConfig(account_type='security', capital_base=1000000)
# }
#
# def initialize(context):                   # 初始化策略运行环境
#     a = Signal('PE')
#     b = Signal('PB')
#     context.signal_generator = SignalGenerator(a, b)
#     pass
#
# def isStable(data):
#     global stable_gap
#     for idx in range(4):
#         pct_change=data[-(idx+1)]
#         if -stable_gap<pct_change<stable_gap:
#             pass
#         else:
#             return False
#     #print(data)
#     return True
#
#
#
# def handle_data(context):                  # 核心策略逻辑
#     global lcg_price_gap,pb_gap
#     account = context.get_account('fantasy_account')
#     cur_date=context.current_date
#     universe = context.get_universe(exclude_halt=True)
#     data = context.history(universe, ['closePrice','PB','PE'], 5, freq='1d', rtype='frame',   style='sat')
#     for stock in universe:
#         data[stock]['pct_change']=(data[stock]['closePrice']/data[stock]['closePrice'].shift(1)-1)*100
#         priceColum = data[stock]['closePrice']
#         pb = data[stock]['PB']
#         #data['cc']=data['closePrice']/data['closePrice'].shift(1)-1
#         if pb[-1]<pb_gap and isStable(data[stock]['pct_change']):
#             account.order(stock, 2000)
#             #print('cur_date %s,stock %s' % (cur_date,stock))
