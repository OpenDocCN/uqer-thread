# %% [markdown]
# # 求助-2

# %%
import pandas as pd
from pandas import DataFrame
T=DataAPI.MktStockFactorsDateRangeGet('600000.XSHG', beginDate='20120101', endDate='20150801', field=['tradeDate', 'PE']).tail(10)
S=DataAPI.MktStockFactorsDateRangeGet('600000.XSHG',beginDate='20120101',endDate='20150815',field=['tradeDate','ROE']).tail(10)
dat = T.merge(S, on=['PE','ROE'])
print dat.head()
