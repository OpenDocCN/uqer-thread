# %% [markdown]
# # 为什么MACD的今天的值明天再用时变了？

# %% [raw]
# from CAL.PyCAL import *
# import pandas as pd
# import numpy as np
# import talib
# short_win = 12         # 短期EMA平滑天数
# long_win  = 29         # 长期EMA平滑天数
# macd_win  = 39         # DEA线平滑天数
# longest_history =90      # 窗口宽度90天
# stkname="399006"
#
# start = '2014-01-01'                       # 回测起始时间
# end = '2015-01-01'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe = ['000001.XSHE', '600000.XSHG']  # 证券池，支持股票和基金
# capital_base = 100000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                           # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     dateend=Date.fromDateTime(account.previous_date)
#     datebegin="20"+(dateend+Period('-120D')).strftime('%y-%m-%d')
#     Acloseprices = DataAPI.MktIdxdGet(tradeDate=u"",indexID=u"",ticker=stkname,beginDate=datebegin,endDate=dateend,field=u'secID,secShortName,closeIndex')
#     prices=np.array(Acloseprices['closeIndex'])
#     macd_tmp = talib.MACD(prices, fastperiod=short_win, slowperiod=long_win, signalperiod=macd_win)    #构建MACD线数组
#     DIF = macd_tmp[0]                #返回结果是三条线的数据
#     DEA = macd_tmp[1]
#     MACD = macd_tmp[2]
#     print dateend,MACD[-10],MACD[-9],MACD[-8],MACD[-7],MACD[-6],MACD[-5],MACD[-4],MACD[-3],MACD[-2],MACD[-1]
