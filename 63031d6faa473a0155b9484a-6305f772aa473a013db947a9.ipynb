# %% [markdown]
# # 【社区免费版变动通知】

# %% [markdown]
# 各位矿友，大家好！
# <br/>
# 岁月如歌，跋涉似舞。优矿自2015年6月18日正式推出以来，一直致力于提升用户的体验，经过多年积累，收获了20W+的注册用户，得到了行业内使用者的一致认可。饮水思源，优矿每一点进步和成功都离不开广大用户的关注、信任、支持和参与，你们的理解和信任是我们成长的强大动力。
# <br/>
#
# 伴随着用户量的急剧增加，我们的后台资源很难做到同步增长。在此，很抱歉的告知各位，我们将于2022-08-27对社区免费版进行一定的调整，主要是数据接口方面，具体为：以股票数据为主体，保留了基本量化回测的必要数据；剔除了财务PIT等深度数据；同时对债券、基金、期货期权、行业、智能数据等模块做了缩减。调整后，数据接口仍保留120+个，200个常规量化因子仍免费提供给各位矿友们使用。

# %% [markdown]
# 若您有更高级的研究需求，可以考虑我们即将推出的新版本——极速版。极速版相对社区免费版有以下优点：更多的数据接口、额外的30个量化因子、因子分析报告/因子分析类库/基金分析类库等更多的功能、更大的内存配置，而且您可以根据自己的需求更灵活地选择相应的数据包和功能模块。最后，优矿提供的付费SDK功能可以随同任何版本一起开通，包括极速版。
# <br/>
# 极速版和社区版几点重要区别如下：
# |  功能配置   | 社区免费版  | 极速版|
# |  ----      | ----  |----  |
# | 因子分析报告  | - |√  |
# | 因子分析类库  | - |√  |
# | 基金分析类库  | - |√  |
# | 策略模拟交易个数  | 3 |5  |
# | 模拟交易信号微信推送  | - |√  |
# | 研究环境内存  | 1G |4G  |
# | notebook运行个数  | 5 |10  |
# | 数据接口数量  | 120+ |240+  |

# %% [markdown]
# 最后，再次感谢您在过去的日子里对我们的支持和厚爱，我们后期仍将会致力于做好社区免费版的维护工作，为新老客户创造持续价值，也愿我们携手共进、共创辉煌！
#
# 如有任何疑问，请联系客户服务邮箱（service.uqer@datayes.com）或4000-820-386，或通过https://uqer.datayes.com/pro/#form 申请专业版（极速版或者其他更高级版本）试用权限。
#
# 感谢！您的理解和支持是我们持续进步的动力！
# PS: 近期参加模拟策略大赛的用户，可以通过邮箱（service.uqer@datayes.com）联系我们临时增加这些API数据的权限。
