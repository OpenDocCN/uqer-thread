# %% [markdown]
# # Notebook

# %%
DataAPI.MktEqudGet(secID=u"",ticker=u"688001",tradeDate=u"20190723",beginDate=u"",endDate=u"",isOpen="",field=u"",pandas="1")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <mercury-input-8-C7D6D7207EA84F9E8DA8C267E9535FDF> in <module>()
# ----> 1 DataAPI.MktEqudGet(secID=u"",ticker=u"688001",tradeDate=u"20190723",beginDate=u"",endDate=u"",isOpen="",field=u"",pandas="1")
#
# AttributeError: 'module' object has no attribute 'MktEqudGet'
