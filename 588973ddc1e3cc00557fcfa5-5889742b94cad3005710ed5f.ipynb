# %% [markdown]
# # 数据纠错

# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import talib
import math 
import lib.hanshu as hanshu
begin="2015-01-01"
end="2015-03-15"
benchmark="NDX.ZIUS"
benchmark0=DataAPI.MktIdxdGet(tradeDate=u"",indexID=benchmark,ticker=u"",beginDate=begin,endDate=end,field=u"tradeDate,closeIndex,precloseIndex",pandas="1")
benchmark0=hanshu.indexzh(benchmark0)
benchmark0=hanshu.zhangdiefu(benchmark0)
benchmark0=benchmark0.set_index("tradeDate")
print benchmark0
benchmark0["holding"].plot(legend=True,figsize=(14,6))
# Out:
#             closePrice  preClosePrice  zhangdiefu  returnrate   holding
# tradeDate
# 2015-01-01     4293.67        4236.28    1.013547    0.013547  1.013547
# 2015-01-02     4230.24        4293.67    0.985227   -0.014773  0.998574
# 2015-01-05     4160.96        4230.24    0.983623   -0.016377  0.982220
# 2015-01-06     4110.83        4160.96    0.987952   -0.012048  0.970387
# 2015-01-07     4160.00        4110.83    1.011961    0.011961  0.981994
# 2015-01-08     4240.55        4160.00    1.019363    0.019363  1.001008
# 2015-01-09     4213.28        4240.55    0.993569   -0.006431  0.994571
# 2015-01-12     4169.97        4213.28    0.989721   -0.010279  0.984347
# 2015-01-13     4166.20        4169.97    0.999096   -0.000904  0.983457
# 2015-01-14     4145.84        4166.20    0.995113   -0.004887  0.978651
# 2015-01-15     4089.65        4145.84    0.986447   -0.013553  0.965387
# 2015-01-16     4142.14        4089.65    1.012835    0.012835  0.977778
# ...
